# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
LinkIndoor200mWomen = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?sport=1&gender=2&div=20527&top=25&event=3"

# %%
page = requests.get(LinkIndoor200mWomen)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7087489" target="_blank">(1) Julien ALFRED</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.01</a><a href="https://www.youtube.com/watch?v=ayEai3o33lA" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7087489" target="_blank">(1) Julien ALFRED</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.01</a><a href="https://www.youtube.com/watch?v=ayEai3o33lA" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6995396" target="_blank">(2) Abby STEINER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72951/4389463" target="_blank">22.09</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/26/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6995396" target="_blank">(2) Abby STEINER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72951/4389463" target="_blank">22.09</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/26/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729916" target="_blank">(3) Favour OFILI</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.11</a><a href="https://www.youtube.com/watch?v=k5zm1YIRCF0&amp;list=PL9WSsnpWNE8NiGBTkrzMZgJEYeRqp5AGR&amp;index=42" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729916" target="_blank">(3) Favour OFILI</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.11</a><a href="https://www.youtube.com/watch?v=k5zm1YIRCF0&amp;list=PL9WSsnpWNE8NiGBTkrzMZgJEYeRqp5AGR&amp;index=42" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Steiner {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416348" target="_blank">22.16</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Steiner {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416348" target="_blank">22.16</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Ofili {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.20</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Ofili {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.20</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77924/4693816" target="_blank">22.26</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77924/4693816" target="_blank">22.26</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Ofili {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76074/4669409" target="_blank">22.36</a> </td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Ofili {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76074/4669409" target="_blank">22.36</a> </td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Steiner {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/71626/4370125" target="_blank">22.37</a><a href="https://youtu.be/K5E4NUSL4XM" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Tiger Paw Invitational (Clemson, S.C.)"><span class="mark-date" style="width: 10%;text-align:right;">2/12/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Steiner {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/71626/4370125" target="_blank">22.37</a><a href="https://youtu.be/K5E4NUSL4XM" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Tiger Paw Invitational (Clemson, S.C.)"><span class="mark-date" style="width: 10%;text-align:right;">2/12/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.38</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.38</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Steiner {4}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118004" target="_blank">22.38</a><a href="https://www.youtube.com/watch?v=wxkEJd_u6VE" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Steiner {4}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118004" target="_blank">22.38</a><a href="https://www.youtube.com/watch?v=wxkEJd_u6VE" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5588173" target="_blank">(4) Gabby THOMAS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Harvard" class="group-logo-inline" src="/images/logos/rankings-article/harvard.png" title="Harvard"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=635">Harvard</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335558" target="_blank">22.38</a><a href="https://www.youtube.com/watch?v=2IhPv3BzRJw" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5588173" target="_blank">(4) Gabby THOMAS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Harvard" class="group-logo-inline" src="/images/logos/rankings-article/harvard.png" title="Harvard"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=635">Harvard</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335558" target="_blank">22.38</a><a href="https://www.youtube.com/watch?v=2IhPv3BzRJw" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(5) Bianca KNIGHT</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1558">Texas</a></td><td style="width: 25%;">22.40  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/14/2008</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(5) Bianca KNIGHT</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1558">Texas</a></td><td style="width: 25%;">22.40  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/14/2008</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Steiner {5}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67216/4090218" target="_blank">22.41</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Steiner {5}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67216/4090218" target="_blank">22.41</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5104436" target="_blank">(6) Ashley HENDERSON</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="San Diego State" class="group-logo-inline" src="/images/logos/rankings-article/san-diego-state.png" title="San Diego State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1354">San Diego State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335558" target="_blank">22.41</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5104436" target="_blank">(6) Ashley HENDERSON</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="San Diego State" class="group-logo-inline" src="/images/logos/rankings-article/san-diego-state.png" title="San Diego State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1354">San Diego State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335558" target="_blank">22.41</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8235208" target="_blank">(7) Autumn WILSON</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.42</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8235208" target="_blank">(7) Autumn WILSON</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.42</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113695" target="_blank">(7) Ariana WASHINGTON</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567/3023722" target="_blank">22.42</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113695" target="_blank">(7) Ariana WASHINGTON</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567/3023722" target="_blank">22.42</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(9) Veronica CAMPBELL</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=59">Arkansas</a></td><td style="width: 25%;">22.43  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2004</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(9) Veronica CAMPBELL</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=59">Arkansas</a></td><td style="width: 25%;">22.43  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2004</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Steiner {6}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72951/4389463" target="_blank">22.44</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/26/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Steiner {6}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72951/4389463" target="_blank">22.44</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/26/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.45</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.45</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Steiner {7}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416348" target="_blank">22.45</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Steiner {7}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416348" target="_blank">22.45</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6534261" target="_blank">(10) Tamara CLARK</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118004" target="_blank">22.45</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6534261" target="_blank">(10) Tamara CLARK</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118004" target="_blank">22.45</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4211980" target="_blank">(10) Felicia BROWN</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/43054" target="_blank">22.45</a> <span class="tooltip" style="font-size: smaller;">b<span class="tooltiptext" style="font-size: smaller;">b = Performance occurred on a 200m/220yd banked track</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/27/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4211980" target="_blank">(10) Felicia BROWN</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/43054" target="_blank">22.45</a> <span class="tooltip" style="font-size: smaller;">b<span class="tooltiptext" style="font-size: smaller;">b = Performance occurred on a 200m/220yd banked track</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/27/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Ofili {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72951/4389463" target="_blank">22.46</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/26/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Ofili {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72951/4389463" target="_blank">22.46</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/26/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Brown {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702410" target="_blank">22.47</a><a href="https://www.youtube.com/watch?v=TNSfU5L3DMs&amp;list=PL9WSsnpWNE8NiGBTkrzMZgJEYeRqp5AGR&amp;index=60" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">b<span class="tooltiptext" style="font-size: smaller;">b = Performance occurred on a 200m/220yd banked track</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Brown {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702410" target="_blank">22.47</a><a href="https://www.youtube.com/watch?v=TNSfU5L3DMs&amp;list=PL9WSsnpWNE8NiGBTkrzMZgJEYeRqp5AGR&amp;index=60" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">b<span class="tooltiptext" style="font-size: smaller;">b = Performance occurred on a 200m/220yd banked track</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6985778" target="_blank">(12) McKenzie LONG</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Ole Miss" class="group-logo-inline" src="/images/logos/rankings-article/ole-miss.png" title="Ole Miss"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=983">Ole Miss</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.48</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
# ...
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7722969" target="_blank">(25) Jadyn MAYS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.58</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7722969" target="_blank">(25) Jadyn MAYS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720937" target="_blank">22.58</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Duncan {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/29008" target="_blank">22.58</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/8/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Duncan {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/29008" target="_blank">22.58</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/8/2013</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(25) Kerron STEWART</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=74">Auburn</a></td><td style="width: 25%;">22.58  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2007</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(25) Kerron STEWART</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=74">Auburn</a></td><td style="width: 25%;">22.58  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2007</span></td></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">Additional All-Conditions Bests</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6586400" target="_blank">Anavia BATTLE</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Ohio State" class="group-logo-inline" src="/images/logos/rankings-article/ohio-state.png" title="Ohio State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1162">Ohio State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72148/4390284" target="_blank">22.39</a> <span class="tooltip" style="font-size: smaller;">OT<span class="tooltiptext" style="font-size: smaller;">OT = Performance occurred on an oversized-track (&gt;200 meters/220 yards)</span></span> </td><td style="width: 10%;text-align:right;" title="Big Ten Indoor Championships (Geneva, Ohio)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6586400" target="_blank">Anavia BATTLE</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Ohio State" class="group-logo-inline" src="/images/logos/rankings-article/ohio-state.png" title="Ohio State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1162">Ohio State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72148/4390284" target="_blank">22.39</a> <span class="tooltip" style="font-size: smaller;">OT<span class="tooltiptext" style="font-size: smaller;">OT = Performance occurred on an oversized-track (&gt;200 meters/220 yards)</span></span> </td><td style="width: 10%;text-align:right;" title="Big Ten Indoor Championships (Geneva, Ohio)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Kerron STEWART</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=74">Auburn</a></td><td style="width: 25%;">22.46 <span class="tooltip" style="font-size: smaller;">OT<span class="tooltiptext" style="font-size: smaller;">OT = Performance occurred on an oversized-track (&gt;200 meters/220 yards)</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2007</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Kerron STEWART</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=74">Auburn</a></td><td style="width: 25%;">22.46 <span class="tooltip" style="font-size: smaller;">OT<span class="tooltiptext" style="font-size: smaller;">OT = Performance occurred on an oversized-track (&gt;200 meters/220 yards)</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2007</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6995396" target="_blank">Abby STEINER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70606/4335106" target="_blank">22.58</a> <span class="tooltip" style="font-size: smaller;">OT<span class="tooltiptext" style="font-size: smaller;">OT = Performance occurred on an oversized-track (&gt;200 meters/220 yards)</span></span> </td><td style="width: 10%;text-align:right;" title="Jim Green Invitational (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">1/15/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6995396" target="_blank">Abby STEINER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70606/4335106" target="_blank">22.58</a> <span class="tooltip" style="font-size: smaller;">OT<span class="tooltiptext" style="font-size: smaller;">OT = Performance occurred on an oversized-track (&gt;200 meters/220 yards)</span></span> </td><td style="width: 10%;text-align:right;" title="Jim Green Invitational (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">1/15/2022</span></td></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">Not Considered For Lists</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5640215" target="_blank">Deajah STEVENS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567/3023722" target="_blank">22.28</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2017</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     DQ for lane violation</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5640215" target="_blank">Deajah STEVENS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567/3023722" target="_blank">22.28</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2017</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     DQ for lane violation</td></tr>,
#  <tr><td class="group-logo-50"><a href="https://allathletics.tv/?utc_source=ustfccca&amp;utc_medium=web&amp;utc_campaign=broadcast_schedule_sidebar" target="_blank"><img alt="eaa" src="/images/logos/rankings-article/eaa.png" title="EAA"/></a></td><td style="line-height: 1em;"><a href="https://allathletics.tv/?utc_source=ustfccca&amp;utc_medium=web&amp;utc_campaign=broadcast_schedule_sidebar" target="_blank">European U20 Championships</a></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Julien ALFREDSRTexas22.01📺 3/11/2023',
#   '(1) Julien ALFREDSR',
#   '',
#   'Texas',
#   '22.01📺 ',
#   '3/11/2023'],
#  [],
#  ['(1) Julien ALFREDSR', '', 'Texas', '22.01📺 ', '3/11/2023'],
#  ['(2) Abby STEINERJRKentucky22.09 2/26/2022',
#   '(2) Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.09 ',
#   '2/26/2022'],
#  [],
#  ['(2) Abby STEINERJR', '', 'Kentucky', '22.09 ', '2/26/2022'],
#  ['(3) Favour OFILIJRLSU22.11📺 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(3) Favour OFILIJR',
#   '',
#   'LSU',
#   '22.11📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['(3) Favour OFILIJR',
#   '',
#   'LSU',
#   '22.11📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JRKentucky22.16 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '22.16 ',
#   '3/12/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JR', '', 'Kentucky', '22.16 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}JRLSU22.20 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {2}JR',
#   '',
#   'LSU',
#   '22.20 ',
#   '3/11/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}JR', '', 'LSU', '22.20 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}SRTexas22.26 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {2}SR',
#   '',
#   'Texas',
#   '22.26 ',
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}SR', '', 'Texas', '22.26 ', '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Ofili {3}JRLSU22.36 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {3}JR',
#   '',
#   'LSU',
#   '22.36 ',
#   '2/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {3}JR', '', 'LSU', '22.36 ', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JRKentucky22.37📺 2/12/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {3}JR',
#   '',
#   'Kentucky',
#   '22.37📺 ',
#   '2/12/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JR', '', 'Kentucky', '22.37📺 ', '2/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}SRTexas22.38 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {3}SR',
#   '',
#   'Texas',
#   '22.38 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}SR',
#   '',
#   'Texas',
#   '22.38 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {4}JRKentucky22.38📺 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Steiner {4}JR',
#   '',
#   'Kentucky',
#   '22.38📺 ',
#   '3/13/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {4}JR', '', 'Kentucky', '22.38📺 ', '3/13/2021'],
#  ['(4) Gabby THOMASJRHarvard22.38📺 3/10/2018',
#   '(4) Gabby THOMASJR',
#   '',
#   'Harvard',
#   '22.38📺 ',
#   '3/10/2018'],
#  [],
#  ['(4) Gabby THOMASJR', '', 'Harvard', '22.38📺 ', '3/10/2018'],
#  ['(5) Bianca KNIGHTFRTexas22.40  3/14/2008',
#   '(5) Bianca KNIGHTFR',
#   '',
#   'Texas',
#   '22.40  ',
#   '3/14/2008'],
#  [],
#  ['(5) Bianca KNIGHTFR', '', 'Texas', '22.40  ', '3/14/2008'],
#  ['\xa0\xa0\xa0\xa0— Steiner {5}JRKentucky22.41 qq = Performance occurred during a non-final round. 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Steiner {5}JR',
#   '',
#   'Kentucky',
#   '22.41 qq = Performance occurred during a non-final round. ',
#   '2/25/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {5}JR',
#   '',
#   'Kentucky',
#   '22.41 qq = Performance occurred during a non-final round. ',
#   '2/25/2021'],
#  ['(6) Ashley HENDERSONSRSan Diego State22.41 3/10/2018',
#   '(6) Ashley HENDERSONSR',
#   '',
#   'San Diego State',
#   '22.41 ',
#   '3/10/2018'],
#  [],
#  ['(6) Ashley HENDERSONSR', '', 'San Diego State', '22.41 ', '3/10/2018'],
#  ['(7) Autumn WILSONFRGeorgia22.42 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(7) Autumn WILSONFR',
#   '',
#   'Georgia',
#   '22.42 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['(7) Autumn WILSONFR',
#   '',
#   'Georgia',
#   '22.42 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(7) Ariana WASHINGTONJROregon22.42 3/11/2017',
#   '(7) Ariana WASHINGTONJR',
#   '',
#   'Oregon',
#   '22.42 ',
#   '3/11/2017'],
#  [],
#  ['(7) Ariana WASHINGTONJR', '', 'Oregon', '22.42 ', '3/11/2017'],
#  ['(9) Veronica CAMPBELLJRArkansas22.43  3/12/2004',
#   '(9) Veronica CAMPBELLJR',
#   '',
#   'Arkansas',
#   '22.43  ',
#   '3/12/2004'],
#  [],
#  ['(9) Veronica CAMPBELLJR', '', 'Arkansas', '22.43  ', '3/12/2004'],
#  ['\xa0\xa0\xa0\xa0— Steiner {6}JRKentucky22.44 2/26/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {6}JR',
#   '',
#   'Kentucky',
#   '22.44 ',
#   '2/26/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {6}JR', '', 'Kentucky', '22.44 ', '2/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}FRGeorgia22.45 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}FR',
#   '',
#   'Georgia',
#   '22.45 ',
#   '3/11/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}FR', '', 'Georgia', '22.45 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {7}JRKentucky22.45 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {7}JR',
#   '',
#   'Kentucky',
#   '22.45 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {7}JR',
#   '',
#   'Kentucky',
#   '22.45 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(10) Tamara CLARKSRAlabama22.45 3/13/2021',
#   '(10) Tamara CLARKSR',
#   '',
#   'Alabama',
#   '22.45 ',
#   '3/13/2021'],
#  [],
#  ['(10) Tamara CLARKSR', '', 'Alabama', '22.45 ', '3/13/2021'],
#  ['(10) Felicia BROWNSRTennessee22.45 bb = Performance occurred on a 200m/220yd banked track 2/27/2016',
#   '(10) Felicia BROWNSR',
#   '',
#   'Tennessee',
#   '22.45 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/27/2016'],
#  [],
#  ['(10) Felicia BROWNSR',
#   '',
#   'Tennessee',
#   '22.45 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/27/2016'],
#  ['\xa0\xa0\xa0\xa0— Ofili {4}SOLSU22.46 2/26/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {4}SO',
#   '',
#   'LSU',
#   '22.46 ',
#   '2/26/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {4}SO', '', 'LSU', '22.46 ', '2/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Brown {2}SRTennessee22.47📺 bb = Performance occurred on a 200m/220yd banked track 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Brown {2}SR',
#   '',
#   'Tennessee',
#   '22.47📺 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/12/2016'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Brown {2}SR',
#   '',
#   'Tennessee',
#   '22.47📺 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/12/2016'],
#  ['(12) McKenzie LONGSROle Miss22.48 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(12) McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '22.48 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['(12) McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '22.48 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Knight {2}FRTexas22.48 qq = Performance occurred during a non-final round. 3/14/2008',
#   '\xa0\xa0\xa0\xa0— Knight {2}FR',
#   '',
#   'Texas',
#   '22.48 qq = Performance occurred during a non-final round. ',
#   '3/14/2008'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Knight {2}FR',
#   '',
#   'Texas',
#   '22.48 qq = Performance occurred during a non-final round. ',
#   '3/14/2008'],
#  ['(13) Anavia BATTLESROhio State22.49 2/18/2022',
#   '(13) Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.49 ',
#   '2/18/2022'],
#  [],
#  ['(13) Anavia BATTLESR', '', 'Ohio State', '22.49 ', '2/18/2022'],
#  ['(13) Sanya RICHARDSSOTexas22.49  3/12/2004',
#   '(13) Sanya RICHARDSSO',
#   '',
#   'Texas',
#   '22.49  ',
#   '3/12/2004'],
#  [],
#  ['(13) Sanya RICHARDSSO', '', 'Texas', '22.49  ', '3/12/2004'],
#  ['(13) Muna LEEJRLSU22.49 qq = Performance occurred during a non-final round. 3/14/2003',
#   '(13) Muna LEEJR',
#   '',
#   'LSU',
#   '22.49 qq = Performance occurred during a non-final round. ',
#   '3/14/2003'],
#  [],
#  ['(13) Muna LEEJR',
#   '',
#   'LSU',
#   '22.49 qq = Performance occurred during a non-final round. ',
#   '3/14/2003'],
#  ['\xa0\xa0\xa0\xa0— Ofili {5}SOLSU22.50 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {5}SO',
#   '',
#   'LSU',
#   '22.50 ',
#   '3/12/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {5}SO', '', 'LSU', '22.50 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {8}JRKentucky22.50 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Steiner {8}JR',
#   '',
#   'Kentucky',
#   '22.50 ',
#   '2/25/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {8}JR', '', 'Kentucky', '22.50 ', '2/25/2021'],
#  ['(16) Kamaria BROWNJRTexas A&M22.50 bb = Performance occurred on a 200m/220yd banked track 3/1/2014',
#   '(16) Kamaria BROWNJR',
#   '',
#   'Texas A&M',
#   '22.50 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/1/2014'],
#  [],
#  ['(16) Kamaria BROWNJR',
#   '',
#   'Texas A&M',
#   '22.50 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/1/2014'],
#  ['\xa0\xa0\xa0\xa0— Brown {2}JRTexas A&M22.51 qq = Performance occurred during a non-final round. 2/28/2014',
#   '\xa0\xa0\xa0\xa0— Brown {2}JR',
#   '',
#   'Texas A&M',
#   '22.51 qq = Performance occurred during a non-final round. ',
#   '2/28/2014'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Brown {2}JR',
#   '',
#   'Texas A&M',
#   '22.51 qq = Performance occurred during a non-final round. ',
#   '2/28/2014'],
#  ['\xa0\xa0\xa0\xa0— Campbell {2}JRArkansas22.51  2/13/2004',
#   '\xa0\xa0\xa0\xa0— Campbell {2}JR',
#   '',
#   'Arkansas',
#   '22.51  ',
#   '2/13/2004'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Campbell {2}JR', '', 'Arkansas', '22.51  ', '2/13/2004'],
#  ['\xa0\xa0\xa0\xa0— Ofili {6}JRLSU22.52 2/25/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {6}JR',
#   '',
#   'LSU',
#   '22.52 ',
#   '2/25/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {6}JR', '', 'LSU', '22.52 ', '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Ofili {7}JRLSU22.52 qq = Performance occurred during a non-final round. 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {7}JR',
#   '',
#   'LSU',
#   '22.52 qq = Performance occurred during a non-final round. ',
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {7}JR',
#   '',
#   'LSU',
#   '22.52 qq = Performance occurred during a non-final round. ',
#   '2/24/2023'],
#  ['(17) Rhasidat ADELEKESOTexas22.52📺 AA = Performance occurred at altitude (>1000 meters above sea level) 1/21/2023',
#   '(17) Rhasidat ADELEKESO',
#   '',
#   'Texas',
#   '22.52📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  [],
#  ['(17) Rhasidat ADELEKESO',
#   '',
#   'Texas',
#   '22.52📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {9}JRKentucky22.52 2/13/2021',
#   '\xa0\xa0\xa0\xa0— Steiner {9}JR',
#   '',
#   'Kentucky',
#   '22.52 ',
#   '2/13/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {9}JR', '', 'Kentucky', '22.52 ', '2/13/2021'],
#  ['(17) Jenna PRANDINIOregon22.52 qq = Performance occurred during a non-final round. 3/13/2015',
#   '(17) Jenna PRANDINI',
#   '',
#   'Oregon',
#   '22.52 qq = Performance occurred during a non-final round. ',
#   '3/13/2015'],
#  [],
#  ['(17) Jenna PRANDINI',
#   '',
#   'Oregon',
#   '22.52 qq = Performance occurred during a non-final round. ',
#   '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Ofili {8}JRLSU22.53 1/27/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {8}JR',
#   '',
#   'LSU',
#   '22.53 ',
#   '1/27/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {8}JR', '', 'LSU', '22.53 ', '1/27/2023'],
#  ['(19) Hannah CUNLIFFEJROregon22.53 3/11/2017',
#   '(19) Hannah CUNLIFFEJR',
#   '',
#   'Oregon',
#   '22.53 ',
#   '3/11/2017'],
#  [],
#  ['(19) Hannah CUNLIFFEJR', '', 'Oregon', '22.53 ', '3/11/2017'],
#  ['\xa0\xa0\xa0\xa0— Long {2}SROle Miss22.54 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Long {2}SR',
#   '',
#   'Ole Miss',
#   '22.54 ',
#   '3/11/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Long {2}SR', '', 'Ole Miss', '22.54 ', '3/11/2023'],
#  ['(20) Deanna HILLJRSouthern California22.54 3/11/2017',
#   '(20) Deanna HILLJR',
#   '',
#   'Southern California',
#   '22.54 ',
#   '3/11/2017'],
#  [],
#  ['(20) Deanna HILLJR', '', 'Southern California', '22.54 ', '3/11/2017'],
#  ['(20) Kimberlyn DUNCANSRLSU22.54 2/24/2013',
#   '(20) Kimberlyn DUNCANSR',
#   '',
#   'LSU',
#   '22.54 ',
#   '2/24/2013'],
#  [],
#  ['(20) Kimberlyn DUNCANSR', '', 'LSU', '22.54 ', '2/24/2013'],
#  ['\xa0\xa0\xa0\xa0— Ofili {9}JRLSU22.55 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {9}JR',
#   '',
#   'LSU',
#   '22.55 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {9}JR',
#   '',
#   'LSU',
#   '22.55 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['(22) Kynnedy FLANNELJRTexas22.55 2/26/2021',
#   '(22) Kynnedy FLANNELJR',
#   '',
#   'Texas',
#   '22.55 ',
#   '2/26/2021'],
#  [],
#  ['(22) Kynnedy FLANNELJR', '', 'Texas', '22.55 ', '2/26/2021'],
#  ['(22) Lynna IRBYFRGeorgia22.55 3/10/2018',
#   '(22) Lynna IRBYFR',
#   '',
#   'Georgia',
#   '22.55 ',
#   '3/10/2018'],
#  [],
#  ['(22) Lynna IRBYFR', '', 'Georgia', '22.55 ', '3/10/2018'],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SRTexas22.56 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {4}SR',
#   '',
#   'Texas',
#   '22.56 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SR',
#   '',
#   'Texas',
#   '22.56 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {10}SOKentucky22.57 2/29/2020',
#   '\xa0\xa0\xa0\xa0— Steiner {10}SO',
#   '',
#   'Kentucky',
#   '22.57 ',
#   '2/29/2020'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {10}SO', '', 'Kentucky', '22.57 ', '2/29/2020'],
#  ['\xa0\xa0\xa0\xa0— Washington {2}JROregon22.57 qq = Performance occurred during a non-final round. 3/10/2017',
#   '\xa0\xa0\xa0\xa0— Washington {2}JR',
#   '',
#   'Oregon',
#   '22.57 qq = Performance occurred during a non-final round. ',
#   '3/10/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Washington {2}JR',
#   '',
#   'Oregon',
#   '22.57 qq = Performance occurred during a non-final round. ',
#   '3/10/2017'],
#  ['(24) Shalonda SOLOMONSOSouth Carolina22.57  3/10/2006',
#   '(24) Shalonda SOLOMONSO',
#   '',
#   'South Carolina',
#   '22.57  ',
#   '3/10/2006'],
#  [],
#  ['(24) Shalonda SOLOMONSO', '', 'South Carolina', '22.57  ', '3/10/2006'],
#  ['(25) Jadyn MAYSSOOregon22.58 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(25) Jadyn MAYSSO',
#   '',
#   'Oregon',
#   '22.58 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['(25) Jadyn MAYSSO',
#   '',
#   'Oregon',
#   '22.58 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Duncan {2}SRLSU22.58 3/8/2013',
#   '\xa0\xa0\xa0\xa0— Duncan {2}SR',
#   '',
#   'LSU',
#   '22.58 ',
#   '3/8/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Duncan {2}SR', '', 'LSU', '22.58 ', '3/8/2013'],
#  ['(25) Kerron STEWARTSRAuburn22.58  3/9/2007',
#   '(25) Kerron STEWARTSR',
#   '',
#   'Auburn',
#   '22.58  ',
#   '3/9/2007'],
#  [],
#  ['(25) Kerron STEWARTSR', '', 'Auburn', '22.58  ', '3/9/2007'],
#  ['Additional All-Conditions Bests'],
#  ['Anavia BATTLESROhio State22.39 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 2/25/2022',
#   'Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.39 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/25/2022'],
#  [],
#  ['Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.39 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/25/2022'],
#  ['Kerron STEWARTAuburn22.46 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 2/25/2007',
#   'Kerron STEWART',
#   '',
#   'Auburn',
#   '22.46 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/25/2007'],
#  [],
#  ['Kerron STEWART',
#   '',
#   'Auburn',
#   '22.46 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/25/2007'],
#  ['Abby STEINERJRKentucky22.58 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 1/15/2022',
#   'Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.58 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '1/15/2022'],
#  [],
#  ['Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.58 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '1/15/2022'],
#  ['Not Considered For Lists'],
#  ['Deajah STEVENSSOOregon22.28 qq = Performance occurred during a non-final round. 3/10/2017\xa0\xa0\xa0\xa0\xa0DQ for lane violation',
#   'Deajah STEVENSSO',
#   '',
#   'Oregon',
#   '22.28 qq = Performance occurred during a non-final round. ',
#   '3/10/2017',
#   '\xa0\xa0\xa0\xa0\xa0DQ for lane violation'],
#  [],
#  ['Deajah STEVENSSO',
#   '',
#   'Oregon',
#   '22.28 qq = Performance occurred during a non-final round. ',
#   '3/10/2017'],
#  ['\xa0\xa0\xa0\xa0\xa0DQ for lane violation'],
#  ['', 'European U20 Championships'],
#  ['', '', '', '']]

# %%
len(rows)
# Out:
# 181

# %%
rows[173]
# Out:
# ['Abby STEINERJR',
#  '',
#  'Kentucky',
#  '22.58 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#  '1/15/2022']

# %%
len(rows)
# Out:
# 181

# %%
RealRows = []

# %%
for i in range(0,174):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [['(1) Julien ALFREDSRTexas22.01📺 3/11/2023',
#   '(1) Julien ALFREDSR',
#   '',
#   'Texas',
#   '22.01📺 ',
#   '3/11/2023'],
#  ['(1) Julien ALFREDSR', '', 'Texas', '22.01📺 ', '3/11/2023'],
#  ['(2) Abby STEINERJRKentucky22.09 2/26/2022',
#   '(2) Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.09 ',
#   '2/26/2022'],
#  ['(2) Abby STEINERJR', '', 'Kentucky', '22.09 ', '2/26/2022'],
#  ['(3) Favour OFILIJRLSU22.11📺 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(3) Favour OFILIJR',
#   '',
#   'LSU',
#   '22.11📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(3) Favour OFILIJR',
#   '',
#   'LSU',
#   '22.11📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JRKentucky22.16 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '22.16 ',
#   '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JR', '', 'Kentucky', '22.16 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}JRLSU22.20 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {2}JR',
#   '',
#   'LSU',
#   '22.20 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}JR', '', 'LSU', '22.20 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}SRTexas22.26 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {2}SR',
#   '',
#   'Texas',
#   '22.26 ',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}SR', '', 'Texas', '22.26 ', '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Ofili {3}JRLSU22.36 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {3}JR',
#   '',
#   'LSU',
#   '22.36 ',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Ofili {3}JR', '', 'LSU', '22.36 ', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JRKentucky22.37📺 2/12/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {3}JR',
#   '',
#   'Kentucky',
#   '22.37📺 ',
#   '2/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JR', '', 'Kentucky', '22.37📺 ', '2/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}SRTexas22.38 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {3}SR',
#   '',
#   'Texas',
#   '22.38 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}SR',
#   '',
#   'Texas',
#   '22.38 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {4}JRKentucky22.38📺 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Steiner {4}JR',
#   '',
#   'Kentucky',
#   '22.38📺 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Steiner {4}JR', '', 'Kentucky', '22.38📺 ', '3/13/2021'],
#  ['(4) Gabby THOMASJRHarvard22.38📺 3/10/2018',
#   '(4) Gabby THOMASJR',
#   '',
#   'Harvard',
#   '22.38📺 ',
#   '3/10/2018'],
#  ['(4) Gabby THOMASJR', '', 'Harvard', '22.38📺 ', '3/10/2018'],
#  ['(5) Bianca KNIGHTFRTexas22.40  3/14/2008',
#   '(5) Bianca KNIGHTFR',
#   '',
#   'Texas',
#   '22.40  ',
#   '3/14/2008'],
#  ['(5) Bianca KNIGHTFR', '', 'Texas', '22.40  ', '3/14/2008'],
#  ['\xa0\xa0\xa0\xa0— Steiner {5}JRKentucky22.41 qq = Performance occurred during a non-final round. 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Steiner {5}JR',
#   '',
#   'Kentucky',
#   '22.41 qq = Performance occurred during a non-final round. ',
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Steiner {5}JR',
#   '',
#   'Kentucky',
#   '22.41 qq = Performance occurred during a non-final round. ',
#   '2/25/2021'],
#  ['(6) Ashley HENDERSONSRSan Diego State22.41 3/10/2018',
#   '(6) Ashley HENDERSONSR',
#   '',
#   'San Diego State',
#   '22.41 ',
#   '3/10/2018'],
#  ['(6) Ashley HENDERSONSR', '', 'San Diego State', '22.41 ', '3/10/2018'],
#  ['(7) Autumn WILSONFRGeorgia22.42 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(7) Autumn WILSONFR',
#   '',
#   'Georgia',
#   '22.42 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(7) Autumn WILSONFR',
#   '',
#   'Georgia',
#   '22.42 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(7) Ariana WASHINGTONJROregon22.42 3/11/2017',
#   '(7) Ariana WASHINGTONJR',
#   '',
#   'Oregon',
#   '22.42 ',
#   '3/11/2017'],
#  ['(7) Ariana WASHINGTONJR', '', 'Oregon', '22.42 ', '3/11/2017'],
#  ['(9) Veronica CAMPBELLJRArkansas22.43  3/12/2004',
#   '(9) Veronica CAMPBELLJR',
#   '',
#   'Arkansas',
#   '22.43  ',
#   '3/12/2004'],
#  ['(9) Veronica CAMPBELLJR', '', 'Arkansas', '22.43  ', '3/12/2004'],
#  ['\xa0\xa0\xa0\xa0— Steiner {6}JRKentucky22.44 2/26/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {6}JR',
#   '',
#   'Kentucky',
#   '22.44 ',
#   '2/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {6}JR', '', 'Kentucky', '22.44 ', '2/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}FRGeorgia22.45 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}FR',
#   '',
#   'Georgia',
#   '22.45 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}FR', '', 'Georgia', '22.45 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {7}JRKentucky22.45 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {7}JR',
#   '',
#   'Kentucky',
#   '22.45 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {7}JR',
#   '',
#   'Kentucky',
#   '22.45 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(10) Tamara CLARKSRAlabama22.45 3/13/2021',
#   '(10) Tamara CLARKSR',
#   '',
#   'Alabama',
#   '22.45 ',
#   '3/13/2021'],
#  ['(10) Tamara CLARKSR', '', 'Alabama', '22.45 ', '3/13/2021'],
#  ['(10) Felicia BROWNSRTennessee22.45 bb = Performance occurred on a 200m/220yd banked track 2/27/2016',
#   '(10) Felicia BROWNSR',
#   '',
#   'Tennessee',
#   '22.45 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/27/2016'],
#  ['(10) Felicia BROWNSR',
#   '',
#   'Tennessee',
#   '22.45 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/27/2016'],
#  ['\xa0\xa0\xa0\xa0— Ofili {4}SOLSU22.46 2/26/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {4}SO',
#   '',
#   'LSU',
#   '22.46 ',
#   '2/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {4}SO', '', 'LSU', '22.46 ', '2/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Brown {2}SRTennessee22.47📺 bb = Performance occurred on a 200m/220yd banked track 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Brown {2}SR',
#   '',
#   'Tennessee',
#   '22.47📺 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Brown {2}SR',
#   '',
#   'Tennessee',
#   '22.47📺 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/12/2016'],
#  ['(12) McKenzie LONGSROle Miss22.48 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(12) McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '22.48 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(12) McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '22.48 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Knight {2}FRTexas22.48 qq = Performance occurred during a non-final round. 3/14/2008',
#   '\xa0\xa0\xa0\xa0— Knight {2}FR',
#   '',
#   'Texas',
#   '22.48 qq = Performance occurred during a non-final round. ',
#   '3/14/2008'],
#  ['\xa0\xa0\xa0\xa0— Knight {2}FR',
#   '',
#   'Texas',
#   '22.48 qq = Performance occurred during a non-final round. ',
#   '3/14/2008'],
#  ['(13) Anavia BATTLESROhio State22.49 2/18/2022',
#   '(13) Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.49 ',
#   '2/18/2022'],
#  ['(13) Anavia BATTLESR', '', 'Ohio State', '22.49 ', '2/18/2022'],
#  ['(13) Sanya RICHARDSSOTexas22.49  3/12/2004',
#   '(13) Sanya RICHARDSSO',
#   '',
#   'Texas',
#   '22.49  ',
#   '3/12/2004'],
#  ['(13) Sanya RICHARDSSO', '', 'Texas', '22.49  ', '3/12/2004'],
#  ['(13) Muna LEEJRLSU22.49 qq = Performance occurred during a non-final round. 3/14/2003',
#   '(13) Muna LEEJR',
#   '',
#   'LSU',
#   '22.49 qq = Performance occurred during a non-final round. ',
#   '3/14/2003'],
#  ['(13) Muna LEEJR',
#   '',
#   'LSU',
#   '22.49 qq = Performance occurred during a non-final round. ',
#   '3/14/2003'],
#  ['\xa0\xa0\xa0\xa0— Ofili {5}SOLSU22.50 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {5}SO',
#   '',
#   'LSU',
#   '22.50 ',
#   '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {5}SO', '', 'LSU', '22.50 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {8}JRKentucky22.50 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Steiner {8}JR',
#   '',
#   'Kentucky',
#   '22.50 ',
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Steiner {8}JR', '', 'Kentucky', '22.50 ', '2/25/2021'],
#  ['(16) Kamaria BROWNJRTexas A&M22.50 bb = Performance occurred on a 200m/220yd banked track 3/1/2014',
#   '(16) Kamaria BROWNJR',
#   '',
#   'Texas A&M',
#   '22.50 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/1/2014'],
#  ['(16) Kamaria BROWNJR',
#   '',
#   'Texas A&M',
#   '22.50 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/1/2014'],
#  ['\xa0\xa0\xa0\xa0— Brown {2}JRTexas A&M22.51 qq = Performance occurred during a non-final round. 2/28/2014',
#   '\xa0\xa0\xa0\xa0— Brown {2}JR',
#   '',
#   'Texas A&M',
#   '22.51 qq = Performance occurred during a non-final round. ',
#   '2/28/2014'],
#  ['\xa0\xa0\xa0\xa0— Brown {2}JR',
#   '',
#   'Texas A&M',
#   '22.51 qq = Performance occurred during a non-final round. ',
#   '2/28/2014'],
#  ['\xa0\xa0\xa0\xa0— Campbell {2}JRArkansas22.51  2/13/2004',
#   '\xa0\xa0\xa0\xa0— Campbell {2}JR',
#   '',
#   'Arkansas',
#   '22.51  ',
#   '2/13/2004'],
#  ['\xa0\xa0\xa0\xa0— Campbell {2}JR', '', 'Arkansas', '22.51  ', '2/13/2004'],
#  ['\xa0\xa0\xa0\xa0— Ofili {6}JRLSU22.52 2/25/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {6}JR',
#   '',
#   'LSU',
#   '22.52 ',
#   '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Ofili {6}JR', '', 'LSU', '22.52 ', '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Ofili {7}JRLSU22.52 qq = Performance occurred during a non-final round. 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {7}JR',
#   '',
#   'LSU',
#   '22.52 qq = Performance occurred during a non-final round. ',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Ofili {7}JR',
#   '',
#   'LSU',
#   '22.52 qq = Performance occurred during a non-final round. ',
#   '2/24/2023'],
#  ['(17) Rhasidat ADELEKESOTexas22.52📺 AA = Performance occurred at altitude (>1000 meters above sea level) 1/21/2023',
#   '(17) Rhasidat ADELEKESO',
#   '',
#   'Texas',
#   '22.52📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  ['(17) Rhasidat ADELEKESO',
#   '',
#   'Texas',
#   '22.52📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {9}JRKentucky22.52 2/13/2021',
#   '\xa0\xa0\xa0\xa0— Steiner {9}JR',
#   '',
#   'Kentucky',
#   '22.52 ',
#   '2/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Steiner {9}JR', '', 'Kentucky', '22.52 ', '2/13/2021'],
#  ['(17) Jenna PRANDINIOregon22.52 qq = Performance occurred during a non-final round. 3/13/2015',
#   '(17) Jenna PRANDINI',
#   '',
#   'Oregon',
#   '22.52 qq = Performance occurred during a non-final round. ',
#   '3/13/2015'],
#  ['(17) Jenna PRANDINI',
#   '',
#   'Oregon',
#   '22.52 qq = Performance occurred during a non-final round. ',
#   '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Ofili {8}JRLSU22.53 1/27/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {8}JR',
#   '',
#   'LSU',
#   '22.53 ',
#   '1/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Ofili {8}JR', '', 'LSU', '22.53 ', '1/27/2023'],
#  ['(19) Hannah CUNLIFFEJROregon22.53 3/11/2017',
#   '(19) Hannah CUNLIFFEJR',
#   '',
#   'Oregon',
#   '22.53 ',
#   '3/11/2017'],
#  ['(19) Hannah CUNLIFFEJR', '', 'Oregon', '22.53 ', '3/11/2017'],
#  ['\xa0\xa0\xa0\xa0— Long {2}SROle Miss22.54 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Long {2}SR',
#   '',
#   'Ole Miss',
#   '22.54 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Long {2}SR', '', 'Ole Miss', '22.54 ', '3/11/2023'],
#  ['(20) Deanna HILLJRSouthern California22.54 3/11/2017',
#   '(20) Deanna HILLJR',
#   '',
#   'Southern California',
#   '22.54 ',
#   '3/11/2017'],
#  ['(20) Deanna HILLJR', '', 'Southern California', '22.54 ', '3/11/2017'],
#  ['(20) Kimberlyn DUNCANSRLSU22.54 2/24/2013',
#   '(20) Kimberlyn DUNCANSR',
#   '',
#   'LSU',
#   '22.54 ',
#   '2/24/2013'],
#  ['(20) Kimberlyn DUNCANSR', '', 'LSU', '22.54 ', '2/24/2013'],
#  ['\xa0\xa0\xa0\xa0— Ofili {9}JRLSU22.55 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {9}JR',
#   '',
#   'LSU',
#   '22.55 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Ofili {9}JR',
#   '',
#   'LSU',
#   '22.55 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['(22) Kynnedy FLANNELJRTexas22.55 2/26/2021',
#   '(22) Kynnedy FLANNELJR',
#   '',
#   'Texas',
#   '22.55 ',
#   '2/26/2021'],
#  ['(22) Kynnedy FLANNELJR', '', 'Texas', '22.55 ', '2/26/2021'],
#  ['(22) Lynna IRBYFRGeorgia22.55 3/10/2018',
#   '(22) Lynna IRBYFR',
#   '',
#   'Georgia',
#   '22.55 ',
#   '3/10/2018'],
#  ['(22) Lynna IRBYFR', '', 'Georgia', '22.55 ', '3/10/2018'],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SRTexas22.56 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {4}SR',
#   '',
#   'Texas',
#   '22.56 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SR',
#   '',
#   'Texas',
#   '22.56 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {10}SOKentucky22.57 2/29/2020',
#   '\xa0\xa0\xa0\xa0— Steiner {10}SO',
#   '',
#   'Kentucky',
#   '22.57 ',
#   '2/29/2020'],
#  ['\xa0\xa0\xa0\xa0— Steiner {10}SO', '', 'Kentucky', '22.57 ', '2/29/2020'],
#  ['\xa0\xa0\xa0\xa0— Washington {2}JROregon22.57 qq = Performance occurred during a non-final round. 3/10/2017',
#   '\xa0\xa0\xa0\xa0— Washington {2}JR',
#   '',
#   'Oregon',
#   '22.57 qq = Performance occurred during a non-final round. ',
#   '3/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Washington {2}JR',
#   '',
#   'Oregon',
#   '22.57 qq = Performance occurred during a non-final round. ',
#   '3/10/2017'],
#  ['(24) Shalonda SOLOMONSOSouth Carolina22.57  3/10/2006',
#   '(24) Shalonda SOLOMONSO',
#   '',
#   'South Carolina',
#   '22.57  ',
#   '3/10/2006'],
#  ['(24) Shalonda SOLOMONSO', '', 'South Carolina', '22.57  ', '3/10/2006'],
#  ['(25) Jadyn MAYSSOOregon22.58 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(25) Jadyn MAYSSO',
#   '',
#   'Oregon',
#   '22.58 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(25) Jadyn MAYSSO',
#   '',
#   'Oregon',
#   '22.58 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Duncan {2}SRLSU22.58 3/8/2013',
#   '\xa0\xa0\xa0\xa0— Duncan {2}SR',
#   '',
#   'LSU',
#   '22.58 ',
#   '3/8/2013'],
#  ['\xa0\xa0\xa0\xa0— Duncan {2}SR', '', 'LSU', '22.58 ', '3/8/2013'],
#  ['(25) Kerron STEWARTSRAuburn22.58  3/9/2007',
#   '(25) Kerron STEWARTSR',
#   '',
#   'Auburn',
#   '22.58  ',
#   '3/9/2007'],
#  ['(25) Kerron STEWARTSR', '', 'Auburn', '22.58  ', '3/9/2007'],
#  ['Anavia BATTLESROhio State22.39 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 2/25/2022',
#   'Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.39 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/25/2022'],
#  ['Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.39 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/25/2022'],
#  ['Kerron STEWARTAuburn22.46 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 2/25/2007',
#   'Kerron STEWART',
#   '',
#   'Auburn',
#   '22.46 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/25/2007'],
#  ['Kerron STEWART',
#   '',
#   'Auburn',
#   '22.46 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/25/2007'],
#  ['Abby STEINERJRKentucky22.58 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 1/15/2022',
#   'Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.58 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '1/15/2022'],
#  ['Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.58 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '1/15/2022']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Julien ALFREDSRTexas22.01📺 3/11/2023',
#   '(1) Julien ALFREDSR',
#   '',
#   'Texas',
#   '22.01📺 ',
#   '3/11/2023'],
#  ['(2) Abby STEINERJRKentucky22.09 2/26/2022',
#   '(2) Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.09 ',
#   '2/26/2022'],
#  ['(3) Favour OFILIJRLSU22.11📺 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(3) Favour OFILIJR',
#   '',
#   'LSU',
#   '22.11📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JRKentucky22.16 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '22.16 ',
#   '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}JRLSU22.20 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {2}JR',
#   '',
#   'LSU',
#   '22.20 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}SRTexas22.26 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {2}SR',
#   '',
#   'Texas',
#   '22.26 ',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Ofili {3}JRLSU22.36 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {3}JR',
#   '',
#   'LSU',
#   '22.36 ',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JRKentucky22.37📺 2/12/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {3}JR',
#   '',
#   'Kentucky',
#   '22.37📺 ',
#   '2/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}SRTexas22.38 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {3}SR',
#   '',
#   'Texas',
#   '22.38 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {4}JRKentucky22.38📺 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Steiner {4}JR',
#   '',
#   'Kentucky',
#   '22.38📺 ',
#   '3/13/2021'],
#  ['(4) Gabby THOMASJRHarvard22.38📺 3/10/2018',
#   '(4) Gabby THOMASJR',
#   '',
#   'Harvard',
#   '22.38📺 ',
#   '3/10/2018'],
#  ['(5) Bianca KNIGHTFRTexas22.40  3/14/2008',
#   '(5) Bianca KNIGHTFR',
#   '',
#   'Texas',
#   '22.40  ',
#   '3/14/2008'],
#  ['\xa0\xa0\xa0\xa0— Steiner {5}JRKentucky22.41 qq = Performance occurred during a non-final round. 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Steiner {5}JR',
#   '',
#   'Kentucky',
#   '22.41 qq = Performance occurred during a non-final round. ',
#   '2/25/2021'],
#  ['(6) Ashley HENDERSONSRSan Diego State22.41 3/10/2018',
#   '(6) Ashley HENDERSONSR',
#   '',
#   'San Diego State',
#   '22.41 ',
#   '3/10/2018'],
#  ['(7) Autumn WILSONFRGeorgia22.42 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(7) Autumn WILSONFR',
#   '',
#   'Georgia',
#   '22.42 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(7) Ariana WASHINGTONJROregon22.42 3/11/2017',
#   '(7) Ariana WASHINGTONJR',
#   '',
#   'Oregon',
#   '22.42 ',
#   '3/11/2017'],
#  ['(9) Veronica CAMPBELLJRArkansas22.43  3/12/2004',
#   '(9) Veronica CAMPBELLJR',
#   '',
#   'Arkansas',
#   '22.43  ',
#   '3/12/2004'],
#  ['\xa0\xa0\xa0\xa0— Steiner {6}JRKentucky22.44 2/26/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {6}JR',
#   '',
#   'Kentucky',
#   '22.44 ',
#   '2/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}FRGeorgia22.45 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}FR',
#   '',
#   'Georgia',
#   '22.45 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {7}JRKentucky22.45 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {7}JR',
#   '',
#   'Kentucky',
#   '22.45 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(10) Tamara CLARKSRAlabama22.45 3/13/2021',
#   '(10) Tamara CLARKSR',
#   '',
#   'Alabama',
#   '22.45 ',
#   '3/13/2021'],
#  ['(10) Felicia BROWNSRTennessee22.45 bb = Performance occurred on a 200m/220yd banked track 2/27/2016',
#   '(10) Felicia BROWNSR',
#   '',
#   'Tennessee',
#   '22.45 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/27/2016'],
#  ['\xa0\xa0\xa0\xa0— Ofili {4}SOLSU22.46 2/26/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {4}SO',
#   '',
#   'LSU',
#   '22.46 ',
#   '2/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Brown {2}SRTennessee22.47📺 bb = Performance occurred on a 200m/220yd banked track 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Brown {2}SR',
#   '',
#   'Tennessee',
#   '22.47📺 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/12/2016'],
#  ['(12) McKenzie LONGSROle Miss22.48 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(12) McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '22.48 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Knight {2}FRTexas22.48 qq = Performance occurred during a non-final round. 3/14/2008',
#   '\xa0\xa0\xa0\xa0— Knight {2}FR',
#   '',
#   'Texas',
#   '22.48 qq = Performance occurred during a non-final round. ',
#   '3/14/2008'],
#  ['(13) Anavia BATTLESROhio State22.49 2/18/2022',
#   '(13) Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.49 ',
#   '2/18/2022'],
#  ['(13) Sanya RICHARDSSOTexas22.49  3/12/2004',
#   '(13) Sanya RICHARDSSO',
#   '',
#   'Texas',
#   '22.49  ',
#   '3/12/2004'],
#  ['(13) Muna LEEJRLSU22.49 qq = Performance occurred during a non-final round. 3/14/2003',
#   '(13) Muna LEEJR',
#   '',
#   'LSU',
#   '22.49 qq = Performance occurred during a non-final round. ',
#   '3/14/2003'],
#  ['\xa0\xa0\xa0\xa0— Ofili {5}SOLSU22.50 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {5}SO',
#   '',
#   'LSU',
#   '22.50 ',
#   '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {8}JRKentucky22.50 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Steiner {8}JR',
#   '',
#   'Kentucky',
#   '22.50 ',
#   '2/25/2021'],
#  ['(16) Kamaria BROWNJRTexas A&M22.50 bb = Performance occurred on a 200m/220yd banked track 3/1/2014',
#   '(16) Kamaria BROWNJR',
#   '',
#   'Texas A&M',
#   '22.50 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/1/2014'],
#  ['\xa0\xa0\xa0\xa0— Brown {2}JRTexas A&M22.51 qq = Performance occurred during a non-final round. 2/28/2014',
#   '\xa0\xa0\xa0\xa0— Brown {2}JR',
#   '',
#   'Texas A&M',
#   '22.51 qq = Performance occurred during a non-final round. ',
#   '2/28/2014'],
#  ['\xa0\xa0\xa0\xa0— Campbell {2}JRArkansas22.51  2/13/2004',
#   '\xa0\xa0\xa0\xa0— Campbell {2}JR',
#   '',
#   'Arkansas',
#   '22.51  ',
#   '2/13/2004'],
#  ['\xa0\xa0\xa0\xa0— Ofili {6}JRLSU22.52 2/25/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {6}JR',
#   '',
#   'LSU',
#   '22.52 ',
#   '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Ofili {7}JRLSU22.52 qq = Performance occurred during a non-final round. 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {7}JR',
#   '',
#   'LSU',
#   '22.52 qq = Performance occurred during a non-final round. ',
#   '2/24/2023'],
#  ['(17) Rhasidat ADELEKESOTexas22.52📺 AA = Performance occurred at altitude (>1000 meters above sea level) 1/21/2023',
#   '(17) Rhasidat ADELEKESO',
#   '',
#   'Texas',
#   '22.52📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {9}JRKentucky22.52 2/13/2021',
#   '\xa0\xa0\xa0\xa0— Steiner {9}JR',
#   '',
#   'Kentucky',
#   '22.52 ',
#   '2/13/2021'],
#  ['(17) Jenna PRANDINIOregon22.52 qq = Performance occurred during a non-final round. 3/13/2015',
#   '(17) Jenna PRANDINI',
#   '',
#   'Oregon',
#   '22.52 qq = Performance occurred during a non-final round. ',
#   '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Ofili {8}JRLSU22.53 1/27/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {8}JR',
#   '',
#   'LSU',
#   '22.53 ',
#   '1/27/2023'],
#  ['(19) Hannah CUNLIFFEJROregon22.53 3/11/2017',
#   '(19) Hannah CUNLIFFEJR',
#   '',
#   'Oregon',
#   '22.53 ',
#   '3/11/2017'],
#  ['\xa0\xa0\xa0\xa0— Long {2}SROle Miss22.54 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Long {2}SR',
#   '',
#   'Ole Miss',
#   '22.54 ',
#   '3/11/2023'],
#  ['(20) Deanna HILLJRSouthern California22.54 3/11/2017',
#   '(20) Deanna HILLJR',
#   '',
#   'Southern California',
#   '22.54 ',
#   '3/11/2017'],
#  ['(20) Kimberlyn DUNCANSRLSU22.54 2/24/2013',
#   '(20) Kimberlyn DUNCANSR',
#   '',
#   'LSU',
#   '22.54 ',
#   '2/24/2013'],
#  ['\xa0\xa0\xa0\xa0— Ofili {9}JRLSU22.55 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Ofili {9}JR',
#   '',
#   'LSU',
#   '22.55 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['(22) Kynnedy FLANNELJRTexas22.55 2/26/2021',
#   '(22) Kynnedy FLANNELJR',
#   '',
#   'Texas',
#   '22.55 ',
#   '2/26/2021'],
#  ['(22) Lynna IRBYFRGeorgia22.55 3/10/2018',
#   '(22) Lynna IRBYFR',
#   '',
#   'Georgia',
#   '22.55 ',
#   '3/10/2018'],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SRTexas22.56 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {4}SR',
#   '',
#   'Texas',
#   '22.56 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {10}SOKentucky22.57 2/29/2020',
#   '\xa0\xa0\xa0\xa0— Steiner {10}SO',
#   '',
#   'Kentucky',
#   '22.57 ',
#   '2/29/2020'],
#  ['\xa0\xa0\xa0\xa0— Washington {2}JROregon22.57 qq = Performance occurred during a non-final round. 3/10/2017',
#   '\xa0\xa0\xa0\xa0— Washington {2}JR',
#   '',
#   'Oregon',
#   '22.57 qq = Performance occurred during a non-final round. ',
#   '3/10/2017'],
#  ['(24) Shalonda SOLOMONSOSouth Carolina22.57  3/10/2006',
#   '(24) Shalonda SOLOMONSO',
#   '',
#   'South Carolina',
#   '22.57  ',
#   '3/10/2006'],
#  ['(25) Jadyn MAYSSOOregon22.58 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(25) Jadyn MAYSSO',
#   '',
#   'Oregon',
#   '22.58 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Duncan {2}SRLSU22.58 3/8/2013',
#   '\xa0\xa0\xa0\xa0— Duncan {2}SR',
#   '',
#   'LSU',
#   '22.58 ',
#   '3/8/2013'],
#  ['(25) Kerron STEWARTSRAuburn22.58  3/9/2007',
#   '(25) Kerron STEWARTSR',
#   '',
#   'Auburn',
#   '22.58  ',
#   '3/9/2007'],
#  ['Anavia BATTLESROhio State22.39 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 2/25/2022',
#   'Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.39 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/25/2022'],
#  ['Kerron STEWARTAuburn22.46 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 2/25/2007',
#   'Kerron STEWART',
#   '',
#   'Auburn',
#   '22.46 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/25/2007'],
#  ['Abby STEINERJRKentucky22.58 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 1/15/2022',
#   'Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.58 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '1/15/2022']]

# %%
RealRealRows[1][4]
# Out:
# '22.09 '

# %%
len(RealRealRows)
# Out:
# 57

# %%
OfficialTimes = []

# %%
for i in range(0,57):
    OfficialTimes.append(RealRealRows[i][4])
OfficialTimes
# Out:
# ['22.01📺 ',
#  '22.09 ',
#  '22.11📺 qq = Performance occurred during a non-final round. ',
#  '22.16 ',
#  '22.20 ',
#  '22.26 ',
#  '22.36 ',
#  '22.37📺 ',
#  '22.38 qq = Performance occurred during a non-final round. ',
#  '22.38📺 ',
#  '22.38📺 ',
#  '22.40  ',
#  '22.41 qq = Performance occurred during a non-final round. ',
#  '22.41 ',
#  '22.42 qq = Performance occurred during a non-final round. ',
#  '22.42 ',
#  '22.43  ',
#  '22.44 ',
#  '22.45 ',
#  '22.45 qq = Performance occurred during a non-final round. ',
#  '22.45 ',
#  '22.45 bb = Performance occurred on a 200m/220yd banked track ',
#  '22.46 ',
#  '22.47📺 bb = Performance occurred on a 200m/220yd banked track ',
#  '22.48 qq = Performance occurred during a non-final round. ',
#  '22.48 qq = Performance occurred during a non-final round. ',
#  '22.49 ',
#  '22.49  ',
#  '22.49 qq = Performance occurred during a non-final round. ',
#  '22.50 ',
#  '22.50 ',
#  '22.50 bb = Performance occurred on a 200m/220yd banked track ',
#  '22.51 qq = Performance occurred during a non-final round. ',
#  '22.51  ',
#  '22.52 ',
#  '22.52 qq = Performance occurred during a non-final round. ',
#  '22.52📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '22.52 ',
#  '22.52 qq = Performance occurred during a non-final round. ',
#  '22.53 ',
#  '22.53 ',
#  '22.54 ',
#  '22.54 ',
#  '22.54 ',
#  '22.55 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '22.55 ',
#  '22.55 ',
#  '22.56 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '22.57 ',
#  '22.57 qq = Performance occurred during a non-final round. ',
#  '22.57  ',
#  '22.58 qq = Performance occurred during a non-final round. ',
#  '22.58 ',
#  '22.58  ',
#  '22.39 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#  '22.46 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#  '22.58 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ']

# %%
RealRealRows[0][1]
# Out:
# '(1) Julien ALFREDSR'

# %%
Names = []

for i in range(0,57):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Julien ALFREDSR',
#  '(2) Abby STEINERJR',
#  '(3) Favour OFILIJR',
#  '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#  '\xa0\xa0\xa0\xa0— Ofili {2}JR',
#  '\xa0\xa0\xa0\xa0— Alfred {2}SR',
#  '\xa0\xa0\xa0\xa0— Ofili {3}JR',
#  '\xa0\xa0\xa0\xa0— Steiner {3}JR',
#  '\xa0\xa0\xa0\xa0— Alfred {3}SR',
#  '\xa0\xa0\xa0\xa0— Steiner {4}JR',
#  '(4) Gabby THOMASJR',
#  '(5) Bianca KNIGHTFR',
#  '\xa0\xa0\xa0\xa0— Steiner {5}JR',
#  '(6) Ashley HENDERSONSR',
#  '(7) Autumn WILSONFR',
#  '(7) Ariana WASHINGTONJR',
#  '(9) Veronica CAMPBELLJR',
#  '\xa0\xa0\xa0\xa0— Steiner {6}JR',
#  '\xa0\xa0\xa0\xa0— Wilson {2}FR',
#  '\xa0\xa0\xa0\xa0— Steiner {7}JR',
#  '(10) Tamara CLARKSR',
#  '(10) Felicia BROWNSR',
#  '\xa0\xa0\xa0\xa0— Ofili {4}SO',
#  '\xa0\xa0\xa0\xa0— Brown {2}SR',
#  '(12) McKenzie LONGSR',
#  '\xa0\xa0\xa0\xa0— Knight {2}FR',
#  '(13) Anavia BATTLESR',
#  '(13) Sanya RICHARDSSO',
#  '(13) Muna LEEJR',
#  '\xa0\xa0\xa0\xa0— Ofili {5}SO',
#  '\xa0\xa0\xa0\xa0— Steiner {8}JR',
#  '(16) Kamaria BROWNJR',
#  '\xa0\xa0\xa0\xa0— Brown {2}JR',
#  '\xa0\xa0\xa0\xa0— Campbell {2}JR',
#  '\xa0\xa0\xa0\xa0— Ofili {6}JR',
#  '\xa0\xa0\xa0\xa0— Ofili {7}JR',
#  '(17) Rhasidat ADELEKESO',
#  '\xa0\xa0\xa0\xa0— Steiner {9}JR',
#  '(17) Jenna PRANDINI',
#  '\xa0\xa0\xa0\xa0— Ofili {8}JR',
#  '(19) Hannah CUNLIFFEJR',
#  '\xa0\xa0\xa0\xa0— Long {2}SR',
#  '(20) Deanna HILLJR',
#  '(20) Kimberlyn DUNCANSR',
#  '\xa0\xa0\xa0\xa0— Ofili {9}JR',
#  '(22) Kynnedy FLANNELJR',
#  '(22) Lynna IRBYFR',
#  '\xa0\xa0\xa0\xa0— Alfred {4}SR',
#  '\xa0\xa0\xa0\xa0— Steiner {10}SO',
#  '\xa0\xa0\xa0\xa0— Washington {2}JR',
#  '(24) Shalonda SOLOMONSO',
#  '(25) Jadyn MAYSSO',
#  '\xa0\xa0\xa0\xa0— Duncan {2}SR',
#  '(25) Kerron STEWARTSR',
#  'Anavia BATTLESR',
#  'Kerron STEWART',
#  'Abby STEINERJR']

# %%
OfficialReGexNames = []

# %%
for i in range(0,57):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Julien ALFREDSR',
#  '(2) Abby STEINERJR',
#  '(3) Favour OFILIJR',
#  '— Steiner {2}JR',
#  '— Ofili {2}JR',
#  '— Alfred {2}SR',
#  '— Ofili {3}JR',
#  '— Steiner {3}JR',
#  '— Alfred {3}SR',
#  '— Steiner {4}JR',
#  '(4) Gabby THOMASJR',
#  '(5) Bianca KNIGHTFR',
#  '— Steiner {5}JR',
#  '(6) Ashley HENDERSONSR',
#  '(7) Autumn WILSONFR',
#  '(7) Ariana WASHINGTONJR',
#  '(9) Veronica CAMPBELLJR',
#  '— Steiner {6}JR',
#  '— Wilson {2}FR',
#  '— Steiner {7}JR',
#  '(10) Tamara CLARKSR',
#  '(10) Felicia BROWNSR',
#  '— Ofili {4}SO',
#  '— Brown {2}SR',
#  '(12) McKenzie LONGSR',
#  '— Knight {2}FR',
#  '(13) Anavia BATTLESR',
#  '(13) Sanya RICHARDSSO',
#  '(13) Muna LEEJR',
#  '— Ofili {5}SO',
#  '— Steiner {8}JR',
#  '(16) Kamaria BROWNJR',
#  '— Brown {2}JR',
#  '— Campbell {2}JR',
#  '— Ofili {6}JR',
#  '— Ofili {7}JR',
#  '(17) Rhasidat ADELEKESO',
#  '— Steiner {9}JR',
#  '(17) Jenna PRANDINI',
#  '— Ofili {8}JR',
#  '(19) Hannah CUNLIFFEJR',
#  '— Long {2}SR',
#  '(20) Deanna HILLJR',
#  '(20) Kimberlyn DUNCANSR',
#  '— Ofili {9}JR',
#  '(22) Kynnedy FLANNELJR',
#  '(22) Lynna IRBYFR',
#  '— Alfred {4}SR',
#  '— Steiner {10}SO',
#  '— Washington {2}JR',
#  '(24) Shalonda SOLOMONSO',
#  '(25) Jadyn MAYSSO',
#  '— Duncan {2}SR',
#  '(25) Kerron STEWARTSR',
#  'Anavia BATTLESR',
#  'Kerron STEWART',
#  'Abby STEINERJR']

# %%
len(OfficialReGexNames)
# Out:
# 57

# %%
CleanedNames = []

for i in range(0,len(OfficialReGexNames)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Julien ALFREDSR',
#  'Abby STEINERJR',
#  'Favour OFILIJR',
#  'Steiner {2}JR',
#  'Ofili {2}JR',
#  'Alfred {2}SR',
#  'Ofili {3}JR',
#  'Steiner {3}JR',
#  'Alfred {3}SR',
#  'Steiner {4}JR',
#  'Gabby THOMASJR',
#  'Bianca KNIGHTFR',
#  'Steiner {5}JR',
#  'Ashley HENDERSONSR',
#  'Autumn WILSONFR',
#  'Ariana WASHINGTONJR',
#  'Veronica CAMPBELLJR',
#  'Steiner {6}JR',
#  'Wilson {2}FR',
#  'Steiner {7}JR',
#  ' Tamara CLARKSR',
#  ' Felicia BROWNSR',
#  'Ofili {4}SO',
#  'Brown {2}SR',
#  ' McKenzie LONGSR',
#  'Knight {2}FR',
#  ' Anavia BATTLESR',
#  ' Sanya RICHARDSSO',
#  ' Muna LEEJR',
#  'Ofili {5}SO',
#  'Steiner {8}JR',
#  ' Kamaria BROWNJR',
#  'Brown {2}JR',
#  'Campbell {2}JR',
#  'Ofili {6}JR',
#  'Ofili {7}JR',
#  ' Rhasidat ADELEKESO',
#  'Steiner {9}JR',
#  ' Jenna PRANDINI',
#  'Ofili {8}JR',
#  ' Hannah CUNLIFFEJR',
#  'Long {2}SR',
#  ' Deanna HILLJR',
#  ' Kimberlyn DUNCANSR',
#  'Ofili {9}JR',
#  ' Kynnedy FLANNELJR',
#  ' Lynna IRBYFR',
#  'Alfred {4}SR',
#  'Steiner {10}SO',
#  'Washington {2}JR',
#  ' Shalonda SOLOMONSO',
#  ' Jadyn MAYSSO',
#  'Duncan {2}SR',
#  ' Kerron STEWARTSR']

# %%
CleanedNames.append("Anavia BATTLESR")
CleanedNames.append("Kerron STEWART")
CleanedNames.append("Abby STEINERJR")

# %%
CleanedNames2 = []

for i in range(0,len(CleanedNames)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Julien ALFREDSR',
#  'Abby STEINERJR',
#  'Favour OFILIJR',
#  'Steiner {2}JR',
#  'Ofili {2}JR',
#  'Alfred {2}SR',
#  'Ofili {3}JR',
#  'Steiner {3}JR',
#  'Alfred {3}SR',
#  'Steiner {4}JR',
#  'Gabby THOMASJR',
#  'Bianca KNIGHTFR',
#  'Steiner {5}JR',
#  'Ashley HENDERSONSR',
#  'Autumn WILSONFR',
#  'Ariana WASHINGTONJR',
#  'Veronica CAMPBELLJR',
#  'Steiner {6}JR',
#  'Wilson {2}FR',
#  'Steiner {7}JR',
#  'Tamara CLARKSR',
#  'Felicia BROWNSR',
#  'Ofili {4}SO',
#  'Brown {2}SR',
#  'McKenzie LONGSR',
#  'Knight {2}FR',
#  'Anavia BATTLESR',
#  'Sanya RICHARDSSO',
#  'Muna LEEJR',
#  'Ofili {5}SO',
#  'Steiner {8}JR',
#  'Kamaria BROWNJR',
#  'Brown {2}JR',
#  'Campbell {2}JR',
#  'Ofili {6}JR',
#  'Ofili {7}JR',
#  'Rhasidat ADELEKESO',
#  'Steiner {9}JR',
#  'Jenna PRANDINI',
#  'Ofili {8}JR',
#  'Hannah CUNLIFFEJR',
#  'Long {2}SR',
#  'Deanna HILLJR',
#  'Kimberlyn DUNCANSR',
#  'Ofili {9}JR',
#  'Kynnedy FLANNELJR',
#  'Lynna IRBYFR',
#  'Alfred {4}SR',
#  'Steiner {10}SO',
#  'Washington {2}JR',
#  'Shalonda SOLOMONSO',
#  'Jadyn MAYSSO',
#  'Duncan {2}SR',
#  'Kerron STEWARTSR',
#  'Anavia BATTLESR',
#  'Kerron STEWART',
#  'Abby STEINERJR']

# %%
len(CleanedNames2)
# Out:
# 57

# %%
len(OfficialTimes)
# Out:
# 57

# %%
len(OfficialReGexNames)
# Out:
# 57

# %%
Schools = []

for i in range(0,len(OfficialTimes)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Texas',
#  'Kentucky',
#  'LSU',
#  'Kentucky',
#  'LSU',
#  'Texas',
#  'LSU',
#  'Kentucky',
#  'Texas',
#  'Kentucky',
#  'Harvard',
#  'Texas',
#  'Kentucky',
#  'San Diego State',
#  'Georgia',
#  'Oregon',
#  'Arkansas',
#  'Kentucky',
#  'Georgia',
#  'Kentucky',
#  'Alabama',
#  'Tennessee',
#  'LSU',
#  'Tennessee',
#  'Ole Miss',
#  'Texas',
#  'Ohio State',
#  'Texas',
#  'LSU',
#  'LSU',
#  'Kentucky',
#  'Texas A&M',
#  'Texas A&M',
#  'Arkansas',
#  'LSU',
#  'LSU',
#  'Texas',
#  'Kentucky',
#  'Oregon',
#  'LSU',
#  'Oregon',
#  'Ole Miss',
#  'Southern California',
#  'LSU',
#  'LSU',
#  'Texas',
#  'Georgia',
#  'Texas',
#  'Kentucky',
#  'Oregon',
#  'South Carolina',
#  'Oregon',
#  'LSU',
#  'Auburn',
#  'Ohio State',
#  'Auburn',
#  'Kentucky']

# %%
Times = []

# %%
for i in range(0,len(OfficialTimes)):
    Times.append(OfficialTimes[i][:5])
    
Times
# Out:
# ['22.01',
#  '22.09',
#  '22.11',
#  '22.16',
#  '22.20',
#  '22.26',
#  '22.36',
#  '22.37',
#  '22.38',
#  '22.38',
#  '22.38',
#  '22.40',
#  '22.41',
#  '22.41',
#  '22.42',
#  '22.42',
#  '22.43',
#  '22.44',
#  '22.45',
#  '22.45',
#  '22.45',
#  '22.45',
#  '22.46',
#  '22.47',
#  '22.48',
#  '22.48',
#  '22.49',
#  '22.49',
#  '22.49',
#  '22.50',
#  '22.50',
#  '22.50',
#  '22.51',
#  '22.51',
#  '22.52',
#  '22.52',
#  '22.52',
#  '22.52',
#  '22.52',
#  '22.53',
#  '22.53',
#  '22.54',
#  '22.54',
#  '22.54',
#  '22.55',
#  '22.55',
#  '22.55',
#  '22.56',
#  '22.57',
#  '22.57',
#  '22.57',
#  '22.58',
#  '22.58',
#  '22.58',
#  '22.39',
#  '22.46',
#  '22.58']

# %%
len(Times)
# Out:
# 57

# %%
IndoorWomens200mDF = pd.DataFrame({'Names': CleanedNames2, 'Times': Times, 'Schools': Schools})

# %%
IndoorWomens200mDF.to_csv('IndoorWomens200m.csv', index=False)
