# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
IndoorLongJumpWomens = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?gender=2&sport=1&div=20527&top=25&event=23"

# %%
page = requests.get(IndoorLongJumpWomens)
soup = BeautifulSoup(page.text,'html')
soup
table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8010897" target="_blank">(1) Jasmine MOORE</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720952" target="_blank">7.03m</a><a href="https://www.youtube.com/watch?v=ZJTXoNFcnxc" target="_blank">📺</a>  23-¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8010897" target="_blank">(1) Jasmine MOORE</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720952" target="_blank">7.03m</a><a href="https://www.youtube.com/watch?v=ZJTXoNFcnxc" target="_blank">📺</a>  23-¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7087499" target="_blank">(2) Tara DAVIS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118019" target="_blank">6.93m</a>  22-9</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7087499" target="_blank">(2) Tara DAVIS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118019" target="_blank">6.93m</a>  22-9</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Moore {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691825" target="_blank">6.91m</a>  22-8</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Moore {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691825" target="_blank">6.91m</a>  22-8</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2220817" target="_blank">(3) Whitney GIPSON</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="TCU" class="group-logo-inline" src="/images/logos/rankings-article/tcu.png" title="TCU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1550">TCU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/24457" target="_blank">6.91m</a>  22-8</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Nampa, Idaho)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2012</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.64, 6.30, FOUL., FOUL, 6.91, 6.22</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2220817" target="_blank">(3) Whitney GIPSON</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="TCU" class="group-logo-inline" src="/images/logos/rankings-article/tcu.png" title="TCU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1550">TCU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/24457" target="_blank">6.91m</a>  22-8</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Nampa, Idaho)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2012</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.64, 6.30, FOUL., FOUL, 6.91, 6.22</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(3) Elva GOULBOURNE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=74">Auburn</a></td><td style="width: 25%;">6.91m  22-8</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/23/2002</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(3) Elva GOULBOURNE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=74">Auburn</a></td><td style="width: 25%;">6.91m  22-8</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/23/2002</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4177198" target="_blank">(5) Sha'Keela SAUNDERS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567/3023737" target="_blank">6.90m</a>  22-7¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2017</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.42, 6.70, 6.55, f, 6.62, 6.90</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4177198" target="_blank">(5) Sha'Keela SAUNDERS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567/3023737" target="_blank">6.90m</a>  22-7¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2017</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.42, 6.70, 6.55, f, 6.62, 6.90</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7958878" target="_blank">(6) Ackelia SMITH</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720952" target="_blank">6.88m</a>  22-7</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7958878" target="_blank">(6) Ackelia SMITH</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720952" target="_blank">6.88m</a>  22-7</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7732041" target="_blank">(6) Claire  BRYANT</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720952" target="_blank">6.88m</a>  22-7</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7732041" target="_blank">(6) Claire  BRYANT</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720952" target="_blank">6.88m</a>  22-7</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Smith {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720952" target="_blank">6.87m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span><span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 22-6½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Smith {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720952" target="_blank">6.87m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span><span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 22-6½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Moore {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720952" target="_blank">6.87m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span><span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 22-6½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Moore {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720952" target="_blank">6.87m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span><span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 22-6½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(8) Blessing OKAGBARE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UTEP" class="group-logo-inline" src="/images/logos/rankings-article/utep.png" title="UTEP"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1669">UTEP</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/15673" target="_blank">6.87m</a>  22-6½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2010</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.48, 6.84, 6.87, p, p, 6.57</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(8) Blessing OKAGBARE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UTEP" class="group-logo-inline" src="/images/logos/rankings-article/utep.png" title="UTEP"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1669">UTEP</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/15673" target="_blank">6.87m</a>  22-6½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2010</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.48, 6.84, 6.87, p, p, 6.57</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(8) Brittney REESE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Ole Miss" class="group-logo-inline" src="/images/logos/rankings-article/ole-miss.png" title="Ole Miss"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=983">Ole Miss</a></td><td style="width: 25%;">6.87m  22-6½</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/1/2008</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(8) Brittney REESE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Ole Miss" class="group-logo-inline" src="/images/logos/rankings-article/ole-miss.png" title="Ole Miss"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=983">Ole Miss</a></td><td style="width: 25%;">6.87m  22-6½</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/1/2008</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Moore {4}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691825" target="_blank">6.86m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-6¼</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Moore {4}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691825" target="_blank">6.86m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-6¼</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Okagbare {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UTEP" class="group-logo-inline" src="/images/logos/rankings-article/utep.png" title="UTEP"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1669">UTEP</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/15673" target="_blank">6.84m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-5¼</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2010</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Okagbare {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UTEP" class="group-logo-inline" src="/images/logos/rankings-article/utep.png" title="UTEP"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1669">UTEP</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/15673" target="_blank">6.84m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-5¼</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2010</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7500561" target="_blank">(10) Ruth USORO</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67776/4090187" target="_blank">6.82m</a>  22-4½</td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/26/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7500561" target="_blank">(10) Ruth USORO</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67776/4090187" target="_blank">6.82m</a>  22-4½</td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/26/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Saunders {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49067" target="_blank">6.82m</a>  22-4½</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Nashville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">2/24/2017</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.67, 6.59, f, 6.56, 6.82, 6.55</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Saunders {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49067" target="_blank">6.82m</a>  22-4½</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Nashville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">2/24/2017</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.67, 6.59, f, 6.56, 6.82, 6.55</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(10) Daphne SAUNDERS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=869">LSU</a></td><td style="width: 25%;">6.82m  22-4½</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">2/26/1994</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(10) Daphne SAUNDERS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=869">LSU</a></td><td style="width: 25%;">6.82m  22-4½</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">2/26/1994</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Reese {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Ole Miss" class="group-logo-inline" src="/images/logos/rankings-article/ole-miss.png" title="Ole Miss"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=983">Ole Miss</a></td><td style="width: 25%;">6.81m  22-4¼</td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/15/2008</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.81, f, 6.53, 6.55, p, p</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Reese {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Ole Miss" class="group-logo-inline" src="/images/logos/rankings-article/ole-miss.png" title="Ole Miss"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=983">Ole Miss</a></td><td style="width: 25%;">6.81m  22-4¼</td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/15/2008</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.81, f, 6.53, 6.55, p, p</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Goulbourne {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=74">Auburn</a></td><td style="width: 25%;">6.81m  22-4¼</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/14/2003</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.81, p, p, p, p, p</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Goulbourne {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=74">Auburn</a></td><td style="width: 25%;">6.81m  22-4¼</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/14/2003</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.81, p, p, p, p, p</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4638071" target="_blank">(12) Quanesha BURKS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702414" target="_blank">6.80m</a>  22-3¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2016</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.56, 6.57, 6.67, 6.27, 6.47, 6.80</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4638071" target="_blank">(12) Quanesha BURKS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702414" target="_blank">6.80m</a>  22-3¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2016</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.56, 6.57, 6.67, 6.27, 6.47, 6.80</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5584298" target="_blank">(12) Akela JONES</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kansas State" class="group-logo-inline" src="/images/logos/rankings-article/kansas-state.png" title="Kansas State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=760">Kansas State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2704020" target="_blank">6.80m</a> <span class="tooltip" style="font-size: smaller;">cb<span class="tooltiptext" style="font-size: smaller;">cb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.)</span></span> 22-3¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2016</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.56, 6.67, 6.80</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5584298" target="_blank">(12) Akela JONES</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kansas State" class="group-logo-inline" src="/images/logos/rankings-article/kansas-state.png" title="Kansas State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=760">Kansas State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2704020" target="_blank">6.80m</a> <span class="tooltip" style="font-size: smaller;">cb<span class="tooltiptext" style="font-size: smaller;">cb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.)</span></span> 22-3¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2016</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.56, 6.67, 6.80</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7488536" target="_blank">(14) Alysah HICKEY</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76080/4669673" target="_blank">6.79m</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 22-3½</td><td style="width: 10%;text-align:right;" title="Don Kirby Collegiate Elite (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.79, f, f, f, 6.41, f</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7488536" target="_blank">(14) Alysah HICKEY</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76080/4669673" target="_blank">6.79m</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 22-3½</td><td style="width: 10%;text-align:right;" title="Don Kirby Collegiate Elite (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.79, f, f, f, 6.41, f</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(15) Tianna MADISON</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1553">Tennessee</a></td><td style="width: 25%;">6.78m  22-3</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2005</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.49, 6.72, 6.78, p, p, p</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(15) Tianna MADISON</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1553">Tennessee</a></td><td style="width: 25%;">6.78m  22-3</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2005</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.49, 6.72, 6.78, p, p, p</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(15) Carol LEWIS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=672">Houston</a></td><td style="width: 25%;">6.78m  22-3</td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">2/2/1985</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(15) Carol LEWIS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=672">Houston</a></td><td style="width: 25%;">6.78m  22-3</td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">2/2/1985</span></td></tr>,
# ...
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(22) Marshavet HOOKER</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;">6.71m  22-¼</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2006</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     4.32, 6.34, 6.60, 6.11, 6.71, p</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Madison {3}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1553">Tennessee</a></td><td style="width: 25%;">6.71m  22-¼</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/27/2005</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Madison {3}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1553">Tennessee</a></td><td style="width: 25%;">6.71m  22-¼</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/27/2005</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(22) Dedra DAVIS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1553">Tennessee</a></td><td style="width: 25%;">6.71m  22-¼</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/1994</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(22) Dedra DAVIS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=1553">Tennessee</a></td><td style="width: 25%;">6.71m  22-¼</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/1994</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Moore {8}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76074/4667504" target="_blank">6.70m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 21-11¾</td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Moore {8}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76074/4667504" target="_blank">6.70m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 21-11¾</td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Bryant {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118019" target="_blank">6.70m</a>  21-11¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Bryant {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118019" target="_blank">6.70m</a>  21-11¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Saunders {4}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567" target="_blank">6.70m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 21-11¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Saunders {4}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567" target="_blank">6.70m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 21-11¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Orji {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49067" target="_blank">6.70m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 21-11¾</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Nashville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">2/24/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Orji {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49067" target="_blank">6.70m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 21-11¾</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Nashville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">2/24/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(24) Jeomi MADUKA</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Cornell" class="group-logo-inline" src="/images/logos/rankings-article/cornell.png" title="Cornell"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=366">Cornell</a></td><td style="width: 25%;">6.70m  21-11¾</td><td style="width: 10%;text-align:right;" title=" (New York, N.Y.)"><span class="mark-date" style="width: 10%;text-align:right;">2/14/2009</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(24) Jeomi MADUKA</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Cornell" class="group-logo-inline" src="/images/logos/rankings-article/cornell.png" title="Cornell"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=366">Cornell</a></td><td style="width: 25%;">6.70m  21-11¾</td><td style="width: 10%;text-align:right;" title=" (New York, N.Y.)"><span class="mark-date" style="width: 10%;text-align:right;">2/14/2009</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(24) Sheila ECHOLS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=869">LSU</a></td><td style="width: 25%;">6.70m  21-11¾</td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">2/28/1987</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(24) Sheila ECHOLS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=1&amp;div=20527&amp;top=25&amp;event=23&amp;team=869">LSU</a></td><td style="width: 25%;">6.70m  21-11¾</td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">2/28/1987</span></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows3 = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows3.append(row_data)

# %%
rows3
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Jasmine MOOREJRFlorida7.03m📺  23-¾3/10/2023',
#   '(1) Jasmine MOOREJR',
#   '',
#   'Florida',
#   '7.03m📺  23-¾',
#   '3/10/2023'],
#  [],
#  ['(1) Jasmine MOOREJR', '', 'Florida', '7.03m📺  23-¾', '3/10/2023'],
#  ['(2) Tara DAVISJRTexas6.93m  22-93/12/2021',
#   '(2) Tara DAVISJR',
#   '',
#   'Texas',
#   '6.93m  22-9',
#   '3/12/2021'],
#  [],
#  ['(2) Tara DAVISJR', '', 'Texas', '6.93m  22-9', '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Moore {2}JRFlorida6.91m  22-82/24/2023',
#   '\xa0\xa0\xa0\xa0— Moore {2}JR',
#   '',
#   'Florida',
#   '6.91m  22-8',
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {2}JR', '', 'Florida', '6.91m  22-8', '2/24/2023'],
#  ['(3) Whitney GIPSONSRTCU6.91m  22-83/9/2012\xa0\xa0\xa0\xa0\xa06.64, 6.30, FOUL., FOUL, 6.91, 6.22',
#   '(3) Whitney GIPSONSR',
#   '',
#   'TCU',
#   '6.91m  22-8',
#   '3/9/2012',
#   '\xa0\xa0\xa0\xa0\xa06.64, 6.30, FOUL., FOUL, 6.91, 6.22'],
#  [],
#  ['(3) Whitney GIPSONSR', '', 'TCU', '6.91m  22-8', '3/9/2012'],
#  ['\xa0\xa0\xa0\xa0\xa06.64, 6.30, FOUL., FOUL, 6.91, 6.22'],
#  ['(3) Elva GOULBOURNEAuburn6.91m  22-82/23/2002',
#   '(3) Elva GOULBOURNE',
#   '',
#   'Auburn',
#   '6.91m  22-8',
#   '2/23/2002'],
#  [],
#  ['(3) Elva GOULBOURNE', '', 'Auburn', '6.91m  22-8', '2/23/2002'],
#  ["(5) Sha'Keela SAUNDERSSRKentucky6.90m  22-7¾3/10/2017\xa0\xa0\xa0\xa0\xa06.42, 6.70, 6.55, f, 6.62, 6.90",
#   "(5) Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.90m  22-7¾',
#   '3/10/2017',
#   '\xa0\xa0\xa0\xa0\xa06.42, 6.70, 6.55, f, 6.62, 6.90'],
#  [],
#  ["(5) Sha'Keela SAUNDERSSR", '', 'Kentucky', '6.90m  22-7¾', '3/10/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.42, 6.70, 6.55, f, 6.62, 6.90'],
#  ['(6) Ackelia SMITHFRTexas6.88m  22-73/10/2023',
#   '(6) Ackelia SMITHFR',
#   '',
#   'Texas',
#   '6.88m  22-7',
#   '3/10/2023'],
#  [],
#  ['(6) Ackelia SMITHFR', '', 'Texas', '6.88m  22-7', '3/10/2023'],
#  ['(6) Claire  BRYANTJRFlorida6.88m  22-73/10/2023',
#   '(6) Claire  BRYANTJR',
#   '',
#   'Florida',
#   '6.88m  22-7',
#   '3/10/2023'],
#  [],
#  ['(6) Claire  BRYANTJR', '', 'Florida', '6.88m  22-7', '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Smith {2}FRTexas6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½3/10/2023",
#   '\xa0\xa0\xa0\xa0— Smith {2}FR',
#   '',
#   'Texas',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Smith {2}FR',
#   '',
#   'Texas',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Moore {3}JRFlorida6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½3/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  ['(8) Blessing OKAGBAREUTEP6.87m  22-6½3/12/2010\xa0\xa0\xa0\xa0\xa06.48, 6.84, 6.87, p, p, 6.57',
#   '(8) Blessing OKAGBARE',
#   '',
#   'UTEP',
#   '6.87m  22-6½',
#   '3/12/2010',
#   '\xa0\xa0\xa0\xa0\xa06.48, 6.84, 6.87, p, p, 6.57'],
#  [],
#  ['(8) Blessing OKAGBARE', '', 'UTEP', '6.87m  22-6½', '3/12/2010'],
#  ['\xa0\xa0\xa0\xa0\xa06.48, 6.84, 6.87, p, p, 6.57'],
#  ['(8) Brittney REESEOle Miss6.87m  22-6½3/1/2008',
#   '(8) Brittney REESE',
#   '',
#   'Ole Miss',
#   '6.87m  22-6½',
#   '3/1/2008'],
#  [],
#  ['(8) Brittney REESE', '', 'Ole Miss', '6.87m  22-6½', '3/1/2008'],
#  ["\xa0\xa0\xa0\xa0— Moore {4}JRFlorida6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼2/24/2023",
#   '\xa0\xa0\xa0\xa0— Moore {4}JR',
#   '',
#   'Florida',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼",
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {4}JR',
#   '',
#   'Florida',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼",
#   '2/24/2023'],
#  ["\xa0\xa0\xa0\xa0— Okagbare {2}SRUTEP6.84m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¼3/12/2010",
#   '\xa0\xa0\xa0\xa0— Okagbare {2}SR',
#   '',
#   'UTEP',
#   "6.84m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¼",
#   '3/12/2010'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Okagbare {2}SR',
#   '',
#   'UTEP',
#   "6.84m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¼",
#   '3/12/2010'],
#  ['(10) Ruth USOROSRTexas Tech6.82m  22-4½2/26/2021',
#   '(10) Ruth USOROSR',
#   '',
#   'Texas Tech',
#   '6.82m  22-4½',
#   '2/26/2021'],
#  [],
#  ['(10) Ruth USOROSR', '', 'Texas Tech', '6.82m  22-4½', '2/26/2021'],
#  ['\xa0\xa0\xa0\xa0— Saunders {2}SRKentucky6.82m  22-4½2/24/2017\xa0\xa0\xa0\xa0\xa06.67, 6.59, f, 6.56, 6.82, 6.55',
#   '\xa0\xa0\xa0\xa0— Saunders {2}SR',
#   '',
#   'Kentucky',
#   '6.82m  22-4½',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.67, 6.59, f, 6.56, 6.82, 6.55'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Saunders {2}SR',
#   '',
#   'Kentucky',
#   '6.82m  22-4½',
#   '2/24/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.67, 6.59, f, 6.56, 6.82, 6.55'],
#  ['(10) Daphne SAUNDERSLSU6.82m  22-4½2/26/1994',
#   '(10) Daphne SAUNDERS',
#   '',
#   'LSU',
#   '6.82m  22-4½',
#   '2/26/1994'],
#  [],
#  ['(10) Daphne SAUNDERS', '', 'LSU', '6.82m  22-4½', '2/26/1994'],
#  ['\xa0\xa0\xa0\xa0— Reese {2}Ole Miss6.81m  22-4¼2/15/2008\xa0\xa0\xa0\xa0\xa06.81, f, 6.53, 6.55, p, p',
#   '\xa0\xa0\xa0\xa0— Reese {2}',
#   '',
#   'Ole Miss',
#   '6.81m  22-4¼',
#   '2/15/2008',
#   '\xa0\xa0\xa0\xa0\xa06.81, f, 6.53, 6.55, p, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Reese {2}', '', 'Ole Miss', '6.81m  22-4¼', '2/15/2008'],
#  ['\xa0\xa0\xa0\xa0\xa06.81, f, 6.53, 6.55, p, p'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}SRAuburn6.81m  22-4¼3/14/2003\xa0\xa0\xa0\xa0\xa06.81, p, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Goulbourne {2}SR',
#   '',
#   'Auburn',
#   '6.81m  22-4¼',
#   '3/14/2003',
#   '\xa0\xa0\xa0\xa0\xa06.81, p, p, p, p, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}SR',
#   '',
#   'Auburn',
#   '6.81m  22-4¼',
#   '3/14/2003'],
#  ['\xa0\xa0\xa0\xa0\xa06.81, p, p, p, p, p'],
#  ['(12) Quanesha BURKSJRAlabama6.80m  22-3¾3/11/2016\xa0\xa0\xa0\xa0\xa06.56, 6.57, 6.67, 6.27, 6.47, 6.80',
#   '(12) Quanesha BURKSJR',
#   '',
#   'Alabama',
#   '6.80m  22-3¾',
#   '3/11/2016',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.57, 6.67, 6.27, 6.47, 6.80'],
#  [],
#  ['(12) Quanesha BURKSJR', '', 'Alabama', '6.80m  22-3¾', '3/11/2016'],
#  ['\xa0\xa0\xa0\xa0\xa06.56, 6.57, 6.67, 6.27, 6.47, 6.80'],
#  ['(12) Akela JONESSRKansas State6.80m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-3¾3/11/2016\xa0\xa0\xa0\xa0\xa06.56, 6.67, 6.80',
#   '(12) Akela JONESSR',
#   '',
#   'Kansas State',
#   '6.80m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-3¾',
#   '3/11/2016',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.67, 6.80'],
#  [],
#  ['(12) Akela JONESSR',
#   '',
#   'Kansas State',
#   '6.80m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-3¾',
#   '3/11/2016'],
#  ['\xa0\xa0\xa0\xa0\xa06.56, 6.67, 6.80'],
#  ['(14) Alysah HICKEYJROregon6.79m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3½2/10/2023\xa0\xa0\xa0\xa0\xa06.79, f, f, f, 6.41, f',
#   '(14) Alysah HICKEYJR',
#   '',
#   'Oregon',
#   '6.79m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3½',
#   '2/10/2023',
#   '\xa0\xa0\xa0\xa0\xa06.79, f, f, f, 6.41, f'],
#  [],
#  ['(14) Alysah HICKEYJR',
#   '',
#   'Oregon',
#   '6.79m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3½',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0\xa06.79, f, f, f, 6.41, f'],
#  ['(15) Tianna MADISONSOTennessee6.78m  22-33/11/2005\xa0\xa0\xa0\xa0\xa06.49, 6.72, 6.78, p, p, p',
#   '(15) Tianna MADISONSO',
#   '',
#   'Tennessee',
#   '6.78m  22-3',
#   '3/11/2005',
#   '\xa0\xa0\xa0\xa0\xa06.49, 6.72, 6.78, p, p, p'],
#  [],
#  ['(15) Tianna MADISONSO', '', 'Tennessee', '6.78m  22-3', '3/11/2005'],
#  ['\xa0\xa0\xa0\xa0\xa06.49, 6.72, 6.78, p, p, p'],
#  ['(15) Carol LEWISHouston6.78m  22-32/2/1985',
#   '(15) Carol LEWIS',
#   '',
#   'Houston',
#   '6.78m  22-3',
#   '2/2/1985'],
#  [],
#  ['(15) Carol LEWIS', '', 'Houston', '6.78m  22-3', '2/2/1985'],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SRAlabama6.76m  22-2¼2/24/2017\xa0\xa0\xa0\xa0\xa06.54, 6.61, 6.76, 6.38, 5.85, p',
#   '\xa0\xa0\xa0\xa0— Burks {2}SR',
#   '',
#   'Alabama',
#   '6.76m  22-2¼',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.54, 6.61, 6.76, 6.38, 5.85, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SR', '', 'Alabama', '6.76m  22-2¼', '2/24/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.54, 6.61, 6.76, 6.38, 5.85, p'],
#  ['\xa0\xa0\xa0\xa0— Reese {3}JROle Miss6.76m  22-2¼3/14/2008\xa0\xa0\xa0\xa0\xa06.56, 6.76, 6.69, 6.70, 6.56, 6.75',
#   '\xa0\xa0\xa0\xa0— Reese {3}JR',
#   '',
#   'Ole Miss',
#   '6.76m  22-2¼',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.76, 6.69, 6.70, 6.56, 6.75'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Reese {3}JR',
#   '',
#   'Ole Miss',
#   '6.76m  22-2¼',
#   '3/14/2008'],
#  ['\xa0\xa0\xa0\xa0\xa06.56, 6.76, 6.69, 6.70, 6.56, 6.75'],
#  ["\xa0\xa0\xa0\xa0— Saunders {2}LSU6.76m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-2¼2/26/1994",
#   '\xa0\xa0\xa0\xa0— Saunders {2}',
#   '',
#   'LSU',
#   "6.76m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-2¼",
#   '2/26/1994'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Saunders {2}',
#   '',
#   'LSU',
#   "6.76m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-2¼",
#   '2/26/1994'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston6.76m  22-2¼2/4/1984',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '6.76m  22-2¼',
#   '2/4/1984'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}', '', 'Houston', '6.76m  22-2¼', '2/4/1984'],
#  ['\xa0\xa0\xa0\xa0— Moore {5}SOFlorida6.75m  22-1¾2/25/2022',
#   '\xa0\xa0\xa0\xa0— Moore {5}SO',
#   '',
#   'Florida',
#   '6.75m  22-1¾',
#   '2/25/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {5}SO', '', 'Florida', '6.75m  22-1¾', '2/25/2022'],
#  ["(17) Monae' NICHOLSSRTexas Tech6.75m  22-1¾1/23/2021",
#   "(17) Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.75m  22-1¾',
#   '1/23/2021'],
#  [],
#  ["(17) Monae' NICHOLSSR", '', 'Texas Tech', '6.75m  22-1¾', '1/23/2021'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}Kansas State6.75m  22-1¾2/26/2016\xa0\xa0\xa0\xa0\xa06.57, 6.75, f, p, p, p',
#   '\xa0\xa0\xa0\xa0— Jones {2}',
#   '',
#   'Kansas State',
#   '6.75m  22-1¾',
#   '2/26/2016',
#   '\xa0\xa0\xa0\xa0\xa06.57, 6.75, f, p, p, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Jones {2}',
#   '',
#   'Kansas State',
#   '6.75m  22-1¾',
#   '2/26/2016'],
#  ['\xa0\xa0\xa0\xa0\xa06.57, 6.75, f, p, p, p'],
#  ['\xa0\xa0\xa0\xa0— Burks {3}Alabama6.75m  22-1¾2/26/2016\xa0\xa0\xa0\xa0\xa0f, 6.75, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Burks {3}',
#   '',
#   'Alabama',
#   '6.75m  22-1¾',
#   '2/26/2016',
#   '\xa0\xa0\xa0\xa0\xa0f, 6.75, p, p, p, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Burks {3}', '', 'Alabama', '6.75m  22-1¾', '2/26/2016'],
#  ['\xa0\xa0\xa0\xa0\xa0f, 6.75, p, p, p, p'],
#  ["\xa0\xa0\xa0\xa0— Reese {4}JROle Miss6.75m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1¾3/14/2008",
#   '\xa0\xa0\xa0\xa0— Reese {4}JR',
#   '',
#   'Ole Miss',
#   "6.75m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1¾",
#   '3/14/2008'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Reese {4}JR',
#   '',
#   'Ole Miss',
#   "6.75m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1¾",
#   '3/14/2008'],
#  ['(18) Alyssa JONESFRStanford6.74m  22-1½3/10/2023',
#   '(18) Alyssa JONESFR',
#   '',
#   'Stanford',
#   '6.74m  22-1½',
#   '3/10/2023'],
#  [],
#  ['(18) Alyssa JONESFR', '', 'Stanford', '6.74m  22-1½', '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {6}JRFlorida6.74m  22-1½2/10/2023',
#   '\xa0\xa0\xa0\xa0— Moore {6}JR',
#   '',
#   'Florida',
#   '6.74m  22-1½',
#   '2/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {6}JR', '', 'Florida', '6.74m  22-1½', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {3}Auburn6.74m  22-1½3/2/2003',
#   '\xa0\xa0\xa0\xa0— Goulbourne {3}',
#   '',
#   'Auburn',
#   '6.74m  22-1½',
#   '3/2/2003'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {3}',
#   '',
#   'Auburn',
#   '6.74m  22-1½',
#   '3/2/2003'],
#  ["\xa0\xa0\xa0\xa0— Moore {7}JRFlorida6.73m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-12/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {7}JR',
#   '',
#   'Florida',
#   "6.73m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1",
#   '2/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {7}JR',
#   '',
#   'Florida',
#   "6.73m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1",
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Smith {3}FRTexas6.73m  22-112/3/2022\xa0\xa0\xa0\xa0\xa06.73, 6.29, 6.19, p, p, p',
#   '\xa0\xa0\xa0\xa0— Smith {3}FR',
#   '',
#   'Texas',
#   '6.73m  22-1',
#   '12/3/2022',
#   '\xa0\xa0\xa0\xa0\xa06.73, 6.29, 6.19, p, p, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Smith {3}FR', '', 'Texas', '6.73m  22-1', '12/3/2022'],
#  ['\xa0\xa0\xa0\xa0\xa06.73, 6.29, 6.19, p, p, p'],
#  ['(19) Kate HALLJRGeorgia6.73m  22-13/9/2018\xa0\xa0\xa0\xa0\xa06.56, 6.69, 6.73, 6.44, 5.47, p',
#   '(19) Kate HALLJR',
#   '',
#   'Georgia',
#   '6.73m  22-1',
#   '3/9/2018',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.69, 6.73, 6.44, 5.47, p'],
#  [],
#  ['(19) Kate HALLJR', '', 'Georgia', '6.73m  22-1', '3/9/2018'],
#  ['\xa0\xa0\xa0\xa0\xa06.56, 6.69, 6.73, 6.44, 5.47, p'],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}SRKentucky6.73m  22-112/9/2016\xa0\xa0\xa0\xa0\xa06.73, 6.49, 6.51, p, p, p',
#   '\xa0\xa0\xa0\xa0— Saunders {3}SR',
#   '',
#   'Kentucky',
#   '6.73m  22-1',
#   '12/9/2016',
#   '\xa0\xa0\xa0\xa0\xa06.73, 6.49, 6.51, p, p, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}SR',
#   '',
#   'Kentucky',
#   '6.73m  22-1',
#   '12/9/2016'],
#  ['\xa0\xa0\xa0\xa0\xa06.73, 6.49, 6.51, p, p, p'],
#  ['(19) Lorraine UGENTCU6.73m AA = Performance occurred at altitude (>1000 meters above sea level) 22-13/14/2014\xa0\xa0\xa0\xa0\xa06.51, 6.55, 6.41, f, 6.73, f',
#   '(19) Lorraine UGEN',
#   '',
#   'TCU',
#   '6.73m AA = Performance occurred at altitude (>1000 meters above sea level) 22-1',
#   '3/14/2014',
#   '\xa0\xa0\xa0\xa0\xa06.51, 6.55, 6.41, f, 6.73, f'],
#  [],
#  ['(19) Lorraine UGEN',
#   '',
#   'TCU',
#   '6.73m AA = Performance occurred at altitude (>1000 meters above sea level) 22-1',
#   '3/14/2014'],
#  ['\xa0\xa0\xa0\xa0\xa06.51, 6.55, 6.41, f, 6.73, f'],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}LSU6.73m  22-13/12/1994',
#   '\xa0\xa0\xa0\xa0— Saunders {3}',
#   '',
#   'LSU',
#   '6.73m  22-1',
#   '3/12/1994'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}', '', 'LSU', '6.73m  22-1', '3/12/1994'],
#  ['\xa0\xa0\xa0\xa0— Burks {4}SRAlabama6.72m  22-¾3/10/2017\xa0\xa0\xa0\xa0\xa06.64, 6.60, f, 6.65, 6.72, f',
#   '\xa0\xa0\xa0\xa0— Burks {4}SR',
#   '',
#   'Alabama',
#   '6.72m  22-¾',
#   '3/10/2017',
#   '\xa0\xa0\xa0\xa0\xa06.64, 6.60, f, 6.65, 6.72, f'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Burks {4}SR', '', 'Alabama', '6.72m  22-¾', '3/10/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.64, 6.60, f, 6.65, 6.72, f'],
#  ['(21) Keturah ORJIJRGeorgia6.72m  22-¾2/24/2017\xa0\xa0\xa0\xa0\xa06.57, 6.58, 6.70, 6.40, 6.72, 6.55',
#   '(21) Keturah ORJIJR',
#   '',
#   'Georgia',
#   '6.72m  22-¾',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.57, 6.58, 6.70, 6.40, 6.72, 6.55'],
#  [],
#  ['(21) Keturah ORJIJR', '', 'Georgia', '6.72m  22-¾', '2/24/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.57, 6.58, 6.70, 6.40, 6.72, 6.55'],
#  ["\xa0\xa0\xa0\xa0— Madison {2}SOTennessee6.72m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¾3/11/2005",
#   '\xa0\xa0\xa0\xa0— Madison {2}SO',
#   '',
#   'Tennessee',
#   "6.72m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¾",
#   '3/11/2005'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Madison {2}SO',
#   '',
#   'Tennessee',
#   "6.72m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¾",
#   '3/11/2005'],
#  ["\xa0\xa0\xa0\xa0— Davis {2}JRTexas6.71m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¼3/12/2021",
#   '\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Texas',
#   "6.71m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¼",
#   '3/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Texas',
#   "6.71m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¼",
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Burks {5}Alabama6.71m  22-¼1/23/2016\xa0\xa0\xa0\xa0\xa06.08, 6.21, 6.31, f, 6.39, 6.71',
#   '\xa0\xa0\xa0\xa0— Burks {5}',
#   '',
#   'Alabama',
#   '6.71m  22-¼',
#   '1/23/2016',
#   '\xa0\xa0\xa0\xa0\xa06.08, 6.21, 6.31, f, 6.39, 6.71'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Burks {5}', '', 'Alabama', '6.71m  22-¼', '1/23/2016'],
#  ['\xa0\xa0\xa0\xa0\xa06.08, 6.21, 6.31, f, 6.39, 6.71'],
#  ['(22) Marshavet HOOKERTexas6.71m  22-¼3/10/2006\xa0\xa0\xa0\xa0\xa04.32, 6.34, 6.60, 6.11, 6.71, p',
#   '(22) Marshavet HOOKER',
#   '',
#   'Texas',
#   '6.71m  22-¼',
#   '3/10/2006',
#   '\xa0\xa0\xa0\xa0\xa04.32, 6.34, 6.60, 6.11, 6.71, p'],
#  [],
#  ['(22) Marshavet HOOKER', '', 'Texas', '6.71m  22-¼', '3/10/2006'],
#  ['\xa0\xa0\xa0\xa0\xa04.32, 6.34, 6.60, 6.11, 6.71, p'],
#  ['\xa0\xa0\xa0\xa0— Madison {3}Tennessee6.71m  22-¼2/27/2005',
#   '\xa0\xa0\xa0\xa0— Madison {3}',
#   '',
#   'Tennessee',
#   '6.71m  22-¼',
#   '2/27/2005'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Madison {3}',
#   '',
#   'Tennessee',
#   '6.71m  22-¼',
#   '2/27/2005'],
#  ['(22) Dedra DAVISTennessee6.71m  22-¼3/11/1994',
#   '(22) Dedra DAVIS',
#   '',
#   'Tennessee',
#   '6.71m  22-¼',
#   '3/11/1994'],
#  [],
#  ['(22) Dedra DAVIS', '', 'Tennessee', '6.71m  22-¼', '3/11/1994'],
#  ["\xa0\xa0\xa0\xa0— Moore {8}JRFlorida6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾2/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {8}JR',
#   '',
#   'Florida',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {8}JR',
#   '',
#   'Florida',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Bryant {2}FRFlorida6.70m  21-11¾3/12/2021',
#   '\xa0\xa0\xa0\xa0— Bryant {2}FR',
#   '',
#   'Florida',
#   '6.70m  21-11¾',
#   '3/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Bryant {2}FR',
#   '',
#   'Florida',
#   '6.70m  21-11¾',
#   '3/12/2021'],
#  ["\xa0\xa0\xa0\xa0— Saunders {4}SRKentucky6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾3/10/2017",
#   '\xa0\xa0\xa0\xa0— Saunders {4}SR',
#   '',
#   'Kentucky',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '3/10/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Saunders {4}SR',
#   '',
#   'Kentucky',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '3/10/2017'],
#  ["\xa0\xa0\xa0\xa0— Orji {2}JRGeorgia6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾2/24/2017",
#   '\xa0\xa0\xa0\xa0— Orji {2}JR',
#   '',
#   'Georgia',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/24/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Orji {2}JR',
#   '',
#   'Georgia',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/24/2017'],
#  ['(24) Jeomi MADUKACornell6.70m  21-11¾2/14/2009',
#   '(24) Jeomi MADUKA',
#   '',
#   'Cornell',
#   '6.70m  21-11¾',
#   '2/14/2009'],
#  [],
#  ['(24) Jeomi MADUKA', '', 'Cornell', '6.70m  21-11¾', '2/14/2009'],
#  ['(24) Sheila ECHOLSLSU6.70m  21-11¾2/28/1987',
#   '(24) Sheila ECHOLS',
#   '',
#   'LSU',
#   '6.70m  21-11¾',
#   '2/28/1987'],
#  [],
#  ['(24) Sheila ECHOLS', '', 'LSU', '6.70m  21-11¾', '2/28/1987'],
#  ['', '', '', '']]

# %%
len(rows3)
# Out:
# 193

# %%
RealRows3 = []

# %%
for i in range(0,193):
        RealRows3.append(rows3[i])

# %%
RealRows3
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Jasmine MOOREJRFlorida7.03m📺  23-¾3/10/2023',
#   '(1) Jasmine MOOREJR',
#   '',
#   'Florida',
#   '7.03m📺  23-¾',
#   '3/10/2023'],
#  [],
#  ['(1) Jasmine MOOREJR', '', 'Florida', '7.03m📺  23-¾', '3/10/2023'],
#  ['(2) Tara DAVISJRTexas6.93m  22-93/12/2021',
#   '(2) Tara DAVISJR',
#   '',
#   'Texas',
#   '6.93m  22-9',
#   '3/12/2021'],
#  [],
#  ['(2) Tara DAVISJR', '', 'Texas', '6.93m  22-9', '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Moore {2}JRFlorida6.91m  22-82/24/2023',
#   '\xa0\xa0\xa0\xa0— Moore {2}JR',
#   '',
#   'Florida',
#   '6.91m  22-8',
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {2}JR', '', 'Florida', '6.91m  22-8', '2/24/2023'],
#  ['(3) Whitney GIPSONSRTCU6.91m  22-83/9/2012\xa0\xa0\xa0\xa0\xa06.64, 6.30, FOUL., FOUL, 6.91, 6.22',
#   '(3) Whitney GIPSONSR',
#   '',
#   'TCU',
#   '6.91m  22-8',
#   '3/9/2012',
#   '\xa0\xa0\xa0\xa0\xa06.64, 6.30, FOUL., FOUL, 6.91, 6.22'],
#  [],
#  ['(3) Whitney GIPSONSR', '', 'TCU', '6.91m  22-8', '3/9/2012'],
#  ['\xa0\xa0\xa0\xa0\xa06.64, 6.30, FOUL., FOUL, 6.91, 6.22'],
#  ['(3) Elva GOULBOURNEAuburn6.91m  22-82/23/2002',
#   '(3) Elva GOULBOURNE',
#   '',
#   'Auburn',
#   '6.91m  22-8',
#   '2/23/2002'],
#  [],
#  ['(3) Elva GOULBOURNE', '', 'Auburn', '6.91m  22-8', '2/23/2002'],
#  ["(5) Sha'Keela SAUNDERSSRKentucky6.90m  22-7¾3/10/2017\xa0\xa0\xa0\xa0\xa06.42, 6.70, 6.55, f, 6.62, 6.90",
#   "(5) Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.90m  22-7¾',
#   '3/10/2017',
#   '\xa0\xa0\xa0\xa0\xa06.42, 6.70, 6.55, f, 6.62, 6.90'],
#  [],
#  ["(5) Sha'Keela SAUNDERSSR", '', 'Kentucky', '6.90m  22-7¾', '3/10/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.42, 6.70, 6.55, f, 6.62, 6.90'],
#  ['(6) Ackelia SMITHFRTexas6.88m  22-73/10/2023',
#   '(6) Ackelia SMITHFR',
#   '',
#   'Texas',
#   '6.88m  22-7',
#   '3/10/2023'],
#  [],
#  ['(6) Ackelia SMITHFR', '', 'Texas', '6.88m  22-7', '3/10/2023'],
#  ['(6) Claire  BRYANTJRFlorida6.88m  22-73/10/2023',
#   '(6) Claire  BRYANTJR',
#   '',
#   'Florida',
#   '6.88m  22-7',
#   '3/10/2023'],
#  [],
#  ['(6) Claire  BRYANTJR', '', 'Florida', '6.88m  22-7', '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Smith {2}FRTexas6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½3/10/2023",
#   '\xa0\xa0\xa0\xa0— Smith {2}FR',
#   '',
#   'Texas',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Smith {2}FR',
#   '',
#   'Texas',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Moore {3}JRFlorida6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½3/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  ['(8) Blessing OKAGBAREUTEP6.87m  22-6½3/12/2010\xa0\xa0\xa0\xa0\xa06.48, 6.84, 6.87, p, p, 6.57',
#   '(8) Blessing OKAGBARE',
#   '',
#   'UTEP',
#   '6.87m  22-6½',
#   '3/12/2010',
#   '\xa0\xa0\xa0\xa0\xa06.48, 6.84, 6.87, p, p, 6.57'],
#  [],
#  ['(8) Blessing OKAGBARE', '', 'UTEP', '6.87m  22-6½', '3/12/2010'],
#  ['\xa0\xa0\xa0\xa0\xa06.48, 6.84, 6.87, p, p, 6.57'],
#  ['(8) Brittney REESEOle Miss6.87m  22-6½3/1/2008',
#   '(8) Brittney REESE',
#   '',
#   'Ole Miss',
#   '6.87m  22-6½',
#   '3/1/2008'],
#  [],
#  ['(8) Brittney REESE', '', 'Ole Miss', '6.87m  22-6½', '3/1/2008'],
#  ["\xa0\xa0\xa0\xa0— Moore {4}JRFlorida6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼2/24/2023",
#   '\xa0\xa0\xa0\xa0— Moore {4}JR',
#   '',
#   'Florida',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼",
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {4}JR',
#   '',
#   'Florida',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼",
#   '2/24/2023'],
#  ["\xa0\xa0\xa0\xa0— Okagbare {2}SRUTEP6.84m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¼3/12/2010",
#   '\xa0\xa0\xa0\xa0— Okagbare {2}SR',
#   '',
#   'UTEP',
#   "6.84m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¼",
#   '3/12/2010'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Okagbare {2}SR',
#   '',
#   'UTEP',
#   "6.84m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¼",
#   '3/12/2010'],
#  ['(10) Ruth USOROSRTexas Tech6.82m  22-4½2/26/2021',
#   '(10) Ruth USOROSR',
#   '',
#   'Texas Tech',
#   '6.82m  22-4½',
#   '2/26/2021'],
#  [],
#  ['(10) Ruth USOROSR', '', 'Texas Tech', '6.82m  22-4½', '2/26/2021'],
#  ['\xa0\xa0\xa0\xa0— Saunders {2}SRKentucky6.82m  22-4½2/24/2017\xa0\xa0\xa0\xa0\xa06.67, 6.59, f, 6.56, 6.82, 6.55',
#   '\xa0\xa0\xa0\xa0— Saunders {2}SR',
#   '',
#   'Kentucky',
#   '6.82m  22-4½',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.67, 6.59, f, 6.56, 6.82, 6.55'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Saunders {2}SR',
#   '',
#   'Kentucky',
#   '6.82m  22-4½',
#   '2/24/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.67, 6.59, f, 6.56, 6.82, 6.55'],
#  ['(10) Daphne SAUNDERSLSU6.82m  22-4½2/26/1994',
#   '(10) Daphne SAUNDERS',
#   '',
#   'LSU',
#   '6.82m  22-4½',
#   '2/26/1994'],
#  [],
#  ['(10) Daphne SAUNDERS', '', 'LSU', '6.82m  22-4½', '2/26/1994'],
#  ['\xa0\xa0\xa0\xa0— Reese {2}Ole Miss6.81m  22-4¼2/15/2008\xa0\xa0\xa0\xa0\xa06.81, f, 6.53, 6.55, p, p',
#   '\xa0\xa0\xa0\xa0— Reese {2}',
#   '',
#   'Ole Miss',
#   '6.81m  22-4¼',
#   '2/15/2008',
#   '\xa0\xa0\xa0\xa0\xa06.81, f, 6.53, 6.55, p, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Reese {2}', '', 'Ole Miss', '6.81m  22-4¼', '2/15/2008'],
#  ['\xa0\xa0\xa0\xa0\xa06.81, f, 6.53, 6.55, p, p'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}SRAuburn6.81m  22-4¼3/14/2003\xa0\xa0\xa0\xa0\xa06.81, p, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Goulbourne {2}SR',
#   '',
#   'Auburn',
#   '6.81m  22-4¼',
#   '3/14/2003',
#   '\xa0\xa0\xa0\xa0\xa06.81, p, p, p, p, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}SR',
#   '',
#   'Auburn',
#   '6.81m  22-4¼',
#   '3/14/2003'],
#  ['\xa0\xa0\xa0\xa0\xa06.81, p, p, p, p, p'],
#  ['(12) Quanesha BURKSJRAlabama6.80m  22-3¾3/11/2016\xa0\xa0\xa0\xa0\xa06.56, 6.57, 6.67, 6.27, 6.47, 6.80',
#   '(12) Quanesha BURKSJR',
#   '',
#   'Alabama',
#   '6.80m  22-3¾',
#   '3/11/2016',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.57, 6.67, 6.27, 6.47, 6.80'],
#  [],
#  ['(12) Quanesha BURKSJR', '', 'Alabama', '6.80m  22-3¾', '3/11/2016'],
#  ['\xa0\xa0\xa0\xa0\xa06.56, 6.57, 6.67, 6.27, 6.47, 6.80'],
#  ['(12) Akela JONESSRKansas State6.80m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-3¾3/11/2016\xa0\xa0\xa0\xa0\xa06.56, 6.67, 6.80',
#   '(12) Akela JONESSR',
#   '',
#   'Kansas State',
#   '6.80m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-3¾',
#   '3/11/2016',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.67, 6.80'],
#  [],
#  ['(12) Akela JONESSR',
#   '',
#   'Kansas State',
#   '6.80m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-3¾',
#   '3/11/2016'],
#  ['\xa0\xa0\xa0\xa0\xa06.56, 6.67, 6.80'],
#  ['(14) Alysah HICKEYJROregon6.79m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3½2/10/2023\xa0\xa0\xa0\xa0\xa06.79, f, f, f, 6.41, f',
#   '(14) Alysah HICKEYJR',
#   '',
#   'Oregon',
#   '6.79m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3½',
#   '2/10/2023',
#   '\xa0\xa0\xa0\xa0\xa06.79, f, f, f, 6.41, f'],
#  [],
#  ['(14) Alysah HICKEYJR',
#   '',
#   'Oregon',
#   '6.79m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3½',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0\xa06.79, f, f, f, 6.41, f'],
#  ['(15) Tianna MADISONSOTennessee6.78m  22-33/11/2005\xa0\xa0\xa0\xa0\xa06.49, 6.72, 6.78, p, p, p',
#   '(15) Tianna MADISONSO',
#   '',
#   'Tennessee',
#   '6.78m  22-3',
#   '3/11/2005',
#   '\xa0\xa0\xa0\xa0\xa06.49, 6.72, 6.78, p, p, p'],
#  [],
#  ['(15) Tianna MADISONSO', '', 'Tennessee', '6.78m  22-3', '3/11/2005'],
#  ['\xa0\xa0\xa0\xa0\xa06.49, 6.72, 6.78, p, p, p'],
#  ['(15) Carol LEWISHouston6.78m  22-32/2/1985',
#   '(15) Carol LEWIS',
#   '',
#   'Houston',
#   '6.78m  22-3',
#   '2/2/1985'],
#  [],
#  ['(15) Carol LEWIS', '', 'Houston', '6.78m  22-3', '2/2/1985'],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SRAlabama6.76m  22-2¼2/24/2017\xa0\xa0\xa0\xa0\xa06.54, 6.61, 6.76, 6.38, 5.85, p',
#   '\xa0\xa0\xa0\xa0— Burks {2}SR',
#   '',
#   'Alabama',
#   '6.76m  22-2¼',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.54, 6.61, 6.76, 6.38, 5.85, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SR', '', 'Alabama', '6.76m  22-2¼', '2/24/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.54, 6.61, 6.76, 6.38, 5.85, p'],
#  ['\xa0\xa0\xa0\xa0— Reese {3}JROle Miss6.76m  22-2¼3/14/2008\xa0\xa0\xa0\xa0\xa06.56, 6.76, 6.69, 6.70, 6.56, 6.75',
#   '\xa0\xa0\xa0\xa0— Reese {3}JR',
#   '',
#   'Ole Miss',
#   '6.76m  22-2¼',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.76, 6.69, 6.70, 6.56, 6.75'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Reese {3}JR',
#   '',
#   'Ole Miss',
#   '6.76m  22-2¼',
#   '3/14/2008'],
#  ['\xa0\xa0\xa0\xa0\xa06.56, 6.76, 6.69, 6.70, 6.56, 6.75'],
#  ["\xa0\xa0\xa0\xa0— Saunders {2}LSU6.76m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-2¼2/26/1994",
#   '\xa0\xa0\xa0\xa0— Saunders {2}',
#   '',
#   'LSU',
#   "6.76m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-2¼",
#   '2/26/1994'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Saunders {2}',
#   '',
#   'LSU',
#   "6.76m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-2¼",
#   '2/26/1994'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston6.76m  22-2¼2/4/1984',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '6.76m  22-2¼',
#   '2/4/1984'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}', '', 'Houston', '6.76m  22-2¼', '2/4/1984'],
#  ['\xa0\xa0\xa0\xa0— Moore {5}SOFlorida6.75m  22-1¾2/25/2022',
#   '\xa0\xa0\xa0\xa0— Moore {5}SO',
#   '',
#   'Florida',
#   '6.75m  22-1¾',
#   '2/25/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {5}SO', '', 'Florida', '6.75m  22-1¾', '2/25/2022'],
#  ["(17) Monae' NICHOLSSRTexas Tech6.75m  22-1¾1/23/2021",
#   "(17) Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.75m  22-1¾',
#   '1/23/2021'],
#  [],
#  ["(17) Monae' NICHOLSSR", '', 'Texas Tech', '6.75m  22-1¾', '1/23/2021'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}Kansas State6.75m  22-1¾2/26/2016\xa0\xa0\xa0\xa0\xa06.57, 6.75, f, p, p, p',
#   '\xa0\xa0\xa0\xa0— Jones {2}',
#   '',
#   'Kansas State',
#   '6.75m  22-1¾',
#   '2/26/2016',
#   '\xa0\xa0\xa0\xa0\xa06.57, 6.75, f, p, p, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Jones {2}',
#   '',
#   'Kansas State',
#   '6.75m  22-1¾',
#   '2/26/2016'],
#  ['\xa0\xa0\xa0\xa0\xa06.57, 6.75, f, p, p, p'],
#  ['\xa0\xa0\xa0\xa0— Burks {3}Alabama6.75m  22-1¾2/26/2016\xa0\xa0\xa0\xa0\xa0f, 6.75, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Burks {3}',
#   '',
#   'Alabama',
#   '6.75m  22-1¾',
#   '2/26/2016',
#   '\xa0\xa0\xa0\xa0\xa0f, 6.75, p, p, p, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Burks {3}', '', 'Alabama', '6.75m  22-1¾', '2/26/2016'],
#  ['\xa0\xa0\xa0\xa0\xa0f, 6.75, p, p, p, p'],
#  ["\xa0\xa0\xa0\xa0— Reese {4}JROle Miss6.75m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1¾3/14/2008",
#   '\xa0\xa0\xa0\xa0— Reese {4}JR',
#   '',
#   'Ole Miss',
#   "6.75m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1¾",
#   '3/14/2008'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Reese {4}JR',
#   '',
#   'Ole Miss',
#   "6.75m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1¾",
#   '3/14/2008'],
#  ['(18) Alyssa JONESFRStanford6.74m  22-1½3/10/2023',
#   '(18) Alyssa JONESFR',
#   '',
#   'Stanford',
#   '6.74m  22-1½',
#   '3/10/2023'],
#  [],
#  ['(18) Alyssa JONESFR', '', 'Stanford', '6.74m  22-1½', '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {6}JRFlorida6.74m  22-1½2/10/2023',
#   '\xa0\xa0\xa0\xa0— Moore {6}JR',
#   '',
#   'Florida',
#   '6.74m  22-1½',
#   '2/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {6}JR', '', 'Florida', '6.74m  22-1½', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {3}Auburn6.74m  22-1½3/2/2003',
#   '\xa0\xa0\xa0\xa0— Goulbourne {3}',
#   '',
#   'Auburn',
#   '6.74m  22-1½',
#   '3/2/2003'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {3}',
#   '',
#   'Auburn',
#   '6.74m  22-1½',
#   '3/2/2003'],
#  ["\xa0\xa0\xa0\xa0— Moore {7}JRFlorida6.73m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-12/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {7}JR',
#   '',
#   'Florida',
#   "6.73m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1",
#   '2/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {7}JR',
#   '',
#   'Florida',
#   "6.73m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1",
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Smith {3}FRTexas6.73m  22-112/3/2022\xa0\xa0\xa0\xa0\xa06.73, 6.29, 6.19, p, p, p',
#   '\xa0\xa0\xa0\xa0— Smith {3}FR',
#   '',
#   'Texas',
#   '6.73m  22-1',
#   '12/3/2022',
#   '\xa0\xa0\xa0\xa0\xa06.73, 6.29, 6.19, p, p, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Smith {3}FR', '', 'Texas', '6.73m  22-1', '12/3/2022'],
#  ['\xa0\xa0\xa0\xa0\xa06.73, 6.29, 6.19, p, p, p'],
#  ['(19) Kate HALLJRGeorgia6.73m  22-13/9/2018\xa0\xa0\xa0\xa0\xa06.56, 6.69, 6.73, 6.44, 5.47, p',
#   '(19) Kate HALLJR',
#   '',
#   'Georgia',
#   '6.73m  22-1',
#   '3/9/2018',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.69, 6.73, 6.44, 5.47, p'],
#  [],
#  ['(19) Kate HALLJR', '', 'Georgia', '6.73m  22-1', '3/9/2018'],
#  ['\xa0\xa0\xa0\xa0\xa06.56, 6.69, 6.73, 6.44, 5.47, p'],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}SRKentucky6.73m  22-112/9/2016\xa0\xa0\xa0\xa0\xa06.73, 6.49, 6.51, p, p, p',
#   '\xa0\xa0\xa0\xa0— Saunders {3}SR',
#   '',
#   'Kentucky',
#   '6.73m  22-1',
#   '12/9/2016',
#   '\xa0\xa0\xa0\xa0\xa06.73, 6.49, 6.51, p, p, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}SR',
#   '',
#   'Kentucky',
#   '6.73m  22-1',
#   '12/9/2016'],
#  ['\xa0\xa0\xa0\xa0\xa06.73, 6.49, 6.51, p, p, p'],
#  ['(19) Lorraine UGENTCU6.73m AA = Performance occurred at altitude (>1000 meters above sea level) 22-13/14/2014\xa0\xa0\xa0\xa0\xa06.51, 6.55, 6.41, f, 6.73, f',
#   '(19) Lorraine UGEN',
#   '',
#   'TCU',
#   '6.73m AA = Performance occurred at altitude (>1000 meters above sea level) 22-1',
#   '3/14/2014',
#   '\xa0\xa0\xa0\xa0\xa06.51, 6.55, 6.41, f, 6.73, f'],
#  [],
#  ['(19) Lorraine UGEN',
#   '',
#   'TCU',
#   '6.73m AA = Performance occurred at altitude (>1000 meters above sea level) 22-1',
#   '3/14/2014'],
#  ['\xa0\xa0\xa0\xa0\xa06.51, 6.55, 6.41, f, 6.73, f'],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}LSU6.73m  22-13/12/1994',
#   '\xa0\xa0\xa0\xa0— Saunders {3}',
#   '',
#   'LSU',
#   '6.73m  22-1',
#   '3/12/1994'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}', '', 'LSU', '6.73m  22-1', '3/12/1994'],
#  ['\xa0\xa0\xa0\xa0— Burks {4}SRAlabama6.72m  22-¾3/10/2017\xa0\xa0\xa0\xa0\xa06.64, 6.60, f, 6.65, 6.72, f',
#   '\xa0\xa0\xa0\xa0— Burks {4}SR',
#   '',
#   'Alabama',
#   '6.72m  22-¾',
#   '3/10/2017',
#   '\xa0\xa0\xa0\xa0\xa06.64, 6.60, f, 6.65, 6.72, f'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Burks {4}SR', '', 'Alabama', '6.72m  22-¾', '3/10/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.64, 6.60, f, 6.65, 6.72, f'],
#  ['(21) Keturah ORJIJRGeorgia6.72m  22-¾2/24/2017\xa0\xa0\xa0\xa0\xa06.57, 6.58, 6.70, 6.40, 6.72, 6.55',
#   '(21) Keturah ORJIJR',
#   '',
#   'Georgia',
#   '6.72m  22-¾',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.57, 6.58, 6.70, 6.40, 6.72, 6.55'],
#  [],
#  ['(21) Keturah ORJIJR', '', 'Georgia', '6.72m  22-¾', '2/24/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.57, 6.58, 6.70, 6.40, 6.72, 6.55'],
#  ["\xa0\xa0\xa0\xa0— Madison {2}SOTennessee6.72m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¾3/11/2005",
#   '\xa0\xa0\xa0\xa0— Madison {2}SO',
#   '',
#   'Tennessee',
#   "6.72m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¾",
#   '3/11/2005'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Madison {2}SO',
#   '',
#   'Tennessee',
#   "6.72m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¾",
#   '3/11/2005'],
#  ["\xa0\xa0\xa0\xa0— Davis {2}JRTexas6.71m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¼3/12/2021",
#   '\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Texas',
#   "6.71m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¼",
#   '3/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Texas',
#   "6.71m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¼",
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Burks {5}Alabama6.71m  22-¼1/23/2016\xa0\xa0\xa0\xa0\xa06.08, 6.21, 6.31, f, 6.39, 6.71',
#   '\xa0\xa0\xa0\xa0— Burks {5}',
#   '',
#   'Alabama',
#   '6.71m  22-¼',
#   '1/23/2016',
#   '\xa0\xa0\xa0\xa0\xa06.08, 6.21, 6.31, f, 6.39, 6.71'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Burks {5}', '', 'Alabama', '6.71m  22-¼', '1/23/2016'],
#  ['\xa0\xa0\xa0\xa0\xa06.08, 6.21, 6.31, f, 6.39, 6.71'],
#  ['(22) Marshavet HOOKERTexas6.71m  22-¼3/10/2006\xa0\xa0\xa0\xa0\xa04.32, 6.34, 6.60, 6.11, 6.71, p',
#   '(22) Marshavet HOOKER',
#   '',
#   'Texas',
#   '6.71m  22-¼',
#   '3/10/2006',
#   '\xa0\xa0\xa0\xa0\xa04.32, 6.34, 6.60, 6.11, 6.71, p'],
#  [],
#  ['(22) Marshavet HOOKER', '', 'Texas', '6.71m  22-¼', '3/10/2006'],
#  ['\xa0\xa0\xa0\xa0\xa04.32, 6.34, 6.60, 6.11, 6.71, p'],
#  ['\xa0\xa0\xa0\xa0— Madison {3}Tennessee6.71m  22-¼2/27/2005',
#   '\xa0\xa0\xa0\xa0— Madison {3}',
#   '',
#   'Tennessee',
#   '6.71m  22-¼',
#   '2/27/2005'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Madison {3}',
#   '',
#   'Tennessee',
#   '6.71m  22-¼',
#   '2/27/2005'],
#  ['(22) Dedra DAVISTennessee6.71m  22-¼3/11/1994',
#   '(22) Dedra DAVIS',
#   '',
#   'Tennessee',
#   '6.71m  22-¼',
#   '3/11/1994'],
#  [],
#  ['(22) Dedra DAVIS', '', 'Tennessee', '6.71m  22-¼', '3/11/1994'],
#  ["\xa0\xa0\xa0\xa0— Moore {8}JRFlorida6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾2/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {8}JR',
#   '',
#   'Florida',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {8}JR',
#   '',
#   'Florida',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Bryant {2}FRFlorida6.70m  21-11¾3/12/2021',
#   '\xa0\xa0\xa0\xa0— Bryant {2}FR',
#   '',
#   'Florida',
#   '6.70m  21-11¾',
#   '3/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Bryant {2}FR',
#   '',
#   'Florida',
#   '6.70m  21-11¾',
#   '3/12/2021'],
#  ["\xa0\xa0\xa0\xa0— Saunders {4}SRKentucky6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾3/10/2017",
#   '\xa0\xa0\xa0\xa0— Saunders {4}SR',
#   '',
#   'Kentucky',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '3/10/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Saunders {4}SR',
#   '',
#   'Kentucky',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '3/10/2017'],
#  ["\xa0\xa0\xa0\xa0— Orji {2}JRGeorgia6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾2/24/2017",
#   '\xa0\xa0\xa0\xa0— Orji {2}JR',
#   '',
#   'Georgia',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/24/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Orji {2}JR',
#   '',
#   'Georgia',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/24/2017'],
#  ['(24) Jeomi MADUKACornell6.70m  21-11¾2/14/2009',
#   '(24) Jeomi MADUKA',
#   '',
#   'Cornell',
#   '6.70m  21-11¾',
#   '2/14/2009'],
#  [],
#  ['(24) Jeomi MADUKA', '', 'Cornell', '6.70m  21-11¾', '2/14/2009'],
#  ['(24) Sheila ECHOLSLSU6.70m  21-11¾2/28/1987',
#   '(24) Sheila ECHOLS',
#   '',
#   'LSU',
#   '6.70m  21-11¾',
#   '2/28/1987'],
#  [],
#  ['(24) Sheila ECHOLS', '', 'LSU', '6.70m  21-11¾', '2/28/1987'],
#  ['', '', '', '']]

# %%
RealRows = []

# %%
for i in range(0,193):
    if len(RealRows3[i]) > 1:
        RealRows.append(RealRows3[i])

# %%
RealRows
# Out:
# [['(1) Jasmine MOOREJRFlorida7.03m📺  23-¾3/10/2023',
#   '(1) Jasmine MOOREJR',
#   '',
#   'Florida',
#   '7.03m📺  23-¾',
#   '3/10/2023'],
#  ['(1) Jasmine MOOREJR', '', 'Florida', '7.03m📺  23-¾', '3/10/2023'],
#  ['(2) Tara DAVISJRTexas6.93m  22-93/12/2021',
#   '(2) Tara DAVISJR',
#   '',
#   'Texas',
#   '6.93m  22-9',
#   '3/12/2021'],
#  ['(2) Tara DAVISJR', '', 'Texas', '6.93m  22-9', '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Moore {2}JRFlorida6.91m  22-82/24/2023',
#   '\xa0\xa0\xa0\xa0— Moore {2}JR',
#   '',
#   'Florida',
#   '6.91m  22-8',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {2}JR', '', 'Florida', '6.91m  22-8', '2/24/2023'],
#  ['(3) Whitney GIPSONSRTCU6.91m  22-83/9/2012\xa0\xa0\xa0\xa0\xa06.64, 6.30, FOUL., FOUL, 6.91, 6.22',
#   '(3) Whitney GIPSONSR',
#   '',
#   'TCU',
#   '6.91m  22-8',
#   '3/9/2012',
#   '\xa0\xa0\xa0\xa0\xa06.64, 6.30, FOUL., FOUL, 6.91, 6.22'],
#  ['(3) Whitney GIPSONSR', '', 'TCU', '6.91m  22-8', '3/9/2012'],
#  ['(3) Elva GOULBOURNEAuburn6.91m  22-82/23/2002',
#   '(3) Elva GOULBOURNE',
#   '',
#   'Auburn',
#   '6.91m  22-8',
#   '2/23/2002'],
#  ['(3) Elva GOULBOURNE', '', 'Auburn', '6.91m  22-8', '2/23/2002'],
#  ["(5) Sha'Keela SAUNDERSSRKentucky6.90m  22-7¾3/10/2017\xa0\xa0\xa0\xa0\xa06.42, 6.70, 6.55, f, 6.62, 6.90",
#   "(5) Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.90m  22-7¾',
#   '3/10/2017',
#   '\xa0\xa0\xa0\xa0\xa06.42, 6.70, 6.55, f, 6.62, 6.90'],
#  ["(5) Sha'Keela SAUNDERSSR", '', 'Kentucky', '6.90m  22-7¾', '3/10/2017'],
#  ['(6) Ackelia SMITHFRTexas6.88m  22-73/10/2023',
#   '(6) Ackelia SMITHFR',
#   '',
#   'Texas',
#   '6.88m  22-7',
#   '3/10/2023'],
#  ['(6) Ackelia SMITHFR', '', 'Texas', '6.88m  22-7', '3/10/2023'],
#  ['(6) Claire  BRYANTJRFlorida6.88m  22-73/10/2023',
#   '(6) Claire  BRYANTJR',
#   '',
#   'Florida',
#   '6.88m  22-7',
#   '3/10/2023'],
#  ['(6) Claire  BRYANTJR', '', 'Florida', '6.88m  22-7', '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Smith {2}FRTexas6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½3/10/2023",
#   '\xa0\xa0\xa0\xa0— Smith {2}FR',
#   '',
#   'Texas',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Smith {2}FR',
#   '',
#   'Texas',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Moore {3}JRFlorida6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½3/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  ['(8) Blessing OKAGBAREUTEP6.87m  22-6½3/12/2010\xa0\xa0\xa0\xa0\xa06.48, 6.84, 6.87, p, p, 6.57',
#   '(8) Blessing OKAGBARE',
#   '',
#   'UTEP',
#   '6.87m  22-6½',
#   '3/12/2010',
#   '\xa0\xa0\xa0\xa0\xa06.48, 6.84, 6.87, p, p, 6.57'],
#  ['(8) Blessing OKAGBARE', '', 'UTEP', '6.87m  22-6½', '3/12/2010'],
#  ['(8) Brittney REESEOle Miss6.87m  22-6½3/1/2008',
#   '(8) Brittney REESE',
#   '',
#   'Ole Miss',
#   '6.87m  22-6½',
#   '3/1/2008'],
#  ['(8) Brittney REESE', '', 'Ole Miss', '6.87m  22-6½', '3/1/2008'],
#  ["\xa0\xa0\xa0\xa0— Moore {4}JRFlorida6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼2/24/2023",
#   '\xa0\xa0\xa0\xa0— Moore {4}JR',
#   '',
#   'Florida',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼",
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {4}JR',
#   '',
#   'Florida',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼",
#   '2/24/2023'],
#  ["\xa0\xa0\xa0\xa0— Okagbare {2}SRUTEP6.84m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¼3/12/2010",
#   '\xa0\xa0\xa0\xa0— Okagbare {2}SR',
#   '',
#   'UTEP',
#   "6.84m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¼",
#   '3/12/2010'],
#  ['\xa0\xa0\xa0\xa0— Okagbare {2}SR',
#   '',
#   'UTEP',
#   "6.84m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¼",
#   '3/12/2010'],
#  ['(10) Ruth USOROSRTexas Tech6.82m  22-4½2/26/2021',
#   '(10) Ruth USOROSR',
#   '',
#   'Texas Tech',
#   '6.82m  22-4½',
#   '2/26/2021'],
#  ['(10) Ruth USOROSR', '', 'Texas Tech', '6.82m  22-4½', '2/26/2021'],
#  ['\xa0\xa0\xa0\xa0— Saunders {2}SRKentucky6.82m  22-4½2/24/2017\xa0\xa0\xa0\xa0\xa06.67, 6.59, f, 6.56, 6.82, 6.55',
#   '\xa0\xa0\xa0\xa0— Saunders {2}SR',
#   '',
#   'Kentucky',
#   '6.82m  22-4½',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.67, 6.59, f, 6.56, 6.82, 6.55'],
#  ['\xa0\xa0\xa0\xa0— Saunders {2}SR',
#   '',
#   'Kentucky',
#   '6.82m  22-4½',
#   '2/24/2017'],
#  ['(10) Daphne SAUNDERSLSU6.82m  22-4½2/26/1994',
#   '(10) Daphne SAUNDERS',
#   '',
#   'LSU',
#   '6.82m  22-4½',
#   '2/26/1994'],
#  ['(10) Daphne SAUNDERS', '', 'LSU', '6.82m  22-4½', '2/26/1994'],
#  ['\xa0\xa0\xa0\xa0— Reese {2}Ole Miss6.81m  22-4¼2/15/2008\xa0\xa0\xa0\xa0\xa06.81, f, 6.53, 6.55, p, p',
#   '\xa0\xa0\xa0\xa0— Reese {2}',
#   '',
#   'Ole Miss',
#   '6.81m  22-4¼',
#   '2/15/2008',
#   '\xa0\xa0\xa0\xa0\xa06.81, f, 6.53, 6.55, p, p'],
#  ['\xa0\xa0\xa0\xa0— Reese {2}', '', 'Ole Miss', '6.81m  22-4¼', '2/15/2008'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}SRAuburn6.81m  22-4¼3/14/2003\xa0\xa0\xa0\xa0\xa06.81, p, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Goulbourne {2}SR',
#   '',
#   'Auburn',
#   '6.81m  22-4¼',
#   '3/14/2003',
#   '\xa0\xa0\xa0\xa0\xa06.81, p, p, p, p, p'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}SR',
#   '',
#   'Auburn',
#   '6.81m  22-4¼',
#   '3/14/2003'],
#  ['(12) Quanesha BURKSJRAlabama6.80m  22-3¾3/11/2016\xa0\xa0\xa0\xa0\xa06.56, 6.57, 6.67, 6.27, 6.47, 6.80',
#   '(12) Quanesha BURKSJR',
#   '',
#   'Alabama',
#   '6.80m  22-3¾',
#   '3/11/2016',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.57, 6.67, 6.27, 6.47, 6.80'],
#  ['(12) Quanesha BURKSJR', '', 'Alabama', '6.80m  22-3¾', '3/11/2016'],
#  ['(12) Akela JONESSRKansas State6.80m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-3¾3/11/2016\xa0\xa0\xa0\xa0\xa06.56, 6.67, 6.80',
#   '(12) Akela JONESSR',
#   '',
#   'Kansas State',
#   '6.80m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-3¾',
#   '3/11/2016',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.67, 6.80'],
#  ['(12) Akela JONESSR',
#   '',
#   'Kansas State',
#   '6.80m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-3¾',
#   '3/11/2016'],
#  ['(14) Alysah HICKEYJROregon6.79m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3½2/10/2023\xa0\xa0\xa0\xa0\xa06.79, f, f, f, 6.41, f',
#   '(14) Alysah HICKEYJR',
#   '',
#   'Oregon',
#   '6.79m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3½',
#   '2/10/2023',
#   '\xa0\xa0\xa0\xa0\xa06.79, f, f, f, 6.41, f'],
#  ['(14) Alysah HICKEYJR',
#   '',
#   'Oregon',
#   '6.79m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3½',
#   '2/10/2023'],
#  ['(15) Tianna MADISONSOTennessee6.78m  22-33/11/2005\xa0\xa0\xa0\xa0\xa06.49, 6.72, 6.78, p, p, p',
#   '(15) Tianna MADISONSO',
#   '',
#   'Tennessee',
#   '6.78m  22-3',
#   '3/11/2005',
#   '\xa0\xa0\xa0\xa0\xa06.49, 6.72, 6.78, p, p, p'],
#  ['(15) Tianna MADISONSO', '', 'Tennessee', '6.78m  22-3', '3/11/2005'],
#  ['(15) Carol LEWISHouston6.78m  22-32/2/1985',
#   '(15) Carol LEWIS',
#   '',
#   'Houston',
#   '6.78m  22-3',
#   '2/2/1985'],
#  ['(15) Carol LEWIS', '', 'Houston', '6.78m  22-3', '2/2/1985'],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SRAlabama6.76m  22-2¼2/24/2017\xa0\xa0\xa0\xa0\xa06.54, 6.61, 6.76, 6.38, 5.85, p',
#   '\xa0\xa0\xa0\xa0— Burks {2}SR',
#   '',
#   'Alabama',
#   '6.76m  22-2¼',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.54, 6.61, 6.76, 6.38, 5.85, p'],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SR', '', 'Alabama', '6.76m  22-2¼', '2/24/2017'],
#  ['\xa0\xa0\xa0\xa0— Reese {3}JROle Miss6.76m  22-2¼3/14/2008\xa0\xa0\xa0\xa0\xa06.56, 6.76, 6.69, 6.70, 6.56, 6.75',
#   '\xa0\xa0\xa0\xa0— Reese {3}JR',
#   '',
#   'Ole Miss',
#   '6.76m  22-2¼',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.76, 6.69, 6.70, 6.56, 6.75'],
#  ['\xa0\xa0\xa0\xa0— Reese {3}JR',
#   '',
#   'Ole Miss',
#   '6.76m  22-2¼',
#   '3/14/2008'],
#  ["\xa0\xa0\xa0\xa0— Saunders {2}LSU6.76m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-2¼2/26/1994",
#   '\xa0\xa0\xa0\xa0— Saunders {2}',
#   '',
#   'LSU',
#   "6.76m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-2¼",
#   '2/26/1994'],
#  ['\xa0\xa0\xa0\xa0— Saunders {2}',
#   '',
#   'LSU',
#   "6.76m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-2¼",
#   '2/26/1994'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston6.76m  22-2¼2/4/1984',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '6.76m  22-2¼',
#   '2/4/1984'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}', '', 'Houston', '6.76m  22-2¼', '2/4/1984'],
#  ['\xa0\xa0\xa0\xa0— Moore {5}SOFlorida6.75m  22-1¾2/25/2022',
#   '\xa0\xa0\xa0\xa0— Moore {5}SO',
#   '',
#   'Florida',
#   '6.75m  22-1¾',
#   '2/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Moore {5}SO', '', 'Florida', '6.75m  22-1¾', '2/25/2022'],
#  ["(17) Monae' NICHOLSSRTexas Tech6.75m  22-1¾1/23/2021",
#   "(17) Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.75m  22-1¾',
#   '1/23/2021'],
#  ["(17) Monae' NICHOLSSR", '', 'Texas Tech', '6.75m  22-1¾', '1/23/2021'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}Kansas State6.75m  22-1¾2/26/2016\xa0\xa0\xa0\xa0\xa06.57, 6.75, f, p, p, p',
#   '\xa0\xa0\xa0\xa0— Jones {2}',
#   '',
#   'Kansas State',
#   '6.75m  22-1¾',
#   '2/26/2016',
#   '\xa0\xa0\xa0\xa0\xa06.57, 6.75, f, p, p, p'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}',
#   '',
#   'Kansas State',
#   '6.75m  22-1¾',
#   '2/26/2016'],
#  ['\xa0\xa0\xa0\xa0— Burks {3}Alabama6.75m  22-1¾2/26/2016\xa0\xa0\xa0\xa0\xa0f, 6.75, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Burks {3}',
#   '',
#   'Alabama',
#   '6.75m  22-1¾',
#   '2/26/2016',
#   '\xa0\xa0\xa0\xa0\xa0f, 6.75, p, p, p, p'],
#  ['\xa0\xa0\xa0\xa0— Burks {3}', '', 'Alabama', '6.75m  22-1¾', '2/26/2016'],
#  ["\xa0\xa0\xa0\xa0— Reese {4}JROle Miss6.75m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1¾3/14/2008",
#   '\xa0\xa0\xa0\xa0— Reese {4}JR',
#   '',
#   'Ole Miss',
#   "6.75m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1¾",
#   '3/14/2008'],
#  ['\xa0\xa0\xa0\xa0— Reese {4}JR',
#   '',
#   'Ole Miss',
#   "6.75m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1¾",
#   '3/14/2008'],
#  ['(18) Alyssa JONESFRStanford6.74m  22-1½3/10/2023',
#   '(18) Alyssa JONESFR',
#   '',
#   'Stanford',
#   '6.74m  22-1½',
#   '3/10/2023'],
#  ['(18) Alyssa JONESFR', '', 'Stanford', '6.74m  22-1½', '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {6}JRFlorida6.74m  22-1½2/10/2023',
#   '\xa0\xa0\xa0\xa0— Moore {6}JR',
#   '',
#   'Florida',
#   '6.74m  22-1½',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {6}JR', '', 'Florida', '6.74m  22-1½', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {3}Auburn6.74m  22-1½3/2/2003',
#   '\xa0\xa0\xa0\xa0— Goulbourne {3}',
#   '',
#   'Auburn',
#   '6.74m  22-1½',
#   '3/2/2003'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {3}',
#   '',
#   'Auburn',
#   '6.74m  22-1½',
#   '3/2/2003'],
#  ["\xa0\xa0\xa0\xa0— Moore {7}JRFlorida6.73m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-12/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {7}JR',
#   '',
#   'Florida',
#   "6.73m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1",
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {7}JR',
#   '',
#   'Florida',
#   "6.73m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1",
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Smith {3}FRTexas6.73m  22-112/3/2022\xa0\xa0\xa0\xa0\xa06.73, 6.29, 6.19, p, p, p',
#   '\xa0\xa0\xa0\xa0— Smith {3}FR',
#   '',
#   'Texas',
#   '6.73m  22-1',
#   '12/3/2022',
#   '\xa0\xa0\xa0\xa0\xa06.73, 6.29, 6.19, p, p, p'],
#  ['\xa0\xa0\xa0\xa0— Smith {3}FR', '', 'Texas', '6.73m  22-1', '12/3/2022'],
#  ['(19) Kate HALLJRGeorgia6.73m  22-13/9/2018\xa0\xa0\xa0\xa0\xa06.56, 6.69, 6.73, 6.44, 5.47, p',
#   '(19) Kate HALLJR',
#   '',
#   'Georgia',
#   '6.73m  22-1',
#   '3/9/2018',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.69, 6.73, 6.44, 5.47, p'],
#  ['(19) Kate HALLJR', '', 'Georgia', '6.73m  22-1', '3/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}SRKentucky6.73m  22-112/9/2016\xa0\xa0\xa0\xa0\xa06.73, 6.49, 6.51, p, p, p',
#   '\xa0\xa0\xa0\xa0— Saunders {3}SR',
#   '',
#   'Kentucky',
#   '6.73m  22-1',
#   '12/9/2016',
#   '\xa0\xa0\xa0\xa0\xa06.73, 6.49, 6.51, p, p, p'],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}SR',
#   '',
#   'Kentucky',
#   '6.73m  22-1',
#   '12/9/2016'],
#  ['(19) Lorraine UGENTCU6.73m AA = Performance occurred at altitude (>1000 meters above sea level) 22-13/14/2014\xa0\xa0\xa0\xa0\xa06.51, 6.55, 6.41, f, 6.73, f',
#   '(19) Lorraine UGEN',
#   '',
#   'TCU',
#   '6.73m AA = Performance occurred at altitude (>1000 meters above sea level) 22-1',
#   '3/14/2014',
#   '\xa0\xa0\xa0\xa0\xa06.51, 6.55, 6.41, f, 6.73, f'],
#  ['(19) Lorraine UGEN',
#   '',
#   'TCU',
#   '6.73m AA = Performance occurred at altitude (>1000 meters above sea level) 22-1',
#   '3/14/2014'],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}LSU6.73m  22-13/12/1994',
#   '\xa0\xa0\xa0\xa0— Saunders {3}',
#   '',
#   'LSU',
#   '6.73m  22-1',
#   '3/12/1994'],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}', '', 'LSU', '6.73m  22-1', '3/12/1994'],
#  ['\xa0\xa0\xa0\xa0— Burks {4}SRAlabama6.72m  22-¾3/10/2017\xa0\xa0\xa0\xa0\xa06.64, 6.60, f, 6.65, 6.72, f',
#   '\xa0\xa0\xa0\xa0— Burks {4}SR',
#   '',
#   'Alabama',
#   '6.72m  22-¾',
#   '3/10/2017',
#   '\xa0\xa0\xa0\xa0\xa06.64, 6.60, f, 6.65, 6.72, f'],
#  ['\xa0\xa0\xa0\xa0— Burks {4}SR', '', 'Alabama', '6.72m  22-¾', '3/10/2017'],
#  ['(21) Keturah ORJIJRGeorgia6.72m  22-¾2/24/2017\xa0\xa0\xa0\xa0\xa06.57, 6.58, 6.70, 6.40, 6.72, 6.55',
#   '(21) Keturah ORJIJR',
#   '',
#   'Georgia',
#   '6.72m  22-¾',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.57, 6.58, 6.70, 6.40, 6.72, 6.55'],
#  ['(21) Keturah ORJIJR', '', 'Georgia', '6.72m  22-¾', '2/24/2017'],
#  ["\xa0\xa0\xa0\xa0— Madison {2}SOTennessee6.72m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¾3/11/2005",
#   '\xa0\xa0\xa0\xa0— Madison {2}SO',
#   '',
#   'Tennessee',
#   "6.72m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¾",
#   '3/11/2005'],
#  ['\xa0\xa0\xa0\xa0— Madison {2}SO',
#   '',
#   'Tennessee',
#   "6.72m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¾",
#   '3/11/2005'],
#  ["\xa0\xa0\xa0\xa0— Davis {2}JRTexas6.71m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¼3/12/2021",
#   '\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Texas',
#   "6.71m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¼",
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Texas',
#   "6.71m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¼",
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Burks {5}Alabama6.71m  22-¼1/23/2016\xa0\xa0\xa0\xa0\xa06.08, 6.21, 6.31, f, 6.39, 6.71',
#   '\xa0\xa0\xa0\xa0— Burks {5}',
#   '',
#   'Alabama',
#   '6.71m  22-¼',
#   '1/23/2016',
#   '\xa0\xa0\xa0\xa0\xa06.08, 6.21, 6.31, f, 6.39, 6.71'],
#  ['\xa0\xa0\xa0\xa0— Burks {5}', '', 'Alabama', '6.71m  22-¼', '1/23/2016'],
#  ['(22) Marshavet HOOKERTexas6.71m  22-¼3/10/2006\xa0\xa0\xa0\xa0\xa04.32, 6.34, 6.60, 6.11, 6.71, p',
#   '(22) Marshavet HOOKER',
#   '',
#   'Texas',
#   '6.71m  22-¼',
#   '3/10/2006',
#   '\xa0\xa0\xa0\xa0\xa04.32, 6.34, 6.60, 6.11, 6.71, p'],
#  ['(22) Marshavet HOOKER', '', 'Texas', '6.71m  22-¼', '3/10/2006'],
#  ['\xa0\xa0\xa0\xa0— Madison {3}Tennessee6.71m  22-¼2/27/2005',
#   '\xa0\xa0\xa0\xa0— Madison {3}',
#   '',
#   'Tennessee',
#   '6.71m  22-¼',
#   '2/27/2005'],
#  ['\xa0\xa0\xa0\xa0— Madison {3}',
#   '',
#   'Tennessee',
#   '6.71m  22-¼',
#   '2/27/2005'],
#  ['(22) Dedra DAVISTennessee6.71m  22-¼3/11/1994',
#   '(22) Dedra DAVIS',
#   '',
#   'Tennessee',
#   '6.71m  22-¼',
#   '3/11/1994'],
#  ['(22) Dedra DAVIS', '', 'Tennessee', '6.71m  22-¼', '3/11/1994'],
#  ["\xa0\xa0\xa0\xa0— Moore {8}JRFlorida6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾2/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {8}JR',
#   '',
#   'Florida',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {8}JR',
#   '',
#   'Florida',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Bryant {2}FRFlorida6.70m  21-11¾3/12/2021',
#   '\xa0\xa0\xa0\xa0— Bryant {2}FR',
#   '',
#   'Florida',
#   '6.70m  21-11¾',
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Bryant {2}FR',
#   '',
#   'Florida',
#   '6.70m  21-11¾',
#   '3/12/2021'],
#  ["\xa0\xa0\xa0\xa0— Saunders {4}SRKentucky6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾3/10/2017",
#   '\xa0\xa0\xa0\xa0— Saunders {4}SR',
#   '',
#   'Kentucky',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '3/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Saunders {4}SR',
#   '',
#   'Kentucky',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '3/10/2017'],
#  ["\xa0\xa0\xa0\xa0— Orji {2}JRGeorgia6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾2/24/2017",
#   '\xa0\xa0\xa0\xa0— Orji {2}JR',
#   '',
#   'Georgia',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/24/2017'],
#  ['\xa0\xa0\xa0\xa0— Orji {2}JR',
#   '',
#   'Georgia',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/24/2017'],
#  ['(24) Jeomi MADUKACornell6.70m  21-11¾2/14/2009',
#   '(24) Jeomi MADUKA',
#   '',
#   'Cornell',
#   '6.70m  21-11¾',
#   '2/14/2009'],
#  ['(24) Jeomi MADUKA', '', 'Cornell', '6.70m  21-11¾', '2/14/2009'],
#  ['(24) Sheila ECHOLSLSU6.70m  21-11¾2/28/1987',
#   '(24) Sheila ECHOLS',
#   '',
#   'LSU',
#   '6.70m  21-11¾',
#   '2/28/1987'],
#  ['(24) Sheila ECHOLS', '', 'LSU', '6.70m  21-11¾', '2/28/1987'],
#  ['', '', '', '']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Jasmine MOOREJRFlorida7.03m📺  23-¾3/10/2023',
#   '(1) Jasmine MOOREJR',
#   '',
#   'Florida',
#   '7.03m📺  23-¾',
#   '3/10/2023'],
#  ['(2) Tara DAVISJRTexas6.93m  22-93/12/2021',
#   '(2) Tara DAVISJR',
#   '',
#   'Texas',
#   '6.93m  22-9',
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Moore {2}JRFlorida6.91m  22-82/24/2023',
#   '\xa0\xa0\xa0\xa0— Moore {2}JR',
#   '',
#   'Florida',
#   '6.91m  22-8',
#   '2/24/2023'],
#  ['(3) Whitney GIPSONSRTCU6.91m  22-83/9/2012\xa0\xa0\xa0\xa0\xa06.64, 6.30, FOUL., FOUL, 6.91, 6.22',
#   '(3) Whitney GIPSONSR',
#   '',
#   'TCU',
#   '6.91m  22-8',
#   '3/9/2012',
#   '\xa0\xa0\xa0\xa0\xa06.64, 6.30, FOUL., FOUL, 6.91, 6.22'],
#  ['(3) Elva GOULBOURNEAuburn6.91m  22-82/23/2002',
#   '(3) Elva GOULBOURNE',
#   '',
#   'Auburn',
#   '6.91m  22-8',
#   '2/23/2002'],
#  ["(5) Sha'Keela SAUNDERSSRKentucky6.90m  22-7¾3/10/2017\xa0\xa0\xa0\xa0\xa06.42, 6.70, 6.55, f, 6.62, 6.90",
#   "(5) Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.90m  22-7¾',
#   '3/10/2017',
#   '\xa0\xa0\xa0\xa0\xa06.42, 6.70, 6.55, f, 6.62, 6.90'],
#  ['(6) Ackelia SMITHFRTexas6.88m  22-73/10/2023',
#   '(6) Ackelia SMITHFR',
#   '',
#   'Texas',
#   '6.88m  22-7',
#   '3/10/2023'],
#  ['(6) Claire  BRYANTJRFlorida6.88m  22-73/10/2023',
#   '(6) Claire  BRYANTJR',
#   '',
#   'Florida',
#   '6.88m  22-7',
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Smith {2}FRTexas6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½3/10/2023",
#   '\xa0\xa0\xa0\xa0— Smith {2}FR',
#   '',
#   'Texas',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Moore {3}JRFlorida6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½3/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  ['(8) Blessing OKAGBAREUTEP6.87m  22-6½3/12/2010\xa0\xa0\xa0\xa0\xa06.48, 6.84, 6.87, p, p, 6.57',
#   '(8) Blessing OKAGBARE',
#   '',
#   'UTEP',
#   '6.87m  22-6½',
#   '3/12/2010',
#   '\xa0\xa0\xa0\xa0\xa06.48, 6.84, 6.87, p, p, 6.57'],
#  ['(8) Brittney REESEOle Miss6.87m  22-6½3/1/2008',
#   '(8) Brittney REESE',
#   '',
#   'Ole Miss',
#   '6.87m  22-6½',
#   '3/1/2008'],
#  ["\xa0\xa0\xa0\xa0— Moore {4}JRFlorida6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼2/24/2023",
#   '\xa0\xa0\xa0\xa0— Moore {4}JR',
#   '',
#   'Florida',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼",
#   '2/24/2023'],
#  ["\xa0\xa0\xa0\xa0— Okagbare {2}SRUTEP6.84m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¼3/12/2010",
#   '\xa0\xa0\xa0\xa0— Okagbare {2}SR',
#   '',
#   'UTEP',
#   "6.84m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¼",
#   '3/12/2010'],
#  ['(10) Ruth USOROSRTexas Tech6.82m  22-4½2/26/2021',
#   '(10) Ruth USOROSR',
#   '',
#   'Texas Tech',
#   '6.82m  22-4½',
#   '2/26/2021'],
#  ['\xa0\xa0\xa0\xa0— Saunders {2}SRKentucky6.82m  22-4½2/24/2017\xa0\xa0\xa0\xa0\xa06.67, 6.59, f, 6.56, 6.82, 6.55',
#   '\xa0\xa0\xa0\xa0— Saunders {2}SR',
#   '',
#   'Kentucky',
#   '6.82m  22-4½',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.67, 6.59, f, 6.56, 6.82, 6.55'],
#  ['(10) Daphne SAUNDERSLSU6.82m  22-4½2/26/1994',
#   '(10) Daphne SAUNDERS',
#   '',
#   'LSU',
#   '6.82m  22-4½',
#   '2/26/1994'],
#  ['\xa0\xa0\xa0\xa0— Reese {2}Ole Miss6.81m  22-4¼2/15/2008\xa0\xa0\xa0\xa0\xa06.81, f, 6.53, 6.55, p, p',
#   '\xa0\xa0\xa0\xa0— Reese {2}',
#   '',
#   'Ole Miss',
#   '6.81m  22-4¼',
#   '2/15/2008',
#   '\xa0\xa0\xa0\xa0\xa06.81, f, 6.53, 6.55, p, p'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}SRAuburn6.81m  22-4¼3/14/2003\xa0\xa0\xa0\xa0\xa06.81, p, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Goulbourne {2}SR',
#   '',
#   'Auburn',
#   '6.81m  22-4¼',
#   '3/14/2003',
#   '\xa0\xa0\xa0\xa0\xa06.81, p, p, p, p, p'],
#  ['(12) Quanesha BURKSJRAlabama6.80m  22-3¾3/11/2016\xa0\xa0\xa0\xa0\xa06.56, 6.57, 6.67, 6.27, 6.47, 6.80',
#   '(12) Quanesha BURKSJR',
#   '',
#   'Alabama',
#   '6.80m  22-3¾',
#   '3/11/2016',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.57, 6.67, 6.27, 6.47, 6.80'],
#  ['(12) Akela JONESSRKansas State6.80m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-3¾3/11/2016\xa0\xa0\xa0\xa0\xa06.56, 6.67, 6.80',
#   '(12) Akela JONESSR',
#   '',
#   'Kansas State',
#   '6.80m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-3¾',
#   '3/11/2016',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.67, 6.80'],
#  ['(14) Alysah HICKEYJROregon6.79m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3½2/10/2023\xa0\xa0\xa0\xa0\xa06.79, f, f, f, 6.41, f',
#   '(14) Alysah HICKEYJR',
#   '',
#   'Oregon',
#   '6.79m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3½',
#   '2/10/2023',
#   '\xa0\xa0\xa0\xa0\xa06.79, f, f, f, 6.41, f'],
#  ['(15) Tianna MADISONSOTennessee6.78m  22-33/11/2005\xa0\xa0\xa0\xa0\xa06.49, 6.72, 6.78, p, p, p',
#   '(15) Tianna MADISONSO',
#   '',
#   'Tennessee',
#   '6.78m  22-3',
#   '3/11/2005',
#   '\xa0\xa0\xa0\xa0\xa06.49, 6.72, 6.78, p, p, p'],
#  ['(15) Carol LEWISHouston6.78m  22-32/2/1985',
#   '(15) Carol LEWIS',
#   '',
#   'Houston',
#   '6.78m  22-3',
#   '2/2/1985'],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SRAlabama6.76m  22-2¼2/24/2017\xa0\xa0\xa0\xa0\xa06.54, 6.61, 6.76, 6.38, 5.85, p',
#   '\xa0\xa0\xa0\xa0— Burks {2}SR',
#   '',
#   'Alabama',
#   '6.76m  22-2¼',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.54, 6.61, 6.76, 6.38, 5.85, p'],
#  ['\xa0\xa0\xa0\xa0— Reese {3}JROle Miss6.76m  22-2¼3/14/2008\xa0\xa0\xa0\xa0\xa06.56, 6.76, 6.69, 6.70, 6.56, 6.75',
#   '\xa0\xa0\xa0\xa0— Reese {3}JR',
#   '',
#   'Ole Miss',
#   '6.76m  22-2¼',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.76, 6.69, 6.70, 6.56, 6.75'],
#  ["\xa0\xa0\xa0\xa0— Saunders {2}LSU6.76m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-2¼2/26/1994",
#   '\xa0\xa0\xa0\xa0— Saunders {2}',
#   '',
#   'LSU',
#   "6.76m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-2¼",
#   '2/26/1994'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston6.76m  22-2¼2/4/1984',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '6.76m  22-2¼',
#   '2/4/1984'],
#  ['\xa0\xa0\xa0\xa0— Moore {5}SOFlorida6.75m  22-1¾2/25/2022',
#   '\xa0\xa0\xa0\xa0— Moore {5}SO',
#   '',
#   'Florida',
#   '6.75m  22-1¾',
#   '2/25/2022'],
#  ["(17) Monae' NICHOLSSRTexas Tech6.75m  22-1¾1/23/2021",
#   "(17) Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.75m  22-1¾',
#   '1/23/2021'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}Kansas State6.75m  22-1¾2/26/2016\xa0\xa0\xa0\xa0\xa06.57, 6.75, f, p, p, p',
#   '\xa0\xa0\xa0\xa0— Jones {2}',
#   '',
#   'Kansas State',
#   '6.75m  22-1¾',
#   '2/26/2016',
#   '\xa0\xa0\xa0\xa0\xa06.57, 6.75, f, p, p, p'],
#  ['\xa0\xa0\xa0\xa0— Burks {3}Alabama6.75m  22-1¾2/26/2016\xa0\xa0\xa0\xa0\xa0f, 6.75, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Burks {3}',
#   '',
#   'Alabama',
#   '6.75m  22-1¾',
#   '2/26/2016',
#   '\xa0\xa0\xa0\xa0\xa0f, 6.75, p, p, p, p'],
#  ["\xa0\xa0\xa0\xa0— Reese {4}JROle Miss6.75m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1¾3/14/2008",
#   '\xa0\xa0\xa0\xa0— Reese {4}JR',
#   '',
#   'Ole Miss',
#   "6.75m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1¾",
#   '3/14/2008'],
#  ['(18) Alyssa JONESFRStanford6.74m  22-1½3/10/2023',
#   '(18) Alyssa JONESFR',
#   '',
#   'Stanford',
#   '6.74m  22-1½',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {6}JRFlorida6.74m  22-1½2/10/2023',
#   '\xa0\xa0\xa0\xa0— Moore {6}JR',
#   '',
#   'Florida',
#   '6.74m  22-1½',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {3}Auburn6.74m  22-1½3/2/2003',
#   '\xa0\xa0\xa0\xa0— Goulbourne {3}',
#   '',
#   'Auburn',
#   '6.74m  22-1½',
#   '3/2/2003'],
#  ["\xa0\xa0\xa0\xa0— Moore {7}JRFlorida6.73m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-12/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {7}JR',
#   '',
#   'Florida',
#   "6.73m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1",
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Smith {3}FRTexas6.73m  22-112/3/2022\xa0\xa0\xa0\xa0\xa06.73, 6.29, 6.19, p, p, p',
#   '\xa0\xa0\xa0\xa0— Smith {3}FR',
#   '',
#   'Texas',
#   '6.73m  22-1',
#   '12/3/2022',
#   '\xa0\xa0\xa0\xa0\xa06.73, 6.29, 6.19, p, p, p'],
#  ['(19) Kate HALLJRGeorgia6.73m  22-13/9/2018\xa0\xa0\xa0\xa0\xa06.56, 6.69, 6.73, 6.44, 5.47, p',
#   '(19) Kate HALLJR',
#   '',
#   'Georgia',
#   '6.73m  22-1',
#   '3/9/2018',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.69, 6.73, 6.44, 5.47, p'],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}SRKentucky6.73m  22-112/9/2016\xa0\xa0\xa0\xa0\xa06.73, 6.49, 6.51, p, p, p',
#   '\xa0\xa0\xa0\xa0— Saunders {3}SR',
#   '',
#   'Kentucky',
#   '6.73m  22-1',
#   '12/9/2016',
#   '\xa0\xa0\xa0\xa0\xa06.73, 6.49, 6.51, p, p, p'],
#  ['(19) Lorraine UGENTCU6.73m AA = Performance occurred at altitude (>1000 meters above sea level) 22-13/14/2014\xa0\xa0\xa0\xa0\xa06.51, 6.55, 6.41, f, 6.73, f',
#   '(19) Lorraine UGEN',
#   '',
#   'TCU',
#   '6.73m AA = Performance occurred at altitude (>1000 meters above sea level) 22-1',
#   '3/14/2014',
#   '\xa0\xa0\xa0\xa0\xa06.51, 6.55, 6.41, f, 6.73, f'],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}LSU6.73m  22-13/12/1994',
#   '\xa0\xa0\xa0\xa0— Saunders {3}',
#   '',
#   'LSU',
#   '6.73m  22-1',
#   '3/12/1994'],
#  ['\xa0\xa0\xa0\xa0— Burks {4}SRAlabama6.72m  22-¾3/10/2017\xa0\xa0\xa0\xa0\xa06.64, 6.60, f, 6.65, 6.72, f',
#   '\xa0\xa0\xa0\xa0— Burks {4}SR',
#   '',
#   'Alabama',
#   '6.72m  22-¾',
#   '3/10/2017',
#   '\xa0\xa0\xa0\xa0\xa06.64, 6.60, f, 6.65, 6.72, f'],
#  ['(21) Keturah ORJIJRGeorgia6.72m  22-¾2/24/2017\xa0\xa0\xa0\xa0\xa06.57, 6.58, 6.70, 6.40, 6.72, 6.55',
#   '(21) Keturah ORJIJR',
#   '',
#   'Georgia',
#   '6.72m  22-¾',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.57, 6.58, 6.70, 6.40, 6.72, 6.55'],
#  ["\xa0\xa0\xa0\xa0— Madison {2}SOTennessee6.72m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¾3/11/2005",
#   '\xa0\xa0\xa0\xa0— Madison {2}SO',
#   '',
#   'Tennessee',
#   "6.72m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¾",
#   '3/11/2005'],
#  ["\xa0\xa0\xa0\xa0— Davis {2}JRTexas6.71m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¼3/12/2021",
#   '\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Texas',
#   "6.71m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¼",
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Burks {5}Alabama6.71m  22-¼1/23/2016\xa0\xa0\xa0\xa0\xa06.08, 6.21, 6.31, f, 6.39, 6.71',
#   '\xa0\xa0\xa0\xa0— Burks {5}',
#   '',
#   'Alabama',
#   '6.71m  22-¼',
#   '1/23/2016',
#   '\xa0\xa0\xa0\xa0\xa06.08, 6.21, 6.31, f, 6.39, 6.71'],
#  ['(22) Marshavet HOOKERTexas6.71m  22-¼3/10/2006\xa0\xa0\xa0\xa0\xa04.32, 6.34, 6.60, 6.11, 6.71, p',
#   '(22) Marshavet HOOKER',
#   '',
#   'Texas',
#   '6.71m  22-¼',
#   '3/10/2006',
#   '\xa0\xa0\xa0\xa0\xa04.32, 6.34, 6.60, 6.11, 6.71, p'],
#  ['\xa0\xa0\xa0\xa0— Madison {3}Tennessee6.71m  22-¼2/27/2005',
#   '\xa0\xa0\xa0\xa0— Madison {3}',
#   '',
#   'Tennessee',
#   '6.71m  22-¼',
#   '2/27/2005'],
#  ['(22) Dedra DAVISTennessee6.71m  22-¼3/11/1994',
#   '(22) Dedra DAVIS',
#   '',
#   'Tennessee',
#   '6.71m  22-¼',
#   '3/11/1994'],
#  ["\xa0\xa0\xa0\xa0— Moore {8}JRFlorida6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾2/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {8}JR',
#   '',
#   'Florida',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Bryant {2}FRFlorida6.70m  21-11¾3/12/2021',
#   '\xa0\xa0\xa0\xa0— Bryant {2}FR',
#   '',
#   'Florida',
#   '6.70m  21-11¾',
#   '3/12/2021'],
#  ["\xa0\xa0\xa0\xa0— Saunders {4}SRKentucky6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾3/10/2017",
#   '\xa0\xa0\xa0\xa0— Saunders {4}SR',
#   '',
#   'Kentucky',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '3/10/2017'],
#  ["\xa0\xa0\xa0\xa0— Orji {2}JRGeorgia6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾2/24/2017",
#   '\xa0\xa0\xa0\xa0— Orji {2}JR',
#   '',
#   'Georgia',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/24/2017'],
#  ['(24) Jeomi MADUKACornell6.70m  21-11¾2/14/2009',
#   '(24) Jeomi MADUKA',
#   '',
#   'Cornell',
#   '6.70m  21-11¾',
#   '2/14/2009'],
#  ['(24) Sheila ECHOLSLSU6.70m  21-11¾2/28/1987',
#   '(24) Sheila ECHOLS',
#   '',
#   'LSU',
#   '6.70m  21-11¾',
#   '2/28/1987'],
#  ['', '', '', '']]

# %%
RealRealRows[2][4]
# Out:
# '6.91m  22-8'

# %%
len(RealRealRows)
# Out:
# 57

# %%
OfficialLengths = []

# %%
for i in range(0,56):
    OfficialLengths.append(RealRealRows[i][4])
OfficialLengths
# Out:
# ['7.03m📺  23-¾',
#  '6.93m  22-9',
#  '6.91m  22-8',
#  '6.91m  22-8',
#  '6.91m  22-8',
#  '6.90m  22-7¾',
#  '6.88m  22-7',
#  '6.88m  22-7',
#  "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#  "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#  '6.87m  22-6½',
#  '6.87m  22-6½',
#  "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼",
#  "6.84m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¼",
#  '6.82m  22-4½',
#  '6.82m  22-4½',
#  '6.82m  22-4½',
#  '6.81m  22-4¼',
#  '6.81m  22-4¼',
#  '6.80m  22-3¾',
#  '6.80m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-3¾',
#  '6.79m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3½',
#  '6.78m  22-3',
#  '6.78m  22-3',
#  '6.76m  22-2¼',
#  '6.76m  22-2¼',
#  "6.76m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-2¼",
#  '6.76m  22-2¼',
#  '6.75m  22-1¾',
#  '6.75m  22-1¾',
#  '6.75m  22-1¾',
#  '6.75m  22-1¾',
#  "6.75m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1¾",
#  '6.74m  22-1½',
#  '6.74m  22-1½',
#  '6.74m  22-1½',
#  "6.73m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1",
#  '6.73m  22-1',
#  '6.73m  22-1',
#  '6.73m  22-1',
#  '6.73m AA = Performance occurred at altitude (>1000 meters above sea level) 22-1',
#  '6.73m  22-1',
#  '6.72m  22-¾',
#  '6.72m  22-¾',
#  "6.72m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¾",
#  "6.71m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¼",
#  '6.71m  22-¼',
#  '6.71m  22-¼',
#  '6.71m  22-¼',
#  '6.71m  22-¼',
#  "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#  '6.70m  21-11¾',
#  "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#  "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#  '6.70m  21-11¾',
#  '6.70m  21-11¾']

# %%
RealRealRows
# Out:
# [['(1) Jasmine MOOREJRFlorida7.03m📺  23-¾3/10/2023',
#   '(1) Jasmine MOOREJR',
#   '',
#   'Florida',
#   '7.03m📺  23-¾',
#   '3/10/2023'],
#  ['(2) Tara DAVISJRTexas6.93m  22-93/12/2021',
#   '(2) Tara DAVISJR',
#   '',
#   'Texas',
#   '6.93m  22-9',
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Moore {2}JRFlorida6.91m  22-82/24/2023',
#   '\xa0\xa0\xa0\xa0— Moore {2}JR',
#   '',
#   'Florida',
#   '6.91m  22-8',
#   '2/24/2023'],
#  ['(3) Whitney GIPSONSRTCU6.91m  22-83/9/2012\xa0\xa0\xa0\xa0\xa06.64, 6.30, FOUL., FOUL, 6.91, 6.22',
#   '(3) Whitney GIPSONSR',
#   '',
#   'TCU',
#   '6.91m  22-8',
#   '3/9/2012',
#   '\xa0\xa0\xa0\xa0\xa06.64, 6.30, FOUL., FOUL, 6.91, 6.22'],
#  ['(3) Elva GOULBOURNEAuburn6.91m  22-82/23/2002',
#   '(3) Elva GOULBOURNE',
#   '',
#   'Auburn',
#   '6.91m  22-8',
#   '2/23/2002'],
#  ["(5) Sha'Keela SAUNDERSSRKentucky6.90m  22-7¾3/10/2017\xa0\xa0\xa0\xa0\xa06.42, 6.70, 6.55, f, 6.62, 6.90",
#   "(5) Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.90m  22-7¾',
#   '3/10/2017',
#   '\xa0\xa0\xa0\xa0\xa06.42, 6.70, 6.55, f, 6.62, 6.90'],
#  ['(6) Ackelia SMITHFRTexas6.88m  22-73/10/2023',
#   '(6) Ackelia SMITHFR',
#   '',
#   'Texas',
#   '6.88m  22-7',
#   '3/10/2023'],
#  ['(6) Claire  BRYANTJRFlorida6.88m  22-73/10/2023',
#   '(6) Claire  BRYANTJR',
#   '',
#   'Florida',
#   '6.88m  22-7',
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Smith {2}FRTexas6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½3/10/2023",
#   '\xa0\xa0\xa0\xa0— Smith {2}FR',
#   '',
#   'Texas',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Moore {3}JRFlorida6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½3/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-6½",
#   '3/10/2023'],
#  ['(8) Blessing OKAGBAREUTEP6.87m  22-6½3/12/2010\xa0\xa0\xa0\xa0\xa06.48, 6.84, 6.87, p, p, 6.57',
#   '(8) Blessing OKAGBARE',
#   '',
#   'UTEP',
#   '6.87m  22-6½',
#   '3/12/2010',
#   '\xa0\xa0\xa0\xa0\xa06.48, 6.84, 6.87, p, p, 6.57'],
#  ['(8) Brittney REESEOle Miss6.87m  22-6½3/1/2008',
#   '(8) Brittney REESE',
#   '',
#   'Ole Miss',
#   '6.87m  22-6½',
#   '3/1/2008'],
#  ["\xa0\xa0\xa0\xa0— Moore {4}JRFlorida6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼2/24/2023",
#   '\xa0\xa0\xa0\xa0— Moore {4}JR',
#   '',
#   'Florida',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼",
#   '2/24/2023'],
#  ["\xa0\xa0\xa0\xa0— Okagbare {2}SRUTEP6.84m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¼3/12/2010",
#   '\xa0\xa0\xa0\xa0— Okagbare {2}SR',
#   '',
#   'UTEP',
#   "6.84m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¼",
#   '3/12/2010'],
#  ['(10) Ruth USOROSRTexas Tech6.82m  22-4½2/26/2021',
#   '(10) Ruth USOROSR',
#   '',
#   'Texas Tech',
#   '6.82m  22-4½',
#   '2/26/2021'],
#  ['\xa0\xa0\xa0\xa0— Saunders {2}SRKentucky6.82m  22-4½2/24/2017\xa0\xa0\xa0\xa0\xa06.67, 6.59, f, 6.56, 6.82, 6.55',
#   '\xa0\xa0\xa0\xa0— Saunders {2}SR',
#   '',
#   'Kentucky',
#   '6.82m  22-4½',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.67, 6.59, f, 6.56, 6.82, 6.55'],
#  ['(10) Daphne SAUNDERSLSU6.82m  22-4½2/26/1994',
#   '(10) Daphne SAUNDERS',
#   '',
#   'LSU',
#   '6.82m  22-4½',
#   '2/26/1994'],
#  ['\xa0\xa0\xa0\xa0— Reese {2}Ole Miss6.81m  22-4¼2/15/2008\xa0\xa0\xa0\xa0\xa06.81, f, 6.53, 6.55, p, p',
#   '\xa0\xa0\xa0\xa0— Reese {2}',
#   '',
#   'Ole Miss',
#   '6.81m  22-4¼',
#   '2/15/2008',
#   '\xa0\xa0\xa0\xa0\xa06.81, f, 6.53, 6.55, p, p'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}SRAuburn6.81m  22-4¼3/14/2003\xa0\xa0\xa0\xa0\xa06.81, p, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Goulbourne {2}SR',
#   '',
#   'Auburn',
#   '6.81m  22-4¼',
#   '3/14/2003',
#   '\xa0\xa0\xa0\xa0\xa06.81, p, p, p, p, p'],
#  ['(12) Quanesha BURKSJRAlabama6.80m  22-3¾3/11/2016\xa0\xa0\xa0\xa0\xa06.56, 6.57, 6.67, 6.27, 6.47, 6.80',
#   '(12) Quanesha BURKSJR',
#   '',
#   'Alabama',
#   '6.80m  22-3¾',
#   '3/11/2016',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.57, 6.67, 6.27, 6.47, 6.80'],
#  ['(12) Akela JONESSRKansas State6.80m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-3¾3/11/2016\xa0\xa0\xa0\xa0\xa06.56, 6.67, 6.80',
#   '(12) Akela JONESSR',
#   '',
#   'Kansas State',
#   '6.80m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-3¾',
#   '3/11/2016',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.67, 6.80'],
#  ['(14) Alysah HICKEYJROregon6.79m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3½2/10/2023\xa0\xa0\xa0\xa0\xa06.79, f, f, f, 6.41, f',
#   '(14) Alysah HICKEYJR',
#   '',
#   'Oregon',
#   '6.79m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3½',
#   '2/10/2023',
#   '\xa0\xa0\xa0\xa0\xa06.79, f, f, f, 6.41, f'],
#  ['(15) Tianna MADISONSOTennessee6.78m  22-33/11/2005\xa0\xa0\xa0\xa0\xa06.49, 6.72, 6.78, p, p, p',
#   '(15) Tianna MADISONSO',
#   '',
#   'Tennessee',
#   '6.78m  22-3',
#   '3/11/2005',
#   '\xa0\xa0\xa0\xa0\xa06.49, 6.72, 6.78, p, p, p'],
#  ['(15) Carol LEWISHouston6.78m  22-32/2/1985',
#   '(15) Carol LEWIS',
#   '',
#   'Houston',
#   '6.78m  22-3',
#   '2/2/1985'],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SRAlabama6.76m  22-2¼2/24/2017\xa0\xa0\xa0\xa0\xa06.54, 6.61, 6.76, 6.38, 5.85, p',
#   '\xa0\xa0\xa0\xa0— Burks {2}SR',
#   '',
#   'Alabama',
#   '6.76m  22-2¼',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.54, 6.61, 6.76, 6.38, 5.85, p'],
#  ['\xa0\xa0\xa0\xa0— Reese {3}JROle Miss6.76m  22-2¼3/14/2008\xa0\xa0\xa0\xa0\xa06.56, 6.76, 6.69, 6.70, 6.56, 6.75',
#   '\xa0\xa0\xa0\xa0— Reese {3}JR',
#   '',
#   'Ole Miss',
#   '6.76m  22-2¼',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.76, 6.69, 6.70, 6.56, 6.75'],
#  ["\xa0\xa0\xa0\xa0— Saunders {2}LSU6.76m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-2¼2/26/1994",
#   '\xa0\xa0\xa0\xa0— Saunders {2}',
#   '',
#   'LSU',
#   "6.76m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-2¼",
#   '2/26/1994'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston6.76m  22-2¼2/4/1984',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '6.76m  22-2¼',
#   '2/4/1984'],
#  ['\xa0\xa0\xa0\xa0— Moore {5}SOFlorida6.75m  22-1¾2/25/2022',
#   '\xa0\xa0\xa0\xa0— Moore {5}SO',
#   '',
#   'Florida',
#   '6.75m  22-1¾',
#   '2/25/2022'],
#  ["(17) Monae' NICHOLSSRTexas Tech6.75m  22-1¾1/23/2021",
#   "(17) Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.75m  22-1¾',
#   '1/23/2021'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}Kansas State6.75m  22-1¾2/26/2016\xa0\xa0\xa0\xa0\xa06.57, 6.75, f, p, p, p',
#   '\xa0\xa0\xa0\xa0— Jones {2}',
#   '',
#   'Kansas State',
#   '6.75m  22-1¾',
#   '2/26/2016',
#   '\xa0\xa0\xa0\xa0\xa06.57, 6.75, f, p, p, p'],
#  ['\xa0\xa0\xa0\xa0— Burks {3}Alabama6.75m  22-1¾2/26/2016\xa0\xa0\xa0\xa0\xa0f, 6.75, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Burks {3}',
#   '',
#   'Alabama',
#   '6.75m  22-1¾',
#   '2/26/2016',
#   '\xa0\xa0\xa0\xa0\xa0f, 6.75, p, p, p, p'],
#  ["\xa0\xa0\xa0\xa0— Reese {4}JROle Miss6.75m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1¾3/14/2008",
#   '\xa0\xa0\xa0\xa0— Reese {4}JR',
#   '',
#   'Ole Miss',
#   "6.75m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1¾",
#   '3/14/2008'],
#  ['(18) Alyssa JONESFRStanford6.74m  22-1½3/10/2023',
#   '(18) Alyssa JONESFR',
#   '',
#   'Stanford',
#   '6.74m  22-1½',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {6}JRFlorida6.74m  22-1½2/10/2023',
#   '\xa0\xa0\xa0\xa0— Moore {6}JR',
#   '',
#   'Florida',
#   '6.74m  22-1½',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {3}Auburn6.74m  22-1½3/2/2003',
#   '\xa0\xa0\xa0\xa0— Goulbourne {3}',
#   '',
#   'Auburn',
#   '6.74m  22-1½',
#   '3/2/2003'],
#  ["\xa0\xa0\xa0\xa0— Moore {7}JRFlorida6.73m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-12/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {7}JR',
#   '',
#   'Florida',
#   "6.73m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-1",
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Smith {3}FRTexas6.73m  22-112/3/2022\xa0\xa0\xa0\xa0\xa06.73, 6.29, 6.19, p, p, p',
#   '\xa0\xa0\xa0\xa0— Smith {3}FR',
#   '',
#   'Texas',
#   '6.73m  22-1',
#   '12/3/2022',
#   '\xa0\xa0\xa0\xa0\xa06.73, 6.29, 6.19, p, p, p'],
#  ['(19) Kate HALLJRGeorgia6.73m  22-13/9/2018\xa0\xa0\xa0\xa0\xa06.56, 6.69, 6.73, 6.44, 5.47, p',
#   '(19) Kate HALLJR',
#   '',
#   'Georgia',
#   '6.73m  22-1',
#   '3/9/2018',
#   '\xa0\xa0\xa0\xa0\xa06.56, 6.69, 6.73, 6.44, 5.47, p'],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}SRKentucky6.73m  22-112/9/2016\xa0\xa0\xa0\xa0\xa06.73, 6.49, 6.51, p, p, p',
#   '\xa0\xa0\xa0\xa0— Saunders {3}SR',
#   '',
#   'Kentucky',
#   '6.73m  22-1',
#   '12/9/2016',
#   '\xa0\xa0\xa0\xa0\xa06.73, 6.49, 6.51, p, p, p'],
#  ['(19) Lorraine UGENTCU6.73m AA = Performance occurred at altitude (>1000 meters above sea level) 22-13/14/2014\xa0\xa0\xa0\xa0\xa06.51, 6.55, 6.41, f, 6.73, f',
#   '(19) Lorraine UGEN',
#   '',
#   'TCU',
#   '6.73m AA = Performance occurred at altitude (>1000 meters above sea level) 22-1',
#   '3/14/2014',
#   '\xa0\xa0\xa0\xa0\xa06.51, 6.55, 6.41, f, 6.73, f'],
#  ['\xa0\xa0\xa0\xa0— Saunders {3}LSU6.73m  22-13/12/1994',
#   '\xa0\xa0\xa0\xa0— Saunders {3}',
#   '',
#   'LSU',
#   '6.73m  22-1',
#   '3/12/1994'],
#  ['\xa0\xa0\xa0\xa0— Burks {4}SRAlabama6.72m  22-¾3/10/2017\xa0\xa0\xa0\xa0\xa06.64, 6.60, f, 6.65, 6.72, f',
#   '\xa0\xa0\xa0\xa0— Burks {4}SR',
#   '',
#   'Alabama',
#   '6.72m  22-¾',
#   '3/10/2017',
#   '\xa0\xa0\xa0\xa0\xa06.64, 6.60, f, 6.65, 6.72, f'],
#  ['(21) Keturah ORJIJRGeorgia6.72m  22-¾2/24/2017\xa0\xa0\xa0\xa0\xa06.57, 6.58, 6.70, 6.40, 6.72, 6.55',
#   '(21) Keturah ORJIJR',
#   '',
#   'Georgia',
#   '6.72m  22-¾',
#   '2/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.57, 6.58, 6.70, 6.40, 6.72, 6.55'],
#  ["\xa0\xa0\xa0\xa0— Madison {2}SOTennessee6.72m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¾3/11/2005",
#   '\xa0\xa0\xa0\xa0— Madison {2}SO',
#   '',
#   'Tennessee',
#   "6.72m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¾",
#   '3/11/2005'],
#  ["\xa0\xa0\xa0\xa0— Davis {2}JRTexas6.71m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¼3/12/2021",
#   '\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Texas',
#   "6.71m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-¼",
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Burks {5}Alabama6.71m  22-¼1/23/2016\xa0\xa0\xa0\xa0\xa06.08, 6.21, 6.31, f, 6.39, 6.71',
#   '\xa0\xa0\xa0\xa0— Burks {5}',
#   '',
#   'Alabama',
#   '6.71m  22-¼',
#   '1/23/2016',
#   '\xa0\xa0\xa0\xa0\xa06.08, 6.21, 6.31, f, 6.39, 6.71'],
#  ['(22) Marshavet HOOKERTexas6.71m  22-¼3/10/2006\xa0\xa0\xa0\xa0\xa04.32, 6.34, 6.60, 6.11, 6.71, p',
#   '(22) Marshavet HOOKER',
#   '',
#   'Texas',
#   '6.71m  22-¼',
#   '3/10/2006',
#   '\xa0\xa0\xa0\xa0\xa04.32, 6.34, 6.60, 6.11, 6.71, p'],
#  ['\xa0\xa0\xa0\xa0— Madison {3}Tennessee6.71m  22-¼2/27/2005',
#   '\xa0\xa0\xa0\xa0— Madison {3}',
#   '',
#   'Tennessee',
#   '6.71m  22-¼',
#   '2/27/2005'],
#  ['(22) Dedra DAVISTennessee6.71m  22-¼3/11/1994',
#   '(22) Dedra DAVIS',
#   '',
#   'Tennessee',
#   '6.71m  22-¼',
#   '3/11/1994'],
#  ["\xa0\xa0\xa0\xa0— Moore {8}JRFlorida6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾2/10/2023",
#   '\xa0\xa0\xa0\xa0— Moore {8}JR',
#   '',
#   'Florida',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Bryant {2}FRFlorida6.70m  21-11¾3/12/2021',
#   '\xa0\xa0\xa0\xa0— Bryant {2}FR',
#   '',
#   'Florida',
#   '6.70m  21-11¾',
#   '3/12/2021'],
#  ["\xa0\xa0\xa0\xa0— Saunders {4}SRKentucky6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾3/10/2017",
#   '\xa0\xa0\xa0\xa0— Saunders {4}SR',
#   '',
#   'Kentucky',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '3/10/2017'],
#  ["\xa0\xa0\xa0\xa0— Orji {2}JRGeorgia6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾2/24/2017",
#   '\xa0\xa0\xa0\xa0— Orji {2}JR',
#   '',
#   'Georgia',
#   "6.70m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 21-11¾",
#   '2/24/2017'],
#  ['(24) Jeomi MADUKACornell6.70m  21-11¾2/14/2009',
#   '(24) Jeomi MADUKA',
#   '',
#   'Cornell',
#   '6.70m  21-11¾',
#   '2/14/2009'],
#  ['(24) Sheila ECHOLSLSU6.70m  21-11¾2/28/1987',
#   '(24) Sheila ECHOLS',
#   '',
#   'LSU',
#   '6.70m  21-11¾',
#   '2/28/1987'],
#  ['', '', '', '']]

# %%
len(RealRealRows)
# Out:
# 57

# %%
RealRealRows[2][1]
# Out:
# '\xa0\xa0\xa0\xa0— Moore {2}JR'

# %%
Names = []

for i in range(0,56):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Jasmine MOOREJR',
#  '(2) Tara DAVISJR',
#  '\xa0\xa0\xa0\xa0— Moore {2}JR',
#  '(3) Whitney GIPSONSR',
#  '(3) Elva GOULBOURNE',
#  "(5) Sha'Keela SAUNDERSSR",
#  '(6) Ackelia SMITHFR',
#  '(6) Claire  BRYANTJR',
#  '\xa0\xa0\xa0\xa0— Smith {2}FR',
#  '\xa0\xa0\xa0\xa0— Moore {3}JR',
#  '(8) Blessing OKAGBARE',
#  '(8) Brittney REESE',
#  '\xa0\xa0\xa0\xa0— Moore {4}JR',
#  '\xa0\xa0\xa0\xa0— Okagbare {2}SR',
#  '(10) Ruth USOROSR',
#  '\xa0\xa0\xa0\xa0— Saunders {2}SR',
#  '(10) Daphne SAUNDERS',
#  '\xa0\xa0\xa0\xa0— Reese {2}',
#  '\xa0\xa0\xa0\xa0— Goulbourne {2}SR',
#  '(12) Quanesha BURKSJR',
#  '(12) Akela JONESSR',
#  '(14) Alysah HICKEYJR',
#  '(15) Tianna MADISONSO',
#  '(15) Carol LEWIS',
#  '\xa0\xa0\xa0\xa0— Burks {2}SR',
#  '\xa0\xa0\xa0\xa0— Reese {3}JR',
#  '\xa0\xa0\xa0\xa0— Saunders {2}',
#  '\xa0\xa0\xa0\xa0— Lewis {2}',
#  '\xa0\xa0\xa0\xa0— Moore {5}SO',
#  "(17) Monae' NICHOLSSR",
#  '\xa0\xa0\xa0\xa0— Jones {2}',
#  '\xa0\xa0\xa0\xa0— Burks {3}',
#  '\xa0\xa0\xa0\xa0— Reese {4}JR',
#  '(18) Alyssa JONESFR',
#  '\xa0\xa0\xa0\xa0— Moore {6}JR',
#  '\xa0\xa0\xa0\xa0— Goulbourne {3}',
#  '\xa0\xa0\xa0\xa0— Moore {7}JR',
#  '\xa0\xa0\xa0\xa0— Smith {3}FR',
#  '(19) Kate HALLJR',
#  '\xa0\xa0\xa0\xa0— Saunders {3}SR',
#  '(19) Lorraine UGEN',
#  '\xa0\xa0\xa0\xa0— Saunders {3}',
#  '\xa0\xa0\xa0\xa0— Burks {4}SR',
#  '(21) Keturah ORJIJR',
#  '\xa0\xa0\xa0\xa0— Madison {2}SO',
#  '\xa0\xa0\xa0\xa0— Davis {2}JR',
#  '\xa0\xa0\xa0\xa0— Burks {5}',
#  '(22) Marshavet HOOKER',
#  '\xa0\xa0\xa0\xa0— Madison {3}',
#  '(22) Dedra DAVIS',
#  '\xa0\xa0\xa0\xa0— Moore {8}JR',
#  '\xa0\xa0\xa0\xa0— Bryant {2}FR',
#  '\xa0\xa0\xa0\xa0— Saunders {4}SR',
#  '\xa0\xa0\xa0\xa0— Orji {2}JR',
#  '(24) Jeomi MADUKA',
#  '(24) Sheila ECHOLS']

# %%
len(Names)
# Out:
# 56

# %%
OfficialReGexNames = []

# %%
for i in range(0,56):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Jasmine MOOREJR',
#  '(2) Tara DAVISJR',
#  '— Moore {2}JR',
#  '(3) Whitney GIPSONSR',
#  '(3) Elva GOULBOURNE',
#  "(5) Sha'Keela SAUNDERSSR",
#  '(6) Ackelia SMITHFR',
#  '(6) Claire  BRYANTJR',
#  '— Smith {2}FR',
#  '— Moore {3}JR',
#  '(8) Blessing OKAGBARE',
#  '(8) Brittney REESE',
#  '— Moore {4}JR',
#  '— Okagbare {2}SR',
#  '(10) Ruth USOROSR',
#  '— Saunders {2}SR',
#  '(10) Daphne SAUNDERS',
#  '— Reese {2}',
#  '— Goulbourne {2}SR',
#  '(12) Quanesha BURKSJR',
#  '(12) Akela JONESSR',
#  '(14) Alysah HICKEYJR',
#  '(15) Tianna MADISONSO',
#  '(15) Carol LEWIS',
#  '— Burks {2}SR',
#  '— Reese {3}JR',
#  '— Saunders {2}',
#  '— Lewis {2}',
#  '— Moore {5}SO',
#  "(17) Monae' NICHOLSSR",
#  '— Jones {2}',
#  '— Burks {3}',
#  '— Reese {4}JR',
#  '(18) Alyssa JONESFR',
#  '— Moore {6}JR',
#  '— Goulbourne {3}',
#  '— Moore {7}JR',
#  '— Smith {3}FR',
#  '(19) Kate HALLJR',
#  '— Saunders {3}SR',
#  '(19) Lorraine UGEN',
#  '— Saunders {3}',
#  '— Burks {4}SR',
#  '(21) Keturah ORJIJR',
#  '— Madison {2}SO',
#  '— Davis {2}JR',
#  '— Burks {5}',
#  '(22) Marshavet HOOKER',
#  '— Madison {3}',
#  '(22) Dedra DAVIS',
#  '— Moore {8}JR',
#  '— Bryant {2}FR',
#  '— Saunders {4}SR',
#  '— Orji {2}JR',
#  '(24) Jeomi MADUKA',
#  '(24) Sheila ECHOLS']

# %%
CleanedNames = []

for i in range(0,len(OfficialReGexNames)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Jasmine MOOREJR',
#  'Tara DAVISJR',
#  'Moore {2}JR',
#  'Whitney GIPSONSR',
#  'Elva GOULBOURNE',
#  "Sha'Keela SAUNDERSSR",
#  'Ackelia SMITHFR',
#  'Claire  BRYANTJR',
#  'Smith {2}FR',
#  'Moore {3}JR',
#  'Blessing OKAGBARE',
#  'Brittney REESE',
#  'Moore {4}JR',
#  'Okagbare {2}SR',
#  ' Ruth USOROSR',
#  'Saunders {2}SR',
#  ' Daphne SAUNDERS',
#  'Reese {2}',
#  'Goulbourne {2}SR',
#  ' Quanesha BURKSJR',
#  ' Akela JONESSR',
#  ' Alysah HICKEYJR',
#  ' Tianna MADISONSO',
#  ' Carol LEWIS',
#  'Burks {2}SR',
#  'Reese {3}JR',
#  'Saunders {2}',
#  'Lewis {2}',
#  'Moore {5}SO',
#  " Monae' NICHOLSSR",
#  'Jones {2}',
#  'Burks {3}',
#  'Reese {4}JR',
#  ' Alyssa JONESFR',
#  'Moore {6}JR',
#  'Goulbourne {3}',
#  'Moore {7}JR',
#  'Smith {3}FR',
#  ' Kate HALLJR',
#  'Saunders {3}SR',
#  ' Lorraine UGEN',
#  'Saunders {3}',
#  'Burks {4}SR',
#  ' Keturah ORJIJR',
#  'Madison {2}SO',
#  'Davis {2}JR',
#  'Burks {5}',
#  ' Marshavet HOOKER',
#  'Madison {3}',
#  ' Dedra DAVIS',
#  'Moore {8}JR',
#  'Bryant {2}FR',
#  'Saunders {4}SR',
#  'Orji {2}JR',
#  ' Jeomi MADUKA',
#  ' Sheila ECHOLS']

# %%
CleanedNames2 = []

for i in range(0,len(OfficialReGexNames)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Jasmine MOOREJR',
#  'Tara DAVISJR',
#  'Moore {2}JR',
#  'Whitney GIPSONSR',
#  'Elva GOULBOURNE',
#  "Sha'Keela SAUNDERSSR",
#  'Ackelia SMITHFR',
#  'Claire  BRYANTJR',
#  'Smith {2}FR',
#  'Moore {3}JR',
#  'Blessing OKAGBARE',
#  'Brittney REESE',
#  'Moore {4}JR',
#  'Okagbare {2}SR',
#  'Ruth USOROSR',
#  'Saunders {2}SR',
#  'Daphne SAUNDERS',
#  'Reese {2}',
#  'Goulbourne {2}SR',
#  'Quanesha BURKSJR',
#  'Akela JONESSR',
#  'Alysah HICKEYJR',
#  'Tianna MADISONSO',
#  'Carol LEWIS',
#  'Burks {2}SR',
#  'Reese {3}JR',
#  'Saunders {2}',
#  'Lewis {2}',
#  'Moore {5}SO',
#  "Monae' NICHOLSSR",
#  'Jones {2}',
#  'Burks {3}',
#  'Reese {4}JR',
#  'Alyssa JONESFR',
#  'Moore {6}JR',
#  'Goulbourne {3}',
#  'Moore {7}JR',
#  'Smith {3}FR',
#  'Kate HALLJR',
#  'Saunders {3}SR',
#  'Lorraine UGEN',
#  'Saunders {3}',
#  'Burks {4}SR',
#  'Keturah ORJIJR',
#  'Madison {2}SO',
#  'Davis {2}JR',
#  'Burks {5}',
#  'Marshavet HOOKER',
#  'Madison {3}',
#  'Dedra DAVIS',
#  'Moore {8}JR',
#  'Bryant {2}FR',
#  'Saunders {4}SR',
#  'Orji {2}JR',
#  'Jeomi MADUKA',
#  'Sheila ECHOLS']

# %%
len(OfficialLengths)
# Out:
# 56

# %%
len(OfficialReGexNames)
# Out:
# 56

# %%
Schools = []

for i in range(0,len(OfficialLengths)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Florida',
#  'Texas',
#  'Florida',
#  'TCU',
#  'Auburn',
#  'Kentucky',
#  'Texas',
#  'Florida',
#  'Texas',
#  'Florida',
#  'UTEP',
#  'Ole Miss',
#  'Florida',
#  'UTEP',
#  'Texas Tech',
#  'Kentucky',
#  'LSU',
#  'Ole Miss',
#  'Auburn',
#  'Alabama',
#  'Kansas State',
#  'Oregon',
#  'Tennessee',
#  'Houston',
#  'Alabama',
#  'Ole Miss',
#  'LSU',
#  'Houston',
#  'Florida',
#  'Texas Tech',
#  'Kansas State',
#  'Alabama',
#  'Ole Miss',
#  'Stanford',
#  'Florida',
#  'Auburn',
#  'Florida',
#  'Texas',
#  'Georgia',
#  'Kentucky',
#  'TCU',
#  'LSU',
#  'Alabama',
#  'Georgia',
#  'Tennessee',
#  'Texas',
#  'Alabama',
#  'Texas',
#  'Tennessee',
#  'Tennessee',
#  'Florida',
#  'Florida',
#  'Kentucky',
#  'Georgia',
#  'Cornell',
#  'LSU']

# %%
OfficialLengths[8][:5]
# Out:
# '6.87m'

# %%
Lengths = []
for i in range(0,len(OfficialLengths)):
    Lengths.append(OfficialLengths[i][:5])
    
Lengths
# Out:
# ['7.03m',
#  '6.93m',
#  '6.91m',
#  '6.91m',
#  '6.91m',
#  '6.90m',
#  '6.88m',
#  '6.88m',
#  '6.87m',
#  '6.87m',
#  '6.87m',
#  '6.87m',
#  '6.86m',
#  '6.84m',
#  '6.82m',
#  '6.82m',
#  '6.82m',
#  '6.81m',
#  '6.81m',
#  '6.80m',
#  '6.80m',
#  '6.79m',
#  '6.78m',
#  '6.78m',
#  '6.76m',
#  '6.76m',
#  '6.76m',
#  '6.76m',
#  '6.75m',
#  '6.75m',
#  '6.75m',
#  '6.75m',
#  '6.75m',
#  '6.74m',
#  '6.74m',
#  '6.74m',
#  '6.73m',
#  '6.73m',
#  '6.73m',
#  '6.73m',
#  '6.73m',
#  '6.73m',
#  '6.72m',
#  '6.72m',
#  '6.72m',
#  '6.71m',
#  '6.71m',
#  '6.71m',
#  '6.71m',
#  '6.71m',
#  '6.70m',
#  '6.70m',
#  '6.70m',
#  '6.70m',
#  '6.70m',
#  '6.70m']

# %%
WomensIndoorLongJumpDF = pd.DataFrame({'Names': CleanedNames2, 'Lengths': Lengths, 'Schools': Schools})
WomensIndoorLongJumpDF.to_csv('WomensIndoorLongJump.csv', index=False)
