# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc

# %%
Link200mMen = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?top=25&event=3"

# %%
page = requests.get(Link200mMen)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(1) Walter DIX</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=529">Florida State</a></td><td style="width: 25%;">19.69<a href="https://www.youtube.com/watch?v=J3inscR3o8E" target="_blank">📺</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI East Regional (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/25/2007</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(1) Walter DIX</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=529">Florida State</a></td><td style="width: 25%;">19.69<a href="https://www.youtube.com/watch?v=J3inscR3o8E" target="_blank">📺</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI East Regional (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/25/2007</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6166402" target="_blank">(2) Divine ODUDURU</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850637" target="_blank">19.73</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6166402" target="_blank">(2) Divine ODUDURU</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850637" target="_blank">19.73</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7980286" target="_blank">(3) Udodi ONWUZURIKE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938108" target="_blank">19.76</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7980286" target="_blank">(3) Udodi ONWUZURIKE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938108" target="_blank">19.76</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Oduduru {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/59993/3791630" target="_blank">19.76</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="Michael Johnson Classic (Waco, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/20/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Oduduru {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/59993/3791630" target="_blank">19.76</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="Michael Johnson Classic (Waco, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/20/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7031139" target="_blank">(4) Terrance LAIRD</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67755/4149990" target="_blank">19.81</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/25/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7031139" target="_blank">(4) Terrance LAIRD</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67755/4149990" target="_blank">19.81</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/25/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Laird {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70259/4262311" target="_blank">19.82</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Laird {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70259/4262311" target="_blank">19.82</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7531871" target="_blank">(5) Joseph FAHNBULLEH</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567494" target="_blank">19.83</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7531871" target="_blank">(5) Joseph FAHNBULLEH</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567494" target="_blank">19.83</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Onwuzurike {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938108" target="_blank">19.84</a><a href="https://www.youtube.com/watch?v=zxiIY-08Yk8" target="_blank">📺</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Onwuzurike {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938108" target="_blank">19.84</a><a href="https://www.youtube.com/watch?v=zxiIY-08Yk8" target="_blank">📺</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113312" target="_blank">(6) Christian COLEMAN</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51920/3197590" target="_blank">19.85</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.5)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">5/27/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113312" target="_blank">(6) Christian COLEMAN</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51920/3197590" target="_blank">19.85</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.5)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">5/27/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7036992" target="_blank">(7) Courtney LINDSEY</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938108" target="_blank">19.86</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7036992" target="_blank">(7) Courtney LINDSEY</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938108" target="_blank">19.86</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(7) Justin GATLIN</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1553">Tennessee</a></td><td style="width: 25%;">19.86  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.5)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Starkville, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/12/2002</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(7) Justin GATLIN</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1553">Tennessee</a></td><td style="width: 25%;">19.86  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.5)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Starkville, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/12/2002</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7727055" target="_blank">(9) Terrence JONES</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938108" target="_blank">19.87</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7727055" target="_blank">(9) Terrence JONES</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938108" target="_blank">19.87</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(9) John CAPEL</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=521">Florida</a></td><td style="width: 25%;">19.87  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Boise, Idaho)"><span class="mark-date" style="width: 10%;text-align:right;">6/5/1999</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(9) John CAPEL</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=521">Florida</a></td><td style="width: 25%;">19.87  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Boise, Idaho)"><span class="mark-date" style="width: 10%;text-align:right;">6/5/1999</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(9) Lorenzo DANIEL</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Mississippi State" class="group-logo-inline" src="/images/logos/rankings-article/mississippi-state.png" title="Mississippi State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=987">Mississippi State</a></td><td style="width: 25%;">19.87  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/3/1988</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(9) Lorenzo DANIEL</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Mississippi State" class="group-logo-inline" src="/images/logos/rankings-article/mississippi-state.png" title="Mississippi State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=987">Mississippi State</a></td><td style="width: 25%;">19.87  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/3/1988</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Lindsey {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938108" target="_blank">19.88</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Lindsey {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938108" target="_blank">19.88</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8363938" target="_blank">(12) Robert GREGORY</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938108" target="_blank">19.89</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8363938" target="_blank">(12) Robert GREGORY</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938108" target="_blank">19.89</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Onwuzurike {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/79702/4929195" target="_blank">19.91</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="Pac-12 Championships (Walnut, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/12/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Onwuzurike {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/79702/4929195" target="_blank">19.91</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="Pac-12 Championships (Walnut, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/12/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Fahnbulleh {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276056" target="_blank">19.91</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.4)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Fahnbulleh {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276056" target="_blank">19.91</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.4)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(13) Wallace SPEARMON</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=59">Arkansas</a></td><td style="width: 25%;">19.91  <br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2005</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(13) Wallace SPEARMON</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=59">Arkansas</a></td><td style="width: 25%;">19.91  <br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2005</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Fahnbulleh {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74135/4536413" target="_blank">19.92</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="LSU Invitational (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;">4/30/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Fahnbulleh {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74135/4536413" target="_blank">19.92</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="LSU Invitational (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;">4/30/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7495800" target="_blank">(14) Matthew BOLING</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74751/4516389" target="_blank">19.92</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.9)</span></td><td style="width: 10%;text-align:right;" title="Georgia Tech Invitational (Atlanta, Ga.)"><span class="mark-date" style="width: 10%;text-align:right;">4/22/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7495800" target="_blank">(14) Matthew BOLING</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74751/4516389" target="_blank">19.92</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.9)</span></td><td style="width: 10%;text-align:right;" title="Georgia Tech Invitational (Atlanta, Ga.)"><span class="mark-date" style="width: 10%;text-align:right;">4/22/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6582462" target="_blank">(15) Cravon GILLESPIE</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850637" target="_blank">19.93</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6582462" target="_blank">(15) Cravon GILLESPIE</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850637" target="_blank">19.93</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Daniel {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Mississippi State" class="group-logo-inline" src="/images/logos/rankings-article/mississippi-state.png" title="Mississippi State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=987">Mississippi State</a></td><td style="width: 25%;">19.93  <br/><span style="font-size:0.7em;font-style: italic;"> (w: -1.5)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Auburn, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">5/15/1988</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Daniel {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Mississippi State" class="group-logo-inline" src="/images/logos/rankings-article/mississippi-state.png" title="Mississippi State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=987">Mississippi State</a></td><td style="width: 25%;">19.93  <br/><span style="font-size:0.7em;font-style: italic;"> (w: -1.5)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Auburn, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">5/15/1988</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8016458" target="_blank">(16) Tarsis OROGOT</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938108" target="_blank">19.94</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8016458" target="_blank">(16) Tarsis OROGOT</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938108" target="_blank">19.94</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Lindsey {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80804/4888710" target="_blank">19.94</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="Texas Tech Corky/Crofoot Shootout (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/28/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
# ...
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6133452" target="_blank">Akeem BLOOMFIELD</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=74">Auburn</a></td><td style="width: 25%;">20.00  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="Spitzen Leichtathletik Luzern (Lucerne, Switzerland)"><span class="mark-date" style="width: 10%;text-align:right;">7/9/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6133452" target="_blank">Akeem BLOOMFIELD</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=74">Auburn</a></td><td style="width: 25%;">20.00  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="Spitzen Leichtathletik Luzern (Lucerne, Switzerland)"><span class="mark-date" style="width: 10%;text-align:right;">7/9/2018</span></td></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">Additional Out-of-Season, All-Conditions Bests</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Ramon CLAY</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Norfolk State" class="group-logo-inline" src="/images/logos/rankings-article/norfolk-state.png" title="Norfolk State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1082">Norfolk State</a></td><td style="width: 25%;">19.99 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.7)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Atlanta, Ga.)"><span class="mark-date" style="width: 10%;text-align:right;">6/23/1996</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Ramon CLAY</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Norfolk State" class="group-logo-inline" src="/images/logos/rankings-article/norfolk-state.png" title="Norfolk State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=1082">Norfolk State</a></td><td style="width: 25%;">19.99 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.7)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Atlanta, Ga.)"><span class="mark-date" style="width: 10%;text-align:right;">6/23/1996</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3716329" target="_blank">Anaso JOBODWANA</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Jackson State" class="group-logo-inline" src="/images/logos/rankings-article/jackson-state.png" title="Jackson State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=727">Jackson State</a></td><td style="width: 25%;">20.00 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.4)</span></td><td style="width: 10%;text-align:right;" title="World University (FISU) Games (Kazan, Russia)"><span class="mark-date" style="width: 10%;text-align:right;">7/10/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3716329" target="_blank">Anaso JOBODWANA</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Jackson State" class="group-logo-inline" src="/images/logos/rankings-article/jackson-state.png" title="Jackson State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=727">Jackson State</a></td><td style="width: 25%;">20.00 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.4)</span></td><td style="width: 10%;text-align:right;" title="World University (FISU) Games (Kazan, Russia)"><span class="mark-date" style="width: 10%;text-align:right;">7/10/2013</span></td></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">Not Considered For Lists</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Tyson GAY</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=59">Arkansas</a></td><td style="width: 25%;">19.93 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2005</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Tyson GAY</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=59">Arkansas</a></td><td style="width: 25%;">19.93 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2005</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Tyson GAY</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=59">Arkansas</a></td><td style="width: 25%;">19.96  <br/><span style="font-size:0.7em;font-style: italic;"> (w: -1.5)</span></td><td style="width: 10%;text-align:right;" title=" (Monaco, Monaco)"><span class="mark-date" style="width: 10%;text-align:right;">9/9/2005</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Tyson GAY</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=59">Arkansas</a></td><td style="width: 25%;">19.96  <br/><span style="font-size:0.7em;font-style: italic;"> (w: -1.5)</span></td><td style="width: 10%;text-align:right;" title=" (Monaco, Monaco)"><span class="mark-date" style="width: 10%;text-align:right;">9/9/2005</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Tyson GAY</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=59">Arkansas</a></td><td style="width: 25%;">19.99 <span class="tooltip" style="font-size: smaller;">W<span class="tooltiptext" style="font-size: smaller;">W = Performance is heavily wind-aided and not valid for qualifying (&gt;4.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 4.3)</span></td><td style="width: 10%;text-align:right;" title="IAAF World Championships (Helsinki, Finland)"><span class="mark-date" style="width: 10%;text-align:right;">8/9/2005</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Tyson GAY</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=59">Arkansas</a></td><td style="width: 25%;">19.99 <span class="tooltip" style="font-size: smaller;">W<span class="tooltiptext" style="font-size: smaller;">W = Performance is heavily wind-aided and not valid for qualifying (&gt;4.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 4.3)</span></td><td style="width: 10%;text-align:right;" title="IAAF World Championships (Helsinki, Finland)"><span class="mark-date" style="width: 10%;text-align:right;">8/9/2005</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Tyson GAY</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=59">Arkansas</a></td><td style="width: 25%;">19.99  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.8)</span></td><td style="width: 10%;text-align:right;" title="London Diamond League (London, England)"><span class="mark-date" style="width: 10%;text-align:right;">7/22/2005</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Tyson GAY</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=1&amp;top=25&amp;event=3&amp;team=59">Arkansas</a></td><td style="width: 25%;">19.99  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.8)</span></td><td style="width: 10%;text-align:right;" title="London Diamond League (London, England)"><span class="mark-date" style="width: 10%;text-align:right;">7/22/2005</span></td></tr>,
#  <tr><td class="group-logo-50"><a href="https://allathletics.tv/?utc_source=ustfccca&amp;utc_medium=web&amp;utc_campaign=broadcast_schedule_sidebar" target="_blank"><img alt="eaa" src="/images/logos/rankings-article/eaa.png" title="EAA"/></a></td><td style="line-height: 1em;"><a href="https://allathletics.tv/?utc_source=ustfccca&amp;utc_medium=web&amp;utc_campaign=broadcast_schedule_sidebar" target="_blank">European U20 Championships</a></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Walter DIXJRFlorida State19.69📺  (w: 0.9)5/25/2007',
#   '(1) Walter DIXJR',
#   '',
#   'Florida State',
#   '19.69📺  (w: 0.9)',
#   '5/25/2007'],
#  [],
#  ['(1) Walter DIXJR', '', 'Florida State', '19.69📺  (w: 0.9)', '5/25/2007'],
#  ['(2) Divine ODUDURUJRTexas Tech19.73  (w: 0.8)6/7/2019',
#   '(2) Divine ODUDURUJR',
#   '',
#   'Texas Tech',
#   '19.73  (w: 0.8)',
#   '6/7/2019'],
#  [],
#  ['(2) Divine ODUDURUJR', '', 'Texas Tech', '19.73  (w: 0.8)', '6/7/2019'],
#  ['(3) Udodi ONWUZURIKESOStanford19.76 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '(3) Udodi ONWUZURIKESO',
#   '',
#   'Stanford',
#   '19.76 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  [],
#  ['(3) Udodi ONWUZURIKESO',
#   '',
#   'Stanford',
#   '19.76 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Oduduru {2}JRTexas Tech19.76  (w: 0.8)4/20/2019',
#   '\xa0\xa0\xa0\xa0— Oduduru {2}JR',
#   '',
#   'Texas Tech',
#   '19.76  (w: 0.8)',
#   '4/20/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Oduduru {2}JR',
#   '',
#   'Texas Tech',
#   '19.76  (w: 0.8)',
#   '4/20/2019'],
#  ['(4) Terrance LAIRDJRLSU19.81  (w: 0.8)3/25/2021',
#   '(4) Terrance LAIRDJR',
#   '',
#   'LSU',
#   '19.81  (w: 0.8)',
#   '3/25/2021'],
#  [],
#  ['(4) Terrance LAIRDJR', '', 'LSU', '19.81  (w: 0.8)', '3/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Laird {2}JRLSU19.82  (w: 1.7)5/13/2021',
#   '\xa0\xa0\xa0\xa0— Laird {2}JR',
#   '',
#   'LSU',
#   '19.82  (w: 1.7)',
#   '5/13/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Laird {2}JR', '', 'LSU', '19.82  (w: 1.7)', '5/13/2021'],
#  ['(5) Joseph FAHNBULLEHSOFlorida19.83  (w: 0.6)6/10/2022',
#   '(5) Joseph FAHNBULLEHSO',
#   '',
#   'Florida',
#   '19.83  (w: 0.6)',
#   '6/10/2022'],
#  [],
#  ['(5) Joseph FAHNBULLEHSO', '', 'Florida', '19.83  (w: 0.6)', '6/10/2022'],
#  ['\xa0\xa0\xa0\xa0— Onwuzurike {2}SOStanford19.84📺  (w: 0.9)6/9/2023',
#   '\xa0\xa0\xa0\xa0— Onwuzurike {2}SO',
#   '',
#   'Stanford',
#   '19.84📺  (w: 0.9)',
#   '6/9/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Onwuzurike {2}SO',
#   '',
#   'Stanford',
#   '19.84📺  (w: 0.9)',
#   '6/9/2023'],
#  ['(6) Christian COLEMANJRTennessee19.85 qq = Performance occurred during a non-final round.  (w: -0.5)5/27/2017',
#   '(6) Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '19.85 qq = Performance occurred during a non-final round.  (w: -0.5)',
#   '5/27/2017'],
#  [],
#  ['(6) Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '19.85 qq = Performance occurred during a non-final round.  (w: -0.5)',
#   '5/27/2017'],
#  ['(7) Courtney LINDSEYSRTexas Tech19.86  (w: 0.9)6/9/2023',
#   '(7) Courtney LINDSEYSR',
#   '',
#   'Texas Tech',
#   '19.86  (w: 0.9)',
#   '6/9/2023'],
#  [],
#  ['(7) Courtney LINDSEYSR', '', 'Texas Tech', '19.86  (w: 0.9)', '6/9/2023'],
#  ['(7) Justin GATLINSOTennessee19.86   (w: 1.5)5/12/2002',
#   '(7) Justin GATLINSO',
#   '',
#   'Tennessee',
#   '19.86   (w: 1.5)',
#   '5/12/2002'],
#  [],
#  ['(7) Justin GATLINSO', '', 'Tennessee', '19.86   (w: 1.5)', '5/12/2002'],
#  ['(9) Terrence JONESJRTexas Tech19.87  (w: 0.9)6/9/2023',
#   '(9) Terrence JONESJR',
#   '',
#   'Texas Tech',
#   '19.87  (w: 0.9)',
#   '6/9/2023'],
#  [],
#  ['(9) Terrence JONESJR', '', 'Texas Tech', '19.87  (w: 0.9)', '6/9/2023'],
#  ['(9) John CAPELFRFlorida19.87   (w: 1.4)6/5/1999',
#   '(9) John CAPELFR',
#   '',
#   'Florida',
#   '19.87   (w: 1.4)',
#   '6/5/1999'],
#  [],
#  ['(9) John CAPELFR', '', 'Florida', '19.87   (w: 1.4)', '6/5/1999'],
#  ['(9) Lorenzo DANIELSRMississippi State19.87   (w: 0.7)6/3/1988',
#   '(9) Lorenzo DANIELSR',
#   '',
#   'Mississippi State',
#   '19.87   (w: 0.7)',
#   '6/3/1988'],
#  [],
#  ['(9) Lorenzo DANIELSR',
#   '',
#   'Mississippi State',
#   '19.87   (w: 0.7)',
#   '6/3/1988'],
#  ['\xa0\xa0\xa0\xa0— Lindsey {2}SRTexas Tech19.88 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '\xa0\xa0\xa0\xa0— Lindsey {2}SR',
#   '',
#   'Texas Tech',
#   '19.88 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lindsey {2}SR',
#   '',
#   'Texas Tech',
#   '19.88 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['(12) Robert GREGORYSOFlorida19.89  (w: 0.9)6/9/2023',
#   '(12) Robert GREGORYSO',
#   '',
#   'Florida',
#   '19.89  (w: 0.9)',
#   '6/9/2023'],
#  [],
#  ['(12) Robert GREGORYSO', '', 'Florida', '19.89  (w: 0.9)', '6/9/2023'],
#  ['\xa0\xa0\xa0\xa0— Onwuzurike {3}SOStanford19.91  (w: 0.9)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Onwuzurike {3}SO',
#   '',
#   'Stanford',
#   '19.91  (w: 0.9)',
#   '5/12/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Onwuzurike {3}SO',
#   '',
#   'Stanford',
#   '19.91  (w: 0.9)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Fahnbulleh {2}FRFlorida19.91  (w: -0.4)6/11/2021',
#   '\xa0\xa0\xa0\xa0— Fahnbulleh {2}FR',
#   '',
#   'Florida',
#   '19.91  (w: -0.4)',
#   '6/11/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Fahnbulleh {2}FR',
#   '',
#   'Florida',
#   '19.91  (w: -0.4)',
#   '6/11/2021'],
#  ['(13) Wallace SPEARMONSOArkansas19.91   (w: -0.7)6/11/2005',
#   '(13) Wallace SPEARMONSO',
#   '',
#   'Arkansas',
#   '19.91   (w: -0.7)',
#   '6/11/2005'],
#  [],
#  ['(13) Wallace SPEARMONSO', '', 'Arkansas', '19.91   (w: -0.7)', '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— Fahnbulleh {3}SOFlorida19.92  (w: 1.4)4/30/2022',
#   '\xa0\xa0\xa0\xa0— Fahnbulleh {3}SO',
#   '',
#   'Florida',
#   '19.92  (w: 1.4)',
#   '4/30/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Fahnbulleh {3}SO',
#   '',
#   'Florida',
#   '19.92  (w: 1.4)',
#   '4/30/2022'],
#  ['(14) Matthew BOLINGSOGeorgia19.92  (w: -0.9)4/22/2022',
#   '(14) Matthew BOLINGSO',
#   '',
#   'Georgia',
#   '19.92  (w: -0.9)',
#   '4/22/2022'],
#  [],
#  ['(14) Matthew BOLINGSO', '', 'Georgia', '19.92  (w: -0.9)', '4/22/2022'],
#  ['(15) Cravon GILLESPIESROregon19.93  (w: 0.8)6/7/2019',
#   '(15) Cravon GILLESPIESR',
#   '',
#   'Oregon',
#   '19.93  (w: 0.8)',
#   '6/7/2019'],
#  [],
#  ['(15) Cravon GILLESPIESR', '', 'Oregon', '19.93  (w: 0.8)', '6/7/2019'],
#  ['\xa0\xa0\xa0\xa0— Daniel {2}SRMississippi State19.93   (w: -1.5)5/15/1988',
#   '\xa0\xa0\xa0\xa0— Daniel {2}SR',
#   '',
#   'Mississippi State',
#   '19.93   (w: -1.5)',
#   '5/15/1988'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Daniel {2}SR',
#   '',
#   'Mississippi State',
#   '19.93   (w: -1.5)',
#   '5/15/1988'],
#  ['(16) Tarsis OROGOTSOAlabama19.94 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '(16) Tarsis OROGOTSO',
#   '',
#   'Alabama',
#   '19.94 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  [],
#  ['(16) Tarsis OROGOTSO',
#   '',
#   'Alabama',
#   '19.94 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Lindsey {3}SRTexas Tech19.94 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)4/28/2023',
#   '\xa0\xa0\xa0\xa0— Lindsey {3}SR',
#   '',
#   'Texas Tech',
#   '19.94 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)',
#   '4/28/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lindsey {3}SR',
#   '',
#   'Texas Tech',
#   '19.94 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)',
#   '4/28/2023'],
#  ['\xa0\xa0\xa0\xa0— Laird {3}JRLSU19.94  (w: -0.4)6/11/2021',
#   '\xa0\xa0\xa0\xa0— Laird {3}JR',
#   '',
#   'LSU',
#   '19.94  (w: -0.4)',
#   '6/11/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Laird {3}JR', '', 'LSU', '19.94  (w: -0.4)', '6/11/2021'],
#  ['\xa0\xa0\xa0\xa0— Gregory {2}SOFlorida19.95 qq = Performance occurred during a non-final round.  (w: 1.0)6/7/2023',
#   '\xa0\xa0\xa0\xa0— Gregory {2}SO',
#   '',
#   'Florida',
#   '19.95 qq = Performance occurred during a non-final round.  (w: 1.0)',
#   '6/7/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Gregory {2}SO',
#   '',
#   'Florida',
#   '19.95 qq = Performance occurred during a non-final round.  (w: 1.0)',
#   '6/7/2023'],
#  ['(17) Nethaneel MITCHELL-BLAKEJRLSU19.95  (w: 0.4)5/14/2016',
#   '(17) Nethaneel MITCHELL-BLAKEJR',
#   '',
#   'LSU',
#   '19.95  (w: 0.4)',
#   '5/14/2016'],
#  [],
#  ['(17) Nethaneel MITCHELL-BLAKEJR',
#   '',
#   'LSU',
#   '19.95  (w: 0.4)',
#   '5/14/2016'],
#  ['(17) Floyd HEARDTexas A&M19.95   (w: 1.9)5/17/1987',
#   '(17) Floyd HEARD',
#   '',
#   'Texas A&M',
#   '19.95   (w: 1.9)',
#   '5/17/1987'],
#  [],
#  ['(17) Floyd HEARD', '', 'Texas A&M', '19.95   (w: 1.9)', '5/17/1987'],
#  ['\xa0\xa0\xa0\xa0— Oduduru {3}JRTexas Tech19.97 qq = Performance occurred during a non-final round.  (w: 2.0)6/5/2019',
#   '\xa0\xa0\xa0\xa0— Oduduru {3}JR',
#   '',
#   'Texas Tech',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '6/5/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Oduduru {3}JR',
#   '',
#   'Texas Tech',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '6/5/2019'],
#  ['(19) Jereem RICHARDSJRAlabama19.97 qq = Performance occurred during a non-final round.  (w: 0.2)5/27/2017',
#   '(19) Jereem RICHARDSJR',
#   '',
#   'Alabama',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '5/27/2017'],
#  [],
#  ['(19) Jereem RICHARDSJR',
#   '',
#   'Alabama',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '5/27/2017'],
#  ['\xa0\xa0\xa0\xa0— Richards {2}JRAlabama19.97 qq = Performance occurred during a non-final round.  (w: 0.2)5/27/2017',
#   '\xa0\xa0\xa0\xa0— Richards {2}JR',
#   '',
#   'Alabama',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '5/27/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Richards {2}JR',
#   '',
#   'Alabama',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '5/27/2017'],
#  ['(19) Dedric DUKESJRFlorida19.97  (w: -0.6)4/5/2014',
#   '(19) Dedric DUKESJR',
#   '',
#   'Florida',
#   '19.97  (w: -0.6)',
#   '4/5/2014'],
#  [],
#  ['(19) Dedric DUKESJR', '', 'Florida', '19.97  (w: -0.6)', '4/5/2014'],
#  ['\xa0\xa0\xa0\xa0— Spearmon {2}SOArkansas19.97   (w: 1.7)4/17/2005',
#   '\xa0\xa0\xa0\xa0— Spearmon {2}SO',
#   '',
#   'Arkansas',
#   '19.97   (w: 1.7)',
#   '4/17/2005'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Spearmon {2}SO',
#   '',
#   'Arkansas',
#   '19.97   (w: 1.7)',
#   '4/17/2005'],
#  ['(21) Javonte HARDINGJRTennessee19.98 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '(21) Javonte HARDINGJR',
#   '',
#   'Tennessee',
#   '19.98 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  [],
#  ['(21) Javonte HARDINGJR',
#   '',
#   'Tennessee',
#   '19.98 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JRTennessee19.98  (w: 0.6)5/13/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '19.98  (w: 0.6)',
#   '5/13/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '19.98  (w: 0.6)',
#   '5/13/2017'],
#  ['\xa0\xa0\xa0\xa0— Gatlin {2}SOTennessee19.98 qq = Performance occurred during a non-final round.  (w: 1.2)5/29/2002',
#   '\xa0\xa0\xa0\xa0— Gatlin {2}SO',
#   '',
#   'Tennessee',
#   '19.98 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '5/29/2002'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Gatlin {2}SO',
#   '',
#   'Tennessee',
#   '19.98 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '5/29/2002'],
#  ['(21) Joe DELOACHHouston19.98   (w: 0.2)5/15/1988',
#   '(21) Joe DELOACH',
#   '',
#   'Houston',
#   '19.98   (w: 0.2)',
#   '5/15/1988'],
#  [],
#  ['(21) Joe DELOACH', '', 'Houston', '19.98   (w: 0.2)', '5/15/1988'],
#  ['(23) Shaun MASWANGANYIJRHouston19.99 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '(23) Shaun MASWANGANYIJR',
#   '',
#   'Houston',
#   '19.99 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  [],
#  ['(23) Shaun MASWANGANYIJR',
#   '',
#   'Houston',
#   '19.99 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Dukes {2}SRFlorida19.99  (w: 0.6)5/16/2015',
#   '\xa0\xa0\xa0\xa0— Dukes {2}SR',
#   '',
#   'Florida',
#   '19.99  (w: 0.6)',
#   '5/16/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Dukes {2}SR',
#   '',
#   'Florida',
#   '19.99  (w: 0.6)',
#   '5/16/2015'],
#  ['(24) Dorian CAMELJRLSU20.00  (w: 1.4)4/30/2022',
#   '(24) Dorian CAMELJR',
#   '',
#   'LSU',
#   '20.00  (w: 1.4)',
#   '4/30/2022'],
#  [],
#  ['(24) Dorian CAMELJR', '', 'LSU', '20.00  (w: 1.4)', '4/30/2022'],
#  ['(24) Ncincilili TITISRSouth Carolina20.00  (w: 1.9)4/21/2018',
#   '(24) Ncincilili TITISR',
#   '',
#   'South Carolina',
#   '20.00  (w: 1.9)',
#   '4/21/2018'],
#  [],
#  ['(24) Ncincilili TITISR',
#   '',
#   'South Carolina',
#   '20.00  (w: 1.9)',
#   '4/21/2018'],
#  ['(24) Ato BOLDONSRUCLA20.00   (w: 1.0)5/19/1996',
#   '(24) Ato BOLDONSR',
#   '',
#   'UCLA',
#   '20.00   (w: 1.0)',
#   '5/19/1996'],
#  [],
#  ['(24) Ato BOLDONSR', '', 'UCLA', '20.00   (w: 1.0)', '5/19/1996'],
#  ['Additional All-Conditions Bests'],
#  ['Andre DE GRASSESouthern California19.58 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)6/12/2015',
#   'Andre DE GRASSE',
#   '',
#   'Southern California',
#   '19.58 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '6/12/2015'],
#  [],
#  ['Andre DE GRASSE',
#   '',
#   'Southern California',
#   '19.58 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '6/12/2015'],
#  ['Robert GREGORYSOFlorida19.60 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.8)5/26/2023',
#   'Robert GREGORYSO',
#   '',
#   'Florida',
#   '19.60 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.8)',
#   '5/26/2023'],
#  [],
#  ['Robert GREGORYSO',
#   '',
#   'Florida',
#   '19.60 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.8)',
#   '5/26/2023'],
#  ['Tarsis OROGOTSOAlabama19.60 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)4/14/2023',
#   'Tarsis OROGOTSO',
#   '',
#   'Alabama',
#   '19.60 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)',
#   '4/14/2023'],
#  [],
#  ['Tarsis OROGOTSO',
#   '',
#   'Alabama',
#   '19.60 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)',
#   '4/14/2023'],
#  ['Leroy BURRELLSRHouston19.61 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)5/19/1990',
#   'Leroy BURRELLSR',
#   '',
#   'Houston',
#   '19.61 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)',
#   '5/19/1990'],
#  [],
#  ['Leroy BURRELLSR',
#   '',
#   'Houston',
#   '19.61 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)',
#   '5/19/1990'],
#  ['Micaiah HARRISSRTexas19.72 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)5/13/2022',
#   'Micaiah HARRISSR',
#   '',
#   'Texas',
#   '19.72 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '5/13/2022'],
#  [],
#  ['Micaiah HARRISSR',
#   '',
#   'Texas',
#   '19.72 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '5/13/2022'],
#  ['Robert GREGORYSOFlorida19.78 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)4/14/2023',
#   'Robert GREGORYSO',
#   '',
#   'Florida',
#   '19.78 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)',
#   '4/14/2023'],
#  [],
#  ['Robert GREGORYSO',
#   '',
#   'Florida',
#   '19.78 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)',
#   '4/14/2023'],
#  ['Courtney LINDSEYJRTexas Tech19.81 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)5/13/2022',
#   'Courtney LINDSEYJR',
#   '',
#   'Texas Tech',
#   '19.81 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '5/13/2022'],
#  [],
#  ['Courtney LINDSEYJR',
#   '',
#   'Texas Tech',
#   '19.81 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '5/13/2022'],
#  ['Terrance LAIRDJRLSU19.82 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)4/24/2021',
#   'Terrance LAIRDJR',
#   '',
#   'LSU',
#   '19.82 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '4/24/2021'],
#  [],
#  ['Terrance LAIRDJR',
#   '',
#   'LSU',
#   '19.82 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '4/24/2021'],
#  ['Bobby CRUSEKent State19.83 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 9.2)4/9/1999',
#   'Bobby CRUSE',
#   '',
#   'Kent State',
#   '19.83 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 9.2)',
#   '4/9/1999'],
#  [],
#  ['Bobby CRUSE',
#   '',
#   'Kent State',
#   '19.83 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 9.2)',
#   '4/9/1999'],
#  ['Michael NORMANSOSouthern California19.84 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)5/13/2018',
#   'Michael NORMANSO',
#   '',
#   'Southern California',
#   '19.84 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '5/13/2018'],
#  [],
#  ['Michael NORMANSO',
#   '',
#   'Southern California',
#   '19.84 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '5/13/2018'],
#  ['Joseph FAHNBULLEHSOFlorida19.85 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.4)5/27/2022',
#   'Joseph FAHNBULLEHSO',
#   '',
#   'Florida',
#   '19.85 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.4)',
#   '5/27/2022'],
#  [],
#  ['Joseph FAHNBULLEHSO',
#   '',
#   'Florida',
#   '19.85 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.4)',
#   '5/27/2022'],
#  ['Dedric DUKESFlorida19.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)6/12/2015',
#   'Dedric DUKES',
#   '',
#   'Florida',
#   '19.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '6/12/2015'],
#  [],
#  ['Dedric DUKES',
#   '',
#   'Florida',
#   '19.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '6/12/2015'],
#  ['Trayvon BROMELLBaylor19.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)6/12/2015',
#   'Trayvon BROMELL',
#   '',
#   'Baylor',
#   '19.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '6/12/2015'],
#  [],
#  ['Trayvon BROMELL',
#   '',
#   'Baylor',
#   '19.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '6/12/2015'],
#  ['Justin GATLINFRTennessee19.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)5/30/2001\xa0\xa0\xa0\xa0\xa0all-conditions world-junior record',
#   'Justin GATLINFR',
#   '',
#   'Tennessee',
#   '19.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)',
#   '5/30/2001',
#   '\xa0\xa0\xa0\xa0\xa0all-conditions world-junior record'],
#  [],
#  ['Justin GATLINFR',
#   '',
#   'Tennessee',
#   '19.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)',
#   '5/30/2001'],
#  ['\xa0\xa0\xa0\xa0\xa0all-conditions world-junior record'],
#  ['Roy MARTINSMU19.86 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.6)5/18/1986',
#   'Roy MARTIN',
#   '',
#   'SMU',
#   '19.86 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.6)',
#   '5/18/1986'],
#  [],
#  ['Roy MARTIN',
#   '',
#   'SMU',
#   '19.86 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.6)',
#   '5/18/1986'],
#  ['Malik MOFFETTJRPenn State19.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.7)5/14/2017',
#   'Malik MOFFETTJR',
#   '',
#   'Penn State',
#   '19.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.7)',
#   '5/14/2017'],
#  [],
#  ['Malik MOFFETTJR',
#   '',
#   'Penn State',
#   '19.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.7)',
#   '5/14/2017'],
#  ['Lorenzo DANIELJRMississippi State19.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.4)5/17/1987',
#   'Lorenzo DANIELJR',
#   '',
#   'Mississippi State',
#   '19.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.4)',
#   '5/17/1987'],
#  [],
#  ['Lorenzo DANIELJR',
#   '',
#   'Mississippi State',
#   '19.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.4)',
#   '5/17/1987'],
#  ['Kennedy  LIGHTNER JRKentucky19.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.8)5/26/2023',
#   'Kennedy  LIGHTNER JR',
#   '',
#   'Kentucky',
#   '19.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.8)',
#   '5/26/2023'],
#  [],
#  ['Kennedy  LIGHTNER JR',
#   '',
#   'Kentucky',
#   '19.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.8)',
#   '5/26/2023'],
#  ['Frank FREDERICKSSRBYU19.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.6)6/1/1991',
#   'Frank FREDERICKSSR',
#   '',
#   'BYU',
#   '19.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.6)',
#   '6/1/1991'],
#  [],
#  ['Frank FREDERICKSSR',
#   '',
#   'BYU',
#   '19.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.6)',
#   '6/1/1991'],
#  ['Dedric DUKESJRFlorida19.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)6/14/2014',
#   'Dedric DUKESJR',
#   '',
#   'Florida',
#   '19.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '6/14/2014'],
#  [],
#  ['Dedric DUKESJR',
#   '',
#   'Florida',
#   '19.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '6/14/2014'],
#  ['Michael JOHNSONSRBaylor19.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)5/19/1990',
#   'Michael JOHNSONSR',
#   '',
#   'Baylor',
#   '19.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)',
#   '5/19/1990'],
#  [],
#  ['Michael JOHNSONSR',
#   '',
#   'Baylor',
#   '19.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)',
#   '5/19/1990'],
#  ['Courtney LINDSEYSRTexas Tech19.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)5/26/2023',
#   'Courtney LINDSEYSR',
#   '',
#   'Texas Tech',
#   '19.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)',
#   '5/26/2023'],
#  [],
#  ['Courtney LINDSEYSR',
#   '',
#   'Texas Tech',
#   '19.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)',
#   '5/26/2023'],
#  ['Cameron MILLERSOLouisville19.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)4/14/2023',
#   'Cameron MILLERSO',
#   '',
#   'Louisville',
#   '19.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)',
#   '4/14/2023'],
#  [],
#  ['Cameron MILLERSO',
#   '',
#   'Louisville',
#   '19.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)',
#   '4/14/2023'],
#  ['Shaun MASWANGANYIFRHouston19.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.3)5/14/2021',
#   'Shaun MASWANGANYIFR',
#   '',
#   'Houston',
#   '19.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.3)',
#   '5/14/2021'],
#  [],
#  ['Shaun MASWANGANYIFR',
#   '',
#   'Houston',
#   '19.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.3)',
#   '5/14/2021'],
#  ['Divine ODUDURUJRTexas Tech19.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)5/24/2019',
#   'Divine ODUDURUJR',
#   '',
#   'Texas Tech',
#   '19.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)',
#   '5/24/2019'],
#  [],
#  ['Divine ODUDURUJR',
#   '',
#   'Texas Tech',
#   '19.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)',
#   '5/24/2019'],
#  ['Terrance LAIRDJRLSU19.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)5/28/2021',
#   'Terrance LAIRDJR',
#   '',
#   'LSU',
#   '19.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '5/28/2021'],
#  [],
#  ['Terrance LAIRDJR',
#   '',
#   'LSU',
#   '19.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '5/28/2021'],
#  ['Joseph FAHNBULLEHFRFlorida19.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)5/28/2021',
#   'Joseph FAHNBULLEHFR',
#   '',
#   'Florida',
#   '19.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '5/28/2021'],
#  [],
#  ['Joseph FAHNBULLEHFR',
#   '',
#   'Florida',
#   '19.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '5/28/2021'],
#  ['Joseph FAHNBULLEHFRFlorida19.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)5/26/2021',
#   'Joseph FAHNBULLEHFR',
#   '',
#   'Florida',
#   '19.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '5/26/2021'],
#  [],
#  ['Joseph FAHNBULLEHFR',
#   '',
#   'Florida',
#   '19.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '5/26/2021'],
#  ['James SANFORDJRSouthern California19.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)6/7/1980',
#   'James SANFORDJR',
#   '',
#   'Southern California',
#   '19.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)',
#   '6/7/1980'],
#  [],
#  ['James SANFORDJR',
#   '',
#   'Southern California',
#   '19.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)',
#   '6/7/1980'],
#  ['Elijah HALLJRHouston19.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)5/14/2017',
#   'Elijah HALLJR',
#   '',
#   'Houston',
#   '19.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '5/14/2017'],
#  [],
#  ['Elijah HALLJR',
#   '',
#   'Houston',
#   '19.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '5/14/2017'],
#  ['Nick GRAYSOOhio State19.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.7)5/14/2017',
#   'Nick GRAYSO',
#   '',
#   'Ohio State',
#   '19.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.7)',
#   '5/14/2017'],
#  [],
#  ['Nick GRAYSO',
#   '',
#   'Ohio State',
#   '19.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.7)',
#   '5/14/2017'],
#  ['Nethaneel MITCHELL-BLAKEJRLSU19.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.6)5/28/2016',
#   'Nethaneel MITCHELL-BLAKEJR',
#   '',
#   'LSU',
#   '19.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.6)',
#   '5/28/2016'],
#  [],
#  ['Nethaneel MITCHELL-BLAKEJR',
#   '',
#   'LSU',
#   '19.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.6)',
#   '5/28/2016'],
#  ['Mike ROBERSONFlorida State19.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)6/7/1980',
#   'Mike ROBERSON',
#   '',
#   'Florida State',
#   '19.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '6/7/1980'],
#  [],
#  ['Mike ROBERSON',
#   '',
#   'Florida State',
#   '19.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '6/7/1980'],
#  ['Brendon RODNEYSRLIU19.97 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.3)5/28/2016',
#   'Brendon RODNEYSR',
#   '',
#   'LIU',
#   '19.97 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.3)',
#   '5/28/2016'],
#  [],
#  ['Brendon RODNEYSR',
#   '',
#   'LIU',
#   '19.97 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.3)',
#   '5/28/2016'],
#  ['Andre EWERSJRFlorida State19.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)5/12/2018',
#   'Andre EWERSJR',
#   '',
#   'Florida State',
#   '19.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)',
#   '5/12/2018'],
#  [],
#  ['Andre EWERSJR',
#   '',
#   'Florida State',
#   '19.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)',
#   '5/12/2018'],
#  ['Jereem RICHARDSJRAlabama19.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.3)5/11/2017',
#   'Jereem RICHARDSJR',
#   '',
#   'Alabama',
#   '19.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.3)',
#   '5/11/2017'],
#  [],
#  ['Jereem RICHARDSJR',
#   '',
#   'Alabama',
#   '19.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.3)',
#   '5/11/2017'],
#  ['Shaun MASWANGANYIJRHouston19.99 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)5/12/2023',
#   'Shaun MASWANGANYIJR',
#   '',
#   'Houston',
#   '19.99 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '5/12/2023'],
#  [],
#  ['Shaun MASWANGANYIJR',
#   '',
#   'Houston',
#   '19.99 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '5/12/2023'],
#  ['Aldrich BAILEY JR.SRTexas19.99 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.3)4/29/2017',
#   'Aldrich BAILEY JR.SR',
#   '',
#   'Texas',
#   '19.99 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.3)',
#   '4/29/2017'],
#  [],
#  ['Aldrich BAILEY JR.SR',
#   '',
#   'Texas',
#   '19.99 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.3)',
#   '4/29/2017'],
#  ['Bryshon NELLUMSRSouthern California19.99 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)6/6/2013',
#   'Bryshon NELLUMSR',
#   '',
#   'Southern California',
#   '19.99 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '6/6/2013'],
#  [],
#  ['Bryshon NELLUMSR',
#   '',
#   'Southern California',
#   '19.99 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '6/6/2013'],
#  ['Maurice MITCHELLFlorida State19.99 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)6/11/2011',
#   'Maurice MITCHELL',
#   '',
#   'Florida State',
#   '19.99 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '6/11/2011'],
#  [],
#  ['Maurice MITCHELL',
#   '',
#   'Florida State',
#   '19.99 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '6/11/2011'],
#  ['Javonte HARDINGJRTennessee20.00 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)5/26/2023',
#   'Javonte HARDINGJR',
#   '',
#   'Tennessee',
#   '20.00 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '5/26/2023'],
#  [],
#  ['Javonte HARDINGJR',
#   '',
#   'Tennessee',
#   '20.00 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '5/26/2023'],
#  ['Robert GREGORYSOTCU20.00 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)5/13/2022',
#   'Robert GREGORYSO',
#   '',
#   'TCU',
#   '20.00 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '5/13/2022'],
#  [],
#  ['Robert GREGORYSO',
#   '',
#   'TCU',
#   '20.00 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '5/13/2022'],
#  ['Additional Out-of-Season Bests'],
#  ['Xavier CARTERLSU19.63   (w: 0.4)7/11/2006',
#   'Xavier CARTER',
#   '',
#   'LSU',
#   '19.63   (w: 0.4)',
#   '7/11/2006'],
#  [],
#  ['Xavier CARTER', '', 'LSU', '19.63   (w: 0.4)', '7/11/2006'],
#  ['Joe DELOACHHouston19.75   (w: 1.7)9/28/1988',
#   'Joe DELOACH',
#   '',
#   'Houston',
#   '19.75   (w: 1.7)',
#   '9/28/1988'],
#  [],
#  ['Joe DELOACH', '', 'Houston', '19.75   (w: 1.7)', '9/28/1988'],
#  ['Ato BOLDONSRUCLA19.80   (w: 0.4)8/1/1996',
#   'Ato BOLDONSR',
#   '',
#   'UCLA',
#   '19.80   (w: 0.4)',
#   '8/1/1996'],
#  [],
#  ['Ato BOLDONSR', '', 'UCLA', '19.80   (w: 0.4)', '8/1/1996'],
#  ['Akeem BLOOMFIELDSOAuburn19.81   (w: 0.1)7/22/2018',
#   'Akeem BLOOMFIELDSO',
#   '',
#   'Auburn',
#   '19.81   (w: 0.1)',
#   '7/22/2018'],
#  [],
#  ['Akeem BLOOMFIELDSO', '', 'Auburn', '19.81   (w: 0.1)', '7/22/2018'],
#  ['Joseph FAHNBULLEHSOFlorida19.84   (w: 0.4)7/21/2022',
#   'Joseph FAHNBULLEHSO',
#   '',
#   'Florida',
#   '19.84   (w: 0.4)',
#   '7/21/2022'],
#  [],
#  ['Joseph FAHNBULLEHSO', '', 'Florida', '19.84   (w: 0.4)', '7/21/2022'],
#  ['Michael NORMANSOSouthern California19.84   (w: -0.6)6/30/2018',
#   'Michael NORMANSO',
#   '',
#   'Southern California',
#   '19.84   (w: -0.6)',
#   '6/30/2018'],
#  [],
#  ['Michael NORMANSO',
#   '',
#   'Southern California',
#   '19.84   (w: -0.6)',
#   '6/30/2018'],
#  ['Courtney LINDSEYSRTexas Tech19.85   (w: -0.1)7/9/2023',
#   'Courtney LINDSEYSR',
#   '',
#   'Texas Tech',
#   '19.85   (w: -0.1)',
#   '7/9/2023'],
#  [],
#  ['Courtney LINDSEYSR', '', 'Texas Tech', '19.85   (w: -0.1)', '7/9/2023'],
#  ['Ato BOLDONSRUCLA19.85   (w: -0.9)7/3/1996',
#   'Ato BOLDONSR',
#   '',
#   'UCLA',
#   '19.85   (w: -0.9)',
#   '7/3/1996'],
#  [],
#  ['Ato BOLDONSR', '', 'UCLA', '19.85   (w: -0.9)', '7/3/1996'],
#  ['Michael JOHNSONBaylor19.85   (w: 0.4)7/6/1990',
#   'Michael JOHNSON',
#   '',
#   'Baylor',
#   '19.85   (w: 0.4)',
#   '7/6/1990'],
#  [],
#  ['Michael JOHNSON', '', 'Baylor', '19.85   (w: 0.4)', '7/6/1990'],
#  ['Isiah YOUNGSROle Miss19.86   (w: 1.6)6/23/2013',
#   'Isiah YOUNGSR',
#   '',
#   'Ole Miss',
#   '19.86   (w: 1.6)',
#   '6/23/2013'],
#  [],
#  ['Isiah YOUNGSR', '', 'Ole Miss', '19.86   (w: 1.6)', '6/23/2013'],
#  ['Walter DIXSRFlorida State19.86   (w: 1.7)7/6/2008',
#   'Walter DIXSR',
#   '',
#   'Florida State',
#   '19.86   (w: 1.7)',
#   '7/6/2008'],
#  [],
#  ['Walter DIXSR', '', 'Florida State', '19.86   (w: 1.7)', '7/6/2008'],
#  ['Michael NORMANSOSouthern California19.88   (w: 0.4)7/5/2018',
#   'Michael NORMANSO',
#   '',
#   'Southern California',
#   '19.88   (w: 0.4)',
#   '7/5/2018'],
#  [],
#  ['Michael NORMANSO',
#   '',
#   'Southern California',
#   '19.88   (w: 0.4)',
#   '7/5/2018'],
#  ['Andre DE GRASSEJRSouthern California19.88   (w: 0.3)7/24/2015',
#   'Andre DE GRASSEJR',
#   '',
#   'Southern California',
#   '19.88   (w: 0.3)',
#   '7/24/2015'],
#  [],
#  ['Andre DE GRASSEJR',
#   '',
#   'Southern California',
#   '19.88   (w: 0.3)',
#   '7/24/2015'],
#  ['Michael JOHNSONBaylor19.88   (w: 1.5)8/8/1990',
#   'Michael JOHNSON',
#   '',
#   'Baylor',
#   '19.88   (w: 1.5)',
#   '8/8/1990'],
#  [],
#  ['Michael JOHNSON', '', 'Baylor', '19.88   (w: 1.5)', '8/8/1990'],
#  ['Wallace SPEARMONSOArkansas19.89   (w: 1.8)7/22/2005',
#   'Wallace SPEARMONSO',
#   '',
#   'Arkansas',
#   '19.89   (w: 1.8)',
#   '7/22/2005'],
#  [],
#  ['Wallace SPEARMONSO', '', 'Arkansas', '19.89   (w: 1.8)', '7/22/2005'],
#  ['Robert GREGORYSOFlorida19.90   (w: -0.1)7/9/2023',
#   'Robert GREGORYSO',
#   '',
#   'Florida',
#   '19.90   (w: -0.1)',
#   '7/9/2023'],
#  [],
#  ['Robert GREGORYSO', '', 'Florida', '19.90   (w: -0.1)', '7/9/2023'],
#  ['Michael JOHNSONSRBaylor19.90   (w: 0.3)6/16/1990',
#   'Michael JOHNSONSR',
#   '',
#   'Baylor',
#   '19.90   (w: 0.3)',
#   '6/16/1990'],
#  [],
#  ['Michael JOHNSONSR', '', 'Baylor', '19.90   (w: 0.3)', '6/16/1990'],
#  ['Joseph FAHNBULLEHSOFlorida19.92 qq = Performance occurred during a non-final round.  (w: -0.1)7/19/2022',
#   'Joseph FAHNBULLEHSO',
#   '',
#   'Florida',
#   '19.92 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '7/19/2022'],
#  [],
#  ['Joseph FAHNBULLEHSO',
#   '',
#   'Florida',
#   '19.92 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '7/19/2022'],
#  ['Courtney LINDSEYSRTexas Tech19.94 qq = Performance occurred during a non-final round.  (w: -0.1)7/9/2023',
#   'Courtney LINDSEYSR',
#   '',
#   'Texas Tech',
#   '19.94 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '7/9/2023'],
#  [],
#  ['Courtney LINDSEYSR',
#   '',
#   'Texas Tech',
#   '19.94 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '7/9/2023'],
#  ['Ato BOLDONUCLA19.94   (w: 0.6)7/8/1996',
#   'Ato BOLDON',
#   '',
#   'UCLA',
#   '19.94   (w: 0.6)',
#   '7/8/1996'],
#  [],
#  ['Ato BOLDON', '', 'UCLA', '19.94   (w: 0.6)', '7/8/1996'],
#  ['Brendon RODNEYSRLIU19.96   (w: 1.1)7/9/2016',
#   'Brendon RODNEYSR',
#   '',
#   'LIU',
#   '19.96   (w: 1.1)',
#   '7/9/2016'],
#  [],
#  ['Brendon RODNEYSR', '', 'LIU', '19.96   (w: 1.1)', '7/9/2016'],
#  ['Coby MILLERAuburn19.96   (w: -0.3)7/23/2000',
#   'Coby MILLER',
#   '',
#   'Auburn',
#   '19.96   (w: -0.3)',
#   '7/23/2000'],
#  [],
#  ['Coby MILLER', '', 'Auburn', '19.96   (w: -0.3)', '7/23/2000'],
#  ['Joe DELOACHHouston19.96   (w: 1.0)7/20/1988',
#   'Joe DELOACH',
#   '',
#   'Houston',
#   '19.96   (w: 1.0)',
#   '7/20/1988'],
#  [],
#  ['Joe DELOACH', '', 'Houston', '19.96   (w: 1.0)', '7/20/1988'],
#  ['Kirk BAPTISTESOHouston19.96   (w: -0.9)8/8/1984',
#   'Kirk BAPTISTESO',
#   '',
#   'Houston',
#   '19.96   (w: -0.9)',
#   '8/8/1984'],
#  [],
#  ['Kirk BAPTISTESO', '', 'Houston', '19.96   (w: -0.9)', '8/8/1984'],
#  ['Xavier CARTERSOLSU19.97   (w: 0.2)8/25/2006',
#   'Xavier CARTERSO',
#   '',
#   'LSU',
#   '19.97   (w: 0.2)',
#   '8/25/2006'],
#  [],
#  ['Xavier CARTERSO', '', 'LSU', '19.97   (w: 0.2)', '8/25/2006'],
#  ['Joseph FAHNBULLEHFRFlorida19.98   (w: -0.5)8/4/2021',
#   'Joseph FAHNBULLEHFR',
#   '',
#   'Florida',
#   '19.98   (w: -0.5)',
#   '8/4/2021'],
#  [],
#  ['Joseph FAHNBULLEHFR', '', 'Florida', '19.98   (w: -0.5)', '8/4/2021'],
#  ['Walter DIXSRFlorida State19.98   (w: -0.9)8/20/2008',
#   'Walter DIXSR',
#   '',
#   'Florida State',
#   '19.98   (w: -0.9)',
#   '8/20/2008'],
#  [],
#  ['Walter DIXSR', '', 'Florida State', '19.98   (w: -0.9)', '8/20/2008'],
#  ['Xavier CARTERLSU19.98   (w: 0.2)7/28/2006',
#   'Xavier CARTER',
#   '',
#   'LSU',
#   '19.98   (w: 0.2)',
#   '7/28/2006'],
#  [],
#  ['Xavier CARTER', '', 'LSU', '19.98   (w: 0.2)', '7/28/2006'],
#  ['Joseph FAHNBULLEHFRFlorida19.99 qq = Performance occurred during a non-final round.  (w: -0.4)8/3/2021',
#   'Joseph FAHNBULLEHFR',
#   '',
#   'Florida',
#   '19.99 qq = Performance occurred during a non-final round.  (w: -0.4)',
#   '8/3/2021'],
#  [],
#  ['Joseph FAHNBULLEHFR',
#   '',
#   'Florida',
#   '19.99 qq = Performance occurred during a non-final round.  (w: -0.4)',
#   '8/3/2021'],
#  ['Rai BENJAMINJRSouthern California19.99   (w: -0.6)6/30/2018',
#   'Rai BENJAMINJR',
#   '',
#   'Southern California',
#   '19.99   (w: -0.6)',
#   '6/30/2018'],
#  [],
#  ['Rai BENJAMINJR',
#   '',
#   'Southern California',
#   '19.99   (w: -0.6)',
#   '6/30/2018'],
#  ['John CAPELFRFlorida19.99   (w: 0.0)6/16/1999',
#   'John CAPELFR',
#   '',
#   'Florida',
#   '19.99   (w: 0.0)',
#   '6/16/1999'],
#  [],
#  ['John CAPELFR', '', 'Florida', '19.99   (w: 0.0)', '6/16/1999'],
#  ['Ato BOLDONSRUCLA19.99   (w: -0.2)8/23/1996',
#   'Ato BOLDONSR',
#   '',
#   'UCLA',
#   '19.99   (w: -0.2)',
#   '8/23/1996'],
#  [],
#  ['Ato BOLDONSR', '', 'UCLA', '19.99   (w: -0.2)', '8/23/1996'],
#  ['Calvin SMITHAlabama19.99   (w: 0.6)8/24/1983',
#   'Calvin SMITH',
#   '',
#   'Alabama',
#   '19.99   (w: 0.6)',
#   '8/24/1983'],
#  [],
#  ['Calvin SMITH', '', 'Alabama', '19.99   (w: 0.6)', '8/24/1983'],
#  ['Robert GREGORYSOFlorida20.00 qq = Performance occurred during a non-final round.  (w: 2.0)7/8/2023',
#   'Robert GREGORYSO',
#   '',
#   'Florida',
#   '20.00 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '7/8/2023'],
#  [],
#  ['Robert GREGORYSO',
#   '',
#   'Florida',
#   '20.00 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '7/8/2023'],
#  ['Akeem BLOOMFIELDSOAuburn20.00   (w: 0.9)7/9/2018',
#   'Akeem BLOOMFIELDSO',
#   '',
#   'Auburn',
#   '20.00   (w: 0.9)',
#   '7/9/2018'],
#  [],
#  ['Akeem BLOOMFIELDSO', '', 'Auburn', '20.00   (w: 0.9)', '7/9/2018'],
#  ['Additional Out-of-Season, All-Conditions Bests'],
#  ['Ramon CLAYNorfolk State19.99 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)6/23/1996',
#   'Ramon CLAY',
#   '',
#   'Norfolk State',
#   '19.99 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '6/23/1996'],
#  [],
#  ['Ramon CLAY',
#   '',
#   'Norfolk State',
#   '19.99 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '6/23/1996'],
#  ['Anaso JOBODWANASOJackson State20.00 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)7/10/2013',
#   'Anaso JOBODWANASO',
#   '',
#   'Jackson State',
#   '20.00 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '7/10/2013'],
#  [],
#  ['Anaso JOBODWANASO',
#   '',
#   'Jackson State',
#   '20.00 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '7/10/2013'],
#  ['Not Considered For Lists'],
#  ['Tyson GAYSRArkansas19.93 qq = Performance occurred during a non-final round.  (w: 0.6)6/10/2005',
#   'Tyson GAYSR',
#   '',
#   'Arkansas',
#   '19.93 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/10/2005'],
#  [],
#  ['Tyson GAYSR',
#   '',
#   'Arkansas',
#   '19.93 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/10/2005'],
#  ['Tyson GAYArkansas19.96   (w: -1.5)9/9/2005',
#   'Tyson GAY',
#   '',
#   'Arkansas',
#   '19.96   (w: -1.5)',
#   '9/9/2005'],
#  [],
#  ['Tyson GAY', '', 'Arkansas', '19.96   (w: -1.5)', '9/9/2005'],
#  ['Tyson GAYSRArkansas19.99 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.3)8/9/2005',
#   'Tyson GAYSR',
#   '',
#   'Arkansas',
#   '19.99 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.3)',
#   '8/9/2005'],
#  [],
#  ['Tyson GAYSR',
#   '',
#   'Arkansas',
#   '19.99 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.3)',
#   '8/9/2005'],
#  ['Tyson GAYSRArkansas19.99   (w: 1.8)7/22/2005',
#   'Tyson GAYSR',
#   '',
#   'Arkansas',
#   '19.99   (w: 1.8)',
#   '7/22/2005'],
#  [],
#  ['Tyson GAYSR', '', 'Arkansas', '19.99   (w: 1.8)', '7/22/2005'],
#  ['', 'European U20 Championships'],
#  ['', '', '', '']]

# %%
rows[128]
# Out:
# ['(24) Ato BOLDONSRUCLA20.00   (w: 1.0)5/19/1996',
#  '(24) Ato BOLDONSR',
#  '',
#  'UCLA',
#  '20.00   (w: 1.0)',
#  '5/19/1996']

# %%
len(rows)
# Out:
# 387

# %%
RealRows = []

# %%
for i in range(0,129):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [['(1) Walter DIXJRFlorida State19.69📺  (w: 0.9)5/25/2007',
#   '(1) Walter DIXJR',
#   '',
#   'Florida State',
#   '19.69📺  (w: 0.9)',
#   '5/25/2007'],
#  ['(1) Walter DIXJR', '', 'Florida State', '19.69📺  (w: 0.9)', '5/25/2007'],
#  ['(2) Divine ODUDURUJRTexas Tech19.73  (w: 0.8)6/7/2019',
#   '(2) Divine ODUDURUJR',
#   '',
#   'Texas Tech',
#   '19.73  (w: 0.8)',
#   '6/7/2019'],
#  ['(2) Divine ODUDURUJR', '', 'Texas Tech', '19.73  (w: 0.8)', '6/7/2019'],
#  ['(3) Udodi ONWUZURIKESOStanford19.76 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '(3) Udodi ONWUZURIKESO',
#   '',
#   'Stanford',
#   '19.76 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['(3) Udodi ONWUZURIKESO',
#   '',
#   'Stanford',
#   '19.76 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Oduduru {2}JRTexas Tech19.76  (w: 0.8)4/20/2019',
#   '\xa0\xa0\xa0\xa0— Oduduru {2}JR',
#   '',
#   'Texas Tech',
#   '19.76  (w: 0.8)',
#   '4/20/2019'],
#  ['\xa0\xa0\xa0\xa0— Oduduru {2}JR',
#   '',
#   'Texas Tech',
#   '19.76  (w: 0.8)',
#   '4/20/2019'],
#  ['(4) Terrance LAIRDJRLSU19.81  (w: 0.8)3/25/2021',
#   '(4) Terrance LAIRDJR',
#   '',
#   'LSU',
#   '19.81  (w: 0.8)',
#   '3/25/2021'],
#  ['(4) Terrance LAIRDJR', '', 'LSU', '19.81  (w: 0.8)', '3/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Laird {2}JRLSU19.82  (w: 1.7)5/13/2021',
#   '\xa0\xa0\xa0\xa0— Laird {2}JR',
#   '',
#   'LSU',
#   '19.82  (w: 1.7)',
#   '5/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Laird {2}JR', '', 'LSU', '19.82  (w: 1.7)', '5/13/2021'],
#  ['(5) Joseph FAHNBULLEHSOFlorida19.83  (w: 0.6)6/10/2022',
#   '(5) Joseph FAHNBULLEHSO',
#   '',
#   'Florida',
#   '19.83  (w: 0.6)',
#   '6/10/2022'],
#  ['(5) Joseph FAHNBULLEHSO', '', 'Florida', '19.83  (w: 0.6)', '6/10/2022'],
#  ['\xa0\xa0\xa0\xa0— Onwuzurike {2}SOStanford19.84📺  (w: 0.9)6/9/2023',
#   '\xa0\xa0\xa0\xa0— Onwuzurike {2}SO',
#   '',
#   'Stanford',
#   '19.84📺  (w: 0.9)',
#   '6/9/2023'],
#  ['\xa0\xa0\xa0\xa0— Onwuzurike {2}SO',
#   '',
#   'Stanford',
#   '19.84📺  (w: 0.9)',
#   '6/9/2023'],
#  ['(6) Christian COLEMANJRTennessee19.85 qq = Performance occurred during a non-final round.  (w: -0.5)5/27/2017',
#   '(6) Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '19.85 qq = Performance occurred during a non-final round.  (w: -0.5)',
#   '5/27/2017'],
#  ['(6) Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '19.85 qq = Performance occurred during a non-final round.  (w: -0.5)',
#   '5/27/2017'],
#  ['(7) Courtney LINDSEYSRTexas Tech19.86  (w: 0.9)6/9/2023',
#   '(7) Courtney LINDSEYSR',
#   '',
#   'Texas Tech',
#   '19.86  (w: 0.9)',
#   '6/9/2023'],
#  ['(7) Courtney LINDSEYSR', '', 'Texas Tech', '19.86  (w: 0.9)', '6/9/2023'],
#  ['(7) Justin GATLINSOTennessee19.86   (w: 1.5)5/12/2002',
#   '(7) Justin GATLINSO',
#   '',
#   'Tennessee',
#   '19.86   (w: 1.5)',
#   '5/12/2002'],
#  ['(7) Justin GATLINSO', '', 'Tennessee', '19.86   (w: 1.5)', '5/12/2002'],
#  ['(9) Terrence JONESJRTexas Tech19.87  (w: 0.9)6/9/2023',
#   '(9) Terrence JONESJR',
#   '',
#   'Texas Tech',
#   '19.87  (w: 0.9)',
#   '6/9/2023'],
#  ['(9) Terrence JONESJR', '', 'Texas Tech', '19.87  (w: 0.9)', '6/9/2023'],
#  ['(9) John CAPELFRFlorida19.87   (w: 1.4)6/5/1999',
#   '(9) John CAPELFR',
#   '',
#   'Florida',
#   '19.87   (w: 1.4)',
#   '6/5/1999'],
#  ['(9) John CAPELFR', '', 'Florida', '19.87   (w: 1.4)', '6/5/1999'],
#  ['(9) Lorenzo DANIELSRMississippi State19.87   (w: 0.7)6/3/1988',
#   '(9) Lorenzo DANIELSR',
#   '',
#   'Mississippi State',
#   '19.87   (w: 0.7)',
#   '6/3/1988'],
#  ['(9) Lorenzo DANIELSR',
#   '',
#   'Mississippi State',
#   '19.87   (w: 0.7)',
#   '6/3/1988'],
#  ['\xa0\xa0\xa0\xa0— Lindsey {2}SRTexas Tech19.88 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '\xa0\xa0\xa0\xa0— Lindsey {2}SR',
#   '',
#   'Texas Tech',
#   '19.88 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Lindsey {2}SR',
#   '',
#   'Texas Tech',
#   '19.88 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['(12) Robert GREGORYSOFlorida19.89  (w: 0.9)6/9/2023',
#   '(12) Robert GREGORYSO',
#   '',
#   'Florida',
#   '19.89  (w: 0.9)',
#   '6/9/2023'],
#  ['(12) Robert GREGORYSO', '', 'Florida', '19.89  (w: 0.9)', '6/9/2023'],
#  ['\xa0\xa0\xa0\xa0— Onwuzurike {3}SOStanford19.91  (w: 0.9)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Onwuzurike {3}SO',
#   '',
#   'Stanford',
#   '19.91  (w: 0.9)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Onwuzurike {3}SO',
#   '',
#   'Stanford',
#   '19.91  (w: 0.9)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Fahnbulleh {2}FRFlorida19.91  (w: -0.4)6/11/2021',
#   '\xa0\xa0\xa0\xa0— Fahnbulleh {2}FR',
#   '',
#   'Florida',
#   '19.91  (w: -0.4)',
#   '6/11/2021'],
#  ['\xa0\xa0\xa0\xa0— Fahnbulleh {2}FR',
#   '',
#   'Florida',
#   '19.91  (w: -0.4)',
#   '6/11/2021'],
#  ['(13) Wallace SPEARMONSOArkansas19.91   (w: -0.7)6/11/2005',
#   '(13) Wallace SPEARMONSO',
#   '',
#   'Arkansas',
#   '19.91   (w: -0.7)',
#   '6/11/2005'],
#  ['(13) Wallace SPEARMONSO', '', 'Arkansas', '19.91   (w: -0.7)', '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— Fahnbulleh {3}SOFlorida19.92  (w: 1.4)4/30/2022',
#   '\xa0\xa0\xa0\xa0— Fahnbulleh {3}SO',
#   '',
#   'Florida',
#   '19.92  (w: 1.4)',
#   '4/30/2022'],
#  ['\xa0\xa0\xa0\xa0— Fahnbulleh {3}SO',
#   '',
#   'Florida',
#   '19.92  (w: 1.4)',
#   '4/30/2022'],
#  ['(14) Matthew BOLINGSOGeorgia19.92  (w: -0.9)4/22/2022',
#   '(14) Matthew BOLINGSO',
#   '',
#   'Georgia',
#   '19.92  (w: -0.9)',
#   '4/22/2022'],
#  ['(14) Matthew BOLINGSO', '', 'Georgia', '19.92  (w: -0.9)', '4/22/2022'],
#  ['(15) Cravon GILLESPIESROregon19.93  (w: 0.8)6/7/2019',
#   '(15) Cravon GILLESPIESR',
#   '',
#   'Oregon',
#   '19.93  (w: 0.8)',
#   '6/7/2019'],
#  ['(15) Cravon GILLESPIESR', '', 'Oregon', '19.93  (w: 0.8)', '6/7/2019'],
#  ['\xa0\xa0\xa0\xa0— Daniel {2}SRMississippi State19.93   (w: -1.5)5/15/1988',
#   '\xa0\xa0\xa0\xa0— Daniel {2}SR',
#   '',
#   'Mississippi State',
#   '19.93   (w: -1.5)',
#   '5/15/1988'],
#  ['\xa0\xa0\xa0\xa0— Daniel {2}SR',
#   '',
#   'Mississippi State',
#   '19.93   (w: -1.5)',
#   '5/15/1988'],
#  ['(16) Tarsis OROGOTSOAlabama19.94 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '(16) Tarsis OROGOTSO',
#   '',
#   'Alabama',
#   '19.94 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['(16) Tarsis OROGOTSO',
#   '',
#   'Alabama',
#   '19.94 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Lindsey {3}SRTexas Tech19.94 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)4/28/2023',
#   '\xa0\xa0\xa0\xa0— Lindsey {3}SR',
#   '',
#   'Texas Tech',
#   '19.94 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)',
#   '4/28/2023'],
#  ['\xa0\xa0\xa0\xa0— Lindsey {3}SR',
#   '',
#   'Texas Tech',
#   '19.94 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)',
#   '4/28/2023'],
#  ['\xa0\xa0\xa0\xa0— Laird {3}JRLSU19.94  (w: -0.4)6/11/2021',
#   '\xa0\xa0\xa0\xa0— Laird {3}JR',
#   '',
#   'LSU',
#   '19.94  (w: -0.4)',
#   '6/11/2021'],
#  ['\xa0\xa0\xa0\xa0— Laird {3}JR', '', 'LSU', '19.94  (w: -0.4)', '6/11/2021'],
#  ['\xa0\xa0\xa0\xa0— Gregory {2}SOFlorida19.95 qq = Performance occurred during a non-final round.  (w: 1.0)6/7/2023',
#   '\xa0\xa0\xa0\xa0— Gregory {2}SO',
#   '',
#   'Florida',
#   '19.95 qq = Performance occurred during a non-final round.  (w: 1.0)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Gregory {2}SO',
#   '',
#   'Florida',
#   '19.95 qq = Performance occurred during a non-final round.  (w: 1.0)',
#   '6/7/2023'],
#  ['(17) Nethaneel MITCHELL-BLAKEJRLSU19.95  (w: 0.4)5/14/2016',
#   '(17) Nethaneel MITCHELL-BLAKEJR',
#   '',
#   'LSU',
#   '19.95  (w: 0.4)',
#   '5/14/2016'],
#  ['(17) Nethaneel MITCHELL-BLAKEJR',
#   '',
#   'LSU',
#   '19.95  (w: 0.4)',
#   '5/14/2016'],
#  ['(17) Floyd HEARDTexas A&M19.95   (w: 1.9)5/17/1987',
#   '(17) Floyd HEARD',
#   '',
#   'Texas A&M',
#   '19.95   (w: 1.9)',
#   '5/17/1987'],
#  ['(17) Floyd HEARD', '', 'Texas A&M', '19.95   (w: 1.9)', '5/17/1987'],
#  ['\xa0\xa0\xa0\xa0— Oduduru {3}JRTexas Tech19.97 qq = Performance occurred during a non-final round.  (w: 2.0)6/5/2019',
#   '\xa0\xa0\xa0\xa0— Oduduru {3}JR',
#   '',
#   'Texas Tech',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '6/5/2019'],
#  ['\xa0\xa0\xa0\xa0— Oduduru {3}JR',
#   '',
#   'Texas Tech',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '6/5/2019'],
#  ['(19) Jereem RICHARDSJRAlabama19.97 qq = Performance occurred during a non-final round.  (w: 0.2)5/27/2017',
#   '(19) Jereem RICHARDSJR',
#   '',
#   'Alabama',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '5/27/2017'],
#  ['(19) Jereem RICHARDSJR',
#   '',
#   'Alabama',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '5/27/2017'],
#  ['\xa0\xa0\xa0\xa0— Richards {2}JRAlabama19.97 qq = Performance occurred during a non-final round.  (w: 0.2)5/27/2017',
#   '\xa0\xa0\xa0\xa0— Richards {2}JR',
#   '',
#   'Alabama',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '5/27/2017'],
#  ['\xa0\xa0\xa0\xa0— Richards {2}JR',
#   '',
#   'Alabama',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '5/27/2017'],
#  ['(19) Dedric DUKESJRFlorida19.97  (w: -0.6)4/5/2014',
#   '(19) Dedric DUKESJR',
#   '',
#   'Florida',
#   '19.97  (w: -0.6)',
#   '4/5/2014'],
#  ['(19) Dedric DUKESJR', '', 'Florida', '19.97  (w: -0.6)', '4/5/2014'],
#  ['\xa0\xa0\xa0\xa0— Spearmon {2}SOArkansas19.97   (w: 1.7)4/17/2005',
#   '\xa0\xa0\xa0\xa0— Spearmon {2}SO',
#   '',
#   'Arkansas',
#   '19.97   (w: 1.7)',
#   '4/17/2005'],
#  ['\xa0\xa0\xa0\xa0— Spearmon {2}SO',
#   '',
#   'Arkansas',
#   '19.97   (w: 1.7)',
#   '4/17/2005'],
#  ['(21) Javonte HARDINGJRTennessee19.98 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '(21) Javonte HARDINGJR',
#   '',
#   'Tennessee',
#   '19.98 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['(21) Javonte HARDINGJR',
#   '',
#   'Tennessee',
#   '19.98 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JRTennessee19.98  (w: 0.6)5/13/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '19.98  (w: 0.6)',
#   '5/13/2017'],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '19.98  (w: 0.6)',
#   '5/13/2017'],
#  ['\xa0\xa0\xa0\xa0— Gatlin {2}SOTennessee19.98 qq = Performance occurred during a non-final round.  (w: 1.2)5/29/2002',
#   '\xa0\xa0\xa0\xa0— Gatlin {2}SO',
#   '',
#   'Tennessee',
#   '19.98 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '5/29/2002'],
#  ['\xa0\xa0\xa0\xa0— Gatlin {2}SO',
#   '',
#   'Tennessee',
#   '19.98 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '5/29/2002'],
#  ['(21) Joe DELOACHHouston19.98   (w: 0.2)5/15/1988',
#   '(21) Joe DELOACH',
#   '',
#   'Houston',
#   '19.98   (w: 0.2)',
#   '5/15/1988'],
#  ['(21) Joe DELOACH', '', 'Houston', '19.98   (w: 0.2)', '5/15/1988'],
#  ['(23) Shaun MASWANGANYIJRHouston19.99 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '(23) Shaun MASWANGANYIJR',
#   '',
#   'Houston',
#   '19.99 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['(23) Shaun MASWANGANYIJR',
#   '',
#   'Houston',
#   '19.99 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Dukes {2}SRFlorida19.99  (w: 0.6)5/16/2015',
#   '\xa0\xa0\xa0\xa0— Dukes {2}SR',
#   '',
#   'Florida',
#   '19.99  (w: 0.6)',
#   '5/16/2015'],
#  ['\xa0\xa0\xa0\xa0— Dukes {2}SR',
#   '',
#   'Florida',
#   '19.99  (w: 0.6)',
#   '5/16/2015'],
#  ['(24) Dorian CAMELJRLSU20.00  (w: 1.4)4/30/2022',
#   '(24) Dorian CAMELJR',
#   '',
#   'LSU',
#   '20.00  (w: 1.4)',
#   '4/30/2022'],
#  ['(24) Dorian CAMELJR', '', 'LSU', '20.00  (w: 1.4)', '4/30/2022'],
#  ['(24) Ncincilili TITISRSouth Carolina20.00  (w: 1.9)4/21/2018',
#   '(24) Ncincilili TITISR',
#   '',
#   'South Carolina',
#   '20.00  (w: 1.9)',
#   '4/21/2018'],
#  ['(24) Ncincilili TITISR',
#   '',
#   'South Carolina',
#   '20.00  (w: 1.9)',
#   '4/21/2018'],
#  ['(24) Ato BOLDONSRUCLA20.00   (w: 1.0)5/19/1996',
#   '(24) Ato BOLDONSR',
#   '',
#   'UCLA',
#   '20.00   (w: 1.0)',
#   '5/19/1996']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Walter DIXJRFlorida State19.69📺  (w: 0.9)5/25/2007',
#   '(1) Walter DIXJR',
#   '',
#   'Florida State',
#   '19.69📺  (w: 0.9)',
#   '5/25/2007'],
#  ['(2) Divine ODUDURUJRTexas Tech19.73  (w: 0.8)6/7/2019',
#   '(2) Divine ODUDURUJR',
#   '',
#   'Texas Tech',
#   '19.73  (w: 0.8)',
#   '6/7/2019'],
#  ['(3) Udodi ONWUZURIKESOStanford19.76 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '(3) Udodi ONWUZURIKESO',
#   '',
#   'Stanford',
#   '19.76 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Oduduru {2}JRTexas Tech19.76  (w: 0.8)4/20/2019',
#   '\xa0\xa0\xa0\xa0— Oduduru {2}JR',
#   '',
#   'Texas Tech',
#   '19.76  (w: 0.8)',
#   '4/20/2019'],
#  ['(4) Terrance LAIRDJRLSU19.81  (w: 0.8)3/25/2021',
#   '(4) Terrance LAIRDJR',
#   '',
#   'LSU',
#   '19.81  (w: 0.8)',
#   '3/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Laird {2}JRLSU19.82  (w: 1.7)5/13/2021',
#   '\xa0\xa0\xa0\xa0— Laird {2}JR',
#   '',
#   'LSU',
#   '19.82  (w: 1.7)',
#   '5/13/2021'],
#  ['(5) Joseph FAHNBULLEHSOFlorida19.83  (w: 0.6)6/10/2022',
#   '(5) Joseph FAHNBULLEHSO',
#   '',
#   'Florida',
#   '19.83  (w: 0.6)',
#   '6/10/2022'],
#  ['\xa0\xa0\xa0\xa0— Onwuzurike {2}SOStanford19.84📺  (w: 0.9)6/9/2023',
#   '\xa0\xa0\xa0\xa0— Onwuzurike {2}SO',
#   '',
#   'Stanford',
#   '19.84📺  (w: 0.9)',
#   '6/9/2023'],
#  ['(6) Christian COLEMANJRTennessee19.85 qq = Performance occurred during a non-final round.  (w: -0.5)5/27/2017',
#   '(6) Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '19.85 qq = Performance occurred during a non-final round.  (w: -0.5)',
#   '5/27/2017'],
#  ['(7) Courtney LINDSEYSRTexas Tech19.86  (w: 0.9)6/9/2023',
#   '(7) Courtney LINDSEYSR',
#   '',
#   'Texas Tech',
#   '19.86  (w: 0.9)',
#   '6/9/2023'],
#  ['(7) Justin GATLINSOTennessee19.86   (w: 1.5)5/12/2002',
#   '(7) Justin GATLINSO',
#   '',
#   'Tennessee',
#   '19.86   (w: 1.5)',
#   '5/12/2002'],
#  ['(9) Terrence JONESJRTexas Tech19.87  (w: 0.9)6/9/2023',
#   '(9) Terrence JONESJR',
#   '',
#   'Texas Tech',
#   '19.87  (w: 0.9)',
#   '6/9/2023'],
#  ['(9) John CAPELFRFlorida19.87   (w: 1.4)6/5/1999',
#   '(9) John CAPELFR',
#   '',
#   'Florida',
#   '19.87   (w: 1.4)',
#   '6/5/1999'],
#  ['(9) Lorenzo DANIELSRMississippi State19.87   (w: 0.7)6/3/1988',
#   '(9) Lorenzo DANIELSR',
#   '',
#   'Mississippi State',
#   '19.87   (w: 0.7)',
#   '6/3/1988'],
#  ['\xa0\xa0\xa0\xa0— Lindsey {2}SRTexas Tech19.88 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '\xa0\xa0\xa0\xa0— Lindsey {2}SR',
#   '',
#   'Texas Tech',
#   '19.88 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['(12) Robert GREGORYSOFlorida19.89  (w: 0.9)6/9/2023',
#   '(12) Robert GREGORYSO',
#   '',
#   'Florida',
#   '19.89  (w: 0.9)',
#   '6/9/2023'],
#  ['\xa0\xa0\xa0\xa0— Onwuzurike {3}SOStanford19.91  (w: 0.9)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Onwuzurike {3}SO',
#   '',
#   'Stanford',
#   '19.91  (w: 0.9)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Fahnbulleh {2}FRFlorida19.91  (w: -0.4)6/11/2021',
#   '\xa0\xa0\xa0\xa0— Fahnbulleh {2}FR',
#   '',
#   'Florida',
#   '19.91  (w: -0.4)',
#   '6/11/2021'],
#  ['(13) Wallace SPEARMONSOArkansas19.91   (w: -0.7)6/11/2005',
#   '(13) Wallace SPEARMONSO',
#   '',
#   'Arkansas',
#   '19.91   (w: -0.7)',
#   '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— Fahnbulleh {3}SOFlorida19.92  (w: 1.4)4/30/2022',
#   '\xa0\xa0\xa0\xa0— Fahnbulleh {3}SO',
#   '',
#   'Florida',
#   '19.92  (w: 1.4)',
#   '4/30/2022'],
#  ['(14) Matthew BOLINGSOGeorgia19.92  (w: -0.9)4/22/2022',
#   '(14) Matthew BOLINGSO',
#   '',
#   'Georgia',
#   '19.92  (w: -0.9)',
#   '4/22/2022'],
#  ['(15) Cravon GILLESPIESROregon19.93  (w: 0.8)6/7/2019',
#   '(15) Cravon GILLESPIESR',
#   '',
#   'Oregon',
#   '19.93  (w: 0.8)',
#   '6/7/2019'],
#  ['\xa0\xa0\xa0\xa0— Daniel {2}SRMississippi State19.93   (w: -1.5)5/15/1988',
#   '\xa0\xa0\xa0\xa0— Daniel {2}SR',
#   '',
#   'Mississippi State',
#   '19.93   (w: -1.5)',
#   '5/15/1988'],
#  ['(16) Tarsis OROGOTSOAlabama19.94 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '(16) Tarsis OROGOTSO',
#   '',
#   'Alabama',
#   '19.94 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Lindsey {3}SRTexas Tech19.94 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)4/28/2023',
#   '\xa0\xa0\xa0\xa0— Lindsey {3}SR',
#   '',
#   'Texas Tech',
#   '19.94 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)',
#   '4/28/2023'],
#  ['\xa0\xa0\xa0\xa0— Laird {3}JRLSU19.94  (w: -0.4)6/11/2021',
#   '\xa0\xa0\xa0\xa0— Laird {3}JR',
#   '',
#   'LSU',
#   '19.94  (w: -0.4)',
#   '6/11/2021'],
#  ['\xa0\xa0\xa0\xa0— Gregory {2}SOFlorida19.95 qq = Performance occurred during a non-final round.  (w: 1.0)6/7/2023',
#   '\xa0\xa0\xa0\xa0— Gregory {2}SO',
#   '',
#   'Florida',
#   '19.95 qq = Performance occurred during a non-final round.  (w: 1.0)',
#   '6/7/2023'],
#  ['(17) Nethaneel MITCHELL-BLAKEJRLSU19.95  (w: 0.4)5/14/2016',
#   '(17) Nethaneel MITCHELL-BLAKEJR',
#   '',
#   'LSU',
#   '19.95  (w: 0.4)',
#   '5/14/2016'],
#  ['(17) Floyd HEARDTexas A&M19.95   (w: 1.9)5/17/1987',
#   '(17) Floyd HEARD',
#   '',
#   'Texas A&M',
#   '19.95   (w: 1.9)',
#   '5/17/1987'],
#  ['\xa0\xa0\xa0\xa0— Oduduru {3}JRTexas Tech19.97 qq = Performance occurred during a non-final round.  (w: 2.0)6/5/2019',
#   '\xa0\xa0\xa0\xa0— Oduduru {3}JR',
#   '',
#   'Texas Tech',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '6/5/2019'],
#  ['(19) Jereem RICHARDSJRAlabama19.97 qq = Performance occurred during a non-final round.  (w: 0.2)5/27/2017',
#   '(19) Jereem RICHARDSJR',
#   '',
#   'Alabama',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '5/27/2017'],
#  ['\xa0\xa0\xa0\xa0— Richards {2}JRAlabama19.97 qq = Performance occurred during a non-final round.  (w: 0.2)5/27/2017',
#   '\xa0\xa0\xa0\xa0— Richards {2}JR',
#   '',
#   'Alabama',
#   '19.97 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '5/27/2017'],
#  ['(19) Dedric DUKESJRFlorida19.97  (w: -0.6)4/5/2014',
#   '(19) Dedric DUKESJR',
#   '',
#   'Florida',
#   '19.97  (w: -0.6)',
#   '4/5/2014'],
#  ['\xa0\xa0\xa0\xa0— Spearmon {2}SOArkansas19.97   (w: 1.7)4/17/2005',
#   '\xa0\xa0\xa0\xa0— Spearmon {2}SO',
#   '',
#   'Arkansas',
#   '19.97   (w: 1.7)',
#   '4/17/2005'],
#  ['(21) Javonte HARDINGJRTennessee19.98 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '(21) Javonte HARDINGJR',
#   '',
#   'Tennessee',
#   '19.98 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JRTennessee19.98  (w: 0.6)5/13/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '19.98  (w: 0.6)',
#   '5/13/2017'],
#  ['\xa0\xa0\xa0\xa0— Gatlin {2}SOTennessee19.98 qq = Performance occurred during a non-final round.  (w: 1.2)5/29/2002',
#   '\xa0\xa0\xa0\xa0— Gatlin {2}SO',
#   '',
#   'Tennessee',
#   '19.98 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '5/29/2002'],
#  ['(21) Joe DELOACHHouston19.98   (w: 0.2)5/15/1988',
#   '(21) Joe DELOACH',
#   '',
#   'Houston',
#   '19.98   (w: 0.2)',
#   '5/15/1988'],
#  ['(23) Shaun MASWANGANYIJRHouston19.99 qq = Performance occurred during a non-final round.  (w: 0.6)6/7/2023',
#   '(23) Shaun MASWANGANYIJR',
#   '',
#   'Houston',
#   '19.99 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Dukes {2}SRFlorida19.99  (w: 0.6)5/16/2015',
#   '\xa0\xa0\xa0\xa0— Dukes {2}SR',
#   '',
#   'Florida',
#   '19.99  (w: 0.6)',
#   '5/16/2015'],
#  ['(24) Dorian CAMELJRLSU20.00  (w: 1.4)4/30/2022',
#   '(24) Dorian CAMELJR',
#   '',
#   'LSU',
#   '20.00  (w: 1.4)',
#   '4/30/2022'],
#  ['(24) Ncincilili TITISRSouth Carolina20.00  (w: 1.9)4/21/2018',
#   '(24) Ncincilili TITISR',
#   '',
#   'South Carolina',
#   '20.00  (w: 1.9)',
#   '4/21/2018'],
#  ['(24) Ato BOLDONSRUCLA20.00   (w: 1.0)5/19/1996',
#   '(24) Ato BOLDONSR',
#   '',
#   'UCLA',
#   '20.00   (w: 1.0)',
#   '5/19/1996']]

# %%
RealRealRows[1][4]
# Out:
# '19.73  (w: 0.8)'

# %%
len(RealRealRows)
# Out:
# 43

# %%
OfficialTimes = []

# %%
for i in range(0,len(RealRealRows)):
    OfficialTimes.append(RealRealRows[i][4])
OfficialTimes
# Out:
# ['19.69📺  (w: 0.9)',
#  '19.73  (w: 0.8)',
#  '19.76 qq = Performance occurred during a non-final round.  (w: 0.6)',
#  '19.76  (w: 0.8)',
#  '19.81  (w: 0.8)',
#  '19.82  (w: 1.7)',
#  '19.83  (w: 0.6)',
#  '19.84📺  (w: 0.9)',
#  '19.85 qq = Performance occurred during a non-final round.  (w: -0.5)',
#  '19.86  (w: 0.9)',
#  '19.86   (w: 1.5)',
#  '19.87  (w: 0.9)',
#  '19.87   (w: 1.4)',
#  '19.87   (w: 0.7)',
#  '19.88 qq = Performance occurred during a non-final round.  (w: 0.6)',
#  '19.89  (w: 0.9)',
#  '19.91  (w: 0.9)',
#  '19.91  (w: -0.4)',
#  '19.91   (w: -0.7)',
#  '19.92  (w: 1.4)',
#  '19.92  (w: -0.9)',
#  '19.93  (w: 0.8)',
#  '19.93   (w: -1.5)',
#  '19.94 qq = Performance occurred during a non-final round.  (w: 0.6)',
#  '19.94 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)',
#  '19.94  (w: -0.4)',
#  '19.95 qq = Performance occurred during a non-final round.  (w: 1.0)',
#  '19.95  (w: 0.4)',
#  '19.95   (w: 1.9)',
#  '19.97 qq = Performance occurred during a non-final round.  (w: 2.0)',
#  '19.97 qq = Performance occurred during a non-final round.  (w: 0.2)',
#  '19.97 qq = Performance occurred during a non-final round.  (w: 0.2)',
#  '19.97  (w: -0.6)',
#  '19.97   (w: 1.7)',
#  '19.98 qq = Performance occurred during a non-final round.  (w: 0.6)',
#  '19.98  (w: 0.6)',
#  '19.98 qq = Performance occurred during a non-final round.  (w: 1.2)',
#  '19.98   (w: 0.2)',
#  '19.99 qq = Performance occurred during a non-final round.  (w: 0.6)',
#  '19.99  (w: 0.6)',
#  '20.00  (w: 1.4)',
#  '20.00  (w: 1.9)',
#  '20.00   (w: 1.0)']

# %%
RealRealRows[0][1]
# Out:
# '(1) Walter DIXJR'

# %%
Names = []

for i in range(0,len(RealRealRows)):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Walter DIXJR',
#  '(2) Divine ODUDURUJR',
#  '(3) Udodi ONWUZURIKESO',
#  '\xa0\xa0\xa0\xa0— Oduduru {2}JR',
#  '(4) Terrance LAIRDJR',
#  '\xa0\xa0\xa0\xa0— Laird {2}JR',
#  '(5) Joseph FAHNBULLEHSO',
#  '\xa0\xa0\xa0\xa0— Onwuzurike {2}SO',
#  '(6) Christian COLEMANJR',
#  '(7) Courtney LINDSEYSR',
#  '(7) Justin GATLINSO',
#  '(9) Terrence JONESJR',
#  '(9) John CAPELFR',
#  '(9) Lorenzo DANIELSR',
#  '\xa0\xa0\xa0\xa0— Lindsey {2}SR',
#  '(12) Robert GREGORYSO',
#  '\xa0\xa0\xa0\xa0— Onwuzurike {3}SO',
#  '\xa0\xa0\xa0\xa0— Fahnbulleh {2}FR',
#  '(13) Wallace SPEARMONSO',
#  '\xa0\xa0\xa0\xa0— Fahnbulleh {3}SO',
#  '(14) Matthew BOLINGSO',
#  '(15) Cravon GILLESPIESR',
#  '\xa0\xa0\xa0\xa0— Daniel {2}SR',
#  '(16) Tarsis OROGOTSO',
#  '\xa0\xa0\xa0\xa0— Lindsey {3}SR',
#  '\xa0\xa0\xa0\xa0— Laird {3}JR',
#  '\xa0\xa0\xa0\xa0— Gregory {2}SO',
#  '(17) Nethaneel MITCHELL-BLAKEJR',
#  '(17) Floyd HEARD',
#  '\xa0\xa0\xa0\xa0— Oduduru {3}JR',
#  '(19) Jereem RICHARDSJR',
#  '\xa0\xa0\xa0\xa0— Richards {2}JR',
#  '(19) Dedric DUKESJR',
#  '\xa0\xa0\xa0\xa0— Spearmon {2}SO',
#  '(21) Javonte HARDINGJR',
#  '\xa0\xa0\xa0\xa0— Coleman {2}JR',
#  '\xa0\xa0\xa0\xa0— Gatlin {2}SO',
#  '(21) Joe DELOACH',
#  '(23) Shaun MASWANGANYIJR',
#  '\xa0\xa0\xa0\xa0— Dukes {2}SR',
#  '(24) Dorian CAMELJR',
#  '(24) Ncincilili TITISR',
#  '(24) Ato BOLDONSR']

# %%
OfficialReGexNames = []

# %%
for i in range(0,len(RealRealRows)):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Walter DIXJR',
#  '(2) Divine ODUDURUJR',
#  '(3) Udodi ONWUZURIKESO',
#  '— Oduduru {2}JR',
#  '(4) Terrance LAIRDJR',
#  '— Laird {2}JR',
#  '(5) Joseph FAHNBULLEHSO',
#  '— Onwuzurike {2}SO',
#  '(6) Christian COLEMANJR',
#  '(7) Courtney LINDSEYSR',
#  '(7) Justin GATLINSO',
#  '(9) Terrence JONESJR',
#  '(9) John CAPELFR',
#  '(9) Lorenzo DANIELSR',
#  '— Lindsey {2}SR',
#  '(12) Robert GREGORYSO',
#  '— Onwuzurike {3}SO',
#  '— Fahnbulleh {2}FR',
#  '(13) Wallace SPEARMONSO',
#  '— Fahnbulleh {3}SO',
#  '(14) Matthew BOLINGSO',
#  '(15) Cravon GILLESPIESR',
#  '— Daniel {2}SR',
#  '(16) Tarsis OROGOTSO',
#  '— Lindsey {3}SR',
#  '— Laird {3}JR',
#  '— Gregory {2}SO',
#  '(17) Nethaneel MITCHELL-BLAKEJR',
#  '(17) Floyd HEARD',
#  '— Oduduru {3}JR',
#  '(19) Jereem RICHARDSJR',
#  '— Richards {2}JR',
#  '(19) Dedric DUKESJR',
#  '— Spearmon {2}SO',
#  '(21) Javonte HARDINGJR',
#  '— Coleman {2}JR',
#  '— Gatlin {2}SO',
#  '(21) Joe DELOACH',
#  '(23) Shaun MASWANGANYIJR',
#  '— Dukes {2}SR',
#  '(24) Dorian CAMELJR',
#  '(24) Ncincilili TITISR',
#  '(24) Ato BOLDONSR']

# %%
CleanedNames = []

for i in range(0,len(RealRealRows)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Walter DIXJR',
#  'Divine ODUDURUJR',
#  'Udodi ONWUZURIKESO',
#  'Oduduru {2}JR',
#  'Terrance LAIRDJR',
#  'Laird {2}JR',
#  'Joseph FAHNBULLEHSO',
#  'Onwuzurike {2}SO',
#  'Christian COLEMANJR',
#  'Courtney LINDSEYSR',
#  'Justin GATLINSO',
#  'Terrence JONESJR',
#  'John CAPELFR',
#  'Lorenzo DANIELSR',
#  'Lindsey {2}SR',
#  ' Robert GREGORYSO',
#  'Onwuzurike {3}SO',
#  'Fahnbulleh {2}FR',
#  ' Wallace SPEARMONSO',
#  'Fahnbulleh {3}SO',
#  ' Matthew BOLINGSO',
#  ' Cravon GILLESPIESR',
#  'Daniel {2}SR',
#  ' Tarsis OROGOTSO',
#  'Lindsey {3}SR',
#  'Laird {3}JR',
#  'Gregory {2}SO',
#  ' Nethaneel MITCHELL-BLAKEJR',
#  ' Floyd HEARD',
#  'Oduduru {3}JR',
#  ' Jereem RICHARDSJR',
#  'Richards {2}JR',
#  ' Dedric DUKESJR',
#  'Spearmon {2}SO',
#  ' Javonte HARDINGJR',
#  'Coleman {2}JR',
#  'Gatlin {2}SO',
#  ' Joe DELOACH',
#  ' Shaun MASWANGANYIJR',
#  'Dukes {2}SR',
#  ' Dorian CAMELJR',
#  ' Ncincilili TITISR',
#  ' Ato BOLDONSR']

# %%
CleanedNames2 = []

for i in range(0,len(RealRealRows)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Walter DIXJR',
#  'Divine ODUDURUJR',
#  'Udodi ONWUZURIKESO',
#  'Oduduru {2}JR',
#  'Terrance LAIRDJR',
#  'Laird {2}JR',
#  'Joseph FAHNBULLEHSO',
#  'Onwuzurike {2}SO',
#  'Christian COLEMANJR',
#  'Courtney LINDSEYSR',
#  'Justin GATLINSO',
#  'Terrence JONESJR',
#  'John CAPELFR',
#  'Lorenzo DANIELSR',
#  'Lindsey {2}SR',
#  'Robert GREGORYSO',
#  'Onwuzurike {3}SO',
#  'Fahnbulleh {2}FR',
#  'Wallace SPEARMONSO',
#  'Fahnbulleh {3}SO',
#  'Matthew BOLINGSO',
#  'Cravon GILLESPIESR',
#  'Daniel {2}SR',
#  'Tarsis OROGOTSO',
#  'Lindsey {3}SR',
#  'Laird {3}JR',
#  'Gregory {2}SO',
#  'Nethaneel MITCHELL-BLAKEJR',
#  'Floyd HEARD',
#  'Oduduru {3}JR',
#  'Jereem RICHARDSJR',
#  'Richards {2}JR',
#  'Dedric DUKESJR',
#  'Spearmon {2}SO',
#  'Javonte HARDINGJR',
#  'Coleman {2}JR',
#  'Gatlin {2}SO',
#  'Joe DELOACH',
#  'Shaun MASWANGANYIJR',
#  'Dukes {2}SR',
#  'Dorian CAMELJR',
#  'Ncincilili TITISR',
#  'Ato BOLDONSR']

# %%
len(OfficialTimes)
# Out:
# 43

# %%
len(OfficialReGexNames)
# Out:
# 43

# %%
Times = []

# %%
for i in range(0,len(OfficialTimes)):
    Times.append(OfficialTimes[i][:5])
    
Times
# Out:
# ['19.69',
#  '19.73',
#  '19.76',
#  '19.76',
#  '19.81',
#  '19.82',
#  '19.83',
#  '19.84',
#  '19.85',
#  '19.86',
#  '19.86',
#  '19.87',
#  '19.87',
#  '19.87',
#  '19.88',
#  '19.89',
#  '19.91',
#  '19.91',
#  '19.91',
#  '19.92',
#  '19.92',
#  '19.93',
#  '19.93',
#  '19.94',
#  '19.94',
#  '19.94',
#  '19.95',
#  '19.95',
#  '19.95',
#  '19.97',
#  '19.97',
#  '19.97',
#  '19.97',
#  '19.97',
#  '19.98',
#  '19.98',
#  '19.98',
#  '19.98',
#  '19.99',
#  '19.99',
#  '20.00',
#  '20.00',
#  '20.00']

# %%
Schools = []

for i in range(0,len(OfficialTimes)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Florida State',
#  'Texas Tech',
#  'Stanford',
#  'Texas Tech',
#  'LSU',
#  'LSU',
#  'Florida',
#  'Stanford',
#  'Tennessee',
#  'Texas Tech',
#  'Tennessee',
#  'Texas Tech',
#  'Florida',
#  'Mississippi State',
#  'Texas Tech',
#  'Florida',
#  'Stanford',
#  'Florida',
#  'Arkansas',
#  'Florida',
#  'Georgia',
#  'Oregon',
#  'Mississippi State',
#  'Alabama',
#  'Texas Tech',
#  'LSU',
#  'Florida',
#  'LSU',
#  'Texas A&M',
#  'Texas Tech',
#  'Alabama',
#  'Alabama',
#  'Florida',
#  'Arkansas',
#  'Tennessee',
#  'Tennessee',
#  'Tennessee',
#  'Houston',
#  'Houston',
#  'Florida',
#  'LSU',
#  'South Carolina',
#  'UCLA']

# %%
Men200mDF = pd.DataFrame({'Names': CleanedNames2, 'Times': Times, 'Schools': Schools})

# %%
Men200mDF.to_csv('Men200m.csv', index=False)
