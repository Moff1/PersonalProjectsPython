# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
Link60mMen = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?sport=1&top=25&event=1"

# %%
page = requests.get(Link60mMen)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7727055" target="_blank">(1) Terrence JONES</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72047" target="_blank">6.45</a> </td><td style="width: 10%;text-align:right;" title="Texas Tech Corky Classic (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">1/15/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7727055" target="_blank">(1) Terrence JONES</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72047" target="_blank">6.45</a> </td><td style="width: 10%;text-align:right;" title="Texas Tech Corky Classic (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">1/15/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113312" target="_blank">(1) Christian COLEMAN</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567/3023721" target="_blank">6.45</a><a href="https://www.youtube.com/watch?v=bVN3WKwMs4w" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113312" target="_blank">(1) Christian COLEMAN</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567/3023721" target="_blank">6.45</a><a href="https://www.youtube.com/watch?v=bVN3WKwMs4w" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(1) Leonard MYLES-MILLS</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="BYU" class="group-logo-inline" src="/images/logos/rankings-article/byu.png" title="BYU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=190">BYU</a></td><td style="width: 25%;">6.45 <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="WAC Indoor Championships (Colorado Springs, Colo.)"><span class="mark-date" style="width: 10%;text-align:right;">2/20/1999</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(1) Leonard MYLES-MILLS</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="BYU" class="group-logo-inline" src="/images/logos/rankings-article/byu.png" title="BYU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=190">BYU</a></td><td style="width: 25%;">6.45 <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="WAC Indoor Championships (Colorado Springs, Colo.)"><span class="mark-date" style="width: 10%;text-align:right;">2/20/1999</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Jones {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720936" target="_blank">6.46</a><a href="https://www.youtube.com/watch?v=5co8VIT6Em8" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Jones {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720936" target="_blank">6.46</a><a href="https://www.youtube.com/watch?v=5co8VIT6Em8" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Jones {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77924/4693812" target="_blank">6.46</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Jones {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77924/4693812" target="_blank">6.46</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(4) Marcus BRUNSON</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona State" class="group-logo-inline" src="/images/logos/rankings-article/arizona-state.png" title="Arizona State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=57">Arizona State</a></td><td style="width: 25%;">6.46 <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title=" (Flagstaff, Ariz.)"><span class="mark-date" style="width: 10%;text-align:right;">1/30/1999</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(4) Marcus BRUNSON</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona State" class="group-logo-inline" src="/images/logos/rankings-article/arizona-state.png" title="Arizona State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=57">Arizona State</a></td><td style="width: 25%;">6.46 <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title=" (Flagstaff, Ariz.)"><span class="mark-date" style="width: 10%;text-align:right;">1/30/1999</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4149229" target="_blank">(5) Ronnie BAKER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="TCU" class="group-logo-inline" src="/images/logos/rankings-article/tcu.png" title="TCU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1550">TCU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41706" target="_blank">6.47</a> <span class="tooltip" style="font-size: smaller;">i<span class="tooltiptext" style="font-size: smaller;">i = event moved indoors because of weather or another issue.</span></span> </td><td style="width: 10%;text-align:right;" title="Birmingham-Southern Invitational (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4149229" target="_blank">(5) Ronnie BAKER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="TCU" class="group-logo-inline" src="/images/logos/rankings-article/tcu.png" title="TCU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1550">TCU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41706" target="_blank">6.47</a> <span class="tooltip" style="font-size: smaller;">i<span class="tooltiptext" style="font-size: smaller;">i = event moved indoors because of weather or another issue.</span></span> </td><td style="width: 10%;text-align:right;" title="Birmingham-Southern Invitational (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Baker {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="TCU" class="group-logo-inline" src="/images/logos/rankings-article/tcu.png" title="TCU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1550">TCU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702409" target="_blank">6.47</a><a href="https://www.flotrack.org/articles/5050006-tcus-baker-shatters-ncaa-champs-60m-record-with-647" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Baker {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="TCU" class="group-logo-inline" src="/images/logos/rankings-article/tcu.png" title="TCU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1550">TCU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702409" target="_blank">6.47</a><a href="https://www.flotrack.org/articles/5050006-tcus-baker-shatters-ncaa-champs-60m-record-with-647" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Jones {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77924/4693812" target="_blank">6.48</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Jones {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77924/4693812" target="_blank">6.48</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7722962" target="_blank">(6) Micah WILLIAMS</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/71331/4352923" target="_blank">6.48</a> </td><td style="width: 10%;text-align:right;" title="Razorback Team Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">1/28/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7722962" target="_blank">(6) Micah WILLIAMS</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/71331/4352923" target="_blank">6.48</a> </td><td style="width: 10%;text-align:right;" title="Razorback Team Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">1/28/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Williams {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70682" target="_blank">6.48</a> </td><td style="width: 10%;text-align:right;" title="Cougar Classic Invitational (Spokane, Wash.)"><span class="mark-date" style="width: 10%;text-align:right;">1/15/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Williams {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70682" target="_blank">6.48</a> </td><td style="width: 10%;text-align:right;" title="Cougar Classic Invitational (Spokane, Wash.)"><span class="mark-date" style="width: 10%;text-align:right;">1/15/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4629579" target="_blank">(6) Cameron BURRELL</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=672">Houston</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702409" target="_blank">6.48</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4629579" target="_blank">(6) Cameron BURRELL</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=672">Houston</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702409" target="_blank">6.48</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(6) Leonard SCOTT</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1553">Tennessee</a></td><td style="width: 25%;">6.48  </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2001</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(6) Leonard SCOTT</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1553">Tennessee</a></td><td style="width: 25%;">6.48  </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2001</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Scott {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1553">Tennessee</a></td><td style="width: 25%;">6.48 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">2/24/2001</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Scott {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1553">Tennessee</a></td><td style="width: 25%;">6.48 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">2/24/2001</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Myles-Mills {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="BYU" class="group-logo-inline" src="/images/logos/rankings-article/byu.png" title="BYU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=190">BYU</a></td><td style="width: 25%;">6.48 <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title=" (Colorado Springs, Colo.)"><span class="mark-date" style="width: 10%;text-align:right;">1/23/1999</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Myles-Mills {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="BYU" class="group-logo-inline" src="/images/logos/rankings-article/byu.png" title="BYU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=190">BYU</a></td><td style="width: 25%;">6.48 <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title=" (Colorado Springs, Colo.)"><span class="mark-date" style="width: 10%;text-align:right;">1/23/1999</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Williams {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77195/4648902" target="_blank">6.49</a><a href="https://twitter.com/travismillerx13/status/1619163734433484805" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Texas Tech Open &amp; Multis (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">1/26/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Williams {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77195/4648902" target="_blank">6.49</a><a href="https://twitter.com/travismillerx13/status/1619163734433484805" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Texas Tech Open &amp; Multis (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">1/26/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Williams {4}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118003" target="_blank">6.49</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Williams {4}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118003" target="_blank">6.49</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Williams {5}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/66346/4091864" target="_blank">6.49</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="Invitational at the Peak (Air Force Academy, Colo.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Williams {5}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/66346/4091864" target="_blank">6.49</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="Invitational at the Peak (Air Force Academy, Colo.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2316948" target="_blank">(9) D'Angelo CHERRY</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Mississippi State" class="group-logo-inline" src="/images/logos/rankings-article/mississippi-state.png" title="Mississippi State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=987">Mississippi State</a></td><td style="width: 25%;">6.49 <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="USATF Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;">3/3/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2316948" target="_blank">(9) D'Angelo CHERRY</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Mississippi State" class="group-logo-inline" src="/images/logos/rankings-article/mississippi-state.png" title="Mississippi State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=987">Mississippi State</a></td><td style="width: 25%;">6.49 <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="USATF Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;">3/3/2013</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7687394" target="_blank">(10) Davonte BURNETT</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416347" target="_blank">6.50</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7687394" target="_blank">(10) Davonte BURNETT</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416347" target="_blank">6.50</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6099791" target="_blank">(10) Grant HOLLOWAY</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/60240/3664839" target="_blank">6.50</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6099791" target="_blank">(10) Grant HOLLOWAY</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/60240/3664839" target="_blank">6.50</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Coleman {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567/3023721" target="_blank">6.50</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Coleman {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567/3023721" target="_blank">6.50</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Burrell {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=672">Houston</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702409" target="_blank">6.50</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Burrell {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=672">Houston</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702409" target="_blank">6.50</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(10) Lee MCRAE</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Pittsburgh" class="group-logo-inline" src="/images/logos/rankings-article/pittsburgh.png" title="Pittsburgh"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1234">Pittsburgh</a></td><td style="width: 25%;">6.50<a href="https://www.youtube.com/watch?v=hzvZ74QeCqg" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="IAAF World Indoor Championships (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">3/7/1987</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(10) Lee MCRAE</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Pittsburgh" class="group-logo-inline" src="/images/logos/rankings-article/pittsburgh.png" title="Pittsburgh"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1234">Pittsburgh</a></td><td style="width: 25%;">6.50<a href="https://www.youtube.com/watch?v=hzvZ74QeCqg" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="IAAF World Indoor Championships (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">3/7/1987</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8363992" target="_blank">(13) Favour ASHE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=74">Auburn</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720936" target="_blank">6.51</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8363992" target="_blank">(13) Favour ASHE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=74">Auburn</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720936" target="_blank">6.51</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
# ...
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Teeters {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oklahoma State" class="group-logo-inline" src="/images/logos/rankings-article/oklahoma-state.png" title="Oklahoma State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=1170">Oklahoma State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/36903" target="_blank">6.52</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/13/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3753495" target="_blank">(19) Dentarius LOCKE</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/34001/2083798" target="_blank">6.52</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;">3/15/2014</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3753495" target="_blank">(19) Dentarius LOCKE</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/34001/2083798" target="_blank">6.52</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;">3/15/2014</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2256568" target="_blank">(19) Jeff DEMPS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/24457" target="_blank">6.52</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Nampa, Idaho)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2012</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2256568" target="_blank">(19) Jeff DEMPS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/24457" target="_blank">6.52</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Nampa, Idaho)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2012</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Ford {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=311">Clemson</a></td><td style="width: 25%;">6.52  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/14/2009</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Ford {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=311">Clemson</a></td><td style="width: 25%;">6.52  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/14/2009</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Cherry {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Mississippi State" class="group-logo-inline" src="/images/logos/rankings-article/mississippi-state.png" title="Mississippi State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=987">Mississippi State</a></td><td style="width: 25%;">6.52  </td><td style="width: 10%;text-align:right;" title="USATF Indoor Championships (Boston, Mass.)"><span class="mark-date" style="width: 10%;text-align:right;">3/1/2009</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Cherry {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Mississippi State" class="group-logo-inline" src="/images/logos/rankings-article/mississippi-state.png" title="Mississippi State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=987">Mississippi State</a></td><td style="width: 25%;">6.52  </td><td style="width: 10%;text-align:right;" title="USATF Indoor Championships (Boston, Mass.)"><span class="mark-date" style="width: 10%;text-align:right;">3/1/2009</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Ford {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=311">Clemson</a></td><td style="width: 25%;">6.52  </td><td style="width: 10%;text-align:right;" title="Doc Hale Virginia Tech Elite (Blacksburg, Va.)"><span class="mark-date" style="width: 10%;text-align:right;">2/6/2009</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Ford {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=311">Clemson</a></td><td style="width: 25%;">6.52  </td><td style="width: 10%;text-align:right;" title="Doc Hale Virginia Tech Elite (Blacksburg, Va.)"><span class="mark-date" style="width: 10%;text-align:right;">2/6/2009</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Brunson {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona State" class="group-logo-inline" src="/images/logos/rankings-article/arizona-state.png" title="Arizona State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=57">Arizona State</a></td><td style="width: 25%;">6.52 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">3/5/1999</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Brunson {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona State" class="group-logo-inline" src="/images/logos/rankings-article/arizona-state.png" title="Arizona State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=57">Arizona State</a></td><td style="width: 25%;">6.52 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">3/5/1999</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(19) Coby MILLER</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=74">Auburn</a></td><td style="width: 25%;">6.52  </td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">2/5/1999</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(19) Coby MILLER</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=74">Auburn</a></td><td style="width: 25%;">6.52  </td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">2/5/1999</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(19) Brian COOPER</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="McNeese State" class="group-logo-inline" src="/images/logos/rankings-article/mcneese-state.png" title="McNeese State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=928">McNeese State</a></td><td style="width: 25%;">6.52  </td><td style="width: 10%;text-align:right;" title=" (Sherbrooke, Quebec)"><span class="mark-date" style="width: 10%;text-align:right;">1/24/1988</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(19) Brian COOPER</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="McNeese State" class="group-logo-inline" src="/images/logos/rankings-article/mcneese-state.png" title="McNeese State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;top=25&amp;event=1&amp;team=928">McNeese State</a></td><td style="width: 25%;">6.52  </td><td style="width: 10%;text-align:right;" title=" (Sherbrooke, Quebec)"><span class="mark-date" style="width: 10%;text-align:right;">1/24/1988</span></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Terrence JONESFRTexas Tech6.45 1/15/2022',
#   '(1) Terrence JONESFR',
#   '',
#   'Texas Tech',
#   '6.45 ',
#   '1/15/2022'],
#  [],
#  ['(1) Terrence JONESFR', '', 'Texas Tech', '6.45 ', '1/15/2022'],
#  ['(1) Christian COLEMANJRTennessee6.45📺 3/11/2017',
#   '(1) Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '6.45📺 ',
#   '3/11/2017'],
#  [],
#  ['(1) Christian COLEMANJR', '', 'Tennessee', '6.45📺 ', '3/11/2017'],
#  ['(1) Leonard MYLES-MILLSSRBYU6.45 AA = Performance occurred at altitude (>1000 meters above sea level) 2/20/1999',
#   '(1) Leonard MYLES-MILLSSR',
#   '',
#   'BYU',
#   '6.45 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/20/1999'],
#  [],
#  ['(1) Leonard MYLES-MILLSSR',
#   '',
#   'BYU',
#   '6.45 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/20/1999'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}SOTexas Tech6.46📺 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Jones {2}SO',
#   '',
#   'Texas Tech',
#   '6.46📺 ',
#   '3/11/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Jones {2}SO', '', 'Texas Tech', '6.46📺 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Jones {3}SOTexas Tech6.46 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Jones {3}SO',
#   '',
#   'Texas Tech',
#   '6.46 ',
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Jones {3}SO', '', 'Texas Tech', '6.46 ', '2/24/2023'],
#  ['(4) Marcus BRUNSONArizona State6.46 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round. 1/30/1999',
#   '(4) Marcus BRUNSON',
#   '',
#   'Arizona State',
#   '6.46 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round. ',
#   '1/30/1999'],
#  [],
#  ['(4) Marcus BRUNSON',
#   '',
#   'Arizona State',
#   '6.46 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round. ',
#   '1/30/1999'],
#  ['(5) Ronnie BAKERSRTCU6.47 ii = event moved indoors because of weather or another issue. 3/12/2016',
#   '(5) Ronnie BAKERSR',
#   '',
#   'TCU',
#   '6.47 ii = event moved indoors because of weather or another issue. ',
#   '3/12/2016'],
#  [],
#  ['(5) Ronnie BAKERSR',
#   '',
#   'TCU',
#   '6.47 ii = event moved indoors because of weather or another issue. ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Baker {2}SRTCU6.47📺 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Baker {2}SR',
#   '',
#   'TCU',
#   '6.47📺 ',
#   '3/12/2016'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Baker {2}SR', '', 'TCU', '6.47📺 ', '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Jones {4}SOTexas Tech6.48 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Jones {4}SO',
#   '',
#   'Texas Tech',
#   '6.48 ',
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Jones {4}SO', '', 'Texas Tech', '6.48 ', '2/24/2023'],
#  ['(6) Micah WILLIAMSFROregon6.48 1/28/2022',
#   '(6) Micah WILLIAMSFR',
#   '',
#   'Oregon',
#   '6.48 ',
#   '1/28/2022'],
#  [],
#  ['(6) Micah WILLIAMSFR', '', 'Oregon', '6.48 ', '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Williams {2}FROregon6.48 1/15/2022',
#   '\xa0\xa0\xa0\xa0— Williams {2}FR',
#   '',
#   'Oregon',
#   '6.48 ',
#   '1/15/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Williams {2}FR', '', 'Oregon', '6.48 ', '1/15/2022'],
#  ['(6) Cameron BURRELLJRHouston6.48 3/12/2016',
#   '(6) Cameron BURRELLJR',
#   '',
#   'Houston',
#   '6.48 ',
#   '3/12/2016'],
#  [],
#  ['(6) Cameron BURRELLJR', '', 'Houston', '6.48 ', '3/12/2016'],
#  ['(6) Leonard SCOTTJRTennessee6.48  2/25/2001',
#   '(6) Leonard SCOTTJR',
#   '',
#   'Tennessee',
#   '6.48  ',
#   '2/25/2001'],
#  [],
#  ['(6) Leonard SCOTTJR', '', 'Tennessee', '6.48  ', '2/25/2001'],
#  ['\xa0\xa0\xa0\xa0— Scott {2}JRTennessee6.48 qq = Performance occurred during a non-final round. 2/24/2001',
#   '\xa0\xa0\xa0\xa0— Scott {2}JR',
#   '',
#   'Tennessee',
#   '6.48 qq = Performance occurred during a non-final round. ',
#   '2/24/2001'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Scott {2}JR',
#   '',
#   'Tennessee',
#   '6.48 qq = Performance occurred during a non-final round. ',
#   '2/24/2001'],
#  ['\xa0\xa0\xa0\xa0— Myles-Mills {2}BYU6.48 AA = Performance occurred at altitude (>1000 meters above sea level) 1/23/1999',
#   '\xa0\xa0\xa0\xa0— Myles-Mills {2}',
#   '',
#   'BYU',
#   '6.48 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/23/1999'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Myles-Mills {2}',
#   '',
#   'BYU',
#   '6.48 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/23/1999'],
#  ['\xa0\xa0\xa0\xa0— Williams {3}SOOregon6.49📺 1/26/2023',
#   '\xa0\xa0\xa0\xa0— Williams {3}SO',
#   '',
#   'Oregon',
#   '6.49📺 ',
#   '1/26/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Williams {3}SO', '', 'Oregon', '6.49📺 ', '1/26/2023'],
#  ['\xa0\xa0\xa0\xa0— Williams {4}FROregon6.49 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Williams {4}FR',
#   '',
#   'Oregon',
#   '6.49 ',
#   '3/13/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Williams {4}FR', '', 'Oregon', '6.49 ', '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Williams {5}FROregon6.49 AA = Performance occurred at altitude (>1000 meters above sea level) 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Williams {5}FR',
#   '',
#   'Oregon',
#   '6.49 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/25/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Williams {5}FR',
#   '',
#   'Oregon',
#   '6.49 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/25/2021'],
#  ["(9) D'Angelo CHERRYMississippi State6.49 AA = Performance occurred at altitude (>1000 meters above sea level) 3/3/2013",
#   "(9) D'Angelo CHERRY",
#   '',
#   'Mississippi State',
#   '6.49 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/3/2013'],
#  [],
#  ["(9) D'Angelo CHERRY",
#   '',
#   'Mississippi State',
#   '6.49 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/3/2013'],
#  ['(10) Davonte BURNETTSRSouthern California6.50 3/12/2022',
#   '(10) Davonte BURNETTSR',
#   '',
#   'Southern California',
#   '6.50 ',
#   '3/12/2022'],
#  [],
#  ['(10) Davonte BURNETTSR', '', 'Southern California', '6.50 ', '3/12/2022'],
#  ['(10) Grant HOLLOWAYJRFlorida6.50 3/9/2019',
#   '(10) Grant HOLLOWAYJR',
#   '',
#   'Florida',
#   '6.50 ',
#   '3/9/2019'],
#  [],
#  ['(10) Grant HOLLOWAYJR', '', 'Florida', '6.50 ', '3/9/2019'],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JRTennessee6.50 qq = Performance occurred during a non-final round. 3/10/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '6.50 qq = Performance occurred during a non-final round. ',
#   '3/10/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '6.50 qq = Performance occurred during a non-final round. ',
#   '3/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Burrell {2}JRHouston6.50 qq = Performance occurred during a non-final round. 3/11/2016',
#   '\xa0\xa0\xa0\xa0— Burrell {2}JR',
#   '',
#   'Houston',
#   '6.50 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Burrell {2}JR',
#   '',
#   'Houston',
#   '6.50 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  ['(10) Lee MCRAEJRPittsburgh6.50📺 3/7/1987',
#   '(10) Lee MCRAEJR',
#   '',
#   'Pittsburgh',
#   '6.50📺 ',
#   '3/7/1987'],
#  [],
#  ['(10) Lee MCRAEJR', '', 'Pittsburgh', '6.50📺 ', '3/7/1987'],
#  ['(13) Favour ASHESOAuburn6.51 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(13) Favour ASHESO',
#   '',
#   'Auburn',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['(13) Favour ASHESO',
#   '',
#   'Auburn',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(13) Ismael KONESRFlorida State6.51📺 1/13/2023',
#   '(13) Ismael KONESR',
#   '',
#   'Florida State',
#   '6.51📺 ',
#   '1/13/2023'],
#  [],
#  ['(13) Ismael KONESR', '', 'Florida State', '6.51📺 ', '1/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Ashe {2}FRTennessee6.51 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Ashe {2}FR',
#   '',
#   'Tennessee',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ashe {2}FR',
#   '',
#   'Tennessee',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {2}JRFlorida6.51📺 1/26/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {2}JR',
#   '',
#   'Florida',
#   '6.51📺 ',
#   '1/26/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {2}JR', '', 'Florida', '6.51📺 ', '1/26/2019'],
#  ['(13) Kendal WILLIAMSSOGeorgia6.51 2/17/2017',
#   '(13) Kendal WILLIAMSSO',
#   '',
#   'Georgia',
#   '6.51 ',
#   '2/17/2017'],
#  [],
#  ['(13) Kendal WILLIAMSSO', '', 'Georgia', '6.51 ', '2/17/2017'],
#  ['\xa0\xa0\xa0\xa0— Coleman {3}JRTennessee6.51 2/4/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {3}JR',
#   '',
#   'Tennessee',
#   '6.51 ',
#   '2/4/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Coleman {3}JR', '', 'Tennessee', '6.51 ', '2/4/2017'],
#  ['\xa0\xa0\xa0\xa0— Baker {3}SRTCU6.51 qq = Performance occurred during a non-final round. 3/11/2016',
#   '\xa0\xa0\xa0\xa0— Baker {3}SR',
#   '',
#   'TCU',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Baker {3}SR',
#   '',
#   'TCU',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  ['\xa0\xa0\xa0\xa0— Baker {4}SRTCU6.51 2/27/2016',
#   '\xa0\xa0\xa0\xa0— Baker {4}SR',
#   '',
#   'TCU',
#   '6.51 ',
#   '2/27/2016'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Baker {4}SR', '', 'TCU', '6.51 ', '2/27/2016'],
#  ['(13) Jacoby FORDJRClemson6.51 qq = Performance occurred during a non-final round. 3/13/2009',
#   '(13) Jacoby FORDJR',
#   '',
#   'Clemson',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/13/2009'],
#  [],
#  ['(13) Jacoby FORDJR',
#   '',
#   'Clemson',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/13/2009'],
#  ['\xa0\xa0\xa0\xa0— Ford {2}JRClemson6.51  2/28/2009',
#   '\xa0\xa0\xa0\xa0— Ford {2}JR',
#   '',
#   'Clemson',
#   '6.51  ',
#   '2/28/2009'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ford {2}JR', '', 'Clemson', '6.51  ', '2/28/2009'],
#  ['(13) Richard THOMPSONSRLSU6.51📺 3/15/2008',
#   '(13) Richard THOMPSONSR',
#   '',
#   'LSU',
#   '6.51📺 ',
#   '3/15/2008'],
#  [],
#  ['(13) Richard THOMPSONSR', '', 'LSU', '6.51📺 ', '3/15/2008'],
#  ['\xa0\xa0\xa0\xa0— Thompson {2}SRLSU6.51 qq = Performance occurred during a non-final round. 3/14/2008',
#   '\xa0\xa0\xa0\xa0— Thompson {2}SR',
#   '',
#   'LSU',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/14/2008'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Thompson {2}SR',
#   '',
#   'LSU',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/14/2008'],
#  ["(13) Ja'Warren HOOKERWashington6.51 AA = Performance occurred at altitude (>1000 meters above sea level) 2/24/2001",
#   "(13) Ja'Warren HOOKER",
#   '',
#   'Washington',
#   '6.51 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/24/2001'],
#  [],
#  ["(13) Ja'Warren HOOKER",
#   '',
#   'Washington',
#   '6.51 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/24/2001'],
#  ['\xa0\xa0\xa0\xa0— Ashe {3}SOAuburn6.52 2/25/2023',
#   '\xa0\xa0\xa0\xa0— Ashe {3}SO',
#   '',
#   'Auburn',
#   '6.52 ',
#   '2/25/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ashe {3}SO', '', 'Auburn', '6.52 ', '2/25/2023'],
#  ['(19) Rikkoi BRATHWAITEJRIndiana6.52 3/12/2022',
#   '(19) Rikkoi BRATHWAITEJR',
#   '',
#   'Indiana',
#   '6.52 ',
#   '3/12/2022'],
#  [],
#  ['(19) Rikkoi BRATHWAITEJR', '', 'Indiana', '6.52 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Ashe {4}FRTennessee6.52 qq = Performance occurred during a non-final round. 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Ashe {4}FR',
#   '',
#   'Tennessee',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '2/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ashe {4}FR',
#   '',
#   'Tennessee',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Ashe {5}FRTennessee6.52 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Ashe {5}FR',
#   '',
#   'Tennessee',
#   '6.52 ',
#   '2/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ashe {5}FR', '', 'Tennessee', '6.52 ', '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Williams {6}FROregon6.52 qq = Performance occurred during a non-final round. 3/12/2021',
#   '\xa0\xa0\xa0\xa0— Williams {6}FR',
#   '',
#   'Oregon',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Williams {6}FR',
#   '',
#   'Oregon',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ['(19) Divine ODUDURUJRTexas Tech6.52 2/23/2019',
#   '(19) Divine ODUDURUJR',
#   '',
#   'Texas Tech',
#   '6.52 ',
#   '2/23/2019'],
#  [],
#  ['(19) Divine ODUDURUJR', '', 'Texas Tech', '6.52 ', '2/23/2019'],
#  ['(19) Elijah HALLSRHouston6.52 3/10/2018',
#   '(19) Elijah HALLSR',
#   '',
#   'Houston',
#   '6.52 ',
#   '3/10/2018'],
#  [],
#  ['(19) Elijah HALLSR', '', 'Houston', '6.52 ', '3/10/2018'],
#  ['(19) Andre EWERSJRFlorida State6.52 1/20/2018',
#   '(19) Andre EWERSJR',
#   '',
#   'Florida State',
#   '6.52 ',
#   '1/20/2018'],
#  [],
#  ['(19) Andre EWERSJR', '', 'Florida State', '6.52 ', '1/20/2018'],
#  ['\xa0\xa0\xa0\xa0— Coleman {4}JRTennessee6.52 2/25/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {4}JR',
#   '',
#   'Tennessee',
#   '6.52 ',
#   '2/25/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Coleman {4}JR', '', 'Tennessee', '6.52 ', '2/25/2017'],
#  ['\xa0\xa0\xa0\xa0— Coleman {5}SOTennessee6.52 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Coleman {5}SO',
#   '',
#   'Tennessee',
#   '6.52 ',
#   '3/12/2016'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Coleman {5}SO', '', 'Tennessee', '6.52 ', '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Baker {5}TCU6.52 3/14/2015',
#   '\xa0\xa0\xa0\xa0— Baker {5}',
#   '',
#   'TCU',
#   '6.52 ',
#   '3/14/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Baker {5}', '', 'TCU', '6.52 ', '3/14/2015'],
#  ['(19) John TEETERSJROklahoma State6.52 2/14/2015',
#   '(19) John TEETERSJR',
#   '',
#   'Oklahoma State',
#   '6.52 ',
#   '2/14/2015'],
#  [],
#  ['(19) John TEETERSJR', '', 'Oklahoma State', '6.52 ', '2/14/2015'],
#  ['\xa0\xa0\xa0\xa0— Teeters {2}JROklahoma State6.52 qq = Performance occurred during a non-final round. 2/13/2015',
#   '\xa0\xa0\xa0\xa0— Teeters {2}JR',
#   '',
#   'Oklahoma State',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '2/13/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Teeters {2}JR',
#   '',
#   'Oklahoma State',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '2/13/2015'],
#  ['(19) Dentarius LOCKEFlorida State6.52 AA = Performance occurred at altitude (>1000 meters above sea level) 3/15/2014',
#   '(19) Dentarius LOCKE',
#   '',
#   'Florida State',
#   '6.52 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  [],
#  ['(19) Dentarius LOCKE',
#   '',
#   'Florida State',
#   '6.52 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  ['(19) Jeff DEMPSFlorida6.52 qq = Performance occurred during a non-final round. 3/9/2012',
#   '(19) Jeff DEMPS',
#   '',
#   'Florida',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/9/2012'],
#  [],
#  ['(19) Jeff DEMPS',
#   '',
#   'Florida',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/9/2012'],
#  ['\xa0\xa0\xa0\xa0— Ford {3}SOClemson6.52  3/14/2009',
#   '\xa0\xa0\xa0\xa0— Ford {3}SO',
#   '',
#   'Clemson',
#   '6.52  ',
#   '3/14/2009'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ford {3}SO', '', 'Clemson', '6.52  ', '3/14/2009'],
#  ['\xa0\xa0\xa0\xa0— Cherry {2}Mississippi State6.52  3/1/2009',
#   '\xa0\xa0\xa0\xa0— Cherry {2}',
#   '',
#   'Mississippi State',
#   '6.52  ',
#   '3/1/2009'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cherry {2}',
#   '',
#   'Mississippi State',
#   '6.52  ',
#   '3/1/2009'],
#  ['\xa0\xa0\xa0\xa0— Ford {4}SOClemson6.52  2/6/2009',
#   '\xa0\xa0\xa0\xa0— Ford {4}SO',
#   '',
#   'Clemson',
#   '6.52  ',
#   '2/6/2009'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ford {4}SO', '', 'Clemson', '6.52  ', '2/6/2009'],
#  ['\xa0\xa0\xa0\xa0— Brunson {2}JRArizona State6.52 qq = Performance occurred during a non-final round. 3/5/1999',
#   '\xa0\xa0\xa0\xa0— Brunson {2}JR',
#   '',
#   'Arizona State',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/5/1999'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Brunson {2}JR',
#   '',
#   'Arizona State',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/5/1999'],
#  ['(19) Coby MILLERAuburn6.52  2/5/1999',
#   '(19) Coby MILLER',
#   '',
#   'Auburn',
#   '6.52  ',
#   '2/5/1999'],
#  [],
#  ['(19) Coby MILLER', '', 'Auburn', '6.52  ', '2/5/1999'],
#  ['(19) Brian COOPERMcNeese State6.52  1/24/1988',
#   '(19) Brian COOPER',
#   '',
#   'McNeese State',
#   '6.52  ',
#   '1/24/1988'],
#  [],
#  ['(19) Brian COOPER', '', 'McNeese State', '6.52  ', '1/24/1988'],
#  ['', '', '', '']]

# %%
len(rows)
# Out:
# 177

# %%
rows[175]
# Out:
# ['(19) Brian COOPER', '', 'McNeese State', '6.52  ', '1/24/1988']

# %%
len(rows)
# Out:
# 177

# %%
RealRows = []

# %%
for i in range(0,175):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [['(1) Terrence JONESFRTexas Tech6.45 1/15/2022',
#   '(1) Terrence JONESFR',
#   '',
#   'Texas Tech',
#   '6.45 ',
#   '1/15/2022'],
#  ['(1) Terrence JONESFR', '', 'Texas Tech', '6.45 ', '1/15/2022'],
#  ['(1) Christian COLEMANJRTennessee6.45📺 3/11/2017',
#   '(1) Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '6.45📺 ',
#   '3/11/2017'],
#  ['(1) Christian COLEMANJR', '', 'Tennessee', '6.45📺 ', '3/11/2017'],
#  ['(1) Leonard MYLES-MILLSSRBYU6.45 AA = Performance occurred at altitude (>1000 meters above sea level) 2/20/1999',
#   '(1) Leonard MYLES-MILLSSR',
#   '',
#   'BYU',
#   '6.45 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/20/1999'],
#  ['(1) Leonard MYLES-MILLSSR',
#   '',
#   'BYU',
#   '6.45 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/20/1999'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}SOTexas Tech6.46📺 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Jones {2}SO',
#   '',
#   'Texas Tech',
#   '6.46📺 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}SO', '', 'Texas Tech', '6.46📺 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Jones {3}SOTexas Tech6.46 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Jones {3}SO',
#   '',
#   'Texas Tech',
#   '6.46 ',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Jones {3}SO', '', 'Texas Tech', '6.46 ', '2/24/2023'],
#  ['(4) Marcus BRUNSONArizona State6.46 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round. 1/30/1999',
#   '(4) Marcus BRUNSON',
#   '',
#   'Arizona State',
#   '6.46 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round. ',
#   '1/30/1999'],
#  ['(4) Marcus BRUNSON',
#   '',
#   'Arizona State',
#   '6.46 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round. ',
#   '1/30/1999'],
#  ['(5) Ronnie BAKERSRTCU6.47 ii = event moved indoors because of weather or another issue. 3/12/2016',
#   '(5) Ronnie BAKERSR',
#   '',
#   'TCU',
#   '6.47 ii = event moved indoors because of weather or another issue. ',
#   '3/12/2016'],
#  ['(5) Ronnie BAKERSR',
#   '',
#   'TCU',
#   '6.47 ii = event moved indoors because of weather or another issue. ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Baker {2}SRTCU6.47📺 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Baker {2}SR',
#   '',
#   'TCU',
#   '6.47📺 ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Baker {2}SR', '', 'TCU', '6.47📺 ', '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Jones {4}SOTexas Tech6.48 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Jones {4}SO',
#   '',
#   'Texas Tech',
#   '6.48 ',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Jones {4}SO', '', 'Texas Tech', '6.48 ', '2/24/2023'],
#  ['(6) Micah WILLIAMSFROregon6.48 1/28/2022',
#   '(6) Micah WILLIAMSFR',
#   '',
#   'Oregon',
#   '6.48 ',
#   '1/28/2022'],
#  ['(6) Micah WILLIAMSFR', '', 'Oregon', '6.48 ', '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Williams {2}FROregon6.48 1/15/2022',
#   '\xa0\xa0\xa0\xa0— Williams {2}FR',
#   '',
#   'Oregon',
#   '6.48 ',
#   '1/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Williams {2}FR', '', 'Oregon', '6.48 ', '1/15/2022'],
#  ['(6) Cameron BURRELLJRHouston6.48 3/12/2016',
#   '(6) Cameron BURRELLJR',
#   '',
#   'Houston',
#   '6.48 ',
#   '3/12/2016'],
#  ['(6) Cameron BURRELLJR', '', 'Houston', '6.48 ', '3/12/2016'],
#  ['(6) Leonard SCOTTJRTennessee6.48  2/25/2001',
#   '(6) Leonard SCOTTJR',
#   '',
#   'Tennessee',
#   '6.48  ',
#   '2/25/2001'],
#  ['(6) Leonard SCOTTJR', '', 'Tennessee', '6.48  ', '2/25/2001'],
#  ['\xa0\xa0\xa0\xa0— Scott {2}JRTennessee6.48 qq = Performance occurred during a non-final round. 2/24/2001',
#   '\xa0\xa0\xa0\xa0— Scott {2}JR',
#   '',
#   'Tennessee',
#   '6.48 qq = Performance occurred during a non-final round. ',
#   '2/24/2001'],
#  ['\xa0\xa0\xa0\xa0— Scott {2}JR',
#   '',
#   'Tennessee',
#   '6.48 qq = Performance occurred during a non-final round. ',
#   '2/24/2001'],
#  ['\xa0\xa0\xa0\xa0— Myles-Mills {2}BYU6.48 AA = Performance occurred at altitude (>1000 meters above sea level) 1/23/1999',
#   '\xa0\xa0\xa0\xa0— Myles-Mills {2}',
#   '',
#   'BYU',
#   '6.48 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/23/1999'],
#  ['\xa0\xa0\xa0\xa0— Myles-Mills {2}',
#   '',
#   'BYU',
#   '6.48 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/23/1999'],
#  ['\xa0\xa0\xa0\xa0— Williams {3}SOOregon6.49📺 1/26/2023',
#   '\xa0\xa0\xa0\xa0— Williams {3}SO',
#   '',
#   'Oregon',
#   '6.49📺 ',
#   '1/26/2023'],
#  ['\xa0\xa0\xa0\xa0— Williams {3}SO', '', 'Oregon', '6.49📺 ', '1/26/2023'],
#  ['\xa0\xa0\xa0\xa0— Williams {4}FROregon6.49 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Williams {4}FR',
#   '',
#   'Oregon',
#   '6.49 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Williams {4}FR', '', 'Oregon', '6.49 ', '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Williams {5}FROregon6.49 AA = Performance occurred at altitude (>1000 meters above sea level) 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Williams {5}FR',
#   '',
#   'Oregon',
#   '6.49 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Williams {5}FR',
#   '',
#   'Oregon',
#   '6.49 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/25/2021'],
#  ["(9) D'Angelo CHERRYMississippi State6.49 AA = Performance occurred at altitude (>1000 meters above sea level) 3/3/2013",
#   "(9) D'Angelo CHERRY",
#   '',
#   'Mississippi State',
#   '6.49 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/3/2013'],
#  ["(9) D'Angelo CHERRY",
#   '',
#   'Mississippi State',
#   '6.49 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/3/2013'],
#  ['(10) Davonte BURNETTSRSouthern California6.50 3/12/2022',
#   '(10) Davonte BURNETTSR',
#   '',
#   'Southern California',
#   '6.50 ',
#   '3/12/2022'],
#  ['(10) Davonte BURNETTSR', '', 'Southern California', '6.50 ', '3/12/2022'],
#  ['(10) Grant HOLLOWAYJRFlorida6.50 3/9/2019',
#   '(10) Grant HOLLOWAYJR',
#   '',
#   'Florida',
#   '6.50 ',
#   '3/9/2019'],
#  ['(10) Grant HOLLOWAYJR', '', 'Florida', '6.50 ', '3/9/2019'],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JRTennessee6.50 qq = Performance occurred during a non-final round. 3/10/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '6.50 qq = Performance occurred during a non-final round. ',
#   '3/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '6.50 qq = Performance occurred during a non-final round. ',
#   '3/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Burrell {2}JRHouston6.50 qq = Performance occurred during a non-final round. 3/11/2016',
#   '\xa0\xa0\xa0\xa0— Burrell {2}JR',
#   '',
#   'Houston',
#   '6.50 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  ['\xa0\xa0\xa0\xa0— Burrell {2}JR',
#   '',
#   'Houston',
#   '6.50 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  ['(10) Lee MCRAEJRPittsburgh6.50📺 3/7/1987',
#   '(10) Lee MCRAEJR',
#   '',
#   'Pittsburgh',
#   '6.50📺 ',
#   '3/7/1987'],
#  ['(10) Lee MCRAEJR', '', 'Pittsburgh', '6.50📺 ', '3/7/1987'],
#  ['(13) Favour ASHESOAuburn6.51 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(13) Favour ASHESO',
#   '',
#   'Auburn',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(13) Favour ASHESO',
#   '',
#   'Auburn',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(13) Ismael KONESRFlorida State6.51📺 1/13/2023',
#   '(13) Ismael KONESR',
#   '',
#   'Florida State',
#   '6.51📺 ',
#   '1/13/2023'],
#  ['(13) Ismael KONESR', '', 'Florida State', '6.51📺 ', '1/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Ashe {2}FRTennessee6.51 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Ashe {2}FR',
#   '',
#   'Tennessee',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Ashe {2}FR',
#   '',
#   'Tennessee',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {2}JRFlorida6.51📺 1/26/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {2}JR',
#   '',
#   'Florida',
#   '6.51📺 ',
#   '1/26/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {2}JR', '', 'Florida', '6.51📺 ', '1/26/2019'],
#  ['(13) Kendal WILLIAMSSOGeorgia6.51 2/17/2017',
#   '(13) Kendal WILLIAMSSO',
#   '',
#   'Georgia',
#   '6.51 ',
#   '2/17/2017'],
#  ['(13) Kendal WILLIAMSSO', '', 'Georgia', '6.51 ', '2/17/2017'],
#  ['\xa0\xa0\xa0\xa0— Coleman {3}JRTennessee6.51 2/4/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {3}JR',
#   '',
#   'Tennessee',
#   '6.51 ',
#   '2/4/2017'],
#  ['\xa0\xa0\xa0\xa0— Coleman {3}JR', '', 'Tennessee', '6.51 ', '2/4/2017'],
#  ['\xa0\xa0\xa0\xa0— Baker {3}SRTCU6.51 qq = Performance occurred during a non-final round. 3/11/2016',
#   '\xa0\xa0\xa0\xa0— Baker {3}SR',
#   '',
#   'TCU',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  ['\xa0\xa0\xa0\xa0— Baker {3}SR',
#   '',
#   'TCU',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  ['\xa0\xa0\xa0\xa0— Baker {4}SRTCU6.51 2/27/2016',
#   '\xa0\xa0\xa0\xa0— Baker {4}SR',
#   '',
#   'TCU',
#   '6.51 ',
#   '2/27/2016'],
#  ['\xa0\xa0\xa0\xa0— Baker {4}SR', '', 'TCU', '6.51 ', '2/27/2016'],
#  ['(13) Jacoby FORDJRClemson6.51 qq = Performance occurred during a non-final round. 3/13/2009',
#   '(13) Jacoby FORDJR',
#   '',
#   'Clemson',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/13/2009'],
#  ['(13) Jacoby FORDJR',
#   '',
#   'Clemson',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/13/2009'],
#  ['\xa0\xa0\xa0\xa0— Ford {2}JRClemson6.51  2/28/2009',
#   '\xa0\xa0\xa0\xa0— Ford {2}JR',
#   '',
#   'Clemson',
#   '6.51  ',
#   '2/28/2009'],
#  ['\xa0\xa0\xa0\xa0— Ford {2}JR', '', 'Clemson', '6.51  ', '2/28/2009'],
#  ['(13) Richard THOMPSONSRLSU6.51📺 3/15/2008',
#   '(13) Richard THOMPSONSR',
#   '',
#   'LSU',
#   '6.51📺 ',
#   '3/15/2008'],
#  ['(13) Richard THOMPSONSR', '', 'LSU', '6.51📺 ', '3/15/2008'],
#  ['\xa0\xa0\xa0\xa0— Thompson {2}SRLSU6.51 qq = Performance occurred during a non-final round. 3/14/2008',
#   '\xa0\xa0\xa0\xa0— Thompson {2}SR',
#   '',
#   'LSU',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/14/2008'],
#  ['\xa0\xa0\xa0\xa0— Thompson {2}SR',
#   '',
#   'LSU',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/14/2008'],
#  ["(13) Ja'Warren HOOKERWashington6.51 AA = Performance occurred at altitude (>1000 meters above sea level) 2/24/2001",
#   "(13) Ja'Warren HOOKER",
#   '',
#   'Washington',
#   '6.51 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/24/2001'],
#  ["(13) Ja'Warren HOOKER",
#   '',
#   'Washington',
#   '6.51 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/24/2001'],
#  ['\xa0\xa0\xa0\xa0— Ashe {3}SOAuburn6.52 2/25/2023',
#   '\xa0\xa0\xa0\xa0— Ashe {3}SO',
#   '',
#   'Auburn',
#   '6.52 ',
#   '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Ashe {3}SO', '', 'Auburn', '6.52 ', '2/25/2023'],
#  ['(19) Rikkoi BRATHWAITEJRIndiana6.52 3/12/2022',
#   '(19) Rikkoi BRATHWAITEJR',
#   '',
#   'Indiana',
#   '6.52 ',
#   '3/12/2022'],
#  ['(19) Rikkoi BRATHWAITEJR', '', 'Indiana', '6.52 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Ashe {4}FRTennessee6.52 qq = Performance occurred during a non-final round. 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Ashe {4}FR',
#   '',
#   'Tennessee',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Ashe {4}FR',
#   '',
#   'Tennessee',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Ashe {5}FRTennessee6.52 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Ashe {5}FR',
#   '',
#   'Tennessee',
#   '6.52 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Ashe {5}FR', '', 'Tennessee', '6.52 ', '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Williams {6}FROregon6.52 qq = Performance occurred during a non-final round. 3/12/2021',
#   '\xa0\xa0\xa0\xa0— Williams {6}FR',
#   '',
#   'Oregon',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Williams {6}FR',
#   '',
#   'Oregon',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ['(19) Divine ODUDURUJRTexas Tech6.52 2/23/2019',
#   '(19) Divine ODUDURUJR',
#   '',
#   'Texas Tech',
#   '6.52 ',
#   '2/23/2019'],
#  ['(19) Divine ODUDURUJR', '', 'Texas Tech', '6.52 ', '2/23/2019'],
#  ['(19) Elijah HALLSRHouston6.52 3/10/2018',
#   '(19) Elijah HALLSR',
#   '',
#   'Houston',
#   '6.52 ',
#   '3/10/2018'],
#  ['(19) Elijah HALLSR', '', 'Houston', '6.52 ', '3/10/2018'],
#  ['(19) Andre EWERSJRFlorida State6.52 1/20/2018',
#   '(19) Andre EWERSJR',
#   '',
#   'Florida State',
#   '6.52 ',
#   '1/20/2018'],
#  ['(19) Andre EWERSJR', '', 'Florida State', '6.52 ', '1/20/2018'],
#  ['\xa0\xa0\xa0\xa0— Coleman {4}JRTennessee6.52 2/25/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {4}JR',
#   '',
#   'Tennessee',
#   '6.52 ',
#   '2/25/2017'],
#  ['\xa0\xa0\xa0\xa0— Coleman {4}JR', '', 'Tennessee', '6.52 ', '2/25/2017'],
#  ['\xa0\xa0\xa0\xa0— Coleman {5}SOTennessee6.52 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Coleman {5}SO',
#   '',
#   'Tennessee',
#   '6.52 ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Coleman {5}SO', '', 'Tennessee', '6.52 ', '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Baker {5}TCU6.52 3/14/2015',
#   '\xa0\xa0\xa0\xa0— Baker {5}',
#   '',
#   'TCU',
#   '6.52 ',
#   '3/14/2015'],
#  ['\xa0\xa0\xa0\xa0— Baker {5}', '', 'TCU', '6.52 ', '3/14/2015'],
#  ['(19) John TEETERSJROklahoma State6.52 2/14/2015',
#   '(19) John TEETERSJR',
#   '',
#   'Oklahoma State',
#   '6.52 ',
#   '2/14/2015'],
#  ['(19) John TEETERSJR', '', 'Oklahoma State', '6.52 ', '2/14/2015'],
#  ['\xa0\xa0\xa0\xa0— Teeters {2}JROklahoma State6.52 qq = Performance occurred during a non-final round. 2/13/2015',
#   '\xa0\xa0\xa0\xa0— Teeters {2}JR',
#   '',
#   'Oklahoma State',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '2/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Teeters {2}JR',
#   '',
#   'Oklahoma State',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '2/13/2015'],
#  ['(19) Dentarius LOCKEFlorida State6.52 AA = Performance occurred at altitude (>1000 meters above sea level) 3/15/2014',
#   '(19) Dentarius LOCKE',
#   '',
#   'Florida State',
#   '6.52 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  ['(19) Dentarius LOCKE',
#   '',
#   'Florida State',
#   '6.52 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  ['(19) Jeff DEMPSFlorida6.52 qq = Performance occurred during a non-final round. 3/9/2012',
#   '(19) Jeff DEMPS',
#   '',
#   'Florida',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/9/2012'],
#  ['(19) Jeff DEMPS',
#   '',
#   'Florida',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/9/2012'],
#  ['\xa0\xa0\xa0\xa0— Ford {3}SOClemson6.52  3/14/2009',
#   '\xa0\xa0\xa0\xa0— Ford {3}SO',
#   '',
#   'Clemson',
#   '6.52  ',
#   '3/14/2009'],
#  ['\xa0\xa0\xa0\xa0— Ford {3}SO', '', 'Clemson', '6.52  ', '3/14/2009'],
#  ['\xa0\xa0\xa0\xa0— Cherry {2}Mississippi State6.52  3/1/2009',
#   '\xa0\xa0\xa0\xa0— Cherry {2}',
#   '',
#   'Mississippi State',
#   '6.52  ',
#   '3/1/2009'],
#  ['\xa0\xa0\xa0\xa0— Cherry {2}',
#   '',
#   'Mississippi State',
#   '6.52  ',
#   '3/1/2009'],
#  ['\xa0\xa0\xa0\xa0— Ford {4}SOClemson6.52  2/6/2009',
#   '\xa0\xa0\xa0\xa0— Ford {4}SO',
#   '',
#   'Clemson',
#   '6.52  ',
#   '2/6/2009'],
#  ['\xa0\xa0\xa0\xa0— Ford {4}SO', '', 'Clemson', '6.52  ', '2/6/2009'],
#  ['\xa0\xa0\xa0\xa0— Brunson {2}JRArizona State6.52 qq = Performance occurred during a non-final round. 3/5/1999',
#   '\xa0\xa0\xa0\xa0— Brunson {2}JR',
#   '',
#   'Arizona State',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/5/1999'],
#  ['\xa0\xa0\xa0\xa0— Brunson {2}JR',
#   '',
#   'Arizona State',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/5/1999'],
#  ['(19) Coby MILLERAuburn6.52  2/5/1999',
#   '(19) Coby MILLER',
#   '',
#   'Auburn',
#   '6.52  ',
#   '2/5/1999'],
#  ['(19) Coby MILLER', '', 'Auburn', '6.52  ', '2/5/1999'],
#  ['(19) Brian COOPERMcNeese State6.52  1/24/1988',
#   '(19) Brian COOPER',
#   '',
#   'McNeese State',
#   '6.52  ',
#   '1/24/1988']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Terrence JONESFRTexas Tech6.45 1/15/2022',
#   '(1) Terrence JONESFR',
#   '',
#   'Texas Tech',
#   '6.45 ',
#   '1/15/2022'],
#  ['(1) Christian COLEMANJRTennessee6.45📺 3/11/2017',
#   '(1) Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '6.45📺 ',
#   '3/11/2017'],
#  ['(1) Leonard MYLES-MILLSSRBYU6.45 AA = Performance occurred at altitude (>1000 meters above sea level) 2/20/1999',
#   '(1) Leonard MYLES-MILLSSR',
#   '',
#   'BYU',
#   '6.45 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/20/1999'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}SOTexas Tech6.46📺 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Jones {2}SO',
#   '',
#   'Texas Tech',
#   '6.46📺 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Jones {3}SOTexas Tech6.46 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Jones {3}SO',
#   '',
#   'Texas Tech',
#   '6.46 ',
#   '2/24/2023'],
#  ['(4) Marcus BRUNSONArizona State6.46 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round. 1/30/1999',
#   '(4) Marcus BRUNSON',
#   '',
#   'Arizona State',
#   '6.46 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round. ',
#   '1/30/1999'],
#  ['(5) Ronnie BAKERSRTCU6.47 ii = event moved indoors because of weather or another issue. 3/12/2016',
#   '(5) Ronnie BAKERSR',
#   '',
#   'TCU',
#   '6.47 ii = event moved indoors because of weather or another issue. ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Baker {2}SRTCU6.47📺 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Baker {2}SR',
#   '',
#   'TCU',
#   '6.47📺 ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Jones {4}SOTexas Tech6.48 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Jones {4}SO',
#   '',
#   'Texas Tech',
#   '6.48 ',
#   '2/24/2023'],
#  ['(6) Micah WILLIAMSFROregon6.48 1/28/2022',
#   '(6) Micah WILLIAMSFR',
#   '',
#   'Oregon',
#   '6.48 ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Williams {2}FROregon6.48 1/15/2022',
#   '\xa0\xa0\xa0\xa0— Williams {2}FR',
#   '',
#   'Oregon',
#   '6.48 ',
#   '1/15/2022'],
#  ['(6) Cameron BURRELLJRHouston6.48 3/12/2016',
#   '(6) Cameron BURRELLJR',
#   '',
#   'Houston',
#   '6.48 ',
#   '3/12/2016'],
#  ['(6) Leonard SCOTTJRTennessee6.48  2/25/2001',
#   '(6) Leonard SCOTTJR',
#   '',
#   'Tennessee',
#   '6.48  ',
#   '2/25/2001'],
#  ['\xa0\xa0\xa0\xa0— Scott {2}JRTennessee6.48 qq = Performance occurred during a non-final round. 2/24/2001',
#   '\xa0\xa0\xa0\xa0— Scott {2}JR',
#   '',
#   'Tennessee',
#   '6.48 qq = Performance occurred during a non-final round. ',
#   '2/24/2001'],
#  ['\xa0\xa0\xa0\xa0— Myles-Mills {2}BYU6.48 AA = Performance occurred at altitude (>1000 meters above sea level) 1/23/1999',
#   '\xa0\xa0\xa0\xa0— Myles-Mills {2}',
#   '',
#   'BYU',
#   '6.48 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/23/1999'],
#  ['\xa0\xa0\xa0\xa0— Williams {3}SOOregon6.49📺 1/26/2023',
#   '\xa0\xa0\xa0\xa0— Williams {3}SO',
#   '',
#   'Oregon',
#   '6.49📺 ',
#   '1/26/2023'],
#  ['\xa0\xa0\xa0\xa0— Williams {4}FROregon6.49 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Williams {4}FR',
#   '',
#   'Oregon',
#   '6.49 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Williams {5}FROregon6.49 AA = Performance occurred at altitude (>1000 meters above sea level) 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Williams {5}FR',
#   '',
#   'Oregon',
#   '6.49 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/25/2021'],
#  ["(9) D'Angelo CHERRYMississippi State6.49 AA = Performance occurred at altitude (>1000 meters above sea level) 3/3/2013",
#   "(9) D'Angelo CHERRY",
#   '',
#   'Mississippi State',
#   '6.49 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/3/2013'],
#  ['(10) Davonte BURNETTSRSouthern California6.50 3/12/2022',
#   '(10) Davonte BURNETTSR',
#   '',
#   'Southern California',
#   '6.50 ',
#   '3/12/2022'],
#  ['(10) Grant HOLLOWAYJRFlorida6.50 3/9/2019',
#   '(10) Grant HOLLOWAYJR',
#   '',
#   'Florida',
#   '6.50 ',
#   '3/9/2019'],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JRTennessee6.50 qq = Performance occurred during a non-final round. 3/10/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '6.50 qq = Performance occurred during a non-final round. ',
#   '3/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Burrell {2}JRHouston6.50 qq = Performance occurred during a non-final round. 3/11/2016',
#   '\xa0\xa0\xa0\xa0— Burrell {2}JR',
#   '',
#   'Houston',
#   '6.50 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  ['(10) Lee MCRAEJRPittsburgh6.50📺 3/7/1987',
#   '(10) Lee MCRAEJR',
#   '',
#   'Pittsburgh',
#   '6.50📺 ',
#   '3/7/1987'],
#  ['(13) Favour ASHESOAuburn6.51 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(13) Favour ASHESO',
#   '',
#   'Auburn',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(13) Ismael KONESRFlorida State6.51📺 1/13/2023',
#   '(13) Ismael KONESR',
#   '',
#   'Florida State',
#   '6.51📺 ',
#   '1/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Ashe {2}FRTennessee6.51 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Ashe {2}FR',
#   '',
#   'Tennessee',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {2}JRFlorida6.51📺 1/26/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {2}JR',
#   '',
#   'Florida',
#   '6.51📺 ',
#   '1/26/2019'],
#  ['(13) Kendal WILLIAMSSOGeorgia6.51 2/17/2017',
#   '(13) Kendal WILLIAMSSO',
#   '',
#   'Georgia',
#   '6.51 ',
#   '2/17/2017'],
#  ['\xa0\xa0\xa0\xa0— Coleman {3}JRTennessee6.51 2/4/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {3}JR',
#   '',
#   'Tennessee',
#   '6.51 ',
#   '2/4/2017'],
#  ['\xa0\xa0\xa0\xa0— Baker {3}SRTCU6.51 qq = Performance occurred during a non-final round. 3/11/2016',
#   '\xa0\xa0\xa0\xa0— Baker {3}SR',
#   '',
#   'TCU',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  ['\xa0\xa0\xa0\xa0— Baker {4}SRTCU6.51 2/27/2016',
#   '\xa0\xa0\xa0\xa0— Baker {4}SR',
#   '',
#   'TCU',
#   '6.51 ',
#   '2/27/2016'],
#  ['(13) Jacoby FORDJRClemson6.51 qq = Performance occurred during a non-final round. 3/13/2009',
#   '(13) Jacoby FORDJR',
#   '',
#   'Clemson',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/13/2009'],
#  ['\xa0\xa0\xa0\xa0— Ford {2}JRClemson6.51  2/28/2009',
#   '\xa0\xa0\xa0\xa0— Ford {2}JR',
#   '',
#   'Clemson',
#   '6.51  ',
#   '2/28/2009'],
#  ['(13) Richard THOMPSONSRLSU6.51📺 3/15/2008',
#   '(13) Richard THOMPSONSR',
#   '',
#   'LSU',
#   '6.51📺 ',
#   '3/15/2008'],
#  ['\xa0\xa0\xa0\xa0— Thompson {2}SRLSU6.51 qq = Performance occurred during a non-final round. 3/14/2008',
#   '\xa0\xa0\xa0\xa0— Thompson {2}SR',
#   '',
#   'LSU',
#   '6.51 qq = Performance occurred during a non-final round. ',
#   '3/14/2008'],
#  ["(13) Ja'Warren HOOKERWashington6.51 AA = Performance occurred at altitude (>1000 meters above sea level) 2/24/2001",
#   "(13) Ja'Warren HOOKER",
#   '',
#   'Washington',
#   '6.51 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/24/2001'],
#  ['\xa0\xa0\xa0\xa0— Ashe {3}SOAuburn6.52 2/25/2023',
#   '\xa0\xa0\xa0\xa0— Ashe {3}SO',
#   '',
#   'Auburn',
#   '6.52 ',
#   '2/25/2023'],
#  ['(19) Rikkoi BRATHWAITEJRIndiana6.52 3/12/2022',
#   '(19) Rikkoi BRATHWAITEJR',
#   '',
#   'Indiana',
#   '6.52 ',
#   '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Ashe {4}FRTennessee6.52 qq = Performance occurred during a non-final round. 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Ashe {4}FR',
#   '',
#   'Tennessee',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Ashe {5}FRTennessee6.52 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Ashe {5}FR',
#   '',
#   'Tennessee',
#   '6.52 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Williams {6}FROregon6.52 qq = Performance occurred during a non-final round. 3/12/2021',
#   '\xa0\xa0\xa0\xa0— Williams {6}FR',
#   '',
#   'Oregon',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ['(19) Divine ODUDURUJRTexas Tech6.52 2/23/2019',
#   '(19) Divine ODUDURUJR',
#   '',
#   'Texas Tech',
#   '6.52 ',
#   '2/23/2019'],
#  ['(19) Elijah HALLSRHouston6.52 3/10/2018',
#   '(19) Elijah HALLSR',
#   '',
#   'Houston',
#   '6.52 ',
#   '3/10/2018'],
#  ['(19) Andre EWERSJRFlorida State6.52 1/20/2018',
#   '(19) Andre EWERSJR',
#   '',
#   'Florida State',
#   '6.52 ',
#   '1/20/2018'],
#  ['\xa0\xa0\xa0\xa0— Coleman {4}JRTennessee6.52 2/25/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {4}JR',
#   '',
#   'Tennessee',
#   '6.52 ',
#   '2/25/2017'],
#  ['\xa0\xa0\xa0\xa0— Coleman {5}SOTennessee6.52 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Coleman {5}SO',
#   '',
#   'Tennessee',
#   '6.52 ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Baker {5}TCU6.52 3/14/2015',
#   '\xa0\xa0\xa0\xa0— Baker {5}',
#   '',
#   'TCU',
#   '6.52 ',
#   '3/14/2015'],
#  ['(19) John TEETERSJROklahoma State6.52 2/14/2015',
#   '(19) John TEETERSJR',
#   '',
#   'Oklahoma State',
#   '6.52 ',
#   '2/14/2015'],
#  ['\xa0\xa0\xa0\xa0— Teeters {2}JROklahoma State6.52 qq = Performance occurred during a non-final round. 2/13/2015',
#   '\xa0\xa0\xa0\xa0— Teeters {2}JR',
#   '',
#   'Oklahoma State',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '2/13/2015'],
#  ['(19) Dentarius LOCKEFlorida State6.52 AA = Performance occurred at altitude (>1000 meters above sea level) 3/15/2014',
#   '(19) Dentarius LOCKE',
#   '',
#   'Florida State',
#   '6.52 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  ['(19) Jeff DEMPSFlorida6.52 qq = Performance occurred during a non-final round. 3/9/2012',
#   '(19) Jeff DEMPS',
#   '',
#   'Florida',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/9/2012'],
#  ['\xa0\xa0\xa0\xa0— Ford {3}SOClemson6.52  3/14/2009',
#   '\xa0\xa0\xa0\xa0— Ford {3}SO',
#   '',
#   'Clemson',
#   '6.52  ',
#   '3/14/2009'],
#  ['\xa0\xa0\xa0\xa0— Cherry {2}Mississippi State6.52  3/1/2009',
#   '\xa0\xa0\xa0\xa0— Cherry {2}',
#   '',
#   'Mississippi State',
#   '6.52  ',
#   '3/1/2009'],
#  ['\xa0\xa0\xa0\xa0— Ford {4}SOClemson6.52  2/6/2009',
#   '\xa0\xa0\xa0\xa0— Ford {4}SO',
#   '',
#   'Clemson',
#   '6.52  ',
#   '2/6/2009'],
#  ['\xa0\xa0\xa0\xa0— Brunson {2}JRArizona State6.52 qq = Performance occurred during a non-final round. 3/5/1999',
#   '\xa0\xa0\xa0\xa0— Brunson {2}JR',
#   '',
#   'Arizona State',
#   '6.52 qq = Performance occurred during a non-final round. ',
#   '3/5/1999'],
#  ['(19) Coby MILLERAuburn6.52  2/5/1999',
#   '(19) Coby MILLER',
#   '',
#   'Auburn',
#   '6.52  ',
#   '2/5/1999'],
#  ['(19) Brian COOPERMcNeese State6.52  1/24/1988',
#   '(19) Brian COOPER',
#   '',
#   'McNeese State',
#   '6.52  ',
#   '1/24/1988']]

# %%
RealRealRows[1][4]
# Out:
# '6.45📺 '

# %%
len(RealRealRows)
# Out:
# 58

# %%
OfficialTimes = []

# %%
for i in range(0,len(RealRealRows)):
    OfficialTimes.append(RealRealRows[i][4])
OfficialTimes
# Out:
# ['6.45 ',
#  '6.45📺 ',
#  '6.45 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '6.46📺 ',
#  '6.46 ',
#  '6.46 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round. ',
#  '6.47 ii = event moved indoors because of weather or another issue. ',
#  '6.47📺 ',
#  '6.48 ',
#  '6.48 ',
#  '6.48 ',
#  '6.48 ',
#  '6.48  ',
#  '6.48 qq = Performance occurred during a non-final round. ',
#  '6.48 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '6.49📺 ',
#  '6.49 ',
#  '6.49 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '6.49 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '6.50 ',
#  '6.50 ',
#  '6.50 qq = Performance occurred during a non-final round. ',
#  '6.50 qq = Performance occurred during a non-final round. ',
#  '6.50📺 ',
#  '6.51 qq = Performance occurred during a non-final round. ',
#  '6.51📺 ',
#  '6.51 qq = Performance occurred during a non-final round. ',
#  '6.51📺 ',
#  '6.51 ',
#  '6.51 ',
#  '6.51 qq = Performance occurred during a non-final round. ',
#  '6.51 ',
#  '6.51 qq = Performance occurred during a non-final round. ',
#  '6.51  ',
#  '6.51📺 ',
#  '6.51 qq = Performance occurred during a non-final round. ',
#  '6.51 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '6.52 ',
#  '6.52 ',
#  '6.52 qq = Performance occurred during a non-final round. ',
#  '6.52 ',
#  '6.52 qq = Performance occurred during a non-final round. ',
#  '6.52 ',
#  '6.52 ',
#  '6.52 ',
#  '6.52 ',
#  '6.52 ',
#  '6.52 ',
#  '6.52 ',
#  '6.52 qq = Performance occurred during a non-final round. ',
#  '6.52 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '6.52 qq = Performance occurred during a non-final round. ',
#  '6.52  ',
#  '6.52  ',
#  '6.52  ',
#  '6.52 qq = Performance occurred during a non-final round. ',
#  '6.52  ',
#  '6.52  ']

# %%
RealRealRows[0][1]
# Out:
# '(1) Terrence JONESFR'

# %%
Names = []

for i in range(0,len(RealRealRows)):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Terrence JONESFR',
#  '(1) Christian COLEMANJR',
#  '(1) Leonard MYLES-MILLSSR',
#  '\xa0\xa0\xa0\xa0— Jones {2}SO',
#  '\xa0\xa0\xa0\xa0— Jones {3}SO',
#  '(4) Marcus BRUNSON',
#  '(5) Ronnie BAKERSR',
#  '\xa0\xa0\xa0\xa0— Baker {2}SR',
#  '\xa0\xa0\xa0\xa0— Jones {4}SO',
#  '(6) Micah WILLIAMSFR',
#  '\xa0\xa0\xa0\xa0— Williams {2}FR',
#  '(6) Cameron BURRELLJR',
#  '(6) Leonard SCOTTJR',
#  '\xa0\xa0\xa0\xa0— Scott {2}JR',
#  '\xa0\xa0\xa0\xa0— Myles-Mills {2}',
#  '\xa0\xa0\xa0\xa0— Williams {3}SO',
#  '\xa0\xa0\xa0\xa0— Williams {4}FR',
#  '\xa0\xa0\xa0\xa0— Williams {5}FR',
#  "(9) D'Angelo CHERRY",
#  '(10) Davonte BURNETTSR',
#  '(10) Grant HOLLOWAYJR',
#  '\xa0\xa0\xa0\xa0— Coleman {2}JR',
#  '\xa0\xa0\xa0\xa0— Burrell {2}JR',
#  '(10) Lee MCRAEJR',
#  '(13) Favour ASHESO',
#  '(13) Ismael KONESR',
#  '\xa0\xa0\xa0\xa0— Ashe {2}FR',
#  '\xa0\xa0\xa0\xa0— Holloway {2}JR',
#  '(13) Kendal WILLIAMSSO',
#  '\xa0\xa0\xa0\xa0— Coleman {3}JR',
#  '\xa0\xa0\xa0\xa0— Baker {3}SR',
#  '\xa0\xa0\xa0\xa0— Baker {4}SR',
#  '(13) Jacoby FORDJR',
#  '\xa0\xa0\xa0\xa0— Ford {2}JR',
#  '(13) Richard THOMPSONSR',
#  '\xa0\xa0\xa0\xa0— Thompson {2}SR',
#  "(13) Ja'Warren HOOKER",
#  '\xa0\xa0\xa0\xa0— Ashe {3}SO',
#  '(19) Rikkoi BRATHWAITEJR',
#  '\xa0\xa0\xa0\xa0— Ashe {4}FR',
#  '\xa0\xa0\xa0\xa0— Ashe {5}FR',
#  '\xa0\xa0\xa0\xa0— Williams {6}FR',
#  '(19) Divine ODUDURUJR',
#  '(19) Elijah HALLSR',
#  '(19) Andre EWERSJR',
#  '\xa0\xa0\xa0\xa0— Coleman {4}JR',
#  '\xa0\xa0\xa0\xa0— Coleman {5}SO',
#  '\xa0\xa0\xa0\xa0— Baker {5}',
#  '(19) John TEETERSJR',
#  '\xa0\xa0\xa0\xa0— Teeters {2}JR',
#  '(19) Dentarius LOCKE',
#  '(19) Jeff DEMPS',
#  '\xa0\xa0\xa0\xa0— Ford {3}SO',
#  '\xa0\xa0\xa0\xa0— Cherry {2}',
#  '\xa0\xa0\xa0\xa0— Ford {4}SO',
#  '\xa0\xa0\xa0\xa0— Brunson {2}JR',
#  '(19) Coby MILLER',
#  '(19) Brian COOPER']

# %%
OfficialReGexNames = []

# %%
for i in range(0,len(RealRealRows)):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Terrence JONESFR',
#  '(1) Christian COLEMANJR',
#  '(1) Leonard MYLES-MILLSSR',
#  '— Jones {2}SO',
#  '— Jones {3}SO',
#  '(4) Marcus BRUNSON',
#  '(5) Ronnie BAKERSR',
#  '— Baker {2}SR',
#  '— Jones {4}SO',
#  '(6) Micah WILLIAMSFR',
#  '— Williams {2}FR',
#  '(6) Cameron BURRELLJR',
#  '(6) Leonard SCOTTJR',
#  '— Scott {2}JR',
#  '— Myles-Mills {2}',
#  '— Williams {3}SO',
#  '— Williams {4}FR',
#  '— Williams {5}FR',
#  "(9) D'Angelo CHERRY",
#  '(10) Davonte BURNETTSR',
#  '(10) Grant HOLLOWAYJR',
#  '— Coleman {2}JR',
#  '— Burrell {2}JR',
#  '(10) Lee MCRAEJR',
#  '(13) Favour ASHESO',
#  '(13) Ismael KONESR',
#  '— Ashe {2}FR',
#  '— Holloway {2}JR',
#  '(13) Kendal WILLIAMSSO',
#  '— Coleman {3}JR',
#  '— Baker {3}SR',
#  '— Baker {4}SR',
#  '(13) Jacoby FORDJR',
#  '— Ford {2}JR',
#  '(13) Richard THOMPSONSR',
#  '— Thompson {2}SR',
#  "(13) Ja'Warren HOOKER",
#  '— Ashe {3}SO',
#  '(19) Rikkoi BRATHWAITEJR',
#  '— Ashe {4}FR',
#  '— Ashe {5}FR',
#  '— Williams {6}FR',
#  '(19) Divine ODUDURUJR',
#  '(19) Elijah HALLSR',
#  '(19) Andre EWERSJR',
#  '— Coleman {4}JR',
#  '— Coleman {5}SO',
#  '— Baker {5}',
#  '(19) John TEETERSJR',
#  '— Teeters {2}JR',
#  '(19) Dentarius LOCKE',
#  '(19) Jeff DEMPS',
#  '— Ford {3}SO',
#  '— Cherry {2}',
#  '— Ford {4}SO',
#  '— Brunson {2}JR',
#  '(19) Coby MILLER',
#  '(19) Brian COOPER']

# %%
CleanedNames = []

for i in range(0,len(RealRealRows)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Terrence JONESFR',
#  'Christian COLEMANJR',
#  'Leonard MYLES-MILLSSR',
#  'Jones {2}SO',
#  'Jones {3}SO',
#  'Marcus BRUNSON',
#  'Ronnie BAKERSR',
#  'Baker {2}SR',
#  'Jones {4}SO',
#  'Micah WILLIAMSFR',
#  'Williams {2}FR',
#  'Cameron BURRELLJR',
#  'Leonard SCOTTJR',
#  'Scott {2}JR',
#  'Myles-Mills {2}',
#  'Williams {3}SO',
#  'Williams {4}FR',
#  'Williams {5}FR',
#  "D'Angelo CHERRY",
#  ' Davonte BURNETTSR',
#  ' Grant HOLLOWAYJR',
#  'Coleman {2}JR',
#  'Burrell {2}JR',
#  ' Lee MCRAEJR',
#  ' Favour ASHESO',
#  ' Ismael KONESR',
#  'Ashe {2}FR',
#  'Holloway {2}JR',
#  ' Kendal WILLIAMSSO',
#  'Coleman {3}JR',
#  'Baker {3}SR',
#  'Baker {4}SR',
#  ' Jacoby FORDJR',
#  'Ford {2}JR',
#  ' Richard THOMPSONSR',
#  'Thompson {2}SR',
#  " Ja'Warren HOOKER",
#  'Ashe {3}SO',
#  ' Rikkoi BRATHWAITEJR',
#  'Ashe {4}FR',
#  'Ashe {5}FR',
#  'Williams {6}FR',
#  ' Divine ODUDURUJR',
#  ' Elijah HALLSR',
#  ' Andre EWERSJR',
#  'Coleman {4}JR',
#  'Coleman {5}SO',
#  'Baker {5}',
#  ' John TEETERSJR',
#  'Teeters {2}JR',
#  ' Dentarius LOCKE',
#  ' Jeff DEMPS',
#  'Ford {3}SO',
#  'Cherry {2}',
#  'Ford {4}SO',
#  'Brunson {2}JR',
#  ' Coby MILLER',
#  ' Brian COOPER']

# %%
CleanedNames2 = []

for i in range(0,len(RealRealRows)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Terrence JONESFR',
#  'Christian COLEMANJR',
#  'Leonard MYLES-MILLSSR',
#  'Jones {2}SO',
#  'Jones {3}SO',
#  'Marcus BRUNSON',
#  'Ronnie BAKERSR',
#  'Baker {2}SR',
#  'Jones {4}SO',
#  'Micah WILLIAMSFR',
#  'Williams {2}FR',
#  'Cameron BURRELLJR',
#  'Leonard SCOTTJR',
#  'Scott {2}JR',
#  'Myles-Mills {2}',
#  'Williams {3}SO',
#  'Williams {4}FR',
#  'Williams {5}FR',
#  "D'Angelo CHERRY",
#  'Davonte BURNETTSR',
#  'Grant HOLLOWAYJR',
#  'Coleman {2}JR',
#  'Burrell {2}JR',
#  'Lee MCRAEJR',
#  'Favour ASHESO',
#  'Ismael KONESR',
#  'Ashe {2}FR',
#  'Holloway {2}JR',
#  'Kendal WILLIAMSSO',
#  'Coleman {3}JR',
#  'Baker {3}SR',
#  'Baker {4}SR',
#  'Jacoby FORDJR',
#  'Ford {2}JR',
#  'Richard THOMPSONSR',
#  'Thompson {2}SR',
#  "Ja'Warren HOOKER",
#  'Ashe {3}SO',
#  'Rikkoi BRATHWAITEJR',
#  'Ashe {4}FR',
#  'Ashe {5}FR',
#  'Williams {6}FR',
#  'Divine ODUDURUJR',
#  'Elijah HALLSR',
#  'Andre EWERSJR',
#  'Coleman {4}JR',
#  'Coleman {5}SO',
#  'Baker {5}',
#  'John TEETERSJR',
#  'Teeters {2}JR',
#  'Dentarius LOCKE',
#  'Jeff DEMPS',
#  'Ford {3}SO',
#  'Cherry {2}',
#  'Ford {4}SO',
#  'Brunson {2}JR',
#  'Coby MILLER',
#  'Brian COOPER']

# %%
len(OfficialTimes)
# Out:
# 58

# %%
len(OfficialReGexNames)
# Out:
# 58

# %%
Schools = []

for i in range(0,len(OfficialTimes)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Texas Tech',
#  'Tennessee',
#  'BYU',
#  'Texas Tech',
#  'Texas Tech',
#  'Arizona State',
#  'TCU',
#  'TCU',
#  'Texas Tech',
#  'Oregon',
#  'Oregon',
#  'Houston',
#  'Tennessee',
#  'Tennessee',
#  'BYU',
#  'Oregon',
#  'Oregon',
#  'Oregon',
#  'Mississippi State',
#  'Southern California',
#  'Florida',
#  'Tennessee',
#  'Houston',
#  'Pittsburgh',
#  'Auburn',
#  'Florida State',
#  'Tennessee',
#  'Florida',
#  'Georgia',
#  'Tennessee',
#  'TCU',
#  'TCU',
#  'Clemson',
#  'Clemson',
#  'LSU',
#  'LSU',
#  'Washington',
#  'Auburn',
#  'Indiana',
#  'Tennessee',
#  'Tennessee',
#  'Oregon',
#  'Texas Tech',
#  'Houston',
#  'Florida State',
#  'Tennessee',
#  'Tennessee',
#  'TCU',
#  'Oklahoma State',
#  'Oklahoma State',
#  'Florida State',
#  'Florida',
#  'Clemson',
#  'Mississippi State',
#  'Clemson',
#  'Arizona State',
#  'Auburn',
#  'McNeese State']

# %%
Times = []
for i in range(0,len(OfficialTimes)):
    Times.append(OfficialTimes[i][:4])
    
Times
# Out:
# ['6.45',
#  '6.45',
#  '6.45',
#  '6.46',
#  '6.46',
#  '6.46',
#  '6.47',
#  '6.47',
#  '6.48',
#  '6.48',
#  '6.48',
#  '6.48',
#  '6.48',
#  '6.48',
#  '6.48',
#  '6.49',
#  '6.49',
#  '6.49',
#  '6.49',
#  '6.50',
#  '6.50',
#  '6.50',
#  '6.50',
#  '6.50',
#  '6.51',
#  '6.51',
#  '6.51',
#  '6.51',
#  '6.51',
#  '6.51',
#  '6.51',
#  '6.51',
#  '6.51',
#  '6.51',
#  '6.51',
#  '6.51',
#  '6.51',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52',
#  '6.52']

# %%
Men60mDF = pd.DataFrame({'Names': CleanedNames2, 'Times': Times, 'Schools': Schools})
Men60mDF.to_csv('Men60m.csv', index=False)
