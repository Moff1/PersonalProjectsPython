# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
Link100m = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?gender=1&sport=2&div=20527&top=25&event=2"

# %%
page = requests.get(Link100m)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113312" target="_blank">(1) Christian COLEMAN</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51935/3199095" target="_blank">9.82</a><a href="https://www.youtube.com/watch?v=rjB5Ndg127c" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113312" target="_blank">(1) Christian COLEMAN</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51935/3199095" target="_blank">9.82</a><a href="https://www.youtube.com/watch?v=rjB5Ndg127c" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7722962" target="_blank">(2) Micah WILLIAMS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75211/4565964" target="_blank">9.86</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West Preliminary (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">5/27/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7722962" target="_blank">(2) Micah WILLIAMS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75211/4565964" target="_blank">9.86</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West Preliminary (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">5/27/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6166402" target="_blank">(2) Divine ODUDURU</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850639" target="_blank">9.86</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6166402" target="_blank">(2) Divine ODUDURU</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850639" target="_blank">9.86</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7036992" target="_blank">(4) Courtney LINDSEY</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938129" target="_blank">9.89</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7036992" target="_blank">(4) Courtney LINDSEY</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938129" target="_blank">9.89</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7731969" target="_blank">(4) PJ AUSTIN</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938129" target="_blank">9.89</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7731969" target="_blank">(4) PJ AUSTIN</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938129" target="_blank">9.89</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3287451" target="_blank">(4) Ngoni MAKUSHA</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/22067" target="_blank">9.89</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2011</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3287451" target="_blank">(4) Ngoni MAKUSHA</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/22067" target="_blank">9.89</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2011</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7989909" target="_blank">(7) Godson OGHENEBRUME</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938129" target="_blank">9.90</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7989909" target="_blank">(7) Godson OGHENEBRUME</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938129" target="_blank">9.90</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7560228" target="_blank">(7) Benjamin AZAMATI</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="West Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/west-texas-am.png" title="West Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1752">West Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72503" target="_blank">9.90</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.0)</span></td><td style="width: 10%;text-align:right;" title="94th Clyde Littlefield Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/25/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7560228" target="_blank">(7) Benjamin AZAMATI</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="West Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/west-texas-am.png" title="West Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1752">West Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72503" target="_blank">9.90</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.0)</span></td><td style="width: 10%;text-align:right;" title="94th Clyde Littlefield Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/25/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4672334" target="_blank">(7) Trayvon BROMELL</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Baylor" class="group-logo-inline" src="/images/logos/rankings-article/baylor.png" title="Baylor"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=101">Baylor</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41405/2568001" target="_blank">9.90</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4672334" target="_blank">(7) Trayvon BROMELL</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Baylor" class="group-logo-inline" src="/images/logos/rankings-article/baylor.png" title="Baylor"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=101">Baylor</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41405/2568001" target="_blank">9.90</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7721646" target="_blank">(10) Shaun MASWANGANYI</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=672">Houston</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938129" target="_blank">9.91</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7721646" target="_blank">(10) Shaun MASWANGANYI</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=672">Houston</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938129" target="_blank">9.91</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7727055" target="_blank">(10) Terrence JONES</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78102/4824382" target="_blank">9.91</a><a href="https://twitter.com/TexasTechTF/status/1647338051515953153" target="_blank">📺</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.0)</span></td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/14/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7727055" target="_blank">(10) Terrence JONES</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78102/4824382" target="_blank">9.91</a><a href="https://twitter.com/TexasTechTF/status/1647338051515953153" target="_blank">📺</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.0)</span></td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/14/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(10) Davidson EZINWA</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Azusa Pacific" class="group-logo-inline" src="/images/logos/rankings-article/azusa-pacific.png" title="Azusa Pacific"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=86">Azusa Pacific</a></td><td style="width: 25%;">9.91  <br/><span style="font-size:0.7em;font-style: italic;"> (w: -2.3)</span></td><td style="width: 10%;text-align:right;" title=" (Azusa, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">4/11/1992</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(10) Davidson EZINWA</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Azusa Pacific" class="group-logo-inline" src="/images/logos/rankings-article/azusa-pacific.png" title="Azusa Pacific"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=86">Azusa Pacific</a></td><td style="width: 25%;">9.91  <br/><span style="font-size:0.7em;font-style: italic;"> (w: -2.3)</span></td><td style="width: 10%;text-align:right;" title=" (Azusa, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">4/11/1992</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7980286" target="_blank">(13) Udodi ONWUZURIKE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81275/4936443" target="_blank">9.92</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West First-Rounds (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/26/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7980286" target="_blank">(13) Udodi ONWUZURIKE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81275/4936443" target="_blank">9.92</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West First-Rounds (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/26/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(13) Ato BOLDON</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1617">UCLA</a></td><td style="width: 25%;">9.92  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/1/1996</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(13) Ato BOLDON</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1617">UCLA</a></td><td style="width: 25%;">9.92  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/1/1996</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Oghenebrume {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938129" target="_blank">9.93</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Oghenebrume {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938129" target="_blank">9.93</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Jones {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81275/4936443" target="_blank">9.93</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West First-Rounds (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/26/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Jones {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81275/4936443" target="_blank">9.93</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West First-Rounds (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/26/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Williams {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74310/4560224" target="_blank">9.93</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.7)</span></td><td style="width: 10%;text-align:right;" title="Pac-12 Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Williams {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74310/4560224" target="_blank">9.93</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.7)</span></td><td style="width: 10%;text-align:right;" title="Pac-12 Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6582462" target="_blank">(15) Cravon GILLESPIE</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850639" target="_blank">9.93</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6582462" target="_blank">(15) Cravon GILLESPIE</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850639" target="_blank">9.93</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5660973" target="_blank">(15) Chris BELCHER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="North Carolina A&amp;T" class="group-logo-inline" src="/images/logos/rankings-article/north-carolina-at.png" title="North Carolina A&amp;T"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1086">North Carolina A&amp;T</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51935/3199095" target="_blank">9.93</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5660973" target="_blank">(15) Chris BELCHER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="North Carolina A&amp;T" class="group-logo-inline" src="/images/logos/rankings-article/north-carolina-at.png" title="North Carolina A&amp;T"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1086">North Carolina A&amp;T</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51935/3199095" target="_blank">9.93</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4629579" target="_blank">(15) Cameron BURRELL</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=672">Houston</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51935/3199095" target="_blank">9.93</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4629579" target="_blank">(15) Cameron BURRELL</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=672">Houston</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51935/3199095" target="_blank">9.93</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3300969" target="_blank">(15) Clayton VAUGHN</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UT Arlington" class="group-logo-inline" src="/images/logos/rankings-article/ut-arlington.png" title="UT Arlington"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1661">UT Arlington</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/40315" target="_blank">9.93</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="Sun Belt Outdoor Championships (Gulf Shores, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">5/10/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3300969" target="_blank">(15) Clayton VAUGHN</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UT Arlington" class="group-logo-inline" src="/images/logos/rankings-article/ut-arlington.png" title="UT Arlington"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1661">UT Arlington</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/40315" target="_blank">9.93</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="Sun Belt Outdoor Championships (Gulf Shores, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">5/10/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(15) Richard THOMPSON</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=869">LSU</a></td><td style="width: 25%;">9.93  <br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.1)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Auburn, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">5/18/2008</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(15) Richard THOMPSON</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=869">LSU</a></td><td style="width: 25%;">9.93  <br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.1)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Auburn, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">5/18/2008</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(15) Walter DIX</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=529">Florida State</a></td><td style="width: 25%;">9.93  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2007</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(15) Walter DIX</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=529">Florida State</a></td><td style="width: 25%;">9.93  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2007</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Boldon {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1617">UCLA</a></td><td style="width: 25%;">9.93  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="Mt. SAC Relays (Walnut, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">4/21/1996</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Boldon {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1617">UCLA</a></td><td style="width: 25%;">9.93  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="Mt. SAC Relays (Walnut, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">4/21/1996</span></td></tr>,
# ...
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4266379" target="_blank">BeeJay LEE</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1432">Southern California</a></td><td style="width: 25%;">9.94 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.7)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/26/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4149229" target="_blank">Ronnie BAKER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="TCU" class="group-logo-inline" src="/images/logos/rankings-article/tcu.png" title="TCU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1550">TCU</a></td><td style="width: 25%;">9.94 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.1)</span></td><td style="width: 10%;text-align:right;" title="USATF U20 Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/25/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4149229" target="_blank">Ronnie BAKER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="TCU" class="group-logo-inline" src="/images/logos/rankings-article/tcu.png" title="TCU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1550">TCU</a></td><td style="width: 25%;">9.94 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.1)</span></td><td style="width: 10%;text-align:right;" title="USATF U20 Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/25/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7722962" target="_blank">Micah WILLIAMS</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70481/4278379" target="_blank">9.95</a> <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.7)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/19/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7722962" target="_blank">Micah WILLIAMS</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70481/4278379" target="_blank">9.95</a> <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.7)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/19/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3307187" target="_blank">Kemar HYMAN</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=529">Florida State</a></td><td style="width: 25%;">9.95 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.8)</span></td><td style="width: 10%;text-align:right;" title="Meeting de Athletismo Madrid (Madrid, Spain)"><span class="mark-date" style="width: 10%;text-align:right;">7/7/2012</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3307187" target="_blank">Kemar HYMAN</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=529">Florida State</a></td><td style="width: 25%;">9.95 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.8)</span></td><td style="width: 10%;text-align:right;" title="Meeting de Athletismo Madrid (Madrid, Spain)"><span class="mark-date" style="width: 10%;text-align:right;">7/7/2012</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Leroy BURRELL</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=672">Houston</a></td><td style="width: 25%;">9.95 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.2)</span></td><td style="width: 10%;text-align:right;" title=" (Stockholm, Sweden)"><span class="mark-date" style="width: 10%;text-align:right;">7/2/1990</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Leroy BURRELL</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=672">Houston</a></td><td style="width: 25%;">9.95 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.2)</span></td><td style="width: 10%;text-align:right;" title=" (Stockholm, Sweden)"><span class="mark-date" style="width: 10%;text-align:right;">7/2/1990</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113312" target="_blank">Christian COLEMAN</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">9.96</a> <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.4)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/2/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113312" target="_blank">Christian COLEMAN</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">9.96</a> <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.4)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/2/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Joe DELOACH</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=672">Houston</a></td><td style="width: 25%;">9.96 <span class="tooltip" style="font-size: smaller;">W<span class="tooltiptext" style="font-size: smaller;">W = Performance is heavily wind-aided and not valid for qualifying (&gt;4.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 4.9)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">7/16/1988</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Joe DELOACH</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=2&amp;team=672">Houston</a></td><td style="width: 25%;">9.96 <span class="tooltip" style="font-size: smaller;">W<span class="tooltiptext" style="font-size: smaller;">W = Performance is heavily wind-aided and not valid for qualifying (&gt;4.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 4.9)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">7/16/1988</span></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Christian COLEMANJRTennessee9.82📺 qq = Performance occurred during a non-final round.  (w: 1.3)6/7/2017',
#   '(1) Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '9.82📺 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2017'],
#  [],
#  ['(1) Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '9.82📺 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2017'],
#  ['(2) Micah WILLIAMSSOOregon9.86 qq = Performance occurred during a non-final round.  (w: 0.7)5/27/2022',
#   '(2) Micah WILLIAMSSO',
#   '',
#   'Oregon',
#   '9.86 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2022'],
#  [],
#  ['(2) Micah WILLIAMSSO',
#   '',
#   'Oregon',
#   '9.86 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2022'],
#  ['(2) Divine ODUDURUJRTexas Tech9.86  (w: 0.8)6/7/2019',
#   '(2) Divine ODUDURUJR',
#   '',
#   'Texas Tech',
#   '9.86  (w: 0.8)',
#   '6/7/2019'],
#  [],
#  ['(2) Divine ODUDURUJR', '', 'Texas Tech', '9.86  (w: 0.8)', '6/7/2019'],
#  ['(4) Courtney LINDSEYSRTexas Tech9.89  (w: 1.8)6/9/2023',
#   '(4) Courtney LINDSEYSR',
#   '',
#   'Texas Tech',
#   '9.89  (w: 1.8)',
#   '6/9/2023'],
#  [],
#  ['(4) Courtney LINDSEYSR', '', 'Texas Tech', '9.89  (w: 1.8)', '6/9/2023'],
#  ['(4) PJ AUSTINSRFlorida9.89 qq = Performance occurred during a non-final round.  (w: 1.3)6/7/2023',
#   '(4) PJ AUSTINSR',
#   '',
#   'Florida',
#   '9.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2023'],
#  [],
#  ['(4) PJ AUSTINSR',
#   '',
#   'Florida',
#   '9.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2023'],
#  ['(4) Ngoni MAKUSHASRFlorida State9.89  (w: 1.3)6/10/2011',
#   '(4) Ngoni MAKUSHASR',
#   '',
#   'Florida State',
#   '9.89  (w: 1.3)',
#   '6/10/2011'],
#  [],
#  ['(4) Ngoni MAKUSHASR', '', 'Florida State', '9.89  (w: 1.3)', '6/10/2011'],
#  ['(7) Godson OGHENEBRUMESOLSU9.90  (w: 1.8)6/9/2023',
#   '(7) Godson OGHENEBRUMESO',
#   '',
#   'LSU',
#   '9.90  (w: 1.8)',
#   '6/9/2023'],
#  [],
#  ['(7) Godson OGHENEBRUMESO', '', 'LSU', '9.90  (w: 1.8)', '6/9/2023'],
#  ['(7) Benjamin AZAMATISOWest Texas A&M9.90 qq = Performance occurred during a non-final round.  (w: 2.0)3/25/2022',
#   '(7) Benjamin AZAMATISO',
#   '',
#   'West Texas A&M',
#   '9.90 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '3/25/2022'],
#  [],
#  ['(7) Benjamin AZAMATISO',
#   '',
#   'West Texas A&M',
#   '9.90 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '3/25/2022'],
#  ['(7) Trayvon BROMELLBaylor9.90 qq = Performance occurred during a non-final round.  (w: 1.7)6/10/2015',
#   '(7) Trayvon BROMELL',
#   '',
#   'Baylor',
#   '9.90 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '6/10/2015'],
#  [],
#  ['(7) Trayvon BROMELL',
#   '',
#   'Baylor',
#   '9.90 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '6/10/2015'],
#  ['(10) Shaun MASWANGANYIJRHouston9.91  (w: 1.8)6/9/2023',
#   '(10) Shaun MASWANGANYIJR',
#   '',
#   'Houston',
#   '9.91  (w: 1.8)',
#   '6/9/2023'],
#  [],
#  ['(10) Shaun MASWANGANYIJR', '', 'Houston', '9.91  (w: 1.8)', '6/9/2023'],
#  ['(10) Terrence JONESJRTexas Tech9.91📺  (w: 1.0)4/14/2023',
#   '(10) Terrence JONESJR',
#   '',
#   'Texas Tech',
#   '9.91📺  (w: 1.0)',
#   '4/14/2023'],
#  [],
#  ['(10) Terrence JONESJR', '', 'Texas Tech', '9.91📺  (w: 1.0)', '4/14/2023'],
#  ['(10) Davidson EZINWAAzusa Pacific9.91   (w: -2.3)4/11/1992',
#   '(10) Davidson EZINWA',
#   '',
#   'Azusa Pacific',
#   '9.91   (w: -2.3)',
#   '4/11/1992'],
#  [],
#  ['(10) Davidson EZINWA',
#   '',
#   'Azusa Pacific',
#   '9.91   (w: -2.3)',
#   '4/11/1992'],
#  ['(13) Udodi ONWUZURIKESOStanford9.92 qq = Performance occurred during a non-final round.  (w: 1.4)5/26/2023',
#   '(13) Udodi ONWUZURIKESO',
#   '',
#   'Stanford',
#   '9.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/26/2023'],
#  [],
#  ['(13) Udodi ONWUZURIKESO',
#   '',
#   'Stanford',
#   '9.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/26/2023'],
#  ['(13) Ato BOLDONSRUCLA9.92   (w: 0.8)6/1/1996',
#   '(13) Ato BOLDONSR',
#   '',
#   'UCLA',
#   '9.92   (w: 0.8)',
#   '6/1/1996'],
#  [],
#  ['(13) Ato BOLDONSR', '', 'UCLA', '9.92   (w: 0.8)', '6/1/1996'],
#  ['\xa0\xa0\xa0\xa0— Oghenebrume {2}SOLSU9.93 qq = Performance occurred during a non-final round.  (w: 0.8)6/7/2023',
#   '\xa0\xa0\xa0\xa0— Oghenebrume {2}SO',
#   '',
#   'LSU',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/7/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Oghenebrume {2}SO',
#   '',
#   'LSU',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}JRTexas Tech9.93 qq = Performance occurred during a non-final round.  (w: 1.4)5/26/2023',
#   '\xa0\xa0\xa0\xa0— Jones {2}JR',
#   '',
#   'Texas Tech',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/26/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Jones {2}JR',
#   '',
#   'Texas Tech',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/26/2023'],
#  ['\xa0\xa0\xa0\xa0— Williams {2}SOOregon9.93  (w: 0.7)5/13/2022',
#   '\xa0\xa0\xa0\xa0— Williams {2}SO',
#   '',
#   'Oregon',
#   '9.93  (w: 0.7)',
#   '5/13/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Williams {2}SO',
#   '',
#   'Oregon',
#   '9.93  (w: 0.7)',
#   '5/13/2022'],
#  ['(15) Cravon GILLESPIESROregon9.93  (w: 0.8)6/7/2019',
#   '(15) Cravon GILLESPIESR',
#   '',
#   'Oregon',
#   '9.93  (w: 0.8)',
#   '6/7/2019'],
#  [],
#  ['(15) Cravon GILLESPIESR', '', 'Oregon', '9.93  (w: 0.8)', '6/7/2019'],
#  ['(15) Chris BELCHERSRNorth Carolina A&T9.93 qq = Performance occurred during a non-final round.  (w: 1.6)6/7/2017',
#   '(15) Chris BELCHERSR',
#   '',
#   'North Carolina A&T',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '6/7/2017'],
#  [],
#  ['(15) Chris BELCHERSR',
#   '',
#   'North Carolina A&T',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '6/7/2017'],
#  ['(15) Cameron BURRELLJRHouston9.93 qq = Performance occurred during a non-final round.  (w: 0.8)6/7/2017',
#   '(15) Cameron BURRELLJR',
#   '',
#   'Houston',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/7/2017'],
#  [],
#  ['(15) Cameron BURRELLJR',
#   '',
#   'Houston',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/7/2017'],
#  ['(15) Clayton VAUGHNSRUT Arlington9.93  (w: 1.7)5/10/2015',
#   '(15) Clayton VAUGHNSR',
#   '',
#   'UT Arlington',
#   '9.93  (w: 1.7)',
#   '5/10/2015'],
#  [],
#  ['(15) Clayton VAUGHNSR', '', 'UT Arlington', '9.93  (w: 1.7)', '5/10/2015'],
#  ['(15) Richard THOMPSONSRLSU9.93   (w: -0.1)5/18/2008',
#   '(15) Richard THOMPSONSR',
#   '',
#   'LSU',
#   '9.93   (w: -0.1)',
#   '5/18/2008'],
#  [],
#  ['(15) Richard THOMPSONSR', '', 'LSU', '9.93   (w: -0.1)', '5/18/2008'],
#  ['(15) Walter DIXJRFlorida State9.93   (w: 0.0)6/8/2007',
#   '(15) Walter DIXJR',
#   '',
#   'Florida State',
#   '9.93   (w: 0.0)',
#   '6/8/2007'],
#  [],
#  ['(15) Walter DIXJR', '', 'Florida State', '9.93   (w: 0.0)', '6/8/2007'],
#  ['\xa0\xa0\xa0\xa0— Boldon {2}SRUCLA9.93   (w: 1.3)4/21/1996',
#   '\xa0\xa0\xa0\xa0— Boldon {2}SR',
#   '',
#   'UCLA',
#   '9.93   (w: 1.3)',
#   '4/21/1996'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Boldon {2}SR',
#   '',
#   'UCLA',
#   '9.93   (w: 1.3)',
#   '4/21/1996'],
#  ["(21) Jo'Vaughn MARTINSOFlorida State9.94  (w: 1.6)4/16/2021",
#   "(21) Jo'Vaughn MARTINSO",
#   '',
#   'Florida State',
#   '9.94  (w: 1.6)',
#   '4/16/2021'],
#  [],
#  ["(21) Jo'Vaughn MARTINSO",
#   '',
#   'Florida State',
#   '9.94  (w: 1.6)',
#   '4/16/2021'],
#  ['\xa0\xa0\xa0\xa0— Oduduru {2}JRTexas Tech9.94  (w: 0.8)4/20/2019',
#   '\xa0\xa0\xa0\xa0— Oduduru {2}JR',
#   '',
#   'Texas Tech',
#   '9.94  (w: 0.8)',
#   '4/20/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Oduduru {2}JR',
#   '',
#   'Texas Tech',
#   '9.94  (w: 0.8)',
#   '4/20/2019'],
#  ['(22) Favour ASHESOAuburn9.96 qq = Performance occurred during a non-final round.  (w: 1.3)6/7/2023',
#   '(22) Favour ASHESO',
#   '',
#   'Auburn',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2023'],
#  [],
#  ['(22) Favour ASHESO',
#   '',
#   'Auburn',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— AZAMATI-KWAKU {2}SOWest Texas A&M9.96  (w: 1.7)5/5/2022',
#   '\xa0\xa0\xa0\xa0— AZAMATI-KWAKU {2}SO',
#   '',
#   'West Texas A&M',
#   '9.96  (w: 1.7)',
#   '5/5/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— AZAMATI-KWAKU {2}SO',
#   '',
#   'West Texas A&M',
#   '9.96  (w: 1.7)',
#   '5/5/2022'],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JRTennessee9.96 qq = Performance occurred during a non-final round.  (w: 1.7)5/27/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '5/27/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '5/27/2017'],
#  ['(22) Senoj-Jay GIVANSJRTexas9.96 qq = Performance occurred during a non-final round.  (w: 1.6)6/8/2016',
#   '(22) Senoj-Jay GIVANSJR',
#   '',
#   'Texas',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '6/8/2016'],
#  [],
#  ['(22) Senoj-Jay GIVANSJR',
#   '',
#   'Texas',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '6/8/2016'],
#  ['(22) Harry ADAMSJRAuburn9.96 qq = Performance occurred during a non-final round.  (w: 1.4)6/6/2012',
#   '(22) Harry ADAMSJR',
#   '',
#   'Auburn',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '6/6/2012'],
#  [],
#  ['(22) Harry ADAMSJR',
#   '',
#   'Auburn',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '6/6/2012'],
#  ['(22) Travis PADGETTClemson9.96   (w: 1.2)5/10/2008',
#   '(22) Travis PADGETT',
#   '',
#   'Clemson',
#   '9.96   (w: 1.2)',
#   '5/10/2008'],
#  [],
#  ['(22) Travis PADGETT', '', 'Clemson', '9.96   (w: 1.2)', '5/10/2008'],
#  ['\xa0\xa0\xa0\xa0— Ezinwa {2}Azusa Pacific9.96   (w: 0.6)4/18/1992',
#   '\xa0\xa0\xa0\xa0— Ezinwa {2}',
#   '',
#   'Azusa Pacific',
#   '9.96   (w: 0.6)',
#   '4/18/1992'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ezinwa {2}',
#   '',
#   'Azusa Pacific',
#   '9.96   (w: 0.6)',
#   '4/18/1992'],
#  ['Additional All-Conditions Bests'],
#  ['Obadele THOMPSONUTEP9.69 AA = Performance occurred at altitude (>1000 meters above sea level)WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.0)4/13/1996',
#   'Obadele THOMPSON',
#   '',
#   'UTEP',
#   '9.69 AA = Performance occurred at altitude (>1000 meters above sea level)WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.0)',
#   '4/13/1996'],
#  [],
#  ['Obadele THOMPSON',
#   '',
#   'UTEP',
#   '9.69 AA = Performance occurred at altitude (>1000 meters above sea level)WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.0)',
#   '4/13/1996'],
#  ['Andre DE GRASSESouthern California9.75 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)6/12/2015',
#   'Andre DE GRASSE',
#   '',
#   'Southern California',
#   '9.75 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '6/12/2015'],
#  [],
#  ['Andre DE GRASSE',
#   '',
#   'Southern California',
#   '9.75 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '6/12/2015'],
#  ['Churandy MARTINAUTEP9.76 AA = Performance occurred at altitude (>1000 meters above sea level)WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 6.1)5/13/2006',
#   'Churandy MARTINA',
#   '',
#   'UTEP',
#   '9.76 AA = Performance occurred at altitude (>1000 meters above sea level)WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 6.1)',
#   '5/13/2006'],
#  [],
#  ['Churandy MARTINA',
#   '',
#   'UTEP',
#   '9.76 AA = Performance occurred at altitude (>1000 meters above sea level)WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 6.1)',
#   '5/13/2006'],
#  ['Trayvon BROMELLFRBaylor9.77 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)5/18/2014',
#   'Trayvon BROMELLFR',
#   '',
#   'Baylor',
#   '9.77 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)',
#   '5/18/2014'],
#  [],
#  ['Trayvon BROMELLFR',
#   '',
#   'Baylor',
#   '9.77 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)',
#   '5/18/2014'],
#  ['Favour ASHEFRTennessee9.79 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)4/30/2022',
#   'Favour ASHEFR',
#   '',
#   'Tennessee',
#   '9.79 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)',
#   '4/30/2022'],
#  [],
#  ['Favour ASHEFR',
#   '',
#   'Tennessee',
#   '9.79 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)',
#   '4/30/2022'],
#  ['Terrance LAIRDJRLSU9.80 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)5/13/2021',
#   'Terrance LAIRDJR',
#   '',
#   'LSU',
#   '9.80 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '5/13/2021'],
#  [],
#  ['Terrance LAIRDJR',
#   '',
#   'LSU',
#   '9.80 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '5/13/2021'],
#  ['Micah WILLIAMSSOOregon9.83 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)4/16/2022',
#   'Micah WILLIAMSSO',
#   '',
#   'Oregon',
#   '9.83 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '4/16/2022'],
#  [],
#  ['Micah WILLIAMSSO',
#   '',
#   'Oregon',
#   '9.83 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '4/16/2022'],
#  ['Leonard SCOTTFRTennessee9.83 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 7.1)4/9/1999',
#   'Leonard SCOTTFR',
#   '',
#   'Tennessee',
#   '9.83 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 7.1)',
#   '4/9/1999'],
#  [],
#  ['Leonard SCOTTFR',
#   '',
#   'Tennessee',
#   '9.83 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 7.1)',
#   '4/9/1999'],
#  ["Da'Marcus FLEMINGJRLSU9.85 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.5)5/26/2023",
#   "Da'Marcus FLEMINGJR",
#   '',
#   'LSU',
#   '9.85 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.5)',
#   '5/26/2023'],
#  [],
#  ["Da'Marcus FLEMINGJR",
#   '',
#   'LSU',
#   '9.85 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.5)',
#   '5/26/2023'],
#  ['Benjamin AZAMATI-KWAKUSOWest Texas A&M9.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)5/5/2022',
#   'Benjamin AZAMATI-KWAKUSO',
#   '',
#   'West Texas A&M',
#   '9.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)',
#   '5/5/2022'],
#  [],
#  ['Benjamin AZAMATI-KWAKUSO',
#   '',
#   'West Texas A&M',
#   '9.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)',
#   '5/5/2022'],
#  ['Cole BECKSRVirginia Tech9.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.5)5/26/2023',
#   'Cole BECKSR',
#   '',
#   'Virginia Tech',
#   '9.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.5)',
#   '5/26/2023'],
#  [],
#  ['Cole BECKSR',
#   '',
#   'Virginia Tech',
#   '9.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.5)',
#   '5/26/2023'],
#  ['Shaun MASWANGANYIFRHouston9.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)5/14/2021',
#   'Shaun MASWANGANYIFR',
#   '',
#   'Houston',
#   '9.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '5/14/2021'],
#  [],
#  ['Shaun MASWANGANYIFR',
#   '',
#   'Houston',
#   '9.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '5/14/2021'],
#  ['Tevin HESTERJRClemson9.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)5/16/2015',
#   'Tevin HESTERJR',
#   '',
#   'Clemson',
#   '9.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '5/16/2015'],
#  [],
#  ['Tevin HESTERJR',
#   '',
#   'Clemson',
#   '9.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '5/16/2015'],
#  ['Andre DE GRASSEJRSouthern California9.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)4/16/2015',
#   'Andre DE GRASSEJR',
#   '',
#   'Southern California',
#   '9.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)',
#   '4/16/2015'],
#  [],
#  ['Andre DE GRASSEJR',
#   '',
#   'Southern California',
#   '9.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)',
#   '4/16/2015'],
#  ['William SNODDYOklahoma9.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 11.2)4/1/1978',
#   'William SNODDY',
#   '',
#   'Oklahoma',
#   '9.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 11.2)',
#   '4/1/1978'],
#  [],
#  ['William SNODDY',
#   '',
#   'Oklahoma',
#   '9.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 11.2)',
#   '4/1/1978'],
#  ['PJ AUSTINSRFlorida9.88 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.5)5/26/2023',
#   'PJ AUSTINSR',
#   '',
#   'Florida',
#   '9.88 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.5)',
#   '5/26/2023'],
#  [],
#  ['PJ AUSTINSR',
#   '',
#   'Florida',
#   '9.88 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.5)',
#   '5/26/2023'],
#  ['Trayvon BROMELLBaylor9.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)6/12/2015',
#   'Trayvon BROMELL',
#   '',
#   'Baylor',
#   '9.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '6/12/2015'],
#  [],
#  ['Trayvon BROMELL',
#   '',
#   'Baylor',
#   '9.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '6/12/2015'],
#  ['Coby MILLERAuburn9.88 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.5)4/1/2000',
#   'Coby MILLER',
#   '',
#   'Auburn',
#   '9.88 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.5)',
#   '4/1/2000'],
#  [],
#  ['Coby MILLER',
#   '',
#   'Auburn',
#   '9.88 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.5)',
#   '4/1/2000'],
#  ['James SANFORDSouthern California9.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)5/3/1980',
#   'James SANFORD',
#   '',
#   'Southern California',
#   '9.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)',
#   '5/3/1980'],
#  [],
#  ['James SANFORD',
#   '',
#   'Southern California',
#   '9.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)',
#   '5/3/1980'],
#  ['Charles SILMONSRTCU9.89📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)6/7/2013',
#   'Charles SILMONSR',
#   '',
#   'TCU',
#   '9.89📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '6/7/2013'],
#  [],
#  ['Charles SILMONSR',
#   '',
#   'TCU',
#   '9.89📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '6/7/2013'],
#  ['Toby MAKOYAWOFRBoston University9.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.6)3/26/2022',
#   'Toby MAKOYAWOFR',
#   '',
#   'Boston University',
#   '9.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.6)',
#   '3/26/2022'],
#  [],
#  ['Toby MAKOYAWOFR',
#   '',
#   'Boston University',
#   '9.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.6)',
#   '3/26/2022'],
#  ['Cameron BURRELLJRHouston9.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.5)5/27/2017',
#   'Cameron BURRELLJR',
#   '',
#   'Houston',
#   '9.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.5)',
#   '5/27/2017'],
#  [],
#  ['Cameron BURRELLJR',
#   '',
#   'Houston',
#   '9.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.5)',
#   '5/27/2017'],
#  ['Jarrion LAWSONArkansas9.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)6/12/2015',
#   'Jarrion LAWSON',
#   '',
#   'Arkansas',
#   '9.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '6/12/2015'],
#  [],
#  ['Jarrion LAWSON',
#   '',
#   'Arkansas',
#   '9.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '6/12/2015'],
#  ['Trayvon BROMELLSOBaylor9.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.3)3/28/2015',
#   'Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.3)',
#   '3/28/2015'],
#  [],
#  ['Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.3)',
#   '3/28/2015'],
#  ['Senoj-Jay GIVANSFRTexas9.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)5/18/2014',
#   'Senoj-Jay GIVANSFR',
#   '',
#   'Texas',
#   '9.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)',
#   '5/18/2014'],
#  [],
#  ['Senoj-Jay GIVANSFR',
#   '',
#   'Texas',
#   '9.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)',
#   '5/18/2014'],
#  ['Teddy WILLIAMSUTSA9.90 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 4/11/2009',
#   'Teddy WILLIAMS',
#   '',
#   'UTSA',
#   '9.90 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/11/2009'],
#  [],
#  ['Teddy WILLIAMS',
#   '',
#   'UTSA',
#   '9.90 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/11/2009'],
#  ['Trayvon BROMELLSOBaylor9.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)5/17/2015',
#   'Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)',
#   '5/17/2015'],
#  [],
#  ['Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)',
#   '5/17/2015'],
#  ['John TEETERSSOOklahoma State9.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)5/18/2014',
#   'John TEETERSSO',
#   '',
#   'Oklahoma State',
#   '9.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)',
#   '5/18/2014'],
#  [],
#  ['John TEETERSSO',
#   '',
#   'Oklahoma State',
#   '9.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)',
#   '5/18/2014'],
#  ['Dentarius LOCKEJRFlorida State9.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)6/7/2013',
#   'Dentarius LOCKEJR',
#   '',
#   'Florida State',
#   '9.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '6/7/2013'],
#  [],
#  ['Dentarius LOCKEJR',
#   '',
#   'Florida State',
#   '9.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '6/7/2013'],
#  ['Raymond STEWARTSRTCU9.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.9)4/22/1989',
#   'Raymond STEWARTSR',
#   '',
#   'TCU',
#   '9.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.9)',
#   '4/22/1989'],
#  [],
#  ['Raymond STEWARTSR',
#   '',
#   'TCU',
#   '9.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.9)',
#   '4/22/1989'],
#  ['Favour ASHESOAuburn9.92 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.4)5/26/2023',
#   'Favour ASHESO',
#   '',
#   'Auburn',
#   '9.92 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.4)',
#   '5/26/2023'],
#  [],
#  ['Favour ASHESO',
#   '',
#   'Auburn',
#   '9.92 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.4)',
#   '5/26/2023'],
#  ['J.T SMITHSRTexas A&M-Commerce9.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.1)5/4/2023',
#   'J.T SMITHSR',
#   '',
#   'Texas A&M-Commerce',
#   '9.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.1)',
#   '5/4/2023'],
#  [],
#  ['J.T SMITHSR',
#   '',
#   'Texas A&M-Commerce',
#   '9.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.1)',
#   '5/4/2023'],
#  ['Trayvon BROMELLFRBaylor9.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)6/11/2014',
#   'Trayvon BROMELLFR',
#   '',
#   'Baylor',
#   '9.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '6/11/2014'],
#  [],
#  ['Trayvon BROMELLFR',
#   '',
#   'Baylor',
#   '9.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '6/11/2014'],
#  ['Charles SILMONSRTCU9.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)6/5/2013',
#   'Charles SILMONSR',
#   '',
#   'TCU',
#   '9.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)',
#   '6/5/2013'],
#  [],
#  ['Charles SILMONSR',
#   '',
#   'TCU',
#   '9.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)',
#   '6/5/2013'],
#  ['Micaiah HARRISSRTexas9.93 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)5/13/2022',
#   'Micaiah HARRISSR',
#   '',
#   'Texas',
#   '9.93 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '5/13/2022'],
#  [],
#  ['Micaiah HARRISSR',
#   '',
#   'Texas',
#   '9.93 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '5/13/2022'],
#  ['Christian COLEMANJRTennessee9.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)4/29/2017',
#   'Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '9.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '4/29/2017'],
#  [],
#  ['Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '9.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '4/29/2017'],
#  ['Trayvon BROMELLSOBaylor9.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)5/29/2015',
#   'Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)',
#   '5/29/2015'],
#  [],
#  ['Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)',
#   '5/29/2015'],
#  ['Godson OGHENEBRUMESOLSU9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)5/26/2023',
#   'Godson OGHENEBRUMESO',
#   '',
#   'LSU',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '5/26/2023'],
#  [],
#  ['Godson OGHENEBRUMESO',
#   '',
#   'LSU',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '5/26/2023'],
#  ['Ismael  KONESONew Orleans9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)5/6/2022',
#   'Ismael  KONESO',
#   '',
#   'New Orleans',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '5/6/2022'],
#  [],
#  ['Ismael  KONESO',
#   '',
#   'New Orleans',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '5/6/2022'],
#  ['Damarcus SIMPSONJROregon9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)5/27/2017',
#   'Damarcus SIMPSONJR',
#   '',
#   'Oregon',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)',
#   '5/27/2017'],
#  [],
#  ['Damarcus SIMPSONJR',
#   '',
#   'Oregon',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)',
#   '5/27/2017'],
#  ['Trayvon BROMELLSOBaylor9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)5/28/2015',
#   'Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)',
#   '5/28/2015'],
#  [],
#  ['Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)',
#   '5/28/2015'],
#  ['Charles SILMONTCU9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)3/30/2013',
#   'Charles SILMON',
#   '',
#   'TCU',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)',
#   '3/30/2013'],
#  [],
#  ['Charles SILMON',
#   '',
#   'TCU',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)',
#   '3/30/2013'],
#  ['Leroy BURRELLSRHouston9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)6/2/1990',
#   'Leroy BURRELLSR',
#   '',
#   'Houston',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)',
#   '6/2/1990'],
#  [],
#  ['Leroy BURRELLSR',
#   '',
#   'Houston',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)',
#   '6/2/1990'],
#  ['Leroy BURRELLSRHouston9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)5/19/1990',
#   'Leroy BURRELLSR',
#   '',
#   'Houston',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '5/19/1990'],
#  [],
#  ['Leroy BURRELLSR',
#   '',
#   'Houston',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '5/19/1990'],
#  ['Mario BURKESRHouston9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)5/12/2019',
#   'Mario BURKESR',
#   '',
#   'Houston',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '5/12/2019'],
#  [],
#  ['Mario BURKESR',
#   '',
#   'Houston',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '5/12/2019'],
#  ['Cameron BURRELLJRHouston9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)5/27/2017',
#   'Cameron BURRELLJR',
#   '',
#   'Houston',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)',
#   '5/27/2017'],
#  [],
#  ['Cameron BURRELLJR',
#   '',
#   'Houston',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)',
#   '5/27/2017'],
#  ['Ronnie BAKERSRTCU9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)3/18/2016',
#   'Ronnie BAKERSR',
#   '',
#   'TCU',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '3/18/2016'],
#  [],
#  ['Ronnie BAKERSR',
#   '',
#   'TCU',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '3/18/2016'],
#  ['John TEETERSJROklahoma State9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)5/28/2015',
#   'John TEETERSJR',
#   '',
#   'Oklahoma State',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)',
#   '5/28/2015'],
#  [],
#  ['John TEETERSJR',
#   '',
#   'Oklahoma State',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)',
#   '5/28/2015'],
#  ['Justin WALKERSRNorthwestern State9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)5/11/2014',
#   'Justin WALKERSR',
#   '',
#   'Northwestern State',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '5/11/2014'],
#  [],
#  ['Justin WALKERSR',
#   '',
#   'Northwestern State',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '5/11/2014'],
#  ['Brandon HICKLINSRLSU9.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.4)5/26/2023',
#   'Brandon HICKLINSR',
#   '',
#   'LSU',
#   '9.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.4)',
#   '5/26/2023'],
#  [],
#  ['Brandon HICKLINSR',
#   '',
#   'LSU',
#   '9.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.4)',
#   '5/26/2023'],
#  ['Shaun MASWANGANYIJRHouston9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)5/12/2023',
#   'Shaun MASWANGANYIJR',
#   '',
#   'Houston',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)',
#   '5/12/2023'],
#  [],
#  ['Shaun MASWANGANYIJR',
#   '',
#   'Houston',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)',
#   '5/12/2023'],
#  ['Micah WILLIAMSSOOregon9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.1)4/16/2022',
#   'Micah WILLIAMSSO',
#   '',
#   'Oregon',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.1)',
#   '4/16/2022'],
#  [],
#  ['Micah WILLIAMSSO',
#   '',
#   'Oregon',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.1)',
#   '4/16/2022'],
#  ['Bryan HENDERSONSRSam Houston State9.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.1)5/16/2021',
#   'Bryan HENDERSONSR',
#   '',
#   'Sam Houston State',
#   '9.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.1)',
#   '5/16/2021'],
#  [],
#  ['Bryan HENDERSONSR',
#   '',
#   'Sam Houston State',
#   '9.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.1)',
#   '5/16/2021'],
#  ['Divine ODUDURUJRTexas Tech9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)6/5/2019',
#   'Divine ODUDURUJR',
#   '',
#   'Texas Tech',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)',
#   '6/5/2019'],
#  [],
#  ['Divine ODUDURUJR',
#   '',
#   'Texas Tech',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)',
#   '6/5/2019'],
#  ['Abdul Hakim SANI BROWNSOFlorida9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)6/5/2019',
#   'Abdul Hakim SANI BROWNSO',
#   '',
#   'Florida',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)',
#   '6/5/2019'],
#  [],
#  ['Abdul Hakim SANI BROWNSO',
#   '',
#   'Florida',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)',
#   '6/5/2019'],
#  ['Kenzo COTTONJRArkansas9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)5/27/2017',
#   'Kenzo COTTONJR',
#   '',
#   'Arkansas',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)',
#   '5/27/2017'],
#  [],
#  ['Kenzo COTTONJR',
#   '',
#   'Arkansas',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)',
#   '5/27/2017'],
#  ['Bryce ROBINSONJRTulsa9.96 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.7)4/30/2015',
#   'Bryce ROBINSONJR',
#   '',
#   'Tulsa',
#   '9.96 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.7)',
#   '4/30/2015'],
#  [],
#  ['Bryce ROBINSONJR',
#   '',
#   'Tulsa',
#   '9.96 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.7)',
#   '4/30/2015'],
#  ['BeeJay LEESRSouthern California9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)4/16/2015',
#   'BeeJay LEESR',
#   '',
#   'Southern California',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)',
#   '4/16/2015'],
#  [],
#  ['BeeJay LEESR',
#   '',
#   'Southern California',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)',
#   '4/16/2015'],
#  ['Isiah YOUNGSROle Miss9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)6/7/2013',
#   'Isiah YOUNGSR',
#   '',
#   'Ole Miss',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '6/7/2013'],
#  [],
#  ['Isiah YOUNGSR',
#   '',
#   'Ole Miss',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '6/7/2013'],
#  ['Jeff DEMPSFlorida9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)6/11/2010',
#   'Jeff DEMPS',
#   '',
#   'Florida',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '6/11/2010'],
#  [],
#  ['Jeff DEMPS',
#   '',
#   'Florida',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '6/11/2010'],
#  ['Demi OMOLEWisconsin9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.9)5/26/2006',
#   'Demi OMOLE',
#   '',
#   'Wisconsin',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.9)',
#   '5/26/2006'],
#  [],
#  ['Demi OMOLE',
#   '',
#   'Wisconsin',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.9)',
#   '5/26/2006'],
#  ['Olan COLEMANTarleton State9.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.2)5/3/2003',
#   'Olan COLEMAN',
#   '',
#   'Tarleton State',
#   '9.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.2)',
#   '5/3/2003'],
#  [],
#  ['Olan COLEMAN',
#   '',
#   'Tarleton State',
#   '9.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.2)',
#   '5/3/2003'],
#  ['Additional Out-of-Season Bests'],
#  ['Trayvon BROMELLSOBaylor9.84 qq = Performance occurred during a non-final round.  (w: 1.3)6/25/2015',
#   'Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.84 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/25/2015'],
#  [],
#  ['Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.84 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/25/2015'],
#  ['Richard THOMPSONSRLSU9.89   (w: 0.0)8/16/2008',
#   'Richard THOMPSONSR',
#   '',
#   'LSU',
#   '9.89   (w: 0.0)',
#   '8/16/2008'],
#  [],
#  ['Richard THOMPSONSR', '', 'LSU', '9.89   (w: 0.0)', '8/16/2008'],
#  ['Travis PADGETTSRClemson9.89 qq = Performance occurred during a non-final round.  (w: 1.6)6/28/2008',
#   'Travis PADGETTSR',
#   '',
#   'Clemson',
#   '9.89 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '6/28/2008'],
#  [],
#  ['Travis PADGETTSR',
#   '',
#   'Clemson',
#   '9.89 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '6/28/2008'],
#  ['Micah WILLIAMSSOOregon9.90   (w: 1.8)6/24/2022',
#   'Micah WILLIAMSSO',
#   '',
#   'Oregon',
#   '9.90   (w: 1.8)',
#   '6/24/2022'],
#  [],
#  ['Micah WILLIAMSSO', '', 'Oregon', '9.90   (w: 1.8)', '6/24/2022'],
#  ['Ato BOLDONSRUCLA9.90   (w: 0.7)7/27/1996',
#   'Ato BOLDONSR',
#   '',
#   'UCLA',
#   '9.90   (w: 0.7)',
#   '7/27/1996'],
#  [],
#  ['Ato BOLDONSR', '', 'UCLA', '9.90   (w: 0.7)', '7/27/1996'],
#  ['Micah WILLIAMSFROregon9.91  (w: 0.8)6/20/2021',
#   'Micah WILLIAMSFR',
#   '',
#   'Oregon',
#   '9.91  (w: 0.8)',
#   '6/20/2021'],
#  [],
#  ['Micah WILLIAMSFR', '', 'Oregon', '9.91  (w: 0.8)', '6/20/2021'],
#  ['Trayvon BROMELLSOBaylor9.91 qq = Performance occurred during a non-final round.  (w: 0.5)8/22/2015',
#   'Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.91 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '8/22/2015'],
#  [],
#  ['Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.91 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '8/22/2015'],
#  ['Walter DIXSRFlorida State9.91   (w: 0.0)8/16/2008',
#   'Walter DIXSR',
#   '',
#   'Florida State',
#   '9.91   (w: 0.0)',
#   '8/16/2008'],
#  [],
#  ['Walter DIXSR', '', 'Florida State', '9.91   (w: 0.0)', '8/16/2008'],
#  ['Andre DE GRASSEJRSouthern California9.92   (w: -0.5)8/23/2015',
#   'Andre DE GRASSEJR',
#   '',
#   'Southern California',
#   '9.92   (w: -0.5)',
#   '8/23/2015'],
#  [],
#  ['Andre DE GRASSEJR',
#   '',
#   'Southern California',
#   '9.92   (w: -0.5)',
#   '8/23/2015'],
#  ['Trayvon BROMELLSOBaylor9.92   (w: -0.5)8/23/2015',
#   'Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.92   (w: -0.5)',
#   '8/23/2015'],
#  [],
#  ['Trayvon BROMELLSO', '', 'Baylor', '9.92   (w: -0.5)', '8/23/2015'],
#  ['Walter DIXFlorida State9.92   (w: 0.2)9/2/2008',
#   'Walter DIX',
#   '',
#   'Florida State',
#   '9.92   (w: 0.2)',
#   '9/2/2008'],
#  [],
#  ['Walter DIX', '', 'Florida State', '9.92   (w: 0.2)', '9/2/2008'],
#  ['Cameron BURRELLSRHouston9.93 qq = Performance occurred during a non-final round.  (w: 1.4)6/21/2018',
#   'Cameron BURRELLSR',
#   '',
#   'Houston',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '6/21/2018'],
#  [],
#  ['Cameron BURRELLSR',
#   '',
#   'Houston',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '6/21/2018'],
#  ['Christian COLEMANJRTennessee9.93 qq = Performance occurred during a non-final round.  (w: 0.2)6/22/2017',
#   'Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '6/22/2017'],
#  [],
#  ['Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '6/22/2017'],
#  ['Christian COLEMANJRTennessee9.93 qq = Performance occurred during a non-final round.  (w: 0.2)6/22/2017',
#   'Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '6/22/2017'],
#  [],
#  ['Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '6/22/2017'],
#  ['Richard THOMPSONSRLSU9.93 qq = Performance occurred during a non-final round.  (w: 0.3)8/16/2008',
#   'Richard THOMPSONSR',
#   '',
#   'LSU',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.3)',
#   '8/16/2008'],
#  [],
#  ['Richard THOMPSONSR',
#   '',
#   'LSU',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.3)',
#   '8/16/2008'],
#  ['Ato BOLDONSRUCLA9.93 qq = Performance occurred during a non-final round.  (w: -0.6)7/27/1996',
#   'Ato BOLDONSR',
#   '',
#   'UCLA',
#   '9.93 qq = Performance occurred during a non-final round.  (w: -0.6)',
#   '7/27/1996'],
#  [],
#  ['Ato BOLDONSR',
#   '',
#   'UCLA',
#   '9.93 qq = Performance occurred during a non-final round.  (w: -0.6)',
#   '7/27/1996'],
#  ['Calvin SMITHAlabama9.93 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.4)7/3/1983',
#   'Calvin SMITH',
#   '',
#   'Alabama',
#   '9.93 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.4)',
#   '7/3/1983'],
#  [],
#  ['Calvin SMITH',
#   '',
#   'Alabama',
#   '9.93 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.4)',
#   '7/3/1983'],
#  ['Micah WILLIAMSSOOregon9.94 qq = Performance occurred during a non-final round.  (w: 1.5)6/24/2022',
#   'Micah WILLIAMSSO',
#   '',
#   'Oregon',
#   '9.94 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '6/24/2022'],
#  [],
#  ['Micah WILLIAMSSO',
#   '',
#   'Oregon',
#   '9.94 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '6/24/2022'],
#  ['Christian COLEMANJRTennessee9.94   (w: -0.8)8/5/2017',
#   'Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '9.94   (w: -0.8)',
#   '8/5/2017'],
#  [],
#  ['Christian COLEMANJR', '', 'Tennessee', '9.94   (w: -0.8)', '8/5/2017'],
#  ['Ato BOLDONSRUCLA9.94   (w: -0.4)7/3/1996',
#   'Ato BOLDONSR',
#   '',
#   'UCLA',
#   '9.94   (w: -0.4)',
#   '7/3/1996'],
#  [],
#  ['Ato BOLDONSR', '', 'UCLA', '9.94   (w: -0.4)', '7/3/1996'],
#  ['Leroy BURRELLJRHouston9.94   (w: 0.8)6/16/1989',
#   'Leroy BURRELLJR',
#   '',
#   'Houston',
#   '9.94   (w: 0.8)',
#   '6/16/1989'],
#  [],
#  ['Leroy BURRELLJR', '', 'Houston', '9.94   (w: 0.8)', '6/16/1989'],
#  ['Christian COLEMANSOTennessee9.95 qq = Performance occurred during a non-final round.  (w: 1.7)7/3/2016',
#   'Christian COLEMANSO',
#   '',
#   'Tennessee',
#   '9.95 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '7/3/2016'],
#  [],
#  ['Christian COLEMANSO',
#   '',
#   'Tennessee',
#   '9.95 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '7/3/2016'],
#  ['Andre DE GRASSEJRSouthern California9.95   (w: 1.5)7/3/2015',
#   'Andre DE GRASSEJR',
#   '',
#   'Southern California',
#   '9.95   (w: 1.5)',
#   '7/3/2015'],
#  [],
#  ['Andre DE GRASSEJR',
#   '',
#   'Southern California',
#   '9.95   (w: 1.5)',
#   '7/3/2015'],
#  ['Kemar HYMANSRFlorida State9.95 qq = Performance occurred during a non-final round.  (w: 1.8)7/7/2012',
#   'Kemar HYMANSR',
#   '',
#   'Florida State',
#   '9.95 qq = Performance occurred during a non-final round.  (w: 1.8)',
#   '7/7/2012'],
#  [],
#  ['Kemar HYMANSR',
#   '',
#   'Florida State',
#   '9.95 qq = Performance occurred during a non-final round.  (w: 1.8)',
#   '7/7/2012'],
#  ['Walter DIXSRFlorida State9.95 qq = Performance occurred during a non-final round.  (w: -0.1)8/16/2008',
#   'Walter DIXSR',
#   '',
#   'Florida State',
#   '9.95 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '8/16/2008'],
#  [],
#  ['Walter DIXSR',
#   '',
#   'Florida State',
#   '9.95 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '8/16/2008'],
#  ['Ato BOLDONSRUCLA9.95 qq = Performance occurred during a non-final round.  (w: -0.3)7/26/1996',
#   'Ato BOLDONSR',
#   '',
#   'UCLA',
#   '9.95 qq = Performance occurred during a non-final round.  (w: -0.3)',
#   '7/26/1996'],
#  [],
#  ['Ato BOLDONSR',
#   '',
#   'UCLA',
#   '9.95 qq = Performance occurred during a non-final round.  (w: -0.3)',
#   '7/26/1996'],
#  ['Frank FREDERICKSSRBYU9.95   (w: 1.2)8/25/1991',
#   'Frank FREDERICKSSR',
#   '',
#   'BYU',
#   '9.95   (w: 1.2)',
#   '8/25/1991'],
#  [],
#  ['Frank FREDERICKSSR', '', 'BYU', '9.95   (w: 1.2)', '8/25/1991'],
#  ['Raymond EKEVWOJRFlorida9.96   (w: 1.6)8/27/2019',
#   'Raymond EKEVWOJR',
#   '',
#   'Florida',
#   '9.96   (w: 1.6)',
#   '8/27/2019'],
#  [],
#  ['Raymond EKEVWOJR', '', 'Florida', '9.96   (w: 1.6)', '8/27/2019'],
#  ['Andre DE GRASSEJRSouthern California9.96 qq = Performance occurred during a non-final round.  (w: -0.4)8/23/2015',
#   'Andre DE GRASSEJR',
#   '',
#   'Southern California',
#   '9.96 qq = Performance occurred during a non-final round.  (w: -0.4)',
#   '8/23/2015'],
#  [],
#  ['Andre DE GRASSEJR',
#   '',
#   'Southern California',
#   '9.96 qq = Performance occurred during a non-final round.  (w: -0.4)',
#   '8/23/2015'],
#  ['Trayvon BROMELLSOBaylor9.96   (w: 0.0)6/26/2015',
#   'Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.96   (w: 0.0)',
#   '6/26/2015'],
#  [],
#  ['Trayvon BROMELLSO', '', 'Baylor', '9.96   (w: 0.0)', '6/26/2015'],
#  ['Quentin BUTLERSRUT Arlington9.96 qq = Performance occurred during a non-final round.  (w: 1.3)6/25/2015',
#   'Quentin BUTLERSR',
#   '',
#   'UT Arlington',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/25/2015'],
#  [],
#  ['Quentin BUTLERSR',
#   '',
#   'UT Arlington',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/25/2015'],
#  ['Dentarius LOCKEJRFlorida State9.96   (w: -0.4)7/19/2013',
#   'Dentarius LOCKEJR',
#   '',
#   'Florida State',
#   '9.96   (w: -0.4)',
#   '7/19/2013'],
#  [],
#  ['Dentarius LOCKEJR', '', 'Florida State', '9.96   (w: -0.4)', '7/19/2013'],
#  ['Walter DIXSRFlorida State9.96 qq = Performance occurred during a non-final round.  (w: 1.7)6/28/2008',
#   'Walter DIXSR',
#   '',
#   'Florida State',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '6/28/2008'],
#  [],
#  ['Walter DIXSR',
#   '',
#   'Florida State',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '6/28/2008'],
#  ['Leroy BURRELLHouston9.96   (w: 0.7)6/29/1990',
#   'Leroy BURRELL',
#   '',
#   'Houston',
#   '9.96   (w: 0.7)',
#   '6/29/1990'],
#  [],
#  ['Leroy BURRELL', '', 'Houston', '9.96   (w: 0.7)', '6/29/1990'],
#  ['Additional Out-of-Season, All-Conditions Bests'],
#  ['Trayvon BROMELLSOBaylor9.76 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.7)6/26/2015',
#   'Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.76 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.7)',
#   '6/26/2015'],
#  [],
#  ['Trayvon BROMELLSO',
#   '',
#   'Baylor',
#   '9.76 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.7)',
#   '6/26/2015'],
#  ['Walter DIXSRFlorida State9.80 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)6/29/2008',
#   'Walter DIXSR',
#   '',
#   'Florida State',
#   '9.80 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)',
#   '6/29/2008'],
#  [],
#  ['Walter DIXSR',
#   '',
#   'Florida State',
#   '9.80 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)',
#   '6/29/2008'],
#  ['Charles SILMONSRTCU9.85 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)6/20/2013',
#   'Charles SILMONSR',
#   '',
#   'TCU',
#   '9.85 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '6/20/2013'],
#  [],
#  ['Charles SILMONSR',
#   '',
#   'TCU',
#   '9.85 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '6/20/2013'],
#  ['Travis PADGETTSRClemson9.85 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)6/29/2008',
#   'Travis PADGETTSR',
#   '',
#   'Clemson',
#   '9.85 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)',
#   '6/29/2008'],
#  [],
#  ['Travis PADGETTSR',
#   '',
#   'Clemson',
#   '9.85 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)',
#   '6/29/2008'],
#  ['Dennis MITCHELLJRFlorida9.86 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.2)7/16/1988',
#   'Dennis MITCHELLJR',
#   '',
#   'Florida',
#   '9.86 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.2)',
#   '7/16/1988'],
#  [],
#  ['Dennis MITCHELLJR',
#   '',
#   'Florida',
#   '9.86 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.2)',
#   '7/16/1988'],
#  ['Frank FREDERICKSSRBYU9.89 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.1)8/24/1991',
#   'Frank FREDERICKSSR',
#   '',
#   'BYU',
#   '9.89 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.1)',
#   '8/24/1991'],
#  [],
#  ['Frank FREDERICKSSR',
#   '',
#   'BYU',
#   '9.89 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.1)',
#   '8/24/1991'],
#  ['Raymond STEWARTSOTCU9.89 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.2)8/9/1987',
#   'Raymond STEWARTSO',
#   '',
#   'TCU',
#   '9.89 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.2)',
#   '8/9/1987'],
#  [],
#  ['Raymond STEWARTSO',
#   '',
#   'TCU',
#   '9.89 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.2)',
#   '8/9/1987'],
#  ['Raymond STEWARTTCU9.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)6/30/1989',
#   'Raymond STEWART',
#   '',
#   'TCU',
#   '9.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)',
#   '6/30/1989'],
#  [],
#  ['Raymond STEWART',
#   '',
#   'TCU',
#   '9.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)',
#   '6/30/1989'],
#  ['Joe DELOACHHouston9.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.2)7/16/1988',
#   'Joe DELOACH',
#   '',
#   'Houston',
#   '9.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.2)',
#   '7/16/1988'],
#  [],
#  ['Joe DELOACH',
#   '',
#   'Houston',
#   '9.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.2)',
#   '7/16/1988'],
#  ['Calvin SMITHAlabama9.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)7/9/1982',
#   'Calvin SMITH',
#   '',
#   'Alabama',
#   '9.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '7/9/1982'],
#  [],
#  ['Calvin SMITH',
#   '',
#   'Alabama',
#   '9.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '7/9/1982'],
#  ['Bob HAYESFlorida A&M9.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.3)10/15/1964\xa0\xa0\xa0\xa0\xa09.9h, officially',
#   'Bob HAYES',
#   '',
#   'Florida A&M',
#   '9.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.3)',
#   '10/15/1964',
#   '\xa0\xa0\xa0\xa0\xa09.9h, officially'],
#  [],
#  ['Bob HAYES',
#   '',
#   'Florida A&M',
#   '9.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.3)',
#   '10/15/1964'],
#  ['\xa0\xa0\xa0\xa0\xa09.9h, officially'],
#  ['Isiah YOUNGSROle Miss9.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)6/20/2013',
#   'Isiah YOUNGSR',
#   '',
#   'Ole Miss',
#   '9.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)',
#   '6/20/2013'],
#  [],
#  ['Isiah YOUNGSR',
#   '',
#   'Ole Miss',
#   '9.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)',
#   '6/20/2013'],
#  ['Walter DIXSRFlorida State9.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)6/29/2008',
#   'Walter DIXSR',
#   '',
#   'Florida State',
#   '9.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '6/29/2008'],
#  [],
#  ['Walter DIXSR',
#   '',
#   'Florida State',
#   '9.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '6/29/2008'],
#  ['Ronnie BAKERJRTCU9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)6/26/2015',
#   'Ronnie BAKERJR',
#   '',
#   'TCU',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)',
#   '6/26/2015'],
#  [],
#  ['Ronnie BAKERJR',
#   '',
#   'TCU',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)',
#   '6/26/2015'],
#  ['BeeJay LEESRSouthern California9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.7)6/26/2015',
#   'BeeJay LEESR',
#   '',
#   'Southern California',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.7)',
#   '6/26/2015'],
#  [],
#  ['BeeJay LEESR',
#   '',
#   'Southern California',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.7)',
#   '6/26/2015'],
#  ['Ronnie BAKERJRTCU9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)6/25/2015',
#   'Ronnie BAKERJR',
#   '',
#   'TCU',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)',
#   '6/25/2015'],
#  [],
#  ['Ronnie BAKERJR',
#   '',
#   'TCU',
#   '9.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)',
#   '6/25/2015'],
#  ['Micah WILLIAMSFROregon9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)6/19/2021',
#   'Micah WILLIAMSFR',
#   '',
#   'Oregon',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '6/19/2021'],
#  [],
#  ['Micah WILLIAMSFR',
#   '',
#   'Oregon',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '6/19/2021'],
#  ['Kemar HYMANSRFlorida State9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)7/7/2012',
#   'Kemar HYMANSR',
#   '',
#   'Florida State',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '7/7/2012'],
#  [],
#  ['Kemar HYMANSR',
#   '',
#   'Florida State',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '7/7/2012'],
#  ['Leroy BURRELLHouston9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)7/2/1990',
#   'Leroy BURRELL',
#   '',
#   'Houston',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '7/2/1990'],
#  [],
#  ['Leroy BURRELL',
#   '',
#   'Houston',
#   '9.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '7/2/1990'],
#  ['Christian COLEMANSOTennessee9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)7/2/2016',
#   'Christian COLEMANSO',
#   '',
#   'Tennessee',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)',
#   '7/2/2016'],
#  [],
#  ['Christian COLEMANSO',
#   '',
#   'Tennessee',
#   '9.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)',
#   '7/2/2016'],
#  ['Joe DELOACHHouston9.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.9)7/16/1988',
#   'Joe DELOACH',
#   '',
#   'Houston',
#   '9.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.9)',
#   '7/16/1988'],
#  [],
#  ['Joe DELOACH',
#   '',
#   'Houston',
#   '9.96 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.9)',
#   '7/16/1988'],
#  ['', '', '', '']]

# %%
rows[100]
# Out:
# ['\xa0\xa0\xa0\xa0— Ezinwa {2}',
#  '',
#  'Azusa Pacific',
#  '9.96   (w: 0.6)',
#  '4/18/1992']

# %%
len(rows)
# Out:
# 457

# %%
RealRows = []

# %%
for i in range(0,101):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [['(1) Christian COLEMANJRTennessee9.82📺 qq = Performance occurred during a non-final round.  (w: 1.3)6/7/2017',
#   '(1) Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '9.82📺 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2017'],
#  ['(1) Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '9.82📺 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2017'],
#  ['(2) Micah WILLIAMSSOOregon9.86 qq = Performance occurred during a non-final round.  (w: 0.7)5/27/2022',
#   '(2) Micah WILLIAMSSO',
#   '',
#   'Oregon',
#   '9.86 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2022'],
#  ['(2) Micah WILLIAMSSO',
#   '',
#   'Oregon',
#   '9.86 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2022'],
#  ['(2) Divine ODUDURUJRTexas Tech9.86  (w: 0.8)6/7/2019',
#   '(2) Divine ODUDURUJR',
#   '',
#   'Texas Tech',
#   '9.86  (w: 0.8)',
#   '6/7/2019'],
#  ['(2) Divine ODUDURUJR', '', 'Texas Tech', '9.86  (w: 0.8)', '6/7/2019'],
#  ['(4) Courtney LINDSEYSRTexas Tech9.89  (w: 1.8)6/9/2023',
#   '(4) Courtney LINDSEYSR',
#   '',
#   'Texas Tech',
#   '9.89  (w: 1.8)',
#   '6/9/2023'],
#  ['(4) Courtney LINDSEYSR', '', 'Texas Tech', '9.89  (w: 1.8)', '6/9/2023'],
#  ['(4) PJ AUSTINSRFlorida9.89 qq = Performance occurred during a non-final round.  (w: 1.3)6/7/2023',
#   '(4) PJ AUSTINSR',
#   '',
#   'Florida',
#   '9.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2023'],
#  ['(4) PJ AUSTINSR',
#   '',
#   'Florida',
#   '9.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2023'],
#  ['(4) Ngoni MAKUSHASRFlorida State9.89  (w: 1.3)6/10/2011',
#   '(4) Ngoni MAKUSHASR',
#   '',
#   'Florida State',
#   '9.89  (w: 1.3)',
#   '6/10/2011'],
#  ['(4) Ngoni MAKUSHASR', '', 'Florida State', '9.89  (w: 1.3)', '6/10/2011'],
#  ['(7) Godson OGHENEBRUMESOLSU9.90  (w: 1.8)6/9/2023',
#   '(7) Godson OGHENEBRUMESO',
#   '',
#   'LSU',
#   '9.90  (w: 1.8)',
#   '6/9/2023'],
#  ['(7) Godson OGHENEBRUMESO', '', 'LSU', '9.90  (w: 1.8)', '6/9/2023'],
#  ['(7) Benjamin AZAMATISOWest Texas A&M9.90 qq = Performance occurred during a non-final round.  (w: 2.0)3/25/2022',
#   '(7) Benjamin AZAMATISO',
#   '',
#   'West Texas A&M',
#   '9.90 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '3/25/2022'],
#  ['(7) Benjamin AZAMATISO',
#   '',
#   'West Texas A&M',
#   '9.90 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '3/25/2022'],
#  ['(7) Trayvon BROMELLBaylor9.90 qq = Performance occurred during a non-final round.  (w: 1.7)6/10/2015',
#   '(7) Trayvon BROMELL',
#   '',
#   'Baylor',
#   '9.90 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '6/10/2015'],
#  ['(7) Trayvon BROMELL',
#   '',
#   'Baylor',
#   '9.90 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '6/10/2015'],
#  ['(10) Shaun MASWANGANYIJRHouston9.91  (w: 1.8)6/9/2023',
#   '(10) Shaun MASWANGANYIJR',
#   '',
#   'Houston',
#   '9.91  (w: 1.8)',
#   '6/9/2023'],
#  ['(10) Shaun MASWANGANYIJR', '', 'Houston', '9.91  (w: 1.8)', '6/9/2023'],
#  ['(10) Terrence JONESJRTexas Tech9.91📺  (w: 1.0)4/14/2023',
#   '(10) Terrence JONESJR',
#   '',
#   'Texas Tech',
#   '9.91📺  (w: 1.0)',
#   '4/14/2023'],
#  ['(10) Terrence JONESJR', '', 'Texas Tech', '9.91📺  (w: 1.0)', '4/14/2023'],
#  ['(10) Davidson EZINWAAzusa Pacific9.91   (w: -2.3)4/11/1992',
#   '(10) Davidson EZINWA',
#   '',
#   'Azusa Pacific',
#   '9.91   (w: -2.3)',
#   '4/11/1992'],
#  ['(10) Davidson EZINWA',
#   '',
#   'Azusa Pacific',
#   '9.91   (w: -2.3)',
#   '4/11/1992'],
#  ['(13) Udodi ONWUZURIKESOStanford9.92 qq = Performance occurred during a non-final round.  (w: 1.4)5/26/2023',
#   '(13) Udodi ONWUZURIKESO',
#   '',
#   'Stanford',
#   '9.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/26/2023'],
#  ['(13) Udodi ONWUZURIKESO',
#   '',
#   'Stanford',
#   '9.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/26/2023'],
#  ['(13) Ato BOLDONSRUCLA9.92   (w: 0.8)6/1/1996',
#   '(13) Ato BOLDONSR',
#   '',
#   'UCLA',
#   '9.92   (w: 0.8)',
#   '6/1/1996'],
#  ['(13) Ato BOLDONSR', '', 'UCLA', '9.92   (w: 0.8)', '6/1/1996'],
#  ['\xa0\xa0\xa0\xa0— Oghenebrume {2}SOLSU9.93 qq = Performance occurred during a non-final round.  (w: 0.8)6/7/2023',
#   '\xa0\xa0\xa0\xa0— Oghenebrume {2}SO',
#   '',
#   'LSU',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Oghenebrume {2}SO',
#   '',
#   'LSU',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}JRTexas Tech9.93 qq = Performance occurred during a non-final round.  (w: 1.4)5/26/2023',
#   '\xa0\xa0\xa0\xa0— Jones {2}JR',
#   '',
#   'Texas Tech',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/26/2023'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}JR',
#   '',
#   'Texas Tech',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/26/2023'],
#  ['\xa0\xa0\xa0\xa0— Williams {2}SOOregon9.93  (w: 0.7)5/13/2022',
#   '\xa0\xa0\xa0\xa0— Williams {2}SO',
#   '',
#   'Oregon',
#   '9.93  (w: 0.7)',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Williams {2}SO',
#   '',
#   'Oregon',
#   '9.93  (w: 0.7)',
#   '5/13/2022'],
#  ['(15) Cravon GILLESPIESROregon9.93  (w: 0.8)6/7/2019',
#   '(15) Cravon GILLESPIESR',
#   '',
#   'Oregon',
#   '9.93  (w: 0.8)',
#   '6/7/2019'],
#  ['(15) Cravon GILLESPIESR', '', 'Oregon', '9.93  (w: 0.8)', '6/7/2019'],
#  ['(15) Chris BELCHERSRNorth Carolina A&T9.93 qq = Performance occurred during a non-final round.  (w: 1.6)6/7/2017',
#   '(15) Chris BELCHERSR',
#   '',
#   'North Carolina A&T',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '6/7/2017'],
#  ['(15) Chris BELCHERSR',
#   '',
#   'North Carolina A&T',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '6/7/2017'],
#  ['(15) Cameron BURRELLJRHouston9.93 qq = Performance occurred during a non-final round.  (w: 0.8)6/7/2017',
#   '(15) Cameron BURRELLJR',
#   '',
#   'Houston',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/7/2017'],
#  ['(15) Cameron BURRELLJR',
#   '',
#   'Houston',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/7/2017'],
#  ['(15) Clayton VAUGHNSRUT Arlington9.93  (w: 1.7)5/10/2015',
#   '(15) Clayton VAUGHNSR',
#   '',
#   'UT Arlington',
#   '9.93  (w: 1.7)',
#   '5/10/2015'],
#  ['(15) Clayton VAUGHNSR', '', 'UT Arlington', '9.93  (w: 1.7)', '5/10/2015'],
#  ['(15) Richard THOMPSONSRLSU9.93   (w: -0.1)5/18/2008',
#   '(15) Richard THOMPSONSR',
#   '',
#   'LSU',
#   '9.93   (w: -0.1)',
#   '5/18/2008'],
#  ['(15) Richard THOMPSONSR', '', 'LSU', '9.93   (w: -0.1)', '5/18/2008'],
#  ['(15) Walter DIXJRFlorida State9.93   (w: 0.0)6/8/2007',
#   '(15) Walter DIXJR',
#   '',
#   'Florida State',
#   '9.93   (w: 0.0)',
#   '6/8/2007'],
#  ['(15) Walter DIXJR', '', 'Florida State', '9.93   (w: 0.0)', '6/8/2007'],
#  ['\xa0\xa0\xa0\xa0— Boldon {2}SRUCLA9.93   (w: 1.3)4/21/1996',
#   '\xa0\xa0\xa0\xa0— Boldon {2}SR',
#   '',
#   'UCLA',
#   '9.93   (w: 1.3)',
#   '4/21/1996'],
#  ['\xa0\xa0\xa0\xa0— Boldon {2}SR',
#   '',
#   'UCLA',
#   '9.93   (w: 1.3)',
#   '4/21/1996'],
#  ["(21) Jo'Vaughn MARTINSOFlorida State9.94  (w: 1.6)4/16/2021",
#   "(21) Jo'Vaughn MARTINSO",
#   '',
#   'Florida State',
#   '9.94  (w: 1.6)',
#   '4/16/2021'],
#  ["(21) Jo'Vaughn MARTINSO",
#   '',
#   'Florida State',
#   '9.94  (w: 1.6)',
#   '4/16/2021'],
#  ['\xa0\xa0\xa0\xa0— Oduduru {2}JRTexas Tech9.94  (w: 0.8)4/20/2019',
#   '\xa0\xa0\xa0\xa0— Oduduru {2}JR',
#   '',
#   'Texas Tech',
#   '9.94  (w: 0.8)',
#   '4/20/2019'],
#  ['\xa0\xa0\xa0\xa0— Oduduru {2}JR',
#   '',
#   'Texas Tech',
#   '9.94  (w: 0.8)',
#   '4/20/2019'],
#  ['(22) Favour ASHESOAuburn9.96 qq = Performance occurred during a non-final round.  (w: 1.3)6/7/2023',
#   '(22) Favour ASHESO',
#   '',
#   'Auburn',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2023'],
#  ['(22) Favour ASHESO',
#   '',
#   'Auburn',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— AZAMATI-KWAKU {2}SOWest Texas A&M9.96  (w: 1.7)5/5/2022',
#   '\xa0\xa0\xa0\xa0— AZAMATI-KWAKU {2}SO',
#   '',
#   'West Texas A&M',
#   '9.96  (w: 1.7)',
#   '5/5/2022'],
#  ['\xa0\xa0\xa0\xa0— AZAMATI-KWAKU {2}SO',
#   '',
#   'West Texas A&M',
#   '9.96  (w: 1.7)',
#   '5/5/2022'],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JRTennessee9.96 qq = Performance occurred during a non-final round.  (w: 1.7)5/27/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '5/27/2017'],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '5/27/2017'],
#  ['(22) Senoj-Jay GIVANSJRTexas9.96 qq = Performance occurred during a non-final round.  (w: 1.6)6/8/2016',
#   '(22) Senoj-Jay GIVANSJR',
#   '',
#   'Texas',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '6/8/2016'],
#  ['(22) Senoj-Jay GIVANSJR',
#   '',
#   'Texas',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '6/8/2016'],
#  ['(22) Harry ADAMSJRAuburn9.96 qq = Performance occurred during a non-final round.  (w: 1.4)6/6/2012',
#   '(22) Harry ADAMSJR',
#   '',
#   'Auburn',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '6/6/2012'],
#  ['(22) Harry ADAMSJR',
#   '',
#   'Auburn',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '6/6/2012'],
#  ['(22) Travis PADGETTClemson9.96   (w: 1.2)5/10/2008',
#   '(22) Travis PADGETT',
#   '',
#   'Clemson',
#   '9.96   (w: 1.2)',
#   '5/10/2008'],
#  ['(22) Travis PADGETT', '', 'Clemson', '9.96   (w: 1.2)', '5/10/2008'],
#  ['\xa0\xa0\xa0\xa0— Ezinwa {2}Azusa Pacific9.96   (w: 0.6)4/18/1992',
#   '\xa0\xa0\xa0\xa0— Ezinwa {2}',
#   '',
#   'Azusa Pacific',
#   '9.96   (w: 0.6)',
#   '4/18/1992'],
#  ['\xa0\xa0\xa0\xa0— Ezinwa {2}',
#   '',
#   'Azusa Pacific',
#   '9.96   (w: 0.6)',
#   '4/18/1992']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Christian COLEMANJRTennessee9.82📺 qq = Performance occurred during a non-final round.  (w: 1.3)6/7/2017',
#   '(1) Christian COLEMANJR',
#   '',
#   'Tennessee',
#   '9.82📺 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2017'],
#  ['(2) Micah WILLIAMSSOOregon9.86 qq = Performance occurred during a non-final round.  (w: 0.7)5/27/2022',
#   '(2) Micah WILLIAMSSO',
#   '',
#   'Oregon',
#   '9.86 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2022'],
#  ['(2) Divine ODUDURUJRTexas Tech9.86  (w: 0.8)6/7/2019',
#   '(2) Divine ODUDURUJR',
#   '',
#   'Texas Tech',
#   '9.86  (w: 0.8)',
#   '6/7/2019'],
#  ['(4) Courtney LINDSEYSRTexas Tech9.89  (w: 1.8)6/9/2023',
#   '(4) Courtney LINDSEYSR',
#   '',
#   'Texas Tech',
#   '9.89  (w: 1.8)',
#   '6/9/2023'],
#  ['(4) PJ AUSTINSRFlorida9.89 qq = Performance occurred during a non-final round.  (w: 1.3)6/7/2023',
#   '(4) PJ AUSTINSR',
#   '',
#   'Florida',
#   '9.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2023'],
#  ['(4) Ngoni MAKUSHASRFlorida State9.89  (w: 1.3)6/10/2011',
#   '(4) Ngoni MAKUSHASR',
#   '',
#   'Florida State',
#   '9.89  (w: 1.3)',
#   '6/10/2011'],
#  ['(7) Godson OGHENEBRUMESOLSU9.90  (w: 1.8)6/9/2023',
#   '(7) Godson OGHENEBRUMESO',
#   '',
#   'LSU',
#   '9.90  (w: 1.8)',
#   '6/9/2023'],
#  ['(7) Benjamin AZAMATISOWest Texas A&M9.90 qq = Performance occurred during a non-final round.  (w: 2.0)3/25/2022',
#   '(7) Benjamin AZAMATISO',
#   '',
#   'West Texas A&M',
#   '9.90 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '3/25/2022'],
#  ['(7) Trayvon BROMELLBaylor9.90 qq = Performance occurred during a non-final round.  (w: 1.7)6/10/2015',
#   '(7) Trayvon BROMELL',
#   '',
#   'Baylor',
#   '9.90 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '6/10/2015'],
#  ['(10) Shaun MASWANGANYIJRHouston9.91  (w: 1.8)6/9/2023',
#   '(10) Shaun MASWANGANYIJR',
#   '',
#   'Houston',
#   '9.91  (w: 1.8)',
#   '6/9/2023'],
#  ['(10) Terrence JONESJRTexas Tech9.91📺  (w: 1.0)4/14/2023',
#   '(10) Terrence JONESJR',
#   '',
#   'Texas Tech',
#   '9.91📺  (w: 1.0)',
#   '4/14/2023'],
#  ['(10) Davidson EZINWAAzusa Pacific9.91   (w: -2.3)4/11/1992',
#   '(10) Davidson EZINWA',
#   '',
#   'Azusa Pacific',
#   '9.91   (w: -2.3)',
#   '4/11/1992'],
#  ['(13) Udodi ONWUZURIKESOStanford9.92 qq = Performance occurred during a non-final round.  (w: 1.4)5/26/2023',
#   '(13) Udodi ONWUZURIKESO',
#   '',
#   'Stanford',
#   '9.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/26/2023'],
#  ['(13) Ato BOLDONSRUCLA9.92   (w: 0.8)6/1/1996',
#   '(13) Ato BOLDONSR',
#   '',
#   'UCLA',
#   '9.92   (w: 0.8)',
#   '6/1/1996'],
#  ['\xa0\xa0\xa0\xa0— Oghenebrume {2}SOLSU9.93 qq = Performance occurred during a non-final round.  (w: 0.8)6/7/2023',
#   '\xa0\xa0\xa0\xa0— Oghenebrume {2}SO',
#   '',
#   'LSU',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}JRTexas Tech9.93 qq = Performance occurred during a non-final round.  (w: 1.4)5/26/2023',
#   '\xa0\xa0\xa0\xa0— Jones {2}JR',
#   '',
#   'Texas Tech',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/26/2023'],
#  ['\xa0\xa0\xa0\xa0— Williams {2}SOOregon9.93  (w: 0.7)5/13/2022',
#   '\xa0\xa0\xa0\xa0— Williams {2}SO',
#   '',
#   'Oregon',
#   '9.93  (w: 0.7)',
#   '5/13/2022'],
#  ['(15) Cravon GILLESPIESROregon9.93  (w: 0.8)6/7/2019',
#   '(15) Cravon GILLESPIESR',
#   '',
#   'Oregon',
#   '9.93  (w: 0.8)',
#   '6/7/2019'],
#  ['(15) Chris BELCHERSRNorth Carolina A&T9.93 qq = Performance occurred during a non-final round.  (w: 1.6)6/7/2017',
#   '(15) Chris BELCHERSR',
#   '',
#   'North Carolina A&T',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '6/7/2017'],
#  ['(15) Cameron BURRELLJRHouston9.93 qq = Performance occurred during a non-final round.  (w: 0.8)6/7/2017',
#   '(15) Cameron BURRELLJR',
#   '',
#   'Houston',
#   '9.93 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/7/2017'],
#  ['(15) Clayton VAUGHNSRUT Arlington9.93  (w: 1.7)5/10/2015',
#   '(15) Clayton VAUGHNSR',
#   '',
#   'UT Arlington',
#   '9.93  (w: 1.7)',
#   '5/10/2015'],
#  ['(15) Richard THOMPSONSRLSU9.93   (w: -0.1)5/18/2008',
#   '(15) Richard THOMPSONSR',
#   '',
#   'LSU',
#   '9.93   (w: -0.1)',
#   '5/18/2008'],
#  ['(15) Walter DIXJRFlorida State9.93   (w: 0.0)6/8/2007',
#   '(15) Walter DIXJR',
#   '',
#   'Florida State',
#   '9.93   (w: 0.0)',
#   '6/8/2007'],
#  ['\xa0\xa0\xa0\xa0— Boldon {2}SRUCLA9.93   (w: 1.3)4/21/1996',
#   '\xa0\xa0\xa0\xa0— Boldon {2}SR',
#   '',
#   'UCLA',
#   '9.93   (w: 1.3)',
#   '4/21/1996'],
#  ["(21) Jo'Vaughn MARTINSOFlorida State9.94  (w: 1.6)4/16/2021",
#   "(21) Jo'Vaughn MARTINSO",
#   '',
#   'Florida State',
#   '9.94  (w: 1.6)',
#   '4/16/2021'],
#  ['\xa0\xa0\xa0\xa0— Oduduru {2}JRTexas Tech9.94  (w: 0.8)4/20/2019',
#   '\xa0\xa0\xa0\xa0— Oduduru {2}JR',
#   '',
#   'Texas Tech',
#   '9.94  (w: 0.8)',
#   '4/20/2019'],
#  ['(22) Favour ASHESOAuburn9.96 qq = Performance occurred during a non-final round.  (w: 1.3)6/7/2023',
#   '(22) Favour ASHESO',
#   '',
#   'Auburn',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— AZAMATI-KWAKU {2}SOWest Texas A&M9.96  (w: 1.7)5/5/2022',
#   '\xa0\xa0\xa0\xa0— AZAMATI-KWAKU {2}SO',
#   '',
#   'West Texas A&M',
#   '9.96  (w: 1.7)',
#   '5/5/2022'],
#  ['\xa0\xa0\xa0\xa0— Coleman {2}JRTennessee9.96 qq = Performance occurred during a non-final round.  (w: 1.7)5/27/2017',
#   '\xa0\xa0\xa0\xa0— Coleman {2}JR',
#   '',
#   'Tennessee',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '5/27/2017'],
#  ['(22) Senoj-Jay GIVANSJRTexas9.96 qq = Performance occurred during a non-final round.  (w: 1.6)6/8/2016',
#   '(22) Senoj-Jay GIVANSJR',
#   '',
#   'Texas',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '6/8/2016'],
#  ['(22) Harry ADAMSJRAuburn9.96 qq = Performance occurred during a non-final round.  (w: 1.4)6/6/2012',
#   '(22) Harry ADAMSJR',
#   '',
#   'Auburn',
#   '9.96 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '6/6/2012'],
#  ['(22) Travis PADGETTClemson9.96   (w: 1.2)5/10/2008',
#   '(22) Travis PADGETT',
#   '',
#   'Clemson',
#   '9.96   (w: 1.2)',
#   '5/10/2008'],
#  ['\xa0\xa0\xa0\xa0— Ezinwa {2}Azusa Pacific9.96   (w: 0.6)4/18/1992',
#   '\xa0\xa0\xa0\xa0— Ezinwa {2}',
#   '',
#   'Azusa Pacific',
#   '9.96   (w: 0.6)',
#   '4/18/1992']]

# %%
RealRealRows[1][4]
# Out:
# '9.86 qq = Performance occurred during a non-final round.  (w: 0.7)'

# %%
len(RealRealRows)
# Out:
# 33

# %%
OfficialTimes = []

# %%
for i in range(0,len(RealRealRows)):
    OfficialTimes.append(RealRealRows[i][4])
OfficialTimes
# Out:
# ['9.82📺 qq = Performance occurred during a non-final round.  (w: 1.3)',
#  '9.86 qq = Performance occurred during a non-final round.  (w: 0.7)',
#  '9.86  (w: 0.8)',
#  '9.89  (w: 1.8)',
#  '9.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#  '9.89  (w: 1.3)',
#  '9.90  (w: 1.8)',
#  '9.90 qq = Performance occurred during a non-final round.  (w: 2.0)',
#  '9.90 qq = Performance occurred during a non-final round.  (w: 1.7)',
#  '9.91  (w: 1.8)',
#  '9.91📺  (w: 1.0)',
#  '9.91   (w: -2.3)',
#  '9.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#  '9.92   (w: 0.8)',
#  '9.93 qq = Performance occurred during a non-final round.  (w: 0.8)',
#  '9.93 qq = Performance occurred during a non-final round.  (w: 1.4)',
#  '9.93  (w: 0.7)',
#  '9.93  (w: 0.8)',
#  '9.93 qq = Performance occurred during a non-final round.  (w: 1.6)',
#  '9.93 qq = Performance occurred during a non-final round.  (w: 0.8)',
#  '9.93  (w: 1.7)',
#  '9.93   (w: -0.1)',
#  '9.93   (w: 0.0)',
#  '9.93   (w: 1.3)',
#  '9.94  (w: 1.6)',
#  '9.94  (w: 0.8)',
#  '9.96 qq = Performance occurred during a non-final round.  (w: 1.3)',
#  '9.96  (w: 1.7)',
#  '9.96 qq = Performance occurred during a non-final round.  (w: 1.7)',
#  '9.96 qq = Performance occurred during a non-final round.  (w: 1.6)',
#  '9.96 qq = Performance occurred during a non-final round.  (w: 1.4)',
#  '9.96   (w: 1.2)',
#  '9.96   (w: 0.6)']

# %%
RealRealRows[0][1]
# Out:
# '(1) Christian COLEMANJR'

# %%
Names = []

for i in range(0,len(RealRealRows)):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Christian COLEMANJR',
#  '(2) Micah WILLIAMSSO',
#  '(2) Divine ODUDURUJR',
#  '(4) Courtney LINDSEYSR',
#  '(4) PJ AUSTINSR',
#  '(4) Ngoni MAKUSHASR',
#  '(7) Godson OGHENEBRUMESO',
#  '(7) Benjamin AZAMATISO',
#  '(7) Trayvon BROMELL',
#  '(10) Shaun MASWANGANYIJR',
#  '(10) Terrence JONESJR',
#  '(10) Davidson EZINWA',
#  '(13) Udodi ONWUZURIKESO',
#  '(13) Ato BOLDONSR',
#  '\xa0\xa0\xa0\xa0— Oghenebrume {2}SO',
#  '\xa0\xa0\xa0\xa0— Jones {2}JR',
#  '\xa0\xa0\xa0\xa0— Williams {2}SO',
#  '(15) Cravon GILLESPIESR',
#  '(15) Chris BELCHERSR',
#  '(15) Cameron BURRELLJR',
#  '(15) Clayton VAUGHNSR',
#  '(15) Richard THOMPSONSR',
#  '(15) Walter DIXJR',
#  '\xa0\xa0\xa0\xa0— Boldon {2}SR',
#  "(21) Jo'Vaughn MARTINSO",
#  '\xa0\xa0\xa0\xa0— Oduduru {2}JR',
#  '(22) Favour ASHESO',
#  '\xa0\xa0\xa0\xa0— AZAMATI-KWAKU {2}SO',
#  '\xa0\xa0\xa0\xa0— Coleman {2}JR',
#  '(22) Senoj-Jay GIVANSJR',
#  '(22) Harry ADAMSJR',
#  '(22) Travis PADGETT',
#  '\xa0\xa0\xa0\xa0— Ezinwa {2}']

# %%
OfficialReGexNames = []

# %%
for i in range(0,len(RealRealRows)):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Christian COLEMANJR',
#  '(2) Micah WILLIAMSSO',
#  '(2) Divine ODUDURUJR',
#  '(4) Courtney LINDSEYSR',
#  '(4) PJ AUSTINSR',
#  '(4) Ngoni MAKUSHASR',
#  '(7) Godson OGHENEBRUMESO',
#  '(7) Benjamin AZAMATISO',
#  '(7) Trayvon BROMELL',
#  '(10) Shaun MASWANGANYIJR',
#  '(10) Terrence JONESJR',
#  '(10) Davidson EZINWA',
#  '(13) Udodi ONWUZURIKESO',
#  '(13) Ato BOLDONSR',
#  '— Oghenebrume {2}SO',
#  '— Jones {2}JR',
#  '— Williams {2}SO',
#  '(15) Cravon GILLESPIESR',
#  '(15) Chris BELCHERSR',
#  '(15) Cameron BURRELLJR',
#  '(15) Clayton VAUGHNSR',
#  '(15) Richard THOMPSONSR',
#  '(15) Walter DIXJR',
#  '— Boldon {2}SR',
#  "(21) Jo'Vaughn MARTINSO",
#  '— Oduduru {2}JR',
#  '(22) Favour ASHESO',
#  '— AZAMATI-KWAKU {2}SO',
#  '— Coleman {2}JR',
#  '(22) Senoj-Jay GIVANSJR',
#  '(22) Harry ADAMSJR',
#  '(22) Travis PADGETT',
#  '— Ezinwa {2}']

# %%
len(OfficialTimes)
# Out:
# 33

# %%
len(OfficialReGexNames)
# Out:
# 33

# %%
type(OfficialTimes)
# Out:
# list

# %%
OfficialTimes[3][:4]
# Out:
# '9.89'

# %%
Times = []

# %%
for i in range(0,len(OfficialTimes)):
    Times.append(OfficialTimes[i][:4])
    
Times
# Out:
# ['9.82',
#  '9.86',
#  '9.86',
#  '9.89',
#  '9.89',
#  '9.89',
#  '9.90',
#  '9.90',
#  '9.90',
#  '9.91',
#  '9.91',
#  '9.91',
#  '9.92',
#  '9.92',
#  '9.93',
#  '9.93',
#  '9.93',
#  '9.93',
#  '9.93',
#  '9.93',
#  '9.93',
#  '9.93',
#  '9.93',
#  '9.93',
#  '9.94',
#  '9.94',
#  '9.96',
#  '9.96',
#  '9.96',
#  '9.96',
#  '9.96',
#  '9.96',
#  '9.96']

# %%
Schools = []

for i in range(0,len(OfficialReGexNames)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Tennessee',
#  'Oregon',
#  'Texas Tech',
#  'Texas Tech',
#  'Florida',
#  'Florida State',
#  'LSU',
#  'West Texas A&M',
#  'Baylor',
#  'Houston',
#  'Texas Tech',
#  'Azusa Pacific',
#  'Stanford',
#  'UCLA',
#  'LSU',
#  'Texas Tech',
#  'Oregon',
#  'Oregon',
#  'North Carolina A&T',
#  'Houston',
#  'UT Arlington',
#  'LSU',
#  'Florida State',
#  'UCLA',
#  'Florida State',
#  'Texas Tech',
#  'Auburn',
#  'West Texas A&M',
#  'Tennessee',
#  'Texas',
#  'Auburn',
#  'Clemson',
#  'Azusa Pacific']

# %%
OfficialReGexNames
# Out:
# ['(1) Christian COLEMANJR',
#  '(2) Micah WILLIAMSSO',
#  '(2) Divine ODUDURUJR',
#  '(4) Courtney LINDSEYSR',
#  '(4) PJ AUSTINSR',
#  '(4) Ngoni MAKUSHASR',
#  '(7) Godson OGHENEBRUMESO',
#  '(7) Benjamin AZAMATISO',
#  '(7) Trayvon BROMELL',
#  '(10) Shaun MASWANGANYIJR',
#  '(10) Terrence JONESJR',
#  '(10) Davidson EZINWA',
#  '(13) Udodi ONWUZURIKESO',
#  '(13) Ato BOLDONSR',
#  '— Oghenebrume {2}SO',
#  '— Jones {2}JR',
#  '— Williams {2}SO',
#  '(15) Cravon GILLESPIESR',
#  '(15) Chris BELCHERSR',
#  '(15) Cameron BURRELLJR',
#  '(15) Clayton VAUGHNSR',
#  '(15) Richard THOMPSONSR',
#  '(15) Walter DIXJR',
#  '— Boldon {2}SR',
#  "(21) Jo'Vaughn MARTINSO",
#  '— Oduduru {2}JR',
#  '(22) Favour ASHESO',
#  '— AZAMATI-KWAKU {2}SO',
#  '— Coleman {2}JR',
#  '(22) Senoj-Jay GIVANSJR',
#  '(22) Harry ADAMSJR',
#  '(22) Travis PADGETT',
#  '— Ezinwa {2}']

# %%
OfficialReGexNames[1][4:]
# Out:
# 'Micah WILLIAMSSO'

# %%
OfficialReGexNames[0]
# Out:
# '(1) Christian COLEMANJR'

# %%
OfficialReGexNames[15][3:]
# Out:
# 'ones {2}JR'

# %%
# Using ord() to get the Unicode code point of a character
#character = 'A'
unicode_code = ord(Coded)

print(f"The Unicode code point of '{Coded}' is {unicode_code}")
# Out:
# The Unicode code point of '—' is 8212

# %%
OfficialReGexNames[15].startswith("—")
# Out:
# True

# %%
CleanedNames = []

# %%
for i in range(0,len(RealRealRows)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Christian COLEMANJR',
#  'Micah WILLIAMSSO',
#  'Divine ODUDURUJR',
#  'Courtney LINDSEYSR',
#  'PJ AUSTINSR',
#  'Ngoni MAKUSHASR',
#  'Godson OGHENEBRUMESO',
#  'Benjamin AZAMATISO',
#  'Trayvon BROMELL',
#  ' Shaun MASWANGANYIJR',
#  ' Terrence JONESJR',
#  ' Davidson EZINWA',
#  ' Udodi ONWUZURIKESO',
#  ' Ato BOLDONSR',
#  'Oghenebrume {2}SO',
#  'Jones {2}JR',
#  'Williams {2}SO',
#  ' Cravon GILLESPIESR',
#  ' Chris BELCHERSR',
#  ' Cameron BURRELLJR',
#  ' Clayton VAUGHNSR',
#  ' Richard THOMPSONSR',
#  ' Walter DIXJR',
#  'Boldon {2}SR',
#  " Jo'Vaughn MARTINSO",
#  'Oduduru {2}JR',
#  ' Favour ASHESO',
#  'AZAMATI-KWAKU {2}SO',
#  'Coleman {2}JR',
#  ' Senoj-Jay GIVANSJR',
#  ' Harry ADAMSJR',
#  ' Travis PADGETT',
#  'Ezinwa {2}']

# %%
CleanedNames2 = []

# %%
for i in range(0,len(RealRealRows)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Christian COLEMANJR',
#  'Micah WILLIAMSSO',
#  'Divine ODUDURUJR',
#  'Courtney LINDSEYSR',
#  'PJ AUSTINSR',
#  'Ngoni MAKUSHASR',
#  'Godson OGHENEBRUMESO',
#  'Benjamin AZAMATISO',
#  'Trayvon BROMELL',
#  'Shaun MASWANGANYIJR',
#  'Terrence JONESJR',
#  'Davidson EZINWA',
#  'Udodi ONWUZURIKESO',
#  'Ato BOLDONSR',
#  'Oghenebrume {2}SO',
#  'Jones {2}JR',
#  'Williams {2}SO',
#  'Cravon GILLESPIESR',
#  'Chris BELCHERSR',
#  'Cameron BURRELLJR',
#  'Clayton VAUGHNSR',
#  'Richard THOMPSONSR',
#  'Walter DIXJR',
#  'Boldon {2}SR',
#  "Jo'Vaughn MARTINSO",
#  'Oduduru {2}JR',
#  'Favour ASHESO',
#  'AZAMATI-KWAKU {2}SO',
#  'Coleman {2}JR',
#  'Senoj-Jay GIVANSJR',
#  'Harry ADAMSJR',
#  'Travis PADGETT',
#  'Ezinwa {2}']

# %%
len(CleanedNames2)
# Out:
# 33

# %%
Mens100mDF = pd.DataFrame({'Names': CleanedNames2, 'Times': Times, 'Schools': Schools})
Mens100mDF.to_csv('Mens100m.csv', index=False)
