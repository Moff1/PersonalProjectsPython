# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc

# %%
Link110mHurdles = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?gender=2&div=20527&top=25&event=14"

# %%
page = requests.get(Link110mHurdles)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6995394" target="_blank">(1) Masai RUSSELL</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77369/4767301" target="_blank">12.36</a><a href="https://twitter.com/LSUTrackField/status/1642249075381657603" target="_blank">📺</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.0)</span></td><td style="width: 10%;text-align:right;" title="95th Clyde Littlefield Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/1/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6995394" target="_blank">(1) Masai RUSSELL</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77369/4767301" target="_blank">12.36</a><a href="https://twitter.com/LSUTrackField/status/1642249075381657603" target="_blank">📺</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.0)</span></td><td style="width: 10%;text-align:right;" title="95th Clyde Littlefield Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/1/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2741604" target="_blank">(2) Brianna ROLLINS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=311">Clemson</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/31188" target="_blank">12.39</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2741604" target="_blank">(2) Brianna ROLLINS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=311">Clemson</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/31188" target="_blank">12.39</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2013</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7511453" target="_blank">(3) Alia ARMSTRONG</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4923398" target="_blank">12.40</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.4)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7511453" target="_blank">(3) Alia ARMSTRONG</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4923398" target="_blank">12.40</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.4)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6548045" target="_blank">(3) Janeek BROWN</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850665" target="_blank">12.40</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6548045" target="_blank">(3) Janeek BROWN</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850665" target="_blank">12.40</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5602993" target="_blank">(3) Jasmine CAMACHO-QUINN</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/56302/3508666" target="_blank">12.40</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.2)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Knoxville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5602993" target="_blank">(3) Jasmine CAMACHO-QUINN</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/56302/3508666" target="_blank">12.40</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.2)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Knoxville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7718451" target="_blank">(6) Ackera NUGENT</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4923398" target="_blank">12.43</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.4)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7718451" target="_blank">(6) Ackera NUGENT</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4923398" target="_blank">12.43</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.4)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6985909" target="_blank">(7) Demisha ROSWELL</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75162/4560542" target="_blank">12.44</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.5)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6985909" target="_blank">(7) Demisha ROSWELL</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75162/4560542" target="_blank">12.44</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.5)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6099525" target="_blank">(7) Tonea MARSHALL</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390/4273635" target="_blank">12.44</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/29/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6099525" target="_blank">(7) Tonea MARSHALL</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390/4273635" target="_blank">12.44</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.8)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/29/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Nugent {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Baylor" class="group-logo-inline" src="/images/logos/rankings-article/baylor.png" title="Baylor"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=101">Baylor</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75162/4560542" target="_blank">12.45</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.5)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Nugent {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Baylor" class="group-logo-inline" src="/images/logos/rankings-article/baylor.png" title="Baylor"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=101">Baylor</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75162/4560542" target="_blank">12.45</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.5)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Russell {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4923398" target="_blank">12.47</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.4)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Russell {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4923398" target="_blank">12.47</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.4)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Rollins {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=311">Clemson</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/31188" target="_blank">12.47</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.2)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/6/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Rollins {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=311">Clemson</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/31188" target="_blank">12.47</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.2)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/6/2013</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Marshall {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276120" target="_blank">12.48</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Marshall {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276120" target="_blank">12.48</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(9) Ginnie POWELL</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=1432">Southern California</a></td><td style="width: 25%;">12.48  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.4)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2006</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(9) Ginnie POWELL</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=1432">Southern California</a></td><td style="width: 25%;">12.48  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.4)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2006</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Russell {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75342/4853618" target="_blank">12.50</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.1)</span></td><td style="width: 10%;text-align:right;" title="Michael Johnson Classic (Waco, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/21/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Russell {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75342/4853618" target="_blank">12.50</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.1)</span></td><td style="width: 10%;text-align:right;" title="Michael Johnson Classic (Waco, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/21/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4513700" target="_blank">(10) Keni HARRISON</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41348" target="_blank">12.50</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.8)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Starkville, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/16/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4513700" target="_blank">(10) Keni HARRISON</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41348" target="_blank">12.50</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.8)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Starkville, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/16/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Nugent {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78407/4880365" target="_blank">12.52</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.2)</span></td><td style="width: 10%;text-align:right;" title="LSU Invitational (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/29/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Nugent {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78407/4880365" target="_blank">12.52</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.2)</span></td><td style="width: 10%;text-align:right;" title="LSU Invitational (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/29/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Marshall {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70259/4263440" target="_blank">12.52</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.6)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Marshall {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70259/4263440" target="_blank">12.52</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.6)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7690421" target="_blank">(11) Chanel BRISSETT</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850665" target="_blank">12.52</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7690421" target="_blank">(11) Chanel BRISSETT</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850665" target="_blank">12.52</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Brown {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850665" target="_blank">12.53</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.1)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/6/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Brown {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850665" target="_blank">12.53</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.1)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/6/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Armstrong {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938114" target="_blank">12.54</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/8/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Armstrong {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938114" target="_blank">12.54</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/8/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6110568" target="_blank">(12) Anna COCKRELL</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276120" target="_blank">12.54</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6110568" target="_blank">(12) Anna COCKRELL</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276120" target="_blank">12.54</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Camacho-Quinn {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57114/3516387" target="_blank">12.54</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Camacho-Quinn {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57114/3516387" target="_blank">12.54</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Nugent {4}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938114" target="_blank">12.55</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.5)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/8/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
# ...
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6548045" target="_blank">Janeek BROWN</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=59">Arkansas</a></td><td style="width: 25%;">12.68 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.5)</span></td><td style="width: 10%;text-align:right;" title="Jamaican (JAAA) Championships (Kingston, Jamaica)"><span class="mark-date" style="width: 10%;text-align:right;">6/23/2019</span></td></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">Additional Out-of-Season, All-Conditions Bests</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2741604" target="_blank">Brianna ROLLINS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=311">Clemson</a></td><td style="width: 25%;">12.30 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.8)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/22/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2741604" target="_blank">Brianna ROLLINS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=311">Clemson</a></td><td style="width: 25%;">12.30 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.8)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/22/2013</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7511453" target="_blank">Alia ARMSTRONG</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=869">LSU</a></td><td style="width: 25%;">12.31 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.5)</span></td><td style="width: 10%;text-align:right;" title="World Athletics Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/24/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7511453" target="_blank">Alia ARMSTRONG</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=869">LSU</a></td><td style="width: 25%;">12.31 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.5)</span></td><td style="width: 10%;text-align:right;" title="World Athletics Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/24/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2741604" target="_blank">Brianna ROLLINS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=311">Clemson</a></td><td style="width: 25%;">12.33 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.3)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/23/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2741604" target="_blank">Brianna ROLLINS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=311">Clemson</a></td><td style="width: 25%;">12.33 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.3)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/23/2013</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4513700" target="_blank">Keni HARRISON</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=770">Kentucky</a></td><td style="width: 25%;">12.46 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.3)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/26/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4513700" target="_blank">Keni HARRISON</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=770">Kentucky</a></td><td style="width: 25%;">12.46 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.3)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/26/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2741604" target="_blank">Brianna ROLLINS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=311">Clemson</a></td><td style="width: 25%;">12.47 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.4)</span></td><td style="width: 10%;text-align:right;" title=" (Lapinlahti, Finland)"><span class="mark-date" style="width: 10%;text-align:right;">7/21/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2741604" target="_blank">Brianna ROLLINS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=311">Clemson</a></td><td style="width: 25%;">12.47 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.4)</span></td><td style="width: 10%;text-align:right;" title=" (Lapinlahti, Finland)"><span class="mark-date" style="width: 10%;text-align:right;">7/21/2013</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3329786" target="_blank">Vashti THOMAS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Academy of Art" class="group-logo-inline" src="/images/logos/rankings-article/academy-of-art.png" title="Academy of Art"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=3">Academy of Art</a></td><td style="width: 25%;">12.63 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.7)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/22/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3329786" target="_blank">Vashti THOMAS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Academy of Art" class="group-logo-inline" src="/images/logos/rankings-article/academy-of-art.png" title="Academy of Art"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=14&amp;team=3">Academy of Art</a></td><td style="width: 25%;">12.63 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.7)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/22/2013</span></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Masai RUSSELLSRKentucky12.36📺  (w: 2.0)4/1/2023',
#   '(1) Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.36📺  (w: 2.0)',
#   '4/1/2023'],
#  [],
#  ['(1) Masai RUSSELLSR', '', 'Kentucky', '12.36📺  (w: 2.0)', '4/1/2023'],
#  ['(2) Brianna ROLLINSJRClemson12.39  (w: 1.7)6/8/2013',
#   '(2) Brianna ROLLINSJR',
#   '',
#   'Clemson',
#   '12.39  (w: 1.7)',
#   '6/8/2013'],
#  [],
#  ['(2) Brianna ROLLINSJR', '', 'Clemson', '12.39  (w: 1.7)', '6/8/2013'],
#  ['(3) Alia ARMSTRONGJRLSU12.40  (w: 0.4)5/13/2023',
#   '(3) Alia ARMSTRONGJR',
#   '',
#   'LSU',
#   '12.40  (w: 0.4)',
#   '5/13/2023'],
#  [],
#  ['(3) Alia ARMSTRONGJR', '', 'LSU', '12.40  (w: 0.4)', '5/13/2023'],
#  ['(3) Janeek BROWNSOArkansas12.40  (w: 0.6)6/8/2019',
#   '(3) Janeek BROWNSO',
#   '',
#   'Arkansas',
#   '12.40  (w: 0.6)',
#   '6/8/2019'],
#  [],
#  ['(3) Janeek BROWNSO', '', 'Arkansas', '12.40  (w: 0.6)', '6/8/2019'],
#  ['(3) Jasmine CAMACHO-QUINNJRKentucky12.40  (w: 1.2)5/13/2018',
#   '(3) Jasmine CAMACHO-QUINNJR',
#   '',
#   'Kentucky',
#   '12.40  (w: 1.2)',
#   '5/13/2018'],
#  [],
#  ['(3) Jasmine CAMACHO-QUINNJR',
#   '',
#   'Kentucky',
#   '12.40  (w: 1.2)',
#   '5/13/2018'],
#  ['(6) Ackera NUGENTJRArkansas12.43  (w: 0.4)5/13/2023',
#   '(6) Ackera NUGENTJR',
#   '',
#   'Arkansas',
#   '12.43  (w: 0.4)',
#   '5/13/2023'],
#  [],
#  ['(6) Ackera NUGENTJR', '', 'Arkansas', '12.43  (w: 0.4)', '5/13/2023'],
#  ['(7) Demisha ROSWELLJRTexas Tech12.44 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)5/13/2022',
#   '(7) Demisha ROSWELLJR',
#   '',
#   'Texas Tech',
#   '12.44 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)',
#   '5/13/2022'],
#  [],
#  ['(7) Demisha ROSWELLJR',
#   '',
#   'Texas Tech',
#   '12.44 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)',
#   '5/13/2022'],
#  ['(7) Tonea MARSHALLSRLSU12.44 qq = Performance occurred during a non-final round.  (w: 0.8)5/29/2021',
#   '(7) Tonea MARSHALLSR',
#   '',
#   'LSU',
#   '12.44 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '5/29/2021'],
#  [],
#  ['(7) Tonea MARSHALLSR',
#   '',
#   'LSU',
#   '12.44 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Nugent {2}FRBaylor12.45 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)5/13/2022',
#   '\xa0\xa0\xa0\xa0— Nugent {2}FR',
#   '',
#   'Baylor',
#   '12.45 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)',
#   '5/13/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Nugent {2}FR',
#   '',
#   'Baylor',
#   '12.45 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Russell {2}SRKentucky12.47  (w: 0.4)5/13/2023',
#   '\xa0\xa0\xa0\xa0— Russell {2}SR',
#   '',
#   'Kentucky',
#   '12.47  (w: 0.4)',
#   '5/13/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Russell {2}SR',
#   '',
#   'Kentucky',
#   '12.47  (w: 0.4)',
#   '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Rollins {2}JRClemson12.47 qq = Performance occurred during a non-final round.  (w: 1.2)6/6/2013',
#   '\xa0\xa0\xa0\xa0— Rollins {2}JR',
#   '',
#   'Clemson',
#   '12.47 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '6/6/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rollins {2}JR',
#   '',
#   'Clemson',
#   '12.47 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '6/6/2013'],
#  ['\xa0\xa0\xa0\xa0— Marshall {2}SRLSU12.48 qq = Performance occurred during a non-final round.  (w: 0.0)6/10/2021',
#   '\xa0\xa0\xa0\xa0— Marshall {2}SR',
#   '',
#   'LSU',
#   '12.48 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/10/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Marshall {2}SR',
#   '',
#   'LSU',
#   '12.48 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/10/2021'],
#  ['(9) Ginnie POWELLSRSouthern California12.48   (w: 0.4)6/9/2006',
#   '(9) Ginnie POWELLSR',
#   '',
#   'Southern California',
#   '12.48   (w: 0.4)',
#   '6/9/2006'],
#  [],
#  ['(9) Ginnie POWELLSR',
#   '',
#   'Southern California',
#   '12.48   (w: 0.4)',
#   '6/9/2006'],
#  ['\xa0\xa0\xa0\xa0— Russell {3}SRKentucky12.50  (w: 1.1)4/21/2023',
#   '\xa0\xa0\xa0\xa0— Russell {3}SR',
#   '',
#   'Kentucky',
#   '12.50  (w: 1.1)',
#   '4/21/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Russell {3}SR',
#   '',
#   'Kentucky',
#   '12.50  (w: 1.1)',
#   '4/21/2023'],
#  ['(10) Keni HARRISONKentucky12.50  (w: 1.8)5/16/2015',
#   '(10) Keni HARRISON',
#   '',
#   'Kentucky',
#   '12.50  (w: 1.8)',
#   '5/16/2015'],
#  [],
#  ['(10) Keni HARRISON', '', 'Kentucky', '12.50  (w: 1.8)', '5/16/2015'],
#  ['\xa0\xa0\xa0\xa0— Nugent {3}JRArkansas12.52  (w: 0.2)4/29/2023',
#   '\xa0\xa0\xa0\xa0— Nugent {3}JR',
#   '',
#   'Arkansas',
#   '12.52  (w: 0.2)',
#   '4/29/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Nugent {3}JR',
#   '',
#   'Arkansas',
#   '12.52  (w: 0.2)',
#   '4/29/2023'],
#  ['\xa0\xa0\xa0\xa0— Marshall {3}SRLSU12.52 qq = Performance occurred during a non-final round.  (w: 1.6)5/13/2021',
#   '\xa0\xa0\xa0\xa0— Marshall {3}SR',
#   '',
#   'LSU',
#   '12.52 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '5/13/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Marshall {3}SR',
#   '',
#   'LSU',
#   '12.52 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '5/13/2021'],
#  ['(11) Chanel BRISSETTSOSouthern California12.52  (w: 0.6)6/8/2019',
#   '(11) Chanel BRISSETTSO',
#   '',
#   'Southern California',
#   '12.52  (w: 0.6)',
#   '6/8/2019'],
#  [],
#  ['(11) Chanel BRISSETTSO',
#   '',
#   'Southern California',
#   '12.52  (w: 0.6)',
#   '6/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Brown {2}SOArkansas12.53 qq = Performance occurred during a non-final round.  (w: 1.1)6/6/2019',
#   '\xa0\xa0\xa0\xa0— Brown {2}SO',
#   '',
#   'Arkansas',
#   '12.53 qq = Performance occurred during a non-final round.  (w: 1.1)',
#   '6/6/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Brown {2}SO',
#   '',
#   'Arkansas',
#   '12.53 qq = Performance occurred during a non-final round.  (w: 1.1)',
#   '6/6/2019'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {2}JRLSU12.54 qq = Performance occurred during a non-final round.  (w: 0.0)6/8/2023',
#   '\xa0\xa0\xa0\xa0— Armstrong {2}JR',
#   '',
#   'LSU',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/8/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Armstrong {2}JR',
#   '',
#   'LSU',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/8/2023'],
#  ['(12) Anna COCKRELLSRSouthern California12.54 qq = Performance occurred during a non-final round.  (w: 0.0)6/10/2021',
#   '(12) Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/10/2021'],
#  [],
#  ['(12) Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/10/2021'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {2}JRKentucky12.54 qq = Performance occurred during a non-final round.  (w: 2.0)6/7/2018',
#   '\xa0\xa0\xa0\xa0— Camacho-Quinn {2}JR',
#   '',
#   'Kentucky',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '6/7/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {2}JR',
#   '',
#   'Kentucky',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Nugent {4}JRArkansas12.55 qq = Performance occurred during a non-final round.  (w: 0.5)6/8/2023',
#   '\xa0\xa0\xa0\xa0— Nugent {4}JR',
#   '',
#   'Arkansas',
#   '12.55 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/8/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Nugent {4}JR',
#   '',
#   'Arkansas',
#   '12.55 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {3}SOLSU12.55 qq = Performance occurred during a non-final round.  (w: 0.2)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Armstrong {3}SO',
#   '',
#   'LSU',
#   '12.55 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '6/9/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Armstrong {3}SO',
#   '',
#   'LSU',
#   '12.55 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Brown {3}SOArkansas12.55  (w: 1.3)5/11/2019',
#   '\xa0\xa0\xa0\xa0— Brown {3}SO',
#   '',
#   'Arkansas',
#   '12.55  (w: 1.3)',
#   '5/11/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Brown {3}SO',
#   '',
#   'Arkansas',
#   '12.55  (w: 1.3)',
#   '5/11/2019'],
#  ['\xa0\xa0\xa0\xa0— Harrison {2}Kentucky12.55  (w: 1.7)6/13/2015',
#   '\xa0\xa0\xa0\xa0— Harrison {2}',
#   '',
#   'Kentucky',
#   '12.55  (w: 1.7)',
#   '6/13/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Harrison {2}',
#   '',
#   'Kentucky',
#   '12.55  (w: 1.7)',
#   '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Powell {2}SRSouthern California12.55 qq = Performance occurred during a non-final round. 6/7/2006',
#   '\xa0\xa0\xa0\xa0— Powell {2}SR',
#   '',
#   'Southern California',
#   '12.55 qq = Performance occurred during a non-final round. ',
#   '6/7/2006'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Powell {2}SR',
#   '',
#   'Southern California',
#   '12.55 qq = Performance occurred during a non-final round. ',
#   '6/7/2006'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {4}JRLSU12.56  (w: 0.2)4/29/2023',
#   '\xa0\xa0\xa0\xa0— Armstrong {4}JR',
#   '',
#   'LSU',
#   '12.56  (w: 0.2)',
#   '4/29/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Armstrong {4}JR',
#   '',
#   'LSU',
#   '12.56  (w: 0.2)',
#   '4/29/2023'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {5}JRLSU12.57  (w: 2.0)4/1/2023',
#   '\xa0\xa0\xa0\xa0— Armstrong {5}JR',
#   '',
#   'LSU',
#   '12.57  (w: 2.0)',
#   '4/1/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Armstrong {5}JR',
#   '',
#   'LSU',
#   '12.57  (w: 2.0)',
#   '4/1/2023'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {6}SOLSU12.57  (w: -0.2)6/11/2022',
#   '\xa0\xa0\xa0\xa0— Armstrong {6}SO',
#   '',
#   'LSU',
#   '12.57  (w: -0.2)',
#   '6/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Armstrong {6}SO',
#   '',
#   'LSU',
#   '12.57  (w: -0.2)',
#   '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Brown {4}SOArkansas12.57  (w: 1.6)4/26/2019',
#   '\xa0\xa0\xa0\xa0— Brown {4}SO',
#   '',
#   'Arkansas',
#   '12.57  (w: 1.6)',
#   '4/26/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Brown {4}SO',
#   '',
#   'Arkansas',
#   '12.57  (w: 1.6)',
#   '4/26/2019'],
#  ['(13) Tobi AMUSANSOUTEP12.57  (w: 1.6)6/10/2017',
#   '(13) Tobi AMUSANSO',
#   '',
#   'UTEP',
#   '12.57  (w: 1.6)',
#   '6/10/2017'],
#  [],
#  ['(13) Tobi AMUSANSO', '', 'UTEP', '12.57  (w: 1.6)', '6/10/2017'],
#  ['(14) Grace STARKSOFlorida12.58  (w: 1.9)4/15/2022',
#   '(14) Grace STARKSO',
#   '',
#   'Florida',
#   '12.58  (w: 1.9)',
#   '4/15/2022'],
#  [],
#  ['(14) Grace STARKSO', '', 'Florida', '12.58  (w: 1.9)', '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Cockrell {2}SRSouthern California12.58  (w: 0.4)6/12/2021',
#   '\xa0\xa0\xa0\xa0— Cockrell {2}SR',
#   '',
#   'Southern California',
#   '12.58  (w: 0.4)',
#   '6/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cockrell {2}SR',
#   '',
#   'Southern California',
#   '12.58  (w: 0.4)',
#   '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {3}JRKentucky12.58 qq = Performance occurred during a non-final round.  (w: 1.6)5/12/2018',
#   '\xa0\xa0\xa0\xa0— Camacho-Quinn {3}JR',
#   '',
#   'Kentucky',
#   '12.58 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '5/12/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {3}JR',
#   '',
#   'Kentucky',
#   '12.58 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '5/12/2018'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {4}SOKentucky12.58  (w: 1.6)6/10/2017',
#   '\xa0\xa0\xa0\xa0— Camacho-Quinn {4}SO',
#   '',
#   'Kentucky',
#   '12.58  (w: 1.6)',
#   '6/10/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {4}SO',
#   '',
#   'Kentucky',
#   '12.58  (w: 1.6)',
#   '6/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {7}JRLSU12.59 qq = Performance occurred during a non-final round.  (w: 2.0)5/27/2023',
#   '\xa0\xa0\xa0\xa0— Armstrong {7}JR',
#   '',
#   'LSU',
#   '12.59 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '5/27/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Armstrong {7}JR',
#   '',
#   'LSU',
#   '12.59 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {5}JRKentucky12.60 qq = Performance occurred during a non-final round.  (w: 0.7)5/25/2018',
#   '\xa0\xa0\xa0\xa0— Camacho-Quinn {5}JR',
#   '',
#   'Kentucky',
#   '12.60 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/25/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {5}JR',
#   '',
#   'Kentucky',
#   '12.60 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/25/2018'],
#  ['(15) Cindy OFILIMichigan12.60  (w: 1.7)6/13/2015',
#   '(15) Cindy OFILI',
#   '',
#   'Michigan',
#   '12.60  (w: 1.7)',
#   '6/13/2015'],
#  [],
#  ['(15) Cindy OFILI', '', 'Michigan', '12.60  (w: 1.7)', '6/13/2015'],
#  ['(15) Priscilla LOPESNebraska12.60   (w: 0.4)6/9/2006',
#   '(15) Priscilla LOPES',
#   '',
#   'Nebraska',
#   '12.60   (w: 0.4)',
#   '6/9/2006'],
#  [],
#  ['(15) Priscilla LOPES', '', 'Nebraska', '12.60   (w: 0.4)', '6/9/2006'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {8}SOLSU12.61  (w: 1.9)4/15/2022',
#   '\xa0\xa0\xa0\xa0— Armstrong {8}SO',
#   '',
#   'LSU',
#   '12.61  (w: 1.9)',
#   '4/15/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Armstrong {8}SO',
#   '',
#   'LSU',
#   '12.61  (w: 1.9)',
#   '4/15/2022'],
#  ['(17) Queen CLAYEVirginia Tech12.61  4/24/2010',
#   '(17) Queen CLAYE',
#   '',
#   'Virginia Tech',
#   '12.61  ',
#   '4/24/2010'],
#  [],
#  ['(17) Queen CLAYE', '', 'Virginia Tech', '12.61  ', '4/24/2010'],
#  ['\xa0\xa0\xa0\xa0— Powell {3}Southern California12.61 AA = Performance occurred at altitude (>1000 meters above sea level) 5/27/2006',
#   '\xa0\xa0\xa0\xa0— Powell {3}',
#   '',
#   'Southern California',
#   '12.61 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/27/2006'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Powell {3}',
#   '',
#   'Southern California',
#   '12.61 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/27/2006'],
#  ['(17) Gail DEVERSUCLA12.61  5/21/1988',
#   '(17) Gail DEVERS',
#   '',
#   'UCLA',
#   '12.61  ',
#   '5/21/1988'],
#  [],
#  ['(17) Gail DEVERS', '', 'UCLA', '12.61  ', '5/21/1988'],
#  ['\xa0\xa0\xa0\xa0— Harrison {3}Kentucky12.62 qq = Performance occurred during a non-final round.  (w: 1.2)5/30/2015',
#   '\xa0\xa0\xa0\xa0— Harrison {3}',
#   '',
#   'Kentucky',
#   '12.62 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '5/30/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Harrison {3}',
#   '',
#   'Kentucky',
#   '12.62 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '5/30/2015'],
#  ['\xa0\xa0\xa0\xa0— Harrison {4}Kentucky12.62  (w: 0.9)4/24/2015',
#   '\xa0\xa0\xa0\xa0— Harrison {4}',
#   '',
#   'Kentucky',
#   '12.62  (w: 0.9)',
#   '4/24/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Harrison {4}',
#   '',
#   'Kentucky',
#   '12.62  (w: 0.9)',
#   '4/24/2015'],
#  ['(19) Nichole DENBYSRTexas12.62   (w: 1.7)6/11/2004',
#   '(19) Nichole DENBYSR',
#   '',
#   'Texas',
#   '12.62   (w: 1.7)',
#   '6/11/2004'],
#  [],
#  ['(19) Nichole DENBYSR', '', 'Texas', '12.62   (w: 1.7)', '6/11/2004'],
#  ['(20) Paula  SALMONSRNorth Carolina A&T12.63  (w: 1.9)4/15/2022',
#   '(20) Paula  SALMONSR',
#   '',
#   'North Carolina A&T',
#   '12.63  (w: 1.9)',
#   '4/15/2022'],
#  [],
#  ['(20) Paula  SALMONSR',
#   '',
#   'North Carolina A&T',
#   '12.63  (w: 1.9)',
#   '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Amusan {2}SOUTEP12.63 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)3/25/2017',
#   '\xa0\xa0\xa0\xa0— Amusan {2}SO',
#   '',
#   'UTEP',
#   '12.63 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)',
#   '3/25/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Amusan {2}SO',
#   '',
#   'UTEP',
#   '12.63 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)',
#   '3/25/2017'],
#  ['\xa0\xa0\xa0\xa0— Lopes {2}Nebraska12.63  5/14/2006',
#   '\xa0\xa0\xa0\xa0— Lopes {2}',
#   '',
#   'Nebraska',
#   '12.63  ',
#   '5/14/2006'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lopes {2}', '', 'Nebraska', '12.63  ', '5/14/2006'],
#  ['\xa0\xa0\xa0\xa0— Powell {4}Southern California12.64  5/14/2006',
#   '\xa0\xa0\xa0\xa0— Powell {4}',
#   '',
#   'Southern California',
#   '12.64  ',
#   '5/14/2006'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Powell {4}',
#   '',
#   'Southern California',
#   '12.64  ',
#   '5/14/2006'],
#  ['\xa0\xa0\xa0\xa0— Lopes {3}Nebraska12.64   (w: 1.7)6/11/2004',
#   '\xa0\xa0\xa0\xa0— Lopes {3}',
#   '',
#   'Nebraska',
#   '12.64   (w: 1.7)',
#   '6/11/2004'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lopes {3}',
#   '',
#   'Nebraska',
#   '12.64   (w: 1.7)',
#   '6/11/2004'],
#  ['(21) Talie BONDSSRArizona12.65  (w: 1.2)4/12/2023',
#   '(21) Talie BONDSSR',
#   '',
#   'Arizona',
#   '12.65  (w: 1.2)',
#   '4/12/2023'],
#  [],
#  ['(21) Talie BONDSSR', '', 'Arizona', '12.65  (w: 1.2)', '4/12/2023'],
#  ['(21) Rushelle BURTONSOTexas12.65  (w: 0.2)5/13/2018',
#   '(21) Rushelle BURTONSO',
#   '',
#   'Texas',
#   '12.65  (w: 0.2)',
#   '5/13/2018'],
#  [],
#  ['(21) Rushelle BURTONSO', '', 'Texas', '12.65  (w: 0.2)', '5/13/2018'],
#  ['\xa0\xa0\xa0\xa0— Burton {2}FRTexas12.65  (w: 1.6)6/10/2017',
#   '\xa0\xa0\xa0\xa0— Burton {2}FR',
#   '',
#   'Texas',
#   '12.65  (w: 1.6)',
#   '6/10/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Burton {2}FR',
#   '',
#   'Texas',
#   '12.65  (w: 1.6)',
#   '6/10/2017'],
#  ['(23) Jasmine JONESSOSouthern California12.66  (w: -0.2)6/11/2022',
#   '(23) Jasmine JONESSO',
#   '',
#   'Southern California',
#   '12.66  (w: -0.2)',
#   '6/11/2022'],
#  [],
#  ['(23) Jasmine JONESSO',
#   '',
#   'Southern California',
#   '12.66  (w: -0.2)',
#   '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Salmon {2}SRNorth Carolina A&T12.66  (w: 1.2)4/22/2022',
#   '\xa0\xa0\xa0\xa0— Salmon {2}SR',
#   '',
#   'North Carolina A&T',
#   '12.66  (w: 1.2)',
#   '4/22/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Salmon {2}SR',
#   '',
#   'North Carolina A&T',
#   '12.66  (w: 1.2)',
#   '4/22/2022'],
#  ['\xa0\xa0\xa0\xa0— Marshall {4}JRLSU12.66  (w: 0.6)6/8/2019',
#   '\xa0\xa0\xa0\xa0— Marshall {4}JR',
#   '',
#   'LSU',
#   '12.66  (w: 0.6)',
#   '6/8/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Marshall {4}JR',
#   '',
#   'LSU',
#   '12.66  (w: 0.6)',
#   '6/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}Michigan12.66  (w: 2.0)4/16/2016',
#   '\xa0\xa0\xa0\xa0— Ofili {2}',
#   '',
#   'Michigan',
#   '12.66  (w: 2.0)',
#   '4/16/2016'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}',
#   '',
#   'Michigan',
#   '12.66  (w: 2.0)',
#   '4/16/2016'],
#  ['\xa0\xa0\xa0\xa0— Harrison {5}Kentucky12.66 qq = Performance occurred during a non-final round.  (w: 0.4)5/29/2015',
#   '\xa0\xa0\xa0\xa0— Harrison {5}',
#   '',
#   'Kentucky',
#   '12.66 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '5/29/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Harrison {5}',
#   '',
#   'Kentucky',
#   '12.66 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '5/29/2015'],
#  ['(24) Alexis GLASCOSOCoastal Carolina12.67 qq = Performance occurred during a non-final round.  (w: 1.9)5/27/2023',
#   '(24) Alexis GLASCOSO',
#   '',
#   'Coastal Carolina',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/27/2023'],
#  [],
#  ['(24) Alexis GLASCOSO',
#   '',
#   'Coastal Carolina',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Bonds {2}SRArizona12.67   (w: 1.2)4/8/2023',
#   '\xa0\xa0\xa0\xa0— Bonds {2}SR',
#   '',
#   'Arizona',
#   '12.67   (w: 1.2)',
#   '4/8/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Bonds {2}SR',
#   '',
#   'Arizona',
#   '12.67   (w: 1.2)',
#   '4/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Bonds {3}SRArizona12.67  (w: 1.2)4/6/2023',
#   '\xa0\xa0\xa0\xa0— Bonds {3}SR',
#   '',
#   'Arizona',
#   '12.67  (w: 1.2)',
#   '4/6/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Bonds {3}SR',
#   '',
#   'Arizona',
#   '12.67  (w: 1.2)',
#   '4/6/2023'],
#  ['\xa0\xa0\xa0\xa0— Stark {2}SOFlorida12.67 qq = Performance occurred during a non-final round.  (w: 1.5)4/16/2022',
#   '\xa0\xa0\xa0\xa0— Stark {2}SO',
#   '',
#   'Florida',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '4/16/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Stark {2}SO',
#   '',
#   'Florida',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '4/16/2022'],
#  ['\xa0\xa0\xa0\xa0— Stark {3}SOFlorida12.67  (w: 1.5)4/15/2022',
#   '\xa0\xa0\xa0\xa0— Stark {3}SO',
#   '',
#   'Florida',
#   '12.67  (w: 1.5)',
#   '4/15/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Stark {3}SO',
#   '',
#   'Florida',
#   '12.67  (w: 1.5)',
#   '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Marshall {5}JRLSU12.67 qq = Performance occurred during a non-final round.  (w: 0.8)6/6/2019',
#   '\xa0\xa0\xa0\xa0— Marshall {5}JR',
#   '',
#   'LSU',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/6/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Marshall {5}JR',
#   '',
#   'LSU',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/6/2019'],
#  ['\xa0\xa0\xa0\xa0— Amusan {3}SOUTEP12.67 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.9)4/22/2017',
#   '\xa0\xa0\xa0\xa0— Amusan {3}SO',
#   '',
#   'UTEP',
#   '12.67 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.9)',
#   '4/22/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Amusan {3}SO',
#   '',
#   'UTEP',
#   '12.67 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.9)',
#   '4/22/2017'],
#  ['\xa0\xa0\xa0\xa0— Claye {2}Virginia Tech12.67   (w: 1.8)6/12/2010',
#   '\xa0\xa0\xa0\xa0— Claye {2}',
#   '',
#   'Virginia Tech',
#   '12.67   (w: 1.8)',
#   '6/12/2010'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Claye {2}',
#   '',
#   'Virginia Tech',
#   '12.67   (w: 1.8)',
#   '6/12/2010'],
#  ['\xa0\xa0\xa0\xa0— Salmon {3}SRNorth Carolina A&T12.68 qq = Performance occurred during a non-final round.  (w: -0.3)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Salmon {3}SR',
#   '',
#   'North Carolina A&T',
#   '12.68 qq = Performance occurred during a non-final round.  (w: -0.3)',
#   '6/9/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Salmon {3}SR',
#   '',
#   'North Carolina A&T',
#   '12.68 qq = Performance occurred during a non-final round.  (w: -0.3)',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Rollins {3}Clemson12.68 qq = Performance occurred during a non-final round.  (w: -1.5)5/11/2013',
#   '\xa0\xa0\xa0\xa0— Rollins {3}',
#   '',
#   'Clemson',
#   '12.68 qq = Performance occurred during a non-final round.  (w: -1.5)',
#   '5/11/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rollins {3}',
#   '',
#   'Clemson',
#   '12.68 qq = Performance occurred during a non-final round.  (w: -1.5)',
#   '5/11/2013'],
#  ['(25) Christina CLEMONSOhio State12.68  (w: 0.4)3/31/2012',
#   '(25) Christina CLEMONS',
#   '',
#   'Ohio State',
#   '12.68  (w: 0.4)',
#   '3/31/2012'],
#  [],
#  ['(25) Christina CLEMONS', '', 'Ohio State', '12.68  (w: 0.4)', '3/31/2012'],
#  ['(25) Perdita FELICIENSRIllinois12.68 qq = Performance occurred during a non-final round. 6/12/2003',
#   '(25) Perdita FELICIENSR',
#   '',
#   'Illinois',
#   '12.68 qq = Performance occurred during a non-final round. ',
#   '6/12/2003'],
#  [],
#  ['(25) Perdita FELICIENSR',
#   '',
#   'Illinois',
#   '12.68 qq = Performance occurred during a non-final round. ',
#   '6/12/2003'],
#  ['(25) Danielle CARRUTHERSIndiana12.68  5/19/2002',
#   '(25) Danielle CARRUTHERS',
#   '',
#   'Indiana',
#   '12.68  ',
#   '5/19/2002'],
#  [],
#  ['(25) Danielle CARRUTHERS', '', 'Indiana', '12.68  ', '5/19/2002'],
#  ['Additional All-Conditions Bests'],
#  ['Ackera NUGENTJRArkansas12.25 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)6/10/2023',
#   'Ackera NUGENTJR',
#   '',
#   'Arkansas',
#   '12.25 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '6/10/2023'],
#  [],
#  ['Ackera NUGENTJR',
#   '',
#   'Arkansas',
#   '12.25 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '6/10/2023'],
#  ['Alia ARMSTRONGJRLSU12.31 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)5/12/2023',
#   'Alia ARMSTRONGJR',
#   '',
#   'LSU',
#   '12.31 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '5/12/2023'],
#  [],
#  ['Alia ARMSTRONGJR',
#   '',
#   'LSU',
#   '12.31 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '5/12/2023'],
#  ['Masai RUSSELLSRKentucky12.32 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)6/10/2023',
#   'Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.32 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '6/10/2023'],
#  [],
#  ['Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.32 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '6/10/2023'],
#  ['Alia ARMSTRONGSOLSU12.33 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)3/26/2022',
#   'Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.33 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '3/26/2022'],
#  [],
#  ['Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.33 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '3/26/2022'],
#  ['Masai RUSSELLSRKentucky12.40 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.9)5/25/2023',
#   'Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.40 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.9)',
#   '5/25/2023'],
#  [],
#  ['Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.40 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.9)',
#   '5/25/2023'],
#  ['Queen CLAYEVirginia Tech12.44 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 4/17/2010',
#   'Queen CLAYE',
#   '',
#   'Virginia Tech',
#   '12.44 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/17/2010'],
#  [],
#  ['Queen CLAYE',
#   '',
#   'Virginia Tech',
#   '12.44 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/17/2010'],
#  ['Alia ARMSTRONGSOLSU12.46 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)5/14/2022',
#   'Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.46 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '5/14/2022'],
#  [],
#  ['Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.46 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '5/14/2022'],
#  ['Queen CLAYEVirginia Tech12.46 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 4/23/2010',
#   'Queen CLAYE',
#   '',
#   'Virginia Tech',
#   '12.46 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/23/2010'],
#  [],
#  ['Queen CLAYE',
#   '',
#   'Virginia Tech',
#   '12.46 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/23/2010'],
#  ['Masai RUSSELLSRKentucky12.47 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)5/12/2023',
#   'Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.47 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '5/12/2023'],
#  [],
#  ['Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.47 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '5/12/2023'],
#  ['Alia ARMSTRONGJRLSU12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)6/10/2023',
#   'Alia ARMSTRONGJR',
#   '',
#   'LSU',
#   '12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '6/10/2023'],
#  [],
#  ['Alia ARMSTRONGJR',
#   '',
#   'LSU',
#   '12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '6/10/2023'],
#  ['Ackera NUGENTJRArkansas12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)5/13/2023',
#   'Ackera NUGENTJR',
#   '',
#   'Arkansas',
#   '12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)',
#   '5/13/2023'],
#  [],
#  ['Ackera NUGENTJR',
#   '',
#   'Arkansas',
#   '12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)',
#   '5/13/2023'],
#  ['Ackera NUGENTJRArkansas12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)5/12/2023',
#   'Ackera NUGENTJR',
#   '',
#   'Arkansas',
#   '12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '5/12/2023'],
#  [],
#  ['Ackera NUGENTJR',
#   '',
#   'Arkansas',
#   '12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '5/12/2023'],
#  ['Kaylah ROBINSONSRTexas A&M12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)3/26/2022',
#   'Kaylah ROBINSONSR',
#   '',
#   'Texas A&M',
#   '12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '3/26/2022'],
#  [],
#  ['Kaylah ROBINSONSR',
#   '',
#   'Texas A&M',
#   '12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '3/26/2022'],
#  ['Tonea MARSHALLSRLSU12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)5/27/2021',
#   'Tonea MARSHALLSR',
#   '',
#   'LSU',
#   '12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)',
#   '5/27/2021'],
#  [],
#  ['Tonea MARSHALLSR',
#   '',
#   'LSU',
#   '12.49 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)',
#   '5/27/2021'],
#  ['Sharika NELVISSRArkansas State12.52 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)6/14/2014',
#   'Sharika NELVISSR',
#   '',
#   'Arkansas State',
#   '12.52 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '6/14/2014'],
#  [],
#  ['Sharika NELVISSR',
#   '',
#   'Arkansas State',
#   '12.52 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '6/14/2014'],
#  ['Tonea MARSHALLSRLSU12.53 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)4/23/2021',
#   'Tonea MARSHALLSR',
#   '',
#   'LSU',
#   '12.53 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '4/23/2021'],
#  [],
#  ['Tonea MARSHALLSR',
#   '',
#   'LSU',
#   '12.53 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '4/23/2021'],
#  ['Jasmine CAMACHO-QUINNJRKentucky12.53 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)4/27/2018',
#   'Jasmine CAMACHO-QUINNJR',
#   '',
#   'Kentucky',
#   '12.53 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '4/27/2018'],
#  [],
#  ['Jasmine CAMACHO-QUINNJR',
#   '',
#   'Kentucky',
#   '12.53 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '4/27/2018'],
#  ['Jasmine CAMACHO-QUINNFRKentucky12.54 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)6/11/2016',
#   'Jasmine CAMACHO-QUINNFR',
#   '',
#   'Kentucky',
#   '12.54 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '6/11/2016'],
#  [],
#  ['Jasmine CAMACHO-QUINNFR',
#   '',
#   'Kentucky',
#   '12.54 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.8)',
#   '6/11/2016'],
#  ['Jasmin STOWERSSRLSU12.54 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)6/14/2014',
#   'Jasmin STOWERSSR',
#   '',
#   'LSU',
#   '12.54 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '6/14/2014'],
#  [],
#  ['Jasmin STOWERSSR',
#   '',
#   'LSU',
#   '12.54 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '6/14/2014'],
#  ['Brianna ROLLINSClemson12.54 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)3/30/2013',
#   'Brianna ROLLINS',
#   '',
#   'Clemson',
#   '12.54 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '3/30/2013'],
#  [],
#  ['Brianna ROLLINS',
#   '',
#   'Clemson',
#   '12.54 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '3/30/2013'],
#  ['Alia ARMSTRONGSOLSU12.55 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.6)4/23/2022',
#   'Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.55 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.6)',
#   '4/23/2022'],
#  [],
#  ['Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.55 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.6)',
#   '4/23/2022'],
#  ['Vashti THOMASAcademy of Art12.56 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)4/18/2013',
#   'Vashti THOMAS',
#   '',
#   'Academy of Art',
#   '12.56 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '4/18/2013'],
#  [],
#  ['Vashti THOMAS',
#   '',
#   'Academy of Art',
#   '12.56 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '4/18/2013'],
#  ['Kaylah ROBINSONSRTexas A&M12.57 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.5)5/28/2022',
#   'Kaylah ROBINSONSR',
#   '',
#   'Texas A&M',
#   '12.57 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.5)',
#   '5/28/2022'],
#  [],
#  ['Kaylah ROBINSONSR',
#   '',
#   'Texas A&M',
#   '12.57 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.5)',
#   '5/28/2022'],
#  ['Tobi AMUSANSOUTEP12.57 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.5)5/27/2017',
#   'Tobi AMUSANSO',
#   '',
#   'UTEP',
#   '12.57 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.5)',
#   '5/27/2017'],
#  [],
#  ['Tobi AMUSANSO',
#   '',
#   'UTEP',
#   '12.57 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.5)',
#   '5/27/2017'],
#  ['Tobi AMUSANSOUTEP12.57 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.5)5/27/2017',
#   'Tobi AMUSANSO',
#   '',
#   'UTEP',
#   '12.57 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.5)',
#   '5/27/2017'],
#  [],
#  ['Tobi AMUSANSO',
#   '',
#   'UTEP',
#   '12.57 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.5)',
#   '5/27/2017'],
#  ['Christina CLEMONSOhio State12.57 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)4/21/2012',
#   'Christina CLEMONS',
#   '',
#   'Ohio State',
#   '12.57 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)',
#   '4/21/2012'],
#  [],
#  ['Christina CLEMONS',
#   '',
#   'Ohio State',
#   '12.57 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)',
#   '4/21/2012'],
#  ['Masai RUSSELLSRKentucky12.58 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.4)5/27/2023',
#   'Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.58 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.4)',
#   '5/27/2023'],
#  [],
#  ['Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.58 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.4)',
#   '5/27/2023'],
#  ['Keni HARRISONKentucky12.59 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)6/13/2015',
#   'Keni HARRISON',
#   '',
#   'Kentucky',
#   '12.59 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '6/13/2015'],
#  [],
#  ['Keni HARRISON',
#   '',
#   'Kentucky',
#   '12.59 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '6/13/2015'],
#  ['Tiffani MCREYNOLDSBaylor12.59 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)5/18/2014',
#   'Tiffani MCREYNOLDS',
#   '',
#   'Baylor',
#   '12.59 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '5/18/2014'],
#  [],
#  ['Tiffani MCREYNOLDS',
#   '',
#   'Baylor',
#   '12.59 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '5/18/2014'],
#  ['Kristi CASTLINVirginia Tech12.59 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 4/17/2010',
#   'Kristi CASTLIN',
#   '',
#   'Virginia Tech',
#   '12.59 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/17/2010'],
#  [],
#  ['Kristi CASTLIN',
#   '',
#   'Virginia Tech',
#   '12.59 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/17/2010'],
#  ['Kaylah ROBINSONSRTexas A&M12.60 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)5/14/2022',
#   'Kaylah ROBINSONSR',
#   '',
#   'Texas A&M',
#   '12.60 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '5/14/2022'],
#  [],
#  ['Kaylah ROBINSONSR',
#   '',
#   'Texas A&M',
#   '12.60 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '5/14/2022'],
#  ['Delloreen ENNISAbilene Christian12.60 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)4/24/1999',
#   'Delloreen ENNIS',
#   '',
#   'Abilene Christian',
#   '12.60 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)',
#   '4/24/1999'],
#  [],
#  ['Delloreen ENNIS',
#   '',
#   'Abilene Christian',
#   '12.60 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)',
#   '4/24/1999'],
#  ['Masai RUSSELLSRKentucky12.61 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.9)3/31/2023',
#   'Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.61 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.9)',
#   '3/31/2023'],
#  [],
#  ['Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.61 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.9)',
#   '3/31/2023'],
#  ['Tara DAVISSOTexas12.61 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)4/23/2021',
#   'Tara DAVISSO',
#   '',
#   'Texas',
#   '12.61 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '4/23/2021'],
#  [],
#  ['Tara DAVISSO',
#   '',
#   'Texas',
#   '12.61 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '4/23/2021'],
#  ['Alia ARMSTRONGJRLSU12.62 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)5/25/2023',
#   'Alia ARMSTRONGJR',
#   '',
#   'LSU',
#   '12.62 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '5/25/2023'],
#  [],
#  ['Alia ARMSTRONGJR',
#   '',
#   'LSU',
#   '12.62 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '5/25/2023'],
#  ['Tonea MARSHALLSRLSU12.62 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.6)5/15/2021',
#   'Tonea MARSHALLSR',
#   '',
#   'LSU',
#   '12.62 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.6)',
#   '5/15/2021'],
#  [],
#  ['Tonea MARSHALLSR',
#   '',
#   'LSU',
#   '12.62 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.6)',
#   '5/15/2021'],
#  ['Jeanine WILLIAMSSRGeorgia Tech12.62 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)5/25/2019',
#   'Jeanine WILLIAMSSR',
#   '',
#   'Georgia Tech',
#   '12.62 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)',
#   '5/25/2019'],
#  [],
#  ['Jeanine WILLIAMSSR',
#   '',
#   'Georgia Tech',
#   '12.62 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)',
#   '5/25/2019'],
#  ['Bridgette OWENSJRFlorida12.62 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)6/14/2014',
#   'Bridgette OWENSJR',
#   '',
#   'Florida',
#   '12.62 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '6/14/2014'],
#  [],
#  ['Bridgette OWENSJR',
#   '',
#   'Florida',
#   '12.62 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '6/14/2014'],
#  ['Rayniah JONESJRUCF12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)4/28/2023',
#   'Rayniah JONESJR',
#   '',
#   'UCF',
#   '12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '4/28/2023'],
#  [],
#  ['Rayniah JONESJR',
#   '',
#   'UCF',
#   '12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '4/28/2023'],
#  ['Ackera NUGENTFRBaylor12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.3)5/27/2021',
#   'Ackera NUGENTFR',
#   '',
#   'Baylor',
#   '12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.3)',
#   '5/27/2021'],
#  [],
#  ['Ackera NUGENTFR',
#   '',
#   'Baylor',
#   '12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.3)',
#   '5/27/2021'],
#  ['Tobi AMUSANSOUTEP12.63 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.3)5/27/2017',
#   'Tobi AMUSANSO',
#   '',
#   'UTEP',
#   '12.63 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.3)',
#   '5/27/2017'],
#  [],
#  ['Tobi AMUSANSO',
#   '',
#   'UTEP',
#   '12.63 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.3)',
#   '5/27/2017'],
#  ['Nia ALISRSouthern California12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)6/11/2011',
#   'Nia ALISR',
#   '',
#   'Southern California',
#   '12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '6/11/2011'],
#  [],
#  ['Nia ALISR',
#   '',
#   'Southern California',
#   '12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '6/11/2011'],
#  ['Nickiesha WILSONLSU12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)5/31/2008',
#   'Nickiesha WILSON',
#   '',
#   'LSU',
#   '12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '5/31/2008'],
#  [],
#  ['Nickiesha WILSON',
#   '',
#   'LSU',
#   '12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '5/31/2008'],
#  ['Rushelle BURTONSOTexas12.64 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.3)3/28/2018',
#   'Rushelle BURTONSO',
#   '',
#   'Texas',
#   '12.64 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.3)',
#   '3/28/2018'],
#  [],
#  ['Rushelle BURTONSO',
#   '',
#   'Texas',
#   '12.64 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.3)',
#   '3/28/2018'],
#  ['Rushelle BURTONFRTexas12.65 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)4/15/2017',
#   'Rushelle BURTONFR',
#   '',
#   'Texas',
#   '12.65 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)',
#   '4/15/2017'],
#  [],
#  ['Rushelle BURTONFR',
#   '',
#   'Texas',
#   '12.65 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)',
#   '4/15/2017'],
#  ['Rayniah JONESJRUCF12.66 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)5/14/2023',
#   'Rayniah JONESJR',
#   '',
#   'UCF',
#   '12.66 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)',
#   '5/14/2023'],
#  [],
#  ['Rayniah JONESJR',
#   '',
#   'UCF',
#   '12.66 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)',
#   '5/14/2023'],
#  ['Demisha ROSWELLJRTexas Tech12.66 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)4/1/2022',
#   'Demisha ROSWELLJR',
#   '',
#   'Texas Tech',
#   '12.66 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '4/1/2022'],
#  [],
#  ['Demisha ROSWELLJR',
#   '',
#   'Texas Tech',
#   '12.66 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '4/1/2022'],
#  ['Sharika NELVISArkansas State12.66 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)5/31/2014',
#   'Sharika NELVIS',
#   '',
#   'Arkansas State',
#   '12.66 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)',
#   '5/31/2014'],
#  [],
#  ['Sharika NELVIS',
#   '',
#   'Arkansas State',
#   '12.66 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)',
#   '5/31/2014'],
#  ['Aasia LAURENCINJRMichigan12.67 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)5/25/2023',
#   'Aasia LAURENCINJR',
#   '',
#   'Michigan',
#   '12.67 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)',
#   '5/25/2023'],
#  [],
#  ['Aasia LAURENCINJR',
#   '',
#   'Michigan',
#   '12.67 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)',
#   '5/25/2023'],
#  ['Devynne CHARLTONJRPurdue12.67 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.6)5/14/2017',
#   'Devynne CHARLTONJR',
#   '',
#   'Purdue',
#   '12.67 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.6)',
#   '5/14/2017'],
#  [],
#  ['Devynne CHARLTONJR',
#   '',
#   'Purdue',
#   '12.67 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.6)',
#   '5/14/2017'],
#  ['Sharika NELVISArkansas State12.67 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)5/11/2014',
#   'Sharika NELVIS',
#   '',
#   'Arkansas State',
#   '12.67 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '5/11/2014'],
#  [],
#  ['Sharika NELVIS',
#   '',
#   'Arkansas State',
#   '12.67 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '5/11/2014'],
# ...
#   '',
#   'Oregon',
#   '12.68 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.8)',
#   '5/27/2017'],
#  ['Alaysha JOHNSONSOOregon12.68 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)5/27/2017',
#   'Alaysha JOHNSONSO',
#   '',
#   'Oregon',
#   '12.68 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)',
#   '5/27/2017'],
#  [],
#  ['Alaysha JOHNSONSO',
#   '',
#   'Oregon',
#   '12.68 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)',
#   '5/27/2017'],
#  ['Keni HARRISONKentucky12.68 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)3/29/2014',
#   'Keni HARRISON',
#   '',
#   'Kentucky',
#   '12.68 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '3/29/2014'],
#  [],
#  ['Keni HARRISON',
#   '',
#   'Kentucky',
#   '12.68 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '3/29/2014'],
#  ['Additional Out-of-Season Bests'],
#  ['Brianna ROLLINSClemson12.26   (w: 1.2)6/23/2013',
#   'Brianna ROLLINS',
#   '',
#   'Clemson',
#   '12.26   (w: 1.2)',
#   '6/23/2013'],
#  [],
#  ['Brianna ROLLINS', '', 'Clemson', '12.26   (w: 1.2)', '6/23/2013'],
#  ['Alia ARMSTRONGSOLSU12.43 qq = Performance occurred during a non-final round.  (w: -0.1)7/24/2022',
#   'Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.43 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '7/24/2022'],
#  [],
#  ['Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.43 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '7/24/2022'],
#  ['Brianna ROLLINSClemson12.44   (w: -0.6)8/17/2013',
#   'Brianna ROLLINS',
#   '',
#   'Clemson',
#   '12.44   (w: -0.6)',
#   '8/17/2013'],
#  [],
#  ['Brianna ROLLINS', '', 'Clemson', '12.44   (w: -0.6)', '8/17/2013'],
#  ['Masai RUSSELLSRKentucky12.46   (w: 0.4)7/8/2023',
#   'Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.46   (w: 0.4)',
#   '7/8/2023'],
#  [],
#  ['Masai RUSSELLSR', '', 'Kentucky', '12.46   (w: 0.4)', '7/8/2023'],
#  ['Alia ARMSTRONGSOLSU12.47   (w: -1.4)6/25/2022',
#   'Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.47   (w: -1.4)',
#   '6/25/2022'],
#  [],
#  ['Alia ARMSTRONGSO', '', 'LSU', '12.47   (w: -1.4)', '6/25/2022'],
#  ['Masai RUSSELLSRKentucky12.48 qq = Performance occurred during a non-final round.  (w: 0.5)7/8/2023',
#   'Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.48 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '7/8/2023'],
#  [],
#  ['Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.48 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '7/8/2023'],
#  ['Alia ARMSTRONGSOLSU12.48 qq = Performance occurred during a non-final round.  (w: 0.5)7/23/2022',
#   'Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.48 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '7/23/2022'],
#  [],
#  ['Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.48 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '7/23/2022'],
#  ['Masai RUSSELLSRKentucky12.50 qq = Performance occurred during a non-final round.  (w: 0.8)8/4/2023',
#   'Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.50 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '8/4/2023'],
#  [],
#  ['Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.50 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '8/4/2023'],
#  ['Tonea MARSHALLSRLSU12.50 qq = Performance occurred during a non-final round.  (w: 1.2)6/20/2021',
#   'Tonea MARSHALLSR',
#   '',
#   'LSU',
#   '12.50 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '6/20/2021'],
#  [],
#  ['Tonea MARSHALLSR',
#   '',
#   'LSU',
#   '12.50 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '6/20/2021'],
#  ['Alia ARMSTRONGSOLSU12.51 qq = Performance occurred during a non-final round.  (w: 0.4)6/24/2022',
#   'Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.51 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '6/24/2022'],
#  [],
#  ['Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.51 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '6/24/2022'],
#  ['Masai RUSSELLSRKentucky12.52   (w: 0.2)8/4/2023',
#   'Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.52   (w: 0.2)',
#   '8/4/2023'],
#  [],
#  ['Masai RUSSELLSR', '', 'Kentucky', '12.52   (w: 0.2)', '8/4/2023'],
#  ['Keni HARRISONKentucky12.52   (w: -0.3)7/17/2015',
#   'Keni HARRISON',
#   '',
#   'Kentucky',
#   '12.52   (w: -0.3)',
#   '7/17/2015'],
#  [],
#  ['Keni HARRISON', '', 'Kentucky', '12.52   (w: -0.3)', '7/17/2015'],
#  ['Perdita FELICIENIllinois12.53   (w: -0.2)8/27/2003',
#   'Perdita FELICIEN',
#   '',
#   'Illinois',
#   '12.53   (w: -0.2)',
#   '8/27/2003'],
#  [],
#  ['Perdita FELICIEN', '', 'Illinois', '12.53   (w: -0.2)', '8/27/2003'],
#  ['Brianna ROLLINSClemson12.54 qq = Performance occurred during a non-final round.  (w: 0.2)8/17/2013',
#   'Brianna ROLLINS',
#   '',
#   'Clemson',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '8/17/2013'],
#  [],
#  ['Brianna ROLLINS',
#   '',
#   'Clemson',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '8/17/2013'],
#  ['Brianna ROLLINSClemson12.55   (w: -0.8)8/17/2013',
#   'Brianna ROLLINS',
#   '',
#   'Clemson',
#   '12.55   (w: -0.8)',
#   '8/17/2013'],
#  [],
#  ['Brianna ROLLINS', '', 'Clemson', '12.55   (w: -0.8)', '8/17/2013'],
#  ['Keni HARRISONKentucky12.56   (w: -0.1)6/27/2015',
#   'Keni HARRISON',
#   '',
#   'Kentucky',
#   '12.56   (w: -0.1)',
#   '6/27/2015'],
#  [],
#  ['Keni HARRISON', '', 'Kentucky', '12.56   (w: -0.1)', '6/27/2015'],
#  ['Tonea MARSHALLJRLSU12.57   (w: 1.7)7/6/2019',
#   'Tonea MARSHALLJR',
#   '',
#   'LSU',
#   '12.57   (w: 1.7)',
#   '7/6/2019'],
#  [],
#  ['Tonea MARSHALLJR', '', 'LSU', '12.57   (w: 1.7)', '7/6/2019'],
#  ['Anna COCKRELLSRSouthern California12.58  (w: 0.8)6/20/2021',
#   'Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '12.58  (w: 0.8)',
#   '6/20/2021'],
#  [],
#  ['Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '12.58  (w: 0.8)',
#   '6/20/2021'],
#  ['Anna COCKRELLSRSouthern California12.59 qq = Performance occurred during a non-final round.  (w: 1.3)6/20/2021',
#   'Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '12.59 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/20/2021'],
#  [],
#  ['Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '12.59 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/20/2021'],
#  ['Keni HARRISONKentucky12.59 qq = Performance occurred during a non-final round.  (w: 1.2)6/27/2015',
#   'Keni HARRISON',
#   '',
#   'Kentucky',
#   '12.59 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '6/27/2015'],
#  [],
#  ['Keni HARRISON',
#   '',
#   'Kentucky',
#   '12.59 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '6/27/2015'],
#  ['Alia ARMSTRONGJRLSU12.60 qq = Performance occurred during a non-final round.  (w: 1.4)7/8/2023',
#   'Alia ARMSTRONGJR',
#   '',
#   'LSU',
#   '12.60 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '7/8/2023'],
#  [],
#  ['Alia ARMSTRONGJR',
#   '',
#   'LSU',
#   '12.60 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '7/8/2023'],
#  ['Janeek BROWNSOArkansas12.61 qq = Performance occurred during a non-final round.  (w: 0.2)10/5/2019',
#   'Janeek BROWNSO',
#   '',
#   'Arkansas',
#   '12.61 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '10/5/2019'],
#  [],
#  ['Janeek BROWNSO',
#   '',
#   'Arkansas',
#   '12.61 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '10/5/2019'],
#  ['Vashti THOMASAcademy of Art12.61   (w: 1.8)7/10/2013',
#   'Vashti THOMAS',
#   '',
#   'Academy of Art',
#   '12.61   (w: 1.8)',
#   '7/10/2013'],
#  [],
#  ['Vashti THOMAS', '', 'Academy of Art', '12.61   (w: 1.8)', '7/10/2013'],
#  ['Janeek BROWNSOArkansas12.62 qq = Performance occurred during a non-final round.  (w: 0.6)10/6/2019',
#   'Janeek BROWNSO',
#   '',
#   'Arkansas',
#   '12.62 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '10/6/2019'],
#  [],
#  ['Janeek BROWNSO',
#   '',
#   'Arkansas',
#   '12.62 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '10/6/2019'],
#  ['Tonea MARSHALLSRLSU12.63  (w: 0.8)6/20/2021',
#   'Tonea MARSHALLSR',
#   '',
#   'LSU',
#   '12.63  (w: 0.8)',
#   '6/20/2021'],
#  [],
#  ['Tonea MARSHALLSR', '', 'LSU', '12.63  (w: 0.8)', '6/20/2021'],
#  ['Anna COCKRELLSRSouthern California12.63 qq = Performance occurred during a non-final round.  (w: 1.0)6/19/2021',
#   'Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '12.63 qq = Performance occurred during a non-final round.  (w: 1.0)',
#   '6/19/2021'],
#  [],
#  ['Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '12.63 qq = Performance occurred during a non-final round.  (w: 1.0)',
#   '6/19/2021'],
#  ['Cindy OFILIMichigan12.63  (w: 0.0)8/17/2016',
#   'Cindy OFILI',
#   '',
#   'Michigan',
#   '12.63  (w: 0.0)',
#   '8/17/2016'],
#  [],
#  ['Cindy OFILI', '', 'Michigan', '12.63  (w: 0.0)', '8/17/2016'],
#  ['Brianna ROLLINSClemson12.63   (w: -0.4)7/17/2013',
#   'Brianna ROLLINS',
#   '',
#   'Clemson',
#   '12.63   (w: -0.4)',
#   '7/17/2013'],
#  [],
#  ['Brianna ROLLINS', '', 'Clemson', '12.63   (w: -0.4)', '7/17/2013'],
#  ['Angie VAUGHNTexas12.63   (w: 0.0)7/25/1998',
#   'Angie VAUGHN',
#   '',
#   'Texas',
#   '12.63   (w: 0.0)',
#   '7/25/1998'],
#  [],
#  ['Angie VAUGHN', '', 'Texas', '12.63   (w: 0.0)', '7/25/1998'],
#  ['Rayniah  JONESFRUCF12.64 qq = Performance occurred during a non-final round.  (w: 1.0)6/19/2021',
#   'Rayniah  JONESFR',
#   '',
#   'UCF',
#   '12.64 qq = Performance occurred during a non-final round.  (w: 1.0)',
#   '6/19/2021'],
#  [],
#  ['Rayniah  JONESFR',
#   '',
#   'UCF',
#   '12.64 qq = Performance occurred during a non-final round.  (w: 1.0)',
#   '6/19/2021'],
#  ['Pedrya SEYMOURIllinois12.64 qq = Performance occurred during a non-final round.  (w: 0.2)8/17/2016\xa0\xa0\xa0\xa0\xa0BAH NR',
#   'Pedrya SEYMOUR',
#   '',
#   'Illinois',
#   '12.64 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '8/17/2016',
#   '\xa0\xa0\xa0\xa0\xa0BAH NR'],
#  [],
#  ['Pedrya SEYMOUR',
#   '',
#   'Illinois',
#   '12.64 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '8/17/2016'],
#  ['\xa0\xa0\xa0\xa0\xa0BAH NR'],
#  ['Alia ARMSTRONGFRLSU12.65 qq = Performance occurred during a non-final round.  (w: 1.2)6/20/2021',
#   'Alia ARMSTRONGFR',
#   '',
#   'LSU',
#   '12.65 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '6/20/2021'],
#  [],
#  ['Alia ARMSTRONGFR',
#   '',
#   'LSU',
#   '12.65 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '6/20/2021'],
#  ['TeJyrica ROBINSONSRNorth Carolina A&T12.65 qq = Performance occurred during a non-final round.  (w: 1.3)6/20/2021',
#   'TeJyrica ROBINSONSR',
#   '',
#   'North Carolina A&T',
#   '12.65 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/20/2021'],
#  [],
#  ['TeJyrica ROBINSONSR',
#   '',
#   'North Carolina A&T',
#   '12.65 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/20/2021'],
#  ['Cindy OFILISRMichigan12.66   (w: 0.2)8/27/2016',
#   'Cindy OFILISR',
#   '',
#   'Michigan',
#   '12.66   (w: 0.2)',
#   '8/27/2016'],
#  [],
#  ['Cindy OFILISR', '', 'Michigan', '12.66   (w: 0.2)', '8/27/2016'],
#  ['Ackera NUGENTJRArkansas12.67   (w: -1.9)7/9/2023',
#   'Ackera NUGENTJR',
#   '',
#   'Arkansas',
#   '12.67   (w: -1.9)',
#   '7/9/2023'],
#  [],
#  ['Ackera NUGENTJR', '', 'Arkansas', '12.67   (w: -1.9)', '7/9/2023'],
#  ['Angie VAUGHNTexas12.67  8/5/1998',
#   'Angie VAUGHN',
#   '',
#   'Texas',
#   '12.67  ',
#   '8/5/1998'],
#  [],
#  ['Angie VAUGHN', '', 'Texas', '12.67  ', '8/5/1998'],
#  ['Ackera NUGENTJRArkansas12.68   (w: 0.2)8/4/2023',
#   'Ackera NUGENTJR',
#   '',
#   'Arkansas',
#   '12.68   (w: 0.2)',
#   '8/4/2023'],
#  [],
#  ['Ackera NUGENTJR', '', 'Arkansas', '12.68   (w: 0.2)', '8/4/2023'],
#  ['Alia ARMSTRONGSOLSU12.68 qq = Performance occurred during a non-final round.  (w: 0.8)6/25/2022',
#   'Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.68 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/25/2022'],
#  [],
#  ['Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.68 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/25/2022'],
#  ['Rayniah  JONESFRUCF12.68 qq = Performance occurred during a non-final round.  (w: 1.3)6/20/2021',
#   'Rayniah  JONESFR',
#   '',
#   'UCF',
#   '12.68 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/20/2021'],
#  [],
#  ['Rayniah  JONESFR',
#   '',
#   'UCF',
#   '12.68 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '6/20/2021'],
#  ['Janeek BROWNSOArkansas12.68 qq = Performance occurred during a non-final round.  (w: 0.5)6/23/2019',
#   'Janeek BROWNSO',
#   '',
#   'Arkansas',
#   '12.68 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/23/2019'],
#  [],
#  ['Janeek BROWNSO',
#   '',
#   'Arkansas',
#   '12.68 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/23/2019'],
#  ['Additional Out-of-Season, All-Conditions Bests'],
#  ['Brianna ROLLINSClemson12.30 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.8)6/22/2013',
#   'Brianna ROLLINS',
#   '',
#   'Clemson',
#   '12.30 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.8)',
#   '6/22/2013'],
#  [],
#  ['Brianna ROLLINS',
#   '',
#   'Clemson',
#   '12.30 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.8)',
#   '6/22/2013'],
#  ['Alia ARMSTRONGSOLSU12.31 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)7/24/2022',
#   'Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.31 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '7/24/2022'],
#  [],
#  ['Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '12.31 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '7/24/2022'],
#  ['Brianna ROLLINSClemson12.33 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)6/23/2013',
#   'Brianna ROLLINS',
#   '',
#   'Clemson',
#   '12.33 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)',
#   '6/23/2013'],
#  [],
#  ['Brianna ROLLINS',
#   '',
#   'Clemson',
#   '12.33 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)',
#   '6/23/2013'],
#  ['Keni HARRISONKentucky12.46 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)6/26/2015',
#   'Keni HARRISON',
#   '',
#   'Kentucky',
#   '12.46 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)',
#   '6/26/2015'],
#  [],
#  ['Keni HARRISON',
#   '',
#   'Kentucky',
#   '12.46 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)',
#   '6/26/2015'],
#  ['Brianna ROLLINSClemson12.47 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)7/21/2013',
#   'Brianna ROLLINS',
#   '',
#   'Clemson',
#   '12.47 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '7/21/2013'],
#  [],
#  ['Brianna ROLLINS',
#   '',
#   'Clemson',
#   '12.47 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '7/21/2013'],
#  ['Vashti THOMASAcademy of Art12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)6/22/2013',
#   'Vashti THOMAS',
#   '',
#   'Academy of Art',
#   '12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '6/22/2013'],
#  [],
#  ['Vashti THOMAS',
#   '',
#   'Academy of Art',
#   '12.63 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '6/22/2013'],
#  ['', '', '', '']]

# %%
len(rows)
# Out:
# 529

# %%
rows[200]
# Out:
# ['\xa0\xa0\xa0\xa0— Amusan {3}SOUTEP12.67 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.9)4/22/2017',
#  '\xa0\xa0\xa0\xa0— Amusan {3}SO',
#  '',
#  'UTEP',
#  '12.67 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.9)',
#  '4/22/2017']

# %%
RealRows = []

# %%
for i in range(0,200):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [['(1) Masai RUSSELLSRKentucky12.36📺  (w: 2.0)4/1/2023',
#   '(1) Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.36📺  (w: 2.0)',
#   '4/1/2023'],
#  ['(1) Masai RUSSELLSR', '', 'Kentucky', '12.36📺  (w: 2.0)', '4/1/2023'],
#  ['(2) Brianna ROLLINSJRClemson12.39  (w: 1.7)6/8/2013',
#   '(2) Brianna ROLLINSJR',
#   '',
#   'Clemson',
#   '12.39  (w: 1.7)',
#   '6/8/2013'],
#  ['(2) Brianna ROLLINSJR', '', 'Clemson', '12.39  (w: 1.7)', '6/8/2013'],
#  ['(3) Alia ARMSTRONGJRLSU12.40  (w: 0.4)5/13/2023',
#   '(3) Alia ARMSTRONGJR',
#   '',
#   'LSU',
#   '12.40  (w: 0.4)',
#   '5/13/2023'],
#  ['(3) Alia ARMSTRONGJR', '', 'LSU', '12.40  (w: 0.4)', '5/13/2023'],
#  ['(3) Janeek BROWNSOArkansas12.40  (w: 0.6)6/8/2019',
#   '(3) Janeek BROWNSO',
#   '',
#   'Arkansas',
#   '12.40  (w: 0.6)',
#   '6/8/2019'],
#  ['(3) Janeek BROWNSO', '', 'Arkansas', '12.40  (w: 0.6)', '6/8/2019'],
#  ['(3) Jasmine CAMACHO-QUINNJRKentucky12.40  (w: 1.2)5/13/2018',
#   '(3) Jasmine CAMACHO-QUINNJR',
#   '',
#   'Kentucky',
#   '12.40  (w: 1.2)',
#   '5/13/2018'],
#  ['(3) Jasmine CAMACHO-QUINNJR',
#   '',
#   'Kentucky',
#   '12.40  (w: 1.2)',
#   '5/13/2018'],
#  ['(6) Ackera NUGENTJRArkansas12.43  (w: 0.4)5/13/2023',
#   '(6) Ackera NUGENTJR',
#   '',
#   'Arkansas',
#   '12.43  (w: 0.4)',
#   '5/13/2023'],
#  ['(6) Ackera NUGENTJR', '', 'Arkansas', '12.43  (w: 0.4)', '5/13/2023'],
#  ['(7) Demisha ROSWELLJRTexas Tech12.44 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)5/13/2022',
#   '(7) Demisha ROSWELLJR',
#   '',
#   'Texas Tech',
#   '12.44 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)',
#   '5/13/2022'],
#  ['(7) Demisha ROSWELLJR',
#   '',
#   'Texas Tech',
#   '12.44 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)',
#   '5/13/2022'],
#  ['(7) Tonea MARSHALLSRLSU12.44 qq = Performance occurred during a non-final round.  (w: 0.8)5/29/2021',
#   '(7) Tonea MARSHALLSR',
#   '',
#   'LSU',
#   '12.44 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '5/29/2021'],
#  ['(7) Tonea MARSHALLSR',
#   '',
#   'LSU',
#   '12.44 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Nugent {2}FRBaylor12.45 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)5/13/2022',
#   '\xa0\xa0\xa0\xa0— Nugent {2}FR',
#   '',
#   'Baylor',
#   '12.45 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Nugent {2}FR',
#   '',
#   'Baylor',
#   '12.45 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Russell {2}SRKentucky12.47  (w: 0.4)5/13/2023',
#   '\xa0\xa0\xa0\xa0— Russell {2}SR',
#   '',
#   'Kentucky',
#   '12.47  (w: 0.4)',
#   '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Russell {2}SR',
#   '',
#   'Kentucky',
#   '12.47  (w: 0.4)',
#   '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Rollins {2}JRClemson12.47 qq = Performance occurred during a non-final round.  (w: 1.2)6/6/2013',
#   '\xa0\xa0\xa0\xa0— Rollins {2}JR',
#   '',
#   'Clemson',
#   '12.47 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '6/6/2013'],
#  ['\xa0\xa0\xa0\xa0— Rollins {2}JR',
#   '',
#   'Clemson',
#   '12.47 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '6/6/2013'],
#  ['\xa0\xa0\xa0\xa0— Marshall {2}SRLSU12.48 qq = Performance occurred during a non-final round.  (w: 0.0)6/10/2021',
#   '\xa0\xa0\xa0\xa0— Marshall {2}SR',
#   '',
#   'LSU',
#   '12.48 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/10/2021'],
#  ['\xa0\xa0\xa0\xa0— Marshall {2}SR',
#   '',
#   'LSU',
#   '12.48 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/10/2021'],
#  ['(9) Ginnie POWELLSRSouthern California12.48   (w: 0.4)6/9/2006',
#   '(9) Ginnie POWELLSR',
#   '',
#   'Southern California',
#   '12.48   (w: 0.4)',
#   '6/9/2006'],
#  ['(9) Ginnie POWELLSR',
#   '',
#   'Southern California',
#   '12.48   (w: 0.4)',
#   '6/9/2006'],
#  ['\xa0\xa0\xa0\xa0— Russell {3}SRKentucky12.50  (w: 1.1)4/21/2023',
#   '\xa0\xa0\xa0\xa0— Russell {3}SR',
#   '',
#   'Kentucky',
#   '12.50  (w: 1.1)',
#   '4/21/2023'],
#  ['\xa0\xa0\xa0\xa0— Russell {3}SR',
#   '',
#   'Kentucky',
#   '12.50  (w: 1.1)',
#   '4/21/2023'],
#  ['(10) Keni HARRISONKentucky12.50  (w: 1.8)5/16/2015',
#   '(10) Keni HARRISON',
#   '',
#   'Kentucky',
#   '12.50  (w: 1.8)',
#   '5/16/2015'],
#  ['(10) Keni HARRISON', '', 'Kentucky', '12.50  (w: 1.8)', '5/16/2015'],
#  ['\xa0\xa0\xa0\xa0— Nugent {3}JRArkansas12.52  (w: 0.2)4/29/2023',
#   '\xa0\xa0\xa0\xa0— Nugent {3}JR',
#   '',
#   'Arkansas',
#   '12.52  (w: 0.2)',
#   '4/29/2023'],
#  ['\xa0\xa0\xa0\xa0— Nugent {3}JR',
#   '',
#   'Arkansas',
#   '12.52  (w: 0.2)',
#   '4/29/2023'],
#  ['\xa0\xa0\xa0\xa0— Marshall {3}SRLSU12.52 qq = Performance occurred during a non-final round.  (w: 1.6)5/13/2021',
#   '\xa0\xa0\xa0\xa0— Marshall {3}SR',
#   '',
#   'LSU',
#   '12.52 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '5/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Marshall {3}SR',
#   '',
#   'LSU',
#   '12.52 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '5/13/2021'],
#  ['(11) Chanel BRISSETTSOSouthern California12.52  (w: 0.6)6/8/2019',
#   '(11) Chanel BRISSETTSO',
#   '',
#   'Southern California',
#   '12.52  (w: 0.6)',
#   '6/8/2019'],
#  ['(11) Chanel BRISSETTSO',
#   '',
#   'Southern California',
#   '12.52  (w: 0.6)',
#   '6/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Brown {2}SOArkansas12.53 qq = Performance occurred during a non-final round.  (w: 1.1)6/6/2019',
#   '\xa0\xa0\xa0\xa0— Brown {2}SO',
#   '',
#   'Arkansas',
#   '12.53 qq = Performance occurred during a non-final round.  (w: 1.1)',
#   '6/6/2019'],
#  ['\xa0\xa0\xa0\xa0— Brown {2}SO',
#   '',
#   'Arkansas',
#   '12.53 qq = Performance occurred during a non-final round.  (w: 1.1)',
#   '6/6/2019'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {2}JRLSU12.54 qq = Performance occurred during a non-final round.  (w: 0.0)6/8/2023',
#   '\xa0\xa0\xa0\xa0— Armstrong {2}JR',
#   '',
#   'LSU',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {2}JR',
#   '',
#   'LSU',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/8/2023'],
#  ['(12) Anna COCKRELLSRSouthern California12.54 qq = Performance occurred during a non-final round.  (w: 0.0)6/10/2021',
#   '(12) Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/10/2021'],
#  ['(12) Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/10/2021'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {2}JRKentucky12.54 qq = Performance occurred during a non-final round.  (w: 2.0)6/7/2018',
#   '\xa0\xa0\xa0\xa0— Camacho-Quinn {2}JR',
#   '',
#   'Kentucky',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {2}JR',
#   '',
#   'Kentucky',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Nugent {4}JRArkansas12.55 qq = Performance occurred during a non-final round.  (w: 0.5)6/8/2023',
#   '\xa0\xa0\xa0\xa0— Nugent {4}JR',
#   '',
#   'Arkansas',
#   '12.55 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Nugent {4}JR',
#   '',
#   'Arkansas',
#   '12.55 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {3}SOLSU12.55 qq = Performance occurred during a non-final round.  (w: 0.2)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Armstrong {3}SO',
#   '',
#   'LSU',
#   '12.55 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {3}SO',
#   '',
#   'LSU',
#   '12.55 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Brown {3}SOArkansas12.55  (w: 1.3)5/11/2019',
#   '\xa0\xa0\xa0\xa0— Brown {3}SO',
#   '',
#   'Arkansas',
#   '12.55  (w: 1.3)',
#   '5/11/2019'],
#  ['\xa0\xa0\xa0\xa0— Brown {3}SO',
#   '',
#   'Arkansas',
#   '12.55  (w: 1.3)',
#   '5/11/2019'],
#  ['\xa0\xa0\xa0\xa0— Harrison {2}Kentucky12.55  (w: 1.7)6/13/2015',
#   '\xa0\xa0\xa0\xa0— Harrison {2}',
#   '',
#   'Kentucky',
#   '12.55  (w: 1.7)',
#   '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Harrison {2}',
#   '',
#   'Kentucky',
#   '12.55  (w: 1.7)',
#   '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Powell {2}SRSouthern California12.55 qq = Performance occurred during a non-final round. 6/7/2006',
#   '\xa0\xa0\xa0\xa0— Powell {2}SR',
#   '',
#   'Southern California',
#   '12.55 qq = Performance occurred during a non-final round. ',
#   '6/7/2006'],
#  ['\xa0\xa0\xa0\xa0— Powell {2}SR',
#   '',
#   'Southern California',
#   '12.55 qq = Performance occurred during a non-final round. ',
#   '6/7/2006'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {4}JRLSU12.56  (w: 0.2)4/29/2023',
#   '\xa0\xa0\xa0\xa0— Armstrong {4}JR',
#   '',
#   'LSU',
#   '12.56  (w: 0.2)',
#   '4/29/2023'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {4}JR',
#   '',
#   'LSU',
#   '12.56  (w: 0.2)',
#   '4/29/2023'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {5}JRLSU12.57  (w: 2.0)4/1/2023',
#   '\xa0\xa0\xa0\xa0— Armstrong {5}JR',
#   '',
#   'LSU',
#   '12.57  (w: 2.0)',
#   '4/1/2023'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {5}JR',
#   '',
#   'LSU',
#   '12.57  (w: 2.0)',
#   '4/1/2023'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {6}SOLSU12.57  (w: -0.2)6/11/2022',
#   '\xa0\xa0\xa0\xa0— Armstrong {6}SO',
#   '',
#   'LSU',
#   '12.57  (w: -0.2)',
#   '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {6}SO',
#   '',
#   'LSU',
#   '12.57  (w: -0.2)',
#   '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Brown {4}SOArkansas12.57  (w: 1.6)4/26/2019',
#   '\xa0\xa0\xa0\xa0— Brown {4}SO',
#   '',
#   'Arkansas',
#   '12.57  (w: 1.6)',
#   '4/26/2019'],
#  ['\xa0\xa0\xa0\xa0— Brown {4}SO',
#   '',
#   'Arkansas',
#   '12.57  (w: 1.6)',
#   '4/26/2019'],
#  ['(13) Tobi AMUSANSOUTEP12.57  (w: 1.6)6/10/2017',
#   '(13) Tobi AMUSANSO',
#   '',
#   'UTEP',
#   '12.57  (w: 1.6)',
#   '6/10/2017'],
#  ['(13) Tobi AMUSANSO', '', 'UTEP', '12.57  (w: 1.6)', '6/10/2017'],
#  ['(14) Grace STARKSOFlorida12.58  (w: 1.9)4/15/2022',
#   '(14) Grace STARKSO',
#   '',
#   'Florida',
#   '12.58  (w: 1.9)',
#   '4/15/2022'],
#  ['(14) Grace STARKSO', '', 'Florida', '12.58  (w: 1.9)', '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Cockrell {2}SRSouthern California12.58  (w: 0.4)6/12/2021',
#   '\xa0\xa0\xa0\xa0— Cockrell {2}SR',
#   '',
#   'Southern California',
#   '12.58  (w: 0.4)',
#   '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Cockrell {2}SR',
#   '',
#   'Southern California',
#   '12.58  (w: 0.4)',
#   '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {3}JRKentucky12.58 qq = Performance occurred during a non-final round.  (w: 1.6)5/12/2018',
#   '\xa0\xa0\xa0\xa0— Camacho-Quinn {3}JR',
#   '',
#   'Kentucky',
#   '12.58 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '5/12/2018'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {3}JR',
#   '',
#   'Kentucky',
#   '12.58 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '5/12/2018'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {4}SOKentucky12.58  (w: 1.6)6/10/2017',
#   '\xa0\xa0\xa0\xa0— Camacho-Quinn {4}SO',
#   '',
#   'Kentucky',
#   '12.58  (w: 1.6)',
#   '6/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {4}SO',
#   '',
#   'Kentucky',
#   '12.58  (w: 1.6)',
#   '6/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {7}JRLSU12.59 qq = Performance occurred during a non-final round.  (w: 2.0)5/27/2023',
#   '\xa0\xa0\xa0\xa0— Armstrong {7}JR',
#   '',
#   'LSU',
#   '12.59 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {7}JR',
#   '',
#   'LSU',
#   '12.59 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {5}JRKentucky12.60 qq = Performance occurred during a non-final round.  (w: 0.7)5/25/2018',
#   '\xa0\xa0\xa0\xa0— Camacho-Quinn {5}JR',
#   '',
#   'Kentucky',
#   '12.60 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {5}JR',
#   '',
#   'Kentucky',
#   '12.60 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/25/2018'],
#  ['(15) Cindy OFILIMichigan12.60  (w: 1.7)6/13/2015',
#   '(15) Cindy OFILI',
#   '',
#   'Michigan',
#   '12.60  (w: 1.7)',
#   '6/13/2015'],
#  ['(15) Cindy OFILI', '', 'Michigan', '12.60  (w: 1.7)', '6/13/2015'],
#  ['(15) Priscilla LOPESNebraska12.60   (w: 0.4)6/9/2006',
#   '(15) Priscilla LOPES',
#   '',
#   'Nebraska',
#   '12.60   (w: 0.4)',
#   '6/9/2006'],
#  ['(15) Priscilla LOPES', '', 'Nebraska', '12.60   (w: 0.4)', '6/9/2006'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {8}SOLSU12.61  (w: 1.9)4/15/2022',
#   '\xa0\xa0\xa0\xa0— Armstrong {8}SO',
#   '',
#   'LSU',
#   '12.61  (w: 1.9)',
#   '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {8}SO',
#   '',
#   'LSU',
#   '12.61  (w: 1.9)',
#   '4/15/2022'],
#  ['(17) Queen CLAYEVirginia Tech12.61  4/24/2010',
#   '(17) Queen CLAYE',
#   '',
#   'Virginia Tech',
#   '12.61  ',
#   '4/24/2010'],
#  ['(17) Queen CLAYE', '', 'Virginia Tech', '12.61  ', '4/24/2010'],
#  ['\xa0\xa0\xa0\xa0— Powell {3}Southern California12.61 AA = Performance occurred at altitude (>1000 meters above sea level) 5/27/2006',
#   '\xa0\xa0\xa0\xa0— Powell {3}',
#   '',
#   'Southern California',
#   '12.61 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/27/2006'],
#  ['\xa0\xa0\xa0\xa0— Powell {3}',
#   '',
#   'Southern California',
#   '12.61 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/27/2006'],
#  ['(17) Gail DEVERSUCLA12.61  5/21/1988',
#   '(17) Gail DEVERS',
#   '',
#   'UCLA',
#   '12.61  ',
#   '5/21/1988'],
#  ['(17) Gail DEVERS', '', 'UCLA', '12.61  ', '5/21/1988'],
#  ['\xa0\xa0\xa0\xa0— Harrison {3}Kentucky12.62 qq = Performance occurred during a non-final round.  (w: 1.2)5/30/2015',
#   '\xa0\xa0\xa0\xa0— Harrison {3}',
#   '',
#   'Kentucky',
#   '12.62 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '5/30/2015'],
#  ['\xa0\xa0\xa0\xa0— Harrison {3}',
#   '',
#   'Kentucky',
#   '12.62 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '5/30/2015'],
#  ['\xa0\xa0\xa0\xa0— Harrison {4}Kentucky12.62  (w: 0.9)4/24/2015',
#   '\xa0\xa0\xa0\xa0— Harrison {4}',
#   '',
#   'Kentucky',
#   '12.62  (w: 0.9)',
#   '4/24/2015'],
#  ['\xa0\xa0\xa0\xa0— Harrison {4}',
#   '',
#   'Kentucky',
#   '12.62  (w: 0.9)',
#   '4/24/2015'],
#  ['(19) Nichole DENBYSRTexas12.62   (w: 1.7)6/11/2004',
#   '(19) Nichole DENBYSR',
#   '',
#   'Texas',
#   '12.62   (w: 1.7)',
#   '6/11/2004'],
#  ['(19) Nichole DENBYSR', '', 'Texas', '12.62   (w: 1.7)', '6/11/2004'],
#  ['(20) Paula  SALMONSRNorth Carolina A&T12.63  (w: 1.9)4/15/2022',
#   '(20) Paula  SALMONSR',
#   '',
#   'North Carolina A&T',
#   '12.63  (w: 1.9)',
#   '4/15/2022'],
#  ['(20) Paula  SALMONSR',
#   '',
#   'North Carolina A&T',
#   '12.63  (w: 1.9)',
#   '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Amusan {2}SOUTEP12.63 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)3/25/2017',
#   '\xa0\xa0\xa0\xa0— Amusan {2}SO',
#   '',
#   'UTEP',
#   '12.63 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)',
#   '3/25/2017'],
#  ['\xa0\xa0\xa0\xa0— Amusan {2}SO',
#   '',
#   'UTEP',
#   '12.63 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)',
#   '3/25/2017'],
#  ['\xa0\xa0\xa0\xa0— Lopes {2}Nebraska12.63  5/14/2006',
#   '\xa0\xa0\xa0\xa0— Lopes {2}',
#   '',
#   'Nebraska',
#   '12.63  ',
#   '5/14/2006'],
#  ['\xa0\xa0\xa0\xa0— Lopes {2}', '', 'Nebraska', '12.63  ', '5/14/2006'],
#  ['\xa0\xa0\xa0\xa0— Powell {4}Southern California12.64  5/14/2006',
#   '\xa0\xa0\xa0\xa0— Powell {4}',
#   '',
#   'Southern California',
#   '12.64  ',
#   '5/14/2006'],
#  ['\xa0\xa0\xa0\xa0— Powell {4}',
#   '',
#   'Southern California',
#   '12.64  ',
#   '5/14/2006'],
#  ['\xa0\xa0\xa0\xa0— Lopes {3}Nebraska12.64   (w: 1.7)6/11/2004',
#   '\xa0\xa0\xa0\xa0— Lopes {3}',
#   '',
#   'Nebraska',
#   '12.64   (w: 1.7)',
#   '6/11/2004'],
#  ['\xa0\xa0\xa0\xa0— Lopes {3}',
#   '',
#   'Nebraska',
#   '12.64   (w: 1.7)',
#   '6/11/2004'],
#  ['(21) Talie BONDSSRArizona12.65  (w: 1.2)4/12/2023',
#   '(21) Talie BONDSSR',
#   '',
#   'Arizona',
#   '12.65  (w: 1.2)',
#   '4/12/2023'],
#  ['(21) Talie BONDSSR', '', 'Arizona', '12.65  (w: 1.2)', '4/12/2023'],
#  ['(21) Rushelle BURTONSOTexas12.65  (w: 0.2)5/13/2018',
#   '(21) Rushelle BURTONSO',
#   '',
#   'Texas',
#   '12.65  (w: 0.2)',
#   '5/13/2018'],
#  ['(21) Rushelle BURTONSO', '', 'Texas', '12.65  (w: 0.2)', '5/13/2018'],
#  ['\xa0\xa0\xa0\xa0— Burton {2}FRTexas12.65  (w: 1.6)6/10/2017',
#   '\xa0\xa0\xa0\xa0— Burton {2}FR',
#   '',
#   'Texas',
#   '12.65  (w: 1.6)',
#   '6/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Burton {2}FR',
#   '',
#   'Texas',
#   '12.65  (w: 1.6)',
#   '6/10/2017'],
#  ['(23) Jasmine JONESSOSouthern California12.66  (w: -0.2)6/11/2022',
#   '(23) Jasmine JONESSO',
#   '',
#   'Southern California',
#   '12.66  (w: -0.2)',
#   '6/11/2022'],
#  ['(23) Jasmine JONESSO',
#   '',
#   'Southern California',
#   '12.66  (w: -0.2)',
#   '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Salmon {2}SRNorth Carolina A&T12.66  (w: 1.2)4/22/2022',
#   '\xa0\xa0\xa0\xa0— Salmon {2}SR',
#   '',
#   'North Carolina A&T',
#   '12.66  (w: 1.2)',
#   '4/22/2022'],
#  ['\xa0\xa0\xa0\xa0— Salmon {2}SR',
#   '',
#   'North Carolina A&T',
#   '12.66  (w: 1.2)',
#   '4/22/2022'],
#  ['\xa0\xa0\xa0\xa0— Marshall {4}JRLSU12.66  (w: 0.6)6/8/2019',
#   '\xa0\xa0\xa0\xa0— Marshall {4}JR',
#   '',
#   'LSU',
#   '12.66  (w: 0.6)',
#   '6/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Marshall {4}JR',
#   '',
#   'LSU',
#   '12.66  (w: 0.6)',
#   '6/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}Michigan12.66  (w: 2.0)4/16/2016',
#   '\xa0\xa0\xa0\xa0— Ofili {2}',
#   '',
#   'Michigan',
#   '12.66  (w: 2.0)',
#   '4/16/2016'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}',
#   '',
#   'Michigan',
#   '12.66  (w: 2.0)',
#   '4/16/2016'],
#  ['\xa0\xa0\xa0\xa0— Harrison {5}Kentucky12.66 qq = Performance occurred during a non-final round.  (w: 0.4)5/29/2015',
#   '\xa0\xa0\xa0\xa0— Harrison {5}',
#   '',
#   'Kentucky',
#   '12.66 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '5/29/2015'],
#  ['\xa0\xa0\xa0\xa0— Harrison {5}',
#   '',
#   'Kentucky',
#   '12.66 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '5/29/2015'],
#  ['(24) Alexis GLASCOSOCoastal Carolina12.67 qq = Performance occurred during a non-final round.  (w: 1.9)5/27/2023',
#   '(24) Alexis GLASCOSO',
#   '',
#   'Coastal Carolina',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/27/2023'],
#  ['(24) Alexis GLASCOSO',
#   '',
#   'Coastal Carolina',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Bonds {2}SRArizona12.67   (w: 1.2)4/8/2023',
#   '\xa0\xa0\xa0\xa0— Bonds {2}SR',
#   '',
#   'Arizona',
#   '12.67   (w: 1.2)',
#   '4/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Bonds {2}SR',
#   '',
#   'Arizona',
#   '12.67   (w: 1.2)',
#   '4/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Bonds {3}SRArizona12.67  (w: 1.2)4/6/2023',
#   '\xa0\xa0\xa0\xa0— Bonds {3}SR',
#   '',
#   'Arizona',
#   '12.67  (w: 1.2)',
#   '4/6/2023'],
#  ['\xa0\xa0\xa0\xa0— Bonds {3}SR',
#   '',
#   'Arizona',
#   '12.67  (w: 1.2)',
#   '4/6/2023'],
#  ['\xa0\xa0\xa0\xa0— Stark {2}SOFlorida12.67 qq = Performance occurred during a non-final round.  (w: 1.5)4/16/2022',
#   '\xa0\xa0\xa0\xa0— Stark {2}SO',
#   '',
#   'Florida',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '4/16/2022'],
#  ['\xa0\xa0\xa0\xa0— Stark {2}SO',
#   '',
#   'Florida',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '4/16/2022'],
#  ['\xa0\xa0\xa0\xa0— Stark {3}SOFlorida12.67  (w: 1.5)4/15/2022',
#   '\xa0\xa0\xa0\xa0— Stark {3}SO',
#   '',
#   'Florida',
#   '12.67  (w: 1.5)',
#   '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Stark {3}SO',
#   '',
#   'Florida',
#   '12.67  (w: 1.5)',
#   '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Marshall {5}JRLSU12.67 qq = Performance occurred during a non-final round.  (w: 0.8)6/6/2019',
#   '\xa0\xa0\xa0\xa0— Marshall {5}JR',
#   '',
#   'LSU',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/6/2019'],
#  ['\xa0\xa0\xa0\xa0— Marshall {5}JR',
#   '',
#   'LSU',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/6/2019']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Masai RUSSELLSRKentucky12.36📺  (w: 2.0)4/1/2023',
#   '(1) Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '12.36📺  (w: 2.0)',
#   '4/1/2023'],
#  ['(2) Brianna ROLLINSJRClemson12.39  (w: 1.7)6/8/2013',
#   '(2) Brianna ROLLINSJR',
#   '',
#   'Clemson',
#   '12.39  (w: 1.7)',
#   '6/8/2013'],
#  ['(3) Alia ARMSTRONGJRLSU12.40  (w: 0.4)5/13/2023',
#   '(3) Alia ARMSTRONGJR',
#   '',
#   'LSU',
#   '12.40  (w: 0.4)',
#   '5/13/2023'],
#  ['(3) Janeek BROWNSOArkansas12.40  (w: 0.6)6/8/2019',
#   '(3) Janeek BROWNSO',
#   '',
#   'Arkansas',
#   '12.40  (w: 0.6)',
#   '6/8/2019'],
#  ['(3) Jasmine CAMACHO-QUINNJRKentucky12.40  (w: 1.2)5/13/2018',
#   '(3) Jasmine CAMACHO-QUINNJR',
#   '',
#   'Kentucky',
#   '12.40  (w: 1.2)',
#   '5/13/2018'],
#  ['(6) Ackera NUGENTJRArkansas12.43  (w: 0.4)5/13/2023',
#   '(6) Ackera NUGENTJR',
#   '',
#   'Arkansas',
#   '12.43  (w: 0.4)',
#   '5/13/2023'],
#  ['(7) Demisha ROSWELLJRTexas Tech12.44 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)5/13/2022',
#   '(7) Demisha ROSWELLJR',
#   '',
#   'Texas Tech',
#   '12.44 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)',
#   '5/13/2022'],
#  ['(7) Tonea MARSHALLSRLSU12.44 qq = Performance occurred during a non-final round.  (w: 0.8)5/29/2021',
#   '(7) Tonea MARSHALLSR',
#   '',
#   'LSU',
#   '12.44 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Nugent {2}FRBaylor12.45 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)5/13/2022',
#   '\xa0\xa0\xa0\xa0— Nugent {2}FR',
#   '',
#   'Baylor',
#   '12.45 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.5)',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Russell {2}SRKentucky12.47  (w: 0.4)5/13/2023',
#   '\xa0\xa0\xa0\xa0— Russell {2}SR',
#   '',
#   'Kentucky',
#   '12.47  (w: 0.4)',
#   '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Rollins {2}JRClemson12.47 qq = Performance occurred during a non-final round.  (w: 1.2)6/6/2013',
#   '\xa0\xa0\xa0\xa0— Rollins {2}JR',
#   '',
#   'Clemson',
#   '12.47 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '6/6/2013'],
#  ['\xa0\xa0\xa0\xa0— Marshall {2}SRLSU12.48 qq = Performance occurred during a non-final round.  (w: 0.0)6/10/2021',
#   '\xa0\xa0\xa0\xa0— Marshall {2}SR',
#   '',
#   'LSU',
#   '12.48 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/10/2021'],
#  ['(9) Ginnie POWELLSRSouthern California12.48   (w: 0.4)6/9/2006',
#   '(9) Ginnie POWELLSR',
#   '',
#   'Southern California',
#   '12.48   (w: 0.4)',
#   '6/9/2006'],
#  ['\xa0\xa0\xa0\xa0— Russell {3}SRKentucky12.50  (w: 1.1)4/21/2023',
#   '\xa0\xa0\xa0\xa0— Russell {3}SR',
#   '',
#   'Kentucky',
#   '12.50  (w: 1.1)',
#   '4/21/2023'],
#  ['(10) Keni HARRISONKentucky12.50  (w: 1.8)5/16/2015',
#   '(10) Keni HARRISON',
#   '',
#   'Kentucky',
#   '12.50  (w: 1.8)',
#   '5/16/2015'],
#  ['\xa0\xa0\xa0\xa0— Nugent {3}JRArkansas12.52  (w: 0.2)4/29/2023',
#   '\xa0\xa0\xa0\xa0— Nugent {3}JR',
#   '',
#   'Arkansas',
#   '12.52  (w: 0.2)',
#   '4/29/2023'],
#  ['\xa0\xa0\xa0\xa0— Marshall {3}SRLSU12.52 qq = Performance occurred during a non-final round.  (w: 1.6)5/13/2021',
#   '\xa0\xa0\xa0\xa0— Marshall {3}SR',
#   '',
#   'LSU',
#   '12.52 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '5/13/2021'],
#  ['(11) Chanel BRISSETTSOSouthern California12.52  (w: 0.6)6/8/2019',
#   '(11) Chanel BRISSETTSO',
#   '',
#   'Southern California',
#   '12.52  (w: 0.6)',
#   '6/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Brown {2}SOArkansas12.53 qq = Performance occurred during a non-final round.  (w: 1.1)6/6/2019',
#   '\xa0\xa0\xa0\xa0— Brown {2}SO',
#   '',
#   'Arkansas',
#   '12.53 qq = Performance occurred during a non-final round.  (w: 1.1)',
#   '6/6/2019'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {2}JRLSU12.54 qq = Performance occurred during a non-final round.  (w: 0.0)6/8/2023',
#   '\xa0\xa0\xa0\xa0— Armstrong {2}JR',
#   '',
#   'LSU',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/8/2023'],
#  ['(12) Anna COCKRELLSRSouthern California12.54 qq = Performance occurred during a non-final round.  (w: 0.0)6/10/2021',
#   '(12) Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/10/2021'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {2}JRKentucky12.54 qq = Performance occurred during a non-final round.  (w: 2.0)6/7/2018',
#   '\xa0\xa0\xa0\xa0— Camacho-Quinn {2}JR',
#   '',
#   'Kentucky',
#   '12.54 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Nugent {4}JRArkansas12.55 qq = Performance occurred during a non-final round.  (w: 0.5)6/8/2023',
#   '\xa0\xa0\xa0\xa0— Nugent {4}JR',
#   '',
#   'Arkansas',
#   '12.55 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {3}SOLSU12.55 qq = Performance occurred during a non-final round.  (w: 0.2)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Armstrong {3}SO',
#   '',
#   'LSU',
#   '12.55 qq = Performance occurred during a non-final round.  (w: 0.2)',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Brown {3}SOArkansas12.55  (w: 1.3)5/11/2019',
#   '\xa0\xa0\xa0\xa0— Brown {3}SO',
#   '',
#   'Arkansas',
#   '12.55  (w: 1.3)',
#   '5/11/2019'],
#  ['\xa0\xa0\xa0\xa0— Harrison {2}Kentucky12.55  (w: 1.7)6/13/2015',
#   '\xa0\xa0\xa0\xa0— Harrison {2}',
#   '',
#   'Kentucky',
#   '12.55  (w: 1.7)',
#   '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Powell {2}SRSouthern California12.55 qq = Performance occurred during a non-final round. 6/7/2006',
#   '\xa0\xa0\xa0\xa0— Powell {2}SR',
#   '',
#   'Southern California',
#   '12.55 qq = Performance occurred during a non-final round. ',
#   '6/7/2006'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {4}JRLSU12.56  (w: 0.2)4/29/2023',
#   '\xa0\xa0\xa0\xa0— Armstrong {4}JR',
#   '',
#   'LSU',
#   '12.56  (w: 0.2)',
#   '4/29/2023'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {5}JRLSU12.57  (w: 2.0)4/1/2023',
#   '\xa0\xa0\xa0\xa0— Armstrong {5}JR',
#   '',
#   'LSU',
#   '12.57  (w: 2.0)',
#   '4/1/2023'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {6}SOLSU12.57  (w: -0.2)6/11/2022',
#   '\xa0\xa0\xa0\xa0— Armstrong {6}SO',
#   '',
#   'LSU',
#   '12.57  (w: -0.2)',
#   '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Brown {4}SOArkansas12.57  (w: 1.6)4/26/2019',
#   '\xa0\xa0\xa0\xa0— Brown {4}SO',
#   '',
#   'Arkansas',
#   '12.57  (w: 1.6)',
#   '4/26/2019'],
#  ['(13) Tobi AMUSANSOUTEP12.57  (w: 1.6)6/10/2017',
#   '(13) Tobi AMUSANSO',
#   '',
#   'UTEP',
#   '12.57  (w: 1.6)',
#   '6/10/2017'],
#  ['(14) Grace STARKSOFlorida12.58  (w: 1.9)4/15/2022',
#   '(14) Grace STARKSO',
#   '',
#   'Florida',
#   '12.58  (w: 1.9)',
#   '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Cockrell {2}SRSouthern California12.58  (w: 0.4)6/12/2021',
#   '\xa0\xa0\xa0\xa0— Cockrell {2}SR',
#   '',
#   'Southern California',
#   '12.58  (w: 0.4)',
#   '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {3}JRKentucky12.58 qq = Performance occurred during a non-final round.  (w: 1.6)5/12/2018',
#   '\xa0\xa0\xa0\xa0— Camacho-Quinn {3}JR',
#   '',
#   'Kentucky',
#   '12.58 qq = Performance occurred during a non-final round.  (w: 1.6)',
#   '5/12/2018'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {4}SOKentucky12.58  (w: 1.6)6/10/2017',
#   '\xa0\xa0\xa0\xa0— Camacho-Quinn {4}SO',
#   '',
#   'Kentucky',
#   '12.58  (w: 1.6)',
#   '6/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {7}JRLSU12.59 qq = Performance occurred during a non-final round.  (w: 2.0)5/27/2023',
#   '\xa0\xa0\xa0\xa0— Armstrong {7}JR',
#   '',
#   'LSU',
#   '12.59 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Camacho-Quinn {5}JRKentucky12.60 qq = Performance occurred during a non-final round.  (w: 0.7)5/25/2018',
#   '\xa0\xa0\xa0\xa0— Camacho-Quinn {5}JR',
#   '',
#   'Kentucky',
#   '12.60 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/25/2018'],
#  ['(15) Cindy OFILIMichigan12.60  (w: 1.7)6/13/2015',
#   '(15) Cindy OFILI',
#   '',
#   'Michigan',
#   '12.60  (w: 1.7)',
#   '6/13/2015'],
#  ['(15) Priscilla LOPESNebraska12.60   (w: 0.4)6/9/2006',
#   '(15) Priscilla LOPES',
#   '',
#   'Nebraska',
#   '12.60   (w: 0.4)',
#   '6/9/2006'],
#  ['\xa0\xa0\xa0\xa0— Armstrong {8}SOLSU12.61  (w: 1.9)4/15/2022',
#   '\xa0\xa0\xa0\xa0— Armstrong {8}SO',
#   '',
#   'LSU',
#   '12.61  (w: 1.9)',
#   '4/15/2022'],
#  ['(17) Queen CLAYEVirginia Tech12.61  4/24/2010',
#   '(17) Queen CLAYE',
#   '',
#   'Virginia Tech',
#   '12.61  ',
#   '4/24/2010'],
#  ['\xa0\xa0\xa0\xa0— Powell {3}Southern California12.61 AA = Performance occurred at altitude (>1000 meters above sea level) 5/27/2006',
#   '\xa0\xa0\xa0\xa0— Powell {3}',
#   '',
#   'Southern California',
#   '12.61 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/27/2006'],
#  ['(17) Gail DEVERSUCLA12.61  5/21/1988',
#   '(17) Gail DEVERS',
#   '',
#   'UCLA',
#   '12.61  ',
#   '5/21/1988'],
#  ['\xa0\xa0\xa0\xa0— Harrison {3}Kentucky12.62 qq = Performance occurred during a non-final round.  (w: 1.2)5/30/2015',
#   '\xa0\xa0\xa0\xa0— Harrison {3}',
#   '',
#   'Kentucky',
#   '12.62 qq = Performance occurred during a non-final round.  (w: 1.2)',
#   '5/30/2015'],
#  ['\xa0\xa0\xa0\xa0— Harrison {4}Kentucky12.62  (w: 0.9)4/24/2015',
#   '\xa0\xa0\xa0\xa0— Harrison {4}',
#   '',
#   'Kentucky',
#   '12.62  (w: 0.9)',
#   '4/24/2015'],
#  ['(19) Nichole DENBYSRTexas12.62   (w: 1.7)6/11/2004',
#   '(19) Nichole DENBYSR',
#   '',
#   'Texas',
#   '12.62   (w: 1.7)',
#   '6/11/2004'],
#  ['(20) Paula  SALMONSRNorth Carolina A&T12.63  (w: 1.9)4/15/2022',
#   '(20) Paula  SALMONSR',
#   '',
#   'North Carolina A&T',
#   '12.63  (w: 1.9)',
#   '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Amusan {2}SOUTEP12.63 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)3/25/2017',
#   '\xa0\xa0\xa0\xa0— Amusan {2}SO',
#   '',
#   'UTEP',
#   '12.63 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.3)',
#   '3/25/2017'],
#  ['\xa0\xa0\xa0\xa0— Lopes {2}Nebraska12.63  5/14/2006',
#   '\xa0\xa0\xa0\xa0— Lopes {2}',
#   '',
#   'Nebraska',
#   '12.63  ',
#   '5/14/2006'],
#  ['\xa0\xa0\xa0\xa0— Powell {4}Southern California12.64  5/14/2006',
#   '\xa0\xa0\xa0\xa0— Powell {4}',
#   '',
#   'Southern California',
#   '12.64  ',
#   '5/14/2006'],
#  ['\xa0\xa0\xa0\xa0— Lopes {3}Nebraska12.64   (w: 1.7)6/11/2004',
#   '\xa0\xa0\xa0\xa0— Lopes {3}',
#   '',
#   'Nebraska',
#   '12.64   (w: 1.7)',
#   '6/11/2004'],
#  ['(21) Talie BONDSSRArizona12.65  (w: 1.2)4/12/2023',
#   '(21) Talie BONDSSR',
#   '',
#   'Arizona',
#   '12.65  (w: 1.2)',
#   '4/12/2023'],
#  ['(21) Rushelle BURTONSOTexas12.65  (w: 0.2)5/13/2018',
#   '(21) Rushelle BURTONSO',
#   '',
#   'Texas',
#   '12.65  (w: 0.2)',
#   '5/13/2018'],
#  ['\xa0\xa0\xa0\xa0— Burton {2}FRTexas12.65  (w: 1.6)6/10/2017',
#   '\xa0\xa0\xa0\xa0— Burton {2}FR',
#   '',
#   'Texas',
#   '12.65  (w: 1.6)',
#   '6/10/2017'],
#  ['(23) Jasmine JONESSOSouthern California12.66  (w: -0.2)6/11/2022',
#   '(23) Jasmine JONESSO',
#   '',
#   'Southern California',
#   '12.66  (w: -0.2)',
#   '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Salmon {2}SRNorth Carolina A&T12.66  (w: 1.2)4/22/2022',
#   '\xa0\xa0\xa0\xa0— Salmon {2}SR',
#   '',
#   'North Carolina A&T',
#   '12.66  (w: 1.2)',
#   '4/22/2022'],
#  ['\xa0\xa0\xa0\xa0— Marshall {4}JRLSU12.66  (w: 0.6)6/8/2019',
#   '\xa0\xa0\xa0\xa0— Marshall {4}JR',
#   '',
#   'LSU',
#   '12.66  (w: 0.6)',
#   '6/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}Michigan12.66  (w: 2.0)4/16/2016',
#   '\xa0\xa0\xa0\xa0— Ofili {2}',
#   '',
#   'Michigan',
#   '12.66  (w: 2.0)',
#   '4/16/2016'],
#  ['\xa0\xa0\xa0\xa0— Harrison {5}Kentucky12.66 qq = Performance occurred during a non-final round.  (w: 0.4)5/29/2015',
#   '\xa0\xa0\xa0\xa0— Harrison {5}',
#   '',
#   'Kentucky',
#   '12.66 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '5/29/2015'],
#  ['(24) Alexis GLASCOSOCoastal Carolina12.67 qq = Performance occurred during a non-final round.  (w: 1.9)5/27/2023',
#   '(24) Alexis GLASCOSO',
#   '',
#   'Coastal Carolina',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Bonds {2}SRArizona12.67   (w: 1.2)4/8/2023',
#   '\xa0\xa0\xa0\xa0— Bonds {2}SR',
#   '',
#   'Arizona',
#   '12.67   (w: 1.2)',
#   '4/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Bonds {3}SRArizona12.67  (w: 1.2)4/6/2023',
#   '\xa0\xa0\xa0\xa0— Bonds {3}SR',
#   '',
#   'Arizona',
#   '12.67  (w: 1.2)',
#   '4/6/2023'],
#  ['\xa0\xa0\xa0\xa0— Stark {2}SOFlorida12.67 qq = Performance occurred during a non-final round.  (w: 1.5)4/16/2022',
#   '\xa0\xa0\xa0\xa0— Stark {2}SO',
#   '',
#   'Florida',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '4/16/2022'],
#  ['\xa0\xa0\xa0\xa0— Stark {3}SOFlorida12.67  (w: 1.5)4/15/2022',
#   '\xa0\xa0\xa0\xa0— Stark {3}SO',
#   '',
#   'Florida',
#   '12.67  (w: 1.5)',
#   '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Marshall {5}JRLSU12.67 qq = Performance occurred during a non-final round.  (w: 0.8)6/6/2019',
#   '\xa0\xa0\xa0\xa0— Marshall {5}JR',
#   '',
#   'LSU',
#   '12.67 qq = Performance occurred during a non-final round.  (w: 0.8)',
#   '6/6/2019']]

# %%
len(RealRealRows)
# Out:
# 66

# %%
RealRealRows[4][1]
# Out:
# '(3) Jasmine CAMACHO-QUINNJR'

# %%
Names = []
for i in range(0,len(RealRealRows)):
    Name = RealRealRows[i][1]
    Names.append(Name)
Names
# Out:
# ['(1) Masai RUSSELLSR',
#  '(2) Brianna ROLLINSJR',
#  '(3) Alia ARMSTRONGJR',
#  '(3) Janeek BROWNSO',
#  '(3) Jasmine CAMACHO-QUINNJR',
#  '(6) Ackera NUGENTJR',
#  '(7) Demisha ROSWELLJR',
#  '(7) Tonea MARSHALLSR',
#  '\xa0\xa0\xa0\xa0— Nugent {2}FR',
#  '\xa0\xa0\xa0\xa0— Russell {2}SR',
#  '\xa0\xa0\xa0\xa0— Rollins {2}JR',
#  '\xa0\xa0\xa0\xa0— Marshall {2}SR',
#  '(9) Ginnie POWELLSR',
#  '\xa0\xa0\xa0\xa0— Russell {3}SR',
#  '(10) Keni HARRISON',
#  '\xa0\xa0\xa0\xa0— Nugent {3}JR',
#  '\xa0\xa0\xa0\xa0— Marshall {3}SR',
#  '(11) Chanel BRISSETTSO',
#  '\xa0\xa0\xa0\xa0— Brown {2}SO',
#  '\xa0\xa0\xa0\xa0— Armstrong {2}JR',
#  '(12) Anna COCKRELLSR',
#  '\xa0\xa0\xa0\xa0— Camacho-Quinn {2}JR',
#  '\xa0\xa0\xa0\xa0— Nugent {4}JR',
#  '\xa0\xa0\xa0\xa0— Armstrong {3}SO',
#  '\xa0\xa0\xa0\xa0— Brown {3}SO',
#  '\xa0\xa0\xa0\xa0— Harrison {2}',
#  '\xa0\xa0\xa0\xa0— Powell {2}SR',
#  '\xa0\xa0\xa0\xa0— Armstrong {4}JR',
#  '\xa0\xa0\xa0\xa0— Armstrong {5}JR',
#  '\xa0\xa0\xa0\xa0— Armstrong {6}SO',
#  '\xa0\xa0\xa0\xa0— Brown {4}SO',
#  '(13) Tobi AMUSANSO',
#  '(14) Grace STARKSO',
#  '\xa0\xa0\xa0\xa0— Cockrell {2}SR',
#  '\xa0\xa0\xa0\xa0— Camacho-Quinn {3}JR',
#  '\xa0\xa0\xa0\xa0— Camacho-Quinn {4}SO',
#  '\xa0\xa0\xa0\xa0— Armstrong {7}JR',
#  '\xa0\xa0\xa0\xa0— Camacho-Quinn {5}JR',
#  '(15) Cindy OFILI',
#  '(15) Priscilla LOPES',
#  '\xa0\xa0\xa0\xa0— Armstrong {8}SO',
#  '(17) Queen CLAYE',
#  '\xa0\xa0\xa0\xa0— Powell {3}',
#  '(17) Gail DEVERS',
#  '\xa0\xa0\xa0\xa0— Harrison {3}',
#  '\xa0\xa0\xa0\xa0— Harrison {4}',
#  '(19) Nichole DENBYSR',
#  '(20) Paula  SALMONSR',
#  '\xa0\xa0\xa0\xa0— Amusan {2}SO',
#  '\xa0\xa0\xa0\xa0— Lopes {2}',
#  '\xa0\xa0\xa0\xa0— Powell {4}',
#  '\xa0\xa0\xa0\xa0— Lopes {3}',
#  '(21) Talie BONDSSR',
#  '(21) Rushelle BURTONSO',
#  '\xa0\xa0\xa0\xa0— Burton {2}FR',
#  '(23) Jasmine JONESSO',
#  '\xa0\xa0\xa0\xa0— Salmon {2}SR',
#  '\xa0\xa0\xa0\xa0— Marshall {4}JR',
#  '\xa0\xa0\xa0\xa0— Ofili {2}',
#  '\xa0\xa0\xa0\xa0— Harrison {5}',
#  '(24) Alexis GLASCOSO',
#  '\xa0\xa0\xa0\xa0— Bonds {2}SR',
#  '\xa0\xa0\xa0\xa0— Bonds {3}SR',
#  '\xa0\xa0\xa0\xa0— Stark {2}SO',
#  '\xa0\xa0\xa0\xa0— Stark {3}SO',
#  '\xa0\xa0\xa0\xa0— Marshall {5}JR']

# %%
OfficialReGexNames = []

for i in range(0,len(RealRealRows)):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Masai RUSSELLSR',
#  '(2) Brianna ROLLINSJR',
#  '(3) Alia ARMSTRONGJR',
#  '(3) Janeek BROWNSO',
#  '(3) Jasmine CAMACHO-QUINNJR',
#  '(6) Ackera NUGENTJR',
#  '(7) Demisha ROSWELLJR',
#  '(7) Tonea MARSHALLSR',
#  '— Nugent {2}FR',
#  '— Russell {2}SR',
#  '— Rollins {2}JR',
#  '— Marshall {2}SR',
#  '(9) Ginnie POWELLSR',
#  '— Russell {3}SR',
#  '(10) Keni HARRISON',
#  '— Nugent {3}JR',
#  '— Marshall {3}SR',
#  '(11) Chanel BRISSETTSO',
#  '— Brown {2}SO',
#  '— Armstrong {2}JR',
#  '(12) Anna COCKRELLSR',
#  '— Camacho-Quinn {2}JR',
#  '— Nugent {4}JR',
#  '— Armstrong {3}SO',
#  '— Brown {3}SO',
#  '— Harrison {2}',
#  '— Powell {2}SR',
#  '— Armstrong {4}JR',
#  '— Armstrong {5}JR',
#  '— Armstrong {6}SO',
#  '— Brown {4}SO',
#  '(13) Tobi AMUSANSO',
#  '(14) Grace STARKSO',
#  '— Cockrell {2}SR',
#  '— Camacho-Quinn {3}JR',
#  '— Camacho-Quinn {4}SO',
#  '— Armstrong {7}JR',
#  '— Camacho-Quinn {5}JR',
#  '(15) Cindy OFILI',
#  '(15) Priscilla LOPES',
#  '— Armstrong {8}SO',
#  '(17) Queen CLAYE',
#  '— Powell {3}',
#  '(17) Gail DEVERS',
#  '— Harrison {3}',
#  '— Harrison {4}',
#  '(19) Nichole DENBYSR',
#  '(20) Paula  SALMONSR',
#  '— Amusan {2}SO',
#  '— Lopes {2}',
#  '— Powell {4}',
#  '— Lopes {3}',
#  '(21) Talie BONDSSR',
#  '(21) Rushelle BURTONSO',
#  '— Burton {2}FR',
#  '(23) Jasmine JONESSO',
#  '— Salmon {2}SR',
#  '— Marshall {4}JR',
#  '— Ofili {2}',
#  '— Harrison {5}',
#  '(24) Alexis GLASCOSO',
#  '— Bonds {2}SR',
#  '— Bonds {3}SR',
#  '— Stark {2}SO',
#  '— Stark {3}SO',
#  '— Marshall {5}JR']

# %%
CleanedNames = []
for i in range(0,len(RealRealRows)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Masai RUSSELLSR',
#  'Brianna ROLLINSJR',
#  'Alia ARMSTRONGJR',
#  'Janeek BROWNSO',
#  'Jasmine CAMACHO-QUINNJR',
#  'Ackera NUGENTJR',
#  'Demisha ROSWELLJR',
#  'Tonea MARSHALLSR',
#  'Nugent {2}FR',
#  'Russell {2}SR',
#  'Rollins {2}JR',
#  'Marshall {2}SR',
#  'Ginnie POWELLSR',
#  'Russell {3}SR',
#  ' Keni HARRISON',
#  'Nugent {3}JR',
#  'Marshall {3}SR',
#  ' Chanel BRISSETTSO',
#  'Brown {2}SO',
#  'Armstrong {2}JR',
#  ' Anna COCKRELLSR',
#  'Camacho-Quinn {2}JR',
#  'Nugent {4}JR',
#  'Armstrong {3}SO',
#  'Brown {3}SO',
#  'Harrison {2}',
#  'Powell {2}SR',
#  'Armstrong {4}JR',
#  'Armstrong {5}JR',
#  'Armstrong {6}SO',
#  'Brown {4}SO',
#  ' Tobi AMUSANSO',
#  ' Grace STARKSO',
#  'Cockrell {2}SR',
#  'Camacho-Quinn {3}JR',
#  'Camacho-Quinn {4}SO',
#  'Armstrong {7}JR',
#  'Camacho-Quinn {5}JR',
#  ' Cindy OFILI',
#  ' Priscilla LOPES',
#  'Armstrong {8}SO',
#  ' Queen CLAYE',
#  'Powell {3}',
#  ' Gail DEVERS',
#  'Harrison {3}',
#  'Harrison {4}',
#  ' Nichole DENBYSR',
#  ' Paula  SALMONSR',
#  'Amusan {2}SO',
#  'Lopes {2}',
#  'Powell {4}',
#  'Lopes {3}',
#  ' Talie BONDSSR',
#  ' Rushelle BURTONSO',
#  'Burton {2}FR',
#  ' Jasmine JONESSO',
#  'Salmon {2}SR',
#  'Marshall {4}JR',
#  'Ofili {2}',
#  'Harrison {5}',
#  ' Alexis GLASCOSO',
#  'Bonds {2}SR',
#  'Bonds {3}SR',
#  'Stark {2}SO',
#  'Stark {3}SO',
#  'Marshall {5}JR']

# %%
CleanedNames2 = []
for i in range(0,len(RealRealRows)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Masai RUSSELLSR',
#  'Brianna ROLLINSJR',
#  'Alia ARMSTRONGJR',
#  'Janeek BROWNSO',
#  'Jasmine CAMACHO-QUINNJR',
#  'Ackera NUGENTJR',
#  'Demisha ROSWELLJR',
#  'Tonea MARSHALLSR',
#  'Nugent {2}FR',
#  'Russell {2}SR',
#  'Rollins {2}JR',
#  'Marshall {2}SR',
#  'Ginnie POWELLSR',
#  'Russell {3}SR',
#  'Keni HARRISON',
#  'Nugent {3}JR',
#  'Marshall {3}SR',
#  'Chanel BRISSETTSO',
#  'Brown {2}SO',
#  'Armstrong {2}JR',
#  'Anna COCKRELLSR',
#  'Camacho-Quinn {2}JR',
#  'Nugent {4}JR',
#  'Armstrong {3}SO',
#  'Brown {3}SO',
#  'Harrison {2}',
#  'Powell {2}SR',
#  'Armstrong {4}JR',
#  'Armstrong {5}JR',
#  'Armstrong {6}SO',
#  'Brown {4}SO',
#  'Tobi AMUSANSO',
#  'Grace STARKSO',
#  'Cockrell {2}SR',
#  'Camacho-Quinn {3}JR',
#  'Camacho-Quinn {4}SO',
#  'Armstrong {7}JR',
#  'Camacho-Quinn {5}JR',
#  'Cindy OFILI',
#  'Priscilla LOPES',
#  'Armstrong {8}SO',
#  'Queen CLAYE',
#  'Powell {3}',
#  'Gail DEVERS',
#  'Harrison {3}',
#  'Harrison {4}',
#  'Nichole DENBYSR',
#  'Paula  SALMONSR',
#  'Amusan {2}SO',
#  'Lopes {2}',
#  'Powell {4}',
#  'Lopes {3}',
#  'Talie BONDSSR',
#  'Rushelle BURTONSO',
#  'Burton {2}FR',
#  'Jasmine JONESSO',
#  'Salmon {2}SR',
#  'Marshall {4}JR',
#  'Ofili {2}',
#  'Harrison {5}',
#  'Alexis GLASCOSO',
#  'Bonds {2}SR',
#  'Bonds {3}SR',
#  'Stark {2}SO',
#  'Stark {3}SO',
#  'Marshall {5}JR']

# %%
RealRealRows[4][3]
# Out:
# 'Kentucky'

# %%
RegexTimes = []

for i in range(0,len(RealRealRows)):
    Times = RealRealRows[i][4][:5]
    RegexTimes.append(Times)
RegexTimes
# Out:
# ['12.36',
#  '12.39',
#  '12.40',
#  '12.40',
#  '12.40',
#  '12.43',
#  '12.44',
#  '12.44',
#  '12.45',
#  '12.47',
#  '12.47',
#  '12.48',
#  '12.48',
#  '12.50',
#  '12.50',
#  '12.52',
#  '12.52',
#  '12.52',
#  '12.53',
#  '12.54',
#  '12.54',
#  '12.54',
#  '12.55',
#  '12.55',
#  '12.55',
#  '12.55',
#  '12.55',
#  '12.56',
#  '12.57',
#  '12.57',
#  '12.57',
#  '12.57',
#  '12.58',
#  '12.58',
#  '12.58',
#  '12.58',
#  '12.59',
#  '12.60',
#  '12.60',
#  '12.60',
#  '12.61',
#  '12.61',
#  '12.61',
#  '12.61',
#  '12.62',
#  '12.62',
#  '12.62',
#  '12.63',
#  '12.63',
#  '12.63',
#  '12.64',
#  '12.64',
#  '12.65',
#  '12.65',
#  '12.65',
#  '12.66',
#  '12.66',
#  '12.66',
#  '12.66',
#  '12.66',
#  '12.67',
#  '12.67',
#  '12.67',
#  '12.67',
#  '12.67',
#  '12.67']

# %%
Schools = []

for i in range(0,len(RealRealRows)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Kentucky',
#  'Clemson',
#  'LSU',
#  'Arkansas',
#  'Kentucky',
#  'Arkansas',
#  'Texas Tech',
#  'LSU',
#  'Baylor',
#  'Kentucky',
#  'Clemson',
#  'LSU',
#  'Southern California',
#  'Kentucky',
#  'Kentucky',
#  'Arkansas',
#  'LSU',
#  'Southern California',
#  'Arkansas',
#  'LSU',
#  'Southern California',
#  'Kentucky',
#  'Arkansas',
#  'LSU',
#  'Arkansas',
#  'Kentucky',
#  'Southern California',
#  'LSU',
#  'LSU',
#  'LSU',
#  'Arkansas',
#  'UTEP',
#  'Florida',
#  'Southern California',
#  'Kentucky',
#  'Kentucky',
#  'LSU',
#  'Kentucky',
#  'Michigan',
#  'Nebraska',
#  'LSU',
#  'Virginia Tech',
#  'Southern California',
#  'UCLA',
#  'Kentucky',
#  'Kentucky',
#  'Texas',
#  'North Carolina A&T',
#  'UTEP',
#  'Nebraska',
#  'Southern California',
#  'Nebraska',
#  'Arizona',
#  'Texas',
#  'Texas',
#  'Southern California',
#  'North Carolina A&T',
#  'LSU',
#  'Michigan',
#  'Kentucky',
#  'Coastal Carolina',
#  'Arizona',
#  'Arizona',
#  'Florida',
#  'Florida',
#  'LSU']

# %%
len(Schools)
# Out:
# 66

# %%
len(RegexTimes)
# Out:
# 66

# %%
len(OfficialReGexNames)
# Out:
# 66

# %%
Men110mHurdlesDF = pd.DataFrame({'Names': CleanedNames2, 'Times': RegexTimes, 'Schools': Schools})
Men110mHurdlesDF.to_csv('Women100mHurdles.csv', index=False)
