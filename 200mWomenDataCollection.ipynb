# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc

# %%
Link200mWomen = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?gender=2&sport=2&div=20527&top=25&event=3"

# %%
page = requests.get(Link200mWomen)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6995396" target="_blank">(1) Abby STEINER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567519" target="_blank">21.80</a><a href="https://www.youtube.com/watch?v=OdlQ0P16N24" target="_blank">📺</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6995396" target="_blank">(1) Abby STEINER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567519" target="_blank">21.80</a><a href="https://www.youtube.com/watch?v=OdlQ0P16N24" target="_blank">📺</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7087489" target="_blank">(2) Julien ALFRED</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78102/4824376" target="_blank">21.91</a><a href="https://twitter.com/TexasTFXC/status/1646999508876685313" target="_blank">📺</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.8)</span></td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/14/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7087489" target="_blank">(2) Julien ALFRED</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78102/4824376" target="_blank">21.91</a><a href="https://twitter.com/TexasTFXC/status/1646999508876685313" target="_blank">📺</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.8)</span></td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/14/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729916" target="_blank">(3) Favour OFILI</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73497/4502544" target="_blank">21.96</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">4/15/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729916" target="_blank">(3) Favour OFILI</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73497/4502544" target="_blank">21.96</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">4/15/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Steiner {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567519" target="_blank">22.02</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.5)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Steiner {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567519" target="_blank">22.02</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.5)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4202028" target="_blank">(4) Kyra JEFFERSON</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51935/3199110" target="_blank">22.02</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.1)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2017</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     11.5/10.5</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4202028" target="_blank">(4) Kyra JEFFERSON</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51935/3199110" target="_blank">22.02</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.1)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2017</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     11.5/10.5</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Ofili {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4555615" target="_blank">22.04</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.2)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Ofili {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4555615" target="_blank">22.04</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.2)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(5) Dawn SOWELL</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;">22.04 <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Provo, Utah)"><span class="mark-date" style="width: 10%;text-align:right;">6/2/1989</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(5) Dawn SOWELL</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;">22.04 <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Provo, Utah)"><span class="mark-date" style="width: 10%;text-align:right;">6/2/1989</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Ofili {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567519" target="_blank">22.05</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Ofili {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567519" target="_blank">22.05</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Steiner {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70609/4514301" target="_blank">22.05</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.5)</span></td><td style="width: 10%;text-align:right;" title="Kentucky Invitational (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">4/22/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Steiner {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70609/4514301" target="_blank">22.05</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.5)</span></td><td style="width: 10%;text-align:right;" title="Kentucky Invitational (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">4/22/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Steiner {4}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4555615" target="_blank">22.07</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.2)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Steiner {4}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4555615" target="_blank">22.07</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.2)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Ofili {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75213/4566144" target="_blank">22.08</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Bloomington, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">5/28/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Ofili {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75213/4566144" target="_blank">22.08</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Bloomington, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">5/28/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7513122" target="_blank">(6) Latasha SMITH</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCF" class="group-logo-inline" src="/images/logos/rankings-article/ucf.png" title="UCF"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1616">UCF</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/79640/4929260" target="_blank">22.09</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="The American Outdoor Championships (Tampa, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/12/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7513122" target="_blank">(6) Latasha SMITH</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCF" class="group-logo-inline" src="/images/logos/rankings-article/ucf.png" title="UCF"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1616">UCF</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/79640/4929260" target="_blank">22.09</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="The American Outdoor Championships (Tampa, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/12/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/79703/4926687" target="_blank">22.09</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.0)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Norman, Okla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/12/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/79703/4926687" target="_blank">22.09</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.0)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Norman, Okla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/12/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5640215" target="_blank">(6) Deajah STEVENS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51891" target="_blank">22.09</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.5)</span></td><td style="width: 10%;text-align:right;" title="Pac-12 Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5640215" target="_blank">(6) Deajah STEVENS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51891" target="_blank">22.09</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.5)</span></td><td style="width: 10%;text-align:right;" title="Pac-12 Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6988927" target="_blank">(8) Cambrea STURGIS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="North Carolina A&amp;T" class="group-logo-inline" src="/images/logos/rankings-article/north-carolina-at.png" title="North Carolina A&amp;T"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1086">North Carolina A&amp;T</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276118" target="_blank">22.12</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.2)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/12/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6988927" target="_blank">(8) Cambrea STURGIS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="North Carolina A&amp;T" class="group-logo-inline" src="/images/logos/rankings-article/north-carolina-at.png" title="North Carolina A&amp;T"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1086">North Carolina A&amp;T</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276118" target="_blank">22.12</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.2)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/12/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Ofili {5}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567519" target="_blank">22.13</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.2)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Ofili {5}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567519" target="_blank">22.13</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.2)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6534261" target="_blank">(9) Tamara CLARK</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390/4273632" target="_blank">22.13</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.5)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/29/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6534261" target="_blank">(9) Tamara CLARK</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390/4273632" target="_blank">22.13</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.5)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/29/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Clark {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390" target="_blank">22.13</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.5)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/27/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Clark {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390" target="_blank">22.13</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.5)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/27/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6598705" target="_blank">(10) Angie ANNELUS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850662" target="_blank">22.16</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6598705" target="_blank">(10) Angie ANNELUS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850662" target="_blank">22.16</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Clark {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276118" target="_blank">22.17</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.2)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/12/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Clark {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276118" target="_blank">22.17</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.2)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/12/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6987308" target="_blank">(11) Sha'Carri RICHARDSON</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850662" target="_blank">22.17</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6987308" target="_blank">(11) Sha'Carri RICHARDSON</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850662" target="_blank">22.17</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4513695" target="_blank">(12) Dezerea BRYANT</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41405/2568016" target="_blank">22.18</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/13/2015</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     11.3/10.9</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4513695" target="_blank">(12) Dezerea BRYANT</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41405/2568016" target="_blank">22.18</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/13/2015</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     11.3/10.9</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Steiner {5}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75213/4566144" target="_blank">22.19</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Bloomington, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">5/26/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Steiner {5}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75213/4566144" target="_blank">22.19</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Bloomington, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">5/26/2022</span></td></tr>,
# ...
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Simone FACEY</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;">22.25  </td><td style="width: 10%;text-align:right;" title="Jamaican (JAAA) Championships (Kingston, Jamaica)"><span class="mark-date" style="width: 10%;text-align:right;">6/29/2008</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Simone FACEY</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;">22.25  </td><td style="width: 10%;text-align:right;" title="Jamaican (JAAA) Championships (Kingston, Jamaica)"><span class="mark-date" style="width: 10%;text-align:right;">6/29/2008</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6995396" target="_blank">Abby STEINER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;">22.26  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="World Athletics Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/21/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6995396" target="_blank">Abby STEINER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;">22.26  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="World Athletics Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/21/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6995396" target="_blank">Abby STEINER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;">22.26 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="World Athletics Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/18/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6995396" target="_blank">Abby STEINER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=770">Kentucky</a></td><td style="width: 25%;">22.26 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="World Athletics Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/18/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2216347" target="_blank">Jeneba TARMOH</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;">22.28  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.0)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/26/2011</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2216347" target="_blank">Jeneba TARMOH</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;">22.28  <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.0)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/26/2011</span></td></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">Additional Out-of-Season, All-Conditions Bests</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2634066" target="_blank">Kimberlyn DUNCAN</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;">21.80 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.2)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/23/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2634066" target="_blank">Kimberlyn DUNCAN</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=869">LSU</a></td><td style="width: 25%;">21.80 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.2)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/23/2013</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3735048" target="_blank">Kamaria BROWN</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;">22.16 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.2)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/23/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3735048" target="_blank">Kamaria BROWN</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;">22.16 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.2)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/23/2013</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3733719" target="_blank">Jenna PRANDINI</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1180">Oregon</a></td><td style="width: 25%;">22.18 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.8)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/27/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3733719" target="_blank">Jenna PRANDINI</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=3&amp;team=1180">Oregon</a></td><td style="width: 25%;">22.18 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.8)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/27/2015</span></td></tr>,
#  <tr><td class="group-logo-50"><a href="https://allathletics.tv/?utc_source=ustfccca&amp;utc_medium=web&amp;utc_campaign=broadcast_schedule_sidebar" target="_blank"><img alt="eaa" src="/images/logos/rankings-article/eaa.png" title="EAA"/></a></td><td style="line-height: 1em;"><a href="https://allathletics.tv/?utc_source=ustfccca&amp;utc_medium=web&amp;utc_campaign=broadcast_schedule_sidebar" target="_blank">European U20 Championships</a></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Abby STEINERJRKentucky21.80📺  (w: 1.3)6/11/2022',
#   '(1) Abby STEINERJR',
#   '',
#   'Kentucky',
#   '21.80📺  (w: 1.3)',
#   '6/11/2022'],
#  [],
#  ['(1) Abby STEINERJR', '', 'Kentucky', '21.80📺  (w: 1.3)', '6/11/2022'],
#  ['(2) Julien ALFREDJRTexas21.91📺  (w: 1.8)4/14/2023',
#   '(2) Julien ALFREDJR',
#   '',
#   'Texas',
#   '21.91📺  (w: 1.8)',
#   '4/14/2023'],
#  [],
#  ['(2) Julien ALFREDJR', '', 'Texas', '21.91📺  (w: 1.8)', '4/14/2023'],
#  ['(3) Favour OFILISOLSU21.96  (w: 1.3)4/15/2022',
#   '(3) Favour OFILISO',
#   '',
#   'LSU',
#   '21.96  (w: 1.3)',
#   '4/15/2022'],
#  [],
#  ['(3) Favour OFILISO', '', 'LSU', '21.96  (w: 1.3)', '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JRKentucky22.02 qq = Performance occurred during a non-final round.  (w: 0.5)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '22.02 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/9/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '22.02 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/9/2022'],
#  ['(4) Kyra JEFFERSONSRFlorida22.02  (w: 1.1)6/10/2017\xa0\xa0\xa0\xa0\xa011.5/10.5',
#   '(4) Kyra JEFFERSONSR',
#   '',
#   'Florida',
#   '22.02  (w: 1.1)',
#   '6/10/2017',
#   '\xa0\xa0\xa0\xa0\xa011.5/10.5'],
#  [],
#  ['(4) Kyra JEFFERSONSR', '', 'Florida', '22.02  (w: 1.1)', '6/10/2017'],
#  ['\xa0\xa0\xa0\xa0\xa011.5/10.5'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}SOLSU22.04  (w: 0.2)5/14/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {2}SO',
#   '',
#   'LSU',
#   '22.04  (w: 0.2)',
#   '5/14/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}SO', '', 'LSU', '22.04  (w: 0.2)', '5/14/2022'],
#  ['(5) Dawn SOWELLSRLSU22.04 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.7)6/2/1989',
#   '(5) Dawn SOWELLSR',
#   '',
#   'LSU',
#   '22.04 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.7)',
#   '6/2/1989'],
#  [],
#  ['(5) Dawn SOWELLSR',
#   '',
#   'LSU',
#   '22.04 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.7)',
#   '6/2/1989'],
#  ['\xa0\xa0\xa0\xa0— Ofili {3}SOLSU22.05  (w: 1.3)6/11/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {3}SO',
#   '',
#   'LSU',
#   '22.05  (w: 1.3)',
#   '6/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {3}SO', '', 'LSU', '22.05  (w: 1.3)', '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JRKentucky22.05  (w: 0.5)4/22/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {3}JR',
#   '',
#   'Kentucky',
#   '22.05  (w: 0.5)',
#   '4/22/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JR',
#   '',
#   'Kentucky',
#   '22.05  (w: 0.5)',
#   '4/22/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {4}JRKentucky22.07  (w: 0.2)5/14/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {4}JR',
#   '',
#   'Kentucky',
#   '22.07  (w: 0.2)',
#   '5/14/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {4}JR',
#   '',
#   'Kentucky',
#   '22.07  (w: 0.2)',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {4}SOLSU22.08 qq = Performance occurred during a non-final round.  (w: 0.7)5/28/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {4}SO',
#   '',
#   'LSU',
#   '22.08 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/28/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {4}SO',
#   '',
#   'LSU',
#   '22.08 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/28/2022'],
#  ['(6) Latasha SMITHJRUCF22.09  (w: 1.4)5/12/2023',
#   '(6) Latasha SMITHJR',
#   '',
#   'UCF',
#   '22.09  (w: 1.4)',
#   '5/12/2023'],
#  [],
#  ['(6) Latasha SMITHJR', '', 'UCF', '22.09  (w: 1.4)', '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}JRTexas22.09  (w: 2.0)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {2}JR',
#   '',
#   'Texas',
#   '22.09  (w: 2.0)',
#   '5/12/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}JR',
#   '',
#   'Texas',
#   '22.09  (w: 2.0)',
#   '5/12/2023'],
#  ['(6) Deajah STEVENSJROregon22.09  (w: 1.5)5/14/2017',
#   '(6) Deajah STEVENSJR',
#   '',
#   'Oregon',
#   '22.09  (w: 1.5)',
#   '5/14/2017'],
#  [],
#  ['(6) Deajah STEVENSJR', '', 'Oregon', '22.09  (w: 1.5)', '5/14/2017'],
#  ['(8) Cambrea STURGISSONorth Carolina A&T22.12  (w: 0.2)6/12/2021',
#   '(8) Cambrea STURGISSO',
#   '',
#   'North Carolina A&T',
#   '22.12  (w: 0.2)',
#   '6/12/2021'],
#  [],
#  ['(8) Cambrea STURGISSO',
#   '',
#   'North Carolina A&T',
#   '22.12  (w: 0.2)',
#   '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Ofili {5}SOLSU22.13 qq = Performance occurred during a non-final round.  (w: -0.2)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {5}SO',
#   '',
#   'LSU',
#   '22.13 qq = Performance occurred during a non-final round.  (w: -0.2)',
#   '6/9/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {5}SO',
#   '',
#   'LSU',
#   '22.13 qq = Performance occurred during a non-final round.  (w: -0.2)',
#   '6/9/2022'],
#  ['(9) Tamara CLARKJRAlabama22.13 qq = Performance occurred during a non-final round.  (w: 0.5)5/29/2021',
#   '(9) Tamara CLARKJR',
#   '',
#   'Alabama',
#   '22.13 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/29/2021'],
#  [],
#  ['(9) Tamara CLARKJR',
#   '',
#   'Alabama',
#   '22.13 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Clark {2}JRAlabama22.13 qq = Performance occurred during a non-final round.  (w: 0.5)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Clark {2}JR',
#   '',
#   'Alabama',
#   '22.13 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/27/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Clark {2}JR',
#   '',
#   'Alabama',
#   '22.13 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/27/2021'],
#  ['(10) Angie ANNELUSJRSouthern California22.16  (w: 1.3)6/8/2019',
#   '(10) Angie ANNELUSJR',
#   '',
#   'Southern California',
#   '22.16  (w: 1.3)',
#   '6/8/2019'],
#  [],
#  ['(10) Angie ANNELUSJR',
#   '',
#   'Southern California',
#   '22.16  (w: 1.3)',
#   '6/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Clark {3}JRAlabama22.17  (w: 0.2)6/12/2021',
#   '\xa0\xa0\xa0\xa0— Clark {3}JR',
#   '',
#   'Alabama',
#   '22.17  (w: 0.2)',
#   '6/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Clark {3}JR',
#   '',
#   'Alabama',
#   '22.17  (w: 0.2)',
#   '6/12/2021'],
#  ["(11) Sha'Carri RICHARDSONFRLSU22.17  (w: 1.3)6/8/2019",
#   "(11) Sha'Carri RICHARDSONFR",
#   '',
#   'LSU',
#   '22.17  (w: 1.3)',
#   '6/8/2019'],
#  [],
#  ["(11) Sha'Carri RICHARDSONFR", '', 'LSU', '22.17  (w: 1.3)', '6/8/2019'],
#  ['(12) Dezerea BRYANTKentucky22.18  (w: 1.9)6/13/2015\xa0\xa0\xa0\xa0\xa011.3/10.9',
#   '(12) Dezerea BRYANT',
#   '',
#   'Kentucky',
#   '22.18  (w: 1.9)',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa011.3/10.9'],
#  [],
#  ['(12) Dezerea BRYANT', '', 'Kentucky', '22.18  (w: 1.9)', '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0\xa011.3/10.9'],
#  ['\xa0\xa0\xa0\xa0— Steiner {5}JRKentucky22.19 qq = Performance occurred during a non-final round.  (w: 0.6)5/26/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {5}JR',
#   '',
#   'Kentucky',
#   '22.19 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '5/26/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {5}JR',
#   '',
#   'Kentucky',
#   '22.19 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '5/26/2022'],
#  ['(13) Kimberlyn DUNCANJRLSU22.19 qq = Performance occurred during a non-final round.  (w: 1.9)6/7/2012',
#   '(13) Kimberlyn DUNCANJR',
#   '',
#   'LSU',
#   '22.19 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '6/7/2012'],
#  [],
#  ['(13) Kimberlyn DUNCANJR',
#   '',
#   'LSU',
#   '22.19 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '6/7/2012'],
#  ['\xa0\xa0\xa0\xa0— Ofili {6}SOLSU22.21  (w: -0.1)5/14/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {6}SO',
#   '',
#   'LSU',
#   '22.21  (w: -0.1)',
#   '5/14/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {6}SO', '', 'LSU', '22.21  (w: -0.1)', '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {7}SOLSU22.21 qq = Performance occurred during a non-final round.  (w: -0.1)5/12/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {7}SO',
#   '',
#   'LSU',
#   '22.21 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '5/12/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {7}SO',
#   '',
#   'LSU',
#   '22.21 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '5/12/2022'],
#  ['(14) Ariana WASHINGTONFROregon22.21  (w: 1.9)6/11/2016',
#   '(14) Ariana WASHINGTONFR',
#   '',
#   'Oregon',
#   '22.21  (w: 1.9)',
#   '6/11/2016'],
#  [],
#  ['(14) Ariana WASHINGTONFR', '', 'Oregon', '22.21  (w: 1.9)', '6/11/2016'],
#  ['(14) Jenna PRANDINIOregon22.21  (w: 1.9)6/13/2015\xa0\xa0\xa0\xa0\xa011.3/10.9',
#   '(14) Jenna PRANDINI',
#   '',
#   'Oregon',
#   '22.21  (w: 1.9)',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa011.3/10.9'],
#  [],
#  ['(14) Jenna PRANDINI', '', 'Oregon', '22.21  (w: 1.9)', '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0\xa011.3/10.9'],
#  ['\xa0\xa0\xa0\xa0— Duncan {2}JRLSU22.22 qq = Performance occurred during a non-final round.  (w: 0.1)5/25/2012',
#   '\xa0\xa0\xa0\xa0— Duncan {2}JR',
#   '',
#   'LSU',
#   '22.22 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/25/2012'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Duncan {2}JR',
#   '',
#   'LSU',
#   '22.22 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/25/2012'],
#  ['(16) Kynnedy FLANNELJRTexas22.23 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)5/13/2022',
#   '(16) Kynnedy FLANNELJR',
#   '',
#   'Texas',
#   '22.23 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)',
#   '5/13/2022'],
#  [],
#  ['(16) Kynnedy FLANNELJR',
#   '',
#   'Texas',
#   '22.23 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)',
#   '5/13/2022'],
#  ['(16) Olivia EKPONEJRTexas A&M22.23  (w: -0.8)5/18/2014',
#   '(16) Olivia EKPONEJR',
#   '',
#   'Texas A&M',
#   '22.23  (w: -0.8)',
#   '5/18/2014'],
#  [],
#  ['(16) Olivia EKPONEJR', '', 'Texas A&M', '22.23  (w: -0.8)', '5/18/2014'],
#  ['(16) Carol RODRIGUEZSouthern California22.23 AA = Performance occurred at altitude (>1000 meters above sea level) 5/26/2006',
#   '(16) Carol RODRIGUEZ',
#   '',
#   'Southern California',
#   '22.23 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/26/2006'],
#  [],
#  ['(16) Carol RODRIGUEZ',
#   '',
#   'Southern California',
#   '22.23 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/26/2006'],
#  ['(19) Kamaria BROWNTexas A&M22.24  (w: 1.9)6/13/2015\xa0\xa0\xa0\xa0\xa011.4/10.8',
#   '(19) Kamaria BROWN',
#   '',
#   'Texas A&M',
#   '22.24  (w: 1.9)',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa011.4/10.8'],
#  [],
#  ['(19) Kamaria BROWN', '', 'Texas A&M', '22.24  (w: 1.9)', '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0\xa011.4/10.8'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}Florida22.24  (w: 1.9)6/13/2015\xa0\xa0\xa0\xa0\xa011.5/10.7',
#   '\xa0\xa0\xa0\xa0— Jefferson {2}',
#   '',
#   'Florida',
#   '22.24  (w: 1.9)',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa011.5/10.7'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}',
#   '',
#   'Florida',
#   '22.24  (w: 1.9)',
#   '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0\xa011.5/10.7'],
#  ['\xa0\xa0\xa0\xa0— Duncan {3}SOLSU22.24  (w: 1.5)6/11/2011',
#   '\xa0\xa0\xa0\xa0— Duncan {3}SO',
#   '',
#   'LSU',
#   '22.24  (w: 1.5)',
#   '6/11/2011'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Duncan {3}SO', '', 'LSU', '22.24  (w: 1.5)', '6/11/2011'],
#  ['\xa0\xa0\xa0\xa0— Flannel {2}JRTexas22.25 qq = Performance occurred during a non-final round.  (w: 0.9)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Flannel {2}JR',
#   '',
#   'Texas',
#   '22.25 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '6/9/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Flannel {2}JR',
#   '',
#   'Texas',
#   '22.25 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '6/9/2022'],
#  ['(20) Lynna IRBYFRGeorgia22.25  (w: 0.6)5/13/2018',
#   '(20) Lynna IRBYFR',
#   '',
#   'Georgia',
#   '22.25  (w: 0.6)',
#   '5/13/2018'],
#  [],
#  ['(20) Lynna IRBYFR', '', 'Georgia', '22.25  (w: 0.6)', '5/13/2018'],
#  ['\xa0\xa0\xa0\xa0— Stevens {2}SOOregon22.25  (w: 1.9)6/11/2016',
#   '\xa0\xa0\xa0\xa0— Stevens {2}SO',
#   '',
#   'Oregon',
#   '22.25  (w: 1.9)',
#   '6/11/2016'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Stevens {2}SO',
#   '',
#   'Oregon',
#   '22.25  (w: 1.9)',
#   '6/11/2016'],
#  ['(21) Anavia BATTLESROhio State22.26 qq = Performance occurred during a non-final round.  (w: 0.9)6/9/2022',
#   '(21) Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '6/9/2022'],
#  [],
#  ['(21) Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '6/9/2022'],
#  ['(21) Kevona DAVISSOTexas22.26 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)5/13/2022',
#   '(21) Kevona DAVISSO',
#   '',
#   'Texas',
#   '22.26 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)',
#   '5/13/2022'],
#  [],
#  ['(21) Kevona DAVISSO',
#   '',
#   'Texas',
#   '22.26 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Sturgis {2}SONorth Carolina A&T22.26 qq = Performance occurred during a non-final round.  (w: 0.0)5/29/2021',
#   '\xa0\xa0\xa0\xa0— Sturgis {2}SO',
#   '',
#   'North Carolina A&T',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/29/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Sturgis {2}SO',
#   '',
#   'North Carolina A&T',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Sturgis {3}SONorth Carolina A&T22.26 qq = Performance occurred during a non-final round.  (w: 0.0)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Sturgis {3}SO',
#   '',
#   'North Carolina A&T',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/27/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Sturgis {3}SO',
#   '',
#   'North Carolina A&T',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/27/2021'],
#  ['(21) Felicia BROWNSRTennessee22.26  (w: -1.3)5/14/2016',
#   '(21) Felicia BROWNSR',
#   '',
#   'Tennessee',
#   '22.26  (w: -1.3)',
#   '5/14/2016'],
#  [],
#  ['(21) Felicia BROWNSR', '', 'Tennessee', '22.26  (w: -1.3)', '5/14/2016'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {3}Florida22.26 qq = Performance occurred during a non-final round.  (w: 1.8)6/11/2015',
#   '\xa0\xa0\xa0\xa0— Jefferson {3}',
#   '',
#   'Florida',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 1.8)',
#   '6/11/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Jefferson {3}',
#   '',
#   'Florida',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 1.8)',
#   '6/11/2015'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {4}SOFlorida22.26 qq = Performance occurred during a non-final round.  (w: 0.5)5/29/2015',
#   '\xa0\xa0\xa0\xa0— Jefferson {4}SO',
#   '',
#   'Florida',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/29/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Jefferson {4}SO',
#   '',
#   'Florida',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/29/2015'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}JRTexas22.28  (w: 0.3)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {3}JR',
#   '',
#   'Texas',
#   '22.28  (w: 0.3)',
#   '5/12/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}JR',
#   '',
#   'Texas',
#   '22.28  (w: 0.3)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Battle {2}SROhio State22.28 qq = Performance occurred during a non-final round.  (w: 1.9)5/29/2021',
#   '\xa0\xa0\xa0\xa0— Battle {2}SR',
#   '',
#   'Ohio State',
#   '22.28 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/29/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Battle {2}SR',
#   '',
#   'Ohio State',
#   '22.28 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Battle {3}SROhio State22.28 qq = Performance occurred during a non-final round.  (w: 1.9)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Battle {3}SR',
#   '',
#   'Ohio State',
#   '22.28 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/27/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Battle {3}SR',
#   '',
#   'Ohio State',
#   '22.28 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Ofili {8}SOLSU22.29 qq = Performance occurred during a non-final round.  (w: 2.0)5/26/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {8}SO',
#   '',
#   'LSU',
#   '22.29 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '5/26/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {8}SO',
#   '',
#   'LSU',
#   '22.29 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '5/26/2022'],
#  ['(24) Porscha LUCASSOTexas A&M22.29 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.4)5/18/2008',
#   '(24) Porscha LUCASSO',
#   '',
#   'Texas A&M',
#   '22.29 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.4)',
#   '5/18/2008'],
#  [],
#  ['(24) Porscha LUCASSO',
#   '',
#   'Texas A&M',
#   '22.29 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.4)',
#   '5/18/2008'],
#  ['(24) LaTasha JENKINSSRBall State22.29   (w: 0.6)6/5/1999',
#   '(24) LaTasha JENKINSSR',
#   '',
#   'Ball State',
#   '22.29   (w: 0.6)',
#   '6/5/1999'],
#  [],
#  ['(24) LaTasha JENKINSSR', '', 'Ball State', '22.29   (w: 0.6)', '6/5/1999'],
#  ['(24) Merlene OTTEYJRNebraska22.29 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round.  (w: -1.7)6/3/1982',
#   '(24) Merlene OTTEYJR',
#   '',
#   'Nebraska',
#   '22.29 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round.  (w: -1.7)',
#   '6/3/1982'],
#  [],
#  ['(24) Merlene OTTEYJR',
#   '',
#   'Nebraska',
#   '22.29 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round.  (w: -1.7)',
#   '6/3/1982'],
#  ['Additional All-Conditions Bests'],
#  ['Julien ALFREDJRTexas21.73📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)6/10/2023',
#   'Julien ALFREDJR',
#   '',
#   'Texas',
#   '21.73📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '6/10/2023'],
#  [],
#  ['Julien ALFREDJR',
#   '',
#   'Texas',
#   '21.73📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '6/10/2023'],
#  ['McKenzie LONGSROle Miss21.88📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)6/10/2023',
#   'McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '21.88📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '6/10/2023'],
#  [],
#  ['McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '21.88📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '6/10/2023'],
#  ['Tamara CLARKJRAlabama21.89 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)5/15/2021',
#   'Tamara CLARKJR',
#   '',
#   'Alabama',
#   '21.89 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)',
#   '5/15/2021'],
#  [],
#  ['Tamara CLARKJR',
#   '',
#   'Alabama',
#   '21.89 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)',
#   '5/15/2021'],
#  ['Shania COLLINSSRTennessee21.97 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.3)5/25/2018',
#   'Shania COLLINSSR',
#   '',
#   'Tennessee',
#   '21.97 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.3)',
#   '5/25/2018'],
#  [],
#  ['Shania COLLINSSR',
#   '',
#   'Tennessee',
#   '21.97 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 5.3)',
#   '5/25/2018'],
#  ['Abby STEINERJRKentucky22.01 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)5/28/2022',
#   'Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.01 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)',
#   '5/28/2022'],
#  [],
#  ['Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.01 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)',
#   '5/28/2022'],
#  ['Kevona DAVISJRTexas22.02📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)6/10/2023',
#   'Kevona DAVISJR',
#   '',
#   'Texas',
#   '22.02📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '6/10/2023'],
#  [],
#  ['Kevona DAVISJR',
#   '',
#   'Texas',
#   '22.02📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '6/10/2023'],
#  ['Jacious SEARSSRTennessee22.04 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)6/10/2023',
#   'Jacious SEARSSR',
#   '',
#   'Tennessee',
#   '22.04 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '6/10/2023'],
#  [],
#  ['Jacious SEARSSR',
#   '',
#   'Tennessee',
#   '22.04 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.5)',
#   '6/10/2023'],
#  ['Kimberlyn DUNCANSRLSU22.04 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)6/8/2013',
#   'Kimberlyn DUNCANSR',
#   '',
#   'LSU',
#   '22.04 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)',
#   '6/8/2013'],
#  [],
#  ['Kimberlyn DUNCANSR',
#   '',
#   'LSU',
#   '22.04 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)',
#   '6/8/2013'],
#  ['Lynna IRBYFRGeorgia22.06 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)5/25/2018',
#   'Lynna IRBYFR',
#   '',
#   'Georgia',
#   '22.06 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)',
#   '5/25/2018'],
#  [],
#  ['Lynna IRBYFR',
#   '',
#   'Georgia',
#   '22.06 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)',
#   '5/25/2018'],
#  ['Merlene OTTEYNebraska22.11 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 4/23/1983',
#   'Merlene OTTEY',
#   '',
#   'Nebraska',
#   '22.11 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/23/1983'],
#  [],
#  ['Merlene OTTEY',
#   '',
#   'Nebraska',
#   '22.11 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/23/1983'],
#  ['Lanae-Tava THOMASSRTexas22.12 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)5/27/2023',
#   'Lanae-Tava THOMASSR',
#   '',
#   'Texas',
#   '22.12 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)',
#   '5/27/2023'],
#  [],
#  ['Lanae-Tava THOMASSR',
#   '',
#   'Texas',
#   '22.12 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)',
#   '5/27/2023'],
#  ['Kimberlyn DUNCANJRLSU22.12 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)5/10/2012',
#   'Kimberlyn DUNCANJR',
#   '',
#   'LSU',
#   '22.12 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '5/10/2012'],
#  [],
#  ['Kimberlyn DUNCANJR',
#   '',
#   'LSU',
#   '22.12 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '5/10/2012'],
#  ['McKenzie LONGSROle Miss22.13 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.9)5/25/2023',
#   'McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '22.13 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.9)',
#   '5/25/2023'],
#  [],
#  ['McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '22.13 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.9)',
#   '5/25/2023'],
#  ['Gabby THOMASJRHarvard22.13 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.6)3/31/2018',
#   'Gabby THOMASJR',
#   '',
#   'Harvard',
#   '22.13 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.6)',
#   '3/31/2018'],
#  [],
#  ['Gabby THOMASJR',
#   '',
#   'Harvard',
#   '22.13 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.6)',
#   '3/31/2018'],
#  ['Kimberlyn DUNCANSRLSU22.15 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)6/6/2013',
#   'Kimberlyn DUNCANSR',
#   '',
#   'LSU',
#   '22.15 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '6/6/2013'],
#  [],
#  ['Kimberlyn DUNCANSR',
#   '',
#   'LSU',
#   '22.15 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '6/6/2013'],
#  ['Favour OFILIFRLSU22.16 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)5/15/2021',
#   'Favour OFILIFR',
#   '',
#   'LSU',
#   '22.16 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)',
#   '5/15/2021'],
#  [],
#  ['Favour OFILIFR',
#   '',
#   'LSU',
#   '22.16 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)',
#   '5/15/2021'],
#  ['Deajah STEVENSJROregon22.16 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)5/27/2017',
#   'Deajah STEVENSJR',
#   '',
#   'Oregon',
#   '22.16 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)',
#   '5/27/2017'],
#  [],
#  ['Deajah STEVENSJR',
#   '',
#   'Oregon',
#   '22.16 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)',
#   '5/27/2017'],
#  ['Deajah STEVENSJROregon22.16 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)5/27/2017',
#   'Deajah STEVENSJR',
#   '',
#   'Oregon',
#   '22.16 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)',
#   '5/27/2017'],
#  [],
#  ['Deajah STEVENSJR',
#   '',
#   'Oregon',
#   '22.16 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)',
#   '5/27/2017'],
#  ['Morolake AKINOSUNSOTexas22.17 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.3)5/18/2014',
#   'Morolake AKINOSUNSO',
#   '',
#   'Texas',
#   '22.17 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.3)',
#   '5/18/2014'],
#  [],
#  ['Morolake AKINOSUNSO',
#   '',
#   'Texas',
#   '22.17 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.3)',
#   '5/18/2014'],
#  ['Kimberlyn DUNCANSOLSU22.18 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 4/23/2011',
#   'Kimberlyn DUNCANSO',
#   '',
#   'LSU',
#   '22.18 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/23/2011'],
#  [],
#  ['Kimberlyn DUNCANSO',
#   '',
#   'LSU',
#   '22.18 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/23/2011'],
#  ['Felicia BROWNSRTennessee22.19 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)5/14/2016',
#   'Felicia BROWNSR',
#   '',
#   'Tennessee',
#   '22.19 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)',
#   '5/14/2016'],
#  [],
#  ['Felicia BROWNSR',
#   '',
#   'Tennessee',
#   '22.19 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)',
#   '5/14/2016'],
#  ['Jasmine CAMACHO-QUINNJRKentucky22.21 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.8)5/25/2018',
#   'Jasmine CAMACHO-QUINNJR',
#   '',
#   'Kentucky',
#   '22.21 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.8)',
#   '5/25/2018'],
#  [],
#  ['Jasmine CAMACHO-QUINNJR',
#   '',
#   'Kentucky',
#   '22.21 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.8)',
#   '5/25/2018'],
#  ['Kamaria BROWNSOTexas A&M22.21 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)6/8/2013',
#   'Kamaria BROWNSO',
#   '',
#   'Texas A&M',
#   '22.21 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)',
#   '6/8/2013'],
#  [],
#  ['Kamaria BROWNSO',
#   '',
#   'Texas A&M',
#   '22.21 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)',
#   '6/8/2013'],
#  ['Muna LEESRLSU22.22 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 5/29/2004',
#   'Muna LEESR',
#   '',
#   'LSU',
#   '22.22 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '5/29/2004'],
#  [],
#  ['Muna LEESR',
#   '',
#   'LSU',
#   '22.22 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '5/29/2004'],
#  ['LaTasha JENKINSBall State22.22 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)6/4/1999',
#   'LaTasha JENKINS',
#   '',
#   'Ball State',
#   '22.22 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '6/4/1999'],
#  [],
#  ['LaTasha JENKINS',
#   '',
#   'Ball State',
#   '22.22 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '6/4/1999'],
#  ['Peta-Gaye DOWDIELSU22.25 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 4/17/1999',
#   'Peta-Gaye DOWDIE',
#   '',
#   'LSU',
#   '22.25 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/17/1999'],
#  [],
#  ['Peta-Gaye DOWDIE',
#   '',
#   'LSU',
#   '22.25 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/17/1999'],
#  ['Caisja CHANDLERSRSouthern California22.27 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)5/27/2023',
#   'Caisja CHANDLERSR',
#   '',
#   'Southern California',
#   '22.27 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)',
#   '5/27/2023'],
#  [],
#  ['Caisja CHANDLERSR',
#   '',
#   'Southern California',
#   '22.27 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.5)',
#   '5/27/2023'],
#  ['Anavia BATTLESROhio State22.27 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 6.3)5/1/2021',
#   'Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.27 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 6.3)',
#   '5/1/2021'],
#  [],
#  ['Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.27 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 6.3)',
#   '5/1/2021'],
#  ['Felicia BROWNSRTennessee22.27 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.1)5/28/2016',
#   'Felicia BROWNSR',
#   '',
#   'Tennessee',
#   '22.27 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.1)',
#   '5/28/2016'],
#  [],
#  ['Felicia BROWNSR',
#   '',
#   'Tennessee',
#   '22.27 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.1)',
#   '5/28/2016'],
#  ['Kimberlyn DUNCANSOLSU22.27 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 5/15/2011',
#   'Kimberlyn DUNCANSO',
#   '',
#   'LSU',
#   '22.27 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '5/15/2011'],
#  [],
#  ['Kimberlyn DUNCANSO',
#   '',
#   'LSU',
#   '22.27 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '5/15/2011'],
#  ['Anavia BATTLESROhio State22.28 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.2)5/15/2022',
#   'Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.28 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.2)',
#   '5/15/2022'],
#  [],
#  ['Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.28 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.2)',
#   '5/15/2022'],
#  ['Kamaria BROWNTexas A&M22.29 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.6)6/11/2015',
#   'Kamaria BROWN',
#   '',
#   'Texas A&M',
#   '22.29 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.6)',
#   '6/11/2015'],
#  [],
#  ['Kamaria BROWN',
#   '',
#   'Texas A&M',
#   '22.29 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.6)',
#   '6/11/2015'],
#  ['Additional Out-of-Season Bests'],
#  ['Abby STEINERJRKentucky21.77   (w: -0.3)6/26/2022',
#   'Abby STEINERJR',
#   '',
#   'Kentucky',
#   '21.77   (w: -0.3)',
#   '6/26/2022'],
#  [],
#  ['Abby STEINERJR', '', 'Kentucky', '21.77   (w: -0.3)', '6/26/2022'],
#  ['Abby STEINERJRKentucky21.80 qq = Performance occurred during a non-final round.  (w: 0.9)6/26/2022',
#   'Abby STEINERJR',
#   '',
#   'Kentucky',
#   '21.80 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '6/26/2022'],
#  [],
#  ['Abby STEINERJR',
#   '',
#   'Kentucky',
#   '21.80 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '6/26/2022'],
#  ['Anavia BATTLESROhio State21.95  (w: 1.3)6/26/2021',
#   'Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '21.95  (w: 1.3)',
#   '6/26/2021'],
#  [],
#  ['Anavia BATTLESR', '', 'Ohio State', '21.95  (w: 1.3)', '6/26/2021'],
#  ['Tamara CLARKJRAlabama21.98  (w: 1.3)6/26/2021',
#   'Tamara CLARKJR',
#   '',
#   'Alabama',
#   '21.98  (w: 1.3)',
#   '6/26/2021'],
#  [],
#  ['Tamara CLARKJR', '', 'Alabama', '21.98  (w: 1.3)', '6/26/2021'],
#  ['Veronica CAMPBELLJRArkansas22.05   (w: 0.8)8/25/2004',
#   'Veronica CAMPBELLJR',
#   '',
#   'Arkansas',
#   '22.05   (w: 0.8)',
#   '8/25/2004'],
#  [],
#  ['Veronica CAMPBELLJR', '', 'Arkansas', '22.05   (w: 0.8)', '8/25/2004'],
#  ['Julien ALFREDJRTexas22.08   (w: 0.2)7/21/2023',
#   'Julien ALFREDJR',
#   '',
#   'Texas',
#   '22.08   (w: 0.2)',
#   '7/21/2023'],
#  [],
#  ['Julien ALFREDJR', '', 'Texas', '22.08   (w: 0.2)', '7/21/2023'],
#  ['Abby STEINERJRKentucky22.14 qq = Performance occurred during a non-final round.  (w: 0.1)6/25/2022',
#   'Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.14 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '6/25/2022'],
#  [],
#  ['Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.14 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '6/25/2022'],
#  ['Abby STEINERJRKentucky22.15 qq = Performance occurred during a non-final round.  (w: -0.1)7/19/2022',
#   'Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.15 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '7/19/2022'],
#  [],
#  ['Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.15 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '7/19/2022'],
#  ['Merlene OTTEYJRNebraska22.17   (w: -1.0)6/20/1982',
#   'Merlene OTTEYJR',
#   '',
#   'Nebraska',
#   '22.17   (w: -1.0)',
#   '6/20/1982'],
#  [],
#  ['Merlene OTTEYJR', '', 'Nebraska', '22.17   (w: -1.0)', '6/20/1982'],
#  ['Gabby THOMASJRHarvard22.19   (w: 0.9)7/22/2018',
#   'Gabby THOMASJR',
#   '',
#   'Harvard',
#   '22.19   (w: 0.9)',
#   '7/22/2018'],
#  [],
#  ['Gabby THOMASJR', '', 'Harvard', '22.19   (w: 0.9)', '7/22/2018'],
#  ['Debbie FERGUSONGeorgia22.19   (w: 0.0)7/3/1999',
#   'Debbie FERGUSON',
#   '',
#   'Georgia',
#   '22.19   (w: 0.0)',
#   '7/3/1999'],
#  [],
#  ['Debbie FERGUSON', '', 'Georgia', '22.19   (w: 0.0)', '7/3/1999'],
#  ['Jenna PRANDINIJROregon22.20   (w: 0.4)6/28/2015',
#   'Jenna PRANDINIJR',
#   '',
#   'Oregon',
#   '22.20   (w: 0.4)',
#   '6/28/2015'],
#  [],
#  ['Jenna PRANDINIJR', '', 'Oregon', '22.20   (w: 0.4)', '6/28/2015'],
#  ['Favour OFILIFRLSU22.23   (w: 1.1)8/21/2021',
#   'Favour OFILIFR',
#   '',
#   'LSU',
#   '22.23   (w: 1.1)',
#   '8/21/2021'],
#  [],
#  ['Favour OFILIFR', '', 'LSU', '22.23   (w: 1.1)', '8/21/2021'],
#  ['Florence GRIFFITHUCLA22.23   (w: 0.9)6/19/1983',
#   'Florence GRIFFITH',
#   '',
#   'UCLA',
#   '22.23   (w: 0.9)',
#   '6/19/1983'],
#  [],
#  ['Florence GRIFFITH', '', 'UCLA', '22.23   (w: 0.9)', '6/19/1983'],
#  ['Favour OFILISOLSU22.24 qq = Performance occurred during a non-final round.  (w: 1.9)7/18/2022',
#   'Favour OFILISO',
#   '',
#   'LSU',
#   '22.24 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '7/18/2022'],
#  [],
#  ['Favour OFILISO',
#   '',
#   'LSU',
#   '22.24 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '7/18/2022'],
#  ['Simone FACEYTexas A&M22.25  6/29/2008',
#   'Simone FACEY',
#   '',
#   'Texas A&M',
#   '22.25  ',
#   '6/29/2008'],
#  [],
#  ['Simone FACEY', '', 'Texas A&M', '22.25  ', '6/29/2008'],
#  ['Abby STEINERJRKentucky22.26   (w: 0.6)7/21/2022',
#   'Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.26   (w: 0.6)',
#   '7/21/2022'],
#  [],
#  ['Abby STEINERJR', '', 'Kentucky', '22.26   (w: 0.6)', '7/21/2022'],
#  ['Abby STEINERJRKentucky22.26 qq = Performance occurred during a non-final round.  (w: 0.9)7/18/2022',
#   'Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '7/18/2022'],
#  [],
#  ['Abby STEINERJR',
#   '',
#   'Kentucky',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '7/18/2022'],
#  ['Jeneba TARMOHTexas A&M22.28   (w: 1.0)6/26/2011',
#   'Jeneba TARMOH',
#   '',
#   'Texas A&M',
#   '22.28   (w: 1.0)',
#   '6/26/2011'],
#  [],
#  ['Jeneba TARMOH', '', 'Texas A&M', '22.28   (w: 1.0)', '6/26/2011'],
#  ['Additional Out-of-Season, All-Conditions Bests'],
#  ['Kimberlyn DUNCANSRLSU21.80 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)6/23/2013',
#   'Kimberlyn DUNCANSR',
#   '',
#   'LSU',
#   '21.80 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '6/23/2013'],
#  [],
#  ['Kimberlyn DUNCANSR',
#   '',
#   'LSU',
#   '21.80 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '6/23/2013'],
#  ['Kamaria BROWNSOTexas A&M22.16 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)6/23/2013',
#   'Kamaria BROWNSO',
#   '',
#   'Texas A&M',
#   '22.16 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '6/23/2013'],
#  [],
#  ['Kamaria BROWNSO',
#   '',
#   'Texas A&M',
#   '22.16 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '6/23/2013'],
#  ['Jenna PRANDINIJROregon22.18 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.8)6/27/2015',
#   'Jenna PRANDINIJR',
#   '',
#   'Oregon',
#   '22.18 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.8)',
#   '6/27/2015'],
#  [],
#  ['Jenna PRANDINIJR',
#   '',
#   'Oregon',
#   '22.18 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.8)',
#   '6/27/2015'],
#  ['', 'European U20 Championships'],
#  ['', '', '', '']]

# %%
rows[162]
# Out:
# ['(24) Merlene OTTEYJR',
#  '',
#  'Nebraska',
#  '22.29 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round.  (w: -1.7)',
#  '6/3/1982']

# %%
len(rows)
# Out:
# 330

# %%
RealRows = []

# %%
for i in range(0,163):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [['(1) Abby STEINERJRKentucky21.80📺  (w: 1.3)6/11/2022',
#   '(1) Abby STEINERJR',
#   '',
#   'Kentucky',
#   '21.80📺  (w: 1.3)',
#   '6/11/2022'],
#  ['(1) Abby STEINERJR', '', 'Kentucky', '21.80📺  (w: 1.3)', '6/11/2022'],
#  ['(2) Julien ALFREDJRTexas21.91📺  (w: 1.8)4/14/2023',
#   '(2) Julien ALFREDJR',
#   '',
#   'Texas',
#   '21.91📺  (w: 1.8)',
#   '4/14/2023'],
#  ['(2) Julien ALFREDJR', '', 'Texas', '21.91📺  (w: 1.8)', '4/14/2023'],
#  ['(3) Favour OFILISOLSU21.96  (w: 1.3)4/15/2022',
#   '(3) Favour OFILISO',
#   '',
#   'LSU',
#   '21.96  (w: 1.3)',
#   '4/15/2022'],
#  ['(3) Favour OFILISO', '', 'LSU', '21.96  (w: 1.3)', '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JRKentucky22.02 qq = Performance occurred during a non-final round.  (w: 0.5)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '22.02 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '22.02 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/9/2022'],
#  ['(4) Kyra JEFFERSONSRFlorida22.02  (w: 1.1)6/10/2017\xa0\xa0\xa0\xa0\xa011.5/10.5',
#   '(4) Kyra JEFFERSONSR',
#   '',
#   'Florida',
#   '22.02  (w: 1.1)',
#   '6/10/2017',
#   '\xa0\xa0\xa0\xa0\xa011.5/10.5'],
#  ['(4) Kyra JEFFERSONSR', '', 'Florida', '22.02  (w: 1.1)', '6/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}SOLSU22.04  (w: 0.2)5/14/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {2}SO',
#   '',
#   'LSU',
#   '22.04  (w: 0.2)',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}SO', '', 'LSU', '22.04  (w: 0.2)', '5/14/2022'],
#  ['(5) Dawn SOWELLSRLSU22.04 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.7)6/2/1989',
#   '(5) Dawn SOWELLSR',
#   '',
#   'LSU',
#   '22.04 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.7)',
#   '6/2/1989'],
#  ['(5) Dawn SOWELLSR',
#   '',
#   'LSU',
#   '22.04 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.7)',
#   '6/2/1989'],
#  ['\xa0\xa0\xa0\xa0— Ofili {3}SOLSU22.05  (w: 1.3)6/11/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {3}SO',
#   '',
#   'LSU',
#   '22.05  (w: 1.3)',
#   '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {3}SO', '', 'LSU', '22.05  (w: 1.3)', '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JRKentucky22.05  (w: 0.5)4/22/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {3}JR',
#   '',
#   'Kentucky',
#   '22.05  (w: 0.5)',
#   '4/22/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JR',
#   '',
#   'Kentucky',
#   '22.05  (w: 0.5)',
#   '4/22/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {4}JRKentucky22.07  (w: 0.2)5/14/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {4}JR',
#   '',
#   'Kentucky',
#   '22.07  (w: 0.2)',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {4}JR',
#   '',
#   'Kentucky',
#   '22.07  (w: 0.2)',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {4}SOLSU22.08 qq = Performance occurred during a non-final round.  (w: 0.7)5/28/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {4}SO',
#   '',
#   'LSU',
#   '22.08 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {4}SO',
#   '',
#   'LSU',
#   '22.08 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/28/2022'],
#  ['(6) Latasha SMITHJRUCF22.09  (w: 1.4)5/12/2023',
#   '(6) Latasha SMITHJR',
#   '',
#   'UCF',
#   '22.09  (w: 1.4)',
#   '5/12/2023'],
#  ['(6) Latasha SMITHJR', '', 'UCF', '22.09  (w: 1.4)', '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}JRTexas22.09  (w: 2.0)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {2}JR',
#   '',
#   'Texas',
#   '22.09  (w: 2.0)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}JR',
#   '',
#   'Texas',
#   '22.09  (w: 2.0)',
#   '5/12/2023'],
#  ['(6) Deajah STEVENSJROregon22.09  (w: 1.5)5/14/2017',
#   '(6) Deajah STEVENSJR',
#   '',
#   'Oregon',
#   '22.09  (w: 1.5)',
#   '5/14/2017'],
#  ['(6) Deajah STEVENSJR', '', 'Oregon', '22.09  (w: 1.5)', '5/14/2017'],
#  ['(8) Cambrea STURGISSONorth Carolina A&T22.12  (w: 0.2)6/12/2021',
#   '(8) Cambrea STURGISSO',
#   '',
#   'North Carolina A&T',
#   '22.12  (w: 0.2)',
#   '6/12/2021'],
#  ['(8) Cambrea STURGISSO',
#   '',
#   'North Carolina A&T',
#   '22.12  (w: 0.2)',
#   '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Ofili {5}SOLSU22.13 qq = Performance occurred during a non-final round.  (w: -0.2)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {5}SO',
#   '',
#   'LSU',
#   '22.13 qq = Performance occurred during a non-final round.  (w: -0.2)',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {5}SO',
#   '',
#   'LSU',
#   '22.13 qq = Performance occurred during a non-final round.  (w: -0.2)',
#   '6/9/2022'],
#  ['(9) Tamara CLARKJRAlabama22.13 qq = Performance occurred during a non-final round.  (w: 0.5)5/29/2021',
#   '(9) Tamara CLARKJR',
#   '',
#   'Alabama',
#   '22.13 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/29/2021'],
#  ['(9) Tamara CLARKJR',
#   '',
#   'Alabama',
#   '22.13 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Clark {2}JRAlabama22.13 qq = Performance occurred during a non-final round.  (w: 0.5)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Clark {2}JR',
#   '',
#   'Alabama',
#   '22.13 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Clark {2}JR',
#   '',
#   'Alabama',
#   '22.13 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/27/2021'],
#  ['(10) Angie ANNELUSJRSouthern California22.16  (w: 1.3)6/8/2019',
#   '(10) Angie ANNELUSJR',
#   '',
#   'Southern California',
#   '22.16  (w: 1.3)',
#   '6/8/2019'],
#  ['(10) Angie ANNELUSJR',
#   '',
#   'Southern California',
#   '22.16  (w: 1.3)',
#   '6/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Clark {3}JRAlabama22.17  (w: 0.2)6/12/2021',
#   '\xa0\xa0\xa0\xa0— Clark {3}JR',
#   '',
#   'Alabama',
#   '22.17  (w: 0.2)',
#   '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Clark {3}JR',
#   '',
#   'Alabama',
#   '22.17  (w: 0.2)',
#   '6/12/2021'],
#  ["(11) Sha'Carri RICHARDSONFRLSU22.17  (w: 1.3)6/8/2019",
#   "(11) Sha'Carri RICHARDSONFR",
#   '',
#   'LSU',
#   '22.17  (w: 1.3)',
#   '6/8/2019'],
#  ["(11) Sha'Carri RICHARDSONFR", '', 'LSU', '22.17  (w: 1.3)', '6/8/2019'],
#  ['(12) Dezerea BRYANTKentucky22.18  (w: 1.9)6/13/2015\xa0\xa0\xa0\xa0\xa011.3/10.9',
#   '(12) Dezerea BRYANT',
#   '',
#   'Kentucky',
#   '22.18  (w: 1.9)',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa011.3/10.9'],
#  ['(12) Dezerea BRYANT', '', 'Kentucky', '22.18  (w: 1.9)', '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Steiner {5}JRKentucky22.19 qq = Performance occurred during a non-final round.  (w: 0.6)5/26/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {5}JR',
#   '',
#   'Kentucky',
#   '22.19 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '5/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {5}JR',
#   '',
#   'Kentucky',
#   '22.19 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '5/26/2022'],
#  ['(13) Kimberlyn DUNCANJRLSU22.19 qq = Performance occurred during a non-final round.  (w: 1.9)6/7/2012',
#   '(13) Kimberlyn DUNCANJR',
#   '',
#   'LSU',
#   '22.19 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '6/7/2012'],
#  ['(13) Kimberlyn DUNCANJR',
#   '',
#   'LSU',
#   '22.19 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '6/7/2012'],
#  ['\xa0\xa0\xa0\xa0— Ofili {6}SOLSU22.21  (w: -0.1)5/14/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {6}SO',
#   '',
#   'LSU',
#   '22.21  (w: -0.1)',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {6}SO', '', 'LSU', '22.21  (w: -0.1)', '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {7}SOLSU22.21 qq = Performance occurred during a non-final round.  (w: -0.1)5/12/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {7}SO',
#   '',
#   'LSU',
#   '22.21 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '5/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {7}SO',
#   '',
#   'LSU',
#   '22.21 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '5/12/2022'],
#  ['(14) Ariana WASHINGTONFROregon22.21  (w: 1.9)6/11/2016',
#   '(14) Ariana WASHINGTONFR',
#   '',
#   'Oregon',
#   '22.21  (w: 1.9)',
#   '6/11/2016'],
#  ['(14) Ariana WASHINGTONFR', '', 'Oregon', '22.21  (w: 1.9)', '6/11/2016'],
#  ['(14) Jenna PRANDINIOregon22.21  (w: 1.9)6/13/2015\xa0\xa0\xa0\xa0\xa011.3/10.9',
#   '(14) Jenna PRANDINI',
#   '',
#   'Oregon',
#   '22.21  (w: 1.9)',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa011.3/10.9'],
#  ['(14) Jenna PRANDINI', '', 'Oregon', '22.21  (w: 1.9)', '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Duncan {2}JRLSU22.22 qq = Performance occurred during a non-final round.  (w: 0.1)5/25/2012',
#   '\xa0\xa0\xa0\xa0— Duncan {2}JR',
#   '',
#   'LSU',
#   '22.22 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/25/2012'],
#  ['\xa0\xa0\xa0\xa0— Duncan {2}JR',
#   '',
#   'LSU',
#   '22.22 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/25/2012'],
#  ['(16) Kynnedy FLANNELJRTexas22.23 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)5/13/2022',
#   '(16) Kynnedy FLANNELJR',
#   '',
#   'Texas',
#   '22.23 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)',
#   '5/13/2022'],
#  ['(16) Kynnedy FLANNELJR',
#   '',
#   'Texas',
#   '22.23 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)',
#   '5/13/2022'],
#  ['(16) Olivia EKPONEJRTexas A&M22.23  (w: -0.8)5/18/2014',
#   '(16) Olivia EKPONEJR',
#   '',
#   'Texas A&M',
#   '22.23  (w: -0.8)',
#   '5/18/2014'],
#  ['(16) Olivia EKPONEJR', '', 'Texas A&M', '22.23  (w: -0.8)', '5/18/2014'],
#  ['(16) Carol RODRIGUEZSouthern California22.23 AA = Performance occurred at altitude (>1000 meters above sea level) 5/26/2006',
#   '(16) Carol RODRIGUEZ',
#   '',
#   'Southern California',
#   '22.23 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/26/2006'],
#  ['(16) Carol RODRIGUEZ',
#   '',
#   'Southern California',
#   '22.23 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/26/2006'],
#  ['(19) Kamaria BROWNTexas A&M22.24  (w: 1.9)6/13/2015\xa0\xa0\xa0\xa0\xa011.4/10.8',
#   '(19) Kamaria BROWN',
#   '',
#   'Texas A&M',
#   '22.24  (w: 1.9)',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa011.4/10.8'],
#  ['(19) Kamaria BROWN', '', 'Texas A&M', '22.24  (w: 1.9)', '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}Florida22.24  (w: 1.9)6/13/2015\xa0\xa0\xa0\xa0\xa011.5/10.7',
#   '\xa0\xa0\xa0\xa0— Jefferson {2}',
#   '',
#   'Florida',
#   '22.24  (w: 1.9)',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa011.5/10.7'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}',
#   '',
#   'Florida',
#   '22.24  (w: 1.9)',
#   '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Duncan {3}SOLSU22.24  (w: 1.5)6/11/2011',
#   '\xa0\xa0\xa0\xa0— Duncan {3}SO',
#   '',
#   'LSU',
#   '22.24  (w: 1.5)',
#   '6/11/2011'],
#  ['\xa0\xa0\xa0\xa0— Duncan {3}SO', '', 'LSU', '22.24  (w: 1.5)', '6/11/2011'],
#  ['\xa0\xa0\xa0\xa0— Flannel {2}JRTexas22.25 qq = Performance occurred during a non-final round.  (w: 0.9)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Flannel {2}JR',
#   '',
#   'Texas',
#   '22.25 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Flannel {2}JR',
#   '',
#   'Texas',
#   '22.25 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '6/9/2022'],
#  ['(20) Lynna IRBYFRGeorgia22.25  (w: 0.6)5/13/2018',
#   '(20) Lynna IRBYFR',
#   '',
#   'Georgia',
#   '22.25  (w: 0.6)',
#   '5/13/2018'],
#  ['(20) Lynna IRBYFR', '', 'Georgia', '22.25  (w: 0.6)', '5/13/2018'],
#  ['\xa0\xa0\xa0\xa0— Stevens {2}SOOregon22.25  (w: 1.9)6/11/2016',
#   '\xa0\xa0\xa0\xa0— Stevens {2}SO',
#   '',
#   'Oregon',
#   '22.25  (w: 1.9)',
#   '6/11/2016'],
#  ['\xa0\xa0\xa0\xa0— Stevens {2}SO',
#   '',
#   'Oregon',
#   '22.25  (w: 1.9)',
#   '6/11/2016'],
#  ['(21) Anavia BATTLESROhio State22.26 qq = Performance occurred during a non-final round.  (w: 0.9)6/9/2022',
#   '(21) Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '6/9/2022'],
#  ['(21) Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '6/9/2022'],
#  ['(21) Kevona DAVISSOTexas22.26 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)5/13/2022',
#   '(21) Kevona DAVISSO',
#   '',
#   'Texas',
#   '22.26 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)',
#   '5/13/2022'],
#  ['(21) Kevona DAVISSO',
#   '',
#   'Texas',
#   '22.26 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Sturgis {2}SONorth Carolina A&T22.26 qq = Performance occurred during a non-final round.  (w: 0.0)5/29/2021',
#   '\xa0\xa0\xa0\xa0— Sturgis {2}SO',
#   '',
#   'North Carolina A&T',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Sturgis {2}SO',
#   '',
#   'North Carolina A&T',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Sturgis {3}SONorth Carolina A&T22.26 qq = Performance occurred during a non-final round.  (w: 0.0)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Sturgis {3}SO',
#   '',
#   'North Carolina A&T',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Sturgis {3}SO',
#   '',
#   'North Carolina A&T',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/27/2021'],
#  ['(21) Felicia BROWNSRTennessee22.26  (w: -1.3)5/14/2016',
#   '(21) Felicia BROWNSR',
#   '',
#   'Tennessee',
#   '22.26  (w: -1.3)',
#   '5/14/2016'],
#  ['(21) Felicia BROWNSR', '', 'Tennessee', '22.26  (w: -1.3)', '5/14/2016'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {3}Florida22.26 qq = Performance occurred during a non-final round.  (w: 1.8)6/11/2015',
#   '\xa0\xa0\xa0\xa0— Jefferson {3}',
#   '',
#   'Florida',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 1.8)',
#   '6/11/2015'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {3}',
#   '',
#   'Florida',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 1.8)',
#   '6/11/2015'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {4}SOFlorida22.26 qq = Performance occurred during a non-final round.  (w: 0.5)5/29/2015',
#   '\xa0\xa0\xa0\xa0— Jefferson {4}SO',
#   '',
#   'Florida',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/29/2015'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {4}SO',
#   '',
#   'Florida',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/29/2015'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}JRTexas22.28  (w: 0.3)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {3}JR',
#   '',
#   'Texas',
#   '22.28  (w: 0.3)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}JR',
#   '',
#   'Texas',
#   '22.28  (w: 0.3)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Battle {2}SROhio State22.28 qq = Performance occurred during a non-final round.  (w: 1.9)5/29/2021',
#   '\xa0\xa0\xa0\xa0— Battle {2}SR',
#   '',
#   'Ohio State',
#   '22.28 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Battle {2}SR',
#   '',
#   'Ohio State',
#   '22.28 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Battle {3}SROhio State22.28 qq = Performance occurred during a non-final round.  (w: 1.9)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Battle {3}SR',
#   '',
#   'Ohio State',
#   '22.28 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Battle {3}SR',
#   '',
#   'Ohio State',
#   '22.28 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Ofili {8}SOLSU22.29 qq = Performance occurred during a non-final round.  (w: 2.0)5/26/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {8}SO',
#   '',
#   'LSU',
#   '22.29 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '5/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {8}SO',
#   '',
#   'LSU',
#   '22.29 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '5/26/2022'],
#  ['(24) Porscha LUCASSOTexas A&M22.29 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.4)5/18/2008',
#   '(24) Porscha LUCASSO',
#   '',
#   'Texas A&M',
#   '22.29 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.4)',
#   '5/18/2008'],
#  ['(24) Porscha LUCASSO',
#   '',
#   'Texas A&M',
#   '22.29 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.4)',
#   '5/18/2008'],
#  ['(24) LaTasha JENKINSSRBall State22.29   (w: 0.6)6/5/1999',
#   '(24) LaTasha JENKINSSR',
#   '',
#   'Ball State',
#   '22.29   (w: 0.6)',
#   '6/5/1999'],
#  ['(24) LaTasha JENKINSSR', '', 'Ball State', '22.29   (w: 0.6)', '6/5/1999'],
#  ['(24) Merlene OTTEYJRNebraska22.29 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round.  (w: -1.7)6/3/1982',
#   '(24) Merlene OTTEYJR',
#   '',
#   'Nebraska',
#   '22.29 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round.  (w: -1.7)',
#   '6/3/1982'],
#  ['(24) Merlene OTTEYJR',
#   '',
#   'Nebraska',
#   '22.29 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round.  (w: -1.7)',
#   '6/3/1982']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Abby STEINERJRKentucky21.80📺  (w: 1.3)6/11/2022',
#   '(1) Abby STEINERJR',
#   '',
#   'Kentucky',
#   '21.80📺  (w: 1.3)',
#   '6/11/2022'],
#  ['(2) Julien ALFREDJRTexas21.91📺  (w: 1.8)4/14/2023',
#   '(2) Julien ALFREDJR',
#   '',
#   'Texas',
#   '21.91📺  (w: 1.8)',
#   '4/14/2023'],
#  ['(3) Favour OFILISOLSU21.96  (w: 1.3)4/15/2022',
#   '(3) Favour OFILISO',
#   '',
#   'LSU',
#   '21.96  (w: 1.3)',
#   '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JRKentucky22.02 qq = Performance occurred during a non-final round.  (w: 0.5)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '22.02 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/9/2022'],
#  ['(4) Kyra JEFFERSONSRFlorida22.02  (w: 1.1)6/10/2017\xa0\xa0\xa0\xa0\xa011.5/10.5',
#   '(4) Kyra JEFFERSONSR',
#   '',
#   'Florida',
#   '22.02  (w: 1.1)',
#   '6/10/2017',
#   '\xa0\xa0\xa0\xa0\xa011.5/10.5'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}SOLSU22.04  (w: 0.2)5/14/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {2}SO',
#   '',
#   'LSU',
#   '22.04  (w: 0.2)',
#   '5/14/2022'],
#  ['(5) Dawn SOWELLSRLSU22.04 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.7)6/2/1989',
#   '(5) Dawn SOWELLSR',
#   '',
#   'LSU',
#   '22.04 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.7)',
#   '6/2/1989'],
#  ['\xa0\xa0\xa0\xa0— Ofili {3}SOLSU22.05  (w: 1.3)6/11/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {3}SO',
#   '',
#   'LSU',
#   '22.05  (w: 1.3)',
#   '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JRKentucky22.05  (w: 0.5)4/22/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {3}JR',
#   '',
#   'Kentucky',
#   '22.05  (w: 0.5)',
#   '4/22/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {4}JRKentucky22.07  (w: 0.2)5/14/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {4}JR',
#   '',
#   'Kentucky',
#   '22.07  (w: 0.2)',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {4}SOLSU22.08 qq = Performance occurred during a non-final round.  (w: 0.7)5/28/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {4}SO',
#   '',
#   'LSU',
#   '22.08 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/28/2022'],
#  ['(6) Latasha SMITHJRUCF22.09  (w: 1.4)5/12/2023',
#   '(6) Latasha SMITHJR',
#   '',
#   'UCF',
#   '22.09  (w: 1.4)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}JRTexas22.09  (w: 2.0)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {2}JR',
#   '',
#   'Texas',
#   '22.09  (w: 2.0)',
#   '5/12/2023'],
#  ['(6) Deajah STEVENSJROregon22.09  (w: 1.5)5/14/2017',
#   '(6) Deajah STEVENSJR',
#   '',
#   'Oregon',
#   '22.09  (w: 1.5)',
#   '5/14/2017'],
#  ['(8) Cambrea STURGISSONorth Carolina A&T22.12  (w: 0.2)6/12/2021',
#   '(8) Cambrea STURGISSO',
#   '',
#   'North Carolina A&T',
#   '22.12  (w: 0.2)',
#   '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Ofili {5}SOLSU22.13 qq = Performance occurred during a non-final round.  (w: -0.2)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {5}SO',
#   '',
#   'LSU',
#   '22.13 qq = Performance occurred during a non-final round.  (w: -0.2)',
#   '6/9/2022'],
#  ['(9) Tamara CLARKJRAlabama22.13 qq = Performance occurred during a non-final round.  (w: 0.5)5/29/2021',
#   '(9) Tamara CLARKJR',
#   '',
#   'Alabama',
#   '22.13 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Clark {2}JRAlabama22.13 qq = Performance occurred during a non-final round.  (w: 0.5)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Clark {2}JR',
#   '',
#   'Alabama',
#   '22.13 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/27/2021'],
#  ['(10) Angie ANNELUSJRSouthern California22.16  (w: 1.3)6/8/2019',
#   '(10) Angie ANNELUSJR',
#   '',
#   'Southern California',
#   '22.16  (w: 1.3)',
#   '6/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Clark {3}JRAlabama22.17  (w: 0.2)6/12/2021',
#   '\xa0\xa0\xa0\xa0— Clark {3}JR',
#   '',
#   'Alabama',
#   '22.17  (w: 0.2)',
#   '6/12/2021'],
#  ["(11) Sha'Carri RICHARDSONFRLSU22.17  (w: 1.3)6/8/2019",
#   "(11) Sha'Carri RICHARDSONFR",
#   '',
#   'LSU',
#   '22.17  (w: 1.3)',
#   '6/8/2019'],
#  ['(12) Dezerea BRYANTKentucky22.18  (w: 1.9)6/13/2015\xa0\xa0\xa0\xa0\xa011.3/10.9',
#   '(12) Dezerea BRYANT',
#   '',
#   'Kentucky',
#   '22.18  (w: 1.9)',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa011.3/10.9'],
#  ['\xa0\xa0\xa0\xa0— Steiner {5}JRKentucky22.19 qq = Performance occurred during a non-final round.  (w: 0.6)5/26/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {5}JR',
#   '',
#   'Kentucky',
#   '22.19 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '5/26/2022'],
#  ['(13) Kimberlyn DUNCANJRLSU22.19 qq = Performance occurred during a non-final round.  (w: 1.9)6/7/2012',
#   '(13) Kimberlyn DUNCANJR',
#   '',
#   'LSU',
#   '22.19 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '6/7/2012'],
#  ['\xa0\xa0\xa0\xa0— Ofili {6}SOLSU22.21  (w: -0.1)5/14/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {6}SO',
#   '',
#   'LSU',
#   '22.21  (w: -0.1)',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {7}SOLSU22.21 qq = Performance occurred during a non-final round.  (w: -0.1)5/12/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {7}SO',
#   '',
#   'LSU',
#   '22.21 qq = Performance occurred during a non-final round.  (w: -0.1)',
#   '5/12/2022'],
#  ['(14) Ariana WASHINGTONFROregon22.21  (w: 1.9)6/11/2016',
#   '(14) Ariana WASHINGTONFR',
#   '',
#   'Oregon',
#   '22.21  (w: 1.9)',
#   '6/11/2016'],
#  ['(14) Jenna PRANDINIOregon22.21  (w: 1.9)6/13/2015\xa0\xa0\xa0\xa0\xa011.3/10.9',
#   '(14) Jenna PRANDINI',
#   '',
#   'Oregon',
#   '22.21  (w: 1.9)',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa011.3/10.9'],
#  ['\xa0\xa0\xa0\xa0— Duncan {2}JRLSU22.22 qq = Performance occurred during a non-final round.  (w: 0.1)5/25/2012',
#   '\xa0\xa0\xa0\xa0— Duncan {2}JR',
#   '',
#   'LSU',
#   '22.22 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/25/2012'],
#  ['(16) Kynnedy FLANNELJRTexas22.23 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)5/13/2022',
#   '(16) Kynnedy FLANNELJR',
#   '',
#   'Texas',
#   '22.23 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)',
#   '5/13/2022'],
#  ['(16) Olivia EKPONEJRTexas A&M22.23  (w: -0.8)5/18/2014',
#   '(16) Olivia EKPONEJR',
#   '',
#   'Texas A&M',
#   '22.23  (w: -0.8)',
#   '5/18/2014'],
#  ['(16) Carol RODRIGUEZSouthern California22.23 AA = Performance occurred at altitude (>1000 meters above sea level) 5/26/2006',
#   '(16) Carol RODRIGUEZ',
#   '',
#   'Southern California',
#   '22.23 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/26/2006'],
#  ['(19) Kamaria BROWNTexas A&M22.24  (w: 1.9)6/13/2015\xa0\xa0\xa0\xa0\xa011.4/10.8',
#   '(19) Kamaria BROWN',
#   '',
#   'Texas A&M',
#   '22.24  (w: 1.9)',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa011.4/10.8'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}Florida22.24  (w: 1.9)6/13/2015\xa0\xa0\xa0\xa0\xa011.5/10.7',
#   '\xa0\xa0\xa0\xa0— Jefferson {2}',
#   '',
#   'Florida',
#   '22.24  (w: 1.9)',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa011.5/10.7'],
#  ['\xa0\xa0\xa0\xa0— Duncan {3}SOLSU22.24  (w: 1.5)6/11/2011',
#   '\xa0\xa0\xa0\xa0— Duncan {3}SO',
#   '',
#   'LSU',
#   '22.24  (w: 1.5)',
#   '6/11/2011'],
#  ['\xa0\xa0\xa0\xa0— Flannel {2}JRTexas22.25 qq = Performance occurred during a non-final round.  (w: 0.9)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Flannel {2}JR',
#   '',
#   'Texas',
#   '22.25 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '6/9/2022'],
#  ['(20) Lynna IRBYFRGeorgia22.25  (w: 0.6)5/13/2018',
#   '(20) Lynna IRBYFR',
#   '',
#   'Georgia',
#   '22.25  (w: 0.6)',
#   '5/13/2018'],
#  ['\xa0\xa0\xa0\xa0— Stevens {2}SOOregon22.25  (w: 1.9)6/11/2016',
#   '\xa0\xa0\xa0\xa0— Stevens {2}SO',
#   '',
#   'Oregon',
#   '22.25  (w: 1.9)',
#   '6/11/2016'],
#  ['(21) Anavia BATTLESROhio State22.26 qq = Performance occurred during a non-final round.  (w: 0.9)6/9/2022',
#   '(21) Anavia BATTLESR',
#   '',
#   'Ohio State',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '6/9/2022'],
#  ['(21) Kevona DAVISSOTexas22.26 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)5/13/2022',
#   '(21) Kevona DAVISSO',
#   '',
#   'Texas',
#   '22.26 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Sturgis {2}SONorth Carolina A&T22.26 qq = Performance occurred during a non-final round.  (w: 0.0)5/29/2021',
#   '\xa0\xa0\xa0\xa0— Sturgis {2}SO',
#   '',
#   'North Carolina A&T',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Sturgis {3}SONorth Carolina A&T22.26 qq = Performance occurred during a non-final round.  (w: 0.0)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Sturgis {3}SO',
#   '',
#   'North Carolina A&T',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/27/2021'],
#  ['(21) Felicia BROWNSRTennessee22.26  (w: -1.3)5/14/2016',
#   '(21) Felicia BROWNSR',
#   '',
#   'Tennessee',
#   '22.26  (w: -1.3)',
#   '5/14/2016'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {3}Florida22.26 qq = Performance occurred during a non-final round.  (w: 1.8)6/11/2015',
#   '\xa0\xa0\xa0\xa0— Jefferson {3}',
#   '',
#   'Florida',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 1.8)',
#   '6/11/2015'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {4}SOFlorida22.26 qq = Performance occurred during a non-final round.  (w: 0.5)5/29/2015',
#   '\xa0\xa0\xa0\xa0— Jefferson {4}SO',
#   '',
#   'Florida',
#   '22.26 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '5/29/2015'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}JRTexas22.28  (w: 0.3)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {3}JR',
#   '',
#   'Texas',
#   '22.28  (w: 0.3)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Battle {2}SROhio State22.28 qq = Performance occurred during a non-final round.  (w: 1.9)5/29/2021',
#   '\xa0\xa0\xa0\xa0— Battle {2}SR',
#   '',
#   'Ohio State',
#   '22.28 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Battle {3}SROhio State22.28 qq = Performance occurred during a non-final round.  (w: 1.9)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Battle {3}SR',
#   '',
#   'Ohio State',
#   '22.28 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Ofili {8}SOLSU22.29 qq = Performance occurred during a non-final round.  (w: 2.0)5/26/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {8}SO',
#   '',
#   'LSU',
#   '22.29 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '5/26/2022'],
#  ['(24) Porscha LUCASSOTexas A&M22.29 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.4)5/18/2008',
#   '(24) Porscha LUCASSO',
#   '',
#   'Texas A&M',
#   '22.29 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.4)',
#   '5/18/2008'],
#  ['(24) LaTasha JENKINSSRBall State22.29   (w: 0.6)6/5/1999',
#   '(24) LaTasha JENKINSSR',
#   '',
#   'Ball State',
#   '22.29   (w: 0.6)',
#   '6/5/1999'],
#  ['(24) Merlene OTTEYJRNebraska22.29 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round.  (w: -1.7)6/3/1982',
#   '(24) Merlene OTTEYJR',
#   '',
#   'Nebraska',
#   '22.29 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round.  (w: -1.7)',
#   '6/3/1982']]

# %%
RealRealRows[1][4]
# Out:
# '21.91📺  (w: 1.8)'

# %%
len(RealRealRows)
# Out:
# 52

# %%
OfficialTimes = []

# %%
for i in range(0,len(RealRealRows)):
    OfficialTimes.append(RealRealRows[i][4])
OfficialTimes
# Out:
# ['21.80📺  (w: 1.3)',
#  '21.91📺  (w: 1.8)',
#  '21.96  (w: 1.3)',
#  '22.02 qq = Performance occurred during a non-final round.  (w: 0.5)',
#  '22.02  (w: 1.1)',
#  '22.04  (w: 0.2)',
#  '22.04 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.7)',
#  '22.05  (w: 1.3)',
#  '22.05  (w: 0.5)',
#  '22.07  (w: 0.2)',
#  '22.08 qq = Performance occurred during a non-final round.  (w: 0.7)',
#  '22.09  (w: 1.4)',
#  '22.09  (w: 2.0)',
#  '22.09  (w: 1.5)',
#  '22.12  (w: 0.2)',
#  '22.13 qq = Performance occurred during a non-final round.  (w: -0.2)',
#  '22.13 qq = Performance occurred during a non-final round.  (w: 0.5)',
#  '22.13 qq = Performance occurred during a non-final round.  (w: 0.5)',
#  '22.16  (w: 1.3)',
#  '22.17  (w: 0.2)',
#  '22.17  (w: 1.3)',
#  '22.18  (w: 1.9)',
#  '22.19 qq = Performance occurred during a non-final round.  (w: 0.6)',
#  '22.19 qq = Performance occurred during a non-final round.  (w: 1.9)',
#  '22.21  (w: -0.1)',
#  '22.21 qq = Performance occurred during a non-final round.  (w: -0.1)',
#  '22.21  (w: 1.9)',
#  '22.21  (w: 1.9)',
#  '22.22 qq = Performance occurred during a non-final round.  (w: 0.1)',
#  '22.23 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)',
#  '22.23  (w: -0.8)',
#  '22.23 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '22.24  (w: 1.9)',
#  '22.24  (w: 1.9)',
#  '22.24  (w: 1.5)',
#  '22.25 qq = Performance occurred during a non-final round.  (w: 0.9)',
#  '22.25  (w: 0.6)',
#  '22.25  (w: 1.9)',
#  '22.26 qq = Performance occurred during a non-final round.  (w: 0.9)',
#  '22.26 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 2.0)',
#  '22.26 qq = Performance occurred during a non-final round.  (w: 0.0)',
#  '22.26 qq = Performance occurred during a non-final round.  (w: 0.0)',
#  '22.26  (w: -1.3)',
#  '22.26 qq = Performance occurred during a non-final round.  (w: 1.8)',
#  '22.26 qq = Performance occurred during a non-final round.  (w: 0.5)',
#  '22.28  (w: 0.3)',
#  '22.28 qq = Performance occurred during a non-final round.  (w: 1.9)',
#  '22.28 qq = Performance occurred during a non-final round.  (w: 1.9)',
#  '22.29 qq = Performance occurred during a non-final round.  (w: 2.0)',
#  '22.29 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.4)',
#  '22.29   (w: 0.6)',
#  '22.29 AA = Performance occurred at altitude (>1000 meters above sea level)qq = Performance occurred during a non-final round.  (w: -1.7)']

# %%
RealRealRows[0][1]
# Out:
# '(1) Abby STEINERJR'

# %%
Names = []

for i in range(0,len(RealRealRows)):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Abby STEINERJR',
#  '(2) Julien ALFREDJR',
#  '(3) Favour OFILISO',
#  '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#  '(4) Kyra JEFFERSONSR',
#  '\xa0\xa0\xa0\xa0— Ofili {2}SO',
#  '(5) Dawn SOWELLSR',
#  '\xa0\xa0\xa0\xa0— Ofili {3}SO',
#  '\xa0\xa0\xa0\xa0— Steiner {3}JR',
#  '\xa0\xa0\xa0\xa0— Steiner {4}JR',
#  '\xa0\xa0\xa0\xa0— Ofili {4}SO',
#  '(6) Latasha SMITHJR',
#  '\xa0\xa0\xa0\xa0— Alfred {2}JR',
#  '(6) Deajah STEVENSJR',
#  '(8) Cambrea STURGISSO',
#  '\xa0\xa0\xa0\xa0— Ofili {5}SO',
#  '(9) Tamara CLARKJR',
#  '\xa0\xa0\xa0\xa0— Clark {2}JR',
#  '(10) Angie ANNELUSJR',
#  '\xa0\xa0\xa0\xa0— Clark {3}JR',
#  "(11) Sha'Carri RICHARDSONFR",
#  '(12) Dezerea BRYANT',
#  '\xa0\xa0\xa0\xa0— Steiner {5}JR',
#  '(13) Kimberlyn DUNCANJR',
#  '\xa0\xa0\xa0\xa0— Ofili {6}SO',
#  '\xa0\xa0\xa0\xa0— Ofili {7}SO',
#  '(14) Ariana WASHINGTONFR',
#  '(14) Jenna PRANDINI',
#  '\xa0\xa0\xa0\xa0— Duncan {2}JR',
#  '(16) Kynnedy FLANNELJR',
#  '(16) Olivia EKPONEJR',
#  '(16) Carol RODRIGUEZ',
#  '(19) Kamaria BROWN',
#  '\xa0\xa0\xa0\xa0— Jefferson {2}',
#  '\xa0\xa0\xa0\xa0— Duncan {3}SO',
#  '\xa0\xa0\xa0\xa0— Flannel {2}JR',
#  '(20) Lynna IRBYFR',
#  '\xa0\xa0\xa0\xa0— Stevens {2}SO',
#  '(21) Anavia BATTLESR',
#  '(21) Kevona DAVISSO',
#  '\xa0\xa0\xa0\xa0— Sturgis {2}SO',
#  '\xa0\xa0\xa0\xa0— Sturgis {3}SO',
#  '(21) Felicia BROWNSR',
#  '\xa0\xa0\xa0\xa0— Jefferson {3}',
#  '\xa0\xa0\xa0\xa0— Jefferson {4}SO',
#  '\xa0\xa0\xa0\xa0— Alfred {3}JR',
#  '\xa0\xa0\xa0\xa0— Battle {2}SR',
#  '\xa0\xa0\xa0\xa0— Battle {3}SR',
#  '\xa0\xa0\xa0\xa0— Ofili {8}SO',
#  '(24) Porscha LUCASSO',
#  '(24) LaTasha JENKINSSR',
#  '(24) Merlene OTTEYJR']

# %%
OfficialReGexNames = []

# %%
for i in range(0,len(RealRealRows)):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Abby STEINERJR',
#  '(2) Julien ALFREDJR',
#  '(3) Favour OFILISO',
#  '— Steiner {2}JR',
#  '(4) Kyra JEFFERSONSR',
#  '— Ofili {2}SO',
#  '(5) Dawn SOWELLSR',
#  '— Ofili {3}SO',
#  '— Steiner {3}JR',
#  '— Steiner {4}JR',
#  '— Ofili {4}SO',
#  '(6) Latasha SMITHJR',
#  '— Alfred {2}JR',
#  '(6) Deajah STEVENSJR',
#  '(8) Cambrea STURGISSO',
#  '— Ofili {5}SO',
#  '(9) Tamara CLARKJR',
#  '— Clark {2}JR',
#  '(10) Angie ANNELUSJR',
#  '— Clark {3}JR',
#  "(11) Sha'Carri RICHARDSONFR",
#  '(12) Dezerea BRYANT',
#  '— Steiner {5}JR',
#  '(13) Kimberlyn DUNCANJR',
#  '— Ofili {6}SO',
#  '— Ofili {7}SO',
#  '(14) Ariana WASHINGTONFR',
#  '(14) Jenna PRANDINI',
#  '— Duncan {2}JR',
#  '(16) Kynnedy FLANNELJR',
#  '(16) Olivia EKPONEJR',
#  '(16) Carol RODRIGUEZ',
#  '(19) Kamaria BROWN',
#  '— Jefferson {2}',
#  '— Duncan {3}SO',
#  '— Flannel {2}JR',
#  '(20) Lynna IRBYFR',
#  '— Stevens {2}SO',
#  '(21) Anavia BATTLESR',
#  '(21) Kevona DAVISSO',
#  '— Sturgis {2}SO',
#  '— Sturgis {3}SO',
#  '(21) Felicia BROWNSR',
#  '— Jefferson {3}',
#  '— Jefferson {4}SO',
#  '— Alfred {3}JR',
#  '— Battle {2}SR',
#  '— Battle {3}SR',
#  '— Ofili {8}SO',
#  '(24) Porscha LUCASSO',
#  '(24) LaTasha JENKINSSR',
#  '(24) Merlene OTTEYJR']

# %%
CleanedNames = []

for i in range(0,len(RealRealRows)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Abby STEINERJR',
#  'Julien ALFREDJR',
#  'Favour OFILISO',
#  'Steiner {2}JR',
#  'Kyra JEFFERSONSR',
#  'Ofili {2}SO',
#  'Dawn SOWELLSR',
#  'Ofili {3}SO',
#  'Steiner {3}JR',
#  'Steiner {4}JR',
#  'Ofili {4}SO',
#  'Latasha SMITHJR',
#  'Alfred {2}JR',
#  'Deajah STEVENSJR',
#  'Cambrea STURGISSO',
#  'Ofili {5}SO',
#  'Tamara CLARKJR',
#  'Clark {2}JR',
#  ' Angie ANNELUSJR',
#  'Clark {3}JR',
#  " Sha'Carri RICHARDSONFR",
#  ' Dezerea BRYANT',
#  'Steiner {5}JR',
#  ' Kimberlyn DUNCANJR',
#  'Ofili {6}SO',
#  'Ofili {7}SO',
#  ' Ariana WASHINGTONFR',
#  ' Jenna PRANDINI',
#  'Duncan {2}JR',
#  ' Kynnedy FLANNELJR',
#  ' Olivia EKPONEJR',
#  ' Carol RODRIGUEZ',
#  ' Kamaria BROWN',
#  'Jefferson {2}',
#  'Duncan {3}SO',
#  'Flannel {2}JR',
#  ' Lynna IRBYFR',
#  'Stevens {2}SO',
#  ' Anavia BATTLESR',
#  ' Kevona DAVISSO',
#  'Sturgis {2}SO',
#  'Sturgis {3}SO',
#  ' Felicia BROWNSR',
#  'Jefferson {3}',
#  'Jefferson {4}SO',
#  'Alfred {3}JR',
#  'Battle {2}SR',
#  'Battle {3}SR',
#  'Ofili {8}SO',
#  ' Porscha LUCASSO',
#  ' LaTasha JENKINSSR',
#  ' Merlene OTTEYJR']

# %%
CleanedNames2 = []

for i in range(0,len(RealRealRows)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Abby STEINERJR',
#  'Julien ALFREDJR',
#  'Favour OFILISO',
#  'Steiner {2}JR',
#  'Kyra JEFFERSONSR',
#  'Ofili {2}SO',
#  'Dawn SOWELLSR',
#  'Ofili {3}SO',
#  'Steiner {3}JR',
#  'Steiner {4}JR',
#  'Ofili {4}SO',
#  'Latasha SMITHJR',
#  'Alfred {2}JR',
#  'Deajah STEVENSJR',
#  'Cambrea STURGISSO',
#  'Ofili {5}SO',
#  'Tamara CLARKJR',
#  'Clark {2}JR',
#  'Angie ANNELUSJR',
#  'Clark {3}JR',
#  "Sha'Carri RICHARDSONFR",
#  'Dezerea BRYANT',
#  'Steiner {5}JR',
#  'Kimberlyn DUNCANJR',
#  'Ofili {6}SO',
#  'Ofili {7}SO',
#  'Ariana WASHINGTONFR',
#  'Jenna PRANDINI',
#  'Duncan {2}JR',
#  'Kynnedy FLANNELJR',
#  'Olivia EKPONEJR',
#  'Carol RODRIGUEZ',
#  'Kamaria BROWN',
#  'Jefferson {2}',
#  'Duncan {3}SO',
#  'Flannel {2}JR',
#  'Lynna IRBYFR',
#  'Stevens {2}SO',
#  'Anavia BATTLESR',
#  'Kevona DAVISSO',
#  'Sturgis {2}SO',
#  'Sturgis {3}SO',
#  'Felicia BROWNSR',
#  'Jefferson {3}',
#  'Jefferson {4}SO',
#  'Alfred {3}JR',
#  'Battle {2}SR',
#  'Battle {3}SR',
#  'Ofili {8}SO',
#  'Porscha LUCASSO',
#  'LaTasha JENKINSSR',
#  'Merlene OTTEYJR']

# %%
len(OfficialTimes)
# Out:
# 52

# %%
len(OfficialReGexNames)
# Out:
# 52

# %%
Schools = []

for i in range(0,len(OfficialTimes)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Kentucky',
#  'Texas',
#  'LSU',
#  'Kentucky',
#  'Florida',
#  'LSU',
#  'LSU',
#  'LSU',
#  'Kentucky',
#  'Kentucky',
#  'LSU',
#  'UCF',
#  'Texas',
#  'Oregon',
#  'North Carolina A&T',
#  'LSU',
#  'Alabama',
#  'Alabama',
#  'Southern California',
#  'Alabama',
#  'LSU',
#  'Kentucky',
#  'Kentucky',
#  'LSU',
#  'LSU',
#  'LSU',
#  'Oregon',
#  'Oregon',
#  'LSU',
#  'Texas',
#  'Texas A&M',
#  'Southern California',
#  'Texas A&M',
#  'Florida',
#  'LSU',
#  'Texas',
#  'Georgia',
#  'Oregon',
#  'Ohio State',
#  'Texas',
#  'North Carolina A&T',
#  'North Carolina A&T',
#  'Tennessee',
#  'Florida',
#  'Florida',
#  'Texas',
#  'Ohio State',
#  'Ohio State',
#  'LSU',
#  'Texas A&M',
#  'Ball State',
#  'Nebraska']

# %%
Times = []
for i in range(0,len(OfficialTimes)):
    Times.append(OfficialTimes[i][:5])
    
Times
# Out:
# ['21.80',
#  '21.91',
#  '21.96',
#  '22.02',
#  '22.02',
#  '22.04',
#  '22.04',
#  '22.05',
#  '22.05',
#  '22.07',
#  '22.08',
#  '22.09',
#  '22.09',
#  '22.09',
#  '22.12',
#  '22.13',
#  '22.13',
#  '22.13',
#  '22.16',
#  '22.17',
#  '22.17',
#  '22.18',
#  '22.19',
#  '22.19',
#  '22.21',
#  '22.21',
#  '22.21',
#  '22.21',
#  '22.22',
#  '22.23',
#  '22.23',
#  '22.23',
#  '22.24',
#  '22.24',
#  '22.24',
#  '22.25',
#  '22.25',
#  '22.25',
#  '22.26',
#  '22.26',
#  '22.26',
#  '22.26',
#  '22.26',
#  '22.26',
#  '22.26',
#  '22.28',
#  '22.28',
#  '22.28',
#  '22.29',
#  '22.29',
#  '22.29',
#  '22.29']

# %%
Womens200mDF = pd.DataFrame({'Names': CleanedNames2, 'Times': Times, 'Schools': Schools})

# %%
Womens200mDF.to_csv('Womens200m.csv', index=False)
