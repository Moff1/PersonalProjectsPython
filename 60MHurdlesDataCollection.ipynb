# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
Link60MHurdles = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?sport=1&div=20527&top=25&event=13"

# %%
page = requests.get(Link60MHurdles)
soup = BeautifulSoup(page.text,'html')
soup
table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6099791" target="_blank">(1) Grant HOLLOWAY</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/60240/3664856" target="_blank">7.35</a><a href="https://www.youtube.com/watch?v=ZNbpQxerdR0" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6099791" target="_blank">(1) Grant HOLLOWAY</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/60240/3664856" target="_blank">7.35</a><a href="https://www.youtube.com/watch?v=ZNbpQxerdR0" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6578646" target="_blank">(2) Trey CUNNINGHAM</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416369" target="_blank">7.38</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6578646" target="_blank">(2) Trey CUNNINGHAM</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416369" target="_blank">7.38</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Cunningham {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72952" target="_blank">7.40</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="ACC Indoor Championships (Blacksburg, Va.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Cunningham {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72952" target="_blank">7.40</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="ACC Indoor Championships (Blacksburg, Va.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Cunningham {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72952/4389578" target="_blank">7.40</a> </td><td style="width: 10%;text-align:right;" title="ACC Indoor Championships (Blacksburg, Va.)"><span class="mark-date" style="width: 10%;text-align:right;">2/24/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Cunningham {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72952/4389578" target="_blank">7.40</a> </td><td style="width: 10%;text-align:right;" title="ACC Indoor Championships (Blacksburg, Va.)"><span class="mark-date" style="width: 10%;text-align:right;">2/24/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6083648" target="_blank">(3) Daniel ROBERTS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/60240/3664856" target="_blank">7.41</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6083648" target="_blank">(3) Daniel ROBERTS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/60240/3664856" target="_blank">7.41</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Cunningham {4}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72952/4389578" target="_blank">7.42</a> </td><td style="width: 10%;text-align:right;" title="ACC Indoor Championships (Blacksburg, Va.)"><span class="mark-date" style="width: 10%;text-align:right;">2/24/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Cunningham {4}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72952/4389578" target="_blank">7.42</a> </td><td style="width: 10%;text-align:right;" title="ACC Indoor Championships (Blacksburg, Va.)"><span class="mark-date" style="width: 10%;text-align:right;">2/24/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Cunningham {5}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/71332/4368909" target="_blank">7.42</a> </td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">2/11/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Cunningham {5}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/71332/4368909" target="_blank">7.42</a> </td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">2/11/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Holloway {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/52542/3288828" target="_blank">7.42</a> </td><td style="width: 10%;text-align:right;" title="Tiger Paw Invitational (Clemson, S.C.)"><span class="mark-date" style="width: 10%;text-align:right;">2/9/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Holloway {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/52542/3288828" target="_blank">7.42</a> </td><td style="width: 10%;text-align:right;" title="Tiger Paw Invitational (Clemson, S.C.)"><span class="mark-date" style="width: 10%;text-align:right;">2/9/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Holloway {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57790/3612066" target="_blank">7.43</a><a href="https://twitter.com/GatorsTF/status/1094035823551492096" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/8/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Holloway {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57790/3612066" target="_blank">7.43</a><a href="https://twitter.com/GatorsTF/status/1094035823551492096" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/8/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Holloway {4}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/60240/3664856" target="_blank">7.44</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/8/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Holloway {4}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/60240/3664856" target="_blank">7.44</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/8/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Holloway {5}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/59788/3638214" target="_blank">7.44</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/23/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Holloway {5}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/59788/3638214" target="_blank">7.44</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/23/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4673631" target="_blank">(4) Omar MCLEOD</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/39148/2390381" target="_blank">7.45</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/14/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4673631" target="_blank">(4) Omar MCLEOD</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/39148/2390381" target="_blank">7.45</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/14/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Cunningham {6}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72336" target="_blank">7.46</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="Texas Tech Open &amp; Multis (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">1/28/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Cunningham {6}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72336" target="_blank">7.46</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="Texas Tech Open &amp; Multis (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">1/28/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Cunningham {7}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72336/4352451" target="_blank">7.46</a> </td><td style="width: 10%;text-align:right;" title="Texas Tech Open &amp; Multis (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">1/28/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Cunningham {7}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72336/4352451" target="_blank">7.46</a> </td><td style="width: 10%;text-align:right;" title="Texas Tech Open &amp; Multis (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">1/28/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Cunningham {8}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72495/4363158" target="_blank">7.47</a> </td><td style="width: 10%;text-align:right;" title="New Balance Indoor Grand Prix (Boston, Mass.)"><span class="mark-date" style="width: 10%;text-align:right;">2/6/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Cunningham {8}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72495/4363158" target="_blank">7.47</a> </td><td style="width: 10%;text-align:right;" title="New Balance Indoor Grand Prix (Boston, Mass.)"><span class="mark-date" style="width: 10%;text-align:right;">2/6/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Holloway {6}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335580" target="_blank">7.47</a><a href="https://www.youtube.com/watch?v=BV0ZePQT13Y" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Holloway {6}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335580" target="_blank">7.47</a><a href="https://www.youtube.com/watch?v=BV0ZePQT13Y" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(5) Reggie TORIAN</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Wisconsin" class="group-logo-inline" src="/images/logos/rankings-article/wisconsin.png" title="Wisconsin"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=1812">Wisconsin</a></td><td style="width: 25%;">7.47  </td><td style="width: 10%;text-align:right;" title="Cannon IV Classic (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">2/7/1997</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(5) Reggie TORIAN</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Wisconsin" class="group-logo-inline" src="/images/logos/rankings-article/wisconsin.png" title="Wisconsin"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=1812">Wisconsin</a></td><td style="width: 25%;">7.47  </td><td style="width: 10%;text-align:right;" title="Cannon IV Classic (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">2/7/1997</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Roberts {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/59788/3638214" target="_blank">7.48</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/23/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Roberts {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/59788/3638214" target="_blank">7.48</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/23/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Holloway {7}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/59788/3638214" target="_blank">7.48</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/22/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Holloway {7}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/59788/3638214" target="_blank">7.48</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/22/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Cunningham {9}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72336" target="_blank">7.49</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="Texas Tech Open &amp; Multis (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">1/28/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Cunningham {9}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72336" target="_blank">7.49</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="Texas Tech Open &amp; Multis (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">1/28/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Cunningham {10}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72336/4352451" target="_blank">7.49</a> </td><td style="width: 10%;text-align:right;" title="Texas Tech Open &amp; Multis (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">1/28/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Cunningham {10}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72336/4352451" target="_blank">7.49</a> </td><td style="width: 10%;text-align:right;" title="Texas Tech Open &amp; Multis (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">1/28/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Holloway {8}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57717/3580925" target="_blank">7.49</a> </td><td style="width: 10%;text-align:right;" title="Clemson Invitational (Clemson, S.C.)"><span class="mark-date" style="width: 10%;text-align:right;">1/18/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Holloway {8}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57717/3580925" target="_blank">7.49</a> </td><td style="width: 10%;text-align:right;" title="Clemson Invitational (Clemson, S.C.)"><span class="mark-date" style="width: 10%;text-align:right;">1/18/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Holloway {9}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57717/3580925" target="_blank">7.49</a><a href="https://twitter.com/GatorsTF/status/1086367746819010560" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="Clemson Invitational (Clemson, S.C.)"><span class="mark-date" style="width: 10%;text-align:right;">1/18/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Holloway {9}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57717/3580925" target="_blank">7.49</a><a href="https://twitter.com/GatorsTF/status/1086367746819010560" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="Clemson Invitational (Clemson, S.C.)"><span class="mark-date" style="width: 10%;text-align:right;">1/18/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Holloway {10}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/52308/3257919" target="_blank">7.49</a> </td><td style="width: 10%;text-align:right;" title="Clemson Invitational (Clemson, S.C.)"><span class="mark-date" style="width: 10%;text-align:right;">1/19/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Holloway {10}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/52308/3257919" target="_blank">7.49</a> </td><td style="width: 10%;text-align:right;" title="Clemson Invitational (Clemson, S.C.)"><span class="mark-date" style="width: 10%;text-align:right;">1/19/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — McLeod {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/36571" target="_blank">7.49</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">2/28/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — McLeod {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/36571" target="_blank">7.49</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">2/28/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2252670" target="_blank">(6) Jarret EATON</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Syracuse" class="group-logo-inline" src="/images/logos/rankings-article/syracuse.png" title="Syracuse"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=1542">Syracuse</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/22603" target="_blank">7.49</a> </td><td style="width: 10%;text-align:right;" title="Penn State National (State College, Pa.)"><span class="mark-date" style="width: 10%;text-align:right;">1/27/2012</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2252670" target="_blank">(6) Jarret EATON</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Syracuse" class="group-logo-inline" src="/images/logos/rankings-article/syracuse.png" title="Syracuse"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=1542">Syracuse</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/22603" target="_blank">7.49</a> </td><td style="width: 10%;text-align:right;" title="Penn State National (State College, Pa.)"><span class="mark-date" style="width: 10%;text-align:right;">1/27/2012</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Torian {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Wisconsin" class="group-logo-inline" src="/images/logos/rankings-article/wisconsin.png" title="Wisconsin"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=1812">Wisconsin</a></td><td style="width: 25%;">7.49  </td><td style="width: 10%;text-align:right;" title="USATF Indoor Championships (Atlanta, Ga.)"><span class="mark-date" style="width: 10%;text-align:right;">2/28/1997</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
# ...
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2257022" target="_blank">(22) Devon HILL</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Miami (Fla.)" class="group-logo-inline" src="/images/logos/rankings-article/miami-fla.png" title="Miami (Fla.)"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=947">Miami (Fla.)</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/24457" target="_blank">7.55</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Nampa, Idaho)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2012</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2257465" target="_blank">(22) Barrett NUGENT</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/24457" target="_blank">7.55</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Nampa, Idaho)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2012</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2257465" target="_blank">(22) Barrett NUGENT</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/24457" target="_blank">7.55</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Nampa, Idaho)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2012</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Riley {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Illinois" class="group-logo-inline" src="/images/logos/rankings-article/illinois.png" title="Illinois"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=690">Illinois</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/24457" target="_blank">7.55</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Nampa, Idaho)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2012</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Riley {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Illinois" class="group-logo-inline" src="/images/logos/rankings-article/illinois.png" title="Illinois"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=690">Illinois</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/24457" target="_blank">7.55</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Nampa, Idaho)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2012</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(22) Ronnie ASH</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oklahoma" class="group-logo-inline" src="/images/logos/rankings-article/oklahoma.png" title="Oklahoma"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=1165">Oklahoma</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/15673" target="_blank">7.55</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2010</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(22) Ronnie ASH</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oklahoma" class="group-logo-inline" src="/images/logos/rankings-article/oklahoma.png" title="Oklahoma"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=1165">Oklahoma</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/15673" target="_blank">7.55</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2010</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(22) Jabari GREER</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=1553">Tennessee</a></td><td style="width: 25%;">7.55  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/15/2003</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(22) Jabari GREER</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=1553">Tennessee</a></td><td style="width: 25%;">7.55  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/15/2003</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Bramlett {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=12">Alabama</a></td><td style="width: 25%;">7.55 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/8/2002</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Bramlett {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=12">Alabama</a></td><td style="width: 25%;">7.55 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/8/2002</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Bramlett {3}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=12">Alabama</a></td><td style="width: 25%;">7.55  </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/24/2002</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Bramlett {3}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=12">Alabama</a></td><td style="width: 25%;">7.55  </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/24/2002</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Bramlett {4}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=12">Alabama</a></td><td style="width: 25%;">7.55  </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2001</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Bramlett {4}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=12">Alabama</a></td><td style="width: 25%;">7.55  </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2001</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Trammell {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="South Carolina" class="group-logo-inline" src="/images/logos/rankings-article/south-carolina.png" title="South Carolina"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=1411">South Carolina</a></td><td style="width: 25%;">7.55  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2000</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Trammell {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="South Carolina" class="group-logo-inline" src="/images/logos/rankings-article/south-carolina.png" title="South Carolina"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;div=20527&amp;top=25&amp;event=13&amp;team=1411">South Carolina</a></td><td style="width: 25%;">7.55  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2000</span></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows3 = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows3.append(row_data)

# %%
rows3
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Grant HOLLOWAYJRFlorida7.35📺 3/9/2019',
#   '(1) Grant HOLLOWAYJR',
#   '',
#   'Florida',
#   '7.35📺 ',
#   '3/9/2019'],
#  [],
#  ['(1) Grant HOLLOWAYJR', '', 'Florida', '7.35📺 ', '3/9/2019'],
#  ['(2) Trey CUNNINGHAMSRFlorida State7.38 3/12/2022',
#   '(2) Trey CUNNINGHAMSR',
#   '',
#   'Florida State',
#   '7.38 ',
#   '3/12/2022'],
#  [],
#  ['(2) Trey CUNNINGHAMSR', '', 'Florida State', '7.38 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {2}SRFlorida State7.40 qq = Performance occurred during a non-final round. 2/25/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {2}SR',
#   '',
#   'Florida State',
#   '7.40 qq = Performance occurred during a non-final round. ',
#   '2/25/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {2}SR',
#   '',
#   'Florida State',
#   '7.40 qq = Performance occurred during a non-final round. ',
#   '2/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {3}SRFlorida State7.40 2/24/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {3}SR',
#   '',
#   'Florida State',
#   '7.40 ',
#   '2/24/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {3}SR',
#   '',
#   'Florida State',
#   '7.40 ',
#   '2/24/2022'],
#  ['(3) Daniel ROBERTSJRKentucky7.41 3/9/2019',
#   '(3) Daniel ROBERTSJR',
#   '',
#   'Kentucky',
#   '7.41 ',
#   '3/9/2019'],
#  [],
#  ['(3) Daniel ROBERTSJR', '', 'Kentucky', '7.41 ', '3/9/2019'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {4}SRFlorida State7.42 2/24/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {4}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/24/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {4}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/24/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {5}SRFlorida State7.42 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {5}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {5}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {2}SOFlorida7.42 2/9/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {2}SO',
#   '',
#   'Florida',
#   '7.42 ',
#   '2/9/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {2}SO', '', 'Florida', '7.42 ', '2/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Holloway {3}JRFlorida7.43📺 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {3}JR',
#   '',
#   'Florida',
#   '7.43📺 ',
#   '2/8/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {3}JR', '', 'Florida', '7.43📺 ', '2/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {4}JRFlorida7.44 qq = Performance occurred during a non-final round. 3/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {4}JR',
#   '',
#   'Florida',
#   '7.44 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {4}JR',
#   '',
#   'Florida',
#   '7.44 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {5}JRFlorida7.44 2/23/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {5}JR',
#   '',
#   'Florida',
#   '7.44 ',
#   '2/23/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {5}JR', '', 'Florida', '7.44 ', '2/23/2019'],
#  ['(4) Omar MCLEODSOArkansas7.45 3/14/2015',
#   '(4) Omar MCLEODSO',
#   '',
#   'Arkansas',
#   '7.45 ',
#   '3/14/2015'],
#  [],
#  ['(4) Omar MCLEODSO', '', 'Arkansas', '7.45 ', '3/14/2015'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {6}SRFlorida State7.46 qq = Performance occurred during a non-final round. 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {6}SR',
#   '',
#   'Florida State',
#   '7.46 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {6}SR',
#   '',
#   'Florida State',
#   '7.46 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {7}SRFlorida State7.46 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {7}SR',
#   '',
#   'Florida State',
#   '7.46 ',
#   '1/28/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {7}SR',
#   '',
#   'Florida State',
#   '7.46 ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {8}SRFlorida State7.47 2/6/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {8}SR',
#   '',
#   'Florida State',
#   '7.47 ',
#   '2/6/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {8}SR',
#   '',
#   'Florida State',
#   '7.47 ',
#   '2/6/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {6}SOFlorida7.47📺 3/10/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {6}SO',
#   '',
#   'Florida',
#   '7.47📺 ',
#   '3/10/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {6}SO', '', 'Florida', '7.47📺 ', '3/10/2018'],
#  ['(5) Reggie TORIANWisconsin7.47  2/7/1997',
#   '(5) Reggie TORIAN',
#   '',
#   'Wisconsin',
#   '7.47  ',
#   '2/7/1997'],
#  [],
#  ['(5) Reggie TORIAN', '', 'Wisconsin', '7.47  ', '2/7/1997'],
#  ['\xa0\xa0\xa0\xa0— Roberts {2}JRKentucky7.48 2/23/2019',
#   '\xa0\xa0\xa0\xa0— Roberts {2}JR',
#   '',
#   'Kentucky',
#   '7.48 ',
#   '2/23/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Roberts {2}JR', '', 'Kentucky', '7.48 ', '2/23/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {7}JRFlorida7.48 qq = Performance occurred during a non-final round. 2/22/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {7}JR',
#   '',
#   'Florida',
#   '7.48 qq = Performance occurred during a non-final round. ',
#   '2/22/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {7}JR',
#   '',
#   'Florida',
#   '7.48 qq = Performance occurred during a non-final round. ',
#   '2/22/2019'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {9}SRFlorida State7.49 qq = Performance occurred during a non-final round. 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {9}SR',
#   '',
#   'Florida State',
#   '7.49 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {9}SR',
#   '',
#   'Florida State',
#   '7.49 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {10}SRFlorida State7.49 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {10}SR',
#   '',
#   'Florida State',
#   '7.49 ',
#   '1/28/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {10}SR',
#   '',
#   'Florida State',
#   '7.49 ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {8}JRFlorida7.49 1/18/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {8}JR',
#   '',
#   'Florida',
#   '7.49 ',
#   '1/18/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {8}JR', '', 'Florida', '7.49 ', '1/18/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {9}JRFlorida7.49📺 qq = Performance occurred during a non-final round. 1/18/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {9}JR',
#   '',
#   'Florida',
#   '7.49📺 qq = Performance occurred during a non-final round. ',
#   '1/18/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {9}JR',
#   '',
#   'Florida',
#   '7.49📺 qq = Performance occurred during a non-final round. ',
#   '1/18/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {10}SOFlorida7.49 1/19/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {10}SO',
#   '',
#   'Florida',
#   '7.49 ',
#   '1/19/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {10}SO', '', 'Florida', '7.49 ', '1/19/2018'],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}SOArkansas7.49 2/28/2015',
#   '\xa0\xa0\xa0\xa0— McLeod {2}SO',
#   '',
#   'Arkansas',
#   '7.49 ',
#   '2/28/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}SO', '', 'Arkansas', '7.49 ', '2/28/2015'],
#  ['(6) Jarret EATONSyracuse7.49 1/27/2012',
#   '(6) Jarret EATON',
#   '',
#   'Syracuse',
#   '7.49 ',
#   '1/27/2012'],
#  [],
#  ['(6) Jarret EATON', '', 'Syracuse', '7.49 ', '1/27/2012'],
#  ['\xa0\xa0\xa0\xa0— Torian {2}Wisconsin7.49  2/28/1997',
#   '\xa0\xa0\xa0\xa0— Torian {2}',
#   '',
#   'Wisconsin',
#   '7.49  ',
#   '2/28/1997'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Torian {2}', '', 'Wisconsin', '7.49  ', '2/28/1997'],
#  ['(7) Cordell TINCHJRPittsburg State7.50 2/10/2023',
#   '(7) Cordell TINCHJR',
#   '',
#   'Pittsburg State',
#   '7.50 ',
#   '2/10/2023'],
#  [],
#  ['(7) Cordell TINCHJR', '', 'Pittsburg State', '7.50 ', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {11}SRFlorida State7.50 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {11}SR',
#   '',
#   'Florida State',
#   '7.50 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {11}SR',
#   '',
#   'Florida State',
#   '7.50 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(7) Eddie LOVETTJRFlorida7.50 3/9/2013',
#   '(7) Eddie LOVETTJR',
#   '',
#   'Florida',
#   '7.50 ',
#   '3/9/2013'],
#  [],
#  ['(7) Eddie LOVETTJR', '', 'Florida', '7.50 ', '3/9/2013'],
#  ['\xa0\xa0\xa0\xa0— Tinch {2}JRPittsburg State7.51 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Tinch {2}JR',
#   '',
#   'Pittsburg State',
#   '7.51 ',
#   '3/11/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Tinch {2}JR',
#   '',
#   'Pittsburg State',
#   '7.51 ',
#   '3/11/2023'],
#  ['(9) Damion THOMASSRLSU7.51 3/13/2021',
#   '(9) Damion THOMASSR',
#   '',
#   'LSU',
#   '7.51 ',
#   '3/13/2021'],
#  [],
#  ['(9) Damion THOMASSR', '', 'LSU', '7.51 ', '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {12}JRFlorida State7.51 2/14/2020',
#   '\xa0\xa0\xa0\xa0— Cunningham {12}JR',
#   '',
#   'Florida State',
#   '7.51 ',
#   '2/14/2020'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {12}JR',
#   '',
#   'Florida State',
#   '7.51 ',
#   '2/14/2020'],
#  ['(9) Aries MERRITTJRTennessee7.51  3/10/2006',
#   '(9) Aries MERRITTJR',
#   '',
#   'Tennessee',
#   '7.51  ',
#   '3/10/2006'],
#  [],
#  ['(9) Aries MERRITTJR', '', 'Tennessee', '7.51  ', '3/10/2006'],
#  ['\xa0\xa0\xa0\xa0— Tinch {3}JRPittsburg State7.52 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Tinch {3}JR',
#   '',
#   'Pittsburg State',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Tinch {3}JR',
#   '',
#   'Pittsburg State',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(11) Caleb DEANJRTexas Tech7.52 2/24/2023',
#   '(11) Caleb DEANJR',
#   '',
#   'Texas Tech',
#   '7.52 ',
#   '2/24/2023'],
#  [],
#  ['(11) Caleb DEANJR', '', 'Texas Tech', '7.52 ', '2/24/2023'],
#  ['(11) Jamal  BRITTJRIowa7.52 3/13/2021',
#   '(11) Jamal  BRITTJR',
#   '',
#   'Iowa',
#   '7.52 ',
#   '3/13/2021'],
#  [],
#  ['(11) Jamal  BRITTJR', '', 'Iowa', '7.52 ', '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {13}JRFlorida State7.52 1/31/2020',
#   '\xa0\xa0\xa0\xa0— Cunningham {13}JR',
#   '',
#   'Florida State',
#   '7.52 ',
#   '1/31/2020'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {13}JR',
#   '',
#   'Florida State',
#   '7.52 ',
#   '1/31/2020'],
#  ['\xa0\xa0\xa0\xa0— Roberts {3}JRKentucky7.52 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Roberts {3}JR',
#   '',
#   'Kentucky',
#   '7.52 ',
#   '2/8/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Roberts {3}JR', '', 'Kentucky', '7.52 ', '2/8/2019'],
#  ['(11) Ron BRAMLETTAlabama7.52 qq = Performance occurred during a non-final round. 2/23/2002',
#   '(11) Ron BRAMLETT',
#   '',
#   'Alabama',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '2/23/2002'],
#  [],
#  ['(11) Ron BRAMLETT',
#   '',
#   'Alabama',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '2/23/2002'],
#  ['(11) Terrence TRAMMELLSOSouth Carolina7.52  3/5/1999',
#   '(11) Terrence TRAMMELLSO',
#   '',
#   'South Carolina',
#   '7.52  ',
#   '3/5/1999'],
#  [],
#  ['(11) Terrence TRAMMELLSO', '', 'South Carolina', '7.52  ', '3/5/1999'],
#  ['(15) Omotade OJORASRSouthern California7.53 2/10/2023',
#   '(15) Omotade OJORASR',
#   '',
#   'Southern California',
#   '7.53 ',
#   '2/10/2023'],
#  [],
#  ['(15) Omotade OJORASR', '', 'Southern California', '7.53 ', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {14}SRFlorida State7.53 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Cunningham {14}SR',
#   '',
#   'Florida State',
#   '7.53 ',
#   '3/13/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {14}SR',
#   '',
#   'Florida State',
#   '7.53 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {15}SOFlorida State7.53 1/24/2019',
#   '\xa0\xa0\xa0\xa0— Cunningham {15}SO',
#   '',
#   'Florida State',
#   '7.53 ',
#   '1/24/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {15}SO',
#   '',
#   'Florida State',
#   '7.53 ',
#   '1/24/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {11}SOFlorida7.53 2/25/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {11}SO',
#   '',
#   'Florida',
#   '7.53 ',
#   '2/25/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {11}SO', '', 'Florida', '7.53 ', '2/25/2018'],
#  ['(15) Myles HUNTERMinnesota State7.53 3/12/2016',
#   '(15) Myles HUNTER',
#   '',
#   'Minnesota State',
#   '7.53 ',
#   '3/12/2016'],
#  [],
#  ['(15) Myles HUNTER', '', 'Minnesota State', '7.53 ', '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Lovett {2}JRFlorida7.53 qq = Performance occurred during a non-final round. 3/8/2013',
#   '\xa0\xa0\xa0\xa0— Lovett {2}JR',
#   '',
#   'Florida',
#   '7.53 qq = Performance occurred during a non-final round. ',
#   '3/8/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lovett {2}JR',
#   '',
#   'Florida',
#   '7.53 qq = Performance occurred during a non-final round. ',
#   '3/8/2013'],
#  ['(15) Andrew RILEYIllinois7.53 2/11/2012',
#   '(15) Andrew RILEY',
#   '',
#   'Illinois',
#   '7.53 ',
#   '2/11/2012'],
#  [],
#  ['(15) Andrew RILEY', '', 'Illinois', '7.53 ', '2/11/2012'],
#  ['(15) Drew BRUNSONSRFlorida State7.53  3/14/2008\xa0\xa0\xa0\xa0\xa0(7.527)',
#   '(15) Drew BRUNSONSR',
#   '',
#   'Florida State',
#   '7.53  ',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa0(7.527)'],
#  [],
#  ['(15) Drew BRUNSONSR', '', 'Florida State', '7.53  ', '3/14/2008'],
#  ['\xa0\xa0\xa0\xa0\xa0(7.527)'],
#  ['(15) Jason RICHARDSONJRSouth Carolina7.53  3/14/2008\xa0\xa0\xa0\xa0\xa0(7.530)',
#   '(15) Jason RICHARDSONJR',
#   '',
#   'South Carolina',
#   '7.53  ',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa0(7.530)'],
#  [],
#  ['(15) Jason RICHARDSONJR', '', 'South Carolina', '7.53  ', '3/14/2008'],
#  ['\xa0\xa0\xa0\xa0\xa0(7.530)'],
#  ['\xa0\xa0\xa0\xa0— Trammell {2}South Carolina7.53  2/13/1999',
#   '\xa0\xa0\xa0\xa0— Trammell {2}',
#   '',
#   'South Carolina',
#   '7.53  ',
#   '2/13/1999'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Trammell {2}',
#   '',
#   'South Carolina',
#   '7.53  ',
#   '2/13/1999'],
#  ['(20) Darius LUFFJRNebraska7.54 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(20) Darius LUFFJR',
#   '',
#   'Nebraska',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['(20) Darius LUFFJR',
#   '',
#   'Nebraska',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {16}SRFlorida State7.54 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {16}SR',
#   '',
#   'Florida State',
#   '7.54 ',
#   '2/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {16}SR',
#   '',
#   'Florida State',
#   '7.54 ',
#   '2/11/2022'],
#  ['(20) Phillip LEMONIOUSSOArkansas7.54 3/13/2021',
#   '(20) Phillip LEMONIOUSSO',
#   '',
#   'Arkansas',
#   '7.54 ',
#   '3/13/2021'],
#  [],
#  ['(20) Phillip LEMONIOUSSO', '', 'Arkansas', '7.54 ', '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Lovett {3}Florida7.54 2/24/2013',
#   '\xa0\xa0\xa0\xa0— Lovett {3}',
#   '',
#   'Florida',
#   '7.54 ',
#   '2/24/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lovett {3}', '', 'Florida', '7.54 ', '2/24/2013'],
#  ['\xa0\xa0\xa0\xa0— Eaton {2}SRSyracuse7.54 3/10/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {2}SR',
#   '',
#   'Syracuse',
#   '7.54 ',
#   '3/10/2012'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Eaton {2}SR', '', 'Syracuse', '7.54 ', '3/10/2012'],
#  ['\xa0\xa0\xa0\xa0— Eaton {3}Syracuse7.54 2/3/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {3}',
#   '',
#   'Syracuse',
#   '7.54 ',
#   '2/3/2012'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Eaton {3}', '', 'Syracuse', '7.54 ', '2/3/2012'],
#  ['\xa0\xa0\xa0\xa0— Eaton {4}Syracuse7.54 qq = Performance occurred during a non-final round. 1/27/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {4}',
#   '',
#   'Syracuse',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '1/27/2012'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Eaton {4}',
#   '',
#   'Syracuse',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '1/27/2012'],
#  ['(22) Giano ROBERTSSRClemson7.55📺 3/11/2023',
#   '(22) Giano ROBERTSSR',
#   '',
#   'Clemson',
#   '7.55📺 ',
#   '3/11/2023'],
#  [],
#  ['(22) Giano ROBERTSSR', '', 'Clemson', '7.55📺 ', '3/11/2023'],
#  ['(22) Leonard MUSTARIFRNorth Carolina A&T7.55 2/11/2022',
#   '(22) Leonard MUSTARIFR',
#   '',
#   'North Carolina A&T',
#   '7.55 ',
#   '2/11/2022'],
#  [],
#  ['(22) Leonard MUSTARIFR', '', 'North Carolina A&T', '7.55 ', '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {17}SRFlorida State7.55 2/12/2021',
#   '\xa0\xa0\xa0\xa0— Cunningham {17}SR',
#   '',
#   'Florida State',
#   '7.55 ',
#   '2/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {17}SR',
#   '',
#   'Florida State',
#   '7.55 ',
#   '2/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {18}SOFlorida State7.55 qq = Performance occurred during a non-final round. 3/8/2019',
#   '\xa0\xa0\xa0\xa0— Cunningham {18}SO',
#   '',
#   'Florida State',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {18}SO',
#   '',
#   'Florida State',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {12}JRFlorida7.55 qq = Performance occurred during a non-final round. 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {12}JR',
#   '',
#   'Florida',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '2/8/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {12}JR',
#   '',
#   'Florida',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '2/8/2019'],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}Arkansas7.55 qq = Performance occurred during a non-final round. 3/13/2015',
#   '\xa0\xa0\xa0\xa0— McLeod {3}',
#   '',
#   'Arkansas',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/13/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}',
#   '',
#   'Arkansas',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/13/2015'],
#  ['(22) Devon HILLMiami (Fla.)7.55 3/10/2012',
#   '(22) Devon HILL',
#   '',
#   'Miami (Fla.)',
#   '7.55 ',
#   '3/10/2012'],
#  [],
#  ['(22) Devon HILL', '', 'Miami (Fla.)', '7.55 ', '3/10/2012'],
#  ['(22) Barrett NUGENTLSU7.55 3/10/2012',
#   '(22) Barrett NUGENT',
#   '',
#   'LSU',
#   '7.55 ',
#   '3/10/2012'],
#  [],
#  ['(22) Barrett NUGENT', '', 'LSU', '7.55 ', '3/10/2012'],
#  ['\xa0\xa0\xa0\xa0— Riley {2}Illinois7.55 qq = Performance occurred during a non-final round. 3/9/2012',
#   '\xa0\xa0\xa0\xa0— Riley {2}',
#   '',
#   'Illinois',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/9/2012'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Riley {2}',
#   '',
#   'Illinois',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/9/2012'],
#  ['(22) Ronnie ASHJROklahoma7.55 qq = Performance occurred during a non-final round. 3/12/2010',
#   '(22) Ronnie ASHJR',
#   '',
#   'Oklahoma',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/12/2010'],
#  [],
#  ['(22) Ronnie ASHJR',
#   '',
#   'Oklahoma',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/12/2010'],
#  ['(22) Jabari GREERSOTennessee7.55  3/15/2003',
#   '(22) Jabari GREERSO',
#   '',
#   'Tennessee',
#   '7.55  ',
#   '3/15/2003'],
#  [],
#  ['(22) Jabari GREERSO', '', 'Tennessee', '7.55  ', '3/15/2003'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {2}SRAlabama7.55 qq = Performance occurred during a non-final round. 3/8/2002',
#   '\xa0\xa0\xa0\xa0— Bramlett {2}SR',
#   '',
#   'Alabama',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2002'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Bramlett {2}SR',
#   '',
#   'Alabama',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2002'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {3}Alabama7.55  2/24/2002',
#   '\xa0\xa0\xa0\xa0— Bramlett {3}',
#   '',
#   'Alabama',
#   '7.55  ',
#   '2/24/2002'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Bramlett {3}', '', 'Alabama', '7.55  ', '2/24/2002'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {4}Alabama7.55  2/25/2001',
#   '\xa0\xa0\xa0\xa0— Bramlett {4}',
#   '',
#   'Alabama',
#   '7.55  ',
#   '2/25/2001'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Bramlett {4}', '', 'Alabama', '7.55  ', '2/25/2001'],
#  ['\xa0\xa0\xa0\xa0— Trammell {3}JRSouth Carolina7.55  3/10/2000',
#   '\xa0\xa0\xa0\xa0— Trammell {3}JR',
#   '',
#   'South Carolina',
#   '7.55  ',
#   '3/10/2000'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Trammell {3}JR',
#   '',
#   'South Carolina',
#   '7.55  ',
#   '3/10/2000'],
#  ['', '', '', '']]

# %%
RealRows3 = []

# %%
len(rows3)
# Out:
# 224

# %%
for i in range(0,224):
        RealRows3.append(rows3[i])

# %%
RealRows3
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Grant HOLLOWAYJRFlorida7.35📺 3/9/2019',
#   '(1) Grant HOLLOWAYJR',
#   '',
#   'Florida',
#   '7.35📺 ',
#   '3/9/2019'],
#  [],
#  ['(1) Grant HOLLOWAYJR', '', 'Florida', '7.35📺 ', '3/9/2019'],
#  ['(2) Trey CUNNINGHAMSRFlorida State7.38 3/12/2022',
#   '(2) Trey CUNNINGHAMSR',
#   '',
#   'Florida State',
#   '7.38 ',
#   '3/12/2022'],
#  [],
#  ['(2) Trey CUNNINGHAMSR', '', 'Florida State', '7.38 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {2}SRFlorida State7.40 qq = Performance occurred during a non-final round. 2/25/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {2}SR',
#   '',
#   'Florida State',
#   '7.40 qq = Performance occurred during a non-final round. ',
#   '2/25/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {2}SR',
#   '',
#   'Florida State',
#   '7.40 qq = Performance occurred during a non-final round. ',
#   '2/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {3}SRFlorida State7.40 2/24/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {3}SR',
#   '',
#   'Florida State',
#   '7.40 ',
#   '2/24/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {3}SR',
#   '',
#   'Florida State',
#   '7.40 ',
#   '2/24/2022'],
#  ['(3) Daniel ROBERTSJRKentucky7.41 3/9/2019',
#   '(3) Daniel ROBERTSJR',
#   '',
#   'Kentucky',
#   '7.41 ',
#   '3/9/2019'],
#  [],
#  ['(3) Daniel ROBERTSJR', '', 'Kentucky', '7.41 ', '3/9/2019'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {4}SRFlorida State7.42 2/24/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {4}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/24/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {4}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/24/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {5}SRFlorida State7.42 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {5}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {5}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {2}SOFlorida7.42 2/9/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {2}SO',
#   '',
#   'Florida',
#   '7.42 ',
#   '2/9/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {2}SO', '', 'Florida', '7.42 ', '2/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Holloway {3}JRFlorida7.43📺 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {3}JR',
#   '',
#   'Florida',
#   '7.43📺 ',
#   '2/8/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {3}JR', '', 'Florida', '7.43📺 ', '2/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {4}JRFlorida7.44 qq = Performance occurred during a non-final round. 3/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {4}JR',
#   '',
#   'Florida',
#   '7.44 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {4}JR',
#   '',
#   'Florida',
#   '7.44 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {5}JRFlorida7.44 2/23/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {5}JR',
#   '',
#   'Florida',
#   '7.44 ',
#   '2/23/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {5}JR', '', 'Florida', '7.44 ', '2/23/2019'],
#  ['(4) Omar MCLEODSOArkansas7.45 3/14/2015',
#   '(4) Omar MCLEODSO',
#   '',
#   'Arkansas',
#   '7.45 ',
#   '3/14/2015'],
#  [],
#  ['(4) Omar MCLEODSO', '', 'Arkansas', '7.45 ', '3/14/2015'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {6}SRFlorida State7.46 qq = Performance occurred during a non-final round. 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {6}SR',
#   '',
#   'Florida State',
#   '7.46 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {6}SR',
#   '',
#   'Florida State',
#   '7.46 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {7}SRFlorida State7.46 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {7}SR',
#   '',
#   'Florida State',
#   '7.46 ',
#   '1/28/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {7}SR',
#   '',
#   'Florida State',
#   '7.46 ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {8}SRFlorida State7.47 2/6/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {8}SR',
#   '',
#   'Florida State',
#   '7.47 ',
#   '2/6/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {8}SR',
#   '',
#   'Florida State',
#   '7.47 ',
#   '2/6/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {6}SOFlorida7.47📺 3/10/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {6}SO',
#   '',
#   'Florida',
#   '7.47📺 ',
#   '3/10/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {6}SO', '', 'Florida', '7.47📺 ', '3/10/2018'],
#  ['(5) Reggie TORIANWisconsin7.47  2/7/1997',
#   '(5) Reggie TORIAN',
#   '',
#   'Wisconsin',
#   '7.47  ',
#   '2/7/1997'],
#  [],
#  ['(5) Reggie TORIAN', '', 'Wisconsin', '7.47  ', '2/7/1997'],
#  ['\xa0\xa0\xa0\xa0— Roberts {2}JRKentucky7.48 2/23/2019',
#   '\xa0\xa0\xa0\xa0— Roberts {2}JR',
#   '',
#   'Kentucky',
#   '7.48 ',
#   '2/23/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Roberts {2}JR', '', 'Kentucky', '7.48 ', '2/23/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {7}JRFlorida7.48 qq = Performance occurred during a non-final round. 2/22/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {7}JR',
#   '',
#   'Florida',
#   '7.48 qq = Performance occurred during a non-final round. ',
#   '2/22/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {7}JR',
#   '',
#   'Florida',
#   '7.48 qq = Performance occurred during a non-final round. ',
#   '2/22/2019'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {9}SRFlorida State7.49 qq = Performance occurred during a non-final round. 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {9}SR',
#   '',
#   'Florida State',
#   '7.49 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {9}SR',
#   '',
#   'Florida State',
#   '7.49 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {10}SRFlorida State7.49 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {10}SR',
#   '',
#   'Florida State',
#   '7.49 ',
#   '1/28/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {10}SR',
#   '',
#   'Florida State',
#   '7.49 ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {8}JRFlorida7.49 1/18/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {8}JR',
#   '',
#   'Florida',
#   '7.49 ',
#   '1/18/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {8}JR', '', 'Florida', '7.49 ', '1/18/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {9}JRFlorida7.49📺 qq = Performance occurred during a non-final round. 1/18/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {9}JR',
#   '',
#   'Florida',
#   '7.49📺 qq = Performance occurred during a non-final round. ',
#   '1/18/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {9}JR',
#   '',
#   'Florida',
#   '7.49📺 qq = Performance occurred during a non-final round. ',
#   '1/18/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {10}SOFlorida7.49 1/19/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {10}SO',
#   '',
#   'Florida',
#   '7.49 ',
#   '1/19/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {10}SO', '', 'Florida', '7.49 ', '1/19/2018'],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}SOArkansas7.49 2/28/2015',
#   '\xa0\xa0\xa0\xa0— McLeod {2}SO',
#   '',
#   'Arkansas',
#   '7.49 ',
#   '2/28/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}SO', '', 'Arkansas', '7.49 ', '2/28/2015'],
#  ['(6) Jarret EATONSyracuse7.49 1/27/2012',
#   '(6) Jarret EATON',
#   '',
#   'Syracuse',
#   '7.49 ',
#   '1/27/2012'],
#  [],
#  ['(6) Jarret EATON', '', 'Syracuse', '7.49 ', '1/27/2012'],
#  ['\xa0\xa0\xa0\xa0— Torian {2}Wisconsin7.49  2/28/1997',
#   '\xa0\xa0\xa0\xa0— Torian {2}',
#   '',
#   'Wisconsin',
#   '7.49  ',
#   '2/28/1997'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Torian {2}', '', 'Wisconsin', '7.49  ', '2/28/1997'],
#  ['(7) Cordell TINCHJRPittsburg State7.50 2/10/2023',
#   '(7) Cordell TINCHJR',
#   '',
#   'Pittsburg State',
#   '7.50 ',
#   '2/10/2023'],
#  [],
#  ['(7) Cordell TINCHJR', '', 'Pittsburg State', '7.50 ', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {11}SRFlorida State7.50 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {11}SR',
#   '',
#   'Florida State',
#   '7.50 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {11}SR',
#   '',
#   'Florida State',
#   '7.50 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(7) Eddie LOVETTJRFlorida7.50 3/9/2013',
#   '(7) Eddie LOVETTJR',
#   '',
#   'Florida',
#   '7.50 ',
#   '3/9/2013'],
#  [],
#  ['(7) Eddie LOVETTJR', '', 'Florida', '7.50 ', '3/9/2013'],
#  ['\xa0\xa0\xa0\xa0— Tinch {2}JRPittsburg State7.51 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Tinch {2}JR',
#   '',
#   'Pittsburg State',
#   '7.51 ',
#   '3/11/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Tinch {2}JR',
#   '',
#   'Pittsburg State',
#   '7.51 ',
#   '3/11/2023'],
#  ['(9) Damion THOMASSRLSU7.51 3/13/2021',
#   '(9) Damion THOMASSR',
#   '',
#   'LSU',
#   '7.51 ',
#   '3/13/2021'],
#  [],
#  ['(9) Damion THOMASSR', '', 'LSU', '7.51 ', '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {12}JRFlorida State7.51 2/14/2020',
#   '\xa0\xa0\xa0\xa0— Cunningham {12}JR',
#   '',
#   'Florida State',
#   '7.51 ',
#   '2/14/2020'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {12}JR',
#   '',
#   'Florida State',
#   '7.51 ',
#   '2/14/2020'],
#  ['(9) Aries MERRITTJRTennessee7.51  3/10/2006',
#   '(9) Aries MERRITTJR',
#   '',
#   'Tennessee',
#   '7.51  ',
#   '3/10/2006'],
#  [],
#  ['(9) Aries MERRITTJR', '', 'Tennessee', '7.51  ', '3/10/2006'],
#  ['\xa0\xa0\xa0\xa0— Tinch {3}JRPittsburg State7.52 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Tinch {3}JR',
#   '',
#   'Pittsburg State',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Tinch {3}JR',
#   '',
#   'Pittsburg State',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(11) Caleb DEANJRTexas Tech7.52 2/24/2023',
#   '(11) Caleb DEANJR',
#   '',
#   'Texas Tech',
#   '7.52 ',
#   '2/24/2023'],
#  [],
#  ['(11) Caleb DEANJR', '', 'Texas Tech', '7.52 ', '2/24/2023'],
#  ['(11) Jamal  BRITTJRIowa7.52 3/13/2021',
#   '(11) Jamal  BRITTJR',
#   '',
#   'Iowa',
#   '7.52 ',
#   '3/13/2021'],
#  [],
#  ['(11) Jamal  BRITTJR', '', 'Iowa', '7.52 ', '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {13}JRFlorida State7.52 1/31/2020',
#   '\xa0\xa0\xa0\xa0— Cunningham {13}JR',
#   '',
#   'Florida State',
#   '7.52 ',
#   '1/31/2020'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {13}JR',
#   '',
#   'Florida State',
#   '7.52 ',
#   '1/31/2020'],
#  ['\xa0\xa0\xa0\xa0— Roberts {3}JRKentucky7.52 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Roberts {3}JR',
#   '',
#   'Kentucky',
#   '7.52 ',
#   '2/8/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Roberts {3}JR', '', 'Kentucky', '7.52 ', '2/8/2019'],
#  ['(11) Ron BRAMLETTAlabama7.52 qq = Performance occurred during a non-final round. 2/23/2002',
#   '(11) Ron BRAMLETT',
#   '',
#   'Alabama',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '2/23/2002'],
#  [],
#  ['(11) Ron BRAMLETT',
#   '',
#   'Alabama',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '2/23/2002'],
#  ['(11) Terrence TRAMMELLSOSouth Carolina7.52  3/5/1999',
#   '(11) Terrence TRAMMELLSO',
#   '',
#   'South Carolina',
#   '7.52  ',
#   '3/5/1999'],
#  [],
#  ['(11) Terrence TRAMMELLSO', '', 'South Carolina', '7.52  ', '3/5/1999'],
#  ['(15) Omotade OJORASRSouthern California7.53 2/10/2023',
#   '(15) Omotade OJORASR',
#   '',
#   'Southern California',
#   '7.53 ',
#   '2/10/2023'],
#  [],
#  ['(15) Omotade OJORASR', '', 'Southern California', '7.53 ', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {14}SRFlorida State7.53 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Cunningham {14}SR',
#   '',
#   'Florida State',
#   '7.53 ',
#   '3/13/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {14}SR',
#   '',
#   'Florida State',
#   '7.53 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {15}SOFlorida State7.53 1/24/2019',
#   '\xa0\xa0\xa0\xa0— Cunningham {15}SO',
#   '',
#   'Florida State',
#   '7.53 ',
#   '1/24/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {15}SO',
#   '',
#   'Florida State',
#   '7.53 ',
#   '1/24/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {11}SOFlorida7.53 2/25/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {11}SO',
#   '',
#   'Florida',
#   '7.53 ',
#   '2/25/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {11}SO', '', 'Florida', '7.53 ', '2/25/2018'],
#  ['(15) Myles HUNTERMinnesota State7.53 3/12/2016',
#   '(15) Myles HUNTER',
#   '',
#   'Minnesota State',
#   '7.53 ',
#   '3/12/2016'],
#  [],
#  ['(15) Myles HUNTER', '', 'Minnesota State', '7.53 ', '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Lovett {2}JRFlorida7.53 qq = Performance occurred during a non-final round. 3/8/2013',
#   '\xa0\xa0\xa0\xa0— Lovett {2}JR',
#   '',
#   'Florida',
#   '7.53 qq = Performance occurred during a non-final round. ',
#   '3/8/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lovett {2}JR',
#   '',
#   'Florida',
#   '7.53 qq = Performance occurred during a non-final round. ',
#   '3/8/2013'],
#  ['(15) Andrew RILEYIllinois7.53 2/11/2012',
#   '(15) Andrew RILEY',
#   '',
#   'Illinois',
#   '7.53 ',
#   '2/11/2012'],
#  [],
#  ['(15) Andrew RILEY', '', 'Illinois', '7.53 ', '2/11/2012'],
#  ['(15) Drew BRUNSONSRFlorida State7.53  3/14/2008\xa0\xa0\xa0\xa0\xa0(7.527)',
#   '(15) Drew BRUNSONSR',
#   '',
#   'Florida State',
#   '7.53  ',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa0(7.527)'],
#  [],
#  ['(15) Drew BRUNSONSR', '', 'Florida State', '7.53  ', '3/14/2008'],
#  ['\xa0\xa0\xa0\xa0\xa0(7.527)'],
#  ['(15) Jason RICHARDSONJRSouth Carolina7.53  3/14/2008\xa0\xa0\xa0\xa0\xa0(7.530)',
#   '(15) Jason RICHARDSONJR',
#   '',
#   'South Carolina',
#   '7.53  ',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa0(7.530)'],
#  [],
#  ['(15) Jason RICHARDSONJR', '', 'South Carolina', '7.53  ', '3/14/2008'],
#  ['\xa0\xa0\xa0\xa0\xa0(7.530)'],
#  ['\xa0\xa0\xa0\xa0— Trammell {2}South Carolina7.53  2/13/1999',
#   '\xa0\xa0\xa0\xa0— Trammell {2}',
#   '',
#   'South Carolina',
#   '7.53  ',
#   '2/13/1999'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Trammell {2}',
#   '',
#   'South Carolina',
#   '7.53  ',
#   '2/13/1999'],
#  ['(20) Darius LUFFJRNebraska7.54 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(20) Darius LUFFJR',
#   '',
#   'Nebraska',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['(20) Darius LUFFJR',
#   '',
#   'Nebraska',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {16}SRFlorida State7.54 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {16}SR',
#   '',
#   'Florida State',
#   '7.54 ',
#   '2/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {16}SR',
#   '',
#   'Florida State',
#   '7.54 ',
#   '2/11/2022'],
#  ['(20) Phillip LEMONIOUSSOArkansas7.54 3/13/2021',
#   '(20) Phillip LEMONIOUSSO',
#   '',
#   'Arkansas',
#   '7.54 ',
#   '3/13/2021'],
#  [],
#  ['(20) Phillip LEMONIOUSSO', '', 'Arkansas', '7.54 ', '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Lovett {3}Florida7.54 2/24/2013',
#   '\xa0\xa0\xa0\xa0— Lovett {3}',
#   '',
#   'Florida',
#   '7.54 ',
#   '2/24/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lovett {3}', '', 'Florida', '7.54 ', '2/24/2013'],
#  ['\xa0\xa0\xa0\xa0— Eaton {2}SRSyracuse7.54 3/10/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {2}SR',
#   '',
#   'Syracuse',
#   '7.54 ',
#   '3/10/2012'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Eaton {2}SR', '', 'Syracuse', '7.54 ', '3/10/2012'],
#  ['\xa0\xa0\xa0\xa0— Eaton {3}Syracuse7.54 2/3/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {3}',
#   '',
#   'Syracuse',
#   '7.54 ',
#   '2/3/2012'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Eaton {3}', '', 'Syracuse', '7.54 ', '2/3/2012'],
#  ['\xa0\xa0\xa0\xa0— Eaton {4}Syracuse7.54 qq = Performance occurred during a non-final round. 1/27/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {4}',
#   '',
#   'Syracuse',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '1/27/2012'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Eaton {4}',
#   '',
#   'Syracuse',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '1/27/2012'],
#  ['(22) Giano ROBERTSSRClemson7.55📺 3/11/2023',
#   '(22) Giano ROBERTSSR',
#   '',
#   'Clemson',
#   '7.55📺 ',
#   '3/11/2023'],
#  [],
#  ['(22) Giano ROBERTSSR', '', 'Clemson', '7.55📺 ', '3/11/2023'],
#  ['(22) Leonard MUSTARIFRNorth Carolina A&T7.55 2/11/2022',
#   '(22) Leonard MUSTARIFR',
#   '',
#   'North Carolina A&T',
#   '7.55 ',
#   '2/11/2022'],
#  [],
#  ['(22) Leonard MUSTARIFR', '', 'North Carolina A&T', '7.55 ', '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {17}SRFlorida State7.55 2/12/2021',
#   '\xa0\xa0\xa0\xa0— Cunningham {17}SR',
#   '',
#   'Florida State',
#   '7.55 ',
#   '2/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {17}SR',
#   '',
#   'Florida State',
#   '7.55 ',
#   '2/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {18}SOFlorida State7.55 qq = Performance occurred during a non-final round. 3/8/2019',
#   '\xa0\xa0\xa0\xa0— Cunningham {18}SO',
#   '',
#   'Florida State',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunningham {18}SO',
#   '',
#   'Florida State',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {12}JRFlorida7.55 qq = Performance occurred during a non-final round. 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {12}JR',
#   '',
#   'Florida',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '2/8/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Holloway {12}JR',
#   '',
#   'Florida',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '2/8/2019'],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}Arkansas7.55 qq = Performance occurred during a non-final round. 3/13/2015',
#   '\xa0\xa0\xa0\xa0— McLeod {3}',
#   '',
#   'Arkansas',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/13/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}',
#   '',
#   'Arkansas',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/13/2015'],
#  ['(22) Devon HILLMiami (Fla.)7.55 3/10/2012',
#   '(22) Devon HILL',
#   '',
#   'Miami (Fla.)',
#   '7.55 ',
#   '3/10/2012'],
#  [],
#  ['(22) Devon HILL', '', 'Miami (Fla.)', '7.55 ', '3/10/2012'],
#  ['(22) Barrett NUGENTLSU7.55 3/10/2012',
#   '(22) Barrett NUGENT',
#   '',
#   'LSU',
#   '7.55 ',
#   '3/10/2012'],
#  [],
#  ['(22) Barrett NUGENT', '', 'LSU', '7.55 ', '3/10/2012'],
#  ['\xa0\xa0\xa0\xa0— Riley {2}Illinois7.55 qq = Performance occurred during a non-final round. 3/9/2012',
#   '\xa0\xa0\xa0\xa0— Riley {2}',
#   '',
#   'Illinois',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/9/2012'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Riley {2}',
#   '',
#   'Illinois',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/9/2012'],
#  ['(22) Ronnie ASHJROklahoma7.55 qq = Performance occurred during a non-final round. 3/12/2010',
#   '(22) Ronnie ASHJR',
#   '',
#   'Oklahoma',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/12/2010'],
#  [],
#  ['(22) Ronnie ASHJR',
#   '',
#   'Oklahoma',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/12/2010'],
#  ['(22) Jabari GREERSOTennessee7.55  3/15/2003',
#   '(22) Jabari GREERSO',
#   '',
#   'Tennessee',
#   '7.55  ',
#   '3/15/2003'],
#  [],
#  ['(22) Jabari GREERSO', '', 'Tennessee', '7.55  ', '3/15/2003'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {2}SRAlabama7.55 qq = Performance occurred during a non-final round. 3/8/2002',
#   '\xa0\xa0\xa0\xa0— Bramlett {2}SR',
#   '',
#   'Alabama',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2002'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Bramlett {2}SR',
#   '',
#   'Alabama',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2002'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {3}Alabama7.55  2/24/2002',
#   '\xa0\xa0\xa0\xa0— Bramlett {3}',
#   '',
#   'Alabama',
#   '7.55  ',
#   '2/24/2002'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Bramlett {3}', '', 'Alabama', '7.55  ', '2/24/2002'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {4}Alabama7.55  2/25/2001',
#   '\xa0\xa0\xa0\xa0— Bramlett {4}',
#   '',
#   'Alabama',
#   '7.55  ',
#   '2/25/2001'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Bramlett {4}', '', 'Alabama', '7.55  ', '2/25/2001'],
#  ['\xa0\xa0\xa0\xa0— Trammell {3}JRSouth Carolina7.55  3/10/2000',
#   '\xa0\xa0\xa0\xa0— Trammell {3}JR',
#   '',
#   'South Carolina',
#   '7.55  ',
#   '3/10/2000'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Trammell {3}JR',
#   '',
#   'South Carolina',
#   '7.55  ',
#   '3/10/2000'],
#  ['', '', '', '']]

# %%
RealRows = []

# %%
for i in range(0,224):
    if len(RealRows3[i]) > 1:
        RealRows.append(RealRows3[i])

# %%
RealRows
# Out:
# [['(1) Grant HOLLOWAYJRFlorida7.35📺 3/9/2019',
#   '(1) Grant HOLLOWAYJR',
#   '',
#   'Florida',
#   '7.35📺 ',
#   '3/9/2019'],
#  ['(1) Grant HOLLOWAYJR', '', 'Florida', '7.35📺 ', '3/9/2019'],
#  ['(2) Trey CUNNINGHAMSRFlorida State7.38 3/12/2022',
#   '(2) Trey CUNNINGHAMSR',
#   '',
#   'Florida State',
#   '7.38 ',
#   '3/12/2022'],
#  ['(2) Trey CUNNINGHAMSR', '', 'Florida State', '7.38 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {2}SRFlorida State7.40 qq = Performance occurred during a non-final round. 2/25/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {2}SR',
#   '',
#   'Florida State',
#   '7.40 qq = Performance occurred during a non-final round. ',
#   '2/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {2}SR',
#   '',
#   'Florida State',
#   '7.40 qq = Performance occurred during a non-final round. ',
#   '2/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {3}SRFlorida State7.40 2/24/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {3}SR',
#   '',
#   'Florida State',
#   '7.40 ',
#   '2/24/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {3}SR',
#   '',
#   'Florida State',
#   '7.40 ',
#   '2/24/2022'],
#  ['(3) Daniel ROBERTSJRKentucky7.41 3/9/2019',
#   '(3) Daniel ROBERTSJR',
#   '',
#   'Kentucky',
#   '7.41 ',
#   '3/9/2019'],
#  ['(3) Daniel ROBERTSJR', '', 'Kentucky', '7.41 ', '3/9/2019'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {4}SRFlorida State7.42 2/24/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {4}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/24/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {4}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/24/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {5}SRFlorida State7.42 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {5}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {5}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {2}SOFlorida7.42 2/9/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {2}SO',
#   '',
#   'Florida',
#   '7.42 ',
#   '2/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Holloway {2}SO', '', 'Florida', '7.42 ', '2/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Holloway {3}JRFlorida7.43📺 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {3}JR',
#   '',
#   'Florida',
#   '7.43📺 ',
#   '2/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {3}JR', '', 'Florida', '7.43📺 ', '2/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {4}JRFlorida7.44 qq = Performance occurred during a non-final round. 3/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {4}JR',
#   '',
#   'Florida',
#   '7.44 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {4}JR',
#   '',
#   'Florida',
#   '7.44 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {5}JRFlorida7.44 2/23/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {5}JR',
#   '',
#   'Florida',
#   '7.44 ',
#   '2/23/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {5}JR', '', 'Florida', '7.44 ', '2/23/2019'],
#  ['(4) Omar MCLEODSOArkansas7.45 3/14/2015',
#   '(4) Omar MCLEODSO',
#   '',
#   'Arkansas',
#   '7.45 ',
#   '3/14/2015'],
#  ['(4) Omar MCLEODSO', '', 'Arkansas', '7.45 ', '3/14/2015'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {6}SRFlorida State7.46 qq = Performance occurred during a non-final round. 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {6}SR',
#   '',
#   'Florida State',
#   '7.46 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {6}SR',
#   '',
#   'Florida State',
#   '7.46 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {7}SRFlorida State7.46 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {7}SR',
#   '',
#   'Florida State',
#   '7.46 ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {7}SR',
#   '',
#   'Florida State',
#   '7.46 ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {8}SRFlorida State7.47 2/6/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {8}SR',
#   '',
#   'Florida State',
#   '7.47 ',
#   '2/6/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {8}SR',
#   '',
#   'Florida State',
#   '7.47 ',
#   '2/6/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {6}SOFlorida7.47📺 3/10/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {6}SO',
#   '',
#   'Florida',
#   '7.47📺 ',
#   '3/10/2018'],
#  ['\xa0\xa0\xa0\xa0— Holloway {6}SO', '', 'Florida', '7.47📺 ', '3/10/2018'],
#  ['(5) Reggie TORIANWisconsin7.47  2/7/1997',
#   '(5) Reggie TORIAN',
#   '',
#   'Wisconsin',
#   '7.47  ',
#   '2/7/1997'],
#  ['(5) Reggie TORIAN', '', 'Wisconsin', '7.47  ', '2/7/1997'],
#  ['\xa0\xa0\xa0\xa0— Roberts {2}JRKentucky7.48 2/23/2019',
#   '\xa0\xa0\xa0\xa0— Roberts {2}JR',
#   '',
#   'Kentucky',
#   '7.48 ',
#   '2/23/2019'],
#  ['\xa0\xa0\xa0\xa0— Roberts {2}JR', '', 'Kentucky', '7.48 ', '2/23/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {7}JRFlorida7.48 qq = Performance occurred during a non-final round. 2/22/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {7}JR',
#   '',
#   'Florida',
#   '7.48 qq = Performance occurred during a non-final round. ',
#   '2/22/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {7}JR',
#   '',
#   'Florida',
#   '7.48 qq = Performance occurred during a non-final round. ',
#   '2/22/2019'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {9}SRFlorida State7.49 qq = Performance occurred during a non-final round. 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {9}SR',
#   '',
#   'Florida State',
#   '7.49 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {9}SR',
#   '',
#   'Florida State',
#   '7.49 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {10}SRFlorida State7.49 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {10}SR',
#   '',
#   'Florida State',
#   '7.49 ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {10}SR',
#   '',
#   'Florida State',
#   '7.49 ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {8}JRFlorida7.49 1/18/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {8}JR',
#   '',
#   'Florida',
#   '7.49 ',
#   '1/18/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {8}JR', '', 'Florida', '7.49 ', '1/18/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {9}JRFlorida7.49📺 qq = Performance occurred during a non-final round. 1/18/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {9}JR',
#   '',
#   'Florida',
#   '7.49📺 qq = Performance occurred during a non-final round. ',
#   '1/18/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {9}JR',
#   '',
#   'Florida',
#   '7.49📺 qq = Performance occurred during a non-final round. ',
#   '1/18/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {10}SOFlorida7.49 1/19/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {10}SO',
#   '',
#   'Florida',
#   '7.49 ',
#   '1/19/2018'],
#  ['\xa0\xa0\xa0\xa0— Holloway {10}SO', '', 'Florida', '7.49 ', '1/19/2018'],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}SOArkansas7.49 2/28/2015',
#   '\xa0\xa0\xa0\xa0— McLeod {2}SO',
#   '',
#   'Arkansas',
#   '7.49 ',
#   '2/28/2015'],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}SO', '', 'Arkansas', '7.49 ', '2/28/2015'],
#  ['(6) Jarret EATONSyracuse7.49 1/27/2012',
#   '(6) Jarret EATON',
#   '',
#   'Syracuse',
#   '7.49 ',
#   '1/27/2012'],
#  ['(6) Jarret EATON', '', 'Syracuse', '7.49 ', '1/27/2012'],
#  ['\xa0\xa0\xa0\xa0— Torian {2}Wisconsin7.49  2/28/1997',
#   '\xa0\xa0\xa0\xa0— Torian {2}',
#   '',
#   'Wisconsin',
#   '7.49  ',
#   '2/28/1997'],
#  ['\xa0\xa0\xa0\xa0— Torian {2}', '', 'Wisconsin', '7.49  ', '2/28/1997'],
#  ['(7) Cordell TINCHJRPittsburg State7.50 2/10/2023',
#   '(7) Cordell TINCHJR',
#   '',
#   'Pittsburg State',
#   '7.50 ',
#   '2/10/2023'],
#  ['(7) Cordell TINCHJR', '', 'Pittsburg State', '7.50 ', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {11}SRFlorida State7.50 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {11}SR',
#   '',
#   'Florida State',
#   '7.50 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {11}SR',
#   '',
#   'Florida State',
#   '7.50 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(7) Eddie LOVETTJRFlorida7.50 3/9/2013',
#   '(7) Eddie LOVETTJR',
#   '',
#   'Florida',
#   '7.50 ',
#   '3/9/2013'],
#  ['(7) Eddie LOVETTJR', '', 'Florida', '7.50 ', '3/9/2013'],
#  ['\xa0\xa0\xa0\xa0— Tinch {2}JRPittsburg State7.51 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Tinch {2}JR',
#   '',
#   'Pittsburg State',
#   '7.51 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Tinch {2}JR',
#   '',
#   'Pittsburg State',
#   '7.51 ',
#   '3/11/2023'],
#  ['(9) Damion THOMASSRLSU7.51 3/13/2021',
#   '(9) Damion THOMASSR',
#   '',
#   'LSU',
#   '7.51 ',
#   '3/13/2021'],
#  ['(9) Damion THOMASSR', '', 'LSU', '7.51 ', '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {12}JRFlorida State7.51 2/14/2020',
#   '\xa0\xa0\xa0\xa0— Cunningham {12}JR',
#   '',
#   'Florida State',
#   '7.51 ',
#   '2/14/2020'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {12}JR',
#   '',
#   'Florida State',
#   '7.51 ',
#   '2/14/2020'],
#  ['(9) Aries MERRITTJRTennessee7.51  3/10/2006',
#   '(9) Aries MERRITTJR',
#   '',
#   'Tennessee',
#   '7.51  ',
#   '3/10/2006'],
#  ['(9) Aries MERRITTJR', '', 'Tennessee', '7.51  ', '3/10/2006'],
#  ['\xa0\xa0\xa0\xa0— Tinch {3}JRPittsburg State7.52 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Tinch {3}JR',
#   '',
#   'Pittsburg State',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Tinch {3}JR',
#   '',
#   'Pittsburg State',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(11) Caleb DEANJRTexas Tech7.52 2/24/2023',
#   '(11) Caleb DEANJR',
#   '',
#   'Texas Tech',
#   '7.52 ',
#   '2/24/2023'],
#  ['(11) Caleb DEANJR', '', 'Texas Tech', '7.52 ', '2/24/2023'],
#  ['(11) Jamal  BRITTJRIowa7.52 3/13/2021',
#   '(11) Jamal  BRITTJR',
#   '',
#   'Iowa',
#   '7.52 ',
#   '3/13/2021'],
#  ['(11) Jamal  BRITTJR', '', 'Iowa', '7.52 ', '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {13}JRFlorida State7.52 1/31/2020',
#   '\xa0\xa0\xa0\xa0— Cunningham {13}JR',
#   '',
#   'Florida State',
#   '7.52 ',
#   '1/31/2020'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {13}JR',
#   '',
#   'Florida State',
#   '7.52 ',
#   '1/31/2020'],
#  ['\xa0\xa0\xa0\xa0— Roberts {3}JRKentucky7.52 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Roberts {3}JR',
#   '',
#   'Kentucky',
#   '7.52 ',
#   '2/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Roberts {3}JR', '', 'Kentucky', '7.52 ', '2/8/2019'],
#  ['(11) Ron BRAMLETTAlabama7.52 qq = Performance occurred during a non-final round. 2/23/2002',
#   '(11) Ron BRAMLETT',
#   '',
#   'Alabama',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '2/23/2002'],
#  ['(11) Ron BRAMLETT',
#   '',
#   'Alabama',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '2/23/2002'],
#  ['(11) Terrence TRAMMELLSOSouth Carolina7.52  3/5/1999',
#   '(11) Terrence TRAMMELLSO',
#   '',
#   'South Carolina',
#   '7.52  ',
#   '3/5/1999'],
#  ['(11) Terrence TRAMMELLSO', '', 'South Carolina', '7.52  ', '3/5/1999'],
#  ['(15) Omotade OJORASRSouthern California7.53 2/10/2023',
#   '(15) Omotade OJORASR',
#   '',
#   'Southern California',
#   '7.53 ',
#   '2/10/2023'],
#  ['(15) Omotade OJORASR', '', 'Southern California', '7.53 ', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {14}SRFlorida State7.53 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Cunningham {14}SR',
#   '',
#   'Florida State',
#   '7.53 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {14}SR',
#   '',
#   'Florida State',
#   '7.53 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {15}SOFlorida State7.53 1/24/2019',
#   '\xa0\xa0\xa0\xa0— Cunningham {15}SO',
#   '',
#   'Florida State',
#   '7.53 ',
#   '1/24/2019'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {15}SO',
#   '',
#   'Florida State',
#   '7.53 ',
#   '1/24/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {11}SOFlorida7.53 2/25/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {11}SO',
#   '',
#   'Florida',
#   '7.53 ',
#   '2/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Holloway {11}SO', '', 'Florida', '7.53 ', '2/25/2018'],
#  ['(15) Myles HUNTERMinnesota State7.53 3/12/2016',
#   '(15) Myles HUNTER',
#   '',
#   'Minnesota State',
#   '7.53 ',
#   '3/12/2016'],
#  ['(15) Myles HUNTER', '', 'Minnesota State', '7.53 ', '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Lovett {2}JRFlorida7.53 qq = Performance occurred during a non-final round. 3/8/2013',
#   '\xa0\xa0\xa0\xa0— Lovett {2}JR',
#   '',
#   'Florida',
#   '7.53 qq = Performance occurred during a non-final round. ',
#   '3/8/2013'],
#  ['\xa0\xa0\xa0\xa0— Lovett {2}JR',
#   '',
#   'Florida',
#   '7.53 qq = Performance occurred during a non-final round. ',
#   '3/8/2013'],
#  ['(15) Andrew RILEYIllinois7.53 2/11/2012',
#   '(15) Andrew RILEY',
#   '',
#   'Illinois',
#   '7.53 ',
#   '2/11/2012'],
#  ['(15) Andrew RILEY', '', 'Illinois', '7.53 ', '2/11/2012'],
#  ['(15) Drew BRUNSONSRFlorida State7.53  3/14/2008\xa0\xa0\xa0\xa0\xa0(7.527)',
#   '(15) Drew BRUNSONSR',
#   '',
#   'Florida State',
#   '7.53  ',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa0(7.527)'],
#  ['(15) Drew BRUNSONSR', '', 'Florida State', '7.53  ', '3/14/2008'],
#  ['(15) Jason RICHARDSONJRSouth Carolina7.53  3/14/2008\xa0\xa0\xa0\xa0\xa0(7.530)',
#   '(15) Jason RICHARDSONJR',
#   '',
#   'South Carolina',
#   '7.53  ',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa0(7.530)'],
#  ['(15) Jason RICHARDSONJR', '', 'South Carolina', '7.53  ', '3/14/2008'],
#  ['\xa0\xa0\xa0\xa0— Trammell {2}South Carolina7.53  2/13/1999',
#   '\xa0\xa0\xa0\xa0— Trammell {2}',
#   '',
#   'South Carolina',
#   '7.53  ',
#   '2/13/1999'],
#  ['\xa0\xa0\xa0\xa0— Trammell {2}',
#   '',
#   'South Carolina',
#   '7.53  ',
#   '2/13/1999'],
#  ['(20) Darius LUFFJRNebraska7.54 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(20) Darius LUFFJR',
#   '',
#   'Nebraska',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(20) Darius LUFFJR',
#   '',
#   'Nebraska',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {16}SRFlorida State7.54 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {16}SR',
#   '',
#   'Florida State',
#   '7.54 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {16}SR',
#   '',
#   'Florida State',
#   '7.54 ',
#   '2/11/2022'],
#  ['(20) Phillip LEMONIOUSSOArkansas7.54 3/13/2021',
#   '(20) Phillip LEMONIOUSSO',
#   '',
#   'Arkansas',
#   '7.54 ',
#   '3/13/2021'],
#  ['(20) Phillip LEMONIOUSSO', '', 'Arkansas', '7.54 ', '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Lovett {3}Florida7.54 2/24/2013',
#   '\xa0\xa0\xa0\xa0— Lovett {3}',
#   '',
#   'Florida',
#   '7.54 ',
#   '2/24/2013'],
#  ['\xa0\xa0\xa0\xa0— Lovett {3}', '', 'Florida', '7.54 ', '2/24/2013'],
#  ['\xa0\xa0\xa0\xa0— Eaton {2}SRSyracuse7.54 3/10/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {2}SR',
#   '',
#   'Syracuse',
#   '7.54 ',
#   '3/10/2012'],
#  ['\xa0\xa0\xa0\xa0— Eaton {2}SR', '', 'Syracuse', '7.54 ', '3/10/2012'],
#  ['\xa0\xa0\xa0\xa0— Eaton {3}Syracuse7.54 2/3/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {3}',
#   '',
#   'Syracuse',
#   '7.54 ',
#   '2/3/2012'],
#  ['\xa0\xa0\xa0\xa0— Eaton {3}', '', 'Syracuse', '7.54 ', '2/3/2012'],
#  ['\xa0\xa0\xa0\xa0— Eaton {4}Syracuse7.54 qq = Performance occurred during a non-final round. 1/27/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {4}',
#   '',
#   'Syracuse',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '1/27/2012'],
#  ['\xa0\xa0\xa0\xa0— Eaton {4}',
#   '',
#   'Syracuse',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '1/27/2012'],
#  ['(22) Giano ROBERTSSRClemson7.55📺 3/11/2023',
#   '(22) Giano ROBERTSSR',
#   '',
#   'Clemson',
#   '7.55📺 ',
#   '3/11/2023'],
#  ['(22) Giano ROBERTSSR', '', 'Clemson', '7.55📺 ', '3/11/2023'],
#  ['(22) Leonard MUSTARIFRNorth Carolina A&T7.55 2/11/2022',
#   '(22) Leonard MUSTARIFR',
#   '',
#   'North Carolina A&T',
#   '7.55 ',
#   '2/11/2022'],
#  ['(22) Leonard MUSTARIFR', '', 'North Carolina A&T', '7.55 ', '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {17}SRFlorida State7.55 2/12/2021',
#   '\xa0\xa0\xa0\xa0— Cunningham {17}SR',
#   '',
#   'Florida State',
#   '7.55 ',
#   '2/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {17}SR',
#   '',
#   'Florida State',
#   '7.55 ',
#   '2/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {18}SOFlorida State7.55 qq = Performance occurred during a non-final round. 3/8/2019',
#   '\xa0\xa0\xa0\xa0— Cunningham {18}SO',
#   '',
#   'Florida State',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {18}SO',
#   '',
#   'Florida State',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {12}JRFlorida7.55 qq = Performance occurred during a non-final round. 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {12}JR',
#   '',
#   'Florida',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '2/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {12}JR',
#   '',
#   'Florida',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '2/8/2019'],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}Arkansas7.55 qq = Performance occurred during a non-final round. 3/13/2015',
#   '\xa0\xa0\xa0\xa0— McLeod {3}',
#   '',
#   'Arkansas',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}',
#   '',
#   'Arkansas',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/13/2015'],
#  ['(22) Devon HILLMiami (Fla.)7.55 3/10/2012',
#   '(22) Devon HILL',
#   '',
#   'Miami (Fla.)',
#   '7.55 ',
#   '3/10/2012'],
#  ['(22) Devon HILL', '', 'Miami (Fla.)', '7.55 ', '3/10/2012'],
#  ['(22) Barrett NUGENTLSU7.55 3/10/2012',
#   '(22) Barrett NUGENT',
#   '',
#   'LSU',
#   '7.55 ',
#   '3/10/2012'],
#  ['(22) Barrett NUGENT', '', 'LSU', '7.55 ', '3/10/2012'],
#  ['\xa0\xa0\xa0\xa0— Riley {2}Illinois7.55 qq = Performance occurred during a non-final round. 3/9/2012',
#   '\xa0\xa0\xa0\xa0— Riley {2}',
#   '',
#   'Illinois',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/9/2012'],
#  ['\xa0\xa0\xa0\xa0— Riley {2}',
#   '',
#   'Illinois',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/9/2012'],
#  ['(22) Ronnie ASHJROklahoma7.55 qq = Performance occurred during a non-final round. 3/12/2010',
#   '(22) Ronnie ASHJR',
#   '',
#   'Oklahoma',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/12/2010'],
#  ['(22) Ronnie ASHJR',
#   '',
#   'Oklahoma',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/12/2010'],
#  ['(22) Jabari GREERSOTennessee7.55  3/15/2003',
#   '(22) Jabari GREERSO',
#   '',
#   'Tennessee',
#   '7.55  ',
#   '3/15/2003'],
#  ['(22) Jabari GREERSO', '', 'Tennessee', '7.55  ', '3/15/2003'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {2}SRAlabama7.55 qq = Performance occurred during a non-final round. 3/8/2002',
#   '\xa0\xa0\xa0\xa0— Bramlett {2}SR',
#   '',
#   'Alabama',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2002'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {2}SR',
#   '',
#   'Alabama',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2002'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {3}Alabama7.55  2/24/2002',
#   '\xa0\xa0\xa0\xa0— Bramlett {3}',
#   '',
#   'Alabama',
#   '7.55  ',
#   '2/24/2002'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {3}', '', 'Alabama', '7.55  ', '2/24/2002'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {4}Alabama7.55  2/25/2001',
#   '\xa0\xa0\xa0\xa0— Bramlett {4}',
#   '',
#   'Alabama',
#   '7.55  ',
#   '2/25/2001'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {4}', '', 'Alabama', '7.55  ', '2/25/2001'],
#  ['\xa0\xa0\xa0\xa0— Trammell {3}JRSouth Carolina7.55  3/10/2000',
#   '\xa0\xa0\xa0\xa0— Trammell {3}JR',
#   '',
#   'South Carolina',
#   '7.55  ',
#   '3/10/2000'],
#  ['\xa0\xa0\xa0\xa0— Trammell {3}JR',
#   '',
#   'South Carolina',
#   '7.55  ',
#   '3/10/2000'],
#  ['', '', '', '']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Grant HOLLOWAYJRFlorida7.35📺 3/9/2019',
#   '(1) Grant HOLLOWAYJR',
#   '',
#   'Florida',
#   '7.35📺 ',
#   '3/9/2019'],
#  ['(2) Trey CUNNINGHAMSRFlorida State7.38 3/12/2022',
#   '(2) Trey CUNNINGHAMSR',
#   '',
#   'Florida State',
#   '7.38 ',
#   '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {2}SRFlorida State7.40 qq = Performance occurred during a non-final round. 2/25/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {2}SR',
#   '',
#   'Florida State',
#   '7.40 qq = Performance occurred during a non-final round. ',
#   '2/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {3}SRFlorida State7.40 2/24/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {3}SR',
#   '',
#   'Florida State',
#   '7.40 ',
#   '2/24/2022'],
#  ['(3) Daniel ROBERTSJRKentucky7.41 3/9/2019',
#   '(3) Daniel ROBERTSJR',
#   '',
#   'Kentucky',
#   '7.41 ',
#   '3/9/2019'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {4}SRFlorida State7.42 2/24/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {4}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/24/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {5}SRFlorida State7.42 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {5}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {2}SOFlorida7.42 2/9/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {2}SO',
#   '',
#   'Florida',
#   '7.42 ',
#   '2/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Holloway {3}JRFlorida7.43📺 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {3}JR',
#   '',
#   'Florida',
#   '7.43📺 ',
#   '2/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {4}JRFlorida7.44 qq = Performance occurred during a non-final round. 3/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {4}JR',
#   '',
#   'Florida',
#   '7.44 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {5}JRFlorida7.44 2/23/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {5}JR',
#   '',
#   'Florida',
#   '7.44 ',
#   '2/23/2019'],
#  ['(4) Omar MCLEODSOArkansas7.45 3/14/2015',
#   '(4) Omar MCLEODSO',
#   '',
#   'Arkansas',
#   '7.45 ',
#   '3/14/2015'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {6}SRFlorida State7.46 qq = Performance occurred during a non-final round. 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {6}SR',
#   '',
#   'Florida State',
#   '7.46 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {7}SRFlorida State7.46 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {7}SR',
#   '',
#   'Florida State',
#   '7.46 ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {8}SRFlorida State7.47 2/6/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {8}SR',
#   '',
#   'Florida State',
#   '7.47 ',
#   '2/6/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {6}SOFlorida7.47📺 3/10/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {6}SO',
#   '',
#   'Florida',
#   '7.47📺 ',
#   '3/10/2018'],
#  ['(5) Reggie TORIANWisconsin7.47  2/7/1997',
#   '(5) Reggie TORIAN',
#   '',
#   'Wisconsin',
#   '7.47  ',
#   '2/7/1997'],
#  ['\xa0\xa0\xa0\xa0— Roberts {2}JRKentucky7.48 2/23/2019',
#   '\xa0\xa0\xa0\xa0— Roberts {2}JR',
#   '',
#   'Kentucky',
#   '7.48 ',
#   '2/23/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {7}JRFlorida7.48 qq = Performance occurred during a non-final round. 2/22/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {7}JR',
#   '',
#   'Florida',
#   '7.48 qq = Performance occurred during a non-final round. ',
#   '2/22/2019'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {9}SRFlorida State7.49 qq = Performance occurred during a non-final round. 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {9}SR',
#   '',
#   'Florida State',
#   '7.49 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {10}SRFlorida State7.49 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {10}SR',
#   '',
#   'Florida State',
#   '7.49 ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {8}JRFlorida7.49 1/18/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {8}JR',
#   '',
#   'Florida',
#   '7.49 ',
#   '1/18/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {9}JRFlorida7.49📺 qq = Performance occurred during a non-final round. 1/18/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {9}JR',
#   '',
#   'Florida',
#   '7.49📺 qq = Performance occurred during a non-final round. ',
#   '1/18/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {10}SOFlorida7.49 1/19/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {10}SO',
#   '',
#   'Florida',
#   '7.49 ',
#   '1/19/2018'],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}SOArkansas7.49 2/28/2015',
#   '\xa0\xa0\xa0\xa0— McLeod {2}SO',
#   '',
#   'Arkansas',
#   '7.49 ',
#   '2/28/2015'],
#  ['(6) Jarret EATONSyracuse7.49 1/27/2012',
#   '(6) Jarret EATON',
#   '',
#   'Syracuse',
#   '7.49 ',
#   '1/27/2012'],
#  ['\xa0\xa0\xa0\xa0— Torian {2}Wisconsin7.49  2/28/1997',
#   '\xa0\xa0\xa0\xa0— Torian {2}',
#   '',
#   'Wisconsin',
#   '7.49  ',
#   '2/28/1997'],
#  ['(7) Cordell TINCHJRPittsburg State7.50 2/10/2023',
#   '(7) Cordell TINCHJR',
#   '',
#   'Pittsburg State',
#   '7.50 ',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {11}SRFlorida State7.50 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {11}SR',
#   '',
#   'Florida State',
#   '7.50 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(7) Eddie LOVETTJRFlorida7.50 3/9/2013',
#   '(7) Eddie LOVETTJR',
#   '',
#   'Florida',
#   '7.50 ',
#   '3/9/2013'],
#  ['\xa0\xa0\xa0\xa0— Tinch {2}JRPittsburg State7.51 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Tinch {2}JR',
#   '',
#   'Pittsburg State',
#   '7.51 ',
#   '3/11/2023'],
#  ['(9) Damion THOMASSRLSU7.51 3/13/2021',
#   '(9) Damion THOMASSR',
#   '',
#   'LSU',
#   '7.51 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {12}JRFlorida State7.51 2/14/2020',
#   '\xa0\xa0\xa0\xa0— Cunningham {12}JR',
#   '',
#   'Florida State',
#   '7.51 ',
#   '2/14/2020'],
#  ['(9) Aries MERRITTJRTennessee7.51  3/10/2006',
#   '(9) Aries MERRITTJR',
#   '',
#   'Tennessee',
#   '7.51  ',
#   '3/10/2006'],
#  ['\xa0\xa0\xa0\xa0— Tinch {3}JRPittsburg State7.52 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Tinch {3}JR',
#   '',
#   'Pittsburg State',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(11) Caleb DEANJRTexas Tech7.52 2/24/2023',
#   '(11) Caleb DEANJR',
#   '',
#   'Texas Tech',
#   '7.52 ',
#   '2/24/2023'],
#  ['(11) Jamal  BRITTJRIowa7.52 3/13/2021',
#   '(11) Jamal  BRITTJR',
#   '',
#   'Iowa',
#   '7.52 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {13}JRFlorida State7.52 1/31/2020',
#   '\xa0\xa0\xa0\xa0— Cunningham {13}JR',
#   '',
#   'Florida State',
#   '7.52 ',
#   '1/31/2020'],
#  ['\xa0\xa0\xa0\xa0— Roberts {3}JRKentucky7.52 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Roberts {3}JR',
#   '',
#   'Kentucky',
#   '7.52 ',
#   '2/8/2019'],
#  ['(11) Ron BRAMLETTAlabama7.52 qq = Performance occurred during a non-final round. 2/23/2002',
#   '(11) Ron BRAMLETT',
#   '',
#   'Alabama',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '2/23/2002'],
#  ['(11) Terrence TRAMMELLSOSouth Carolina7.52  3/5/1999',
#   '(11) Terrence TRAMMELLSO',
#   '',
#   'South Carolina',
#   '7.52  ',
#   '3/5/1999'],
#  ['(15) Omotade OJORASRSouthern California7.53 2/10/2023',
#   '(15) Omotade OJORASR',
#   '',
#   'Southern California',
#   '7.53 ',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {14}SRFlorida State7.53 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Cunningham {14}SR',
#   '',
#   'Florida State',
#   '7.53 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {15}SOFlorida State7.53 1/24/2019',
#   '\xa0\xa0\xa0\xa0— Cunningham {15}SO',
#   '',
#   'Florida State',
#   '7.53 ',
#   '1/24/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {11}SOFlorida7.53 2/25/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {11}SO',
#   '',
#   'Florida',
#   '7.53 ',
#   '2/25/2018'],
#  ['(15) Myles HUNTERMinnesota State7.53 3/12/2016',
#   '(15) Myles HUNTER',
#   '',
#   'Minnesota State',
#   '7.53 ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Lovett {2}JRFlorida7.53 qq = Performance occurred during a non-final round. 3/8/2013',
#   '\xa0\xa0\xa0\xa0— Lovett {2}JR',
#   '',
#   'Florida',
#   '7.53 qq = Performance occurred during a non-final round. ',
#   '3/8/2013'],
#  ['(15) Andrew RILEYIllinois7.53 2/11/2012',
#   '(15) Andrew RILEY',
#   '',
#   'Illinois',
#   '7.53 ',
#   '2/11/2012'],
#  ['(15) Drew BRUNSONSRFlorida State7.53  3/14/2008\xa0\xa0\xa0\xa0\xa0(7.527)',
#   '(15) Drew BRUNSONSR',
#   '',
#   'Florida State',
#   '7.53  ',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa0(7.527)'],
#  ['(15) Jason RICHARDSONJRSouth Carolina7.53  3/14/2008\xa0\xa0\xa0\xa0\xa0(7.530)',
#   '(15) Jason RICHARDSONJR',
#   '',
#   'South Carolina',
#   '7.53  ',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa0(7.530)'],
#  ['\xa0\xa0\xa0\xa0— Trammell {2}South Carolina7.53  2/13/1999',
#   '\xa0\xa0\xa0\xa0— Trammell {2}',
#   '',
#   'South Carolina',
#   '7.53  ',
#   '2/13/1999'],
#  ['(20) Darius LUFFJRNebraska7.54 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(20) Darius LUFFJR',
#   '',
#   'Nebraska',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {16}SRFlorida State7.54 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {16}SR',
#   '',
#   'Florida State',
#   '7.54 ',
#   '2/11/2022'],
#  ['(20) Phillip LEMONIOUSSOArkansas7.54 3/13/2021',
#   '(20) Phillip LEMONIOUSSO',
#   '',
#   'Arkansas',
#   '7.54 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Lovett {3}Florida7.54 2/24/2013',
#   '\xa0\xa0\xa0\xa0— Lovett {3}',
#   '',
#   'Florida',
#   '7.54 ',
#   '2/24/2013'],
#  ['\xa0\xa0\xa0\xa0— Eaton {2}SRSyracuse7.54 3/10/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {2}SR',
#   '',
#   'Syracuse',
#   '7.54 ',
#   '3/10/2012'],
#  ['\xa0\xa0\xa0\xa0— Eaton {3}Syracuse7.54 2/3/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {3}',
#   '',
#   'Syracuse',
#   '7.54 ',
#   '2/3/2012'],
#  ['\xa0\xa0\xa0\xa0— Eaton {4}Syracuse7.54 qq = Performance occurred during a non-final round. 1/27/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {4}',
#   '',
#   'Syracuse',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '1/27/2012'],
#  ['(22) Giano ROBERTSSRClemson7.55📺 3/11/2023',
#   '(22) Giano ROBERTSSR',
#   '',
#   'Clemson',
#   '7.55📺 ',
#   '3/11/2023'],
#  ['(22) Leonard MUSTARIFRNorth Carolina A&T7.55 2/11/2022',
#   '(22) Leonard MUSTARIFR',
#   '',
#   'North Carolina A&T',
#   '7.55 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {17}SRFlorida State7.55 2/12/2021',
#   '\xa0\xa0\xa0\xa0— Cunningham {17}SR',
#   '',
#   'Florida State',
#   '7.55 ',
#   '2/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {18}SOFlorida State7.55 qq = Performance occurred during a non-final round. 3/8/2019',
#   '\xa0\xa0\xa0\xa0— Cunningham {18}SO',
#   '',
#   'Florida State',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {12}JRFlorida7.55 qq = Performance occurred during a non-final round. 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {12}JR',
#   '',
#   'Florida',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '2/8/2019'],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}Arkansas7.55 qq = Performance occurred during a non-final round. 3/13/2015',
#   '\xa0\xa0\xa0\xa0— McLeod {3}',
#   '',
#   'Arkansas',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/13/2015'],
#  ['(22) Devon HILLMiami (Fla.)7.55 3/10/2012',
#   '(22) Devon HILL',
#   '',
#   'Miami (Fla.)',
#   '7.55 ',
#   '3/10/2012'],
#  ['(22) Barrett NUGENTLSU7.55 3/10/2012',
#   '(22) Barrett NUGENT',
#   '',
#   'LSU',
#   '7.55 ',
#   '3/10/2012'],
#  ['\xa0\xa0\xa0\xa0— Riley {2}Illinois7.55 qq = Performance occurred during a non-final round. 3/9/2012',
#   '\xa0\xa0\xa0\xa0— Riley {2}',
#   '',
#   'Illinois',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/9/2012'],
#  ['(22) Ronnie ASHJROklahoma7.55 qq = Performance occurred during a non-final round. 3/12/2010',
#   '(22) Ronnie ASHJR',
#   '',
#   'Oklahoma',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/12/2010'],
#  ['(22) Jabari GREERSOTennessee7.55  3/15/2003',
#   '(22) Jabari GREERSO',
#   '',
#   'Tennessee',
#   '7.55  ',
#   '3/15/2003'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {2}SRAlabama7.55 qq = Performance occurred during a non-final round. 3/8/2002',
#   '\xa0\xa0\xa0\xa0— Bramlett {2}SR',
#   '',
#   'Alabama',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2002'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {3}Alabama7.55  2/24/2002',
#   '\xa0\xa0\xa0\xa0— Bramlett {3}',
#   '',
#   'Alabama',
#   '7.55  ',
#   '2/24/2002'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {4}Alabama7.55  2/25/2001',
#   '\xa0\xa0\xa0\xa0— Bramlett {4}',
#   '',
#   'Alabama',
#   '7.55  ',
#   '2/25/2001'],
#  ['\xa0\xa0\xa0\xa0— Trammell {3}JRSouth Carolina7.55  3/10/2000',
#   '\xa0\xa0\xa0\xa0— Trammell {3}JR',
#   '',
#   'South Carolina',
#   '7.55  ',
#   '3/10/2000'],
#  ['', '', '', '']]

# %%
len(RealRealRows)
# Out:
# 74

# %%
RealRealRows[0][4]
# Out:
# '7.35📺 '

# %%
OfficialTimes = []

# %%
for i in range(0,73):
    OfficialTimes.append(RealRealRows[i][4])
OfficialTimes
# Out:
# ['7.35📺 ',
#  '7.38 ',
#  '7.40 qq = Performance occurred during a non-final round. ',
#  '7.40 ',
#  '7.41 ',
#  '7.42 ',
#  '7.42 ',
#  '7.42 ',
#  '7.43📺 ',
#  '7.44 qq = Performance occurred during a non-final round. ',
#  '7.44 ',
#  '7.45 ',
#  '7.46 qq = Performance occurred during a non-final round. ',
#  '7.46 ',
#  '7.47 ',
#  '7.47📺 ',
#  '7.47  ',
#  '7.48 ',
#  '7.48 qq = Performance occurred during a non-final round. ',
#  '7.49 qq = Performance occurred during a non-final round. ',
#  '7.49 ',
#  '7.49 ',
#  '7.49📺 qq = Performance occurred during a non-final round. ',
#  '7.49 ',
#  '7.49 ',
#  '7.49 ',
#  '7.49  ',
#  '7.50 ',
#  '7.50 qq = Performance occurred during a non-final round. ',
#  '7.50 ',
#  '7.51 ',
#  '7.51 ',
#  '7.51 ',
#  '7.51  ',
#  '7.52 qq = Performance occurred during a non-final round. ',
#  '7.52 ',
#  '7.52 ',
#  '7.52 ',
#  '7.52 ',
#  '7.52 qq = Performance occurred during a non-final round. ',
#  '7.52  ',
#  '7.53 ',
#  '7.53 ',
#  '7.53 ',
#  '7.53 ',
#  '7.53 ',
#  '7.53 qq = Performance occurred during a non-final round. ',
#  '7.53 ',
#  '7.53  ',
#  '7.53  ',
#  '7.53  ',
#  '7.54 qq = Performance occurred during a non-final round. ',
#  '7.54 ',
#  '7.54 ',
#  '7.54 ',
#  '7.54 ',
#  '7.54 ',
#  '7.54 qq = Performance occurred during a non-final round. ',
#  '7.55📺 ',
#  '7.55 ',
#  '7.55 ',
#  '7.55 qq = Performance occurred during a non-final round. ',
#  '7.55 qq = Performance occurred during a non-final round. ',
#  '7.55 qq = Performance occurred during a non-final round. ',
#  '7.55 ',
#  '7.55 ',
#  '7.55 qq = Performance occurred during a non-final round. ',
#  '7.55 qq = Performance occurred during a non-final round. ',
#  '7.55  ',
#  '7.55 qq = Performance occurred during a non-final round. ',
#  '7.55  ',
#  '7.55  ',
#  '7.55  ']

# %%
len(OfficialTimes)
# Out:
# 73

# %%
RealRealRows
# Out:
# [['(1) Grant HOLLOWAYJRFlorida7.35📺 3/9/2019',
#   '(1) Grant HOLLOWAYJR',
#   '',
#   'Florida',
#   '7.35📺 ',
#   '3/9/2019'],
#  ['(2) Trey CUNNINGHAMSRFlorida State7.38 3/12/2022',
#   '(2) Trey CUNNINGHAMSR',
#   '',
#   'Florida State',
#   '7.38 ',
#   '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {2}SRFlorida State7.40 qq = Performance occurred during a non-final round. 2/25/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {2}SR',
#   '',
#   'Florida State',
#   '7.40 qq = Performance occurred during a non-final round. ',
#   '2/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {3}SRFlorida State7.40 2/24/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {3}SR',
#   '',
#   'Florida State',
#   '7.40 ',
#   '2/24/2022'],
#  ['(3) Daniel ROBERTSJRKentucky7.41 3/9/2019',
#   '(3) Daniel ROBERTSJR',
#   '',
#   'Kentucky',
#   '7.41 ',
#   '3/9/2019'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {4}SRFlorida State7.42 2/24/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {4}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/24/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {5}SRFlorida State7.42 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {5}SR',
#   '',
#   'Florida State',
#   '7.42 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {2}SOFlorida7.42 2/9/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {2}SO',
#   '',
#   'Florida',
#   '7.42 ',
#   '2/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Holloway {3}JRFlorida7.43📺 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {3}JR',
#   '',
#   'Florida',
#   '7.43📺 ',
#   '2/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {4}JRFlorida7.44 qq = Performance occurred during a non-final round. 3/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {4}JR',
#   '',
#   'Florida',
#   '7.44 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {5}JRFlorida7.44 2/23/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {5}JR',
#   '',
#   'Florida',
#   '7.44 ',
#   '2/23/2019'],
#  ['(4) Omar MCLEODSOArkansas7.45 3/14/2015',
#   '(4) Omar MCLEODSO',
#   '',
#   'Arkansas',
#   '7.45 ',
#   '3/14/2015'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {6}SRFlorida State7.46 qq = Performance occurred during a non-final round. 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {6}SR',
#   '',
#   'Florida State',
#   '7.46 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {7}SRFlorida State7.46 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {7}SR',
#   '',
#   'Florida State',
#   '7.46 ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {8}SRFlorida State7.47 2/6/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {8}SR',
#   '',
#   'Florida State',
#   '7.47 ',
#   '2/6/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {6}SOFlorida7.47📺 3/10/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {6}SO',
#   '',
#   'Florida',
#   '7.47📺 ',
#   '3/10/2018'],
#  ['(5) Reggie TORIANWisconsin7.47  2/7/1997',
#   '(5) Reggie TORIAN',
#   '',
#   'Wisconsin',
#   '7.47  ',
#   '2/7/1997'],
#  ['\xa0\xa0\xa0\xa0— Roberts {2}JRKentucky7.48 2/23/2019',
#   '\xa0\xa0\xa0\xa0— Roberts {2}JR',
#   '',
#   'Kentucky',
#   '7.48 ',
#   '2/23/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {7}JRFlorida7.48 qq = Performance occurred during a non-final round. 2/22/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {7}JR',
#   '',
#   'Florida',
#   '7.48 qq = Performance occurred during a non-final round. ',
#   '2/22/2019'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {9}SRFlorida State7.49 qq = Performance occurred during a non-final round. 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {9}SR',
#   '',
#   'Florida State',
#   '7.49 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {10}SRFlorida State7.49 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {10}SR',
#   '',
#   'Florida State',
#   '7.49 ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Holloway {8}JRFlorida7.49 1/18/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {8}JR',
#   '',
#   'Florida',
#   '7.49 ',
#   '1/18/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {9}JRFlorida7.49📺 qq = Performance occurred during a non-final round. 1/18/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {9}JR',
#   '',
#   'Florida',
#   '7.49📺 qq = Performance occurred during a non-final round. ',
#   '1/18/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {10}SOFlorida7.49 1/19/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {10}SO',
#   '',
#   'Florida',
#   '7.49 ',
#   '1/19/2018'],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}SOArkansas7.49 2/28/2015',
#   '\xa0\xa0\xa0\xa0— McLeod {2}SO',
#   '',
#   'Arkansas',
#   '7.49 ',
#   '2/28/2015'],
#  ['(6) Jarret EATONSyracuse7.49 1/27/2012',
#   '(6) Jarret EATON',
#   '',
#   'Syracuse',
#   '7.49 ',
#   '1/27/2012'],
#  ['\xa0\xa0\xa0\xa0— Torian {2}Wisconsin7.49  2/28/1997',
#   '\xa0\xa0\xa0\xa0— Torian {2}',
#   '',
#   'Wisconsin',
#   '7.49  ',
#   '2/28/1997'],
#  ['(7) Cordell TINCHJRPittsburg State7.50 2/10/2023',
#   '(7) Cordell TINCHJR',
#   '',
#   'Pittsburg State',
#   '7.50 ',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {11}SRFlorida State7.50 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {11}SR',
#   '',
#   'Florida State',
#   '7.50 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(7) Eddie LOVETTJRFlorida7.50 3/9/2013',
#   '(7) Eddie LOVETTJR',
#   '',
#   'Florida',
#   '7.50 ',
#   '3/9/2013'],
#  ['\xa0\xa0\xa0\xa0— Tinch {2}JRPittsburg State7.51 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Tinch {2}JR',
#   '',
#   'Pittsburg State',
#   '7.51 ',
#   '3/11/2023'],
#  ['(9) Damion THOMASSRLSU7.51 3/13/2021',
#   '(9) Damion THOMASSR',
#   '',
#   'LSU',
#   '7.51 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {12}JRFlorida State7.51 2/14/2020',
#   '\xa0\xa0\xa0\xa0— Cunningham {12}JR',
#   '',
#   'Florida State',
#   '7.51 ',
#   '2/14/2020'],
#  ['(9) Aries MERRITTJRTennessee7.51  3/10/2006',
#   '(9) Aries MERRITTJR',
#   '',
#   'Tennessee',
#   '7.51  ',
#   '3/10/2006'],
#  ['\xa0\xa0\xa0\xa0— Tinch {3}JRPittsburg State7.52 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Tinch {3}JR',
#   '',
#   'Pittsburg State',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(11) Caleb DEANJRTexas Tech7.52 2/24/2023',
#   '(11) Caleb DEANJR',
#   '',
#   'Texas Tech',
#   '7.52 ',
#   '2/24/2023'],
#  ['(11) Jamal  BRITTJRIowa7.52 3/13/2021',
#   '(11) Jamal  BRITTJR',
#   '',
#   'Iowa',
#   '7.52 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {13}JRFlorida State7.52 1/31/2020',
#   '\xa0\xa0\xa0\xa0— Cunningham {13}JR',
#   '',
#   'Florida State',
#   '7.52 ',
#   '1/31/2020'],
#  ['\xa0\xa0\xa0\xa0— Roberts {3}JRKentucky7.52 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Roberts {3}JR',
#   '',
#   'Kentucky',
#   '7.52 ',
#   '2/8/2019'],
#  ['(11) Ron BRAMLETTAlabama7.52 qq = Performance occurred during a non-final round. 2/23/2002',
#   '(11) Ron BRAMLETT',
#   '',
#   'Alabama',
#   '7.52 qq = Performance occurred during a non-final round. ',
#   '2/23/2002'],
#  ['(11) Terrence TRAMMELLSOSouth Carolina7.52  3/5/1999',
#   '(11) Terrence TRAMMELLSO',
#   '',
#   'South Carolina',
#   '7.52  ',
#   '3/5/1999'],
#  ['(15) Omotade OJORASRSouthern California7.53 2/10/2023',
#   '(15) Omotade OJORASR',
#   '',
#   'Southern California',
#   '7.53 ',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {14}SRFlorida State7.53 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Cunningham {14}SR',
#   '',
#   'Florida State',
#   '7.53 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {15}SOFlorida State7.53 1/24/2019',
#   '\xa0\xa0\xa0\xa0— Cunningham {15}SO',
#   '',
#   'Florida State',
#   '7.53 ',
#   '1/24/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {11}SOFlorida7.53 2/25/2018',
#   '\xa0\xa0\xa0\xa0— Holloway {11}SO',
#   '',
#   'Florida',
#   '7.53 ',
#   '2/25/2018'],
#  ['(15) Myles HUNTERMinnesota State7.53 3/12/2016',
#   '(15) Myles HUNTER',
#   '',
#   'Minnesota State',
#   '7.53 ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Lovett {2}JRFlorida7.53 qq = Performance occurred during a non-final round. 3/8/2013',
#   '\xa0\xa0\xa0\xa0— Lovett {2}JR',
#   '',
#   'Florida',
#   '7.53 qq = Performance occurred during a non-final round. ',
#   '3/8/2013'],
#  ['(15) Andrew RILEYIllinois7.53 2/11/2012',
#   '(15) Andrew RILEY',
#   '',
#   'Illinois',
#   '7.53 ',
#   '2/11/2012'],
#  ['(15) Drew BRUNSONSRFlorida State7.53  3/14/2008\xa0\xa0\xa0\xa0\xa0(7.527)',
#   '(15) Drew BRUNSONSR',
#   '',
#   'Florida State',
#   '7.53  ',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa0(7.527)'],
#  ['(15) Jason RICHARDSONJRSouth Carolina7.53  3/14/2008\xa0\xa0\xa0\xa0\xa0(7.530)',
#   '(15) Jason RICHARDSONJR',
#   '',
#   'South Carolina',
#   '7.53  ',
#   '3/14/2008',
#   '\xa0\xa0\xa0\xa0\xa0(7.530)'],
#  ['\xa0\xa0\xa0\xa0— Trammell {2}South Carolina7.53  2/13/1999',
#   '\xa0\xa0\xa0\xa0— Trammell {2}',
#   '',
#   'South Carolina',
#   '7.53  ',
#   '2/13/1999'],
#  ['(20) Darius LUFFJRNebraska7.54 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(20) Darius LUFFJR',
#   '',
#   'Nebraska',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {16}SRFlorida State7.54 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Cunningham {16}SR',
#   '',
#   'Florida State',
#   '7.54 ',
#   '2/11/2022'],
#  ['(20) Phillip LEMONIOUSSOArkansas7.54 3/13/2021',
#   '(20) Phillip LEMONIOUSSO',
#   '',
#   'Arkansas',
#   '7.54 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Lovett {3}Florida7.54 2/24/2013',
#   '\xa0\xa0\xa0\xa0— Lovett {3}',
#   '',
#   'Florida',
#   '7.54 ',
#   '2/24/2013'],
#  ['\xa0\xa0\xa0\xa0— Eaton {2}SRSyracuse7.54 3/10/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {2}SR',
#   '',
#   'Syracuse',
#   '7.54 ',
#   '3/10/2012'],
#  ['\xa0\xa0\xa0\xa0— Eaton {3}Syracuse7.54 2/3/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {3}',
#   '',
#   'Syracuse',
#   '7.54 ',
#   '2/3/2012'],
#  ['\xa0\xa0\xa0\xa0— Eaton {4}Syracuse7.54 qq = Performance occurred during a non-final round. 1/27/2012',
#   '\xa0\xa0\xa0\xa0— Eaton {4}',
#   '',
#   'Syracuse',
#   '7.54 qq = Performance occurred during a non-final round. ',
#   '1/27/2012'],
#  ['(22) Giano ROBERTSSRClemson7.55📺 3/11/2023',
#   '(22) Giano ROBERTSSR',
#   '',
#   'Clemson',
#   '7.55📺 ',
#   '3/11/2023'],
#  ['(22) Leonard MUSTARIFRNorth Carolina A&T7.55 2/11/2022',
#   '(22) Leonard MUSTARIFR',
#   '',
#   'North Carolina A&T',
#   '7.55 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {17}SRFlorida State7.55 2/12/2021',
#   '\xa0\xa0\xa0\xa0— Cunningham {17}SR',
#   '',
#   'Florida State',
#   '7.55 ',
#   '2/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Cunningham {18}SOFlorida State7.55 qq = Performance occurred during a non-final round. 3/8/2019',
#   '\xa0\xa0\xa0\xa0— Cunningham {18}SO',
#   '',
#   'Florida State',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Holloway {12}JRFlorida7.55 qq = Performance occurred during a non-final round. 2/8/2019',
#   '\xa0\xa0\xa0\xa0— Holloway {12}JR',
#   '',
#   'Florida',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '2/8/2019'],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}Arkansas7.55 qq = Performance occurred during a non-final round. 3/13/2015',
#   '\xa0\xa0\xa0\xa0— McLeod {3}',
#   '',
#   'Arkansas',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/13/2015'],
#  ['(22) Devon HILLMiami (Fla.)7.55 3/10/2012',
#   '(22) Devon HILL',
#   '',
#   'Miami (Fla.)',
#   '7.55 ',
#   '3/10/2012'],
#  ['(22) Barrett NUGENTLSU7.55 3/10/2012',
#   '(22) Barrett NUGENT',
#   '',
#   'LSU',
#   '7.55 ',
#   '3/10/2012'],
#  ['\xa0\xa0\xa0\xa0— Riley {2}Illinois7.55 qq = Performance occurred during a non-final round. 3/9/2012',
#   '\xa0\xa0\xa0\xa0— Riley {2}',
#   '',
#   'Illinois',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/9/2012'],
#  ['(22) Ronnie ASHJROklahoma7.55 qq = Performance occurred during a non-final round. 3/12/2010',
#   '(22) Ronnie ASHJR',
#   '',
#   'Oklahoma',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/12/2010'],
#  ['(22) Jabari GREERSOTennessee7.55  3/15/2003',
#   '(22) Jabari GREERSO',
#   '',
#   'Tennessee',
#   '7.55  ',
#   '3/15/2003'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {2}SRAlabama7.55 qq = Performance occurred during a non-final round. 3/8/2002',
#   '\xa0\xa0\xa0\xa0— Bramlett {2}SR',
#   '',
#   'Alabama',
#   '7.55 qq = Performance occurred during a non-final round. ',
#   '3/8/2002'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {3}Alabama7.55  2/24/2002',
#   '\xa0\xa0\xa0\xa0— Bramlett {3}',
#   '',
#   'Alabama',
#   '7.55  ',
#   '2/24/2002'],
#  ['\xa0\xa0\xa0\xa0— Bramlett {4}Alabama7.55  2/25/2001',
#   '\xa0\xa0\xa0\xa0— Bramlett {4}',
#   '',
#   'Alabama',
#   '7.55  ',
#   '2/25/2001'],
#  ['\xa0\xa0\xa0\xa0— Trammell {3}JRSouth Carolina7.55  3/10/2000',
#   '\xa0\xa0\xa0\xa0— Trammell {3}JR',
#   '',
#   'South Carolina',
#   '7.55  ',
#   '3/10/2000'],
#  ['', '', '', '']]

# %%
RealRealRows[1][1]
# Out:
# '(2) Trey CUNNINGHAMSR'

# %%
Names = []

for i in range(0,74):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Grant HOLLOWAYJR',
#  '(2) Trey CUNNINGHAMSR',
#  '\xa0\xa0\xa0\xa0— Cunningham {2}SR',
#  '\xa0\xa0\xa0\xa0— Cunningham {3}SR',
#  '(3) Daniel ROBERTSJR',
#  '\xa0\xa0\xa0\xa0— Cunningham {4}SR',
#  '\xa0\xa0\xa0\xa0— Cunningham {5}SR',
#  '\xa0\xa0\xa0\xa0— Holloway {2}SO',
#  '\xa0\xa0\xa0\xa0— Holloway {3}JR',
#  '\xa0\xa0\xa0\xa0— Holloway {4}JR',
#  '\xa0\xa0\xa0\xa0— Holloway {5}JR',
#  '(4) Omar MCLEODSO',
#  '\xa0\xa0\xa0\xa0— Cunningham {6}SR',
#  '\xa0\xa0\xa0\xa0— Cunningham {7}SR',
#  '\xa0\xa0\xa0\xa0— Cunningham {8}SR',
#  '\xa0\xa0\xa0\xa0— Holloway {6}SO',
#  '(5) Reggie TORIAN',
#  '\xa0\xa0\xa0\xa0— Roberts {2}JR',
#  '\xa0\xa0\xa0\xa0— Holloway {7}JR',
#  '\xa0\xa0\xa0\xa0— Cunningham {9}SR',
#  '\xa0\xa0\xa0\xa0— Cunningham {10}SR',
#  '\xa0\xa0\xa0\xa0— Holloway {8}JR',
#  '\xa0\xa0\xa0\xa0— Holloway {9}JR',
#  '\xa0\xa0\xa0\xa0— Holloway {10}SO',
#  '\xa0\xa0\xa0\xa0— McLeod {2}SO',
#  '(6) Jarret EATON',
#  '\xa0\xa0\xa0\xa0— Torian {2}',
#  '(7) Cordell TINCHJR',
#  '\xa0\xa0\xa0\xa0— Cunningham {11}SR',
#  '(7) Eddie LOVETTJR',
#  '\xa0\xa0\xa0\xa0— Tinch {2}JR',
#  '(9) Damion THOMASSR',
#  '\xa0\xa0\xa0\xa0— Cunningham {12}JR',
#  '(9) Aries MERRITTJR',
#  '\xa0\xa0\xa0\xa0— Tinch {3}JR',
#  '(11) Caleb DEANJR',
#  '(11) Jamal  BRITTJR',
#  '\xa0\xa0\xa0\xa0— Cunningham {13}JR',
#  '\xa0\xa0\xa0\xa0— Roberts {3}JR',
#  '(11) Ron BRAMLETT',
#  '(11) Terrence TRAMMELLSO',
#  '(15) Omotade OJORASR',
#  '\xa0\xa0\xa0\xa0— Cunningham {14}SR',
#  '\xa0\xa0\xa0\xa0— Cunningham {15}SO',
#  '\xa0\xa0\xa0\xa0— Holloway {11}SO',
#  '(15) Myles HUNTER',
#  '\xa0\xa0\xa0\xa0— Lovett {2}JR',
#  '(15) Andrew RILEY',
#  '(15) Drew BRUNSONSR',
#  '(15) Jason RICHARDSONJR',
#  '\xa0\xa0\xa0\xa0— Trammell {2}',
#  '(20) Darius LUFFJR',
#  '\xa0\xa0\xa0\xa0— Cunningham {16}SR',
#  '(20) Phillip LEMONIOUSSO',
#  '\xa0\xa0\xa0\xa0— Lovett {3}',
#  '\xa0\xa0\xa0\xa0— Eaton {2}SR',
#  '\xa0\xa0\xa0\xa0— Eaton {3}',
#  '\xa0\xa0\xa0\xa0— Eaton {4}',
#  '(22) Giano ROBERTSSR',
#  '(22) Leonard MUSTARIFR',
#  '\xa0\xa0\xa0\xa0— Cunningham {17}SR',
#  '\xa0\xa0\xa0\xa0— Cunningham {18}SO',
#  '\xa0\xa0\xa0\xa0— Holloway {12}JR',
#  '\xa0\xa0\xa0\xa0— McLeod {3}',
#  '(22) Devon HILL',
#  '(22) Barrett NUGENT',
#  '\xa0\xa0\xa0\xa0— Riley {2}',
#  '(22) Ronnie ASHJR',
#  '(22) Jabari GREERSO',
#  '\xa0\xa0\xa0\xa0— Bramlett {2}SR',
#  '\xa0\xa0\xa0\xa0— Bramlett {3}',
#  '\xa0\xa0\xa0\xa0— Bramlett {4}',
#  '\xa0\xa0\xa0\xa0— Trammell {3}JR',
#  '']

# %%
len(Names)
# Out:
# 74

# %%
len(Names)
# Out:
# 74

# %%
OfficialReGexNames = []

# %%
for i in range(0,73):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Grant HOLLOWAYJR',
#  '(2) Trey CUNNINGHAMSR',
#  '— Cunningham {2}SR',
#  '— Cunningham {3}SR',
#  '(3) Daniel ROBERTSJR',
#  '— Cunningham {4}SR',
#  '— Cunningham {5}SR',
#  '— Holloway {2}SO',
#  '— Holloway {3}JR',
#  '— Holloway {4}JR',
#  '— Holloway {5}JR',
#  '(4) Omar MCLEODSO',
#  '— Cunningham {6}SR',
#  '— Cunningham {7}SR',
#  '— Cunningham {8}SR',
#  '— Holloway {6}SO',
#  '(5) Reggie TORIAN',
#  '— Roberts {2}JR',
#  '— Holloway {7}JR',
#  '— Cunningham {9}SR',
#  '— Cunningham {10}SR',
#  '— Holloway {8}JR',
#  '— Holloway {9}JR',
#  '— Holloway {10}SO',
#  '— McLeod {2}SO',
#  '(6) Jarret EATON',
#  '— Torian {2}',
#  '(7) Cordell TINCHJR',
#  '— Cunningham {11}SR',
#  '(7) Eddie LOVETTJR',
#  '— Tinch {2}JR',
#  '(9) Damion THOMASSR',
#  '— Cunningham {12}JR',
#  '(9) Aries MERRITTJR',
#  '— Tinch {3}JR',
#  '(11) Caleb DEANJR',
#  '(11) Jamal  BRITTJR',
#  '— Cunningham {13}JR',
#  '— Roberts {3}JR',
#  '(11) Ron BRAMLETT',
#  '(11) Terrence TRAMMELLSO',
#  '(15) Omotade OJORASR',
#  '— Cunningham {14}SR',
#  '— Cunningham {15}SO',
#  '— Holloway {11}SO',
#  '(15) Myles HUNTER',
#  '— Lovett {2}JR',
#  '(15) Andrew RILEY',
#  '(15) Drew BRUNSONSR',
#  '(15) Jason RICHARDSONJR',
#  '— Trammell {2}',
#  '(20) Darius LUFFJR',
#  '— Cunningham {16}SR',
#  '(20) Phillip LEMONIOUSSO',
#  '— Lovett {3}',
#  '— Eaton {2}SR',
#  '— Eaton {3}',
#  '— Eaton {4}',
#  '(22) Giano ROBERTSSR',
#  '(22) Leonard MUSTARIFR',
#  '— Cunningham {17}SR',
#  '— Cunningham {18}SO',
#  '— Holloway {12}JR',
#  '— McLeod {3}',
#  '(22) Devon HILL',
#  '(22) Barrett NUGENT',
#  '— Riley {2}',
#  '(22) Ronnie ASHJR',
#  '(22) Jabari GREERSO',
#  '— Bramlett {2}SR',
#  '— Bramlett {3}',
#  '— Bramlett {4}',
#  '— Trammell {3}JR']

# %%
CleanedNames = []

for i in range(0,len(OfficialReGexNames)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Grant HOLLOWAYJR',
#  'Trey CUNNINGHAMSR',
#  'Cunningham {2}SR',
#  'Cunningham {3}SR',
#  'Daniel ROBERTSJR',
#  'Cunningham {4}SR',
#  'Cunningham {5}SR',
#  'Holloway {2}SO',
#  'Holloway {3}JR',
#  'Holloway {4}JR',
#  'Holloway {5}JR',
#  'Omar MCLEODSO',
#  'Cunningham {6}SR',
#  'Cunningham {7}SR',
#  'Cunningham {8}SR',
#  'Holloway {6}SO',
#  'Reggie TORIAN',
#  'Roberts {2}JR',
#  'Holloway {7}JR',
#  'Cunningham {9}SR',
#  'Cunningham {10}SR',
#  'Holloway {8}JR',
#  'Holloway {9}JR',
#  'Holloway {10}SO',
#  'McLeod {2}SO',
#  'Jarret EATON',
#  'Torian {2}',
#  'Cordell TINCHJR',
#  'Cunningham {11}SR',
#  'Eddie LOVETTJR',
#  'Tinch {2}JR',
#  'Damion THOMASSR',
#  'Cunningham {12}JR',
#  'Aries MERRITTJR',
#  'Tinch {3}JR',
#  ' Caleb DEANJR',
#  ' Jamal  BRITTJR',
#  'Cunningham {13}JR',
#  'Roberts {3}JR',
#  ' Ron BRAMLETT',
#  ' Terrence TRAMMELLSO',
#  ' Omotade OJORASR',
#  'Cunningham {14}SR',
#  'Cunningham {15}SO',
#  'Holloway {11}SO',
#  ' Myles HUNTER',
#  'Lovett {2}JR',
#  ' Andrew RILEY',
#  ' Drew BRUNSONSR',
#  ' Jason RICHARDSONJR',
#  'Trammell {2}',
#  ' Darius LUFFJR',
#  'Cunningham {16}SR',
#  ' Phillip LEMONIOUSSO',
#  'Lovett {3}',
#  'Eaton {2}SR',
#  'Eaton {3}',
#  'Eaton {4}',
#  ' Giano ROBERTSSR',
#  ' Leonard MUSTARIFR',
#  'Cunningham {17}SR',
#  'Cunningham {18}SO',
#  'Holloway {12}JR',
#  'McLeod {3}',
#  ' Devon HILL',
#  ' Barrett NUGENT',
#  'Riley {2}',
#  ' Ronnie ASHJR',
#  ' Jabari GREERSO',
#  'Bramlett {2}SR',
#  'Bramlett {3}',
#  'Bramlett {4}',
#  'Trammell {3}JR']

# %%
CleanedNames2 = []

for i in range(0,len(OfficialReGexNames)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Grant HOLLOWAYJR',
#  'Trey CUNNINGHAMSR',
#  'Cunningham {2}SR',
#  'Cunningham {3}SR',
#  'Daniel ROBERTSJR',
#  'Cunningham {4}SR',
#  'Cunningham {5}SR',
#  'Holloway {2}SO',
#  'Holloway {3}JR',
#  'Holloway {4}JR',
#  'Holloway {5}JR',
#  'Omar MCLEODSO',
#  'Cunningham {6}SR',
#  'Cunningham {7}SR',
#  'Cunningham {8}SR',
#  'Holloway {6}SO',
#  'Reggie TORIAN',
#  'Roberts {2}JR',
#  'Holloway {7}JR',
#  'Cunningham {9}SR',
#  'Cunningham {10}SR',
#  'Holloway {8}JR',
#  'Holloway {9}JR',
#  'Holloway {10}SO',
#  'McLeod {2}SO',
#  'Jarret EATON',
#  'Torian {2}',
#  'Cordell TINCHJR',
#  'Cunningham {11}SR',
#  'Eddie LOVETTJR',
#  'Tinch {2}JR',
#  'Damion THOMASSR',
#  'Cunningham {12}JR',
#  'Aries MERRITTJR',
#  'Tinch {3}JR',
#  'Caleb DEANJR',
#  'Jamal  BRITTJR',
#  'Cunningham {13}JR',
#  'Roberts {3}JR',
#  'Ron BRAMLETT',
#  'Terrence TRAMMELLSO',
#  'Omotade OJORASR',
#  'Cunningham {14}SR',
#  'Cunningham {15}SO',
#  'Holloway {11}SO',
#  'Myles HUNTER',
#  'Lovett {2}JR',
#  'Andrew RILEY',
#  'Drew BRUNSONSR',
#  'Jason RICHARDSONJR',
#  'Trammell {2}',
#  'Darius LUFFJR',
#  'Cunningham {16}SR',
#  'Phillip LEMONIOUSSO',
#  'Lovett {3}',
#  'Eaton {2}SR',
#  'Eaton {3}',
#  'Eaton {4}',
#  'Giano ROBERTSSR',
#  'Leonard MUSTARIFR',
#  'Cunningham {17}SR',
#  'Cunningham {18}SO',
#  'Holloway {12}JR',
#  'McLeod {3}',
#  'Devon HILL',
#  'Barrett NUGENT',
#  'Riley {2}',
#  'Ronnie ASHJR',
#  'Jabari GREERSO',
#  'Bramlett {2}SR',
#  'Bramlett {3}',
#  'Bramlett {4}',
#  'Trammell {3}JR']

# %%
OfficialTimesReGex = []

# %%
for i in range(0,73):
    OfficialTimesReGex.append(OfficialTimes[i][:4])
    
OfficialTimesReGex
# Out:
# ['7.35',
#  '7.38',
#  '7.40',
#  '7.40',
#  '7.41',
#  '7.42',
#  '7.42',
#  '7.42',
#  '7.43',
#  '7.44',
#  '7.44',
#  '7.45',
#  '7.46',
#  '7.46',
#  '7.47',
#  '7.47',
#  '7.47',
#  '7.48',
#  '7.48',
#  '7.49',
#  '7.49',
#  '7.49',
#  '7.49',
#  '7.49',
#  '7.49',
#  '7.49',
#  '7.49',
#  '7.50',
#  '7.50',
#  '7.50',
#  '7.51',
#  '7.51',
#  '7.51',
#  '7.51',
#  '7.52',
#  '7.52',
#  '7.52',
#  '7.52',
#  '7.52',
#  '7.52',
#  '7.52',
#  '7.53',
#  '7.53',
#  '7.53',
#  '7.53',
#  '7.53',
#  '7.53',
#  '7.53',
#  '7.53',
#  '7.53',
#  '7.53',
#  '7.54',
#  '7.54',
#  '7.54',
#  '7.54',
#  '7.54',
#  '7.54',
#  '7.54',
#  '7.55',
#  '7.55',
#  '7.55',
#  '7.55',
#  '7.55',
#  '7.55',
#  '7.55',
#  '7.55',
#  '7.55',
#  '7.55',
#  '7.55',
#  '7.55',
#  '7.55',
#  '7.55',
#  '7.55']

# %%
len(OfficialTimesReGex)
# Out:
# 73

# %%
len(OfficialReGexNames)
# Out:
# 73

# %%
Schools = []

for i in range(0,len(OfficialTimesReGex)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Florida',
#  'Florida State',
#  'Florida State',
#  'Florida State',
#  'Kentucky',
#  'Florida State',
#  'Florida State',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Arkansas',
#  'Florida State',
#  'Florida State',
#  'Florida State',
#  'Florida',
#  'Wisconsin',
#  'Kentucky',
#  'Florida',
#  'Florida State',
#  'Florida State',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Arkansas',
#  'Syracuse',
#  'Wisconsin',
#  'Pittsburg State',
#  'Florida State',
#  'Florida',
#  'Pittsburg State',
#  'LSU',
#  'Florida State',
#  'Tennessee',
#  'Pittsburg State',
#  'Texas Tech',
#  'Iowa',
#  'Florida State',
#  'Kentucky',
#  'Alabama',
#  'South Carolina',
#  'Southern California',
#  'Florida State',
#  'Florida State',
#  'Florida',
#  'Minnesota State',
#  'Florida',
#  'Illinois',
#  'Florida State',
#  'South Carolina',
#  'South Carolina',
#  'Nebraska',
#  'Florida State',
#  'Arkansas',
#  'Florida',
#  'Syracuse',
#  'Syracuse',
#  'Syracuse',
#  'Clemson',
#  'North Carolina A&T',
#  'Florida State',
#  'Florida State',
#  'Florida',
#  'Arkansas',
#  'Miami (Fla.)',
#  'LSU',
#  'Illinois',
#  'Oklahoma',
#  'Tennessee',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'South Carolina']

# %%
Men60mHurdlesDF = pd.DataFrame({'Names': CleanedNames2, 'Times': OfficialTimesReGex, 'Schools': Schools})
Men60mHurdlesDF.to_csv('Mens60mHurdles.csv', index=False)
