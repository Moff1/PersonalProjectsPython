# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc

# %%
Link100mWomen = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?gender=2&sport=2&div=20527&top=25&event=2"

# %%
page = requests.get(Link100mWomen)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6987308" target="_blank">(1) Sha'Carri RICHARDSON</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850634" target="_blank">10.75</a><a href="https://www.youtube.com/watch?v=5AtrRxp918I" target="_blank">📺</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6987308" target="_blank">(1) Sha'Carri RICHARDSON</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850634" target="_blank">10.75</a><a href="https://www.youtube.com/watch?v=5AtrRxp918I" target="_blank">📺</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(2) Dawn SOWELL</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;">10.78 <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Provo, Utah)"><span class="mark-date" style="width: 10%;text-align:right;">6/3/1989</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(2) Dawn SOWELL</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;">10.78 <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Provo, Utah)"><span class="mark-date" style="width: 10%;text-align:right;">6/3/1989</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7087489" target="_blank">(3) Julien ALFRED</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75162/4560508" target="_blank">10.81</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7087489" target="_blank">(3) Julien ALFRED</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75162/4560508" target="_blank">10.81</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81275/4936468" target="_blank">10.83</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West First-Rounds (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/27/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81275/4936468" target="_blank">10.83</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.7)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West First-Rounds (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/27/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/79703/4926680" target="_blank">10.84</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.2)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Norman, Okla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/12/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/79703/4926680" target="_blank">10.84</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.2)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Norman, Okla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/12/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5122093" target="_blank">(4) Aleia HOBBS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/47401" target="_blank">10.85</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.0)</span></td><td style="width: 10%;text-align:right;" title="SEC Relays (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;">4/29/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5122093" target="_blank">(4) Aleia HOBBS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/47401" target="_blank">10.85</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.0)</span></td><td style="width: 10%;text-align:right;" title="SEC Relays (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;">4/29/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7540568" target="_blank">(5) Melissa JEFFERSON</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Coastal Carolina" class="group-logo-inline" src="/images/logos/rankings-article/coastal-carolina.png" title="Coastal Carolina"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=320">Coastal Carolina</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75133/4557179" target="_blank">10.88</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.5)</span></td><td style="width: 10%;text-align:right;" title="Sun Belt Outdoor Championships (Lafayette, La.)"><span class="mark-date" style="width: 10%;text-align:right;">5/12/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7540568" target="_blank">(5) Melissa JEFFERSON</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Coastal Carolina" class="group-logo-inline" src="/images/logos/rankings-article/coastal-carolina.png" title="Coastal Carolina"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=320">Coastal Carolina</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75133/4557179" target="_blank">10.88</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.5)</span></td><td style="width: 10%;text-align:right;" title="Sun Belt Outdoor Championships (Lafayette, La.)"><span class="mark-date" style="width: 10%;text-align:right;">5/12/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6598713" target="_blank">(6) Twanisha TERRY</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70371/4272767" target="_blank">10.89</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West Preliminary (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/29/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6598713" target="_blank">(6) Twanisha TERRY</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70371/4272767" target="_blank">10.89</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West Preliminary (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/29/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Terry {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70371" target="_blank">10.89</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West Preliminary (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/27/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Terry {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70371" target="_blank">10.89</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West Preliminary (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/27/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567491" target="_blank">10.90</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567491" target="_blank">10.90</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.6)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6995396" target="_blank">(7) Abby STEINER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567491" target="_blank">10.90</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6995396" target="_blank">(7) Abby STEINER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567491" target="_blank">10.90</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Hobbs {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57099/3515259" target="_blank">10.90</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Tampa, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/25/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Hobbs {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57099/3515259" target="_blank">10.90</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Tampa, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/25/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Hobbs {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57114/3516369" target="_blank">10.91</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Hobbs {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57114/3516369" target="_blank">10.91</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Steiner {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74133/4482449" target="_blank">10.92</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.5)</span></td><td style="width: 10%;text-align:right;" title="Joe May Invitational (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;">4/9/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Steiner {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74133/4482449" target="_blank">10.92</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.5)</span></td><td style="width: 10%;text-align:right;" title="Joe May Invitational (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;">4/9/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6988927" target="_blank">(8) Cambrea STURGIS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="North Carolina A&amp;T" class="group-logo-inline" src="/images/logos/rankings-article/north-carolina-at.png" title="North Carolina A&amp;T"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1086">North Carolina A&amp;T</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390/4273610" target="_blank">10.92</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/29/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6988927" target="_blank">(8) Cambrea STURGIS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="North Carolina A&amp;T" class="group-logo-inline" src="/images/logos/rankings-article/north-carolina-at.png" title="North Carolina A&amp;T"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1086">North Carolina A&amp;T</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390/4273610" target="_blank">10.92</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/29/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Sturgis {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="North Carolina A&amp;T" class="group-logo-inline" src="/images/logos/rankings-article/north-carolina-at.png" title="North Carolina A&amp;T"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1086">North Carolina A&amp;T</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390" target="_blank">10.92</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/27/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Sturgis {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="North Carolina A&amp;T" class="group-logo-inline" src="/images/logos/rankings-article/north-carolina-at.png" title="North Carolina A&amp;T"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1086">North Carolina A&amp;T</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390" target="_blank">10.92</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/27/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Hobbs {4}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/56302/3508628" target="_blank">10.92</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.5)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Knoxville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Hobbs {4}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/56302/3508628" target="_blank">10.92</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.5)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Knoxville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3733719" target="_blank">(8) Jenna PRANDINI</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/38249" target="_blank">10.92</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="Mt. SAC Relays (Walnut, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">4/16/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3733719" target="_blank">(8) Jenna PRANDINI</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/38249" target="_blank">10.92</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="Mt. SAC Relays (Walnut, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">4/16/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729916" target="_blank">(10) Favour OFILI</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4557126" target="_blank">10.93</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.7)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729916" target="_blank">(10) Favour OFILI</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4557126" target="_blank">10.93</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.7)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Ofili {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74135/4536424" target="_blank">10.93</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.0)</span></td><td style="width: 10%;text-align:right;" title="LSU Invitational (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;">4/30/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Ofili {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74135/4536424" target="_blank">10.93</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.0)</span></td><td style="width: 10%;text-align:right;" title="LSU Invitational (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;">4/30/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Hobbs {5}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/56302/3508628" target="_blank">10.93</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.4)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Knoxville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">5/12/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Hobbs {5}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/56302/3508628" target="_blank">10.93</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.4)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Knoxville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">5/12/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Sowell {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;">10.93  </td><td style="width: 10%;text-align:right;" title="Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/7/1989</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Sowell {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;">10.93  </td><td style="width: 10%;text-align:right;" title="Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/7/1989</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {5}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/79226/4888959" target="_blank">10.95</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.8)</span></td><td style="width: 10%;text-align:right;" title="Texas Invitational (outdoor) (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/28/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {5}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/79226/4888959" target="_blank">10.95</a> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.8)</span></td><td style="width: 10%;text-align:right;" title="Texas Invitational (outdoor) (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/28/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7690425" target="_blank">(11) Kevona DAVIS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75162" target="_blank">10.95</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7690425" target="_blank">(11) Kevona DAVIS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75162" target="_blank">10.95</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr>,
# ...
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5122093" target="_blank">Aleia HOBBS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57132/3517320" target="_blank">10.89</a> <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.2)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/22/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5122093" target="_blank">Aleia HOBBS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57132/3517320" target="_blank">10.89</a> <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.2)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/22/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3733719" target="_blank">Jenna PRANDINI</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1180">Oregon</a></td><td style="width: 25%;">10.90 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.0)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/25/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3733719" target="_blank">Jenna PRANDINI</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1180">Oregon</a></td><td style="width: 25%;">10.90 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.0)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/25/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5104436" target="_blank">Ashley HENDERSON</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="San Diego State" class="group-logo-inline" src="/images/logos/rankings-article/san-diego-state.png" title="San Diego State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1354">San Diego State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57132/3517320" target="_blank">10.91</a> <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.0)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/21/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5104436" target="_blank">Ashley HENDERSON</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="San Diego State" class="group-logo-inline" src="/images/logos/rankings-article/san-diego-state.png" title="San Diego State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1354">San Diego State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57132/3517320" target="_blank">10.91</a> <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.0)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/21/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4672809" target="_blank">Morolake AKINOSUN</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">10.97</a> <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.1)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/3/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4672809" target="_blank">Morolake AKINOSUN</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">10.97</a> <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.1)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/3/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4672809" target="_blank">Morolake AKINOSUN</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;">10.97 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.2)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/26/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4672809" target="_blank">Morolake AKINOSUN</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;">10.97 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.2)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/26/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Alex ANDERSON</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;">10.98 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.4)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/27/2008</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Alex ANDERSON</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?gender=2&amp;sport=2&amp;team=1558">Texas</a></td><td style="width: 25%;">10.98 <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> <br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.4)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/27/2008</span></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ["(1) Sha'Carri RICHARDSONFRLSU10.75📺  (w: 1.6)6/8/2019",
#   "(1) Sha'Carri RICHARDSONFR",
#   '',
#   'LSU',
#   '10.75📺  (w: 1.6)',
#   '6/8/2019'],
#  [],
#  ["(1) Sha'Carri RICHARDSONFR", '', 'LSU', '10.75📺  (w: 1.6)', '6/8/2019'],
#  ['(2) Dawn SOWELLSRLSU10.78 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.0)6/3/1989',
#   '(2) Dawn SOWELLSR',
#   '',
#   'LSU',
#   '10.78 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.0)',
#   '6/3/1989'],
#  [],
#  ['(2) Dawn SOWELLSR',
#   '',
#   'LSU',
#   '10.78 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.0)',
#   '6/3/1989'],
#  ['(3) Julien ALFREDSOTexas10.81 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.7)5/14/2022',
#   '(3) Julien ALFREDSO',
#   '',
#   'Texas',
#   '10.81 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.7)',
#   '5/14/2022'],
#  [],
#  ['(3) Julien ALFREDSO',
#   '',
#   'Texas',
#   '10.81 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.7)',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}JRTexas10.83 qq = Performance occurred during a non-final round.  (w: 0.7)5/27/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {2}JR',
#   '',
#   'Texas',
#   '10.83 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}JR',
#   '',
#   'Texas',
#   '10.83 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}JRTexas10.84  (w: 0.2)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {3}JR',
#   '',
#   'Texas',
#   '10.84  (w: 0.2)',
#   '5/12/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}JR',
#   '',
#   'Texas',
#   '10.84  (w: 0.2)',
#   '5/12/2023'],
#  ['(4) Aleia HOBBSJRLSU10.85  (w: 2.0)4/29/2017',
#   '(4) Aleia HOBBSJR',
#   '',
#   'LSU',
#   '10.85  (w: 2.0)',
#   '4/29/2017'],
#  [],
#  ['(4) Aleia HOBBSJR', '', 'LSU', '10.85  (w: 2.0)', '4/29/2017'],
#  ['(5) Melissa JEFFERSONSOCoastal Carolina10.88  (w: 1.5)5/12/2022',
#   '(5) Melissa JEFFERSONSO',
#   '',
#   'Coastal Carolina',
#   '10.88  (w: 1.5)',
#   '5/12/2022'],
#  [],
#  ['(5) Melissa JEFFERSONSO',
#   '',
#   'Coastal Carolina',
#   '10.88  (w: 1.5)',
#   '5/12/2022'],
#  ['(6) Twanisha TERRYSRSouthern California10.89 qq = Performance occurred during a non-final round.  (w: 1.3)5/29/2021',
#   '(6) Twanisha TERRYSR',
#   '',
#   'Southern California',
#   '10.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '5/29/2021'],
#  [],
#  ['(6) Twanisha TERRYSR',
#   '',
#   'Southern California',
#   '10.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Terry {2}SRSouthern California10.89 qq = Performance occurred during a non-final round.  (w: 1.3)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Terry {2}SR',
#   '',
#   'Southern California',
#   '10.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '5/27/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Terry {2}SR',
#   '',
#   'Southern California',
#   '10.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SOTexas10.90 qq = Performance occurred during a non-final round.  (w: 0.6)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Alfred {4}SO',
#   '',
#   'Texas',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SO',
#   '',
#   'Texas',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  ['(7) Abby STEINERJRKentucky10.90 qq = Performance occurred during a non-final round.  (w: 1.0)6/9/2022',
#   '(7) Abby STEINERJR',
#   '',
#   'Kentucky',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 1.0)',
#   '6/9/2022'],
#  [],
#  ['(7) Abby STEINERJR',
#   '',
#   'Kentucky',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 1.0)',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {2}SRLSU10.90 qq = Performance occurred during a non-final round.  (w: 1.9)5/25/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {2}SR',
#   '',
#   'LSU',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/25/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Hobbs {2}SR',
#   '',
#   'LSU',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {3}SRLSU10.91 qq = Performance occurred during a non-final round.  (w: 0.0)6/7/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {3}SR',
#   '',
#   'LSU',
#   '10.91 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/7/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Hobbs {3}SR',
#   '',
#   'LSU',
#   '10.91 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JRKentucky10.92  (w: 0.5)4/9/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '10.92  (w: 0.5)',
#   '4/9/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '10.92  (w: 0.5)',
#   '4/9/2022'],
#  ['(8) Cambrea STURGISSONorth Carolina A&T10.92 qq = Performance occurred during a non-final round.  (w: 1.4)5/29/2021',
#   '(8) Cambrea STURGISSO',
#   '',
#   'North Carolina A&T',
#   '10.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/29/2021'],
#  [],
#  ['(8) Cambrea STURGISSO',
#   '',
#   'North Carolina A&T',
#   '10.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Sturgis {2}SONorth Carolina A&T10.92 qq = Performance occurred during a non-final round.  (w: 1.4)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Sturgis {2}SO',
#   '',
#   'North Carolina A&T',
#   '10.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/27/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Sturgis {2}SO',
#   '',
#   'North Carolina A&T',
#   '10.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {4}SRLSU10.92  (w: 1.5)5/13/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {4}SR',
#   '',
#   'LSU',
#   '10.92  (w: 1.5)',
#   '5/13/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Hobbs {4}SR', '', 'LSU', '10.92  (w: 1.5)', '5/13/2018'],
#  ['(8) Jenna PRANDINIJROregon10.92  (w: 1.4)4/16/2015',
#   '(8) Jenna PRANDINIJR',
#   '',
#   'Oregon',
#   '10.92  (w: 1.4)',
#   '4/16/2015'],
#  [],
#  ['(8) Jenna PRANDINIJR', '', 'Oregon', '10.92  (w: 1.4)', '4/16/2015'],
#  ['(10) Favour OFILISOLSU10.93  (w: -0.7)5/14/2022',
#   '(10) Favour OFILISO',
#   '',
#   'LSU',
#   '10.93  (w: -0.7)',
#   '5/14/2022'],
#  [],
#  ['(10) Favour OFILISO', '', 'LSU', '10.93  (w: -0.7)', '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}SOLSU10.93  (w: 2.0)4/30/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {2}SO',
#   '',
#   'LSU',
#   '10.93  (w: 2.0)',
#   '4/30/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}SO', '', 'LSU', '10.93  (w: 2.0)', '4/30/2022'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {5}SRLSU10.93 qq = Performance occurred during a non-final round.  (w: 0.4)5/12/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {5}SR',
#   '',
#   'LSU',
#   '10.93 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '5/12/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Hobbs {5}SR',
#   '',
#   'LSU',
#   '10.93 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '5/12/2018'],
#  ['\xa0\xa0\xa0\xa0— Sowell {2}LSU10.93  4/7/1989',
#   '\xa0\xa0\xa0\xa0— Sowell {2}',
#   '',
#   'LSU',
#   '10.93  ',
#   '4/7/1989'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Sowell {2}', '', 'LSU', '10.93  ', '4/7/1989'],
#  ['\xa0\xa0\xa0\xa0— Alfred {5}JRTexas10.95  (w: 1.8)4/28/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {5}JR',
#   '',
#   'Texas',
#   '10.95  (w: 1.8)',
#   '4/28/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {5}JR',
#   '',
#   'Texas',
#   '10.95  (w: 1.8)',
#   '4/28/2023'],
#  ['(11) Kevona DAVISSOTexas10.95 qq = Performance occurred during a non-final round.  (w: 0.9)5/14/2022',
#   '(11) Kevona DAVISSO',
#   '',
#   'Texas',
#   '10.95 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '5/14/2022'],
#  [],
#  ['(11) Kevona DAVISSO',
#   '',
#   'Texas',
#   '10.95 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}SOTexas10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.9)5/13/2022',
#   '\xa0\xa0\xa0\xa0— Davis {2}SO',
#   '',
#   'Texas',
#   '10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.9)',
#   '5/13/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {2}SO',
#   '',
#   'Texas',
#   '10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.9)',
#   '5/13/2022'],
#  ['(11) Kayla WHITESRNorth Carolina A&T10.95  (w: 1.6)6/8/2019',
#   '(11) Kayla WHITESR',
#   '',
#   'North Carolina A&T',
#   '10.95  (w: 1.6)',
#   '6/8/2019'],
#  [],
#  ['(11) Kayla WHITESR',
#   '',
#   'North Carolina A&T',
#   '10.95  (w: 1.6)',
#   '6/8/2019'],
#  ['(11) Simone FACEYSRTexas A&M10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.8)5/18/2008',
#   '(11) Simone FACEYSR',
#   '',
#   'Texas A&M',
#   '10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.8)',
#   '5/18/2008'],
#  [],
#  ['(11) Simone FACEYSR',
#   '',
#   'Texas A&M',
#   '10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.8)',
#   '5/18/2008'],
#  ['(14) Jacious SEARSSRTennessee10.96  (w: 0.9)5/13/2023',
#   '(14) Jacious SEARSSR',
#   '',
#   'Tennessee',
#   '10.96  (w: 0.9)',
#   '5/13/2023'],
#  [],
#  ['(14) Jacious SEARSSR', '', 'Tennessee', '10.96  (w: 0.9)', '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}SOCoastal Carolina10.96 qq = Performance occurred during a non-final round.  (w: 0.6)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Jefferson {2}SO',
#   '',
#   'Coastal Carolina',
#   '10.96 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}SO',
#   '',
#   'Coastal Carolina',
#   '10.96 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  ['(14) Tamara CLARKJRAlabama10.96  (w: 0.7)4/23/2021',
#   '(14) Tamara CLARKJR',
#   '',
#   'Alabama',
#   '10.96  (w: 0.7)',
#   '4/23/2021'],
#  [],
#  ['(14) Tamara CLARKJR', '', 'Alabama', '10.96  (w: 0.7)', '4/23/2021'],
#  ['\xa0\xa0\xa0\xa0— White {2}SRNorth Carolina A&T10.96  (w: 1.5)5/4/2019',
#   '\xa0\xa0\xa0\xa0— White {2}SR',
#   '',
#   'North Carolina A&T',
#   '10.96  (w: 1.5)',
#   '5/4/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— White {2}SR',
#   '',
#   'North Carolina A&T',
#   '10.96  (w: 1.5)',
#   '5/4/2019'],
#  ['(14) Mikiah BRISCOJRLSU10.96  (w: 0.3)6/10/2017',
#   '(14) Mikiah BRISCOJR',
#   '',
#   'LSU',
#   '10.96  (w: 0.3)',
#   '6/10/2017'],
#  [],
#  ['(14) Mikiah BRISCOJR', '', 'LSU', '10.96  (w: 0.3)', '6/10/2017'],
#  ['(14) English GARDNERJROregon10.96  (w: 0.9)6/7/2013',
#   '(14) English GARDNERJR',
#   '',
#   'Oregon',
#   '10.96  (w: 0.9)',
#   '6/7/2013'],
#  [],
#  ['(14) English GARDNERJR', '', 'Oregon', '10.96  (w: 0.9)', '6/7/2013'],
#  ['(14) Kimberlyn DUNCANJRLSU10.96  (w: 1.9)5/13/2012',
#   '(14) Kimberlyn DUNCANJR',
#   '',
#   'LSU',
#   '10.96  (w: 1.9)',
#   '5/13/2012'],
#  [],
#  ['(14) Kimberlyn DUNCANJR', '', 'LSU', '10.96  (w: 1.9)', '5/13/2012'],
#  ['(19) Kemba NELSONSROregon10.97 qq = Performance occurred during a non-final round.  (w: 0.4)6/9/2022',
#   '(19) Kemba NELSONSR',
#   '',
#   'Oregon',
#   '10.97 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '6/9/2022'],
#  [],
#  ['(19) Kemba NELSONSR',
#   '',
#   'Oregon',
#   '10.97 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '6/9/2022'],
#  ['(19) Grace NWOKOCHAFRNorth Carolina A&T10.97 qq = Performance occurred during a non-final round.  (w: 0.6)6/9/2022',
#   '(19) Grace NWOKOCHAFR',
#   '',
#   'North Carolina A&T',
#   '10.97 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  [],
#  ['(19) Grace NWOKOCHAFR',
#   '',
#   'North Carolina A&T',
#   '10.97 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  ['(19) Lauryn WILLIAMSJRMiami (Fla.)10.97   (w: 1.0)6/11/2004',
#   '(19) Lauryn WILLIAMSJR',
#   '',
#   'Miami (Fla.)',
#   '10.97   (w: 1.0)',
#   '6/11/2004'],
#  [],
#  ['(19) Lauryn WILLIAMSJR',
#   '',
#   'Miami (Fla.)',
#   '10.97   (w: 1.0)',
#   '6/11/2004'],
#  ['(22) Ezinne ABBASRTexas10.98 qq = Performance occurred during a non-final round.  (w: 0.7)5/27/2023',
#   '(22) Ezinne ABBASR',
#   '',
#   'Texas',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2023'],
#  [],
#  ['(22) Ezinne ABBASR',
#   '',
#   'Texas',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {6}SOTexas10.98  (w: 1.7)4/13/2022',
#   '\xa0\xa0\xa0\xa0— Alfred {6}SO',
#   '',
#   'Texas',
#   '10.98  (w: 1.7)',
#   '4/13/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {6}SO',
#   '',
#   'Texas',
#   '10.98  (w: 1.7)',
#   '4/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Nelson {2}JROregon10.98 qq = Performance occurred during a non-final round.  (w: 0.1)5/29/2021',
#   '\xa0\xa0\xa0\xa0— Nelson {2}JR',
#   '',
#   'Oregon',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/29/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Nelson {2}JR',
#   '',
#   'Oregon',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Clark {2}JRAlabama10.98 qq = Performance occurred during a non-final round.  (w: 0.0)5/29/2021',
#   '\xa0\xa0\xa0\xa0— Clark {2}JR',
#   '',
#   'Alabama',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/29/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Clark {2}JR',
#   '',
#   'Alabama',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Nelson {3}JROregon10.98 qq = Performance occurred during a non-final round.  (w: 0.1)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Nelson {3}JR',
#   '',
#   'Oregon',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/27/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Nelson {3}JR',
#   '',
#   'Oregon',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Clark {3}JRAlabama10.98 qq = Performance occurred during a non-final round.  (w: 0.0)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Clark {3}JR',
#   '',
#   'Alabama',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/27/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Clark {3}JR',
#   '',
#   'Alabama',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Terry {3}SOSouthern California10.98  (w: 1.6)6/8/2019',
#   '\xa0\xa0\xa0\xa0— Terry {3}SO',
#   '',
#   'Southern California',
#   '10.98  (w: 1.6)',
#   '6/8/2019'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Terry {3}SO',
#   '',
#   'Southern California',
#   '10.98  (w: 1.6)',
#   '6/8/2019'],
#  ['(22) Shania COLLINSSRTennessee10.98 qq = Performance occurred during a non-final round.  (w: 1.5)6/7/2018',
#   '(22) Shania COLLINSSR',
#   '',
#   'Tennessee',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '6/7/2018'],
#  [],
#  ['(22) Shania COLLINSSR',
#   '',
#   'Tennessee',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {6}SRLSU10.98 qq = Performance occurred during a non-final round.  (w: 1.8)5/24/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {6}SR',
#   '',
#   'LSU',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.8)',
#   '5/24/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Hobbs {6}SR',
#   '',
#   'LSU',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.8)',
#   '5/24/2018'],
#  ['(22) Ashley HENDERSONJRSan Diego State10.98  (w: 0.3)4/28/2018',
#   '(22) Ashley HENDERSONJR',
#   '',
#   'San Diego State',
#   '10.98  (w: 0.3)',
#   '4/28/2018'],
#  [],
#  ['(22) Ashley HENDERSONJR',
#   '',
#   'San Diego State',
#   '10.98  (w: 0.3)',
#   '4/28/2018'],
#  ['(22) Debbie FERGUSONSRGeorgia10.98 qq = Performance occurred during a non-final round.  (w: 1.1)6/4/1999',
#   '(22) Debbie FERGUSONSR',
#   '',
#   'Georgia',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.1)',
#   '6/4/1999'],
#  [],
#  ['(22) Debbie FERGUSONSR',
#   '',
#   'Georgia',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.1)',
#   '6/4/1999'],
#  ['Additional All-Conditions Bests'],
#  ['Julien ALFREDJRTexas10.72 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)6/10/2023',
#   'Julien ALFREDJR',
#   '',
#   'Texas',
#   '10.72 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)',
#   '6/10/2023'],
#  [],
#  ['Julien ALFREDJR',
#   '',
#   'Texas',
#   '10.72 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)',
#   '6/10/2023'],
#  ['Julien ALFREDJRTexas10.72📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)4/14/2023',
#   'Julien ALFREDJR',
#   '',
#   'Texas',
#   '10.72📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '4/14/2023'],
#  [],
#  ['Julien ALFREDJR',
#   '',
#   'Texas',
#   '10.72📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '4/14/2023'],
#  ['Julien ALFREDJRTexas10.74 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.4)5/13/2023',
#   'Julien ALFREDJR',
#   '',
#   'Texas',
#   '10.74 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.4)',
#   '5/13/2023'],
#  [],
#  ['Julien ALFREDJR',
#   '',
#   'Texas',
#   '10.74 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.4)',
#   '5/13/2023'],
#  ['Cambrea STURGISSONorth Carolina A&T10.74 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)6/12/2021',
#   'Cambrea STURGISSO',
#   '',
#   'North Carolina A&T',
#   '10.74 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)',
#   '6/12/2021'],
#  [],
#  ['Cambrea STURGISSO',
#   '',
#   'North Carolina A&T',
#   '10.74 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)',
#   '6/12/2021'],
#  ['Twanisha TERRYSRSouthern California10.79 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)6/12/2021',
#   'Twanisha TERRYSR',
#   '',
#   'Southern California',
#   '10.79 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)',
#   '6/12/2021'],
#  [],
#  ['Twanisha TERRYSR',
#   '',
#   'Southern California',
#   '10.79 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)',
#   '6/12/2021'],
#  ['McKenzie LONGSROle Miss10.80 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)4/1/2023',
#   'McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '10.80 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)',
#   '4/1/2023'],
#  [],
#  ['McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '10.80 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)',
#   '4/1/2023'],
#  ['Julien ALFREDSOTexas10.80 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)5/28/2022',
#   'Julien ALFREDSO',
#   '',
#   'Texas',
#   '10.80 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '5/28/2022'],
#  [],
#  ['Julien ALFREDSO',
#   '',
#   'Texas',
#   '10.80 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '5/28/2022'],
#  ['Julien ALFREDSOTexas10.80 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)5/15/2022',
#   'Julien ALFREDSO',
#   '',
#   'Texas',
#   '10.80 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '5/15/2022'],
#  [],
#  ['Julien ALFREDSO',
#   '',
#   'Texas',
#   '10.80 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '5/15/2022'],
#  ['Rosemary CHUKWUMASOTexas Tech10.82 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)5/28/2022',
#   'Rosemary CHUKWUMASO',
#   '',
#   'Texas Tech',
#   '10.82 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)',
#   '5/28/2022'],
#  [],
#  ['Rosemary CHUKWUMASO',
#   '',
#   'Texas Tech',
#   '10.82 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)',
#   '5/28/2022'],
#  ['Celera BARNESSRSouthern California10.82 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)3/26/2022',
#   'Celera BARNESSR',
#   '',
#   'Southern California',
#   '10.82 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '3/26/2022'],
#  [],
#  ['Celera BARNESSR',
#   '',
#   'Southern California',
#   '10.82 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '3/26/2022'],
#  ['Kevona DAVISSOTexas10.83 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)5/13/2022',
#   'Kevona DAVISSO',
#   '',
#   'Texas',
#   '10.83 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '5/13/2022'],
#  [],
#  ['Kevona DAVISSO',
#   '',
#   'Texas',
#   '10.83 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '5/13/2022'],
#  ['Jada BAYLARKSRArkansas10.83 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)3/26/2022',
#   'Jada BAYLARKSR',
#   '',
#   'Arkansas',
#   '10.83 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '3/26/2022'],
#  [],
#  ['Jada BAYLARKSR',
#   '',
#   'Arkansas',
#   '10.83 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '3/26/2022'],
#  ['Rosemary CHUKWUMAJRTexas Tech10.85 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)4/14/2023',
#   'Rosemary CHUKWUMAJR',
#   '',
#   'Texas Tech',
#   '10.85 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '4/14/2023'],
#  [],
#  ['Rosemary CHUKWUMAJR',
#   '',
#   'Texas Tech',
#   '10.85 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '4/14/2023'],
#  ['Kemba NELSONSROregon10.85 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)5/28/2022',
#   'Kemba NELSONSR',
#   '',
#   'Oregon',
#   '10.85 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)',
#   '5/28/2022'],
#  [],
#  ['Kemba NELSONSR',
#   '',
#   'Oregon',
#   '10.85 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)',
#   '5/28/2022'],
#  ['Aleia HOBBSSRLSU10.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.7)3/28/2018',
#   'Aleia HOBBSSR',
#   '',
#   'LSU',
#   '10.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.7)',
#   '3/28/2018'],
#  [],
#  ['Aleia HOBBSSR',
#   '',
#   'LSU',
#   '10.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.7)',
#   '3/28/2018'],
#  ['Gail DEVERSSRUCLA10.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)6/4/1988',
#   'Gail DEVERSSR',
#   '',
#   'UCLA',
#   '10.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)',
#   '6/4/1988'],
#  [],
#  ['Gail DEVERSSR',
#   '',
#   'UCLA',
#   '10.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)',
#   '6/4/1988'],
#  ['Kennedy BLACKMONSROklahoma10.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)6/10/2023',
#   'Kennedy BLACKMONSR',
#   '',
#   'Oklahoma',
#   '10.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)',
#   '6/10/2023'],
#  [],
#  ['Kennedy BLACKMONSR',
#   '',
#   'Oklahoma',
#   '10.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)',
#   '6/10/2023'],
#  ['Symone DARIUSSRNorth Carolina A&T10.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.3)6/4/2022',
#   'Symone DARIUSSR',
#   '',
#   'North Carolina A&T',
#   '10.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.3)',
#   '6/4/2022'],
#  [],
#  ['Symone DARIUSSR',
#   '',
#   'North Carolina A&T',
#   '10.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.3)',
#   '6/4/2022'],
#  ['Tamara CLARKJRAlabama10.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)5/13/2021',
#   'Tamara CLARKJR',
#   '',
#   'Alabama',
#   '10.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '5/13/2021'],
#  [],
#  ['Tamara CLARKJR',
#   '',
#   'Alabama',
#   '10.87 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '5/13/2021'],
#  ['Rosemary CHUKWUMASOTexas Tech10.88 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)5/13/2022',
#   'Rosemary CHUKWUMASO',
#   '',
#   'Texas Tech',
#   '10.88 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '5/13/2022'],
#  [],
#  ['Rosemary CHUKWUMASO',
#   '',
#   'Texas Tech',
#   '10.88 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '5/13/2022'],
#  ['Tamara CLARKJRAlabama10.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)6/12/2021',
#   'Tamara CLARKJR',
#   '',
#   'Alabama',
#   '10.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)',
#   '6/12/2021'],
#  [],
#  ['Tamara CLARKJR',
#   '',
#   'Alabama',
#   '10.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)',
#   '6/12/2021'],
#  ['Jasmine TODDSOOregon10.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.7)5/29/2015',
#   'Jasmine TODDSO',
#   '',
#   'Oregon',
#   '10.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.7)',
#   '5/29/2015'],
#  [],
#  ['Jasmine TODDSO',
#   '',
#   'Oregon',
#   '10.88 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.7)',
#   '5/29/2015'],
#  ['Celera BARNESSRSouthern California10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)5/28/2022',
#   'Celera BARNESSR',
#   '',
#   'Southern California',
#   '10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '5/28/2022'],
#  [],
#  ['Celera BARNESSR',
#   '',
#   'Southern California',
#   '10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '5/28/2022'],
#  ['Deajah STEVENSJROregon10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.9)5/27/2017',
#   'Deajah STEVENSJR',
#   '',
#   'Oregon',
#   '10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.9)',
#   '5/27/2017'],
#  [],
#  ['Deajah STEVENSJR',
#   '',
#   'Oregon',
#   '10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.9)',
#   '5/27/2017'],
#  ['Deajah STEVENSJROregon10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.9)5/26/2017',
#   'Deajah STEVENSJR',
#   '',
#   'Oregon',
#   '10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.9)',
#   '5/26/2017'],
#  [],
#  ['Deajah STEVENSJR',
#   '',
#   'Oregon',
#   '10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.9)',
#   '5/26/2017'],
#  ['Jasmine TODDSOOregon10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)5/28/2015',
#   'Jasmine TODDSO',
#   '',
#   'Oregon',
#   '10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)',
#   '5/28/2015'],
#  [],
#  ['Jasmine TODDSO',
#   '',
#   'Oregon',
#   '10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.0)',
#   '5/28/2015'],
#  ['Favour OFILISOLSU10.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)4/23/2022',
#   'Favour OFILISO',
#   '',
#   'LSU',
#   '10.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)',
#   '4/23/2022'],
#  [],
#  ['Favour OFILISO',
#   '',
#   'LSU',
#   '10.90 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.2)',
#   '4/23/2022'],
#  ['Kemba NELSONJROregon10.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)6/12/2021',
#   'Kemba NELSONJR',
#   '',
#   'Oregon',
#   '10.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)',
#   '6/12/2021'],
#  [],
#  ['Kemba NELSONJR',
#   '',
#   'Oregon',
#   '10.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.2)',
#   '6/12/2021'],
#  ['Chryste GAINESSRStanford10.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)6/5/1992',
#   'Chryste GAINESSR',
#   '',
#   'Stanford',
#   '10.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)',
#   '6/5/1992'],
#  [],
#  ['Chryste GAINESSR',
#   '',
#   'Stanford',
#   '10.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)',
#   '6/5/1992'],
#  ['Chryste GAINESStanford10.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)5/9/1992',
#   'Chryste GAINES',
#   '',
#   'Stanford',
#   '10.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '5/9/1992'],
#  [],
#  ['Chryste GAINES',
#   '',
#   'Stanford',
#   '10.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.7)',
#   '5/9/1992'],
#  ['Kemba NELSONJROregon10.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)5/27/2021',
#   'Kemba NELSONJR',
#   '',
#   'Oregon',
#   '10.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)',
#   '5/27/2021'],
#  [],
#  ['Kemba NELSONJR',
#   '',
#   'Oregon',
#   '10.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.1)',
#   '5/27/2021'],
#  ["Sha'Carri RICHARDSONFRLSU10.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.3)3/30/2019",
#   "Sha'Carri RICHARDSONFR",
#   '',
#   'LSU',
#   '10.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.3)',
#   '3/30/2019'],
#  [],
#  ["Sha'Carri RICHARDSONFR",
#   '',
#   'LSU',
#   '10.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.3)',
#   '3/30/2019'],
#  ['Carlette GUIDRYSRTexas10.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.1)6/1/1991',
#   'Carlette GUIDRYSR',
#   '',
#   'Texas',
#   '10.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.1)',
#   '6/1/1991'],
#  [],
#  ['Carlette GUIDRYSR',
#   '',
#   'Texas',
#   '10.91 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 5.1)',
#   '6/1/1991'],
#  ['McKenzie LONGSROle Miss10.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)4/15/2023',
#   'McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '10.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '4/15/2023'],
#  [],
#  ['McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '10.92 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '4/15/2023'],
#  ['Talitha DIGGSJRFlorida10.92 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)4/1/2023',
#   'Talitha DIGGSJR',
#   '',
#   'Florida',
#   '10.92 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)',
#   '4/1/2023'],
#  [],
#  ['Talitha DIGGSJR',
#   '',
#   'Florida',
#   '10.92 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 4.1)',
#   '4/1/2023'],
#  ['Ezinne ABBASRTexas10.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.4)5/12/2023',
#   'Ezinne ABBASR',
#   '',
#   'Texas',
#   '10.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.4)',
#   '5/12/2023'],
#  [],
#  ['Ezinne ABBASR',
#   '',
#   'Texas',
#   '10.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.4)',
#   '5/12/2023'],
#  ['Kevona DAVISJRTexas10.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)4/14/2023',
#   'Kevona DAVISJR',
#   '',
#   'Texas',
#   '10.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '4/14/2023'],
#  [],
#  ['Kevona DAVISJR',
#   '',
#   'Texas',
#   '10.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '4/14/2023'],
#  ['Aleia HOBBSSRLSU10.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)3/31/2018',
#   'Aleia HOBBSSR',
#   '',
#   'LSU',
#   '10.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '3/31/2018'],
#  [],
#  ['Aleia HOBBSSR',
#   '',
#   'LSU',
#   '10.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '3/31/2018'],
#  ['Ginnie POWELLSouthern California10.93 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.1)5/27/2006',
#   'Ginnie POWELL',
#   '',
#   'Southern California',
#   '10.93 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.1)',
#   '5/27/2006'],
#  [],
#  ['Ginnie POWELL',
#   '',
#   'Southern California',
#   '10.93 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.1)',
#   '5/27/2006'],
#  ['Dawn SOWELLLSU10.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 5/27/1989',
#   'Dawn SOWELL',
#   '',
#   'LSU',
#   '10.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '5/27/1989'],
#  [],
#  ['Dawn SOWELL',
#   '',
#   'LSU',
#   '10.93 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '5/27/1989'],
#  ['Jacious SEARSSRTennessee10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)6/10/2023',
#   'Jacious SEARSSR',
#   '',
#   'Tennessee',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)',
#   '6/10/2023'],
#  [],
#  ['Jacious SEARSSR',
#   '',
#   'Tennessee',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)',
#   '6/10/2023'],
#  ['Rosemary CHUKWUMAJRTexas Tech10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)5/13/2023',
#   'Rosemary CHUKWUMAJR',
#   '',
#   'Texas Tech',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '5/13/2023'],
#  [],
#  ['Rosemary CHUKWUMAJR',
#   '',
#   'Texas Tech',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '5/13/2023'],
#  ['Kevona DAVISJRTexas10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)5/13/2023',
#   'Kevona DAVISJR',
#   '',
#   'Texas',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '5/13/2023'],
#  [],
#  ['Kevona DAVISJR',
#   '',
#   'Texas',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '5/13/2023'],
#  ['Rayniah JONESJRUCF10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)5/12/2023',
#   'Rayniah JONESJR',
#   '',
#   'UCF',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '5/12/2023'],
#  [],
#  ['Rayniah JONESJR',
#   '',
#   'UCF',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '5/12/2023'],
#  ['Kennedy BLACKMONSROklahoma10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)5/12/2023',
#   'Kennedy BLACKMONSR',
#   '',
#   'Oklahoma',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '5/12/2023'],
#  [],
#  ['Kennedy BLACKMONSR',
#   '',
#   'Oklahoma',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.2)',
#   '5/12/2023'],
#  ['Rosemary CHUKWUMASOTexas Tech10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)5/14/2022',
#   'Rosemary CHUKWUMASO',
#   '',
#   'Texas Tech',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)',
#   '5/14/2022'],
#  [],
#  ['Rosemary CHUKWUMASO',
#   '',
#   'Texas Tech',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.4)',
#   '5/14/2022'],
#  ['Destiny SMITH-BARNETTJRUNLV10.94 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)5/13/2017',
#   'Destiny SMITH-BARNETTJR',
#   '',
#   'UNLV',
#   '10.94 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)',
#   '5/13/2017'],
#  [],
#  ['Destiny SMITH-BARNETTJR',
#   '',
#   'UNLV',
#   '10.94 AA = Performance occurred at altitude (>1000 meters above sea level)ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)',
#   '5/13/2017'],
#  ['Morolake AKINOSUNJRTexas10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 3/28/2015',
#   'Morolake AKINOSUNJR',
#   '',
#   'Texas',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '3/28/2015'],
#  [],
#  ['Morolake AKINOSUNJR',
#   '',
#   'Texas',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '3/28/2015'],
#  ['Kimberlyn DUNCANJRLSU10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)3/28/2012',
#   'Kimberlyn DUNCANJR',
#   '',
#   'LSU',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)',
#   '3/28/2012'],
#  [],
#  ['Kimberlyn DUNCANJR',
#   '',
#   'LSU',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.0)',
#   '3/28/2012'],
#  ['Jeneba TARMOHTexas A&M10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 4/9/2011',
#   'Jeneba TARMOH',
#   '',
#   'Texas A&M',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/9/2011'],
#  [],
#  ['Jeneba TARMOH',
#   '',
#   'Texas A&M',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '4/9/2011'],
#  ['Lauryn WILLIAMSJRMiami (Fla.)10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.8)6/10/2004',
#   'Lauryn WILLIAMSJR',
#   '',
#   'Miami (Fla.)',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.8)',
#   '6/10/2004'],
#  [],
#  ['Lauryn WILLIAMSJR',
#   '',
#   'Miami (Fla.)',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.8)',
#   '6/10/2004'],
#  ['Debbie FERGUSONJRGeorgia10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)6/6/1998',
#   'Debbie FERGUSONJR',
#   '',
#   'Georgia',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)',
#   '6/6/1998'],
#  [],
#  ['Debbie FERGUSONJR',
#   '',
#   'Georgia',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 4.0)',
#   '6/6/1998'],
#  ['Chryste GAINESSRStanford10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)5/22/1992',
#   'Chryste GAINESSR',
#   '',
#   'Stanford',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '5/22/1992'],
#  [],
#  ['Chryste GAINESSR',
#   '',
#   'Stanford',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.1)',
#   '5/22/1992'],
#  ['Jackie WASHINGTONHouston10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 5/18/1986',
#   'Jackie WASHINGTON',
#   '',
#   'Houston',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '5/18/1986'],
#  [],
#  ['Jackie WASHINGTON',
#   '',
#   'Houston',
#   '10.94 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) ',
#   '5/18/1986'],
#  ['Kaila JACKSONFRGeorgia10.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)5/25/2023',
#   'Kaila JACKSONFR',
#   '',
#   'Georgia',
#   '10.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)',
#   '5/25/2023'],
#  [],
#  ['Kaila JACKSONFR',
#   '',
#   'Georgia',
#   '10.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.6)',
#   '5/25/2023'],
#  ['Ezinne ABBASRCalifornia10.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)5/28/2022',
#   'Ezinne ABBASR',
#   '',
#   'California',
#   '10.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '5/28/2022'],
#  [],
#  ['Ezinne ABBASR',
#   '',
#   'California',
#   '10.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.7)',
#   '5/28/2022'],
#  ['Ariana WASHINGTONFROregon10.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)6/11/2016',
#   'Ariana WASHINGTONFR',
#   '',
#   'Oregon',
#   '10.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '6/11/2016'],
#  [],
#  ['Ariana WASHINGTONFR',
#   '',
#   'Oregon',
#   '10.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '6/11/2016'],
#  ['Remona BURCHELLJRAlabama10.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)6/11/2014',
#   'Remona BURCHELLJR',
#   '',
#   'Alabama',
#   '10.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)',
#   '6/11/2014'],
#  [],
#  ['Remona BURCHELLJR',
#   '',
#   'Alabama',
#   '10.95 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.3)',
#   '6/11/2014'],
#  ['Kaila JACKSONFRGeorgia10.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)6/10/2023',
#   'Kaila JACKSONFR',
#   '',
#   'Georgia',
#   '10.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)',
#   '6/10/2023'],
#  [],
#  ['Kaila JACKSONFR',
#   '',
#   'Georgia',
#   '10.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.3)',
#   '6/10/2023'],
#  ['Talitha DIGGSJRFlorida10.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)4/14/2023',
#   'Talitha DIGGSJR',
#   '',
#   'Florida',
#   '10.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '4/14/2023'],
#  [],
#  ['Talitha DIGGSJR',
#   '',
#   'Florida',
#   '10.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.4)',
#   '4/14/2023'],
#  ['Twanisha TERRYFRSouthern California10.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)5/13/2018',
#   'Twanisha TERRYFR',
#   '',
#   'Southern California',
#   '10.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '5/13/2018'],
#  [],
#  ['Twanisha TERRYFR',
#   '',
#   'Southern California',
#   '10.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '5/13/2018'],
#  ['Ashley HENDERSONSOSan Diego State10.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)6/11/2016',
#   'Ashley HENDERSONSO',
#   '',
#   'San Diego State',
#   '10.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '6/11/2016'],
#  [],
#  ['Ashley HENDERSONSO',
#   '',
#   'San Diego State',
#   '10.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.6)',
#   '6/11/2016'],
#  ['Jenna PRANDINIOregon10.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.1)6/13/2015',
#   'Jenna PRANDINI',
#   '',
#   'Oregon',
#   '10.96 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.1)',
# ...
#  [],
#  ['Erin KINNEYJR',
#   '',
#   'South Dakota',
#   '10.98 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)  (w: 9.9)',
#   '4/8/2023'],
#  ['Anthaya CHARLTONFRKentucky10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)4/1/2023',
#   'Anthaya CHARLTONFR',
#   '',
#   'Kentucky',
#   '10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)',
#   '4/1/2023'],
#  [],
#  ['Anthaya CHARLTONFR',
#   '',
#   'Kentucky',
#   '10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)',
#   '4/1/2023'],
#  ['Kortnei JOHNSONJRLSU10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.7)3/31/2018',
#   'Kortnei JOHNSONJR',
#   '',
#   'LSU',
#   '10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.7)',
#   '3/31/2018'],
#  [],
#  ['Kortnei JOHNSONJR',
#   '',
#   'LSU',
#   '10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.7)',
#   '3/31/2018'],
#  ['Deanna HILLSRSouthern California10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)3/23/2018',
#   'Deanna HILLSR',
#   '',
#   'Southern California',
#   '10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)',
#   '3/23/2018'],
#  [],
#  ['Deanna HILLSR',
#   '',
#   'Southern California',
#   '10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 3.5)',
#   '3/23/2018'],
#  ['Blessing OKAGBAREUTEP10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)6/11/2010',
#   'Blessing OKAGBARE',
#   '',
#   'UTEP',
#   '10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '6/11/2010'],
#  [],
#  ['Blessing OKAGBARE',
#   '',
#   'UTEP',
#   '10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.8)',
#   '6/11/2010'],
#  ['Additional Out-of-Season Bests'],
#  ['Melissa JEFFERSONSOCoastal Carolina10.82 qq = Performance occurred during a non-final round.  (w: 0.5)6/24/2022',
#   'Melissa JEFFERSONSO',
#   '',
#   'Coastal Carolina',
#   '10.82 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/24/2022'],
#  [],
#  ['Melissa JEFFERSONSO',
#   '',
#   'Coastal Carolina',
#   '10.82 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/24/2022'],
#  ['English GARDNERJROregon10.85   (w: 1.8)6/23/2013',
#   'English GARDNERJR',
#   '',
#   'Oregon',
#   '10.85   (w: 1.8)',
#   '6/23/2013'],
#  [],
#  ['English GARDNERJR', '', 'Oregon', '10.85   (w: 1.8)', '6/23/2013'],
#  ['Octavious FREEMANSOUCF10.87   (w: 1.8)6/23/2013',
#   'Octavious FREEMANSO',
#   '',
#   'UCF',
#   '10.87   (w: 1.8)',
#   '6/23/2013'],
#  [],
#  ['Octavious FREEMANSO', '', 'UCF', '10.87   (w: 1.8)', '6/23/2013'],
#  ['Kemba NELSONSROregon10.88   (w: 0.9)6/24/2022',
#   'Kemba NELSONSR',
#   '',
#   'Oregon',
#   '10.88   (w: 0.9)',
#   '6/24/2022'],
#  [],
#  ['Kemba NELSONSR', '', 'Oregon', '10.88   (w: 0.9)', '6/24/2022'],
#  ['Julien ALFREDJRTexas10.89   (w: 0.7)7/18/2023',
#   'Julien ALFREDJR',
#   '',
#   'Texas',
#   '10.89   (w: 0.7)',
#   '7/18/2023'],
#  [],
#  ['Julien ALFREDJR', '', 'Texas', '10.89   (w: 0.7)', '7/18/2023'],
#  ['Octavious FREEMANUCF10.90 qq = Performance occurred during a non-final round.  (w: 1.7)6/20/2013',
#   'Octavious FREEMAN',
#   '',
#   'UCF',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '6/20/2013'],
#  [],
#  ['Octavious FREEMAN',
#   '',
#   'UCF',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '6/20/2013'],
#  ['Aleia HOBBSSRLSU10.91  (w: 0.6)6/22/2018',
#   'Aleia HOBBSSR',
#   '',
#   'LSU',
#   '10.91  (w: 0.6)',
#   '6/22/2018'],
#  [],
#  ['Aleia HOBBSSR', '', 'LSU', '10.91  (w: 0.6)', '6/22/2018'],
#  ['Melissa JEFFERSONSOCoastal Carolina10.92 qq = Performance occurred during a non-final round.  (w: -0.2)7/17/2022',
#   'Melissa JEFFERSONSO',
#   '',
#   'Coastal Carolina',
#   '10.92 qq = Performance occurred during a non-final round.  (w: -0.2)',
#   '7/17/2022'],
#  [],
#  ['Melissa JEFFERSONSO',
#   '',
#   'Coastal Carolina',
#   '10.92 qq = Performance occurred during a non-final round.  (w: -0.2)',
#   '7/17/2022'],
#  ['Jasmine TODDSOOregon10.92   (w: 1.2)6/26/2015',
#   'Jasmine TODDSO',
#   '',
#   'Oregon',
#   '10.92   (w: 1.2)',
#   '6/26/2015'],
#  [],
#  ['Jasmine TODDSO', '', 'Oregon', '10.92   (w: 1.2)', '6/26/2015'],
#  ['Jenna PRANDINIJROregon10.92 qq = Performance occurred during a non-final round.  (w: 1.5)6/26/2015',
#   'Jenna PRANDINIJR',
#   '',
#   'Oregon',
#   '10.92 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '6/26/2015'],
#  [],
#  ['Jenna PRANDINIJR',
#   '',
#   'Oregon',
#   '10.92 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '6/26/2015'],
#  ["D'Andre HILLLSU10.92   (w: 1.1)6/15/1996",
#   "D'Andre HILL",
#   '',
#   'LSU',
#   '10.92   (w: 1.1)',
#   '6/15/1996'],
#  [],
#  ["D'Andre HILL", '', 'LSU', '10.92   (w: 1.1)', '6/15/1996'],
#  ['Veronica CAMPBELLJRArkansas10.93 qq = Performance occurred during a non-final round.  (w: 0.1)8/21/2004',
#   'Veronica CAMPBELLJR',
#   '',
#   'Arkansas',
#   '10.93 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '8/21/2004'],
#  [],
#  ['Veronica CAMPBELLJR',
#   '',
#   'Arkansas',
#   '10.93 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '8/21/2004'],
#  ['Celera BARNESSRSouthern California10.94 qq = Performance occurred during a non-final round.  (w: 1.8)6/24/2022',
#   'Celera BARNESSR',
#   '',
#   'Southern California',
#   '10.94 qq = Performance occurred during a non-final round.  (w: 1.8)',
#   '6/24/2022'],
#  [],
#  ['Celera BARNESSR',
#   '',
#   'Southern California',
#   '10.94 qq = Performance occurred during a non-final round.  (w: 1.8)',
#   '6/24/2022'],
#  ['English GARDNERJROregon10.94 qq = Performance occurred during a non-final round.  (w: -0.5)8/11/2013',
#   'English GARDNERJR',
#   '',
#   'Oregon',
#   '10.94 qq = Performance occurred during a non-final round.  (w: -0.5)',
#   '8/11/2013'],
#  [],
#  ['English GARDNERJR',
#   '',
#   'Oregon',
#   '10.94 qq = Performance occurred during a non-final round.  (w: -0.5)',
#   '8/11/2013'],
#  ['Carlette GUIDRYSRTexas10.94   (w: 1.0)6/14/1991',
#   'Carlette GUIDRYSR',
#   '',
#   'Texas',
#   '10.94   (w: 1.0)',
#   '6/14/1991'],
#  [],
#  ['Carlette GUIDRYSR', '', 'Texas', '10.94   (w: 1.0)', '6/14/1991'],
#  ['Diane WILLIAMSCal State LA10.94 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.6)7/3/1983',
#   'Diane WILLIAMS',
#   '',
#   'Cal State LA',
#   '10.94 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.6)',
#   '7/3/1983'],
#  [],
#  ['Diane WILLIAMS',
#   '',
#   'Cal State LA',
#   '10.94 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.6)',
#   '7/3/1983'],
#  ['Morolake AKINOSUNSRTexas10.95  (w: 1.0)7/3/2016',
#   'Morolake AKINOSUNSR',
#   '',
#   'Texas',
#   '10.95  (w: 1.0)',
#   '7/3/2016'],
#  [],
#  ['Morolake AKINOSUNSR', '', 'Texas', '10.95  (w: 1.0)', '7/3/2016'],
#  ['Ashley HENDERSONJRSan Diego State10.96  (w: 0.6)6/22/2018',
#   'Ashley HENDERSONJR',
#   '',
#   'San Diego State',
#   '10.96  (w: 0.6)',
#   '6/22/2018'],
#  [],
#  ['Ashley HENDERSONJR', '', 'San Diego State', '10.96  (w: 0.6)', '6/22/2018'],
#  ['Jenna PRANDINIJROregon10.96   (w: 1.2)6/26/2015',
#   'Jenna PRANDINIJR',
#   '',
#   'Oregon',
#   '10.96   (w: 1.2)',
#   '6/26/2015'],
#  [],
#  ['Jenna PRANDINIJR', '', 'Oregon', '10.96   (w: 1.2)', '6/26/2015'],
#  ['Aurieyall SCOTTUCF10.96 qq = Performance occurred during a non-final round.  (w: 2.0)6/20/2013',
#   'Aurieyall SCOTT',
#   '',
#   'UCF',
#   '10.96 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '6/20/2013'],
#  [],
#  ['Aurieyall SCOTT',
#   '',
#   'UCF',
#   '10.96 qq = Performance occurred during a non-final round.  (w: 2.0)',
#   '6/20/2013'],
#  ['Lauryn WILLIAMSJRMiami (Fla.)10.96   (w: -0.1)8/21/2004',
#   'Lauryn WILLIAMSJR',
#   '',
#   'Miami (Fla.)',
#   '10.96   (w: -0.1)',
#   '8/21/2004'],
#  [],
#  ['Lauryn WILLIAMSJR', '', 'Miami (Fla.)', '10.96   (w: -0.1)', '8/21/2004'],
#  ['Aleia HOBBSSRLSU10.97 qq = Performance occurred during a non-final round.  (w: 1.7)6/21/2018',
#   'Aleia HOBBSSR',
#   '',
#   'LSU',
#   '10.97 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '6/21/2018'],
#  [],
#  ['Aleia HOBBSSR',
#   '',
#   'LSU',
#   '10.97 qq = Performance occurred during a non-final round.  (w: 1.7)',
#   '6/21/2018'],
#  ['English GARDNERJROregon10.97   (w: -0.3)8/12/2013',
#   'English GARDNERJR',
#   '',
#   'Oregon',
#   '10.97   (w: -0.3)',
#   '8/12/2013'],
#  [],
#  ['English GARDNERJR', '', 'Oregon', '10.97   (w: -0.3)', '8/12/2013'],
#  ['Veronica CAMPBELLJRArkansas10.97   (w: -0.1)8/21/2004',
#   'Veronica CAMPBELLJR',
#   '',
#   'Arkansas',
#   '10.97   (w: -0.1)',
#   '8/21/2004'],
#  [],
#  ['Veronica CAMPBELLJR', '', 'Arkansas', '10.97   (w: -0.1)', '8/21/2004'],
#  ['Debbie FERGUSONGeorgia10.97   (w: 1.1)8/5/1998',
#   'Debbie FERGUSON',
#   '',
#   'Georgia',
#   '10.97   (w: 1.1)',
#   '8/5/1998'],
#  [],
#  ['Debbie FERGUSON', '', 'Georgia', '10.97   (w: 1.1)', '8/5/1998'],
#  ["D'Andre HILLLSU10.97 qq = Performance occurred during a non-final round.  (w: 1.1)6/15/1996",
#   "D'Andre HILL",
#   '',
#   'LSU',
#   '10.97 qq = Performance occurred during a non-final round.  (w: 1.1)',
#   '6/15/1996'],
#  [],
#  ["D'Andre HILL",
#   '',
#   'LSU',
#   '10.97 qq = Performance occurred during a non-final round.  (w: 1.1)',
#   '6/15/1996'],
#  ['Gail DEVERSUCLA10.97   (w: 0.0)7/16/1988',
#   'Gail DEVERS',
#   '',
#   'UCLA',
#   '10.97   (w: 0.0)',
#   '7/16/1988'],
#  [],
#  ['Gail DEVERS', '', 'UCLA', '10.97   (w: 0.0)', '7/16/1988'],
#  ['Kemba NELSONSROregon10.98 qq = Performance occurred during a non-final round.  (w: 0.5)6/24/2022',
#   'Kemba NELSONSR',
#   '',
#   'Oregon',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/24/2022'],
#  [],
#  ['Kemba NELSONSR',
#   '',
#   'Oregon',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.5)',
#   '6/24/2022'],
#  ['Kemba NELSONSROregon10.98 qq = Performance occurred during a non-final round.  (w: 1.5)6/23/2022',
#   'Kemba NELSONSR',
#   '',
#   'Oregon',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '6/23/2022'],
#  [],
#  ['Kemba NELSONSR',
#   '',
#   'Oregon',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '6/23/2022'],
#  ['Additional Out-of-Season, All-Conditions Bests'],
#  ['Melissa JEFFERSONSOCoastal Carolina10.69 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)6/24/2022',
#   'Melissa JEFFERSONSO',
#   '',
#   'Coastal Carolina',
#   '10.69 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)',
#   '6/24/2022'],
#  [],
#  ['Melissa JEFFERSONSO',
#   '',
#   'Coastal Carolina',
#   '10.69 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)',
#   '6/24/2022'],
#  ['Celera BARNESSRSouthern California10.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)6/24/2022',
#   'Celera BARNESSR',
#   '',
#   'Southern California',
#   '10.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)',
#   '6/24/2022'],
#  [],
#  ['Celera BARNESSR',
#   '',
#   'Southern California',
#   '10.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)  (w: 2.9)',
#   '6/24/2022'],
#  ['Jasmine TODDSOOregon10.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)6/26/2015',
#   'Jasmine TODDSO',
#   '',
#   'Oregon',
#   '10.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '6/26/2015'],
#  [],
#  ['Jasmine TODDSO',
#   '',
#   'Oregon',
#   '10.86 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '6/26/2015'],
#  ['Jasmine TODDSOOregon10.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.5)6/25/2015',
#   'Jasmine TODDSO',
#   '',
#   'Oregon',
#   '10.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.5)',
#   '6/25/2015'],
#  [],
#  ['Jasmine TODDSO',
#   '',
#   'Oregon',
#   '10.87 WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round.  (w: 4.5)',
#   '6/25/2015'],
#  ['Aleia HOBBSSRLSU10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)6/22/2018',
#   'Aleia HOBBSSR',
#   '',
#   'LSU',
#   '10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '6/22/2018'],
#  [],
#  ['Aleia HOBBSSR',
#   '',
#   'LSU',
#   '10.89 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 2.2)',
#   '6/22/2018'],
#  ['Jenna PRANDINIJROregon10.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)6/25/2015',
#   'Jenna PRANDINIJR',
#   '',
#   'Oregon',
#   '10.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)',
#   '6/25/2015'],
#  [],
#  ['Jenna PRANDINIJR',
#   '',
#   'Oregon',
#   '10.90 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)',
#   '6/25/2015'],
#  ['Ashley HENDERSONJRSan Diego State10.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)6/21/2018',
#   'Ashley HENDERSONJR',
#   '',
#   'San Diego State',
#   '10.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)',
#   '6/21/2018'],
#  [],
#  ['Ashley HENDERSONJR',
#   '',
#   'San Diego State',
#   '10.91 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.0)',
#   '6/21/2018'],
#  ['Morolake AKINOSUNSRTexas10.97 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.1)7/3/2016',
#   'Morolake AKINOSUNSR',
#   '',
#   'Texas',
#   '10.97 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.1)',
#   '7/3/2016'],
#  [],
#  ['Morolake AKINOSUNSR',
#   '',
#   'Texas',
#   '10.97 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.1)',
#   '7/3/2016'],
#  ['Morolake AKINOSUNJRTexas10.97 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)6/26/2015',
#   'Morolake AKINOSUNJR',
#   '',
#   'Texas',
#   '10.97 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '6/26/2015'],
#  [],
#  ['Morolake AKINOSUNJR',
#   '',
#   'Texas',
#   '10.97 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.2)',
#   '6/26/2015'],
#  ['Alex ANDERSONJRTexas10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.4)6/27/2008',
#   'Alex ANDERSONJR',
#   '',
#   'Texas',
#   '10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.4)',
#   '6/27/2008'],
#  [],
#  ['Alex ANDERSONJR',
#   '',
#   'Texas',
#   '10.98 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round.  (w: 3.4)',
#   '6/27/2008'],
#  ['', '', '', '']]

# %%
rows[143]
# Out:
# ['(22) Debbie FERGUSONSRGeorgia10.98 qq = Performance occurred during a non-final round.  (w: 1.1)6/4/1999',
#  '(22) Debbie FERGUSONSR',
#  '',
#  'Georgia',
#  '10.98 qq = Performance occurred during a non-final round.  (w: 1.1)',
#  '6/4/1999']

# %%
len(rows)
# Out:
# 507

# %%
RealRows = []

# %%
for i in range(0,144):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [["(1) Sha'Carri RICHARDSONFRLSU10.75📺  (w: 1.6)6/8/2019",
#   "(1) Sha'Carri RICHARDSONFR",
#   '',
#   'LSU',
#   '10.75📺  (w: 1.6)',
#   '6/8/2019'],
#  ["(1) Sha'Carri RICHARDSONFR", '', 'LSU', '10.75📺  (w: 1.6)', '6/8/2019'],
#  ['(2) Dawn SOWELLSRLSU10.78 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.0)6/3/1989',
#   '(2) Dawn SOWELLSR',
#   '',
#   'LSU',
#   '10.78 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.0)',
#   '6/3/1989'],
#  ['(2) Dawn SOWELLSR',
#   '',
#   'LSU',
#   '10.78 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.0)',
#   '6/3/1989'],
#  ['(3) Julien ALFREDSOTexas10.81 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.7)5/14/2022',
#   '(3) Julien ALFREDSO',
#   '',
#   'Texas',
#   '10.81 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.7)',
#   '5/14/2022'],
#  ['(3) Julien ALFREDSO',
#   '',
#   'Texas',
#   '10.81 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.7)',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}JRTexas10.83 qq = Performance occurred during a non-final round.  (w: 0.7)5/27/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {2}JR',
#   '',
#   'Texas',
#   '10.83 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}JR',
#   '',
#   'Texas',
#   '10.83 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}JRTexas10.84  (w: 0.2)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {3}JR',
#   '',
#   'Texas',
#   '10.84  (w: 0.2)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}JR',
#   '',
#   'Texas',
#   '10.84  (w: 0.2)',
#   '5/12/2023'],
#  ['(4) Aleia HOBBSJRLSU10.85  (w: 2.0)4/29/2017',
#   '(4) Aleia HOBBSJR',
#   '',
#   'LSU',
#   '10.85  (w: 2.0)',
#   '4/29/2017'],
#  ['(4) Aleia HOBBSJR', '', 'LSU', '10.85  (w: 2.0)', '4/29/2017'],
#  ['(5) Melissa JEFFERSONSOCoastal Carolina10.88  (w: 1.5)5/12/2022',
#   '(5) Melissa JEFFERSONSO',
#   '',
#   'Coastal Carolina',
#   '10.88  (w: 1.5)',
#   '5/12/2022'],
#  ['(5) Melissa JEFFERSONSO',
#   '',
#   'Coastal Carolina',
#   '10.88  (w: 1.5)',
#   '5/12/2022'],
#  ['(6) Twanisha TERRYSRSouthern California10.89 qq = Performance occurred during a non-final round.  (w: 1.3)5/29/2021',
#   '(6) Twanisha TERRYSR',
#   '',
#   'Southern California',
#   '10.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '5/29/2021'],
#  ['(6) Twanisha TERRYSR',
#   '',
#   'Southern California',
#   '10.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Terry {2}SRSouthern California10.89 qq = Performance occurred during a non-final round.  (w: 1.3)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Terry {2}SR',
#   '',
#   'Southern California',
#   '10.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Terry {2}SR',
#   '',
#   'Southern California',
#   '10.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SOTexas10.90 qq = Performance occurred during a non-final round.  (w: 0.6)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Alfred {4}SO',
#   '',
#   'Texas',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SO',
#   '',
#   'Texas',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  ['(7) Abby STEINERJRKentucky10.90 qq = Performance occurred during a non-final round.  (w: 1.0)6/9/2022',
#   '(7) Abby STEINERJR',
#   '',
#   'Kentucky',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 1.0)',
#   '6/9/2022'],
#  ['(7) Abby STEINERJR',
#   '',
#   'Kentucky',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 1.0)',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {2}SRLSU10.90 qq = Performance occurred during a non-final round.  (w: 1.9)5/25/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {2}SR',
#   '',
#   'LSU',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {2}SR',
#   '',
#   'LSU',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {3}SRLSU10.91 qq = Performance occurred during a non-final round.  (w: 0.0)6/7/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {3}SR',
#   '',
#   'LSU',
#   '10.91 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {3}SR',
#   '',
#   'LSU',
#   '10.91 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JRKentucky10.92  (w: 0.5)4/9/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '10.92  (w: 0.5)',
#   '4/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '10.92  (w: 0.5)',
#   '4/9/2022'],
#  ['(8) Cambrea STURGISSONorth Carolina A&T10.92 qq = Performance occurred during a non-final round.  (w: 1.4)5/29/2021',
#   '(8) Cambrea STURGISSO',
#   '',
#   'North Carolina A&T',
#   '10.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/29/2021'],
#  ['(8) Cambrea STURGISSO',
#   '',
#   'North Carolina A&T',
#   '10.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Sturgis {2}SONorth Carolina A&T10.92 qq = Performance occurred during a non-final round.  (w: 1.4)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Sturgis {2}SO',
#   '',
#   'North Carolina A&T',
#   '10.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Sturgis {2}SO',
#   '',
#   'North Carolina A&T',
#   '10.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {4}SRLSU10.92  (w: 1.5)5/13/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {4}SR',
#   '',
#   'LSU',
#   '10.92  (w: 1.5)',
#   '5/13/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {4}SR', '', 'LSU', '10.92  (w: 1.5)', '5/13/2018'],
#  ['(8) Jenna PRANDINIJROregon10.92  (w: 1.4)4/16/2015',
#   '(8) Jenna PRANDINIJR',
#   '',
#   'Oregon',
#   '10.92  (w: 1.4)',
#   '4/16/2015'],
#  ['(8) Jenna PRANDINIJR', '', 'Oregon', '10.92  (w: 1.4)', '4/16/2015'],
#  ['(10) Favour OFILISOLSU10.93  (w: -0.7)5/14/2022',
#   '(10) Favour OFILISO',
#   '',
#   'LSU',
#   '10.93  (w: -0.7)',
#   '5/14/2022'],
#  ['(10) Favour OFILISO', '', 'LSU', '10.93  (w: -0.7)', '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}SOLSU10.93  (w: 2.0)4/30/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {2}SO',
#   '',
#   'LSU',
#   '10.93  (w: 2.0)',
#   '4/30/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}SO', '', 'LSU', '10.93  (w: 2.0)', '4/30/2022'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {5}SRLSU10.93 qq = Performance occurred during a non-final round.  (w: 0.4)5/12/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {5}SR',
#   '',
#   'LSU',
#   '10.93 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '5/12/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {5}SR',
#   '',
#   'LSU',
#   '10.93 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '5/12/2018'],
#  ['\xa0\xa0\xa0\xa0— Sowell {2}LSU10.93  4/7/1989',
#   '\xa0\xa0\xa0\xa0— Sowell {2}',
#   '',
#   'LSU',
#   '10.93  ',
#   '4/7/1989'],
#  ['\xa0\xa0\xa0\xa0— Sowell {2}', '', 'LSU', '10.93  ', '4/7/1989'],
#  ['\xa0\xa0\xa0\xa0— Alfred {5}JRTexas10.95  (w: 1.8)4/28/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {5}JR',
#   '',
#   'Texas',
#   '10.95  (w: 1.8)',
#   '4/28/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {5}JR',
#   '',
#   'Texas',
#   '10.95  (w: 1.8)',
#   '4/28/2023'],
#  ['(11) Kevona DAVISSOTexas10.95 qq = Performance occurred during a non-final round.  (w: 0.9)5/14/2022',
#   '(11) Kevona DAVISSO',
#   '',
#   'Texas',
#   '10.95 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '5/14/2022'],
#  ['(11) Kevona DAVISSO',
#   '',
#   'Texas',
#   '10.95 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}SOTexas10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.9)5/13/2022',
#   '\xa0\xa0\xa0\xa0— Davis {2}SO',
#   '',
#   'Texas',
#   '10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.9)',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}SO',
#   '',
#   'Texas',
#   '10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.9)',
#   '5/13/2022'],
#  ['(11) Kayla WHITESRNorth Carolina A&T10.95  (w: 1.6)6/8/2019',
#   '(11) Kayla WHITESR',
#   '',
#   'North Carolina A&T',
#   '10.95  (w: 1.6)',
#   '6/8/2019'],
#  ['(11) Kayla WHITESR',
#   '',
#   'North Carolina A&T',
#   '10.95  (w: 1.6)',
#   '6/8/2019'],
#  ['(11) Simone FACEYSRTexas A&M10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.8)5/18/2008',
#   '(11) Simone FACEYSR',
#   '',
#   'Texas A&M',
#   '10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.8)',
#   '5/18/2008'],
#  ['(11) Simone FACEYSR',
#   '',
#   'Texas A&M',
#   '10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.8)',
#   '5/18/2008'],
#  ['(14) Jacious SEARSSRTennessee10.96  (w: 0.9)5/13/2023',
#   '(14) Jacious SEARSSR',
#   '',
#   'Tennessee',
#   '10.96  (w: 0.9)',
#   '5/13/2023'],
#  ['(14) Jacious SEARSSR', '', 'Tennessee', '10.96  (w: 0.9)', '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}SOCoastal Carolina10.96 qq = Performance occurred during a non-final round.  (w: 0.6)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Jefferson {2}SO',
#   '',
#   'Coastal Carolina',
#   '10.96 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}SO',
#   '',
#   'Coastal Carolina',
#   '10.96 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  ['(14) Tamara CLARKJRAlabama10.96  (w: 0.7)4/23/2021',
#   '(14) Tamara CLARKJR',
#   '',
#   'Alabama',
#   '10.96  (w: 0.7)',
#   '4/23/2021'],
#  ['(14) Tamara CLARKJR', '', 'Alabama', '10.96  (w: 0.7)', '4/23/2021'],
#  ['\xa0\xa0\xa0\xa0— White {2}SRNorth Carolina A&T10.96  (w: 1.5)5/4/2019',
#   '\xa0\xa0\xa0\xa0— White {2}SR',
#   '',
#   'North Carolina A&T',
#   '10.96  (w: 1.5)',
#   '5/4/2019'],
#  ['\xa0\xa0\xa0\xa0— White {2}SR',
#   '',
#   'North Carolina A&T',
#   '10.96  (w: 1.5)',
#   '5/4/2019'],
#  ['(14) Mikiah BRISCOJRLSU10.96  (w: 0.3)6/10/2017',
#   '(14) Mikiah BRISCOJR',
#   '',
#   'LSU',
#   '10.96  (w: 0.3)',
#   '6/10/2017'],
#  ['(14) Mikiah BRISCOJR', '', 'LSU', '10.96  (w: 0.3)', '6/10/2017'],
#  ['(14) English GARDNERJROregon10.96  (w: 0.9)6/7/2013',
#   '(14) English GARDNERJR',
#   '',
#   'Oregon',
#   '10.96  (w: 0.9)',
#   '6/7/2013'],
#  ['(14) English GARDNERJR', '', 'Oregon', '10.96  (w: 0.9)', '6/7/2013'],
#  ['(14) Kimberlyn DUNCANJRLSU10.96  (w: 1.9)5/13/2012',
#   '(14) Kimberlyn DUNCANJR',
#   '',
#   'LSU',
#   '10.96  (w: 1.9)',
#   '5/13/2012'],
#  ['(14) Kimberlyn DUNCANJR', '', 'LSU', '10.96  (w: 1.9)', '5/13/2012'],
#  ['(19) Kemba NELSONSROregon10.97 qq = Performance occurred during a non-final round.  (w: 0.4)6/9/2022',
#   '(19) Kemba NELSONSR',
#   '',
#   'Oregon',
#   '10.97 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '6/9/2022'],
#  ['(19) Kemba NELSONSR',
#   '',
#   'Oregon',
#   '10.97 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '6/9/2022'],
#  ['(19) Grace NWOKOCHAFRNorth Carolina A&T10.97 qq = Performance occurred during a non-final round.  (w: 0.6)6/9/2022',
#   '(19) Grace NWOKOCHAFR',
#   '',
#   'North Carolina A&T',
#   '10.97 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  ['(19) Grace NWOKOCHAFR',
#   '',
#   'North Carolina A&T',
#   '10.97 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  ['(19) Lauryn WILLIAMSJRMiami (Fla.)10.97   (w: 1.0)6/11/2004',
#   '(19) Lauryn WILLIAMSJR',
#   '',
#   'Miami (Fla.)',
#   '10.97   (w: 1.0)',
#   '6/11/2004'],
#  ['(19) Lauryn WILLIAMSJR',
#   '',
#   'Miami (Fla.)',
#   '10.97   (w: 1.0)',
#   '6/11/2004'],
#  ['(22) Ezinne ABBASRTexas10.98 qq = Performance occurred during a non-final round.  (w: 0.7)5/27/2023',
#   '(22) Ezinne ABBASR',
#   '',
#   'Texas',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2023'],
#  ['(22) Ezinne ABBASR',
#   '',
#   'Texas',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {6}SOTexas10.98  (w: 1.7)4/13/2022',
#   '\xa0\xa0\xa0\xa0— Alfred {6}SO',
#   '',
#   'Texas',
#   '10.98  (w: 1.7)',
#   '4/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {6}SO',
#   '',
#   'Texas',
#   '10.98  (w: 1.7)',
#   '4/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Nelson {2}JROregon10.98 qq = Performance occurred during a non-final round.  (w: 0.1)5/29/2021',
#   '\xa0\xa0\xa0\xa0— Nelson {2}JR',
#   '',
#   'Oregon',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Nelson {2}JR',
#   '',
#   'Oregon',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Clark {2}JRAlabama10.98 qq = Performance occurred during a non-final round.  (w: 0.0)5/29/2021',
#   '\xa0\xa0\xa0\xa0— Clark {2}JR',
#   '',
#   'Alabama',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Clark {2}JR',
#   '',
#   'Alabama',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Nelson {3}JROregon10.98 qq = Performance occurred during a non-final round.  (w: 0.1)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Nelson {3}JR',
#   '',
#   'Oregon',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Nelson {3}JR',
#   '',
#   'Oregon',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Clark {3}JRAlabama10.98 qq = Performance occurred during a non-final round.  (w: 0.0)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Clark {3}JR',
#   '',
#   'Alabama',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Clark {3}JR',
#   '',
#   'Alabama',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Terry {3}SOSouthern California10.98  (w: 1.6)6/8/2019',
#   '\xa0\xa0\xa0\xa0— Terry {3}SO',
#   '',
#   'Southern California',
#   '10.98  (w: 1.6)',
#   '6/8/2019'],
#  ['\xa0\xa0\xa0\xa0— Terry {3}SO',
#   '',
#   'Southern California',
#   '10.98  (w: 1.6)',
#   '6/8/2019'],
#  ['(22) Shania COLLINSSRTennessee10.98 qq = Performance occurred during a non-final round.  (w: 1.5)6/7/2018',
#   '(22) Shania COLLINSSR',
#   '',
#   'Tennessee',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '6/7/2018'],
#  ['(22) Shania COLLINSSR',
#   '',
#   'Tennessee',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {6}SRLSU10.98 qq = Performance occurred during a non-final round.  (w: 1.8)5/24/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {6}SR',
#   '',
#   'LSU',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.8)',
#   '5/24/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {6}SR',
#   '',
#   'LSU',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.8)',
#   '5/24/2018'],
#  ['(22) Ashley HENDERSONJRSan Diego State10.98  (w: 0.3)4/28/2018',
#   '(22) Ashley HENDERSONJR',
#   '',
#   'San Diego State',
#   '10.98  (w: 0.3)',
#   '4/28/2018'],
#  ['(22) Ashley HENDERSONJR',
#   '',
#   'San Diego State',
#   '10.98  (w: 0.3)',
#   '4/28/2018'],
#  ['(22) Debbie FERGUSONSRGeorgia10.98 qq = Performance occurred during a non-final round.  (w: 1.1)6/4/1999',
#   '(22) Debbie FERGUSONSR',
#   '',
#   'Georgia',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.1)',
#   '6/4/1999']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [["(1) Sha'Carri RICHARDSONFRLSU10.75📺  (w: 1.6)6/8/2019",
#   "(1) Sha'Carri RICHARDSONFR",
#   '',
#   'LSU',
#   '10.75📺  (w: 1.6)',
#   '6/8/2019'],
#  ['(2) Dawn SOWELLSRLSU10.78 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.0)6/3/1989',
#   '(2) Dawn SOWELLSR',
#   '',
#   'LSU',
#   '10.78 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.0)',
#   '6/3/1989'],
#  ['(3) Julien ALFREDSOTexas10.81 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.7)5/14/2022',
#   '(3) Julien ALFREDSO',
#   '',
#   'Texas',
#   '10.81 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.7)',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}JRTexas10.83 qq = Performance occurred during a non-final round.  (w: 0.7)5/27/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {2}JR',
#   '',
#   'Texas',
#   '10.83 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}JRTexas10.84  (w: 0.2)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {3}JR',
#   '',
#   'Texas',
#   '10.84  (w: 0.2)',
#   '5/12/2023'],
#  ['(4) Aleia HOBBSJRLSU10.85  (w: 2.0)4/29/2017',
#   '(4) Aleia HOBBSJR',
#   '',
#   'LSU',
#   '10.85  (w: 2.0)',
#   '4/29/2017'],
#  ['(5) Melissa JEFFERSONSOCoastal Carolina10.88  (w: 1.5)5/12/2022',
#   '(5) Melissa JEFFERSONSO',
#   '',
#   'Coastal Carolina',
#   '10.88  (w: 1.5)',
#   '5/12/2022'],
#  ['(6) Twanisha TERRYSRSouthern California10.89 qq = Performance occurred during a non-final round.  (w: 1.3)5/29/2021',
#   '(6) Twanisha TERRYSR',
#   '',
#   'Southern California',
#   '10.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Terry {2}SRSouthern California10.89 qq = Performance occurred during a non-final round.  (w: 1.3)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Terry {2}SR',
#   '',
#   'Southern California',
#   '10.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SOTexas10.90 qq = Performance occurred during a non-final round.  (w: 0.6)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Alfred {4}SO',
#   '',
#   'Texas',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  ['(7) Abby STEINERJRKentucky10.90 qq = Performance occurred during a non-final round.  (w: 1.0)6/9/2022',
#   '(7) Abby STEINERJR',
#   '',
#   'Kentucky',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 1.0)',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {2}SRLSU10.90 qq = Performance occurred during a non-final round.  (w: 1.9)5/25/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {2}SR',
#   '',
#   'LSU',
#   '10.90 qq = Performance occurred during a non-final round.  (w: 1.9)',
#   '5/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {3}SRLSU10.91 qq = Performance occurred during a non-final round.  (w: 0.0)6/7/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {3}SR',
#   '',
#   'LSU',
#   '10.91 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JRKentucky10.92  (w: 0.5)4/9/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '10.92  (w: 0.5)',
#   '4/9/2022'],
#  ['(8) Cambrea STURGISSONorth Carolina A&T10.92 qq = Performance occurred during a non-final round.  (w: 1.4)5/29/2021',
#   '(8) Cambrea STURGISSO',
#   '',
#   'North Carolina A&T',
#   '10.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Sturgis {2}SONorth Carolina A&T10.92 qq = Performance occurred during a non-final round.  (w: 1.4)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Sturgis {2}SO',
#   '',
#   'North Carolina A&T',
#   '10.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {4}SRLSU10.92  (w: 1.5)5/13/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {4}SR',
#   '',
#   'LSU',
#   '10.92  (w: 1.5)',
#   '5/13/2018'],
#  ['(8) Jenna PRANDINIJROregon10.92  (w: 1.4)4/16/2015',
#   '(8) Jenna PRANDINIJR',
#   '',
#   'Oregon',
#   '10.92  (w: 1.4)',
#   '4/16/2015'],
#  ['(10) Favour OFILISOLSU10.93  (w: -0.7)5/14/2022',
#   '(10) Favour OFILISO',
#   '',
#   'LSU',
#   '10.93  (w: -0.7)',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Ofili {2}SOLSU10.93  (w: 2.0)4/30/2022',
#   '\xa0\xa0\xa0\xa0— Ofili {2}SO',
#   '',
#   'LSU',
#   '10.93  (w: 2.0)',
#   '4/30/2022'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {5}SRLSU10.93 qq = Performance occurred during a non-final round.  (w: 0.4)5/12/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {5}SR',
#   '',
#   'LSU',
#   '10.93 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '5/12/2018'],
#  ['\xa0\xa0\xa0\xa0— Sowell {2}LSU10.93  4/7/1989',
#   '\xa0\xa0\xa0\xa0— Sowell {2}',
#   '',
#   'LSU',
#   '10.93  ',
#   '4/7/1989'],
#  ['\xa0\xa0\xa0\xa0— Alfred {5}JRTexas10.95  (w: 1.8)4/28/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {5}JR',
#   '',
#   'Texas',
#   '10.95  (w: 1.8)',
#   '4/28/2023'],
#  ['(11) Kevona DAVISSOTexas10.95 qq = Performance occurred during a non-final round.  (w: 0.9)5/14/2022',
#   '(11) Kevona DAVISSO',
#   '',
#   'Texas',
#   '10.95 qq = Performance occurred during a non-final round.  (w: 0.9)',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}SOTexas10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.9)5/13/2022',
#   '\xa0\xa0\xa0\xa0— Davis {2}SO',
#   '',
#   'Texas',
#   '10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.9)',
#   '5/13/2022'],
#  ['(11) Kayla WHITESRNorth Carolina A&T10.95  (w: 1.6)6/8/2019',
#   '(11) Kayla WHITESR',
#   '',
#   'North Carolina A&T',
#   '10.95  (w: 1.6)',
#   '6/8/2019'],
#  ['(11) Simone FACEYSRTexas A&M10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.8)5/18/2008',
#   '(11) Simone FACEYSR',
#   '',
#   'Texas A&M',
#   '10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.8)',
#   '5/18/2008'],
#  ['(14) Jacious SEARSSRTennessee10.96  (w: 0.9)5/13/2023',
#   '(14) Jacious SEARSSR',
#   '',
#   'Tennessee',
#   '10.96  (w: 0.9)',
#   '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}SOCoastal Carolina10.96 qq = Performance occurred during a non-final round.  (w: 0.6)6/9/2022',
#   '\xa0\xa0\xa0\xa0— Jefferson {2}SO',
#   '',
#   'Coastal Carolina',
#   '10.96 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  ['(14) Tamara CLARKJRAlabama10.96  (w: 0.7)4/23/2021',
#   '(14) Tamara CLARKJR',
#   '',
#   'Alabama',
#   '10.96  (w: 0.7)',
#   '4/23/2021'],
#  ['\xa0\xa0\xa0\xa0— White {2}SRNorth Carolina A&T10.96  (w: 1.5)5/4/2019',
#   '\xa0\xa0\xa0\xa0— White {2}SR',
#   '',
#   'North Carolina A&T',
#   '10.96  (w: 1.5)',
#   '5/4/2019'],
#  ['(14) Mikiah BRISCOJRLSU10.96  (w: 0.3)6/10/2017',
#   '(14) Mikiah BRISCOJR',
#   '',
#   'LSU',
#   '10.96  (w: 0.3)',
#   '6/10/2017'],
#  ['(14) English GARDNERJROregon10.96  (w: 0.9)6/7/2013',
#   '(14) English GARDNERJR',
#   '',
#   'Oregon',
#   '10.96  (w: 0.9)',
#   '6/7/2013'],
#  ['(14) Kimberlyn DUNCANJRLSU10.96  (w: 1.9)5/13/2012',
#   '(14) Kimberlyn DUNCANJR',
#   '',
#   'LSU',
#   '10.96  (w: 1.9)',
#   '5/13/2012'],
#  ['(19) Kemba NELSONSROregon10.97 qq = Performance occurred during a non-final round.  (w: 0.4)6/9/2022',
#   '(19) Kemba NELSONSR',
#   '',
#   'Oregon',
#   '10.97 qq = Performance occurred during a non-final round.  (w: 0.4)',
#   '6/9/2022'],
#  ['(19) Grace NWOKOCHAFRNorth Carolina A&T10.97 qq = Performance occurred during a non-final round.  (w: 0.6)6/9/2022',
#   '(19) Grace NWOKOCHAFR',
#   '',
#   'North Carolina A&T',
#   '10.97 qq = Performance occurred during a non-final round.  (w: 0.6)',
#   '6/9/2022'],
#  ['(19) Lauryn WILLIAMSJRMiami (Fla.)10.97   (w: 1.0)6/11/2004',
#   '(19) Lauryn WILLIAMSJR',
#   '',
#   'Miami (Fla.)',
#   '10.97   (w: 1.0)',
#   '6/11/2004'],
#  ['(22) Ezinne ABBASRTexas10.98 qq = Performance occurred during a non-final round.  (w: 0.7)5/27/2023',
#   '(22) Ezinne ABBASR',
#   '',
#   'Texas',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.7)',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {6}SOTexas10.98  (w: 1.7)4/13/2022',
#   '\xa0\xa0\xa0\xa0— Alfred {6}SO',
#   '',
#   'Texas',
#   '10.98  (w: 1.7)',
#   '4/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Nelson {2}JROregon10.98 qq = Performance occurred during a non-final round.  (w: 0.1)5/29/2021',
#   '\xa0\xa0\xa0\xa0— Nelson {2}JR',
#   '',
#   'Oregon',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Clark {2}JRAlabama10.98 qq = Performance occurred during a non-final round.  (w: 0.0)5/29/2021',
#   '\xa0\xa0\xa0\xa0— Clark {2}JR',
#   '',
#   'Alabama',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Nelson {3}JROregon10.98 qq = Performance occurred during a non-final round.  (w: 0.1)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Nelson {3}JR',
#   '',
#   'Oregon',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.1)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Clark {3}JRAlabama10.98 qq = Performance occurred during a non-final round.  (w: 0.0)5/27/2021',
#   '\xa0\xa0\xa0\xa0— Clark {3}JR',
#   '',
#   'Alabama',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 0.0)',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Terry {3}SOSouthern California10.98  (w: 1.6)6/8/2019',
#   '\xa0\xa0\xa0\xa0— Terry {3}SO',
#   '',
#   'Southern California',
#   '10.98  (w: 1.6)',
#   '6/8/2019'],
#  ['(22) Shania COLLINSSRTennessee10.98 qq = Performance occurred during a non-final round.  (w: 1.5)6/7/2018',
#   '(22) Shania COLLINSSR',
#   '',
#   'Tennessee',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.5)',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {6}SRLSU10.98 qq = Performance occurred during a non-final round.  (w: 1.8)5/24/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {6}SR',
#   '',
#   'LSU',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.8)',
#   '5/24/2018'],
#  ['(22) Ashley HENDERSONJRSan Diego State10.98  (w: 0.3)4/28/2018',
#   '(22) Ashley HENDERSONJR',
#   '',
#   'San Diego State',
#   '10.98  (w: 0.3)',
#   '4/28/2018'],
#  ['(22) Debbie FERGUSONSRGeorgia10.98 qq = Performance occurred during a non-final round.  (w: 1.1)6/4/1999',
#   '(22) Debbie FERGUSONSR',
#   '',
#   'Georgia',
#   '10.98 qq = Performance occurred during a non-final round.  (w: 1.1)',
#   '6/4/1999']]

# %%
RealRealRows[1][4]
# Out:
# '10.78 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.0)'

# %%
len(RealRealRows)
# Out:
# 48

# %%
OfficialTimes = []

# %%
for i in range(0,len(RealRealRows)):
    OfficialTimes.append(RealRealRows[i][4])
OfficialTimes
# Out:
# ['10.75📺  (w: 1.6)',
#  '10.78 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.0)',
#  '10.81 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.7)',
#  '10.83 qq = Performance occurred during a non-final round.  (w: 0.7)',
#  '10.84  (w: 0.2)',
#  '10.85  (w: 2.0)',
#  '10.88  (w: 1.5)',
#  '10.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#  '10.89 qq = Performance occurred during a non-final round.  (w: 1.3)',
#  '10.90 qq = Performance occurred during a non-final round.  (w: 0.6)',
#  '10.90 qq = Performance occurred during a non-final round.  (w: 1.0)',
#  '10.90 qq = Performance occurred during a non-final round.  (w: 1.9)',
#  '10.91 qq = Performance occurred during a non-final round.  (w: 0.0)',
#  '10.92  (w: 0.5)',
#  '10.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#  '10.92 qq = Performance occurred during a non-final round.  (w: 1.4)',
#  '10.92  (w: 1.5)',
#  '10.92  (w: 1.4)',
#  '10.93  (w: -0.7)',
#  '10.93  (w: 2.0)',
#  '10.93 qq = Performance occurred during a non-final round.  (w: 0.4)',
#  '10.93  ',
#  '10.95  (w: 1.8)',
#  '10.95 qq = Performance occurred during a non-final round.  (w: 0.9)',
#  '10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 0.9)',
#  '10.95  (w: 1.6)',
#  '10.95 AA = Performance occurred at altitude (>1000 meters above sea level)  (w: 1.8)',
#  '10.96  (w: 0.9)',
#  '10.96 qq = Performance occurred during a non-final round.  (w: 0.6)',
#  '10.96  (w: 0.7)',
#  '10.96  (w: 1.5)',
#  '10.96  (w: 0.3)',
#  '10.96  (w: 0.9)',
#  '10.96  (w: 1.9)',
#  '10.97 qq = Performance occurred during a non-final round.  (w: 0.4)',
#  '10.97 qq = Performance occurred during a non-final round.  (w: 0.6)',
#  '10.97   (w: 1.0)',
#  '10.98 qq = Performance occurred during a non-final round.  (w: 0.7)',
#  '10.98  (w: 1.7)',
#  '10.98 qq = Performance occurred during a non-final round.  (w: 0.1)',
#  '10.98 qq = Performance occurred during a non-final round.  (w: 0.0)',
#  '10.98 qq = Performance occurred during a non-final round.  (w: 0.1)',
#  '10.98 qq = Performance occurred during a non-final round.  (w: 0.0)',
#  '10.98  (w: 1.6)',
#  '10.98 qq = Performance occurred during a non-final round.  (w: 1.5)',
#  '10.98 qq = Performance occurred during a non-final round.  (w: 1.8)',
#  '10.98  (w: 0.3)',
#  '10.98 qq = Performance occurred during a non-final round.  (w: 1.1)']

# %%
RealRealRows[0][1]
# Out:
# "(1) Sha'Carri RICHARDSONFR"

# %%
Names = []

for i in range(0,48):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ["(1) Sha'Carri RICHARDSONFR",
#  '(2) Dawn SOWELLSR',
#  '(3) Julien ALFREDSO',
#  '\xa0\xa0\xa0\xa0— Alfred {2}JR',
#  '\xa0\xa0\xa0\xa0— Alfred {3}JR',
#  '(4) Aleia HOBBSJR',
#  '(5) Melissa JEFFERSONSO',
#  '(6) Twanisha TERRYSR',
#  '\xa0\xa0\xa0\xa0— Terry {2}SR',
#  '\xa0\xa0\xa0\xa0— Alfred {4}SO',
#  '(7) Abby STEINERJR',
#  '\xa0\xa0\xa0\xa0— Hobbs {2}SR',
#  '\xa0\xa0\xa0\xa0— Hobbs {3}SR',
#  '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#  '(8) Cambrea STURGISSO',
#  '\xa0\xa0\xa0\xa0— Sturgis {2}SO',
#  '\xa0\xa0\xa0\xa0— Hobbs {4}SR',
#  '(8) Jenna PRANDINIJR',
#  '(10) Favour OFILISO',
#  '\xa0\xa0\xa0\xa0— Ofili {2}SO',
#  '\xa0\xa0\xa0\xa0— Hobbs {5}SR',
#  '\xa0\xa0\xa0\xa0— Sowell {2}',
#  '\xa0\xa0\xa0\xa0— Alfred {5}JR',
#  '(11) Kevona DAVISSO',
#  '\xa0\xa0\xa0\xa0— Davis {2}SO',
#  '(11) Kayla WHITESR',
#  '(11) Simone FACEYSR',
#  '(14) Jacious SEARSSR',
#  '\xa0\xa0\xa0\xa0— Jefferson {2}SO',
#  '(14) Tamara CLARKJR',
#  '\xa0\xa0\xa0\xa0— White {2}SR',
#  '(14) Mikiah BRISCOJR',
#  '(14) English GARDNERJR',
#  '(14) Kimberlyn DUNCANJR',
#  '(19) Kemba NELSONSR',
#  '(19) Grace NWOKOCHAFR',
#  '(19) Lauryn WILLIAMSJR',
#  '(22) Ezinne ABBASR',
#  '\xa0\xa0\xa0\xa0— Alfred {6}SO',
#  '\xa0\xa0\xa0\xa0— Nelson {2}JR',
#  '\xa0\xa0\xa0\xa0— Clark {2}JR',
#  '\xa0\xa0\xa0\xa0— Nelson {3}JR',
#  '\xa0\xa0\xa0\xa0— Clark {3}JR',
#  '\xa0\xa0\xa0\xa0— Terry {3}SO',
#  '(22) Shania COLLINSSR',
#  '\xa0\xa0\xa0\xa0— Hobbs {6}SR',
#  '(22) Ashley HENDERSONJR',
#  '(22) Debbie FERGUSONSR']

# %%
OfficialReGexNames = []

# %%
for i in range(0,48):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ["(1) Sha'Carri RICHARDSONFR",
#  '(2) Dawn SOWELLSR',
#  '(3) Julien ALFREDSO',
#  '— Alfred {2}JR',
#  '— Alfred {3}JR',
#  '(4) Aleia HOBBSJR',
#  '(5) Melissa JEFFERSONSO',
#  '(6) Twanisha TERRYSR',
#  '— Terry {2}SR',
#  '— Alfred {4}SO',
#  '(7) Abby STEINERJR',
#  '— Hobbs {2}SR',
#  '— Hobbs {3}SR',
#  '— Steiner {2}JR',
#  '(8) Cambrea STURGISSO',
#  '— Sturgis {2}SO',
#  '— Hobbs {4}SR',
#  '(8) Jenna PRANDINIJR',
#  '(10) Favour OFILISO',
#  '— Ofili {2}SO',
#  '— Hobbs {5}SR',
#  '— Sowell {2}',
#  '— Alfred {5}JR',
#  '(11) Kevona DAVISSO',
#  '— Davis {2}SO',
#  '(11) Kayla WHITESR',
#  '(11) Simone FACEYSR',
#  '(14) Jacious SEARSSR',
#  '— Jefferson {2}SO',
#  '(14) Tamara CLARKJR',
#  '— White {2}SR',
#  '(14) Mikiah BRISCOJR',
#  '(14) English GARDNERJR',
#  '(14) Kimberlyn DUNCANJR',
#  '(19) Kemba NELSONSR',
#  '(19) Grace NWOKOCHAFR',
#  '(19) Lauryn WILLIAMSJR',
#  '(22) Ezinne ABBASR',
#  '— Alfred {6}SO',
#  '— Nelson {2}JR',
#  '— Clark {2}JR',
#  '— Nelson {3}JR',
#  '— Clark {3}JR',
#  '— Terry {3}SO',
#  '(22) Shania COLLINSSR',
#  '— Hobbs {6}SR',
#  '(22) Ashley HENDERSONJR',
#  '(22) Debbie FERGUSONSR']

# %%
CleanedNames = []

for i in range(0,len(OfficialReGexNames)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ["Sha'Carri RICHARDSONFR",
#  'Dawn SOWELLSR',
#  'Julien ALFREDSO',
#  'Alfred {2}JR',
#  'Alfred {3}JR',
#  'Aleia HOBBSJR',
#  'Melissa JEFFERSONSO',
#  'Twanisha TERRYSR',
#  'Terry {2}SR',
#  'Alfred {4}SO',
#  'Abby STEINERJR',
#  'Hobbs {2}SR',
#  'Hobbs {3}SR',
#  'Steiner {2}JR',
#  'Cambrea STURGISSO',
#  'Sturgis {2}SO',
#  'Hobbs {4}SR',
#  'Jenna PRANDINIJR',
#  ' Favour OFILISO',
#  'Ofili {2}SO',
#  'Hobbs {5}SR',
#  'Sowell {2}',
#  'Alfred {5}JR',
#  ' Kevona DAVISSO',
#  'Davis {2}SO',
#  ' Kayla WHITESR',
#  ' Simone FACEYSR',
#  ' Jacious SEARSSR',
#  'Jefferson {2}SO',
#  ' Tamara CLARKJR',
#  'White {2}SR',
#  ' Mikiah BRISCOJR',
#  ' English GARDNERJR',
#  ' Kimberlyn DUNCANJR',
#  ' Kemba NELSONSR',
#  ' Grace NWOKOCHAFR',
#  ' Lauryn WILLIAMSJR',
#  ' Ezinne ABBASR',
#  'Alfred {6}SO',
#  'Nelson {2}JR',
#  'Clark {2}JR',
#  'Nelson {3}JR',
#  'Clark {3}JR',
#  'Terry {3}SO',
#  ' Shania COLLINSSR',
#  'Hobbs {6}SR',
#  ' Ashley HENDERSONJR',
#  ' Debbie FERGUSONSR']

# %%
CleanedNames2 = []

for i in range(0,len(OfficialReGexNames)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ["Sha'Carri RICHARDSONFR",
#  'Dawn SOWELLSR',
#  'Julien ALFREDSO',
#  'Alfred {2}JR',
#  'Alfred {3}JR',
#  'Aleia HOBBSJR',
#  'Melissa JEFFERSONSO',
#  'Twanisha TERRYSR',
#  'Terry {2}SR',
#  'Alfred {4}SO',
#  'Abby STEINERJR',
#  'Hobbs {2}SR',
#  'Hobbs {3}SR',
#  'Steiner {2}JR',
#  'Cambrea STURGISSO',
#  'Sturgis {2}SO',
#  'Hobbs {4}SR',
#  'Jenna PRANDINIJR',
#  'Favour OFILISO',
#  'Ofili {2}SO',
#  'Hobbs {5}SR',
#  'Sowell {2}',
#  'Alfred {5}JR',
#  'Kevona DAVISSO',
#  'Davis {2}SO',
#  'Kayla WHITESR',
#  'Simone FACEYSR',
#  'Jacious SEARSSR',
#  'Jefferson {2}SO',
#  'Tamara CLARKJR',
#  'White {2}SR',
#  'Mikiah BRISCOJR',
#  'English GARDNERJR',
#  'Kimberlyn DUNCANJR',
#  'Kemba NELSONSR',
#  'Grace NWOKOCHAFR',
#  'Lauryn WILLIAMSJR',
#  'Ezinne ABBASR',
#  'Alfred {6}SO',
#  'Nelson {2}JR',
#  'Clark {2}JR',
#  'Nelson {3}JR',
#  'Clark {3}JR',
#  'Terry {3}SO',
#  'Shania COLLINSSR',
#  'Hobbs {6}SR',
#  'Ashley HENDERSONJR',
#  'Debbie FERGUSONSR']

# %%
len(OfficialTimes)
# Out:
# 48

# %%
len(OfficialReGexNames)
# Out:
# 48

# %%
RealRealRows[3][3]
# Out:
# 'Texas'

# %%
Schools = []

for i in range(0,len(OfficialReGexNames)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['LSU',
#  'LSU',
#  'Texas',
#  'Texas',
#  'Texas',
#  'LSU',
#  'Coastal Carolina',
#  'Southern California',
#  'Southern California',
#  'Texas',
#  'Kentucky',
#  'LSU',
#  'LSU',
#  'Kentucky',
#  'North Carolina A&T',
#  'North Carolina A&T',
#  'LSU',
#  'Oregon',
#  'LSU',
#  'LSU',
#  'LSU',
#  'LSU',
#  'Texas',
#  'Texas',
#  'Texas',
#  'North Carolina A&T',
#  'Texas A&M',
#  'Tennessee',
#  'Coastal Carolina',
#  'Alabama',
#  'North Carolina A&T',
#  'LSU',
#  'Oregon',
#  'LSU',
#  'Oregon',
#  'North Carolina A&T',
#  'Miami (Fla.)',
#  'Texas',
#  'Texas',
#  'Oregon',
#  'Alabama',
#  'Oregon',
#  'Alabama',
#  'Southern California',
#  'Tennessee',
#  'LSU',
#  'San Diego State',
#  'Georgia']

# %%
OfficialTimes[3][:5]
# Out:
# '10.83'

# %%
len(Schools)
# Out:
# 48

# %%
Times = []
for i in range(0,len(OfficialTimes)):
    Times.append(OfficialTimes[i][:5])
    
Times
# Out:
# ['10.75',
#  '10.78',
#  '10.81',
#  '10.83',
#  '10.84',
#  '10.85',
#  '10.88',
#  '10.89',
#  '10.89',
#  '10.90',
#  '10.90',
#  '10.90',
#  '10.91',
#  '10.92',
#  '10.92',
#  '10.92',
#  '10.92',
#  '10.92',
#  '10.93',
#  '10.93',
#  '10.93',
#  '10.93',
#  '10.95',
#  '10.95',
#  '10.95',
#  '10.95',
#  '10.95',
#  '10.96',
#  '10.96',
#  '10.96',
#  '10.96',
#  '10.96',
#  '10.96',
#  '10.96',
#  '10.97',
#  '10.97',
#  '10.97',
#  '10.98',
#  '10.98',
#  '10.98',
#  '10.98',
#  '10.98',
#  '10.98',
#  '10.98',
#  '10.98',
#  '10.98',
#  '10.98',
#  '10.98']

# %%
Womens100mDF = pd.DataFrame({'Names': CleanedNames2, 'Times': Times, 'Schools': Schools})
Womens100mDF.to_csv('Womens100m.csv', index=False)
