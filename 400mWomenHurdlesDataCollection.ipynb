# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc

# %%
Link400mHurdlesWomen = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?gender=2&sport=2&div=20527&top=25&event=16"

# %%
page = requests.get(Link400mHurdlesWomen)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6531200" target="_blank">(1) Sydney MCLAUGHLIN</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/56302/3508662" target="_blank">52.75</a><a href="https://www.youtube.com/watch?v=DRlu2cpfIMc" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Knoxville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6531200" target="_blank">(1) Sydney MCLAUGHLIN</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/56302/3508662" target="_blank">52.75</a><a href="https://www.youtube.com/watch?v=DRlu2cpfIMc" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Knoxville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3272889" target="_blank">(2) Kori CARTER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/31188" target="_blank">53.21</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3272889" target="_blank">(2) Kori CARTER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/31188" target="_blank">53.21</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2013</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7488009" target="_blank">(3) Britton WILSON</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78102/4824387" target="_blank">53.23</a><a href="https://twitter.com/RazorbackTF/status/1647070767979573248" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/14/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7488009" target="_blank">(3) Britton WILSON</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78102/4824387" target="_blank">53.23</a><a href="https://twitter.com/RazorbackTF/status/1647070767979573248" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/14/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4922034" target="_blank">53.28</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4922034" target="_blank">53.28</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4638024" target="_blank">(4) Shamier LITTLE</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46699/2884162" target="_blank">53.51</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4638024" target="_blank">(4) Shamier LITTLE</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46699/2884162" target="_blank">53.51</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(5) Sheena JOHNSON</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1617">UCLA</a></td><td style="width: 25%;">53.54  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/12/2004</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(5) Sheena JOHNSON</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1617">UCLA</a></td><td style="width: 25%;">53.54  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/12/2004</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — McLaughlin {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54177/3473057" target="_blank">53.60</a> </td><td style="width: 10%;text-align:right;" title="Arkansas National Relay Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">4/27/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — McLaughlin {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54177/3473057" target="_blank">53.60</a> </td><td style="width: 10%;text-align:right;" title="Arkansas National Relay Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">4/27/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81275/4936459" target="_blank">53.71</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West First-Rounds (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/27/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81275/4936459" target="_blank">53.71</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West First-Rounds (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/27/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2242979" target="_blank">(6) Georganne MOLINE</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona" class="group-logo-inline" src="/images/logos/rankings-article/arizona.png" title="Arizona"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=55">Arizona</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/31188" target="_blank">53.72</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2242979" target="_blank">(6) Georganne MOLINE</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona" class="group-logo-inline" src="/images/logos/rankings-article/arizona.png" title="Arizona"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=55">Arizona</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/31188" target="_blank">53.72</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2013</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Little {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41405/2568003" target="_blank">53.74</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/13/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Little {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41405/2568003" target="_blank">53.74</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/13/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4555617" target="_blank">53.75</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4555617" target="_blank">53.75</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {5}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4922034" target="_blank">53.76</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {5}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4922034" target="_blank">53.76</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {6}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567498" target="_blank">53.86</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {6}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567498" target="_blank">53.86</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — McLaughlin {3}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57114/3516374" target="_blank">53.96</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — McLaughlin {3}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57114/3516374" target="_blank">53.96</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {7}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81275/4936459" target="_blank">54.08</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West First-Rounds (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/25/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {7}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81275/4936459" target="_blank">54.08</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West First-Rounds (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/25/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4513700" target="_blank">(7) Keni HARRISON</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41405/2568003" target="_blank">54.09</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/13/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4513700" target="_blank">(7) Keni HARRISON</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41405/2568003" target="_blank">54.09</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/13/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — McLaughlin {4}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57114/3516374" target="_blank">54.15</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — McLaughlin {4}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57114/3516374" target="_blank">54.15</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Carter {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/31035" target="_blank">54.21</a> </td><td style="width: 10%;text-align:right;" title="Pac-12 Championships (Los Angeles, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">5/12/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Carter {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/31035" target="_blank">54.21</a> </td><td style="width: 10%;text-align:right;" title="Pac-12 Championships (Los Angeles, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">5/12/2013</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(8) Lashinda DEMUS</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="South Carolina" class="group-logo-inline" src="/images/logos/rankings-article/south-carolina.png" title="South Carolina"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1411">South Carolina</a></td><td style="width: 25%;">54.22  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/12/2004</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(8) Lashinda DEMUS</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="South Carolina" class="group-logo-inline" src="/images/logos/rankings-article/south-carolina.png" title="South Carolina"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1411">South Carolina</a></td><td style="width: 25%;">54.22  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/12/2004</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {8}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4555617" target="_blank">54.23</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {8}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4555617" target="_blank">54.23</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {9}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844" target="_blank">54.23</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/12/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {9}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844" target="_blank">54.23</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/12/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Johnson {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1617">UCLA</a></td><td style="width: 25%;">54.24  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/13/2003</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Johnson {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1617">UCLA</a></td><td style="width: 25%;">54.24  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/13/2003</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(9) Nicole LEACH</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1617">UCLA</a></td><td style="width: 25%;">54.32  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2007</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(9) Nicole LEACH</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1617">UCLA</a></td><td style="width: 25%;">54.32  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2007</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(9) Shauna SMITH</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Wyoming" class="group-logo-inline" src="/images/logos/rankings-article/wyoming.png" title="Wyoming"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1820">Wyoming</a></td><td style="width: 25%;">54.32  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2005</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(9) Shauna SMITH</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Wyoming" class="group-logo-inline" src="/images/logos/rankings-article/wyoming.png" title="Wyoming"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1820">Wyoming</a></td><td style="width: 25%;">54.32  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2005</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Johnson {3}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1617">UCLA</a></td><td style="width: 25%;">54.32  </td><td style="width: 10%;text-align:right;" title="NCAA DI West T&amp;F Regional (Northridge, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2004</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Johnson {3}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1617">UCLA</a></td><td style="width: 25%;">54.32  </td><td style="width: 10%;text-align:right;" title="NCAA DI West T&amp;F Regional (Northridge, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2004</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {10}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72503/4440620" target="_blank">54.37</a> </td><td style="width: 10%;text-align:right;" title="94th Clyde Littlefield Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/25/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {10}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72503/4440620" target="_blank">54.37</a> </td><td style="width: 10%;text-align:right;" title="94th Clyde Littlefield Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/25/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Smith {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Wyoming" class="group-logo-inline" src="/images/logos/rankings-article/wyoming.png" title="Wyoming"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1820">Wyoming</a></td><td style="width: 25%;">54.37  </td><td style="width: 10%;text-align:right;" title="NCAA DI West T&amp;F Regional (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">5/28/2005</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
# ...
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2242979" target="_blank">Georganne MOLINE</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona" class="group-logo-inline" src="/images/logos/rankings-article/arizona.png" title="Arizona"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=55">Arizona</a></td><td style="width: 25%;">54.31 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="Olympic Games (London, England)"><span class="mark-date" style="width: 10%;text-align:right;">8/5/2012</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Lashinda DEMUS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="South Carolina" class="group-logo-inline" src="/images/logos/rankings-article/south-carolina.png" title="South Carolina"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1411">South Carolina</a></td><td style="width: 25%;">54.32 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="Olympic Games (Athens, Greece)"><span class="mark-date" style="width: 10%;text-align:right;">8/22/2004</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Lashinda DEMUS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="South Carolina" class="group-logo-inline" src="/images/logos/rankings-article/south-carolina.png" title="South Carolina"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1411">South Carolina</a></td><td style="width: 25%;">54.32 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="Olympic Games (Athens, Greece)"><span class="mark-date" style="width: 10%;text-align:right;">8/22/2004</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2242979" target="_blank">Georganne MOLINE</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona" class="group-logo-inline" src="/images/logos/rankings-article/arizona.png" title="Arizona"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=55">Arizona</a></td><td style="width: 25%;">54.33  </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/1/2012</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2242979" target="_blank">Georganne MOLINE</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona" class="group-logo-inline" src="/images/logos/rankings-article/arizona.png" title="Arizona"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=55">Arizona</a></td><td style="width: 25%;">54.33  </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/1/2012</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Tonja BUFORD</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Illinois" class="group-logo-inline" src="/images/logos/rankings-article/illinois.png" title="Illinois"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=690">Illinois</a></td><td style="width: 25%;">54.38  </td><td style="width: 10%;text-align:right;" title="IAAF World Championships (Stuttgart, Germany)"><span class="mark-date" style="width: 10%;text-align:right;">8/17/1993</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Tonja BUFORD</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Illinois" class="group-logo-inline" src="/images/logos/rankings-article/illinois.png" title="Illinois"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=690">Illinois</a></td><td style="width: 25%;">54.38  </td><td style="width: 10%;text-align:right;" title="IAAF World Championships (Stuttgart, Germany)"><span class="mark-date" style="width: 10%;text-align:right;">8/17/1993</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7488009" target="_blank">Britton WILSON</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;">54.54 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="World Athletics Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/19/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7488009" target="_blank">Britton WILSON</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=59">Arkansas</a></td><td style="width: 25%;">54.54 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="World Athletics Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/19/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5612192" target="_blank">Sage WATSON</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona" class="group-logo-inline" src="/images/logos/rankings-article/arizona.png" title="Arizona"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=55">Arizona</a></td><td style="width: 25%;">54.59  </td><td style="width: 10%;text-align:right;" title="Meeting de Athletismo Madrid (Madrid, Spain)"><span class="mark-date" style="width: 10%;text-align:right;">7/14/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5612192" target="_blank">Sage WATSON</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona" class="group-logo-inline" src="/images/logos/rankings-article/arizona.png" title="Arizona"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=55">Arizona</a></td><td style="width: 25%;">54.59  </td><td style="width: 10%;text-align:right;" title="Meeting de Athletismo Madrid (Madrid, Spain)"><span class="mark-date" style="width: 10%;text-align:right;">7/14/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Queen CLAYE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia Tech" class="group-logo-inline" src="/images/logos/rankings-article/virginia-tech.png" title="Virginia Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1701">Virginia Tech</a></td><td style="width: 25%;">54.60  </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/29/2008</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Queen CLAYE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia Tech" class="group-logo-inline" src="/images/logos/rankings-article/virginia-tech.png" title="Virginia Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1701">Virginia Tech</a></td><td style="width: 25%;">54.60  </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/29/2008</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4180520" target="_blank">Autumne FRANKLIN</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Harvard" class="group-logo-inline" src="/images/logos/rankings-article/harvard.png" title="Harvard"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=635">Harvard</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">54.65</a> </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/10/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4180520" target="_blank">Autumne FRANKLIN</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Harvard" class="group-logo-inline" src="/images/logos/rankings-article/harvard.png" title="Harvard"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=635">Harvard</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">54.65</a> </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/10/2016</span></td></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">Not Considered For Lists</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Melaine WALKER</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1558">Texas</a></td><td style="width: 25%;">53.84  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2006</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Melaine WALKER</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=16&amp;team=1558">Texas</a></td><td style="width: 25%;">53.84  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2006</span></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Sydney MCLAUGHLINFRKentucky52.75📺 5/13/2018',
#   '(1) Sydney MCLAUGHLINFR',
#   '',
#   'Kentucky',
#   '52.75📺 ',
#   '5/13/2018'],
#  [],
#  ['(1) Sydney MCLAUGHLINFR', '', 'Kentucky', '52.75📺 ', '5/13/2018'],
#  ['(2) Kori CARTERJRStanford53.21 6/7/2013',
#   '(2) Kori CARTERJR',
#   '',
#   'Stanford',
#   '53.21 ',
#   '6/7/2013'],
#  [],
#  ['(2) Kori CARTERJR', '', 'Stanford', '53.21 ', '6/7/2013'],
#  ['(3) Britton WILSONJRArkansas53.23📺 4/14/2023',
#   '(3) Britton WILSONJR',
#   '',
#   'Arkansas',
#   '53.23📺 ',
#   '4/14/2023'],
#  [],
#  ['(3) Britton WILSONJR', '', 'Arkansas', '53.23📺 ', '4/14/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}JRArkansas53.28 5/13/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}JR',
#   '',
#   'Arkansas',
#   '53.28 ',
#   '5/13/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}JR', '', 'Arkansas', '53.28 ', '5/13/2023'],
#  ['(4) Shamier LITTLEJRTexas A&M53.51 6/11/2016',
#   '(4) Shamier LITTLEJR',
#   '',
#   'Texas A&M',
#   '53.51 ',
#   '6/11/2016'],
#  [],
#  ['(4) Shamier LITTLEJR', '', 'Texas A&M', '53.51 ', '6/11/2016'],
#  ['(5) Sheena JOHNSONSRUCLA53.54  6/12/2004',
#   '(5) Sheena JOHNSONSR',
#   '',
#   'UCLA',
#   '53.54  ',
#   '6/12/2004'],
#  [],
#  ['(5) Sheena JOHNSONSR', '', 'UCLA', '53.54  ', '6/12/2004'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {2}FRKentucky53.60 4/27/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {2}FR',
#   '',
#   'Kentucky',
#   '53.60 ',
#   '4/27/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {2}FR', '', 'Kentucky', '53.60 ', '4/27/2018'],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}JRArkansas53.71 qq = Performance occurred during a non-final round. 5/27/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {3}JR',
#   '',
#   'Arkansas',
#   '53.71 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}JR',
#   '',
#   'Arkansas',
#   '53.71 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['(6) Georganne MOLINESRArizona53.72 6/7/2013',
#   '(6) Georganne MOLINESR',
#   '',
#   'Arizona',
#   '53.72 ',
#   '6/7/2013'],
#  [],
#  ['(6) Georganne MOLINESR', '', 'Arizona', '53.72 ', '6/7/2013'],
#  ['\xa0\xa0\xa0\xa0— Little {2}Texas A&M53.74 6/13/2015',
#   '\xa0\xa0\xa0\xa0— Little {2}',
#   '',
#   'Texas A&M',
#   '53.74 ',
#   '6/13/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Little {2}', '', 'Texas A&M', '53.74 ', '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Wilson {4}SOArkansas53.75 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {4}SO',
#   '',
#   'Arkansas',
#   '53.75 ',
#   '5/14/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {4}SO', '', 'Arkansas', '53.75 ', '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {5}JRArkansas53.76 qq = Performance occurred during a non-final round. 5/11/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {5}JR',
#   '',
#   'Arkansas',
#   '53.76 qq = Performance occurred during a non-final round. ',
#   '5/11/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {5}JR',
#   '',
#   'Arkansas',
#   '53.76 qq = Performance occurred during a non-final round. ',
#   '5/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {6}SOArkansas53.86 6/11/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {6}SO',
#   '',
#   'Arkansas',
#   '53.86 ',
#   '6/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {6}SO', '', 'Arkansas', '53.86 ', '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {3}FRKentucky53.96 6/9/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {3}FR',
#   '',
#   'Kentucky',
#   '53.96 ',
#   '6/9/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {3}FR', '', 'Kentucky', '53.96 ', '6/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Wilson {7}JRArkansas54.08 qq = Performance occurred during a non-final round. 5/25/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {7}JR',
#   '',
#   'Arkansas',
#   '54.08 qq = Performance occurred during a non-final round. ',
#   '5/25/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {7}JR',
#   '',
#   'Arkansas',
#   '54.08 qq = Performance occurred during a non-final round. ',
#   '5/25/2023'],
#  ['(7) Keni HARRISONKentucky54.09 6/13/2015',
#   '(7) Keni HARRISON',
#   '',
#   'Kentucky',
#   '54.09 ',
#   '6/13/2015'],
#  [],
#  ['(7) Keni HARRISON', '', 'Kentucky', '54.09 ', '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {4}FRKentucky54.15 qq = Performance occurred during a non-final round. 6/7/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {4}FR',
#   '',
#   'Kentucky',
#   '54.15 qq = Performance occurred during a non-final round. ',
#   '6/7/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {4}FR',
#   '',
#   'Kentucky',
#   '54.15 qq = Performance occurred during a non-final round. ',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Carter {2}Stanford54.21 5/12/2013',
#   '\xa0\xa0\xa0\xa0— Carter {2}',
#   '',
#   'Stanford',
#   '54.21 ',
#   '5/12/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Carter {2}', '', 'Stanford', '54.21 ', '5/12/2013'],
#  ['(8) Lashinda DEMUSSOSouth Carolina54.22  6/12/2004',
#   '(8) Lashinda DEMUSSO',
#   '',
#   'South Carolina',
#   '54.22  ',
#   '6/12/2004'],
#  [],
#  ['(8) Lashinda DEMUSSO', '', 'South Carolina', '54.22  ', '6/12/2004'],
#  ['\xa0\xa0\xa0\xa0— Wilson {8}SOArkansas54.23 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {8}SO',
#   '',
#   'Arkansas',
#   '54.23 ',
#   '5/14/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {8}SO', '', 'Arkansas', '54.23 ', '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {9}SOArkansas54.23 qq = Performance occurred during a non-final round. 5/12/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {9}SO',
#   '',
#   'Arkansas',
#   '54.23 qq = Performance occurred during a non-final round. ',
#   '5/12/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {9}SO',
#   '',
#   'Arkansas',
#   '54.23 qq = Performance occurred during a non-final round. ',
#   '5/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Johnson {2}JRUCLA54.24  6/13/2003',
#   '\xa0\xa0\xa0\xa0— Johnson {2}JR',
#   '',
#   'UCLA',
#   '54.24  ',
#   '6/13/2003'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Johnson {2}JR', '', 'UCLA', '54.24  ', '6/13/2003'],
#  ['(9) Nicole LEACHSOUCLA54.32  6/9/2007',
#   '(9) Nicole LEACHSO',
#   '',
#   'UCLA',
#   '54.32  ',
#   '6/9/2007'],
#  [],
#  ['(9) Nicole LEACHSO', '', 'UCLA', '54.32  ', '6/9/2007'],
#  ['(9) Shauna SMITHSRWyoming54.32  6/11/2005',
#   '(9) Shauna SMITHSR',
#   '',
#   'Wyoming',
#   '54.32  ',
#   '6/11/2005'],
#  [],
#  ['(9) Shauna SMITHSR', '', 'Wyoming', '54.32  ', '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— Johnson {3}UCLA54.32  5/14/2004',
#   '\xa0\xa0\xa0\xa0— Johnson {3}',
#   '',
#   'UCLA',
#   '54.32  ',
#   '5/14/2004'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Johnson {3}', '', 'UCLA', '54.32  ', '5/14/2004'],
#  ['\xa0\xa0\xa0\xa0— Wilson {10}SOArkansas54.37 3/25/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {10}SO',
#   '',
#   'Arkansas',
#   '54.37 ',
#   '3/25/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {10}SO', '', 'Arkansas', '54.37 ', '3/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Smith {2}Wyoming54.37  5/28/2005',
#   '\xa0\xa0\xa0\xa0— Smith {2}',
#   '',
#   'Wyoming',
#   '54.37  ',
#   '5/28/2005'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Smith {2}', '', 'Wyoming', '54.37  ', '5/28/2005'],
#  ['(11) Savannah SUTHERLANDSOMichigan54.45 6/10/2023',
#   '(11) Savannah SUTHERLANDSO',
#   '',
#   'Michigan',
#   '54.45 ',
#   '6/10/2023'],
#  [],
#  ['(11) Savannah SUTHERLANDSO', '', 'Michigan', '54.45 ', '6/10/2023'],
#  ['(11) Nickiesha WILSONJRLSU54.45  6/13/2008',
#   '(11) Nickiesha WILSONJR',
#   '',
#   'LSU',
#   '54.45  ',
#   '6/13/2008'],
#  [],
#  ['(11) Nickiesha WILSONJR', '', 'LSU', '54.45  ', '6/13/2008'],
#  ['(13) Markita JAMESSRAuburn54.47  6/10/2006',
#   '(13) Markita JAMESSR',
#   '',
#   'Auburn',
#   '54.47  ',
#   '6/10/2006'],
#  [],
#  ['(13) Markita JAMESSR', '', 'Auburn', '54.47  ', '6/10/2006'],
#  ['(13) Shevon STODDARTSRSouth Carolina54.47  6/11/2005',
#   '(13) Shevon STODDARTSR',
#   '',
#   'South Carolina',
#   '54.47  ',
#   '6/11/2005'],
#  [],
#  ['(13) Shevon STODDARTSR', '', 'South Carolina', '54.47  ', '6/11/2005'],
#  ['(15) Anna HALLSOFlorida54.48 qq = Performance occurred during a non-final round. 6/9/2022',
#   '(15) Anna HALLSO',
#   '',
#   'Florida',
#   '54.48 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  [],
#  ['(15) Anna HALLSO',
#   '',
#   'Florida',
#   '54.48 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Carter {3}Stanford54.50 qq = Performance occurred during a non-final round. 5/25/2013',
#   '\xa0\xa0\xa0\xa0— Carter {3}',
#   '',
#   'Stanford',
#   '54.50 qq = Performance occurred during a non-final round. ',
#   '5/25/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Carter {3}',
#   '',
#   'Stanford',
#   '54.50 qq = Performance occurred during a non-final round. ',
#   '5/25/2013'],
#  ['\xa0\xa0\xa0\xa0— Demus {2}South Carolina54.50  2004',
#   '\xa0\xa0\xa0\xa0— Demus {2}',
#   '',
#   'South Carolina',
#   '54.50  ',
#   '2004'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Demus {2}', '', 'South Carolina', '54.50  ', '2004'],
#  ['(16) Sage WATSONSRArizona54.52 6/10/2017',
#   '(16) Sage WATSONSR',
#   '',
#   'Arizona',
#   '54.52 ',
#   '6/10/2017'],
#  [],
#  ['(16) Sage WATSONSR', '', 'Arizona', '54.52 ', '6/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Moline {2}Arizona54.54 5/12/2013',
#   '\xa0\xa0\xa0\xa0— Moline {2}',
#   '',
#   'Arizona',
#   '54.54 ',
#   '5/12/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moline {2}', '', 'Arizona', '54.54 ', '5/12/2013'],
#  ['(17) Ryan TOLBERTVanderbilt54.54  6/6/1997',
#   '(17) Ryan TOLBERT',
#   '',
#   'Vanderbilt',
#   '54.54  ',
#   '6/6/1997'],
#  [],
#  ['(17) Ryan TOLBERT', '', 'Vanderbilt', '54.54  ', '6/6/1997'],
#  ['(18) Queen CLAYESRVirginia Tech54.55  6/11/2010',
#   '(18) Queen CLAYESR',
#   '',
#   'Virginia Tech',
#   '54.55  ',
#   '6/11/2010'],
#  [],
#  ['(18) Queen CLAYESR', '', 'Virginia Tech', '54.55  ', '6/11/2010'],
#  ['(19) Tiffany ROSS-WILLIAMSJRSouth Carolina54.56  6/11/2005',
#   '(19) Tiffany ROSS-WILLIAMSJR',
#   '',
#   'South Carolina',
#   '54.56  ',
#   '6/11/2005'],
#  [],
#  ['(19) Tiffany ROSS-WILLIAMSJR',
#   '',
#   'South Carolina',
#   '54.56  ',
#   '6/11/2005'],
#  ['(19) Tonya WILLIAMSIllinois54.56  5/31/1996',
#   '(19) Tonya WILLIAMS',
#   '',
#   'Illinois',
#   '54.56  ',
#   '5/31/1996'],
#  [],
#  ['(19) Tonya WILLIAMS', '', 'Illinois', '54.56  ', '5/31/1996'],
#  ['\xa0\xa0\xa0\xa0— Moline {3}Arizona54.59 qq = Performance occurred during a non-final round. 5/25/2013',
#   '\xa0\xa0\xa0\xa0— Moline {3}',
#   '',
#   'Arizona',
#   '54.59 qq = Performance occurred during a non-final round. ',
#   '5/25/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moline {3}',
#   '',
#   'Arizona',
#   '54.59 qq = Performance occurred during a non-final round. ',
#   '5/25/2013'],
#  ['(21) Raasin MCINTOSHTexas54.60  4/5/2003',
#   '(21) Raasin MCINTOSH',
#   '',
#   'Texas',
#   '54.60  ',
#   '4/5/2003'],
#  [],
#  ['(21) Raasin MCINTOSH', '', 'Texas', '54.60  ', '4/5/2003'],
#  ['\xa0\xa0\xa0\xa0— Leach {2}JRUCLA54.62  6/13/2008',
#   '\xa0\xa0\xa0\xa0— Leach {2}JR',
#   '',
#   'UCLA',
#   '54.62  ',
#   '6/13/2008'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Leach {2}JR', '', 'UCLA', '54.62  ', '6/13/2008'],
#  ['\xa0\xa0\xa0\xa0— Wilson {11}SOArkansas54.65 3/25/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {11}SO',
#   '',
#   'Arkansas',
#   '54.65 ',
#   '3/25/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {11}SO', '', 'Arkansas', '54.65 ', '3/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {12}SOArkansas54.65 qq = Performance occurred during a non-final round. 3/24/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {12}SO',
#   '',
#   'Arkansas',
#   '54.65 qq = Performance occurred during a non-final round. ',
#   '3/24/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {12}SO',
#   '',
#   'Arkansas',
#   '54.65 qq = Performance occurred during a non-final round. ',
#   '3/24/2022'],
#  ['(22) Masai RUSSELLSRKentucky54.66 6/10/2023',
#   '(22) Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '54.66 ',
#   '6/10/2023'],
#  [],
#  ['(22) Masai RUSSELLSR', '', 'Kentucky', '54.66 ', '6/10/2023'],
#  ['(22) LaTanya SHEFFIELDJRSan Diego State54.66  5/31/1985',
#   '(22) LaTanya SHEFFIELDJR',
#   '',
#   'San Diego State',
#   '54.66  ',
#   '5/31/1985'],
#  [],
#  ['(22) LaTanya SHEFFIELDJR', '', 'San Diego State', '54.66  ', '5/31/1985'],
#  ['\xa0\xa0\xa0\xa0— Wilson {13}JRArkansas54.67 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {13}JR',
#   '',
#   'Arkansas',
#   '54.67 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {13}JR',
#   '',
#   'Arkansas',
#   '54.67 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(24) Kiah SEYMOURJRKentucky54.67 6/11/2016',
#   '(24) Kiah SEYMOURJR',
#   '',
#   'Kentucky',
#   '54.67 ',
#   '6/11/2016'],
#  [],
#  ['(24) Kiah SEYMOURJR', '', 'Kentucky', '54.67 ', '6/11/2016'],
#  ['\xa0\xa0\xa0\xa0— Carter {4}JRStanford54.67 qq = Performance occurred during a non-final round. 6/5/2013',
#   '\xa0\xa0\xa0\xa0— Carter {4}JR',
#   '',
#   'Stanford',
#   '54.67 qq = Performance occurred during a non-final round. ',
#   '6/5/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Carter {4}JR',
#   '',
#   'Stanford',
#   '54.67 qq = Performance occurred during a non-final round. ',
#   '6/5/2013'],
#  ['(25) Anna COCKRELLSRSouthern California54.68 6/12/2021',
#   '(25) Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '54.68 ',
#   '6/12/2021'],
#  [],
#  ['(25) Anna COCKRELLSR', '', 'Southern California', '54.68 ', '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Little {3}Texas A&M54.68 5/16/2015',
#   '\xa0\xa0\xa0\xa0— Little {3}',
#   '',
#   'Texas A&M',
#   '54.68 ',
#   '5/16/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Little {3}', '', 'Texas A&M', '54.68 ', '5/16/2015'],
#  ['Additional Out-of-Season Bests'],
#  ['Sheena JOHNSONUCLA52.95  7/11/2004',
#   'Sheena JOHNSON',
#   '',
#   'UCLA',
#   '52.95  ',
#   '7/11/2004'],
#  [],
#  ['Sheena JOHNSON', '', 'UCLA', '52.95  ', '7/11/2004'],
#  ['Britton WILSONSOArkansas53.08  6/25/2022',
#   'Britton WILSONSO',
#   '',
#   'Arkansas',
#   '53.08  ',
#   '6/25/2022'],
#  [],
#  ['Britton WILSONSO', '', 'Arkansas', '53.08  ', '6/25/2022'],
#  ['Lashinda DEMUSSouth Carolina53.43  7/11/2004',
#   'Lashinda DEMUS',
#   '',
#   'South Carolina',
#   '53.43  ',
#   '7/11/2004'],
#  [],
#  ['Lashinda DEMUS', '', 'South Carolina', '53.43  ', '7/11/2004'],
#  ['Janeene VICKERSUCLA53.47  8/29/1991',
#   'Janeene VICKERS',
#   '',
#   'UCLA',
#   '53.47  ',
#   '8/29/1991'],
#  [],
#  ['Janeene VICKERS', '', 'UCLA', '53.47  ', '8/29/1991'],
#  ['Anna COCKRELLSRSouthern California53.70 6/27/2021',
#   'Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '53.70 ',
#   '6/27/2021'],
#  [],
#  ['Anna COCKRELLSR', '', 'Southern California', '53.70 ', '6/27/2021'],
#  ['Britton WILSONSOArkansas53.72 qq = Performance occurred during a non-final round. 7/20/2022',
#   'Britton WILSONSO',
#   '',
#   'Arkansas',
#   '53.72 qq = Performance occurred during a non-final round. ',
#   '7/20/2022'],
#  [],
#  ['Britton WILSONSO',
#   '',
#   'Arkansas',
#   '53.72 qq = Performance occurred during a non-final round. ',
#   '7/20/2022'],
#  ['Shamier LITTLETexas A&M53.83  6/28/2015',
#   'Shamier LITTLE',
#   '',
#   'Texas A&M',
#   '53.83  ',
#   '6/28/2015'],
#  [],
#  ['Shamier LITTLE', '', 'Texas A&M', '53.83  ', '6/28/2015'],
#  ['Sheena JOHNSONUCLA53.83  8/25/2004',
#   'Sheena JOHNSON',
#   '',
#   'UCLA',
#   '53.83  ',
#   '8/25/2004'],
#  [],
#  ['Sheena JOHNSON', '', 'UCLA', '53.83  ', '8/25/2004'],
#  ['Georganne MOLINEArizona53.88  6/23/2013',
#   'Georganne MOLINE',
#   '',
#   'Arizona',
#   '53.88  ',
#   '6/23/2013'],
#  [],
#  ['Georganne MOLINE', '', 'Arizona', '53.88  ', '6/23/2013'],
#  ['Georganne MOLINEArizona53.92  8/8/2012',
#   'Georganne MOLINE',
#   '',
#   'Arizona',
#   '53.92  ',
#   '8/8/2012'],
#  [],
#  ['Georganne MOLINE', '', 'Arizona', '53.92  ', '8/8/2012'],
#  ['Shamier LITTLETexas A&M53.94  8/26/2015',
#   'Shamier LITTLE',
#   '',
#   'Texas A&M',
#   '53.94  ',
#   '8/26/2015'],
#  [],
#  ['Shamier LITTLE', '', 'Texas A&M', '53.94  ', '8/26/2015'],
#  ['Shamier LITTLE?Texas A&M53.97  9/1/2016',
#   'Shamier LITTLE?',
#   '',
#   'Texas A&M',
#   '53.97  ',
#   '9/1/2016'],
#  [],
#  ['Shamier LITTLE?', '', 'Texas A&M', '53.97  ', '9/1/2016'],
#  ['Nickiesha WILSONLSU53.97 qq = Performance occurred during a non-final round. 8/28/2007',
#   'Nickiesha WILSON',
#   '',
#   'LSU',
#   '53.97 qq = Performance occurred during a non-final round. ',
#   '8/28/2007'],
#  [],
#  ['Nickiesha WILSON',
#   '',
#   'LSU',
#   '53.97 qq = Performance occurred during a non-final round. ',
#   '8/28/2007'],
#  ['Lashinda DEMUSSouth Carolina53.98  7/1/2012',
#   'Lashinda DEMUS',
#   '',
#   'South Carolina',
#   '53.98  ',
#   '7/1/2012'],
#  [],
#  ['Lashinda DEMUS', '', 'South Carolina', '53.98  ', '7/1/2012'],
#  ['Britton WILSONSOArkansas54.02  7/22/2022',
#   'Britton WILSONSO',
#   '',
#   'Arkansas',
#   '54.02  ',
#   '7/22/2022'],
#  [],
#  ['Britton WILSONSO', '', 'Arkansas', '54.02  ', '7/22/2022'],
#  ['Deon HEMMINGSCentral State54.12  8/17/1993',
#   'Deon HEMMINGS',
#   '',
#   'Central State',
#   '54.12  ',
#   '8/17/1993'],
#  [],
#  ['Deon HEMMINGS', '', 'Central State', '54.12  ', '8/17/1993'],
#  ['Shamier LITTLE?Texas A&M54.14 qq = Performance occurred during a non-final round. 6/27/2015',
#   'Shamier LITTLE?',
#   '',
#   'Texas A&M',
#   '54.14 qq = Performance occurred during a non-final round. ',
#   '6/27/2015'],
#  [],
#  ['Shamier LITTLE?',
#   '',
#   'Texas A&M',
#   '54.14 qq = Performance occurred during a non-final round. ',
#   '6/27/2015'],
#  ['Raasin MCINTOSHTexas54.16  7/11/2004',
#   'Raasin MCINTOSH',
#   '',
#   'Texas',
#   '54.16  ',
#   '7/11/2004'],
#  [],
#  ['Raasin MCINTOSH', '', 'Texas', '54.16  ', '7/11/2004'],
#  ['Anna COCKRELLSRSouthern California54.17 qq = Performance occurred during a non-final round. 8/2/2021',
#   'Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '54.17 qq = Performance occurred during a non-final round. ',
#   '8/2/2021'],
#  [],
#  ['Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '54.17 qq = Performance occurred during a non-final round. ',
#   '8/2/2021'],
#  ['Tonya WILLIAMSIllinois54.17  7/3/1996',
#   'Tonya WILLIAMS',
#   '',
#   'Illinois',
#   '54.17  ',
#   '7/3/1996'],
#  [],
#  ['Tonya WILLIAMS', '', 'Illinois', '54.17  ', '7/3/1996'],
#  ['Georganne MOLINEArizona54.19  7/6/2013',
#   'Georganne MOLINE',
#   '',
#   'Arizona',
#   '54.19  ',
#   '7/6/2013'],
#  [],
#  ['Georganne MOLINE', '', 'Arizona', '54.19  ', '7/6/2013'],
#  ['Shauna SMITHWyoming54.21  6/25/2005',
#   'Shauna SMITH',
#   '',
#   'Wyoming',
#   '54.21  ',
#   '6/25/2005'],
#  [],
#  ['Shauna SMITH', '', 'Wyoming', '54.21  ', '6/25/2005'],
#  ['Ryan TOLBERTVanderbilt54.21  6/14/1997',
#   'Ryan TOLBERT',
#   '',
#   'Vanderbilt',
#   '54.21  ',
#   '6/14/1997'],
#  [],
#  ['Ryan TOLBERT', '', 'Vanderbilt', '54.21  ', '6/14/1997'],
#  ['Georganne MOLINEArizona54.31 qq = Performance occurred during a non-final round. 8/5/2012',
#   'Georganne MOLINE',
#   '',
#   'Arizona',
#   '54.31 qq = Performance occurred during a non-final round. ',
#   '8/5/2012'],
#  [],
#  ['Georganne MOLINE',
#   '',
#   'Arizona',
#   '54.31 qq = Performance occurred during a non-final round. ',
#   '8/5/2012'],
#  ['Lashinda DEMUSSouth Carolina54.32 qq = Performance occurred during a non-final round. 8/22/2004',
#   'Lashinda DEMUS',
#   '',
#   'South Carolina',
#   '54.32 qq = Performance occurred during a non-final round. ',
#   '8/22/2004'],
#  [],
#  ['Lashinda DEMUS',
#   '',
#   'South Carolina',
#   '54.32 qq = Performance occurred during a non-final round. ',
#   '8/22/2004'],
#  ['Georganne MOLINEArizona54.33  7/1/2012',
#   'Georganne MOLINE',
#   '',
#   'Arizona',
#   '54.33  ',
#   '7/1/2012'],
#  [],
#  ['Georganne MOLINE', '', 'Arizona', '54.33  ', '7/1/2012'],
#  ['Tonja BUFORDIllinois54.38  8/17/1993',
#   'Tonja BUFORD',
#   '',
#   'Illinois',
#   '54.38  ',
#   '8/17/1993'],
#  [],
#  ['Tonja BUFORD', '', 'Illinois', '54.38  ', '8/17/1993'],
#  ['Britton WILSONSOArkansas54.54 qq = Performance occurred during a non-final round. 7/19/2022',
#   'Britton WILSONSO',
#   '',
#   'Arkansas',
#   '54.54 qq = Performance occurred during a non-final round. ',
#   '7/19/2022'],
#  [],
#  ['Britton WILSONSO',
#   '',
#   'Arkansas',
#   '54.54 qq = Performance occurred during a non-final round. ',
#   '7/19/2022'],
#  ['Sage WATSONSRArizona54.59  7/14/2017',
#   'Sage WATSONSR',
#   '',
#   'Arizona',
#   '54.59  ',
#   '7/14/2017'],
#  [],
#  ['Sage WATSONSR', '', 'Arizona', '54.59  ', '7/14/2017'],
#  ['Queen CLAYEVirginia Tech54.60  6/29/2008',
#   'Queen CLAYE',
#   '',
#   'Virginia Tech',
#   '54.60  ',
#   '6/29/2008'],
#  [],
#  ['Queen CLAYE', '', 'Virginia Tech', '54.60  ', '6/29/2008'],
#  ['Autumne FRANKLINHarvard54.65 7/10/2016',
#   'Autumne FRANKLIN',
#   '',
#   'Harvard',
#   '54.65 ',
#   '7/10/2016'],
#  [],
#  ['Autumne FRANKLIN', '', 'Harvard', '54.65 ', '7/10/2016'],
#  ['Not Considered For Lists'],
#  ['Melaine WALKERTexas53.84  6/10/2006',
#   'Melaine WALKER',
#   '',
#   'Texas',
#   '53.84  ',
#   '6/10/2006'],
#  [],
#  ['Melaine WALKER', '', 'Texas', '53.84  ', '6/10/2006'],
#  ['', '', '', '']]

# %%
rows[155]
# Out:
# ['\xa0\xa0\xa0\xa0— Little {3}Texas A&M54.68 5/16/2015',
#  '\xa0\xa0\xa0\xa0— Little {3}',
#  '',
#  'Texas A&M',
#  '54.68 ',
#  '5/16/2015']

# %%
len(rows)
# Out:
# 257

# %%
RealRows = []

# %%
for i in range(0,156):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [['(1) Sydney MCLAUGHLINFRKentucky52.75📺 5/13/2018',
#   '(1) Sydney MCLAUGHLINFR',
#   '',
#   'Kentucky',
#   '52.75📺 ',
#   '5/13/2018'],
#  ['(1) Sydney MCLAUGHLINFR', '', 'Kentucky', '52.75📺 ', '5/13/2018'],
#  ['(2) Kori CARTERJRStanford53.21 6/7/2013',
#   '(2) Kori CARTERJR',
#   '',
#   'Stanford',
#   '53.21 ',
#   '6/7/2013'],
#  ['(2) Kori CARTERJR', '', 'Stanford', '53.21 ', '6/7/2013'],
#  ['(3) Britton WILSONJRArkansas53.23📺 4/14/2023',
#   '(3) Britton WILSONJR',
#   '',
#   'Arkansas',
#   '53.23📺 ',
#   '4/14/2023'],
#  ['(3) Britton WILSONJR', '', 'Arkansas', '53.23📺 ', '4/14/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}JRArkansas53.28 5/13/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}JR',
#   '',
#   'Arkansas',
#   '53.28 ',
#   '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}JR', '', 'Arkansas', '53.28 ', '5/13/2023'],
#  ['(4) Shamier LITTLEJRTexas A&M53.51 6/11/2016',
#   '(4) Shamier LITTLEJR',
#   '',
#   'Texas A&M',
#   '53.51 ',
#   '6/11/2016'],
#  ['(4) Shamier LITTLEJR', '', 'Texas A&M', '53.51 ', '6/11/2016'],
#  ['(5) Sheena JOHNSONSRUCLA53.54  6/12/2004',
#   '(5) Sheena JOHNSONSR',
#   '',
#   'UCLA',
#   '53.54  ',
#   '6/12/2004'],
#  ['(5) Sheena JOHNSONSR', '', 'UCLA', '53.54  ', '6/12/2004'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {2}FRKentucky53.60 4/27/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {2}FR',
#   '',
#   'Kentucky',
#   '53.60 ',
#   '4/27/2018'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {2}FR', '', 'Kentucky', '53.60 ', '4/27/2018'],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}JRArkansas53.71 qq = Performance occurred during a non-final round. 5/27/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {3}JR',
#   '',
#   'Arkansas',
#   '53.71 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}JR',
#   '',
#   'Arkansas',
#   '53.71 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['(6) Georganne MOLINESRArizona53.72 6/7/2013',
#   '(6) Georganne MOLINESR',
#   '',
#   'Arizona',
#   '53.72 ',
#   '6/7/2013'],
#  ['(6) Georganne MOLINESR', '', 'Arizona', '53.72 ', '6/7/2013'],
#  ['\xa0\xa0\xa0\xa0— Little {2}Texas A&M53.74 6/13/2015',
#   '\xa0\xa0\xa0\xa0— Little {2}',
#   '',
#   'Texas A&M',
#   '53.74 ',
#   '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Little {2}', '', 'Texas A&M', '53.74 ', '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Wilson {4}SOArkansas53.75 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {4}SO',
#   '',
#   'Arkansas',
#   '53.75 ',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {4}SO', '', 'Arkansas', '53.75 ', '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {5}JRArkansas53.76 qq = Performance occurred during a non-final round. 5/11/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {5}JR',
#   '',
#   'Arkansas',
#   '53.76 qq = Performance occurred during a non-final round. ',
#   '5/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {5}JR',
#   '',
#   'Arkansas',
#   '53.76 qq = Performance occurred during a non-final round. ',
#   '5/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {6}SOArkansas53.86 6/11/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {6}SO',
#   '',
#   'Arkansas',
#   '53.86 ',
#   '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {6}SO', '', 'Arkansas', '53.86 ', '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {3}FRKentucky53.96 6/9/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {3}FR',
#   '',
#   'Kentucky',
#   '53.96 ',
#   '6/9/2018'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {3}FR', '', 'Kentucky', '53.96 ', '6/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Wilson {7}JRArkansas54.08 qq = Performance occurred during a non-final round. 5/25/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {7}JR',
#   '',
#   'Arkansas',
#   '54.08 qq = Performance occurred during a non-final round. ',
#   '5/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {7}JR',
#   '',
#   'Arkansas',
#   '54.08 qq = Performance occurred during a non-final round. ',
#   '5/25/2023'],
#  ['(7) Keni HARRISONKentucky54.09 6/13/2015',
#   '(7) Keni HARRISON',
#   '',
#   'Kentucky',
#   '54.09 ',
#   '6/13/2015'],
#  ['(7) Keni HARRISON', '', 'Kentucky', '54.09 ', '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {4}FRKentucky54.15 qq = Performance occurred during a non-final round. 6/7/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {4}FR',
#   '',
#   'Kentucky',
#   '54.15 qq = Performance occurred during a non-final round. ',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {4}FR',
#   '',
#   'Kentucky',
#   '54.15 qq = Performance occurred during a non-final round. ',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Carter {2}Stanford54.21 5/12/2013',
#   '\xa0\xa0\xa0\xa0— Carter {2}',
#   '',
#   'Stanford',
#   '54.21 ',
#   '5/12/2013'],
#  ['\xa0\xa0\xa0\xa0— Carter {2}', '', 'Stanford', '54.21 ', '5/12/2013'],
#  ['(8) Lashinda DEMUSSOSouth Carolina54.22  6/12/2004',
#   '(8) Lashinda DEMUSSO',
#   '',
#   'South Carolina',
#   '54.22  ',
#   '6/12/2004'],
#  ['(8) Lashinda DEMUSSO', '', 'South Carolina', '54.22  ', '6/12/2004'],
#  ['\xa0\xa0\xa0\xa0— Wilson {8}SOArkansas54.23 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {8}SO',
#   '',
#   'Arkansas',
#   '54.23 ',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {8}SO', '', 'Arkansas', '54.23 ', '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {9}SOArkansas54.23 qq = Performance occurred during a non-final round. 5/12/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {9}SO',
#   '',
#   'Arkansas',
#   '54.23 qq = Performance occurred during a non-final round. ',
#   '5/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {9}SO',
#   '',
#   'Arkansas',
#   '54.23 qq = Performance occurred during a non-final round. ',
#   '5/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Johnson {2}JRUCLA54.24  6/13/2003',
#   '\xa0\xa0\xa0\xa0— Johnson {2}JR',
#   '',
#   'UCLA',
#   '54.24  ',
#   '6/13/2003'],
#  ['\xa0\xa0\xa0\xa0— Johnson {2}JR', '', 'UCLA', '54.24  ', '6/13/2003'],
#  ['(9) Nicole LEACHSOUCLA54.32  6/9/2007',
#   '(9) Nicole LEACHSO',
#   '',
#   'UCLA',
#   '54.32  ',
#   '6/9/2007'],
#  ['(9) Nicole LEACHSO', '', 'UCLA', '54.32  ', '6/9/2007'],
#  ['(9) Shauna SMITHSRWyoming54.32  6/11/2005',
#   '(9) Shauna SMITHSR',
#   '',
#   'Wyoming',
#   '54.32  ',
#   '6/11/2005'],
#  ['(9) Shauna SMITHSR', '', 'Wyoming', '54.32  ', '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— Johnson {3}UCLA54.32  5/14/2004',
#   '\xa0\xa0\xa0\xa0— Johnson {3}',
#   '',
#   'UCLA',
#   '54.32  ',
#   '5/14/2004'],
#  ['\xa0\xa0\xa0\xa0— Johnson {3}', '', 'UCLA', '54.32  ', '5/14/2004'],
#  ['\xa0\xa0\xa0\xa0— Wilson {10}SOArkansas54.37 3/25/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {10}SO',
#   '',
#   'Arkansas',
#   '54.37 ',
#   '3/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {10}SO', '', 'Arkansas', '54.37 ', '3/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Smith {2}Wyoming54.37  5/28/2005',
#   '\xa0\xa0\xa0\xa0— Smith {2}',
#   '',
#   'Wyoming',
#   '54.37  ',
#   '5/28/2005'],
#  ['\xa0\xa0\xa0\xa0— Smith {2}', '', 'Wyoming', '54.37  ', '5/28/2005'],
#  ['(11) Savannah SUTHERLANDSOMichigan54.45 6/10/2023',
#   '(11) Savannah SUTHERLANDSO',
#   '',
#   'Michigan',
#   '54.45 ',
#   '6/10/2023'],
#  ['(11) Savannah SUTHERLANDSO', '', 'Michigan', '54.45 ', '6/10/2023'],
#  ['(11) Nickiesha WILSONJRLSU54.45  6/13/2008',
#   '(11) Nickiesha WILSONJR',
#   '',
#   'LSU',
#   '54.45  ',
#   '6/13/2008'],
#  ['(11) Nickiesha WILSONJR', '', 'LSU', '54.45  ', '6/13/2008'],
#  ['(13) Markita JAMESSRAuburn54.47  6/10/2006',
#   '(13) Markita JAMESSR',
#   '',
#   'Auburn',
#   '54.47  ',
#   '6/10/2006'],
#  ['(13) Markita JAMESSR', '', 'Auburn', '54.47  ', '6/10/2006'],
#  ['(13) Shevon STODDARTSRSouth Carolina54.47  6/11/2005',
#   '(13) Shevon STODDARTSR',
#   '',
#   'South Carolina',
#   '54.47  ',
#   '6/11/2005'],
#  ['(13) Shevon STODDARTSR', '', 'South Carolina', '54.47  ', '6/11/2005'],
#  ['(15) Anna HALLSOFlorida54.48 qq = Performance occurred during a non-final round. 6/9/2022',
#   '(15) Anna HALLSO',
#   '',
#   'Florida',
#   '54.48 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['(15) Anna HALLSO',
#   '',
#   'Florida',
#   '54.48 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Carter {3}Stanford54.50 qq = Performance occurred during a non-final round. 5/25/2013',
#   '\xa0\xa0\xa0\xa0— Carter {3}',
#   '',
#   'Stanford',
#   '54.50 qq = Performance occurred during a non-final round. ',
#   '5/25/2013'],
#  ['\xa0\xa0\xa0\xa0— Carter {3}',
#   '',
#   'Stanford',
#   '54.50 qq = Performance occurred during a non-final round. ',
#   '5/25/2013'],
#  ['\xa0\xa0\xa0\xa0— Demus {2}South Carolina54.50  2004',
#   '\xa0\xa0\xa0\xa0— Demus {2}',
#   '',
#   'South Carolina',
#   '54.50  ',
#   '2004'],
#  ['\xa0\xa0\xa0\xa0— Demus {2}', '', 'South Carolina', '54.50  ', '2004'],
#  ['(16) Sage WATSONSRArizona54.52 6/10/2017',
#   '(16) Sage WATSONSR',
#   '',
#   'Arizona',
#   '54.52 ',
#   '6/10/2017'],
#  ['(16) Sage WATSONSR', '', 'Arizona', '54.52 ', '6/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Moline {2}Arizona54.54 5/12/2013',
#   '\xa0\xa0\xa0\xa0— Moline {2}',
#   '',
#   'Arizona',
#   '54.54 ',
#   '5/12/2013'],
#  ['\xa0\xa0\xa0\xa0— Moline {2}', '', 'Arizona', '54.54 ', '5/12/2013'],
#  ['(17) Ryan TOLBERTVanderbilt54.54  6/6/1997',
#   '(17) Ryan TOLBERT',
#   '',
#   'Vanderbilt',
#   '54.54  ',
#   '6/6/1997'],
#  ['(17) Ryan TOLBERT', '', 'Vanderbilt', '54.54  ', '6/6/1997'],
#  ['(18) Queen CLAYESRVirginia Tech54.55  6/11/2010',
#   '(18) Queen CLAYESR',
#   '',
#   'Virginia Tech',
#   '54.55  ',
#   '6/11/2010'],
#  ['(18) Queen CLAYESR', '', 'Virginia Tech', '54.55  ', '6/11/2010'],
#  ['(19) Tiffany ROSS-WILLIAMSJRSouth Carolina54.56  6/11/2005',
#   '(19) Tiffany ROSS-WILLIAMSJR',
#   '',
#   'South Carolina',
#   '54.56  ',
#   '6/11/2005'],
#  ['(19) Tiffany ROSS-WILLIAMSJR',
#   '',
#   'South Carolina',
#   '54.56  ',
#   '6/11/2005'],
#  ['(19) Tonya WILLIAMSIllinois54.56  5/31/1996',
#   '(19) Tonya WILLIAMS',
#   '',
#   'Illinois',
#   '54.56  ',
#   '5/31/1996'],
#  ['(19) Tonya WILLIAMS', '', 'Illinois', '54.56  ', '5/31/1996'],
#  ['\xa0\xa0\xa0\xa0— Moline {3}Arizona54.59 qq = Performance occurred during a non-final round. 5/25/2013',
#   '\xa0\xa0\xa0\xa0— Moline {3}',
#   '',
#   'Arizona',
#   '54.59 qq = Performance occurred during a non-final round. ',
#   '5/25/2013'],
#  ['\xa0\xa0\xa0\xa0— Moline {3}',
#   '',
#   'Arizona',
#   '54.59 qq = Performance occurred during a non-final round. ',
#   '5/25/2013'],
#  ['(21) Raasin MCINTOSHTexas54.60  4/5/2003',
#   '(21) Raasin MCINTOSH',
#   '',
#   'Texas',
#   '54.60  ',
#   '4/5/2003'],
#  ['(21) Raasin MCINTOSH', '', 'Texas', '54.60  ', '4/5/2003'],
#  ['\xa0\xa0\xa0\xa0— Leach {2}JRUCLA54.62  6/13/2008',
#   '\xa0\xa0\xa0\xa0— Leach {2}JR',
#   '',
#   'UCLA',
#   '54.62  ',
#   '6/13/2008'],
#  ['\xa0\xa0\xa0\xa0— Leach {2}JR', '', 'UCLA', '54.62  ', '6/13/2008'],
#  ['\xa0\xa0\xa0\xa0— Wilson {11}SOArkansas54.65 3/25/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {11}SO',
#   '',
#   'Arkansas',
#   '54.65 ',
#   '3/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {11}SO', '', 'Arkansas', '54.65 ', '3/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {12}SOArkansas54.65 qq = Performance occurred during a non-final round. 3/24/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {12}SO',
#   '',
#   'Arkansas',
#   '54.65 qq = Performance occurred during a non-final round. ',
#   '3/24/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {12}SO',
#   '',
#   'Arkansas',
#   '54.65 qq = Performance occurred during a non-final round. ',
#   '3/24/2022'],
#  ['(22) Masai RUSSELLSRKentucky54.66 6/10/2023',
#   '(22) Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '54.66 ',
#   '6/10/2023'],
#  ['(22) Masai RUSSELLSR', '', 'Kentucky', '54.66 ', '6/10/2023'],
#  ['(22) LaTanya SHEFFIELDJRSan Diego State54.66  5/31/1985',
#   '(22) LaTanya SHEFFIELDJR',
#   '',
#   'San Diego State',
#   '54.66  ',
#   '5/31/1985'],
#  ['(22) LaTanya SHEFFIELDJR', '', 'San Diego State', '54.66  ', '5/31/1985'],
#  ['\xa0\xa0\xa0\xa0— Wilson {13}JRArkansas54.67 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {13}JR',
#   '',
#   'Arkansas',
#   '54.67 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {13}JR',
#   '',
#   'Arkansas',
#   '54.67 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(24) Kiah SEYMOURJRKentucky54.67 6/11/2016',
#   '(24) Kiah SEYMOURJR',
#   '',
#   'Kentucky',
#   '54.67 ',
#   '6/11/2016'],
#  ['(24) Kiah SEYMOURJR', '', 'Kentucky', '54.67 ', '6/11/2016'],
#  ['\xa0\xa0\xa0\xa0— Carter {4}JRStanford54.67 qq = Performance occurred during a non-final round. 6/5/2013',
#   '\xa0\xa0\xa0\xa0— Carter {4}JR',
#   '',
#   'Stanford',
#   '54.67 qq = Performance occurred during a non-final round. ',
#   '6/5/2013'],
#  ['\xa0\xa0\xa0\xa0— Carter {4}JR',
#   '',
#   'Stanford',
#   '54.67 qq = Performance occurred during a non-final round. ',
#   '6/5/2013'],
#  ['(25) Anna COCKRELLSRSouthern California54.68 6/12/2021',
#   '(25) Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '54.68 ',
#   '6/12/2021'],
#  ['(25) Anna COCKRELLSR', '', 'Southern California', '54.68 ', '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Little {3}Texas A&M54.68 5/16/2015',
#   '\xa0\xa0\xa0\xa0— Little {3}',
#   '',
#   'Texas A&M',
#   '54.68 ',
#   '5/16/2015']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Sydney MCLAUGHLINFRKentucky52.75📺 5/13/2018',
#   '(1) Sydney MCLAUGHLINFR',
#   '',
#   'Kentucky',
#   '52.75📺 ',
#   '5/13/2018'],
#  ['(2) Kori CARTERJRStanford53.21 6/7/2013',
#   '(2) Kori CARTERJR',
#   '',
#   'Stanford',
#   '53.21 ',
#   '6/7/2013'],
#  ['(3) Britton WILSONJRArkansas53.23📺 4/14/2023',
#   '(3) Britton WILSONJR',
#   '',
#   'Arkansas',
#   '53.23📺 ',
#   '4/14/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}JRArkansas53.28 5/13/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}JR',
#   '',
#   'Arkansas',
#   '53.28 ',
#   '5/13/2023'],
#  ['(4) Shamier LITTLEJRTexas A&M53.51 6/11/2016',
#   '(4) Shamier LITTLEJR',
#   '',
#   'Texas A&M',
#   '53.51 ',
#   '6/11/2016'],
#  ['(5) Sheena JOHNSONSRUCLA53.54  6/12/2004',
#   '(5) Sheena JOHNSONSR',
#   '',
#   'UCLA',
#   '53.54  ',
#   '6/12/2004'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {2}FRKentucky53.60 4/27/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {2}FR',
#   '',
#   'Kentucky',
#   '53.60 ',
#   '4/27/2018'],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}JRArkansas53.71 qq = Performance occurred during a non-final round. 5/27/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {3}JR',
#   '',
#   'Arkansas',
#   '53.71 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['(6) Georganne MOLINESRArizona53.72 6/7/2013',
#   '(6) Georganne MOLINESR',
#   '',
#   'Arizona',
#   '53.72 ',
#   '6/7/2013'],
#  ['\xa0\xa0\xa0\xa0— Little {2}Texas A&M53.74 6/13/2015',
#   '\xa0\xa0\xa0\xa0— Little {2}',
#   '',
#   'Texas A&M',
#   '53.74 ',
#   '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Wilson {4}SOArkansas53.75 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {4}SO',
#   '',
#   'Arkansas',
#   '53.75 ',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {5}JRArkansas53.76 qq = Performance occurred during a non-final round. 5/11/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {5}JR',
#   '',
#   'Arkansas',
#   '53.76 qq = Performance occurred during a non-final round. ',
#   '5/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {6}SOArkansas53.86 6/11/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {6}SO',
#   '',
#   'Arkansas',
#   '53.86 ',
#   '6/11/2022'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {3}FRKentucky53.96 6/9/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {3}FR',
#   '',
#   'Kentucky',
#   '53.96 ',
#   '6/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Wilson {7}JRArkansas54.08 qq = Performance occurred during a non-final round. 5/25/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {7}JR',
#   '',
#   'Arkansas',
#   '54.08 qq = Performance occurred during a non-final round. ',
#   '5/25/2023'],
#  ['(7) Keni HARRISONKentucky54.09 6/13/2015',
#   '(7) Keni HARRISON',
#   '',
#   'Kentucky',
#   '54.09 ',
#   '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {4}FRKentucky54.15 qq = Performance occurred during a non-final round. 6/7/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {4}FR',
#   '',
#   'Kentucky',
#   '54.15 qq = Performance occurred during a non-final round. ',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Carter {2}Stanford54.21 5/12/2013',
#   '\xa0\xa0\xa0\xa0— Carter {2}',
#   '',
#   'Stanford',
#   '54.21 ',
#   '5/12/2013'],
#  ['(8) Lashinda DEMUSSOSouth Carolina54.22  6/12/2004',
#   '(8) Lashinda DEMUSSO',
#   '',
#   'South Carolina',
#   '54.22  ',
#   '6/12/2004'],
#  ['\xa0\xa0\xa0\xa0— Wilson {8}SOArkansas54.23 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {8}SO',
#   '',
#   'Arkansas',
#   '54.23 ',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {9}SOArkansas54.23 qq = Performance occurred during a non-final round. 5/12/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {9}SO',
#   '',
#   'Arkansas',
#   '54.23 qq = Performance occurred during a non-final round. ',
#   '5/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Johnson {2}JRUCLA54.24  6/13/2003',
#   '\xa0\xa0\xa0\xa0— Johnson {2}JR',
#   '',
#   'UCLA',
#   '54.24  ',
#   '6/13/2003'],
#  ['(9) Nicole LEACHSOUCLA54.32  6/9/2007',
#   '(9) Nicole LEACHSO',
#   '',
#   'UCLA',
#   '54.32  ',
#   '6/9/2007'],
#  ['(9) Shauna SMITHSRWyoming54.32  6/11/2005',
#   '(9) Shauna SMITHSR',
#   '',
#   'Wyoming',
#   '54.32  ',
#   '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— Johnson {3}UCLA54.32  5/14/2004',
#   '\xa0\xa0\xa0\xa0— Johnson {3}',
#   '',
#   'UCLA',
#   '54.32  ',
#   '5/14/2004'],
#  ['\xa0\xa0\xa0\xa0— Wilson {10}SOArkansas54.37 3/25/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {10}SO',
#   '',
#   'Arkansas',
#   '54.37 ',
#   '3/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Smith {2}Wyoming54.37  5/28/2005',
#   '\xa0\xa0\xa0\xa0— Smith {2}',
#   '',
#   'Wyoming',
#   '54.37  ',
#   '5/28/2005'],
#  ['(11) Savannah SUTHERLANDSOMichigan54.45 6/10/2023',
#   '(11) Savannah SUTHERLANDSO',
#   '',
#   'Michigan',
#   '54.45 ',
#   '6/10/2023'],
#  ['(11) Nickiesha WILSONJRLSU54.45  6/13/2008',
#   '(11) Nickiesha WILSONJR',
#   '',
#   'LSU',
#   '54.45  ',
#   '6/13/2008'],
#  ['(13) Markita JAMESSRAuburn54.47  6/10/2006',
#   '(13) Markita JAMESSR',
#   '',
#   'Auburn',
#   '54.47  ',
#   '6/10/2006'],
#  ['(13) Shevon STODDARTSRSouth Carolina54.47  6/11/2005',
#   '(13) Shevon STODDARTSR',
#   '',
#   'South Carolina',
#   '54.47  ',
#   '6/11/2005'],
#  ['(15) Anna HALLSOFlorida54.48 qq = Performance occurred during a non-final round. 6/9/2022',
#   '(15) Anna HALLSO',
#   '',
#   'Florida',
#   '54.48 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Carter {3}Stanford54.50 qq = Performance occurred during a non-final round. 5/25/2013',
#   '\xa0\xa0\xa0\xa0— Carter {3}',
#   '',
#   'Stanford',
#   '54.50 qq = Performance occurred during a non-final round. ',
#   '5/25/2013'],
#  ['\xa0\xa0\xa0\xa0— Demus {2}South Carolina54.50  2004',
#   '\xa0\xa0\xa0\xa0— Demus {2}',
#   '',
#   'South Carolina',
#   '54.50  ',
#   '2004'],
#  ['(16) Sage WATSONSRArizona54.52 6/10/2017',
#   '(16) Sage WATSONSR',
#   '',
#   'Arizona',
#   '54.52 ',
#   '6/10/2017'],
#  ['\xa0\xa0\xa0\xa0— Moline {2}Arizona54.54 5/12/2013',
#   '\xa0\xa0\xa0\xa0— Moline {2}',
#   '',
#   'Arizona',
#   '54.54 ',
#   '5/12/2013'],
#  ['(17) Ryan TOLBERTVanderbilt54.54  6/6/1997',
#   '(17) Ryan TOLBERT',
#   '',
#   'Vanderbilt',
#   '54.54  ',
#   '6/6/1997'],
#  ['(18) Queen CLAYESRVirginia Tech54.55  6/11/2010',
#   '(18) Queen CLAYESR',
#   '',
#   'Virginia Tech',
#   '54.55  ',
#   '6/11/2010'],
#  ['(19) Tiffany ROSS-WILLIAMSJRSouth Carolina54.56  6/11/2005',
#   '(19) Tiffany ROSS-WILLIAMSJR',
#   '',
#   'South Carolina',
#   '54.56  ',
#   '6/11/2005'],
#  ['(19) Tonya WILLIAMSIllinois54.56  5/31/1996',
#   '(19) Tonya WILLIAMS',
#   '',
#   'Illinois',
#   '54.56  ',
#   '5/31/1996'],
#  ['\xa0\xa0\xa0\xa0— Moline {3}Arizona54.59 qq = Performance occurred during a non-final round. 5/25/2013',
#   '\xa0\xa0\xa0\xa0— Moline {3}',
#   '',
#   'Arizona',
#   '54.59 qq = Performance occurred during a non-final round. ',
#   '5/25/2013'],
#  ['(21) Raasin MCINTOSHTexas54.60  4/5/2003',
#   '(21) Raasin MCINTOSH',
#   '',
#   'Texas',
#   '54.60  ',
#   '4/5/2003'],
#  ['\xa0\xa0\xa0\xa0— Leach {2}JRUCLA54.62  6/13/2008',
#   '\xa0\xa0\xa0\xa0— Leach {2}JR',
#   '',
#   'UCLA',
#   '54.62  ',
#   '6/13/2008'],
#  ['\xa0\xa0\xa0\xa0— Wilson {11}SOArkansas54.65 3/25/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {11}SO',
#   '',
#   'Arkansas',
#   '54.65 ',
#   '3/25/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {12}SOArkansas54.65 qq = Performance occurred during a non-final round. 3/24/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {12}SO',
#   '',
#   'Arkansas',
#   '54.65 qq = Performance occurred during a non-final round. ',
#   '3/24/2022'],
#  ['(22) Masai RUSSELLSRKentucky54.66 6/10/2023',
#   '(22) Masai RUSSELLSR',
#   '',
#   'Kentucky',
#   '54.66 ',
#   '6/10/2023'],
#  ['(22) LaTanya SHEFFIELDJRSan Diego State54.66  5/31/1985',
#   '(22) LaTanya SHEFFIELDJR',
#   '',
#   'San Diego State',
#   '54.66  ',
#   '5/31/1985'],
#  ['\xa0\xa0\xa0\xa0— Wilson {13}JRArkansas54.67 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {13}JR',
#   '',
#   'Arkansas',
#   '54.67 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(24) Kiah SEYMOURJRKentucky54.67 6/11/2016',
#   '(24) Kiah SEYMOURJR',
#   '',
#   'Kentucky',
#   '54.67 ',
#   '6/11/2016'],
#  ['\xa0\xa0\xa0\xa0— Carter {4}JRStanford54.67 qq = Performance occurred during a non-final round. 6/5/2013',
#   '\xa0\xa0\xa0\xa0— Carter {4}JR',
#   '',
#   'Stanford',
#   '54.67 qq = Performance occurred during a non-final round. ',
#   '6/5/2013'],
#  ['(25) Anna COCKRELLSRSouthern California54.68 6/12/2021',
#   '(25) Anna COCKRELLSR',
#   '',
#   'Southern California',
#   '54.68 ',
#   '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Little {3}Texas A&M54.68 5/16/2015',
#   '\xa0\xa0\xa0\xa0— Little {3}',
#   '',
#   'Texas A&M',
#   '54.68 ',
#   '5/16/2015']]

# %%
RealRealRows[1][4]
# Out:
# '53.21 '

# %%
len(RealRealRows)
# Out:
# 52

# %%
OfficialTimes = []

# %%
for i in range(0,len(RealRealRows)):
    OfficialTimes.append(RealRealRows[i][4])
OfficialTimes
# Out:
# ['52.75📺 ',
#  '53.21 ',
#  '53.23📺 ',
#  '53.28 ',
#  '53.51 ',
#  '53.54  ',
#  '53.60 ',
#  '53.71 qq = Performance occurred during a non-final round. ',
#  '53.72 ',
#  '53.74 ',
#  '53.75 ',
#  '53.76 qq = Performance occurred during a non-final round. ',
#  '53.86 ',
#  '53.96 ',
#  '54.08 qq = Performance occurred during a non-final round. ',
#  '54.09 ',
#  '54.15 qq = Performance occurred during a non-final round. ',
#  '54.21 ',
#  '54.22  ',
#  '54.23 ',
#  '54.23 qq = Performance occurred during a non-final round. ',
#  '54.24  ',
#  '54.32  ',
#  '54.32  ',
#  '54.32  ',
#  '54.37 ',
#  '54.37  ',
#  '54.45 ',
#  '54.45  ',
#  '54.47  ',
#  '54.47  ',
#  '54.48 qq = Performance occurred during a non-final round. ',
#  '54.50 qq = Performance occurred during a non-final round. ',
#  '54.50  ',
#  '54.52 ',
#  '54.54 ',
#  '54.54  ',
#  '54.55  ',
#  '54.56  ',
#  '54.56  ',
#  '54.59 qq = Performance occurred during a non-final round. ',
#  '54.60  ',
#  '54.62  ',
#  '54.65 ',
#  '54.65 qq = Performance occurred during a non-final round. ',
#  '54.66 ',
#  '54.66  ',
#  '54.67 qq = Performance occurred during a non-final round. ',
#  '54.67 ',
#  '54.67 qq = Performance occurred during a non-final round. ',
#  '54.68 ',
#  '54.68 ']

# %%
RealRealRows[0][1]
# Out:
# '(1) Sydney MCLAUGHLINFR'

# %%
Names = []

for i in range(0,52):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Sydney MCLAUGHLINFR',
#  '(2) Kori CARTERJR',
#  '(3) Britton WILSONJR',
#  '\xa0\xa0\xa0\xa0— Wilson {2}JR',
#  '(4) Shamier LITTLEJR',
#  '(5) Sheena JOHNSONSR',
#  '\xa0\xa0\xa0\xa0— McLaughlin {2}FR',
#  '\xa0\xa0\xa0\xa0— Wilson {3}JR',
#  '(6) Georganne MOLINESR',
#  '\xa0\xa0\xa0\xa0— Little {2}',
#  '\xa0\xa0\xa0\xa0— Wilson {4}SO',
#  '\xa0\xa0\xa0\xa0— Wilson {5}JR',
#  '\xa0\xa0\xa0\xa0— Wilson {6}SO',
#  '\xa0\xa0\xa0\xa0— McLaughlin {3}FR',
#  '\xa0\xa0\xa0\xa0— Wilson {7}JR',
#  '(7) Keni HARRISON',
#  '\xa0\xa0\xa0\xa0— McLaughlin {4}FR',
#  '\xa0\xa0\xa0\xa0— Carter {2}',
#  '(8) Lashinda DEMUSSO',
#  '\xa0\xa0\xa0\xa0— Wilson {8}SO',
#  '\xa0\xa0\xa0\xa0— Wilson {9}SO',
#  '\xa0\xa0\xa0\xa0— Johnson {2}JR',
#  '(9) Nicole LEACHSO',
#  '(9) Shauna SMITHSR',
#  '\xa0\xa0\xa0\xa0— Johnson {3}',
#  '\xa0\xa0\xa0\xa0— Wilson {10}SO',
#  '\xa0\xa0\xa0\xa0— Smith {2}',
#  '(11) Savannah SUTHERLANDSO',
#  '(11) Nickiesha WILSONJR',
#  '(13) Markita JAMESSR',
#  '(13) Shevon STODDARTSR',
#  '(15) Anna HALLSO',
#  '\xa0\xa0\xa0\xa0— Carter {3}',
#  '\xa0\xa0\xa0\xa0— Demus {2}',
#  '(16) Sage WATSONSR',
#  '\xa0\xa0\xa0\xa0— Moline {2}',
#  '(17) Ryan TOLBERT',
#  '(18) Queen CLAYESR',
#  '(19) Tiffany ROSS-WILLIAMSJR',
#  '(19) Tonya WILLIAMS',
#  '\xa0\xa0\xa0\xa0— Moline {3}',
#  '(21) Raasin MCINTOSH',
#  '\xa0\xa0\xa0\xa0— Leach {2}JR',
#  '\xa0\xa0\xa0\xa0— Wilson {11}SO',
#  '\xa0\xa0\xa0\xa0— Wilson {12}SO',
#  '(22) Masai RUSSELLSR',
#  '(22) LaTanya SHEFFIELDJR',
#  '\xa0\xa0\xa0\xa0— Wilson {13}JR',
#  '(24) Kiah SEYMOURJR',
#  '\xa0\xa0\xa0\xa0— Carter {4}JR',
#  '(25) Anna COCKRELLSR',
#  '\xa0\xa0\xa0\xa0— Little {3}']

# %%
OfficialReGexNames = []

# %%
for i in range(0,52):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Sydney MCLAUGHLINFR',
#  '(2) Kori CARTERJR',
#  '(3) Britton WILSONJR',
#  '— Wilson {2}JR',
#  '(4) Shamier LITTLEJR',
#  '(5) Sheena JOHNSONSR',
#  '— McLaughlin {2}FR',
#  '— Wilson {3}JR',
#  '(6) Georganne MOLINESR',
#  '— Little {2}',
#  '— Wilson {4}SO',
#  '— Wilson {5}JR',
#  '— Wilson {6}SO',
#  '— McLaughlin {3}FR',
#  '— Wilson {7}JR',
#  '(7) Keni HARRISON',
#  '— McLaughlin {4}FR',
#  '— Carter {2}',
#  '(8) Lashinda DEMUSSO',
#  '— Wilson {8}SO',
#  '— Wilson {9}SO',
#  '— Johnson {2}JR',
#  '(9) Nicole LEACHSO',
#  '(9) Shauna SMITHSR',
#  '— Johnson {3}',
#  '— Wilson {10}SO',
#  '— Smith {2}',
#  '(11) Savannah SUTHERLANDSO',
#  '(11) Nickiesha WILSONJR',
#  '(13) Markita JAMESSR',
#  '(13) Shevon STODDARTSR',
#  '(15) Anna HALLSO',
#  '— Carter {3}',
#  '— Demus {2}',
#  '(16) Sage WATSONSR',
#  '— Moline {2}',
#  '(17) Ryan TOLBERT',
#  '(18) Queen CLAYESR',
#  '(19) Tiffany ROSS-WILLIAMSJR',
#  '(19) Tonya WILLIAMS',
#  '— Moline {3}',
#  '(21) Raasin MCINTOSH',
#  '— Leach {2}JR',
#  '— Wilson {11}SO',
#  '— Wilson {12}SO',
#  '(22) Masai RUSSELLSR',
#  '(22) LaTanya SHEFFIELDJR',
#  '— Wilson {13}JR',
#  '(24) Kiah SEYMOURJR',
#  '— Carter {4}JR',
#  '(25) Anna COCKRELLSR',
#  '— Little {3}']

# %%
CleanedNames = []

for i in range(0,len(RealRealRows)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Sydney MCLAUGHLINFR',
#  'Kori CARTERJR',
#  'Britton WILSONJR',
#  'Wilson {2}JR',
#  'Shamier LITTLEJR',
#  'Sheena JOHNSONSR',
#  'McLaughlin {2}FR',
#  'Wilson {3}JR',
#  'Georganne MOLINESR',
#  'Little {2}',
#  'Wilson {4}SO',
#  'Wilson {5}JR',
#  'Wilson {6}SO',
#  'McLaughlin {3}FR',
#  'Wilson {7}JR',
#  'Keni HARRISON',
#  'McLaughlin {4}FR',
#  'Carter {2}',
#  'Lashinda DEMUSSO',
#  'Wilson {8}SO',
#  'Wilson {9}SO',
#  'Johnson {2}JR',
#  'Nicole LEACHSO',
#  'Shauna SMITHSR',
#  'Johnson {3}',
#  'Wilson {10}SO',
#  'Smith {2}',
#  ' Savannah SUTHERLANDSO',
#  ' Nickiesha WILSONJR',
#  ' Markita JAMESSR',
#  ' Shevon STODDARTSR',
#  ' Anna HALLSO',
#  'Carter {3}',
#  'Demus {2}',
#  ' Sage WATSONSR',
#  'Moline {2}',
#  ' Ryan TOLBERT',
#  ' Queen CLAYESR',
#  ' Tiffany ROSS-WILLIAMSJR',
#  ' Tonya WILLIAMS',
#  'Moline {3}',
#  ' Raasin MCINTOSH',
#  'Leach {2}JR',
#  'Wilson {11}SO',
#  'Wilson {12}SO',
#  ' Masai RUSSELLSR',
#  ' LaTanya SHEFFIELDJR',
#  'Wilson {13}JR',
#  ' Kiah SEYMOURJR',
#  'Carter {4}JR',
#  ' Anna COCKRELLSR',
#  'Little {3}']

# %%
CleanedNames2 = []

for i in range(0,len(RealRealRows)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Sydney MCLAUGHLINFR',
#  'Kori CARTERJR',
#  'Britton WILSONJR',
#  'Wilson {2}JR',
#  'Shamier LITTLEJR',
#  'Sheena JOHNSONSR',
#  'McLaughlin {2}FR',
#  'Wilson {3}JR',
#  'Georganne MOLINESR',
#  'Little {2}',
#  'Wilson {4}SO',
#  'Wilson {5}JR',
#  'Wilson {6}SO',
#  'McLaughlin {3}FR',
#  'Wilson {7}JR',
#  'Keni HARRISON',
#  'McLaughlin {4}FR',
#  'Carter {2}',
#  'Lashinda DEMUSSO',
#  'Wilson {8}SO',
#  'Wilson {9}SO',
#  'Johnson {2}JR',
#  'Nicole LEACHSO',
#  'Shauna SMITHSR',
#  'Johnson {3}',
#  'Wilson {10}SO',
#  'Smith {2}',
#  'Savannah SUTHERLANDSO',
#  'Nickiesha WILSONJR',
#  'Markita JAMESSR',
#  'Shevon STODDARTSR',
#  'Anna HALLSO',
#  'Carter {3}',
#  'Demus {2}',
#  'Sage WATSONSR',
#  'Moline {2}',
#  'Ryan TOLBERT',
#  'Queen CLAYESR',
#  'Tiffany ROSS-WILLIAMSJR',
#  'Tonya WILLIAMS',
#  'Moline {3}',
#  'Raasin MCINTOSH',
#  'Leach {2}JR',
#  'Wilson {11}SO',
#  'Wilson {12}SO',
#  'Masai RUSSELLSR',
#  'LaTanya SHEFFIELDJR',
#  'Wilson {13}JR',
#  'Kiah SEYMOURJR',
#  'Carter {4}JR',
#  'Anna COCKRELLSR',
#  'Little {3}']

# %%
len(OfficialTimes)
# Out:
# 52

# %%
Schools = []

for i in range(0,len(OfficialTimes)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Kentucky',
#  'Stanford',
#  'Arkansas',
#  'Arkansas',
#  'Texas A&M',
#  'UCLA',
#  'Kentucky',
#  'Arkansas',
#  'Arizona',
#  'Texas A&M',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Kentucky',
#  'Arkansas',
#  'Kentucky',
#  'Kentucky',
#  'Stanford',
#  'South Carolina',
#  'Arkansas',
#  'Arkansas',
#  'UCLA',
#  'UCLA',
#  'Wyoming',
#  'UCLA',
#  'Arkansas',
#  'Wyoming',
#  'Michigan',
#  'LSU',
#  'Auburn',
#  'South Carolina',
#  'Florida',
#  'Stanford',
#  'South Carolina',
#  'Arizona',
#  'Arizona',
#  'Vanderbilt',
#  'Virginia Tech',
#  'South Carolina',
#  'Illinois',
#  'Arizona',
#  'Texas',
#  'UCLA',
#  'Arkansas',
#  'Arkansas',
#  'Kentucky',
#  'San Diego State',
#  'Arkansas',
#  'Kentucky',
#  'Stanford',
#  'Southern California',
#  'Texas A&M']

# %%
Times = []

# %%
for i in range(0,len(OfficialTimes)):
    Times.append(OfficialTimes[i][:5])
    
Times
# Out:
# ['52.75',
#  '53.21',
#  '53.23',
#  '53.28',
#  '53.51',
#  '53.54',
#  '53.60',
#  '53.71',
#  '53.72',
#  '53.74',
#  '53.75',
#  '53.76',
#  '53.86',
#  '53.96',
#  '54.08',
#  '54.09',
#  '54.15',
#  '54.21',
#  '54.22',
#  '54.23',
#  '54.23',
#  '54.24',
#  '54.32',
#  '54.32',
#  '54.32',
#  '54.37',
#  '54.37',
#  '54.45',
#  '54.45',
#  '54.47',
#  '54.47',
#  '54.48',
#  '54.50',
#  '54.50',
#  '54.52',
#  '54.54',
#  '54.54',
#  '54.55',
#  '54.56',
#  '54.56',
#  '54.59',
#  '54.60',
#  '54.62',
#  '54.65',
#  '54.65',
#  '54.66',
#  '54.66',
#  '54.67',
#  '54.67',
#  '54.67',
#  '54.68',
#  '54.68']

# %%
Womens400mHurdlesDF = pd.DataFrame({'Names': CleanedNames2, 'Times': Times, 'Schools': Schools})

# %%
Womens400mHurdlesDF.to_csv('Womens400mHurdles.csv', index=False)
