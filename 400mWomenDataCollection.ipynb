# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc

# %%
Link400mWomen = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?gender=2&sport=2&div=20527&top=25&event=4"

# %%
page = requests.get(Link400mWomen)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7488009" target="_blank">(1) Britton WILSON</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4923403" target="_blank">49.13</a><a href="https://www.youtube.com/watch?v=-NN5-BK01-I" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7488009" target="_blank">(1) Britton WILSON</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4923403" target="_blank">49.13</a><a href="https://www.youtube.com/watch?v=-NN5-BK01-I" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7690419" target="_blank">(2) Rhasidat ADELEKE</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938121" target="_blank">49.20</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7690419" target="_blank">(2) Rhasidat ADELEKE</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938121" target="_blank">49.20</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938121" target="_blank">49.36</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/8/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938121" target="_blank">49.36</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/8/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4923403" target="_blank">49.40</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/12/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4923403" target="_blank">49.40</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/12/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {4}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81275/4936464" target="_blank">49.51</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West First-Rounds (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/27/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {4}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81275/4936464" target="_blank">49.51</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West First-Rounds (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/27/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {5}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78102/4824405" target="_blank">49.51</a><a href="https://twitter.com/RazorbackTF/status/1647315371765161984" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/14/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {5}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78102/4824405" target="_blank">49.51</a><a href="https://twitter.com/RazorbackTF/status/1647315371765161984" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/14/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Adeleke {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81275/4936464" target="_blank">49.54</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West First-Rounds (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/27/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Adeleke {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81275/4936464" target="_blank">49.54</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West First-Rounds (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/27/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729637" target="_blank">(3) Athing MU</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276119" target="_blank">49.57</a><a href="https://www.youtube.com/watch?v=8MFSeTY7_d8" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/12/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729637" target="_blank">(3) Athing MU</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276119" target="_blank">49.57</a><a href="https://www.youtube.com/watch?v=8MFSeTY7_d8" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/12/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {6}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938121" target="_blank">49.64</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {6}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938121" target="_blank">49.64</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Mu {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70371/4272770" target="_blank">49.68</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West Preliminary (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/29/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Mu {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70371/4272770" target="_blank">49.68</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West Preliminary (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/29/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4206022" target="_blank">(4) Courtney OKOLO</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41857" target="_blank">49.71</a> </td><td style="width: 10%;text-align:right;" title="LSU Alumni Gold (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;">4/23/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4206022" target="_blank">(4) Courtney OKOLO</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41857" target="_blank">49.71</a> </td><td style="width: 10%;text-align:right;" title="LSU Alumni Gold (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;">4/23/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6562293" target="_blank">(5) Lynna IRBY</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57114/3516386" target="_blank">49.80</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6562293" target="_blank">(5) Lynna IRBY</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57114/3516386" target="_blank">49.80</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Mu {3}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70259/4263439" target="_blank">49.84</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Mu {3}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70259/4263439" target="_blank">49.84</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Adeleke {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938121" target="_blank">49.86</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/8/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Adeleke {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938121" target="_blank">49.86</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/8/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7496294" target="_blank">(6) Charokee YOUNG</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73497/4502570" target="_blank">49.87</a> </td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">4/15/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7496294" target="_blank">(6) Charokee YOUNG</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73497/4502570" target="_blank">49.87</a> </td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">4/15/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Adeleke {4}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78102/4824405" target="_blank">49.90</a> </td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/14/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Adeleke {4}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78102/4824405" target="_blank">49.90</a> </td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/14/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7732042" target="_blank">(7) Talitha DIGGS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567521" target="_blank">49.99</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7732042" target="_blank">(7) Talitha DIGGS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567521" target="_blank">49.99</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5095585" target="_blank">(7) Kendall ELLIS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/55278/3508258" target="_blank">49.99</a> </td><td style="width: 10%;text-align:right;" title="Pac-12 Championships (Palo Alto, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5095585" target="_blank">(7) Kendall ELLIS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/55278/3508258" target="_blank">49.99</a> </td><td style="width: 10%;text-align:right;" title="Pac-12 Championships (Palo Alto, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Young {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74108/4462663" target="_blank">50.00</a> </td><td style="width: 10%;text-align:right;" title="Texas at Texas A&amp;M (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/2/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Young {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74108/4462663" target="_blank">50.00</a> </td><td style="width: 10%;text-align:right;" title="Texas at Texas A&amp;M (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/2/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Okolo {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/35585" target="_blank">50.03</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/18/2014</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Okolo {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/35585" target="_blank">50.03</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/18/2014</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Mu {4}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70259/4263439" target="_blank">50.04</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Mu {4}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70259/4263439" target="_blank">50.04</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {7}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4557146" target="_blank">50.05</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {7}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4557146" target="_blank">50.05</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6531200" target="_blank">(9) Sydney MCLAUGHLIN</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/53568/3384018" target="_blank">50.07</a> </td><td style="width: 10%;text-align:right;" title="Florida Relays (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">3/31/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6531200" target="_blank">(9) Sydney MCLAUGHLIN</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/53568/3384018" target="_blank">50.07</a> </td><td style="width: 10%;text-align:right;" title="Florida Relays (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">3/31/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Diggs {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567521" target="_blank">50.08</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Diggs {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567521" target="_blank">50.08</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(10) Monique HENDERSON</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1617">UCLA</a></td><td style="width: 25%;">50.10  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2005</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
# ...
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4675715" target="_blank">Shakima WIMBLEY</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Miami (Fla.)" class="group-logo-inline" src="/images/logos/rankings-article/miami-fla.png" title="Miami (Fla.)"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=947">Miami (Fla.)</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51954/3200400" target="_blank">50.36</a> </td><td style="width: 10%;text-align:right;" title="USATF Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/24/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4675715" target="_blank">Shakima WIMBLEY</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Miami (Fla.)" class="group-logo-inline" src="/images/logos/rankings-article/miami-fla.png" title="Miami (Fla.)"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=947">Miami (Fla.)</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51954/3200400" target="_blank">50.36</a> </td><td style="width: 10%;text-align:right;" title="USATF Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/24/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4675715" target="_blank">Shakima WIMBLEY</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Miami (Fla.)" class="group-logo-inline" src="/images/logos/rankings-article/miami-fla.png" title="Miami (Fla.)"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=947">Miami (Fla.)</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51953" target="_blank">50.36</a> </td><td style="width: 10%;text-align:right;" title="USATF U20 Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/24/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4675715" target="_blank">Shakima WIMBLEY</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Miami (Fla.)" class="group-logo-inline" src="/images/logos/rankings-article/miami-fla.png" title="Miami (Fla.)"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=947">Miami (Fla.)</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51953" target="_blank">50.36</a> </td><td style="width: 10%;text-align:right;" title="USATF U20 Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/24/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5095585" target="_blank">Kendall ELLIS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57132/3517370" target="_blank">50.37</a> </td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/23/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5095585" target="_blank">Kendall ELLIS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57132/3517370" target="_blank">50.37</a> </td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/23/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4206022" target="_blank">Courtney OKOLO</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">50.37</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/2/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4206022" target="_blank">Courtney OKOLO</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">50.37</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/2/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4206022" target="_blank">Courtney OKOLO</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">50.39</a> </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/3/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4206022" target="_blank">Courtney OKOLO</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">50.39</a> </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/3/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>Sherri HOWARD</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Cal State LA" class="group-logo-inline" src="/images/logos/rankings-article/cal-state-la.png" title="Cal State LA"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=202">Cal State LA</a></td><td style="width: 25%;">50.40  </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Los Angeles, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/19/1984</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>Sherri HOWARD</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Cal State LA" class="group-logo-inline" src="/images/logos/rankings-article/cal-state-la.png" title="Cal State LA"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=202">Cal State LA</a></td><td style="width: 25%;">50.40  </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Los Angeles, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/19/1984</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7478918" target="_blank">Rosey EFFIONG</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;">50.41  </td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">7/8/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7478918" target="_blank">Rosey EFFIONG</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;">50.41  </td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">7/8/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7037373" target="_blank">Wadeline JONATHAS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="South Carolina" class="group-logo-inline" src="/images/logos/rankings-article/south-carolina.png" title="South Carolina"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1411">South Carolina</a></td><td style="width: 25%;">50.44  </td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">7/27/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7037373" target="_blank">Wadeline JONATHAS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="South Carolina" class="group-logo-inline" src="/images/logos/rankings-article/south-carolina.png" title="South Carolina"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1411">South Carolina</a></td><td style="width: 25%;">50.44  </td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">7/27/2019</span></td></tr>,
#  <tr><td class="group-logo-50"><a href="https://allathletics.tv/?utc_source=ustfccca&amp;utc_medium=web&amp;utc_campaign=broadcast_schedule_sidebar" target="_blank"><img alt="eaa" src="/images/logos/rankings-article/eaa.png" title="EAA"/></a></td><td style="line-height: 1em;"><a href="https://allathletics.tv/?utc_source=ustfccca&amp;utc_medium=web&amp;utc_campaign=broadcast_schedule_sidebar" target="_blank">European U20 Championships</a></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Britton WILSONJRArkansas49.13📺 5/13/2023',
#   '(1) Britton WILSONJR',
#   '',
#   'Arkansas',
#   '49.13📺 ',
#   '5/13/2023'],
#  [],
#  ['(1) Britton WILSONJR', '', 'Arkansas', '49.13📺 ', '5/13/2023'],
#  ['(2) Rhasidat ADELEKEJRTexas49.20 6/10/2023',
#   '(2) Rhasidat ADELEKEJR',
#   '',
#   'Texas',
#   '49.20 ',
#   '6/10/2023'],
#  [],
#  ['(2) Rhasidat ADELEKEJR', '', 'Texas', '49.20 ', '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}JRArkansas49.36 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}JR',
#   '',
#   'Arkansas',
#   '49.36 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}JR',
#   '',
#   'Arkansas',
#   '49.36 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}JRArkansas49.40 qq = Performance occurred during a non-final round. 5/12/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {3}JR',
#   '',
#   'Arkansas',
#   '49.40 qq = Performance occurred during a non-final round. ',
#   '5/12/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}JR',
#   '',
#   'Arkansas',
#   '49.40 qq = Performance occurred during a non-final round. ',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {4}JRArkansas49.51 qq = Performance occurred during a non-final round. 5/27/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {4}JR',
#   '',
#   'Arkansas',
#   '49.51 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {4}JR',
#   '',
#   'Arkansas',
#   '49.51 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {5}JRArkansas49.51📺 4/14/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {5}JR',
#   '',
#   'Arkansas',
#   '49.51📺 ',
#   '4/14/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {5}JR', '', 'Arkansas', '49.51📺 ', '4/14/2023'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {2}JRTexas49.54 qq = Performance occurred during a non-final round. 5/27/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {2}JR',
#   '',
#   'Texas',
#   '49.54 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Adeleke {2}JR',
#   '',
#   'Texas',
#   '49.54 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['(3) Athing MUFRTexas A&M49.57📺 6/12/2021',
#   '(3) Athing MUFR',
#   '',
#   'Texas A&M',
#   '49.57📺 ',
#   '6/12/2021'],
#  [],
#  ['(3) Athing MUFR', '', 'Texas A&M', '49.57📺 ', '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Wilson {6}JRArkansas49.64 6/10/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {6}JR',
#   '',
#   'Arkansas',
#   '49.64 ',
#   '6/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {6}JR', '', 'Arkansas', '49.64 ', '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FRTexas A&M49.68 qq = Performance occurred during a non-final round. 5/29/2021',
#   '\xa0\xa0\xa0\xa0— Mu {2}FR',
#   '',
#   'Texas A&M',
#   '49.68 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FR',
#   '',
#   'Texas A&M',
#   '49.68 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  ['(4) Courtney OKOLOSRTexas49.71 4/23/2016',
#   '(4) Courtney OKOLOSR',
#   '',
#   'Texas',
#   '49.71 ',
#   '4/23/2016'],
#  [],
#  ['(4) Courtney OKOLOSR', '', 'Texas', '49.71 ', '4/23/2016'],
#  ['(5) Lynna IRBYFRGeorgia49.80 6/9/2018',
#   '(5) Lynna IRBYFR',
#   '',
#   'Georgia',
#   '49.80 ',
#   '6/9/2018'],
#  [],
#  ['(5) Lynna IRBYFR', '', 'Georgia', '49.80 ', '6/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Mu {3}FRTexas A&M49.84 5/13/2021',
#   '\xa0\xa0\xa0\xa0— Mu {3}FR',
#   '',
#   'Texas A&M',
#   '49.84 ',
#   '5/13/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Mu {3}FR', '', 'Texas A&M', '49.84 ', '5/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {3}JRTexas49.86 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {3}JR',
#   '',
#   'Texas',
#   '49.86 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Adeleke {3}JR',
#   '',
#   'Texas',
#   '49.86 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(6) Charokee YOUNGSOTexas A&M49.87 4/15/2022',
#   '(6) Charokee YOUNGSO',
#   '',
#   'Texas A&M',
#   '49.87 ',
#   '4/15/2022'],
#  [],
#  ['(6) Charokee YOUNGSO', '', 'Texas A&M', '49.87 ', '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {4}JRTexas49.90 4/14/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {4}JR',
#   '',
#   'Texas',
#   '49.90 ',
#   '4/14/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Adeleke {4}JR', '', 'Texas', '49.90 ', '4/14/2023'],
#  ['(7) Talitha DIGGSSOFlorida49.99 6/11/2022',
#   '(7) Talitha DIGGSSO',
#   '',
#   'Florida',
#   '49.99 ',
#   '6/11/2022'],
#  [],
#  ['(7) Talitha DIGGSSO', '', 'Florida', '49.99 ', '6/11/2022'],
#  ['(7) Kendall ELLISSRSouthern California49.99 5/13/2018',
#   '(7) Kendall ELLISSR',
#   '',
#   'Southern California',
#   '49.99 ',
#   '5/13/2018'],
#  [],
#  ['(7) Kendall ELLISSR', '', 'Southern California', '49.99 ', '5/13/2018'],
#  ['\xa0\xa0\xa0\xa0— Young {2}SOTexas A&M50.00 4/2/2022',
#   '\xa0\xa0\xa0\xa0— Young {2}SO',
#   '',
#   'Texas A&M',
#   '50.00 ',
#   '4/2/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Young {2}SO', '', 'Texas A&M', '50.00 ', '4/2/2022'],
#  ['\xa0\xa0\xa0\xa0— Okolo {2}SOTexas50.03 5/18/2014',
#   '\xa0\xa0\xa0\xa0— Okolo {2}SO',
#   '',
#   'Texas',
#   '50.03 ',
#   '5/18/2014'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Okolo {2}SO', '', 'Texas', '50.03 ', '5/18/2014'],
#  ['\xa0\xa0\xa0\xa0— Mu {4}FRTexas A&M50.04 qq = Performance occurred during a non-final round. 5/13/2021',
#   '\xa0\xa0\xa0\xa0— Mu {4}FR',
#   '',
#   'Texas A&M',
#   '50.04 qq = Performance occurred during a non-final round. ',
#   '5/13/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Mu {4}FR',
#   '',
#   'Texas A&M',
#   '50.04 qq = Performance occurred during a non-final round. ',
#   '5/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Wilson {7}SOArkansas50.05 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {7}SO',
#   '',
#   'Arkansas',
#   '50.05 ',
#   '5/14/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {7}SO', '', 'Arkansas', '50.05 ', '5/14/2022'],
#  ['(9) Sydney MCLAUGHLINFRKentucky50.07 3/31/2018',
#   '(9) Sydney MCLAUGHLINFR',
#   '',
#   'Kentucky',
#   '50.07 ',
#   '3/31/2018'],
#  [],
#  ['(9) Sydney MCLAUGHLINFR', '', 'Kentucky', '50.07 ', '3/31/2018'],
#  ['\xa0\xa0\xa0\xa0— Diggs {2}SOFlorida50.08 qq = Performance occurred during a non-final round. 6/9/2022',
#   '\xa0\xa0\xa0\xa0— Diggs {2}SO',
#   '',
#   'Florida',
#   '50.08 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Diggs {2}SO',
#   '',
#   'Florida',
#   '50.08 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['(10) Monique HENDERSONSRUCLA50.10  6/11/2005',
#   '(10) Monique HENDERSONSR',
#   '',
#   'UCLA',
#   '50.10  ',
#   '6/11/2005'],
#  [],
#  ['(10) Monique HENDERSONSR', '', 'UCLA', '50.10  ', '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— Irby {2}FRGeorgia50.11 qq = Performance occurred during a non-final round. 6/7/2018',
#   '\xa0\xa0\xa0\xa0— Irby {2}FR',
#   '',
#   'Georgia',
#   '50.11 qq = Performance occurred during a non-final round. ',
#   '6/7/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Irby {2}FR',
#   '',
#   'Georgia',
#   '50.11 qq = Performance occurred during a non-final round. ',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Wilson {8}JRArkansas50.15 qq = Performance occurred during a non-final round. 5/25/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {8}JR',
#   '',
#   'Arkansas',
#   '50.15 qq = Performance occurred during a non-final round. ',
#   '5/25/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {8}JR',
#   '',
#   'Arkansas',
#   '50.15 qq = Performance occurred during a non-final round. ',
#   '5/25/2023'],
#  ['(11) Natasha HASTINGSJRSouth Carolina50.15  6/9/2007',
#   '(11) Natasha HASTINGSJR',
#   '',
#   'South Carolina',
#   '50.15  ',
#   '6/9/2007'],
#  [],
#  ['(11) Natasha HASTINGSJR', '', 'South Carolina', '50.15  ', '6/9/2007'],
#  ['(12) Rosey EFFIONGSOArkansas50.17 qq = Performance occurred during a non-final round. 5/27/2023',
#   '(12) Rosey EFFIONGSO',
#   '',
#   'Arkansas',
#   '50.17 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  [],
#  ['(12) Rosey EFFIONGSO',
#   '',
#   'Arkansas',
#   '50.17 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['(13) Stacey-Ann WILLIAMS JRTexas50.18 qq = Performance occurred during a non-final round. 6/9/2022',
#   '(13) Stacey-Ann WILLIAMS JR',
#   '',
#   'Texas',
#   '50.18 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  [],
#  ['(13) Stacey-Ann WILLIAMS JR',
#   '',
#   'Texas',
#   '50.18 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['(13) Pauline DAVISSRAlabama50.18 AA = Performance occurred at altitude (>1000 meters above sea level) 6/3/1989',
#   '(13) Pauline DAVISSR',
#   '',
#   'Alabama',
#   '50.18 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '6/3/1989'],
#  [],
#  ['(13) Pauline DAVISSR',
#   '',
#   'Alabama',
#   '50.18 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '6/3/1989'],
#  ['\xa0\xa0\xa0\xa0— Ellis {2}SRSouthern California50.19 6/9/2018',
#   '\xa0\xa0\xa0\xa0— Ellis {2}SR',
#   '',
#   'Southern California',
#   '50.19 ',
#   '6/9/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ellis {2}SR',
#   '',
#   'Southern California',
#   '50.19 ',
#   '6/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Williams  {2}JRTexas50.21 AA = Performance occurred at altitude (>1000 meters above sea level) 5/13/2022',
#   '\xa0\xa0\xa0\xa0— Williams  {2}JR',
#   '',
#   'Texas',
#   '50.21 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/13/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Williams  {2}JR',
#   '',
#   'Texas',
#   '50.21 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/13/2022'],
#  ['(15) Nickisha PRYCESOArkansas50.23 6/10/2023',
#   '(15) Nickisha PRYCESO',
#   '',
#   'Arkansas',
#   '50.23 ',
#   '6/10/2023'],
#  [],
#  ['(15) Nickisha PRYCESO', '', 'Arkansas', '50.23 ', '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Okolo {3}SOTexas50.23 6/13/2014\xa0\xa0\xa0\xa0\xa024.1/26.1',
#   '\xa0\xa0\xa0\xa0— Okolo {3}SO',
#   '',
#   'Texas',
#   '50.23 ',
#   '6/13/2014',
#   '\xa0\xa0\xa0\xa0\xa024.1/26.1'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Okolo {3}SO', '', 'Texas', '50.23 ', '6/13/2014'],
#  ['\xa0\xa0\xa0\xa0\xa024.1/26.1'],
#  ['\xa0\xa0\xa0\xa0— Hastings {2}JRSouth Carolina50.23  5/26/2007',
#   '\xa0\xa0\xa0\xa0— Hastings {2}JR',
#   '',
#   'South Carolina',
#   '50.23  ',
#   '5/26/2007'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Hastings {2}JR',
#   '',
#   'South Carolina',
#   '50.23  ',
#   '5/26/2007'],
#  ['(16) Ashley SPENCERSOIllinois50.28 6/7/2013',
#   '(16) Ashley SPENCERSO',
#   '',
#   'Illinois',
#   '50.28 ',
#   '6/7/2013'],
#  [],
#  ['(16) Ashley SPENCERSO', '', 'Illinois', '50.28 ', '6/7/2013'],
#  ['\xa0\xa0\xa0\xa0— Williams {3}JRTexas50.29 qq = Performance occurred during a non-final round. 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Williams {3}JR',
#   '',
#   'Texas',
#   '50.29 qq = Performance occurred during a non-final round. ',
#   '5/14/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Williams {3}JR',
#   '',
#   'Texas',
#   '50.29 qq = Performance occurred during a non-final round. ',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Williams  {4}JRTexas50.29 AA = Performance occurred at altitude (>1000 meters above sea level) 5/13/2022',
#   '\xa0\xa0\xa0\xa0— Williams  {4}JR',
#   '',
#   'Texas',
#   '50.29 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/13/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Williams  {4}JR',
#   '',
#   'Texas',
#   '50.29 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Pryce {2}SOArkansas50.31 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Pryce {2}SO',
#   '',
#   'Arkansas',
#   '50.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pryce {2}SO',
#   '',
#   'Arkansas',
#   '50.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ["(17) Jan'Taijah FORDJRSouthern California50.31 qq = Performance occurred during a non-final round. 6/8/2023",
#   "(17) Jan'Taijah FORDJR",
#   '',
#   'Southern California',
#   '50.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  [],
#  ["(17) Jan'Taijah FORDJR",
#   '',
#   'Southern California',
#   '50.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(18) DeeDee TROTTERJRTennessee50.32  6/12/2004',
#   '(18) DeeDee TROTTERJR',
#   '',
#   'Tennessee',
#   '50.32  ',
#   '6/12/2004'],
#  [],
#  ['(18) DeeDee TROTTERJR', '', 'Tennessee', '50.32  ', '6/12/2004'],
#  ['(19) Jermaisha ARNOLDSOTexas A&M50.33 qq = Performance occurred during a non-final round. 5/27/2023',
#   '(19) Jermaisha ARNOLDSO',
#   '',
#   'Texas A&M',
#   '50.33 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  [],
#  ['(19) Jermaisha ARNOLDSO',
#   '',
#   'Texas A&M',
#   '50.33 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Williams  {5}SOTexas50.34 qq = Performance occurred during a non-final round. 5/29/2021',
#   '\xa0\xa0\xa0\xa0— Williams  {5}SO',
#   '',
#   'Texas',
#   '50.34 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Williams  {5}SO',
#   '',
#   'Texas',
#   '50.34 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Williams {6}SOTexas50.34 qq = Performance occurred during a non-final round. 5/27/2021',
#   '\xa0\xa0\xa0\xa0— Williams {6}SO',
#   '',
#   'Texas',
#   '50.34 qq = Performance occurred during a non-final round. ',
#   '5/27/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Williams {6}SO',
#   '',
#   'Texas',
#   '50.34 qq = Performance occurred during a non-final round. ',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Diggs {3}JRFlorida50.35 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Diggs {3}JR',
#   '',
#   'Florida',
#   '50.35 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Diggs {3}JR',
#   '',
#   'Florida',
#   '50.35 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Okolo {4}SRTexas50.36 6/11/2016\xa0\xa0\xa0\xa0\xa024.3/26.1 (13.6)',
#   '\xa0\xa0\xa0\xa0— Okolo {4}SR',
#   '',
#   'Texas',
#   '50.36 ',
#   '6/11/2016',
#   '\xa0\xa0\xa0\xa0\xa024.3/26.1 (13.6)'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Okolo {4}SR', '', 'Texas', '50.36 ', '6/11/2016'],
#  ['\xa0\xa0\xa0\xa0\xa024.3/26.1 (13.6)'],
#  ['(20) Chrisann GORDONSRTexas50.39 qq = Performance occurred during a non-final round. 6/8/2017',
#   '(20) Chrisann GORDONSR',
#   '',
#   'Texas',
#   '50.39 qq = Performance occurred during a non-final round. ',
#   '6/8/2017'],
#  [],
#  ['(20) Chrisann GORDONSR',
#   '',
#   'Texas',
#   '50.39 qq = Performance occurred during a non-final round. ',
#   '6/8/2017'],
#  ['(20) Joanna ATKINSSOAuburn50.39  6/13/2009',
#   '(20) Joanna ATKINSSO',
#   '',
#   'Auburn',
#   '50.39  ',
#   '6/13/2009'],
#  [],
#  ['(20) Joanna ATKINSSO', '', 'Auburn', '50.39  ', '6/13/2009'],
#  ['(22) Ziyah HOLMANJRMichigan50.40 qq = Performance occurred during a non-final round. 6/8/2023',
#   '(22) Ziyah HOLMANJR',
#   '',
#   'Michigan',
#   '50.40 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  [],
#  ['(22) Ziyah HOLMANJR',
#   '',
#   'Michigan',
#   '50.40 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(22) Shakima WIMBLEYSRMiami (Fla.)50.40 5/14/2017',
#   '(22) Shakima WIMBLEYSR',
#   '',
#   'Miami (Fla.)',
#   '50.40 ',
#   '5/14/2017'],
#  [],
#  ['(22) Shakima WIMBLEYSR', '', 'Miami (Fla.)', '50.40 ', '5/14/2017'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}JRSouthern California50.44 5/12/2023',
#   '\xa0\xa0\xa0\xa0— Jones {2}JR',
#   '',
#   'Southern California',
#   '50.44 ',
#   '5/12/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Jones {2}JR',
#   '',
#   'Southern California',
#   '50.44 ',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Irby {3}FRGeorgia50.44 qq = Performance occurred during a non-final round. 5/25/2018',
#   '\xa0\xa0\xa0\xa0— Irby {3}FR',
#   '',
#   'Georgia',
#   '50.44 qq = Performance occurred during a non-final round. ',
#   '5/25/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Irby {3}FR',
#   '',
#   'Georgia',
#   '50.44 qq = Performance occurred during a non-final round. ',
#   '5/25/2018'],
#  ['(24) Kennedy SIMONJRTexas50.45 qq = Performance occurred during a non-final round. 6/9/2022',
#   '(24) Kennedy SIMONJR',
#   '',
#   'Texas',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  [],
#  ['(24) Kennedy SIMONJR',
#   '',
#   'Texas',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Young {3}SOTexas A&M50.45 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Young {3}SO',
#   '',
#   'Texas A&M',
#   '50.45 ',
#   '5/14/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Young {3}SO', '', 'Texas A&M', '50.45 ', '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Ellis {3}JRSouthern California50.45 qq = Performance occurred during a non-final round. 5/27/2017',
#   '\xa0\xa0\xa0\xa0— Ellis {3}JR',
#   '',
#   'Southern California',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '5/27/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ellis {3}JR',
#   '',
#   'Southern California',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '5/27/2017'],
#  ['\xa0\xa0\xa0\xa0— Ellis {4}JRSouthern California50.45 qq = Performance occurred during a non-final round. 5/26/2017',
#   '\xa0\xa0\xa0\xa0— Ellis {4}JR',
#   '',
#   'Southern California',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '5/26/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Ellis {4}JR',
#   '',
#   'Southern California',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '5/26/2017'],
#  ['\xa0\xa0\xa0\xa0— Young {4}SOTexas A&M50.46 qq = Performance occurred during a non-final round. 6/9/2022',
#   '\xa0\xa0\xa0\xa0— Young {4}SO',
#   '',
#   'Texas A&M',
#   '50.46 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Young {4}SO',
#   '',
#   'Texas A&M',
#   '50.46 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['(25) Kendall BAISDENFRTexas50.46 5/18/2014',
#   '(25) Kendall BAISDENFR',
#   '',
#   'Texas',
#   '50.46 ',
#   '5/18/2014'],
#  [],
#  ['(25) Kendall BAISDENFR', '', 'Texas', '50.46 ', '5/18/2014'],
#  ['Additional Out-of-Season Bests'],
#  ['Wadeline JONATHASJRSouth Carolina49.60📺 10/3/2019',
#   'Wadeline JONATHASJR',
#   '',
#   'South Carolina',
#   '49.60📺 ',
#   '10/3/2019'],
#  [],
#  ['Wadeline JONATHASJR', '', 'South Carolina', '49.60📺 ', '10/3/2019'],
#  ['Britton WILSONJRArkansas49.79  7/8/2023',
#   'Britton WILSONJR',
#   '',
#   'Arkansas',
#   '49.79  ',
#   '7/8/2023'],
#  [],
#  ['Britton WILSONJR', '', 'Arkansas', '49.79  ', '7/8/2023'],
#  ['Natasha HASTINGSJRSouth Carolina49.84  6/23/2007',
#   'Natasha HASTINGSJR',
#   '',
#   'South Carolina',
#   '49.84  ',
#   '6/23/2007'],
#  [],
#  ['Natasha HASTINGSJR', '', 'South Carolina', '49.84  ', '6/23/2007'],
#  ['Sanya RICHARDSSOTexas49.89  7/17/2004',
#   'Sanya RICHARDSSO',
#   '',
#   'Texas',
#   '49.89  ',
#   '7/17/2004'],
#  [],
#  ['Sanya RICHARDSSO', '', 'Texas', '49.89  ', '7/17/2004'],
#  ['Marita PAYNEFlorida State49.91  8/6/1984',
#   'Marita PAYNE',
#   '',
#   'Florida State',
#   '49.91  ',
#   '8/6/1984'],
#  [],
#  ['Marita PAYNE', '', 'Florida State', '49.91  ', '8/6/1984'],
#  ['Talitha DIGGSJRFlorida49.93  7/8/2023',
#   'Talitha DIGGSJR',
#   '',
#   'Florida',
#   '49.93  ',
#   '7/8/2023'],
#  [],
#  ['Talitha DIGGSJR', '', 'Florida', '49.93  ', '7/8/2023'],
#  ['Lillie LEATHERWOODAlabama49.95  6/27/1987',
#   'Lillie LEATHERWOOD',
#   '',
#   'Alabama',
#   '49.95  ',
#   '6/27/1987'],
#  [],
#  ['Lillie LEATHERWOOD', '', 'Alabama', '49.95  ', '6/27/1987'],
#  ['Monique HENDERSONUCLA49.96  6/25/2005',
#   'Monique HENDERSON',
#   '',
#   'UCLA',
#   '49.96  ',
#   '6/25/2005'],
#  [],
#  ['Monique HENDERSON', '', 'UCLA', '49.96  ', '6/25/2005'],
#  ['Rhasidat ADELEKEJRTexas49.99  7/21/2023',
#   'Rhasidat ADELEKEJR',
#   '',
#   'Texas',
#   '49.99  ',
#   '7/21/2023'],
#  [],
#  ['Rhasidat ADELEKEJR', '', 'Texas', '49.99  ', '7/21/2023'],
#  ['Kendall ELLISJRSouthern California50.00 6/24/2017',
#   'Kendall ELLISJR',
#   '',
#   'Southern California',
#   '50.00 ',
#   '6/24/2017'],
#  [],
#  ['Kendall ELLISJR', '', 'Southern California', '50.00 ', '6/24/2017'],
#  ['Kendall ELLISJRSouthern California50.00 6/24/2017',
#   'Kendall ELLISJR',
#   '',
#   'Southern California',
#   '50.00 ',
#   '6/24/2017'],
#  [],
#  ['Kendall ELLISJR', '', 'Southern California', '50.00 ', '6/24/2017'],
#  ['DeeDee TROTTERJRTennessee50.00  8/24/2004',
#   'DeeDee TROTTERJR',
#   '',
#   'Tennessee',
#   '50.00  ',
#   '8/24/2004'],
#  [],
#  ['DeeDee TROTTERJR', '', 'Tennessee', '50.00  ', '8/24/2004'],
#  ['Marita PAYNEFlorida State50.06  8/10/1983',
#   'Marita PAYNE',
#   '',
#   'Florida State',
#   '50.06  ',
#   '8/10/1983'],
#  [],
#  ['Marita PAYNE', '', 'Florida State', '50.06  ', '8/10/1983'],
#  ['Wadeline JONATHASJRSouth Carolina50.07 qq = Performance occurred during a non-final round. 10/1/2019',
#   'Wadeline JONATHASJR',
#   '',
#   'South Carolina',
#   '50.07 qq = Performance occurred during a non-final round. ',
#   '10/1/2019'],
#  [],
#  ['Wadeline JONATHASJR',
#   '',
#   'South Carolina',
#   '50.07 qq = Performance occurred during a non-final round. ',
#   '10/1/2019'],
#  ['Britton WILSONJRArkansas50.08 qq = Performance occurred during a non-final round. 7/6/2023',
#   'Britton WILSONJR',
#   '',
#   'Arkansas',
#   '50.08 qq = Performance occurred during a non-final round. ',
#   '7/6/2023'],
#  [],
#  ['Britton WILSONJR',
#   '',
#   'Arkansas',
#   '50.08 qq = Performance occurred during a non-final round. ',
#   '7/6/2023'],
#  ['Sanya RICHARDSSOTexas50.11 qq = Performance occurred during a non-final round. 8/21/2004',
#   'Sanya RICHARDSSO',
#   '',
#   'Texas',
#   '50.11 qq = Performance occurred during a non-final round. ',
#   '8/21/2004'],
#  [],
#  ['Sanya RICHARDSSO',
#   '',
#   'Texas',
#   '50.11 qq = Performance occurred during a non-final round. ',
#   '8/21/2004'],
#  ['Juliet CAMPBELLAuburn50.11  7/3/1993',
#   'Juliet CAMPBELL',
#   '',
#   'Auburn',
#   '50.11  ',
#   '7/3/1993'],
#  [],
#  ['Juliet CAMPBELL', '', 'Auburn', '50.11  ', '7/3/1993'],
#  ['Chrisann GORDONSRTexas50.13  6/25/2017',
#   'Chrisann GORDONSR',
#   '',
#   'Texas',
#   '50.13  ',
#   '6/25/2017'],
#  [],
#  ['Chrisann GORDONSR', '', 'Texas', '50.13  ', '6/25/2017'],
#  ['Stacey Ann WILLIAMSSOTexas50.14  6/27/2021',
#   'Stacey Ann WILLIAMSSO',
#   '',
#   'Texas',
#   '50.14  ',
#   '6/27/2021'],
#  [],
#  ['Stacey Ann WILLIAMSSO', '', 'Texas', '50.14  ', '6/27/2021'],
#  ['Ximena RESTREPONebraska50.14  8/5/1991',
#   'Ximena RESTREPO',
#   '',
#   'Nebraska',
#   '50.14  ',
#   '8/5/1991'],
#  [],
#  ['Ximena RESTREPO', '', 'Nebraska', '50.14  ', '8/5/1991'],
#  ['Charokee YOUNGSOTexas A&M50.19 qq = Performance occurred during a non-final round. 6/25/2022',
#   'Charokee YOUNGSO',
#   '',
#   'Texas A&M',
#   '50.19 qq = Performance occurred during a non-final round. ',
#   '6/25/2022'],
#  [],
#  ['Charokee YOUNGSO',
#   '',
#   'Texas A&M',
#   '50.19 qq = Performance occurred during a non-final round. ',
#   '6/25/2022'],
#  ['Sanya RICHARDSSOTexas50.19  8/24/2004',
#   'Sanya RICHARDSSO',
#   '',
#   'Texas',
#   '50.19  ',
#   '8/24/2004'],
#  [],
#  ['Sanya RICHARDSSO', '', 'Texas', '50.19  ', '8/24/2004'],
#  ['Nickisha PRYCESOArkansas50.21  7/9/2023',
#   'Nickisha PRYCESO',
#   '',
#   'Arkansas',
#   '50.21  ',
#   '7/9/2023'],
#  [],
#  ['Nickisha PRYCESO', '', 'Arkansas', '50.21  ', '7/9/2023'],
#  ['Talitha DIGGSSOFlorida50.22  6/25/2022',
#   'Talitha DIGGSSO',
#   '',
#   'Florida',
#   '50.22  ',
#   '6/25/2022'],
#  [],
#  ['Talitha DIGGSSO', '', 'Florida', '50.22  ', '6/25/2022'],
#  ['Kendall ELLISJRSouthern California50.24 qq = Performance occurred during a non-final round. 6/23/2017',
#   'Kendall ELLISJR',
#   '',
#   'Southern California',
#   '50.24 qq = Performance occurred during a non-final round. ',
#   '6/23/2017'],
#  [],
#  ['Kendall ELLISJR',
#   '',
#   'Southern California',
#   '50.24 qq = Performance occurred during a non-final round. ',
#   '6/23/2017'],
#  ['Kendall ELLISJRSouthern California50.24 qq = Performance occurred during a non-final round. 6/23/2017',
#   'Kendall ELLISJR',
#   '',
#   'Southern California',
#   '50.24 qq = Performance occurred during a non-final round. ',
#   '6/23/2017'],
#  [],
#  ['Kendall ELLISJR',
#   '',
#   'Southern California',
#   '50.24 qq = Performance occurred during a non-final round. ',
#   '6/23/2017'],
#  ['Taylor ELLIS-WATSONSRArkansas50.25 7/3/2016',
#   'Taylor ELLIS-WATSONSR',
#   '',
#   'Arkansas',
#   '50.25 ',
#   '7/3/2016'],
#  [],
#  ['Taylor ELLIS-WATSONSR', '', 'Arkansas', '50.25 ', '7/3/2016'],
#  ['Chrisann GORDONSRTexas50.30 qq = Performance occurred during a non-final round. 6/24/2017',
#   'Chrisann GORDONSR',
#   '',
#   'Texas',
#   '50.30 qq = Performance occurred during a non-final round. ',
#   '6/24/2017'],
#  [],
#  ['Chrisann GORDONSR',
#   '',
#   'Texas',
#   '50.30 qq = Performance occurred during a non-final round. ',
#   '6/24/2017'],
#  ['Maicel MALONEArizona State50.33  7/7/1991',
#   'Maicel MALONE',
#   '',
#   'Arizona State',
#   '50.33  ',
#   '7/7/1991'],
#  [],
#  ['Maicel MALONE', '', 'Arizona State', '50.33  ', '7/7/1991'],
#  ['Shakima WIMBLEYSRMiami (Fla.)50.36 6/24/2017',
#   'Shakima WIMBLEYSR',
#   '',
#   'Miami (Fla.)',
#   '50.36 ',
#   '6/24/2017'],
#  [],
#  ['Shakima WIMBLEYSR', '', 'Miami (Fla.)', '50.36 ', '6/24/2017'],
#  ['Shakima WIMBLEYSRMiami (Fla.)50.36 6/24/2017',
#   'Shakima WIMBLEYSR',
#   '',
#   'Miami (Fla.)',
#   '50.36 ',
#   '6/24/2017'],
#  [],
#  ['Shakima WIMBLEYSR', '', 'Miami (Fla.)', '50.36 ', '6/24/2017'],
#  ['Kendall ELLISSRSouthern California50.37 6/23/2018',
#   'Kendall ELLISSR',
#   '',
#   'Southern California',
#   '50.37 ',
#   '6/23/2018'],
#  [],
#  ['Kendall ELLISSR', '', 'Southern California', '50.37 ', '6/23/2018'],
#  ['Courtney OKOLOSRTexas50.37 qq = Performance occurred during a non-final round. 7/2/2016',
#   'Courtney OKOLOSR',
#   '',
#   'Texas',
#   '50.37 qq = Performance occurred during a non-final round. ',
#   '7/2/2016'],
#  [],
#  ['Courtney OKOLOSR',
#   '',
#   'Texas',
#   '50.37 qq = Performance occurred during a non-final round. ',
#   '7/2/2016'],
#  ['Courtney OKOLOSRTexas50.39 7/3/2016',
#   'Courtney OKOLOSR',
#   '',
#   'Texas',
#   '50.39 ',
#   '7/3/2016'],
#  [],
#  ['Courtney OKOLOSR', '', 'Texas', '50.39 ', '7/3/2016'],
#  ['Sherri HOWARDCal State LA50.40  6/19/1984',
#   'Sherri HOWARD',
#   '',
#   'Cal State LA',
#   '50.40  ',
#   '6/19/1984'],
#  [],
#  ['Sherri HOWARD', '', 'Cal State LA', '50.40  ', '6/19/1984'],
#  ['Rosey EFFIONGSOArkansas50.41  7/8/2023',
#   'Rosey EFFIONGSO',
#   '',
#   'Arkansas',
#   '50.41  ',
#   '7/8/2023'],
#  [],
#  ['Rosey EFFIONGSO', '', 'Arkansas', '50.41  ', '7/8/2023'],
#  ['Wadeline JONATHASJRSouth Carolina50.44  7/27/2019',
#   'Wadeline JONATHASJR',
#   '',
#   'South Carolina',
#   '50.44  ',
#   '7/27/2019'],
#  [],
#  ['Wadeline JONATHASJR', '', 'South Carolina', '50.44  ', '7/27/2019'],
#  ['', 'European U20 Championships'],
#  ['', '', '', '']]

# %%
rows[180]
# Out:
# ['(25) Kendall BAISDENFR', '', 'Texas', '50.46 ', '5/18/2014']

# %%
len(rows)
# Out:
# 295

# %%
RealRows = []

# %%
for i in range(0,181):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [['(1) Britton WILSONJRArkansas49.13📺 5/13/2023',
#   '(1) Britton WILSONJR',
#   '',
#   'Arkansas',
#   '49.13📺 ',
#   '5/13/2023'],
#  ['(1) Britton WILSONJR', '', 'Arkansas', '49.13📺 ', '5/13/2023'],
#  ['(2) Rhasidat ADELEKEJRTexas49.20 6/10/2023',
#   '(2) Rhasidat ADELEKEJR',
#   '',
#   'Texas',
#   '49.20 ',
#   '6/10/2023'],
#  ['(2) Rhasidat ADELEKEJR', '', 'Texas', '49.20 ', '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}JRArkansas49.36 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}JR',
#   '',
#   'Arkansas',
#   '49.36 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}JR',
#   '',
#   'Arkansas',
#   '49.36 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}JRArkansas49.40 qq = Performance occurred during a non-final round. 5/12/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {3}JR',
#   '',
#   'Arkansas',
#   '49.40 qq = Performance occurred during a non-final round. ',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}JR',
#   '',
#   'Arkansas',
#   '49.40 qq = Performance occurred during a non-final round. ',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {4}JRArkansas49.51 qq = Performance occurred during a non-final round. 5/27/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {4}JR',
#   '',
#   'Arkansas',
#   '49.51 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {4}JR',
#   '',
#   'Arkansas',
#   '49.51 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {5}JRArkansas49.51📺 4/14/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {5}JR',
#   '',
#   'Arkansas',
#   '49.51📺 ',
#   '4/14/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {5}JR', '', 'Arkansas', '49.51📺 ', '4/14/2023'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {2}JRTexas49.54 qq = Performance occurred during a non-final round. 5/27/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {2}JR',
#   '',
#   'Texas',
#   '49.54 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {2}JR',
#   '',
#   'Texas',
#   '49.54 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['(3) Athing MUFRTexas A&M49.57📺 6/12/2021',
#   '(3) Athing MUFR',
#   '',
#   'Texas A&M',
#   '49.57📺 ',
#   '6/12/2021'],
#  ['(3) Athing MUFR', '', 'Texas A&M', '49.57📺 ', '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Wilson {6}JRArkansas49.64 6/10/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {6}JR',
#   '',
#   'Arkansas',
#   '49.64 ',
#   '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {6}JR', '', 'Arkansas', '49.64 ', '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FRTexas A&M49.68 qq = Performance occurred during a non-final round. 5/29/2021',
#   '\xa0\xa0\xa0\xa0— Mu {2}FR',
#   '',
#   'Texas A&M',
#   '49.68 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FR',
#   '',
#   'Texas A&M',
#   '49.68 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  ['(4) Courtney OKOLOSRTexas49.71 4/23/2016',
#   '(4) Courtney OKOLOSR',
#   '',
#   'Texas',
#   '49.71 ',
#   '4/23/2016'],
#  ['(4) Courtney OKOLOSR', '', 'Texas', '49.71 ', '4/23/2016'],
#  ['(5) Lynna IRBYFRGeorgia49.80 6/9/2018',
#   '(5) Lynna IRBYFR',
#   '',
#   'Georgia',
#   '49.80 ',
#   '6/9/2018'],
#  ['(5) Lynna IRBYFR', '', 'Georgia', '49.80 ', '6/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Mu {3}FRTexas A&M49.84 5/13/2021',
#   '\xa0\xa0\xa0\xa0— Mu {3}FR',
#   '',
#   'Texas A&M',
#   '49.84 ',
#   '5/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Mu {3}FR', '', 'Texas A&M', '49.84 ', '5/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {3}JRTexas49.86 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {3}JR',
#   '',
#   'Texas',
#   '49.86 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {3}JR',
#   '',
#   'Texas',
#   '49.86 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(6) Charokee YOUNGSOTexas A&M49.87 4/15/2022',
#   '(6) Charokee YOUNGSO',
#   '',
#   'Texas A&M',
#   '49.87 ',
#   '4/15/2022'],
#  ['(6) Charokee YOUNGSO', '', 'Texas A&M', '49.87 ', '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {4}JRTexas49.90 4/14/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {4}JR',
#   '',
#   'Texas',
#   '49.90 ',
#   '4/14/2023'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {4}JR', '', 'Texas', '49.90 ', '4/14/2023'],
#  ['(7) Talitha DIGGSSOFlorida49.99 6/11/2022',
#   '(7) Talitha DIGGSSO',
#   '',
#   'Florida',
#   '49.99 ',
#   '6/11/2022'],
#  ['(7) Talitha DIGGSSO', '', 'Florida', '49.99 ', '6/11/2022'],
#  ['(7) Kendall ELLISSRSouthern California49.99 5/13/2018',
#   '(7) Kendall ELLISSR',
#   '',
#   'Southern California',
#   '49.99 ',
#   '5/13/2018'],
#  ['(7) Kendall ELLISSR', '', 'Southern California', '49.99 ', '5/13/2018'],
#  ['\xa0\xa0\xa0\xa0— Young {2}SOTexas A&M50.00 4/2/2022',
#   '\xa0\xa0\xa0\xa0— Young {2}SO',
#   '',
#   'Texas A&M',
#   '50.00 ',
#   '4/2/2022'],
#  ['\xa0\xa0\xa0\xa0— Young {2}SO', '', 'Texas A&M', '50.00 ', '4/2/2022'],
#  ['\xa0\xa0\xa0\xa0— Okolo {2}SOTexas50.03 5/18/2014',
#   '\xa0\xa0\xa0\xa0— Okolo {2}SO',
#   '',
#   'Texas',
#   '50.03 ',
#   '5/18/2014'],
#  ['\xa0\xa0\xa0\xa0— Okolo {2}SO', '', 'Texas', '50.03 ', '5/18/2014'],
#  ['\xa0\xa0\xa0\xa0— Mu {4}FRTexas A&M50.04 qq = Performance occurred during a non-final round. 5/13/2021',
#   '\xa0\xa0\xa0\xa0— Mu {4}FR',
#   '',
#   'Texas A&M',
#   '50.04 qq = Performance occurred during a non-final round. ',
#   '5/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Mu {4}FR',
#   '',
#   'Texas A&M',
#   '50.04 qq = Performance occurred during a non-final round. ',
#   '5/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Wilson {7}SOArkansas50.05 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {7}SO',
#   '',
#   'Arkansas',
#   '50.05 ',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {7}SO', '', 'Arkansas', '50.05 ', '5/14/2022'],
#  ['(9) Sydney MCLAUGHLINFRKentucky50.07 3/31/2018',
#   '(9) Sydney MCLAUGHLINFR',
#   '',
#   'Kentucky',
#   '50.07 ',
#   '3/31/2018'],
#  ['(9) Sydney MCLAUGHLINFR', '', 'Kentucky', '50.07 ', '3/31/2018'],
#  ['\xa0\xa0\xa0\xa0— Diggs {2}SOFlorida50.08 qq = Performance occurred during a non-final round. 6/9/2022',
#   '\xa0\xa0\xa0\xa0— Diggs {2}SO',
#   '',
#   'Florida',
#   '50.08 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Diggs {2}SO',
#   '',
#   'Florida',
#   '50.08 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['(10) Monique HENDERSONSRUCLA50.10  6/11/2005',
#   '(10) Monique HENDERSONSR',
#   '',
#   'UCLA',
#   '50.10  ',
#   '6/11/2005'],
#  ['(10) Monique HENDERSONSR', '', 'UCLA', '50.10  ', '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— Irby {2}FRGeorgia50.11 qq = Performance occurred during a non-final round. 6/7/2018',
#   '\xa0\xa0\xa0\xa0— Irby {2}FR',
#   '',
#   'Georgia',
#   '50.11 qq = Performance occurred during a non-final round. ',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Irby {2}FR',
#   '',
#   'Georgia',
#   '50.11 qq = Performance occurred during a non-final round. ',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Wilson {8}JRArkansas50.15 qq = Performance occurred during a non-final round. 5/25/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {8}JR',
#   '',
#   'Arkansas',
#   '50.15 qq = Performance occurred during a non-final round. ',
#   '5/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {8}JR',
#   '',
#   'Arkansas',
#   '50.15 qq = Performance occurred during a non-final round. ',
#   '5/25/2023'],
#  ['(11) Natasha HASTINGSJRSouth Carolina50.15  6/9/2007',
#   '(11) Natasha HASTINGSJR',
#   '',
#   'South Carolina',
#   '50.15  ',
#   '6/9/2007'],
#  ['(11) Natasha HASTINGSJR', '', 'South Carolina', '50.15  ', '6/9/2007'],
#  ['(12) Rosey EFFIONGSOArkansas50.17 qq = Performance occurred during a non-final round. 5/27/2023',
#   '(12) Rosey EFFIONGSO',
#   '',
#   'Arkansas',
#   '50.17 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['(12) Rosey EFFIONGSO',
#   '',
#   'Arkansas',
#   '50.17 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['(13) Stacey-Ann WILLIAMS JRTexas50.18 qq = Performance occurred during a non-final round. 6/9/2022',
#   '(13) Stacey-Ann WILLIAMS JR',
#   '',
#   'Texas',
#   '50.18 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['(13) Stacey-Ann WILLIAMS JR',
#   '',
#   'Texas',
#   '50.18 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['(13) Pauline DAVISSRAlabama50.18 AA = Performance occurred at altitude (>1000 meters above sea level) 6/3/1989',
#   '(13) Pauline DAVISSR',
#   '',
#   'Alabama',
#   '50.18 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '6/3/1989'],
#  ['(13) Pauline DAVISSR',
#   '',
#   'Alabama',
#   '50.18 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '6/3/1989'],
#  ['\xa0\xa0\xa0\xa0— Ellis {2}SRSouthern California50.19 6/9/2018',
#   '\xa0\xa0\xa0\xa0— Ellis {2}SR',
#   '',
#   'Southern California',
#   '50.19 ',
#   '6/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Ellis {2}SR',
#   '',
#   'Southern California',
#   '50.19 ',
#   '6/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Williams  {2}JRTexas50.21 AA = Performance occurred at altitude (>1000 meters above sea level) 5/13/2022',
#   '\xa0\xa0\xa0\xa0— Williams  {2}JR',
#   '',
#   'Texas',
#   '50.21 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Williams  {2}JR',
#   '',
#   'Texas',
#   '50.21 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/13/2022'],
#  ['(15) Nickisha PRYCESOArkansas50.23 6/10/2023',
#   '(15) Nickisha PRYCESO',
#   '',
#   'Arkansas',
#   '50.23 ',
#   '6/10/2023'],
#  ['(15) Nickisha PRYCESO', '', 'Arkansas', '50.23 ', '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Okolo {3}SOTexas50.23 6/13/2014\xa0\xa0\xa0\xa0\xa024.1/26.1',
#   '\xa0\xa0\xa0\xa0— Okolo {3}SO',
#   '',
#   'Texas',
#   '50.23 ',
#   '6/13/2014',
#   '\xa0\xa0\xa0\xa0\xa024.1/26.1'],
#  ['\xa0\xa0\xa0\xa0— Okolo {3}SO', '', 'Texas', '50.23 ', '6/13/2014'],
#  ['\xa0\xa0\xa0\xa0— Hastings {2}JRSouth Carolina50.23  5/26/2007',
#   '\xa0\xa0\xa0\xa0— Hastings {2}JR',
#   '',
#   'South Carolina',
#   '50.23  ',
#   '5/26/2007'],
#  ['\xa0\xa0\xa0\xa0— Hastings {2}JR',
#   '',
#   'South Carolina',
#   '50.23  ',
#   '5/26/2007'],
#  ['(16) Ashley SPENCERSOIllinois50.28 6/7/2013',
#   '(16) Ashley SPENCERSO',
#   '',
#   'Illinois',
#   '50.28 ',
#   '6/7/2013'],
#  ['(16) Ashley SPENCERSO', '', 'Illinois', '50.28 ', '6/7/2013'],
#  ['\xa0\xa0\xa0\xa0— Williams {3}JRTexas50.29 qq = Performance occurred during a non-final round. 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Williams {3}JR',
#   '',
#   'Texas',
#   '50.29 qq = Performance occurred during a non-final round. ',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Williams {3}JR',
#   '',
#   'Texas',
#   '50.29 qq = Performance occurred during a non-final round. ',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Williams  {4}JRTexas50.29 AA = Performance occurred at altitude (>1000 meters above sea level) 5/13/2022',
#   '\xa0\xa0\xa0\xa0— Williams  {4}JR',
#   '',
#   'Texas',
#   '50.29 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Williams  {4}JR',
#   '',
#   'Texas',
#   '50.29 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Pryce {2}SOArkansas50.31 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Pryce {2}SO',
#   '',
#   'Arkansas',
#   '50.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Pryce {2}SO',
#   '',
#   'Arkansas',
#   '50.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ["(17) Jan'Taijah FORDJRSouthern California50.31 qq = Performance occurred during a non-final round. 6/8/2023",
#   "(17) Jan'Taijah FORDJR",
#   '',
#   'Southern California',
#   '50.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ["(17) Jan'Taijah FORDJR",
#   '',
#   'Southern California',
#   '50.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(18) DeeDee TROTTERJRTennessee50.32  6/12/2004',
#   '(18) DeeDee TROTTERJR',
#   '',
#   'Tennessee',
#   '50.32  ',
#   '6/12/2004'],
#  ['(18) DeeDee TROTTERJR', '', 'Tennessee', '50.32  ', '6/12/2004'],
#  ['(19) Jermaisha ARNOLDSOTexas A&M50.33 qq = Performance occurred during a non-final round. 5/27/2023',
#   '(19) Jermaisha ARNOLDSO',
#   '',
#   'Texas A&M',
#   '50.33 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['(19) Jermaisha ARNOLDSO',
#   '',
#   'Texas A&M',
#   '50.33 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Williams  {5}SOTexas50.34 qq = Performance occurred during a non-final round. 5/29/2021',
#   '\xa0\xa0\xa0\xa0— Williams  {5}SO',
#   '',
#   'Texas',
#   '50.34 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Williams  {5}SO',
#   '',
#   'Texas',
#   '50.34 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Williams {6}SOTexas50.34 qq = Performance occurred during a non-final round. 5/27/2021',
#   '\xa0\xa0\xa0\xa0— Williams {6}SO',
#   '',
#   'Texas',
#   '50.34 qq = Performance occurred during a non-final round. ',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Williams {6}SO',
#   '',
#   'Texas',
#   '50.34 qq = Performance occurred during a non-final round. ',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Diggs {3}JRFlorida50.35 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Diggs {3}JR',
#   '',
#   'Florida',
#   '50.35 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Diggs {3}JR',
#   '',
#   'Florida',
#   '50.35 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Okolo {4}SRTexas50.36 6/11/2016\xa0\xa0\xa0\xa0\xa024.3/26.1 (13.6)',
#   '\xa0\xa0\xa0\xa0— Okolo {4}SR',
#   '',
#   'Texas',
#   '50.36 ',
#   '6/11/2016',
#   '\xa0\xa0\xa0\xa0\xa024.3/26.1 (13.6)'],
#  ['\xa0\xa0\xa0\xa0— Okolo {4}SR', '', 'Texas', '50.36 ', '6/11/2016'],
#  ['(20) Chrisann GORDONSRTexas50.39 qq = Performance occurred during a non-final round. 6/8/2017',
#   '(20) Chrisann GORDONSR',
#   '',
#   'Texas',
#   '50.39 qq = Performance occurred during a non-final round. ',
#   '6/8/2017'],
#  ['(20) Chrisann GORDONSR',
#   '',
#   'Texas',
#   '50.39 qq = Performance occurred during a non-final round. ',
#   '6/8/2017'],
#  ['(20) Joanna ATKINSSOAuburn50.39  6/13/2009',
#   '(20) Joanna ATKINSSO',
#   '',
#   'Auburn',
#   '50.39  ',
#   '6/13/2009'],
#  ['(20) Joanna ATKINSSO', '', 'Auburn', '50.39  ', '6/13/2009'],
#  ['(22) Ziyah HOLMANJRMichigan50.40 qq = Performance occurred during a non-final round. 6/8/2023',
#   '(22) Ziyah HOLMANJR',
#   '',
#   'Michigan',
#   '50.40 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(22) Ziyah HOLMANJR',
#   '',
#   'Michigan',
#   '50.40 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(22) Shakima WIMBLEYSRMiami (Fla.)50.40 5/14/2017',
#   '(22) Shakima WIMBLEYSR',
#   '',
#   'Miami (Fla.)',
#   '50.40 ',
#   '5/14/2017'],
#  ['(22) Shakima WIMBLEYSR', '', 'Miami (Fla.)', '50.40 ', '5/14/2017'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}JRSouthern California50.44 5/12/2023',
#   '\xa0\xa0\xa0\xa0— Jones {2}JR',
#   '',
#   'Southern California',
#   '50.44 ',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}JR',
#   '',
#   'Southern California',
#   '50.44 ',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Irby {3}FRGeorgia50.44 qq = Performance occurred during a non-final round. 5/25/2018',
#   '\xa0\xa0\xa0\xa0— Irby {3}FR',
#   '',
#   'Georgia',
#   '50.44 qq = Performance occurred during a non-final round. ',
#   '5/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Irby {3}FR',
#   '',
#   'Georgia',
#   '50.44 qq = Performance occurred during a non-final round. ',
#   '5/25/2018'],
#  ['(24) Kennedy SIMONJRTexas50.45 qq = Performance occurred during a non-final round. 6/9/2022',
#   '(24) Kennedy SIMONJR',
#   '',
#   'Texas',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['(24) Kennedy SIMONJR',
#   '',
#   'Texas',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Young {3}SOTexas A&M50.45 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Young {3}SO',
#   '',
#   'Texas A&M',
#   '50.45 ',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Young {3}SO', '', 'Texas A&M', '50.45 ', '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Ellis {3}JRSouthern California50.45 qq = Performance occurred during a non-final round. 5/27/2017',
#   '\xa0\xa0\xa0\xa0— Ellis {3}JR',
#   '',
#   'Southern California',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '5/27/2017'],
#  ['\xa0\xa0\xa0\xa0— Ellis {3}JR',
#   '',
#   'Southern California',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '5/27/2017'],
#  ['\xa0\xa0\xa0\xa0— Ellis {4}JRSouthern California50.45 qq = Performance occurred during a non-final round. 5/26/2017',
#   '\xa0\xa0\xa0\xa0— Ellis {4}JR',
#   '',
#   'Southern California',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '5/26/2017'],
#  ['\xa0\xa0\xa0\xa0— Ellis {4}JR',
#   '',
#   'Southern California',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '5/26/2017'],
#  ['\xa0\xa0\xa0\xa0— Young {4}SOTexas A&M50.46 qq = Performance occurred during a non-final round. 6/9/2022',
#   '\xa0\xa0\xa0\xa0— Young {4}SO',
#   '',
#   'Texas A&M',
#   '50.46 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Young {4}SO',
#   '',
#   'Texas A&M',
#   '50.46 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['(25) Kendall BAISDENFRTexas50.46 5/18/2014',
#   '(25) Kendall BAISDENFR',
#   '',
#   'Texas',
#   '50.46 ',
#   '5/18/2014'],
#  ['(25) Kendall BAISDENFR', '', 'Texas', '50.46 ', '5/18/2014']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Britton WILSONJRArkansas49.13📺 5/13/2023',
#   '(1) Britton WILSONJR',
#   '',
#   'Arkansas',
#   '49.13📺 ',
#   '5/13/2023'],
#  ['(2) Rhasidat ADELEKEJRTexas49.20 6/10/2023',
#   '(2) Rhasidat ADELEKEJR',
#   '',
#   'Texas',
#   '49.20 ',
#   '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}JRArkansas49.36 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}JR',
#   '',
#   'Arkansas',
#   '49.36 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}JRArkansas49.40 qq = Performance occurred during a non-final round. 5/12/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {3}JR',
#   '',
#   'Arkansas',
#   '49.40 qq = Performance occurred during a non-final round. ',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {4}JRArkansas49.51 qq = Performance occurred during a non-final round. 5/27/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {4}JR',
#   '',
#   'Arkansas',
#   '49.51 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {5}JRArkansas49.51📺 4/14/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {5}JR',
#   '',
#   'Arkansas',
#   '49.51📺 ',
#   '4/14/2023'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {2}JRTexas49.54 qq = Performance occurred during a non-final round. 5/27/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {2}JR',
#   '',
#   'Texas',
#   '49.54 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['(3) Athing MUFRTexas A&M49.57📺 6/12/2021',
#   '(3) Athing MUFR',
#   '',
#   'Texas A&M',
#   '49.57📺 ',
#   '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Wilson {6}JRArkansas49.64 6/10/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {6}JR',
#   '',
#   'Arkansas',
#   '49.64 ',
#   '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FRTexas A&M49.68 qq = Performance occurred during a non-final round. 5/29/2021',
#   '\xa0\xa0\xa0\xa0— Mu {2}FR',
#   '',
#   'Texas A&M',
#   '49.68 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  ['(4) Courtney OKOLOSRTexas49.71 4/23/2016',
#   '(4) Courtney OKOLOSR',
#   '',
#   'Texas',
#   '49.71 ',
#   '4/23/2016'],
#  ['(5) Lynna IRBYFRGeorgia49.80 6/9/2018',
#   '(5) Lynna IRBYFR',
#   '',
#   'Georgia',
#   '49.80 ',
#   '6/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Mu {3}FRTexas A&M49.84 5/13/2021',
#   '\xa0\xa0\xa0\xa0— Mu {3}FR',
#   '',
#   'Texas A&M',
#   '49.84 ',
#   '5/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {3}JRTexas49.86 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {3}JR',
#   '',
#   'Texas',
#   '49.86 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(6) Charokee YOUNGSOTexas A&M49.87 4/15/2022',
#   '(6) Charokee YOUNGSO',
#   '',
#   'Texas A&M',
#   '49.87 ',
#   '4/15/2022'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {4}JRTexas49.90 4/14/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {4}JR',
#   '',
#   'Texas',
#   '49.90 ',
#   '4/14/2023'],
#  ['(7) Talitha DIGGSSOFlorida49.99 6/11/2022',
#   '(7) Talitha DIGGSSO',
#   '',
#   'Florida',
#   '49.99 ',
#   '6/11/2022'],
#  ['(7) Kendall ELLISSRSouthern California49.99 5/13/2018',
#   '(7) Kendall ELLISSR',
#   '',
#   'Southern California',
#   '49.99 ',
#   '5/13/2018'],
#  ['\xa0\xa0\xa0\xa0— Young {2}SOTexas A&M50.00 4/2/2022',
#   '\xa0\xa0\xa0\xa0— Young {2}SO',
#   '',
#   'Texas A&M',
#   '50.00 ',
#   '4/2/2022'],
#  ['\xa0\xa0\xa0\xa0— Okolo {2}SOTexas50.03 5/18/2014',
#   '\xa0\xa0\xa0\xa0— Okolo {2}SO',
#   '',
#   'Texas',
#   '50.03 ',
#   '5/18/2014'],
#  ['\xa0\xa0\xa0\xa0— Mu {4}FRTexas A&M50.04 qq = Performance occurred during a non-final round. 5/13/2021',
#   '\xa0\xa0\xa0\xa0— Mu {4}FR',
#   '',
#   'Texas A&M',
#   '50.04 qq = Performance occurred during a non-final round. ',
#   '5/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Wilson {7}SOArkansas50.05 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {7}SO',
#   '',
#   'Arkansas',
#   '50.05 ',
#   '5/14/2022'],
#  ['(9) Sydney MCLAUGHLINFRKentucky50.07 3/31/2018',
#   '(9) Sydney MCLAUGHLINFR',
#   '',
#   'Kentucky',
#   '50.07 ',
#   '3/31/2018'],
#  ['\xa0\xa0\xa0\xa0— Diggs {2}SOFlorida50.08 qq = Performance occurred during a non-final round. 6/9/2022',
#   '\xa0\xa0\xa0\xa0— Diggs {2}SO',
#   '',
#   'Florida',
#   '50.08 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['(10) Monique HENDERSONSRUCLA50.10  6/11/2005',
#   '(10) Monique HENDERSONSR',
#   '',
#   'UCLA',
#   '50.10  ',
#   '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— Irby {2}FRGeorgia50.11 qq = Performance occurred during a non-final round. 6/7/2018',
#   '\xa0\xa0\xa0\xa0— Irby {2}FR',
#   '',
#   'Georgia',
#   '50.11 qq = Performance occurred during a non-final round. ',
#   '6/7/2018'],
#  ['\xa0\xa0\xa0\xa0— Wilson {8}JRArkansas50.15 qq = Performance occurred during a non-final round. 5/25/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {8}JR',
#   '',
#   'Arkansas',
#   '50.15 qq = Performance occurred during a non-final round. ',
#   '5/25/2023'],
#  ['(11) Natasha HASTINGSJRSouth Carolina50.15  6/9/2007',
#   '(11) Natasha HASTINGSJR',
#   '',
#   'South Carolina',
#   '50.15  ',
#   '6/9/2007'],
#  ['(12) Rosey EFFIONGSOArkansas50.17 qq = Performance occurred during a non-final round. 5/27/2023',
#   '(12) Rosey EFFIONGSO',
#   '',
#   'Arkansas',
#   '50.17 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['(13) Stacey-Ann WILLIAMS JRTexas50.18 qq = Performance occurred during a non-final round. 6/9/2022',
#   '(13) Stacey-Ann WILLIAMS JR',
#   '',
#   'Texas',
#   '50.18 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['(13) Pauline DAVISSRAlabama50.18 AA = Performance occurred at altitude (>1000 meters above sea level) 6/3/1989',
#   '(13) Pauline DAVISSR',
#   '',
#   'Alabama',
#   '50.18 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '6/3/1989'],
#  ['\xa0\xa0\xa0\xa0— Ellis {2}SRSouthern California50.19 6/9/2018',
#   '\xa0\xa0\xa0\xa0— Ellis {2}SR',
#   '',
#   'Southern California',
#   '50.19 ',
#   '6/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Williams  {2}JRTexas50.21 AA = Performance occurred at altitude (>1000 meters above sea level) 5/13/2022',
#   '\xa0\xa0\xa0\xa0— Williams  {2}JR',
#   '',
#   'Texas',
#   '50.21 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/13/2022'],
#  ['(15) Nickisha PRYCESOArkansas50.23 6/10/2023',
#   '(15) Nickisha PRYCESO',
#   '',
#   'Arkansas',
#   '50.23 ',
#   '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Okolo {3}SOTexas50.23 6/13/2014\xa0\xa0\xa0\xa0\xa024.1/26.1',
#   '\xa0\xa0\xa0\xa0— Okolo {3}SO',
#   '',
#   'Texas',
#   '50.23 ',
#   '6/13/2014',
#   '\xa0\xa0\xa0\xa0\xa024.1/26.1'],
#  ['\xa0\xa0\xa0\xa0— Hastings {2}JRSouth Carolina50.23  5/26/2007',
#   '\xa0\xa0\xa0\xa0— Hastings {2}JR',
#   '',
#   'South Carolina',
#   '50.23  ',
#   '5/26/2007'],
#  ['(16) Ashley SPENCERSOIllinois50.28 6/7/2013',
#   '(16) Ashley SPENCERSO',
#   '',
#   'Illinois',
#   '50.28 ',
#   '6/7/2013'],
#  ['\xa0\xa0\xa0\xa0— Williams {3}JRTexas50.29 qq = Performance occurred during a non-final round. 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Williams {3}JR',
#   '',
#   'Texas',
#   '50.29 qq = Performance occurred during a non-final round. ',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Williams  {4}JRTexas50.29 AA = Performance occurred at altitude (>1000 meters above sea level) 5/13/2022',
#   '\xa0\xa0\xa0\xa0— Williams  {4}JR',
#   '',
#   'Texas',
#   '50.29 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Pryce {2}SOArkansas50.31 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Pryce {2}SO',
#   '',
#   'Arkansas',
#   '50.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ["(17) Jan'Taijah FORDJRSouthern California50.31 qq = Performance occurred during a non-final round. 6/8/2023",
#   "(17) Jan'Taijah FORDJR",
#   '',
#   'Southern California',
#   '50.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(18) DeeDee TROTTERJRTennessee50.32  6/12/2004',
#   '(18) DeeDee TROTTERJR',
#   '',
#   'Tennessee',
#   '50.32  ',
#   '6/12/2004'],
#  ['(19) Jermaisha ARNOLDSOTexas A&M50.33 qq = Performance occurred during a non-final round. 5/27/2023',
#   '(19) Jermaisha ARNOLDSO',
#   '',
#   'Texas A&M',
#   '50.33 qq = Performance occurred during a non-final round. ',
#   '5/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Williams  {5}SOTexas50.34 qq = Performance occurred during a non-final round. 5/29/2021',
#   '\xa0\xa0\xa0\xa0— Williams  {5}SO',
#   '',
#   'Texas',
#   '50.34 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Williams {6}SOTexas50.34 qq = Performance occurred during a non-final round. 5/27/2021',
#   '\xa0\xa0\xa0\xa0— Williams {6}SO',
#   '',
#   'Texas',
#   '50.34 qq = Performance occurred during a non-final round. ',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Diggs {3}JRFlorida50.35 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Diggs {3}JR',
#   '',
#   'Florida',
#   '50.35 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Okolo {4}SRTexas50.36 6/11/2016\xa0\xa0\xa0\xa0\xa024.3/26.1 (13.6)',
#   '\xa0\xa0\xa0\xa0— Okolo {4}SR',
#   '',
#   'Texas',
#   '50.36 ',
#   '6/11/2016',
#   '\xa0\xa0\xa0\xa0\xa024.3/26.1 (13.6)'],
#  ['(20) Chrisann GORDONSRTexas50.39 qq = Performance occurred during a non-final round. 6/8/2017',
#   '(20) Chrisann GORDONSR',
#   '',
#   'Texas',
#   '50.39 qq = Performance occurred during a non-final round. ',
#   '6/8/2017'],
#  ['(20) Joanna ATKINSSOAuburn50.39  6/13/2009',
#   '(20) Joanna ATKINSSO',
#   '',
#   'Auburn',
#   '50.39  ',
#   '6/13/2009'],
#  ['(22) Ziyah HOLMANJRMichigan50.40 qq = Performance occurred during a non-final round. 6/8/2023',
#   '(22) Ziyah HOLMANJR',
#   '',
#   'Michigan',
#   '50.40 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(22) Shakima WIMBLEYSRMiami (Fla.)50.40 5/14/2017',
#   '(22) Shakima WIMBLEYSR',
#   '',
#   'Miami (Fla.)',
#   '50.40 ',
#   '5/14/2017'],
#  ['\xa0\xa0\xa0\xa0— Jones {2}JRSouthern California50.44 5/12/2023',
#   '\xa0\xa0\xa0\xa0— Jones {2}JR',
#   '',
#   'Southern California',
#   '50.44 ',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Irby {3}FRGeorgia50.44 qq = Performance occurred during a non-final round. 5/25/2018',
#   '\xa0\xa0\xa0\xa0— Irby {3}FR',
#   '',
#   'Georgia',
#   '50.44 qq = Performance occurred during a non-final round. ',
#   '5/25/2018'],
#  ['(24) Kennedy SIMONJRTexas50.45 qq = Performance occurred during a non-final round. 6/9/2022',
#   '(24) Kennedy SIMONJR',
#   '',
#   'Texas',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['\xa0\xa0\xa0\xa0— Young {3}SOTexas A&M50.45 5/14/2022',
#   '\xa0\xa0\xa0\xa0— Young {3}SO',
#   '',
#   'Texas A&M',
#   '50.45 ',
#   '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— Ellis {3}JRSouthern California50.45 qq = Performance occurred during a non-final round. 5/27/2017',
#   '\xa0\xa0\xa0\xa0— Ellis {3}JR',
#   '',
#   'Southern California',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '5/27/2017'],
#  ['\xa0\xa0\xa0\xa0— Ellis {4}JRSouthern California50.45 qq = Performance occurred during a non-final round. 5/26/2017',
#   '\xa0\xa0\xa0\xa0— Ellis {4}JR',
#   '',
#   'Southern California',
#   '50.45 qq = Performance occurred during a non-final round. ',
#   '5/26/2017'],
#  ['\xa0\xa0\xa0\xa0— Young {4}SOTexas A&M50.46 qq = Performance occurred during a non-final round. 6/9/2022',
#   '\xa0\xa0\xa0\xa0— Young {4}SO',
#   '',
#   'Texas A&M',
#   '50.46 qq = Performance occurred during a non-final round. ',
#   '6/9/2022'],
#  ['(25) Kendall BAISDENFRTexas50.46 5/18/2014',
#   '(25) Kendall BAISDENFR',
#   '',
#   'Texas',
#   '50.46 ',
#   '5/18/2014']]

# %%
RealRealRows[1][4]
# Out:
# '49.20 '

# %%
len(RealRealRows)
# Out:
# 59

# %%
OfficialTimes = []

# %%
for i in range(0,59):
    OfficialTimes.append(RealRealRows[i][4])
OfficialTimes
# Out:
# ['49.13📺 ',
#  '49.20 ',
#  '49.36 qq = Performance occurred during a non-final round. ',
#  '49.40 qq = Performance occurred during a non-final round. ',
#  '49.51 qq = Performance occurred during a non-final round. ',
#  '49.51📺 ',
#  '49.54 qq = Performance occurred during a non-final round. ',
#  '49.57📺 ',
#  '49.64 ',
#  '49.68 qq = Performance occurred during a non-final round. ',
#  '49.71 ',
#  '49.80 ',
#  '49.84 ',
#  '49.86 qq = Performance occurred during a non-final round. ',
#  '49.87 ',
#  '49.90 ',
#  '49.99 ',
#  '49.99 ',
#  '50.00 ',
#  '50.03 ',
#  '50.04 qq = Performance occurred during a non-final round. ',
#  '50.05 ',
#  '50.07 ',
#  '50.08 qq = Performance occurred during a non-final round. ',
#  '50.10  ',
#  '50.11 qq = Performance occurred during a non-final round. ',
#  '50.15 qq = Performance occurred during a non-final round. ',
#  '50.15  ',
#  '50.17 qq = Performance occurred during a non-final round. ',
#  '50.18 qq = Performance occurred during a non-final round. ',
#  '50.18 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '50.19 ',
#  '50.21 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '50.23 ',
#  '50.23 ',
#  '50.23  ',
#  '50.28 ',
#  '50.29 qq = Performance occurred during a non-final round. ',
#  '50.29 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '50.31 qq = Performance occurred during a non-final round. ',
#  '50.31 qq = Performance occurred during a non-final round. ',
#  '50.32  ',
#  '50.33 qq = Performance occurred during a non-final round. ',
#  '50.34 qq = Performance occurred during a non-final round. ',
#  '50.34 qq = Performance occurred during a non-final round. ',
#  '50.35 qq = Performance occurred during a non-final round. ',
#  '50.36 ',
#  '50.39 qq = Performance occurred during a non-final round. ',
#  '50.39  ',
#  '50.40 qq = Performance occurred during a non-final round. ',
#  '50.40 ',
#  '50.44 ',
#  '50.44 qq = Performance occurred during a non-final round. ',
#  '50.45 qq = Performance occurred during a non-final round. ',
#  '50.45 ',
#  '50.45 qq = Performance occurred during a non-final round. ',
#  '50.45 qq = Performance occurred during a non-final round. ',
#  '50.46 qq = Performance occurred during a non-final round. ',
#  '50.46 ']

# %%
RealRealRows[0][1]
# Out:
# '(1) Britton WILSONJR'

# %%
Names = []

for i in range(0,59):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Britton WILSONJR',
#  '(2) Rhasidat ADELEKEJR',
#  '\xa0\xa0\xa0\xa0— Wilson {2}JR',
#  '\xa0\xa0\xa0\xa0— Wilson {3}JR',
#  '\xa0\xa0\xa0\xa0— Wilson {4}JR',
#  '\xa0\xa0\xa0\xa0— Wilson {5}JR',
#  '\xa0\xa0\xa0\xa0— Adeleke {2}JR',
#  '(3) Athing MUFR',
#  '\xa0\xa0\xa0\xa0— Wilson {6}JR',
#  '\xa0\xa0\xa0\xa0— Mu {2}FR',
#  '(4) Courtney OKOLOSR',
#  '(5) Lynna IRBYFR',
#  '\xa0\xa0\xa0\xa0— Mu {3}FR',
#  '\xa0\xa0\xa0\xa0— Adeleke {3}JR',
#  '(6) Charokee YOUNGSO',
#  '\xa0\xa0\xa0\xa0— Adeleke {4}JR',
#  '(7) Talitha DIGGSSO',
#  '(7) Kendall ELLISSR',
#  '\xa0\xa0\xa0\xa0— Young {2}SO',
#  '\xa0\xa0\xa0\xa0— Okolo {2}SO',
#  '\xa0\xa0\xa0\xa0— Mu {4}FR',
#  '\xa0\xa0\xa0\xa0— Wilson {7}SO',
#  '(9) Sydney MCLAUGHLINFR',
#  '\xa0\xa0\xa0\xa0— Diggs {2}SO',
#  '(10) Monique HENDERSONSR',
#  '\xa0\xa0\xa0\xa0— Irby {2}FR',
#  '\xa0\xa0\xa0\xa0— Wilson {8}JR',
#  '(11) Natasha HASTINGSJR',
#  '(12) Rosey EFFIONGSO',
#  '(13) Stacey-Ann WILLIAMS JR',
#  '(13) Pauline DAVISSR',
#  '\xa0\xa0\xa0\xa0— Ellis {2}SR',
#  '\xa0\xa0\xa0\xa0— Williams  {2}JR',
#  '(15) Nickisha PRYCESO',
#  '\xa0\xa0\xa0\xa0— Okolo {3}SO',
#  '\xa0\xa0\xa0\xa0— Hastings {2}JR',
#  '(16) Ashley SPENCERSO',
#  '\xa0\xa0\xa0\xa0— Williams {3}JR',
#  '\xa0\xa0\xa0\xa0— Williams  {4}JR',
#  '\xa0\xa0\xa0\xa0— Pryce {2}SO',
#  "(17) Jan'Taijah FORDJR",
#  '(18) DeeDee TROTTERJR',
#  '(19) Jermaisha ARNOLDSO',
#  '\xa0\xa0\xa0\xa0— Williams  {5}SO',
#  '\xa0\xa0\xa0\xa0— Williams {6}SO',
#  '\xa0\xa0\xa0\xa0— Diggs {3}JR',
#  '\xa0\xa0\xa0\xa0— Okolo {4}SR',
#  '(20) Chrisann GORDONSR',
#  '(20) Joanna ATKINSSO',
#  '(22) Ziyah HOLMANJR',
#  '(22) Shakima WIMBLEYSR',
#  '\xa0\xa0\xa0\xa0— Jones {2}JR',
#  '\xa0\xa0\xa0\xa0— Irby {3}FR',
#  '(24) Kennedy SIMONJR',
#  '\xa0\xa0\xa0\xa0— Young {3}SO',
#  '\xa0\xa0\xa0\xa0— Ellis {3}JR',
#  '\xa0\xa0\xa0\xa0— Ellis {4}JR',
#  '\xa0\xa0\xa0\xa0— Young {4}SO',
#  '(25) Kendall BAISDENFR']

# %%
OfficialReGexNames = []

# %%
for i in range(0,59):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Britton WILSONJR',
#  '(2) Rhasidat ADELEKEJR',
#  '— Wilson {2}JR',
#  '— Wilson {3}JR',
#  '— Wilson {4}JR',
#  '— Wilson {5}JR',
#  '— Adeleke {2}JR',
#  '(3) Athing MUFR',
#  '— Wilson {6}JR',
#  '— Mu {2}FR',
#  '(4) Courtney OKOLOSR',
#  '(5) Lynna IRBYFR',
#  '— Mu {3}FR',
#  '— Adeleke {3}JR',
#  '(6) Charokee YOUNGSO',
#  '— Adeleke {4}JR',
#  '(7) Talitha DIGGSSO',
#  '(7) Kendall ELLISSR',
#  '— Young {2}SO',
#  '— Okolo {2}SO',
#  '— Mu {4}FR',
#  '— Wilson {7}SO',
#  '(9) Sydney MCLAUGHLINFR',
#  '— Diggs {2}SO',
#  '(10) Monique HENDERSONSR',
#  '— Irby {2}FR',
#  '— Wilson {8}JR',
#  '(11) Natasha HASTINGSJR',
#  '(12) Rosey EFFIONGSO',
#  '(13) Stacey-Ann WILLIAMS JR',
#  '(13) Pauline DAVISSR',
#  '— Ellis {2}SR',
#  '— Williams  {2}JR',
#  '(15) Nickisha PRYCESO',
#  '— Okolo {3}SO',
#  '— Hastings {2}JR',
#  '(16) Ashley SPENCERSO',
#  '— Williams {3}JR',
#  '— Williams  {4}JR',
#  '— Pryce {2}SO',
#  "(17) Jan'Taijah FORDJR",
#  '(18) DeeDee TROTTERJR',
#  '(19) Jermaisha ARNOLDSO',
#  '— Williams  {5}SO',
#  '— Williams {6}SO',
#  '— Diggs {3}JR',
#  '— Okolo {4}SR',
#  '(20) Chrisann GORDONSR',
#  '(20) Joanna ATKINSSO',
#  '(22) Ziyah HOLMANJR',
#  '(22) Shakima WIMBLEYSR',
#  '— Jones {2}JR',
#  '— Irby {3}FR',
#  '(24) Kennedy SIMONJR',
#  '— Young {3}SO',
#  '— Ellis {3}JR',
#  '— Ellis {4}JR',
#  '— Young {4}SO',
#  '(25) Kendall BAISDENFR']

# %%
CleanedNames = []

for i in range(0,len(RealRealRows)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Britton WILSONJR',
#  'Rhasidat ADELEKEJR',
#  'Wilson {2}JR',
#  'Wilson {3}JR',
#  'Wilson {4}JR',
#  'Wilson {5}JR',
#  'Adeleke {2}JR',
#  'Athing MUFR',
#  'Wilson {6}JR',
#  'Mu {2}FR',
#  'Courtney OKOLOSR',
#  'Lynna IRBYFR',
#  'Mu {3}FR',
#  'Adeleke {3}JR',
#  'Charokee YOUNGSO',
#  'Adeleke {4}JR',
#  'Talitha DIGGSSO',
#  'Kendall ELLISSR',
#  'Young {2}SO',
#  'Okolo {2}SO',
#  'Mu {4}FR',
#  'Wilson {7}SO',
#  'Sydney MCLAUGHLINFR',
#  'Diggs {2}SO',
#  ' Monique HENDERSONSR',
#  'Irby {2}FR',
#  'Wilson {8}JR',
#  ' Natasha HASTINGSJR',
#  ' Rosey EFFIONGSO',
#  ' Stacey-Ann WILLIAMS JR',
#  ' Pauline DAVISSR',
#  'Ellis {2}SR',
#  'Williams  {2}JR',
#  ' Nickisha PRYCESO',
#  'Okolo {3}SO',
#  'Hastings {2}JR',
#  ' Ashley SPENCERSO',
#  'Williams {3}JR',
#  'Williams  {4}JR',
#  'Pryce {2}SO',
#  " Jan'Taijah FORDJR",
#  ' DeeDee TROTTERJR',
#  ' Jermaisha ARNOLDSO',
#  'Williams  {5}SO',
#  'Williams {6}SO',
#  'Diggs {3}JR',
#  'Okolo {4}SR',
#  ' Chrisann GORDONSR',
#  ' Joanna ATKINSSO',
#  ' Ziyah HOLMANJR',
#  ' Shakima WIMBLEYSR',
#  'Jones {2}JR',
#  'Irby {3}FR',
#  ' Kennedy SIMONJR',
#  'Young {3}SO',
#  'Ellis {3}JR',
#  'Ellis {4}JR',
#  'Young {4}SO',
#  ' Kendall BAISDENFR']

# %%
CleanedNames2 = []

for i in range(0,len(RealRealRows)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Britton WILSONJR',
#  'Rhasidat ADELEKEJR',
#  'Wilson {2}JR',
#  'Wilson {3}JR',
#  'Wilson {4}JR',
#  'Wilson {5}JR',
#  'Adeleke {2}JR',
#  'Athing MUFR',
#  'Wilson {6}JR',
#  'Mu {2}FR',
#  'Courtney OKOLOSR',
#  'Lynna IRBYFR',
#  'Mu {3}FR',
#  'Adeleke {3}JR',
#  'Charokee YOUNGSO',
#  'Adeleke {4}JR',
#  'Talitha DIGGSSO',
#  'Kendall ELLISSR',
#  'Young {2}SO',
#  'Okolo {2}SO',
#  'Mu {4}FR',
#  'Wilson {7}SO',
#  'Sydney MCLAUGHLINFR',
#  'Diggs {2}SO',
#  'Monique HENDERSONSR',
#  'Irby {2}FR',
#  'Wilson {8}JR',
#  'Natasha HASTINGSJR',
#  'Rosey EFFIONGSO',
#  'Stacey-Ann WILLIAMS JR',
#  'Pauline DAVISSR',
#  'Ellis {2}SR',
#  'Williams  {2}JR',
#  'Nickisha PRYCESO',
#  'Okolo {3}SO',
#  'Hastings {2}JR',
#  'Ashley SPENCERSO',
#  'Williams {3}JR',
#  'Williams  {4}JR',
#  'Pryce {2}SO',
#  "Jan'Taijah FORDJR",
#  'DeeDee TROTTERJR',
#  'Jermaisha ARNOLDSO',
#  'Williams  {5}SO',
#  'Williams {6}SO',
#  'Diggs {3}JR',
#  'Okolo {4}SR',
#  'Chrisann GORDONSR',
#  'Joanna ATKINSSO',
#  'Ziyah HOLMANJR',
#  'Shakima WIMBLEYSR',
#  'Jones {2}JR',
#  'Irby {3}FR',
#  'Kennedy SIMONJR',
#  'Young {3}SO',
#  'Ellis {3}JR',
#  'Ellis {4}JR',
#  'Young {4}SO',
#  'Kendall BAISDENFR']

# %%
len(OfficialTimes)
# Out:
# 59

# %%
len(OfficialReGexNames)
# Out:
# 59

# %%
Times = []

# %%
for i in range(0,len(OfficialTimes)):
    Times.append(OfficialTimes[i][:5])
    
Times
# Out:
# ['49.13',
#  '49.20',
#  '49.36',
#  '49.40',
#  '49.51',
#  '49.51',
#  '49.54',
#  '49.57',
#  '49.64',
#  '49.68',
#  '49.71',
#  '49.80',
#  '49.84',
#  '49.86',
#  '49.87',
#  '49.90',
#  '49.99',
#  '49.99',
#  '50.00',
#  '50.03',
#  '50.04',
#  '50.05',
#  '50.07',
#  '50.08',
#  '50.10',
#  '50.11',
#  '50.15',
#  '50.15',
#  '50.17',
#  '50.18',
#  '50.18',
#  '50.19',
#  '50.21',
#  '50.23',
#  '50.23',
#  '50.23',
#  '50.28',
#  '50.29',
#  '50.29',
#  '50.31',
#  '50.31',
#  '50.32',
#  '50.33',
#  '50.34',
#  '50.34',
#  '50.35',
#  '50.36',
#  '50.39',
#  '50.39',
#  '50.40',
#  '50.40',
#  '50.44',
#  '50.44',
#  '50.45',
#  '50.45',
#  '50.45',
#  '50.45',
#  '50.46',
#  '50.46']

# %%
Schools = []

for i in range(0,len(OfficialTimes)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Arkansas',
#  'Texas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Texas',
#  'Texas A&M',
#  'Arkansas',
#  'Texas A&M',
#  'Texas',
#  'Georgia',
#  'Texas A&M',
#  'Texas',
#  'Texas A&M',
#  'Texas',
#  'Florida',
#  'Southern California',
#  'Texas A&M',
#  'Texas',
#  'Texas A&M',
#  'Arkansas',
#  'Kentucky',
#  'Florida',
#  'UCLA',
#  'Georgia',
#  'Arkansas',
#  'South Carolina',
#  'Arkansas',
#  'Texas',
#  'Alabama',
#  'Southern California',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'South Carolina',
#  'Illinois',
#  'Texas',
#  'Texas',
#  'Arkansas',
#  'Southern California',
#  'Tennessee',
#  'Texas A&M',
#  'Texas',
#  'Texas',
#  'Florida',
#  'Texas',
#  'Texas',
#  'Auburn',
#  'Michigan',
#  'Miami (Fla.)',
#  'Southern California',
#  'Georgia',
#  'Texas',
#  'Texas A&M',
#  'Southern California',
#  'Southern California',
#  'Texas A&M',
#  'Texas']

# %%
Womens400mDF = pd.DataFrame({'Names': CleanedNames2, 'Times': Times, 'Schools': Schools})

# %%
Womens400mDF.to_csv('OutdoorWomens400m.csv', index=False)
