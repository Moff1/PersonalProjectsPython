# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# %%
DecathalonLink = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?gender=1&sport=1&div=20527&top=25&event=31"

# %%
page = requests.get(DecathalonLink)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
# ...

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Kyle GARLANDSRGeorgia6,639📺 3/10/2023',
#   '(1) Kyle GARLANDSR',
#   '',
#   'Georgia',
#   '6,639📺 ',
#   '3/10/2023'],
#  [],
#  ['(1) Kyle GARLANDSR', '', 'Georgia', '6,639📺 ', '3/10/2023'],
#  ['(2) Ayden OWENS-DELERMEJRArkansas6,518 3/10/2023',
#   '(2) Ayden OWENS-DELERMEJR',
#   '',
#   'Arkansas',
#   '6,518 ',
#   '3/10/2023'],
#  [],
#  ['(2) Ayden OWENS-DELERMEJR', '', 'Arkansas', '6,518 ', '3/10/2023'],
#  ['(3) Ashton EATONSROregon6,499📺 3/13/2010\xa0\xa0\xa0\xa0\xa0then-WORLD RECORD -- 6.71, 7.73/25-4½, 13.12/43-½, 2.11/6-11 [3561], 7.77, 5.10/16-8¾, 2:32.67 [2938]',
#   '(3) Ashton EATONSR',
#   '',
#   'Oregon',
#   '6,499📺 ',
#   '3/13/2010',
#   '\xa0\xa0\xa0\xa0\xa0then-WORLD RECORD -- 6.71, 7.73/25-4½, 13.12/43-½, 2.11/6-11 [3561], 7.77, 5.10/16-8¾, 2:32.67 [2938]'],
#  [],
#  ['(3) Ashton EATONSR', '', 'Oregon', '6,499📺 ', '3/13/2010'],
# ...

# %%
rows[167]
# Out:
# ['\xa0\xa0\xa0\xa0\xa07.13, 7.56/24-9¾, 13.84/45-5, 2.06/6-9 [3365]; 8.09, 5.30/17-4½, 2:54.42']

# %%
len(rows)
# Out:
# 171

# %%
RealRows = []

# %%
for i in range(0,167):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [['(1) Kyle GARLANDSRGeorgia6,639📺 3/10/2023',
#   '(1) Kyle GARLANDSR',
#   '',
#   'Georgia',
#   '6,639📺 ',
#   '3/10/2023'],
#  ['(1) Kyle GARLANDSR', '', 'Georgia', '6,639📺 ', '3/10/2023'],
#  ['(2) Ayden OWENS-DELERMEJRArkansas6,518 3/10/2023',
#   '(2) Ayden OWENS-DELERMEJR',
#   '',
#   'Arkansas',
#   '6,518 ',
#   '3/10/2023'],
#  ['(2) Ayden OWENS-DELERMEJR', '', 'Arkansas', '6,518 ', '3/10/2023'],
#  ['(3) Ashton EATONSROregon6,499📺 3/13/2010\xa0\xa0\xa0\xa0\xa0then-WORLD RECORD -- 6.71, 7.73/25-4½, 13.12/43-½, 2.11/6-11 [3561], 7.77, 5.10/16-8¾, 2:32.67 [2938]',
#   '(3) Ashton EATONSR',
#   '',
#   'Oregon',
#   '6,499📺 ',
#   '3/13/2010',
#   '\xa0\xa0\xa0\xa0\xa0then-WORLD RECORD -- 6.71, 7.73/25-4½, 13.12/43-½, 2.11/6-11 [3561], 7.77, 5.10/16-8¾, 2:32.67 [2938]'],
#  ['(3) Ashton EATONSR', '', 'Oregon', '6,499📺 ', '3/13/2010'],
#  ['\xa0\xa0\xa0\xa0— Garland {2}SRGeorgia6,415 1/27/2023\xa0\xa0\xa0\xa0\xa06.86, 7.56, 16.26, 2.19 [3732]; 7.84, 5.00, 2:51.40',
# ...

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Kyle GARLANDSRGeorgia6,639📺 3/10/2023',
#   '(1) Kyle GARLANDSR',
#   '',
#   'Georgia',
#   '6,639📺 ',
#   '3/10/2023'],
#  ['(2) Ayden OWENS-DELERMEJRArkansas6,518 3/10/2023',
#   '(2) Ayden OWENS-DELERMEJR',
#   '',
#   'Arkansas',
#   '6,518 ',
#   '3/10/2023'],
#  ['(3) Ashton EATONSROregon6,499📺 3/13/2010\xa0\xa0\xa0\xa0\xa0then-WORLD RECORD -- 6.71, 7.73/25-4½, 13.12/43-½, 2.11/6-11 [3561], 7.77, 5.10/16-8¾, 2:32.67 [2938]',
#   '(3) Ashton EATONSR',
#   '',
#   'Oregon',
#   '6,499📺 ',
#   '3/13/2010',
#   '\xa0\xa0\xa0\xa0\xa0then-WORLD RECORD -- 6.71, 7.73/25-4½, 13.12/43-½, 2.11/6-11 [3561], 7.77, 5.10/16-8¾, 2:32.67 [2938]'],
#  ['\xa0\xa0\xa0\xa0— Garland {2}SRGeorgia6,415 1/27/2023\xa0\xa0\xa0\xa0\xa06.86, 7.56, 16.26, 2.19 [3732]; 7.84, 5.00, 2:51.40',
#   '\xa0\xa0\xa0\xa0— Garland {2}SR',
#   '',
#   'Georgia',
#   '6,415 ',
#   '1/27/2023',
#   '\xa0\xa0\xa0\xa0\xa06.86, 7.56, 16.26, 2.19 [3732]; 7.84, 5.00, 2:51.40'],
# ...

# %%
RealRealRows[0][4]
# Out:
# '6,639📺 '

# %%
len(RealRealRows)
# Out:
# 45

# %%
OfficialScores = []

# %%
for i in range(0,len(RealRealRows)):
    OfficialScores.append(RealRealRows[i][4])
OfficialScores
# Out:
# ['6,639📺 ',
#  '6,518 ',
#  '6,499📺 ',
#  '6,415 ',
#  '6,272 ',
#  '6,264 ',
#  '6,256 ',
#  '6,237 ',
#  '6,214 ',
#  '6,211 ',
#  '6,208 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '6,205 ',
#  '6,200 ',
#  '6,200 ',
#  '6,196 ',
#  '6,190 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '6,188 ',
#  '6,177 ',
#  '6,175 ',
#  '6,174  ',
#  '6,173 ',
#  '6,165 ',
#  '6,165 ',
#  '6,163 ',
#  '6,156 ',
#  '6,148 ',
#  '6,138 ',
#  '6,136  ',
#  '6,114 ',
#  '6,097 ',
#  '6,090 ',
#  '6,090 ',
#  '6,089 ',
#  '6,082 ',
#  '6,082 ',
#  '6,081 ',
#  '6,071 ',
#  '6,070 ',
#  '6,069 ',
#  '6,068 ',
#  '6,061 ',
#  '6,059 ',
#  '6,051 ',
#  '6,048 ',
#  '6,048  ']

# %%
Scores = []
for i in range(0,len(OfficialScores)):
    Scores.append(OfficialScores[i][:5])
    
Scores
# Out:
# ['6,639',
#  '6,518',
#  '6,499',
#  '6,415',
#  '6,272',
#  '6,264',
#  '6,256',
#  '6,237',
#  '6,214',
#  '6,211',
#  '6,208',
#  '6,205',
#  '6,200',
#  '6,200',
#  '6,196',
#  '6,190',
#  '6,188',
#  '6,177',
#  '6,175',
#  '6,174',
#  '6,173',
#  '6,165',
#  '6,165',
#  '6,163',
#  '6,156',
#  '6,148',
#  '6,138',
#  '6,136',
#  '6,114',
#  '6,097',
#  '6,090',
#  '6,090',
#  '6,089',
#  '6,082',
#  '6,082',
#  '6,081',
#  '6,071',
#  '6,070',
#  '6,069',
#  '6,068',
#  '6,061',
#  '6,059',
#  '6,051',
#  '6,048',
#  '6,048']

# %%
OfficialNames = []
for i in range(0,len(RealRealRows)):
    OfficialNames.append(RealRealRows[i][1])
OfficialNames
# Out:
# ['(1) Kyle GARLANDSR',
#  '(2) Ayden OWENS-DELERMEJR',
#  '(3) Ashton EATONSR',
#  '\xa0\xa0\xa0\xa0— Garland {2}SR',
#  '\xa0\xa0\xa0\xa0— Owens-Delerme {2}SO',
#  '(4) Karel TILGASO',
#  '\xa0\xa0\xa0\xa0— Eaton {2}',
#  '\xa0\xa0\xa0\xa0— Owens-Delerme {3}JR',
#  '(5) Leo NEUGEBAUER JR',
#  '\xa0\xa0\xa0\xa0— Owens-Delerme {4}SO',
#  '(6) Trey HARDEE',
#  '\xa0\xa0\xa0\xa0— Garland {3}SO',
#  '\xa0\xa0\xa0\xa0— Garland {4}SO',
#  '\xa0\xa0\xa0\xa0— Garland {5}SO',
#  '(7) Till STEINFORTHSO',
#  '(8) Curtis BEACH',
#  '(9) Tim DUCKWORTHSR',
#  '(10) Devon WILLIAMSSR',
#  '(11) Kevin LAZASJR',
#  '\xa0\xa0\xa0\xa0— Eaton {3}',
#  '(12) Zach ZIEMEKSR',
#  '\xa0\xa0\xa0\xa0— Duckworth {2}JR',
#  '(13) Japheth CATOJR',
#  '\xa0\xa0\xa0\xa0— Garland {6}SO',
#  '(14) Jeremy TAIWO',
#  '\xa0\xa0\xa0\xa0— Neugebauer  {2}SO',
#  '\xa0\xa0\xa0\xa0— Beach {2}JR',
#  '(15) Donovan KILMARTINFR',
#  '(16) Johannes ERMJR',
#  '\xa0\xa0\xa0\xa0— Neugebauer  {3}JR',
#  '(17) Hunter VEITHSR',
# ...

# %%
OfficialSchool = []
for i in range(0,len(RealRealRows)):
    OfficialSchool.append(RealRealRows[i][3])
OfficialSchool
# Out:
# ['Georgia',
#  'Arkansas',
#  'Oregon',
#  'Georgia',
#  'Arkansas',
#  'Georgia',
#  'Oregon',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Nebraska',
#  'Duke',
#  'Kentucky',
#  'Georgia',
#  'Arkansas',
#  'Oregon',
#  'Wisconsin',
#  'Kentucky',
#  'Wisconsin',
#  'Georgia',
#  'Washington',
#  'Texas',
#  'Duke',
#  'Texas',
#  'Georgia',
#  'Texas',
#  'Wichita State',
#  'Wisconsin',
#  'Minnesota',
#  'Nebraska',
#  'Wisconsin',
#  'Sam Houston State',
#  'Kentucky',
#  'Minnesota',
#  'Princeton',
#  'Georgia',
#  'Washington',
#  'Pittsburgh',
#  'Georgia',
#  'Iowa',
#  'Texas']

# %%
OfficialReGexNames = []
for i in range(0,len(RealRealRows)):
    if OfficialNames[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(OfficialNames[i][4:])
    else:
        OfficialReGexNames.append(OfficialNames[i])
        
OfficialReGexNames
# Out:
# ['(1) Kyle GARLANDSR',
#  '(2) Ayden OWENS-DELERMEJR',
#  '(3) Ashton EATONSR',
#  '— Garland {2}SR',
#  '— Owens-Delerme {2}SO',
#  '(4) Karel TILGASO',
#  '— Eaton {2}',
#  '— Owens-Delerme {3}JR',
#  '(5) Leo NEUGEBAUER JR',
#  '— Owens-Delerme {4}SO',
#  '(6) Trey HARDEE',
#  '— Garland {3}SO',
#  '— Garland {4}SO',
#  '— Garland {5}SO',
#  '(7) Till STEINFORTHSO',
#  '(8) Curtis BEACH',
#  '(9) Tim DUCKWORTHSR',
#  '(10) Devon WILLIAMSSR',
#  '(11) Kevin LAZASJR',
#  '— Eaton {3}',
#  '(12) Zach ZIEMEKSR',
#  '— Duckworth {2}JR',
#  '(13) Japheth CATOJR',
#  '— Garland {6}SO',
#  '(14) Jeremy TAIWO',
#  '— Neugebauer  {2}SO',
#  '— Beach {2}JR',
#  '(15) Donovan KILMARTINFR',
#  '(16) Johannes ERMJR',
#  '— Neugebauer  {3}JR',
#  '(17) Hunter VEITHSR',
#  '— Cato {2}',
#  '(18) Luca WIELANDSR',
#  '— Steinforth {2}SO',
#  '— Cato {3}',
#  '(19) Tyler ADAMSSR',
#  '— Duckworth {3}SR',
#  '— Wieland {2}',
#  '(20) Andrei IOSIVASJR',
#  '(21) Garrett SCANTLING',
# ...

# %%
CleanedNames = []
for i in range(0,len(RealRealRows)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Kyle GARLANDSR',
#  'Ayden OWENS-DELERMEJR',
#  'Ashton EATONSR',
#  'Garland {2}SR',
#  'Owens-Delerme {2}SO',
#  'Karel TILGASO',
#  'Eaton {2}',
#  'Owens-Delerme {3}JR',
#  'Leo NEUGEBAUER JR',
#  'Owens-Delerme {4}SO',
#  'Trey HARDEE',
#  'Garland {3}SO',
#  'Garland {4}SO',
#  'Garland {5}SO',
#  'Till STEINFORTHSO',
#  'Curtis BEACH',
#  'Tim DUCKWORTHSR',
#  ' Devon WILLIAMSSR',
#  ' Kevin LAZASJR',
#  'Eaton {3}',
#  ' Zach ZIEMEKSR',
#  'Duckworth {2}JR',
#  ' Japheth CATOJR',
#  'Garland {6}SO',
#  ' Jeremy TAIWO',
#  'Neugebauer  {2}SO',
#  'Beach {2}JR',
#  ' Donovan KILMARTINFR',
#  ' Johannes ERMJR',
#  'Neugebauer  {3}JR',
#  ' Hunter VEITHSR',
#  'Cato {2}',
#  ' Luca WIELANDSR',
#  'Steinforth {2}SO',
#  'Cato {3}',
#  ' Tyler ADAMSSR',
#  'Duckworth {3}SR',
#  'Wieland {2}',
#  ' Andrei IOSIVASJR',
#  ' Garrett SCANTLING',
#  ' Bruno COMIN PESCADORJR',
#  ' Felix WOLTERSR',
#  ' Karl SALURIJR',
#  ' Peyton HAACKJR',
#  'Kilmartin {2}JR']

# %%
CleanedNames2 = []
for i in range(0,len(RealRealRows)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Kyle GARLANDSR',
#  'Ayden OWENS-DELERMEJR',
#  'Ashton EATONSR',
#  'Garland {2}SR',
#  'Owens-Delerme {2}SO',
#  'Karel TILGASO',
#  'Eaton {2}',
#  'Owens-Delerme {3}JR',
#  'Leo NEUGEBAUER JR',
#  'Owens-Delerme {4}SO',
#  'Trey HARDEE',
#  'Garland {3}SO',
#  'Garland {4}SO',
#  'Garland {5}SO',
#  'Till STEINFORTHSO',
#  'Curtis BEACH',
#  'Tim DUCKWORTHSR',
#  'Devon WILLIAMSSR',
#  'Kevin LAZASJR',
#  'Eaton {3}',
#  'Zach ZIEMEKSR',
#  'Duckworth {2}JR',
#  'Japheth CATOJR',
#  'Garland {6}SO',
#  'Jeremy TAIWO',
#  'Neugebauer  {2}SO',
#  'Beach {2}JR',
#  'Donovan KILMARTINFR',
#  'Johannes ERMJR',
#  'Neugebauer  {3}JR',
#  'Hunter VEITHSR',
#  'Cato {2}',
#  'Luca WIELANDSR',
#  'Steinforth {2}SO',
#  'Cato {3}',
#  'Tyler ADAMSSR',
#  'Duckworth {3}SR',
#  'Wieland {2}',
#  'Andrei IOSIVASJR',
#  'Garrett SCANTLING',
#  'Bruno COMIN PESCADORJR',
#  'Felix WOLTERSR',
#  'Karl SALURIJR',
#  'Peyton HAACKJR',
#  'Kilmartin {2}JR']

# %%
MensHepDF = pd.DataFrame({'Names': CleanedNames2, 'Scores': Scores, 'Schools': OfficialSchool})
MensHepDF.to_csv('MensHep.csv', index=False)
