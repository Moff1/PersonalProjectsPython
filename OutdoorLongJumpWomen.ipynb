# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
LongJump = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?gender=2&sport=2&div=20527&top=25&event=23"

# %%
page = requests.get(LongJump)
soup = BeautifulSoup(page.text,'html')
soup
table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7087499" target="_blank">(1) Tara DAVIS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67755/4149948" target="_blank">7.14m</a><a href="https://www.youtube.com/watch?v=zom4O5Spgb8" target="_blank">📺</a>  23-5¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.0)</span></td><td style="width: 10%;text-align:right;" title="Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/25/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7087499" target="_blank">(1) Tara DAVIS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67755/4149948" target="_blank">7.14m</a><a href="https://www.youtube.com/watch?v=zom4O5Spgb8" target="_blank">📺</a>  23-5¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.0)</span></td><td style="width: 10%;text-align:right;" title="Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/25/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7958878" target="_blank">(2) Ackelia SMITH</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/79703/4926684" target="_blank">7.08m</a>  23-2¾<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.9)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Norman, Okla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/12/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7958878" target="_blank">(2) Ackelia SMITH</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/79703/4926684" target="_blank">7.08m</a>  23-2¾<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.9)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Norman, Okla.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/12/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(3) Jackie JOYNER-KERSEE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1617">UCLA</a></td><td style="width: 25%;">6.99m  22-11¼</td><td style="width: 10%;text-align:right;" title=" (Westwood, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">5/4/1985</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(3) Jackie JOYNER-KERSEE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1617">UCLA</a></td><td style="width: 25%;">6.99m  22-11¼</td><td style="width: 10%;text-align:right;" title=" (Westwood, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">5/4/1985</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6562811" target="_blank">(4) Monae' NICHOLS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75162/4560552" target="_blank">6.97m</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 22-10½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.0)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6562811" target="_blank">(4) Monae' NICHOLS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75162/4560552" target="_blank">6.97m</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 22-10½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.0)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Davis {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70288/4266368" target="_blank">6.97m</a>  22-10½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Manhattan, Kan.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Davis {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70288/4266368" target="_blank">6.97m</a>  22-10½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.3)</span></td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Manhattan, Kan.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Davis {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/69517/4241284" target="_blank">6.97m</a>  22-10½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.5)</span></td><td style="width: 10%;text-align:right;" title="Texas Invitational (outdoor) (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/30/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Davis {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/69517/4241284" target="_blank">6.97m</a>  22-10½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.5)</span></td><td style="width: 10%;text-align:right;" title="Texas Invitational (outdoor) (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/30/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Davis {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67755/4149948" target="_blank">6.97m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-10½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.0)</span></td><td style="width: 10%;text-align:right;" title="Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/25/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Davis {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67755/4149948" target="_blank">6.97m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-10½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.0)</span></td><td style="width: 10%;text-align:right;" title="Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/25/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(4) Carol LEWIS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=672">Houston</a></td><td style="width: 25%;">6.97m  22-10½</td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">4/29/1984</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(4) Carol LEWIS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=672">Houston</a></td><td style="width: 25%;">6.97m  22-10½</td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">4/29/1984</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6559750" target="_blank">(6) Tyra GITTENS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70259/4263448" target="_blank">6.96m</a> <span class="tooltip" style="font-size: smaller;">cb<span class="tooltiptext" style="font-size: smaller;">cb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.)</span></span> 22-10<br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.0)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6559750" target="_blank">(6) Tyra GITTENS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70259/4263448" target="_blank">6.96m</a> <span class="tooltip" style="font-size: smaller;">cb<span class="tooltiptext" style="font-size: smaller;">cb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.)</span></span> 22-10<br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.0)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/13/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(7) Sheila ECHOLS</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=869">LSU</a></td><td style="width: 25%;">6.94m  22-9¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: -1.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;">6/5/1987</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(7) Sheila ECHOLS</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=869">LSU</a></td><td style="width: 25%;">6.94m  22-9¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: -1.0)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;">6/5/1987</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(8) Brittney REESE</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Ole Miss" class="group-logo-inline" src="/images/logos/rankings-article/ole-miss.png" title="Ole Miss"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=983">Ole Miss</a></td><td style="width: 25%;">6.93m  22-9<br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/12/2008</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(8) Brittney REESE</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Ole Miss" class="group-logo-inline" src="/images/logos/rankings-article/ole-miss.png" title="Ole Miss"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=983">Ole Miss</a></td><td style="width: 25%;">6.93m  22-9<br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.9)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/12/2008</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Davis {5}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/69517/4241284" target="_blank">6.92m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-8½<br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.7)</span></td><td style="width: 10%;text-align:right;" title="Texas Invitational (outdoor) (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/30/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Davis {5}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/69517/4241284" target="_blank">6.92m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-8½<br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.7)</span></td><td style="width: 10%;text-align:right;" title="Texas Invitational (outdoor) (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/30/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Lewis {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=672">Houston</a></td><td style="width: 25%;">6.92m  22-8½</td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">4/28/1985</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Lewis {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=672">Houston</a></td><td style="width: 25%;">6.92m  22-8½</td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">4/28/1985</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Lewis {3}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=672">Houston</a></td><td style="width: 25%;">6.90m <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-7¾</td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">4/28/1985</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Lewis {3}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=672">Houston</a></td><td style="width: 25%;">6.90m <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-7¾</td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">4/28/1985</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7091735" target="_blank">(9) Deborah ACQUAH</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74108/4462667" target="_blank">6.89m</a>  22-7¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.7)</span></td><td style="width: 10%;text-align:right;" title="Texas at Texas A&amp;M (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/2/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7091735" target="_blank">(9) Deborah ACQUAH</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74108/4462667" target="_blank">6.89m</a>  22-7¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.7)</span></td><td style="width: 10%;text-align:right;" title="Texas at Texas A&amp;M (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/2/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Smith {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938104" target="_blank">6.88m</a>  22-7<br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.2)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/8/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Smith {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938104" target="_blank">6.88m</a>  22-7<br/><span style="font-size:0.7em;font-style: italic;"> (w: -0.2)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/8/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8010897" target="_blank">(10) Jasmine MOORE</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4923386" target="_blank">6.88m</a>  22-7<br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.3)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/12/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8010897" target="_blank">(10) Jasmine MOORE</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4923386" target="_blank">6.88m</a>  22-7<br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.3)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/12/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(10) Blessing OKAGBARE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UTEP" class="group-logo-inline" src="/images/logos/rankings-article/utep.png" title="UTEP"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1669">UTEP</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/16429" target="_blank">6.88m</a>  22-7</td><td style="width: 10%;text-align:right;" title="Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/2/2010</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(10) Blessing OKAGBARE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UTEP" class="group-logo-inline" src="/images/logos/rankings-article/utep.png" title="UTEP"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1669">UTEP</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/16429" target="_blank">6.88m</a>  22-7</td><td style="width: 10%;text-align:right;" title="Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/2/2010</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8324337" target="_blank">(12) Alyssa JONES</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938104" target="_blank">6.86m</a>  22-6¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.1)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/8/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8324337" target="_blank">(12) Alyssa JONES</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938104" target="_blank">6.86m</a>  22-6¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: 0.1)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/8/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Nichols {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72999" target="_blank">6.86m</a>  22-6¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="Mt. SAC Relays (Walnut, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">4/16/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Nichols {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72999" target="_blank">6.86m</a>  22-6¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="Mt. SAC Relays (Walnut, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">4/16/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Nichols {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72997/4504270" target="_blank">6.86m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-6¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="Mt. SAC Relays [USATF Golden Games] (Walnut, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">4/13/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Nichols {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72997/4504270" target="_blank">6.86m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-6¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="Mt. SAC Relays [USATF Golden Games] (Walnut, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">4/13/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(12) Daphne SAUNDERS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=869">LSU</a></td><td style="width: 25%;">6.86m  22-6¼</td><td style="width: 10%;text-align:right;" title=" (Knoxville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">5/15/1993</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(12) Daphne SAUNDERS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=869">LSU</a></td><td style="width: 25%;">6.86m  22-6¼</td><td style="width: 10%;text-align:right;" title=" (Knoxville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">5/15/1993</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Davis {6}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/69517/4241284" target="_blank">6.85m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-5¾<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="Texas Invitational (outdoor) (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/30/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Davis {6}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/69517/4241284" target="_blank">6.85m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-5¾<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.7)</span></td><td style="width: 10%;text-align:right;" title="Texas Invitational (outdoor) (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/30/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5651827" target="_blank">(14) Yanis DAVID</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850652" target="_blank">6.84m</a>  22-5¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.5)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/6/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5651827" target="_blank">(14) Yanis DAVID</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850652" target="_blank">6.84m</a>  22-5¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.5)</span></td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/6/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4638071" target="_blank">(14) Quanesha BURKS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41348" target="_blank">6.84m</a>  22-5¼<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.9)</span></td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Starkville, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/15/2015</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     f, 6.24(0.0), 6.46(3.3), 6.36(1.7), 6.74(2.0), 6.84(1.9)</td></tr></table></div></td></tr>,
#  <tr></tr>,
# ...
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4177198" target="_blank">Sha'Keela SAUNDERS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">6.79m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-3½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/2/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4177198" target="_blank">Sha'Keela SAUNDERS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">6.79m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 22-3½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 1.4)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/2/2016</span></td></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">Additional Out-of-Season, All-Conditions Bests</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4177198" target="_blank">Sha'Keela SAUNDERS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51954/3200355" target="_blank">6.92m</a> <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> 22-8½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.0)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/24/2017</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.66(0.9), f, 6.57(-0.2), 6.77(-0.8), 6.92w(3.0), 6.58(0.8)</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4177198" target="_blank">Sha'Keela SAUNDERS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51954/3200355" target="_blank">6.92m</a> <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> 22-8½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.0)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/24/2017</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.66(0.9), f, 6.57(-0.2), 6.77(-0.8), 6.92w(3.0), 6.58(0.8)</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4177198" target="_blank">Sha'Keela SAUNDERS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51953" target="_blank">6.92m</a> <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> 22-8½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.0)</span></td><td style="width: 10%;text-align:right;" title="USATF U20 Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/24/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4177198" target="_blank">Sha'Keela SAUNDERS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51953" target="_blank">6.92m</a> <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> 22-8½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 3.0)</span></td><td style="width: 10%;text-align:right;" title="USATF U20 Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/24/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7040094" target="_blank">Aliyah WHISBY</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=573">Georgia</a></td><td style="width: 25%;">6.82m <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> 22-4½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.8)</span></td><td style="width: 10%;text-align:right;" title="NACAC U23 Championships (Queretaro, Mexico)"><span class="mark-date" style="width: 10%;text-align:right;">7/5/2019</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7040094" target="_blank">Aliyah WHISBY</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=573">Georgia</a></td><td style="width: 25%;">6.82m <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> 22-4½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.8)</span></td><td style="width: 10%;text-align:right;" title="NACAC U23 Championships (Queretaro, Mexico)"><span class="mark-date" style="width: 10%;text-align:right;">7/5/2019</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8010897" target="_blank">Jasmine MOORE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;">6.80m <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> 22-3¾<br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.5)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/23/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8010897" target="_blank">Jasmine MOORE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;">6.80m <span class="tooltip" style="font-size: smaller;">w<span class="tooltiptext" style="font-size: smaller;">w = Performance is wind-aided and not valid for records or lists (&gt;2.0 m/s)</span></span> 22-3¾<br/><span style="font-size:0.7em;font-style: italic;"> (w: 2.5)</span></td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/23/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4177198" target="_blank">Sha'Keela SAUNDERS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">6.79m</a> <span class="tooltip" style="font-size: smaller;">W<span class="tooltiptext" style="font-size: smaller;">W = Performance is heavily wind-aided and not valid for qualifying (&gt;4.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> 22-3½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 5.0)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/1/2016</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.79w(5.0), p, p</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4177198" target="_blank">Sha'Keela SAUNDERS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?gender=2&amp;sport=2&amp;div=20527&amp;top=25&amp;event=23&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">6.79m</a> <span class="tooltip" style="font-size: smaller;">W<span class="tooltiptext" style="font-size: smaller;">W = Performance is heavily wind-aided and not valid for qualifying (&gt;4.0 m/s)</span></span><span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> 22-3½<br/><span style="font-size:0.7em;font-style: italic;"> (w: 5.0)</span></td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/1/2016</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     6.79w(5.0), p, p</td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows3 = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows3.append(row_data)

# %%
rows3
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Tara DAVISSOTexas7.14m📺  23-5¼ (w: 1.0)3/25/2021',
#   '(1) Tara DAVISSO',
#   '',
#   'Texas',
#   '7.14m📺  23-5¼ (w: 1.0)',
#   '3/25/2021'],
#  [],
#  ['(1) Tara DAVISSO', '', 'Texas', '7.14m📺  23-5¼ (w: 1.0)', '3/25/2021'],
#  ['(2) Ackelia SMITHSOTexas7.08m  23-2¾ (w: 1.9)5/12/2023',
#   '(2) Ackelia SMITHSO',
#   '',
#   'Texas',
#   '7.08m  23-2¾ (w: 1.9)',
#   '5/12/2023'],
#  [],
#  ['(2) Ackelia SMITHSO', '', 'Texas', '7.08m  23-2¾ (w: 1.9)', '5/12/2023'],
#  ['(3) Jackie JOYNER-KERSEEUCLA6.99m  22-11¼5/4/1985',
#   '(3) Jackie JOYNER-KERSEE',
#   '',
#   'UCLA',
#   '6.99m  22-11¼',
#   '5/4/1985'],
#  [],
#  ['(3) Jackie JOYNER-KERSEE', '', 'UCLA', '6.99m  22-11¼', '5/4/1985'],
#  ["(4) Monae' NICHOLSSRTexas Tech6.97m AA = Performance occurred at altitude (>1000 meters above sea level) 22-10½ (w: 1.0)5/13/2022",
#   "(4) Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.97m AA = Performance occurred at altitude (>1000 meters above sea level) 22-10½ (w: 1.0)',
#   '5/13/2022'],
#  [],
#  ["(4) Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.97m AA = Performance occurred at altitude (>1000 meters above sea level) 22-10½ (w: 1.0)',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}SOTexas6.97m  22-10½ (w: 1.3)5/14/2021',
#   '\xa0\xa0\xa0\xa0— Davis {2}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 1.3)',
#   '5/14/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {2}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 1.3)',
#   '5/14/2021'],
#  ['\xa0\xa0\xa0\xa0— Davis {3}SOTexas6.97m  22-10½ (w: 0.5)4/30/2021',
#   '\xa0\xa0\xa0\xa0— Davis {3}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 0.5)',
#   '4/30/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {3}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 0.5)',
#   '4/30/2021'],
#  ["\xa0\xa0\xa0\xa0— Davis {4}SOTexas6.97m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-10½ (w: 1.0)3/25/2021",
#   '\xa0\xa0\xa0\xa0— Davis {4}SO',
#   '',
#   'Texas',
#   "6.97m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-10½ (w: 1.0)",
#   '3/25/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {4}SO',
#   '',
#   'Texas',
#   "6.97m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-10½ (w: 1.0)",
#   '3/25/2021'],
#  ['(4) Carol LEWISHouston6.97m  22-10½4/29/1984',
#   '(4) Carol LEWIS',
#   '',
#   'Houston',
#   '6.97m  22-10½',
#   '4/29/1984'],
#  [],
#  ['(4) Carol LEWIS', '', 'Houston', '6.97m  22-10½', '4/29/1984'],
#  ['(6) Tyra GITTENSJRTexas A&M6.96m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-10 (w: 2.0)5/13/2021',
#   '(6) Tyra GITTENSJR',
#   '',
#   'Texas A&M',
#   '6.96m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-10 (w: 2.0)',
#   '5/13/2021'],
#  [],
#  ['(6) Tyra GITTENSJR',
#   '',
#   'Texas A&M',
#   '6.96m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-10 (w: 2.0)',
#   '5/13/2021'],
#  ['(7) Sheila ECHOLSSRLSU6.94m  22-9¼ (w: -1.0)6/5/1987',
#   '(7) Sheila ECHOLSSR',
#   '',
#   'LSU',
#   '6.94m  22-9¼ (w: -1.0)',
#   '6/5/1987'],
#  [],
#  ['(7) Sheila ECHOLSSR', '', 'LSU', '6.94m  22-9¼ (w: -1.0)', '6/5/1987'],
#  ['(8) Brittney REESEJROle Miss6.93m  22-9 (w: 0.9)6/12/2008',
#   '(8) Brittney REESEJR',
#   '',
#   'Ole Miss',
#   '6.93m  22-9 (w: 0.9)',
#   '6/12/2008'],
#  [],
#  ['(8) Brittney REESEJR', '', 'Ole Miss', '6.93m  22-9 (w: 0.9)', '6/12/2008'],
#  ["\xa0\xa0\xa0\xa0— Davis {5}SOTexas6.92m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-8½ (w: -0.7)4/30/2021",
#   '\xa0\xa0\xa0\xa0— Davis {5}SO',
#   '',
#   'Texas',
#   "6.92m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-8½ (w: -0.7)",
#   '4/30/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {5}SO',
#   '',
#   'Texas',
#   "6.92m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-8½ (w: -0.7)",
#   '4/30/2021'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston6.92m  22-8½4/28/1985',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '6.92m  22-8½',
#   '4/28/1985'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}', '', 'Houston', '6.92m  22-8½', '4/28/1985'],
#  ["\xa0\xa0\xa0\xa0— Lewis {3}Houston6.90m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-7¾4/28/1985",
#   '\xa0\xa0\xa0\xa0— Lewis {3}',
#   '',
#   'Houston',
#   "6.90m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-7¾",
#   '4/28/1985'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lewis {3}',
#   '',
#   'Houston',
#   "6.90m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-7¾",
#   '4/28/1985'],
#  ['(9) Deborah ACQUAHSRTexas A&M6.89m  22-7¼ (w: 0.7)4/2/2022',
#   '(9) Deborah ACQUAHSR',
#   '',
#   'Texas A&M',
#   '6.89m  22-7¼ (w: 0.7)',
#   '4/2/2022'],
#  [],
#  ['(9) Deborah ACQUAHSR',
#   '',
#   'Texas A&M',
#   '6.89m  22-7¼ (w: 0.7)',
#   '4/2/2022'],
#  ['\xa0\xa0\xa0\xa0— Smith {2}SOTexas6.88m  22-7 (w: -0.2)6/8/2023',
#   '\xa0\xa0\xa0\xa0— Smith {2}SO',
#   '',
#   'Texas',
#   '6.88m  22-7 (w: -0.2)',
#   '6/8/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Smith {2}SO',
#   '',
#   'Texas',
#   '6.88m  22-7 (w: -0.2)',
#   '6/8/2023'],
#  ['(10) Jasmine MOOREJRFlorida6.88m  22-7 (w: 0.3)5/12/2023',
#   '(10) Jasmine MOOREJR',
#   '',
#   'Florida',
#   '6.88m  22-7 (w: 0.3)',
#   '5/12/2023'],
#  [],
#  ['(10) Jasmine MOOREJR', '', 'Florida', '6.88m  22-7 (w: 0.3)', '5/12/2023'],
#  ['(10) Blessing OKAGBAREUTEP6.88m  22-74/2/2010',
#   '(10) Blessing OKAGBARE',
#   '',
#   'UTEP',
#   '6.88m  22-7',
#   '4/2/2010'],
#  [],
#  ['(10) Blessing OKAGBARE', '', 'UTEP', '6.88m  22-7', '4/2/2010'],
#  ['(12) Alyssa JONESFRStanford6.86m  22-6¼ (w: 0.1)6/8/2023',
#   '(12) Alyssa JONESFR',
#   '',
#   'Stanford',
#   '6.86m  22-6¼ (w: 0.1)',
#   '6/8/2023'],
#  [],
#  ['(12) Alyssa JONESFR', '', 'Stanford', '6.86m  22-6¼ (w: 0.1)', '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Nichols {2}SRTexas Tech6.86m  22-6¼ (w: 1.7)4/16/2022',
#   '\xa0\xa0\xa0\xa0— Nichols {2}SR',
#   '',
#   'Texas Tech',
#   '6.86m  22-6¼ (w: 1.7)',
#   '4/16/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Nichols {2}SR',
#   '',
#   'Texas Tech',
#   '6.86m  22-6¼ (w: 1.7)',
#   '4/16/2022'],
#  ["\xa0\xa0\xa0\xa0— Nichols {3}SRTexas Tech6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼ (w: 1.7)4/13/2022",
#   '\xa0\xa0\xa0\xa0— Nichols {3}SR',
#   '',
#   'Texas Tech',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼ (w: 1.7)",
#   '4/13/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Nichols {3}SR',
#   '',
#   'Texas Tech',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼ (w: 1.7)",
#   '4/13/2022'],
#  ['(12) Daphne SAUNDERSLSU6.86m  22-6¼5/15/1993',
#   '(12) Daphne SAUNDERS',
#   '',
#   'LSU',
#   '6.86m  22-6¼',
#   '5/15/1993'],
#  [],
#  ['(12) Daphne SAUNDERS', '', 'LSU', '6.86m  22-6¼', '5/15/1993'],
#  ["\xa0\xa0\xa0\xa0— Davis {6}SOTexas6.85m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¾ (w: 1.7)4/30/2021",
#   '\xa0\xa0\xa0\xa0— Davis {6}SO',
#   '',
#   'Texas',
#   "6.85m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¾ (w: 1.7)",
#   '4/30/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {6}SO',
#   '',
#   'Texas',
#   "6.85m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¾ (w: 1.7)",
#   '4/30/2021'],
#  ['(14) Yanis DAVIDSRFlorida6.84m  22-5¼ (w: 1.5)6/6/2019',
#   '(14) Yanis DAVIDSR',
#   '',
#   'Florida',
#   '6.84m  22-5¼ (w: 1.5)',
#   '6/6/2019'],
#  [],
#  ['(14) Yanis DAVIDSR', '', 'Florida', '6.84m  22-5¼ (w: 1.5)', '6/6/2019'],
#  ['(14) Quanesha BURKSAlabama6.84m  22-5¼ (w: 1.9)5/15/2015\xa0\xa0\xa0\xa0\xa0f, 6.24(0.0), 6.46(3.3), 6.36(1.7), 6.74(2.0), 6.84(1.9)',
#   '(14) Quanesha BURKS',
#   '',
#   'Alabama',
#   '6.84m  22-5¼ (w: 1.9)',
#   '5/15/2015',
#   '\xa0\xa0\xa0\xa0\xa0f, 6.24(0.0), 6.46(3.3), 6.36(1.7), 6.74(2.0), 6.84(1.9)'],
#  [],
#  ['(14) Quanesha BURKS', '', 'Alabama', '6.84m  22-5¼ (w: 1.9)', '5/15/2015'],
#  ['\xa0\xa0\xa0\xa0\xa0f, 6.24(0.0), 6.46(3.3), 6.36(1.7), 6.74(2.0), 6.84(1.9)'],
#  ['\xa0\xa0\xa0\xa0— Reese {2}Ole Miss6.84m  22-5¼5/17/2008',
#   '\xa0\xa0\xa0\xa0— Reese {2}',
#   '',
#   'Ole Miss',
#   '6.84m  22-5¼',
#   '5/17/2008'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Reese {2}', '', 'Ole Miss', '6.84m  22-5¼', '5/17/2008'],
#  ['\xa0\xa0\xa0\xa0— Moore {2}FRGeorgia6.83m  22-5 (w: 0.4)4/9/2021',
#   '\xa0\xa0\xa0\xa0— Moore {2}FR',
#   '',
#   'Georgia',
#   '6.83m  22-5 (w: 0.4)',
#   '4/9/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {2}FR',
#   '',
#   'Georgia',
#   '6.83m  22-5 (w: 0.4)',
#   '4/9/2021'],
#  ['\xa0\xa0\xa0\xa0— Moore {3}JRFlorida6.82m  22-4½ (w: 1.5)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 1.5)',
#   '5/12/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 1.5)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {4}SOFlorida6.82m  22-4½ (w: 2.0)4/30/2022',
#   '\xa0\xa0\xa0\xa0— Moore {4}SO',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 2.0)',
#   '4/30/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {4}SO',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 2.0)',
#   '4/30/2022'],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SRAlabama6.82m  22-4½ (w: 0.2)5/13/2017\xa0\xa0\xa0\xa0\xa06.82(0.2), f, p, 6.28(0.3), 6.73(0.0), 6.82(0.0)',
#   '\xa0\xa0\xa0\xa0— Burks {2}SR',
#   '',
#   'Alabama',
#   '6.82m  22-4½ (w: 0.2)',
#   '5/13/2017',
#   '\xa0\xa0\xa0\xa0\xa06.82(0.2), f, p, 6.28(0.3), 6.73(0.0), 6.82(0.0)'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SR',
#   '',
#   'Alabama',
#   '6.82m  22-4½ (w: 0.2)',
#   '5/13/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.82(0.2), f, p, 6.28(0.3), 6.73(0.0), 6.82(0.0)'],
#  ['(16) Rhonda WATKINSUCLA6.82m  22-4½5/25/2007',
#   '(16) Rhonda WATKINS',
#   '',
#   'UCLA',
#   '6.82m  22-4½',
#   '5/25/2007'],
#  [],
#  ['(16) Rhonda WATKINS', '', 'UCLA', '6.82m  22-4½', '5/25/2007'],
#  ['(16) Tianna MADISONTennessee6.82m  22-4½4/9/2005',
#   '(16) Tianna MADISON',
#   '',
#   'Tennessee',
#   '6.82m  22-4½',
#   '4/9/2005'],
#  [],
#  ['(16) Tianna MADISON', '', 'Tennessee', '6.82m  22-4½', '4/9/2005'],
#  ['(16) Elva GOULBOURNEJRAuburn6.82m  22-4½ (w: -0.5)5/30/2002',
#   '(16) Elva GOULBOURNEJR',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: -0.5)',
#   '5/30/2002'],
#  [],
#  ['(16) Elva GOULBOURNEJR',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: -0.5)',
#   '5/30/2002'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}Auburn6.82m  22-4½ (w: 1.1)5/12/2002',
#   '\xa0\xa0\xa0\xa0— Goulbourne {2}',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: 1.1)',
#   '5/12/2002'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: 1.1)',
#   '5/12/2002'],
#  ['\xa0\xa0\xa0\xa0— Moore {5}JRFlorida6.81m  22-4¼ (w: 0.6)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Moore {5}JR',
#   '',
#   'Florida',
#   '6.81m  22-4¼ (w: 0.6)',
#   '5/12/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {5}JR',
#   '',
#   'Florida',
#   '6.81m  22-4¼ (w: 0.6)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Acquah {2}JRTexas A&M6.81m  22-4¼ (w: 1.6)4/23/2021',
#   '\xa0\xa0\xa0\xa0— Acquah {2}JR',
#   '',
#   'Texas A&M',
#   '6.81m  22-4¼ (w: 1.6)',
#   '4/23/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Acquah {2}JR',
#   '',
#   'Texas A&M',
#   '6.81m  22-4¼ (w: 1.6)',
#   '4/23/2021'],
#  ['(19) Keturah ORJISRGeorgia6.81m  22-4¼ (w: 0.8)5/12/2018\xa0\xa0\xa0\xa0\xa06.55(0.0), f, 6.81(0.8), f, p, 6.78(0.1)',
#   '(19) Keturah ORJISR',
#   '',
#   'Georgia',
#   '6.81m  22-4¼ (w: 0.8)',
#   '5/12/2018',
#   '\xa0\xa0\xa0\xa0\xa06.55(0.0), f, 6.81(0.8), f, p, 6.78(0.1)'],
#  [],
#  ['(19) Keturah ORJISR', '', 'Georgia', '6.81m  22-4¼ (w: 0.8)', '5/12/2018'],
#  ['\xa0\xa0\xa0\xa0\xa06.55(0.0), f, 6.81(0.8), f, p, 6.78(0.1)'],
#  ['(19) Meledy SMITHTexas Southern6.81m  22-4¼5/6/1988',
#   '(19) Meledy SMITH',
#   '',
#   'Texas Southern',
#   '6.81m  22-4¼',
#   '5/6/1988'],
#  [],
#  ['(19) Meledy SMITH', '', 'Texas Southern', '6.81m  22-4¼', '5/6/1988'],
#  ['(19) Angie THACKERNebraska6.81m  22-4¼5/11/1984',
#   '(19) Angie THACKER',
#   '',
#   'Nebraska',
#   '6.81m  22-4¼',
#   '5/11/1984'],
#  [],
#  ['(19) Angie THACKER', '', 'Nebraska', '6.81m  22-4¼', '5/11/1984'],
#  ["\xa0\xa0\xa0\xa0— Nichols {4}SRTexas Tech6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-3¾ (w: 0.7)5/13/2022",
#   '\xa0\xa0\xa0\xa0— Nichols {4}SR',
#   '',
#   'Texas Tech',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-3¾ (w: 0.7)",
#   '5/13/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Nichols {4}SR',
#   '',
#   'Texas Tech',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-3¾ (w: 0.7)",
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Nichols {5}SRTexas Tech6.80m  22-3¾ (w: 1.5)3/26/2022',
#   '\xa0\xa0\xa0\xa0— Nichols {5}SR',
#   '',
#   'Texas Tech',
#   '6.80m  22-3¾ (w: 1.5)',
#   '3/26/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Nichols {5}SR',
#   '',
#   'Texas Tech',
#   '6.80m  22-3¾ (w: 1.5)',
#   '3/26/2022'],
#  ['(22) Jenna PRANDINIOregon6.80m  22-3¾ (w: 1.7)6/11/2015\xa0\xa0\xa0\xa0\xa04.48w(3.4), 6.38w(3.0), 6.80(1.7), PASS, PASS, FOUL (also in 100 and 200 prelims)',
#   '(22) Jenna PRANDINI',
#   '',
#   'Oregon',
#   '6.80m  22-3¾ (w: 1.7)',
#   '6/11/2015',
#   '\xa0\xa0\xa0\xa0\xa04.48w(3.4), 6.38w(3.0), 6.80(1.7), PASS, PASS, FOUL (also in 100 and 200 prelims)'],
#  [],
#  ['(22) Jenna PRANDINI', '', 'Oregon', '6.80m  22-3¾ (w: 1.7)', '6/11/2015'],
#  ['\xa0\xa0\xa0\xa0\xa04.48w(3.4), 6.38w(3.0), 6.80(1.7), PASS, PASS, FOUL (also in 100 and 200 prelims)'],
#  ["(22) Whitney GIPSONSRTCU6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3¾ (w: 1.4)6/7/2012",
#   '(22) Whitney GIPSONSR',
#   '',
#   'TCU',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3¾ (w: 1.4)",
#   '6/7/2012'],
#  [],
#  ['(22) Whitney GIPSONSR',
#   '',
#   'TCU',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3¾ (w: 1.4)",
#   '6/7/2012'],
#  ["(24) Sha'Keela SAUNDERSSRKentucky6.79m  22-3½ (w: 1.2)4/29/2017\xa0\xa0\xa0\xa0\xa06.77(2.0), f, 6.76(2.0), 6.57(0.1), 6.72(0.7), 6.79(1.2)",
#   "(24) Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.79m  22-3½ (w: 1.2)',
#   '4/29/2017',
#   '\xa0\xa0\xa0\xa0\xa06.77(2.0), f, 6.76(2.0), 6.57(0.1), 6.72(0.7), 6.79(1.2)'],
#  [],
#  ["(24) Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.79m  22-3½ (w: 1.2)',
#   '4/29/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.77(2.0), f, 6.76(2.0), 6.57(0.1), 6.72(0.7), 6.79(1.2)'],
#  ['\xa0\xa0\xa0\xa0— Okagbare {2}UTEP6.79m  22-3½ (w: 0.8)6/12/2010',
#   '\xa0\xa0\xa0\xa0— Okagbare {2}',
#   '',
#   'UTEP',
#   '6.79m  22-3½ (w: 0.8)',
#   '6/12/2010'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Okagbare {2}',
#   '',
#   'UTEP',
#   '6.79m  22-3½ (w: 0.8)',
#   '6/12/2010'],
#  ['(25) Ruth USOROSRTexas Tech6.78m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3 (w: 0.8)5/13/2022',
#   '(25) Ruth USOROSR',
#   '',
#   'Texas Tech',
#   '6.78m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3 (w: 0.8)',
#   '5/13/2022'],
#  [],
#  ['(25) Ruth USOROSR',
#   '',
#   'Texas Tech',
#   '6.78m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3 (w: 0.8)',
#   '5/13/2022'],
#  ["\xa0\xa0\xa0\xa0— Orji {2}SRGeorgia6.78m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3 (w: 0.1)5/12/2018",
#   '\xa0\xa0\xa0\xa0— Orji {2}SR',
#   '',
#   'Georgia',
#   "6.78m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3 (w: 0.1)",
#   '5/12/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Orji {2}SR',
#   '',
#   'Georgia',
#   "6.78m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3 (w: 0.1)",
#   '5/12/2018'],
#  ['(25) Taliyah BROOKSSRArkansas6.78m  22-3 (w: 1.2)3/24/2018\xa0\xa0\xa0\xa0\xa06.44w(2.7), 6.28(0.6), f, f, 6.38(0.0), 6.78(1.2)',
#   '(25) Taliyah BROOKSSR',
#   '',
#   'Arkansas',
#   '6.78m  22-3 (w: 1.2)',
#   '3/24/2018',
#   '\xa0\xa0\xa0\xa0\xa06.44w(2.7), 6.28(0.6), f, f, 6.38(0.0), 6.78(1.2)'],
#  [],
#  ['(25) Taliyah BROOKSSR',
#   '',
#   'Arkansas',
#   '6.78m  22-3 (w: 1.2)',
#   '3/24/2018'],
#  ['\xa0\xa0\xa0\xa0\xa06.44w(2.7), 6.28(0.6), f, f, 6.38(0.0), 6.78(1.2)'],
#  ['(25) Tori BOWIESouthern Miss6.78m  22-3 (w: 0.0)5/11/2012',
#   '(25) Tori BOWIE',
#   '',
#   'Southern Miss',
#   '6.78m  22-3 (w: 0.0)',
#   '5/11/2012'],
#  [],
#  ['(25) Tori BOWIE', '', 'Southern Miss', '6.78m  22-3 (w: 0.0)', '5/11/2012'],
#  ['(25) Diane GUTHRIE-GRESHAMGeorge Mason6.78m  22-31992',
#   '(25) Diane GUTHRIE-GRESHAM',
#   '',
#   'George Mason',
#   '6.78m  22-3',
#   '1992'],
#  [],
#  ['(25) Diane GUTHRIE-GRESHAM', '', 'George Mason', '6.78m  22-3', '1992'],
#  ['(25) Aisha JAMESIowa6.78m  22-32003',
#   '(25) Aisha JAMES',
#   '',
#   'Iowa',
#   '6.78m  22-3',
#   '2003'],
#  [],
#  ['(25) Aisha JAMES', '', 'Iowa', '6.78m  22-3', '2003'],
#  ['Additional All-Conditions Bests'],
#  ['Carol LEWISHouston7.03m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 23-¾5/26/1984',
#   'Carol LEWIS',
#   '',
#   'Houston',
#   '7.03m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 23-¾',
#   '5/26/1984'],
#  [],
#  ['Carol LEWIS',
#   '',
#   'Houston',
#   '7.03m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 23-¾',
#   '5/26/1984'],
#  ['Jasmine MOOREJRFlorida6.98m📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-10¾ (w: 2.7)4/14/2023\xa0\xa0\xa0\xa0\xa06.66W(5.5), 6.45(-0.3), 6.49w(3.0), 6.64w(2.6), 6.57(1.9), 6.98w(2.7)',
#   'Jasmine MOOREJR',
#   '',
#   'Florida',
#   '6.98m📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-10¾ (w: 2.7)',
#   '4/14/2023',
#   '\xa0\xa0\xa0\xa0\xa06.66W(5.5), 6.45(-0.3), 6.49w(3.0), 6.64w(2.6), 6.57(1.9), 6.98w(2.7)'],
#  [],
#  ['Jasmine MOOREJR',
#   '',
#   'Florida',
#   '6.98m📺 ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-10¾ (w: 2.7)',
#   '4/14/2023'],
#  ['\xa0\xa0\xa0\xa0\xa06.66W(5.5), 6.45(-0.3), 6.49w(3.0), 6.64w(2.6), 6.57(1.9), 6.98w(2.7)'],
#  ['Rhonda WATKINSSOUCLA6.96m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-10 (w: 2.5)6/7/2007',
#   'Rhonda WATKINSSO',
#   '',
#   'UCLA',
#   '6.96m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-10 (w: 2.5)',
#   '6/7/2007'],
#  [],
#  ['Rhonda WATKINSSO',
#   '',
#   'UCLA',
#   '6.96m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-10 (w: 2.5)',
#   '6/7/2007'],
#  ['Tyra GITTENSJRTexas A&M6.95m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round. 22-9¾ (w: 2.9)5/27/2021',
#   'Tyra GITTENSJR',
#   '',
#   'Texas A&M',
#   '6.95m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round. 22-9¾ (w: 2.9)',
#   '5/27/2021'],
#  [],
#  ['Tyra GITTENSJR',
#   '',
#   'Texas A&M',
#   '6.95m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round. 22-9¾ (w: 2.9)',
#   '5/27/2021'],
#  ['Tianna MADISONTennessee6.92m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-8½5/14/2005',
#   'Tianna MADISON',
#   '',
#   'Tennessee',
#   '6.92m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-8½',
#   '5/14/2005'],
#  [],
#  ['Tianna MADISON',
#   '',
#   'Tennessee',
#   '6.92m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-8½',
#   '5/14/2005'],
#  ['Diane GUTHRIESRGeorge Mason6.92m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-8½6/3/1995',
#   'Diane GUTHRIESR',
#   '',
#   'George Mason',
#   '6.92m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-8½',
#   '6/3/1995'],
#  [],
#  ['Diane GUTHRIESR',
#   '',
#   'George Mason',
#   '6.92m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-8½',
#   '6/3/1995'],
#  ['Quanesha BURKSAlabama6.91m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-8 (w: 2.6)6/11/2015\xa0\xa0\xa0\xa0\xa06.70w(3.6), 6.74w(2.4), 6.61w(3.4), 6.51w(2.7), 6.91w(2.6), 6.75w(2.2)',
#   'Quanesha BURKS',
#   '',
#   'Alabama',
#   '6.91m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-8 (w: 2.6)',
#   '6/11/2015',
#   '\xa0\xa0\xa0\xa0\xa06.70w(3.6), 6.74w(2.4), 6.61w(3.4), 6.51w(2.7), 6.91w(2.6), 6.75w(2.2)'],
#  [],
#  ['Quanesha BURKS',
#   '',
#   'Alabama',
#   '6.91m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-8 (w: 2.6)',
#   '6/11/2015'],
#  ['\xa0\xa0\xa0\xa0\xa06.70w(3.6), 6.74w(2.4), 6.61w(3.4), 6.51w(2.7), 6.91w(2.6), 6.75w(2.2)'],
#  ['Quanesha BURKSSRAlabama6.90m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-7¾ (w: 2.1)4/29/2017\xa0\xa0\xa0\xa0\xa06.28w(3.5), 6.90w(2.1), 6.76(0.1), 6.65(0.8), 6.62(1.5), 6.77(1.3)',
#   'Quanesha BURKSSR',
#   '',
#   'Alabama',
#   '6.90m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-7¾ (w: 2.1)',
#   '4/29/2017',
#   '\xa0\xa0\xa0\xa0\xa06.28w(3.5), 6.90w(2.1), 6.76(0.1), 6.65(0.8), 6.62(1.5), 6.77(1.3)'],
#  [],
#  ['Quanesha BURKSSR',
#   '',
#   'Alabama',
#   '6.90m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-7¾ (w: 2.1)',
#   '4/29/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.28w(3.5), 6.90w(2.1), 6.76(0.1), 6.65(0.8), 6.62(1.5), 6.77(1.3)'],
#  ["Monae' NICHOLSSRTexas Tech6.89m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-7¼ (w: 3.1)4/16/2022",
#   "Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.89m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-7¼ (w: 3.1)',
#   '4/16/2022'],
#  [],
#  ["Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.89m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-7¼ (w: 3.1)',
#   '4/16/2022'],
#  ["Monae' NICHOLSSRTexas Tech6.89m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-7¼ (w: 3.1)4/13/2022",
#   "Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.89m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-7¼ (w: 3.1)',
#   '4/13/2022'],
#  [],
#  ["Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.89m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-7¼ (w: 3.1)',
#   '4/13/2022'],
#  ['Marshevet HOOKERTexas6.89m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-7¼5/14/2005',
#   'Marshevet HOOKER',
#   '',
#   'Texas',
#   '6.89m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-7¼',
#   '5/14/2005'],
#  [],
#  ['Marshevet HOOKER',
#   '',
#   'Texas',
#   '6.89m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-7¼',
#   '5/14/2005'],
#  ['Tara DAVISSOTexas6.86m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round. 22-6¼ (w: 2.5)5/27/2021',
#   'Tara DAVISSO',
#   '',
#   'Texas',
#   '6.86m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round. 22-6¼ (w: 2.5)',
#   '5/27/2021'],
#  [],
#  ['Tara DAVISSO',
#   '',
#   'Texas',
#   '6.86m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round. 22-6¼ (w: 2.5)',
#   '5/27/2021'],
#  ['Chelsea HAYESLouisiana Tech6.86m WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s) 22-6¼ (w: 5.0)3/31/2012\xa0\xa0\xa0\xa0\xa06.39 (2.8), 6.48 (2.1), 6.86 (5.0), FOUL, FOUL, FOUL',
#   'Chelsea HAYES',
#   '',
#   'Louisiana Tech',
#   '6.86m WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s) 22-6¼ (w: 5.0)',
#   '3/31/2012',
#   '\xa0\xa0\xa0\xa0\xa06.39 (2.8), 6.48 (2.1), 6.86 (5.0), FOUL, FOUL, FOUL'],
#  [],
#  ['Chelsea HAYES',
#   '',
#   'Louisiana Tech',
#   '6.86m WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s) 22-6¼ (w: 5.0)',
#   '3/31/2012'],
#  ['\xa0\xa0\xa0\xa0\xa06.39 (2.8), 6.48 (2.1), 6.86 (5.0), FOUL, FOUL, FOUL'],
#  ['Dedra DAVISTennessee6.85m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-5¾ (w: 2.2)6/1/1994',
#   'Dedra DAVIS',
#   '',
#   'Tennessee',
#   '6.85m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-5¾ (w: 2.2)',
#   '6/1/1994'],
#  [],
#  ['Dedra DAVIS',
#   '',
#   'Tennessee',
#   '6.85m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-5¾ (w: 2.2)',
#   '6/1/1994'],
#  ["Gwen LOUDHawai'i6.85m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-5¾6/2/1984",
#   'Gwen LOUD',
#   '',
#   "Hawai'i",
#   '6.85m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-5¾',
#   '6/2/1984'],
#  [],
#  ['Gwen LOUD',
#   '',
#   "Hawai'i",
#   '6.85m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-5¾',
#   '6/2/1984'],
#  ['Lorraine UGENTCU6.83m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-5 (w: 2.8)3/15/2012',
#   'Lorraine UGEN',
#   '',
#   'TCU',
#   '6.83m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-5 (w: 2.8)',
#   '3/15/2012'],
#  [],
#  ['Lorraine UGEN',
#   '',
#   'TCU',
#   '6.83m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-5 (w: 2.8)',
#   '3/15/2012'],
#  ['Tyra GITTENSSRTexas6.82m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-4½ (w: 2.6)3/26/2022',
#   'Tyra GITTENSSR',
#   '',
#   'Texas',
#   '6.82m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-4½ (w: 2.6)',
#   '3/26/2022'],
#  [],
#  ['Tyra GITTENSSR',
#   '',
#   'Texas',
#   '6.82m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-4½ (w: 2.6)',
#   '3/26/2022'],
#  ['Chioma AGWUNOBIWestern Kentucky6.82m AA = Performance occurred at altitude (>1000 meters above sea level)WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s) 22-4½ (w: 4.6)5/17/2015',
#   'Chioma AGWUNOBI',
#   '',
#   'Western Kentucky',
#   '6.82m AA = Performance occurred at altitude (>1000 meters above sea level)WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s) 22-4½ (w: 4.6)',
#   '5/17/2015'],
#  [],
#  ['Chioma AGWUNOBI',
#   '',
#   'Western Kentucky',
#   '6.82m AA = Performance occurred at altitude (>1000 meters above sea level)WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s) 22-4½ (w: 4.6)',
#   '5/17/2015'],
#  ['Whitney GIPSONTCU6.82m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-4½ (w: 2.4)6/7/2012\xa0\xa0\xa0\xa0\xa06.50, 6.82w, 6.80, 4.86, 6.53, 6.29',
#   'Whitney GIPSON',
#   '',
#   'TCU',
#   '6.82m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-4½ (w: 2.4)',
#   '6/7/2012',
#   '\xa0\xa0\xa0\xa0\xa06.50, 6.82w, 6.80, 4.86, 6.53, 6.29'],
#  [],
#  ['Whitney GIPSON',
#   '',
#   'TCU',
#   '6.82m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-4½ (w: 2.4)',
#   '6/7/2012'],
#  ['\xa0\xa0\xa0\xa0\xa06.50, 6.82w, 6.80, 4.86, 6.53, 6.29'],
#  ['Alysah HICKEYFROregon6.81m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round. 22-4¼ (w: 2.3)5/27/2021',
#   'Alysah HICKEYFR',
#   '',
#   'Oregon',
#   '6.81m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round. 22-4¼ (w: 2.3)',
#   '5/27/2021'],
#  [],
#  ['Alysah HICKEYFR',
#   '',
#   'Oregon',
#   '6.81m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round. 22-4¼ (w: 2.3)',
#   '5/27/2021'],
#  ['Sydney CONLEYSRKansas6.81m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round. 22-4¼ (w: 2.2)5/27/2017\xa0\xa0\xa0\xa0\xa06.66(1.9), 6.81w(2.2), p',
#   'Sydney CONLEYSR',
#   '',
#   'Kansas',
#   '6.81m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round. 22-4¼ (w: 2.2)',
#   '5/27/2017',
#   '\xa0\xa0\xa0\xa0\xa06.66(1.9), 6.81w(2.2), p'],
#  [],
#  ['Sydney CONLEYSR',
#   '',
#   'Kansas',
#   '6.81m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s)qq = Performance occurred during a non-final round. 22-4¼ (w: 2.2)',
#   '5/27/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.66(1.9), 6.81w(2.2), p'],
#  ['Deborah ACQUAHJRTexas A&M6.80m WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s) 22-3¾ (w: 4.7)5/15/2021',
#   'Deborah ACQUAHJR',
#   '',
#   'Texas A&M',
#   '6.80m WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s) 22-3¾ (w: 4.7)',
#   '5/15/2021'],
#  [],
#  ['Deborah ACQUAHJR',
#   '',
#   'Texas A&M',
#   '6.80m WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s) 22-3¾ (w: 4.7)',
#   '5/15/2021'],
#  ['Angie THACKERNebraska6.80m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-3¾6/2/1984',
#   'Angie THACKER',
#   '',
#   'Nebraska',
#   '6.80m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-3¾',
#   '6/2/1984'],
#  [],
#  ['Angie THACKER',
#   '',
#   'Nebraska',
#   '6.80m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-3¾',
#   '6/2/1984'],
#  ['Alyssa JONESFRStanford6.79m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-3½ (w: 2.4)5/12/2023',
#   'Alyssa JONESFR',
#   '',
#   'Stanford',
#   '6.79m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-3½ (w: 2.4)',
#   '5/12/2023'],
#  [],
#  ['Alyssa JONESFR',
#   '',
#   'Stanford',
#   '6.79m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-3½ (w: 2.4)',
#   '5/12/2023'],
#  ['Deborah ACQUAHSRTexas A&M6.78m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-3 (w: 2.7)3/26/2022',
#   'Deborah ACQUAHSR',
#   '',
#   'Texas A&M',
#   '6.78m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-3 (w: 2.7)',
#   '3/26/2022'],
#  [],
#  ['Deborah ACQUAHSR',
#   '',
#   'Texas A&M',
#   '6.78m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-3 (w: 2.7)',
#   '3/26/2022'],
#  ['Additional Out-of-Season Bests'],
#  ['Jackie JOYNER-KERSEEUCLA7.24m  23-98/21/1985',
#   'Jackie JOYNER-KERSEE',
#   '',
#   'UCLA',
#   '7.24m  23-9',
#   '8/21/1985'],
#  [],
#  ['Jackie JOYNER-KERSEE', '', 'UCLA', '7.24m  23-9', '8/21/1985'],
#  ['Chelsea HAYESLouisiana Tech7.10m  23-3½ (w: 1.6)7/1/2012\xa0\xa0\xa0\xa0\xa06.76w, f, f, f, f, 7.10',
#   'Chelsea HAYES',
#   '',
#   'Louisiana Tech',
#   '7.10m  23-3½ (w: 1.6)',
#   '7/1/2012',
#   '\xa0\xa0\xa0\xa0\xa06.76w, f, f, f, f, 7.10'],
#  [],
#  ['Chelsea HAYES', '', 'Louisiana Tech', '7.10m  23-3½ (w: 1.6)', '7/1/2012'],
#  ['\xa0\xa0\xa0\xa0\xa06.76w, f, f, f, f, 7.10'],
#  ['Tara DAVISSOTexas7.04m  23-1¼ (w: 1.4)6/26/2021',
#   'Tara DAVISSO',
#   '',
#   'Texas',
#   '7.04m  23-1¼ (w: 1.4)',
#   '6/26/2021'],
#  [],
#  ['Tara DAVISSO', '', 'Texas', '7.04m  23-1¼ (w: 1.4)', '6/26/2021'],
#  ['Carol LEWISHouston7.04m  23-1¼8/21/1985',
#   'Carol LEWIS',
#   '',
#   'Houston',
#   '7.04m  23-1¼',
#   '8/21/1985'],
#  [],
#  ['Carol LEWIS', '', 'Houston', '7.04m  23-1¼', '8/21/1985'],
#  ['Whitney GIPSONTCU6.97m  22-10½ (w: 1.2)7/1/2012\xa0\xa0\xa0\xa0\xa06.73, f, 6.78, 6.87, f, 6.97',
#   'Whitney GIPSON',
#   '',
#   'TCU',
#   '6.97m  22-10½ (w: 1.2)',
#   '7/1/2012',
#   '\xa0\xa0\xa0\xa0\xa06.73, f, 6.78, 6.87, f, 6.97'],
#  [],
#  ['Whitney GIPSON', '', 'TCU', '6.97m  22-10½ (w: 1.2)', '7/1/2012'],
#  ['\xa0\xa0\xa0\xa0\xa06.73, f, 6.78, 6.87, f, 6.97'],
#  ['Vashti THOMASAcademy of Art6.97m qq = Performance occurred during a non-final round. 22-10½ (w: 1.0)6/29/2012',
#   'Vashti THOMAS',
#   '',
#   'Academy of Art',
#   '6.97m qq = Performance occurred during a non-final round. 22-10½ (w: 1.0)',
#   '6/29/2012'],
#  [],
#  ['Vashti THOMAS',
#   '',
#   'Academy of Art',
#   '6.97m qq = Performance occurred during a non-final round. 22-10½ (w: 1.0)',
#   '6/29/2012'],
#  ['Deborah ACQUAHSRTexas A&M6.94m  22-9¼ (w: 1.8)8/7/2022',
#   'Deborah ACQUAHSR',
#   '',
#   'Texas A&M',
#   '6.94m  22-9¼ (w: 1.8)',
#   '8/7/2022'],
#  [],
#  ['Deborah ACQUAHSR', '', 'Texas A&M', '6.94m  22-9¼ (w: 1.8)', '8/7/2022'],
#  ['Quanesha BURKSAlabama6.93m  22-9 (w: 2.0)8/9/2015',
#   'Quanesha BURKS',
#   '',
#   'Alabama',
#   '6.93m  22-9 (w: 2.0)',
#   '8/9/2015'],
#  [],
#  ['Quanesha BURKS', '', 'Alabama', '6.93m  22-9 (w: 2.0)', '8/9/2015'],
#  ['Blessing OKAGBAREUTEP6.91m  22-88/22/2008\xa0\xa0\xa0\xa0\xa06.91, 6.62, 6.79, 6.70, 6.83, f',
#   'Blessing OKAGBARE',
#   '',
#   'UTEP',
#   '6.91m  22-8',
#   '8/22/2008',
#   '\xa0\xa0\xa0\xa0\xa06.91, 6.62, 6.79, 6.70, 6.83, f'],
#  [],
#  ['Blessing OKAGBARE', '', 'UTEP', '6.91m  22-8', '8/22/2008'],
#  ['\xa0\xa0\xa0\xa0\xa06.91, 6.62, 6.79, 6.70, 6.83, f'],
#  ['Jodi ANDERSONCSUN6.90m  22-7¾6/10/1978',
#   'Jodi ANDERSON',
#   '',
#   'CSUN',
#   '6.90m  22-7¾',
#   '6/10/1978'],
#  [],
#  ['Jodi ANDERSON', '', 'CSUN', '6.90m  22-7¾', '6/10/1978'],
#  ["Sha'Keela SAUNDERSKentucky6.89m  22-7¼ (w: 1.8)7/2/2016\xa0\xa0\xa0\xa0\xa06.89(1.8), 6.68(0.6), f(2.1), 6.79(1.4), 6.83(1.4), f(1.5)",
#   "Sha'Keela SAUNDERS",
#   '',
#   'Kentucky',
#   '6.89m  22-7¼ (w: 1.8)',
#   '7/2/2016',
#   '\xa0\xa0\xa0\xa0\xa06.89(1.8), 6.68(0.6), f(2.1), 6.79(1.4), 6.83(1.4), f(1.5)'],
#  [],
#  ["Sha'Keela SAUNDERS", '', 'Kentucky', '6.89m  22-7¼ (w: 1.8)', '7/2/2016'],
#  ['\xa0\xa0\xa0\xa0\xa06.89(1.8), 6.68(0.6), f(2.1), 6.79(1.4), 6.83(1.4), f(1.5)'],
#  ['Tianna MADISONTennessee6.89m  22-7¼8/10/2005',
#   'Tianna MADISON',
#   '',
#   'Tennessee',
#   '6.89m  22-7¼',
#   '8/10/2005'],
#  [],
#  ['Tianna MADISON', '', 'Tennessee', '6.89m  22-7¼', '8/10/2005'],
#  ["Whitney GIPSONTCU6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6½ (w: 0.6)7/1/2012",
#   'Whitney GIPSON',
#   '',
#   'TCU',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6½ (w: 0.6)",
#   '7/1/2012'],
#  [],
#  ['Whitney GIPSON',
#   '',
#   'TCU',
#   "6.87m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6½ (w: 0.6)",
#   '7/1/2012'],
#  ['JROle Miss6.87m qq = Performance occurred during a non-final round. 22-6½ (w: 1.1)8/19/2008',
#   'JR',
#   '',
#   'Ole Miss',
#   '6.87m qq = Performance occurred during a non-final round. 22-6½ (w: 1.1)',
#   '8/19/2008'],
#  [],
#  ['JR',
#   '',
#   'Ole Miss',
#   '6.87m qq = Performance occurred during a non-final round. 22-6½ (w: 1.1)',
#   '8/19/2008'],
#  ['Meosha HUBBARDLife (Ga.)6.87m AA = Performance occurred at altitude (>1000 meters above sea level) 22-6½7/6/2000',
#   'Meosha HUBBARD',
#   '',
#   'Life (Ga.)',
#   '6.87m AA = Performance occurred at altitude (>1000 meters above sea level) 22-6½',
#   '7/6/2000'],
#  [],
#  ['Meosha HUBBARD',
#   '',
#   'Life (Ga.)',
#   '6.87m AA = Performance occurred at altitude (>1000 meters above sea level) 22-6½',
#   '7/6/2000'],
#  ['Lacena GOLDINGAuburn6.87m  22-6½6/27/1998',
#   'Lacena GOLDING',
#   '',
#   'Auburn',
#   '6.87m  22-6½',
#   '6/27/1998'],
#  [],
#  ['Lacena GOLDING', '', 'Auburn', '6.87m  22-6½', '6/27/1998'],
#  ['Deborah ACQUAHSRTexas A&M6.85m qq = Performance occurred during a non-final round. 22-5¾ (w: 1.1)8/5/2022',
#   'Deborah ACQUAHSR',
#   '',
#   'Texas A&M',
#   '6.85m qq = Performance occurred during a non-final round. 22-5¾ (w: 1.1)',
#   '8/5/2022'],
#  [],
#  ['Deborah ACQUAHSR',
#   '',
#   'Texas A&M',
#   '6.85m qq = Performance occurred during a non-final round. 22-5¾ (w: 1.1)',
#   '8/5/2022'],
#  ['Tara DAVISSOTexas6.85m qq = Performance occurred during a non-final round. 22-5¾ (w: 0.6)8/1/2021',
#   'Tara DAVISSO',
#   '',
#   'Texas',
#   '6.85m qq = Performance occurred during a non-final round. 22-5¾ (w: 0.6)',
#   '8/1/2021'],
#  [],
#  ['Tara DAVISSO',
#   '',
#   'Texas',
#   '6.85m qq = Performance occurred during a non-final round. 22-5¾ (w: 0.6)',
#   '8/1/2021'],
#  ['Tara DAVISSOTexas6.84m  22-5¼ (w: 0.8)8/3/2021',
#   'Tara DAVISSO',
#   '',
#   'Texas',
#   '6.84m  22-5¼ (w: 0.8)',
#   '8/3/2021'],
#  [],
#  ['Tara DAVISSO', '', 'Texas', '6.84m  22-5¼ (w: 0.8)', '8/3/2021'],
#  ['Jasmine TODDOregon6.84m  22-5¼ (w: 1.2)6/27/2015\xa0\xa0\xa0\xa0\xa06.70(1.6), 6.45(1.7), 6.63(0.3), 6.84(1.2), 6.39(1.5), 6.62(0.5)',
#   'Jasmine TODD',
#   '',
#   'Oregon',
#   '6.84m  22-5¼ (w: 1.2)',
#   '6/27/2015',
#   '\xa0\xa0\xa0\xa0\xa06.70(1.6), 6.45(1.7), 6.63(0.3), 6.84(1.2), 6.39(1.5), 6.62(0.5)'],
#  [],
#  ['Jasmine TODD', '', 'Oregon', '6.84m  22-5¼ (w: 1.2)', '6/27/2015'],
#  ['\xa0\xa0\xa0\xa0\xa06.70(1.6), 6.45(1.7), 6.63(0.3), 6.84(1.2), 6.39(1.5), 6.62(0.5)'],
#  ['Quanesha BURKSSRAlabama6.83m  22-5 (w: 0.5)7/6/2017\xa0\xa0\xa0\xa0\xa06.24(-1.3), 6.32(-0.9), 6.83(0.5), 6.53(0.0), p, p',
#   'Quanesha BURKSSR',
#   '',
#   'Alabama',
#   '6.83m  22-5 (w: 0.5)',
#   '7/6/2017',
#   '\xa0\xa0\xa0\xa0\xa06.24(-1.3), 6.32(-0.9), 6.83(0.5), 6.53(0.0), p, p'],
#  [],
#  ['Quanesha BURKSSR', '', 'Alabama', '6.83m  22-5 (w: 0.5)', '7/6/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.24(-1.3), 6.32(-0.9), 6.83(0.5), 6.53(0.0), p, p'],
#  ["Sha'Keela SAUNDERSKentucky6.83m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5 (w: 1.4)7/2/2016",
#   "Sha'Keela SAUNDERS",
#   '',
#   'Kentucky',
#   "6.83m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5 (w: 1.4)",
#   '7/2/2016'],
#  [],
#  ["Sha'Keela SAUNDERS",
#   '',
#   'Kentucky',
#   "6.83m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5 (w: 1.4)",
#   '7/2/2016'],
#  ['Whitney GIPSONTCU6.83m qq = Performance occurred during a non-final round. 22-5 (w: 1.4)6/29/2012',
#   'Whitney GIPSON',
#   '',
#   'TCU',
#   '6.83m qq = Performance occurred during a non-final round. 22-5 (w: 1.4)',
#   '6/29/2012'],
#  [],
#  ['Whitney GIPSON',
#   '',
#   'TCU',
#   '6.83m qq = Performance occurred during a non-final round. 22-5 (w: 1.4)',
#   '6/29/2012'],
#  ['SOOle Miss6.83m qq = Performance occurred during a non-final round. 22-5 (w: -0.1)8/27/2007',
#   'SO',
#   '',
#   'Ole Miss',
#   '6.83m qq = Performance occurred during a non-final round. 22-5 (w: -0.1)',
#   '8/27/2007'],
#  [],
#  ['SO',
#   '',
#   'Ole Miss',
#   '6.83m qq = Performance occurred during a non-final round. 22-5 (w: -0.1)',
#   '8/27/2007'],
#  ['Jennifer INNISSCal State LA6.82m  22-4½8/14/1982',
#   'Jennifer INNISS',
#   '',
#   'Cal State LA',
#   '6.82m  22-4½',
#   '8/14/1982'],
#  [],
#  ['Jennifer INNISS', '', 'Cal State LA', '6.82m  22-4½', '8/14/1982'],
#  ['JROle Miss6.80m  22-3¾ (w: 0.0)7/22/2008',
#   'JR',
#   '',
#   'Ole Miss',
#   '6.80m  22-3¾ (w: 0.0)',
#   '7/22/2008'],
#  [],
#  ['JR', '', 'Ole Miss', '6.80m  22-3¾ (w: 0.0)', '7/22/2008'],
#  ["Sha'Keela SAUNDERSKentucky6.79m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3½ (w: 1.4)7/2/2016",
#   "Sha'Keela SAUNDERS",
#   '',
#   'Kentucky',
#   "6.79m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3½ (w: 1.4)",
#   '7/2/2016'],
#  [],
#  ["Sha'Keela SAUNDERS",
#   '',
#   'Kentucky',
#   "6.79m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3½ (w: 1.4)",
#   '7/2/2016'],
#  ['Additional Out-of-Season, All-Conditions Bests'],
#  ["Sha'Keela SAUNDERSSRKentucky6.92m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-8½ (w: 3.0)6/24/2017\xa0\xa0\xa0\xa0\xa06.66(0.9), f, 6.57(-0.2), 6.77(-0.8), 6.92w(3.0), 6.58(0.8)",
#   "Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.92m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-8½ (w: 3.0)',
#   '6/24/2017',
#   '\xa0\xa0\xa0\xa0\xa06.66(0.9), f, 6.57(-0.2), 6.77(-0.8), 6.92w(3.0), 6.58(0.8)'],
#  [],
#  ["Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.92m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-8½ (w: 3.0)',
#   '6/24/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.66(0.9), f, 6.57(-0.2), 6.77(-0.8), 6.92w(3.0), 6.58(0.8)'],
#  ["Sha'Keela SAUNDERSSRKentucky6.92m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-8½ (w: 3.0)6/24/2017",
#   "Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.92m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-8½ (w: 3.0)',
#   '6/24/2017'],
#  [],
#  ["Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.92m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-8½ (w: 3.0)',
#   '6/24/2017'],
#  ['Aliyah WHISBYSOGeorgia6.82m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-4½ (w: 2.8)7/5/2019',
#   'Aliyah WHISBYSO',
#   '',
#   'Georgia',
#   '6.82m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-4½ (w: 2.8)',
#   '7/5/2019'],
#  [],
#  ['Aliyah WHISBYSO',
#   '',
#   'Georgia',
#   '6.82m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-4½ (w: 2.8)',
#   '7/5/2019'],
#  ['Jasmine MOORESOFlorida6.80m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-3¾ (w: 2.5)6/23/2022',
#   'Jasmine MOORESO',
#   '',
#   'Florida',
#   '6.80m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-3¾ (w: 2.5)',
#   '6/23/2022'],
#  [],
#  ['Jasmine MOORESO',
#   '',
#   'Florida',
#   '6.80m ww = Performance is wind-aided and not valid for records or lists (>2.0 m/s) 22-3¾ (w: 2.5)',
#   '6/23/2022'],
#  ["Sha'Keela SAUNDERSKentucky6.79m WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round. 22-3½ (w: 5.0)7/1/2016\xa0\xa0\xa0\xa0\xa06.79w(5.0), p, p",
#   "Sha'Keela SAUNDERS",
#   '',
#   'Kentucky',
#   '6.79m WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round. 22-3½ (w: 5.0)',
#   '7/1/2016',
#   '\xa0\xa0\xa0\xa0\xa06.79w(5.0), p, p'],
#  [],
#  ["Sha'Keela SAUNDERS",
#   '',
#   'Kentucky',
#   '6.79m WW = Performance is heavily wind-aided and not valid for qualifying (>4.0 m/s)qq = Performance occurred during a non-final round. 22-3½ (w: 5.0)',
#   '7/1/2016'],
#  ['\xa0\xa0\xa0\xa0\xa06.79w(5.0), p, p'],
#  ['', '', '', '']]

# %%
len(rows3)
# Out:
# 350

# %%
rows3[161]
# Out:
# ['Additional All-Conditions Bests']

# %%
RealRows3 = []

# %%
for i in range(0,161):
        RealRows3.append(rows3[i])

# %%
RealRows3
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Tara DAVISSOTexas7.14m📺  23-5¼ (w: 1.0)3/25/2021',
#   '(1) Tara DAVISSO',
#   '',
#   'Texas',
#   '7.14m📺  23-5¼ (w: 1.0)',
#   '3/25/2021'],
#  [],
#  ['(1) Tara DAVISSO', '', 'Texas', '7.14m📺  23-5¼ (w: 1.0)', '3/25/2021'],
#  ['(2) Ackelia SMITHSOTexas7.08m  23-2¾ (w: 1.9)5/12/2023',
#   '(2) Ackelia SMITHSO',
#   '',
#   'Texas',
#   '7.08m  23-2¾ (w: 1.9)',
#   '5/12/2023'],
#  [],
#  ['(2) Ackelia SMITHSO', '', 'Texas', '7.08m  23-2¾ (w: 1.9)', '5/12/2023'],
#  ['(3) Jackie JOYNER-KERSEEUCLA6.99m  22-11¼5/4/1985',
#   '(3) Jackie JOYNER-KERSEE',
#   '',
#   'UCLA',
#   '6.99m  22-11¼',
#   '5/4/1985'],
#  [],
#  ['(3) Jackie JOYNER-KERSEE', '', 'UCLA', '6.99m  22-11¼', '5/4/1985'],
#  ["(4) Monae' NICHOLSSRTexas Tech6.97m AA = Performance occurred at altitude (>1000 meters above sea level) 22-10½ (w: 1.0)5/13/2022",
#   "(4) Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.97m AA = Performance occurred at altitude (>1000 meters above sea level) 22-10½ (w: 1.0)',
#   '5/13/2022'],
#  [],
#  ["(4) Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.97m AA = Performance occurred at altitude (>1000 meters above sea level) 22-10½ (w: 1.0)',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}SOTexas6.97m  22-10½ (w: 1.3)5/14/2021',
#   '\xa0\xa0\xa0\xa0— Davis {2}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 1.3)',
#   '5/14/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {2}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 1.3)',
#   '5/14/2021'],
#  ['\xa0\xa0\xa0\xa0— Davis {3}SOTexas6.97m  22-10½ (w: 0.5)4/30/2021',
#   '\xa0\xa0\xa0\xa0— Davis {3}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 0.5)',
#   '4/30/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {3}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 0.5)',
#   '4/30/2021'],
#  ["\xa0\xa0\xa0\xa0— Davis {4}SOTexas6.97m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-10½ (w: 1.0)3/25/2021",
#   '\xa0\xa0\xa0\xa0— Davis {4}SO',
#   '',
#   'Texas',
#   "6.97m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-10½ (w: 1.0)",
#   '3/25/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {4}SO',
#   '',
#   'Texas',
#   "6.97m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-10½ (w: 1.0)",
#   '3/25/2021'],
#  ['(4) Carol LEWISHouston6.97m  22-10½4/29/1984',
#   '(4) Carol LEWIS',
#   '',
#   'Houston',
#   '6.97m  22-10½',
#   '4/29/1984'],
#  [],
#  ['(4) Carol LEWIS', '', 'Houston', '6.97m  22-10½', '4/29/1984'],
#  ['(6) Tyra GITTENSJRTexas A&M6.96m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-10 (w: 2.0)5/13/2021',
#   '(6) Tyra GITTENSJR',
#   '',
#   'Texas A&M',
#   '6.96m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-10 (w: 2.0)',
#   '5/13/2021'],
#  [],
#  ['(6) Tyra GITTENSJR',
#   '',
#   'Texas A&M',
#   '6.96m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-10 (w: 2.0)',
#   '5/13/2021'],
#  ['(7) Sheila ECHOLSSRLSU6.94m  22-9¼ (w: -1.0)6/5/1987',
#   '(7) Sheila ECHOLSSR',
#   '',
#   'LSU',
#   '6.94m  22-9¼ (w: -1.0)',
#   '6/5/1987'],
#  [],
#  ['(7) Sheila ECHOLSSR', '', 'LSU', '6.94m  22-9¼ (w: -1.0)', '6/5/1987'],
#  ['(8) Brittney REESEJROle Miss6.93m  22-9 (w: 0.9)6/12/2008',
#   '(8) Brittney REESEJR',
#   '',
#   'Ole Miss',
#   '6.93m  22-9 (w: 0.9)',
#   '6/12/2008'],
#  [],
#  ['(8) Brittney REESEJR', '', 'Ole Miss', '6.93m  22-9 (w: 0.9)', '6/12/2008'],
#  ["\xa0\xa0\xa0\xa0— Davis {5}SOTexas6.92m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-8½ (w: -0.7)4/30/2021",
#   '\xa0\xa0\xa0\xa0— Davis {5}SO',
#   '',
#   'Texas',
#   "6.92m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-8½ (w: -0.7)",
#   '4/30/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {5}SO',
#   '',
#   'Texas',
#   "6.92m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-8½ (w: -0.7)",
#   '4/30/2021'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston6.92m  22-8½4/28/1985',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '6.92m  22-8½',
#   '4/28/1985'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}', '', 'Houston', '6.92m  22-8½', '4/28/1985'],
#  ["\xa0\xa0\xa0\xa0— Lewis {3}Houston6.90m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-7¾4/28/1985",
#   '\xa0\xa0\xa0\xa0— Lewis {3}',
#   '',
#   'Houston',
#   "6.90m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-7¾",
#   '4/28/1985'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lewis {3}',
#   '',
#   'Houston',
#   "6.90m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-7¾",
#   '4/28/1985'],
#  ['(9) Deborah ACQUAHSRTexas A&M6.89m  22-7¼ (w: 0.7)4/2/2022',
#   '(9) Deborah ACQUAHSR',
#   '',
#   'Texas A&M',
#   '6.89m  22-7¼ (w: 0.7)',
#   '4/2/2022'],
#  [],
#  ['(9) Deborah ACQUAHSR',
#   '',
#   'Texas A&M',
#   '6.89m  22-7¼ (w: 0.7)',
#   '4/2/2022'],
#  ['\xa0\xa0\xa0\xa0— Smith {2}SOTexas6.88m  22-7 (w: -0.2)6/8/2023',
#   '\xa0\xa0\xa0\xa0— Smith {2}SO',
#   '',
#   'Texas',
#   '6.88m  22-7 (w: -0.2)',
#   '6/8/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Smith {2}SO',
#   '',
#   'Texas',
#   '6.88m  22-7 (w: -0.2)',
#   '6/8/2023'],
#  ['(10) Jasmine MOOREJRFlorida6.88m  22-7 (w: 0.3)5/12/2023',
#   '(10) Jasmine MOOREJR',
#   '',
#   'Florida',
#   '6.88m  22-7 (w: 0.3)',
#   '5/12/2023'],
#  [],
#  ['(10) Jasmine MOOREJR', '', 'Florida', '6.88m  22-7 (w: 0.3)', '5/12/2023'],
#  ['(10) Blessing OKAGBAREUTEP6.88m  22-74/2/2010',
#   '(10) Blessing OKAGBARE',
#   '',
#   'UTEP',
#   '6.88m  22-7',
#   '4/2/2010'],
#  [],
#  ['(10) Blessing OKAGBARE', '', 'UTEP', '6.88m  22-7', '4/2/2010'],
#  ['(12) Alyssa JONESFRStanford6.86m  22-6¼ (w: 0.1)6/8/2023',
#   '(12) Alyssa JONESFR',
#   '',
#   'Stanford',
#   '6.86m  22-6¼ (w: 0.1)',
#   '6/8/2023'],
#  [],
#  ['(12) Alyssa JONESFR', '', 'Stanford', '6.86m  22-6¼ (w: 0.1)', '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Nichols {2}SRTexas Tech6.86m  22-6¼ (w: 1.7)4/16/2022',
#   '\xa0\xa0\xa0\xa0— Nichols {2}SR',
#   '',
#   'Texas Tech',
#   '6.86m  22-6¼ (w: 1.7)',
#   '4/16/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Nichols {2}SR',
#   '',
#   'Texas Tech',
#   '6.86m  22-6¼ (w: 1.7)',
#   '4/16/2022'],
#  ["\xa0\xa0\xa0\xa0— Nichols {3}SRTexas Tech6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼ (w: 1.7)4/13/2022",
#   '\xa0\xa0\xa0\xa0— Nichols {3}SR',
#   '',
#   'Texas Tech',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼ (w: 1.7)",
#   '4/13/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Nichols {3}SR',
#   '',
#   'Texas Tech',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼ (w: 1.7)",
#   '4/13/2022'],
#  ['(12) Daphne SAUNDERSLSU6.86m  22-6¼5/15/1993',
#   '(12) Daphne SAUNDERS',
#   '',
#   'LSU',
#   '6.86m  22-6¼',
#   '5/15/1993'],
#  [],
#  ['(12) Daphne SAUNDERS', '', 'LSU', '6.86m  22-6¼', '5/15/1993'],
#  ["\xa0\xa0\xa0\xa0— Davis {6}SOTexas6.85m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¾ (w: 1.7)4/30/2021",
#   '\xa0\xa0\xa0\xa0— Davis {6}SO',
#   '',
#   'Texas',
#   "6.85m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¾ (w: 1.7)",
#   '4/30/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {6}SO',
#   '',
#   'Texas',
#   "6.85m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¾ (w: 1.7)",
#   '4/30/2021'],
#  ['(14) Yanis DAVIDSRFlorida6.84m  22-5¼ (w: 1.5)6/6/2019',
#   '(14) Yanis DAVIDSR',
#   '',
#   'Florida',
#   '6.84m  22-5¼ (w: 1.5)',
#   '6/6/2019'],
#  [],
#  ['(14) Yanis DAVIDSR', '', 'Florida', '6.84m  22-5¼ (w: 1.5)', '6/6/2019'],
#  ['(14) Quanesha BURKSAlabama6.84m  22-5¼ (w: 1.9)5/15/2015\xa0\xa0\xa0\xa0\xa0f, 6.24(0.0), 6.46(3.3), 6.36(1.7), 6.74(2.0), 6.84(1.9)',
#   '(14) Quanesha BURKS',
#   '',
#   'Alabama',
#   '6.84m  22-5¼ (w: 1.9)',
#   '5/15/2015',
#   '\xa0\xa0\xa0\xa0\xa0f, 6.24(0.0), 6.46(3.3), 6.36(1.7), 6.74(2.0), 6.84(1.9)'],
#  [],
#  ['(14) Quanesha BURKS', '', 'Alabama', '6.84m  22-5¼ (w: 1.9)', '5/15/2015'],
#  ['\xa0\xa0\xa0\xa0\xa0f, 6.24(0.0), 6.46(3.3), 6.36(1.7), 6.74(2.0), 6.84(1.9)'],
#  ['\xa0\xa0\xa0\xa0— Reese {2}Ole Miss6.84m  22-5¼5/17/2008',
#   '\xa0\xa0\xa0\xa0— Reese {2}',
#   '',
#   'Ole Miss',
#   '6.84m  22-5¼',
#   '5/17/2008'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Reese {2}', '', 'Ole Miss', '6.84m  22-5¼', '5/17/2008'],
#  ['\xa0\xa0\xa0\xa0— Moore {2}FRGeorgia6.83m  22-5 (w: 0.4)4/9/2021',
#   '\xa0\xa0\xa0\xa0— Moore {2}FR',
#   '',
#   'Georgia',
#   '6.83m  22-5 (w: 0.4)',
#   '4/9/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {2}FR',
#   '',
#   'Georgia',
#   '6.83m  22-5 (w: 0.4)',
#   '4/9/2021'],
#  ['\xa0\xa0\xa0\xa0— Moore {3}JRFlorida6.82m  22-4½ (w: 1.5)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 1.5)',
#   '5/12/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 1.5)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {4}SOFlorida6.82m  22-4½ (w: 2.0)4/30/2022',
#   '\xa0\xa0\xa0\xa0— Moore {4}SO',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 2.0)',
#   '4/30/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {4}SO',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 2.0)',
#   '4/30/2022'],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SRAlabama6.82m  22-4½ (w: 0.2)5/13/2017\xa0\xa0\xa0\xa0\xa06.82(0.2), f, p, 6.28(0.3), 6.73(0.0), 6.82(0.0)',
#   '\xa0\xa0\xa0\xa0— Burks {2}SR',
#   '',
#   'Alabama',
#   '6.82m  22-4½ (w: 0.2)',
#   '5/13/2017',
#   '\xa0\xa0\xa0\xa0\xa06.82(0.2), f, p, 6.28(0.3), 6.73(0.0), 6.82(0.0)'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SR',
#   '',
#   'Alabama',
#   '6.82m  22-4½ (w: 0.2)',
#   '5/13/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.82(0.2), f, p, 6.28(0.3), 6.73(0.0), 6.82(0.0)'],
#  ['(16) Rhonda WATKINSUCLA6.82m  22-4½5/25/2007',
#   '(16) Rhonda WATKINS',
#   '',
#   'UCLA',
#   '6.82m  22-4½',
#   '5/25/2007'],
#  [],
#  ['(16) Rhonda WATKINS', '', 'UCLA', '6.82m  22-4½', '5/25/2007'],
#  ['(16) Tianna MADISONTennessee6.82m  22-4½4/9/2005',
#   '(16) Tianna MADISON',
#   '',
#   'Tennessee',
#   '6.82m  22-4½',
#   '4/9/2005'],
#  [],
#  ['(16) Tianna MADISON', '', 'Tennessee', '6.82m  22-4½', '4/9/2005'],
#  ['(16) Elva GOULBOURNEJRAuburn6.82m  22-4½ (w: -0.5)5/30/2002',
#   '(16) Elva GOULBOURNEJR',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: -0.5)',
#   '5/30/2002'],
#  [],
#  ['(16) Elva GOULBOURNEJR',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: -0.5)',
#   '5/30/2002'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}Auburn6.82m  22-4½ (w: 1.1)5/12/2002',
#   '\xa0\xa0\xa0\xa0— Goulbourne {2}',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: 1.1)',
#   '5/12/2002'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: 1.1)',
#   '5/12/2002'],
#  ['\xa0\xa0\xa0\xa0— Moore {5}JRFlorida6.81m  22-4¼ (w: 0.6)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Moore {5}JR',
#   '',
#   'Florida',
#   '6.81m  22-4¼ (w: 0.6)',
#   '5/12/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Moore {5}JR',
#   '',
#   'Florida',
#   '6.81m  22-4¼ (w: 0.6)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Acquah {2}JRTexas A&M6.81m  22-4¼ (w: 1.6)4/23/2021',
#   '\xa0\xa0\xa0\xa0— Acquah {2}JR',
#   '',
#   'Texas A&M',
#   '6.81m  22-4¼ (w: 1.6)',
#   '4/23/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Acquah {2}JR',
#   '',
#   'Texas A&M',
#   '6.81m  22-4¼ (w: 1.6)',
#   '4/23/2021'],
#  ['(19) Keturah ORJISRGeorgia6.81m  22-4¼ (w: 0.8)5/12/2018\xa0\xa0\xa0\xa0\xa06.55(0.0), f, 6.81(0.8), f, p, 6.78(0.1)',
#   '(19) Keturah ORJISR',
#   '',
#   'Georgia',
#   '6.81m  22-4¼ (w: 0.8)',
#   '5/12/2018',
#   '\xa0\xa0\xa0\xa0\xa06.55(0.0), f, 6.81(0.8), f, p, 6.78(0.1)'],
#  [],
#  ['(19) Keturah ORJISR', '', 'Georgia', '6.81m  22-4¼ (w: 0.8)', '5/12/2018'],
#  ['\xa0\xa0\xa0\xa0\xa06.55(0.0), f, 6.81(0.8), f, p, 6.78(0.1)'],
#  ['(19) Meledy SMITHTexas Southern6.81m  22-4¼5/6/1988',
#   '(19) Meledy SMITH',
#   '',
#   'Texas Southern',
#   '6.81m  22-4¼',
#   '5/6/1988'],
#  [],
#  ['(19) Meledy SMITH', '', 'Texas Southern', '6.81m  22-4¼', '5/6/1988'],
#  ['(19) Angie THACKERNebraska6.81m  22-4¼5/11/1984',
#   '(19) Angie THACKER',
#   '',
#   'Nebraska',
#   '6.81m  22-4¼',
#   '5/11/1984'],
#  [],
#  ['(19) Angie THACKER', '', 'Nebraska', '6.81m  22-4¼', '5/11/1984'],
#  ["\xa0\xa0\xa0\xa0— Nichols {4}SRTexas Tech6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-3¾ (w: 0.7)5/13/2022",
#   '\xa0\xa0\xa0\xa0— Nichols {4}SR',
#   '',
#   'Texas Tech',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-3¾ (w: 0.7)",
#   '5/13/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Nichols {4}SR',
#   '',
#   'Texas Tech',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-3¾ (w: 0.7)",
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Nichols {5}SRTexas Tech6.80m  22-3¾ (w: 1.5)3/26/2022',
#   '\xa0\xa0\xa0\xa0— Nichols {5}SR',
#   '',
#   'Texas Tech',
#   '6.80m  22-3¾ (w: 1.5)',
#   '3/26/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Nichols {5}SR',
#   '',
#   'Texas Tech',
#   '6.80m  22-3¾ (w: 1.5)',
#   '3/26/2022'],
#  ['(22) Jenna PRANDINIOregon6.80m  22-3¾ (w: 1.7)6/11/2015\xa0\xa0\xa0\xa0\xa04.48w(3.4), 6.38w(3.0), 6.80(1.7), PASS, PASS, FOUL (also in 100 and 200 prelims)',
#   '(22) Jenna PRANDINI',
#   '',
#   'Oregon',
#   '6.80m  22-3¾ (w: 1.7)',
#   '6/11/2015',
#   '\xa0\xa0\xa0\xa0\xa04.48w(3.4), 6.38w(3.0), 6.80(1.7), PASS, PASS, FOUL (also in 100 and 200 prelims)'],
#  [],
#  ['(22) Jenna PRANDINI', '', 'Oregon', '6.80m  22-3¾ (w: 1.7)', '6/11/2015'],
#  ['\xa0\xa0\xa0\xa0\xa04.48w(3.4), 6.38w(3.0), 6.80(1.7), PASS, PASS, FOUL (also in 100 and 200 prelims)'],
#  ["(22) Whitney GIPSONSRTCU6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3¾ (w: 1.4)6/7/2012",
#   '(22) Whitney GIPSONSR',
#   '',
#   'TCU',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3¾ (w: 1.4)",
#   '6/7/2012'],
#  [],
#  ['(22) Whitney GIPSONSR',
#   '',
#   'TCU',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3¾ (w: 1.4)",
#   '6/7/2012'],
#  ["(24) Sha'Keela SAUNDERSSRKentucky6.79m  22-3½ (w: 1.2)4/29/2017\xa0\xa0\xa0\xa0\xa06.77(2.0), f, 6.76(2.0), 6.57(0.1), 6.72(0.7), 6.79(1.2)",
#   "(24) Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.79m  22-3½ (w: 1.2)',
#   '4/29/2017',
#   '\xa0\xa0\xa0\xa0\xa06.77(2.0), f, 6.76(2.0), 6.57(0.1), 6.72(0.7), 6.79(1.2)'],
#  [],
#  ["(24) Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.79m  22-3½ (w: 1.2)',
#   '4/29/2017'],
#  ['\xa0\xa0\xa0\xa0\xa06.77(2.0), f, 6.76(2.0), 6.57(0.1), 6.72(0.7), 6.79(1.2)'],
#  ['\xa0\xa0\xa0\xa0— Okagbare {2}UTEP6.79m  22-3½ (w: 0.8)6/12/2010',
#   '\xa0\xa0\xa0\xa0— Okagbare {2}',
#   '',
#   'UTEP',
#   '6.79m  22-3½ (w: 0.8)',
#   '6/12/2010'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Okagbare {2}',
#   '',
#   'UTEP',
#   '6.79m  22-3½ (w: 0.8)',
#   '6/12/2010'],
#  ['(25) Ruth USOROSRTexas Tech6.78m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3 (w: 0.8)5/13/2022',
#   '(25) Ruth USOROSR',
#   '',
#   'Texas Tech',
#   '6.78m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3 (w: 0.8)',
#   '5/13/2022'],
#  [],
#  ['(25) Ruth USOROSR',
#   '',
#   'Texas Tech',
#   '6.78m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3 (w: 0.8)',
#   '5/13/2022'],
#  ["\xa0\xa0\xa0\xa0— Orji {2}SRGeorgia6.78m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3 (w: 0.1)5/12/2018",
#   '\xa0\xa0\xa0\xa0— Orji {2}SR',
#   '',
#   'Georgia',
#   "6.78m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3 (w: 0.1)",
#   '5/12/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Orji {2}SR',
#   '',
#   'Georgia',
#   "6.78m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3 (w: 0.1)",
#   '5/12/2018'],
#  ['(25) Taliyah BROOKSSRArkansas6.78m  22-3 (w: 1.2)3/24/2018\xa0\xa0\xa0\xa0\xa06.44w(2.7), 6.28(0.6), f, f, 6.38(0.0), 6.78(1.2)',
#   '(25) Taliyah BROOKSSR',
#   '',
#   'Arkansas',
#   '6.78m  22-3 (w: 1.2)',
#   '3/24/2018',
#   '\xa0\xa0\xa0\xa0\xa06.44w(2.7), 6.28(0.6), f, f, 6.38(0.0), 6.78(1.2)'],
#  [],
#  ['(25) Taliyah BROOKSSR',
#   '',
#   'Arkansas',
#   '6.78m  22-3 (w: 1.2)',
#   '3/24/2018'],
#  ['\xa0\xa0\xa0\xa0\xa06.44w(2.7), 6.28(0.6), f, f, 6.38(0.0), 6.78(1.2)'],
#  ['(25) Tori BOWIESouthern Miss6.78m  22-3 (w: 0.0)5/11/2012',
#   '(25) Tori BOWIE',
#   '',
#   'Southern Miss',
#   '6.78m  22-3 (w: 0.0)',
#   '5/11/2012'],
#  [],
#  ['(25) Tori BOWIE', '', 'Southern Miss', '6.78m  22-3 (w: 0.0)', '5/11/2012'],
#  ['(25) Diane GUTHRIE-GRESHAMGeorge Mason6.78m  22-31992',
#   '(25) Diane GUTHRIE-GRESHAM',
#   '',
#   'George Mason',
#   '6.78m  22-3',
#   '1992'],
#  [],
#  ['(25) Diane GUTHRIE-GRESHAM', '', 'George Mason', '6.78m  22-3', '1992'],
#  ['(25) Aisha JAMESIowa6.78m  22-32003',
#   '(25) Aisha JAMES',
#   '',
#   'Iowa',
#   '6.78m  22-3',
#   '2003'],
#  [],
#  ['(25) Aisha JAMES', '', 'Iowa', '6.78m  22-3', '2003']]

# %%
RealRows = []

# %%
for i in range(0,161):
    if len(RealRows3[i]) > 1:
        RealRows.append(RealRows3[i])

# %%
RealRows
# Out:
# [['(1) Tara DAVISSOTexas7.14m📺  23-5¼ (w: 1.0)3/25/2021',
#   '(1) Tara DAVISSO',
#   '',
#   'Texas',
#   '7.14m📺  23-5¼ (w: 1.0)',
#   '3/25/2021'],
#  ['(1) Tara DAVISSO', '', 'Texas', '7.14m📺  23-5¼ (w: 1.0)', '3/25/2021'],
#  ['(2) Ackelia SMITHSOTexas7.08m  23-2¾ (w: 1.9)5/12/2023',
#   '(2) Ackelia SMITHSO',
#   '',
#   'Texas',
#   '7.08m  23-2¾ (w: 1.9)',
#   '5/12/2023'],
#  ['(2) Ackelia SMITHSO', '', 'Texas', '7.08m  23-2¾ (w: 1.9)', '5/12/2023'],
#  ['(3) Jackie JOYNER-KERSEEUCLA6.99m  22-11¼5/4/1985',
#   '(3) Jackie JOYNER-KERSEE',
#   '',
#   'UCLA',
#   '6.99m  22-11¼',
#   '5/4/1985'],
#  ['(3) Jackie JOYNER-KERSEE', '', 'UCLA', '6.99m  22-11¼', '5/4/1985'],
#  ["(4) Monae' NICHOLSSRTexas Tech6.97m AA = Performance occurred at altitude (>1000 meters above sea level) 22-10½ (w: 1.0)5/13/2022",
#   "(4) Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.97m AA = Performance occurred at altitude (>1000 meters above sea level) 22-10½ (w: 1.0)',
#   '5/13/2022'],
#  ["(4) Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.97m AA = Performance occurred at altitude (>1000 meters above sea level) 22-10½ (w: 1.0)',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}SOTexas6.97m  22-10½ (w: 1.3)5/14/2021',
#   '\xa0\xa0\xa0\xa0— Davis {2}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 1.3)',
#   '5/14/2021'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 1.3)',
#   '5/14/2021'],
#  ['\xa0\xa0\xa0\xa0— Davis {3}SOTexas6.97m  22-10½ (w: 0.5)4/30/2021',
#   '\xa0\xa0\xa0\xa0— Davis {3}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 0.5)',
#   '4/30/2021'],
#  ['\xa0\xa0\xa0\xa0— Davis {3}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 0.5)',
#   '4/30/2021'],
#  ["\xa0\xa0\xa0\xa0— Davis {4}SOTexas6.97m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-10½ (w: 1.0)3/25/2021",
#   '\xa0\xa0\xa0\xa0— Davis {4}SO',
#   '',
#   'Texas',
#   "6.97m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-10½ (w: 1.0)",
#   '3/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Davis {4}SO',
#   '',
#   'Texas',
#   "6.97m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-10½ (w: 1.0)",
#   '3/25/2021'],
#  ['(4) Carol LEWISHouston6.97m  22-10½4/29/1984',
#   '(4) Carol LEWIS',
#   '',
#   'Houston',
#   '6.97m  22-10½',
#   '4/29/1984'],
#  ['(4) Carol LEWIS', '', 'Houston', '6.97m  22-10½', '4/29/1984'],
#  ['(6) Tyra GITTENSJRTexas A&M6.96m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-10 (w: 2.0)5/13/2021',
#   '(6) Tyra GITTENSJR',
#   '',
#   'Texas A&M',
#   '6.96m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-10 (w: 2.0)',
#   '5/13/2021'],
#  ['(6) Tyra GITTENSJR',
#   '',
#   'Texas A&M',
#   '6.96m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-10 (w: 2.0)',
#   '5/13/2021'],
#  ['(7) Sheila ECHOLSSRLSU6.94m  22-9¼ (w: -1.0)6/5/1987',
#   '(7) Sheila ECHOLSSR',
#   '',
#   'LSU',
#   '6.94m  22-9¼ (w: -1.0)',
#   '6/5/1987'],
#  ['(7) Sheila ECHOLSSR', '', 'LSU', '6.94m  22-9¼ (w: -1.0)', '6/5/1987'],
#  ['(8) Brittney REESEJROle Miss6.93m  22-9 (w: 0.9)6/12/2008',
#   '(8) Brittney REESEJR',
#   '',
#   'Ole Miss',
#   '6.93m  22-9 (w: 0.9)',
#   '6/12/2008'],
#  ['(8) Brittney REESEJR', '', 'Ole Miss', '6.93m  22-9 (w: 0.9)', '6/12/2008'],
#  ["\xa0\xa0\xa0\xa0— Davis {5}SOTexas6.92m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-8½ (w: -0.7)4/30/2021",
#   '\xa0\xa0\xa0\xa0— Davis {5}SO',
#   '',
#   'Texas',
#   "6.92m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-8½ (w: -0.7)",
#   '4/30/2021'],
#  ['\xa0\xa0\xa0\xa0— Davis {5}SO',
#   '',
#   'Texas',
#   "6.92m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-8½ (w: -0.7)",
#   '4/30/2021'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston6.92m  22-8½4/28/1985',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '6.92m  22-8½',
#   '4/28/1985'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}', '', 'Houston', '6.92m  22-8½', '4/28/1985'],
#  ["\xa0\xa0\xa0\xa0— Lewis {3}Houston6.90m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-7¾4/28/1985",
#   '\xa0\xa0\xa0\xa0— Lewis {3}',
#   '',
#   'Houston',
#   "6.90m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-7¾",
#   '4/28/1985'],
#  ['\xa0\xa0\xa0\xa0— Lewis {3}',
#   '',
#   'Houston',
#   "6.90m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-7¾",
#   '4/28/1985'],
#  ['(9) Deborah ACQUAHSRTexas A&M6.89m  22-7¼ (w: 0.7)4/2/2022',
#   '(9) Deborah ACQUAHSR',
#   '',
#   'Texas A&M',
#   '6.89m  22-7¼ (w: 0.7)',
#   '4/2/2022'],
#  ['(9) Deborah ACQUAHSR',
#   '',
#   'Texas A&M',
#   '6.89m  22-7¼ (w: 0.7)',
#   '4/2/2022'],
#  ['\xa0\xa0\xa0\xa0— Smith {2}SOTexas6.88m  22-7 (w: -0.2)6/8/2023',
#   '\xa0\xa0\xa0\xa0— Smith {2}SO',
#   '',
#   'Texas',
#   '6.88m  22-7 (w: -0.2)',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Smith {2}SO',
#   '',
#   'Texas',
#   '6.88m  22-7 (w: -0.2)',
#   '6/8/2023'],
#  ['(10) Jasmine MOOREJRFlorida6.88m  22-7 (w: 0.3)5/12/2023',
#   '(10) Jasmine MOOREJR',
#   '',
#   'Florida',
#   '6.88m  22-7 (w: 0.3)',
#   '5/12/2023'],
#  ['(10) Jasmine MOOREJR', '', 'Florida', '6.88m  22-7 (w: 0.3)', '5/12/2023'],
#  ['(10) Blessing OKAGBAREUTEP6.88m  22-74/2/2010',
#   '(10) Blessing OKAGBARE',
#   '',
#   'UTEP',
#   '6.88m  22-7',
#   '4/2/2010'],
#  ['(10) Blessing OKAGBARE', '', 'UTEP', '6.88m  22-7', '4/2/2010'],
#  ['(12) Alyssa JONESFRStanford6.86m  22-6¼ (w: 0.1)6/8/2023',
#   '(12) Alyssa JONESFR',
#   '',
#   'Stanford',
#   '6.86m  22-6¼ (w: 0.1)',
#   '6/8/2023'],
#  ['(12) Alyssa JONESFR', '', 'Stanford', '6.86m  22-6¼ (w: 0.1)', '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Nichols {2}SRTexas Tech6.86m  22-6¼ (w: 1.7)4/16/2022',
#   '\xa0\xa0\xa0\xa0— Nichols {2}SR',
#   '',
#   'Texas Tech',
#   '6.86m  22-6¼ (w: 1.7)',
#   '4/16/2022'],
#  ['\xa0\xa0\xa0\xa0— Nichols {2}SR',
#   '',
#   'Texas Tech',
#   '6.86m  22-6¼ (w: 1.7)',
#   '4/16/2022'],
#  ["\xa0\xa0\xa0\xa0— Nichols {3}SRTexas Tech6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼ (w: 1.7)4/13/2022",
#   '\xa0\xa0\xa0\xa0— Nichols {3}SR',
#   '',
#   'Texas Tech',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼ (w: 1.7)",
#   '4/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Nichols {3}SR',
#   '',
#   'Texas Tech',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼ (w: 1.7)",
#   '4/13/2022'],
#  ['(12) Daphne SAUNDERSLSU6.86m  22-6¼5/15/1993',
#   '(12) Daphne SAUNDERS',
#   '',
#   'LSU',
#   '6.86m  22-6¼',
#   '5/15/1993'],
#  ['(12) Daphne SAUNDERS', '', 'LSU', '6.86m  22-6¼', '5/15/1993'],
#  ["\xa0\xa0\xa0\xa0— Davis {6}SOTexas6.85m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¾ (w: 1.7)4/30/2021",
#   '\xa0\xa0\xa0\xa0— Davis {6}SO',
#   '',
#   'Texas',
#   "6.85m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¾ (w: 1.7)",
#   '4/30/2021'],
#  ['\xa0\xa0\xa0\xa0— Davis {6}SO',
#   '',
#   'Texas',
#   "6.85m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¾ (w: 1.7)",
#   '4/30/2021'],
#  ['(14) Yanis DAVIDSRFlorida6.84m  22-5¼ (w: 1.5)6/6/2019',
#   '(14) Yanis DAVIDSR',
#   '',
#   'Florida',
#   '6.84m  22-5¼ (w: 1.5)',
#   '6/6/2019'],
#  ['(14) Yanis DAVIDSR', '', 'Florida', '6.84m  22-5¼ (w: 1.5)', '6/6/2019'],
#  ['(14) Quanesha BURKSAlabama6.84m  22-5¼ (w: 1.9)5/15/2015\xa0\xa0\xa0\xa0\xa0f, 6.24(0.0), 6.46(3.3), 6.36(1.7), 6.74(2.0), 6.84(1.9)',
#   '(14) Quanesha BURKS',
#   '',
#   'Alabama',
#   '6.84m  22-5¼ (w: 1.9)',
#   '5/15/2015',
#   '\xa0\xa0\xa0\xa0\xa0f, 6.24(0.0), 6.46(3.3), 6.36(1.7), 6.74(2.0), 6.84(1.9)'],
#  ['(14) Quanesha BURKS', '', 'Alabama', '6.84m  22-5¼ (w: 1.9)', '5/15/2015'],
#  ['\xa0\xa0\xa0\xa0— Reese {2}Ole Miss6.84m  22-5¼5/17/2008',
#   '\xa0\xa0\xa0\xa0— Reese {2}',
#   '',
#   'Ole Miss',
#   '6.84m  22-5¼',
#   '5/17/2008'],
#  ['\xa0\xa0\xa0\xa0— Reese {2}', '', 'Ole Miss', '6.84m  22-5¼', '5/17/2008'],
#  ['\xa0\xa0\xa0\xa0— Moore {2}FRGeorgia6.83m  22-5 (w: 0.4)4/9/2021',
#   '\xa0\xa0\xa0\xa0— Moore {2}FR',
#   '',
#   'Georgia',
#   '6.83m  22-5 (w: 0.4)',
#   '4/9/2021'],
#  ['\xa0\xa0\xa0\xa0— Moore {2}FR',
#   '',
#   'Georgia',
#   '6.83m  22-5 (w: 0.4)',
#   '4/9/2021'],
#  ['\xa0\xa0\xa0\xa0— Moore {3}JRFlorida6.82m  22-4½ (w: 1.5)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 1.5)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 1.5)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {4}SOFlorida6.82m  22-4½ (w: 2.0)4/30/2022',
#   '\xa0\xa0\xa0\xa0— Moore {4}SO',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 2.0)',
#   '4/30/2022'],
#  ['\xa0\xa0\xa0\xa0— Moore {4}SO',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 2.0)',
#   '4/30/2022'],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SRAlabama6.82m  22-4½ (w: 0.2)5/13/2017\xa0\xa0\xa0\xa0\xa06.82(0.2), f, p, 6.28(0.3), 6.73(0.0), 6.82(0.0)',
#   '\xa0\xa0\xa0\xa0— Burks {2}SR',
#   '',
#   'Alabama',
#   '6.82m  22-4½ (w: 0.2)',
#   '5/13/2017',
#   '\xa0\xa0\xa0\xa0\xa06.82(0.2), f, p, 6.28(0.3), 6.73(0.0), 6.82(0.0)'],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SR',
#   '',
#   'Alabama',
#   '6.82m  22-4½ (w: 0.2)',
#   '5/13/2017'],
#  ['(16) Rhonda WATKINSUCLA6.82m  22-4½5/25/2007',
#   '(16) Rhonda WATKINS',
#   '',
#   'UCLA',
#   '6.82m  22-4½',
#   '5/25/2007'],
#  ['(16) Rhonda WATKINS', '', 'UCLA', '6.82m  22-4½', '5/25/2007'],
#  ['(16) Tianna MADISONTennessee6.82m  22-4½4/9/2005',
#   '(16) Tianna MADISON',
#   '',
#   'Tennessee',
#   '6.82m  22-4½',
#   '4/9/2005'],
#  ['(16) Tianna MADISON', '', 'Tennessee', '6.82m  22-4½', '4/9/2005'],
#  ['(16) Elva GOULBOURNEJRAuburn6.82m  22-4½ (w: -0.5)5/30/2002',
#   '(16) Elva GOULBOURNEJR',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: -0.5)',
#   '5/30/2002'],
#  ['(16) Elva GOULBOURNEJR',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: -0.5)',
#   '5/30/2002'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}Auburn6.82m  22-4½ (w: 1.1)5/12/2002',
#   '\xa0\xa0\xa0\xa0— Goulbourne {2}',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: 1.1)',
#   '5/12/2002'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: 1.1)',
#   '5/12/2002'],
#  ['\xa0\xa0\xa0\xa0— Moore {5}JRFlorida6.81m  22-4¼ (w: 0.6)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Moore {5}JR',
#   '',
#   'Florida',
#   '6.81m  22-4¼ (w: 0.6)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {5}JR',
#   '',
#   'Florida',
#   '6.81m  22-4¼ (w: 0.6)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Acquah {2}JRTexas A&M6.81m  22-4¼ (w: 1.6)4/23/2021',
#   '\xa0\xa0\xa0\xa0— Acquah {2}JR',
#   '',
#   'Texas A&M',
#   '6.81m  22-4¼ (w: 1.6)',
#   '4/23/2021'],
#  ['\xa0\xa0\xa0\xa0— Acquah {2}JR',
#   '',
#   'Texas A&M',
#   '6.81m  22-4¼ (w: 1.6)',
#   '4/23/2021'],
#  ['(19) Keturah ORJISRGeorgia6.81m  22-4¼ (w: 0.8)5/12/2018\xa0\xa0\xa0\xa0\xa06.55(0.0), f, 6.81(0.8), f, p, 6.78(0.1)',
#   '(19) Keturah ORJISR',
#   '',
#   'Georgia',
#   '6.81m  22-4¼ (w: 0.8)',
#   '5/12/2018',
#   '\xa0\xa0\xa0\xa0\xa06.55(0.0), f, 6.81(0.8), f, p, 6.78(0.1)'],
#  ['(19) Keturah ORJISR', '', 'Georgia', '6.81m  22-4¼ (w: 0.8)', '5/12/2018'],
#  ['(19) Meledy SMITHTexas Southern6.81m  22-4¼5/6/1988',
#   '(19) Meledy SMITH',
#   '',
#   'Texas Southern',
#   '6.81m  22-4¼',
#   '5/6/1988'],
#  ['(19) Meledy SMITH', '', 'Texas Southern', '6.81m  22-4¼', '5/6/1988'],
#  ['(19) Angie THACKERNebraska6.81m  22-4¼5/11/1984',
#   '(19) Angie THACKER',
#   '',
#   'Nebraska',
#   '6.81m  22-4¼',
#   '5/11/1984'],
#  ['(19) Angie THACKER', '', 'Nebraska', '6.81m  22-4¼', '5/11/1984'],
#  ["\xa0\xa0\xa0\xa0— Nichols {4}SRTexas Tech6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-3¾ (w: 0.7)5/13/2022",
#   '\xa0\xa0\xa0\xa0— Nichols {4}SR',
#   '',
#   'Texas Tech',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-3¾ (w: 0.7)",
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Nichols {4}SR',
#   '',
#   'Texas Tech',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-3¾ (w: 0.7)",
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Nichols {5}SRTexas Tech6.80m  22-3¾ (w: 1.5)3/26/2022',
#   '\xa0\xa0\xa0\xa0— Nichols {5}SR',
#   '',
#   'Texas Tech',
#   '6.80m  22-3¾ (w: 1.5)',
#   '3/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Nichols {5}SR',
#   '',
#   'Texas Tech',
#   '6.80m  22-3¾ (w: 1.5)',
#   '3/26/2022'],
#  ['(22) Jenna PRANDINIOregon6.80m  22-3¾ (w: 1.7)6/11/2015\xa0\xa0\xa0\xa0\xa04.48w(3.4), 6.38w(3.0), 6.80(1.7), PASS, PASS, FOUL (also in 100 and 200 prelims)',
#   '(22) Jenna PRANDINI',
#   '',
#   'Oregon',
#   '6.80m  22-3¾ (w: 1.7)',
#   '6/11/2015',
#   '\xa0\xa0\xa0\xa0\xa04.48w(3.4), 6.38w(3.0), 6.80(1.7), PASS, PASS, FOUL (also in 100 and 200 prelims)'],
#  ['(22) Jenna PRANDINI', '', 'Oregon', '6.80m  22-3¾ (w: 1.7)', '6/11/2015'],
#  ["(22) Whitney GIPSONSRTCU6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3¾ (w: 1.4)6/7/2012",
#   '(22) Whitney GIPSONSR',
#   '',
#   'TCU',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3¾ (w: 1.4)",
#   '6/7/2012'],
#  ['(22) Whitney GIPSONSR',
#   '',
#   'TCU',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3¾ (w: 1.4)",
#   '6/7/2012'],
#  ["(24) Sha'Keela SAUNDERSSRKentucky6.79m  22-3½ (w: 1.2)4/29/2017\xa0\xa0\xa0\xa0\xa06.77(2.0), f, 6.76(2.0), 6.57(0.1), 6.72(0.7), 6.79(1.2)",
#   "(24) Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.79m  22-3½ (w: 1.2)',
#   '4/29/2017',
#   '\xa0\xa0\xa0\xa0\xa06.77(2.0), f, 6.76(2.0), 6.57(0.1), 6.72(0.7), 6.79(1.2)'],
#  ["(24) Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.79m  22-3½ (w: 1.2)',
#   '4/29/2017'],
#  ['\xa0\xa0\xa0\xa0— Okagbare {2}UTEP6.79m  22-3½ (w: 0.8)6/12/2010',
#   '\xa0\xa0\xa0\xa0— Okagbare {2}',
#   '',
#   'UTEP',
#   '6.79m  22-3½ (w: 0.8)',
#   '6/12/2010'],
#  ['\xa0\xa0\xa0\xa0— Okagbare {2}',
#   '',
#   'UTEP',
#   '6.79m  22-3½ (w: 0.8)',
#   '6/12/2010'],
#  ['(25) Ruth USOROSRTexas Tech6.78m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3 (w: 0.8)5/13/2022',
#   '(25) Ruth USOROSR',
#   '',
#   'Texas Tech',
#   '6.78m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3 (w: 0.8)',
#   '5/13/2022'],
#  ['(25) Ruth USOROSR',
#   '',
#   'Texas Tech',
#   '6.78m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3 (w: 0.8)',
#   '5/13/2022'],
#  ["\xa0\xa0\xa0\xa0— Orji {2}SRGeorgia6.78m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3 (w: 0.1)5/12/2018",
#   '\xa0\xa0\xa0\xa0— Orji {2}SR',
#   '',
#   'Georgia',
#   "6.78m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3 (w: 0.1)",
#   '5/12/2018'],
#  ['\xa0\xa0\xa0\xa0— Orji {2}SR',
#   '',
#   'Georgia',
#   "6.78m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3 (w: 0.1)",
#   '5/12/2018'],
#  ['(25) Taliyah BROOKSSRArkansas6.78m  22-3 (w: 1.2)3/24/2018\xa0\xa0\xa0\xa0\xa06.44w(2.7), 6.28(0.6), f, f, 6.38(0.0), 6.78(1.2)',
#   '(25) Taliyah BROOKSSR',
#   '',
#   'Arkansas',
#   '6.78m  22-3 (w: 1.2)',
#   '3/24/2018',
#   '\xa0\xa0\xa0\xa0\xa06.44w(2.7), 6.28(0.6), f, f, 6.38(0.0), 6.78(1.2)'],
#  ['(25) Taliyah BROOKSSR',
#   '',
#   'Arkansas',
#   '6.78m  22-3 (w: 1.2)',
#   '3/24/2018'],
#  ['(25) Tori BOWIESouthern Miss6.78m  22-3 (w: 0.0)5/11/2012',
#   '(25) Tori BOWIE',
#   '',
#   'Southern Miss',
#   '6.78m  22-3 (w: 0.0)',
#   '5/11/2012'],
#  ['(25) Tori BOWIE', '', 'Southern Miss', '6.78m  22-3 (w: 0.0)', '5/11/2012'],
#  ['(25) Diane GUTHRIE-GRESHAMGeorge Mason6.78m  22-31992',
#   '(25) Diane GUTHRIE-GRESHAM',
#   '',
#   'George Mason',
#   '6.78m  22-3',
#   '1992'],
#  ['(25) Diane GUTHRIE-GRESHAM', '', 'George Mason', '6.78m  22-3', '1992'],
#  ['(25) Aisha JAMESIowa6.78m  22-32003',
#   '(25) Aisha JAMES',
#   '',
#   'Iowa',
#   '6.78m  22-3',
#   '2003'],
#  ['(25) Aisha JAMES', '', 'Iowa', '6.78m  22-3', '2003']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Tara DAVISSOTexas7.14m📺  23-5¼ (w: 1.0)3/25/2021',
#   '(1) Tara DAVISSO',
#   '',
#   'Texas',
#   '7.14m📺  23-5¼ (w: 1.0)',
#   '3/25/2021'],
#  ['(2) Ackelia SMITHSOTexas7.08m  23-2¾ (w: 1.9)5/12/2023',
#   '(2) Ackelia SMITHSO',
#   '',
#   'Texas',
#   '7.08m  23-2¾ (w: 1.9)',
#   '5/12/2023'],
#  ['(3) Jackie JOYNER-KERSEEUCLA6.99m  22-11¼5/4/1985',
#   '(3) Jackie JOYNER-KERSEE',
#   '',
#   'UCLA',
#   '6.99m  22-11¼',
#   '5/4/1985'],
#  ["(4) Monae' NICHOLSSRTexas Tech6.97m AA = Performance occurred at altitude (>1000 meters above sea level) 22-10½ (w: 1.0)5/13/2022",
#   "(4) Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.97m AA = Performance occurred at altitude (>1000 meters above sea level) 22-10½ (w: 1.0)',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}SOTexas6.97m  22-10½ (w: 1.3)5/14/2021',
#   '\xa0\xa0\xa0\xa0— Davis {2}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 1.3)',
#   '5/14/2021'],
#  ['\xa0\xa0\xa0\xa0— Davis {3}SOTexas6.97m  22-10½ (w: 0.5)4/30/2021',
#   '\xa0\xa0\xa0\xa0— Davis {3}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 0.5)',
#   '4/30/2021'],
#  ["\xa0\xa0\xa0\xa0— Davis {4}SOTexas6.97m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-10½ (w: 1.0)3/25/2021",
#   '\xa0\xa0\xa0\xa0— Davis {4}SO',
#   '',
#   'Texas',
#   "6.97m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-10½ (w: 1.0)",
#   '3/25/2021'],
#  ['(4) Carol LEWISHouston6.97m  22-10½4/29/1984',
#   '(4) Carol LEWIS',
#   '',
#   'Houston',
#   '6.97m  22-10½',
#   '4/29/1984'],
#  ['(6) Tyra GITTENSJRTexas A&M6.96m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-10 (w: 2.0)5/13/2021',
#   '(6) Tyra GITTENSJR',
#   '',
#   'Texas A&M',
#   '6.96m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-10 (w: 2.0)',
#   '5/13/2021'],
#  ['(7) Sheila ECHOLSSRLSU6.94m  22-9¼ (w: -1.0)6/5/1987',
#   '(7) Sheila ECHOLSSR',
#   '',
#   'LSU',
#   '6.94m  22-9¼ (w: -1.0)',
#   '6/5/1987'],
#  ['(8) Brittney REESEJROle Miss6.93m  22-9 (w: 0.9)6/12/2008',
#   '(8) Brittney REESEJR',
#   '',
#   'Ole Miss',
#   '6.93m  22-9 (w: 0.9)',
#   '6/12/2008'],
#  ["\xa0\xa0\xa0\xa0— Davis {5}SOTexas6.92m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-8½ (w: -0.7)4/30/2021",
#   '\xa0\xa0\xa0\xa0— Davis {5}SO',
#   '',
#   'Texas',
#   "6.92m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-8½ (w: -0.7)",
#   '4/30/2021'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston6.92m  22-8½4/28/1985',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '6.92m  22-8½',
#   '4/28/1985'],
#  ["\xa0\xa0\xa0\xa0— Lewis {3}Houston6.90m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-7¾4/28/1985",
#   '\xa0\xa0\xa0\xa0— Lewis {3}',
#   '',
#   'Houston',
#   "6.90m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-7¾",
#   '4/28/1985'],
#  ['(9) Deborah ACQUAHSRTexas A&M6.89m  22-7¼ (w: 0.7)4/2/2022',
#   '(9) Deborah ACQUAHSR',
#   '',
#   'Texas A&M',
#   '6.89m  22-7¼ (w: 0.7)',
#   '4/2/2022'],
#  ['\xa0\xa0\xa0\xa0— Smith {2}SOTexas6.88m  22-7 (w: -0.2)6/8/2023',
#   '\xa0\xa0\xa0\xa0— Smith {2}SO',
#   '',
#   'Texas',
#   '6.88m  22-7 (w: -0.2)',
#   '6/8/2023'],
#  ['(10) Jasmine MOOREJRFlorida6.88m  22-7 (w: 0.3)5/12/2023',
#   '(10) Jasmine MOOREJR',
#   '',
#   'Florida',
#   '6.88m  22-7 (w: 0.3)',
#   '5/12/2023'],
#  ['(10) Blessing OKAGBAREUTEP6.88m  22-74/2/2010',
#   '(10) Blessing OKAGBARE',
#   '',
#   'UTEP',
#   '6.88m  22-7',
#   '4/2/2010'],
#  ['(12) Alyssa JONESFRStanford6.86m  22-6¼ (w: 0.1)6/8/2023',
#   '(12) Alyssa JONESFR',
#   '',
#   'Stanford',
#   '6.86m  22-6¼ (w: 0.1)',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Nichols {2}SRTexas Tech6.86m  22-6¼ (w: 1.7)4/16/2022',
#   '\xa0\xa0\xa0\xa0— Nichols {2}SR',
#   '',
#   'Texas Tech',
#   '6.86m  22-6¼ (w: 1.7)',
#   '4/16/2022'],
#  ["\xa0\xa0\xa0\xa0— Nichols {3}SRTexas Tech6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼ (w: 1.7)4/13/2022",
#   '\xa0\xa0\xa0\xa0— Nichols {3}SR',
#   '',
#   'Texas Tech',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼ (w: 1.7)",
#   '4/13/2022'],
#  ['(12) Daphne SAUNDERSLSU6.86m  22-6¼5/15/1993',
#   '(12) Daphne SAUNDERS',
#   '',
#   'LSU',
#   '6.86m  22-6¼',
#   '5/15/1993'],
#  ["\xa0\xa0\xa0\xa0— Davis {6}SOTexas6.85m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¾ (w: 1.7)4/30/2021",
#   '\xa0\xa0\xa0\xa0— Davis {6}SO',
#   '',
#   'Texas',
#   "6.85m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¾ (w: 1.7)",
#   '4/30/2021'],
#  ['(14) Yanis DAVIDSRFlorida6.84m  22-5¼ (w: 1.5)6/6/2019',
#   '(14) Yanis DAVIDSR',
#   '',
#   'Florida',
#   '6.84m  22-5¼ (w: 1.5)',
#   '6/6/2019'],
#  ['(14) Quanesha BURKSAlabama6.84m  22-5¼ (w: 1.9)5/15/2015\xa0\xa0\xa0\xa0\xa0f, 6.24(0.0), 6.46(3.3), 6.36(1.7), 6.74(2.0), 6.84(1.9)',
#   '(14) Quanesha BURKS',
#   '',
#   'Alabama',
#   '6.84m  22-5¼ (w: 1.9)',
#   '5/15/2015',
#   '\xa0\xa0\xa0\xa0\xa0f, 6.24(0.0), 6.46(3.3), 6.36(1.7), 6.74(2.0), 6.84(1.9)'],
#  ['\xa0\xa0\xa0\xa0— Reese {2}Ole Miss6.84m  22-5¼5/17/2008',
#   '\xa0\xa0\xa0\xa0— Reese {2}',
#   '',
#   'Ole Miss',
#   '6.84m  22-5¼',
#   '5/17/2008'],
#  ['\xa0\xa0\xa0\xa0— Moore {2}FRGeorgia6.83m  22-5 (w: 0.4)4/9/2021',
#   '\xa0\xa0\xa0\xa0— Moore {2}FR',
#   '',
#   'Georgia',
#   '6.83m  22-5 (w: 0.4)',
#   '4/9/2021'],
#  ['\xa0\xa0\xa0\xa0— Moore {3}JRFlorida6.82m  22-4½ (w: 1.5)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 1.5)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {4}SOFlorida6.82m  22-4½ (w: 2.0)4/30/2022',
#   '\xa0\xa0\xa0\xa0— Moore {4}SO',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 2.0)',
#   '4/30/2022'],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SRAlabama6.82m  22-4½ (w: 0.2)5/13/2017\xa0\xa0\xa0\xa0\xa06.82(0.2), f, p, 6.28(0.3), 6.73(0.0), 6.82(0.0)',
#   '\xa0\xa0\xa0\xa0— Burks {2}SR',
#   '',
#   'Alabama',
#   '6.82m  22-4½ (w: 0.2)',
#   '5/13/2017',
#   '\xa0\xa0\xa0\xa0\xa06.82(0.2), f, p, 6.28(0.3), 6.73(0.0), 6.82(0.0)'],
#  ['(16) Rhonda WATKINSUCLA6.82m  22-4½5/25/2007',
#   '(16) Rhonda WATKINS',
#   '',
#   'UCLA',
#   '6.82m  22-4½',
#   '5/25/2007'],
#  ['(16) Tianna MADISONTennessee6.82m  22-4½4/9/2005',
#   '(16) Tianna MADISON',
#   '',
#   'Tennessee',
#   '6.82m  22-4½',
#   '4/9/2005'],
#  ['(16) Elva GOULBOURNEJRAuburn6.82m  22-4½ (w: -0.5)5/30/2002',
#   '(16) Elva GOULBOURNEJR',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: -0.5)',
#   '5/30/2002'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}Auburn6.82m  22-4½ (w: 1.1)5/12/2002',
#   '\xa0\xa0\xa0\xa0— Goulbourne {2}',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: 1.1)',
#   '5/12/2002'],
#  ['\xa0\xa0\xa0\xa0— Moore {5}JRFlorida6.81m  22-4¼ (w: 0.6)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Moore {5}JR',
#   '',
#   'Florida',
#   '6.81m  22-4¼ (w: 0.6)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Acquah {2}JRTexas A&M6.81m  22-4¼ (w: 1.6)4/23/2021',
#   '\xa0\xa0\xa0\xa0— Acquah {2}JR',
#   '',
#   'Texas A&M',
#   '6.81m  22-4¼ (w: 1.6)',
#   '4/23/2021'],
#  ['(19) Keturah ORJISRGeorgia6.81m  22-4¼ (w: 0.8)5/12/2018\xa0\xa0\xa0\xa0\xa06.55(0.0), f, 6.81(0.8), f, p, 6.78(0.1)',
#   '(19) Keturah ORJISR',
#   '',
#   'Georgia',
#   '6.81m  22-4¼ (w: 0.8)',
#   '5/12/2018',
#   '\xa0\xa0\xa0\xa0\xa06.55(0.0), f, 6.81(0.8), f, p, 6.78(0.1)'],
#  ['(19) Meledy SMITHTexas Southern6.81m  22-4¼5/6/1988',
#   '(19) Meledy SMITH',
#   '',
#   'Texas Southern',
#   '6.81m  22-4¼',
#   '5/6/1988'],
#  ['(19) Angie THACKERNebraska6.81m  22-4¼5/11/1984',
#   '(19) Angie THACKER',
#   '',
#   'Nebraska',
#   '6.81m  22-4¼',
#   '5/11/1984'],
#  ["\xa0\xa0\xa0\xa0— Nichols {4}SRTexas Tech6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-3¾ (w: 0.7)5/13/2022",
#   '\xa0\xa0\xa0\xa0— Nichols {4}SR',
#   '',
#   'Texas Tech',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-3¾ (w: 0.7)",
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Nichols {5}SRTexas Tech6.80m  22-3¾ (w: 1.5)3/26/2022',
#   '\xa0\xa0\xa0\xa0— Nichols {5}SR',
#   '',
#   'Texas Tech',
#   '6.80m  22-3¾ (w: 1.5)',
#   '3/26/2022'],
#  ['(22) Jenna PRANDINIOregon6.80m  22-3¾ (w: 1.7)6/11/2015\xa0\xa0\xa0\xa0\xa04.48w(3.4), 6.38w(3.0), 6.80(1.7), PASS, PASS, FOUL (also in 100 and 200 prelims)',
#   '(22) Jenna PRANDINI',
#   '',
#   'Oregon',
#   '6.80m  22-3¾ (w: 1.7)',
#   '6/11/2015',
#   '\xa0\xa0\xa0\xa0\xa04.48w(3.4), 6.38w(3.0), 6.80(1.7), PASS, PASS, FOUL (also in 100 and 200 prelims)'],
#  ["(22) Whitney GIPSONSRTCU6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3¾ (w: 1.4)6/7/2012",
#   '(22) Whitney GIPSONSR',
#   '',
#   'TCU',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3¾ (w: 1.4)",
#   '6/7/2012'],
#  ["(24) Sha'Keela SAUNDERSSRKentucky6.79m  22-3½ (w: 1.2)4/29/2017\xa0\xa0\xa0\xa0\xa06.77(2.0), f, 6.76(2.0), 6.57(0.1), 6.72(0.7), 6.79(1.2)",
#   "(24) Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.79m  22-3½ (w: 1.2)',
#   '4/29/2017',
#   '\xa0\xa0\xa0\xa0\xa06.77(2.0), f, 6.76(2.0), 6.57(0.1), 6.72(0.7), 6.79(1.2)'],
#  ['\xa0\xa0\xa0\xa0— Okagbare {2}UTEP6.79m  22-3½ (w: 0.8)6/12/2010',
#   '\xa0\xa0\xa0\xa0— Okagbare {2}',
#   '',
#   'UTEP',
#   '6.79m  22-3½ (w: 0.8)',
#   '6/12/2010'],
#  ['(25) Ruth USOROSRTexas Tech6.78m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3 (w: 0.8)5/13/2022',
#   '(25) Ruth USOROSR',
#   '',
#   'Texas Tech',
#   '6.78m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3 (w: 0.8)',
#   '5/13/2022'],
#  ["\xa0\xa0\xa0\xa0— Orji {2}SRGeorgia6.78m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3 (w: 0.1)5/12/2018",
#   '\xa0\xa0\xa0\xa0— Orji {2}SR',
#   '',
#   'Georgia',
#   "6.78m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3 (w: 0.1)",
#   '5/12/2018'],
#  ['(25) Taliyah BROOKSSRArkansas6.78m  22-3 (w: 1.2)3/24/2018\xa0\xa0\xa0\xa0\xa06.44w(2.7), 6.28(0.6), f, f, 6.38(0.0), 6.78(1.2)',
#   '(25) Taliyah BROOKSSR',
#   '',
#   'Arkansas',
#   '6.78m  22-3 (w: 1.2)',
#   '3/24/2018',
#   '\xa0\xa0\xa0\xa0\xa06.44w(2.7), 6.28(0.6), f, f, 6.38(0.0), 6.78(1.2)'],
#  ['(25) Tori BOWIESouthern Miss6.78m  22-3 (w: 0.0)5/11/2012',
#   '(25) Tori BOWIE',
#   '',
#   'Southern Miss',
#   '6.78m  22-3 (w: 0.0)',
#   '5/11/2012'],
#  ['(25) Diane GUTHRIE-GRESHAMGeorge Mason6.78m  22-31992',
#   '(25) Diane GUTHRIE-GRESHAM',
#   '',
#   'George Mason',
#   '6.78m  22-3',
#   '1992'],
#  ['(25) Aisha JAMESIowa6.78m  22-32003',
#   '(25) Aisha JAMES',
#   '',
#   'Iowa',
#   '6.78m  22-3',
#   '2003']]

# %%
RealRealRows[2][4]
# Out:
# '6.99m  22-11¼'

# %%
len(RealRealRows)
# Out:
# 51

# %%
OfficialLengths = []

# %%
for i in range(0,len(RealRealRows)):
    OfficialLengths.append(RealRealRows[i][4])
OfficialLengths
# Out:
# ['7.14m📺  23-5¼ (w: 1.0)',
#  '7.08m  23-2¾ (w: 1.9)',
#  '6.99m  22-11¼',
#  '6.97m AA = Performance occurred at altitude (>1000 meters above sea level) 22-10½ (w: 1.0)',
#  '6.97m  22-10½ (w: 1.3)',
#  '6.97m  22-10½ (w: 0.5)',
#  "6.97m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-10½ (w: 1.0)",
#  '6.97m  22-10½',
#  '6.96m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-10 (w: 2.0)',
#  '6.94m  22-9¼ (w: -1.0)',
#  '6.93m  22-9 (w: 0.9)',
#  "6.92m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-8½ (w: -0.7)",
#  '6.92m  22-8½',
#  "6.90m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-7¾",
#  '6.89m  22-7¼ (w: 0.7)',
#  '6.88m  22-7 (w: -0.2)',
#  '6.88m  22-7 (w: 0.3)',
#  '6.88m  22-7',
#  '6.86m  22-6¼ (w: 0.1)',
#  '6.86m  22-6¼ (w: 1.7)',
#  "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼ (w: 1.7)",
#  '6.86m  22-6¼',
#  "6.85m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¾ (w: 1.7)",
#  '6.84m  22-5¼ (w: 1.5)',
#  '6.84m  22-5¼ (w: 1.9)',
#  '6.84m  22-5¼',
#  '6.83m  22-5 (w: 0.4)',
#  '6.82m  22-4½ (w: 1.5)',
#  '6.82m  22-4½ (w: 2.0)',
#  '6.82m  22-4½ (w: 0.2)',
#  '6.82m  22-4½',
#  '6.82m  22-4½',
#  '6.82m  22-4½ (w: -0.5)',
#  '6.82m  22-4½ (w: 1.1)',
#  '6.81m  22-4¼ (w: 0.6)',
#  '6.81m  22-4¼ (w: 1.6)',
#  '6.81m  22-4¼ (w: 0.8)',
#  '6.81m  22-4¼',
#  '6.81m  22-4¼',
#  "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-3¾ (w: 0.7)",
#  '6.80m  22-3¾ (w: 1.5)',
#  '6.80m  22-3¾ (w: 1.7)',
#  "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3¾ (w: 1.4)",
#  '6.79m  22-3½ (w: 1.2)',
#  '6.79m  22-3½ (w: 0.8)',
#  '6.78m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3 (w: 0.8)',
#  "6.78m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3 (w: 0.1)",
#  '6.78m  22-3 (w: 1.2)',
#  '6.78m  22-3 (w: 0.0)',
#  '6.78m  22-3',
#  '6.78m  22-3']

# %%
RealRealRows
# Out:
# [['(1) Tara DAVISSOTexas7.14m📺  23-5¼ (w: 1.0)3/25/2021',
#   '(1) Tara DAVISSO',
#   '',
#   'Texas',
#   '7.14m📺  23-5¼ (w: 1.0)',
#   '3/25/2021'],
#  ['(2) Ackelia SMITHSOTexas7.08m  23-2¾ (w: 1.9)5/12/2023',
#   '(2) Ackelia SMITHSO',
#   '',
#   'Texas',
#   '7.08m  23-2¾ (w: 1.9)',
#   '5/12/2023'],
#  ['(3) Jackie JOYNER-KERSEEUCLA6.99m  22-11¼5/4/1985',
#   '(3) Jackie JOYNER-KERSEE',
#   '',
#   'UCLA',
#   '6.99m  22-11¼',
#   '5/4/1985'],
#  ["(4) Monae' NICHOLSSRTexas Tech6.97m AA = Performance occurred at altitude (>1000 meters above sea level) 22-10½ (w: 1.0)5/13/2022",
#   "(4) Monae' NICHOLSSR",
#   '',
#   'Texas Tech',
#   '6.97m AA = Performance occurred at altitude (>1000 meters above sea level) 22-10½ (w: 1.0)',
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}SOTexas6.97m  22-10½ (w: 1.3)5/14/2021',
#   '\xa0\xa0\xa0\xa0— Davis {2}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 1.3)',
#   '5/14/2021'],
#  ['\xa0\xa0\xa0\xa0— Davis {3}SOTexas6.97m  22-10½ (w: 0.5)4/30/2021',
#   '\xa0\xa0\xa0\xa0— Davis {3}SO',
#   '',
#   'Texas',
#   '6.97m  22-10½ (w: 0.5)',
#   '4/30/2021'],
#  ["\xa0\xa0\xa0\xa0— Davis {4}SOTexas6.97m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-10½ (w: 1.0)3/25/2021",
#   '\xa0\xa0\xa0\xa0— Davis {4}SO',
#   '',
#   'Texas',
#   "6.97m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-10½ (w: 1.0)",
#   '3/25/2021'],
#  ['(4) Carol LEWISHouston6.97m  22-10½4/29/1984',
#   '(4) Carol LEWIS',
#   '',
#   'Houston',
#   '6.97m  22-10½',
#   '4/29/1984'],
#  ['(6) Tyra GITTENSJRTexas A&M6.96m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-10 (w: 2.0)5/13/2021',
#   '(6) Tyra GITTENSJR',
#   '',
#   'Texas A&M',
#   '6.96m cbcb = Performance occurred within a combined event (decathlon, heptathlon, pentathlon, etc.) 22-10 (w: 2.0)',
#   '5/13/2021'],
#  ['(7) Sheila ECHOLSSRLSU6.94m  22-9¼ (w: -1.0)6/5/1987',
#   '(7) Sheila ECHOLSSR',
#   '',
#   'LSU',
#   '6.94m  22-9¼ (w: -1.0)',
#   '6/5/1987'],
#  ['(8) Brittney REESEJROle Miss6.93m  22-9 (w: 0.9)6/12/2008',
#   '(8) Brittney REESEJR',
#   '',
#   'Ole Miss',
#   '6.93m  22-9 (w: 0.9)',
#   '6/12/2008'],
#  ["\xa0\xa0\xa0\xa0— Davis {5}SOTexas6.92m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-8½ (w: -0.7)4/30/2021",
#   '\xa0\xa0\xa0\xa0— Davis {5}SO',
#   '',
#   'Texas',
#   "6.92m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-8½ (w: -0.7)",
#   '4/30/2021'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston6.92m  22-8½4/28/1985',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '6.92m  22-8½',
#   '4/28/1985'],
#  ["\xa0\xa0\xa0\xa0— Lewis {3}Houston6.90m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-7¾4/28/1985",
#   '\xa0\xa0\xa0\xa0— Lewis {3}',
#   '',
#   'Houston',
#   "6.90m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-7¾",
#   '4/28/1985'],
#  ['(9) Deborah ACQUAHSRTexas A&M6.89m  22-7¼ (w: 0.7)4/2/2022',
#   '(9) Deborah ACQUAHSR',
#   '',
#   'Texas A&M',
#   '6.89m  22-7¼ (w: 0.7)',
#   '4/2/2022'],
#  ['\xa0\xa0\xa0\xa0— Smith {2}SOTexas6.88m  22-7 (w: -0.2)6/8/2023',
#   '\xa0\xa0\xa0\xa0— Smith {2}SO',
#   '',
#   'Texas',
#   '6.88m  22-7 (w: -0.2)',
#   '6/8/2023'],
#  ['(10) Jasmine MOOREJRFlorida6.88m  22-7 (w: 0.3)5/12/2023',
#   '(10) Jasmine MOOREJR',
#   '',
#   'Florida',
#   '6.88m  22-7 (w: 0.3)',
#   '5/12/2023'],
#  ['(10) Blessing OKAGBAREUTEP6.88m  22-74/2/2010',
#   '(10) Blessing OKAGBARE',
#   '',
#   'UTEP',
#   '6.88m  22-7',
#   '4/2/2010'],
#  ['(12) Alyssa JONESFRStanford6.86m  22-6¼ (w: 0.1)6/8/2023',
#   '(12) Alyssa JONESFR',
#   '',
#   'Stanford',
#   '6.86m  22-6¼ (w: 0.1)',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Nichols {2}SRTexas Tech6.86m  22-6¼ (w: 1.7)4/16/2022',
#   '\xa0\xa0\xa0\xa0— Nichols {2}SR',
#   '',
#   'Texas Tech',
#   '6.86m  22-6¼ (w: 1.7)',
#   '4/16/2022'],
#  ["\xa0\xa0\xa0\xa0— Nichols {3}SRTexas Tech6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼ (w: 1.7)4/13/2022",
#   '\xa0\xa0\xa0\xa0— Nichols {3}SR',
#   '',
#   'Texas Tech',
#   "6.86m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-6¼ (w: 1.7)",
#   '4/13/2022'],
#  ['(12) Daphne SAUNDERSLSU6.86m  22-6¼5/15/1993',
#   '(12) Daphne SAUNDERS',
#   '',
#   'LSU',
#   '6.86m  22-6¼',
#   '5/15/1993'],
#  ["\xa0\xa0\xa0\xa0— Davis {6}SOTexas6.85m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¾ (w: 1.7)4/30/2021",
#   '\xa0\xa0\xa0\xa0— Davis {6}SO',
#   '',
#   'Texas',
#   "6.85m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-5¾ (w: 1.7)",
#   '4/30/2021'],
#  ['(14) Yanis DAVIDSRFlorida6.84m  22-5¼ (w: 1.5)6/6/2019',
#   '(14) Yanis DAVIDSR',
#   '',
#   'Florida',
#   '6.84m  22-5¼ (w: 1.5)',
#   '6/6/2019'],
#  ['(14) Quanesha BURKSAlabama6.84m  22-5¼ (w: 1.9)5/15/2015\xa0\xa0\xa0\xa0\xa0f, 6.24(0.0), 6.46(3.3), 6.36(1.7), 6.74(2.0), 6.84(1.9)',
#   '(14) Quanesha BURKS',
#   '',
#   'Alabama',
#   '6.84m  22-5¼ (w: 1.9)',
#   '5/15/2015',
#   '\xa0\xa0\xa0\xa0\xa0f, 6.24(0.0), 6.46(3.3), 6.36(1.7), 6.74(2.0), 6.84(1.9)'],
#  ['\xa0\xa0\xa0\xa0— Reese {2}Ole Miss6.84m  22-5¼5/17/2008',
#   '\xa0\xa0\xa0\xa0— Reese {2}',
#   '',
#   'Ole Miss',
#   '6.84m  22-5¼',
#   '5/17/2008'],
#  ['\xa0\xa0\xa0\xa0— Moore {2}FRGeorgia6.83m  22-5 (w: 0.4)4/9/2021',
#   '\xa0\xa0\xa0\xa0— Moore {2}FR',
#   '',
#   'Georgia',
#   '6.83m  22-5 (w: 0.4)',
#   '4/9/2021'],
#  ['\xa0\xa0\xa0\xa0— Moore {3}JRFlorida6.82m  22-4½ (w: 1.5)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Moore {3}JR',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 1.5)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Moore {4}SOFlorida6.82m  22-4½ (w: 2.0)4/30/2022',
#   '\xa0\xa0\xa0\xa0— Moore {4}SO',
#   '',
#   'Florida',
#   '6.82m  22-4½ (w: 2.0)',
#   '4/30/2022'],
#  ['\xa0\xa0\xa0\xa0— Burks {2}SRAlabama6.82m  22-4½ (w: 0.2)5/13/2017\xa0\xa0\xa0\xa0\xa06.82(0.2), f, p, 6.28(0.3), 6.73(0.0), 6.82(0.0)',
#   '\xa0\xa0\xa0\xa0— Burks {2}SR',
#   '',
#   'Alabama',
#   '6.82m  22-4½ (w: 0.2)',
#   '5/13/2017',
#   '\xa0\xa0\xa0\xa0\xa06.82(0.2), f, p, 6.28(0.3), 6.73(0.0), 6.82(0.0)'],
#  ['(16) Rhonda WATKINSUCLA6.82m  22-4½5/25/2007',
#   '(16) Rhonda WATKINS',
#   '',
#   'UCLA',
#   '6.82m  22-4½',
#   '5/25/2007'],
#  ['(16) Tianna MADISONTennessee6.82m  22-4½4/9/2005',
#   '(16) Tianna MADISON',
#   '',
#   'Tennessee',
#   '6.82m  22-4½',
#   '4/9/2005'],
#  ['(16) Elva GOULBOURNEJRAuburn6.82m  22-4½ (w: -0.5)5/30/2002',
#   '(16) Elva GOULBOURNEJR',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: -0.5)',
#   '5/30/2002'],
#  ['\xa0\xa0\xa0\xa0— Goulbourne {2}Auburn6.82m  22-4½ (w: 1.1)5/12/2002',
#   '\xa0\xa0\xa0\xa0— Goulbourne {2}',
#   '',
#   'Auburn',
#   '6.82m  22-4½ (w: 1.1)',
#   '5/12/2002'],
#  ['\xa0\xa0\xa0\xa0— Moore {5}JRFlorida6.81m  22-4¼ (w: 0.6)5/12/2023',
#   '\xa0\xa0\xa0\xa0— Moore {5}JR',
#   '',
#   'Florida',
#   '6.81m  22-4¼ (w: 0.6)',
#   '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— Acquah {2}JRTexas A&M6.81m  22-4¼ (w: 1.6)4/23/2021',
#   '\xa0\xa0\xa0\xa0— Acquah {2}JR',
#   '',
#   'Texas A&M',
#   '6.81m  22-4¼ (w: 1.6)',
#   '4/23/2021'],
#  ['(19) Keturah ORJISRGeorgia6.81m  22-4¼ (w: 0.8)5/12/2018\xa0\xa0\xa0\xa0\xa06.55(0.0), f, 6.81(0.8), f, p, 6.78(0.1)',
#   '(19) Keturah ORJISR',
#   '',
#   'Georgia',
#   '6.81m  22-4¼ (w: 0.8)',
#   '5/12/2018',
#   '\xa0\xa0\xa0\xa0\xa06.55(0.0), f, 6.81(0.8), f, p, 6.78(0.1)'],
#  ['(19) Meledy SMITHTexas Southern6.81m  22-4¼5/6/1988',
#   '(19) Meledy SMITH',
#   '',
#   'Texas Southern',
#   '6.81m  22-4¼',
#   '5/6/1988'],
#  ['(19) Angie THACKERNebraska6.81m  22-4¼5/11/1984',
#   '(19) Angie THACKER',
#   '',
#   'Nebraska',
#   '6.81m  22-4¼',
#   '5/11/1984'],
#  ["\xa0\xa0\xa0\xa0— Nichols {4}SRTexas Tech6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-3¾ (w: 0.7)5/13/2022",
#   '\xa0\xa0\xa0\xa0— Nichols {4}SR',
#   '',
#   'Texas Tech',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 22-3¾ (w: 0.7)",
#   '5/13/2022'],
#  ['\xa0\xa0\xa0\xa0— Nichols {5}SRTexas Tech6.80m  22-3¾ (w: 1.5)3/26/2022',
#   '\xa0\xa0\xa0\xa0— Nichols {5}SR',
#   '',
#   'Texas Tech',
#   '6.80m  22-3¾ (w: 1.5)',
#   '3/26/2022'],
#  ['(22) Jenna PRANDINIOregon6.80m  22-3¾ (w: 1.7)6/11/2015\xa0\xa0\xa0\xa0\xa04.48w(3.4), 6.38w(3.0), 6.80(1.7), PASS, PASS, FOUL (also in 100 and 200 prelims)',
#   '(22) Jenna PRANDINI',
#   '',
#   'Oregon',
#   '6.80m  22-3¾ (w: 1.7)',
#   '6/11/2015',
#   '\xa0\xa0\xa0\xa0\xa04.48w(3.4), 6.38w(3.0), 6.80(1.7), PASS, PASS, FOUL (also in 100 and 200 prelims)'],
#  ["(22) Whitney GIPSONSRTCU6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3¾ (w: 1.4)6/7/2012",
#   '(22) Whitney GIPSONSR',
#   '',
#   'TCU',
#   "6.80m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3¾ (w: 1.4)",
#   '6/7/2012'],
#  ["(24) Sha'Keela SAUNDERSSRKentucky6.79m  22-3½ (w: 1.2)4/29/2017\xa0\xa0\xa0\xa0\xa06.77(2.0), f, 6.76(2.0), 6.57(0.1), 6.72(0.7), 6.79(1.2)",
#   "(24) Sha'Keela SAUNDERSSR",
#   '',
#   'Kentucky',
#   '6.79m  22-3½ (w: 1.2)',
#   '4/29/2017',
#   '\xa0\xa0\xa0\xa0\xa06.77(2.0), f, 6.76(2.0), 6.57(0.1), 6.72(0.7), 6.79(1.2)'],
#  ['\xa0\xa0\xa0\xa0— Okagbare {2}UTEP6.79m  22-3½ (w: 0.8)6/12/2010',
#   '\xa0\xa0\xa0\xa0— Okagbare {2}',
#   '',
#   'UTEP',
#   '6.79m  22-3½ (w: 0.8)',
#   '6/12/2010'],
#  ['(25) Ruth USOROSRTexas Tech6.78m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3 (w: 0.8)5/13/2022',
#   '(25) Ruth USOROSR',
#   '',
#   'Texas Tech',
#   '6.78m AA = Performance occurred at altitude (>1000 meters above sea level) 22-3 (w: 0.8)',
#   '5/13/2022'],
#  ["\xa0\xa0\xa0\xa0— Orji {2}SRGeorgia6.78m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3 (w: 0.1)5/12/2018",
#   '\xa0\xa0\xa0\xa0— Orji {2}SR',
#   '',
#   'Georgia',
#   "6.78m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 22-3 (w: 0.1)",
#   '5/12/2018'],
#  ['(25) Taliyah BROOKSSRArkansas6.78m  22-3 (w: 1.2)3/24/2018\xa0\xa0\xa0\xa0\xa06.44w(2.7), 6.28(0.6), f, f, 6.38(0.0), 6.78(1.2)',
#   '(25) Taliyah BROOKSSR',
#   '',
#   'Arkansas',
#   '6.78m  22-3 (w: 1.2)',
#   '3/24/2018',
#   '\xa0\xa0\xa0\xa0\xa06.44w(2.7), 6.28(0.6), f, f, 6.38(0.0), 6.78(1.2)'],
#  ['(25) Tori BOWIESouthern Miss6.78m  22-3 (w: 0.0)5/11/2012',
#   '(25) Tori BOWIE',
#   '',
#   'Southern Miss',
#   '6.78m  22-3 (w: 0.0)',
#   '5/11/2012'],
#  ['(25) Diane GUTHRIE-GRESHAMGeorge Mason6.78m  22-31992',
#   '(25) Diane GUTHRIE-GRESHAM',
#   '',
#   'George Mason',
#   '6.78m  22-3',
#   '1992'],
#  ['(25) Aisha JAMESIowa6.78m  22-32003',
#   '(25) Aisha JAMES',
#   '',
#   'Iowa',
#   '6.78m  22-3',
#   '2003']]

# %%
len(RealRealRows)
# Out:
# 51

# %%
RealRealRows[2][1]
# Out:
# '(3) Jackie JOYNER-KERSEE'

# %%
Names = []

for i in range(0,len(RealRealRows)):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Tara DAVISSO',
#  '(2) Ackelia SMITHSO',
#  '(3) Jackie JOYNER-KERSEE',
#  "(4) Monae' NICHOLSSR",
#  '\xa0\xa0\xa0\xa0— Davis {2}SO',
#  '\xa0\xa0\xa0\xa0— Davis {3}SO',
#  '\xa0\xa0\xa0\xa0— Davis {4}SO',
#  '(4) Carol LEWIS',
#  '(6) Tyra GITTENSJR',
#  '(7) Sheila ECHOLSSR',
#  '(8) Brittney REESEJR',
#  '\xa0\xa0\xa0\xa0— Davis {5}SO',
#  '\xa0\xa0\xa0\xa0— Lewis {2}',
#  '\xa0\xa0\xa0\xa0— Lewis {3}',
#  '(9) Deborah ACQUAHSR',
#  '\xa0\xa0\xa0\xa0— Smith {2}SO',
#  '(10) Jasmine MOOREJR',
#  '(10) Blessing OKAGBARE',
#  '(12) Alyssa JONESFR',
#  '\xa0\xa0\xa0\xa0— Nichols {2}SR',
#  '\xa0\xa0\xa0\xa0— Nichols {3}SR',
#  '(12) Daphne SAUNDERS',
#  '\xa0\xa0\xa0\xa0— Davis {6}SO',
#  '(14) Yanis DAVIDSR',
#  '(14) Quanesha BURKS',
#  '\xa0\xa0\xa0\xa0— Reese {2}',
#  '\xa0\xa0\xa0\xa0— Moore {2}FR',
#  '\xa0\xa0\xa0\xa0— Moore {3}JR',
#  '\xa0\xa0\xa0\xa0— Moore {4}SO',
#  '\xa0\xa0\xa0\xa0— Burks {2}SR',
#  '(16) Rhonda WATKINS',
#  '(16) Tianna MADISON',
#  '(16) Elva GOULBOURNEJR',
#  '\xa0\xa0\xa0\xa0— Goulbourne {2}',
#  '\xa0\xa0\xa0\xa0— Moore {5}JR',
#  '\xa0\xa0\xa0\xa0— Acquah {2}JR',
#  '(19) Keturah ORJISR',
#  '(19) Meledy SMITH',
#  '(19) Angie THACKER',
#  '\xa0\xa0\xa0\xa0— Nichols {4}SR',
#  '\xa0\xa0\xa0\xa0— Nichols {5}SR',
#  '(22) Jenna PRANDINI',
#  '(22) Whitney GIPSONSR',
#  "(24) Sha'Keela SAUNDERSSR",
#  '\xa0\xa0\xa0\xa0— Okagbare {2}',
#  '(25) Ruth USOROSR',
#  '\xa0\xa0\xa0\xa0— Orji {2}SR',
#  '(25) Taliyah BROOKSSR',
#  '(25) Tori BOWIE',
#  '(25) Diane GUTHRIE-GRESHAM',
#  '(25) Aisha JAMES']

# %%
len(Names)
# Out:
# 51

# %%
OfficialReGexNames = []

# %%
for i in range(0,len(Names)):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Tara DAVISSO',
#  '(2) Ackelia SMITHSO',
#  '(3) Jackie JOYNER-KERSEE',
#  "(4) Monae' NICHOLSSR",
#  '— Davis {2}SO',
#  '— Davis {3}SO',
#  '— Davis {4}SO',
#  '(4) Carol LEWIS',
#  '(6) Tyra GITTENSJR',
#  '(7) Sheila ECHOLSSR',
#  '(8) Brittney REESEJR',
#  '— Davis {5}SO',
#  '— Lewis {2}',
#  '— Lewis {3}',
#  '(9) Deborah ACQUAHSR',
#  '— Smith {2}SO',
#  '(10) Jasmine MOOREJR',
#  '(10) Blessing OKAGBARE',
#  '(12) Alyssa JONESFR',
#  '— Nichols {2}SR',
#  '— Nichols {3}SR',
#  '(12) Daphne SAUNDERS',
#  '— Davis {6}SO',
#  '(14) Yanis DAVIDSR',
#  '(14) Quanesha BURKS',
#  '— Reese {2}',
#  '— Moore {2}FR',
#  '— Moore {3}JR',
#  '— Moore {4}SO',
#  '— Burks {2}SR',
#  '(16) Rhonda WATKINS',
#  '(16) Tianna MADISON',
#  '(16) Elva GOULBOURNEJR',
#  '— Goulbourne {2}',
#  '— Moore {5}JR',
#  '— Acquah {2}JR',
#  '(19) Keturah ORJISR',
#  '(19) Meledy SMITH',
#  '(19) Angie THACKER',
#  '— Nichols {4}SR',
#  '— Nichols {5}SR',
#  '(22) Jenna PRANDINI',
#  '(22) Whitney GIPSONSR',
#  "(24) Sha'Keela SAUNDERSSR",
#  '— Okagbare {2}',
#  '(25) Ruth USOROSR',
#  '— Orji {2}SR',
#  '(25) Taliyah BROOKSSR',
#  '(25) Tori BOWIE',
#  '(25) Diane GUTHRIE-GRESHAM',
#  '(25) Aisha JAMES']

# %%
CleanedNames = []

for i in range(0,len(RealRealRows)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Tara DAVISSO',
#  'Ackelia SMITHSO',
#  'Jackie JOYNER-KERSEE',
#  "Monae' NICHOLSSR",
#  'Davis {2}SO',
#  'Davis {3}SO',
#  'Davis {4}SO',
#  'Carol LEWIS',
#  'Tyra GITTENSJR',
#  'Sheila ECHOLSSR',
#  'Brittney REESEJR',
#  'Davis {5}SO',
#  'Lewis {2}',
#  'Lewis {3}',
#  'Deborah ACQUAHSR',
#  'Smith {2}SO',
#  ' Jasmine MOOREJR',
#  ' Blessing OKAGBARE',
#  ' Alyssa JONESFR',
#  'Nichols {2}SR',
#  'Nichols {3}SR',
#  ' Daphne SAUNDERS',
#  'Davis {6}SO',
#  ' Yanis DAVIDSR',
#  ' Quanesha BURKS',
#  'Reese {2}',
#  'Moore {2}FR',
#  'Moore {3}JR',
#  'Moore {4}SO',
#  'Burks {2}SR',
#  ' Rhonda WATKINS',
#  ' Tianna MADISON',
#  ' Elva GOULBOURNEJR',
#  'Goulbourne {2}',
#  'Moore {5}JR',
#  'Acquah {2}JR',
#  ' Keturah ORJISR',
#  ' Meledy SMITH',
#  ' Angie THACKER',
#  'Nichols {4}SR',
#  'Nichols {5}SR',
#  ' Jenna PRANDINI',
#  ' Whitney GIPSONSR',
#  " Sha'Keela SAUNDERSSR",
#  'Okagbare {2}',
#  ' Ruth USOROSR',
#  'Orji {2}SR',
#  ' Taliyah BROOKSSR',
#  ' Tori BOWIE',
#  ' Diane GUTHRIE-GRESHAM',
#  ' Aisha JAMES']

# %%
CleanedNames2 = []

for i in range(0,len(RealRealRows)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Tara DAVISSO',
#  'Ackelia SMITHSO',
#  'Jackie JOYNER-KERSEE',
#  "Monae' NICHOLSSR",
#  'Davis {2}SO',
#  'Davis {3}SO',
#  'Davis {4}SO',
#  'Carol LEWIS',
#  'Tyra GITTENSJR',
#  'Sheila ECHOLSSR',
#  'Brittney REESEJR',
#  'Davis {5}SO',
#  'Lewis {2}',
#  'Lewis {3}',
#  'Deborah ACQUAHSR',
#  'Smith {2}SO',
#  'Jasmine MOOREJR',
#  'Blessing OKAGBARE',
#  'Alyssa JONESFR',
#  'Nichols {2}SR',
#  'Nichols {3}SR',
#  'Daphne SAUNDERS',
#  'Davis {6}SO',
#  'Yanis DAVIDSR',
#  'Quanesha BURKS',
#  'Reese {2}',
#  'Moore {2}FR',
#  'Moore {3}JR',
#  'Moore {4}SO',
#  'Burks {2}SR',
#  'Rhonda WATKINS',
#  'Tianna MADISON',
#  'Elva GOULBOURNEJR',
#  'Goulbourne {2}',
#  'Moore {5}JR',
#  'Acquah {2}JR',
#  'Keturah ORJISR',
#  'Meledy SMITH',
#  'Angie THACKER',
#  'Nichols {4}SR',
#  'Nichols {5}SR',
#  'Jenna PRANDINI',
#  'Whitney GIPSONSR',
#  "Sha'Keela SAUNDERSSR",
#  'Okagbare {2}',
#  'Ruth USOROSR',
#  'Orji {2}SR',
#  'Taliyah BROOKSSR',
#  'Tori BOWIE',
#  'Diane GUTHRIE-GRESHAM',
#  'Aisha JAMES']

# %%
len(OfficialReGexNames)
# Out:
# 51

# %%
Schools = []

for i in range(0,len(OfficialReGexNames)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Texas',
#  'Texas',
#  'UCLA',
#  'Texas Tech',
#  'Texas',
#  'Texas',
#  'Texas',
#  'Houston',
#  'Texas A&M',
#  'LSU',
#  'Ole Miss',
#  'Texas',
#  'Houston',
#  'Houston',
#  'Texas A&M',
#  'Texas',
#  'Florida',
#  'UTEP',
#  'Stanford',
#  'Texas Tech',
#  'Texas Tech',
#  'LSU',
#  'Texas',
#  'Florida',
#  'Alabama',
#  'Ole Miss',
#  'Georgia',
#  'Florida',
#  'Florida',
#  'Alabama',
#  'UCLA',
#  'Tennessee',
#  'Auburn',
#  'Auburn',
#  'Florida',
#  'Texas A&M',
#  'Georgia',
#  'Texas Southern',
#  'Nebraska',
#  'Texas Tech',
#  'Texas Tech',
#  'Oregon',
#  'TCU',
#  'Kentucky',
#  'UTEP',
#  'Texas Tech',
#  'Georgia',
#  'Arkansas',
#  'Southern Miss',
#  'George Mason',
#  'Iowa']

# %%
Lengths = []
for i in range(0,len(OfficialReGexNames)):
    Lengths.append(OfficialLengths[i][:5])
    
Lengths
# Out:
# ['7.14m',
#  '7.08m',
#  '6.99m',
#  '6.97m',
#  '6.97m',
#  '6.97m',
#  '6.97m',
#  '6.97m',
#  '6.96m',
#  '6.94m',
#  '6.93m',
#  '6.92m',
#  '6.92m',
#  '6.90m',
#  '6.89m',
#  '6.88m',
#  '6.88m',
#  '6.88m',
#  '6.86m',
#  '6.86m',
#  '6.86m',
#  '6.86m',
#  '6.85m',
#  '6.84m',
#  '6.84m',
#  '6.84m',
#  '6.83m',
#  '6.82m',
#  '6.82m',
#  '6.82m',
#  '6.82m',
#  '6.82m',
#  '6.82m',
#  '6.82m',
#  '6.81m',
#  '6.81m',
#  '6.81m',
#  '6.81m',
#  '6.81m',
#  '6.80m',
#  '6.80m',
#  '6.80m',
#  '6.80m',
#  '6.79m',
#  '6.79m',
#  '6.78m',
#  '6.78m',
#  '6.78m',
#  '6.78m',
#  '6.78m',
#  '6.78m']

# %%
WomensOutdoorLongJumpDF = pd.DataFrame({'Names': CleanedNames2, 'Lengths': Lengths, 'Schools': Schools})
WomensOutdoorLongJumpDF.to_csv('WomensOutdoorLongJump.csv', index=False)
