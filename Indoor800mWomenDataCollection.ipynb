# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
LinkIndoor800mWomen = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?sport=1&gender=2&div=20527&top=25&event=6"

# %%
page = requests.get(LinkIndoor800mWomen)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729637" target="_blank">(1) Athing MU</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67216/4090232" target="_blank">1:58.40</a><a href="https://www.youtube.com/watch?v=jac1m0JLKfY&amp;list=PLwFwbEuKYdKY_1dCvG2Dow0EsjJRNxh1W" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729637" target="_blank">(1) Athing MU</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67216/4090232" target="_blank">1:58.40</a><a href="https://www.youtube.com/watch?v=jac1m0JLKfY&amp;list=PLwFwbEuKYdKY_1dCvG2Dow0EsjJRNxh1W" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8239785" target="_blank">(2) Roisin WILLIS</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720943" target="_blank">1:59.93</a><a href="https://www.youtube.com/watch?v=awwEoD108EI" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8239785" target="_blank">(2) Roisin WILLIS</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720943" target="_blank">1:59.93</a><a href="https://www.youtube.com/watch?v=awwEoD108EI" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Willis {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76416/4669658" target="_blank">1:59.95</a> </td><td style="width: 10%;text-align:right;" title="Wisconsin Windy City Invitational (Chicago, Ill.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Willis {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76416/4669658" target="_blank">1:59.95</a> </td><td style="width: 10%;text-align:right;" title="Wisconsin Windy City Invitational (Chicago, Ill.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8239784" target="_blank">(3) Juliette WHITTAKER</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720943" target="_blank">2:00.05</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8239784" target="_blank">(3) Juliette WHITTAKER</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720943" target="_blank">2:00.05</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7930954" target="_blank">(4) Michaela ROSE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76446/4667853" target="_blank">2:00.18</a> </td><td style="width: 10%;text-align:right;" title="David Hemery Valentine Invitational (Boston, Mass.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7930954" target="_blank">(4) Michaela ROSE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76446/4667853" target="_blank">2:00.18</a> </td><td style="width: 10%;text-align:right;" title="David Hemery Valentine Invitational (Boston, Mass.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Whittaker {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76416/4669658" target="_blank">2:00.32</a> </td><td style="width: 10%;text-align:right;" title="Wisconsin Windy City Invitational (Chicago, Ill.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Whittaker {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76416/4669658" target="_blank">2:00.32</a> </td><td style="width: 10%;text-align:right;" title="Wisconsin Windy City Invitational (Chicago, Ill.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5977375" target="_blank">(5) Aaliyah MILLER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Baylor" class="group-logo-inline" src="/images/logos/rankings-article/baylor.png" title="Baylor"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=101">Baylor</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118010" target="_blank">2:00.69</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5977375" target="_blank">(5) Aaliyah MILLER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Baylor" class="group-logo-inline" src="/images/logos/rankings-article/baylor.png" title="Baylor"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=101">Baylor</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118010" target="_blank">2:00.69</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5610186" target="_blank">(5) Jazmine FRAY</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/47852/2974205" target="_blank">2:00.69</a> <span class="tooltip" style="font-size: smaller;">b<span class="tooltiptext" style="font-size: smaller;">b = Performance occurred on a 200m/220yd banked track</span></span> </td><td style="width: 10%;text-align:right;" title="Tiger Paw Invitational (Clemson, S.C.)"><span class="mark-date" style="width: 10%;text-align:right;">2/11/2017</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     29.35, 29.61 [58.96], 30.42 [1:29.38], 31.31 (61.73)</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5610186" target="_blank">(5) Jazmine FRAY</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/47852/2974205" target="_blank">2:00.69</a> <span class="tooltip" style="font-size: smaller;">b<span class="tooltiptext" style="font-size: smaller;">b = Performance occurred on a 200m/220yd banked track</span></span> </td><td style="width: 10%;text-align:right;" title="Tiger Paw Invitational (Clemson, S.C.)"><span class="mark-date" style="width: 10%;text-align:right;">2/11/2017</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     29.35, 29.61 [58.96], 30.42 [1:29.38], 31.31 (61.73)</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5964394" target="_blank">(7) Nia AKINS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Penn" class="group-logo-inline" src="/images/logos/rankings-article/penn.png" title="Penn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1208">Penn</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/63788" target="_blank">2:00.71</a> </td><td style="width: 10%;text-align:right;" title="David Hemery Valentine Invitational (Boston, Mass.)"><span class="mark-date" style="width: 10%;text-align:right;">2/14/2020</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5964394" target="_blank">(7) Nia AKINS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Penn" class="group-logo-inline" src="/images/logos/rankings-article/penn.png" title="Penn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1208">Penn</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/63788" target="_blank">2:00.71</a> </td><td style="width: 10%;text-align:right;" title="David Hemery Valentine Invitational (Boston, Mass.)"><span class="mark-date" style="width: 10%;text-align:right;">2/14/2020</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(8) Nicole COOK</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1553">Tennessee</a></td><td style="width: 25%;">2:00.75  </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/27/2005</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(8) Nicole COOK</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1553">Tennessee</a></td><td style="width: 25%;">2:00.75  </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/27/2005</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Rose {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720943" target="_blank">2:00.85</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Rose {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720943" target="_blank">2:00.85</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113694" target="_blank">(9) Raevyn ROGERS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41740" target="_blank">2:00.90</a> <span class="tooltip" style="font-size: smaller;">b<span class="tooltiptext" style="font-size: smaller;">b = Performance occurred on a 200m/220yd banked track</span></span> </td><td style="width: 10%;text-align:right;" title="NYRR Millrose Games (New York, N.Y.)"><span class="mark-date" style="width: 10%;text-align:right;">2/20/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113694" target="_blank">(9) Raevyn ROGERS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41740" target="_blank">2:00.90</a> <span class="tooltip" style="font-size: smaller;">b<span class="tooltiptext" style="font-size: smaller;">b = Performance occurred on a 200m/220yd banked track</span></span> </td><td style="width: 10%;text-align:right;" title="NYRR Millrose Games (New York, N.Y.)"><span class="mark-date" style="width: 10%;text-align:right;">2/20/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Mu {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/66740/4039206" target="_blank">2:01.07</a><a href="https://twitter.com/aggietfxc/status/1350590749138628608" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Ted Nelson Invitational I (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">1/16/2021</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     29.02, 31.73 [60.75], 30.63, 29.70 [60.32]</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Mu {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/66740/4039206" target="_blank">2:01.07</a><a href="https://twitter.com/aggietfxc/status/1350590749138628608" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Ted Nelson Invitational I (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">1/16/2021</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     29.02, 31.73 [60.75], 30.63, 29.70 [60.32]</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Rose {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691835" target="_blank">2:01.09</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/25/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Rose {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691835" target="_blank">2:01.09</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/25/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Rogers {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567/3023728" target="_blank">2:01.09</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2017</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     28.01, 32.03 [60.04], 31.17, 29.89 [61.06]</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Rogers {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567/3023728" target="_blank">2:01.09</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2017</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     28.01, 32.03 [60.04], 31.17, 29.89 [61.06]</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7003997" target="_blank">(10) Laurie BARTON</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=311">Clemson</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118010" target="_blank">2:01.21</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7003997" target="_blank">(10) Laurie BARTON</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=311">Clemson</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118010" target="_blank">2:01.21</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7000102" target="_blank">(11) Shafiqua MALONEY</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118010" target="_blank">2:01.22</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7000102" target="_blank">(11) Shafiqua MALONEY</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118010" target="_blank">2:01.22</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6904226" target="_blank">(12) Imogen BARRETT</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76446/4667853" target="_blank">2:01.23</a> </td><td style="width: 10%;text-align:right;" title="David Hemery Valentine Invitational (Boston, Mass.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6904226" target="_blank">(12) Imogen BARRETT</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76446/4667853" target="_blank">2:01.23</a> </td><td style="width: 10%;text-align:right;" title="David Hemery Valentine Invitational (Boston, Mass.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7402013" target="_blank">(12) Lindsey BUTLER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia Tech" class="group-logo-inline" src="/images/logos/rankings-article/virginia-tech.png" title="Virginia Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1701">Virginia Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72952/4389589" target="_blank">2:01.23</a> </td><td style="width: 10%;text-align:right;" title="ACC Indoor Championships (Blacksburg, Va.)"><span class="mark-date" style="width: 10%;text-align:right;">2/24/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7402013" target="_blank">(12) Lindsey BUTLER</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia Tech" class="group-logo-inline" src="/images/logos/rankings-article/virginia-tech.png" title="Virginia Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1701">Virginia Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72952/4389589" target="_blank">2:01.23</a> </td><td style="width: 10%;text-align:right;" title="ACC Indoor Championships (Blacksburg, Va.)"><span class="mark-date" style="width: 10%;text-align:right;">2/24/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Butler {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia Tech" class="group-logo-inline" src="/images/logos/rankings-article/virginia-tech.png" title="Virginia Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1701">Virginia Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416354" target="_blank">2:01.37</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Butler {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia Tech" class="group-logo-inline" src="/images/logos/rankings-article/virginia-tech.png" title="Virginia Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1701">Virginia Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416354" target="_blank">2:01.37</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(14) Phoebe WRIGHT</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/15304/971575" target="_blank">2:01.47</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/28/2010</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(14) Phoebe WRIGHT</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/15304/971575" target="_blank">2:01.47</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/28/2010</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6430701" target="_blank">(15) Sabrina SOUTHERLAND</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335565" target="_blank">2:01.55</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6430701" target="_blank">(15) Sabrina SOUTHERLAND</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335565" target="_blank">2:01.55</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4991018" target="_blank">(16) Natoya GOULE</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=311">Clemson</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/39148/2390366" target="_blank">2:01.64</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/14/2015</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     27.08, 29.55 [56.63], 31.41 [1:28.04], 33.60</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4991018" target="_blank">(16) Natoya GOULE</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=311">Clemson</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/39148/2390366" target="_blank">2:01.64</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/14/2015</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     27.08, 29.55 [56.63], 31.41 [1:28.04], 33.60</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(17) Amy WICKUS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Wisconsin" class="group-logo-inline" src="/images/logos/rankings-article/wisconsin.png" title="Wisconsin"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1812">Wisconsin</a></td><td style="width: 25%;">2:01.65  </td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">2/12/1994</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(17) Amy WICKUS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Wisconsin" class="group-logo-inline" src="/images/logos/rankings-article/wisconsin.png" title="Wisconsin"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1812">Wisconsin</a></td><td style="width: 25%;">2:01.65  </td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">2/12/1994</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Rose {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76073/4649181" target="_blank">2:01.66</a> </td><td style="width: 10%;text-align:right;" title="Razorback Team Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">1/27/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     28.92, 30.23, 30.50, 32.02 [59.15/62.52]</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Rose {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76073/4649181" target="_blank">2:01.66</a> </td><td style="width: 10%;text-align:right;" title="Razorback Team Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">1/27/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     28.92, 30.23, 30.50, 32.02 [59.15/62.52]</td></tr>,
# ...
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7488009" target="_blank">(23) Britton WILSON</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691835" target="_blank">2:02.13</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/25/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7488009" target="_blank">(23) Britton WILSON</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691835" target="_blank">2:02.13</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/25/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77712/4678892" target="_blank">2:02.13</a> </td><td style="width: 10%;text-align:right;" title="Arkansas Qualifier (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/17/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77712/4678892" target="_blank">2:02.13</a> </td><td style="width: 10%;text-align:right;" title="Arkansas Qualifier (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/17/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4629717" target="_blank">(23) Hanna GREEN</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia Tech" class="group-logo-inline" src="/images/logos/rankings-article/virginia-tech.png" title="Virginia Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1701">Virginia Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567/3023728" target="_blank">2:02.13</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4629717" target="_blank">(23) Hanna GREEN</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia Tech" class="group-logo-inline" src="/images/logos/rankings-article/virginia-tech.png" title="Virginia Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1701">Virginia Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/49567/3023728" target="_blank">2:02.13</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7480911" target="_blank">(25) Carley THOMAS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Washington" class="group-logo-inline" src="/images/logos/rankings-article/washington.png" title="Washington"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1721">Washington</a></td><td style="width: 25%;">2:02.15  </td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/4/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7480911" target="_blank">(25) Carley THOMAS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Washington" class="group-logo-inline" src="/images/logos/rankings-article/washington.png" title="Washington"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1721">Washington</a></td><td style="width: 25%;">2:02.15  </td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/4/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Thomas {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Washington" class="group-logo-inline" src="/images/logos/rankings-article/washington.png" title="Washington"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1721">Washington</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76105" target="_blank">2:02.15</a> </td><td style="width: 10%;text-align:right;" title="Bruce Lehane Scarlet and White Invitational (Boston, Mass.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/3/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Thomas {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Washington" class="group-logo-inline" src="/images/logos/rankings-article/washington.png" title="Washington"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1721">Washington</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76105" target="_blank">2:02.15</a> </td><td style="width: 10%;text-align:right;" title="Bruce Lehane Scarlet and White Invitational (Boston, Mass.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/3/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Butler {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia Tech" class="group-logo-inline" src="/images/logos/rankings-article/virginia-tech.png" title="Virginia Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1701">Virginia Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118010" target="_blank">2:02.15</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Butler {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia Tech" class="group-logo-inline" src="/images/logos/rankings-article/virginia-tech.png" title="Virginia Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1701">Virginia Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118010" target="_blank">2:02.15</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">Additional All-Conditions Bests</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3272989" target="_blank">Laura ROESLER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/31575" target="_blank">2:01.32</a> <span class="tooltip" style="font-size: smaller;">OT<span class="tooltiptext" style="font-size: smaller;">OT = Performance occurred on an oversized-track (&gt;200 meters/220 yards)</span></span> </td><td style="width: 10%;text-align:right;" title="Rod McCravy Memorial (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">1/25/2014</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3272989" target="_blank">Laura ROESLER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/31575" target="_blank">2:01.32</a> <span class="tooltip" style="font-size: smaller;">OT<span class="tooltiptext" style="font-size: smaller;">OT = Performance occurred on an oversized-track (&gt;200 meters/220 yards)</span></span> </td><td style="width: 10%;text-align:right;" title="Rod McCravy Memorial (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">1/25/2014</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4510820" target="_blank">Shea COLLINSWORTH</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="BYU" class="group-logo-inline" src="/images/logos/rankings-article/byu.png" title="BYU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=190">BYU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/48733" target="_blank">2:01.42</a> <span class="tooltip" style="font-size: smaller;">OT<span class="tooltiptext" style="font-size: smaller;">OT = Performance occurred on an oversized-track (&gt;200 meters/220 yards)</span></span> </td><td style="width: 10%;text-align:right;" title="Iowa State Classic (Ames, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">2/11/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4510820" target="_blank">Shea COLLINSWORTH</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="BYU" class="group-logo-inline" src="/images/logos/rankings-article/byu.png" title="BYU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=6&amp;team=190">BYU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/48733" target="_blank">2:01.42</a> <span class="tooltip" style="font-size: smaller;">OT<span class="tooltiptext" style="font-size: smaller;">OT = Performance occurred on an oversized-track (&gt;200 meters/220 yards)</span></span> </td><td style="width: 10%;text-align:right;" title="Iowa State Classic (Ames, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">2/11/2017</span></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Athing MUFRTexas A&M1:58.40📺 2/25/2021',
#   '(1) Athing MUFR',
#   '',
#   'Texas A&M',
#   '1:58.40📺 ',
#   '2/25/2021'],
#  [],
#  ['(1) Athing MUFR', '', 'Texas A&M', '1:58.40📺 ', '2/25/2021'],
#  ['(2) Roisin WILLISFRStanford1:59.93📺 3/11/2023',
#   '(2) Roisin WILLISFR',
#   '',
#   'Stanford',
#   '1:59.93📺 ',
#   '3/11/2023'],
#  [],
#  ['(2) Roisin WILLISFR', '', 'Stanford', '1:59.93📺 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Willis {2}FRStanford1:59.95 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Willis {2}FR',
#   '',
#   'Stanford',
#   '1:59.95 ',
#   '2/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Willis {2}FR', '', 'Stanford', '1:59.95 ', '2/10/2023'],
#  ['(3) Juliette WHITTAKERFRStanford2:00.05 3/11/2023',
#   '(3) Juliette WHITTAKERFR',
#   '',
#   'Stanford',
#   '2:00.05 ',
#   '3/11/2023'],
#  [],
#  ['(3) Juliette WHITTAKERFR', '', 'Stanford', '2:00.05 ', '3/11/2023'],
#  ['(4) Michaela ROSESOLSU2:00.18 2/10/2023',
#   '(4) Michaela ROSESO',
#   '',
#   'LSU',
#   '2:00.18 ',
#   '2/10/2023'],
#  [],
#  ['(4) Michaela ROSESO', '', 'LSU', '2:00.18 ', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Whittaker {2}FRStanford2:00.32 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Whittaker {2}FR',
#   '',
#   'Stanford',
#   '2:00.32 ',
#   '2/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Whittaker {2}FR',
#   '',
#   'Stanford',
#   '2:00.32 ',
#   '2/10/2023'],
#  ['(5) Aaliyah MILLERSRBaylor2:00.69 3/13/2021',
#   '(5) Aaliyah MILLERSR',
#   '',
#   'Baylor',
#   '2:00.69 ',
#   '3/13/2021'],
#  [],
#  ['(5) Aaliyah MILLERSR', '', 'Baylor', '2:00.69 ', '3/13/2021'],
#  ['(5) Jazmine FRAYSOTexas A&M2:00.69 bb = Performance occurred on a 200m/220yd banked track 2/11/2017\xa0\xa0\xa0\xa0\xa029.35, 29.61 [58.96], 30.42 [1:29.38], 31.31 (61.73)',
#   '(5) Jazmine FRAYSO',
#   '',
#   'Texas A&M',
#   '2:00.69 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/11/2017',
#   '\xa0\xa0\xa0\xa0\xa029.35, 29.61 [58.96], 30.42 [1:29.38], 31.31 (61.73)'],
#  [],
#  ['(5) Jazmine FRAYSO',
#   '',
#   'Texas A&M',
#   '2:00.69 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/11/2017'],
#  ['\xa0\xa0\xa0\xa0\xa029.35, 29.61 [58.96], 30.42 [1:29.38], 31.31 (61.73)'],
#  ['(7) Nia AKINSSRPenn2:00.71 2/14/2020',
#   '(7) Nia AKINSSR',
#   '',
#   'Penn',
#   '2:00.71 ',
#   '2/14/2020'],
#  [],
#  ['(7) Nia AKINSSR', '', 'Penn', '2:00.71 ', '2/14/2020'],
#  ['(8) Nicole COOKSRTennessee2:00.75  2/27/2005',
#   '(8) Nicole COOKSR',
#   '',
#   'Tennessee',
#   '2:00.75  ',
#   '2/27/2005'],
#  [],
#  ['(8) Nicole COOKSR', '', 'Tennessee', '2:00.75  ', '2/27/2005'],
#  ['\xa0\xa0\xa0\xa0— Rose {2}SOLSU2:00.85 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Rose {2}SO',
#   '',
#   'LSU',
#   '2:00.85 ',
#   '3/11/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rose {2}SO', '', 'LSU', '2:00.85 ', '3/11/2023'],
#  ['(9) Raevyn ROGERSSOOregon2:00.90 bb = Performance occurred on a 200m/220yd banked track 2/20/2016',
#   '(9) Raevyn ROGERSSO',
#   '',
#   'Oregon',
#   '2:00.90 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/20/2016'],
#  [],
#  ['(9) Raevyn ROGERSSO',
#   '',
#   'Oregon',
#   '2:00.90 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/20/2016'],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FRTexas A&M2:01.07📺 1/16/2021\xa0\xa0\xa0\xa0\xa029.02, 31.73 [60.75], 30.63, 29.70 [60.32]',
#   '\xa0\xa0\xa0\xa0— Mu {2}FR',
#   '',
#   'Texas A&M',
#   '2:01.07📺 ',
#   '1/16/2021',
#   '\xa0\xa0\xa0\xa0\xa029.02, 31.73 [60.75], 30.63, 29.70 [60.32]'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FR', '', 'Texas A&M', '2:01.07📺 ', '1/16/2021'],
#  ['\xa0\xa0\xa0\xa0\xa029.02, 31.73 [60.75], 30.63, 29.70 [60.32]'],
#  ['\xa0\xa0\xa0\xa0— Rose {3}SOLSU2:01.09 2/25/2023',
#   '\xa0\xa0\xa0\xa0— Rose {3}SO',
#   '',
#   'LSU',
#   '2:01.09 ',
#   '2/25/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rose {3}SO', '', 'LSU', '2:01.09 ', '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Rogers {2}JROregon2:01.09 3/11/2017\xa0\xa0\xa0\xa0\xa028.01, 32.03 [60.04], 31.17, 29.89 [61.06]',
#   '\xa0\xa0\xa0\xa0— Rogers {2}JR',
#   '',
#   'Oregon',
#   '2:01.09 ',
#   '3/11/2017',
#   '\xa0\xa0\xa0\xa0\xa028.01, 32.03 [60.04], 31.17, 29.89 [61.06]'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rogers {2}JR', '', 'Oregon', '2:01.09 ', '3/11/2017'],
#  ['\xa0\xa0\xa0\xa0\xa028.01, 32.03 [60.04], 31.17, 29.89 [61.06]'],
#  ['(10) Laurie BARTONSRClemson2:01.21 3/13/2021',
#   '(10) Laurie BARTONSR',
#   '',
#   'Clemson',
#   '2:01.21 ',
#   '3/13/2021'],
#  [],
#  ['(10) Laurie BARTONSR', '', 'Clemson', '2:01.21 ', '3/13/2021'],
#  ['(11) Shafiqua MALONEYSRArkansas2:01.22 3/13/2021',
#   '(11) Shafiqua MALONEYSR',
#   '',
#   'Arkansas',
#   '2:01.22 ',
#   '3/13/2021'],
#  [],
#  ['(11) Shafiqua MALONEYSR', '', 'Arkansas', '2:01.22 ', '3/13/2021'],
#  ['(12) Imogen BARRETTSRFlorida2:01.23 2/10/2023',
#   '(12) Imogen BARRETTSR',
#   '',
#   'Florida',
#   '2:01.23 ',
#   '2/10/2023'],
#  [],
#  ['(12) Imogen BARRETTSR', '', 'Florida', '2:01.23 ', '2/10/2023'],
#  ['(12) Lindsey BUTLERJRVirginia Tech2:01.23 2/24/2022',
#   '(12) Lindsey BUTLERJR',
#   '',
#   'Virginia Tech',
#   '2:01.23 ',
#   '2/24/2022'],
#  [],
#  ['(12) Lindsey BUTLERJR', '', 'Virginia Tech', '2:01.23 ', '2/24/2022'],
#  ['\xa0\xa0\xa0\xa0— Butler {2}JRVirginia Tech2:01.37 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Butler {2}JR',
#   '',
#   'Virginia Tech',
#   '2:01.37 ',
#   '3/12/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Butler {2}JR',
#   '',
#   'Virginia Tech',
#   '2:01.37 ',
#   '3/12/2022'],
#  ['(14) Phoebe WRIGHTSRTennessee2:01.47 2/28/2010',
#   '(14) Phoebe WRIGHTSR',
#   '',
#   'Tennessee',
#   '2:01.47 ',
#   '2/28/2010'],
#  [],
#  ['(14) Phoebe WRIGHTSR', '', 'Tennessee', '2:01.47 ', '2/28/2010'],
#  ['(15) Sabrina SOUTHERLANDSROregon2:01.55 3/10/2018',
#   '(15) Sabrina SOUTHERLANDSR',
#   '',
#   'Oregon',
#   '2:01.55 ',
#   '3/10/2018'],
#  [],
#  ['(15) Sabrina SOUTHERLANDSR', '', 'Oregon', '2:01.55 ', '3/10/2018'],
#  ['(16) Natoya GOULESRClemson2:01.64 3/14/2015\xa0\xa0\xa0\xa0\xa027.08, 29.55 [56.63], 31.41 [1:28.04], 33.60',
#   '(16) Natoya GOULESR',
#   '',
#   'Clemson',
#   '2:01.64 ',
#   '3/14/2015',
#   '\xa0\xa0\xa0\xa0\xa027.08, 29.55 [56.63], 31.41 [1:28.04], 33.60'],
#  [],
#  ['(16) Natoya GOULESR', '', 'Clemson', '2:01.64 ', '3/14/2015'],
#  ['\xa0\xa0\xa0\xa0\xa027.08, 29.55 [56.63], 31.41 [1:28.04], 33.60'],
#  ['(17) Amy WICKUSWisconsin2:01.65  2/12/1994',
#   '(17) Amy WICKUS',
#   '',
#   'Wisconsin',
#   '2:01.65  ',
#   '2/12/1994'],
#  [],
#  ['(17) Amy WICKUS', '', 'Wisconsin', '2:01.65  ', '2/12/1994'],
#  ['\xa0\xa0\xa0\xa0— Rose {4}SOLSU2:01.66 1/27/2023\xa0\xa0\xa0\xa0\xa028.92, 30.23, 30.50, 32.02 [59.15/62.52]',
#   '\xa0\xa0\xa0\xa0— Rose {4}SO',
#   '',
#   'LSU',
#   '2:01.66 ',
#   '1/27/2023',
#   '\xa0\xa0\xa0\xa0\xa028.92, 30.23, 30.50, 32.02 [59.15/62.52]'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rose {4}SO', '', 'LSU', '2:01.66 ', '1/27/2023'],
#  ['\xa0\xa0\xa0\xa0\xa028.92, 30.23, 30.50, 32.02 [59.15/62.52]'],
#  ['\xa0\xa0\xa0\xa0— Maloney {2}SRArkansas2:01.74 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Maloney {2}SR',
#   '',
#   'Arkansas',
#   '2:01.74 ',
#   '2/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Maloney {2}SR', '', 'Arkansas', '2:01.74 ', '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Rogers {3}JROregon2:01.75 bb = Performance occurred on a 200m/220yd banked track 1/28/2017',
#   '\xa0\xa0\xa0\xa0— Rogers {3}JR',
#   '',
#   'Oregon',
#   '2:01.75 bb = Performance occurred on a 200m/220yd banked track ',
#   '1/28/2017'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rogers {3}JR',
#   '',
#   'Oregon',
#   '2:01.75 bb = Performance occurred on a 200m/220yd banked track ',
#   '1/28/2017'],
#  ['(18) Hazel CLARKSRFlorida2:01.77  3/6/1999',
#   '(18) Hazel CLARKSR',
#   '',
#   'Florida',
#   '2:01.77  ',
#   '3/6/1999'],
#  [],
#  ['(18) Hazel CLARKSR', '', 'Florida', '2:01.77  ', '3/6/1999'],
#  ['\xa0\xa0\xa0\xa0— Whittaker {3}FRStanford2:01.82 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Whittaker {3}FR',
#   '',
#   'Stanford',
#   '2:01.82 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Whittaker {3}FR',
#   '',
#   'Stanford',
#   '2:01.82 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Clark {2}Florida2:01.84  2/21/1999',
#   '\xa0\xa0\xa0\xa0— Clark {2}',
#   '',
#   'Florida',
#   '2:01.84  ',
#   '2/21/1999'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Clark {2}', '', 'Florida', '2:01.84  ', '2/21/1999'],
#  ['\xa0\xa0\xa0\xa0— Clark {3}SRFlorida2:01.84  2/21/1999',
#   '\xa0\xa0\xa0\xa0— Clark {3}SR',
#   '',
#   'Florida',
#   '2:01.84  ',
#   '2/21/1999'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Clark {3}SR', '', 'Florida', '2:01.84  ', '2/21/1999'],
#  ['(19) Claire SEYMOURJRBYU2:01.96 3/12/2022',
#   '(19) Claire SEYMOURJR',
#   '',
#   'BYU',
#   '2:01.96 ',
#   '3/12/2022'],
#  [],
#  ['(19) Claire SEYMOURJR', '', 'BYU', '2:01.96 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Butler {3}SOVirginia Tech2:01.96 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Butler {3}SO',
#   '',
#   'Virginia Tech',
#   '2:01.96 ',
#   '2/25/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Butler {3}SO',
#   '',
#   'Virginia Tech',
#   '2:01.96 ',
#   '2/25/2021'],
#  ['(19) Aneita DENTONArkansas2:01.96  2/27/2005',
#   '(19) Aneita DENTON',
#   '',
#   'Arkansas',
#   '2:01.96  ',
#   '2/27/2005'],
#  [],
#  ['(19) Aneita DENTON', '', 'Arkansas', '2:01.96  ', '2/27/2005'],
#  ['\xa0\xa0\xa0\xa0— Barton {2}SRClemson2:01.99 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Barton {2}SR',
#   '',
#   'Clemson',
#   '2:01.99 ',
#   '2/25/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Barton {2}SR', '', 'Clemson', '2:01.99 ', '2/25/2021'],
#  ['(21) Sarah HENDRICKSRKennesaw State2:02.00  2/4/2023',
#   '(21) Sarah HENDRICKSR',
#   '',
#   'Kennesaw State',
#   '2:02.00  ',
#   '2/4/2023'],
#  [],
#  ['(21) Sarah HENDRICKSR', '', 'Kennesaw State', '2:02.00  ', '2/4/2023'],
#  ['\xa0\xa0\xa0\xa0— Hendrick {2}SRKennesaw State2:02.00 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Hendrick {2}SR',
#   '',
#   'Kennesaw State',
#   '2:02.00 ',
#   '2/3/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Hendrick {2}SR',
#   '',
#   'Kennesaw State',
#   '2:02.00 ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Goule {2}JRLSU2:02.00 3/9/2013\xa0\xa0\xa0\xa0\xa027.30, 31.65 [58.95], 31.94 [1:30.89], 31.11; (58.94/63.05)',
#   '\xa0\xa0\xa0\xa0— Goule {2}JR',
#   '',
#   'LSU',
#   '2:02.00 ',
#   '3/9/2013',
#   '\xa0\xa0\xa0\xa0\xa027.30, 31.65 [58.95], 31.94 [1:30.89], 31.11; (58.94/63.05)'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Goule {2}JR', '', 'LSU', '2:02.00 ', '3/9/2013'],
#  ['\xa0\xa0\xa0\xa0\xa027.30, 31.65 [58.95], 31.94 [1:30.89], 31.11; (58.94/63.05)'],
#  ['\xa0\xa0\xa0\xa0— Clark {4}Florida2:02.01  1/22/1999',
#   '\xa0\xa0\xa0\xa0— Clark {4}',
#   '',
#   'Florida',
#   '2:02.01  ',
#   '1/22/1999'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Clark {4}', '', 'Florida', '2:02.01  ', '1/22/1999'],
#  ['\xa0\xa0\xa0\xa0— Wickus {2}JRWisconsin2:02.05  3/12/1994',
#   '\xa0\xa0\xa0\xa0— Wickus {2}JR',
#   '',
#   'Wisconsin',
#   '2:02.05  ',
#   '3/12/1994'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wickus {2}JR', '', 'Wisconsin', '2:02.05  ', '3/12/1994'],
#  ['(22) Valery TOBIASSRTexas2:02.07 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(22) Valery TOBIASSR',
#   '',
#   'Texas',
#   '2:02.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['(22) Valery TOBIASSR',
#   '',
#   'Texas',
#   '2:02.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Maloney {3}SRArkansas2:02.10 2/26/2022',
#   '\xa0\xa0\xa0\xa0— Maloney {3}SR',
#   '',
#   'Arkansas',
#   '2:02.10 ',
#   '2/26/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Maloney {3}SR', '', 'Arkansas', '2:02.10 ', '2/26/2022'],
#  ['(23) Britton WILSONSOArkansas2:02.13 2/25/2023',
#   '(23) Britton WILSONSO',
#   '',
#   'Arkansas',
#   '2:02.13 ',
#   '2/25/2023'],
#  [],
#  ['(23) Britton WILSONSO', '', 'Arkansas', '2:02.13 ', '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}SOArkansas2:02.13 2/17/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}SO',
#   '',
#   'Arkansas',
#   '2:02.13 ',
#   '2/17/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}SO', '', 'Arkansas', '2:02.13 ', '2/17/2023'],
#  ['(23) Hanna GREENSRVirginia Tech2:02.13 3/11/2017',
#   '(23) Hanna GREENSR',
#   '',
#   'Virginia Tech',
#   '2:02.13 ',
#   '3/11/2017'],
#  [],
#  ['(23) Hanna GREENSR', '', 'Virginia Tech', '2:02.13 ', '3/11/2017'],
#  ['(25) Carley THOMASJRWashington2:02.15  2/4/2023',
#   '(25) Carley THOMASJR',
#   '',
#   'Washington',
#   '2:02.15  ',
#   '2/4/2023'],
#  [],
#  ['(25) Carley THOMASJR', '', 'Washington', '2:02.15  ', '2/4/2023'],
#  ['\xa0\xa0\xa0\xa0— Thomas {2}JRWashington2:02.15 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Thomas {2}JR',
#   '',
#   'Washington',
#   '2:02.15 ',
#   '2/3/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Thomas {2}JR', '', 'Washington', '2:02.15 ', '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Butler {4}SOVirginia Tech2:02.15 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Butler {4}SO',
#   '',
#   'Virginia Tech',
#   '2:02.15 ',
#   '3/13/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Butler {4}SO',
#   '',
#   'Virginia Tech',
#   '2:02.15 ',
#   '3/13/2021'],
#  ['Additional All-Conditions Bests'],
#  ['Laura ROESLERSROregon2:01.32 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 1/25/2014',
#   'Laura ROESLERSR',
#   '',
#   'Oregon',
#   '2:01.32 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '1/25/2014'],
#  [],
#  ['Laura ROESLERSR',
#   '',
#   'Oregon',
#   '2:01.32 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '1/25/2014'],
#  ['Shea COLLINSWORTHSRBYU2:01.42 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 2/11/2017',
#   'Shea COLLINSWORTHSR',
#   '',
#   'BYU',
#   '2:01.42 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/11/2017'],
#  [],
#  ['Shea COLLINSWORTHSR',
#   '',
#   'BYU',
#   '2:01.42 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/11/2017'],
#  ['', '', '', '']]

# %%
len(rows)
# Out:
# 160

# %%
rows[158]
# Out:
# ['Shea COLLINSWORTHSR',
#  '',
#  'BYU',
#  '2:01.42 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#  '2/11/2017']

# %%
len(rows)
# Out:
# 160

# %%
RealRows = []

# %%
for i in range(0,159):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [['(1) Athing MUFRTexas A&M1:58.40📺 2/25/2021',
#   '(1) Athing MUFR',
#   '',
#   'Texas A&M',
#   '1:58.40📺 ',
#   '2/25/2021'],
#  ['(1) Athing MUFR', '', 'Texas A&M', '1:58.40📺 ', '2/25/2021'],
#  ['(2) Roisin WILLISFRStanford1:59.93📺 3/11/2023',
#   '(2) Roisin WILLISFR',
#   '',
#   'Stanford',
#   '1:59.93📺 ',
#   '3/11/2023'],
#  ['(2) Roisin WILLISFR', '', 'Stanford', '1:59.93📺 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Willis {2}FRStanford1:59.95 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Willis {2}FR',
#   '',
#   'Stanford',
#   '1:59.95 ',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Willis {2}FR', '', 'Stanford', '1:59.95 ', '2/10/2023'],
#  ['(3) Juliette WHITTAKERFRStanford2:00.05 3/11/2023',
#   '(3) Juliette WHITTAKERFR',
#   '',
#   'Stanford',
#   '2:00.05 ',
#   '3/11/2023'],
#  ['(3) Juliette WHITTAKERFR', '', 'Stanford', '2:00.05 ', '3/11/2023'],
#  ['(4) Michaela ROSESOLSU2:00.18 2/10/2023',
#   '(4) Michaela ROSESO',
#   '',
#   'LSU',
#   '2:00.18 ',
#   '2/10/2023'],
#  ['(4) Michaela ROSESO', '', 'LSU', '2:00.18 ', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Whittaker {2}FRStanford2:00.32 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Whittaker {2}FR',
#   '',
#   'Stanford',
#   '2:00.32 ',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Whittaker {2}FR',
#   '',
#   'Stanford',
#   '2:00.32 ',
#   '2/10/2023'],
#  ['(5) Aaliyah MILLERSRBaylor2:00.69 3/13/2021',
#   '(5) Aaliyah MILLERSR',
#   '',
#   'Baylor',
#   '2:00.69 ',
#   '3/13/2021'],
#  ['(5) Aaliyah MILLERSR', '', 'Baylor', '2:00.69 ', '3/13/2021'],
#  ['(5) Jazmine FRAYSOTexas A&M2:00.69 bb = Performance occurred on a 200m/220yd banked track 2/11/2017\xa0\xa0\xa0\xa0\xa029.35, 29.61 [58.96], 30.42 [1:29.38], 31.31 (61.73)',
#   '(5) Jazmine FRAYSO',
#   '',
#   'Texas A&M',
#   '2:00.69 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/11/2017',
#   '\xa0\xa0\xa0\xa0\xa029.35, 29.61 [58.96], 30.42 [1:29.38], 31.31 (61.73)'],
#  ['(5) Jazmine FRAYSO',
#   '',
#   'Texas A&M',
#   '2:00.69 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/11/2017'],
#  ['(7) Nia AKINSSRPenn2:00.71 2/14/2020',
#   '(7) Nia AKINSSR',
#   '',
#   'Penn',
#   '2:00.71 ',
#   '2/14/2020'],
#  ['(7) Nia AKINSSR', '', 'Penn', '2:00.71 ', '2/14/2020'],
#  ['(8) Nicole COOKSRTennessee2:00.75  2/27/2005',
#   '(8) Nicole COOKSR',
#   '',
#   'Tennessee',
#   '2:00.75  ',
#   '2/27/2005'],
#  ['(8) Nicole COOKSR', '', 'Tennessee', '2:00.75  ', '2/27/2005'],
#  ['\xa0\xa0\xa0\xa0— Rose {2}SOLSU2:00.85 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Rose {2}SO',
#   '',
#   'LSU',
#   '2:00.85 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {2}SO', '', 'LSU', '2:00.85 ', '3/11/2023'],
#  ['(9) Raevyn ROGERSSOOregon2:00.90 bb = Performance occurred on a 200m/220yd banked track 2/20/2016',
#   '(9) Raevyn ROGERSSO',
#   '',
#   'Oregon',
#   '2:00.90 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/20/2016'],
#  ['(9) Raevyn ROGERSSO',
#   '',
#   'Oregon',
#   '2:00.90 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/20/2016'],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FRTexas A&M2:01.07📺 1/16/2021\xa0\xa0\xa0\xa0\xa029.02, 31.73 [60.75], 30.63, 29.70 [60.32]',
#   '\xa0\xa0\xa0\xa0— Mu {2}FR',
#   '',
#   'Texas A&M',
#   '2:01.07📺 ',
#   '1/16/2021',
#   '\xa0\xa0\xa0\xa0\xa029.02, 31.73 [60.75], 30.63, 29.70 [60.32]'],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FR', '', 'Texas A&M', '2:01.07📺 ', '1/16/2021'],
#  ['\xa0\xa0\xa0\xa0— Rose {3}SOLSU2:01.09 2/25/2023',
#   '\xa0\xa0\xa0\xa0— Rose {3}SO',
#   '',
#   'LSU',
#   '2:01.09 ',
#   '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {3}SO', '', 'LSU', '2:01.09 ', '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Rogers {2}JROregon2:01.09 3/11/2017\xa0\xa0\xa0\xa0\xa028.01, 32.03 [60.04], 31.17, 29.89 [61.06]',
#   '\xa0\xa0\xa0\xa0— Rogers {2}JR',
#   '',
#   'Oregon',
#   '2:01.09 ',
#   '3/11/2017',
#   '\xa0\xa0\xa0\xa0\xa028.01, 32.03 [60.04], 31.17, 29.89 [61.06]'],
#  ['\xa0\xa0\xa0\xa0— Rogers {2}JR', '', 'Oregon', '2:01.09 ', '3/11/2017'],
#  ['(10) Laurie BARTONSRClemson2:01.21 3/13/2021',
#   '(10) Laurie BARTONSR',
#   '',
#   'Clemson',
#   '2:01.21 ',
#   '3/13/2021'],
#  ['(10) Laurie BARTONSR', '', 'Clemson', '2:01.21 ', '3/13/2021'],
#  ['(11) Shafiqua MALONEYSRArkansas2:01.22 3/13/2021',
#   '(11) Shafiqua MALONEYSR',
#   '',
#   'Arkansas',
#   '2:01.22 ',
#   '3/13/2021'],
#  ['(11) Shafiqua MALONEYSR', '', 'Arkansas', '2:01.22 ', '3/13/2021'],
#  ['(12) Imogen BARRETTSRFlorida2:01.23 2/10/2023',
#   '(12) Imogen BARRETTSR',
#   '',
#   'Florida',
#   '2:01.23 ',
#   '2/10/2023'],
#  ['(12) Imogen BARRETTSR', '', 'Florida', '2:01.23 ', '2/10/2023'],
#  ['(12) Lindsey BUTLERJRVirginia Tech2:01.23 2/24/2022',
#   '(12) Lindsey BUTLERJR',
#   '',
#   'Virginia Tech',
#   '2:01.23 ',
#   '2/24/2022'],
#  ['(12) Lindsey BUTLERJR', '', 'Virginia Tech', '2:01.23 ', '2/24/2022'],
#  ['\xa0\xa0\xa0\xa0— Butler {2}JRVirginia Tech2:01.37 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Butler {2}JR',
#   '',
#   'Virginia Tech',
#   '2:01.37 ',
#   '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Butler {2}JR',
#   '',
#   'Virginia Tech',
#   '2:01.37 ',
#   '3/12/2022'],
#  ['(14) Phoebe WRIGHTSRTennessee2:01.47 2/28/2010',
#   '(14) Phoebe WRIGHTSR',
#   '',
#   'Tennessee',
#   '2:01.47 ',
#   '2/28/2010'],
#  ['(14) Phoebe WRIGHTSR', '', 'Tennessee', '2:01.47 ', '2/28/2010'],
#  ['(15) Sabrina SOUTHERLANDSROregon2:01.55 3/10/2018',
#   '(15) Sabrina SOUTHERLANDSR',
#   '',
#   'Oregon',
#   '2:01.55 ',
#   '3/10/2018'],
#  ['(15) Sabrina SOUTHERLANDSR', '', 'Oregon', '2:01.55 ', '3/10/2018'],
#  ['(16) Natoya GOULESRClemson2:01.64 3/14/2015\xa0\xa0\xa0\xa0\xa027.08, 29.55 [56.63], 31.41 [1:28.04], 33.60',
#   '(16) Natoya GOULESR',
#   '',
#   'Clemson',
#   '2:01.64 ',
#   '3/14/2015',
#   '\xa0\xa0\xa0\xa0\xa027.08, 29.55 [56.63], 31.41 [1:28.04], 33.60'],
#  ['(16) Natoya GOULESR', '', 'Clemson', '2:01.64 ', '3/14/2015'],
#  ['(17) Amy WICKUSWisconsin2:01.65  2/12/1994',
#   '(17) Amy WICKUS',
#   '',
#   'Wisconsin',
#   '2:01.65  ',
#   '2/12/1994'],
#  ['(17) Amy WICKUS', '', 'Wisconsin', '2:01.65  ', '2/12/1994'],
#  ['\xa0\xa0\xa0\xa0— Rose {4}SOLSU2:01.66 1/27/2023\xa0\xa0\xa0\xa0\xa028.92, 30.23, 30.50, 32.02 [59.15/62.52]',
#   '\xa0\xa0\xa0\xa0— Rose {4}SO',
#   '',
#   'LSU',
#   '2:01.66 ',
#   '1/27/2023',
#   '\xa0\xa0\xa0\xa0\xa028.92, 30.23, 30.50, 32.02 [59.15/62.52]'],
#  ['\xa0\xa0\xa0\xa0— Rose {4}SO', '', 'LSU', '2:01.66 ', '1/27/2023'],
#  ['\xa0\xa0\xa0\xa0— Maloney {2}SRArkansas2:01.74 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Maloney {2}SR',
#   '',
#   'Arkansas',
#   '2:01.74 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Maloney {2}SR', '', 'Arkansas', '2:01.74 ', '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Rogers {3}JROregon2:01.75 bb = Performance occurred on a 200m/220yd banked track 1/28/2017',
#   '\xa0\xa0\xa0\xa0— Rogers {3}JR',
#   '',
#   'Oregon',
#   '2:01.75 bb = Performance occurred on a 200m/220yd banked track ',
#   '1/28/2017'],
#  ['\xa0\xa0\xa0\xa0— Rogers {3}JR',
#   '',
#   'Oregon',
#   '2:01.75 bb = Performance occurred on a 200m/220yd banked track ',
#   '1/28/2017'],
#  ['(18) Hazel CLARKSRFlorida2:01.77  3/6/1999',
#   '(18) Hazel CLARKSR',
#   '',
#   'Florida',
#   '2:01.77  ',
#   '3/6/1999'],
#  ['(18) Hazel CLARKSR', '', 'Florida', '2:01.77  ', '3/6/1999'],
#  ['\xa0\xa0\xa0\xa0— Whittaker {3}FRStanford2:01.82 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Whittaker {3}FR',
#   '',
#   'Stanford',
#   '2:01.82 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Whittaker {3}FR',
#   '',
#   'Stanford',
#   '2:01.82 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Clark {2}Florida2:01.84  2/21/1999',
#   '\xa0\xa0\xa0\xa0— Clark {2}',
#   '',
#   'Florida',
#   '2:01.84  ',
#   '2/21/1999'],
#  ['\xa0\xa0\xa0\xa0— Clark {2}', '', 'Florida', '2:01.84  ', '2/21/1999'],
#  ['\xa0\xa0\xa0\xa0— Clark {3}SRFlorida2:01.84  2/21/1999',
#   '\xa0\xa0\xa0\xa0— Clark {3}SR',
#   '',
#   'Florida',
#   '2:01.84  ',
#   '2/21/1999'],
#  ['\xa0\xa0\xa0\xa0— Clark {3}SR', '', 'Florida', '2:01.84  ', '2/21/1999'],
#  ['(19) Claire SEYMOURJRBYU2:01.96 3/12/2022',
#   '(19) Claire SEYMOURJR',
#   '',
#   'BYU',
#   '2:01.96 ',
#   '3/12/2022'],
#  ['(19) Claire SEYMOURJR', '', 'BYU', '2:01.96 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Butler {3}SOVirginia Tech2:01.96 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Butler {3}SO',
#   '',
#   'Virginia Tech',
#   '2:01.96 ',
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Butler {3}SO',
#   '',
#   'Virginia Tech',
#   '2:01.96 ',
#   '2/25/2021'],
#  ['(19) Aneita DENTONArkansas2:01.96  2/27/2005',
#   '(19) Aneita DENTON',
#   '',
#   'Arkansas',
#   '2:01.96  ',
#   '2/27/2005'],
#  ['(19) Aneita DENTON', '', 'Arkansas', '2:01.96  ', '2/27/2005'],
#  ['\xa0\xa0\xa0\xa0— Barton {2}SRClemson2:01.99 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Barton {2}SR',
#   '',
#   'Clemson',
#   '2:01.99 ',
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Barton {2}SR', '', 'Clemson', '2:01.99 ', '2/25/2021'],
#  ['(21) Sarah HENDRICKSRKennesaw State2:02.00  2/4/2023',
#   '(21) Sarah HENDRICKSR',
#   '',
#   'Kennesaw State',
#   '2:02.00  ',
#   '2/4/2023'],
#  ['(21) Sarah HENDRICKSR', '', 'Kennesaw State', '2:02.00  ', '2/4/2023'],
#  ['\xa0\xa0\xa0\xa0— Hendrick {2}SRKennesaw State2:02.00 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Hendrick {2}SR',
#   '',
#   'Kennesaw State',
#   '2:02.00 ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Hendrick {2}SR',
#   '',
#   'Kennesaw State',
#   '2:02.00 ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Goule {2}JRLSU2:02.00 3/9/2013\xa0\xa0\xa0\xa0\xa027.30, 31.65 [58.95], 31.94 [1:30.89], 31.11; (58.94/63.05)',
#   '\xa0\xa0\xa0\xa0— Goule {2}JR',
#   '',
#   'LSU',
#   '2:02.00 ',
#   '3/9/2013',
#   '\xa0\xa0\xa0\xa0\xa027.30, 31.65 [58.95], 31.94 [1:30.89], 31.11; (58.94/63.05)'],
#  ['\xa0\xa0\xa0\xa0— Goule {2}JR', '', 'LSU', '2:02.00 ', '3/9/2013'],
#  ['\xa0\xa0\xa0\xa0— Clark {4}Florida2:02.01  1/22/1999',
#   '\xa0\xa0\xa0\xa0— Clark {4}',
#   '',
#   'Florida',
#   '2:02.01  ',
#   '1/22/1999'],
#  ['\xa0\xa0\xa0\xa0— Clark {4}', '', 'Florida', '2:02.01  ', '1/22/1999'],
#  ['\xa0\xa0\xa0\xa0— Wickus {2}JRWisconsin2:02.05  3/12/1994',
#   '\xa0\xa0\xa0\xa0— Wickus {2}JR',
#   '',
#   'Wisconsin',
#   '2:02.05  ',
#   '3/12/1994'],
#  ['\xa0\xa0\xa0\xa0— Wickus {2}JR', '', 'Wisconsin', '2:02.05  ', '3/12/1994'],
#  ['(22) Valery TOBIASSRTexas2:02.07 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(22) Valery TOBIASSR',
#   '',
#   'Texas',
#   '2:02.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(22) Valery TOBIASSR',
#   '',
#   'Texas',
#   '2:02.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Maloney {3}SRArkansas2:02.10 2/26/2022',
#   '\xa0\xa0\xa0\xa0— Maloney {3}SR',
#   '',
#   'Arkansas',
#   '2:02.10 ',
#   '2/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Maloney {3}SR', '', 'Arkansas', '2:02.10 ', '2/26/2022'],
#  ['(23) Britton WILSONSOArkansas2:02.13 2/25/2023',
#   '(23) Britton WILSONSO',
#   '',
#   'Arkansas',
#   '2:02.13 ',
#   '2/25/2023'],
#  ['(23) Britton WILSONSO', '', 'Arkansas', '2:02.13 ', '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}SOArkansas2:02.13 2/17/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}SO',
#   '',
#   'Arkansas',
#   '2:02.13 ',
#   '2/17/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}SO', '', 'Arkansas', '2:02.13 ', '2/17/2023'],
#  ['(23) Hanna GREENSRVirginia Tech2:02.13 3/11/2017',
#   '(23) Hanna GREENSR',
#   '',
#   'Virginia Tech',
#   '2:02.13 ',
#   '3/11/2017'],
#  ['(23) Hanna GREENSR', '', 'Virginia Tech', '2:02.13 ', '3/11/2017'],
#  ['(25) Carley THOMASJRWashington2:02.15  2/4/2023',
#   '(25) Carley THOMASJR',
#   '',
#   'Washington',
#   '2:02.15  ',
#   '2/4/2023'],
#  ['(25) Carley THOMASJR', '', 'Washington', '2:02.15  ', '2/4/2023'],
#  ['\xa0\xa0\xa0\xa0— Thomas {2}JRWashington2:02.15 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Thomas {2}JR',
#   '',
#   'Washington',
#   '2:02.15 ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Thomas {2}JR', '', 'Washington', '2:02.15 ', '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Butler {4}SOVirginia Tech2:02.15 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Butler {4}SO',
#   '',
#   'Virginia Tech',
#   '2:02.15 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Butler {4}SO',
#   '',
#   'Virginia Tech',
#   '2:02.15 ',
#   '3/13/2021'],
#  ['Laura ROESLERSROregon2:01.32 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 1/25/2014',
#   'Laura ROESLERSR',
#   '',
#   'Oregon',
#   '2:01.32 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '1/25/2014'],
#  ['Laura ROESLERSR',
#   '',
#   'Oregon',
#   '2:01.32 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '1/25/2014'],
#  ['Shea COLLINSWORTHSRBYU2:01.42 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 2/11/2017',
#   'Shea COLLINSWORTHSR',
#   '',
#   'BYU',
#   '2:01.42 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/11/2017'],
#  ['Shea COLLINSWORTHSR',
#   '',
#   'BYU',
#   '2:01.42 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/11/2017']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Athing MUFRTexas A&M1:58.40📺 2/25/2021',
#   '(1) Athing MUFR',
#   '',
#   'Texas A&M',
#   '1:58.40📺 ',
#   '2/25/2021'],
#  ['(2) Roisin WILLISFRStanford1:59.93📺 3/11/2023',
#   '(2) Roisin WILLISFR',
#   '',
#   'Stanford',
#   '1:59.93📺 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Willis {2}FRStanford1:59.95 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Willis {2}FR',
#   '',
#   'Stanford',
#   '1:59.95 ',
#   '2/10/2023'],
#  ['(3) Juliette WHITTAKERFRStanford2:00.05 3/11/2023',
#   '(3) Juliette WHITTAKERFR',
#   '',
#   'Stanford',
#   '2:00.05 ',
#   '3/11/2023'],
#  ['(4) Michaela ROSESOLSU2:00.18 2/10/2023',
#   '(4) Michaela ROSESO',
#   '',
#   'LSU',
#   '2:00.18 ',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Whittaker {2}FRStanford2:00.32 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Whittaker {2}FR',
#   '',
#   'Stanford',
#   '2:00.32 ',
#   '2/10/2023'],
#  ['(5) Aaliyah MILLERSRBaylor2:00.69 3/13/2021',
#   '(5) Aaliyah MILLERSR',
#   '',
#   'Baylor',
#   '2:00.69 ',
#   '3/13/2021'],
#  ['(5) Jazmine FRAYSOTexas A&M2:00.69 bb = Performance occurred on a 200m/220yd banked track 2/11/2017\xa0\xa0\xa0\xa0\xa029.35, 29.61 [58.96], 30.42 [1:29.38], 31.31 (61.73)',
#   '(5) Jazmine FRAYSO',
#   '',
#   'Texas A&M',
#   '2:00.69 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/11/2017',
#   '\xa0\xa0\xa0\xa0\xa029.35, 29.61 [58.96], 30.42 [1:29.38], 31.31 (61.73)'],
#  ['(7) Nia AKINSSRPenn2:00.71 2/14/2020',
#   '(7) Nia AKINSSR',
#   '',
#   'Penn',
#   '2:00.71 ',
#   '2/14/2020'],
#  ['(8) Nicole COOKSRTennessee2:00.75  2/27/2005',
#   '(8) Nicole COOKSR',
#   '',
#   'Tennessee',
#   '2:00.75  ',
#   '2/27/2005'],
#  ['\xa0\xa0\xa0\xa0— Rose {2}SOLSU2:00.85 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Rose {2}SO',
#   '',
#   'LSU',
#   '2:00.85 ',
#   '3/11/2023'],
#  ['(9) Raevyn ROGERSSOOregon2:00.90 bb = Performance occurred on a 200m/220yd banked track 2/20/2016',
#   '(9) Raevyn ROGERSSO',
#   '',
#   'Oregon',
#   '2:00.90 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/20/2016'],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FRTexas A&M2:01.07📺 1/16/2021\xa0\xa0\xa0\xa0\xa029.02, 31.73 [60.75], 30.63, 29.70 [60.32]',
#   '\xa0\xa0\xa0\xa0— Mu {2}FR',
#   '',
#   'Texas A&M',
#   '2:01.07📺 ',
#   '1/16/2021',
#   '\xa0\xa0\xa0\xa0\xa029.02, 31.73 [60.75], 30.63, 29.70 [60.32]'],
#  ['\xa0\xa0\xa0\xa0— Rose {3}SOLSU2:01.09 2/25/2023',
#   '\xa0\xa0\xa0\xa0— Rose {3}SO',
#   '',
#   'LSU',
#   '2:01.09 ',
#   '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Rogers {2}JROregon2:01.09 3/11/2017\xa0\xa0\xa0\xa0\xa028.01, 32.03 [60.04], 31.17, 29.89 [61.06]',
#   '\xa0\xa0\xa0\xa0— Rogers {2}JR',
#   '',
#   'Oregon',
#   '2:01.09 ',
#   '3/11/2017',
#   '\xa0\xa0\xa0\xa0\xa028.01, 32.03 [60.04], 31.17, 29.89 [61.06]'],
#  ['(10) Laurie BARTONSRClemson2:01.21 3/13/2021',
#   '(10) Laurie BARTONSR',
#   '',
#   'Clemson',
#   '2:01.21 ',
#   '3/13/2021'],
#  ['(11) Shafiqua MALONEYSRArkansas2:01.22 3/13/2021',
#   '(11) Shafiqua MALONEYSR',
#   '',
#   'Arkansas',
#   '2:01.22 ',
#   '3/13/2021'],
#  ['(12) Imogen BARRETTSRFlorida2:01.23 2/10/2023',
#   '(12) Imogen BARRETTSR',
#   '',
#   'Florida',
#   '2:01.23 ',
#   '2/10/2023'],
#  ['(12) Lindsey BUTLERJRVirginia Tech2:01.23 2/24/2022',
#   '(12) Lindsey BUTLERJR',
#   '',
#   'Virginia Tech',
#   '2:01.23 ',
#   '2/24/2022'],
#  ['\xa0\xa0\xa0\xa0— Butler {2}JRVirginia Tech2:01.37 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Butler {2}JR',
#   '',
#   'Virginia Tech',
#   '2:01.37 ',
#   '3/12/2022'],
#  ['(14) Phoebe WRIGHTSRTennessee2:01.47 2/28/2010',
#   '(14) Phoebe WRIGHTSR',
#   '',
#   'Tennessee',
#   '2:01.47 ',
#   '2/28/2010'],
#  ['(15) Sabrina SOUTHERLANDSROregon2:01.55 3/10/2018',
#   '(15) Sabrina SOUTHERLANDSR',
#   '',
#   'Oregon',
#   '2:01.55 ',
#   '3/10/2018'],
#  ['(16) Natoya GOULESRClemson2:01.64 3/14/2015\xa0\xa0\xa0\xa0\xa027.08, 29.55 [56.63], 31.41 [1:28.04], 33.60',
#   '(16) Natoya GOULESR',
#   '',
#   'Clemson',
#   '2:01.64 ',
#   '3/14/2015',
#   '\xa0\xa0\xa0\xa0\xa027.08, 29.55 [56.63], 31.41 [1:28.04], 33.60'],
#  ['(17) Amy WICKUSWisconsin2:01.65  2/12/1994',
#   '(17) Amy WICKUS',
#   '',
#   'Wisconsin',
#   '2:01.65  ',
#   '2/12/1994'],
#  ['\xa0\xa0\xa0\xa0— Rose {4}SOLSU2:01.66 1/27/2023\xa0\xa0\xa0\xa0\xa028.92, 30.23, 30.50, 32.02 [59.15/62.52]',
#   '\xa0\xa0\xa0\xa0— Rose {4}SO',
#   '',
#   'LSU',
#   '2:01.66 ',
#   '1/27/2023',
#   '\xa0\xa0\xa0\xa0\xa028.92, 30.23, 30.50, 32.02 [59.15/62.52]'],
#  ['\xa0\xa0\xa0\xa0— Maloney {2}SRArkansas2:01.74 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Maloney {2}SR',
#   '',
#   'Arkansas',
#   '2:01.74 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Rogers {3}JROregon2:01.75 bb = Performance occurred on a 200m/220yd banked track 1/28/2017',
#   '\xa0\xa0\xa0\xa0— Rogers {3}JR',
#   '',
#   'Oregon',
#   '2:01.75 bb = Performance occurred on a 200m/220yd banked track ',
#   '1/28/2017'],
#  ['(18) Hazel CLARKSRFlorida2:01.77  3/6/1999',
#   '(18) Hazel CLARKSR',
#   '',
#   'Florida',
#   '2:01.77  ',
#   '3/6/1999'],
#  ['\xa0\xa0\xa0\xa0— Whittaker {3}FRStanford2:01.82 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Whittaker {3}FR',
#   '',
#   'Stanford',
#   '2:01.82 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Clark {2}Florida2:01.84  2/21/1999',
#   '\xa0\xa0\xa0\xa0— Clark {2}',
#   '',
#   'Florida',
#   '2:01.84  ',
#   '2/21/1999'],
#  ['\xa0\xa0\xa0\xa0— Clark {3}SRFlorida2:01.84  2/21/1999',
#   '\xa0\xa0\xa0\xa0— Clark {3}SR',
#   '',
#   'Florida',
#   '2:01.84  ',
#   '2/21/1999'],
#  ['(19) Claire SEYMOURJRBYU2:01.96 3/12/2022',
#   '(19) Claire SEYMOURJR',
#   '',
#   'BYU',
#   '2:01.96 ',
#   '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Butler {3}SOVirginia Tech2:01.96 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Butler {3}SO',
#   '',
#   'Virginia Tech',
#   '2:01.96 ',
#   '2/25/2021'],
#  ['(19) Aneita DENTONArkansas2:01.96  2/27/2005',
#   '(19) Aneita DENTON',
#   '',
#   'Arkansas',
#   '2:01.96  ',
#   '2/27/2005'],
#  ['\xa0\xa0\xa0\xa0— Barton {2}SRClemson2:01.99 2/25/2021',
#   '\xa0\xa0\xa0\xa0— Barton {2}SR',
#   '',
#   'Clemson',
#   '2:01.99 ',
#   '2/25/2021'],
#  ['(21) Sarah HENDRICKSRKennesaw State2:02.00  2/4/2023',
#   '(21) Sarah HENDRICKSR',
#   '',
#   'Kennesaw State',
#   '2:02.00  ',
#   '2/4/2023'],
#  ['\xa0\xa0\xa0\xa0— Hendrick {2}SRKennesaw State2:02.00 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Hendrick {2}SR',
#   '',
#   'Kennesaw State',
#   '2:02.00 ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Goule {2}JRLSU2:02.00 3/9/2013\xa0\xa0\xa0\xa0\xa027.30, 31.65 [58.95], 31.94 [1:30.89], 31.11; (58.94/63.05)',
#   '\xa0\xa0\xa0\xa0— Goule {2}JR',
#   '',
#   'LSU',
#   '2:02.00 ',
#   '3/9/2013',
#   '\xa0\xa0\xa0\xa0\xa027.30, 31.65 [58.95], 31.94 [1:30.89], 31.11; (58.94/63.05)'],
#  ['\xa0\xa0\xa0\xa0— Clark {4}Florida2:02.01  1/22/1999',
#   '\xa0\xa0\xa0\xa0— Clark {4}',
#   '',
#   'Florida',
#   '2:02.01  ',
#   '1/22/1999'],
#  ['\xa0\xa0\xa0\xa0— Wickus {2}JRWisconsin2:02.05  3/12/1994',
#   '\xa0\xa0\xa0\xa0— Wickus {2}JR',
#   '',
#   'Wisconsin',
#   '2:02.05  ',
#   '3/12/1994'],
#  ['(22) Valery TOBIASSRTexas2:02.07 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(22) Valery TOBIASSR',
#   '',
#   'Texas',
#   '2:02.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Maloney {3}SRArkansas2:02.10 2/26/2022',
#   '\xa0\xa0\xa0\xa0— Maloney {3}SR',
#   '',
#   'Arkansas',
#   '2:02.10 ',
#   '2/26/2022'],
#  ['(23) Britton WILSONSOArkansas2:02.13 2/25/2023',
#   '(23) Britton WILSONSO',
#   '',
#   'Arkansas',
#   '2:02.13 ',
#   '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}SOArkansas2:02.13 2/17/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}SO',
#   '',
#   'Arkansas',
#   '2:02.13 ',
#   '2/17/2023'],
#  ['(23) Hanna GREENSRVirginia Tech2:02.13 3/11/2017',
#   '(23) Hanna GREENSR',
#   '',
#   'Virginia Tech',
#   '2:02.13 ',
#   '3/11/2017'],
#  ['(25) Carley THOMASJRWashington2:02.15  2/4/2023',
#   '(25) Carley THOMASJR',
#   '',
#   'Washington',
#   '2:02.15  ',
#   '2/4/2023'],
#  ['\xa0\xa0\xa0\xa0— Thomas {2}JRWashington2:02.15 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Thomas {2}JR',
#   '',
#   'Washington',
#   '2:02.15 ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Butler {4}SOVirginia Tech2:02.15 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Butler {4}SO',
#   '',
#   'Virginia Tech',
#   '2:02.15 ',
#   '3/13/2021'],
#  ['Laura ROESLERSROregon2:01.32 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 1/25/2014',
#   'Laura ROESLERSR',
#   '',
#   'Oregon',
#   '2:01.32 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '1/25/2014'],
#  ['Shea COLLINSWORTHSRBYU2:01.42 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) 2/11/2017',
#   'Shea COLLINSWORTHSR',
#   '',
#   'BYU',
#   '2:01.42 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#   '2/11/2017']]

# %%
RealRealRows[1][4]
# Out:
# '1:59.93📺 '

# %%
len(RealRealRows)
# Out:
# 50

# %%
OfficialTimes = []

# %%
for i in range(0,50):
    OfficialTimes.append(RealRealRows[i][4])
OfficialTimes
# Out:
# ['1:58.40📺 ',
#  '1:59.93📺 ',
#  '1:59.95 ',
#  '2:00.05 ',
#  '2:00.18 ',
#  '2:00.32 ',
#  '2:00.69 ',
#  '2:00.69 bb = Performance occurred on a 200m/220yd banked track ',
#  '2:00.71 ',
#  '2:00.75  ',
#  '2:00.85 ',
#  '2:00.90 bb = Performance occurred on a 200m/220yd banked track ',
#  '2:01.07📺 ',
#  '2:01.09 ',
#  '2:01.09 ',
#  '2:01.21 ',
#  '2:01.22 ',
#  '2:01.23 ',
#  '2:01.23 ',
#  '2:01.37 ',
#  '2:01.47 ',
#  '2:01.55 ',
#  '2:01.64 ',
#  '2:01.65  ',
#  '2:01.66 ',
#  '2:01.74 ',
#  '2:01.75 bb = Performance occurred on a 200m/220yd banked track ',
#  '2:01.77  ',
#  '2:01.82 qq = Performance occurred during a non-final round. ',
#  '2:01.84  ',
#  '2:01.84  ',
#  '2:01.96 ',
#  '2:01.96 ',
#  '2:01.96  ',
#  '2:01.99 ',
#  '2:02.00  ',
#  '2:02.00 ',
#  '2:02.00 ',
#  '2:02.01  ',
#  '2:02.05  ',
#  '2:02.07 qq = Performance occurred during a non-final round. ',
#  '2:02.10 ',
#  '2:02.13 ',
#  '2:02.13 ',
#  '2:02.13 ',
#  '2:02.15  ',
#  '2:02.15 ',
#  '2:02.15 ',
#  '2:01.32 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ',
#  '2:01.42 OTOT = Performance occurred on an oversized-track (>200 meters/220 yards) ']

# %%
RealRealRows[0][1]
# Out:
# '(1) Athing MUFR'

# %%
Names = []

for i in range(0,50):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Athing MUFR',
#  '(2) Roisin WILLISFR',
#  '\xa0\xa0\xa0\xa0— Willis {2}FR',
#  '(3) Juliette WHITTAKERFR',
#  '(4) Michaela ROSESO',
#  '\xa0\xa0\xa0\xa0— Whittaker {2}FR',
#  '(5) Aaliyah MILLERSR',
#  '(5) Jazmine FRAYSO',
#  '(7) Nia AKINSSR',
#  '(8) Nicole COOKSR',
#  '\xa0\xa0\xa0\xa0— Rose {2}SO',
#  '(9) Raevyn ROGERSSO',
#  '\xa0\xa0\xa0\xa0— Mu {2}FR',
#  '\xa0\xa0\xa0\xa0— Rose {3}SO',
#  '\xa0\xa0\xa0\xa0— Rogers {2}JR',
#  '(10) Laurie BARTONSR',
#  '(11) Shafiqua MALONEYSR',
#  '(12) Imogen BARRETTSR',
#  '(12) Lindsey BUTLERJR',
#  '\xa0\xa0\xa0\xa0— Butler {2}JR',
#  '(14) Phoebe WRIGHTSR',
#  '(15) Sabrina SOUTHERLANDSR',
#  '(16) Natoya GOULESR',
#  '(17) Amy WICKUS',
#  '\xa0\xa0\xa0\xa0— Rose {4}SO',
#  '\xa0\xa0\xa0\xa0— Maloney {2}SR',
#  '\xa0\xa0\xa0\xa0— Rogers {3}JR',
#  '(18) Hazel CLARKSR',
#  '\xa0\xa0\xa0\xa0— Whittaker {3}FR',
#  '\xa0\xa0\xa0\xa0— Clark {2}',
#  '\xa0\xa0\xa0\xa0— Clark {3}SR',
#  '(19) Claire SEYMOURJR',
#  '\xa0\xa0\xa0\xa0— Butler {3}SO',
#  '(19) Aneita DENTON',
#  '\xa0\xa0\xa0\xa0— Barton {2}SR',
#  '(21) Sarah HENDRICKSR',
#  '\xa0\xa0\xa0\xa0— Hendrick {2}SR',
#  '\xa0\xa0\xa0\xa0— Goule {2}JR',
#  '\xa0\xa0\xa0\xa0— Clark {4}',
#  '\xa0\xa0\xa0\xa0— Wickus {2}JR',
#  '(22) Valery TOBIASSR',
#  '\xa0\xa0\xa0\xa0— Maloney {3}SR',
#  '(23) Britton WILSONSO',
#  '\xa0\xa0\xa0\xa0— Wilson {2}SO',
#  '(23) Hanna GREENSR',
#  '(25) Carley THOMASJR',
#  '\xa0\xa0\xa0\xa0— Thomas {2}JR',
#  '\xa0\xa0\xa0\xa0— Butler {4}SO',
#  'Laura ROESLERSR',
#  'Shea COLLINSWORTHSR']

# %%
OfficialReGexNames = []

# %%
for i in range(0,50):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Athing MUFR',
#  '(2) Roisin WILLISFR',
#  '— Willis {2}FR',
#  '(3) Juliette WHITTAKERFR',
#  '(4) Michaela ROSESO',
#  '— Whittaker {2}FR',
#  '(5) Aaliyah MILLERSR',
#  '(5) Jazmine FRAYSO',
#  '(7) Nia AKINSSR',
#  '(8) Nicole COOKSR',
#  '— Rose {2}SO',
#  '(9) Raevyn ROGERSSO',
#  '— Mu {2}FR',
#  '— Rose {3}SO',
#  '— Rogers {2}JR',
#  '(10) Laurie BARTONSR',
#  '(11) Shafiqua MALONEYSR',
#  '(12) Imogen BARRETTSR',
#  '(12) Lindsey BUTLERJR',
#  '— Butler {2}JR',
#  '(14) Phoebe WRIGHTSR',
#  '(15) Sabrina SOUTHERLANDSR',
#  '(16) Natoya GOULESR',
#  '(17) Amy WICKUS',
#  '— Rose {4}SO',
#  '— Maloney {2}SR',
#  '— Rogers {3}JR',
#  '(18) Hazel CLARKSR',
#  '— Whittaker {3}FR',
#  '— Clark {2}',
#  '— Clark {3}SR',
#  '(19) Claire SEYMOURJR',
#  '— Butler {3}SO',
#  '(19) Aneita DENTON',
#  '— Barton {2}SR',
#  '(21) Sarah HENDRICKSR',
#  '— Hendrick {2}SR',
#  '— Goule {2}JR',
#  '— Clark {4}',
#  '— Wickus {2}JR',
#  '(22) Valery TOBIASSR',
#  '— Maloney {3}SR',
#  '(23) Britton WILSONSO',
#  '— Wilson {2}SO',
#  '(23) Hanna GREENSR',
#  '(25) Carley THOMASJR',
#  '— Thomas {2}JR',
#  '— Butler {4}SO',
#  'Laura ROESLERSR',
#  'Shea COLLINSWORTHSR']

# %%
CleanedNames = []

for i in range(0,len(OfficialReGexNames)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Athing MUFR',
#  'Roisin WILLISFR',
#  'Willis {2}FR',
#  'Juliette WHITTAKERFR',
#  'Michaela ROSESO',
#  'Whittaker {2}FR',
#  'Aaliyah MILLERSR',
#  'Jazmine FRAYSO',
#  'Nia AKINSSR',
#  'Nicole COOKSR',
#  'Rose {2}SO',
#  'Raevyn ROGERSSO',
#  'Mu {2}FR',
#  'Rose {3}SO',
#  'Rogers {2}JR',
#  ' Laurie BARTONSR',
#  ' Shafiqua MALONEYSR',
#  ' Imogen BARRETTSR',
#  ' Lindsey BUTLERJR',
#  'Butler {2}JR',
#  ' Phoebe WRIGHTSR',
#  ' Sabrina SOUTHERLANDSR',
#  ' Natoya GOULESR',
#  ' Amy WICKUS',
#  'Rose {4}SO',
#  'Maloney {2}SR',
#  'Rogers {3}JR',
#  ' Hazel CLARKSR',
#  'Whittaker {3}FR',
#  'Clark {2}',
#  'Clark {3}SR',
#  ' Claire SEYMOURJR',
#  'Butler {3}SO',
#  ' Aneita DENTON',
#  'Barton {2}SR',
#  ' Sarah HENDRICKSR',
#  'Hendrick {2}SR',
#  'Goule {2}JR',
#  'Clark {4}',
#  'Wickus {2}JR',
#  ' Valery TOBIASSR',
#  'Maloney {3}SR',
#  ' Britton WILSONSO',
#  'Wilson {2}SO',
#  ' Hanna GREENSR',
#  ' Carley THOMASJR',
#  'Thomas {2}JR',
#  'Butler {4}SO']

# %%
CleanedNames.append("Laura ROESLERSR")
CleanedNames.append("Shea COLLINSWORTHJR")

# %%
CleanedNames2 = []

for i in range(0,len(OfficialReGexNames)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Athing MUFR',
#  'Roisin WILLISFR',
#  'Willis {2}FR',
#  'Juliette WHITTAKERFR',
#  'Michaela ROSESO',
#  'Whittaker {2}FR',
#  'Aaliyah MILLERSR',
#  'Jazmine FRAYSO',
#  'Nia AKINSSR',
#  'Nicole COOKSR',
#  'Rose {2}SO',
#  'Raevyn ROGERSSO',
#  'Mu {2}FR',
#  'Rose {3}SO',
#  'Rogers {2}JR',
#  'Laurie BARTONSR',
#  'Shafiqua MALONEYSR',
#  'Imogen BARRETTSR',
#  'Lindsey BUTLERJR',
#  'Butler {2}JR',
#  'Phoebe WRIGHTSR',
#  'Sabrina SOUTHERLANDSR',
#  'Natoya GOULESR',
#  'Amy WICKUS',
#  'Rose {4}SO',
#  'Maloney {2}SR',
#  'Rogers {3}JR',
#  'Hazel CLARKSR',
#  'Whittaker {3}FR',
#  'Clark {2}',
#  'Clark {3}SR',
#  'Claire SEYMOURJR',
#  'Butler {3}SO',
#  'Aneita DENTON',
#  'Barton {2}SR',
#  'Sarah HENDRICKSR',
#  'Hendrick {2}SR',
#  'Goule {2}JR',
#  'Clark {4}',
#  'Wickus {2}JR',
#  'Valery TOBIASSR',
#  'Maloney {3}SR',
#  'Britton WILSONSO',
#  'Wilson {2}SO',
#  'Hanna GREENSR',
#  'Carley THOMASJR',
#  'Thomas {2}JR',
#  'Butler {4}SO',
#  'Laura ROESLERSR',
#  'Shea COLLINSWORTHJR']

# %%
len(OfficialTimes)
# Out:
# 50

# %%
len(OfficialReGexNames)
# Out:
# 50

# %%
Schools = []

for i in range(0,len(OfficialTimes)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Texas A&M',
#  'Stanford',
#  'Stanford',
#  'Stanford',
#  'LSU',
#  'Stanford',
#  'Baylor',
#  'Texas A&M',
#  'Penn',
#  'Tennessee',
#  'LSU',
#  'Oregon',
#  'Texas A&M',
#  'LSU',
#  'Oregon',
#  'Clemson',
#  'Arkansas',
#  'Florida',
#  'Virginia Tech',
#  'Virginia Tech',
#  'Tennessee',
#  'Oregon',
#  'Clemson',
#  'Wisconsin',
#  'LSU',
#  'Arkansas',
#  'Oregon',
#  'Florida',
#  'Stanford',
#  'Florida',
#  'Florida',
#  'BYU',
#  'Virginia Tech',
#  'Arkansas',
#  'Clemson',
#  'Kennesaw State',
#  'Kennesaw State',
#  'LSU',
#  'Florida',
#  'Wisconsin',
#  'Texas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Virginia Tech',
#  'Washington',
#  'Washington',
#  'Virginia Tech',
#  'Oregon',
#  'BYU']

# %%
Times = []
for i in range(0,len(OfficialTimes)):
    Times.append(OfficialTimes[i][:7])
    
Times
# Out:
# ['1:58.40',
#  '1:59.93',
#  '1:59.95',
#  '2:00.05',
#  '2:00.18',
#  '2:00.32',
#  '2:00.69',
#  '2:00.69',
#  '2:00.71',
#  '2:00.75',
#  '2:00.85',
#  '2:00.90',
#  '2:01.07',
#  '2:01.09',
#  '2:01.09',
#  '2:01.21',
#  '2:01.22',
#  '2:01.23',
#  '2:01.23',
#  '2:01.37',
#  '2:01.47',
#  '2:01.55',
#  '2:01.64',
#  '2:01.65',
#  '2:01.66',
#  '2:01.74',
#  '2:01.75',
#  '2:01.77',
#  '2:01.82',
#  '2:01.84',
#  '2:01.84',
#  '2:01.96',
#  '2:01.96',
#  '2:01.96',
#  '2:01.99',
#  '2:02.00',
#  '2:02.00',
#  '2:02.00',
#  '2:02.01',
#  '2:02.05',
#  '2:02.07',
#  '2:02.10',
#  '2:02.13',
#  '2:02.13',
#  '2:02.13',
#  '2:02.15',
#  '2:02.15',
#  '2:02.15',
#  '2:01.32',
#  '2:01.42']

# %%
WomensIndoor800mDF = pd.DataFrame({'Names': CleanedNames2, 'Times': Times, 'Schools': Schools})
WomensIndoor800mDF.to_csv('WomensIndoor800m.csv', index=False)
