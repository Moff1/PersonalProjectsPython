# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
IndoorLongJumpMens = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?gender=1&sport=1&div=20527&top=25&event=23"

# %%
page = requests.get(IndoorLongJumpMens)
soup = BeautifulSoup(page.text,'html')
soup
table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(1) Miguel PATE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=12">Alabama</a></td><td style="width: 25%;">8.59m<a href="https://www.youtube.com/watch?v=w80Pxi7Oio0" target="_blank">📺</a>  28-2¼</td><td style="width: 10%;text-align:right;" title="USATF Indoor Championships (New York, N.Y.)"><span class="mark-date" style="width: 10%;text-align:right;">3/1/2002</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     7.81, 8.59, p, p, p, p</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(1) Miguel PATE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=12">Alabama</a></td><td style="width: 25%;">8.59m<a href="https://www.youtube.com/watch?v=w80Pxi7Oio0" target="_blank">📺</a>  28-2¼</td><td style="width: 10%;text-align:right;" title="USATF Indoor Championships (New York, N.Y.)"><span class="mark-date" style="width: 10%;text-align:right;">3/1/2002</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     7.81, 8.59, p, p, p, p</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(2) Carl LEWIS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=672">Houston</a></td><td style="width: 25%;">8.49m  27-10¼</td><td style="width: 10%;text-align:right;" title=" (Fort Worth, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/20/1981</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(2) Carl LEWIS</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=672">Houston</a></td><td style="width: 25%;">8.49m  27-10¼</td><td style="width: 10%;text-align:right;" title=" (Fort Worth, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/20/1981</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Lewis {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=672">Houston</a></td><td style="width: 25%;">8.48m  27-10</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Detroit, Mich.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/1981</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Lewis {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Houston" class="group-logo-inline" src="/images/logos/rankings-article/houston.png" title="Houston"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=672">Houston</a></td><td style="width: 25%;">8.48m  27-10</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Detroit, Mich.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/1981</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6551772" target="_blank">(3) Juvaughn HARRISON</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118018" target="_blank">8.45m</a>  27-8¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6551772" target="_blank">(3) Juvaughn HARRISON</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118018" target="_blank">8.45m</a>  27-8¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(4) Erick WALDER</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;">8.43m  27-8</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/1994</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(4) Erick WALDER</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;">8.43m  27-8</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/1994</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7487907" target="_blank">(5) Carey MCLEOD</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720951" target="_blank">8.40m</a>  27-6¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7487907" target="_blank">(5) Carey MCLEOD</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720951" target="_blank">8.40m</a>  27-6¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7023317" target="_blank">(6) Cameron CRUMP</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Mississippi State" class="group-logo-inline" src="/images/logos/rankings-article/mississippi-state.png" title="Mississippi State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=987">Mississippi State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720951" target="_blank">8.39m</a>  27-6½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7023317" target="_blank">(6) Cameron CRUMP</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Mississippi State" class="group-logo-inline" src="/images/logos/rankings-article/mississippi-state.png" title="Mississippi State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=987">Mississippi State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720951" target="_blank">8.39m</a>  27-6½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Crump {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Mississippi State" class="group-logo-inline" src="/images/logos/rankings-article/mississippi-state.png" title="Mississippi State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=987">Mississippi State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691812" target="_blank">8.39m</a>  27-6½</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Crump {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Mississippi State" class="group-logo-inline" src="/images/logos/rankings-article/mississippi-state.png" title="Mississippi State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=987">Mississippi State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691812" target="_blank">8.39m</a>  27-6½</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4189148" target="_blank">(6) Jarrion LAWSON</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/34001/2083812" target="_blank">8.39m</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 27-6½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;">3/14/2014</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     f, 7.68, f, f, 8.01, 8.39</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4189148" target="_blank">(6) Jarrion LAWSON</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/34001/2083812" target="_blank">8.39m</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 27-6½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;">3/14/2014</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     f, 7.68, f, f, 8.01, 8.39</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7524768" target="_blank">(8) Jeremiah DAVIS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720951" target="_blank">8.37m</a>  27-5½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7524768" target="_blank">(8) Jeremiah DAVIS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720951" target="_blank">8.37m</a>  27-5½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7524772" target="_blank">(9) Isaac GRIMES</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118018" target="_blank">8.35m</a>  27-4¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7524772" target="_blank">(9) Isaac GRIMES</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118018" target="_blank">8.35m</a>  27-4¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Pate {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=12">Alabama</a></td><td style="width: 25%;">8.35m  27-4¾</td><td style="width: 10%;text-align:right;" title=" (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">1/18/2002</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Pate {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=12">Alabama</a></td><td style="width: 25%;">8.35m  27-4¾</td><td style="width: 10%;text-align:right;" title=" (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">1/18/2002</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Pate {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=12">Alabama</a></td><td style="width: 25%;">8.34m  27-4½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/8/2002</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     8.24, 8.34, f, f, f, f</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Pate {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=12">Alabama</a></td><td style="width: 25%;">8.34m  27-4½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/8/2002</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     8.24, 8.34, f, f, f, f</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7697085" target="_blank">(10) Wayne PINNOCK</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720951" target="_blank">8.33m</a>  27-4</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7697085" target="_blank">(10) Wayne PINNOCK</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720951" target="_blank">8.33m</a>  27-4</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Harrison {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67216/4090209" target="_blank">8.33m</a>  27-4</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Harrison {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67216/4090209" target="_blank">8.33m</a>  27-4</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Grimes {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/66361/4069503" target="_blank">8.33m</a>  27-4</td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/12/2021</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     7.47, 8.04, f, f, 8.27, 8.33</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Grimes {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/66361/4069503" target="_blank">8.33m</a>  27-4</td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/12/2021</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     7.47, 8.04, f, f, 8.27, 8.33</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Walder {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;">8.33m  27-4</td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">2/5/1994</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Walder {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;">8.33m  27-4</td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">2/5/1994</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Walder {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;">8.33m  27-4</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/1993</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Walder {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;">8.33m  27-4</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/1993</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(10) Reggie KELLY</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Jackson State" class="group-logo-inline" src="/images/logos/rankings-article/jackson-state.png" title="Jackson State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=727">Jackson State</a></td><td style="width: 25%;">8.33m  27-4</td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">12/3/1983</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(10) Reggie KELLY</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Jackson State" class="group-logo-inline" src="/images/logos/rankings-article/jackson-state.png" title="Jackson State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=727">Jackson State</a></td><td style="width: 25%;">8.33m  27-4</td><td style="width: 10%;text-align:right;" title=" ()"><span class="mark-date" style="width: 10%;text-align:right;">12/3/1983</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Pinnock {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720951" target="_blank">8.32m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span><span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 27-3¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Pinnock {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720951" target="_blank">8.32m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span><span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 27-3¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Pinnock {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691812" target="_blank">8.31m</a>  27-3¼</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Pinnock {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691812" target="_blank">8.31m</a>  27-3¼</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Crump {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Mississippi State" class="group-logo-inline" src="/images/logos/rankings-article/mississippi-state.png" title="Mississippi State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=987">Mississippi State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720951" target="_blank">8.30m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span><span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 27-2¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Crump {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Mississippi State" class="group-logo-inline" src="/images/logos/rankings-article/mississippi-state.png" title="Mississippi State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=987">Mississippi State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720951" target="_blank">8.30m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span><span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 27-2¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(12) Bob BEAMON</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UTEP" class="group-logo-inline" src="/images/logos/rankings-article/utep.png" title="UTEP"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=1669">UTEP</a></td><td style="width: 25%;">8.30m  27-2¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Detroit, Mich.)"><span class="mark-date" style="width: 10%;text-align:right;">3/16/1968</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     then-world record</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(12) Bob BEAMON</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UTEP" class="group-logo-inline" src="/images/logos/rankings-article/utep.png" title="UTEP"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=1669">UTEP</a></td><td style="width: 25%;">8.30m  27-2¾</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Detroit, Mich.)"><span class="mark-date" style="width: 10%;text-align:right;">3/16/1968</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     then-world record</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Davis {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76080/4669679" target="_blank">8.28m</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 27-2</td><td style="width: 10%;text-align:right;" title="Don Kirby Collegiate Elite (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     8.28, p, p, p, p, p</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Davis {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76080/4669679" target="_blank">8.28m</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> 27-2</td><td style="width: 10%;text-align:right;" title="Don Kirby Collegiate Elite (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     8.28, p, p, p, p, p</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3756082" target="_blank">(13) Marquis DENDY</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/39148/2390373" target="_blank">8.28m</a>  27-2</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2015</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     f, 8.28, f, f, f, 8.27</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3756082" target="_blank">(13) Marquis DENDY</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/39148/2390373" target="_blank">8.28m</a>  27-2</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2015</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     f, 8.28, f, f, f, 8.27</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Dendy {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/29008" target="_blank">8.28m</a>  27-2</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/8/2013</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     f, f, 8.10, 8.23, 8.28, f</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Dendy {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/29008" target="_blank">8.28m</a>  27-2</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/8/2013</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     f, f, 8.10, 8.23, 8.28, f</td></tr>,
# ...
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Grimes {5}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118018" target="_blank">8.20m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 26-11</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(23) Roland MCGHEE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Middle Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/middle-tennessee.png" title="Middle Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=959">Middle Tennessee</a></td><td style="width: 25%;">8.20m  26-11</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/1993</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(23) Roland MCGHEE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Middle Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/middle-tennessee.png" title="Middle Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=959">Middle Tennessee</a></td><td style="width: 25%;">8.20m  26-11</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/1993</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — McLeod {5}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691812" target="_blank">8.19m</a>  26-10½</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — McLeod {5}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691812" target="_blank">8.19m</a>  26-10½</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — McLeod {6}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/65502/3983431" target="_blank">8.19m</a>  26-10½</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/28/2020</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — McLeod {6}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/65502/3983431" target="_blank">8.19m</a>  26-10½</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/28/2020</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5658829" target="_blank">(24) Will WILLIAMS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335572" target="_blank">8.19m</a>  26-10½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2018</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     7.98, 7.82, 7.93, 7.89, f, 8.19</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5658829" target="_blank">(24) Will WILLIAMS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335572" target="_blank">8.19m</a>  26-10½</td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2018</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     7.98, 7.82, 7.93, 7.89, f, 8.19</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Harrison {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67216/4090209" target="_blank">8.18m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 26-10</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Harrison {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67216/4090209" target="_blank">8.18m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 26-10</td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Grimes {6}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/66503/4053653" target="_blank">8.18m</a>  26-10</td><td style="width: 10%;text-align:right;" title="Bob Pollock Indoor Invitational (Clemson, S.C.)"><span class="mark-date" style="width: 10%;text-align:right;">1/29/2021</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     7.62, 7.86, 7.83, f, 8.18, 7.98</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Grimes {6}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida State" class="group-logo-inline" src="/images/logos/rankings-article/florida-state.png" title="Florida State"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=529">Florida State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/66503/4053653" target="_blank">8.18m</a>  26-10</td><td style="width: 10%;text-align:right;" title="Bob Pollock Indoor Invitational (Clemson, S.C.)"><span class="mark-date" style="width: 10%;text-align:right;">1/29/2021</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     7.62, 7.86, 7.83, f, 8.18, 7.98</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Crawford {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Rutgers" class="group-logo-inline" src="/images/logos/rankings-article/rutgers.png" title="Rutgers"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=1315">Rutgers</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/33046" target="_blank">8.18m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 26-10</td><td style="width: 10%;text-align:right;" title="The American Indoor Championships (New York, N.Y.)"><span class="mark-date" style="width: 10%;text-align:right;">3/1/2014</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Crawford {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Rutgers" class="group-logo-inline" src="/images/logos/rankings-article/rutgers.png" title="Rutgers"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=1315">Rutgers</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/33046" target="_blank">8.18m</a> <span class="tooltip" style="font-size: smaller;">+<span class="tooltiptext" style="font-size: smaller;">+ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round</span></span> 26-10</td><td style="width: 10%;text-align:right;" title="The American Indoor Championships (New York, N.Y.)"><span class="mark-date" style="width: 10%;text-align:right;">3/1/2014</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(25) Melvin LISTER</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;">8.18m  26-10</td><td style="width: 10%;text-align:right;" title=" (Joplin, Mo.)"><span class="mark-date" style="width: 10%;text-align:right;">2/5/2000</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(25) Melvin LISTER</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/collegiate-all-time-bests?sport=1&amp;top=25&amp;event=23&amp;team=59">Arkansas</a></td><td style="width: 25%;">8.18m  26-10</td><td style="width: 10%;text-align:right;" title=" (Joplin, Mo.)"><span class="mark-date" style="width: 10%;text-align:right;">2/5/2000</span></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows3 = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows3.append(row_data)

# %%
rows3
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Miguel PATEAlabama8.59m📺  28-2¼3/1/2002\xa0\xa0\xa0\xa0\xa07.81, 8.59, p, p, p, p',
#   '(1) Miguel PATE',
#   '',
#   'Alabama',
#   '8.59m📺  28-2¼',
#   '3/1/2002',
#   '\xa0\xa0\xa0\xa0\xa07.81, 8.59, p, p, p, p'],
#  [],
#  ['(1) Miguel PATE', '', 'Alabama', '8.59m📺  28-2¼', '3/1/2002'],
#  ['\xa0\xa0\xa0\xa0\xa07.81, 8.59, p, p, p, p'],
#  ['(2) Carl LEWISHouston8.49m  27-10¼2/20/1981',
#   '(2) Carl LEWIS',
#   '',
#   'Houston',
#   '8.49m  27-10¼',
#   '2/20/1981'],
#  [],
#  ['(2) Carl LEWIS', '', 'Houston', '8.49m  27-10¼', '2/20/1981'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston8.48m  27-103/13/1981',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '8.48m  27-10',
#   '3/13/1981'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}', '', 'Houston', '8.48m  27-10', '3/13/1981'],
#  ['(3) Juvaughn HARRISONSRLSU8.45m  27-8¾3/12/2021',
#   '(3) Juvaughn HARRISONSR',
#   '',
#   'LSU',
#   '8.45m  27-8¾',
#   '3/12/2021'],
#  [],
#  ['(3) Juvaughn HARRISONSR', '', 'LSU', '8.45m  27-8¾', '3/12/2021'],
#  ['(4) Erick WALDERSRArkansas8.43m  27-83/11/1994',
#   '(4) Erick WALDERSR',
#   '',
#   'Arkansas',
#   '8.43m  27-8',
#   '3/11/1994'],
#  [],
#  ['(4) Erick WALDERSR', '', 'Arkansas', '8.43m  27-8', '3/11/1994'],
#  ['(5) Carey MCLEODSRArkansas8.40m  27-6¾3/10/2023',
#   '(5) Carey MCLEODSR',
#   '',
#   'Arkansas',
#   '8.40m  27-6¾',
#   '3/10/2023'],
#  [],
#  ['(5) Carey MCLEODSR', '', 'Arkansas', '8.40m  27-6¾', '3/10/2023'],
#  ['(6) Cameron CRUMPSRMississippi State8.39m  27-6½3/10/2023',
#   '(6) Cameron CRUMPSR',
#   '',
#   'Mississippi State',
#   '8.39m  27-6½',
#   '3/10/2023'],
#  [],
#  ['(6) Cameron CRUMPSR', '', 'Mississippi State', '8.39m  27-6½', '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Crump {2}SRMississippi State8.39m  27-6½2/24/2023',
#   '\xa0\xa0\xa0\xa0— Crump {2}SR',
#   '',
#   'Mississippi State',
#   '8.39m  27-6½',
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Crump {2}SR',
#   '',
#   'Mississippi State',
#   '8.39m  27-6½',
#   '2/24/2023'],
#  ['(6) Jarrion LAWSONArkansas8.39m AA = Performance occurred at altitude (>1000 meters above sea level) 27-6½3/14/2014\xa0\xa0\xa0\xa0\xa0f, 7.68, f, f, 8.01, 8.39',
#   '(6) Jarrion LAWSON',
#   '',
#   'Arkansas',
#   '8.39m AA = Performance occurred at altitude (>1000 meters above sea level) 27-6½',
#   '3/14/2014',
#   '\xa0\xa0\xa0\xa0\xa0f, 7.68, f, f, 8.01, 8.39'],
#  [],
#  ['(6) Jarrion LAWSON',
#   '',
#   'Arkansas',
#   '8.39m AA = Performance occurred at altitude (>1000 meters above sea level) 27-6½',
#   '3/14/2014'],
#  ['\xa0\xa0\xa0\xa0\xa0f, 7.68, f, f, 8.01, 8.39'],
#  ['(8) Jeremiah DAVISJRFlorida State8.37m  27-5½3/10/2023',
#   '(8) Jeremiah DAVISJR',
#   '',
#   'Florida State',
#   '8.37m  27-5½',
#   '3/10/2023'],
#  [],
#  ['(8) Jeremiah DAVISJR', '', 'Florida State', '8.37m  27-5½', '3/10/2023'],
#  ['(9) Isaac GRIMESSRFlorida State8.35m  27-4¾3/12/2021',
#   '(9) Isaac GRIMESSR',
#   '',
#   'Florida State',
#   '8.35m  27-4¾',
#   '3/12/2021'],
#  [],
#  ['(9) Isaac GRIMESSR', '', 'Florida State', '8.35m  27-4¾', '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Pate {2}Alabama8.35m  27-4¾1/18/2002',
#   '\xa0\xa0\xa0\xa0— Pate {2}',
#   '',
#   'Alabama',
#   '8.35m  27-4¾',
#   '1/18/2002'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pate {2}', '', 'Alabama', '8.35m  27-4¾', '1/18/2002'],
#  ['\xa0\xa0\xa0\xa0— Pate {3}SRAlabama8.34m  27-4½3/8/2002\xa0\xa0\xa0\xa0\xa08.24, 8.34, f, f, f, f',
#   '\xa0\xa0\xa0\xa0— Pate {3}SR',
#   '',
#   'Alabama',
#   '8.34m  27-4½',
#   '3/8/2002',
#   '\xa0\xa0\xa0\xa0\xa08.24, 8.34, f, f, f, f'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pate {3}SR', '', 'Alabama', '8.34m  27-4½', '3/8/2002'],
#  ['\xa0\xa0\xa0\xa0\xa08.24, 8.34, f, f, f, f'],
#  ['(10) Wayne PINNOCKSOArkansas8.33m  27-43/10/2023',
#   '(10) Wayne PINNOCKSO',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '3/10/2023'],
#  [],
#  ['(10) Wayne PINNOCKSO', '', 'Arkansas', '8.33m  27-4', '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Harrison {2}SRLSU8.33m  27-42/25/2021',
#   '\xa0\xa0\xa0\xa0— Harrison {2}SR',
#   '',
#   'LSU',
#   '8.33m  27-4',
#   '2/25/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Harrison {2}SR', '', 'LSU', '8.33m  27-4', '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Grimes {2}SRFlorida State8.33m  27-42/12/2021\xa0\xa0\xa0\xa0\xa07.47, 8.04, f, f, 8.27, 8.33',
#   '\xa0\xa0\xa0\xa0— Grimes {2}SR',
#   '',
#   'Florida State',
#   '8.33m  27-4',
#   '2/12/2021',
#   '\xa0\xa0\xa0\xa0\xa07.47, 8.04, f, f, 8.27, 8.33'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Grimes {2}SR',
#   '',
#   'Florida State',
#   '8.33m  27-4',
#   '2/12/2021'],
#  ['\xa0\xa0\xa0\xa0\xa07.47, 8.04, f, f, 8.27, 8.33'],
#  ['\xa0\xa0\xa0\xa0— Walder {2}Arkansas8.33m  27-42/5/1994',
#   '\xa0\xa0\xa0\xa0— Walder {2}',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '2/5/1994'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Walder {2}', '', 'Arkansas', '8.33m  27-4', '2/5/1994'],
#  ['\xa0\xa0\xa0\xa0— Walder {3}JRArkansas8.33m  27-43/12/1993',
#   '\xa0\xa0\xa0\xa0— Walder {3}JR',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '3/12/1993'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Walder {3}JR',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '3/12/1993'],
#  ['(10) Reggie KELLYJackson State8.33m  27-412/3/1983',
#   '(10) Reggie KELLY',
#   '',
#   'Jackson State',
#   '8.33m  27-4',
#   '12/3/1983'],
#  [],
#  ['(10) Reggie KELLY', '', 'Jackson State', '8.33m  27-4', '12/3/1983'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {2}SOArkansas8.32m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-3¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {2}SO',
#   '',
#   'Arkansas',
#   "8.32m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-3¾",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pinnock {2}SO',
#   '',
#   'Arkansas',
#   "8.32m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-3¾",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Pinnock {3}SOArkansas8.31m  27-3¼2/24/2023',
#   '\xa0\xa0\xa0\xa0— Pinnock {3}SO',
#   '',
#   'Arkansas',
#   '8.31m  27-3¼',
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pinnock {3}SO',
#   '',
#   'Arkansas',
#   '8.31m  27-3¼',
#   '2/24/2023'],
#  ["\xa0\xa0\xa0\xa0— Crump {3}SRMississippi State8.30m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-2¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Crump {3}SR',
#   '',
#   'Mississippi State',
#   "8.30m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-2¾",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Crump {3}SR',
#   '',
#   'Mississippi State',
#   "8.30m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-2¾",
#   '3/10/2023'],
#  ['(12) Bob BEAMONSOUTEP8.30m  27-2¾3/16/1968\xa0\xa0\xa0\xa0\xa0then-world record',
#   '(12) Bob BEAMONSO',
#   '',
#   'UTEP',
#   '8.30m  27-2¾',
#   '3/16/1968',
#   '\xa0\xa0\xa0\xa0\xa0then-world record'],
#  [],
#  ['(12) Bob BEAMONSO', '', 'UTEP', '8.30m  27-2¾', '3/16/1968'],
#  ['\xa0\xa0\xa0\xa0\xa0then-world record'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}JRFlorida State8.28m AA = Performance occurred at altitude (>1000 meters above sea level) 27-22/10/2023\xa0\xa0\xa0\xa0\xa08.28, p, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Florida State',
#   '8.28m AA = Performance occurred at altitude (>1000 meters above sea level) 27-2',
#   '2/10/2023',
#   '\xa0\xa0\xa0\xa0\xa08.28, p, p, p, p, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Florida State',
#   '8.28m AA = Performance occurred at altitude (>1000 meters above sea level) 27-2',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0\xa08.28, p, p, p, p, p'],
#  ['(13) Marquis DENDYFlorida8.28m  27-23/13/2015\xa0\xa0\xa0\xa0\xa0f, 8.28, f, f, f, 8.27',
#   '(13) Marquis DENDY',
#   '',
#   'Florida',
#   '8.28m  27-2',
#   '3/13/2015',
#   '\xa0\xa0\xa0\xa0\xa0f, 8.28, f, f, f, 8.27'],
#  [],
#  ['(13) Marquis DENDY', '', 'Florida', '8.28m  27-2', '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0\xa0f, 8.28, f, f, f, 8.27'],
#  ['\xa0\xa0\xa0\xa0— Dendy {2}SOFlorida8.28m  27-23/8/2013\xa0\xa0\xa0\xa0\xa0f, f, 8.10, 8.23, 8.28, f',
#   '\xa0\xa0\xa0\xa0— Dendy {2}SO',
#   '',
#   'Florida',
#   '8.28m  27-2',
#   '3/8/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, f, 8.10, 8.23, 8.28, f'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Dendy {2}SO', '', 'Florida', '8.28m  27-2', '3/8/2013'],
#  ['\xa0\xa0\xa0\xa0\xa0f, f, 8.10, 8.23, 8.28, f'],
#  ['(13) Brian JOHNSONSRSouthern8.28m  27-23/14/2003\xa0\xa0\xa0\xa0\xa08.28, f, f, f, 8.15, 8.15',
#   '(13) Brian JOHNSONSR',
#   '',
#   'Southern',
#   '8.28m  27-2',
#   '3/14/2003',
#   '\xa0\xa0\xa0\xa0\xa08.28, f, f, f, 8.15, 8.15'],
#  [],
#  ['(13) Brian JOHNSONSR', '', 'Southern', '8.28m  27-2', '3/14/2003'],
#  ['\xa0\xa0\xa0\xa0\xa08.28, f, f, f, 8.15, 8.15'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {4}SOArkansas8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-1¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {4}SO',
#   '',
#   'Arkansas',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-1¾",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pinnock {4}SO',
#   '',
#   'Arkansas',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-1¾",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Grimes {3}SRFlorida State8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾2/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {3}SR',
#   '',
#   'Florida State',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '2/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Grimes {3}SR',
#   '',
#   'Florida State',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '2/12/2021'],
#  ["\xa0\xa0\xa0\xa0— Dendy {3}SRFlorida8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾3/13/2015",
#   '\xa0\xa0\xa0\xa0— Dendy {3}SR',
#   '',
#   'Florida',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '3/13/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Dendy {3}SR',
#   '',
#   'Florida',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Lawson {2}Arkansas8.27m  27-1¾3/13/2015\xa0\xa0\xa0\xa0\xa07.44, 7.93, 7.44, 7.72, 5.39, 8.27',
#   '\xa0\xa0\xa0\xa0— Lawson {2}',
#   '',
#   'Arkansas',
#   '8.27m  27-1¾',
#   '3/13/2015',
#   '\xa0\xa0\xa0\xa0\xa07.44, 7.93, 7.44, 7.72, 5.39, 8.27'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lawson {2}', '', 'Arkansas', '8.27m  27-1¾', '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0\xa07.44, 7.93, 7.44, 7.72, 5.39, 8.27'],
#  ['(15) John MOFFITTLSU8.27m  27-1¾2/14/2004',
#   '(15) John MOFFITT',
#   '',
#   'LSU',
#   '8.27m  27-1¾',
#   '2/14/2004'],
#  [],
#  ['(15) John MOFFITT', '', 'LSU', '8.27m  27-1¾', '2/14/2004'],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}JRTennessee8.26m  27-1¼3/12/2021',
#   '\xa0\xa0\xa0\xa0— McLeod {2}JR',
#   '',
#   'Tennessee',
#   '8.26m  27-1¼',
#   '3/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}JR',
#   '',
#   'Tennessee',
#   '8.26m  27-1¼',
#   '3/12/2021'],
#  ['(16) Charlton EHIZUELEN?Illinois8.26m  27-1¼3/7/1975',
#   '(16) Charlton EHIZUELEN?',
#   '',
#   'Illinois',
#   '8.26m  27-1¼',
#   '3/7/1975'],
#  [],
#  ['(16) Charlton EHIZUELEN?', '', 'Illinois', '8.26m  27-1¼', '3/7/1975'],
#  ['(17) Matthew BOLINGSOGeorgia8.25m  27-¾1/15/2022',
#   '(17) Matthew BOLINGSO',
#   '',
#   'Georgia',
#   '8.25m  27-¾',
#   '1/15/2022'],
#  [],
#  ['(17) Matthew BOLINGSO', '', 'Georgia', '8.25m  27-¾', '1/15/2022'],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}JRTennessee8.25m  27-¾2/25/2021',
#   '\xa0\xa0\xa0\xa0— McLeod {3}JR',
#   '',
#   'Tennessee',
#   '8.25m  27-¾',
#   '2/25/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}JR',
#   '',
#   'Tennessee',
#   '8.25m  27-¾',
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Dendy {4}Florida8.25m  27-¾2/23/2013\xa0\xa0\xa0\xa0\xa0f, 8.25, 8.22, p, 8.24, p',
#   '\xa0\xa0\xa0\xa0— Dendy {4}',
#   '',
#   'Florida',
#   '8.25m  27-¾',
#   '2/23/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, 8.25, 8.22, p, 8.24, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Dendy {4}', '', 'Florida', '8.25m  27-¾', '2/23/2013'],
#  ['\xa0\xa0\xa0\xa0\xa0f, 8.25, 8.22, p, 8.24, p'],
#  ['\xa0\xa0\xa0\xa0— Lewis {3}SOHouston8.25m ii = event moved indoors because of weather or another issue. 27-¾6/5/1981\xa0\xa0\xa0\xa0\xa0(event held indoors)',
#   '\xa0\xa0\xa0\xa0— Lewis {3}SO',
#   '',
#   'Houston',
#   '8.25m ii = event moved indoors because of weather or another issue. 27-¾',
#   '6/5/1981',
#   '\xa0\xa0\xa0\xa0\xa0(event held indoors)'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lewis {3}SO',
#   '',
#   'Houston',
#   '8.25m ii = event moved indoors because of weather or another issue. 27-¾',
#   '6/5/1981'],
#  ['\xa0\xa0\xa0\xa0\xa0(event held indoors)'],
#  ['\xa0\xa0\xa0\xa0— Beamon {2}SOUTEP8.25m  27-¾1/20/1968\xa0\xa0\xa0\xa0\xa0then-world record; 26-7½ (8.11), 27-1 (8.25), f, p, p, p ',
#   '\xa0\xa0\xa0\xa0— Beamon {2}SO',
#   '',
#   'UTEP',
#   '8.25m  27-¾',
#   '1/20/1968',
#   '\xa0\xa0\xa0\xa0\xa0then-world record; 26-7½ (8.11), 27-1 (8.25), f, p, p, p '],
#  [],
#  ['\xa0\xa0\xa0\xa0— Beamon {2}SO', '', 'UTEP', '8.25m  27-¾', '1/20/1968'],
#  ['\xa0\xa0\xa0\xa0\xa0then-world record; 26-7½ (8.11), 27-1 (8.25), f, p, p, p '],
#  ["\xa0\xa0\xa0\xa0— Dendy {5}Florida8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½2/23/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {5}',
#   '',
#   'Florida',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '2/23/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Dendy {5}',
#   '',
#   'Florida',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '2/23/2013'],
#  ["\xa0\xa0\xa0\xa0— Pate {4}SRAlabama8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½3/8/2002",
#   '\xa0\xa0\xa0\xa0— Pate {4}SR',
#   '',
#   'Alabama',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '3/8/2002'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pate {4}SR',
#   '',
#   'Alabama',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '3/8/2002'],
#  ['(18) Roland MCGHEEMiddle Tennessee8.24m  27-½1/30/1993',
#   '(18) Roland MCGHEE',
#   '',
#   'Middle Tennessee',
#   '8.24m  27-½',
#   '1/30/1993'],
#  [],
#  ['(18) Roland MCGHEE', '', 'Middle Tennessee', '8.24m  27-½', '1/30/1993'],
#  ["\xa0\xa0\xa0\xa0— Davis {3}JRFlorida State8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-03/10/2023",
#   '\xa0\xa0\xa0\xa0— Davis {3}JR',
#   '',
#   'Florida State',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-0",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {3}JR',
#   '',
#   'Florida State',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-0",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Dendy {6}SOFlorida8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-03/8/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {6}SO',
#   '',
#   'Florida',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-0",
#   '3/8/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Dendy {6}SO',
#   '',
#   'Florida',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-0",
#   '3/8/2013'],
#  ['(19) Savante STRINGFELLOWOle Miss8.23m  27-02/3/2001',
#   '(19) Savante STRINGFELLOW',
#   '',
#   'Ole Miss',
#   '8.23m  27-0',
#   '2/3/2001'],
#  [],
#  ['(19) Savante STRINGFELLOW', '', 'Ole Miss', '8.23m  27-0', '2/3/2001'],
#  ['(19) Leroy BURRELLSRHouston8.23m  27-03/9/1990',
#   '(19) Leroy BURRELLSR',
#   '',
#   'Houston',
#   '8.23m  27-0',
#   '3/9/1990'],
#  [],
#  ['(19) Leroy BURRELLSR', '', 'Houston', '8.23m  27-0', '3/9/1990'],
#  ["\xa0\xa0\xa0\xa0— McLeod {4}SRArkansas8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— McLeod {4}SR',
#   '',
#   'Arkansas',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¾",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLeod {4}SR',
#   '',
#   'Arkansas',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¾",
#   '3/10/2023'],
#  ['(21) Corey CRAWFORDRutgers8.22m  26-11¾3/1/2014\xa0\xa0\xa0\xa0\xa08.07, 7.69, f, 8.18, f, 8.22',
#   '(21) Corey CRAWFORD',
#   '',
#   'Rutgers',
#   '8.22m  26-11¾',
#   '3/1/2014',
#   '\xa0\xa0\xa0\xa0\xa08.07, 7.69, f, 8.18, f, 8.22'],
#  [],
#  ['(21) Corey CRAWFORD', '', 'Rutgers', '8.22m  26-11¾', '3/1/2014'],
#  ['\xa0\xa0\xa0\xa0\xa08.07, 7.69, f, 8.18, f, 8.22'],
#  ["\xa0\xa0\xa0\xa0— Dendy {7}Florida8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¾2/23/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {7}',
#   '',
#   'Florida',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¾",
#   '2/23/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Dendy {7}',
#   '',
#   'Florida',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¾",
#   '2/23/2013'],
#  ['\xa0\xa0\xa0\xa0— Pate {5}Alabama8.22m  26-11¾2/24/2002',
#   '\xa0\xa0\xa0\xa0— Pate {5}',
#   '',
#   'Alabama',
#   '8.22m  26-11¾',
#   '2/24/2002'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pate {5}', '', 'Alabama', '8.22m  26-11¾', '2/24/2002'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {5}SOArkansas8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¼3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {5}SO',
#   '',
#   'Arkansas',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¼",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pinnock {5}SO',
#   '',
#   'Arkansas',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¼",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Crump {4}SRMississippi State8.21m  26-11¼2/10/2023',
#   '\xa0\xa0\xa0\xa0— Crump {4}SR',
#   '',
#   'Mississippi State',
#   '8.21m  26-11¼',
#   '2/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Crump {4}SR',
#   '',
#   'Mississippi State',
#   '8.21m  26-11¼',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Davis {4}JRFlorida State8.21m  26-11¼1/27/2023\xa0\xa0\xa0\xa0\xa08.21, 8.04, 8.21, f, p, f',
#   '\xa0\xa0\xa0\xa0— Davis {4}JR',
#   '',
#   'Florida State',
#   '8.21m  26-11¼',
#   '1/27/2023',
#   '\xa0\xa0\xa0\xa0\xa08.21, 8.04, 8.21, f, p, f'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {4}JR',
#   '',
#   'Florida State',
#   '8.21m  26-11¼',
#   '1/27/2023'],
#  ['\xa0\xa0\xa0\xa0\xa08.21, 8.04, 8.21, f, p, f'],
#  ["\xa0\xa0\xa0\xa0— Grimes {4}SRFlorida State8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¼3/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {4}SR',
#   '',
#   'Florida State',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¼",
#   '3/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Grimes {4}SR',
#   '',
#   'Florida State',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¼",
#   '3/12/2021'],
#  ['(22) Damar FORBESSRLSU8.21m  26-11¼3/8/2013\xa0\xa0\xa0\xa0\xa0f, 7.92, 7.87, f, 8.21, 7.82',
#   '(22) Damar FORBESSR',
#   '',
#   'LSU',
#   '8.21m  26-11¼',
#   '3/8/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, 7.92, 7.87, f, 8.21, 7.82'],
#  [],
#  ['(22) Damar FORBESSR', '', 'LSU', '8.21m  26-11¼', '3/8/2013'],
#  ['\xa0\xa0\xa0\xa0\xa0f, 7.92, 7.87, f, 8.21, 7.82'],
#  ["\xa0\xa0\xa0\xa0— Grimes {5}SRFlorida State8.20m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-113/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {5}SR',
#   '',
#   'Florida State',
#   "8.20m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11",
#   '3/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Grimes {5}SR',
#   '',
#   'Florida State',
#   "8.20m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11",
#   '3/12/2021'],
#  ['(23) Roland MCGHEEMiddle Tennessee8.20m  26-113/12/1993',
#   '(23) Roland MCGHEE',
#   '',
#   'Middle Tennessee',
#   '8.20m  26-11',
#   '3/12/1993'],
#  [],
#  ['(23) Roland MCGHEE', '', 'Middle Tennessee', '8.20m  26-11', '3/12/1993'],
#  ['\xa0\xa0\xa0\xa0— McLeod {5}SRArkansas8.19m  26-10½2/24/2023',
#   '\xa0\xa0\xa0\xa0— McLeod {5}SR',
#   '',
#   'Arkansas',
#   '8.19m  26-10½',
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLeod {5}SR',
#   '',
#   'Arkansas',
#   '8.19m  26-10½',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— McLeod {6}SOTennessee8.19m  26-10½2/28/2020',
#   '\xa0\xa0\xa0\xa0— McLeod {6}SO',
#   '',
#   'Tennessee',
#   '8.19m  26-10½',
#   '2/28/2020'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLeod {6}SO',
#   '',
#   'Tennessee',
#   '8.19m  26-10½',
#   '2/28/2020'],
#  ['(24) Will WILLIAMSSRTexas A&M8.19m  26-10½3/9/2018\xa0\xa0\xa0\xa0\xa07.98, 7.82, 7.93, 7.89, f, 8.19',
#   '(24) Will WILLIAMSSR',
#   '',
#   'Texas A&M',
#   '8.19m  26-10½',
#   '3/9/2018',
#   '\xa0\xa0\xa0\xa0\xa07.98, 7.82, 7.93, 7.89, f, 8.19'],
#  [],
#  ['(24) Will WILLIAMSSR', '', 'Texas A&M', '8.19m  26-10½', '3/9/2018'],
#  ['\xa0\xa0\xa0\xa0\xa07.98, 7.82, 7.93, 7.89, f, 8.19'],
#  ["\xa0\xa0\xa0\xa0— Harrison {3}SRLSU8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-102/25/2021",
#   '\xa0\xa0\xa0\xa0— Harrison {3}SR',
#   '',
#   'LSU',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '2/25/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Harrison {3}SR',
#   '',
#   'LSU',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Grimes {6}SRFlorida State8.18m  26-101/29/2021\xa0\xa0\xa0\xa0\xa07.62, 7.86, 7.83, f, 8.18, 7.98',
#   '\xa0\xa0\xa0\xa0— Grimes {6}SR',
#   '',
#   'Florida State',
#   '8.18m  26-10',
#   '1/29/2021',
#   '\xa0\xa0\xa0\xa0\xa07.62, 7.86, 7.83, f, 8.18, 7.98'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Grimes {6}SR',
#   '',
#   'Florida State',
#   '8.18m  26-10',
#   '1/29/2021'],
#  ['\xa0\xa0\xa0\xa0\xa07.62, 7.86, 7.83, f, 8.18, 7.98'],
#  ["\xa0\xa0\xa0\xa0— Crawford {2}Rutgers8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-103/1/2014",
#   '\xa0\xa0\xa0\xa0— Crawford {2}',
#   '',
#   'Rutgers',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '3/1/2014'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Crawford {2}',
#   '',
#   'Rutgers',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '3/1/2014'],
#  ['(25) Melvin LISTERArkansas8.18m  26-102/5/2000',
#   '(25) Melvin LISTER',
#   '',
#   'Arkansas',
#   '8.18m  26-10',
#   '2/5/2000'],
#  [],
#  ['(25) Melvin LISTER', '', 'Arkansas', '8.18m  26-10', '2/5/2000'],
#  ['', '', '', '']]

# %%
len(rows3)
# Out:
# 213

# %%
RealRows3 = []

# %%
for i in range(0,213):
        RealRows3.append(rows3[i])

# %%
RealRows3
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Miguel PATEAlabama8.59m📺  28-2¼3/1/2002\xa0\xa0\xa0\xa0\xa07.81, 8.59, p, p, p, p',
#   '(1) Miguel PATE',
#   '',
#   'Alabama',
#   '8.59m📺  28-2¼',
#   '3/1/2002',
#   '\xa0\xa0\xa0\xa0\xa07.81, 8.59, p, p, p, p'],
#  [],
#  ['(1) Miguel PATE', '', 'Alabama', '8.59m📺  28-2¼', '3/1/2002'],
#  ['\xa0\xa0\xa0\xa0\xa07.81, 8.59, p, p, p, p'],
#  ['(2) Carl LEWISHouston8.49m  27-10¼2/20/1981',
#   '(2) Carl LEWIS',
#   '',
#   'Houston',
#   '8.49m  27-10¼',
#   '2/20/1981'],
#  [],
#  ['(2) Carl LEWIS', '', 'Houston', '8.49m  27-10¼', '2/20/1981'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston8.48m  27-103/13/1981',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '8.48m  27-10',
#   '3/13/1981'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}', '', 'Houston', '8.48m  27-10', '3/13/1981'],
#  ['(3) Juvaughn HARRISONSRLSU8.45m  27-8¾3/12/2021',
#   '(3) Juvaughn HARRISONSR',
#   '',
#   'LSU',
#   '8.45m  27-8¾',
#   '3/12/2021'],
#  [],
#  ['(3) Juvaughn HARRISONSR', '', 'LSU', '8.45m  27-8¾', '3/12/2021'],
#  ['(4) Erick WALDERSRArkansas8.43m  27-83/11/1994',
#   '(4) Erick WALDERSR',
#   '',
#   'Arkansas',
#   '8.43m  27-8',
#   '3/11/1994'],
#  [],
#  ['(4) Erick WALDERSR', '', 'Arkansas', '8.43m  27-8', '3/11/1994'],
#  ['(5) Carey MCLEODSRArkansas8.40m  27-6¾3/10/2023',
#   '(5) Carey MCLEODSR',
#   '',
#   'Arkansas',
#   '8.40m  27-6¾',
#   '3/10/2023'],
#  [],
#  ['(5) Carey MCLEODSR', '', 'Arkansas', '8.40m  27-6¾', '3/10/2023'],
#  ['(6) Cameron CRUMPSRMississippi State8.39m  27-6½3/10/2023',
#   '(6) Cameron CRUMPSR',
#   '',
#   'Mississippi State',
#   '8.39m  27-6½',
#   '3/10/2023'],
#  [],
#  ['(6) Cameron CRUMPSR', '', 'Mississippi State', '8.39m  27-6½', '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Crump {2}SRMississippi State8.39m  27-6½2/24/2023',
#   '\xa0\xa0\xa0\xa0— Crump {2}SR',
#   '',
#   'Mississippi State',
#   '8.39m  27-6½',
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Crump {2}SR',
#   '',
#   'Mississippi State',
#   '8.39m  27-6½',
#   '2/24/2023'],
#  ['(6) Jarrion LAWSONArkansas8.39m AA = Performance occurred at altitude (>1000 meters above sea level) 27-6½3/14/2014\xa0\xa0\xa0\xa0\xa0f, 7.68, f, f, 8.01, 8.39',
#   '(6) Jarrion LAWSON',
#   '',
#   'Arkansas',
#   '8.39m AA = Performance occurred at altitude (>1000 meters above sea level) 27-6½',
#   '3/14/2014',
#   '\xa0\xa0\xa0\xa0\xa0f, 7.68, f, f, 8.01, 8.39'],
#  [],
#  ['(6) Jarrion LAWSON',
#   '',
#   'Arkansas',
#   '8.39m AA = Performance occurred at altitude (>1000 meters above sea level) 27-6½',
#   '3/14/2014'],
#  ['\xa0\xa0\xa0\xa0\xa0f, 7.68, f, f, 8.01, 8.39'],
#  ['(8) Jeremiah DAVISJRFlorida State8.37m  27-5½3/10/2023',
#   '(8) Jeremiah DAVISJR',
#   '',
#   'Florida State',
#   '8.37m  27-5½',
#   '3/10/2023'],
#  [],
#  ['(8) Jeremiah DAVISJR', '', 'Florida State', '8.37m  27-5½', '3/10/2023'],
#  ['(9) Isaac GRIMESSRFlorida State8.35m  27-4¾3/12/2021',
#   '(9) Isaac GRIMESSR',
#   '',
#   'Florida State',
#   '8.35m  27-4¾',
#   '3/12/2021'],
#  [],
#  ['(9) Isaac GRIMESSR', '', 'Florida State', '8.35m  27-4¾', '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Pate {2}Alabama8.35m  27-4¾1/18/2002',
#   '\xa0\xa0\xa0\xa0— Pate {2}',
#   '',
#   'Alabama',
#   '8.35m  27-4¾',
#   '1/18/2002'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pate {2}', '', 'Alabama', '8.35m  27-4¾', '1/18/2002'],
#  ['\xa0\xa0\xa0\xa0— Pate {3}SRAlabama8.34m  27-4½3/8/2002\xa0\xa0\xa0\xa0\xa08.24, 8.34, f, f, f, f',
#   '\xa0\xa0\xa0\xa0— Pate {3}SR',
#   '',
#   'Alabama',
#   '8.34m  27-4½',
#   '3/8/2002',
#   '\xa0\xa0\xa0\xa0\xa08.24, 8.34, f, f, f, f'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pate {3}SR', '', 'Alabama', '8.34m  27-4½', '3/8/2002'],
#  ['\xa0\xa0\xa0\xa0\xa08.24, 8.34, f, f, f, f'],
#  ['(10) Wayne PINNOCKSOArkansas8.33m  27-43/10/2023',
#   '(10) Wayne PINNOCKSO',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '3/10/2023'],
#  [],
#  ['(10) Wayne PINNOCKSO', '', 'Arkansas', '8.33m  27-4', '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Harrison {2}SRLSU8.33m  27-42/25/2021',
#   '\xa0\xa0\xa0\xa0— Harrison {2}SR',
#   '',
#   'LSU',
#   '8.33m  27-4',
#   '2/25/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Harrison {2}SR', '', 'LSU', '8.33m  27-4', '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Grimes {2}SRFlorida State8.33m  27-42/12/2021\xa0\xa0\xa0\xa0\xa07.47, 8.04, f, f, 8.27, 8.33',
#   '\xa0\xa0\xa0\xa0— Grimes {2}SR',
#   '',
#   'Florida State',
#   '8.33m  27-4',
#   '2/12/2021',
#   '\xa0\xa0\xa0\xa0\xa07.47, 8.04, f, f, 8.27, 8.33'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Grimes {2}SR',
#   '',
#   'Florida State',
#   '8.33m  27-4',
#   '2/12/2021'],
#  ['\xa0\xa0\xa0\xa0\xa07.47, 8.04, f, f, 8.27, 8.33'],
#  ['\xa0\xa0\xa0\xa0— Walder {2}Arkansas8.33m  27-42/5/1994',
#   '\xa0\xa0\xa0\xa0— Walder {2}',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '2/5/1994'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Walder {2}', '', 'Arkansas', '8.33m  27-4', '2/5/1994'],
#  ['\xa0\xa0\xa0\xa0— Walder {3}JRArkansas8.33m  27-43/12/1993',
#   '\xa0\xa0\xa0\xa0— Walder {3}JR',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '3/12/1993'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Walder {3}JR',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '3/12/1993'],
#  ['(10) Reggie KELLYJackson State8.33m  27-412/3/1983',
#   '(10) Reggie KELLY',
#   '',
#   'Jackson State',
#   '8.33m  27-4',
#   '12/3/1983'],
#  [],
#  ['(10) Reggie KELLY', '', 'Jackson State', '8.33m  27-4', '12/3/1983'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {2}SOArkansas8.32m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-3¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {2}SO',
#   '',
#   'Arkansas',
#   "8.32m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-3¾",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pinnock {2}SO',
#   '',
#   'Arkansas',
#   "8.32m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-3¾",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Pinnock {3}SOArkansas8.31m  27-3¼2/24/2023',
#   '\xa0\xa0\xa0\xa0— Pinnock {3}SO',
#   '',
#   'Arkansas',
#   '8.31m  27-3¼',
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pinnock {3}SO',
#   '',
#   'Arkansas',
#   '8.31m  27-3¼',
#   '2/24/2023'],
#  ["\xa0\xa0\xa0\xa0— Crump {3}SRMississippi State8.30m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-2¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Crump {3}SR',
#   '',
#   'Mississippi State',
#   "8.30m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-2¾",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Crump {3}SR',
#   '',
#   'Mississippi State',
#   "8.30m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-2¾",
#   '3/10/2023'],
#  ['(12) Bob BEAMONSOUTEP8.30m  27-2¾3/16/1968\xa0\xa0\xa0\xa0\xa0then-world record',
#   '(12) Bob BEAMONSO',
#   '',
#   'UTEP',
#   '8.30m  27-2¾',
#   '3/16/1968',
#   '\xa0\xa0\xa0\xa0\xa0then-world record'],
#  [],
#  ['(12) Bob BEAMONSO', '', 'UTEP', '8.30m  27-2¾', '3/16/1968'],
#  ['\xa0\xa0\xa0\xa0\xa0then-world record'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}JRFlorida State8.28m AA = Performance occurred at altitude (>1000 meters above sea level) 27-22/10/2023\xa0\xa0\xa0\xa0\xa08.28, p, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Florida State',
#   '8.28m AA = Performance occurred at altitude (>1000 meters above sea level) 27-2',
#   '2/10/2023',
#   '\xa0\xa0\xa0\xa0\xa08.28, p, p, p, p, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Florida State',
#   '8.28m AA = Performance occurred at altitude (>1000 meters above sea level) 27-2',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0\xa08.28, p, p, p, p, p'],
#  ['(13) Marquis DENDYFlorida8.28m  27-23/13/2015\xa0\xa0\xa0\xa0\xa0f, 8.28, f, f, f, 8.27',
#   '(13) Marquis DENDY',
#   '',
#   'Florida',
#   '8.28m  27-2',
#   '3/13/2015',
#   '\xa0\xa0\xa0\xa0\xa0f, 8.28, f, f, f, 8.27'],
#  [],
#  ['(13) Marquis DENDY', '', 'Florida', '8.28m  27-2', '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0\xa0f, 8.28, f, f, f, 8.27'],
#  ['\xa0\xa0\xa0\xa0— Dendy {2}SOFlorida8.28m  27-23/8/2013\xa0\xa0\xa0\xa0\xa0f, f, 8.10, 8.23, 8.28, f',
#   '\xa0\xa0\xa0\xa0— Dendy {2}SO',
#   '',
#   'Florida',
#   '8.28m  27-2',
#   '3/8/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, f, 8.10, 8.23, 8.28, f'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Dendy {2}SO', '', 'Florida', '8.28m  27-2', '3/8/2013'],
#  ['\xa0\xa0\xa0\xa0\xa0f, f, 8.10, 8.23, 8.28, f'],
#  ['(13) Brian JOHNSONSRSouthern8.28m  27-23/14/2003\xa0\xa0\xa0\xa0\xa08.28, f, f, f, 8.15, 8.15',
#   '(13) Brian JOHNSONSR',
#   '',
#   'Southern',
#   '8.28m  27-2',
#   '3/14/2003',
#   '\xa0\xa0\xa0\xa0\xa08.28, f, f, f, 8.15, 8.15'],
#  [],
#  ['(13) Brian JOHNSONSR', '', 'Southern', '8.28m  27-2', '3/14/2003'],
#  ['\xa0\xa0\xa0\xa0\xa08.28, f, f, f, 8.15, 8.15'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {4}SOArkansas8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-1¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {4}SO',
#   '',
#   'Arkansas',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-1¾",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pinnock {4}SO',
#   '',
#   'Arkansas',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-1¾",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Grimes {3}SRFlorida State8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾2/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {3}SR',
#   '',
#   'Florida State',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '2/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Grimes {3}SR',
#   '',
#   'Florida State',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '2/12/2021'],
#  ["\xa0\xa0\xa0\xa0— Dendy {3}SRFlorida8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾3/13/2015",
#   '\xa0\xa0\xa0\xa0— Dendy {3}SR',
#   '',
#   'Florida',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '3/13/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Dendy {3}SR',
#   '',
#   'Florida',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Lawson {2}Arkansas8.27m  27-1¾3/13/2015\xa0\xa0\xa0\xa0\xa07.44, 7.93, 7.44, 7.72, 5.39, 8.27',
#   '\xa0\xa0\xa0\xa0— Lawson {2}',
#   '',
#   'Arkansas',
#   '8.27m  27-1¾',
#   '3/13/2015',
#   '\xa0\xa0\xa0\xa0\xa07.44, 7.93, 7.44, 7.72, 5.39, 8.27'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lawson {2}', '', 'Arkansas', '8.27m  27-1¾', '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0\xa07.44, 7.93, 7.44, 7.72, 5.39, 8.27'],
#  ['(15) John MOFFITTLSU8.27m  27-1¾2/14/2004',
#   '(15) John MOFFITT',
#   '',
#   'LSU',
#   '8.27m  27-1¾',
#   '2/14/2004'],
#  [],
#  ['(15) John MOFFITT', '', 'LSU', '8.27m  27-1¾', '2/14/2004'],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}JRTennessee8.26m  27-1¼3/12/2021',
#   '\xa0\xa0\xa0\xa0— McLeod {2}JR',
#   '',
#   'Tennessee',
#   '8.26m  27-1¼',
#   '3/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}JR',
#   '',
#   'Tennessee',
#   '8.26m  27-1¼',
#   '3/12/2021'],
#  ['(16) Charlton EHIZUELEN?Illinois8.26m  27-1¼3/7/1975',
#   '(16) Charlton EHIZUELEN?',
#   '',
#   'Illinois',
#   '8.26m  27-1¼',
#   '3/7/1975'],
#  [],
#  ['(16) Charlton EHIZUELEN?', '', 'Illinois', '8.26m  27-1¼', '3/7/1975'],
#  ['(17) Matthew BOLINGSOGeorgia8.25m  27-¾1/15/2022',
#   '(17) Matthew BOLINGSO',
#   '',
#   'Georgia',
#   '8.25m  27-¾',
#   '1/15/2022'],
#  [],
#  ['(17) Matthew BOLINGSO', '', 'Georgia', '8.25m  27-¾', '1/15/2022'],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}JRTennessee8.25m  27-¾2/25/2021',
#   '\xa0\xa0\xa0\xa0— McLeod {3}JR',
#   '',
#   'Tennessee',
#   '8.25m  27-¾',
#   '2/25/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}JR',
#   '',
#   'Tennessee',
#   '8.25m  27-¾',
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Dendy {4}Florida8.25m  27-¾2/23/2013\xa0\xa0\xa0\xa0\xa0f, 8.25, 8.22, p, 8.24, p',
#   '\xa0\xa0\xa0\xa0— Dendy {4}',
#   '',
#   'Florida',
#   '8.25m  27-¾',
#   '2/23/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, 8.25, 8.22, p, 8.24, p'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Dendy {4}', '', 'Florida', '8.25m  27-¾', '2/23/2013'],
#  ['\xa0\xa0\xa0\xa0\xa0f, 8.25, 8.22, p, 8.24, p'],
#  ['\xa0\xa0\xa0\xa0— Lewis {3}SOHouston8.25m ii = event moved indoors because of weather or another issue. 27-¾6/5/1981\xa0\xa0\xa0\xa0\xa0(event held indoors)',
#   '\xa0\xa0\xa0\xa0— Lewis {3}SO',
#   '',
#   'Houston',
#   '8.25m ii = event moved indoors because of weather or another issue. 27-¾',
#   '6/5/1981',
#   '\xa0\xa0\xa0\xa0\xa0(event held indoors)'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Lewis {3}SO',
#   '',
#   'Houston',
#   '8.25m ii = event moved indoors because of weather or another issue. 27-¾',
#   '6/5/1981'],
#  ['\xa0\xa0\xa0\xa0\xa0(event held indoors)'],
#  ['\xa0\xa0\xa0\xa0— Beamon {2}SOUTEP8.25m  27-¾1/20/1968\xa0\xa0\xa0\xa0\xa0then-world record; 26-7½ (8.11), 27-1 (8.25), f, p, p, p ',
#   '\xa0\xa0\xa0\xa0— Beamon {2}SO',
#   '',
#   'UTEP',
#   '8.25m  27-¾',
#   '1/20/1968',
#   '\xa0\xa0\xa0\xa0\xa0then-world record; 26-7½ (8.11), 27-1 (8.25), f, p, p, p '],
#  [],
#  ['\xa0\xa0\xa0\xa0— Beamon {2}SO', '', 'UTEP', '8.25m  27-¾', '1/20/1968'],
#  ['\xa0\xa0\xa0\xa0\xa0then-world record; 26-7½ (8.11), 27-1 (8.25), f, p, p, p '],
#  ["\xa0\xa0\xa0\xa0— Dendy {5}Florida8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½2/23/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {5}',
#   '',
#   'Florida',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '2/23/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Dendy {5}',
#   '',
#   'Florida',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '2/23/2013'],
#  ["\xa0\xa0\xa0\xa0— Pate {4}SRAlabama8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½3/8/2002",
#   '\xa0\xa0\xa0\xa0— Pate {4}SR',
#   '',
#   'Alabama',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '3/8/2002'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pate {4}SR',
#   '',
#   'Alabama',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '3/8/2002'],
#  ['(18) Roland MCGHEEMiddle Tennessee8.24m  27-½1/30/1993',
#   '(18) Roland MCGHEE',
#   '',
#   'Middle Tennessee',
#   '8.24m  27-½',
#   '1/30/1993'],
#  [],
#  ['(18) Roland MCGHEE', '', 'Middle Tennessee', '8.24m  27-½', '1/30/1993'],
#  ["\xa0\xa0\xa0\xa0— Davis {3}JRFlorida State8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-03/10/2023",
#   '\xa0\xa0\xa0\xa0— Davis {3}JR',
#   '',
#   'Florida State',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-0",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {3}JR',
#   '',
#   'Florida State',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-0",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Dendy {6}SOFlorida8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-03/8/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {6}SO',
#   '',
#   'Florida',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-0",
#   '3/8/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Dendy {6}SO',
#   '',
#   'Florida',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-0",
#   '3/8/2013'],
#  ['(19) Savante STRINGFELLOWOle Miss8.23m  27-02/3/2001',
#   '(19) Savante STRINGFELLOW',
#   '',
#   'Ole Miss',
#   '8.23m  27-0',
#   '2/3/2001'],
#  [],
#  ['(19) Savante STRINGFELLOW', '', 'Ole Miss', '8.23m  27-0', '2/3/2001'],
#  ['(19) Leroy BURRELLSRHouston8.23m  27-03/9/1990',
#   '(19) Leroy BURRELLSR',
#   '',
#   'Houston',
#   '8.23m  27-0',
#   '3/9/1990'],
#  [],
#  ['(19) Leroy BURRELLSR', '', 'Houston', '8.23m  27-0', '3/9/1990'],
#  ["\xa0\xa0\xa0\xa0— McLeod {4}SRArkansas8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— McLeod {4}SR',
#   '',
#   'Arkansas',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¾",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLeod {4}SR',
#   '',
#   'Arkansas',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¾",
#   '3/10/2023'],
#  ['(21) Corey CRAWFORDRutgers8.22m  26-11¾3/1/2014\xa0\xa0\xa0\xa0\xa08.07, 7.69, f, 8.18, f, 8.22',
#   '(21) Corey CRAWFORD',
#   '',
#   'Rutgers',
#   '8.22m  26-11¾',
#   '3/1/2014',
#   '\xa0\xa0\xa0\xa0\xa08.07, 7.69, f, 8.18, f, 8.22'],
#  [],
#  ['(21) Corey CRAWFORD', '', 'Rutgers', '8.22m  26-11¾', '3/1/2014'],
#  ['\xa0\xa0\xa0\xa0\xa08.07, 7.69, f, 8.18, f, 8.22'],
#  ["\xa0\xa0\xa0\xa0— Dendy {7}Florida8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¾2/23/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {7}',
#   '',
#   'Florida',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¾",
#   '2/23/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Dendy {7}',
#   '',
#   'Florida',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¾",
#   '2/23/2013'],
#  ['\xa0\xa0\xa0\xa0— Pate {5}Alabama8.22m  26-11¾2/24/2002',
#   '\xa0\xa0\xa0\xa0— Pate {5}',
#   '',
#   'Alabama',
#   '8.22m  26-11¾',
#   '2/24/2002'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pate {5}', '', 'Alabama', '8.22m  26-11¾', '2/24/2002'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {5}SOArkansas8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¼3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {5}SO',
#   '',
#   'Arkansas',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¼",
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Pinnock {5}SO',
#   '',
#   'Arkansas',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¼",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Crump {4}SRMississippi State8.21m  26-11¼2/10/2023',
#   '\xa0\xa0\xa0\xa0— Crump {4}SR',
#   '',
#   'Mississippi State',
#   '8.21m  26-11¼',
#   '2/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Crump {4}SR',
#   '',
#   'Mississippi State',
#   '8.21m  26-11¼',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Davis {4}JRFlorida State8.21m  26-11¼1/27/2023\xa0\xa0\xa0\xa0\xa08.21, 8.04, 8.21, f, p, f',
#   '\xa0\xa0\xa0\xa0— Davis {4}JR',
#   '',
#   'Florida State',
#   '8.21m  26-11¼',
#   '1/27/2023',
#   '\xa0\xa0\xa0\xa0\xa08.21, 8.04, 8.21, f, p, f'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Davis {4}JR',
#   '',
#   'Florida State',
#   '8.21m  26-11¼',
#   '1/27/2023'],
#  ['\xa0\xa0\xa0\xa0\xa08.21, 8.04, 8.21, f, p, f'],
#  ["\xa0\xa0\xa0\xa0— Grimes {4}SRFlorida State8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¼3/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {4}SR',
#   '',
#   'Florida State',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¼",
#   '3/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Grimes {4}SR',
#   '',
#   'Florida State',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¼",
#   '3/12/2021'],
#  ['(22) Damar FORBESSRLSU8.21m  26-11¼3/8/2013\xa0\xa0\xa0\xa0\xa0f, 7.92, 7.87, f, 8.21, 7.82',
#   '(22) Damar FORBESSR',
#   '',
#   'LSU',
#   '8.21m  26-11¼',
#   '3/8/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, 7.92, 7.87, f, 8.21, 7.82'],
#  [],
#  ['(22) Damar FORBESSR', '', 'LSU', '8.21m  26-11¼', '3/8/2013'],
#  ['\xa0\xa0\xa0\xa0\xa0f, 7.92, 7.87, f, 8.21, 7.82'],
#  ["\xa0\xa0\xa0\xa0— Grimes {5}SRFlorida State8.20m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-113/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {5}SR',
#   '',
#   'Florida State',
#   "8.20m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11",
#   '3/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Grimes {5}SR',
#   '',
#   'Florida State',
#   "8.20m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11",
#   '3/12/2021'],
#  ['(23) Roland MCGHEEMiddle Tennessee8.20m  26-113/12/1993',
#   '(23) Roland MCGHEE',
#   '',
#   'Middle Tennessee',
#   '8.20m  26-11',
#   '3/12/1993'],
#  [],
#  ['(23) Roland MCGHEE', '', 'Middle Tennessee', '8.20m  26-11', '3/12/1993'],
#  ['\xa0\xa0\xa0\xa0— McLeod {5}SRArkansas8.19m  26-10½2/24/2023',
#   '\xa0\xa0\xa0\xa0— McLeod {5}SR',
#   '',
#   'Arkansas',
#   '8.19m  26-10½',
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLeod {5}SR',
#   '',
#   'Arkansas',
#   '8.19m  26-10½',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— McLeod {6}SOTennessee8.19m  26-10½2/28/2020',
#   '\xa0\xa0\xa0\xa0— McLeod {6}SO',
#   '',
#   'Tennessee',
#   '8.19m  26-10½',
#   '2/28/2020'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLeod {6}SO',
#   '',
#   'Tennessee',
#   '8.19m  26-10½',
#   '2/28/2020'],
#  ['(24) Will WILLIAMSSRTexas A&M8.19m  26-10½3/9/2018\xa0\xa0\xa0\xa0\xa07.98, 7.82, 7.93, 7.89, f, 8.19',
#   '(24) Will WILLIAMSSR',
#   '',
#   'Texas A&M',
#   '8.19m  26-10½',
#   '3/9/2018',
#   '\xa0\xa0\xa0\xa0\xa07.98, 7.82, 7.93, 7.89, f, 8.19'],
#  [],
#  ['(24) Will WILLIAMSSR', '', 'Texas A&M', '8.19m  26-10½', '3/9/2018'],
#  ['\xa0\xa0\xa0\xa0\xa07.98, 7.82, 7.93, 7.89, f, 8.19'],
#  ["\xa0\xa0\xa0\xa0— Harrison {3}SRLSU8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-102/25/2021",
#   '\xa0\xa0\xa0\xa0— Harrison {3}SR',
#   '',
#   'LSU',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '2/25/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Harrison {3}SR',
#   '',
#   'LSU',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Grimes {6}SRFlorida State8.18m  26-101/29/2021\xa0\xa0\xa0\xa0\xa07.62, 7.86, 7.83, f, 8.18, 7.98',
#   '\xa0\xa0\xa0\xa0— Grimes {6}SR',
#   '',
#   'Florida State',
#   '8.18m  26-10',
#   '1/29/2021',
#   '\xa0\xa0\xa0\xa0\xa07.62, 7.86, 7.83, f, 8.18, 7.98'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Grimes {6}SR',
#   '',
#   'Florida State',
#   '8.18m  26-10',
#   '1/29/2021'],
#  ['\xa0\xa0\xa0\xa0\xa07.62, 7.86, 7.83, f, 8.18, 7.98'],
#  ["\xa0\xa0\xa0\xa0— Crawford {2}Rutgers8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-103/1/2014",
#   '\xa0\xa0\xa0\xa0— Crawford {2}',
#   '',
#   'Rutgers',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '3/1/2014'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Crawford {2}',
#   '',
#   'Rutgers',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '3/1/2014'],
#  ['(25) Melvin LISTERArkansas8.18m  26-102/5/2000',
#   '(25) Melvin LISTER',
#   '',
#   'Arkansas',
#   '8.18m  26-10',
#   '2/5/2000'],
#  [],
#  ['(25) Melvin LISTER', '', 'Arkansas', '8.18m  26-10', '2/5/2000'],
#  ['', '', '', '']]

# %%
RealRows = []

# %%
for i in range(0,213):
    if len(RealRows3[i]) > 1:
        RealRows.append(RealRows3[i])

# %%
RealRows
# Out:
# [['(1) Miguel PATEAlabama8.59m📺  28-2¼3/1/2002\xa0\xa0\xa0\xa0\xa07.81, 8.59, p, p, p, p',
#   '(1) Miguel PATE',
#   '',
#   'Alabama',
#   '8.59m📺  28-2¼',
#   '3/1/2002',
#   '\xa0\xa0\xa0\xa0\xa07.81, 8.59, p, p, p, p'],
#  ['(1) Miguel PATE', '', 'Alabama', '8.59m📺  28-2¼', '3/1/2002'],
#  ['(2) Carl LEWISHouston8.49m  27-10¼2/20/1981',
#   '(2) Carl LEWIS',
#   '',
#   'Houston',
#   '8.49m  27-10¼',
#   '2/20/1981'],
#  ['(2) Carl LEWIS', '', 'Houston', '8.49m  27-10¼', '2/20/1981'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston8.48m  27-103/13/1981',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '8.48m  27-10',
#   '3/13/1981'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}', '', 'Houston', '8.48m  27-10', '3/13/1981'],
#  ['(3) Juvaughn HARRISONSRLSU8.45m  27-8¾3/12/2021',
#   '(3) Juvaughn HARRISONSR',
#   '',
#   'LSU',
#   '8.45m  27-8¾',
#   '3/12/2021'],
#  ['(3) Juvaughn HARRISONSR', '', 'LSU', '8.45m  27-8¾', '3/12/2021'],
#  ['(4) Erick WALDERSRArkansas8.43m  27-83/11/1994',
#   '(4) Erick WALDERSR',
#   '',
#   'Arkansas',
#   '8.43m  27-8',
#   '3/11/1994'],
#  ['(4) Erick WALDERSR', '', 'Arkansas', '8.43m  27-8', '3/11/1994'],
#  ['(5) Carey MCLEODSRArkansas8.40m  27-6¾3/10/2023',
#   '(5) Carey MCLEODSR',
#   '',
#   'Arkansas',
#   '8.40m  27-6¾',
#   '3/10/2023'],
#  ['(5) Carey MCLEODSR', '', 'Arkansas', '8.40m  27-6¾', '3/10/2023'],
#  ['(6) Cameron CRUMPSRMississippi State8.39m  27-6½3/10/2023',
#   '(6) Cameron CRUMPSR',
#   '',
#   'Mississippi State',
#   '8.39m  27-6½',
#   '3/10/2023'],
#  ['(6) Cameron CRUMPSR', '', 'Mississippi State', '8.39m  27-6½', '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Crump {2}SRMississippi State8.39m  27-6½2/24/2023',
#   '\xa0\xa0\xa0\xa0— Crump {2}SR',
#   '',
#   'Mississippi State',
#   '8.39m  27-6½',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Crump {2}SR',
#   '',
#   'Mississippi State',
#   '8.39m  27-6½',
#   '2/24/2023'],
#  ['(6) Jarrion LAWSONArkansas8.39m AA = Performance occurred at altitude (>1000 meters above sea level) 27-6½3/14/2014\xa0\xa0\xa0\xa0\xa0f, 7.68, f, f, 8.01, 8.39',
#   '(6) Jarrion LAWSON',
#   '',
#   'Arkansas',
#   '8.39m AA = Performance occurred at altitude (>1000 meters above sea level) 27-6½',
#   '3/14/2014',
#   '\xa0\xa0\xa0\xa0\xa0f, 7.68, f, f, 8.01, 8.39'],
#  ['(6) Jarrion LAWSON',
#   '',
#   'Arkansas',
#   '8.39m AA = Performance occurred at altitude (>1000 meters above sea level) 27-6½',
#   '3/14/2014'],
#  ['(8) Jeremiah DAVISJRFlorida State8.37m  27-5½3/10/2023',
#   '(8) Jeremiah DAVISJR',
#   '',
#   'Florida State',
#   '8.37m  27-5½',
#   '3/10/2023'],
#  ['(8) Jeremiah DAVISJR', '', 'Florida State', '8.37m  27-5½', '3/10/2023'],
#  ['(9) Isaac GRIMESSRFlorida State8.35m  27-4¾3/12/2021',
#   '(9) Isaac GRIMESSR',
#   '',
#   'Florida State',
#   '8.35m  27-4¾',
#   '3/12/2021'],
#  ['(9) Isaac GRIMESSR', '', 'Florida State', '8.35m  27-4¾', '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Pate {2}Alabama8.35m  27-4¾1/18/2002',
#   '\xa0\xa0\xa0\xa0— Pate {2}',
#   '',
#   'Alabama',
#   '8.35m  27-4¾',
#   '1/18/2002'],
#  ['\xa0\xa0\xa0\xa0— Pate {2}', '', 'Alabama', '8.35m  27-4¾', '1/18/2002'],
#  ['\xa0\xa0\xa0\xa0— Pate {3}SRAlabama8.34m  27-4½3/8/2002\xa0\xa0\xa0\xa0\xa08.24, 8.34, f, f, f, f',
#   '\xa0\xa0\xa0\xa0— Pate {3}SR',
#   '',
#   'Alabama',
#   '8.34m  27-4½',
#   '3/8/2002',
#   '\xa0\xa0\xa0\xa0\xa08.24, 8.34, f, f, f, f'],
#  ['\xa0\xa0\xa0\xa0— Pate {3}SR', '', 'Alabama', '8.34m  27-4½', '3/8/2002'],
#  ['(10) Wayne PINNOCKSOArkansas8.33m  27-43/10/2023',
#   '(10) Wayne PINNOCKSO',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '3/10/2023'],
#  ['(10) Wayne PINNOCKSO', '', 'Arkansas', '8.33m  27-4', '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Harrison {2}SRLSU8.33m  27-42/25/2021',
#   '\xa0\xa0\xa0\xa0— Harrison {2}SR',
#   '',
#   'LSU',
#   '8.33m  27-4',
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Harrison {2}SR', '', 'LSU', '8.33m  27-4', '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Grimes {2}SRFlorida State8.33m  27-42/12/2021\xa0\xa0\xa0\xa0\xa07.47, 8.04, f, f, 8.27, 8.33',
#   '\xa0\xa0\xa0\xa0— Grimes {2}SR',
#   '',
#   'Florida State',
#   '8.33m  27-4',
#   '2/12/2021',
#   '\xa0\xa0\xa0\xa0\xa07.47, 8.04, f, f, 8.27, 8.33'],
#  ['\xa0\xa0\xa0\xa0— Grimes {2}SR',
#   '',
#   'Florida State',
#   '8.33m  27-4',
#   '2/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Walder {2}Arkansas8.33m  27-42/5/1994',
#   '\xa0\xa0\xa0\xa0— Walder {2}',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '2/5/1994'],
#  ['\xa0\xa0\xa0\xa0— Walder {2}', '', 'Arkansas', '8.33m  27-4', '2/5/1994'],
#  ['\xa0\xa0\xa0\xa0— Walder {3}JRArkansas8.33m  27-43/12/1993',
#   '\xa0\xa0\xa0\xa0— Walder {3}JR',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '3/12/1993'],
#  ['\xa0\xa0\xa0\xa0— Walder {3}JR',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '3/12/1993'],
#  ['(10) Reggie KELLYJackson State8.33m  27-412/3/1983',
#   '(10) Reggie KELLY',
#   '',
#   'Jackson State',
#   '8.33m  27-4',
#   '12/3/1983'],
#  ['(10) Reggie KELLY', '', 'Jackson State', '8.33m  27-4', '12/3/1983'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {2}SOArkansas8.32m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-3¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {2}SO',
#   '',
#   'Arkansas',
#   "8.32m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-3¾",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Pinnock {2}SO',
#   '',
#   'Arkansas',
#   "8.32m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-3¾",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Pinnock {3}SOArkansas8.31m  27-3¼2/24/2023',
#   '\xa0\xa0\xa0\xa0— Pinnock {3}SO',
#   '',
#   'Arkansas',
#   '8.31m  27-3¼',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Pinnock {3}SO',
#   '',
#   'Arkansas',
#   '8.31m  27-3¼',
#   '2/24/2023'],
#  ["\xa0\xa0\xa0\xa0— Crump {3}SRMississippi State8.30m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-2¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Crump {3}SR',
#   '',
#   'Mississippi State',
#   "8.30m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-2¾",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Crump {3}SR',
#   '',
#   'Mississippi State',
#   "8.30m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-2¾",
#   '3/10/2023'],
#  ['(12) Bob BEAMONSOUTEP8.30m  27-2¾3/16/1968\xa0\xa0\xa0\xa0\xa0then-world record',
#   '(12) Bob BEAMONSO',
#   '',
#   'UTEP',
#   '8.30m  27-2¾',
#   '3/16/1968',
#   '\xa0\xa0\xa0\xa0\xa0then-world record'],
#  ['(12) Bob BEAMONSO', '', 'UTEP', '8.30m  27-2¾', '3/16/1968'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}JRFlorida State8.28m AA = Performance occurred at altitude (>1000 meters above sea level) 27-22/10/2023\xa0\xa0\xa0\xa0\xa08.28, p, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Florida State',
#   '8.28m AA = Performance occurred at altitude (>1000 meters above sea level) 27-2',
#   '2/10/2023',
#   '\xa0\xa0\xa0\xa0\xa08.28, p, p, p, p, p'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Florida State',
#   '8.28m AA = Performance occurred at altitude (>1000 meters above sea level) 27-2',
#   '2/10/2023'],
#  ['(13) Marquis DENDYFlorida8.28m  27-23/13/2015\xa0\xa0\xa0\xa0\xa0f, 8.28, f, f, f, 8.27',
#   '(13) Marquis DENDY',
#   '',
#   'Florida',
#   '8.28m  27-2',
#   '3/13/2015',
#   '\xa0\xa0\xa0\xa0\xa0f, 8.28, f, f, f, 8.27'],
#  ['(13) Marquis DENDY', '', 'Florida', '8.28m  27-2', '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Dendy {2}SOFlorida8.28m  27-23/8/2013\xa0\xa0\xa0\xa0\xa0f, f, 8.10, 8.23, 8.28, f',
#   '\xa0\xa0\xa0\xa0— Dendy {2}SO',
#   '',
#   'Florida',
#   '8.28m  27-2',
#   '3/8/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, f, 8.10, 8.23, 8.28, f'],
#  ['\xa0\xa0\xa0\xa0— Dendy {2}SO', '', 'Florida', '8.28m  27-2', '3/8/2013'],
#  ['(13) Brian JOHNSONSRSouthern8.28m  27-23/14/2003\xa0\xa0\xa0\xa0\xa08.28, f, f, f, 8.15, 8.15',
#   '(13) Brian JOHNSONSR',
#   '',
#   'Southern',
#   '8.28m  27-2',
#   '3/14/2003',
#   '\xa0\xa0\xa0\xa0\xa08.28, f, f, f, 8.15, 8.15'],
#  ['(13) Brian JOHNSONSR', '', 'Southern', '8.28m  27-2', '3/14/2003'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {4}SOArkansas8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-1¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {4}SO',
#   '',
#   'Arkansas',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-1¾",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Pinnock {4}SO',
#   '',
#   'Arkansas',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-1¾",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Grimes {3}SRFlorida State8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾2/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {3}SR',
#   '',
#   'Florida State',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '2/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Grimes {3}SR',
#   '',
#   'Florida State',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '2/12/2021'],
#  ["\xa0\xa0\xa0\xa0— Dendy {3}SRFlorida8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾3/13/2015",
#   '\xa0\xa0\xa0\xa0— Dendy {3}SR',
#   '',
#   'Florida',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Dendy {3}SR',
#   '',
#   'Florida',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Lawson {2}Arkansas8.27m  27-1¾3/13/2015\xa0\xa0\xa0\xa0\xa07.44, 7.93, 7.44, 7.72, 5.39, 8.27',
#   '\xa0\xa0\xa0\xa0— Lawson {2}',
#   '',
#   'Arkansas',
#   '8.27m  27-1¾',
#   '3/13/2015',
#   '\xa0\xa0\xa0\xa0\xa07.44, 7.93, 7.44, 7.72, 5.39, 8.27'],
#  ['\xa0\xa0\xa0\xa0— Lawson {2}', '', 'Arkansas', '8.27m  27-1¾', '3/13/2015'],
#  ['(15) John MOFFITTLSU8.27m  27-1¾2/14/2004',
#   '(15) John MOFFITT',
#   '',
#   'LSU',
#   '8.27m  27-1¾',
#   '2/14/2004'],
#  ['(15) John MOFFITT', '', 'LSU', '8.27m  27-1¾', '2/14/2004'],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}JRTennessee8.26m  27-1¼3/12/2021',
#   '\xa0\xa0\xa0\xa0— McLeod {2}JR',
#   '',
#   'Tennessee',
#   '8.26m  27-1¼',
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}JR',
#   '',
#   'Tennessee',
#   '8.26m  27-1¼',
#   '3/12/2021'],
#  ['(16) Charlton EHIZUELEN?Illinois8.26m  27-1¼3/7/1975',
#   '(16) Charlton EHIZUELEN?',
#   '',
#   'Illinois',
#   '8.26m  27-1¼',
#   '3/7/1975'],
#  ['(16) Charlton EHIZUELEN?', '', 'Illinois', '8.26m  27-1¼', '3/7/1975'],
#  ['(17) Matthew BOLINGSOGeorgia8.25m  27-¾1/15/2022',
#   '(17) Matthew BOLINGSO',
#   '',
#   'Georgia',
#   '8.25m  27-¾',
#   '1/15/2022'],
#  ['(17) Matthew BOLINGSO', '', 'Georgia', '8.25m  27-¾', '1/15/2022'],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}JRTennessee8.25m  27-¾2/25/2021',
#   '\xa0\xa0\xa0\xa0— McLeod {3}JR',
#   '',
#   'Tennessee',
#   '8.25m  27-¾',
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}JR',
#   '',
#   'Tennessee',
#   '8.25m  27-¾',
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Dendy {4}Florida8.25m  27-¾2/23/2013\xa0\xa0\xa0\xa0\xa0f, 8.25, 8.22, p, 8.24, p',
#   '\xa0\xa0\xa0\xa0— Dendy {4}',
#   '',
#   'Florida',
#   '8.25m  27-¾',
#   '2/23/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, 8.25, 8.22, p, 8.24, p'],
#  ['\xa0\xa0\xa0\xa0— Dendy {4}', '', 'Florida', '8.25m  27-¾', '2/23/2013'],
#  ['\xa0\xa0\xa0\xa0— Lewis {3}SOHouston8.25m ii = event moved indoors because of weather or another issue. 27-¾6/5/1981\xa0\xa0\xa0\xa0\xa0(event held indoors)',
#   '\xa0\xa0\xa0\xa0— Lewis {3}SO',
#   '',
#   'Houston',
#   '8.25m ii = event moved indoors because of weather or another issue. 27-¾',
#   '6/5/1981',
#   '\xa0\xa0\xa0\xa0\xa0(event held indoors)'],
#  ['\xa0\xa0\xa0\xa0— Lewis {3}SO',
#   '',
#   'Houston',
#   '8.25m ii = event moved indoors because of weather or another issue. 27-¾',
#   '6/5/1981'],
#  ['\xa0\xa0\xa0\xa0— Beamon {2}SOUTEP8.25m  27-¾1/20/1968\xa0\xa0\xa0\xa0\xa0then-world record; 26-7½ (8.11), 27-1 (8.25), f, p, p, p ',
#   '\xa0\xa0\xa0\xa0— Beamon {2}SO',
#   '',
#   'UTEP',
#   '8.25m  27-¾',
#   '1/20/1968',
#   '\xa0\xa0\xa0\xa0\xa0then-world record; 26-7½ (8.11), 27-1 (8.25), f, p, p, p '],
#  ['\xa0\xa0\xa0\xa0— Beamon {2}SO', '', 'UTEP', '8.25m  27-¾', '1/20/1968'],
#  ["\xa0\xa0\xa0\xa0— Dendy {5}Florida8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½2/23/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {5}',
#   '',
#   'Florida',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '2/23/2013'],
#  ['\xa0\xa0\xa0\xa0— Dendy {5}',
#   '',
#   'Florida',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '2/23/2013'],
#  ["\xa0\xa0\xa0\xa0— Pate {4}SRAlabama8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½3/8/2002",
#   '\xa0\xa0\xa0\xa0— Pate {4}SR',
#   '',
#   'Alabama',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '3/8/2002'],
#  ['\xa0\xa0\xa0\xa0— Pate {4}SR',
#   '',
#   'Alabama',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '3/8/2002'],
#  ['(18) Roland MCGHEEMiddle Tennessee8.24m  27-½1/30/1993',
#   '(18) Roland MCGHEE',
#   '',
#   'Middle Tennessee',
#   '8.24m  27-½',
#   '1/30/1993'],
#  ['(18) Roland MCGHEE', '', 'Middle Tennessee', '8.24m  27-½', '1/30/1993'],
#  ["\xa0\xa0\xa0\xa0— Davis {3}JRFlorida State8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-03/10/2023",
#   '\xa0\xa0\xa0\xa0— Davis {3}JR',
#   '',
#   'Florida State',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-0",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Davis {3}JR',
#   '',
#   'Florida State',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-0",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Dendy {6}SOFlorida8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-03/8/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {6}SO',
#   '',
#   'Florida',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-0",
#   '3/8/2013'],
#  ['\xa0\xa0\xa0\xa0— Dendy {6}SO',
#   '',
#   'Florida',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-0",
#   '3/8/2013'],
#  ['(19) Savante STRINGFELLOWOle Miss8.23m  27-02/3/2001',
#   '(19) Savante STRINGFELLOW',
#   '',
#   'Ole Miss',
#   '8.23m  27-0',
#   '2/3/2001'],
#  ['(19) Savante STRINGFELLOW', '', 'Ole Miss', '8.23m  27-0', '2/3/2001'],
#  ['(19) Leroy BURRELLSRHouston8.23m  27-03/9/1990',
#   '(19) Leroy BURRELLSR',
#   '',
#   'Houston',
#   '8.23m  27-0',
#   '3/9/1990'],
#  ['(19) Leroy BURRELLSR', '', 'Houston', '8.23m  27-0', '3/9/1990'],
#  ["\xa0\xa0\xa0\xa0— McLeod {4}SRArkansas8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— McLeod {4}SR',
#   '',
#   'Arkansas',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¾",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— McLeod {4}SR',
#   '',
#   'Arkansas',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¾",
#   '3/10/2023'],
#  ['(21) Corey CRAWFORDRutgers8.22m  26-11¾3/1/2014\xa0\xa0\xa0\xa0\xa08.07, 7.69, f, 8.18, f, 8.22',
#   '(21) Corey CRAWFORD',
#   '',
#   'Rutgers',
#   '8.22m  26-11¾',
#   '3/1/2014',
#   '\xa0\xa0\xa0\xa0\xa08.07, 7.69, f, 8.18, f, 8.22'],
#  ['(21) Corey CRAWFORD', '', 'Rutgers', '8.22m  26-11¾', '3/1/2014'],
#  ["\xa0\xa0\xa0\xa0— Dendy {7}Florida8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¾2/23/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {7}',
#   '',
#   'Florida',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¾",
#   '2/23/2013'],
#  ['\xa0\xa0\xa0\xa0— Dendy {7}',
#   '',
#   'Florida',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¾",
#   '2/23/2013'],
#  ['\xa0\xa0\xa0\xa0— Pate {5}Alabama8.22m  26-11¾2/24/2002',
#   '\xa0\xa0\xa0\xa0— Pate {5}',
#   '',
#   'Alabama',
#   '8.22m  26-11¾',
#   '2/24/2002'],
#  ['\xa0\xa0\xa0\xa0— Pate {5}', '', 'Alabama', '8.22m  26-11¾', '2/24/2002'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {5}SOArkansas8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¼3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {5}SO',
#   '',
#   'Arkansas',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¼",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Pinnock {5}SO',
#   '',
#   'Arkansas',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¼",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Crump {4}SRMississippi State8.21m  26-11¼2/10/2023',
#   '\xa0\xa0\xa0\xa0— Crump {4}SR',
#   '',
#   'Mississippi State',
#   '8.21m  26-11¼',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Crump {4}SR',
#   '',
#   'Mississippi State',
#   '8.21m  26-11¼',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Davis {4}JRFlorida State8.21m  26-11¼1/27/2023\xa0\xa0\xa0\xa0\xa08.21, 8.04, 8.21, f, p, f',
#   '\xa0\xa0\xa0\xa0— Davis {4}JR',
#   '',
#   'Florida State',
#   '8.21m  26-11¼',
#   '1/27/2023',
#   '\xa0\xa0\xa0\xa0\xa08.21, 8.04, 8.21, f, p, f'],
#  ['\xa0\xa0\xa0\xa0— Davis {4}JR',
#   '',
#   'Florida State',
#   '8.21m  26-11¼',
#   '1/27/2023'],
#  ["\xa0\xa0\xa0\xa0— Grimes {4}SRFlorida State8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¼3/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {4}SR',
#   '',
#   'Florida State',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¼",
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Grimes {4}SR',
#   '',
#   'Florida State',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¼",
#   '3/12/2021'],
#  ['(22) Damar FORBESSRLSU8.21m  26-11¼3/8/2013\xa0\xa0\xa0\xa0\xa0f, 7.92, 7.87, f, 8.21, 7.82',
#   '(22) Damar FORBESSR',
#   '',
#   'LSU',
#   '8.21m  26-11¼',
#   '3/8/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, 7.92, 7.87, f, 8.21, 7.82'],
#  ['(22) Damar FORBESSR', '', 'LSU', '8.21m  26-11¼', '3/8/2013'],
#  ["\xa0\xa0\xa0\xa0— Grimes {5}SRFlorida State8.20m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-113/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {5}SR',
#   '',
#   'Florida State',
#   "8.20m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11",
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Grimes {5}SR',
#   '',
#   'Florida State',
#   "8.20m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11",
#   '3/12/2021'],
#  ['(23) Roland MCGHEEMiddle Tennessee8.20m  26-113/12/1993',
#   '(23) Roland MCGHEE',
#   '',
#   'Middle Tennessee',
#   '8.20m  26-11',
#   '3/12/1993'],
#  ['(23) Roland MCGHEE', '', 'Middle Tennessee', '8.20m  26-11', '3/12/1993'],
#  ['\xa0\xa0\xa0\xa0— McLeod {5}SRArkansas8.19m  26-10½2/24/2023',
#   '\xa0\xa0\xa0\xa0— McLeod {5}SR',
#   '',
#   'Arkansas',
#   '8.19m  26-10½',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— McLeod {5}SR',
#   '',
#   'Arkansas',
#   '8.19m  26-10½',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— McLeod {6}SOTennessee8.19m  26-10½2/28/2020',
#   '\xa0\xa0\xa0\xa0— McLeod {6}SO',
#   '',
#   'Tennessee',
#   '8.19m  26-10½',
#   '2/28/2020'],
#  ['\xa0\xa0\xa0\xa0— McLeod {6}SO',
#   '',
#   'Tennessee',
#   '8.19m  26-10½',
#   '2/28/2020'],
#  ['(24) Will WILLIAMSSRTexas A&M8.19m  26-10½3/9/2018\xa0\xa0\xa0\xa0\xa07.98, 7.82, 7.93, 7.89, f, 8.19',
#   '(24) Will WILLIAMSSR',
#   '',
#   'Texas A&M',
#   '8.19m  26-10½',
#   '3/9/2018',
#   '\xa0\xa0\xa0\xa0\xa07.98, 7.82, 7.93, 7.89, f, 8.19'],
#  ['(24) Will WILLIAMSSR', '', 'Texas A&M', '8.19m  26-10½', '3/9/2018'],
#  ["\xa0\xa0\xa0\xa0— Harrison {3}SRLSU8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-102/25/2021",
#   '\xa0\xa0\xa0\xa0— Harrison {3}SR',
#   '',
#   'LSU',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Harrison {3}SR',
#   '',
#   'LSU',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Grimes {6}SRFlorida State8.18m  26-101/29/2021\xa0\xa0\xa0\xa0\xa07.62, 7.86, 7.83, f, 8.18, 7.98',
#   '\xa0\xa0\xa0\xa0— Grimes {6}SR',
#   '',
#   'Florida State',
#   '8.18m  26-10',
#   '1/29/2021',
#   '\xa0\xa0\xa0\xa0\xa07.62, 7.86, 7.83, f, 8.18, 7.98'],
#  ['\xa0\xa0\xa0\xa0— Grimes {6}SR',
#   '',
#   'Florida State',
#   '8.18m  26-10',
#   '1/29/2021'],
#  ["\xa0\xa0\xa0\xa0— Crawford {2}Rutgers8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-103/1/2014",
#   '\xa0\xa0\xa0\xa0— Crawford {2}',
#   '',
#   'Rutgers',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '3/1/2014'],
#  ['\xa0\xa0\xa0\xa0— Crawford {2}',
#   '',
#   'Rutgers',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '3/1/2014'],
#  ['(25) Melvin LISTERArkansas8.18m  26-102/5/2000',
#   '(25) Melvin LISTER',
#   '',
#   'Arkansas',
#   '8.18m  26-10',
#   '2/5/2000'],
#  ['(25) Melvin LISTER', '', 'Arkansas', '8.18m  26-10', '2/5/2000'],
#  ['', '', '', '']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Miguel PATEAlabama8.59m📺  28-2¼3/1/2002\xa0\xa0\xa0\xa0\xa07.81, 8.59, p, p, p, p',
#   '(1) Miguel PATE',
#   '',
#   'Alabama',
#   '8.59m📺  28-2¼',
#   '3/1/2002',
#   '\xa0\xa0\xa0\xa0\xa07.81, 8.59, p, p, p, p'],
#  ['(2) Carl LEWISHouston8.49m  27-10¼2/20/1981',
#   '(2) Carl LEWIS',
#   '',
#   'Houston',
#   '8.49m  27-10¼',
#   '2/20/1981'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston8.48m  27-103/13/1981',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '8.48m  27-10',
#   '3/13/1981'],
#  ['(3) Juvaughn HARRISONSRLSU8.45m  27-8¾3/12/2021',
#   '(3) Juvaughn HARRISONSR',
#   '',
#   'LSU',
#   '8.45m  27-8¾',
#   '3/12/2021'],
#  ['(4) Erick WALDERSRArkansas8.43m  27-83/11/1994',
#   '(4) Erick WALDERSR',
#   '',
#   'Arkansas',
#   '8.43m  27-8',
#   '3/11/1994'],
#  ['(5) Carey MCLEODSRArkansas8.40m  27-6¾3/10/2023',
#   '(5) Carey MCLEODSR',
#   '',
#   'Arkansas',
#   '8.40m  27-6¾',
#   '3/10/2023'],
#  ['(6) Cameron CRUMPSRMississippi State8.39m  27-6½3/10/2023',
#   '(6) Cameron CRUMPSR',
#   '',
#   'Mississippi State',
#   '8.39m  27-6½',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Crump {2}SRMississippi State8.39m  27-6½2/24/2023',
#   '\xa0\xa0\xa0\xa0— Crump {2}SR',
#   '',
#   'Mississippi State',
#   '8.39m  27-6½',
#   '2/24/2023'],
#  ['(6) Jarrion LAWSONArkansas8.39m AA = Performance occurred at altitude (>1000 meters above sea level) 27-6½3/14/2014\xa0\xa0\xa0\xa0\xa0f, 7.68, f, f, 8.01, 8.39',
#   '(6) Jarrion LAWSON',
#   '',
#   'Arkansas',
#   '8.39m AA = Performance occurred at altitude (>1000 meters above sea level) 27-6½',
#   '3/14/2014',
#   '\xa0\xa0\xa0\xa0\xa0f, 7.68, f, f, 8.01, 8.39'],
#  ['(8) Jeremiah DAVISJRFlorida State8.37m  27-5½3/10/2023',
#   '(8) Jeremiah DAVISJR',
#   '',
#   'Florida State',
#   '8.37m  27-5½',
#   '3/10/2023'],
#  ['(9) Isaac GRIMESSRFlorida State8.35m  27-4¾3/12/2021',
#   '(9) Isaac GRIMESSR',
#   '',
#   'Florida State',
#   '8.35m  27-4¾',
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Pate {2}Alabama8.35m  27-4¾1/18/2002',
#   '\xa0\xa0\xa0\xa0— Pate {2}',
#   '',
#   'Alabama',
#   '8.35m  27-4¾',
#   '1/18/2002'],
#  ['\xa0\xa0\xa0\xa0— Pate {3}SRAlabama8.34m  27-4½3/8/2002\xa0\xa0\xa0\xa0\xa08.24, 8.34, f, f, f, f',
#   '\xa0\xa0\xa0\xa0— Pate {3}SR',
#   '',
#   'Alabama',
#   '8.34m  27-4½',
#   '3/8/2002',
#   '\xa0\xa0\xa0\xa0\xa08.24, 8.34, f, f, f, f'],
#  ['(10) Wayne PINNOCKSOArkansas8.33m  27-43/10/2023',
#   '(10) Wayne PINNOCKSO',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Harrison {2}SRLSU8.33m  27-42/25/2021',
#   '\xa0\xa0\xa0\xa0— Harrison {2}SR',
#   '',
#   'LSU',
#   '8.33m  27-4',
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Grimes {2}SRFlorida State8.33m  27-42/12/2021\xa0\xa0\xa0\xa0\xa07.47, 8.04, f, f, 8.27, 8.33',
#   '\xa0\xa0\xa0\xa0— Grimes {2}SR',
#   '',
#   'Florida State',
#   '8.33m  27-4',
#   '2/12/2021',
#   '\xa0\xa0\xa0\xa0\xa07.47, 8.04, f, f, 8.27, 8.33'],
#  ['\xa0\xa0\xa0\xa0— Walder {2}Arkansas8.33m  27-42/5/1994',
#   '\xa0\xa0\xa0\xa0— Walder {2}',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '2/5/1994'],
#  ['\xa0\xa0\xa0\xa0— Walder {3}JRArkansas8.33m  27-43/12/1993',
#   '\xa0\xa0\xa0\xa0— Walder {3}JR',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '3/12/1993'],
#  ['(10) Reggie KELLYJackson State8.33m  27-412/3/1983',
#   '(10) Reggie KELLY',
#   '',
#   'Jackson State',
#   '8.33m  27-4',
#   '12/3/1983'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {2}SOArkansas8.32m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-3¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {2}SO',
#   '',
#   'Arkansas',
#   "8.32m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-3¾",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Pinnock {3}SOArkansas8.31m  27-3¼2/24/2023',
#   '\xa0\xa0\xa0\xa0— Pinnock {3}SO',
#   '',
#   'Arkansas',
#   '8.31m  27-3¼',
#   '2/24/2023'],
#  ["\xa0\xa0\xa0\xa0— Crump {3}SRMississippi State8.30m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-2¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Crump {3}SR',
#   '',
#   'Mississippi State',
#   "8.30m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-2¾",
#   '3/10/2023'],
#  ['(12) Bob BEAMONSOUTEP8.30m  27-2¾3/16/1968\xa0\xa0\xa0\xa0\xa0then-world record',
#   '(12) Bob BEAMONSO',
#   '',
#   'UTEP',
#   '8.30m  27-2¾',
#   '3/16/1968',
#   '\xa0\xa0\xa0\xa0\xa0then-world record'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}JRFlorida State8.28m AA = Performance occurred at altitude (>1000 meters above sea level) 27-22/10/2023\xa0\xa0\xa0\xa0\xa08.28, p, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Florida State',
#   '8.28m AA = Performance occurred at altitude (>1000 meters above sea level) 27-2',
#   '2/10/2023',
#   '\xa0\xa0\xa0\xa0\xa08.28, p, p, p, p, p'],
#  ['(13) Marquis DENDYFlorida8.28m  27-23/13/2015\xa0\xa0\xa0\xa0\xa0f, 8.28, f, f, f, 8.27',
#   '(13) Marquis DENDY',
#   '',
#   'Florida',
#   '8.28m  27-2',
#   '3/13/2015',
#   '\xa0\xa0\xa0\xa0\xa0f, 8.28, f, f, f, 8.27'],
#  ['\xa0\xa0\xa0\xa0— Dendy {2}SOFlorida8.28m  27-23/8/2013\xa0\xa0\xa0\xa0\xa0f, f, 8.10, 8.23, 8.28, f',
#   '\xa0\xa0\xa0\xa0— Dendy {2}SO',
#   '',
#   'Florida',
#   '8.28m  27-2',
#   '3/8/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, f, 8.10, 8.23, 8.28, f'],
#  ['(13) Brian JOHNSONSRSouthern8.28m  27-23/14/2003\xa0\xa0\xa0\xa0\xa08.28, f, f, f, 8.15, 8.15',
#   '(13) Brian JOHNSONSR',
#   '',
#   'Southern',
#   '8.28m  27-2',
#   '3/14/2003',
#   '\xa0\xa0\xa0\xa0\xa08.28, f, f, f, 8.15, 8.15'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {4}SOArkansas8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-1¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {4}SO',
#   '',
#   'Arkansas',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-1¾",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Grimes {3}SRFlorida State8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾2/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {3}SR',
#   '',
#   'Florida State',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '2/12/2021'],
#  ["\xa0\xa0\xa0\xa0— Dendy {3}SRFlorida8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾3/13/2015",
#   '\xa0\xa0\xa0\xa0— Dendy {3}SR',
#   '',
#   'Florida',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Lawson {2}Arkansas8.27m  27-1¾3/13/2015\xa0\xa0\xa0\xa0\xa07.44, 7.93, 7.44, 7.72, 5.39, 8.27',
#   '\xa0\xa0\xa0\xa0— Lawson {2}',
#   '',
#   'Arkansas',
#   '8.27m  27-1¾',
#   '3/13/2015',
#   '\xa0\xa0\xa0\xa0\xa07.44, 7.93, 7.44, 7.72, 5.39, 8.27'],
#  ['(15) John MOFFITTLSU8.27m  27-1¾2/14/2004',
#   '(15) John MOFFITT',
#   '',
#   'LSU',
#   '8.27m  27-1¾',
#   '2/14/2004'],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}JRTennessee8.26m  27-1¼3/12/2021',
#   '\xa0\xa0\xa0\xa0— McLeod {2}JR',
#   '',
#   'Tennessee',
#   '8.26m  27-1¼',
#   '3/12/2021'],
#  ['(16) Charlton EHIZUELEN?Illinois8.26m  27-1¼3/7/1975',
#   '(16) Charlton EHIZUELEN?',
#   '',
#   'Illinois',
#   '8.26m  27-1¼',
#   '3/7/1975'],
#  ['(17) Matthew BOLINGSOGeorgia8.25m  27-¾1/15/2022',
#   '(17) Matthew BOLINGSO',
#   '',
#   'Georgia',
#   '8.25m  27-¾',
#   '1/15/2022'],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}JRTennessee8.25m  27-¾2/25/2021',
#   '\xa0\xa0\xa0\xa0— McLeod {3}JR',
#   '',
#   'Tennessee',
#   '8.25m  27-¾',
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Dendy {4}Florida8.25m  27-¾2/23/2013\xa0\xa0\xa0\xa0\xa0f, 8.25, 8.22, p, 8.24, p',
#   '\xa0\xa0\xa0\xa0— Dendy {4}',
#   '',
#   'Florida',
#   '8.25m  27-¾',
#   '2/23/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, 8.25, 8.22, p, 8.24, p'],
#  ['\xa0\xa0\xa0\xa0— Lewis {3}SOHouston8.25m ii = event moved indoors because of weather or another issue. 27-¾6/5/1981\xa0\xa0\xa0\xa0\xa0(event held indoors)',
#   '\xa0\xa0\xa0\xa0— Lewis {3}SO',
#   '',
#   'Houston',
#   '8.25m ii = event moved indoors because of weather or another issue. 27-¾',
#   '6/5/1981',
#   '\xa0\xa0\xa0\xa0\xa0(event held indoors)'],
#  ['\xa0\xa0\xa0\xa0— Beamon {2}SOUTEP8.25m  27-¾1/20/1968\xa0\xa0\xa0\xa0\xa0then-world record; 26-7½ (8.11), 27-1 (8.25), f, p, p, p ',
#   '\xa0\xa0\xa0\xa0— Beamon {2}SO',
#   '',
#   'UTEP',
#   '8.25m  27-¾',
#   '1/20/1968',
#   '\xa0\xa0\xa0\xa0\xa0then-world record; 26-7½ (8.11), 27-1 (8.25), f, p, p, p '],
#  ["\xa0\xa0\xa0\xa0— Dendy {5}Florida8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½2/23/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {5}',
#   '',
#   'Florida',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '2/23/2013'],
#  ["\xa0\xa0\xa0\xa0— Pate {4}SRAlabama8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½3/8/2002",
#   '\xa0\xa0\xa0\xa0— Pate {4}SR',
#   '',
#   'Alabama',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '3/8/2002'],
#  ['(18) Roland MCGHEEMiddle Tennessee8.24m  27-½1/30/1993',
#   '(18) Roland MCGHEE',
#   '',
#   'Middle Tennessee',
#   '8.24m  27-½',
#   '1/30/1993'],
#  ["\xa0\xa0\xa0\xa0— Davis {3}JRFlorida State8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-03/10/2023",
#   '\xa0\xa0\xa0\xa0— Davis {3}JR',
#   '',
#   'Florida State',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-0",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Dendy {6}SOFlorida8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-03/8/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {6}SO',
#   '',
#   'Florida',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-0",
#   '3/8/2013'],
#  ['(19) Savante STRINGFELLOWOle Miss8.23m  27-02/3/2001',
#   '(19) Savante STRINGFELLOW',
#   '',
#   'Ole Miss',
#   '8.23m  27-0',
#   '2/3/2001'],
#  ['(19) Leroy BURRELLSRHouston8.23m  27-03/9/1990',
#   '(19) Leroy BURRELLSR',
#   '',
#   'Houston',
#   '8.23m  27-0',
#   '3/9/1990'],
#  ["\xa0\xa0\xa0\xa0— McLeod {4}SRArkansas8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— McLeod {4}SR',
#   '',
#   'Arkansas',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¾",
#   '3/10/2023'],
#  ['(21) Corey CRAWFORDRutgers8.22m  26-11¾3/1/2014\xa0\xa0\xa0\xa0\xa08.07, 7.69, f, 8.18, f, 8.22',
#   '(21) Corey CRAWFORD',
#   '',
#   'Rutgers',
#   '8.22m  26-11¾',
#   '3/1/2014',
#   '\xa0\xa0\xa0\xa0\xa08.07, 7.69, f, 8.18, f, 8.22'],
#  ["\xa0\xa0\xa0\xa0— Dendy {7}Florida8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¾2/23/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {7}',
#   '',
#   'Florida',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¾",
#   '2/23/2013'],
#  ['\xa0\xa0\xa0\xa0— Pate {5}Alabama8.22m  26-11¾2/24/2002',
#   '\xa0\xa0\xa0\xa0— Pate {5}',
#   '',
#   'Alabama',
#   '8.22m  26-11¾',
#   '2/24/2002'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {5}SOArkansas8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¼3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {5}SO',
#   '',
#   'Arkansas',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¼",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Crump {4}SRMississippi State8.21m  26-11¼2/10/2023',
#   '\xa0\xa0\xa0\xa0— Crump {4}SR',
#   '',
#   'Mississippi State',
#   '8.21m  26-11¼',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Davis {4}JRFlorida State8.21m  26-11¼1/27/2023\xa0\xa0\xa0\xa0\xa08.21, 8.04, 8.21, f, p, f',
#   '\xa0\xa0\xa0\xa0— Davis {4}JR',
#   '',
#   'Florida State',
#   '8.21m  26-11¼',
#   '1/27/2023',
#   '\xa0\xa0\xa0\xa0\xa08.21, 8.04, 8.21, f, p, f'],
#  ["\xa0\xa0\xa0\xa0— Grimes {4}SRFlorida State8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¼3/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {4}SR',
#   '',
#   'Florida State',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¼",
#   '3/12/2021'],
#  ['(22) Damar FORBESSRLSU8.21m  26-11¼3/8/2013\xa0\xa0\xa0\xa0\xa0f, 7.92, 7.87, f, 8.21, 7.82',
#   '(22) Damar FORBESSR',
#   '',
#   'LSU',
#   '8.21m  26-11¼',
#   '3/8/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, 7.92, 7.87, f, 8.21, 7.82'],
#  ["\xa0\xa0\xa0\xa0— Grimes {5}SRFlorida State8.20m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-113/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {5}SR',
#   '',
#   'Florida State',
#   "8.20m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11",
#   '3/12/2021'],
#  ['(23) Roland MCGHEEMiddle Tennessee8.20m  26-113/12/1993',
#   '(23) Roland MCGHEE',
#   '',
#   'Middle Tennessee',
#   '8.20m  26-11',
#   '3/12/1993'],
#  ['\xa0\xa0\xa0\xa0— McLeod {5}SRArkansas8.19m  26-10½2/24/2023',
#   '\xa0\xa0\xa0\xa0— McLeod {5}SR',
#   '',
#   'Arkansas',
#   '8.19m  26-10½',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— McLeod {6}SOTennessee8.19m  26-10½2/28/2020',
#   '\xa0\xa0\xa0\xa0— McLeod {6}SO',
#   '',
#   'Tennessee',
#   '8.19m  26-10½',
#   '2/28/2020'],
#  ['(24) Will WILLIAMSSRTexas A&M8.19m  26-10½3/9/2018\xa0\xa0\xa0\xa0\xa07.98, 7.82, 7.93, 7.89, f, 8.19',
#   '(24) Will WILLIAMSSR',
#   '',
#   'Texas A&M',
#   '8.19m  26-10½',
#   '3/9/2018',
#   '\xa0\xa0\xa0\xa0\xa07.98, 7.82, 7.93, 7.89, f, 8.19'],
#  ["\xa0\xa0\xa0\xa0— Harrison {3}SRLSU8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-102/25/2021",
#   '\xa0\xa0\xa0\xa0— Harrison {3}SR',
#   '',
#   'LSU',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Grimes {6}SRFlorida State8.18m  26-101/29/2021\xa0\xa0\xa0\xa0\xa07.62, 7.86, 7.83, f, 8.18, 7.98',
#   '\xa0\xa0\xa0\xa0— Grimes {6}SR',
#   '',
#   'Florida State',
#   '8.18m  26-10',
#   '1/29/2021',
#   '\xa0\xa0\xa0\xa0\xa07.62, 7.86, 7.83, f, 8.18, 7.98'],
#  ["\xa0\xa0\xa0\xa0— Crawford {2}Rutgers8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-103/1/2014",
#   '\xa0\xa0\xa0\xa0— Crawford {2}',
#   '',
#   'Rutgers',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '3/1/2014'],
#  ['(25) Melvin LISTERArkansas8.18m  26-102/5/2000',
#   '(25) Melvin LISTER',
#   '',
#   'Arkansas',
#   '8.18m  26-10',
#   '2/5/2000'],
#  ['', '', '', '']]

# %%
RealRealRows[2][4]
# Out:
# '8.48m  27-10'

# %%
len(RealRealRows)
# Out:
# 65

# %%
OfficialLengths = []

# %%
for i in range(0,64):
    OfficialLengths.append(RealRealRows[i][4])
OfficialLengths
# Out:
# ['8.59m📺  28-2¼',
#  '8.49m  27-10¼',
#  '8.48m  27-10',
#  '8.45m  27-8¾',
#  '8.43m  27-8',
#  '8.40m  27-6¾',
#  '8.39m  27-6½',
#  '8.39m  27-6½',
#  '8.39m AA = Performance occurred at altitude (>1000 meters above sea level) 27-6½',
#  '8.37m  27-5½',
#  '8.35m  27-4¾',
#  '8.35m  27-4¾',
#  '8.34m  27-4½',
#  '8.33m  27-4',
#  '8.33m  27-4',
#  '8.33m  27-4',
#  '8.33m  27-4',
#  '8.33m  27-4',
#  '8.33m  27-4',
#  "8.32m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-3¾",
#  '8.31m  27-3¼',
#  "8.30m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-2¾",
#  '8.30m  27-2¾',
#  '8.28m AA = Performance occurred at altitude (>1000 meters above sea level) 27-2',
#  '8.28m  27-2',
#  '8.28m  27-2',
#  '8.28m  27-2',
#  "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-1¾",
#  "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#  "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#  '8.27m  27-1¾',
#  '8.27m  27-1¾',
#  '8.26m  27-1¼',
#  '8.26m  27-1¼',
#  '8.25m  27-¾',
#  '8.25m  27-¾',
#  '8.25m  27-¾',
#  '8.25m ii = event moved indoors because of weather or another issue. 27-¾',
#  '8.25m  27-¾',
#  "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#  "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#  '8.24m  27-½',
#  "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-0",
#  "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-0",
#  '8.23m  27-0',
#  '8.23m  27-0',
#  "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¾",
#  '8.22m  26-11¾',
#  "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¾",
#  '8.22m  26-11¾',
#  "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¼",
#  '8.21m  26-11¼',
#  '8.21m  26-11¼',
#  "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¼",
#  '8.21m  26-11¼',
#  "8.20m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11",
#  '8.20m  26-11',
#  '8.19m  26-10½',
#  '8.19m  26-10½',
#  '8.19m  26-10½',
#  "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#  '8.18m  26-10',
#  "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#  '8.18m  26-10']

# %%
RealRealRows
# Out:
# [['(1) Miguel PATEAlabama8.59m📺  28-2¼3/1/2002\xa0\xa0\xa0\xa0\xa07.81, 8.59, p, p, p, p',
#   '(1) Miguel PATE',
#   '',
#   'Alabama',
#   '8.59m📺  28-2¼',
#   '3/1/2002',
#   '\xa0\xa0\xa0\xa0\xa07.81, 8.59, p, p, p, p'],
#  ['(2) Carl LEWISHouston8.49m  27-10¼2/20/1981',
#   '(2) Carl LEWIS',
#   '',
#   'Houston',
#   '8.49m  27-10¼',
#   '2/20/1981'],
#  ['\xa0\xa0\xa0\xa0— Lewis {2}Houston8.48m  27-103/13/1981',
#   '\xa0\xa0\xa0\xa0— Lewis {2}',
#   '',
#   'Houston',
#   '8.48m  27-10',
#   '3/13/1981'],
#  ['(3) Juvaughn HARRISONSRLSU8.45m  27-8¾3/12/2021',
#   '(3) Juvaughn HARRISONSR',
#   '',
#   'LSU',
#   '8.45m  27-8¾',
#   '3/12/2021'],
#  ['(4) Erick WALDERSRArkansas8.43m  27-83/11/1994',
#   '(4) Erick WALDERSR',
#   '',
#   'Arkansas',
#   '8.43m  27-8',
#   '3/11/1994'],
#  ['(5) Carey MCLEODSRArkansas8.40m  27-6¾3/10/2023',
#   '(5) Carey MCLEODSR',
#   '',
#   'Arkansas',
#   '8.40m  27-6¾',
#   '3/10/2023'],
#  ['(6) Cameron CRUMPSRMississippi State8.39m  27-6½3/10/2023',
#   '(6) Cameron CRUMPSR',
#   '',
#   'Mississippi State',
#   '8.39m  27-6½',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Crump {2}SRMississippi State8.39m  27-6½2/24/2023',
#   '\xa0\xa0\xa0\xa0— Crump {2}SR',
#   '',
#   'Mississippi State',
#   '8.39m  27-6½',
#   '2/24/2023'],
#  ['(6) Jarrion LAWSONArkansas8.39m AA = Performance occurred at altitude (>1000 meters above sea level) 27-6½3/14/2014\xa0\xa0\xa0\xa0\xa0f, 7.68, f, f, 8.01, 8.39',
#   '(6) Jarrion LAWSON',
#   '',
#   'Arkansas',
#   '8.39m AA = Performance occurred at altitude (>1000 meters above sea level) 27-6½',
#   '3/14/2014',
#   '\xa0\xa0\xa0\xa0\xa0f, 7.68, f, f, 8.01, 8.39'],
#  ['(8) Jeremiah DAVISJRFlorida State8.37m  27-5½3/10/2023',
#   '(8) Jeremiah DAVISJR',
#   '',
#   'Florida State',
#   '8.37m  27-5½',
#   '3/10/2023'],
#  ['(9) Isaac GRIMESSRFlorida State8.35m  27-4¾3/12/2021',
#   '(9) Isaac GRIMESSR',
#   '',
#   'Florida State',
#   '8.35m  27-4¾',
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Pate {2}Alabama8.35m  27-4¾1/18/2002',
#   '\xa0\xa0\xa0\xa0— Pate {2}',
#   '',
#   'Alabama',
#   '8.35m  27-4¾',
#   '1/18/2002'],
#  ['\xa0\xa0\xa0\xa0— Pate {3}SRAlabama8.34m  27-4½3/8/2002\xa0\xa0\xa0\xa0\xa08.24, 8.34, f, f, f, f',
#   '\xa0\xa0\xa0\xa0— Pate {3}SR',
#   '',
#   'Alabama',
#   '8.34m  27-4½',
#   '3/8/2002',
#   '\xa0\xa0\xa0\xa0\xa08.24, 8.34, f, f, f, f'],
#  ['(10) Wayne PINNOCKSOArkansas8.33m  27-43/10/2023',
#   '(10) Wayne PINNOCKSO',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Harrison {2}SRLSU8.33m  27-42/25/2021',
#   '\xa0\xa0\xa0\xa0— Harrison {2}SR',
#   '',
#   'LSU',
#   '8.33m  27-4',
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Grimes {2}SRFlorida State8.33m  27-42/12/2021\xa0\xa0\xa0\xa0\xa07.47, 8.04, f, f, 8.27, 8.33',
#   '\xa0\xa0\xa0\xa0— Grimes {2}SR',
#   '',
#   'Florida State',
#   '8.33m  27-4',
#   '2/12/2021',
#   '\xa0\xa0\xa0\xa0\xa07.47, 8.04, f, f, 8.27, 8.33'],
#  ['\xa0\xa0\xa0\xa0— Walder {2}Arkansas8.33m  27-42/5/1994',
#   '\xa0\xa0\xa0\xa0— Walder {2}',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '2/5/1994'],
#  ['\xa0\xa0\xa0\xa0— Walder {3}JRArkansas8.33m  27-43/12/1993',
#   '\xa0\xa0\xa0\xa0— Walder {3}JR',
#   '',
#   'Arkansas',
#   '8.33m  27-4',
#   '3/12/1993'],
#  ['(10) Reggie KELLYJackson State8.33m  27-412/3/1983',
#   '(10) Reggie KELLY',
#   '',
#   'Jackson State',
#   '8.33m  27-4',
#   '12/3/1983'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {2}SOArkansas8.32m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-3¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {2}SO',
#   '',
#   'Arkansas',
#   "8.32m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-3¾",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Pinnock {3}SOArkansas8.31m  27-3¼2/24/2023',
#   '\xa0\xa0\xa0\xa0— Pinnock {3}SO',
#   '',
#   'Arkansas',
#   '8.31m  27-3¼',
#   '2/24/2023'],
#  ["\xa0\xa0\xa0\xa0— Crump {3}SRMississippi State8.30m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-2¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Crump {3}SR',
#   '',
#   'Mississippi State',
#   "8.30m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-2¾",
#   '3/10/2023'],
#  ['(12) Bob BEAMONSOUTEP8.30m  27-2¾3/16/1968\xa0\xa0\xa0\xa0\xa0then-world record',
#   '(12) Bob BEAMONSO',
#   '',
#   'UTEP',
#   '8.30m  27-2¾',
#   '3/16/1968',
#   '\xa0\xa0\xa0\xa0\xa0then-world record'],
#  ['\xa0\xa0\xa0\xa0— Davis {2}JRFlorida State8.28m AA = Performance occurred at altitude (>1000 meters above sea level) 27-22/10/2023\xa0\xa0\xa0\xa0\xa08.28, p, p, p, p, p',
#   '\xa0\xa0\xa0\xa0— Davis {2}JR',
#   '',
#   'Florida State',
#   '8.28m AA = Performance occurred at altitude (>1000 meters above sea level) 27-2',
#   '2/10/2023',
#   '\xa0\xa0\xa0\xa0\xa08.28, p, p, p, p, p'],
#  ['(13) Marquis DENDYFlorida8.28m  27-23/13/2015\xa0\xa0\xa0\xa0\xa0f, 8.28, f, f, f, 8.27',
#   '(13) Marquis DENDY',
#   '',
#   'Florida',
#   '8.28m  27-2',
#   '3/13/2015',
#   '\xa0\xa0\xa0\xa0\xa0f, 8.28, f, f, f, 8.27'],
#  ['\xa0\xa0\xa0\xa0— Dendy {2}SOFlorida8.28m  27-23/8/2013\xa0\xa0\xa0\xa0\xa0f, f, 8.10, 8.23, 8.28, f',
#   '\xa0\xa0\xa0\xa0— Dendy {2}SO',
#   '',
#   'Florida',
#   '8.28m  27-2',
#   '3/8/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, f, 8.10, 8.23, 8.28, f'],
#  ['(13) Brian JOHNSONSRSouthern8.28m  27-23/14/2003\xa0\xa0\xa0\xa0\xa08.28, f, f, f, 8.15, 8.15',
#   '(13) Brian JOHNSONSR',
#   '',
#   'Southern',
#   '8.28m  27-2',
#   '3/14/2003',
#   '\xa0\xa0\xa0\xa0\xa08.28, f, f, f, 8.15, 8.15'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {4}SOArkansas8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-1¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {4}SO',
#   '',
#   'Arkansas',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-1¾",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Grimes {3}SRFlorida State8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾2/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {3}SR',
#   '',
#   'Florida State',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '2/12/2021'],
#  ["\xa0\xa0\xa0\xa0— Dendy {3}SRFlorida8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾3/13/2015",
#   '\xa0\xa0\xa0\xa0— Dendy {3}SR',
#   '',
#   'Florida',
#   "8.27m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-1¾",
#   '3/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Lawson {2}Arkansas8.27m  27-1¾3/13/2015\xa0\xa0\xa0\xa0\xa07.44, 7.93, 7.44, 7.72, 5.39, 8.27',
#   '\xa0\xa0\xa0\xa0— Lawson {2}',
#   '',
#   'Arkansas',
#   '8.27m  27-1¾',
#   '3/13/2015',
#   '\xa0\xa0\xa0\xa0\xa07.44, 7.93, 7.44, 7.72, 5.39, 8.27'],
#  ['(15) John MOFFITTLSU8.27m  27-1¾2/14/2004',
#   '(15) John MOFFITT',
#   '',
#   'LSU',
#   '8.27m  27-1¾',
#   '2/14/2004'],
#  ['\xa0\xa0\xa0\xa0— McLeod {2}JRTennessee8.26m  27-1¼3/12/2021',
#   '\xa0\xa0\xa0\xa0— McLeod {2}JR',
#   '',
#   'Tennessee',
#   '8.26m  27-1¼',
#   '3/12/2021'],
#  ['(16) Charlton EHIZUELEN?Illinois8.26m  27-1¼3/7/1975',
#   '(16) Charlton EHIZUELEN?',
#   '',
#   'Illinois',
#   '8.26m  27-1¼',
#   '3/7/1975'],
#  ['(17) Matthew BOLINGSOGeorgia8.25m  27-¾1/15/2022',
#   '(17) Matthew BOLINGSO',
#   '',
#   'Georgia',
#   '8.25m  27-¾',
#   '1/15/2022'],
#  ['\xa0\xa0\xa0\xa0— McLeod {3}JRTennessee8.25m  27-¾2/25/2021',
#   '\xa0\xa0\xa0\xa0— McLeod {3}JR',
#   '',
#   'Tennessee',
#   '8.25m  27-¾',
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Dendy {4}Florida8.25m  27-¾2/23/2013\xa0\xa0\xa0\xa0\xa0f, 8.25, 8.22, p, 8.24, p',
#   '\xa0\xa0\xa0\xa0— Dendy {4}',
#   '',
#   'Florida',
#   '8.25m  27-¾',
#   '2/23/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, 8.25, 8.22, p, 8.24, p'],
#  ['\xa0\xa0\xa0\xa0— Lewis {3}SOHouston8.25m ii = event moved indoors because of weather or another issue. 27-¾6/5/1981\xa0\xa0\xa0\xa0\xa0(event held indoors)',
#   '\xa0\xa0\xa0\xa0— Lewis {3}SO',
#   '',
#   'Houston',
#   '8.25m ii = event moved indoors because of weather or another issue. 27-¾',
#   '6/5/1981',
#   '\xa0\xa0\xa0\xa0\xa0(event held indoors)'],
#  ['\xa0\xa0\xa0\xa0— Beamon {2}SOUTEP8.25m  27-¾1/20/1968\xa0\xa0\xa0\xa0\xa0then-world record; 26-7½ (8.11), 27-1 (8.25), f, p, p, p ',
#   '\xa0\xa0\xa0\xa0— Beamon {2}SO',
#   '',
#   'UTEP',
#   '8.25m  27-¾',
#   '1/20/1968',
#   '\xa0\xa0\xa0\xa0\xa0then-world record; 26-7½ (8.11), 27-1 (8.25), f, p, p, p '],
#  ["\xa0\xa0\xa0\xa0— Dendy {5}Florida8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½2/23/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {5}',
#   '',
#   'Florida',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '2/23/2013'],
#  ["\xa0\xa0\xa0\xa0— Pate {4}SRAlabama8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½3/8/2002",
#   '\xa0\xa0\xa0\xa0— Pate {4}SR',
#   '',
#   'Alabama',
#   "8.24m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-½",
#   '3/8/2002'],
#  ['(18) Roland MCGHEEMiddle Tennessee8.24m  27-½1/30/1993',
#   '(18) Roland MCGHEE',
#   '',
#   'Middle Tennessee',
#   '8.24m  27-½',
#   '1/30/1993'],
#  ["\xa0\xa0\xa0\xa0— Davis {3}JRFlorida State8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-03/10/2023",
#   '\xa0\xa0\xa0\xa0— Davis {3}JR',
#   '',
#   'Florida State',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 27-0",
#   '3/10/2023'],
#  ["\xa0\xa0\xa0\xa0— Dendy {6}SOFlorida8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-03/8/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {6}SO',
#   '',
#   'Florida',
#   "8.23m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 27-0",
#   '3/8/2013'],
#  ['(19) Savante STRINGFELLOWOle Miss8.23m  27-02/3/2001',
#   '(19) Savante STRINGFELLOW',
#   '',
#   'Ole Miss',
#   '8.23m  27-0',
#   '2/3/2001'],
#  ['(19) Leroy BURRELLSRHouston8.23m  27-03/9/1990',
#   '(19) Leroy BURRELLSR',
#   '',
#   'Houston',
#   '8.23m  27-0',
#   '3/9/1990'],
#  ["\xa0\xa0\xa0\xa0— McLeod {4}SRArkansas8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¾3/10/2023",
#   '\xa0\xa0\xa0\xa0— McLeod {4}SR',
#   '',
#   'Arkansas',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¾",
#   '3/10/2023'],
#  ['(21) Corey CRAWFORDRutgers8.22m  26-11¾3/1/2014\xa0\xa0\xa0\xa0\xa08.07, 7.69, f, 8.18, f, 8.22',
#   '(21) Corey CRAWFORD',
#   '',
#   'Rutgers',
#   '8.22m  26-11¾',
#   '3/1/2014',
#   '\xa0\xa0\xa0\xa0\xa08.07, 7.69, f, 8.18, f, 8.22'],
#  ["\xa0\xa0\xa0\xa0— Dendy {7}Florida8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¾2/23/2013",
#   '\xa0\xa0\xa0\xa0— Dendy {7}',
#   '',
#   'Florida',
#   "8.22m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¾",
#   '2/23/2013'],
#  ['\xa0\xa0\xa0\xa0— Pate {5}Alabama8.22m  26-11¾2/24/2002',
#   '\xa0\xa0\xa0\xa0— Pate {5}',
#   '',
#   'Alabama',
#   '8.22m  26-11¾',
#   '2/24/2002'],
#  ["\xa0\xa0\xa0\xa0— Pinnock {5}SOArkansas8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¼3/10/2023",
#   '\xa0\xa0\xa0\xa0— Pinnock {5}SO',
#   '',
#   'Arkansas',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the roundAA = Performance occurred at altitude (>1000 meters above sea level) 26-11¼",
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Crump {4}SRMississippi State8.21m  26-11¼2/10/2023',
#   '\xa0\xa0\xa0\xa0— Crump {4}SR',
#   '',
#   'Mississippi State',
#   '8.21m  26-11¼',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Davis {4}JRFlorida State8.21m  26-11¼1/27/2023\xa0\xa0\xa0\xa0\xa08.21, 8.04, 8.21, f, p, f',
#   '\xa0\xa0\xa0\xa0— Davis {4}JR',
#   '',
#   'Florida State',
#   '8.21m  26-11¼',
#   '1/27/2023',
#   '\xa0\xa0\xa0\xa0\xa08.21, 8.04, 8.21, f, p, f'],
#  ["\xa0\xa0\xa0\xa0— Grimes {4}SRFlorida State8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¼3/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {4}SR',
#   '',
#   'Florida State',
#   "8.21m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11¼",
#   '3/12/2021'],
#  ['(22) Damar FORBESSRLSU8.21m  26-11¼3/8/2013\xa0\xa0\xa0\xa0\xa0f, 7.92, 7.87, f, 8.21, 7.82',
#   '(22) Damar FORBESSR',
#   '',
#   'LSU',
#   '8.21m  26-11¼',
#   '3/8/2013',
#   '\xa0\xa0\xa0\xa0\xa0f, 7.92, 7.87, f, 8.21, 7.82'],
#  ["\xa0\xa0\xa0\xa0— Grimes {5}SRFlorida State8.20m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-113/12/2021",
#   '\xa0\xa0\xa0\xa0— Grimes {5}SR',
#   '',
#   'Florida State',
#   "8.20m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-11",
#   '3/12/2021'],
#  ['(23) Roland MCGHEEMiddle Tennessee8.20m  26-113/12/1993',
#   '(23) Roland MCGHEE',
#   '',
#   'Middle Tennessee',
#   '8.20m  26-11',
#   '3/12/1993'],
#  ['\xa0\xa0\xa0\xa0— McLeod {5}SRArkansas8.19m  26-10½2/24/2023',
#   '\xa0\xa0\xa0\xa0— McLeod {5}SR',
#   '',
#   'Arkansas',
#   '8.19m  26-10½',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— McLeod {6}SOTennessee8.19m  26-10½2/28/2020',
#   '\xa0\xa0\xa0\xa0— McLeod {6}SO',
#   '',
#   'Tennessee',
#   '8.19m  26-10½',
#   '2/28/2020'],
#  ['(24) Will WILLIAMSSRTexas A&M8.19m  26-10½3/9/2018\xa0\xa0\xa0\xa0\xa07.98, 7.82, 7.93, 7.89, f, 8.19',
#   '(24) Will WILLIAMSSR',
#   '',
#   'Texas A&M',
#   '8.19m  26-10½',
#   '3/9/2018',
#   '\xa0\xa0\xa0\xa0\xa07.98, 7.82, 7.93, 7.89, f, 8.19'],
#  ["\xa0\xa0\xa0\xa0— Harrison {3}SRLSU8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-102/25/2021",
#   '\xa0\xa0\xa0\xa0— Harrison {3}SR',
#   '',
#   'LSU',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '2/25/2021'],
#  ['\xa0\xa0\xa0\xa0— Grimes {6}SRFlorida State8.18m  26-101/29/2021\xa0\xa0\xa0\xa0\xa07.62, 7.86, 7.83, f, 8.18, 7.98',
#   '\xa0\xa0\xa0\xa0— Grimes {6}SR',
#   '',
#   'Florida State',
#   '8.18m  26-10',
#   '1/29/2021',
#   '\xa0\xa0\xa0\xa0\xa07.62, 7.86, 7.83, f, 8.18, 7.98'],
#  ["\xa0\xa0\xa0\xa0— Crawford {2}Rutgers8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-103/1/2014",
#   '\xa0\xa0\xa0\xa0— Crawford {2}',
#   '',
#   'Rutgers',
#   "8.18m ++ = Enroute to a longer distance or a supplemental field-event mark from the performer's best during the round 26-10",
#   '3/1/2014'],
#  ['(25) Melvin LISTERArkansas8.18m  26-102/5/2000',
#   '(25) Melvin LISTER',
#   '',
#   'Arkansas',
#   '8.18m  26-10',
#   '2/5/2000'],
#  ['', '', '', '']]

# %%
len(RealRealRows)
# Out:
# 65

# %%
RealRealRows[2][1]
# Out:
# '\xa0\xa0\xa0\xa0— Lewis {2}'

# %%
Names = []

for i in range(0,64):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Miguel PATE',
#  '(2) Carl LEWIS',
#  '\xa0\xa0\xa0\xa0— Lewis {2}',
#  '(3) Juvaughn HARRISONSR',
#  '(4) Erick WALDERSR',
#  '(5) Carey MCLEODSR',
#  '(6) Cameron CRUMPSR',
#  '\xa0\xa0\xa0\xa0— Crump {2}SR',
#  '(6) Jarrion LAWSON',
#  '(8) Jeremiah DAVISJR',
#  '(9) Isaac GRIMESSR',
#  '\xa0\xa0\xa0\xa0— Pate {2}',
#  '\xa0\xa0\xa0\xa0— Pate {3}SR',
#  '(10) Wayne PINNOCKSO',
#  '\xa0\xa0\xa0\xa0— Harrison {2}SR',
#  '\xa0\xa0\xa0\xa0— Grimes {2}SR',
#  '\xa0\xa0\xa0\xa0— Walder {2}',
#  '\xa0\xa0\xa0\xa0— Walder {3}JR',
#  '(10) Reggie KELLY',
#  '\xa0\xa0\xa0\xa0— Pinnock {2}SO',
#  '\xa0\xa0\xa0\xa0— Pinnock {3}SO',
#  '\xa0\xa0\xa0\xa0— Crump {3}SR',
#  '(12) Bob BEAMONSO',
#  '\xa0\xa0\xa0\xa0— Davis {2}JR',
#  '(13) Marquis DENDY',
#  '\xa0\xa0\xa0\xa0— Dendy {2}SO',
#  '(13) Brian JOHNSONSR',
#  '\xa0\xa0\xa0\xa0— Pinnock {4}SO',
#  '\xa0\xa0\xa0\xa0— Grimes {3}SR',
#  '\xa0\xa0\xa0\xa0— Dendy {3}SR',
#  '\xa0\xa0\xa0\xa0— Lawson {2}',
#  '(15) John MOFFITT',
#  '\xa0\xa0\xa0\xa0— McLeod {2}JR',
#  '(16) Charlton EHIZUELEN?',
#  '(17) Matthew BOLINGSO',
#  '\xa0\xa0\xa0\xa0— McLeod {3}JR',
#  '\xa0\xa0\xa0\xa0— Dendy {4}',
#  '\xa0\xa0\xa0\xa0— Lewis {3}SO',
#  '\xa0\xa0\xa0\xa0— Beamon {2}SO',
#  '\xa0\xa0\xa0\xa0— Dendy {5}',
#  '\xa0\xa0\xa0\xa0— Pate {4}SR',
#  '(18) Roland MCGHEE',
#  '\xa0\xa0\xa0\xa0— Davis {3}JR',
#  '\xa0\xa0\xa0\xa0— Dendy {6}SO',
#  '(19) Savante STRINGFELLOW',
#  '(19) Leroy BURRELLSR',
#  '\xa0\xa0\xa0\xa0— McLeod {4}SR',
#  '(21) Corey CRAWFORD',
#  '\xa0\xa0\xa0\xa0— Dendy {7}',
#  '\xa0\xa0\xa0\xa0— Pate {5}',
#  '\xa0\xa0\xa0\xa0— Pinnock {5}SO',
#  '\xa0\xa0\xa0\xa0— Crump {4}SR',
#  '\xa0\xa0\xa0\xa0— Davis {4}JR',
#  '\xa0\xa0\xa0\xa0— Grimes {4}SR',
#  '(22) Damar FORBESSR',
#  '\xa0\xa0\xa0\xa0— Grimes {5}SR',
#  '(23) Roland MCGHEE',
#  '\xa0\xa0\xa0\xa0— McLeod {5}SR',
#  '\xa0\xa0\xa0\xa0— McLeod {6}SO',
#  '(24) Will WILLIAMSSR',
#  '\xa0\xa0\xa0\xa0— Harrison {3}SR',
#  '\xa0\xa0\xa0\xa0— Grimes {6}SR',
#  '\xa0\xa0\xa0\xa0— Crawford {2}',
#  '(25) Melvin LISTER']

# %%
len(Names)
# Out:
# 64

# %%
OfficialReGexNames = []

# %%
for i in range(0,64):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Miguel PATE',
#  '(2) Carl LEWIS',
#  '— Lewis {2}',
#  '(3) Juvaughn HARRISONSR',
#  '(4) Erick WALDERSR',
#  '(5) Carey MCLEODSR',
#  '(6) Cameron CRUMPSR',
#  '— Crump {2}SR',
#  '(6) Jarrion LAWSON',
#  '(8) Jeremiah DAVISJR',
#  '(9) Isaac GRIMESSR',
#  '— Pate {2}',
#  '— Pate {3}SR',
#  '(10) Wayne PINNOCKSO',
#  '— Harrison {2}SR',
#  '— Grimes {2}SR',
#  '— Walder {2}',
#  '— Walder {3}JR',
#  '(10) Reggie KELLY',
#  '— Pinnock {2}SO',
#  '— Pinnock {3}SO',
#  '— Crump {3}SR',
#  '(12) Bob BEAMONSO',
#  '— Davis {2}JR',
#  '(13) Marquis DENDY',
#  '— Dendy {2}SO',
#  '(13) Brian JOHNSONSR',
#  '— Pinnock {4}SO',
#  '— Grimes {3}SR',
#  '— Dendy {3}SR',
#  '— Lawson {2}',
#  '(15) John MOFFITT',
#  '— McLeod {2}JR',
#  '(16) Charlton EHIZUELEN?',
#  '(17) Matthew BOLINGSO',
#  '— McLeod {3}JR',
#  '— Dendy {4}',
#  '— Lewis {3}SO',
#  '— Beamon {2}SO',
#  '— Dendy {5}',
#  '— Pate {4}SR',
#  '(18) Roland MCGHEE',
#  '— Davis {3}JR',
#  '— Dendy {6}SO',
#  '(19) Savante STRINGFELLOW',
#  '(19) Leroy BURRELLSR',
#  '— McLeod {4}SR',
#  '(21) Corey CRAWFORD',
#  '— Dendy {7}',
#  '— Pate {5}',
#  '— Pinnock {5}SO',
#  '— Crump {4}SR',
#  '— Davis {4}JR',
#  '— Grimes {4}SR',
#  '(22) Damar FORBESSR',
#  '— Grimes {5}SR',
#  '(23) Roland MCGHEE',
#  '— McLeod {5}SR',
#  '— McLeod {6}SO',
#  '(24) Will WILLIAMSSR',
#  '— Harrison {3}SR',
#  '— Grimes {6}SR',
#  '— Crawford {2}',
#  '(25) Melvin LISTER']

# %%
CleanedNames = []

for i in range(0,len(OfficialReGexNames)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Miguel PATE',
#  'Carl LEWIS',
#  'Lewis {2}',
#  'Juvaughn HARRISONSR',
#  'Erick WALDERSR',
#  'Carey MCLEODSR',
#  'Cameron CRUMPSR',
#  'Crump {2}SR',
#  'Jarrion LAWSON',
#  'Jeremiah DAVISJR',
#  'Isaac GRIMESSR',
#  'Pate {2}',
#  'Pate {3}SR',
#  ' Wayne PINNOCKSO',
#  'Harrison {2}SR',
#  'Grimes {2}SR',
#  'Walder {2}',
#  'Walder {3}JR',
#  ' Reggie KELLY',
#  'Pinnock {2}SO',
#  'Pinnock {3}SO',
#  'Crump {3}SR',
#  ' Bob BEAMONSO',
#  'Davis {2}JR',
#  ' Marquis DENDY',
#  'Dendy {2}SO',
#  ' Brian JOHNSONSR',
#  'Pinnock {4}SO',
#  'Grimes {3}SR',
#  'Dendy {3}SR',
#  'Lawson {2}',
#  ' John MOFFITT',
#  'McLeod {2}JR',
#  ' Charlton EHIZUELEN?',
#  ' Matthew BOLINGSO',
#  'McLeod {3}JR',
#  'Dendy {4}',
#  'Lewis {3}SO',
#  'Beamon {2}SO',
#  'Dendy {5}',
#  'Pate {4}SR',
#  ' Roland MCGHEE',
#  'Davis {3}JR',
#  'Dendy {6}SO',
#  ' Savante STRINGFELLOW',
#  ' Leroy BURRELLSR',
#  'McLeod {4}SR',
#  ' Corey CRAWFORD',
#  'Dendy {7}',
#  'Pate {5}',
#  'Pinnock {5}SO',
#  'Crump {4}SR',
#  'Davis {4}JR',
#  'Grimes {4}SR',
#  ' Damar FORBESSR',
#  'Grimes {5}SR',
#  ' Roland MCGHEE',
#  'McLeod {5}SR',
#  'McLeod {6}SO',
#  ' Will WILLIAMSSR',
#  'Harrison {3}SR',
#  'Grimes {6}SR',
#  'Crawford {2}',
#  ' Melvin LISTER']

# %%
CleanedNames2 = []

for i in range(0,len(OfficialReGexNames)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Miguel PATE',
#  'Carl LEWIS',
#  'Lewis {2}',
#  'Juvaughn HARRISONSR',
#  'Erick WALDERSR',
#  'Carey MCLEODSR',
#  'Cameron CRUMPSR',
#  'Crump {2}SR',
#  'Jarrion LAWSON',
#  'Jeremiah DAVISJR',
#  'Isaac GRIMESSR',
#  'Pate {2}',
#  'Pate {3}SR',
#  'Wayne PINNOCKSO',
#  'Harrison {2}SR',
#  'Grimes {2}SR',
#  'Walder {2}',
#  'Walder {3}JR',
#  'Reggie KELLY',
#  'Pinnock {2}SO',
#  'Pinnock {3}SO',
#  'Crump {3}SR',
#  'Bob BEAMONSO',
#  'Davis {2}JR',
#  'Marquis DENDY',
#  'Dendy {2}SO',
#  'Brian JOHNSONSR',
#  'Pinnock {4}SO',
#  'Grimes {3}SR',
#  'Dendy {3}SR',
#  'Lawson {2}',
#  'John MOFFITT',
#  'McLeod {2}JR',
#  'Charlton EHIZUELEN?',
#  'Matthew BOLINGSO',
#  'McLeod {3}JR',
#  'Dendy {4}',
#  'Lewis {3}SO',
#  'Beamon {2}SO',
#  'Dendy {5}',
#  'Pate {4}SR',
#  'Roland MCGHEE',
#  'Davis {3}JR',
#  'Dendy {6}SO',
#  'Savante STRINGFELLOW',
#  'Leroy BURRELLSR',
#  'McLeod {4}SR',
#  'Corey CRAWFORD',
#  'Dendy {7}',
#  'Pate {5}',
#  'Pinnock {5}SO',
#  'Crump {4}SR',
#  'Davis {4}JR',
#  'Grimes {4}SR',
#  'Damar FORBESSR',
#  'Grimes {5}SR',
#  'Roland MCGHEE',
#  'McLeod {5}SR',
#  'McLeod {6}SO',
#  'Will WILLIAMSSR',
#  'Harrison {3}SR',
#  'Grimes {6}SR',
#  'Crawford {2}',
#  'Melvin LISTER']

# %%
len(OfficialReGexNames)
# Out:
# 64

# %%
len(OfficialLengths)
# Out:
# 64

# %%
Schools = []

for i in range(0,len(OfficialLengths)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Alabama',
#  'Houston',
#  'Houston',
#  'LSU',
#  'Arkansas',
#  'Arkansas',
#  'Mississippi State',
#  'Mississippi State',
#  'Arkansas',
#  'Florida State',
#  'Florida State',
#  'Alabama',
#  'Alabama',
#  'Arkansas',
#  'LSU',
#  'Florida State',
#  'Arkansas',
#  'Arkansas',
#  'Jackson State',
#  'Arkansas',
#  'Arkansas',
#  'Mississippi State',
#  'UTEP',
#  'Florida State',
#  'Florida',
#  'Florida',
#  'Southern',
#  'Arkansas',
#  'Florida State',
#  'Florida',
#  'Arkansas',
#  'LSU',
#  'Tennessee',
#  'Illinois',
#  'Georgia',
#  'Tennessee',
#  'Florida',
#  'Houston',
#  'UTEP',
#  'Florida',
#  'Alabama',
#  'Middle Tennessee',
#  'Florida State',
#  'Florida',
#  'Ole Miss',
#  'Houston',
#  'Arkansas',
#  'Rutgers',
#  'Florida',
#  'Alabama',
#  'Arkansas',
#  'Mississippi State',
#  'Florida State',
#  'Florida State',
#  'LSU',
#  'Florida State',
#  'Middle Tennessee',
#  'Arkansas',
#  'Tennessee',
#  'Texas A&M',
#  'LSU',
#  'Florida State',
#  'Rutgers',
#  'Arkansas']

# %%
MenLongJump = pd.DataFrame({'Names': CleanedNames2, 'Length': OfficialLengths, 'Schools': Schools})
MenLongJump.to_csv('IndoorLongJumpMens.csv', index=False)
