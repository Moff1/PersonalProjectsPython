# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
LinkOutdoor4x400m = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?sport=2&gender=1&div=20527&top=25&event=19"

# %%
page = requests.get(LinkOutdoor4x400m)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Team', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Team</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(1) Florida</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:57.74</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Emmanuel BAMIDELE, Jacory PATTERSON, JeVaughn POWELL 44.93, Ryan WILLIE 44.28</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(1) Florida</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:57.74</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Emmanuel BAMIDELE, Jacory PATTERSON, JeVaughn POWELL 44.93, Ryan WILLIE 44.28</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — FLORIDA {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4927313" target="_blank">2:57.76</a><a href="https://www.youtube.com/watch?v=vFQqyoO8puw" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 43.98, Ryan WILLIE 43.32</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — FLORIDA {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4927313" target="_blank">2:57.76</a><a href="https://www.youtube.com/watch?v=vFQqyoO8puw" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 43.98, Ryan WILLIE 43.32</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(2) Arizona State</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona State" class="group-logo-inline" src="/images/logos/rankings-article/arizona-state.png" title="Arizona State"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:57.78</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Dubem NWACHUKWU, Jeremiah CURRY, Jalen DRAYDEN 45.32, Justin ROBINSON 43.91</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(2) Arizona State</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona State" class="group-logo-inline" src="/images/logos/rankings-article/arizona-state.png" title="Arizona State"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:57.78</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Dubem NWACHUKWU, Jeremiah CURRY, Jalen DRAYDEN 45.32, Justin ROBINSON 43.91</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(3) Alabama</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4927313" target="_blank">2:58.01</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Chris ROBINSON, Khaleb MCRAE, Tarsis OROGOT, Corde LONG</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(3) Alabama</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4927313" target="_blank">2:58.01</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Chris ROBINSON, Khaleb MCRAE, Tarsis OROGOT, Corde LONG</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — FLORIDA {3}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73497/4502551" target="_blank">2:58.53</a><a href="https://www.youtube.com/watch?v=fCbhdEvRejQ" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">4/16/2022</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Jacory PATTERSON 44.4, Ryan WILLIE 44.5, Jacob MILEY 46.0, Champion ALLISON 43.6</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — FLORIDA {3}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73497/4502551" target="_blank">2:58.53</a><a href="https://www.youtube.com/watch?v=fCbhdEvRejQ" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Tom Jones Memorial Classic (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">4/16/2022</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Jacory PATTERSON 44.4, Ryan WILLIE 44.5, Jacob MILEY 46.0, Champion ALLISON 43.6</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — FLORIDA {4}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:58.62</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 44.70, Ryan WILLIE 44.53</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — FLORIDA {4}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:58.62</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 44.70, Ryan WILLIE 44.53</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(4) Georgia</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77369/4767334" target="_blank">2:58.82</a><a href="https://www.youtube.com/watch?v=AcPI01t_axA" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="95th Clyde Littlefield Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/1/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Elija GODWIN 44.8, Matthew BOLING 43.7, Caleb CAVANAUGH 45.53, Will SUMNER 44.80</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(4) Georgia</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77369/4767334" target="_blank">2:58.82</a><a href="https://www.youtube.com/watch?v=AcPI01t_axA" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="95th Clyde Littlefield Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/1/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Elija GODWIN 44.8, Matthew BOLING 43.7, Caleb CAVANAUGH 45.53, Will SUMNER 44.80</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — FLORIDA {5}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567539" target="_blank">2:58.88</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2022</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Jacory PATTERSON (JR) 44.8, Ryan WILLIE (SO) 44.2, Jacob MILEY (SO) 45.85, Champion ALLISON (JR) 44.06</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — FLORIDA {5}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75224/4567539" target="_blank">2:58.88</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2022</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Jacory PATTERSON (JR) 44.8, Ryan WILLIE (SO) 44.2, Jacob MILEY (SO) 45.85, Champion ALLISON (JR) 44.06</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(5) Southern California</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57114/3516403" target="_blank">2:59.00</a><a href="https://www.youtube.com/watch?v=1wNcTeMMvtI" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2018</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Ricky Morgan (SR), Rai Benjamin (JR), Zach Shinnick (FR) 45.86, Michael Norman (SO) 43.62</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(5) Southern California</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57114/3516403" target="_blank">2:59.00</a><a href="https://www.youtube.com/watch?v=1wNcTeMMvtI" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2018</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Ricky Morgan (SR), Rai Benjamin (JR), Zach Shinnick (FR) 45.86, Michael Norman (SO) 43.62</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(6) Texas A&amp;M</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850682" target="_blank">2:59.05</a><a href="https://www.youtube.com/watch?v=g20Acgu1Lgo" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2019</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Bryce DEADMON (JR), Robert GRANT (SR), Kyree JOHNSON (SO) 45.24, Devin DIXON (SR) 44.11</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(6) Texas A&amp;M</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850682" target="_blank">2:59.05</a><a href="https://www.youtube.com/watch?v=g20Acgu1Lgo" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2019</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Bryce DEADMON (JR), Robert GRANT (SR), Kyree JOHNSON (SO) 45.24, Devin DIXON (SR) 44.11</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — ARIZONA STATE {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona State" class="group-logo-inline" src="/images/logos/rankings-article/arizona-state.png" title="Arizona State"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:59.14</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Dubem NWACHUKWU, Gamali FELIX, Trevin MOYER, Jeremiah CURRY 43.55</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — ARIZONA STATE {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona State" class="group-logo-inline" src="/images/logos/rankings-article/arizona-state.png" title="Arizona State"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:59.14</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Dubem NWACHUKWU, Gamali FELIX, Trevin MOYER, Jeremiah CURRY 43.55</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — ALABAMA {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77369/4767334" target="_blank">2:59.15</a> </td><td style="width: 10%;text-align:right;" title="95th Clyde Littlefield Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/1/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Khaleb MCRAE 45.0, Tarsis OROGOT 44.0, Leander FORBES 45.15, Chris ROBINSON 45.04</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — ALABAMA {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77369/4767334" target="_blank">2:59.15</a> </td><td style="width: 10%;text-align:right;" title="95th Clyde Littlefield Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/1/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Khaleb MCRAE 45.0, Tarsis OROGOT 44.0, Leander FORBES 45.15, Chris ROBINSON 45.04</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(7) North Carolina A&amp;T</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="North Carolina A&amp;T" class="group-logo-inline" src="/images/logos/rankings-article/north-carolina-at.png" title="North Carolina A&amp;T"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390/4273642" target="_blank">2:59.21</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/29/2021</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.65, Trevor STEWART (SR) 43.70</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(7) North Carolina A&amp;T</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="North Carolina A&amp;T" class="group-logo-inline" src="/images/logos/rankings-article/north-carolina-at.png" title="North Carolina A&amp;T"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390/4273642" target="_blank">2:59.21</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/29/2021</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.65, Trevor STEWART (SR) 43.70</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — ALABAMA {3}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:59.24</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Chris ROBINSON, Corde LONG, Tarsis OROGOT, Khaleb MCRAE</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — ALABAMA {3}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:59.24</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Chris ROBINSON, Corde LONG, Tarsis OROGOT, Khaleb MCRAE</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(8) UCLA</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77369/4767334" target="_blank">2:59.25</a> </td><td style="width: 10%;text-align:right;" title="95th Clyde Littlefield Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/1/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Antonie NORTJE, Willington WRIGHT, Ismail TURNER 44.31, Cameron REYNOLDS 44.49</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(8) UCLA</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77369/4767334" target="_blank">2:59.25</a> </td><td style="width: 10%;text-align:right;" title="95th Clyde Littlefield Texas Relays (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/1/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Antonie NORTJE, Willington WRIGHT, Ismail TURNER 44.31, Cameron REYNOLDS 44.49</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — FLORIDA {6}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4559052" target="_blank">2:59.44</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Jacory PATTERSON, Ryan WILLIE, Jacob MILEY, Champion ALLISON</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — FLORIDA {6}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4559052" target="_blank">2:59.44</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Jacory PATTERSON, Ryan WILLIE, Jacob MILEY, Champion ALLISON</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — UCLA {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:59.51</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Myles MISENER-DALEY, Willington WRIGHT, Antonie NORTJE 44.37, Cameron REYNOLDS 44.13</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — UCLA {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:59.51</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Myles MISENER-DALEY, Willington WRIGHT, Antonie NORTJE 44.37, Cameron REYNOLDS 44.13</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(9) LSU</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;">2:59.59<a href="https://www.youtube.com/watch?v=hvt_wqwXHDc" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2005</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Reggie Dardar 46.4, Kelly Willie 44.4, Bennie Brazell 44.8, Xavier Carter 44.0</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(9) LSU</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;">2:59.59<a href="https://www.youtube.com/watch?v=hvt_wqwXHDc" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2005</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Reggie Dardar 46.4, Kelly Willie 44.4, Bennie Brazell 44.8, Xavier Carter 44.0</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — FLORIDA {7}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850682" target="_blank">2:59.60</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2019</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Benjamin LOBO VEDEL (SO), Chantz SAWYERS (SO), Denzel VILLAMAN (JR) 45.26, Grant HOLLOWAY (JR) 43.74</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — FLORIDA {7}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850682" target="_blank">2:59.60</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2019</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Benjamin LOBO VEDEL (SO), Chantz SAWYERS (SO), Denzel VILLAMAN (JR) 45.26, Grant HOLLOWAY (JR) 43.74</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — TEXAS A&amp;M {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/36208" target="_blank">2:59.60</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/14/2014</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Aldrich Bailey 46.5, Carlyle Roudette 44.7, Bralon Taplin 44.30, Deon Lendore 44.10</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — TEXAS A&amp;M {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/36208" target="_blank">2:59.60</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/14/2014</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Aldrich Bailey 46.5, Carlyle Roudette 44.7, Bralon Taplin 44.30, Deon Lendore 44.10</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — GEORGIA {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4927313" target="_blank">2:59.63</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Elija GODWIN, Matthew BOLING, Christopher MORALES WILLIAM, Will SUMNER</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — GEORGIA {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4927313" target="_blank">2:59.63</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Elija GODWIN, Matthew BOLING, Christopher MORALES WILLIAM, Will SUMNER</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — FLORIDA {8}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/33480/2139649" target="_blank">2:59.73</a> </td><td style="width: 10%;text-align:right;" title="Florida Relays (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">4/5/2014</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Najee Glass, Hugh Graham, Jr, Dedric Dukes, Arman Hall</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — FLORIDA {8}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/33480/2139649" target="_blank">2:59.73</a> </td><td style="width: 10%;text-align:right;" title="Florida Relays (Gainesville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">4/5/2014</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Najee Glass, Hugh Graham, Jr, Dedric Dukes, Arman Hall</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(10) Clemson</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:59.78</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Wanya MCCOY, D'Andre ANDERSON, Aman THORNTON 44.73, Tarees RHODEN 44.42</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(10) Clemson</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:59.78</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Wanya MCCOY, D'Andre ANDERSON, Aman THORNTON 44.73, Tarees RHODEN 44.42</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — UCLA {3}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:59.82</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Antonie NORTJE, Willington WRIGHT, Myles MISENER-DALEY 44.48, Cameron REYNOLDS 44.99</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — UCLA {3}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">2:59.82</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/9/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Antonie NORTJE, Willington WRIGHT, Myles MISENER-DALEY 44.48, Cameron REYNOLDS 44.99</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — TEXAS A&amp;M {3}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57114/3516403" target="_blank">2:59.91</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2018</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Bryce Deadmon (SO), Kyree Johnson (FR), Ilolo Izu (JR) 45.43, Devin Dixon (SO) 43.93</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — TEXAS A&amp;M {3}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57114/3516403" target="_blank">2:59.91</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/8/2018</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Bryce Deadmon (SO), Kyree Johnson (FR), Ilolo Izu (JR) 45.43, Devin Dixon (SO) 43.93</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — UCLA {4}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;">2:59.91  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/4/1988</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Steve Lewis 45.0, Kevin Young 44.4, Danny Everett 45.3, Henry Thomas 45.2</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — UCLA {4}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="UCLA" class="group-logo-inline" src="/images/logos/rankings-article/ucla.png" title="UCLA"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;">2:59.91  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/4/1988</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Steve Lewis 45.0, Kevin Young 44.4, Danny Everett 45.3, Henry Thomas 45.2</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(11) Kentucky</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/74844/4559052" target="_blank">2:59.93</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Oxford, Miss.)"><span class="mark-date" style="width: 10%;text-align:right;">5/14/2022</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Dwight ST HILLAIRE, Lance LANG, Kennedy LIGHTNER, Brian FAUST</td></tr></table></div></td></tr>,
#  <tr></tr>,
# ...
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — OHIO STATE {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Ohio State" class="group-logo-inline" src="/images/logos/rankings-article/ohio-state.png" title="Ohio State"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;">3:01.41  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/6/1992</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — OHIO STATE {3}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Ohio State" class="group-logo-inline" src="/images/logos/rankings-article/ohio-state.png" title="Ohio State"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;">3:01.41  </td><td style="width: 10%;text-align:right;" title=" ((TBA))"><span class="mark-date" style="width: 10%;text-align:right;">1992</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Rich Jones, Aaron Payne, Robert Smith, Chris Nelloms</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — OHIO STATE {3}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Ohio State" class="group-logo-inline" src="/images/logos/rankings-article/ohio-state.png" title="Ohio State"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;">3:01.41  </td><td style="width: 10%;text-align:right;" title=" ((TBA))"><span class="mark-date" style="width: 10%;text-align:right;">1992</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Rich Jones, Aaron Payne, Robert Smith, Chris Nelloms</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — TEXAS A&amp;M {23}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/36169" target="_blank">3:01.42</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West Preliminary (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">5/31/2014</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Carlyle Roudette, Aldrich Bailey, Jr., Bralon Taplin, Deon Lendore</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — TEXAS A&amp;M {23}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/36169" target="_blank">3:01.42</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - West Preliminary (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">5/31/2014</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Carlyle Roudette, Aldrich Bailey, Jr., Bralon Taplin, Deon Lendore</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — BAYLOR {15}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Baylor" class="group-logo-inline" src="/images/logos/rankings-article/baylor.png" title="Baylor"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;">3:01.46  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Durham, N.C.)"><span class="mark-date" style="width: 10%;text-align:right;">6/3/2000</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Zsolt Szeglet 46.3, Bayano Kamani 45.4, Floyd Thompson 45.1, Brandon Couts 44.7</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — BAYLOR {15}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Baylor" class="group-logo-inline" src="/images/logos/rankings-article/baylor.png" title="Baylor"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;">3:01.46  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Durham, N.C.)"><span class="mark-date" style="width: 10%;text-align:right;">6/3/2000</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Zsolt Szeglet 46.3, Bayano Kamani 45.4, Floyd Thompson 45.1, Brandon Couts 44.7</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — OKLAHOMA {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oklahoma" class="group-logo-inline" src="/images/logos/rankings-article/oklahoma.png" title="Oklahoma"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;">3:01.46  </td><td style="width: 10%;text-align:right;" title="Drake Relays (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">4/28/1984</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Aubrey Jones 45.7, Donnie Kemp 44.9, Dannie Carter 45.8, Don Bly 45.1</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — OKLAHOMA {2}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oklahoma" class="group-logo-inline" src="/images/logos/rankings-article/oklahoma.png" title="Oklahoma"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;">3:01.46  </td><td style="width: 10%;text-align:right;" title="Drake Relays (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">4/28/1984</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Aubrey Jones 45.7, Donnie Kemp 44.9, Dannie Carter 45.8, Don Bly 45.1</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — NORTH CAROLINA A&amp;T {4}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="North Carolina A&amp;T" class="group-logo-inline" src="/images/logos/rankings-article/north-carolina-at.png" title="North Carolina A&amp;T"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850682" target="_blank">3:01.50</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2019</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Akeem LINDO (FR), Akeem SIRLEAF (JR), Trevor STEWART (JR) 44.13, Kemarni MIGHTY (JR) 45.22</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — NORTH CAROLINA A&amp;T {4}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="North Carolina A&amp;T" class="group-logo-inline" src="/images/logos/rankings-article/north-carolina-at.png" title="North Carolina A&amp;T"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/62668/3850682" target="_blank">3:01.50</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2019</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Akeem LINDO (FR), Akeem SIRLEAF (JR), Trevor STEWART (JR) 44.13, Kemarni MIGHTY (JR) 45.22</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — GEORGIA {3}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">3:01.51</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Matthew BOLING, Caleb CAVANAUGH, Christopher MORALES WILLIAMS, Will SUMNER</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — GEORGIA {3}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938110" target="_blank">3:01.51</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/7/2023</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Matthew BOLING, Caleb CAVANAUGH, Christopher MORALES WILLIAMS, Will SUMNER</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — TEXAS A&amp;M {24}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72823/4427244" target="_blank">3:01.51</a> </td><td style="width: 10%;text-align:right;" title="Baldy Castillo Invitational (Tempe, Ariz.)"><span class="mark-date" style="width: 10%;text-align:right;">3/19/2022</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">      CHEVANNIE, 7778460 OMAJUWA, 7729602 BRANDON, 7729617 JAMES</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — TEXAS A&amp;M {24}</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72823/4427244" target="_blank">3:01.51</a> </td><td style="width: 10%;text-align:right;" title="Baldy Castillo Invitational (Tempe, Ariz.)"><span class="mark-date" style="width: 10%;text-align:right;">3/19/2022</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">      CHEVANNIE, 7778460 OMAJUWA, 7729602 BRANDON, 7729617 JAMES</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(25) Stephen F. Austin</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stephen F. Austin" class="group-logo-inline" src="/images/logos/rankings-article/stephen-f-austin.png" title="Stephen F. Austin"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276062" target="_blank">3:01.52</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2021</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Muzuri MATTAR (SO), Paul MARTIN (FR), Jeremiah CURRY (SO) 45.89, Auhmad ROBINSON (FR) 43.45</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(25) Stephen F. Austin</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stephen F. Austin" class="group-logo-inline" src="/images/logos/rankings-article/stephen-f-austin.png" title="Stephen F. Austin"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276062" target="_blank">3:01.52</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/11/2021</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     Muzuri MATTAR (SO), Paul MARTIN (FR), Jeremiah CURRY (SO) 45.89, Auhmad ROBINSON (FR) 43.45</td></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">Converted From an Event of Similar Length</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>OKLAHOMA</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oklahoma" class="group-logo-inline" src="/images/logos/rankings-article/oklahoma.png" title="Oklahoma"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;">3:00.26c  </td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Waco, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/18/1997</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>OKLAHOMA</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oklahoma" class="group-logo-inline" src="/images/logos/rankings-article/oklahoma.png" title="Oklahoma"/></span></td><td style="width: 25%;"> </td><td style="width: 25%;">3:00.26c  </td><td style="width: 10%;text-align:right;" title="Big 12 Outdoor Championships (Waco, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">5/18/1997</span></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Florida\xa02:57.74 6/9/2023\xa0\xa0\xa0\xa0\xa0Emmanuel BAMIDELE, Jacory PATTERSON, JeVaughn POWELL 44.93, Ryan WILLIE 44.28',
#   '(1) Florida',
#   '',
#   '\xa0',
#   '2:57.74 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Emmanuel BAMIDELE, Jacory PATTERSON, JeVaughn POWELL 44.93, Ryan WILLIE 44.28'],
#  [],
#  ['(1) Florida', '', '\xa0', '2:57.74 ', '6/9/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Emmanuel BAMIDELE, Jacory PATTERSON, JeVaughn POWELL 44.93, Ryan WILLIE 44.28'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {2}\xa02:57.76📺 5/13/2023\xa0\xa0\xa0\xa0\xa0JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 43.98, Ryan WILLIE 43.32',
#   '\xa0\xa0\xa0\xa0— FLORIDA {2}',
#   '',
#   '\xa0',
#   '2:57.76📺 ',
#   '5/13/2023',
#   '\xa0\xa0\xa0\xa0\xa0JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 43.98, Ryan WILLIE 43.32'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {2}', '', '\xa0', '2:57.76📺 ', '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 43.98, Ryan WILLIE 43.32'],
#  ['(2) Arizona State\xa02:57.78 6/9/2023\xa0\xa0\xa0\xa0\xa0Dubem NWACHUKWU, Jeremiah CURRY, Jalen DRAYDEN 45.32, Justin ROBINSON 43.91',
#   '(2) Arizona State',
#   '',
#   '\xa0',
#   '2:57.78 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Dubem NWACHUKWU, Jeremiah CURRY, Jalen DRAYDEN 45.32, Justin ROBINSON 43.91'],
#  [],
#  ['(2) Arizona State', '', '\xa0', '2:57.78 ', '6/9/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Dubem NWACHUKWU, Jeremiah CURRY, Jalen DRAYDEN 45.32, Justin ROBINSON 43.91'],
#  ['(3) Alabama\xa02:58.01 5/13/2023\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Khaleb MCRAE, Tarsis OROGOT, Corde LONG',
#   '(3) Alabama',
#   '',
#   '\xa0',
#   '2:58.01 ',
#   '5/13/2023',
#   '\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Khaleb MCRAE, Tarsis OROGOT, Corde LONG'],
#  [],
#  ['(3) Alabama', '', '\xa0', '2:58.01 ', '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Khaleb MCRAE, Tarsis OROGOT, Corde LONG'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {3}\xa02:58.53📺 4/16/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON 44.4, Ryan WILLIE 44.5, Jacob MILEY 46.0, Champion ALLISON 43.6',
#   '\xa0\xa0\xa0\xa0— FLORIDA {3}',
#   '',
#   '\xa0',
#   '2:58.53📺 ',
#   '4/16/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON 44.4, Ryan WILLIE 44.5, Jacob MILEY 46.0, Champion ALLISON 43.6'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {3}', '', '\xa0', '2:58.53📺 ', '4/16/2022'],
#  ['\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON 44.4, Ryan WILLIE 44.5, Jacob MILEY 46.0, Champion ALLISON 43.6'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {4}\xa02:58.62 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 44.70, Ryan WILLIE 44.53',
#   '\xa0\xa0\xa0\xa0— FLORIDA {4}',
#   '',
#   '\xa0',
#   '2:58.62 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 44.70, Ryan WILLIE 44.53'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {4}',
#   '',
#   '\xa0',
#   '2:58.62 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 44.70, Ryan WILLIE 44.53'],
#  ['(4) Georgia\xa02:58.82📺 4/1/2023\xa0\xa0\xa0\xa0\xa0Elija GODWIN 44.8, Matthew BOLING 43.7, Caleb CAVANAUGH 45.53, Will SUMNER 44.80',
#   '(4) Georgia',
#   '',
#   '\xa0',
#   '2:58.82📺 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Elija GODWIN 44.8, Matthew BOLING 43.7, Caleb CAVANAUGH 45.53, Will SUMNER 44.80'],
#  [],
#  ['(4) Georgia', '', '\xa0', '2:58.82📺 ', '4/1/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Elija GODWIN 44.8, Matthew BOLING 43.7, Caleb CAVANAUGH 45.53, Will SUMNER 44.80'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {5}\xa02:58.88 6/10/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON (JR) 44.8, Ryan WILLIE (SO) 44.2, Jacob MILEY (SO) 45.85, Champion ALLISON (JR) 44.06',
#   '\xa0\xa0\xa0\xa0— FLORIDA {5}',
#   '',
#   '\xa0',
#   '2:58.88 ',
#   '6/10/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON (JR) 44.8, Ryan WILLIE (SO) 44.2, Jacob MILEY (SO) 45.85, Champion ALLISON (JR) 44.06'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {5}', '', '\xa0', '2:58.88 ', '6/10/2022'],
#  ['\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON (JR) 44.8, Ryan WILLIE (SO) 44.2, Jacob MILEY (SO) 45.85, Champion ALLISON (JR) 44.06'],
#  ['(5) Southern California\xa02:59.00📺 6/8/2018\xa0\xa0\xa0\xa0\xa0Ricky Morgan (SR), Rai Benjamin (JR), Zach Shinnick (FR) 45.86, Michael Norman (SO) 43.62',
#   '(5) Southern California',
#   '',
#   '\xa0',
#   '2:59.00📺 ',
#   '6/8/2018',
#   '\xa0\xa0\xa0\xa0\xa0Ricky Morgan (SR), Rai Benjamin (JR), Zach Shinnick (FR) 45.86, Michael Norman (SO) 43.62'],
#  [],
#  ['(5) Southern California', '', '\xa0', '2:59.00📺 ', '6/8/2018'],
#  ['\xa0\xa0\xa0\xa0\xa0Ricky Morgan (SR), Rai Benjamin (JR), Zach Shinnick (FR) 45.86, Michael Norman (SO) 43.62'],
#  ['(6) Texas A&M\xa02:59.05📺 6/7/2019\xa0\xa0\xa0\xa0\xa0Bryce DEADMON (JR), Robert GRANT (SR), Kyree JOHNSON (SO) 45.24, Devin DIXON (SR) 44.11',
#   '(6) Texas A&M',
#   '',
#   '\xa0',
#   '2:59.05📺 ',
#   '6/7/2019',
#   '\xa0\xa0\xa0\xa0\xa0Bryce DEADMON (JR), Robert GRANT (SR), Kyree JOHNSON (SO) 45.24, Devin DIXON (SR) 44.11'],
#  [],
#  ['(6) Texas A&M', '', '\xa0', '2:59.05📺 ', '6/7/2019'],
#  ['\xa0\xa0\xa0\xa0\xa0Bryce DEADMON (JR), Robert GRANT (SR), Kyree JOHNSON (SO) 45.24, Devin DIXON (SR) 44.11'],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {2}\xa02:59.14 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Dubem NWACHUKWU, Gamali FELIX, Trevin MOYER, Jeremiah CURRY 43.55',
#   '\xa0\xa0\xa0\xa0— ARIZONA STATE {2}',
#   '',
#   '\xa0',
#   '2:59.14 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Dubem NWACHUKWU, Gamali FELIX, Trevin MOYER, Jeremiah CURRY 43.55'],
#  [],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {2}',
#   '',
#   '\xa0',
#   '2:59.14 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Dubem NWACHUKWU, Gamali FELIX, Trevin MOYER, Jeremiah CURRY 43.55'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {2}\xa02:59.15 4/1/2023\xa0\xa0\xa0\xa0\xa0Khaleb MCRAE 45.0, Tarsis OROGOT 44.0, Leander FORBES 45.15, Chris ROBINSON 45.04',
#   '\xa0\xa0\xa0\xa0— ALABAMA {2}',
#   '',
#   '\xa0',
#   '2:59.15 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Khaleb MCRAE 45.0, Tarsis OROGOT 44.0, Leander FORBES 45.15, Chris ROBINSON 45.04'],
#  [],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {2}', '', '\xa0', '2:59.15 ', '4/1/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Khaleb MCRAE 45.0, Tarsis OROGOT 44.0, Leander FORBES 45.15, Chris ROBINSON 45.04'],
#  ['(7) North Carolina A&T\xa02:59.21 qq = Performance occurred during a non-final round. 5/29/2021\xa0\xa0\xa0\xa0\xa0Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.65, Trevor STEWART (SR) 43.70',
#   '(7) North Carolina A&T',
#   '',
#   '\xa0',
#   '2:59.21 qq = Performance occurred during a non-final round. ',
#   '5/29/2021',
#   '\xa0\xa0\xa0\xa0\xa0Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.65, Trevor STEWART (SR) 43.70'],
#  [],
#  ['(7) North Carolina A&T',
#   '',
#   '\xa0',
#   '2:59.21 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0\xa0Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.65, Trevor STEWART (SR) 43.70'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {3}\xa02:59.24 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Corde LONG, Tarsis OROGOT, Khaleb MCRAE',
#   '\xa0\xa0\xa0\xa0— ALABAMA {3}',
#   '',
#   '\xa0',
#   '2:59.24 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Corde LONG, Tarsis OROGOT, Khaleb MCRAE'],
#  [],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {3}',
#   '',
#   '\xa0',
#   '2:59.24 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Corde LONG, Tarsis OROGOT, Khaleb MCRAE'],
#  ['(8) UCLA\xa02:59.25 4/1/2023\xa0\xa0\xa0\xa0\xa0Antonie NORTJE, Willington WRIGHT, Ismail TURNER 44.31, Cameron REYNOLDS 44.49',
#   '(8) UCLA',
#   '',
#   '\xa0',
#   '2:59.25 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Antonie NORTJE, Willington WRIGHT, Ismail TURNER 44.31, Cameron REYNOLDS 44.49'],
#  [],
#  ['(8) UCLA', '', '\xa0', '2:59.25 ', '4/1/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Antonie NORTJE, Willington WRIGHT, Ismail TURNER 44.31, Cameron REYNOLDS 44.49'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {6}\xa02:59.44 5/14/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON, Ryan WILLIE, Jacob MILEY, Champion ALLISON',
#   '\xa0\xa0\xa0\xa0— FLORIDA {6}',
#   '',
#   '\xa0',
#   '2:59.44 ',
#   '5/14/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON, Ryan WILLIE, Jacob MILEY, Champion ALLISON'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {6}', '', '\xa0', '2:59.44 ', '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON, Ryan WILLIE, Jacob MILEY, Champion ALLISON'],
#  ['\xa0\xa0\xa0\xa0— UCLA {2}\xa02:59.51 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Myles MISENER-DALEY, Willington WRIGHT, Antonie NORTJE 44.37, Cameron REYNOLDS 44.13',
#   '\xa0\xa0\xa0\xa0— UCLA {2}',
#   '',
#   '\xa0',
#   '2:59.51 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Myles MISENER-DALEY, Willington WRIGHT, Antonie NORTJE 44.37, Cameron REYNOLDS 44.13'],
#  [],
#  ['\xa0\xa0\xa0\xa0— UCLA {2}',
#   '',
#   '\xa0',
#   '2:59.51 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Myles MISENER-DALEY, Willington WRIGHT, Antonie NORTJE 44.37, Cameron REYNOLDS 44.13'],
#  ['(9) LSU\xa02:59.59📺 6/11/2005\xa0\xa0\xa0\xa0\xa0Reggie Dardar 46.4, Kelly Willie 44.4, Bennie Brazell 44.8, Xavier Carter 44.0',
#   '(9) LSU',
#   '',
#   '\xa0',
#   '2:59.59📺 ',
#   '6/11/2005',
#   '\xa0\xa0\xa0\xa0\xa0Reggie Dardar 46.4, Kelly Willie 44.4, Bennie Brazell 44.8, Xavier Carter 44.0'],
#  [],
#  ['(9) LSU', '', '\xa0', '2:59.59📺 ', '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0\xa0Reggie Dardar 46.4, Kelly Willie 44.4, Bennie Brazell 44.8, Xavier Carter 44.0'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {7}\xa02:59.60 6/7/2019\xa0\xa0\xa0\xa0\xa0Benjamin LOBO VEDEL (SO), Chantz SAWYERS (SO), Denzel VILLAMAN (JR) 45.26, Grant HOLLOWAY (JR) 43.74',
#   '\xa0\xa0\xa0\xa0— FLORIDA {7}',
#   '',
#   '\xa0',
#   '2:59.60 ',
#   '6/7/2019',
#   '\xa0\xa0\xa0\xa0\xa0Benjamin LOBO VEDEL (SO), Chantz SAWYERS (SO), Denzel VILLAMAN (JR) 45.26, Grant HOLLOWAY (JR) 43.74'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {7}', '', '\xa0', '2:59.60 ', '6/7/2019'],
#  ['\xa0\xa0\xa0\xa0\xa0Benjamin LOBO VEDEL (SO), Chantz SAWYERS (SO), Denzel VILLAMAN (JR) 45.26, Grant HOLLOWAY (JR) 43.74'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {2}\xa02:59.60 6/14/2014\xa0\xa0\xa0\xa0\xa0Aldrich Bailey 46.5, Carlyle Roudette 44.7, Bralon Taplin 44.30, Deon Lendore 44.10',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {2}',
#   '',
#   '\xa0',
#   '2:59.60 ',
#   '6/14/2014',
#   '\xa0\xa0\xa0\xa0\xa0Aldrich Bailey 46.5, Carlyle Roudette 44.7, Bralon Taplin 44.30, Deon Lendore 44.10'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {2}', '', '\xa0', '2:59.60 ', '6/14/2014'],
#  ['\xa0\xa0\xa0\xa0\xa0Aldrich Bailey 46.5, Carlyle Roudette 44.7, Bralon Taplin 44.30, Deon Lendore 44.10'],
#  ['\xa0\xa0\xa0\xa0— GEORGIA {2}\xa02:59.63 5/13/2023\xa0\xa0\xa0\xa0\xa0Elija GODWIN, Matthew BOLING, Christopher MORALES WILLIAM, Will SUMNER',
#   '\xa0\xa0\xa0\xa0— GEORGIA {2}',
#   '',
#   '\xa0',
#   '2:59.63 ',
#   '5/13/2023',
#   '\xa0\xa0\xa0\xa0\xa0Elija GODWIN, Matthew BOLING, Christopher MORALES WILLIAM, Will SUMNER'],
#  [],
#  ['\xa0\xa0\xa0\xa0— GEORGIA {2}', '', '\xa0', '2:59.63 ', '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Elija GODWIN, Matthew BOLING, Christopher MORALES WILLIAM, Will SUMNER'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {8}\xa02:59.73 4/5/2014\xa0\xa0\xa0\xa0\xa0Najee Glass, Hugh Graham, Jr, Dedric Dukes, Arman Hall',
#   '\xa0\xa0\xa0\xa0— FLORIDA {8}',
#   '',
#   '\xa0',
#   '2:59.73 ',
#   '4/5/2014',
#   '\xa0\xa0\xa0\xa0\xa0Najee Glass, Hugh Graham, Jr, Dedric Dukes, Arman Hall'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {8}', '', '\xa0', '2:59.73 ', '4/5/2014'],
#  ['\xa0\xa0\xa0\xa0\xa0Najee Glass, Hugh Graham, Jr, Dedric Dukes, Arman Hall'],
#  ["(10) Clemson\xa02:59.78 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Wanya MCCOY, D'Andre ANDERSON, Aman THORNTON 44.73, Tarees RHODEN 44.42",
#   '(10) Clemson',
#   '',
#   '\xa0',
#   '2:59.78 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   "\xa0\xa0\xa0\xa0\xa0Wanya MCCOY, D'Andre ANDERSON, Aman THORNTON 44.73, Tarees RHODEN 44.42"],
#  [],
#  ['(10) Clemson',
#   '',
#   '\xa0',
#   '2:59.78 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ["\xa0\xa0\xa0\xa0\xa0Wanya MCCOY, D'Andre ANDERSON, Aman THORNTON 44.73, Tarees RHODEN 44.42"],
#  ['\xa0\xa0\xa0\xa0— UCLA {3}\xa02:59.82 6/9/2023\xa0\xa0\xa0\xa0\xa0Antonie NORTJE, Willington WRIGHT, Myles MISENER-DALEY 44.48, Cameron REYNOLDS 44.99',
#   '\xa0\xa0\xa0\xa0— UCLA {3}',
#   '',
#   '\xa0',
#   '2:59.82 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Antonie NORTJE, Willington WRIGHT, Myles MISENER-DALEY 44.48, Cameron REYNOLDS 44.99'],
#  [],
#  ['\xa0\xa0\xa0\xa0— UCLA {3}', '', '\xa0', '2:59.82 ', '6/9/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Antonie NORTJE, Willington WRIGHT, Myles MISENER-DALEY 44.48, Cameron REYNOLDS 44.99'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {3}\xa02:59.91 6/8/2018\xa0\xa0\xa0\xa0\xa0Bryce Deadmon (SO), Kyree Johnson (FR), Ilolo Izu (JR) 45.43, Devin Dixon (SO) 43.93',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {3}',
#   '',
#   '\xa0',
#   '2:59.91 ',
#   '6/8/2018',
#   '\xa0\xa0\xa0\xa0\xa0Bryce Deadmon (SO), Kyree Johnson (FR), Ilolo Izu (JR) 45.43, Devin Dixon (SO) 43.93'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {3}', '', '\xa0', '2:59.91 ', '6/8/2018'],
#  ['\xa0\xa0\xa0\xa0\xa0Bryce Deadmon (SO), Kyree Johnson (FR), Ilolo Izu (JR) 45.43, Devin Dixon (SO) 43.93'],
#  ['\xa0\xa0\xa0\xa0— UCLA {4}\xa02:59.91  6/4/1988\xa0\xa0\xa0\xa0\xa0Steve Lewis 45.0, Kevin Young 44.4, Danny Everett 45.3, Henry Thomas 45.2',
#   '\xa0\xa0\xa0\xa0— UCLA {4}',
#   '',
#   '\xa0',
#   '2:59.91  ',
#   '6/4/1988',
#   '\xa0\xa0\xa0\xa0\xa0Steve Lewis 45.0, Kevin Young 44.4, Danny Everett 45.3, Henry Thomas 45.2'],
#  [],
#  ['\xa0\xa0\xa0\xa0— UCLA {4}', '', '\xa0', '2:59.91  ', '6/4/1988'],
#  ['\xa0\xa0\xa0\xa0\xa0Steve Lewis 45.0, Kevin Young 44.4, Danny Everett 45.3, Henry Thomas 45.2'],
#  ['(11) Kentucky\xa02:59.93 5/14/2022\xa0\xa0\xa0\xa0\xa0Dwight ST HILLAIRE, Lance LANG, Kennedy LIGHTNER, Brian FAUST',
#   '(11) Kentucky',
#   '',
#   '\xa0',
#   '2:59.93 ',
#   '5/14/2022',
#   '\xa0\xa0\xa0\xa0\xa0Dwight ST HILLAIRE, Lance LANG, Kennedy LIGHTNER, Brian FAUST'],
#  [],
#  ['(11) Kentucky', '', '\xa0', '2:59.93 ', '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0\xa0Dwight ST HILLAIRE, Lance LANG, Kennedy LIGHTNER, Brian FAUST'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {4}\xa02:59.95 qq = Performance occurred during a non-final round. 6/10/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Mylik Kerley (JR), Robert Grant (JR) 45.16, Fred Kerley (SR) 43.96',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {4}',
#   '',
#   '\xa0',
#   '2:59.95 qq = Performance occurred during a non-final round. ',
#   '6/10/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Mylik Kerley (JR), Robert Grant (JR) 45.16, Fred Kerley (SR) 43.96'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {4}',
#   '',
#   '\xa0',
#   '2:59.95 qq = Performance occurred during a non-final round. ',
#   '6/10/2017'],
#  ['\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Mylik Kerley (JR), Robert Grant (JR) 45.16, Fred Kerley (SR) 43.96'],
#  ['(12) Georgia Tech\xa02:59.95  6/6/1992\xa0\xa0\xa0\xa0\xa0Octavius Terry 45.6, Julian Amedee 45.5, Derrick Adkins 45.0, Derek Mills 43.9',
#   '(12) Georgia Tech',
#   '',
#   '\xa0',
#   '2:59.95  ',
#   '6/6/1992',
#   '\xa0\xa0\xa0\xa0\xa0Octavius Terry 45.6, Julian Amedee 45.5, Derrick Adkins 45.0, Derek Mills 43.9'],
#  [],
#  ['(12) Georgia Tech', '', '\xa0', '2:59.95  ', '6/6/1992'],
#  ['\xa0\xa0\xa0\xa0\xa0Octavius Terry 45.6, Julian Amedee 45.5, Derrick Adkins 45.0, Derek Mills 43.9'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {2}\xa02:59.98 6/10/2022\xa0\xa0\xa0\xa0\xa0Nicholas RAMEY (SR) 46.4, Zach SHINNICK (SR) 44.6, Johnnie BLOCKBURGER (JR) 44.26, Kasaun JAMES (SR) 44.78',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {2}',
#   '',
#   '\xa0',
#   '2:59.98 ',
#   '6/10/2022',
#   '\xa0\xa0\xa0\xa0\xa0Nicholas RAMEY (SR) 46.4, Zach SHINNICK (SR) 44.6, Johnnie BLOCKBURGER (JR) 44.26, Kasaun JAMES (SR) 44.78'],
#  [],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {2}',
#   '',
#   '\xa0',
#   '2:59.98 ',
#   '6/10/2022'],
#  ['\xa0\xa0\xa0\xa0\xa0Nicholas RAMEY (SR) 46.4, Zach SHINNICK (SR) 44.6, Johnnie BLOCKBURGER (JR) 44.26, Kasaun JAMES (SR) 44.78'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {5}\xa02:59.98 6/10/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO) 46.7h, Mylik Kerley (JR) 44.2h, Robert Grant (JR) 45.11, Fred Kerley (SR) 43.99',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {5}',
#   '',
#   '\xa0',
#   '2:59.98 ',
#   '6/10/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO) 46.7h, Mylik Kerley (JR) 44.2h, Robert Grant (JR) 45.11, Fred Kerley (SR) 43.99'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {5}', '', '\xa0', '2:59.98 ', '6/10/2017'],
#  ['\xa0\xa0\xa0\xa0\xa0Richard Rose (SO) 46.7h, Mylik Kerley (JR) 44.2h, Robert Grant (JR) 45.11, Fred Kerley (SR) 43.99'],
#  ['(13) Florida State\xa02:59.99  6/13/2009\xa0\xa0\xa0\xa0\xa0Kevin Williams 46.6, Kevin Borlée 43.8, Charles Clark 45.85, Jonathan Borlée 43.78',
#   '(13) Florida State',
#   '',
#   '\xa0',
#   '2:59.99  ',
#   '6/13/2009',
#   '\xa0\xa0\xa0\xa0\xa0Kevin Williams 46.6, Kevin Borlée 43.8, Charles Clark 45.85, Jonathan Borlée 43.78'],
#  [],
#  ['(13) Florida State', '', '\xa0', '2:59.99  ', '6/13/2009'],
#  ['\xa0\xa0\xa0\xa0\xa0Kevin Williams 46.6, Kevin Borlée 43.8, Charles Clark 45.85, Jonathan Borlée 43.78'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {9}\xa03:00.02 6/9/2012\xa0\xa0\xa0\xa0\xa0Dedric Dukes 45.6, Hugh Graham 45.1, Leonardo Seymore 45.31, Tony McQuay 44.00',
#   '\xa0\xa0\xa0\xa0— FLORIDA {9}',
#   '',
#   '\xa0',
#   '3:00.02 ',
#   '6/9/2012',
#   '\xa0\xa0\xa0\xa0\xa0Dedric Dukes 45.6, Hugh Graham 45.1, Leonardo Seymore 45.31, Tony McQuay 44.00'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {9}', '', '\xa0', '3:00.02 ', '6/9/2012'],
#  ['\xa0\xa0\xa0\xa0\xa0Dedric Dukes 45.6, Hugh Graham 45.1, Leonardo Seymore 45.31, Tony McQuay 44.00'],
#  ['(14) Baylor\xa03:00.04  6/9/2007\xa0\xa0\xa0\xa0\xa0Reggie Witherspoon 45.6, LeJerald Betters 44.4, Kevin Mutai 45.18, Quentin Iglehart-Summers 44.88',
#   '(14) Baylor',
#   '',
#   '\xa0',
#   '3:00.04  ',
#   '6/9/2007',
#   '\xa0\xa0\xa0\xa0\xa0Reggie Witherspoon 45.6, LeJerald Betters 44.4, Kevin Mutai 45.18, Quentin Iglehart-Summers 44.88'],
#  [],
#  ['(14) Baylor', '', '\xa0', '3:00.04  ', '6/9/2007'],
#  ['\xa0\xa0\xa0\xa0\xa0Reggie Witherspoon 45.6, LeJerald Betters 44.4, Kevin Mutai 45.18, Quentin Iglehart-Summers 44.88'],
#  ['(15) Houston\xa03:00.07 6/7/2019\xa0\xa0\xa0\xa0\xa0Amere LATTIN (SR), Kahmari MONTGOMERY (SR), Jermaine HOLT (JR) 45.26, Obi IGBOKWE (SR) 44.40',
#   '(15) Houston',
#   '',
#   '\xa0',
#   '3:00.07 ',
#   '6/7/2019',
#   '\xa0\xa0\xa0\xa0\xa0Amere LATTIN (SR), Kahmari MONTGOMERY (SR), Jermaine HOLT (JR) 45.26, Obi IGBOKWE (SR) 44.40'],
#  [],
#  ['(15) Houston', '', '\xa0', '3:00.07 ', '6/7/2019'],
#  ['\xa0\xa0\xa0\xa0\xa0Amere LATTIN (SR), Kahmari MONTGOMERY (SR), Jermaine HOLT (JR) 45.26, Obi IGBOKWE (SR) 44.40'],
#  ["(16) Iowa\xa03:00.14 6/7/2019\xa0\xa0\xa0\xa0\xa0Wayne LAWRENCE JR. (FR), Antonio WOODARD (JR), Karayme BARTLEY (JR) 44.22, Mar'yea HARRIS (SR) 44.75",
#   '(16) Iowa',
#   '',
#   '\xa0',
#   '3:00.14 ',
#   '6/7/2019',
#   "\xa0\xa0\xa0\xa0\xa0Wayne LAWRENCE JR. (FR), Antonio WOODARD (JR), Karayme BARTLEY (JR) 44.22, Mar'yea HARRIS (SR) 44.75"],
#  [],
#  ['(16) Iowa', '', '\xa0', '3:00.14 ', '6/7/2019'],
#  ["\xa0\xa0\xa0\xa0\xa0Wayne LAWRENCE JR. (FR), Antonio WOODARD (JR), Karayme BARTLEY (JR) 44.22, Mar'yea HARRIS (SR) 44.75"],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {4}\xa03:00.17 6/10/2022\xa0\xa0\xa0\xa0\xa0Leander FORBES (JR) 46.5, Demetrius JACKSON (JR) 44.6, Corde LONG (SO) 44.77, Khaleb MCRAE (SO) 44.28',
#   '\xa0\xa0\xa0\xa0— ALABAMA {4}',
#   '',
#   '\xa0',
#   '3:00.17 ',
#   '6/10/2022',
#   '\xa0\xa0\xa0\xa0\xa0Leander FORBES (JR) 46.5, Demetrius JACKSON (JR) 44.6, Corde LONG (SO) 44.77, Khaleb MCRAE (SO) 44.28'],
#  [],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {4}', '', '\xa0', '3:00.17 ', '6/10/2022'],
#  ['\xa0\xa0\xa0\xa0\xa0Leander FORBES (JR) 46.5, Demetrius JACKSON (JR) 44.6, Corde LONG (SO) 44.77, Khaleb MCRAE (SO) 44.28'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {2}\xa03:00.22  6/14/2008\xa0\xa0\xa0\xa0\xa0Marcus Boyd 45.8, Justin Boyd 45.5, LeJerald Betters 44.37, Quentin Iglehart-Summers 44.50',
#   '\xa0\xa0\xa0\xa0— BAYLOR {2}',
#   '',
#   '\xa0',
#   '3:00.22  ',
#   '6/14/2008',
#   '\xa0\xa0\xa0\xa0\xa0Marcus Boyd 45.8, Justin Boyd 45.5, LeJerald Betters 44.37, Quentin Iglehart-Summers 44.50'],
#  [],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {2}', '', '\xa0', '3:00.22  ', '6/14/2008'],
#  ['\xa0\xa0\xa0\xa0\xa0Marcus Boyd 45.8, Justin Boyd 45.5, LeJerald Betters 44.37, Quentin Iglehart-Summers 44.50'],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {2}\xa03:00.23 3/27/2021\xa0\xa0\xa0\xa0\xa0Stokes, Ross, Young, Stewart',
#   '\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {2}',
#   '',
#   '\xa0',
#   '3:00.23 ',
#   '3/27/2021',
#   '\xa0\xa0\xa0\xa0\xa0Stokes, Ross, Young, Stewart'],
#  [],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {2}',
#   '',
#   '\xa0',
#   '3:00.23 ',
#   '3/27/2021'],
#  ['\xa0\xa0\xa0\xa0\xa0Stokes, Ross, Young, Stewart'],
#  ['(17) Texas\xa03:00.31 qq = Performance occurred during a non-final round. 6/8/2022\xa0\xa0\xa0\xa0\xa0Jon MAAS (SR), Jonathan JONES (JR), Willington WRIGHT (JR) 44.34, Brian HERRON (SO) 44.72',
#   '(17) Texas',
#   '',
#   '\xa0',
#   '3:00.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jon MAAS (SR), Jonathan JONES (JR), Willington WRIGHT (JR) 44.34, Brian HERRON (SO) 44.72'],
#  [],
#  ['(17) Texas',
#   '',
#   '\xa0',
#   '3:00.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2022'],
#  ['\xa0\xa0\xa0\xa0\xa0Jon MAAS (SR), Jonathan JONES (JR), Willington WRIGHT (JR) 44.34, Brian HERRON (SO) 44.72'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {10}\xa03:00.31  4/3/2010',
#   '\xa0\xa0\xa0\xa0— FLORIDA {10}',
#   '',
#   '\xa0',
#   '3:00.31  ',
#   '4/3/2010'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {10}', '', '\xa0', '3:00.31  ', '4/3/2010'],
#  ['\xa0\xa0\xa0\xa0— LSU {2}\xa03:00.38 4/23/2016\xa0\xa0\xa0\xa0\xa0Lamar Bruton, Michael Cherry, Cyril Grayson, Fitzroy Dunkley',
#   '\xa0\xa0\xa0\xa0— LSU {2}',
#   '',
#   '\xa0',
#   '3:00.38 ',
#   '4/23/2016',
#   '\xa0\xa0\xa0\xa0\xa0Lamar Bruton, Michael Cherry, Cyril Grayson, Fitzroy Dunkley'],
#  [],
#  ['\xa0\xa0\xa0\xa0— LSU {2}', '', '\xa0', '3:00.38 ', '4/23/2016'],
#  ['\xa0\xa0\xa0\xa0\xa0Lamar Bruton, Michael Cherry, Cyril Grayson, Fitzroy Dunkley'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {5}\xa03:00.42 qq = Performance occurred during a non-final round. 6/8/2022\xa0\xa0\xa0\xa0\xa0Leander FORBES (JR), Demetrius JACKSON (JR), Corde LONG (SO) 44.44, Khaleb MCRAE (SO) 44.06',
#   '\xa0\xa0\xa0\xa0— ALABAMA {5}',
#   '',
#   '\xa0',
#   '3:00.42 qq = Performance occurred during a non-final round. ',
#   '6/8/2022',
#   '\xa0\xa0\xa0\xa0\xa0Leander FORBES (JR), Demetrius JACKSON (JR), Corde LONG (SO) 44.44, Khaleb MCRAE (SO) 44.06'],
#  [],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {5}',
#   '',
#   '\xa0',
#   '3:00.42 qq = Performance occurred during a non-final round. ',
#   '6/8/2022'],
#  ['\xa0\xa0\xa0\xa0\xa0Leander FORBES (JR), Demetrius JACKSON (JR), Corde LONG (SO) 44.44, Khaleb MCRAE (SO) 44.06'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {11}\xa03:00.42 6/14/2014\xa0\xa0\xa0\xa0\xa0Najee Glass 46.1, Hugh Graham 45.0, Dedric Dukes 44.59, Arman Hall 44.73',
#   '\xa0\xa0\xa0\xa0— FLORIDA {11}',
#   '',
#   '\xa0',
#   '3:00.42 ',
#   '6/14/2014',
#   '\xa0\xa0\xa0\xa0\xa0Najee Glass 46.1, Hugh Graham 45.0, Dedric Dukes 44.59, Arman Hall 44.73'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {11}', '', '\xa0', '3:00.42 ', '6/14/2014'],
#  ['\xa0\xa0\xa0\xa0\xa0Najee Glass 46.1, Hugh Graham 45.0, Dedric Dukes 44.59, Arman Hall 44.73'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {6}\xa03:00.45 4/9/2011\xa0\xa0\xa0\xa0\xa0Bryan Miller, Tabarie Henry, Michael Preble, Demetrius Pinder',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {6}',
#   '',
#   '\xa0',
#   '3:00.45 ',
#   '4/9/2011',
#   '\xa0\xa0\xa0\xa0\xa0Bryan Miller, Tabarie Henry, Michael Preble, Demetrius Pinder'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {6}', '', '\xa0', '3:00.45 ', '4/9/2011'],
#  ['\xa0\xa0\xa0\xa0\xa0Bryan Miller, Tabarie Henry, Michael Preble, Demetrius Pinder'],
#  ['\xa0\xa0\xa0\xa0— LSU {3}\xa03:00.48 5/14/2016\xa0\xa0\xa0\xa0\xa0Lamar Bruton, Michael Cherry, Cyril Grayson, Fitzroy Dunkley',
#   '\xa0\xa0\xa0\xa0— LSU {3}',
#   '',
#   '\xa0',
#   '3:00.48 ',
#   '5/14/2016',
#   '\xa0\xa0\xa0\xa0\xa0Lamar Bruton, Michael Cherry, Cyril Grayson, Fitzroy Dunkley'],
#  [],
#  ['\xa0\xa0\xa0\xa0— LSU {3}', '', '\xa0', '3:00.48 ', '5/14/2016'],
#  ['\xa0\xa0\xa0\xa0\xa0Lamar Bruton, Michael Cherry, Cyril Grayson, Fitzroy Dunkley'],
#  ['\xa0\xa0\xa0\xa0— UCLA {5}\xa03:00.55  6/6/1987\xa0\xa0\xa0\xa0\xa0Anthony Washington 47.0, Kevin Young 44.7, Henry Thomas 44.0, Danny Everett 44.9',
#   '\xa0\xa0\xa0\xa0— UCLA {5}',
#   '',
#   '\xa0',
#   '3:00.55  ',
#   '6/6/1987',
#   '\xa0\xa0\xa0\xa0\xa0Anthony Washington 47.0, Kevin Young 44.7, Henry Thomas 44.0, Danny Everett 44.9'],
#  [],
#  ['\xa0\xa0\xa0\xa0— UCLA {5}', '', '\xa0', '3:00.55  ', '6/6/1987'],
#  ['\xa0\xa0\xa0\xa0\xa0Anthony Washington 47.0, Kevin Young 44.7, Henry Thomas 44.0, Danny Everett 44.9'],
#  ['\xa0\xa0\xa0\xa0— LSU {4}\xa03:00.56 6/8/2018\xa0\xa0\xa0\xa0\xa0Jahnoy Thompson (JR), Correion Mosby (JR), Renard Howell (SR), Jaron Flournoy (JR)',
#   '\xa0\xa0\xa0\xa0— LSU {4}',
#   '',
#   '\xa0',
#   '3:00.56 ',
#   '6/8/2018',
#   '\xa0\xa0\xa0\xa0\xa0Jahnoy Thompson (JR), Correion Mosby (JR), Renard Howell (SR), Jaron Flournoy (JR)'],
#  [],
#  ['\xa0\xa0\xa0\xa0— LSU {4}', '', '\xa0', '3:00.56 ', '6/8/2018'],
#  ['\xa0\xa0\xa0\xa0\xa0Jahnoy Thompson (JR), Correion Mosby (JR), Renard Howell (SR), Jaron Flournoy (JR)'],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {3}\xa03:00.57  6/11/2005\xa0\xa0\xa0\xa0\xa0Rich Allen 46.7, Seth Amoo 44.3, Domenick Peterson 45.2, Lewis Banda 44.4',
#   '\xa0\xa0\xa0\xa0— ARIZONA STATE {3}',
#   '',
#   '\xa0',
#   '3:00.57  ',
#   '6/11/2005',
#   '\xa0\xa0\xa0\xa0\xa0Rich Allen 46.7, Seth Amoo 44.3, Domenick Peterson 45.2, Lewis Banda 44.4'],
#  [],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {3}', '', '\xa0', '3:00.57  ', '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0\xa0Rich Allen 46.7, Seth Amoo 44.3, Domenick Peterson 45.2, Lewis Banda 44.4'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {3}\xa03:00.58 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Demar FRANCIS, Nathaniel EZEKIEL, Hasani BARR 44.85, Dillon BEDELL 44.37',
#   '\xa0\xa0\xa0\xa0— BAYLOR {3}',
#   '',
#   '\xa0',
#   '3:00.58 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Demar FRANCIS, Nathaniel EZEKIEL, Hasani BARR 44.85, Dillon BEDELL 44.37'],
#  [],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {3}',
#   '',
#   '\xa0',
#   '3:00.58 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Demar FRANCIS, Nathaniel EZEKIEL, Hasani BARR 44.85, Dillon BEDELL 44.37'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {3}\xa03:00.58  6/6/1992\xa0\xa0\xa0\xa0\xa0Travis Hannah 45.3, Curtis Conway 45.4, Martin Cannady 46.3, Quincy Watts 43.6',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {3}',
#   '',
#   '\xa0',
#   '3:00.58  ',
#   '6/6/1992',
#   '\xa0\xa0\xa0\xa0\xa0Travis Hannah 45.3, Curtis Conway 45.4, Martin Cannady 46.3, Quincy Watts 43.6'],
#  [],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {3}',
#   '',
#   '\xa0',
#   '3:00.58  ',
#   '6/6/1992'],
#  ['\xa0\xa0\xa0\xa0\xa0Travis Hannah 45.3, Curtis Conway 45.4, Martin Cannady 46.3, Quincy Watts 43.6'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {4}\xa03:00.60 qq = Performance occurred during a non-final round. 6/1/1995\xa0\xa0\xa0\xa0\xa0Michael Ford (JR), Raoul Howard (JR), Corey Williams (SR), Deon Minor (SR)',
#   '\xa0\xa0\xa0\xa0— BAYLOR {4}',
#   '',
#   '\xa0',
#   '3:00.60 qq = Performance occurred during a non-final round. ',
#   '6/1/1995',
#   '\xa0\xa0\xa0\xa0\xa0Michael Ford (JR), Raoul Howard (JR), Corey Williams (SR), Deon Minor (SR)'],
#  [],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {4}',
#   '',
#   '\xa0',
#   '3:00.60 qq = Performance occurred during a non-final round. ',
#   '6/1/1995'],
#  ['\xa0\xa0\xa0\xa0\xa0Michael Ford (JR), Raoul Howard (JR), Corey Williams (SR), Deon Minor (SR)'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {5}\xa03:00.61 4/1/2023\xa0\xa0\xa0\xa0\xa0Kamden JACKSON, Matthew MOORER, Dillon BEDELL 45.36, Nathaniel EZEKIEL 44.78',
#   '\xa0\xa0\xa0\xa0— BAYLOR {5}',
#   '',
#   '\xa0',
#   '3:00.61 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Kamden JACKSON, Matthew MOORER, Dillon BEDELL 45.36, Nathaniel EZEKIEL 44.78'],
#  [],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {5}', '', '\xa0', '3:00.61 ', '4/1/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Kamden JACKSON, Matthew MOORER, Dillon BEDELL 45.36, Nathaniel EZEKIEL 44.78'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {6}\xa03:00.61  4/1/1995\xa0\xa0\xa0\xa0\xa0Michael Ford, Raoul Howard, Deon Minor , Marlon Ramsey',
#   '\xa0\xa0\xa0\xa0— BAYLOR {6}',
#   '',
#   '\xa0',
#   '3:00.61  ',
#   '4/1/1995',
#   '\xa0\xa0\xa0\xa0\xa0Michael Ford, Raoul Howard, Deon Minor , Marlon Ramsey'],
#  [],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {6}', '', '\xa0', '3:00.61  ', '4/1/1995'],
#  ['\xa0\xa0\xa0\xa0\xa0Michael Ford, Raoul Howard, Deon Minor , Marlon Ramsey'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {7}\xa03:00.62 6/11/2011\xa0\xa0\xa0\xa0\xa0Bryan Miller 45.5, Demetrius Pinder 44.6, Michael Preble 45.60, Tabarie Henry 44.86',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {7}',
#   '',
#   '\xa0',
#   '3:00.62 ',
#   '6/11/2011',
#   '\xa0\xa0\xa0\xa0\xa0Bryan Miller 45.5, Demetrius Pinder 44.6, Michael Preble 45.60, Tabarie Henry 44.86'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {7}', '', '\xa0', '3:00.62 ', '6/11/2011'],
#  ['\xa0\xa0\xa0\xa0\xa0Bryan Miller 45.5, Demetrius Pinder 44.6, Michael Preble 45.60, Tabarie Henry 44.86'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {4}\xa03:00.64 6/9/2012\xa0\xa0\xa0\xa0\xa0Joey Hughes 45.8, Josh Mance 44.7, Reggie Wyatt 45.30, Bryshon Nellum 44.82',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {4}',
#   '',
#   '\xa0',
#   '3:00.64 ',
#   '6/9/2012',
#   '\xa0\xa0\xa0\xa0\xa0Joey Hughes 45.8, Josh Mance 44.7, Reggie Wyatt 45.30, Bryshon Nellum 44.82'],
#  [],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {4}',
#   '',
#   '\xa0',
#   '3:00.64 ',
#   '6/9/2012'],
#  ['\xa0\xa0\xa0\xa0\xa0Joey Hughes 45.8, Josh Mance 44.7, Reggie Wyatt 45.30, Bryshon Nellum 44.82'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {7}\xa03:00.64  6/6/1992\xa0\xa0\xa0\xa0\xa0Daniel Fredericks 45.8, Tony Miller 44.9, Etheridge Green 45.1, Deon Minor 44.8',
#   '\xa0\xa0\xa0\xa0— BAYLOR {7}',
#   '',
#   '\xa0',
#   '3:00.64  ',
#   '6/6/1992',
#   '\xa0\xa0\xa0\xa0\xa0Daniel Fredericks 45.8, Tony Miller 44.9, Etheridge Green 45.1, Deon Minor 44.8'],
#  [],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {7}', '', '\xa0', '3:00.64  ', '6/6/1992'],
#  ['\xa0\xa0\xa0\xa0\xa0Daniel Fredericks 45.8, Tony Miller 44.9, Etheridge Green 45.1, Deon Minor 44.8'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {12}\xa03:00.68  6/4/1988\xa0\xa0\xa0\xa0\xa0Calvin Long 45.6, Dennis Mitchell 44.4, Timmy Johnson 45.5, Mark Everett 45.2',
#   '\xa0\xa0\xa0\xa0— FLORIDA {12}',
#   '',
#   '\xa0',
#   '3:00.68  ',
#   '6/4/1988',
#   '\xa0\xa0\xa0\xa0\xa0Calvin Long 45.6, Dennis Mitchell 44.4, Timmy Johnson 45.5, Mark Everett 45.2'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {12}', '', '\xa0', '3:00.68  ', '6/4/1988'],
#  ['\xa0\xa0\xa0\xa0\xa0Calvin Long 45.6, Dennis Mitchell 44.4, Timmy Johnson 45.5, Mark Everett 45.2'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {8}\xa03:00.69 qq = Performance occurred during a non-final round. 5/27/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Fred Kerley (SR), Robert Grant (JR) 45.30, Mylik Kerley (JR) 45.30',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {8}',
#   '',
#   '\xa0',
#   '3:00.69 qq = Performance occurred during a non-final round. ',
#   '5/27/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Fred Kerley (SR), Robert Grant (JR) 45.30, Mylik Kerley (JR) 45.30'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {8}',
#   '',
#   '\xa0',
#   '3:00.69 qq = Performance occurred during a non-final round. ',
#   '5/27/2017'],
#  ['\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Fred Kerley (SR), Robert Grant (JR) 45.30, Mylik Kerley (JR) 45.30'],
#  ['\xa0\xa0\xa0\xa0— LSU {5}\xa03:00.69 6/11/2016\xa0\xa0\xa0\xa0\xa0Lamar Bruton (JR) 46.4, Michael Cherry (JR) 44.2, Cyril Grayson (SR) 45.80, Fitzroy Dunkley (SR) 44.29',
#   '\xa0\xa0\xa0\xa0— LSU {5}',
#   '',
#   '\xa0',
#   '3:00.69 ',
#   '6/11/2016',
#   '\xa0\xa0\xa0\xa0\xa0Lamar Bruton (JR) 46.4, Michael Cherry (JR) 44.2, Cyril Grayson (SR) 45.80, Fitzroy Dunkley (SR) 44.29'],
#  [],
#  ['\xa0\xa0\xa0\xa0— LSU {5}', '', '\xa0', '3:00.69 ', '6/11/2016'],
#  ['\xa0\xa0\xa0\xa0\xa0Lamar Bruton (JR) 46.4, Michael Cherry (JR) 44.2, Cyril Grayson (SR) 45.80, Fitzroy Dunkley (SR) 44.29'],
#  ['\xa0\xa0\xa0\xa0— TEXAS {2}\xa03:00.70 qq = Performance occurred during a non-final round. 5/27/2022\xa0\xa0\xa0\xa0\xa0Jon MAAS (SR), Jonathan JONES (JR), Willington WRIGHT (JR), Brian HERRON (SO)',
#   '\xa0\xa0\xa0\xa0— TEXAS {2}',
#   '',
#   '\xa0',
#   '3:00.70 qq = Performance occurred during a non-final round. ',
#   '5/27/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jon MAAS (SR), Jonathan JONES (JR), Willington WRIGHT (JR), Brian HERRON (SO)'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS {2}',
#   '',
#   '\xa0',
#   '3:00.70 qq = Performance occurred during a non-final round. ',
#   '5/27/2022'],
#  ['\xa0\xa0\xa0\xa0\xa0Jon MAAS (SR), Jonathan JONES (JR), Willington WRIGHT (JR), Brian HERRON (SO)'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {9}\xa03:00.72 5/13/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Fred Kerley (SR), Robert Grant (JR) 45.48, Mylik Kerley (JR) 45.00',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {9}',
#   '',
#   '\xa0',
#   '3:00.72 ',
#   '5/13/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Fred Kerley (SR), Robert Grant (JR) 45.48, Mylik Kerley (JR) 45.00'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {9}', '', '\xa0', '3:00.72 ', '5/13/2017'],
#  ['\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Fred Kerley (SR), Robert Grant (JR) 45.48, Mylik Kerley (JR) 45.00'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {8}\xa03:00.73 5/12/2023\xa0\xa0\xa0\xa0\xa0Matthew MOORER, Hasani BARR, Nathaniel EZEKIEL, Dillon BEDELL',
#   '\xa0\xa0\xa0\xa0— BAYLOR {8}',
#   '',
#   '\xa0',
#   '3:00.73 ',
#   '5/12/2023',
#   '\xa0\xa0\xa0\xa0\xa0Matthew MOORER, Hasani BARR, Nathaniel EZEKIEL, Dillon BEDELL'],
#  [],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {8}', '', '\xa0', '3:00.73 ', '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Matthew MOORER, Hasani BARR, Nathaniel EZEKIEL, Dillon BEDELL'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {10}\xa03:00.74 4/29/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO) 45.8h, Fred Kerley (SR) 43.7h, Devin Dixon (FR) 46.22, Mylik Kerley (JR) 44.99',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {10}',
#   '',
#   '\xa0',
#   '3:00.74 ',
#   '4/29/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO) 45.8h, Fred Kerley (SR) 43.7h, Devin Dixon (FR) 46.22, Mylik Kerley (JR) 44.99'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {10}', '', '\xa0', '3:00.74 ', '4/29/2017'],
#  ['\xa0\xa0\xa0\xa0\xa0Richard Rose (SO) 45.8h, Fred Kerley (SR) 43.7h, Devin Dixon (FR) 46.22, Mylik Kerley (JR) 44.99'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {11}\xa03:00.76 qq = Performance occurred during a non-final round. 6/12/2014\xa0\xa0\xa0\xa0\xa0Aldrich Bailey, Jr., Carlyle Roudette, Bralon Taplin, Deon Lendore',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {11}',
#   '',
#   '\xa0',
#   '3:00.76 qq = Performance occurred during a non-final round. ',
#   '6/12/2014',
#   '\xa0\xa0\xa0\xa0\xa0Aldrich Bailey, Jr., Carlyle Roudette, Bralon Taplin, Deon Lendore'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {11}',
#   '',
#   '\xa0',
#   '3:00.76 qq = Performance occurred during a non-final round. ',
#   '6/12/2014'],
#  ['\xa0\xa0\xa0\xa0\xa0Aldrich Bailey, Jr., Carlyle Roudette, Bralon Taplin, Deon Lendore'],
#  ['(18) Southern Illinois\xa03:00.78  4/28/1984\xa0\xa0\xa0\xa0\xa0Parry Duncan 45.5, Tony Adams 45.6, Elvis Forde 45.1, Michael Franks 44.5',
#   '(18) Southern Illinois',
#   '',
#   '\xa0',
#   '3:00.78  ',
#   '4/28/1984',
#   '\xa0\xa0\xa0\xa0\xa0Parry Duncan 45.5, Tony Adams 45.6, Elvis Forde 45.1, Michael Franks 44.5'],
#  [],
#  ['(18) Southern Illinois', '', '\xa0', '3:00.78  ', '4/28/1984'],
#  ['\xa0\xa0\xa0\xa0\xa0Parry Duncan 45.5, Tony Adams 45.6, Elvis Forde 45.1, Michael Franks 44.5'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {6}\xa03:00.81 6/9/2023\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Tarsis OROGOT, Corde LONG 46.76, Khaleb MCRAE 44.14',
#   '\xa0\xa0\xa0\xa0— ALABAMA {6}',
#   '',
#   '\xa0',
#   '3:00.81 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Tarsis OROGOT, Corde LONG 46.76, Khaleb MCRAE 44.14'],
#  [],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {6}', '', '\xa0', '3:00.81 ', '6/9/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Tarsis OROGOT, Corde LONG 46.76, Khaleb MCRAE 44.14'],
#  ['(19) Oregon\xa03:00.81  6/11/2005\xa0\xa0\xa0\xa0\xa0Jordan Kent 46.5, Kedar Inico 44.3, AK Ikwuakor 45.4, John Scherer 44.6',
#   '(19) Oregon',
#   '',
#   '\xa0',
#   '3:00.81  ',
#   '6/11/2005',
#   '\xa0\xa0\xa0\xa0\xa0Jordan Kent 46.5, Kedar Inico 44.3, AK Ikwuakor 45.4, John Scherer 44.6'],
#  [],
#  ['(19) Oregon', '', '\xa0', '3:00.81  ', '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0\xa0Jordan Kent 46.5, Kedar Inico 44.3, AK Ikwuakor 45.4, John Scherer 44.6'],
#  ['(19) SMU\xa03:00.81  6/6/1987\xa0\xa0\xa0\xa0\xa0Harold Spells 46.1, Kevin Robinzine 44.2, Cedric Matterson 45.8, Roy Martin 44.8',
#   '(19) SMU',
#   '',
#   '\xa0',
#   '3:00.81  ',
#   '6/6/1987',
#   '\xa0\xa0\xa0\xa0\xa0Harold Spells 46.1, Kevin Robinzine 44.2, Cedric Matterson 45.8, Roy Martin 44.8'],
#  [],
#  ['(19) SMU', '', '\xa0', '3:00.81  ', '6/6/1987'],
#  ['\xa0\xa0\xa0\xa0\xa0Harold Spells 46.1, Kevin Robinzine 44.2, Cedric Matterson 45.8, Roy Martin 44.8'],
#  ['(21) Ohio State\xa03:00.82  6/5/1993\xa0\xa0\xa0\xa0\xa0Rich Jones 46.2, Aaron Payne 45.0, Robert Smith 45.4, Chris Nelloms 44.2',
#   '(21) Ohio State',
#   '',
#   '\xa0',
#   '3:00.82  ',
#   '6/5/1993',
#   '\xa0\xa0\xa0\xa0\xa0Rich Jones 46.2, Aaron Payne 45.0, Robert Smith 45.4, Chris Nelloms 44.2'],
#  [],
#  ['(21) Ohio State', '', '\xa0', '3:00.82  ', '6/5/1993'],
#  ['\xa0\xa0\xa0\xa0\xa0Rich Jones 46.2, Aaron Payne 45.0, Robert Smith 45.4, Chris Nelloms 44.2'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {9}\xa03:00.83  6/6/1987\xa0\xa0\xa0\xa0\xa0Darnell Chase 46.0, Keith Stanford 45.0, Michael Johnson 45.2, Raymond Pierre 44.7',
#   '\xa0\xa0\xa0\xa0— BAYLOR {9}',
#   '',
#   '\xa0',
#   '3:00.83  ',
#   '6/6/1987',
#   '\xa0\xa0\xa0\xa0\xa0Darnell Chase 46.0, Keith Stanford 45.0, Michael Johnson 45.2, Raymond Pierre 44.7'],
#  [],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {9}', '', '\xa0', '3:00.83  ', '6/6/1987'],
#  ['\xa0\xa0\xa0\xa0\xa0Darnell Chase 46.0, Keith Stanford 45.0, Michael Johnson 45.2, Raymond Pierre 44.7'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {10}\xa03:00.84  6/1/1985\xa0\xa0\xa0\xa0\xa0Darnell Chase 46.0, Derwin Graham 45.8, Johnny Thomas 44.8, Willie Caldwell 44.3',
#   '\xa0\xa0\xa0\xa0— BAYLOR {10}',
#   '',
#   '\xa0',
#   '3:00.84  ',
#   '6/1/1985',
#   '\xa0\xa0\xa0\xa0\xa0Darnell Chase 46.0, Derwin Graham 45.8, Johnny Thomas 44.8, Willie Caldwell 44.3'],
#  [],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {10}', '', '\xa0', '3:00.84  ', '6/1/1985'],
#  ['\xa0\xa0\xa0\xa0\xa0Darnell Chase 46.0, Derwin Graham 45.8, Johnny Thomas 44.8, Willie Caldwell 44.3'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {12}\xa03:00.88 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Eric HEMPHILL III, Omajuwa ETIWE, DeMarco ESCOBAR, Auhmad ROBINSON 44.36',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {12}',
#   '',
#   '\xa0',
#   '3:00.88 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Eric HEMPHILL III, Omajuwa ETIWE, DeMarco ESCOBAR, Auhmad ROBINSON 44.36'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {12}',
#   '',
#   '\xa0',
#   '3:00.88 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Eric HEMPHILL III, Omajuwa ETIWE, DeMarco ESCOBAR, Auhmad ROBINSON 44.36'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {13}\xa03:00.89  6/12/2010\xa0\xa0\xa0\xa0\xa0Bryan Miller 46.4, Demetrius Pinder 44.6, Curtis Mitchell 45.07, Tabarie Henry 44.79',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {13}',
#   '',
#   '\xa0',
#   '3:00.89  ',
#   '6/12/2010',
#   '\xa0\xa0\xa0\xa0\xa0Bryan Miller 46.4, Demetrius Pinder 44.6, Curtis Mitchell 45.07, Tabarie Henry 44.79'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {13}', '', '\xa0', '3:00.89  ', '6/12/2010'],
#  ['\xa0\xa0\xa0\xa0\xa0Bryan Miller 46.4, Demetrius Pinder 44.6, Curtis Mitchell 45.07, Tabarie Henry 44.79'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {14}\xa03:00.90 6/9/2023\xa0\xa0\xa0\xa0\xa0Eric HEMPHILL III, Omajuwa ETIWE, DeMarco ESCOBAR, Auhmad ROBINSON',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {14}',
#   '',
#   '\xa0',
#   '3:00.90 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Eric HEMPHILL III, Omajuwa ETIWE, DeMarco ESCOBAR, Auhmad ROBINSON'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {14}', '', '\xa0', '3:00.90 ', '6/9/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Eric HEMPHILL III, Omajuwa ETIWE, DeMarco ESCOBAR, Auhmad ROBINSON'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {15}\xa03:00.91  6/13/2009',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {15}',
#   '',
#   '\xa0',
#   '3:00.91  ',
#   '6/13/2009'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {15}', '', '\xa0', '3:00.91  ', '6/13/2009'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {16}\xa03:00.91 AA = Performance occurred at altitude (>1000 meters above sea level) 6/3/1989\xa0\xa0\xa0\xa0\xa0Stanley Kerr 45.4, Errington Lindo 45.8, Derrick Florence 45.0, Howard Davis 44.7',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {16}',
#   '',
#   '\xa0',
#   '3:00.91 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '6/3/1989',
#   '\xa0\xa0\xa0\xa0\xa0Stanley Kerr 45.4, Errington Lindo 45.8, Derrick Florence 45.0, Howard Davis 44.7'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {16}',
#   '',
#   '\xa0',
#   '3:00.91 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '6/3/1989'],
#  ['\xa0\xa0\xa0\xa0\xa0Stanley Kerr 45.4, Errington Lindo 45.8, Derrick Florence 45.0, Howard Davis 44.7'],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {3}\xa03:00.92 6/11/2021\xa0\xa0\xa0\xa0\xa0Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.89, Trevor STEWART (SR) 44.17',
#   '\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {3}',
#   '',
#   '\xa0',
#   '3:00.92 ',
#   '6/11/2021',
#   '\xa0\xa0\xa0\xa0\xa0Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.89, Trevor STEWART (SR) 44.17'],
#  [],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {3}',
#   '',
#   '\xa0',
#   '3:00.92 ',
#   '6/11/2021'],
#  ['\xa0\xa0\xa0\xa0\xa0Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.89, Trevor STEWART (SR) 44.17'],
#  ['(22) Arkansas\xa03:00.97 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Lance LANG, James BENSON II, Connor WASHINGTON, Christopher BAILEY 44.37',
#   '(22) Arkansas',
#   '',
#   '\xa0',
#   '3:00.97 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Lance LANG, James BENSON II, Connor WASHINGTON, Christopher BAILEY 44.37'],
#  [],
#  ['(22) Arkansas',
#   '',
#   '\xa0',
#   '3:00.97 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Lance LANG, James BENSON II, Connor WASHINGTON, Christopher BAILEY 44.37'],
#  ['\xa0\xa0\xa0\xa0— LSU {6}\xa03:01.00 3/27/2021\xa0\xa0\xa0\xa0\xa0Camel, Burrell, Terry, Williams',
#   '\xa0\xa0\xa0\xa0— LSU {6}',
#   '',
#   '\xa0',
#   '3:01.00 ',
#   '3/27/2021',
#   '\xa0\xa0\xa0\xa0\xa0Camel, Burrell, Terry, Williams'],
#  [],
#  ['\xa0\xa0\xa0\xa0— LSU {6}', '', '\xa0', '3:01.00 ', '3/27/2021'],
#  ['\xa0\xa0\xa0\xa0\xa0Camel, Burrell, Terry, Williams'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {13}\xa03:01.00 3/31/2018\xa0\xa0\xa0\xa0\xa0Fasasi, Holloway, Sawyers, Vedel',
#   '\xa0\xa0\xa0\xa0— FLORIDA {13}',
#   '',
#   '\xa0',
#   '3:01.00 ',
#   '3/31/2018',
#   '\xa0\xa0\xa0\xa0\xa0Fasasi, Holloway, Sawyers, Vedel'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {13}', '', '\xa0', '3:01.00 ', '3/31/2018'],
#  ['\xa0\xa0\xa0\xa0\xa0Fasasi, Holloway, Sawyers, Vedel'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {11}\xa03:01.03  6/12/2004\xa0\xa0\xa0\xa0\xa0Wil Fitts 46.7, Braelon Davis 46.0, Jeremy Wariner 44.0, Darold Williamson 44.3',
#   '\xa0\xa0\xa0\xa0— BAYLOR {11}',
#   '',
#   '\xa0',
#   '3:01.03  ',
#   '6/12/2004',
#   '\xa0\xa0\xa0\xa0\xa0Wil Fitts 46.7, Braelon Davis 46.0, Jeremy Wariner 44.0, Darold Williamson 44.3'],
#  [],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {11}', '', '\xa0', '3:01.03  ', '6/12/2004'],
#  ['\xa0\xa0\xa0\xa0\xa0Wil Fitts 46.7, Braelon Davis 46.0, Jeremy Wariner 44.0, Darold Williamson 44.3'],
#  ['\xa0\xa0\xa0\xa0— LSU {7}\xa03:01.07 6/11/2011\xa0\xa0\xa0\xa0\xa0Robert Simmons 46.7, Ade Alleyne-Forte 45.0, Caleb Williams 44.54, Riker Hylton 44.88',
#   '\xa0\xa0\xa0\xa0— LSU {7}',
#   '',
#   '\xa0',
#   '3:01.07 ',
#   '6/11/2011',
#   '\xa0\xa0\xa0\xa0\xa0Robert Simmons 46.7, Ade Alleyne-Forte 45.0, Caleb Williams 44.54, Riker Hylton 44.88'],
#  [],
#  ['\xa0\xa0\xa0\xa0— LSU {7}', '', '\xa0', '3:01.07 ', '6/11/2011'],
#  ['\xa0\xa0\xa0\xa0\xa0Robert Simmons 46.7, Ade Alleyne-Forte 45.0, Caleb Williams 44.54, Riker Hylton 44.88'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {17}\xa03:01.07  6/9/2007\xa0\xa0\xa0\xa0\xa0Bryant McCombs 45.9, Alfred Robinson 45.0, Marcus Pitre 45.49, Justin Oliver 44.67',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {17}',
#   '',
#   '\xa0',
#   '3:01.07  ',
#   '6/9/2007',
#   '\xa0\xa0\xa0\xa0\xa0Bryant McCombs 45.9, Alfred Robinson 45.0, Marcus Pitre 45.49, Justin Oliver 44.67'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {17}', '', '\xa0', '3:01.07  ', '6/9/2007'],
#  ['\xa0\xa0\xa0\xa0\xa0Bryant McCombs 45.9, Alfred Robinson 45.0, Marcus Pitre 45.49, Justin Oliver 44.67'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {5}\xa03:01.11 qq = Performance occurred during a non-final round. 5/26/2018',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {5}',
#   '',
#   '\xa0',
#   '3:01.11 qq = Performance occurred during a non-final round. ',
#   '5/26/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {5}',
#   '',
#   '\xa0',
#   '3:01.11 qq = Performance occurred during a non-final round. ',
#   '5/26/2018'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {14}\xa03:01.12 6/11/2016\xa0\xa0\xa0\xa0\xa0Kunle Fasasi (FR) 45.7, Arman Hall (SR) 44.6, Hugh Graham, Jr (SR) 45.67, Najee Glass (SR) 45.08',
#   '\xa0\xa0\xa0\xa0— FLORIDA {14}',
#   '',
#   '\xa0',
#   '3:01.12 ',
#   '6/11/2016',
#   '\xa0\xa0\xa0\xa0\xa0Kunle Fasasi (FR) 45.7, Arman Hall (SR) 44.6, Hugh Graham, Jr (SR) 45.67, Najee Glass (SR) 45.08'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {14}', '', '\xa0', '3:01.12 ', '6/11/2016'],
#  ['\xa0\xa0\xa0\xa0\xa0Kunle Fasasi (FR) 45.7, Arman Hall (SR) 44.6, Hugh Graham, Jr (SR) 45.67, Najee Glass (SR) 45.08'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {12}\xa03:01.12  6/13/2009',
#   '\xa0\xa0\xa0\xa0— BAYLOR {12}',
#   '',
#   '\xa0',
#   '3:01.12  ',
#   '6/13/2009'],
#  [],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {12}', '', '\xa0', '3:01.12  ', '6/13/2009'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {18}\xa03:01.13 qq = Performance occurred during a non-final round. 6/6/2018',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {18}',
#   '',
#   '\xa0',
#   '3:01.13 qq = Performance occurred during a non-final round. ',
#   '6/6/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {18}',
#   '',
#   '\xa0',
#   '3:01.13 qq = Performance occurred during a non-final round. ',
#   '6/6/2018'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {7}\xa03:01.16  6/1/1985\xa0\xa0\xa0\xa0\xa0Terry Menefee 45.6, Tony Davis 46.1, Bernie Jackson 45.3, Cedric Vaughans 44.2',
#   '\xa0\xa0\xa0\xa0— ALABAMA {7}',
#   '',
#   '\xa0',
#   '3:01.16  ',
#   '6/1/1985',
#   '\xa0\xa0\xa0\xa0\xa0Terry Menefee 45.6, Tony Davis 46.1, Bernie Jackson 45.3, Cedric Vaughans 44.2'],
#  [],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {7}', '', '\xa0', '3:01.16  ', '6/1/1985'],
#  ['\xa0\xa0\xa0\xa0\xa0Terry Menefee 45.6, Tony Davis 46.1, Bernie Jackson 45.3, Cedric Vaughans 44.2'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {8}\xa03:01.16  1985\xa0\xa0\xa0\xa0\xa0Menefee, Davis, Jackson, Vaughans',
#   '\xa0\xa0\xa0\xa0— ALABAMA {8}',
#   '',
#   '\xa0',
#   '3:01.16  ',
#   '1985',
#   '\xa0\xa0\xa0\xa0\xa0Menefee, Davis, Jackson, Vaughans'],
#  [],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {8}', '', '\xa0', '3:01.16  ', '1985'],
#  ['\xa0\xa0\xa0\xa0\xa0Menefee, Davis, Jackson, Vaughans'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {19}\xa03:01.17 5/13/2018\xa0\xa0\xa0\xa0\xa0Rose, Deadmon, Izu, Dixon',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {19}',
#   '',
#   '\xa0',
#   '3:01.17 ',
#   '5/13/2018',
#   '\xa0\xa0\xa0\xa0\xa0Rose, Deadmon, Izu, Dixon'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {19}', '', '\xa0', '3:01.17 ', '5/13/2018'],
#  ['\xa0\xa0\xa0\xa0\xa0Rose, Deadmon, Izu, Dixon'],
#  ['(23) Iowa State\xa03:01.17  6/1/1985\xa0\xa0\xa0\xa0\xa0Sebron Flenaugh 47.6, Leroy Dixson 44.7, Danny Harris 44.3, Sunday Uti 44.6',
#   '(23) Iowa State',
#   '',
#   '\xa0',
#   '3:01.17  ',
#   '6/1/1985',
#   '\xa0\xa0\xa0\xa0\xa0Sebron Flenaugh 47.6, Leroy Dixson 44.7, Danny Harris 44.3, Sunday Uti 44.6'],
#  [],
#  ['(23) Iowa State', '', '\xa0', '3:01.17  ', '6/1/1985'],
#  ['\xa0\xa0\xa0\xa0\xa0Sebron Flenaugh 47.6, Leroy Dixson 44.7, Danny Harris 44.3, Sunday Uti 44.6'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {20}\xa03:01.19 5/18/2014',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {20}',
#   '',
#   '\xa0',
#   '3:01.19 ',
#   '5/18/2014'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {20}', '', '\xa0', '3:01.19 ', '5/18/2014'],
#  ['\xa0\xa0\xa0\xa0— LSU {8}\xa03:01.21 6/9/2012\xa0\xa0\xa0\xa0\xa0Simmons, Williams, Alleyne-Forte, Hylton',
#   '\xa0\xa0\xa0\xa0— LSU {8}',
#   '',
#   '\xa0',
#   '3:01.21 ',
#   '6/9/2012',
#   '\xa0\xa0\xa0\xa0\xa0Simmons, Williams, Alleyne-Forte, Hylton'],
#  [],
#  ['\xa0\xa0\xa0\xa0— LSU {8}', '', '\xa0', '3:01.21 ', '6/9/2012'],
#  ['\xa0\xa0\xa0\xa0\xa0Simmons, Williams, Alleyne-Forte, Hylton'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {15}\xa03:01.22 qq = Performance occurred during a non-final round. 5/27/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON, Ryan WILLIE, Kemuel SANTANA, Champion ALLISON',
#   '\xa0\xa0\xa0\xa0— FLORIDA {15}',
#   '',
#   '\xa0',
#   '3:01.22 qq = Performance occurred during a non-final round. ',
#   '5/27/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON, Ryan WILLIE, Kemuel SANTANA, Champion ALLISON'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {15}',
#   '',
#   '\xa0',
#   '3:01.22 qq = Performance occurred during a non-final round. ',
#   '5/27/2022'],
#  ['\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON, Ryan WILLIE, Kemuel SANTANA, Champion ALLISON'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {13}\xa03:01.22  6/5/1993\xa0\xa0\xa0\xa0\xa0Daniel Fredericks 46.4, Dion Minor 45.3, Tony Miller 44.7, Etheridge Green 44.8',
#   '\xa0\xa0\xa0\xa0— BAYLOR {13}',
#   '',
#   '\xa0',
#   '3:01.22  ',
#   '6/5/1993',
#   '\xa0\xa0\xa0\xa0\xa0Daniel Fredericks 46.4, Dion Minor 45.3, Tony Miller 44.7, Etheridge Green 44.8'],
#  [],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {13}', '', '\xa0', '3:01.22  ', '6/5/1993'],
#  ['\xa0\xa0\xa0\xa0\xa0Daniel Fredericks 46.4, Dion Minor 45.3, Tony Miller 44.7, Etheridge Green 44.8'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {21}\xa03:01.23 qq = Performance occurred during a non-final round. 5/26/2018',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {21}',
#   '',
#   '\xa0',
#   '3:01.23 qq = Performance occurred during a non-final round. ',
#   '5/26/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {21}',
#   '',
#   '\xa0',
#   '3:01.23 qq = Performance occurred during a non-final round. ',
#   '5/26/2018'],
#  ['(24) Oklahoma\xa03:01.25  6/7/1997\xa0\xa0\xa0\xa0\xa0Edward Clarke 45.6, Danny McFarlane 45.6, Ryan Kite 45.14, Roxbert Martin 44.91',
#   '(24) Oklahoma',
#   '',
#   '\xa0',
#   '3:01.25  ',
#   '6/7/1997',
#   '\xa0\xa0\xa0\xa0\xa0Edward Clarke 45.6, Danny McFarlane 45.6, Ryan Kite 45.14, Roxbert Martin 44.91'],
#  [],
#  ['(24) Oklahoma', '', '\xa0', '3:01.25  ', '6/7/1997'],
#  ['\xa0\xa0\xa0\xa0\xa0Edward Clarke 45.6, Danny McFarlane 45.6, Ryan Kite 45.14, Roxbert Martin 44.91'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {14}\xa03:01.25  6/1/1996\xa0\xa0\xa0\xa0\xa0Michael Ford 46.2, Raoul Howard 45.3, Darrin Strong 45.1, Marlon Ramsey 44.7',
#   '\xa0\xa0\xa0\xa0— BAYLOR {14}',
#   '',
#   '\xa0',
#   '3:01.25  ',
#   '6/1/1996',
#   '\xa0\xa0\xa0\xa0\xa0Michael Ford 46.2, Raoul Howard 45.3, Darrin Strong 45.1, Marlon Ramsey 44.7'],
#  [],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {14}', '', '\xa0', '3:01.25  ', '6/1/1996'],
#  ['\xa0\xa0\xa0\xa0\xa0Michael Ford 46.2, Raoul Howard 45.3, Darrin Strong 45.1, Marlon Ramsey 44.7'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {22}\xa03:01.26 qq = Performance occurred during a non-final round. 6/5/2019\xa0\xa0\xa0\xa0\xa0Bryce DEADMON (JR), Robert GRANT (SR), DeWitt THOMAS (SR) 45.87, Devin DIXON (JR) 44.40',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {22}',
#   '',
#   '\xa0',
#   '3:01.26 qq = Performance occurred during a non-final round. ',
#   '6/5/2019',
#   '\xa0\xa0\xa0\xa0\xa0Bryce DEADMON (JR), Robert GRANT (SR), DeWitt THOMAS (SR) 45.87, Devin DIXON (JR) 44.40'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {22}',
#   '',
#   '\xa0',
#   '3:01.26 qq = Performance occurred during a non-final round. ',
#   '6/5/2019'],
#  ['\xa0\xa0\xa0\xa0\xa0Bryce DEADMON (JR), Robert GRANT (SR), DeWitt THOMAS (SR) 45.87, Devin DIXON (JR) 44.40'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {16}\xa03:01.26 3/29/2014\xa0\xa0\xa0\xa0\xa0Najee Glass 46.3, Hugh Graham, Jr. 44.7, Dedric Dukes 45.2, Arman Hall 45.0',
#   '\xa0\xa0\xa0\xa0— FLORIDA {16}',
#   '',
#   '\xa0',
#   '3:01.26 ',
#   '3/29/2014',
#   '\xa0\xa0\xa0\xa0\xa0Najee Glass 46.3, Hugh Graham, Jr. 44.7, Dedric Dukes 45.2, Arman Hall 45.0'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {16}', '', '\xa0', '3:01.26 ', '3/29/2014'],
#  ['\xa0\xa0\xa0\xa0\xa0Najee Glass 46.3, Hugh Graham, Jr. 44.7, Dedric Dukes 45.2, Arman Hall 45.0'],
#  ['\xa0\xa0\xa0\xa0— TEXAS {3}\xa03:01.28 3/27/2021\xa0\xa0\xa0\xa0\xa0Maas, Harris, Jones, Wright',
#   '\xa0\xa0\xa0\xa0— TEXAS {3}',
#   '',
#   '\xa0',
#   '3:01.28 ',
#   '3/27/2021',
#   '\xa0\xa0\xa0\xa0\xa0Maas, Harris, Jones, Wright'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS {3}', '', '\xa0', '3:01.28 ', '3/27/2021'],
#  ['\xa0\xa0\xa0\xa0\xa0Maas, Harris, Jones, Wright'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {17}\xa03:01.30 qq = Performance occurred during a non-final round. 6/8/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON (JR), Ryan WILLIE (SO), Jacob MILEY (SO) 46.19, Champion ALLISON (JR) 44.75',
#   '\xa0\xa0\xa0\xa0— FLORIDA {17}',
#   '',
#   '\xa0',
#   '3:01.30 qq = Performance occurred during a non-final round. ',
#   '6/8/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON (JR), Ryan WILLIE (SO), Jacob MILEY (SO) 46.19, Champion ALLISON (JR) 44.75'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {17}',
#   '',
#   '\xa0',
#   '3:01.30 qq = Performance occurred during a non-final round. ',
#   '6/8/2022'],
#  ['\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON (JR), Ryan WILLIE (SO), Jacob MILEY (SO) 46.19, Champion ALLISON (JR) 44.75'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {6}\xa03:01.30 qq = Performance occurred during a non-final round. 6/6/2018',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {6}',
#   '',
#   '\xa0',
#   '3:01.30 qq = Performance occurred during a non-final round. ',
#   '6/6/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {6}',
#   '',
#   '\xa0',
#   '3:01.30 qq = Performance occurred during a non-final round. ',
#   '6/6/2018'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {18}\xa03:01.34 6/8/2013\xa0\xa0\xa0\xa0\xa0Najee Glass (FR) 46.0, Hugh Graham, Jr. (SO) 45.4, Dedric Dukes (SO) 45.09, Arman Hall (FR) 44.86',
#   '\xa0\xa0\xa0\xa0— FLORIDA {18}',
#   '',
#   '\xa0',
#   '3:01.34 ',
#   '6/8/2013',
#   '\xa0\xa0\xa0\xa0\xa0Najee Glass (FR) 46.0, Hugh Graham, Jr. (SO) 45.4, Dedric Dukes (SO) 45.09, Arman Hall (FR) 44.86'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {18}', '', '\xa0', '3:01.34 ', '6/8/2013'],
#  ['\xa0\xa0\xa0\xa0\xa0Najee Glass (FR) 46.0, Hugh Graham, Jr. (SO) 45.4, Dedric Dukes (SO) 45.09, Arman Hall (FR) 44.86'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {19}\xa03:01.36  6/11/2005',
#   '\xa0\xa0\xa0\xa0— FLORIDA {19}',
#   '',
#   '\xa0',
#   '3:01.36  ',
#   '6/11/2005'],
#  [],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {19}', '', '\xa0', '3:01.36  ', '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {4}\xa03:01.38 4/1/2023\xa0\xa0\xa0\xa0\xa0Justin ROBINSON, Jeremiah CURRY, Dubem NWACHUKWU 44.80, Trevin MOYER 45.37',
#   '\xa0\xa0\xa0\xa0— ARIZONA STATE {4}',
#   '',
#   '\xa0',
#   '3:01.38 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Justin ROBINSON, Jeremiah CURRY, Dubem NWACHUKWU 44.80, Trevin MOYER 45.37'],
#  [],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {4}', '', '\xa0', '3:01.38 ', '4/1/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Justin ROBINSON, Jeremiah CURRY, Dubem NWACHUKWU 44.80, Trevin MOYER 45.37'],
#  ['\xa0\xa0\xa0\xa0— OHIO STATE {2}\xa03:01.41  6/6/1992',
#   '\xa0\xa0\xa0\xa0— OHIO STATE {2}',
#   '',
#   '\xa0',
#   '3:01.41  ',
#   '6/6/1992'],
#  [],
#  ['\xa0\xa0\xa0\xa0— OHIO STATE {2}', '', '\xa0', '3:01.41  ', '6/6/1992'],
#  ['\xa0\xa0\xa0\xa0— OHIO STATE {3}\xa03:01.41  1992\xa0\xa0\xa0\xa0\xa0Rich Jones, Aaron Payne, Robert Smith, Chris Nelloms',
#   '\xa0\xa0\xa0\xa0— OHIO STATE {3}',
#   '',
#   '\xa0',
#   '3:01.41  ',
#   '1992',
#   '\xa0\xa0\xa0\xa0\xa0Rich Jones, Aaron Payne, Robert Smith, Chris Nelloms'],
#  [],
#  ['\xa0\xa0\xa0\xa0— OHIO STATE {3}', '', '\xa0', '3:01.41  ', '1992'],
#  ['\xa0\xa0\xa0\xa0\xa0Rich Jones, Aaron Payne, Robert Smith, Chris Nelloms'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {23}\xa03:01.42 qq = Performance occurred during a non-final round. 5/31/2014\xa0\xa0\xa0\xa0\xa0Carlyle Roudette, Aldrich Bailey, Jr., Bralon Taplin, Deon Lendore',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {23}',
#   '',
#   '\xa0',
#   '3:01.42 qq = Performance occurred during a non-final round. ',
#   '5/31/2014',
#   '\xa0\xa0\xa0\xa0\xa0Carlyle Roudette, Aldrich Bailey, Jr., Bralon Taplin, Deon Lendore'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {23}',
#   '',
#   '\xa0',
#   '3:01.42 qq = Performance occurred during a non-final round. ',
#   '5/31/2014'],
#  ['\xa0\xa0\xa0\xa0\xa0Carlyle Roudette, Aldrich Bailey, Jr., Bralon Taplin, Deon Lendore'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {15}\xa03:01.46  6/3/2000\xa0\xa0\xa0\xa0\xa0Zsolt Szeglet 46.3, Bayano Kamani 45.4, Floyd Thompson 45.1, Brandon Couts 44.7',
#   '\xa0\xa0\xa0\xa0— BAYLOR {15}',
#   '',
#   '\xa0',
#   '3:01.46  ',
#   '6/3/2000',
#   '\xa0\xa0\xa0\xa0\xa0Zsolt Szeglet 46.3, Bayano Kamani 45.4, Floyd Thompson 45.1, Brandon Couts 44.7'],
#  [],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {15}', '', '\xa0', '3:01.46  ', '6/3/2000'],
#  ['\xa0\xa0\xa0\xa0\xa0Zsolt Szeglet 46.3, Bayano Kamani 45.4, Floyd Thompson 45.1, Brandon Couts 44.7'],
#  ['\xa0\xa0\xa0\xa0— OKLAHOMA {2}\xa03:01.46  4/28/1984\xa0\xa0\xa0\xa0\xa0Aubrey Jones 45.7, Donnie Kemp 44.9, Dannie Carter 45.8, Don Bly 45.1',
#   '\xa0\xa0\xa0\xa0— OKLAHOMA {2}',
#   '',
#   '\xa0',
#   '3:01.46  ',
#   '4/28/1984',
#   '\xa0\xa0\xa0\xa0\xa0Aubrey Jones 45.7, Donnie Kemp 44.9, Dannie Carter 45.8, Don Bly 45.1'],
#  [],
#  ['\xa0\xa0\xa0\xa0— OKLAHOMA {2}', '', '\xa0', '3:01.46  ', '4/28/1984'],
#  ['\xa0\xa0\xa0\xa0\xa0Aubrey Jones 45.7, Donnie Kemp 44.9, Dannie Carter 45.8, Don Bly 45.1'],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {4}\xa03:01.50 6/7/2019\xa0\xa0\xa0\xa0\xa0Akeem LINDO (FR), Akeem SIRLEAF (JR), Trevor STEWART (JR) 44.13, Kemarni MIGHTY (JR) 45.22',
#   '\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {4}',
#   '',
#   '\xa0',
#   '3:01.50 ',
#   '6/7/2019',
#   '\xa0\xa0\xa0\xa0\xa0Akeem LINDO (FR), Akeem SIRLEAF (JR), Trevor STEWART (JR) 44.13, Kemarni MIGHTY (JR) 45.22'],
#  [],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {4}',
#   '',
#   '\xa0',
#   '3:01.50 ',
#   '6/7/2019'],
#  ['\xa0\xa0\xa0\xa0\xa0Akeem LINDO (FR), Akeem SIRLEAF (JR), Trevor STEWART (JR) 44.13, Kemarni MIGHTY (JR) 45.22'],
#  ['\xa0\xa0\xa0\xa0— GEORGIA {3}\xa03:01.51 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Matthew BOLING, Caleb CAVANAUGH, Christopher MORALES WILLIAMS, Will SUMNER',
#   '\xa0\xa0\xa0\xa0— GEORGIA {3}',
#   '',
#   '\xa0',
#   '3:01.51 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Matthew BOLING, Caleb CAVANAUGH, Christopher MORALES WILLIAMS, Will SUMNER'],
#  [],
#  ['\xa0\xa0\xa0\xa0— GEORGIA {3}',
#   '',
#   '\xa0',
#   '3:01.51 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0\xa0Matthew BOLING, Caleb CAVANAUGH, Christopher MORALES WILLIAMS, Will SUMNER'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {24}\xa03:01.51 3/19/2022\xa0\xa0\xa0\xa0\xa0 CHEVANNIE, 7778460 OMAJUWA, 7729602 BRANDON, 7729617 JAMES',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {24}',
#   '',
#   '\xa0',
#   '3:01.51 ',
#   '3/19/2022',
#   '\xa0\xa0\xa0\xa0\xa0 CHEVANNIE, 7778460 OMAJUWA, 7729602 BRANDON, 7729617 JAMES'],
#  [],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {24}', '', '\xa0', '3:01.51 ', '3/19/2022'],
#  ['\xa0\xa0\xa0\xa0\xa0 CHEVANNIE, 7778460 OMAJUWA, 7729602 BRANDON, 7729617 JAMES'],
#  ['(25) Stephen F. Austin\xa03:01.52 6/11/2021\xa0\xa0\xa0\xa0\xa0Muzuri MATTAR (SO), Paul MARTIN (FR), Jeremiah CURRY (SO) 45.89, Auhmad ROBINSON (FR) 43.45',
#   '(25) Stephen F. Austin',
#   '',
#   '\xa0',
#   '3:01.52 ',
#   '6/11/2021',
#   '\xa0\xa0\xa0\xa0\xa0Muzuri MATTAR (SO), Paul MARTIN (FR), Jeremiah CURRY (SO) 45.89, Auhmad ROBINSON (FR) 43.45'],
#  [],
#  ['(25) Stephen F. Austin', '', '\xa0', '3:01.52 ', '6/11/2021'],
#  ['\xa0\xa0\xa0\xa0\xa0Muzuri MATTAR (SO), Paul MARTIN (FR), Jeremiah CURRY (SO) 45.89, Auhmad ROBINSON (FR) 43.45'],
#  ['Converted From an Event of Similar Length'],
#  ['OKLAHOMA\xa03:00.26c  5/18/1997',
#   'OKLAHOMA',
#   '',
#   '\xa0',
#   '3:00.26c  ',
#   '5/18/1997'],
#  [],
#  ['OKLAHOMA', '', '\xa0', '3:00.26c  ', '5/18/1997'],
#  ['', '', '', '']]

# %%
len(rows)
# Out:
# 461

# %%
rows[459]
# Out:
# ['OKLAHOMA', '', '\xa0', '3:00.26c  ', '5/18/1997']

# %%
len(rows)
# Out:
# 461

# %%
RealRows = []

# %%
for i in range(0,460):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [['(1) Florida\xa02:57.74 6/9/2023\xa0\xa0\xa0\xa0\xa0Emmanuel BAMIDELE, Jacory PATTERSON, JeVaughn POWELL 44.93, Ryan WILLIE 44.28',
#   '(1) Florida',
#   '',
#   '\xa0',
#   '2:57.74 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Emmanuel BAMIDELE, Jacory PATTERSON, JeVaughn POWELL 44.93, Ryan WILLIE 44.28'],
#  ['(1) Florida', '', '\xa0', '2:57.74 ', '6/9/2023'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {2}\xa02:57.76📺 5/13/2023\xa0\xa0\xa0\xa0\xa0JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 43.98, Ryan WILLIE 43.32',
#   '\xa0\xa0\xa0\xa0— FLORIDA {2}',
#   '',
#   '\xa0',
#   '2:57.76📺 ',
#   '5/13/2023',
#   '\xa0\xa0\xa0\xa0\xa0JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 43.98, Ryan WILLIE 43.32'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {2}', '', '\xa0', '2:57.76📺 ', '5/13/2023'],
#  ['(2) Arizona State\xa02:57.78 6/9/2023\xa0\xa0\xa0\xa0\xa0Dubem NWACHUKWU, Jeremiah CURRY, Jalen DRAYDEN 45.32, Justin ROBINSON 43.91',
#   '(2) Arizona State',
#   '',
#   '\xa0',
#   '2:57.78 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Dubem NWACHUKWU, Jeremiah CURRY, Jalen DRAYDEN 45.32, Justin ROBINSON 43.91'],
#  ['(2) Arizona State', '', '\xa0', '2:57.78 ', '6/9/2023'],
#  ['(3) Alabama\xa02:58.01 5/13/2023\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Khaleb MCRAE, Tarsis OROGOT, Corde LONG',
#   '(3) Alabama',
#   '',
#   '\xa0',
#   '2:58.01 ',
#   '5/13/2023',
#   '\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Khaleb MCRAE, Tarsis OROGOT, Corde LONG'],
#  ['(3) Alabama', '', '\xa0', '2:58.01 ', '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {3}\xa02:58.53📺 4/16/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON 44.4, Ryan WILLIE 44.5, Jacob MILEY 46.0, Champion ALLISON 43.6',
#   '\xa0\xa0\xa0\xa0— FLORIDA {3}',
#   '',
#   '\xa0',
#   '2:58.53📺 ',
#   '4/16/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON 44.4, Ryan WILLIE 44.5, Jacob MILEY 46.0, Champion ALLISON 43.6'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {3}', '', '\xa0', '2:58.53📺 ', '4/16/2022'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {4}\xa02:58.62 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 44.70, Ryan WILLIE 44.53',
#   '\xa0\xa0\xa0\xa0— FLORIDA {4}',
#   '',
#   '\xa0',
#   '2:58.62 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 44.70, Ryan WILLIE 44.53'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {4}',
#   '',
#   '\xa0',
#   '2:58.62 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['(4) Georgia\xa02:58.82📺 4/1/2023\xa0\xa0\xa0\xa0\xa0Elija GODWIN 44.8, Matthew BOLING 43.7, Caleb CAVANAUGH 45.53, Will SUMNER 44.80',
#   '(4) Georgia',
#   '',
#   '\xa0',
#   '2:58.82📺 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Elija GODWIN 44.8, Matthew BOLING 43.7, Caleb CAVANAUGH 45.53, Will SUMNER 44.80'],
#  ['(4) Georgia', '', '\xa0', '2:58.82📺 ', '4/1/2023'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {5}\xa02:58.88 6/10/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON (JR) 44.8, Ryan WILLIE (SO) 44.2, Jacob MILEY (SO) 45.85, Champion ALLISON (JR) 44.06',
#   '\xa0\xa0\xa0\xa0— FLORIDA {5}',
#   '',
#   '\xa0',
#   '2:58.88 ',
#   '6/10/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON (JR) 44.8, Ryan WILLIE (SO) 44.2, Jacob MILEY (SO) 45.85, Champion ALLISON (JR) 44.06'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {5}', '', '\xa0', '2:58.88 ', '6/10/2022'],
#  ['(5) Southern California\xa02:59.00📺 6/8/2018\xa0\xa0\xa0\xa0\xa0Ricky Morgan (SR), Rai Benjamin (JR), Zach Shinnick (FR) 45.86, Michael Norman (SO) 43.62',
#   '(5) Southern California',
#   '',
#   '\xa0',
#   '2:59.00📺 ',
#   '6/8/2018',
#   '\xa0\xa0\xa0\xa0\xa0Ricky Morgan (SR), Rai Benjamin (JR), Zach Shinnick (FR) 45.86, Michael Norman (SO) 43.62'],
#  ['(5) Southern California', '', '\xa0', '2:59.00📺 ', '6/8/2018'],
#  ['(6) Texas A&M\xa02:59.05📺 6/7/2019\xa0\xa0\xa0\xa0\xa0Bryce DEADMON (JR), Robert GRANT (SR), Kyree JOHNSON (SO) 45.24, Devin DIXON (SR) 44.11',
#   '(6) Texas A&M',
#   '',
#   '\xa0',
#   '2:59.05📺 ',
#   '6/7/2019',
#   '\xa0\xa0\xa0\xa0\xa0Bryce DEADMON (JR), Robert GRANT (SR), Kyree JOHNSON (SO) 45.24, Devin DIXON (SR) 44.11'],
#  ['(6) Texas A&M', '', '\xa0', '2:59.05📺 ', '6/7/2019'],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {2}\xa02:59.14 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Dubem NWACHUKWU, Gamali FELIX, Trevin MOYER, Jeremiah CURRY 43.55',
#   '\xa0\xa0\xa0\xa0— ARIZONA STATE {2}',
#   '',
#   '\xa0',
#   '2:59.14 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Dubem NWACHUKWU, Gamali FELIX, Trevin MOYER, Jeremiah CURRY 43.55'],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {2}',
#   '',
#   '\xa0',
#   '2:59.14 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {2}\xa02:59.15 4/1/2023\xa0\xa0\xa0\xa0\xa0Khaleb MCRAE 45.0, Tarsis OROGOT 44.0, Leander FORBES 45.15, Chris ROBINSON 45.04',
#   '\xa0\xa0\xa0\xa0— ALABAMA {2}',
#   '',
#   '\xa0',
#   '2:59.15 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Khaleb MCRAE 45.0, Tarsis OROGOT 44.0, Leander FORBES 45.15, Chris ROBINSON 45.04'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {2}', '', '\xa0', '2:59.15 ', '4/1/2023'],
#  ['(7) North Carolina A&T\xa02:59.21 qq = Performance occurred during a non-final round. 5/29/2021\xa0\xa0\xa0\xa0\xa0Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.65, Trevor STEWART (SR) 43.70',
#   '(7) North Carolina A&T',
#   '',
#   '\xa0',
#   '2:59.21 qq = Performance occurred during a non-final round. ',
#   '5/29/2021',
#   '\xa0\xa0\xa0\xa0\xa0Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.65, Trevor STEWART (SR) 43.70'],
#  ['(7) North Carolina A&T',
#   '',
#   '\xa0',
#   '2:59.21 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {3}\xa02:59.24 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Corde LONG, Tarsis OROGOT, Khaleb MCRAE',
#   '\xa0\xa0\xa0\xa0— ALABAMA {3}',
#   '',
#   '\xa0',
#   '2:59.24 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Corde LONG, Tarsis OROGOT, Khaleb MCRAE'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {3}',
#   '',
#   '\xa0',
#   '2:59.24 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['(8) UCLA\xa02:59.25 4/1/2023\xa0\xa0\xa0\xa0\xa0Antonie NORTJE, Willington WRIGHT, Ismail TURNER 44.31, Cameron REYNOLDS 44.49',
#   '(8) UCLA',
#   '',
#   '\xa0',
#   '2:59.25 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Antonie NORTJE, Willington WRIGHT, Ismail TURNER 44.31, Cameron REYNOLDS 44.49'],
#  ['(8) UCLA', '', '\xa0', '2:59.25 ', '4/1/2023'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {6}\xa02:59.44 5/14/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON, Ryan WILLIE, Jacob MILEY, Champion ALLISON',
#   '\xa0\xa0\xa0\xa0— FLORIDA {6}',
#   '',
#   '\xa0',
#   '2:59.44 ',
#   '5/14/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON, Ryan WILLIE, Jacob MILEY, Champion ALLISON'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {6}', '', '\xa0', '2:59.44 ', '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— UCLA {2}\xa02:59.51 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Myles MISENER-DALEY, Willington WRIGHT, Antonie NORTJE 44.37, Cameron REYNOLDS 44.13',
#   '\xa0\xa0\xa0\xa0— UCLA {2}',
#   '',
#   '\xa0',
#   '2:59.51 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Myles MISENER-DALEY, Willington WRIGHT, Antonie NORTJE 44.37, Cameron REYNOLDS 44.13'],
#  ['\xa0\xa0\xa0\xa0— UCLA {2}',
#   '',
#   '\xa0',
#   '2:59.51 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['(9) LSU\xa02:59.59📺 6/11/2005\xa0\xa0\xa0\xa0\xa0Reggie Dardar 46.4, Kelly Willie 44.4, Bennie Brazell 44.8, Xavier Carter 44.0',
#   '(9) LSU',
#   '',
#   '\xa0',
#   '2:59.59📺 ',
#   '6/11/2005',
#   '\xa0\xa0\xa0\xa0\xa0Reggie Dardar 46.4, Kelly Willie 44.4, Bennie Brazell 44.8, Xavier Carter 44.0'],
#  ['(9) LSU', '', '\xa0', '2:59.59📺 ', '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {7}\xa02:59.60 6/7/2019\xa0\xa0\xa0\xa0\xa0Benjamin LOBO VEDEL (SO), Chantz SAWYERS (SO), Denzel VILLAMAN (JR) 45.26, Grant HOLLOWAY (JR) 43.74',
#   '\xa0\xa0\xa0\xa0— FLORIDA {7}',
#   '',
#   '\xa0',
#   '2:59.60 ',
#   '6/7/2019',
#   '\xa0\xa0\xa0\xa0\xa0Benjamin LOBO VEDEL (SO), Chantz SAWYERS (SO), Denzel VILLAMAN (JR) 45.26, Grant HOLLOWAY (JR) 43.74'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {7}', '', '\xa0', '2:59.60 ', '6/7/2019'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {2}\xa02:59.60 6/14/2014\xa0\xa0\xa0\xa0\xa0Aldrich Bailey 46.5, Carlyle Roudette 44.7, Bralon Taplin 44.30, Deon Lendore 44.10',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {2}',
#   '',
#   '\xa0',
#   '2:59.60 ',
#   '6/14/2014',
#   '\xa0\xa0\xa0\xa0\xa0Aldrich Bailey 46.5, Carlyle Roudette 44.7, Bralon Taplin 44.30, Deon Lendore 44.10'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {2}', '', '\xa0', '2:59.60 ', '6/14/2014'],
#  ['\xa0\xa0\xa0\xa0— GEORGIA {2}\xa02:59.63 5/13/2023\xa0\xa0\xa0\xa0\xa0Elija GODWIN, Matthew BOLING, Christopher MORALES WILLIAM, Will SUMNER',
#   '\xa0\xa0\xa0\xa0— GEORGIA {2}',
#   '',
#   '\xa0',
#   '2:59.63 ',
#   '5/13/2023',
#   '\xa0\xa0\xa0\xa0\xa0Elija GODWIN, Matthew BOLING, Christopher MORALES WILLIAM, Will SUMNER'],
#  ['\xa0\xa0\xa0\xa0— GEORGIA {2}', '', '\xa0', '2:59.63 ', '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {8}\xa02:59.73 4/5/2014\xa0\xa0\xa0\xa0\xa0Najee Glass, Hugh Graham, Jr, Dedric Dukes, Arman Hall',
#   '\xa0\xa0\xa0\xa0— FLORIDA {8}',
#   '',
#   '\xa0',
#   '2:59.73 ',
#   '4/5/2014',
#   '\xa0\xa0\xa0\xa0\xa0Najee Glass, Hugh Graham, Jr, Dedric Dukes, Arman Hall'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {8}', '', '\xa0', '2:59.73 ', '4/5/2014'],
#  ["(10) Clemson\xa02:59.78 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Wanya MCCOY, D'Andre ANDERSON, Aman THORNTON 44.73, Tarees RHODEN 44.42",
#   '(10) Clemson',
#   '',
#   '\xa0',
#   '2:59.78 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   "\xa0\xa0\xa0\xa0\xa0Wanya MCCOY, D'Andre ANDERSON, Aman THORNTON 44.73, Tarees RHODEN 44.42"],
#  ['(10) Clemson',
#   '',
#   '\xa0',
#   '2:59.78 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— UCLA {3}\xa02:59.82 6/9/2023\xa0\xa0\xa0\xa0\xa0Antonie NORTJE, Willington WRIGHT, Myles MISENER-DALEY 44.48, Cameron REYNOLDS 44.99',
#   '\xa0\xa0\xa0\xa0— UCLA {3}',
#   '',
#   '\xa0',
#   '2:59.82 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Antonie NORTJE, Willington WRIGHT, Myles MISENER-DALEY 44.48, Cameron REYNOLDS 44.99'],
#  ['\xa0\xa0\xa0\xa0— UCLA {3}', '', '\xa0', '2:59.82 ', '6/9/2023'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {3}\xa02:59.91 6/8/2018\xa0\xa0\xa0\xa0\xa0Bryce Deadmon (SO), Kyree Johnson (FR), Ilolo Izu (JR) 45.43, Devin Dixon (SO) 43.93',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {3}',
#   '',
#   '\xa0',
#   '2:59.91 ',
#   '6/8/2018',
#   '\xa0\xa0\xa0\xa0\xa0Bryce Deadmon (SO), Kyree Johnson (FR), Ilolo Izu (JR) 45.43, Devin Dixon (SO) 43.93'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {3}', '', '\xa0', '2:59.91 ', '6/8/2018'],
#  ['\xa0\xa0\xa0\xa0— UCLA {4}\xa02:59.91  6/4/1988\xa0\xa0\xa0\xa0\xa0Steve Lewis 45.0, Kevin Young 44.4, Danny Everett 45.3, Henry Thomas 45.2',
#   '\xa0\xa0\xa0\xa0— UCLA {4}',
#   '',
#   '\xa0',
#   '2:59.91  ',
#   '6/4/1988',
#   '\xa0\xa0\xa0\xa0\xa0Steve Lewis 45.0, Kevin Young 44.4, Danny Everett 45.3, Henry Thomas 45.2'],
#  ['\xa0\xa0\xa0\xa0— UCLA {4}', '', '\xa0', '2:59.91  ', '6/4/1988'],
#  ['(11) Kentucky\xa02:59.93 5/14/2022\xa0\xa0\xa0\xa0\xa0Dwight ST HILLAIRE, Lance LANG, Kennedy LIGHTNER, Brian FAUST',
#   '(11) Kentucky',
#   '',
#   '\xa0',
#   '2:59.93 ',
#   '5/14/2022',
#   '\xa0\xa0\xa0\xa0\xa0Dwight ST HILLAIRE, Lance LANG, Kennedy LIGHTNER, Brian FAUST'],
#  ['(11) Kentucky', '', '\xa0', '2:59.93 ', '5/14/2022'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {4}\xa02:59.95 qq = Performance occurred during a non-final round. 6/10/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Mylik Kerley (JR), Robert Grant (JR) 45.16, Fred Kerley (SR) 43.96',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {4}',
#   '',
#   '\xa0',
#   '2:59.95 qq = Performance occurred during a non-final round. ',
#   '6/10/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Mylik Kerley (JR), Robert Grant (JR) 45.16, Fred Kerley (SR) 43.96'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {4}',
#   '',
#   '\xa0',
#   '2:59.95 qq = Performance occurred during a non-final round. ',
#   '6/10/2017'],
#  ['(12) Georgia Tech\xa02:59.95  6/6/1992\xa0\xa0\xa0\xa0\xa0Octavius Terry 45.6, Julian Amedee 45.5, Derrick Adkins 45.0, Derek Mills 43.9',
#   '(12) Georgia Tech',
#   '',
#   '\xa0',
#   '2:59.95  ',
#   '6/6/1992',
#   '\xa0\xa0\xa0\xa0\xa0Octavius Terry 45.6, Julian Amedee 45.5, Derrick Adkins 45.0, Derek Mills 43.9'],
#  ['(12) Georgia Tech', '', '\xa0', '2:59.95  ', '6/6/1992'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {2}\xa02:59.98 6/10/2022\xa0\xa0\xa0\xa0\xa0Nicholas RAMEY (SR) 46.4, Zach SHINNICK (SR) 44.6, Johnnie BLOCKBURGER (JR) 44.26, Kasaun JAMES (SR) 44.78',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {2}',
#   '',
#   '\xa0',
#   '2:59.98 ',
#   '6/10/2022',
#   '\xa0\xa0\xa0\xa0\xa0Nicholas RAMEY (SR) 46.4, Zach SHINNICK (SR) 44.6, Johnnie BLOCKBURGER (JR) 44.26, Kasaun JAMES (SR) 44.78'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {2}',
#   '',
#   '\xa0',
#   '2:59.98 ',
#   '6/10/2022'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {5}\xa02:59.98 6/10/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO) 46.7h, Mylik Kerley (JR) 44.2h, Robert Grant (JR) 45.11, Fred Kerley (SR) 43.99',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {5}',
#   '',
#   '\xa0',
#   '2:59.98 ',
#   '6/10/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO) 46.7h, Mylik Kerley (JR) 44.2h, Robert Grant (JR) 45.11, Fred Kerley (SR) 43.99'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {5}', '', '\xa0', '2:59.98 ', '6/10/2017'],
#  ['(13) Florida State\xa02:59.99  6/13/2009\xa0\xa0\xa0\xa0\xa0Kevin Williams 46.6, Kevin Borlée 43.8, Charles Clark 45.85, Jonathan Borlée 43.78',
#   '(13) Florida State',
#   '',
#   '\xa0',
#   '2:59.99  ',
#   '6/13/2009',
#   '\xa0\xa0\xa0\xa0\xa0Kevin Williams 46.6, Kevin Borlée 43.8, Charles Clark 45.85, Jonathan Borlée 43.78'],
#  ['(13) Florida State', '', '\xa0', '2:59.99  ', '6/13/2009'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {9}\xa03:00.02 6/9/2012\xa0\xa0\xa0\xa0\xa0Dedric Dukes 45.6, Hugh Graham 45.1, Leonardo Seymore 45.31, Tony McQuay 44.00',
#   '\xa0\xa0\xa0\xa0— FLORIDA {9}',
#   '',
#   '\xa0',
#   '3:00.02 ',
#   '6/9/2012',
#   '\xa0\xa0\xa0\xa0\xa0Dedric Dukes 45.6, Hugh Graham 45.1, Leonardo Seymore 45.31, Tony McQuay 44.00'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {9}', '', '\xa0', '3:00.02 ', '6/9/2012'],
#  ['(14) Baylor\xa03:00.04  6/9/2007\xa0\xa0\xa0\xa0\xa0Reggie Witherspoon 45.6, LeJerald Betters 44.4, Kevin Mutai 45.18, Quentin Iglehart-Summers 44.88',
#   '(14) Baylor',
#   '',
#   '\xa0',
#   '3:00.04  ',
#   '6/9/2007',
#   '\xa0\xa0\xa0\xa0\xa0Reggie Witherspoon 45.6, LeJerald Betters 44.4, Kevin Mutai 45.18, Quentin Iglehart-Summers 44.88'],
#  ['(14) Baylor', '', '\xa0', '3:00.04  ', '6/9/2007'],
#  ['(15) Houston\xa03:00.07 6/7/2019\xa0\xa0\xa0\xa0\xa0Amere LATTIN (SR), Kahmari MONTGOMERY (SR), Jermaine HOLT (JR) 45.26, Obi IGBOKWE (SR) 44.40',
#   '(15) Houston',
#   '',
#   '\xa0',
#   '3:00.07 ',
#   '6/7/2019',
#   '\xa0\xa0\xa0\xa0\xa0Amere LATTIN (SR), Kahmari MONTGOMERY (SR), Jermaine HOLT (JR) 45.26, Obi IGBOKWE (SR) 44.40'],
#  ['(15) Houston', '', '\xa0', '3:00.07 ', '6/7/2019'],
#  ["(16) Iowa\xa03:00.14 6/7/2019\xa0\xa0\xa0\xa0\xa0Wayne LAWRENCE JR. (FR), Antonio WOODARD (JR), Karayme BARTLEY (JR) 44.22, Mar'yea HARRIS (SR) 44.75",
#   '(16) Iowa',
#   '',
#   '\xa0',
#   '3:00.14 ',
#   '6/7/2019',
#   "\xa0\xa0\xa0\xa0\xa0Wayne LAWRENCE JR. (FR), Antonio WOODARD (JR), Karayme BARTLEY (JR) 44.22, Mar'yea HARRIS (SR) 44.75"],
#  ['(16) Iowa', '', '\xa0', '3:00.14 ', '6/7/2019'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {4}\xa03:00.17 6/10/2022\xa0\xa0\xa0\xa0\xa0Leander FORBES (JR) 46.5, Demetrius JACKSON (JR) 44.6, Corde LONG (SO) 44.77, Khaleb MCRAE (SO) 44.28',
#   '\xa0\xa0\xa0\xa0— ALABAMA {4}',
#   '',
#   '\xa0',
#   '3:00.17 ',
#   '6/10/2022',
#   '\xa0\xa0\xa0\xa0\xa0Leander FORBES (JR) 46.5, Demetrius JACKSON (JR) 44.6, Corde LONG (SO) 44.77, Khaleb MCRAE (SO) 44.28'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {4}', '', '\xa0', '3:00.17 ', '6/10/2022'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {2}\xa03:00.22  6/14/2008\xa0\xa0\xa0\xa0\xa0Marcus Boyd 45.8, Justin Boyd 45.5, LeJerald Betters 44.37, Quentin Iglehart-Summers 44.50',
#   '\xa0\xa0\xa0\xa0— BAYLOR {2}',
#   '',
#   '\xa0',
#   '3:00.22  ',
#   '6/14/2008',
#   '\xa0\xa0\xa0\xa0\xa0Marcus Boyd 45.8, Justin Boyd 45.5, LeJerald Betters 44.37, Quentin Iglehart-Summers 44.50'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {2}', '', '\xa0', '3:00.22  ', '6/14/2008'],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {2}\xa03:00.23 3/27/2021\xa0\xa0\xa0\xa0\xa0Stokes, Ross, Young, Stewart',
#   '\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {2}',
#   '',
#   '\xa0',
#   '3:00.23 ',
#   '3/27/2021',
#   '\xa0\xa0\xa0\xa0\xa0Stokes, Ross, Young, Stewart'],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {2}',
#   '',
#   '\xa0',
#   '3:00.23 ',
#   '3/27/2021'],
#  ['(17) Texas\xa03:00.31 qq = Performance occurred during a non-final round. 6/8/2022\xa0\xa0\xa0\xa0\xa0Jon MAAS (SR), Jonathan JONES (JR), Willington WRIGHT (JR) 44.34, Brian HERRON (SO) 44.72',
#   '(17) Texas',
#   '',
#   '\xa0',
#   '3:00.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jon MAAS (SR), Jonathan JONES (JR), Willington WRIGHT (JR) 44.34, Brian HERRON (SO) 44.72'],
#  ['(17) Texas',
#   '',
#   '\xa0',
#   '3:00.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2022'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {10}\xa03:00.31  4/3/2010',
#   '\xa0\xa0\xa0\xa0— FLORIDA {10}',
#   '',
#   '\xa0',
#   '3:00.31  ',
#   '4/3/2010'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {10}', '', '\xa0', '3:00.31  ', '4/3/2010'],
#  ['\xa0\xa0\xa0\xa0— LSU {2}\xa03:00.38 4/23/2016\xa0\xa0\xa0\xa0\xa0Lamar Bruton, Michael Cherry, Cyril Grayson, Fitzroy Dunkley',
#   '\xa0\xa0\xa0\xa0— LSU {2}',
#   '',
#   '\xa0',
#   '3:00.38 ',
#   '4/23/2016',
#   '\xa0\xa0\xa0\xa0\xa0Lamar Bruton, Michael Cherry, Cyril Grayson, Fitzroy Dunkley'],
#  ['\xa0\xa0\xa0\xa0— LSU {2}', '', '\xa0', '3:00.38 ', '4/23/2016'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {5}\xa03:00.42 qq = Performance occurred during a non-final round. 6/8/2022\xa0\xa0\xa0\xa0\xa0Leander FORBES (JR), Demetrius JACKSON (JR), Corde LONG (SO) 44.44, Khaleb MCRAE (SO) 44.06',
#   '\xa0\xa0\xa0\xa0— ALABAMA {5}',
#   '',
#   '\xa0',
#   '3:00.42 qq = Performance occurred during a non-final round. ',
#   '6/8/2022',
#   '\xa0\xa0\xa0\xa0\xa0Leander FORBES (JR), Demetrius JACKSON (JR), Corde LONG (SO) 44.44, Khaleb MCRAE (SO) 44.06'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {5}',
#   '',
#   '\xa0',
#   '3:00.42 qq = Performance occurred during a non-final round. ',
#   '6/8/2022'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {11}\xa03:00.42 6/14/2014\xa0\xa0\xa0\xa0\xa0Najee Glass 46.1, Hugh Graham 45.0, Dedric Dukes 44.59, Arman Hall 44.73',
#   '\xa0\xa0\xa0\xa0— FLORIDA {11}',
#   '',
#   '\xa0',
#   '3:00.42 ',
#   '6/14/2014',
#   '\xa0\xa0\xa0\xa0\xa0Najee Glass 46.1, Hugh Graham 45.0, Dedric Dukes 44.59, Arman Hall 44.73'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {11}', '', '\xa0', '3:00.42 ', '6/14/2014'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {6}\xa03:00.45 4/9/2011\xa0\xa0\xa0\xa0\xa0Bryan Miller, Tabarie Henry, Michael Preble, Demetrius Pinder',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {6}',
#   '',
#   '\xa0',
#   '3:00.45 ',
#   '4/9/2011',
#   '\xa0\xa0\xa0\xa0\xa0Bryan Miller, Tabarie Henry, Michael Preble, Demetrius Pinder'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {6}', '', '\xa0', '3:00.45 ', '4/9/2011'],
#  ['\xa0\xa0\xa0\xa0— LSU {3}\xa03:00.48 5/14/2016\xa0\xa0\xa0\xa0\xa0Lamar Bruton, Michael Cherry, Cyril Grayson, Fitzroy Dunkley',
#   '\xa0\xa0\xa0\xa0— LSU {3}',
#   '',
#   '\xa0',
#   '3:00.48 ',
#   '5/14/2016',
#   '\xa0\xa0\xa0\xa0\xa0Lamar Bruton, Michael Cherry, Cyril Grayson, Fitzroy Dunkley'],
#  ['\xa0\xa0\xa0\xa0— LSU {3}', '', '\xa0', '3:00.48 ', '5/14/2016'],
#  ['\xa0\xa0\xa0\xa0— UCLA {5}\xa03:00.55  6/6/1987\xa0\xa0\xa0\xa0\xa0Anthony Washington 47.0, Kevin Young 44.7, Henry Thomas 44.0, Danny Everett 44.9',
#   '\xa0\xa0\xa0\xa0— UCLA {5}',
#   '',
#   '\xa0',
#   '3:00.55  ',
#   '6/6/1987',
#   '\xa0\xa0\xa0\xa0\xa0Anthony Washington 47.0, Kevin Young 44.7, Henry Thomas 44.0, Danny Everett 44.9'],
#  ['\xa0\xa0\xa0\xa0— UCLA {5}', '', '\xa0', '3:00.55  ', '6/6/1987'],
#  ['\xa0\xa0\xa0\xa0— LSU {4}\xa03:00.56 6/8/2018\xa0\xa0\xa0\xa0\xa0Jahnoy Thompson (JR), Correion Mosby (JR), Renard Howell (SR), Jaron Flournoy (JR)',
#   '\xa0\xa0\xa0\xa0— LSU {4}',
#   '',
#   '\xa0',
#   '3:00.56 ',
#   '6/8/2018',
#   '\xa0\xa0\xa0\xa0\xa0Jahnoy Thompson (JR), Correion Mosby (JR), Renard Howell (SR), Jaron Flournoy (JR)'],
#  ['\xa0\xa0\xa0\xa0— LSU {4}', '', '\xa0', '3:00.56 ', '6/8/2018'],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {3}\xa03:00.57  6/11/2005\xa0\xa0\xa0\xa0\xa0Rich Allen 46.7, Seth Amoo 44.3, Domenick Peterson 45.2, Lewis Banda 44.4',
#   '\xa0\xa0\xa0\xa0— ARIZONA STATE {3}',
#   '',
#   '\xa0',
#   '3:00.57  ',
#   '6/11/2005',
#   '\xa0\xa0\xa0\xa0\xa0Rich Allen 46.7, Seth Amoo 44.3, Domenick Peterson 45.2, Lewis Banda 44.4'],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {3}', '', '\xa0', '3:00.57  ', '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {3}\xa03:00.58 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Demar FRANCIS, Nathaniel EZEKIEL, Hasani BARR 44.85, Dillon BEDELL 44.37',
#   '\xa0\xa0\xa0\xa0— BAYLOR {3}',
#   '',
#   '\xa0',
#   '3:00.58 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Demar FRANCIS, Nathaniel EZEKIEL, Hasani BARR 44.85, Dillon BEDELL 44.37'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {3}',
#   '',
#   '\xa0',
#   '3:00.58 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {3}\xa03:00.58  6/6/1992\xa0\xa0\xa0\xa0\xa0Travis Hannah 45.3, Curtis Conway 45.4, Martin Cannady 46.3, Quincy Watts 43.6',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {3}',
#   '',
#   '\xa0',
#   '3:00.58  ',
#   '6/6/1992',
#   '\xa0\xa0\xa0\xa0\xa0Travis Hannah 45.3, Curtis Conway 45.4, Martin Cannady 46.3, Quincy Watts 43.6'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {3}',
#   '',
#   '\xa0',
#   '3:00.58  ',
#   '6/6/1992'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {4}\xa03:00.60 qq = Performance occurred during a non-final round. 6/1/1995\xa0\xa0\xa0\xa0\xa0Michael Ford (JR), Raoul Howard (JR), Corey Williams (SR), Deon Minor (SR)',
#   '\xa0\xa0\xa0\xa0— BAYLOR {4}',
#   '',
#   '\xa0',
#   '3:00.60 qq = Performance occurred during a non-final round. ',
#   '6/1/1995',
#   '\xa0\xa0\xa0\xa0\xa0Michael Ford (JR), Raoul Howard (JR), Corey Williams (SR), Deon Minor (SR)'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {4}',
#   '',
#   '\xa0',
#   '3:00.60 qq = Performance occurred during a non-final round. ',
#   '6/1/1995'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {5}\xa03:00.61 4/1/2023\xa0\xa0\xa0\xa0\xa0Kamden JACKSON, Matthew MOORER, Dillon BEDELL 45.36, Nathaniel EZEKIEL 44.78',
#   '\xa0\xa0\xa0\xa0— BAYLOR {5}',
#   '',
#   '\xa0',
#   '3:00.61 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Kamden JACKSON, Matthew MOORER, Dillon BEDELL 45.36, Nathaniel EZEKIEL 44.78'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {5}', '', '\xa0', '3:00.61 ', '4/1/2023'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {6}\xa03:00.61  4/1/1995\xa0\xa0\xa0\xa0\xa0Michael Ford, Raoul Howard, Deon Minor , Marlon Ramsey',
#   '\xa0\xa0\xa0\xa0— BAYLOR {6}',
#   '',
#   '\xa0',
#   '3:00.61  ',
#   '4/1/1995',
#   '\xa0\xa0\xa0\xa0\xa0Michael Ford, Raoul Howard, Deon Minor , Marlon Ramsey'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {6}', '', '\xa0', '3:00.61  ', '4/1/1995'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {7}\xa03:00.62 6/11/2011\xa0\xa0\xa0\xa0\xa0Bryan Miller 45.5, Demetrius Pinder 44.6, Michael Preble 45.60, Tabarie Henry 44.86',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {7}',
#   '',
#   '\xa0',
#   '3:00.62 ',
#   '6/11/2011',
#   '\xa0\xa0\xa0\xa0\xa0Bryan Miller 45.5, Demetrius Pinder 44.6, Michael Preble 45.60, Tabarie Henry 44.86'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {7}', '', '\xa0', '3:00.62 ', '6/11/2011'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {4}\xa03:00.64 6/9/2012\xa0\xa0\xa0\xa0\xa0Joey Hughes 45.8, Josh Mance 44.7, Reggie Wyatt 45.30, Bryshon Nellum 44.82',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {4}',
#   '',
#   '\xa0',
#   '3:00.64 ',
#   '6/9/2012',
#   '\xa0\xa0\xa0\xa0\xa0Joey Hughes 45.8, Josh Mance 44.7, Reggie Wyatt 45.30, Bryshon Nellum 44.82'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {4}',
#   '',
#   '\xa0',
#   '3:00.64 ',
#   '6/9/2012'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {7}\xa03:00.64  6/6/1992\xa0\xa0\xa0\xa0\xa0Daniel Fredericks 45.8, Tony Miller 44.9, Etheridge Green 45.1, Deon Minor 44.8',
#   '\xa0\xa0\xa0\xa0— BAYLOR {7}',
#   '',
#   '\xa0',
#   '3:00.64  ',
#   '6/6/1992',
#   '\xa0\xa0\xa0\xa0\xa0Daniel Fredericks 45.8, Tony Miller 44.9, Etheridge Green 45.1, Deon Minor 44.8'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {7}', '', '\xa0', '3:00.64  ', '6/6/1992'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {12}\xa03:00.68  6/4/1988\xa0\xa0\xa0\xa0\xa0Calvin Long 45.6, Dennis Mitchell 44.4, Timmy Johnson 45.5, Mark Everett 45.2',
#   '\xa0\xa0\xa0\xa0— FLORIDA {12}',
#   '',
#   '\xa0',
#   '3:00.68  ',
#   '6/4/1988',
#   '\xa0\xa0\xa0\xa0\xa0Calvin Long 45.6, Dennis Mitchell 44.4, Timmy Johnson 45.5, Mark Everett 45.2'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {12}', '', '\xa0', '3:00.68  ', '6/4/1988'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {8}\xa03:00.69 qq = Performance occurred during a non-final round. 5/27/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Fred Kerley (SR), Robert Grant (JR) 45.30, Mylik Kerley (JR) 45.30',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {8}',
#   '',
#   '\xa0',
#   '3:00.69 qq = Performance occurred during a non-final round. ',
#   '5/27/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Fred Kerley (SR), Robert Grant (JR) 45.30, Mylik Kerley (JR) 45.30'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {8}',
#   '',
#   '\xa0',
#   '3:00.69 qq = Performance occurred during a non-final round. ',
#   '5/27/2017'],
#  ['\xa0\xa0\xa0\xa0— LSU {5}\xa03:00.69 6/11/2016\xa0\xa0\xa0\xa0\xa0Lamar Bruton (JR) 46.4, Michael Cherry (JR) 44.2, Cyril Grayson (SR) 45.80, Fitzroy Dunkley (SR) 44.29',
#   '\xa0\xa0\xa0\xa0— LSU {5}',
#   '',
#   '\xa0',
#   '3:00.69 ',
#   '6/11/2016',
#   '\xa0\xa0\xa0\xa0\xa0Lamar Bruton (JR) 46.4, Michael Cherry (JR) 44.2, Cyril Grayson (SR) 45.80, Fitzroy Dunkley (SR) 44.29'],
#  ['\xa0\xa0\xa0\xa0— LSU {5}', '', '\xa0', '3:00.69 ', '6/11/2016'],
#  ['\xa0\xa0\xa0\xa0— TEXAS {2}\xa03:00.70 qq = Performance occurred during a non-final round. 5/27/2022\xa0\xa0\xa0\xa0\xa0Jon MAAS (SR), Jonathan JONES (JR), Willington WRIGHT (JR), Brian HERRON (SO)',
#   '\xa0\xa0\xa0\xa0— TEXAS {2}',
#   '',
#   '\xa0',
#   '3:00.70 qq = Performance occurred during a non-final round. ',
#   '5/27/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jon MAAS (SR), Jonathan JONES (JR), Willington WRIGHT (JR), Brian HERRON (SO)'],
#  ['\xa0\xa0\xa0\xa0— TEXAS {2}',
#   '',
#   '\xa0',
#   '3:00.70 qq = Performance occurred during a non-final round. ',
#   '5/27/2022'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {9}\xa03:00.72 5/13/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Fred Kerley (SR), Robert Grant (JR) 45.48, Mylik Kerley (JR) 45.00',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {9}',
#   '',
#   '\xa0',
#   '3:00.72 ',
#   '5/13/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Fred Kerley (SR), Robert Grant (JR) 45.48, Mylik Kerley (JR) 45.00'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {9}', '', '\xa0', '3:00.72 ', '5/13/2017'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {8}\xa03:00.73 5/12/2023\xa0\xa0\xa0\xa0\xa0Matthew MOORER, Hasani BARR, Nathaniel EZEKIEL, Dillon BEDELL',
#   '\xa0\xa0\xa0\xa0— BAYLOR {8}',
#   '',
#   '\xa0',
#   '3:00.73 ',
#   '5/12/2023',
#   '\xa0\xa0\xa0\xa0\xa0Matthew MOORER, Hasani BARR, Nathaniel EZEKIEL, Dillon BEDELL'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {8}', '', '\xa0', '3:00.73 ', '5/12/2023'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {10}\xa03:00.74 4/29/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO) 45.8h, Fred Kerley (SR) 43.7h, Devin Dixon (FR) 46.22, Mylik Kerley (JR) 44.99',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {10}',
#   '',
#   '\xa0',
#   '3:00.74 ',
#   '4/29/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO) 45.8h, Fred Kerley (SR) 43.7h, Devin Dixon (FR) 46.22, Mylik Kerley (JR) 44.99'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {10}', '', '\xa0', '3:00.74 ', '4/29/2017'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {11}\xa03:00.76 qq = Performance occurred during a non-final round. 6/12/2014\xa0\xa0\xa0\xa0\xa0Aldrich Bailey, Jr., Carlyle Roudette, Bralon Taplin, Deon Lendore',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {11}',
#   '',
#   '\xa0',
#   '3:00.76 qq = Performance occurred during a non-final round. ',
#   '6/12/2014',
#   '\xa0\xa0\xa0\xa0\xa0Aldrich Bailey, Jr., Carlyle Roudette, Bralon Taplin, Deon Lendore'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {11}',
#   '',
#   '\xa0',
#   '3:00.76 qq = Performance occurred during a non-final round. ',
#   '6/12/2014'],
#  ['(18) Southern Illinois\xa03:00.78  4/28/1984\xa0\xa0\xa0\xa0\xa0Parry Duncan 45.5, Tony Adams 45.6, Elvis Forde 45.1, Michael Franks 44.5',
#   '(18) Southern Illinois',
#   '',
#   '\xa0',
#   '3:00.78  ',
#   '4/28/1984',
#   '\xa0\xa0\xa0\xa0\xa0Parry Duncan 45.5, Tony Adams 45.6, Elvis Forde 45.1, Michael Franks 44.5'],
#  ['(18) Southern Illinois', '', '\xa0', '3:00.78  ', '4/28/1984'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {6}\xa03:00.81 6/9/2023\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Tarsis OROGOT, Corde LONG 46.76, Khaleb MCRAE 44.14',
#   '\xa0\xa0\xa0\xa0— ALABAMA {6}',
#   '',
#   '\xa0',
#   '3:00.81 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Tarsis OROGOT, Corde LONG 46.76, Khaleb MCRAE 44.14'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {6}', '', '\xa0', '3:00.81 ', '6/9/2023'],
#  ['(19) Oregon\xa03:00.81  6/11/2005\xa0\xa0\xa0\xa0\xa0Jordan Kent 46.5, Kedar Inico 44.3, AK Ikwuakor 45.4, John Scherer 44.6',
#   '(19) Oregon',
#   '',
#   '\xa0',
#   '3:00.81  ',
#   '6/11/2005',
#   '\xa0\xa0\xa0\xa0\xa0Jordan Kent 46.5, Kedar Inico 44.3, AK Ikwuakor 45.4, John Scherer 44.6'],
#  ['(19) Oregon', '', '\xa0', '3:00.81  ', '6/11/2005'],
#  ['(19) SMU\xa03:00.81  6/6/1987\xa0\xa0\xa0\xa0\xa0Harold Spells 46.1, Kevin Robinzine 44.2, Cedric Matterson 45.8, Roy Martin 44.8',
#   '(19) SMU',
#   '',
#   '\xa0',
#   '3:00.81  ',
#   '6/6/1987',
#   '\xa0\xa0\xa0\xa0\xa0Harold Spells 46.1, Kevin Robinzine 44.2, Cedric Matterson 45.8, Roy Martin 44.8'],
#  ['(19) SMU', '', '\xa0', '3:00.81  ', '6/6/1987'],
#  ['(21) Ohio State\xa03:00.82  6/5/1993\xa0\xa0\xa0\xa0\xa0Rich Jones 46.2, Aaron Payne 45.0, Robert Smith 45.4, Chris Nelloms 44.2',
#   '(21) Ohio State',
#   '',
#   '\xa0',
#   '3:00.82  ',
#   '6/5/1993',
#   '\xa0\xa0\xa0\xa0\xa0Rich Jones 46.2, Aaron Payne 45.0, Robert Smith 45.4, Chris Nelloms 44.2'],
#  ['(21) Ohio State', '', '\xa0', '3:00.82  ', '6/5/1993'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {9}\xa03:00.83  6/6/1987\xa0\xa0\xa0\xa0\xa0Darnell Chase 46.0, Keith Stanford 45.0, Michael Johnson 45.2, Raymond Pierre 44.7',
#   '\xa0\xa0\xa0\xa0— BAYLOR {9}',
#   '',
#   '\xa0',
#   '3:00.83  ',
#   '6/6/1987',
#   '\xa0\xa0\xa0\xa0\xa0Darnell Chase 46.0, Keith Stanford 45.0, Michael Johnson 45.2, Raymond Pierre 44.7'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {9}', '', '\xa0', '3:00.83  ', '6/6/1987'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {10}\xa03:00.84  6/1/1985\xa0\xa0\xa0\xa0\xa0Darnell Chase 46.0, Derwin Graham 45.8, Johnny Thomas 44.8, Willie Caldwell 44.3',
#   '\xa0\xa0\xa0\xa0— BAYLOR {10}',
#   '',
#   '\xa0',
#   '3:00.84  ',
#   '6/1/1985',
#   '\xa0\xa0\xa0\xa0\xa0Darnell Chase 46.0, Derwin Graham 45.8, Johnny Thomas 44.8, Willie Caldwell 44.3'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {10}', '', '\xa0', '3:00.84  ', '6/1/1985'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {12}\xa03:00.88 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Eric HEMPHILL III, Omajuwa ETIWE, DeMarco ESCOBAR, Auhmad ROBINSON 44.36',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {12}',
#   '',
#   '\xa0',
#   '3:00.88 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Eric HEMPHILL III, Omajuwa ETIWE, DeMarco ESCOBAR, Auhmad ROBINSON 44.36'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {12}',
#   '',
#   '\xa0',
#   '3:00.88 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {13}\xa03:00.89  6/12/2010\xa0\xa0\xa0\xa0\xa0Bryan Miller 46.4, Demetrius Pinder 44.6, Curtis Mitchell 45.07, Tabarie Henry 44.79',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {13}',
#   '',
#   '\xa0',
#   '3:00.89  ',
#   '6/12/2010',
#   '\xa0\xa0\xa0\xa0\xa0Bryan Miller 46.4, Demetrius Pinder 44.6, Curtis Mitchell 45.07, Tabarie Henry 44.79'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {13}', '', '\xa0', '3:00.89  ', '6/12/2010'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {14}\xa03:00.90 6/9/2023\xa0\xa0\xa0\xa0\xa0Eric HEMPHILL III, Omajuwa ETIWE, DeMarco ESCOBAR, Auhmad ROBINSON',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {14}',
#   '',
#   '\xa0',
#   '3:00.90 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Eric HEMPHILL III, Omajuwa ETIWE, DeMarco ESCOBAR, Auhmad ROBINSON'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {14}', '', '\xa0', '3:00.90 ', '6/9/2023'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {15}\xa03:00.91  6/13/2009',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {15}',
#   '',
#   '\xa0',
#   '3:00.91  ',
#   '6/13/2009'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {15}', '', '\xa0', '3:00.91  ', '6/13/2009'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {16}\xa03:00.91 AA = Performance occurred at altitude (>1000 meters above sea level) 6/3/1989\xa0\xa0\xa0\xa0\xa0Stanley Kerr 45.4, Errington Lindo 45.8, Derrick Florence 45.0, Howard Davis 44.7',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {16}',
#   '',
#   '\xa0',
#   '3:00.91 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '6/3/1989',
#   '\xa0\xa0\xa0\xa0\xa0Stanley Kerr 45.4, Errington Lindo 45.8, Derrick Florence 45.0, Howard Davis 44.7'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {16}',
#   '',
#   '\xa0',
#   '3:00.91 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '6/3/1989'],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {3}\xa03:00.92 6/11/2021\xa0\xa0\xa0\xa0\xa0Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.89, Trevor STEWART (SR) 44.17',
#   '\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {3}',
#   '',
#   '\xa0',
#   '3:00.92 ',
#   '6/11/2021',
#   '\xa0\xa0\xa0\xa0\xa0Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.89, Trevor STEWART (SR) 44.17'],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {3}',
#   '',
#   '\xa0',
#   '3:00.92 ',
#   '6/11/2021'],
#  ['(22) Arkansas\xa03:00.97 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Lance LANG, James BENSON II, Connor WASHINGTON, Christopher BAILEY 44.37',
#   '(22) Arkansas',
#   '',
#   '\xa0',
#   '3:00.97 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Lance LANG, James BENSON II, Connor WASHINGTON, Christopher BAILEY 44.37'],
#  ['(22) Arkansas',
#   '',
#   '\xa0',
#   '3:00.97 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— LSU {6}\xa03:01.00 3/27/2021\xa0\xa0\xa0\xa0\xa0Camel, Burrell, Terry, Williams',
#   '\xa0\xa0\xa0\xa0— LSU {6}',
#   '',
#   '\xa0',
#   '3:01.00 ',
#   '3/27/2021',
#   '\xa0\xa0\xa0\xa0\xa0Camel, Burrell, Terry, Williams'],
#  ['\xa0\xa0\xa0\xa0— LSU {6}', '', '\xa0', '3:01.00 ', '3/27/2021'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {13}\xa03:01.00 3/31/2018\xa0\xa0\xa0\xa0\xa0Fasasi, Holloway, Sawyers, Vedel',
#   '\xa0\xa0\xa0\xa0— FLORIDA {13}',
#   '',
#   '\xa0',
#   '3:01.00 ',
#   '3/31/2018',
#   '\xa0\xa0\xa0\xa0\xa0Fasasi, Holloway, Sawyers, Vedel'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {13}', '', '\xa0', '3:01.00 ', '3/31/2018'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {11}\xa03:01.03  6/12/2004\xa0\xa0\xa0\xa0\xa0Wil Fitts 46.7, Braelon Davis 46.0, Jeremy Wariner 44.0, Darold Williamson 44.3',
#   '\xa0\xa0\xa0\xa0— BAYLOR {11}',
#   '',
#   '\xa0',
#   '3:01.03  ',
#   '6/12/2004',
#   '\xa0\xa0\xa0\xa0\xa0Wil Fitts 46.7, Braelon Davis 46.0, Jeremy Wariner 44.0, Darold Williamson 44.3'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {11}', '', '\xa0', '3:01.03  ', '6/12/2004'],
#  ['\xa0\xa0\xa0\xa0— LSU {7}\xa03:01.07 6/11/2011\xa0\xa0\xa0\xa0\xa0Robert Simmons 46.7, Ade Alleyne-Forte 45.0, Caleb Williams 44.54, Riker Hylton 44.88',
#   '\xa0\xa0\xa0\xa0— LSU {7}',
#   '',
#   '\xa0',
#   '3:01.07 ',
#   '6/11/2011',
#   '\xa0\xa0\xa0\xa0\xa0Robert Simmons 46.7, Ade Alleyne-Forte 45.0, Caleb Williams 44.54, Riker Hylton 44.88'],
#  ['\xa0\xa0\xa0\xa0— LSU {7}', '', '\xa0', '3:01.07 ', '6/11/2011'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {17}\xa03:01.07  6/9/2007\xa0\xa0\xa0\xa0\xa0Bryant McCombs 45.9, Alfred Robinson 45.0, Marcus Pitre 45.49, Justin Oliver 44.67',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {17}',
#   '',
#   '\xa0',
#   '3:01.07  ',
#   '6/9/2007',
#   '\xa0\xa0\xa0\xa0\xa0Bryant McCombs 45.9, Alfred Robinson 45.0, Marcus Pitre 45.49, Justin Oliver 44.67'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {17}', '', '\xa0', '3:01.07  ', '6/9/2007'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {5}\xa03:01.11 qq = Performance occurred during a non-final round. 5/26/2018',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {5}',
#   '',
#   '\xa0',
#   '3:01.11 qq = Performance occurred during a non-final round. ',
#   '5/26/2018'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {5}',
#   '',
#   '\xa0',
#   '3:01.11 qq = Performance occurred during a non-final round. ',
#   '5/26/2018'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {14}\xa03:01.12 6/11/2016\xa0\xa0\xa0\xa0\xa0Kunle Fasasi (FR) 45.7, Arman Hall (SR) 44.6, Hugh Graham, Jr (SR) 45.67, Najee Glass (SR) 45.08',
#   '\xa0\xa0\xa0\xa0— FLORIDA {14}',
#   '',
#   '\xa0',
#   '3:01.12 ',
#   '6/11/2016',
#   '\xa0\xa0\xa0\xa0\xa0Kunle Fasasi (FR) 45.7, Arman Hall (SR) 44.6, Hugh Graham, Jr (SR) 45.67, Najee Glass (SR) 45.08'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {14}', '', '\xa0', '3:01.12 ', '6/11/2016'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {12}\xa03:01.12  6/13/2009',
#   '\xa0\xa0\xa0\xa0— BAYLOR {12}',
#   '',
#   '\xa0',
#   '3:01.12  ',
#   '6/13/2009'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {12}', '', '\xa0', '3:01.12  ', '6/13/2009'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {18}\xa03:01.13 qq = Performance occurred during a non-final round. 6/6/2018',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {18}',
#   '',
#   '\xa0',
#   '3:01.13 qq = Performance occurred during a non-final round. ',
#   '6/6/2018'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {18}',
#   '',
#   '\xa0',
#   '3:01.13 qq = Performance occurred during a non-final round. ',
#   '6/6/2018'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {7}\xa03:01.16  6/1/1985\xa0\xa0\xa0\xa0\xa0Terry Menefee 45.6, Tony Davis 46.1, Bernie Jackson 45.3, Cedric Vaughans 44.2',
#   '\xa0\xa0\xa0\xa0— ALABAMA {7}',
#   '',
#   '\xa0',
#   '3:01.16  ',
#   '6/1/1985',
#   '\xa0\xa0\xa0\xa0\xa0Terry Menefee 45.6, Tony Davis 46.1, Bernie Jackson 45.3, Cedric Vaughans 44.2'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {7}', '', '\xa0', '3:01.16  ', '6/1/1985'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {8}\xa03:01.16  1985\xa0\xa0\xa0\xa0\xa0Menefee, Davis, Jackson, Vaughans',
#   '\xa0\xa0\xa0\xa0— ALABAMA {8}',
#   '',
#   '\xa0',
#   '3:01.16  ',
#   '1985',
#   '\xa0\xa0\xa0\xa0\xa0Menefee, Davis, Jackson, Vaughans'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {8}', '', '\xa0', '3:01.16  ', '1985'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {19}\xa03:01.17 5/13/2018\xa0\xa0\xa0\xa0\xa0Rose, Deadmon, Izu, Dixon',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {19}',
#   '',
#   '\xa0',
#   '3:01.17 ',
#   '5/13/2018',
#   '\xa0\xa0\xa0\xa0\xa0Rose, Deadmon, Izu, Dixon'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {19}', '', '\xa0', '3:01.17 ', '5/13/2018'],
#  ['(23) Iowa State\xa03:01.17  6/1/1985\xa0\xa0\xa0\xa0\xa0Sebron Flenaugh 47.6, Leroy Dixson 44.7, Danny Harris 44.3, Sunday Uti 44.6',
#   '(23) Iowa State',
#   '',
#   '\xa0',
#   '3:01.17  ',
#   '6/1/1985',
#   '\xa0\xa0\xa0\xa0\xa0Sebron Flenaugh 47.6, Leroy Dixson 44.7, Danny Harris 44.3, Sunday Uti 44.6'],
#  ['(23) Iowa State', '', '\xa0', '3:01.17  ', '6/1/1985'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {20}\xa03:01.19 5/18/2014',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {20}',
#   '',
#   '\xa0',
#   '3:01.19 ',
#   '5/18/2014'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {20}', '', '\xa0', '3:01.19 ', '5/18/2014'],
#  ['\xa0\xa0\xa0\xa0— LSU {8}\xa03:01.21 6/9/2012\xa0\xa0\xa0\xa0\xa0Simmons, Williams, Alleyne-Forte, Hylton',
#   '\xa0\xa0\xa0\xa0— LSU {8}',
#   '',
#   '\xa0',
#   '3:01.21 ',
#   '6/9/2012',
#   '\xa0\xa0\xa0\xa0\xa0Simmons, Williams, Alleyne-Forte, Hylton'],
#  ['\xa0\xa0\xa0\xa0— LSU {8}', '', '\xa0', '3:01.21 ', '6/9/2012'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {15}\xa03:01.22 qq = Performance occurred during a non-final round. 5/27/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON, Ryan WILLIE, Kemuel SANTANA, Champion ALLISON',
#   '\xa0\xa0\xa0\xa0— FLORIDA {15}',
#   '',
#   '\xa0',
#   '3:01.22 qq = Performance occurred during a non-final round. ',
#   '5/27/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON, Ryan WILLIE, Kemuel SANTANA, Champion ALLISON'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {15}',
#   '',
#   '\xa0',
#   '3:01.22 qq = Performance occurred during a non-final round. ',
#   '5/27/2022'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {13}\xa03:01.22  6/5/1993\xa0\xa0\xa0\xa0\xa0Daniel Fredericks 46.4, Dion Minor 45.3, Tony Miller 44.7, Etheridge Green 44.8',
#   '\xa0\xa0\xa0\xa0— BAYLOR {13}',
#   '',
#   '\xa0',
#   '3:01.22  ',
#   '6/5/1993',
#   '\xa0\xa0\xa0\xa0\xa0Daniel Fredericks 46.4, Dion Minor 45.3, Tony Miller 44.7, Etheridge Green 44.8'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {13}', '', '\xa0', '3:01.22  ', '6/5/1993'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {21}\xa03:01.23 qq = Performance occurred during a non-final round. 5/26/2018',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {21}',
#   '',
#   '\xa0',
#   '3:01.23 qq = Performance occurred during a non-final round. ',
#   '5/26/2018'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {21}',
#   '',
#   '\xa0',
#   '3:01.23 qq = Performance occurred during a non-final round. ',
#   '5/26/2018'],
#  ['(24) Oklahoma\xa03:01.25  6/7/1997\xa0\xa0\xa0\xa0\xa0Edward Clarke 45.6, Danny McFarlane 45.6, Ryan Kite 45.14, Roxbert Martin 44.91',
#   '(24) Oklahoma',
#   '',
#   '\xa0',
#   '3:01.25  ',
#   '6/7/1997',
#   '\xa0\xa0\xa0\xa0\xa0Edward Clarke 45.6, Danny McFarlane 45.6, Ryan Kite 45.14, Roxbert Martin 44.91'],
#  ['(24) Oklahoma', '', '\xa0', '3:01.25  ', '6/7/1997'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {14}\xa03:01.25  6/1/1996\xa0\xa0\xa0\xa0\xa0Michael Ford 46.2, Raoul Howard 45.3, Darrin Strong 45.1, Marlon Ramsey 44.7',
#   '\xa0\xa0\xa0\xa0— BAYLOR {14}',
#   '',
#   '\xa0',
#   '3:01.25  ',
#   '6/1/1996',
#   '\xa0\xa0\xa0\xa0\xa0Michael Ford 46.2, Raoul Howard 45.3, Darrin Strong 45.1, Marlon Ramsey 44.7'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {14}', '', '\xa0', '3:01.25  ', '6/1/1996'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {22}\xa03:01.26 qq = Performance occurred during a non-final round. 6/5/2019\xa0\xa0\xa0\xa0\xa0Bryce DEADMON (JR), Robert GRANT (SR), DeWitt THOMAS (SR) 45.87, Devin DIXON (JR) 44.40',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {22}',
#   '',
#   '\xa0',
#   '3:01.26 qq = Performance occurred during a non-final round. ',
#   '6/5/2019',
#   '\xa0\xa0\xa0\xa0\xa0Bryce DEADMON (JR), Robert GRANT (SR), DeWitt THOMAS (SR) 45.87, Devin DIXON (JR) 44.40'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {22}',
#   '',
#   '\xa0',
#   '3:01.26 qq = Performance occurred during a non-final round. ',
#   '6/5/2019'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {16}\xa03:01.26 3/29/2014\xa0\xa0\xa0\xa0\xa0Najee Glass 46.3, Hugh Graham, Jr. 44.7, Dedric Dukes 45.2, Arman Hall 45.0',
#   '\xa0\xa0\xa0\xa0— FLORIDA {16}',
#   '',
#   '\xa0',
#   '3:01.26 ',
#   '3/29/2014',
#   '\xa0\xa0\xa0\xa0\xa0Najee Glass 46.3, Hugh Graham, Jr. 44.7, Dedric Dukes 45.2, Arman Hall 45.0'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {16}', '', '\xa0', '3:01.26 ', '3/29/2014'],
#  ['\xa0\xa0\xa0\xa0— TEXAS {3}\xa03:01.28 3/27/2021\xa0\xa0\xa0\xa0\xa0Maas, Harris, Jones, Wright',
#   '\xa0\xa0\xa0\xa0— TEXAS {3}',
#   '',
#   '\xa0',
#   '3:01.28 ',
#   '3/27/2021',
#   '\xa0\xa0\xa0\xa0\xa0Maas, Harris, Jones, Wright'],
#  ['\xa0\xa0\xa0\xa0— TEXAS {3}', '', '\xa0', '3:01.28 ', '3/27/2021'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {17}\xa03:01.30 qq = Performance occurred during a non-final round. 6/8/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON (JR), Ryan WILLIE (SO), Jacob MILEY (SO) 46.19, Champion ALLISON (JR) 44.75',
#   '\xa0\xa0\xa0\xa0— FLORIDA {17}',
#   '',
#   '\xa0',
#   '3:01.30 qq = Performance occurred during a non-final round. ',
#   '6/8/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON (JR), Ryan WILLIE (SO), Jacob MILEY (SO) 46.19, Champion ALLISON (JR) 44.75'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {17}',
#   '',
#   '\xa0',
#   '3:01.30 qq = Performance occurred during a non-final round. ',
#   '6/8/2022'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {6}\xa03:01.30 qq = Performance occurred during a non-final round. 6/6/2018',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {6}',
#   '',
#   '\xa0',
#   '3:01.30 qq = Performance occurred during a non-final round. ',
#   '6/6/2018'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {6}',
#   '',
#   '\xa0',
#   '3:01.30 qq = Performance occurred during a non-final round. ',
#   '6/6/2018'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {18}\xa03:01.34 6/8/2013\xa0\xa0\xa0\xa0\xa0Najee Glass (FR) 46.0, Hugh Graham, Jr. (SO) 45.4, Dedric Dukes (SO) 45.09, Arman Hall (FR) 44.86',
#   '\xa0\xa0\xa0\xa0— FLORIDA {18}',
#   '',
#   '\xa0',
#   '3:01.34 ',
#   '6/8/2013',
#   '\xa0\xa0\xa0\xa0\xa0Najee Glass (FR) 46.0, Hugh Graham, Jr. (SO) 45.4, Dedric Dukes (SO) 45.09, Arman Hall (FR) 44.86'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {18}', '', '\xa0', '3:01.34 ', '6/8/2013'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {19}\xa03:01.36  6/11/2005',
#   '\xa0\xa0\xa0\xa0— FLORIDA {19}',
#   '',
#   '\xa0',
#   '3:01.36  ',
#   '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {19}', '', '\xa0', '3:01.36  ', '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {4}\xa03:01.38 4/1/2023\xa0\xa0\xa0\xa0\xa0Justin ROBINSON, Jeremiah CURRY, Dubem NWACHUKWU 44.80, Trevin MOYER 45.37',
#   '\xa0\xa0\xa0\xa0— ARIZONA STATE {4}',
#   '',
#   '\xa0',
#   '3:01.38 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Justin ROBINSON, Jeremiah CURRY, Dubem NWACHUKWU 44.80, Trevin MOYER 45.37'],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {4}', '', '\xa0', '3:01.38 ', '4/1/2023'],
#  ['\xa0\xa0\xa0\xa0— OHIO STATE {2}\xa03:01.41  6/6/1992',
#   '\xa0\xa0\xa0\xa0— OHIO STATE {2}',
#   '',
#   '\xa0',
#   '3:01.41  ',
#   '6/6/1992'],
#  ['\xa0\xa0\xa0\xa0— OHIO STATE {2}', '', '\xa0', '3:01.41  ', '6/6/1992'],
#  ['\xa0\xa0\xa0\xa0— OHIO STATE {3}\xa03:01.41  1992\xa0\xa0\xa0\xa0\xa0Rich Jones, Aaron Payne, Robert Smith, Chris Nelloms',
#   '\xa0\xa0\xa0\xa0— OHIO STATE {3}',
#   '',
#   '\xa0',
#   '3:01.41  ',
#   '1992',
#   '\xa0\xa0\xa0\xa0\xa0Rich Jones, Aaron Payne, Robert Smith, Chris Nelloms'],
#  ['\xa0\xa0\xa0\xa0— OHIO STATE {3}', '', '\xa0', '3:01.41  ', '1992'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {23}\xa03:01.42 qq = Performance occurred during a non-final round. 5/31/2014\xa0\xa0\xa0\xa0\xa0Carlyle Roudette, Aldrich Bailey, Jr., Bralon Taplin, Deon Lendore',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {23}',
#   '',
#   '\xa0',
#   '3:01.42 qq = Performance occurred during a non-final round. ',
#   '5/31/2014',
#   '\xa0\xa0\xa0\xa0\xa0Carlyle Roudette, Aldrich Bailey, Jr., Bralon Taplin, Deon Lendore'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {23}',
#   '',
#   '\xa0',
#   '3:01.42 qq = Performance occurred during a non-final round. ',
#   '5/31/2014'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {15}\xa03:01.46  6/3/2000\xa0\xa0\xa0\xa0\xa0Zsolt Szeglet 46.3, Bayano Kamani 45.4, Floyd Thompson 45.1, Brandon Couts 44.7',
#   '\xa0\xa0\xa0\xa0— BAYLOR {15}',
#   '',
#   '\xa0',
#   '3:01.46  ',
#   '6/3/2000',
#   '\xa0\xa0\xa0\xa0\xa0Zsolt Szeglet 46.3, Bayano Kamani 45.4, Floyd Thompson 45.1, Brandon Couts 44.7'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {15}', '', '\xa0', '3:01.46  ', '6/3/2000'],
#  ['\xa0\xa0\xa0\xa0— OKLAHOMA {2}\xa03:01.46  4/28/1984\xa0\xa0\xa0\xa0\xa0Aubrey Jones 45.7, Donnie Kemp 44.9, Dannie Carter 45.8, Don Bly 45.1',
#   '\xa0\xa0\xa0\xa0— OKLAHOMA {2}',
#   '',
#   '\xa0',
#   '3:01.46  ',
#   '4/28/1984',
#   '\xa0\xa0\xa0\xa0\xa0Aubrey Jones 45.7, Donnie Kemp 44.9, Dannie Carter 45.8, Don Bly 45.1'],
#  ['\xa0\xa0\xa0\xa0— OKLAHOMA {2}', '', '\xa0', '3:01.46  ', '4/28/1984'],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {4}\xa03:01.50 6/7/2019\xa0\xa0\xa0\xa0\xa0Akeem LINDO (FR), Akeem SIRLEAF (JR), Trevor STEWART (JR) 44.13, Kemarni MIGHTY (JR) 45.22',
#   '\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {4}',
#   '',
#   '\xa0',
#   '3:01.50 ',
#   '6/7/2019',
#   '\xa0\xa0\xa0\xa0\xa0Akeem LINDO (FR), Akeem SIRLEAF (JR), Trevor STEWART (JR) 44.13, Kemarni MIGHTY (JR) 45.22'],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {4}',
#   '',
#   '\xa0',
#   '3:01.50 ',
#   '6/7/2019'],
#  ['\xa0\xa0\xa0\xa0— GEORGIA {3}\xa03:01.51 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Matthew BOLING, Caleb CAVANAUGH, Christopher MORALES WILLIAMS, Will SUMNER',
#   '\xa0\xa0\xa0\xa0— GEORGIA {3}',
#   '',
#   '\xa0',
#   '3:01.51 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Matthew BOLING, Caleb CAVANAUGH, Christopher MORALES WILLIAMS, Will SUMNER'],
#  ['\xa0\xa0\xa0\xa0— GEORGIA {3}',
#   '',
#   '\xa0',
#   '3:01.51 qq = Performance occurred during a non-final round. ',
#   '6/7/2023'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {24}\xa03:01.51 3/19/2022\xa0\xa0\xa0\xa0\xa0 CHEVANNIE, 7778460 OMAJUWA, 7729602 BRANDON, 7729617 JAMES',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {24}',
#   '',
#   '\xa0',
#   '3:01.51 ',
#   '3/19/2022',
#   '\xa0\xa0\xa0\xa0\xa0 CHEVANNIE, 7778460 OMAJUWA, 7729602 BRANDON, 7729617 JAMES'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {24}', '', '\xa0', '3:01.51 ', '3/19/2022'],
#  ['(25) Stephen F. Austin\xa03:01.52 6/11/2021\xa0\xa0\xa0\xa0\xa0Muzuri MATTAR (SO), Paul MARTIN (FR), Jeremiah CURRY (SO) 45.89, Auhmad ROBINSON (FR) 43.45',
#   '(25) Stephen F. Austin',
#   '',
#   '\xa0',
#   '3:01.52 ',
#   '6/11/2021',
#   '\xa0\xa0\xa0\xa0\xa0Muzuri MATTAR (SO), Paul MARTIN (FR), Jeremiah CURRY (SO) 45.89, Auhmad ROBINSON (FR) 43.45'],
#  ['(25) Stephen F. Austin', '', '\xa0', '3:01.52 ', '6/11/2021'],
#  ['OKLAHOMA\xa03:00.26c  5/18/1997',
#   'OKLAHOMA',
#   '',
#   '\xa0',
#   '3:00.26c  ',
#   '5/18/1997'],
#  ['OKLAHOMA', '', '\xa0', '3:00.26c  ', '5/18/1997']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Florida\xa02:57.74 6/9/2023\xa0\xa0\xa0\xa0\xa0Emmanuel BAMIDELE, Jacory PATTERSON, JeVaughn POWELL 44.93, Ryan WILLIE 44.28',
#   '(1) Florida',
#   '',
#   '\xa0',
#   '2:57.74 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Emmanuel BAMIDELE, Jacory PATTERSON, JeVaughn POWELL 44.93, Ryan WILLIE 44.28'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {2}\xa02:57.76📺 5/13/2023\xa0\xa0\xa0\xa0\xa0JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 43.98, Ryan WILLIE 43.32',
#   '\xa0\xa0\xa0\xa0— FLORIDA {2}',
#   '',
#   '\xa0',
#   '2:57.76📺 ',
#   '5/13/2023',
#   '\xa0\xa0\xa0\xa0\xa0JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 43.98, Ryan WILLIE 43.32'],
#  ['(2) Arizona State\xa02:57.78 6/9/2023\xa0\xa0\xa0\xa0\xa0Dubem NWACHUKWU, Jeremiah CURRY, Jalen DRAYDEN 45.32, Justin ROBINSON 43.91',
#   '(2) Arizona State',
#   '',
#   '\xa0',
#   '2:57.78 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Dubem NWACHUKWU, Jeremiah CURRY, Jalen DRAYDEN 45.32, Justin ROBINSON 43.91'],
#  ['(3) Alabama\xa02:58.01 5/13/2023\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Khaleb MCRAE, Tarsis OROGOT, Corde LONG',
#   '(3) Alabama',
#   '',
#   '\xa0',
#   '2:58.01 ',
#   '5/13/2023',
#   '\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Khaleb MCRAE, Tarsis OROGOT, Corde LONG'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {3}\xa02:58.53📺 4/16/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON 44.4, Ryan WILLIE 44.5, Jacob MILEY 46.0, Champion ALLISON 43.6',
#   '\xa0\xa0\xa0\xa0— FLORIDA {3}',
#   '',
#   '\xa0',
#   '2:58.53📺 ',
#   '4/16/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON 44.4, Ryan WILLIE 44.5, Jacob MILEY 46.0, Champion ALLISON 43.6'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {4}\xa02:58.62 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 44.70, Ryan WILLIE 44.53',
#   '\xa0\xa0\xa0\xa0— FLORIDA {4}',
#   '',
#   '\xa0',
#   '2:58.62 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0JeVaughn POWELL, Emmanuel BAMIDELE, Jacory PATTERSON 44.70, Ryan WILLIE 44.53'],
#  ['(4) Georgia\xa02:58.82📺 4/1/2023\xa0\xa0\xa0\xa0\xa0Elija GODWIN 44.8, Matthew BOLING 43.7, Caleb CAVANAUGH 45.53, Will SUMNER 44.80',
#   '(4) Georgia',
#   '',
#   '\xa0',
#   '2:58.82📺 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Elija GODWIN 44.8, Matthew BOLING 43.7, Caleb CAVANAUGH 45.53, Will SUMNER 44.80'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {5}\xa02:58.88 6/10/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON (JR) 44.8, Ryan WILLIE (SO) 44.2, Jacob MILEY (SO) 45.85, Champion ALLISON (JR) 44.06',
#   '\xa0\xa0\xa0\xa0— FLORIDA {5}',
#   '',
#   '\xa0',
#   '2:58.88 ',
#   '6/10/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON (JR) 44.8, Ryan WILLIE (SO) 44.2, Jacob MILEY (SO) 45.85, Champion ALLISON (JR) 44.06'],
#  ['(5) Southern California\xa02:59.00📺 6/8/2018\xa0\xa0\xa0\xa0\xa0Ricky Morgan (SR), Rai Benjamin (JR), Zach Shinnick (FR) 45.86, Michael Norman (SO) 43.62',
#   '(5) Southern California',
#   '',
#   '\xa0',
#   '2:59.00📺 ',
#   '6/8/2018',
#   '\xa0\xa0\xa0\xa0\xa0Ricky Morgan (SR), Rai Benjamin (JR), Zach Shinnick (FR) 45.86, Michael Norman (SO) 43.62'],
#  ['(6) Texas A&M\xa02:59.05📺 6/7/2019\xa0\xa0\xa0\xa0\xa0Bryce DEADMON (JR), Robert GRANT (SR), Kyree JOHNSON (SO) 45.24, Devin DIXON (SR) 44.11',
#   '(6) Texas A&M',
#   '',
#   '\xa0',
#   '2:59.05📺 ',
#   '6/7/2019',
#   '\xa0\xa0\xa0\xa0\xa0Bryce DEADMON (JR), Robert GRANT (SR), Kyree JOHNSON (SO) 45.24, Devin DIXON (SR) 44.11'],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {2}\xa02:59.14 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Dubem NWACHUKWU, Gamali FELIX, Trevin MOYER, Jeremiah CURRY 43.55',
#   '\xa0\xa0\xa0\xa0— ARIZONA STATE {2}',
#   '',
#   '\xa0',
#   '2:59.14 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Dubem NWACHUKWU, Gamali FELIX, Trevin MOYER, Jeremiah CURRY 43.55'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {2}\xa02:59.15 4/1/2023\xa0\xa0\xa0\xa0\xa0Khaleb MCRAE 45.0, Tarsis OROGOT 44.0, Leander FORBES 45.15, Chris ROBINSON 45.04',
#   '\xa0\xa0\xa0\xa0— ALABAMA {2}',
#   '',
#   '\xa0',
#   '2:59.15 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Khaleb MCRAE 45.0, Tarsis OROGOT 44.0, Leander FORBES 45.15, Chris ROBINSON 45.04'],
#  ['(7) North Carolina A&T\xa02:59.21 qq = Performance occurred during a non-final round. 5/29/2021\xa0\xa0\xa0\xa0\xa0Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.65, Trevor STEWART (SR) 43.70',
#   '(7) North Carolina A&T',
#   '',
#   '\xa0',
#   '2:59.21 qq = Performance occurred during a non-final round. ',
#   '5/29/2021',
#   '\xa0\xa0\xa0\xa0\xa0Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.65, Trevor STEWART (SR) 43.70'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {3}\xa02:59.24 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Corde LONG, Tarsis OROGOT, Khaleb MCRAE',
#   '\xa0\xa0\xa0\xa0— ALABAMA {3}',
#   '',
#   '\xa0',
#   '2:59.24 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Corde LONG, Tarsis OROGOT, Khaleb MCRAE'],
#  ['(8) UCLA\xa02:59.25 4/1/2023\xa0\xa0\xa0\xa0\xa0Antonie NORTJE, Willington WRIGHT, Ismail TURNER 44.31, Cameron REYNOLDS 44.49',
#   '(8) UCLA',
#   '',
#   '\xa0',
#   '2:59.25 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Antonie NORTJE, Willington WRIGHT, Ismail TURNER 44.31, Cameron REYNOLDS 44.49'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {6}\xa02:59.44 5/14/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON, Ryan WILLIE, Jacob MILEY, Champion ALLISON',
#   '\xa0\xa0\xa0\xa0— FLORIDA {6}',
#   '',
#   '\xa0',
#   '2:59.44 ',
#   '5/14/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON, Ryan WILLIE, Jacob MILEY, Champion ALLISON'],
#  ['\xa0\xa0\xa0\xa0— UCLA {2}\xa02:59.51 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Myles MISENER-DALEY, Willington WRIGHT, Antonie NORTJE 44.37, Cameron REYNOLDS 44.13',
#   '\xa0\xa0\xa0\xa0— UCLA {2}',
#   '',
#   '\xa0',
#   '2:59.51 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Myles MISENER-DALEY, Willington WRIGHT, Antonie NORTJE 44.37, Cameron REYNOLDS 44.13'],
#  ['(9) LSU\xa02:59.59📺 6/11/2005\xa0\xa0\xa0\xa0\xa0Reggie Dardar 46.4, Kelly Willie 44.4, Bennie Brazell 44.8, Xavier Carter 44.0',
#   '(9) LSU',
#   '',
#   '\xa0',
#   '2:59.59📺 ',
#   '6/11/2005',
#   '\xa0\xa0\xa0\xa0\xa0Reggie Dardar 46.4, Kelly Willie 44.4, Bennie Brazell 44.8, Xavier Carter 44.0'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {7}\xa02:59.60 6/7/2019\xa0\xa0\xa0\xa0\xa0Benjamin LOBO VEDEL (SO), Chantz SAWYERS (SO), Denzel VILLAMAN (JR) 45.26, Grant HOLLOWAY (JR) 43.74',
#   '\xa0\xa0\xa0\xa0— FLORIDA {7}',
#   '',
#   '\xa0',
#   '2:59.60 ',
#   '6/7/2019',
#   '\xa0\xa0\xa0\xa0\xa0Benjamin LOBO VEDEL (SO), Chantz SAWYERS (SO), Denzel VILLAMAN (JR) 45.26, Grant HOLLOWAY (JR) 43.74'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {2}\xa02:59.60 6/14/2014\xa0\xa0\xa0\xa0\xa0Aldrich Bailey 46.5, Carlyle Roudette 44.7, Bralon Taplin 44.30, Deon Lendore 44.10',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {2}',
#   '',
#   '\xa0',
#   '2:59.60 ',
#   '6/14/2014',
#   '\xa0\xa0\xa0\xa0\xa0Aldrich Bailey 46.5, Carlyle Roudette 44.7, Bralon Taplin 44.30, Deon Lendore 44.10'],
#  ['\xa0\xa0\xa0\xa0— GEORGIA {2}\xa02:59.63 5/13/2023\xa0\xa0\xa0\xa0\xa0Elija GODWIN, Matthew BOLING, Christopher MORALES WILLIAM, Will SUMNER',
#   '\xa0\xa0\xa0\xa0— GEORGIA {2}',
#   '',
#   '\xa0',
#   '2:59.63 ',
#   '5/13/2023',
#   '\xa0\xa0\xa0\xa0\xa0Elija GODWIN, Matthew BOLING, Christopher MORALES WILLIAM, Will SUMNER'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {8}\xa02:59.73 4/5/2014\xa0\xa0\xa0\xa0\xa0Najee Glass, Hugh Graham, Jr, Dedric Dukes, Arman Hall',
#   '\xa0\xa0\xa0\xa0— FLORIDA {8}',
#   '',
#   '\xa0',
#   '2:59.73 ',
#   '4/5/2014',
#   '\xa0\xa0\xa0\xa0\xa0Najee Glass, Hugh Graham, Jr, Dedric Dukes, Arman Hall'],
#  ["(10) Clemson\xa02:59.78 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Wanya MCCOY, D'Andre ANDERSON, Aman THORNTON 44.73, Tarees RHODEN 44.42",
#   '(10) Clemson',
#   '',
#   '\xa0',
#   '2:59.78 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   "\xa0\xa0\xa0\xa0\xa0Wanya MCCOY, D'Andre ANDERSON, Aman THORNTON 44.73, Tarees RHODEN 44.42"],
#  ['\xa0\xa0\xa0\xa0— UCLA {3}\xa02:59.82 6/9/2023\xa0\xa0\xa0\xa0\xa0Antonie NORTJE, Willington WRIGHT, Myles MISENER-DALEY 44.48, Cameron REYNOLDS 44.99',
#   '\xa0\xa0\xa0\xa0— UCLA {3}',
#   '',
#   '\xa0',
#   '2:59.82 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Antonie NORTJE, Willington WRIGHT, Myles MISENER-DALEY 44.48, Cameron REYNOLDS 44.99'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {3}\xa02:59.91 6/8/2018\xa0\xa0\xa0\xa0\xa0Bryce Deadmon (SO), Kyree Johnson (FR), Ilolo Izu (JR) 45.43, Devin Dixon (SO) 43.93',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {3}',
#   '',
#   '\xa0',
#   '2:59.91 ',
#   '6/8/2018',
#   '\xa0\xa0\xa0\xa0\xa0Bryce Deadmon (SO), Kyree Johnson (FR), Ilolo Izu (JR) 45.43, Devin Dixon (SO) 43.93'],
#  ['\xa0\xa0\xa0\xa0— UCLA {4}\xa02:59.91  6/4/1988\xa0\xa0\xa0\xa0\xa0Steve Lewis 45.0, Kevin Young 44.4, Danny Everett 45.3, Henry Thomas 45.2',
#   '\xa0\xa0\xa0\xa0— UCLA {4}',
#   '',
#   '\xa0',
#   '2:59.91  ',
#   '6/4/1988',
#   '\xa0\xa0\xa0\xa0\xa0Steve Lewis 45.0, Kevin Young 44.4, Danny Everett 45.3, Henry Thomas 45.2'],
#  ['(11) Kentucky\xa02:59.93 5/14/2022\xa0\xa0\xa0\xa0\xa0Dwight ST HILLAIRE, Lance LANG, Kennedy LIGHTNER, Brian FAUST',
#   '(11) Kentucky',
#   '',
#   '\xa0',
#   '2:59.93 ',
#   '5/14/2022',
#   '\xa0\xa0\xa0\xa0\xa0Dwight ST HILLAIRE, Lance LANG, Kennedy LIGHTNER, Brian FAUST'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {4}\xa02:59.95 qq = Performance occurred during a non-final round. 6/10/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Mylik Kerley (JR), Robert Grant (JR) 45.16, Fred Kerley (SR) 43.96',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {4}',
#   '',
#   '\xa0',
#   '2:59.95 qq = Performance occurred during a non-final round. ',
#   '6/10/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Mylik Kerley (JR), Robert Grant (JR) 45.16, Fred Kerley (SR) 43.96'],
#  ['(12) Georgia Tech\xa02:59.95  6/6/1992\xa0\xa0\xa0\xa0\xa0Octavius Terry 45.6, Julian Amedee 45.5, Derrick Adkins 45.0, Derek Mills 43.9',
#   '(12) Georgia Tech',
#   '',
#   '\xa0',
#   '2:59.95  ',
#   '6/6/1992',
#   '\xa0\xa0\xa0\xa0\xa0Octavius Terry 45.6, Julian Amedee 45.5, Derrick Adkins 45.0, Derek Mills 43.9'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {2}\xa02:59.98 6/10/2022\xa0\xa0\xa0\xa0\xa0Nicholas RAMEY (SR) 46.4, Zach SHINNICK (SR) 44.6, Johnnie BLOCKBURGER (JR) 44.26, Kasaun JAMES (SR) 44.78',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {2}',
#   '',
#   '\xa0',
#   '2:59.98 ',
#   '6/10/2022',
#   '\xa0\xa0\xa0\xa0\xa0Nicholas RAMEY (SR) 46.4, Zach SHINNICK (SR) 44.6, Johnnie BLOCKBURGER (JR) 44.26, Kasaun JAMES (SR) 44.78'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {5}\xa02:59.98 6/10/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO) 46.7h, Mylik Kerley (JR) 44.2h, Robert Grant (JR) 45.11, Fred Kerley (SR) 43.99',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {5}',
#   '',
#   '\xa0',
#   '2:59.98 ',
#   '6/10/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO) 46.7h, Mylik Kerley (JR) 44.2h, Robert Grant (JR) 45.11, Fred Kerley (SR) 43.99'],
#  ['(13) Florida State\xa02:59.99  6/13/2009\xa0\xa0\xa0\xa0\xa0Kevin Williams 46.6, Kevin Borlée 43.8, Charles Clark 45.85, Jonathan Borlée 43.78',
#   '(13) Florida State',
#   '',
#   '\xa0',
#   '2:59.99  ',
#   '6/13/2009',
#   '\xa0\xa0\xa0\xa0\xa0Kevin Williams 46.6, Kevin Borlée 43.8, Charles Clark 45.85, Jonathan Borlée 43.78'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {9}\xa03:00.02 6/9/2012\xa0\xa0\xa0\xa0\xa0Dedric Dukes 45.6, Hugh Graham 45.1, Leonardo Seymore 45.31, Tony McQuay 44.00',
#   '\xa0\xa0\xa0\xa0— FLORIDA {9}',
#   '',
#   '\xa0',
#   '3:00.02 ',
#   '6/9/2012',
#   '\xa0\xa0\xa0\xa0\xa0Dedric Dukes 45.6, Hugh Graham 45.1, Leonardo Seymore 45.31, Tony McQuay 44.00'],
#  ['(14) Baylor\xa03:00.04  6/9/2007\xa0\xa0\xa0\xa0\xa0Reggie Witherspoon 45.6, LeJerald Betters 44.4, Kevin Mutai 45.18, Quentin Iglehart-Summers 44.88',
#   '(14) Baylor',
#   '',
#   '\xa0',
#   '3:00.04  ',
#   '6/9/2007',
#   '\xa0\xa0\xa0\xa0\xa0Reggie Witherspoon 45.6, LeJerald Betters 44.4, Kevin Mutai 45.18, Quentin Iglehart-Summers 44.88'],
#  ['(15) Houston\xa03:00.07 6/7/2019\xa0\xa0\xa0\xa0\xa0Amere LATTIN (SR), Kahmari MONTGOMERY (SR), Jermaine HOLT (JR) 45.26, Obi IGBOKWE (SR) 44.40',
#   '(15) Houston',
#   '',
#   '\xa0',
#   '3:00.07 ',
#   '6/7/2019',
#   '\xa0\xa0\xa0\xa0\xa0Amere LATTIN (SR), Kahmari MONTGOMERY (SR), Jermaine HOLT (JR) 45.26, Obi IGBOKWE (SR) 44.40'],
#  ["(16) Iowa\xa03:00.14 6/7/2019\xa0\xa0\xa0\xa0\xa0Wayne LAWRENCE JR. (FR), Antonio WOODARD (JR), Karayme BARTLEY (JR) 44.22, Mar'yea HARRIS (SR) 44.75",
#   '(16) Iowa',
#   '',
#   '\xa0',
#   '3:00.14 ',
#   '6/7/2019',
#   "\xa0\xa0\xa0\xa0\xa0Wayne LAWRENCE JR. (FR), Antonio WOODARD (JR), Karayme BARTLEY (JR) 44.22, Mar'yea HARRIS (SR) 44.75"],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {4}\xa03:00.17 6/10/2022\xa0\xa0\xa0\xa0\xa0Leander FORBES (JR) 46.5, Demetrius JACKSON (JR) 44.6, Corde LONG (SO) 44.77, Khaleb MCRAE (SO) 44.28',
#   '\xa0\xa0\xa0\xa0— ALABAMA {4}',
#   '',
#   '\xa0',
#   '3:00.17 ',
#   '6/10/2022',
#   '\xa0\xa0\xa0\xa0\xa0Leander FORBES (JR) 46.5, Demetrius JACKSON (JR) 44.6, Corde LONG (SO) 44.77, Khaleb MCRAE (SO) 44.28'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {2}\xa03:00.22  6/14/2008\xa0\xa0\xa0\xa0\xa0Marcus Boyd 45.8, Justin Boyd 45.5, LeJerald Betters 44.37, Quentin Iglehart-Summers 44.50',
#   '\xa0\xa0\xa0\xa0— BAYLOR {2}',
#   '',
#   '\xa0',
#   '3:00.22  ',
#   '6/14/2008',
#   '\xa0\xa0\xa0\xa0\xa0Marcus Boyd 45.8, Justin Boyd 45.5, LeJerald Betters 44.37, Quentin Iglehart-Summers 44.50'],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {2}\xa03:00.23 3/27/2021\xa0\xa0\xa0\xa0\xa0Stokes, Ross, Young, Stewart',
#   '\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {2}',
#   '',
#   '\xa0',
#   '3:00.23 ',
#   '3/27/2021',
#   '\xa0\xa0\xa0\xa0\xa0Stokes, Ross, Young, Stewart'],
#  ['(17) Texas\xa03:00.31 qq = Performance occurred during a non-final round. 6/8/2022\xa0\xa0\xa0\xa0\xa0Jon MAAS (SR), Jonathan JONES (JR), Willington WRIGHT (JR) 44.34, Brian HERRON (SO) 44.72',
#   '(17) Texas',
#   '',
#   '\xa0',
#   '3:00.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jon MAAS (SR), Jonathan JONES (JR), Willington WRIGHT (JR) 44.34, Brian HERRON (SO) 44.72'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {10}\xa03:00.31  4/3/2010',
#   '\xa0\xa0\xa0\xa0— FLORIDA {10}',
#   '',
#   '\xa0',
#   '3:00.31  ',
#   '4/3/2010'],
#  ['\xa0\xa0\xa0\xa0— LSU {2}\xa03:00.38 4/23/2016\xa0\xa0\xa0\xa0\xa0Lamar Bruton, Michael Cherry, Cyril Grayson, Fitzroy Dunkley',
#   '\xa0\xa0\xa0\xa0— LSU {2}',
#   '',
#   '\xa0',
#   '3:00.38 ',
#   '4/23/2016',
#   '\xa0\xa0\xa0\xa0\xa0Lamar Bruton, Michael Cherry, Cyril Grayson, Fitzroy Dunkley'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {5}\xa03:00.42 qq = Performance occurred during a non-final round. 6/8/2022\xa0\xa0\xa0\xa0\xa0Leander FORBES (JR), Demetrius JACKSON (JR), Corde LONG (SO) 44.44, Khaleb MCRAE (SO) 44.06',
#   '\xa0\xa0\xa0\xa0— ALABAMA {5}',
#   '',
#   '\xa0',
#   '3:00.42 qq = Performance occurred during a non-final round. ',
#   '6/8/2022',
#   '\xa0\xa0\xa0\xa0\xa0Leander FORBES (JR), Demetrius JACKSON (JR), Corde LONG (SO) 44.44, Khaleb MCRAE (SO) 44.06'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {11}\xa03:00.42 6/14/2014\xa0\xa0\xa0\xa0\xa0Najee Glass 46.1, Hugh Graham 45.0, Dedric Dukes 44.59, Arman Hall 44.73',
#   '\xa0\xa0\xa0\xa0— FLORIDA {11}',
#   '',
#   '\xa0',
#   '3:00.42 ',
#   '6/14/2014',
#   '\xa0\xa0\xa0\xa0\xa0Najee Glass 46.1, Hugh Graham 45.0, Dedric Dukes 44.59, Arman Hall 44.73'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {6}\xa03:00.45 4/9/2011\xa0\xa0\xa0\xa0\xa0Bryan Miller, Tabarie Henry, Michael Preble, Demetrius Pinder',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {6}',
#   '',
#   '\xa0',
#   '3:00.45 ',
#   '4/9/2011',
#   '\xa0\xa0\xa0\xa0\xa0Bryan Miller, Tabarie Henry, Michael Preble, Demetrius Pinder'],
#  ['\xa0\xa0\xa0\xa0— LSU {3}\xa03:00.48 5/14/2016\xa0\xa0\xa0\xa0\xa0Lamar Bruton, Michael Cherry, Cyril Grayson, Fitzroy Dunkley',
#   '\xa0\xa0\xa0\xa0— LSU {3}',
#   '',
#   '\xa0',
#   '3:00.48 ',
#   '5/14/2016',
#   '\xa0\xa0\xa0\xa0\xa0Lamar Bruton, Michael Cherry, Cyril Grayson, Fitzroy Dunkley'],
#  ['\xa0\xa0\xa0\xa0— UCLA {5}\xa03:00.55  6/6/1987\xa0\xa0\xa0\xa0\xa0Anthony Washington 47.0, Kevin Young 44.7, Henry Thomas 44.0, Danny Everett 44.9',
#   '\xa0\xa0\xa0\xa0— UCLA {5}',
#   '',
#   '\xa0',
#   '3:00.55  ',
#   '6/6/1987',
#   '\xa0\xa0\xa0\xa0\xa0Anthony Washington 47.0, Kevin Young 44.7, Henry Thomas 44.0, Danny Everett 44.9'],
#  ['\xa0\xa0\xa0\xa0— LSU {4}\xa03:00.56 6/8/2018\xa0\xa0\xa0\xa0\xa0Jahnoy Thompson (JR), Correion Mosby (JR), Renard Howell (SR), Jaron Flournoy (JR)',
#   '\xa0\xa0\xa0\xa0— LSU {4}',
#   '',
#   '\xa0',
#   '3:00.56 ',
#   '6/8/2018',
#   '\xa0\xa0\xa0\xa0\xa0Jahnoy Thompson (JR), Correion Mosby (JR), Renard Howell (SR), Jaron Flournoy (JR)'],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {3}\xa03:00.57  6/11/2005\xa0\xa0\xa0\xa0\xa0Rich Allen 46.7, Seth Amoo 44.3, Domenick Peterson 45.2, Lewis Banda 44.4',
#   '\xa0\xa0\xa0\xa0— ARIZONA STATE {3}',
#   '',
#   '\xa0',
#   '3:00.57  ',
#   '6/11/2005',
#   '\xa0\xa0\xa0\xa0\xa0Rich Allen 46.7, Seth Amoo 44.3, Domenick Peterson 45.2, Lewis Banda 44.4'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {3}\xa03:00.58 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Demar FRANCIS, Nathaniel EZEKIEL, Hasani BARR 44.85, Dillon BEDELL 44.37',
#   '\xa0\xa0\xa0\xa0— BAYLOR {3}',
#   '',
#   '\xa0',
#   '3:00.58 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Demar FRANCIS, Nathaniel EZEKIEL, Hasani BARR 44.85, Dillon BEDELL 44.37'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {3}\xa03:00.58  6/6/1992\xa0\xa0\xa0\xa0\xa0Travis Hannah 45.3, Curtis Conway 45.4, Martin Cannady 46.3, Quincy Watts 43.6',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {3}',
#   '',
#   '\xa0',
#   '3:00.58  ',
#   '6/6/1992',
#   '\xa0\xa0\xa0\xa0\xa0Travis Hannah 45.3, Curtis Conway 45.4, Martin Cannady 46.3, Quincy Watts 43.6'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {4}\xa03:00.60 qq = Performance occurred during a non-final round. 6/1/1995\xa0\xa0\xa0\xa0\xa0Michael Ford (JR), Raoul Howard (JR), Corey Williams (SR), Deon Minor (SR)',
#   '\xa0\xa0\xa0\xa0— BAYLOR {4}',
#   '',
#   '\xa0',
#   '3:00.60 qq = Performance occurred during a non-final round. ',
#   '6/1/1995',
#   '\xa0\xa0\xa0\xa0\xa0Michael Ford (JR), Raoul Howard (JR), Corey Williams (SR), Deon Minor (SR)'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {5}\xa03:00.61 4/1/2023\xa0\xa0\xa0\xa0\xa0Kamden JACKSON, Matthew MOORER, Dillon BEDELL 45.36, Nathaniel EZEKIEL 44.78',
#   '\xa0\xa0\xa0\xa0— BAYLOR {5}',
#   '',
#   '\xa0',
#   '3:00.61 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Kamden JACKSON, Matthew MOORER, Dillon BEDELL 45.36, Nathaniel EZEKIEL 44.78'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {6}\xa03:00.61  4/1/1995\xa0\xa0\xa0\xa0\xa0Michael Ford, Raoul Howard, Deon Minor , Marlon Ramsey',
#   '\xa0\xa0\xa0\xa0— BAYLOR {6}',
#   '',
#   '\xa0',
#   '3:00.61  ',
#   '4/1/1995',
#   '\xa0\xa0\xa0\xa0\xa0Michael Ford, Raoul Howard, Deon Minor , Marlon Ramsey'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {7}\xa03:00.62 6/11/2011\xa0\xa0\xa0\xa0\xa0Bryan Miller 45.5, Demetrius Pinder 44.6, Michael Preble 45.60, Tabarie Henry 44.86',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {7}',
#   '',
#   '\xa0',
#   '3:00.62 ',
#   '6/11/2011',
#   '\xa0\xa0\xa0\xa0\xa0Bryan Miller 45.5, Demetrius Pinder 44.6, Michael Preble 45.60, Tabarie Henry 44.86'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {4}\xa03:00.64 6/9/2012\xa0\xa0\xa0\xa0\xa0Joey Hughes 45.8, Josh Mance 44.7, Reggie Wyatt 45.30, Bryshon Nellum 44.82',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {4}',
#   '',
#   '\xa0',
#   '3:00.64 ',
#   '6/9/2012',
#   '\xa0\xa0\xa0\xa0\xa0Joey Hughes 45.8, Josh Mance 44.7, Reggie Wyatt 45.30, Bryshon Nellum 44.82'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {7}\xa03:00.64  6/6/1992\xa0\xa0\xa0\xa0\xa0Daniel Fredericks 45.8, Tony Miller 44.9, Etheridge Green 45.1, Deon Minor 44.8',
#   '\xa0\xa0\xa0\xa0— BAYLOR {7}',
#   '',
#   '\xa0',
#   '3:00.64  ',
#   '6/6/1992',
#   '\xa0\xa0\xa0\xa0\xa0Daniel Fredericks 45.8, Tony Miller 44.9, Etheridge Green 45.1, Deon Minor 44.8'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {12}\xa03:00.68  6/4/1988\xa0\xa0\xa0\xa0\xa0Calvin Long 45.6, Dennis Mitchell 44.4, Timmy Johnson 45.5, Mark Everett 45.2',
#   '\xa0\xa0\xa0\xa0— FLORIDA {12}',
#   '',
#   '\xa0',
#   '3:00.68  ',
#   '6/4/1988',
#   '\xa0\xa0\xa0\xa0\xa0Calvin Long 45.6, Dennis Mitchell 44.4, Timmy Johnson 45.5, Mark Everett 45.2'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {8}\xa03:00.69 qq = Performance occurred during a non-final round. 5/27/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Fred Kerley (SR), Robert Grant (JR) 45.30, Mylik Kerley (JR) 45.30',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {8}',
#   '',
#   '\xa0',
#   '3:00.69 qq = Performance occurred during a non-final round. ',
#   '5/27/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Fred Kerley (SR), Robert Grant (JR) 45.30, Mylik Kerley (JR) 45.30'],
#  ['\xa0\xa0\xa0\xa0— LSU {5}\xa03:00.69 6/11/2016\xa0\xa0\xa0\xa0\xa0Lamar Bruton (JR) 46.4, Michael Cherry (JR) 44.2, Cyril Grayson (SR) 45.80, Fitzroy Dunkley (SR) 44.29',
#   '\xa0\xa0\xa0\xa0— LSU {5}',
#   '',
#   '\xa0',
#   '3:00.69 ',
#   '6/11/2016',
#   '\xa0\xa0\xa0\xa0\xa0Lamar Bruton (JR) 46.4, Michael Cherry (JR) 44.2, Cyril Grayson (SR) 45.80, Fitzroy Dunkley (SR) 44.29'],
#  ['\xa0\xa0\xa0\xa0— TEXAS {2}\xa03:00.70 qq = Performance occurred during a non-final round. 5/27/2022\xa0\xa0\xa0\xa0\xa0Jon MAAS (SR), Jonathan JONES (JR), Willington WRIGHT (JR), Brian HERRON (SO)',
#   '\xa0\xa0\xa0\xa0— TEXAS {2}',
#   '',
#   '\xa0',
#   '3:00.70 qq = Performance occurred during a non-final round. ',
#   '5/27/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jon MAAS (SR), Jonathan JONES (JR), Willington WRIGHT (JR), Brian HERRON (SO)'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {9}\xa03:00.72 5/13/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Fred Kerley (SR), Robert Grant (JR) 45.48, Mylik Kerley (JR) 45.00',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {9}',
#   '',
#   '\xa0',
#   '3:00.72 ',
#   '5/13/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO), Fred Kerley (SR), Robert Grant (JR) 45.48, Mylik Kerley (JR) 45.00'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {8}\xa03:00.73 5/12/2023\xa0\xa0\xa0\xa0\xa0Matthew MOORER, Hasani BARR, Nathaniel EZEKIEL, Dillon BEDELL',
#   '\xa0\xa0\xa0\xa0— BAYLOR {8}',
#   '',
#   '\xa0',
#   '3:00.73 ',
#   '5/12/2023',
#   '\xa0\xa0\xa0\xa0\xa0Matthew MOORER, Hasani BARR, Nathaniel EZEKIEL, Dillon BEDELL'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {10}\xa03:00.74 4/29/2017\xa0\xa0\xa0\xa0\xa0Richard Rose (SO) 45.8h, Fred Kerley (SR) 43.7h, Devin Dixon (FR) 46.22, Mylik Kerley (JR) 44.99',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {10}',
#   '',
#   '\xa0',
#   '3:00.74 ',
#   '4/29/2017',
#   '\xa0\xa0\xa0\xa0\xa0Richard Rose (SO) 45.8h, Fred Kerley (SR) 43.7h, Devin Dixon (FR) 46.22, Mylik Kerley (JR) 44.99'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {11}\xa03:00.76 qq = Performance occurred during a non-final round. 6/12/2014\xa0\xa0\xa0\xa0\xa0Aldrich Bailey, Jr., Carlyle Roudette, Bralon Taplin, Deon Lendore',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {11}',
#   '',
#   '\xa0',
#   '3:00.76 qq = Performance occurred during a non-final round. ',
#   '6/12/2014',
#   '\xa0\xa0\xa0\xa0\xa0Aldrich Bailey, Jr., Carlyle Roudette, Bralon Taplin, Deon Lendore'],
#  ['(18) Southern Illinois\xa03:00.78  4/28/1984\xa0\xa0\xa0\xa0\xa0Parry Duncan 45.5, Tony Adams 45.6, Elvis Forde 45.1, Michael Franks 44.5',
#   '(18) Southern Illinois',
#   '',
#   '\xa0',
#   '3:00.78  ',
#   '4/28/1984',
#   '\xa0\xa0\xa0\xa0\xa0Parry Duncan 45.5, Tony Adams 45.6, Elvis Forde 45.1, Michael Franks 44.5'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {6}\xa03:00.81 6/9/2023\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Tarsis OROGOT, Corde LONG 46.76, Khaleb MCRAE 44.14',
#   '\xa0\xa0\xa0\xa0— ALABAMA {6}',
#   '',
#   '\xa0',
#   '3:00.81 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Chris ROBINSON, Tarsis OROGOT, Corde LONG 46.76, Khaleb MCRAE 44.14'],
#  ['(19) Oregon\xa03:00.81  6/11/2005\xa0\xa0\xa0\xa0\xa0Jordan Kent 46.5, Kedar Inico 44.3, AK Ikwuakor 45.4, John Scherer 44.6',
#   '(19) Oregon',
#   '',
#   '\xa0',
#   '3:00.81  ',
#   '6/11/2005',
#   '\xa0\xa0\xa0\xa0\xa0Jordan Kent 46.5, Kedar Inico 44.3, AK Ikwuakor 45.4, John Scherer 44.6'],
#  ['(19) SMU\xa03:00.81  6/6/1987\xa0\xa0\xa0\xa0\xa0Harold Spells 46.1, Kevin Robinzine 44.2, Cedric Matterson 45.8, Roy Martin 44.8',
#   '(19) SMU',
#   '',
#   '\xa0',
#   '3:00.81  ',
#   '6/6/1987',
#   '\xa0\xa0\xa0\xa0\xa0Harold Spells 46.1, Kevin Robinzine 44.2, Cedric Matterson 45.8, Roy Martin 44.8'],
#  ['(21) Ohio State\xa03:00.82  6/5/1993\xa0\xa0\xa0\xa0\xa0Rich Jones 46.2, Aaron Payne 45.0, Robert Smith 45.4, Chris Nelloms 44.2',
#   '(21) Ohio State',
#   '',
#   '\xa0',
#   '3:00.82  ',
#   '6/5/1993',
#   '\xa0\xa0\xa0\xa0\xa0Rich Jones 46.2, Aaron Payne 45.0, Robert Smith 45.4, Chris Nelloms 44.2'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {9}\xa03:00.83  6/6/1987\xa0\xa0\xa0\xa0\xa0Darnell Chase 46.0, Keith Stanford 45.0, Michael Johnson 45.2, Raymond Pierre 44.7',
#   '\xa0\xa0\xa0\xa0— BAYLOR {9}',
#   '',
#   '\xa0',
#   '3:00.83  ',
#   '6/6/1987',
#   '\xa0\xa0\xa0\xa0\xa0Darnell Chase 46.0, Keith Stanford 45.0, Michael Johnson 45.2, Raymond Pierre 44.7'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {10}\xa03:00.84  6/1/1985\xa0\xa0\xa0\xa0\xa0Darnell Chase 46.0, Derwin Graham 45.8, Johnny Thomas 44.8, Willie Caldwell 44.3',
#   '\xa0\xa0\xa0\xa0— BAYLOR {10}',
#   '',
#   '\xa0',
#   '3:00.84  ',
#   '6/1/1985',
#   '\xa0\xa0\xa0\xa0\xa0Darnell Chase 46.0, Derwin Graham 45.8, Johnny Thomas 44.8, Willie Caldwell 44.3'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {12}\xa03:00.88 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Eric HEMPHILL III, Omajuwa ETIWE, DeMarco ESCOBAR, Auhmad ROBINSON 44.36',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {12}',
#   '',
#   '\xa0',
#   '3:00.88 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Eric HEMPHILL III, Omajuwa ETIWE, DeMarco ESCOBAR, Auhmad ROBINSON 44.36'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {13}\xa03:00.89  6/12/2010\xa0\xa0\xa0\xa0\xa0Bryan Miller 46.4, Demetrius Pinder 44.6, Curtis Mitchell 45.07, Tabarie Henry 44.79',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {13}',
#   '',
#   '\xa0',
#   '3:00.89  ',
#   '6/12/2010',
#   '\xa0\xa0\xa0\xa0\xa0Bryan Miller 46.4, Demetrius Pinder 44.6, Curtis Mitchell 45.07, Tabarie Henry 44.79'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {14}\xa03:00.90 6/9/2023\xa0\xa0\xa0\xa0\xa0Eric HEMPHILL III, Omajuwa ETIWE, DeMarco ESCOBAR, Auhmad ROBINSON',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {14}',
#   '',
#   '\xa0',
#   '3:00.90 ',
#   '6/9/2023',
#   '\xa0\xa0\xa0\xa0\xa0Eric HEMPHILL III, Omajuwa ETIWE, DeMarco ESCOBAR, Auhmad ROBINSON'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {15}\xa03:00.91  6/13/2009',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {15}',
#   '',
#   '\xa0',
#   '3:00.91  ',
#   '6/13/2009'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {16}\xa03:00.91 AA = Performance occurred at altitude (>1000 meters above sea level) 6/3/1989\xa0\xa0\xa0\xa0\xa0Stanley Kerr 45.4, Errington Lindo 45.8, Derrick Florence 45.0, Howard Davis 44.7',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {16}',
#   '',
#   '\xa0',
#   '3:00.91 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '6/3/1989',
#   '\xa0\xa0\xa0\xa0\xa0Stanley Kerr 45.4, Errington Lindo 45.8, Derrick Florence 45.0, Howard Davis 44.7'],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {3}\xa03:00.92 6/11/2021\xa0\xa0\xa0\xa0\xa0Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.89, Trevor STEWART (SR) 44.17',
#   '\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {3}',
#   '',
#   '\xa0',
#   '3:00.92 ',
#   '6/11/2021',
#   '\xa0\xa0\xa0\xa0\xa0Daniel STOKES (JR), Randolph ROSS (SO), Akeem SIRLEAF (SR) 45.89, Trevor STEWART (SR) 44.17'],
#  ['(22) Arkansas\xa03:00.97 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Lance LANG, James BENSON II, Connor WASHINGTON, Christopher BAILEY 44.37',
#   '(22) Arkansas',
#   '',
#   '\xa0',
#   '3:00.97 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Lance LANG, James BENSON II, Connor WASHINGTON, Christopher BAILEY 44.37'],
#  ['\xa0\xa0\xa0\xa0— LSU {6}\xa03:01.00 3/27/2021\xa0\xa0\xa0\xa0\xa0Camel, Burrell, Terry, Williams',
#   '\xa0\xa0\xa0\xa0— LSU {6}',
#   '',
#   '\xa0',
#   '3:01.00 ',
#   '3/27/2021',
#   '\xa0\xa0\xa0\xa0\xa0Camel, Burrell, Terry, Williams'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {13}\xa03:01.00 3/31/2018\xa0\xa0\xa0\xa0\xa0Fasasi, Holloway, Sawyers, Vedel',
#   '\xa0\xa0\xa0\xa0— FLORIDA {13}',
#   '',
#   '\xa0',
#   '3:01.00 ',
#   '3/31/2018',
#   '\xa0\xa0\xa0\xa0\xa0Fasasi, Holloway, Sawyers, Vedel'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {11}\xa03:01.03  6/12/2004\xa0\xa0\xa0\xa0\xa0Wil Fitts 46.7, Braelon Davis 46.0, Jeremy Wariner 44.0, Darold Williamson 44.3',
#   '\xa0\xa0\xa0\xa0— BAYLOR {11}',
#   '',
#   '\xa0',
#   '3:01.03  ',
#   '6/12/2004',
#   '\xa0\xa0\xa0\xa0\xa0Wil Fitts 46.7, Braelon Davis 46.0, Jeremy Wariner 44.0, Darold Williamson 44.3'],
#  ['\xa0\xa0\xa0\xa0— LSU {7}\xa03:01.07 6/11/2011\xa0\xa0\xa0\xa0\xa0Robert Simmons 46.7, Ade Alleyne-Forte 45.0, Caleb Williams 44.54, Riker Hylton 44.88',
#   '\xa0\xa0\xa0\xa0— LSU {7}',
#   '',
#   '\xa0',
#   '3:01.07 ',
#   '6/11/2011',
#   '\xa0\xa0\xa0\xa0\xa0Robert Simmons 46.7, Ade Alleyne-Forte 45.0, Caleb Williams 44.54, Riker Hylton 44.88'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {17}\xa03:01.07  6/9/2007\xa0\xa0\xa0\xa0\xa0Bryant McCombs 45.9, Alfred Robinson 45.0, Marcus Pitre 45.49, Justin Oliver 44.67',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {17}',
#   '',
#   '\xa0',
#   '3:01.07  ',
#   '6/9/2007',
#   '\xa0\xa0\xa0\xa0\xa0Bryant McCombs 45.9, Alfred Robinson 45.0, Marcus Pitre 45.49, Justin Oliver 44.67'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {5}\xa03:01.11 qq = Performance occurred during a non-final round. 5/26/2018',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {5}',
#   '',
#   '\xa0',
#   '3:01.11 qq = Performance occurred during a non-final round. ',
#   '5/26/2018'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {14}\xa03:01.12 6/11/2016\xa0\xa0\xa0\xa0\xa0Kunle Fasasi (FR) 45.7, Arman Hall (SR) 44.6, Hugh Graham, Jr (SR) 45.67, Najee Glass (SR) 45.08',
#   '\xa0\xa0\xa0\xa0— FLORIDA {14}',
#   '',
#   '\xa0',
#   '3:01.12 ',
#   '6/11/2016',
#   '\xa0\xa0\xa0\xa0\xa0Kunle Fasasi (FR) 45.7, Arman Hall (SR) 44.6, Hugh Graham, Jr (SR) 45.67, Najee Glass (SR) 45.08'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {12}\xa03:01.12  6/13/2009',
#   '\xa0\xa0\xa0\xa0— BAYLOR {12}',
#   '',
#   '\xa0',
#   '3:01.12  ',
#   '6/13/2009'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {18}\xa03:01.13 qq = Performance occurred during a non-final round. 6/6/2018',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {18}',
#   '',
#   '\xa0',
#   '3:01.13 qq = Performance occurred during a non-final round. ',
#   '6/6/2018'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {7}\xa03:01.16  6/1/1985\xa0\xa0\xa0\xa0\xa0Terry Menefee 45.6, Tony Davis 46.1, Bernie Jackson 45.3, Cedric Vaughans 44.2',
#   '\xa0\xa0\xa0\xa0— ALABAMA {7}',
#   '',
#   '\xa0',
#   '3:01.16  ',
#   '6/1/1985',
#   '\xa0\xa0\xa0\xa0\xa0Terry Menefee 45.6, Tony Davis 46.1, Bernie Jackson 45.3, Cedric Vaughans 44.2'],
#  ['\xa0\xa0\xa0\xa0— ALABAMA {8}\xa03:01.16  1985\xa0\xa0\xa0\xa0\xa0Menefee, Davis, Jackson, Vaughans',
#   '\xa0\xa0\xa0\xa0— ALABAMA {8}',
#   '',
#   '\xa0',
#   '3:01.16  ',
#   '1985',
#   '\xa0\xa0\xa0\xa0\xa0Menefee, Davis, Jackson, Vaughans'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {19}\xa03:01.17 5/13/2018\xa0\xa0\xa0\xa0\xa0Rose, Deadmon, Izu, Dixon',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {19}',
#   '',
#   '\xa0',
#   '3:01.17 ',
#   '5/13/2018',
#   '\xa0\xa0\xa0\xa0\xa0Rose, Deadmon, Izu, Dixon'],
#  ['(23) Iowa State\xa03:01.17  6/1/1985\xa0\xa0\xa0\xa0\xa0Sebron Flenaugh 47.6, Leroy Dixson 44.7, Danny Harris 44.3, Sunday Uti 44.6',
#   '(23) Iowa State',
#   '',
#   '\xa0',
#   '3:01.17  ',
#   '6/1/1985',
#   '\xa0\xa0\xa0\xa0\xa0Sebron Flenaugh 47.6, Leroy Dixson 44.7, Danny Harris 44.3, Sunday Uti 44.6'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {20}\xa03:01.19 5/18/2014',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {20}',
#   '',
#   '\xa0',
#   '3:01.19 ',
#   '5/18/2014'],
#  ['\xa0\xa0\xa0\xa0— LSU {8}\xa03:01.21 6/9/2012\xa0\xa0\xa0\xa0\xa0Simmons, Williams, Alleyne-Forte, Hylton',
#   '\xa0\xa0\xa0\xa0— LSU {8}',
#   '',
#   '\xa0',
#   '3:01.21 ',
#   '6/9/2012',
#   '\xa0\xa0\xa0\xa0\xa0Simmons, Williams, Alleyne-Forte, Hylton'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {15}\xa03:01.22 qq = Performance occurred during a non-final round. 5/27/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON, Ryan WILLIE, Kemuel SANTANA, Champion ALLISON',
#   '\xa0\xa0\xa0\xa0— FLORIDA {15}',
#   '',
#   '\xa0',
#   '3:01.22 qq = Performance occurred during a non-final round. ',
#   '5/27/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON, Ryan WILLIE, Kemuel SANTANA, Champion ALLISON'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {13}\xa03:01.22  6/5/1993\xa0\xa0\xa0\xa0\xa0Daniel Fredericks 46.4, Dion Minor 45.3, Tony Miller 44.7, Etheridge Green 44.8',
#   '\xa0\xa0\xa0\xa0— BAYLOR {13}',
#   '',
#   '\xa0',
#   '3:01.22  ',
#   '6/5/1993',
#   '\xa0\xa0\xa0\xa0\xa0Daniel Fredericks 46.4, Dion Minor 45.3, Tony Miller 44.7, Etheridge Green 44.8'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {21}\xa03:01.23 qq = Performance occurred during a non-final round. 5/26/2018',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {21}',
#   '',
#   '\xa0',
#   '3:01.23 qq = Performance occurred during a non-final round. ',
#   '5/26/2018'],
#  ['(24) Oklahoma\xa03:01.25  6/7/1997\xa0\xa0\xa0\xa0\xa0Edward Clarke 45.6, Danny McFarlane 45.6, Ryan Kite 45.14, Roxbert Martin 44.91',
#   '(24) Oklahoma',
#   '',
#   '\xa0',
#   '3:01.25  ',
#   '6/7/1997',
#   '\xa0\xa0\xa0\xa0\xa0Edward Clarke 45.6, Danny McFarlane 45.6, Ryan Kite 45.14, Roxbert Martin 44.91'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {14}\xa03:01.25  6/1/1996\xa0\xa0\xa0\xa0\xa0Michael Ford 46.2, Raoul Howard 45.3, Darrin Strong 45.1, Marlon Ramsey 44.7',
#   '\xa0\xa0\xa0\xa0— BAYLOR {14}',
#   '',
#   '\xa0',
#   '3:01.25  ',
#   '6/1/1996',
#   '\xa0\xa0\xa0\xa0\xa0Michael Ford 46.2, Raoul Howard 45.3, Darrin Strong 45.1, Marlon Ramsey 44.7'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {22}\xa03:01.26 qq = Performance occurred during a non-final round. 6/5/2019\xa0\xa0\xa0\xa0\xa0Bryce DEADMON (JR), Robert GRANT (SR), DeWitt THOMAS (SR) 45.87, Devin DIXON (JR) 44.40',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {22}',
#   '',
#   '\xa0',
#   '3:01.26 qq = Performance occurred during a non-final round. ',
#   '6/5/2019',
#   '\xa0\xa0\xa0\xa0\xa0Bryce DEADMON (JR), Robert GRANT (SR), DeWitt THOMAS (SR) 45.87, Devin DIXON (JR) 44.40'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {16}\xa03:01.26 3/29/2014\xa0\xa0\xa0\xa0\xa0Najee Glass 46.3, Hugh Graham, Jr. 44.7, Dedric Dukes 45.2, Arman Hall 45.0',
#   '\xa0\xa0\xa0\xa0— FLORIDA {16}',
#   '',
#   '\xa0',
#   '3:01.26 ',
#   '3/29/2014',
#   '\xa0\xa0\xa0\xa0\xa0Najee Glass 46.3, Hugh Graham, Jr. 44.7, Dedric Dukes 45.2, Arman Hall 45.0'],
#  ['\xa0\xa0\xa0\xa0— TEXAS {3}\xa03:01.28 3/27/2021\xa0\xa0\xa0\xa0\xa0Maas, Harris, Jones, Wright',
#   '\xa0\xa0\xa0\xa0— TEXAS {3}',
#   '',
#   '\xa0',
#   '3:01.28 ',
#   '3/27/2021',
#   '\xa0\xa0\xa0\xa0\xa0Maas, Harris, Jones, Wright'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {17}\xa03:01.30 qq = Performance occurred during a non-final round. 6/8/2022\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON (JR), Ryan WILLIE (SO), Jacob MILEY (SO) 46.19, Champion ALLISON (JR) 44.75',
#   '\xa0\xa0\xa0\xa0— FLORIDA {17}',
#   '',
#   '\xa0',
#   '3:01.30 qq = Performance occurred during a non-final round. ',
#   '6/8/2022',
#   '\xa0\xa0\xa0\xa0\xa0Jacory PATTERSON (JR), Ryan WILLIE (SO), Jacob MILEY (SO) 46.19, Champion ALLISON (JR) 44.75'],
#  ['\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {6}\xa03:01.30 qq = Performance occurred during a non-final round. 6/6/2018',
#   '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {6}',
#   '',
#   '\xa0',
#   '3:01.30 qq = Performance occurred during a non-final round. ',
#   '6/6/2018'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {18}\xa03:01.34 6/8/2013\xa0\xa0\xa0\xa0\xa0Najee Glass (FR) 46.0, Hugh Graham, Jr. (SO) 45.4, Dedric Dukes (SO) 45.09, Arman Hall (FR) 44.86',
#   '\xa0\xa0\xa0\xa0— FLORIDA {18}',
#   '',
#   '\xa0',
#   '3:01.34 ',
#   '6/8/2013',
#   '\xa0\xa0\xa0\xa0\xa0Najee Glass (FR) 46.0, Hugh Graham, Jr. (SO) 45.4, Dedric Dukes (SO) 45.09, Arman Hall (FR) 44.86'],
#  ['\xa0\xa0\xa0\xa0— FLORIDA {19}\xa03:01.36  6/11/2005',
#   '\xa0\xa0\xa0\xa0— FLORIDA {19}',
#   '',
#   '\xa0',
#   '3:01.36  ',
#   '6/11/2005'],
#  ['\xa0\xa0\xa0\xa0— ARIZONA STATE {4}\xa03:01.38 4/1/2023\xa0\xa0\xa0\xa0\xa0Justin ROBINSON, Jeremiah CURRY, Dubem NWACHUKWU 44.80, Trevin MOYER 45.37',
#   '\xa0\xa0\xa0\xa0— ARIZONA STATE {4}',
#   '',
#   '\xa0',
#   '3:01.38 ',
#   '4/1/2023',
#   '\xa0\xa0\xa0\xa0\xa0Justin ROBINSON, Jeremiah CURRY, Dubem NWACHUKWU 44.80, Trevin MOYER 45.37'],
#  ['\xa0\xa0\xa0\xa0— OHIO STATE {2}\xa03:01.41  6/6/1992',
#   '\xa0\xa0\xa0\xa0— OHIO STATE {2}',
#   '',
#   '\xa0',
#   '3:01.41  ',
#   '6/6/1992'],
#  ['\xa0\xa0\xa0\xa0— OHIO STATE {3}\xa03:01.41  1992\xa0\xa0\xa0\xa0\xa0Rich Jones, Aaron Payne, Robert Smith, Chris Nelloms',
#   '\xa0\xa0\xa0\xa0— OHIO STATE {3}',
#   '',
#   '\xa0',
#   '3:01.41  ',
#   '1992',
#   '\xa0\xa0\xa0\xa0\xa0Rich Jones, Aaron Payne, Robert Smith, Chris Nelloms'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {23}\xa03:01.42 qq = Performance occurred during a non-final round. 5/31/2014\xa0\xa0\xa0\xa0\xa0Carlyle Roudette, Aldrich Bailey, Jr., Bralon Taplin, Deon Lendore',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {23}',
#   '',
#   '\xa0',
#   '3:01.42 qq = Performance occurred during a non-final round. ',
#   '5/31/2014',
#   '\xa0\xa0\xa0\xa0\xa0Carlyle Roudette, Aldrich Bailey, Jr., Bralon Taplin, Deon Lendore'],
#  ['\xa0\xa0\xa0\xa0— BAYLOR {15}\xa03:01.46  6/3/2000\xa0\xa0\xa0\xa0\xa0Zsolt Szeglet 46.3, Bayano Kamani 45.4, Floyd Thompson 45.1, Brandon Couts 44.7',
#   '\xa0\xa0\xa0\xa0— BAYLOR {15}',
#   '',
#   '\xa0',
#   '3:01.46  ',
#   '6/3/2000',
#   '\xa0\xa0\xa0\xa0\xa0Zsolt Szeglet 46.3, Bayano Kamani 45.4, Floyd Thompson 45.1, Brandon Couts 44.7'],
#  ['\xa0\xa0\xa0\xa0— OKLAHOMA {2}\xa03:01.46  4/28/1984\xa0\xa0\xa0\xa0\xa0Aubrey Jones 45.7, Donnie Kemp 44.9, Dannie Carter 45.8, Don Bly 45.1',
#   '\xa0\xa0\xa0\xa0— OKLAHOMA {2}',
#   '',
#   '\xa0',
#   '3:01.46  ',
#   '4/28/1984',
#   '\xa0\xa0\xa0\xa0\xa0Aubrey Jones 45.7, Donnie Kemp 44.9, Dannie Carter 45.8, Don Bly 45.1'],
#  ['\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {4}\xa03:01.50 6/7/2019\xa0\xa0\xa0\xa0\xa0Akeem LINDO (FR), Akeem SIRLEAF (JR), Trevor STEWART (JR) 44.13, Kemarni MIGHTY (JR) 45.22',
#   '\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {4}',
#   '',
#   '\xa0',
#   '3:01.50 ',
#   '6/7/2019',
#   '\xa0\xa0\xa0\xa0\xa0Akeem LINDO (FR), Akeem SIRLEAF (JR), Trevor STEWART (JR) 44.13, Kemarni MIGHTY (JR) 45.22'],
#  ['\xa0\xa0\xa0\xa0— GEORGIA {3}\xa03:01.51 qq = Performance occurred during a non-final round. 6/7/2023\xa0\xa0\xa0\xa0\xa0Matthew BOLING, Caleb CAVANAUGH, Christopher MORALES WILLIAMS, Will SUMNER',
#   '\xa0\xa0\xa0\xa0— GEORGIA {3}',
#   '',
#   '\xa0',
#   '3:01.51 qq = Performance occurred during a non-final round. ',
#   '6/7/2023',
#   '\xa0\xa0\xa0\xa0\xa0Matthew BOLING, Caleb CAVANAUGH, Christopher MORALES WILLIAMS, Will SUMNER'],
#  ['\xa0\xa0\xa0\xa0— TEXAS A&M {24}\xa03:01.51 3/19/2022\xa0\xa0\xa0\xa0\xa0 CHEVANNIE, 7778460 OMAJUWA, 7729602 BRANDON, 7729617 JAMES',
#   '\xa0\xa0\xa0\xa0— TEXAS A&M {24}',
#   '',
#   '\xa0',
#   '3:01.51 ',
#   '3/19/2022',
#   '\xa0\xa0\xa0\xa0\xa0 CHEVANNIE, 7778460 OMAJUWA, 7729602 BRANDON, 7729617 JAMES'],
#  ['(25) Stephen F. Austin\xa03:01.52 6/11/2021\xa0\xa0\xa0\xa0\xa0Muzuri MATTAR (SO), Paul MARTIN (FR), Jeremiah CURRY (SO) 45.89, Auhmad ROBINSON (FR) 43.45',
#   '(25) Stephen F. Austin',
#   '',
#   '\xa0',
#   '3:01.52 ',
#   '6/11/2021',
#   '\xa0\xa0\xa0\xa0\xa0Muzuri MATTAR (SO), Paul MARTIN (FR), Jeremiah CURRY (SO) 45.89, Auhmad ROBINSON (FR) 43.45'],
#  ['OKLAHOMA\xa03:00.26c  5/18/1997',
#   'OKLAHOMA',
#   '',
#   '\xa0',
#   '3:00.26c  ',
#   '5/18/1997']]

# %%
RealRealRows[1][4]
# Out:
# '2:57.76📺 '

# %%
len(RealRealRows)
# Out:
# 117

# %%
OfficialTimes = []

# %%
for i in range(0,len(RealRealRows)):
    OfficialTimes.append(RealRealRows[i][4])
OfficialTimes
# Out:
# ['2:57.74 ',
#  '2:57.76📺 ',
#  '2:57.78 ',
#  '2:58.01 ',
#  '2:58.53📺 ',
#  '2:58.62 qq = Performance occurred during a non-final round. ',
#  '2:58.82📺 ',
#  '2:58.88 ',
#  '2:59.00📺 ',
#  '2:59.05📺 ',
#  '2:59.14 qq = Performance occurred during a non-final round. ',
#  '2:59.15 ',
#  '2:59.21 qq = Performance occurred during a non-final round. ',
#  '2:59.24 qq = Performance occurred during a non-final round. ',
#  '2:59.25 ',
#  '2:59.44 ',
#  '2:59.51 qq = Performance occurred during a non-final round. ',
#  '2:59.59📺 ',
#  '2:59.60 ',
#  '2:59.60 ',
#  '2:59.63 ',
#  '2:59.73 ',
#  '2:59.78 qq = Performance occurred during a non-final round. ',
#  '2:59.82 ',
#  '2:59.91 ',
#  '2:59.91  ',
#  '2:59.93 ',
#  '2:59.95 qq = Performance occurred during a non-final round. ',
#  '2:59.95  ',
#  '2:59.98 ',
#  '2:59.98 ',
#  '2:59.99  ',
#  '3:00.02 ',
#  '3:00.04  ',
#  '3:00.07 ',
#  '3:00.14 ',
#  '3:00.17 ',
#  '3:00.22  ',
#  '3:00.23 ',
#  '3:00.31 qq = Performance occurred during a non-final round. ',
#  '3:00.31  ',
#  '3:00.38 ',
#  '3:00.42 qq = Performance occurred during a non-final round. ',
#  '3:00.42 ',
#  '3:00.45 ',
#  '3:00.48 ',
#  '3:00.55  ',
#  '3:00.56 ',
#  '3:00.57  ',
#  '3:00.58 qq = Performance occurred during a non-final round. ',
#  '3:00.58  ',
#  '3:00.60 qq = Performance occurred during a non-final round. ',
#  '3:00.61 ',
#  '3:00.61  ',
#  '3:00.62 ',
#  '3:00.64 ',
#  '3:00.64  ',
#  '3:00.68  ',
#  '3:00.69 qq = Performance occurred during a non-final round. ',
#  '3:00.69 ',
#  '3:00.70 qq = Performance occurred during a non-final round. ',
#  '3:00.72 ',
#  '3:00.73 ',
#  '3:00.74 ',
#  '3:00.76 qq = Performance occurred during a non-final round. ',
#  '3:00.78  ',
#  '3:00.81 ',
#  '3:00.81  ',
#  '3:00.81  ',
#  '3:00.82  ',
#  '3:00.83  ',
#  '3:00.84  ',
#  '3:00.88 qq = Performance occurred during a non-final round. ',
#  '3:00.89  ',
#  '3:00.90 ',
#  '3:00.91  ',
#  '3:00.91 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '3:00.92 ',
#  '3:00.97 qq = Performance occurred during a non-final round. ',
#  '3:01.00 ',
#  '3:01.00 ',
#  '3:01.03  ',
#  '3:01.07 ',
#  '3:01.07  ',
#  '3:01.11 qq = Performance occurred during a non-final round. ',
#  '3:01.12 ',
#  '3:01.12  ',
#  '3:01.13 qq = Performance occurred during a non-final round. ',
#  '3:01.16  ',
#  '3:01.16  ',
#  '3:01.17 ',
#  '3:01.17  ',
#  '3:01.19 ',
#  '3:01.21 ',
#  '3:01.22 qq = Performance occurred during a non-final round. ',
#  '3:01.22  ',
#  '3:01.23 qq = Performance occurred during a non-final round. ',
#  '3:01.25  ',
#  '3:01.25  ',
#  '3:01.26 qq = Performance occurred during a non-final round. ',
#  '3:01.26 ',
#  '3:01.28 ',
#  '3:01.30 qq = Performance occurred during a non-final round. ',
#  '3:01.30 qq = Performance occurred during a non-final round. ',
#  '3:01.34 ',
#  '3:01.36  ',
#  '3:01.38 ',
#  '3:01.41  ',
#  '3:01.41  ',
#  '3:01.42 qq = Performance occurred during a non-final round. ',
#  '3:01.46  ',
#  '3:01.46  ',
#  '3:01.50 ',
#  '3:01.51 qq = Performance occurred during a non-final round. ',
#  '3:01.51 ',
#  '3:01.52 ',
#  '3:00.26c  ']

# %%
RealRealRows[0][1]
# Out:
# '(1) Florida'

# %%
Names = []

for i in range(0,len(RealRealRows)):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Florida',
#  '\xa0\xa0\xa0\xa0— FLORIDA {2}',
#  '(2) Arizona State',
#  '(3) Alabama',
#  '\xa0\xa0\xa0\xa0— FLORIDA {3}',
#  '\xa0\xa0\xa0\xa0— FLORIDA {4}',
#  '(4) Georgia',
#  '\xa0\xa0\xa0\xa0— FLORIDA {5}',
#  '(5) Southern California',
#  '(6) Texas A&M',
#  '\xa0\xa0\xa0\xa0— ARIZONA STATE {2}',
#  '\xa0\xa0\xa0\xa0— ALABAMA {2}',
#  '(7) North Carolina A&T',
#  '\xa0\xa0\xa0\xa0— ALABAMA {3}',
#  '(8) UCLA',
#  '\xa0\xa0\xa0\xa0— FLORIDA {6}',
#  '\xa0\xa0\xa0\xa0— UCLA {2}',
#  '(9) LSU',
#  '\xa0\xa0\xa0\xa0— FLORIDA {7}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {2}',
#  '\xa0\xa0\xa0\xa0— GEORGIA {2}',
#  '\xa0\xa0\xa0\xa0— FLORIDA {8}',
#  '(10) Clemson',
#  '\xa0\xa0\xa0\xa0— UCLA {3}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {3}',
#  '\xa0\xa0\xa0\xa0— UCLA {4}',
#  '(11) Kentucky',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {4}',
#  '(12) Georgia Tech',
#  '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {2}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {5}',
#  '(13) Florida State',
#  '\xa0\xa0\xa0\xa0— FLORIDA {9}',
#  '(14) Baylor',
#  '(15) Houston',
#  '(16) Iowa',
#  '\xa0\xa0\xa0\xa0— ALABAMA {4}',
#  '\xa0\xa0\xa0\xa0— BAYLOR {2}',
#  '\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {2}',
#  '(17) Texas',
#  '\xa0\xa0\xa0\xa0— FLORIDA {10}',
#  '\xa0\xa0\xa0\xa0— LSU {2}',
#  '\xa0\xa0\xa0\xa0— ALABAMA {5}',
#  '\xa0\xa0\xa0\xa0— FLORIDA {11}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {6}',
#  '\xa0\xa0\xa0\xa0— LSU {3}',
#  '\xa0\xa0\xa0\xa0— UCLA {5}',
#  '\xa0\xa0\xa0\xa0— LSU {4}',
#  '\xa0\xa0\xa0\xa0— ARIZONA STATE {3}',
#  '\xa0\xa0\xa0\xa0— BAYLOR {3}',
#  '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {3}',
#  '\xa0\xa0\xa0\xa0— BAYLOR {4}',
#  '\xa0\xa0\xa0\xa0— BAYLOR {5}',
#  '\xa0\xa0\xa0\xa0— BAYLOR {6}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {7}',
#  '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {4}',
#  '\xa0\xa0\xa0\xa0— BAYLOR {7}',
#  '\xa0\xa0\xa0\xa0— FLORIDA {12}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {8}',
#  '\xa0\xa0\xa0\xa0— LSU {5}',
#  '\xa0\xa0\xa0\xa0— TEXAS {2}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {9}',
#  '\xa0\xa0\xa0\xa0— BAYLOR {8}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {10}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {11}',
#  '(18) Southern Illinois',
#  '\xa0\xa0\xa0\xa0— ALABAMA {6}',
#  '(19) Oregon',
#  '(19) SMU',
#  '(21) Ohio State',
#  '\xa0\xa0\xa0\xa0— BAYLOR {9}',
#  '\xa0\xa0\xa0\xa0— BAYLOR {10}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {12}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {13}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {14}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {15}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {16}',
#  '\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {3}',
#  '(22) Arkansas',
#  '\xa0\xa0\xa0\xa0— LSU {6}',
#  '\xa0\xa0\xa0\xa0— FLORIDA {13}',
#  '\xa0\xa0\xa0\xa0— BAYLOR {11}',
#  '\xa0\xa0\xa0\xa0— LSU {7}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {17}',
#  '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {5}',
#  '\xa0\xa0\xa0\xa0— FLORIDA {14}',
#  '\xa0\xa0\xa0\xa0— BAYLOR {12}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {18}',
#  '\xa0\xa0\xa0\xa0— ALABAMA {7}',
#  '\xa0\xa0\xa0\xa0— ALABAMA {8}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {19}',
#  '(23) Iowa State',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {20}',
#  '\xa0\xa0\xa0\xa0— LSU {8}',
#  '\xa0\xa0\xa0\xa0— FLORIDA {15}',
#  '\xa0\xa0\xa0\xa0— BAYLOR {13}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {21}',
#  '(24) Oklahoma',
#  '\xa0\xa0\xa0\xa0— BAYLOR {14}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {22}',
#  '\xa0\xa0\xa0\xa0— FLORIDA {16}',
#  '\xa0\xa0\xa0\xa0— TEXAS {3}',
#  '\xa0\xa0\xa0\xa0— FLORIDA {17}',
#  '\xa0\xa0\xa0\xa0— SOUTHERN CALIFORNIA {6}',
#  '\xa0\xa0\xa0\xa0— FLORIDA {18}',
#  '\xa0\xa0\xa0\xa0— FLORIDA {19}',
#  '\xa0\xa0\xa0\xa0— ARIZONA STATE {4}',
#  '\xa0\xa0\xa0\xa0— OHIO STATE {2}',
#  '\xa0\xa0\xa0\xa0— OHIO STATE {3}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {23}',
#  '\xa0\xa0\xa0\xa0— BAYLOR {15}',
#  '\xa0\xa0\xa0\xa0— OKLAHOMA {2}',
#  '\xa0\xa0\xa0\xa0— NORTH CAROLINA A&T {4}',
#  '\xa0\xa0\xa0\xa0— GEORGIA {3}',
#  '\xa0\xa0\xa0\xa0— TEXAS A&M {24}',
#  '(25) Stephen F. Austin',
#  'OKLAHOMA']

# %%
OfficialReGexNames = []

# %%
for i in range(0,len(RealRealRows)):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Florida',
#  '— FLORIDA {2}',
#  '(2) Arizona State',
#  '(3) Alabama',
#  '— FLORIDA {3}',
#  '— FLORIDA {4}',
#  '(4) Georgia',
#  '— FLORIDA {5}',
#  '(5) Southern California',
#  '(6) Texas A&M',
#  '— ARIZONA STATE {2}',
#  '— ALABAMA {2}',
#  '(7) North Carolina A&T',
#  '— ALABAMA {3}',
#  '(8) UCLA',
#  '— FLORIDA {6}',
#  '— UCLA {2}',
#  '(9) LSU',
#  '— FLORIDA {7}',
#  '— TEXAS A&M {2}',
#  '— GEORGIA {2}',
#  '— FLORIDA {8}',
#  '(10) Clemson',
#  '— UCLA {3}',
#  '— TEXAS A&M {3}',
#  '— UCLA {4}',
#  '(11) Kentucky',
#  '— TEXAS A&M {4}',
#  '(12) Georgia Tech',
#  '— SOUTHERN CALIFORNIA {2}',
#  '— TEXAS A&M {5}',
#  '(13) Florida State',
#  '— FLORIDA {9}',
#  '(14) Baylor',
#  '(15) Houston',
#  '(16) Iowa',
#  '— ALABAMA {4}',
#  '— BAYLOR {2}',
#  '— NORTH CAROLINA A&T {2}',
#  '(17) Texas',
#  '— FLORIDA {10}',
#  '— LSU {2}',
#  '— ALABAMA {5}',
#  '— FLORIDA {11}',
#  '— TEXAS A&M {6}',
#  '— LSU {3}',
#  '— UCLA {5}',
#  '— LSU {4}',
#  '— ARIZONA STATE {3}',
#  '— BAYLOR {3}',
#  '— SOUTHERN CALIFORNIA {3}',
#  '— BAYLOR {4}',
#  '— BAYLOR {5}',
#  '— BAYLOR {6}',
#  '— TEXAS A&M {7}',
#  '— SOUTHERN CALIFORNIA {4}',
#  '— BAYLOR {7}',
#  '— FLORIDA {12}',
#  '— TEXAS A&M {8}',
#  '— LSU {5}',
#  '— TEXAS {2}',
#  '— TEXAS A&M {9}',
#  '— BAYLOR {8}',
#  '— TEXAS A&M {10}',
#  '— TEXAS A&M {11}',
#  '(18) Southern Illinois',
#  '— ALABAMA {6}',
#  '(19) Oregon',
#  '(19) SMU',
#  '(21) Ohio State',
#  '— BAYLOR {9}',
#  '— BAYLOR {10}',
#  '— TEXAS A&M {12}',
#  '— TEXAS A&M {13}',
#  '— TEXAS A&M {14}',
#  '— TEXAS A&M {15}',
#  '— TEXAS A&M {16}',
#  '— NORTH CAROLINA A&T {3}',
#  '(22) Arkansas',
#  '— LSU {6}',
#  '— FLORIDA {13}',
#  '— BAYLOR {11}',
#  '— LSU {7}',
#  '— TEXAS A&M {17}',
#  '— SOUTHERN CALIFORNIA {5}',
#  '— FLORIDA {14}',
#  '— BAYLOR {12}',
#  '— TEXAS A&M {18}',
#  '— ALABAMA {7}',
#  '— ALABAMA {8}',
#  '— TEXAS A&M {19}',
#  '(23) Iowa State',
#  '— TEXAS A&M {20}',
#  '— LSU {8}',
#  '— FLORIDA {15}',
#  '— BAYLOR {13}',
#  '— TEXAS A&M {21}',
#  '(24) Oklahoma',
#  '— BAYLOR {14}',
#  '— TEXAS A&M {22}',
#  '— FLORIDA {16}',
#  '— TEXAS {3}',
#  '— FLORIDA {17}',
#  '— SOUTHERN CALIFORNIA {6}',
#  '— FLORIDA {18}',
#  '— FLORIDA {19}',
#  '— ARIZONA STATE {4}',
#  '— OHIO STATE {2}',
#  '— OHIO STATE {3}',
#  '— TEXAS A&M {23}',
#  '— BAYLOR {15}',
#  '— OKLAHOMA {2}',
#  '— NORTH CAROLINA A&T {4}',
#  '— GEORGIA {3}',
#  '— TEXAS A&M {24}',
#  '(25) Stephen F. Austin',
#  'OKLAHOMA']

# %%
CleanedNames = []

for i in range(0,len(RealRealRows)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Florida',
#  'FLORIDA {2}',
#  'Arizona State',
#  'Alabama',
#  'FLORIDA {3}',
#  'FLORIDA {4}',
#  'Georgia',
#  'FLORIDA {5}',
#  'Southern California',
#  'Texas A&M',
#  'ARIZONA STATE {2}',
#  'ALABAMA {2}',
#  'North Carolina A&T',
#  'ALABAMA {3}',
#  'UCLA',
#  'FLORIDA {6}',
#  'UCLA {2}',
#  'LSU',
#  'FLORIDA {7}',
#  'TEXAS A&M {2}',
#  'GEORGIA {2}',
#  'FLORIDA {8}',
#  ' Clemson',
#  'UCLA {3}',
#  'TEXAS A&M {3}',
#  'UCLA {4}',
#  ' Kentucky',
#  'TEXAS A&M {4}',
#  ' Georgia Tech',
#  'SOUTHERN CALIFORNIA {2}',
#  'TEXAS A&M {5}',
#  ' Florida State',
#  'FLORIDA {9}',
#  ' Baylor',
#  ' Houston',
#  ' Iowa',
#  'ALABAMA {4}',
#  'BAYLOR {2}',
#  'NORTH CAROLINA A&T {2}',
#  ' Texas',
#  'FLORIDA {10}',
#  'LSU {2}',
#  'ALABAMA {5}',
#  'FLORIDA {11}',
#  'TEXAS A&M {6}',
#  'LSU {3}',
#  'UCLA {5}',
#  'LSU {4}',
#  'ARIZONA STATE {3}',
#  'BAYLOR {3}',
#  'SOUTHERN CALIFORNIA {3}',
#  'BAYLOR {4}',
#  'BAYLOR {5}',
#  'BAYLOR {6}',
#  'TEXAS A&M {7}',
#  'SOUTHERN CALIFORNIA {4}',
#  'BAYLOR {7}',
#  'FLORIDA {12}',
#  'TEXAS A&M {8}',
#  'LSU {5}',
#  'TEXAS {2}',
#  'TEXAS A&M {9}',
#  'BAYLOR {8}',
#  'TEXAS A&M {10}',
#  'TEXAS A&M {11}',
#  ' Southern Illinois',
#  'ALABAMA {6}',
#  ' Oregon',
#  ' SMU',
#  ' Ohio State',
#  'BAYLOR {9}',
#  'BAYLOR {10}',
#  'TEXAS A&M {12}',
#  'TEXAS A&M {13}',
#  'TEXAS A&M {14}',
#  'TEXAS A&M {15}',
#  'TEXAS A&M {16}',
#  'NORTH CAROLINA A&T {3}',
#  ' Arkansas',
#  'LSU {6}',
#  'FLORIDA {13}',
#  'BAYLOR {11}',
#  'LSU {7}',
#  'TEXAS A&M {17}',
#  'SOUTHERN CALIFORNIA {5}',
#  'FLORIDA {14}',
#  'BAYLOR {12}',
#  'TEXAS A&M {18}',
#  'ALABAMA {7}',
#  'ALABAMA {8}',
#  'TEXAS A&M {19}',
#  ' Iowa State',
#  'TEXAS A&M {20}',
#  'LSU {8}',
#  'FLORIDA {15}',
#  'BAYLOR {13}',
#  'TEXAS A&M {21}',
#  ' Oklahoma',
#  'BAYLOR {14}',
#  'TEXAS A&M {22}',
#  'FLORIDA {16}',
#  'TEXAS {3}',
#  'FLORIDA {17}',
#  'SOUTHERN CALIFORNIA {6}',
#  'FLORIDA {18}',
#  'FLORIDA {19}',
#  'ARIZONA STATE {4}',
#  'OHIO STATE {2}',
#  'OHIO STATE {3}',
#  'TEXAS A&M {23}',
#  'BAYLOR {15}',
#  'OKLAHOMA {2}',
#  'NORTH CAROLINA A&T {4}',
#  'GEORGIA {3}',
#  'TEXAS A&M {24}',
#  ' Stephen F. Austin']

# %%
CleanedNames.append("OKLAHOMA")

# %%
CleanedNames2 = []

for i in range(0,len(RealRealRows)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Florida',
#  'FLORIDA {2}',
#  'Arizona State',
#  'Alabama',
#  'FLORIDA {3}',
#  'FLORIDA {4}',
#  'Georgia',
#  'FLORIDA {5}',
#  'Southern California',
#  'Texas A&M',
#  'ARIZONA STATE {2}',
#  'ALABAMA {2}',
#  'North Carolina A&T',
#  'ALABAMA {3}',
#  'UCLA',
#  'FLORIDA {6}',
#  'UCLA {2}',
#  'LSU',
#  'FLORIDA {7}',
#  'TEXAS A&M {2}',
#  'GEORGIA {2}',
#  'FLORIDA {8}',
#  'Clemson',
#  'UCLA {3}',
#  'TEXAS A&M {3}',
#  'UCLA {4}',
#  'Kentucky',
#  'TEXAS A&M {4}',
#  'Georgia Tech',
#  'SOUTHERN CALIFORNIA {2}',
#  'TEXAS A&M {5}',
#  'Florida State',
#  'FLORIDA {9}',
#  'Baylor',
#  'Houston',
#  'Iowa',
#  'ALABAMA {4}',
#  'BAYLOR {2}',
#  'NORTH CAROLINA A&T {2}',
#  'Texas',
#  'FLORIDA {10}',
#  'LSU {2}',
#  'ALABAMA {5}',
#  'FLORIDA {11}',
#  'TEXAS A&M {6}',
#  'LSU {3}',
#  'UCLA {5}',
#  'LSU {4}',
#  'ARIZONA STATE {3}',
#  'BAYLOR {3}',
#  'SOUTHERN CALIFORNIA {3}',
#  'BAYLOR {4}',
#  'BAYLOR {5}',
#  'BAYLOR {6}',
#  'TEXAS A&M {7}',
#  'SOUTHERN CALIFORNIA {4}',
#  'BAYLOR {7}',
#  'FLORIDA {12}',
#  'TEXAS A&M {8}',
#  'LSU {5}',
#  'TEXAS {2}',
#  'TEXAS A&M {9}',
#  'BAYLOR {8}',
#  'TEXAS A&M {10}',
#  'TEXAS A&M {11}',
#  'Southern Illinois',
#  'ALABAMA {6}',
#  'Oregon',
#  'SMU',
#  'Ohio State',
#  'BAYLOR {9}',
#  'BAYLOR {10}',
#  'TEXAS A&M {12}',
#  'TEXAS A&M {13}',
#  'TEXAS A&M {14}',
#  'TEXAS A&M {15}',
#  'TEXAS A&M {16}',
#  'NORTH CAROLINA A&T {3}',
#  'Arkansas',
#  'LSU {6}',
#  'FLORIDA {13}',
#  'BAYLOR {11}',
#  'LSU {7}',
#  'TEXAS A&M {17}',
#  'SOUTHERN CALIFORNIA {5}',
#  'FLORIDA {14}',
#  'BAYLOR {12}',
#  'TEXAS A&M {18}',
#  'ALABAMA {7}',
#  'ALABAMA {8}',
#  'TEXAS A&M {19}',
#  'Iowa State',
#  'TEXAS A&M {20}',
#  'LSU {8}',
#  'FLORIDA {15}',
#  'BAYLOR {13}',
#  'TEXAS A&M {21}',
#  'Oklahoma',
#  'BAYLOR {14}',
#  'TEXAS A&M {22}',
#  'FLORIDA {16}',
#  'TEXAS {3}',
#  'FLORIDA {17}',
#  'SOUTHERN CALIFORNIA {6}',
#  'FLORIDA {18}',
#  'FLORIDA {19}',
#  'ARIZONA STATE {4}',
#  'OHIO STATE {2}',
#  'OHIO STATE {3}',
#  'TEXAS A&M {23}',
#  'BAYLOR {15}',
#  'OKLAHOMA {2}',
#  'NORTH CAROLINA A&T {4}',
#  'GEORGIA {3}',
#  'TEXAS A&M {24}',
#  'Stephen F. Austin',
#  'OKLAHOMA']

# %%
len(OfficialTimes)
# Out:
# 117

# %%
len(OfficialReGexNames)
# Out:
# 117

# %%
Times = []

# %%
for i in range(0,len(OfficialTimes)):
    Times.append(OfficialTimes[i][:7])
    
Times
# Out:
# ['2:57.74',
#  '2:57.76',
#  '2:57.78',
#  '2:58.01',
#  '2:58.53',
#  '2:58.62',
#  '2:58.82',
#  '2:58.88',
#  '2:59.00',
#  '2:59.05',
#  '2:59.14',
#  '2:59.15',
#  '2:59.21',
#  '2:59.24',
#  '2:59.25',
#  '2:59.44',
#  '2:59.51',
#  '2:59.59',
#  '2:59.60',
#  '2:59.60',
#  '2:59.63',
#  '2:59.73',
#  '2:59.78',
#  '2:59.82',
#  '2:59.91',
#  '2:59.91',
#  '2:59.93',
#  '2:59.95',
#  '2:59.95',
#  '2:59.98',
#  '2:59.98',
#  '2:59.99',
#  '3:00.02',
#  '3:00.04',
#  '3:00.07',
#  '3:00.14',
#  '3:00.17',
#  '3:00.22',
#  '3:00.23',
#  '3:00.31',
#  '3:00.31',
#  '3:00.38',
#  '3:00.42',
#  '3:00.42',
#  '3:00.45',
#  '3:00.48',
#  '3:00.55',
#  '3:00.56',
#  '3:00.57',
#  '3:00.58',
#  '3:00.58',
#  '3:00.60',
#  '3:00.61',
#  '3:00.61',
#  '3:00.62',
#  '3:00.64',
#  '3:00.64',
#  '3:00.68',
#  '3:00.69',
#  '3:00.69',
#  '3:00.70',
#  '3:00.72',
#  '3:00.73',
#  '3:00.74',
#  '3:00.76',
#  '3:00.78',
#  '3:00.81',
#  '3:00.81',
#  '3:00.81',
#  '3:00.82',
#  '3:00.83',
#  '3:00.84',
#  '3:00.88',
#  '3:00.89',
#  '3:00.90',
#  '3:00.91',
#  '3:00.91',
#  '3:00.92',
#  '3:00.97',
#  '3:01.00',
#  '3:01.00',
#  '3:01.03',
#  '3:01.07',
#  '3:01.07',
#  '3:01.11',
#  '3:01.12',
#  '3:01.12',
#  '3:01.13',
#  '3:01.16',
#  '3:01.16',
#  '3:01.17',
#  '3:01.17',
#  '3:01.19',
#  '3:01.21',
#  '3:01.22',
#  '3:01.22',
#  '3:01.23',
#  '3:01.25',
#  '3:01.25',
#  '3:01.26',
#  '3:01.26',
#  '3:01.28',
#  '3:01.30',
#  '3:01.30',
#  '3:01.34',
#  '3:01.36',
#  '3:01.38',
#  '3:01.41',
#  '3:01.41',
#  '3:01.42',
#  '3:01.46',
#  '3:01.46',
#  '3:01.50',
#  '3:01.51',
#  '3:01.51',
#  '3:01.52',
#  '3:00.26']

# %%
OutdoorMens4x400mDF = pd.DataFrame({'Schools': CleanedNames2, 'Times': Times})

# %%
OutdoorMens4x400mDF.to_csv('OutdoorMens4x400m.csv', index=False)
