# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
Link800mWomen = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?gender=2&sport=2&div=20527&top=25&event=6"

# %%
page = requests.get(Link800mWomen)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729637" target="_blank">(1) Athing MU</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68122/4209447" target="_blank">1:57.73</a><a href="https://www.youtube.com/watch?v=pLqMGZnwGXA" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Michael Johnson Classic (Waco, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/16/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729637" target="_blank">(1) Athing MU</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68122/4209447" target="_blank">1:57.73</a><a href="https://www.youtube.com/watch?v=pLqMGZnwGXA" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Michael Johnson Classic (Waco, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">4/16/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7930954" target="_blank">(2) Michaela ROSE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76221/4827248" target="_blank">1:59.08</a><a href="https://twitter.com/LSUTrackField/status/1647018169234751488" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Bryan Clay Invitational (Azusa, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/13/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7930954" target="_blank">(2) Michaela ROSE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76221/4827248" target="_blank">1:59.08</a><a href="https://twitter.com/LSUTrackField/status/1647018169234751488" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Bryan Clay Invitational (Azusa, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/13/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113694" target="_blank">(3) Raevyn ROGERS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51129" target="_blank">1:59.10</a> </td><td style="width: 10%;text-align:right;" title="Mt. SAC Relays (Torrance, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">4/15/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113694" target="_blank">(3) Raevyn ROGERS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51129" target="_blank">1:59.10</a> </td><td style="width: 10%;text-align:right;" title="Mt. SAC Relays (Torrance, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">4/15/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(4) Suzy FAVOR</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Wisconsin" class="group-logo-inline" src="/images/logos/rankings-article/wisconsin.png" title="Wisconsin"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1812">Wisconsin</a></td><td style="width: 25%;">1:59.11  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Durham, N.C.)"><span class="mark-date" style="width: 10%;text-align:right;">6/1/1990</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(4) Suzy FAVOR</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Wisconsin" class="group-logo-inline" src="/images/logos/rankings-article/wisconsin.png" title="Wisconsin"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1812">Wisconsin</a></td><td style="width: 25%;">1:59.11  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Durham, N.C.)"><span class="mark-date" style="width: 10%;text-align:right;">6/1/1990</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(5) Alysia JOHNSON</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="California" class="group-logo-inline" src="/images/logos/rankings-article/california.png" title="California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=211">California</a></td><td style="width: 25%;">1:59.29  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2007</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(5) Alysia JOHNSON</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="California" class="group-logo-inline" src="/images/logos/rankings-article/california.png" title="California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=211">California</a></td><td style="width: 25%;">1:59.29  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2007</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(6) Katie ERDMAN</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Michigan" class="group-logo-inline" src="/images/logos/rankings-article/michigan.png" title="Michigan"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=950">Michigan</a></td><td style="width: 25%;">1:59.35  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2007</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(6) Katie ERDMAN</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Michigan" class="group-logo-inline" src="/images/logos/rankings-article/michigan.png" title="Michigan"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=950">Michigan</a></td><td style="width: 25%;">1:59.35  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Sacramento, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">6/9/2007</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Rogers {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41405/2568011" target="_blank">1:59.71</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/13/2015</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     57.79/61.92</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Rogers {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41405/2568011" target="_blank">1:59.71</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/13/2015</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     57.79/61.92</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Rose {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4922033" target="_blank">1:59.73</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Rose {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/80833/4922033" target="_blank">1:59.73</a> </td><td style="width: 10%;text-align:right;" title="SEC Outdoor Championships (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">5/13/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Rose {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938132" target="_blank">1:59.83</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Rose {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938132" target="_blank">1:59.83</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Rogers {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51935/3199105" target="_blank">2:00.02</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2017</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     58.34/61.68</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Rogers {3}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51935/3199105" target="_blank">2:00.02</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/10/2017</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     58.34/61.68</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6547986" target="_blank">(7) Claire SEYMOUR</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="BYU" class="group-logo-inline" src="/images/logos/rankings-article/byu.png" title="BYU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=190">BYU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76221/4827248" target="_blank">2:00.04</a> </td><td style="width: 10%;text-align:right;" title="Bryan Clay Invitational (Azusa, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/13/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6547986" target="_blank">(7) Claire SEYMOUR</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="BYU" class="group-logo-inline" src="/images/logos/rankings-article/byu.png" title="BYU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=190">BYU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76221/4827248" target="_blank">2:00.04</a> </td><td style="width: 10%;text-align:right;" title="Bryan Clay Invitational (Azusa, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/13/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4991018" target="_blank">(8) Natoya GOULE</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/31188" target="_blank">2:00.06</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2013</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4991018" target="_blank">(8) Natoya GOULE</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/31188" target="_blank">2:00.06</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/7/2013</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(9) Jasmin JONES</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1553">Tennessee</a></td><td style="width: 25%;">2:00.24  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Durham, N.C.)"><span class="mark-date" style="width: 10%;text-align:right;">6/1/1990</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(9) Jasmin JONES</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1553">Tennessee</a></td><td style="width: 25%;">2:00.24  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Durham, N.C.)"><span class="mark-date" style="width: 10%;text-align:right;">6/1/1990</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(10) Inez TURNER</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas State" class="group-logo-inline" src="/images/logos/rankings-article/texas-state.png" title="Texas State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1568">Texas State</a></td><td style="width: 25%;">2:00.27  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Knoxville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">6/2/1995</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(10) Inez TURNER</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas State" class="group-logo-inline" src="/images/logos/rankings-article/texas-state.png" title="Texas State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1568">Texas State</a></td><td style="width: 25%;">2:00.27  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Knoxville, Tenn.)"><span class="mark-date" style="width: 10%;text-align:right;">6/2/1995</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7700503" target="_blank">(11) Michaela MEYER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia" class="group-logo-inline" src="/images/logos/rankings-article/virginia.png" title="Virginia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1699">Virginia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276115" target="_blank">2:00.28</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/12/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7700503" target="_blank">(11) Michaela MEYER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia" class="group-logo-inline" src="/images/logos/rankings-article/virginia.png" title="Virginia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1699">Virginia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70445/4276115" target="_blank">2:00.28</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/12/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Rose {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938132" target="_blank">2:00.31</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/8/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Rose {4}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938132" target="_blank">2:00.31</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/8/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7008908" target="_blank">(12) Valery TOBIAS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76221/4827248" target="_blank">2:00.31</a> </td><td style="width: 10%;text-align:right;" title="Bryan Clay Invitational (Azusa, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/13/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7008908" target="_blank">(12) Valery TOBIAS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76221/4827248" target="_blank">2:00.31</a> </td><td style="width: 10%;text-align:right;" title="Bryan Clay Invitational (Azusa, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/13/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Rose {5}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78213" target="_blank">2:00.34</a> </td><td style="width: 10%;text-align:right;" title="Davenport-Milburn Pelican Relays (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/8/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Rose {5}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78213" target="_blank">2:00.34</a> </td><td style="width: 10%;text-align:right;" title="Davenport-Milburn Pelican Relays (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/8/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Rose {6}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78404/4796643" target="_blank">2:00.34</a> </td><td style="width: 10%;text-align:right;" title="Lloyd Wills Invitational (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/8/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Rose {6}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78404/4796643" target="_blank">2:00.34</a> </td><td style="width: 10%;text-align:right;" title="Lloyd Wills Invitational (Baton Rouge, La.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">4/8/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Meyer {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia" class="group-logo-inline" src="/images/logos/rankings-article/virginia.png" title="Virginia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1699">Virginia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390/4273626" target="_blank">2:00.40</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/29/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Meyer {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia" class="group-logo-inline" src="/images/logos/rankings-article/virginia.png" title="Virginia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1699">Virginia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390/4273626" target="_blank">2:00.40</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/29/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Meyer {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia" class="group-logo-inline" src="/images/logos/rankings-article/virginia.png" title="Virginia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1699">Virginia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390" target="_blank">2:00.40</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/27/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Meyer {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia" class="group-logo-inline" src="/images/logos/rankings-article/virginia.png" title="Virginia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1699">Virginia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70390" target="_blank">2:00.40</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA DI Outdoor Championships - East Preliminary (Jacksonville, Fla.)"><span class="mark-date" style="width: 10%;text-align:right;">5/27/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7481168" target="_blank">(13) Gabija GALVYDYTE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oklahoma State" class="group-logo-inline" src="/images/logos/rankings-article/oklahoma-state.png" title="Oklahoma State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1170">Oklahoma State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938132" target="_blank">2:00.47</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7481168" target="_blank">(13) Gabija GALVYDYTE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oklahoma State" class="group-logo-inline" src="/images/logos/rankings-article/oklahoma-state.png" title="Oklahoma State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1170">Oklahoma State</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938132" target="_blank">2:00.47</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(14) Meredith RAINEY</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Harvard" class="group-logo-inline" src="/images/logos/rankings-article/harvard.png" title="Harvard"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=635">Harvard</a></td><td style="width: 25%;">2:00.48  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Durham, N.C.)"><span class="mark-date" style="width: 10%;text-align:right;">6/1/1990</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(14) Meredith RAINEY</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Harvard" class="group-logo-inline" src="/images/logos/rankings-article/harvard.png" title="Harvard"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=635">Harvard</a></td><td style="width: 25%;">2:00.48  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Durham, N.C.)"><span class="mark-date" style="width: 10%;text-align:right;">6/1/1990</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3272989" target="_blank">(15) Laura ROESLER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/33302" target="_blank">2:00.54</a> </td><td style="width: 10%;text-align:right;" title="Mt. SAC Relays (Walnut, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">4/19/2014</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3272989" target="_blank">(15) Laura ROESLER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/33302" target="_blank">2:00.54</a> </td><td style="width: 10%;text-align:right;" title="Mt. SAC Relays (Walnut, Calif.)"><span class="mark-date" style="width: 10%;text-align:right;">4/19/2014</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Seymour {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="BYU" class="group-logo-inline" src="/images/logos/rankings-article/byu.png" title="BYU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=190">BYU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938132" target="_blank">2:00.55</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Seymour {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="BYU" class="group-logo-inline" src="/images/logos/rankings-article/byu.png" title="BYU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=190">BYU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/81300/4938132" target="_blank">2:00.55</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Outdoor Championships (Austin, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">6/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Johnson {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="California" class="group-logo-inline" src="/images/logos/rankings-article/california.png" title="California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=211">California</a></td><td style="width: 25%;">2:00.57  </td><td style="width: 10%;text-align:right;" title="Pac-10 Championships (Tempe, Ariz.)"><span class="mark-date" style="width: 10%;text-align:right;">5/17/2008</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Johnson {2}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="California" class="group-logo-inline" src="/images/logos/rankings-article/california.png" title="California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=211">California</a></td><td style="width: 25%;">2:00.57  </td><td style="width: 10%;text-align:right;" title="Pac-10 Championships (Tempe, Ariz.)"><span class="mark-date" style="width: 10%;text-align:right;">5/17/2008</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5966783" target="_blank">(16) Sage HURTA</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Colorado" class="group-logo-inline" src="/images/logos/rankings-article/colorado.png" title="Colorado"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=335">Colorado</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68303/4170068" target="_blank">2:00.62</a> </td><td style="width: 10%;text-align:right;" title="GCU Antelope Invitational (Phoenix, Ariz.)"><span class="mark-date" style="width: 10%;text-align:right;">4/3/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
# ...
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113694" target="_blank">Raevyn ROGERS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">2:00.59</a> </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/4/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113694" target="_blank">Raevyn ROGERS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">2:00.59</a> </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/4/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113694" target="_blank">Raevyn ROGERS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">2:00.61</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/2/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5113694" target="_blank">Raevyn ROGERS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/46783" target="_blank">2:00.61</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">7/2/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5111599" target="_blank">Olivia BAKER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57132/3517316" target="_blank">2:00.63</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/22/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5111599" target="_blank">Olivia BAKER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1501">Stanford</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/57132/3517316" target="_blank">2:00.63</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="USATF Championships (Des Moines, Iowa)"><span class="mark-date" style="width: 10%;text-align:right;">6/22/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729637" target="_blank">Athing MU</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70481/4278422" target="_blank">2:00.69</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/24/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729637" target="_blank">Athing MU</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70481/4278422" target="_blank">2:00.69</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/24/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8239784" target="_blank">Juliette WHITTAKER</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1501">Stanford</a></td><td style="width: 25%;">2:00.74 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">7/6/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8239784" target="_blank">Juliette WHITTAKER</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Stanford" class="group-logo-inline" src="/images/logos/rankings-article/stanford.png" title="Stanford"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1501">Stanford</a></td><td style="width: 25%;">2:00.74 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">7/6/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7700503" target="_blank">Michaela MEYER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia" class="group-logo-inline" src="/images/logos/rankings-article/virginia.png" title="Virginia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1699">Virginia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70481/4278422" target="_blank">2:00.75</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/24/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7700503" target="_blank">Michaela MEYER</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Virginia" class="group-logo-inline" src="/images/logos/rankings-article/virginia.png" title="Virginia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=1699">Virginia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/70481/4278422" target="_blank">2:00.75</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="U.S. Olympic Trials - Track &amp; Field (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;">6/24/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7930954" target="_blank">Michaela ROSE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;">2:00.79 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">7/6/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7930954" target="_blank">Michaela ROSE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=2&amp;gender=2&amp;top=25&amp;event=6&amp;team=869">LSU</a></td><td style="width: 25%;">2:00.79 <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="USATF Championships (Eugene, Ore.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">7/6/2023</span></td></tr>,
#  <tr><td class="group-logo-50"><a href="https://www.flotrack.org/events/10268929-2023-aau-junior-olympic-games?utc_source=ustfccca&amp;utc_medium=web&amp;utc_campaign=broadcast_schedule_sidebar" target="_blank"><img alt="flotrack" src="/images/logos/rankings-article/flotrack.png" title="Flotrack"/></a></td><td style="line-height: 1em;"><a href="https://www.flotrack.org/events/10268929-2023-aau-junior-olympic-games?utc_source=ustfccca&amp;utc_medium=web&amp;utc_campaign=broadcast_schedule_sidebar" target="_blank">AAU Junior Olympics</a></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Athing MUFRTexas A&M1:57.73📺 4/16/2021',
#   '(1) Athing MUFR',
#   '',
#   'Texas A&M',
#   '1:57.73📺 ',
#   '4/16/2021'],
#  [],
#  ['(1) Athing MUFR', '', 'Texas A&M', '1:57.73📺 ', '4/16/2021'],
#  ['(2) Michaela ROSESOLSU1:59.08📺 4/13/2023',
#   '(2) Michaela ROSESO',
#   '',
#   'LSU',
#   '1:59.08📺 ',
#   '4/13/2023'],
#  [],
#  ['(2) Michaela ROSESO', '', 'LSU', '1:59.08📺 ', '4/13/2023'],
#  ['(3) Raevyn ROGERSJROregon1:59.10 4/15/2017',
#   '(3) Raevyn ROGERSJR',
#   '',
#   'Oregon',
#   '1:59.10 ',
#   '4/15/2017'],
#  [],
#  ['(3) Raevyn ROGERSJR', '', 'Oregon', '1:59.10 ', '4/15/2017'],
#  ['(4) Suzy FAVORSRWisconsin1:59.11  6/1/1990',
#   '(4) Suzy FAVORSR',
#   '',
#   'Wisconsin',
#   '1:59.11  ',
#   '6/1/1990'],
#  [],
#  ['(4) Suzy FAVORSR', '', 'Wisconsin', '1:59.11  ', '6/1/1990'],
#  ['(5) Alysia JOHNSONJRCalifornia1:59.29  6/9/2007',
#   '(5) Alysia JOHNSONJR',
#   '',
#   'California',
#   '1:59.29  ',
#   '6/9/2007'],
#  [],
#  ['(5) Alysia JOHNSONJR', '', 'California', '1:59.29  ', '6/9/2007'],
#  ['(6) Katie ERDMANMichigan1:59.35  6/9/2007',
#   '(6) Katie ERDMAN',
#   '',
#   'Michigan',
#   '1:59.35  ',
#   '6/9/2007'],
#  [],
#  ['(6) Katie ERDMAN', '', 'Michigan', '1:59.35  ', '6/9/2007'],
#  ['\xa0\xa0\xa0\xa0— Rogers {2}Oregon1:59.71 6/13/2015\xa0\xa0\xa0\xa0\xa057.79/61.92',
#   '\xa0\xa0\xa0\xa0— Rogers {2}',
#   '',
#   'Oregon',
#   '1:59.71 ',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa057.79/61.92'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rogers {2}', '', 'Oregon', '1:59.71 ', '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0\xa057.79/61.92'],
#  ['\xa0\xa0\xa0\xa0— Rose {2}SOLSU1:59.73 5/13/2023',
#   '\xa0\xa0\xa0\xa0— Rose {2}SO',
#   '',
#   'LSU',
#   '1:59.73 ',
#   '5/13/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rose {2}SO', '', 'LSU', '1:59.73 ', '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {3}SOLSU1:59.83 6/10/2023',
#   '\xa0\xa0\xa0\xa0— Rose {3}SO',
#   '',
#   'LSU',
#   '1:59.83 ',
#   '6/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rose {3}SO', '', 'LSU', '1:59.83 ', '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Rogers {3}JROregon2:00.02 6/10/2017\xa0\xa0\xa0\xa0\xa058.34/61.68',
#   '\xa0\xa0\xa0\xa0— Rogers {3}JR',
#   '',
#   'Oregon',
#   '2:00.02 ',
#   '6/10/2017',
#   '\xa0\xa0\xa0\xa0\xa058.34/61.68'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rogers {3}JR', '', 'Oregon', '2:00.02 ', '6/10/2017'],
#  ['\xa0\xa0\xa0\xa0\xa058.34/61.68'],
#  ['(7) Claire SEYMOURSRBYU2:00.04 4/13/2023',
#   '(7) Claire SEYMOURSR',
#   '',
#   'BYU',
#   '2:00.04 ',
#   '4/13/2023'],
#  [],
#  ['(7) Claire SEYMOURSR', '', 'BYU', '2:00.04 ', '4/13/2023'],
#  ['(8) Natoya GOULEJRLSU2:00.06 6/7/2013',
#   '(8) Natoya GOULEJR',
#   '',
#   'LSU',
#   '2:00.06 ',
#   '6/7/2013'],
#  [],
#  ['(8) Natoya GOULEJR', '', 'LSU', '2:00.06 ', '6/7/2013'],
#  ['(9) Jasmin JONESTennessee2:00.24  6/1/1990',
#   '(9) Jasmin JONES',
#   '',
#   'Tennessee',
#   '2:00.24  ',
#   '6/1/1990'],
#  [],
#  ['(9) Jasmin JONES', '', 'Tennessee', '2:00.24  ', '6/1/1990'],
#  ['(10) Inez TURNERSRTexas State2:00.27  6/2/1995',
#   '(10) Inez TURNERSR',
#   '',
#   'Texas State',
#   '2:00.27  ',
#   '6/2/1995'],
#  [],
#  ['(10) Inez TURNERSR', '', 'Texas State', '2:00.27  ', '6/2/1995'],
#  ['(11) Michaela MEYERSRVirginia2:00.28 6/12/2021',
#   '(11) Michaela MEYERSR',
#   '',
#   'Virginia',
#   '2:00.28 ',
#   '6/12/2021'],
#  [],
#  ['(11) Michaela MEYERSR', '', 'Virginia', '2:00.28 ', '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Rose {4}SOLSU2:00.31 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Rose {4}SO',
#   '',
#   'LSU',
#   '2:00.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rose {4}SO',
#   '',
#   'LSU',
#   '2:00.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(12) Valery TOBIASSRTexas2:00.31 4/13/2023',
#   '(12) Valery TOBIASSR',
#   '',
#   'Texas',
#   '2:00.31 ',
#   '4/13/2023'],
#  [],
#  ['(12) Valery TOBIASSR', '', 'Texas', '2:00.31 ', '4/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {5}SOLSU2:00.34 4/8/2023',
#   '\xa0\xa0\xa0\xa0— Rose {5}SO',
#   '',
#   'LSU',
#   '2:00.34 ',
#   '4/8/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rose {5}SO', '', 'LSU', '2:00.34 ', '4/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {6}SOLSU2:00.34 4/8/2023',
#   '\xa0\xa0\xa0\xa0— Rose {6}SO',
#   '',
#   'LSU',
#   '2:00.34 ',
#   '4/8/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rose {6}SO', '', 'LSU', '2:00.34 ', '4/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Meyer {2}SRVirginia2:00.40 qq = Performance occurred during a non-final round. 5/29/2021',
#   '\xa0\xa0\xa0\xa0— Meyer {2}SR',
#   '',
#   'Virginia',
#   '2:00.40 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Meyer {2}SR',
#   '',
#   'Virginia',
#   '2:00.40 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Meyer {3}SRVirginia2:00.40 qq = Performance occurred during a non-final round. 5/27/2021',
#   '\xa0\xa0\xa0\xa0— Meyer {3}SR',
#   '',
#   'Virginia',
#   '2:00.40 qq = Performance occurred during a non-final round. ',
#   '5/27/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Meyer {3}SR',
#   '',
#   'Virginia',
#   '2:00.40 qq = Performance occurred during a non-final round. ',
#   '5/27/2021'],
#  ['(13) Gabija GALVYDYTESOOklahoma State2:00.47 6/10/2023',
#   '(13) Gabija GALVYDYTESO',
#   '',
#   'Oklahoma State',
#   '2:00.47 ',
#   '6/10/2023'],
#  [],
#  ['(13) Gabija GALVYDYTESO', '', 'Oklahoma State', '2:00.47 ', '6/10/2023'],
#  ['(14) Meredith RAINEYHarvard2:00.48  6/1/1990',
#   '(14) Meredith RAINEY',
#   '',
#   'Harvard',
#   '2:00.48  ',
#   '6/1/1990'],
#  [],
#  ['(14) Meredith RAINEY', '', 'Harvard', '2:00.48  ', '6/1/1990'],
#  ['(15) Laura ROESLERSROregon2:00.54 4/19/2014',
#   '(15) Laura ROESLERSR',
#   '',
#   'Oregon',
#   '2:00.54 ',
#   '4/19/2014'],
#  [],
#  ['(15) Laura ROESLERSR', '', 'Oregon', '2:00.54 ', '4/19/2014'],
#  ['\xa0\xa0\xa0\xa0— Seymour {2}SRBYU2:00.55 6/10/2023',
#   '\xa0\xa0\xa0\xa0— Seymour {2}SR',
#   '',
#   'BYU',
#   '2:00.55 ',
#   '6/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Seymour {2}SR', '', 'BYU', '2:00.55 ', '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Johnson {2}California2:00.57  5/17/2008',
#   '\xa0\xa0\xa0\xa0— Johnson {2}',
#   '',
#   'California',
#   '2:00.57  ',
#   '5/17/2008'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Johnson {2}', '', 'California', '2:00.57  ', '5/17/2008'],
#  ['(16) Sage HURTASRColorado2:00.62 4/3/2021',
#   '(16) Sage HURTASR',
#   '',
#   'Colorado',
#   '2:00.62 ',
#   '4/3/2021'],
#  [],
#  ['(16) Sage HURTASR', '', 'Colorado', '2:00.62 ', '4/3/2021'],
#  ['(16) Emily RICHARDSJROhio Northern2:00.62  6/10/2017',
#   '(16) Emily RICHARDSJR',
#   '',
#   'Ohio Northern',
#   '2:00.62  ',
#   '6/10/2017'],
#  [],
#  ['(16) Emily RICHARDSJR', '', 'Ohio Northern', '2:00.62  ', '6/10/2017'],
#  ['(18) Claudia SAUNDERSStanford2:00.63 6/13/2015\xa0\xa0\xa0\xa0\xa058.27/62.36',
#   '(18) Claudia SAUNDERS',
#   '',
#   'Stanford',
#   '2:00.63 ',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa058.27/62.36'],
#  [],
#  ['(18) Claudia SAUNDERS', '', 'Stanford', '2:00.63 ', '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0\xa058.27/62.36'],
#  ['(19) Laurie BARTONJRClemson2:00.65 6/12/2021',
#   '(19) Laurie BARTONJR',
#   '',
#   'Clemson',
#   '2:00.65 ',
#   '6/12/2021'],
#  [],
#  ['(19) Laurie BARTONJR', '', 'Clemson', '2:00.65 ', '6/12/2021'],
#  ['(19) Trena HULLUNLV2:00.65  5/16/1987',
#   '(19) Trena HULL',
#   '',
#   'UNLV',
#   '2:00.65  ',
#   '5/16/1987'],
#  [],
#  ['(19) Trena HULL', '', 'UNLV', '2:00.65  ', '5/16/1987'],
#  ['\xa0\xa0\xa0\xa0— Richards {2}SROhio Northern2:00.67  6/2/2018\xa0\xa0\xa0\xa0\xa058.64/60.67',
#   '\xa0\xa0\xa0\xa0— Richards {2}SR',
#   '',
#   'Ohio Northern',
#   '2:00.67  ',
#   '6/2/2018',
#   '\xa0\xa0\xa0\xa0\xa058.64/60.67'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Richards {2}SR',
#   '',
#   'Ohio Northern',
#   '2:00.67  ',
#   '6/2/2018'],
#  ['\xa0\xa0\xa0\xa0\xa058.64/60.67'],
#  ['\xa0\xa0\xa0\xa0— Tobias {2}SRTexas2:00.68 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Tobias {2}SR',
#   '',
#   'Texas',
#   '2:00.68 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Tobias {2}SR',
#   '',
#   'Texas',
#   '2:00.68 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Barton {2}JRClemson2:00.70 5/13/2021',
#   '\xa0\xa0\xa0\xa0— Barton {2}JR',
#   '',
#   'Clemson',
#   '2:00.70 ',
#   '5/13/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Barton {2}JR', '', 'Clemson', '2:00.70 ', '5/13/2021'],
#  ['(21) Sabrina SOUTHERLANDSROregon2:00.72 qq = Performance occurred during a non-final round. 5/25/2018\xa0\xa0\xa0\xa0\xa058.34/62.39',
#   '(21) Sabrina SOUTHERLANDSR',
#   '',
#   'Oregon',
#   '2:00.72 qq = Performance occurred during a non-final round. ',
#   '5/25/2018',
#   '\xa0\xa0\xa0\xa0\xa058.34/62.39'],
#  [],
#  ['(21) Sabrina SOUTHERLANDSR',
#   '',
#   'Oregon',
#   '2:00.72 qq = Performance occurred during a non-final round. ',
#   '5/25/2018'],
#  ['\xa0\xa0\xa0\xa0\xa058.34/62.39'],
#  ['\xa0\xa0\xa0\xa0— Rogers {4}SOOregon2:00.75 6/11/2016\xa0\xa0\xa0\xa0\xa059.67/61.08: 28.60, 31.07, 31.44 [1:31.11], 29.64 (14.5)',
#   '\xa0\xa0\xa0\xa0— Rogers {4}SO',
#   '',
#   'Oregon',
#   '2:00.75 ',
#   '6/11/2016',
#   '\xa0\xa0\xa0\xa0\xa059.67/61.08: 28.60, 31.07, 31.44 [1:31.11], 29.64 (14.5)'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Rogers {4}SO', '', 'Oregon', '2:00.75 ', '6/11/2016'],
#  ['\xa0\xa0\xa0\xa0\xa059.67/61.08: 28.60, 31.07, 31.44 [1:31.11], 29.64 (14.5)'],
#  ['\xa0\xa0\xa0\xa0— Goule {2}JRLSU2:00.76 4/20/2013',
#   '\xa0\xa0\xa0\xa0— Goule {2}JR',
#   '',
#   'LSU',
#   '2:00.76 ',
#   '4/20/2013'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Goule {2}JR', '', 'LSU', '2:00.76 ', '4/20/2013'],
#  ['\xa0\xa0\xa0\xa0— Johnson {3}California2:00.77  5/31/2008',
#   '\xa0\xa0\xa0\xa0— Johnson {3}',
#   '',
#   'California',
#   '2:00.77  ',
#   '5/31/2008'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Johnson {3}', '', 'California', '2:00.77  ', '5/31/2008'],
#  ['(22) Geena GALLSRMichigan2:00.80  6/13/2009',
#   '(22) Geena GALLSR',
#   '',
#   'Michigan',
#   '2:00.80  ',
#   '6/13/2009'],
#  [],
#  ['(22) Geena GALLSR', '', 'Michigan', '2:00.80  ', '6/13/2009'],
#  ['\xa0\xa0\xa0\xa0— Seymour {3}SRBYU2:00.81  5/6/2023',
#   '\xa0\xa0\xa0\xa0— Seymour {3}SR',
#   '',
#   'BYU',
#   '2:00.81  ',
#   '5/6/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Seymour {3}SR', '', 'BYU', '2:00.81  ', '5/6/2023'],
#  ['(23) Karen BAKEWELLMiami (Ohio)2:00.85  6/6/1986',
#   '(23) Karen BAKEWELL',
#   '',
#   'Miami (Ohio)',
#   '2:00.85  ',
#   '6/6/1986'],
#  [],
#  ['(23) Karen BAKEWELL', '', 'Miami (Ohio)', '2:00.85  ', '6/6/1986'],
#  ['(24) Aaliyah MILLERJRBaylor2:00.87 4/16/2021',
#   '(24) Aaliyah MILLERJR',
#   '',
#   'Baylor',
#   '2:00.87 ',
#   '4/16/2021'],
#  [],
#  ['(24) Aaliyah MILLERJR', '', 'Baylor', '2:00.87 ', '4/16/2021'],
#  ['(24) Phoebe WRIGHTSRTennessee2:00.87 qq = Performance occurred during a non-final round. 5/28/2010',
#   '(24) Phoebe WRIGHTSR',
#   '',
#   'Tennessee',
#   '2:00.87 qq = Performance occurred during a non-final round. ',
#   '5/28/2010'],
#  [],
#  ['(24) Phoebe WRIGHTSR',
#   '',
#   'Tennessee',
#   '2:00.87 qq = Performance occurred during a non-final round. ',
#   '5/28/2010'],
#  ['Additional Out-of-Season Bests'],
#  ['Athing MUFRTexas A&M1:55.04📺 8/21/2021',
#   'Athing MUFR',
#   '',
#   'Texas A&M',
#   '1:55.04📺 ',
#   '8/21/2021'],
#  [],
#  ['Athing MUFR', '', 'Texas A&M', '1:55.04📺 ', '8/21/2021'],
#  ['Athing MUFRTexas A&M1:55.21📺 8/3/2021',
#   'Athing MUFR',
#   '',
#   'Texas A&M',
#   '1:55.21📺 ',
#   '8/3/2021'],
#  [],
#  ['Athing MUFR', '', 'Texas A&M', '1:55.21📺 ', '8/3/2021'],
#  ['Athing MUFRTexas A&M1:56.07📺 6/27/2021',
#   'Athing MUFR',
#   '',
#   'Texas A&M',
#   '1:56.07📺 ',
#   '6/27/2021'],
#  [],
#  ['Athing MUFR', '', 'Texas A&M', '1:56.07📺 ', '6/27/2021'],
#  ['Athing MUFRTexas A&M1:58.07 qq = Performance occurred during a non-final round. 7/31/2021',
#   'Athing MUFR',
#   '',
#   'Texas A&M',
#   '1:58.07 qq = Performance occurred during a non-final round. ',
#   '7/31/2021'],
#  [],
#  ['Athing MUFR',
#   '',
#   'Texas A&M',
#   '1:58.07 qq = Performance occurred during a non-final round. ',
#   '7/31/2021'],
#  ['Phoebe WRIGHTTennessee1:58.22  7/3/2010',
#   'Phoebe WRIGHT',
#   '',
#   'Tennessee',
#   '1:58.22  ',
#   '7/3/2010'],
#  [],
#  ['Phoebe WRIGHT', '', 'Tennessee', '1:58.22  ', '7/3/2010'],
#  ['Claudette GROENENDAALOregon1:58.33  8/16/1985',
#   'Claudette GROENENDAAL',
#   '',
#   'Oregon',
#   '1:58.33  ',
#   '8/16/1985'],
#  [],
#  ['Claudette GROENENDAAL', '', 'Oregon', '1:58.33  ', '8/16/1985'],
#  ['Brigita LANGERHOLCSouthern California1:58.51  9/25/2000',
#   'Brigita LANGERHOLC',
#   '',
#   'Southern California',
#   '1:58.51  ',
#   '9/25/2000'],
#  [],
#  ['Brigita LANGERHOLC', '', 'Southern California', '1:58.51  ', '9/25/2000'],
#  ['Michaela MEYERSRVirginia1:58.55 6/27/2021',
#   'Michaela MEYERSR',
#   '',
#   'Virginia',
#   '1:58.55 ',
#   '6/27/2021'],
#  [],
#  ['Michaela MEYERSR', '', 'Virginia', '1:58.55 ', '6/27/2021'],
#  ['Laura ROESLERSROregon1:59.04  6/29/2014',
#   'Laura ROESLERSR',
#   '',
#   'Oregon',
#   '1:59.04  ',
#   '6/29/2014'],
#  [],
#  ['Laura ROESLERSR', '', 'Oregon', '1:59.04  ', '6/29/2014'],
#  ['Dawn WILLIAMSArkansas State1:59.06  7/27/1996',
#   'Dawn WILLIAMS',
#   '',
#   'Arkansas State',
#   '1:59.06  ',
#   '7/27/1996'],
#  [],
#  ['Dawn WILLIAMS', '', 'Arkansas State', '1:59.06  ', '7/27/1996'],
#  ['Alysia MONTAÑOCalifornia1:59.08  6/25/2012',
#   'Alysia MONTAÑO',
#   '',
#   'California',
#   '1:59.08  ',
#   '6/25/2012'],
#  [],
#  ['Alysia MONTAÑO', '', 'California', '1:59.08  ', '6/25/2012'],
#  ['Athing MUFRTexas A&M1:59.31 qq = Performance occurred during a non-final round. 6/25/2021',
#   'Athing MUFR',
#   '',
#   'Texas A&M',
#   '1:59.31 qq = Performance occurred during a non-final round. ',
#   '6/25/2021'],
#  [],
#  ['Athing MUFR',
#   '',
#   'Texas A&M',
#   '1:59.31 qq = Performance occurred during a non-final round. ',
#   '6/25/2021'],
#  ['Amy WICKUSSRWisconsin1:59.42  7/25/1995',
#   'Amy WICKUSSR',
#   '',
#   'Wisconsin',
#   '1:59.42  ',
#   '7/25/1995'],
#  [],
#  ['Amy WICKUSSR', '', 'Wisconsin', '1:59.42  ', '7/25/1995'],
#  ['Laura ROESLERSROregon1:59.44  7/18/2014',
#   'Laura ROESLERSR',
#   '',
#   'Oregon',
#   '1:59.44  ',
#   '7/18/2014'],
#  [],
#  ['Laura ROESLERSR', '', 'Oregon', '1:59.44  ', '7/18/2014'],
#  ['Inez TURNERTexas State1:59.49  7/22/1995',
#   'Inez TURNER',
#   '',
#   'Texas State',
#   '1:59.49  ',
#   '7/22/1995'],
#  [],
#  ['Inez TURNER', '', 'Texas State', '1:59.49  ', '7/22/1995'],
#  ['Katya KOSTETSKAYATexas State1:59.52  8/14/2007',
#   'Katya KOSTETSKAYA',
#   '',
#   'Texas State',
#   '1:59.52  ',
#   '8/14/2007'],
#  [],
#  ['Katya KOSTETSKAYA', '', 'Texas State', '1:59.52  ', '8/14/2007'],
#  ['Natoya GOULESRClemson1:59.63  6/27/2015',
#   'Natoya GOULESR',
#   '',
#   'Clemson',
#   '1:59.63  ',
#   '6/27/2015'],
#  [],
#  ['Natoya GOULESR', '', 'Clemson', '1:59.63  ', '6/27/2015'],
#  ['Leann WARRENOregon1:59.63  7/25/1981',
#   'Leann WARREN',
#   '',
#   'Oregon',
#   '1:59.63  ',
#   '7/25/1981'],
#  [],
#  ['Leann WARREN', '', 'Oregon', '1:59.63  ', '7/25/1981'],
#  ['Meredith RAINEYHarvard1:59.73  8/15/1990',
#   'Meredith RAINEY',
#   '',
#   'Harvard',
#   '1:59.73  ',
#   '8/15/1990'],
#  [],
#  ['Meredith RAINEY', '', 'Harvard', '1:59.73  ', '8/15/1990'],
#  ['Kristie SCHOFFIELDSRBoise State1:59.80  6/26/2022',
#   'Kristie SCHOFFIELDSR',
#   '',
#   'Boise State',
#   '1:59.80  ',
#   '6/26/2022'],
#  [],
#  ['Kristie SCHOFFIELDSR', '', 'Boise State', '1:59.80  ', '6/26/2022'],
#  ['Molly LUDLOWIndiana1:59.83  7/18/2010',
#   'Molly LUDLOW',
#   '',
#   'Indiana',
#   '1:59.83  ',
#   '7/18/2010'],
#  [],
#  ['Molly LUDLOW', '', 'Indiana', '1:59.83  ', '7/18/2010'],
#  ['Wendy KNUDSONColorado State1:59.91  7/23/1976',
#   'Wendy KNUDSON',
#   '',
#   'Colorado State',
#   '1:59.91  ',
#   '7/23/1976'],
#  [],
#  ['Wendy KNUDSON', '', 'Colorado State', '1:59.91  ', '7/23/1976'],
#  ['Natoya GOULEJRLSU1:59.93  6/23/2013',
#   'Natoya GOULEJR',
#   '',
#   'LSU',
#   '1:59.93  ',
#   '6/23/2013'],
#  [],
#  ['Natoya GOULEJR', '', 'LSU', '1:59.93  ', '6/23/2013'],
#  ['Carley THOMASJRWashington1:59.95  7/14/2023',
#   'Carley THOMASJR',
#   '',
#   'Washington',
#   '1:59.95  ',
#   '7/14/2023'],
#  [],
#  ['Carley THOMASJR', '', 'Washington', '1:59.95  ', '7/14/2023'],
#  ['Sage HURTASRColorado2:00.08 qq = Performance occurred during a non-final round. 6/24/2021',
#   'Sage HURTASR',
#   '',
#   'Colorado',
#   '2:00.08 qq = Performance occurred during a non-final round. ',
#   '6/24/2021'],
#  [],
#  ['Sage HURTASR',
#   '',
#   'Colorado',
#   '2:00.08 qq = Performance occurred during a non-final round. ',
#   '6/24/2021'],
#  ['Olivia BAKERSRStanford2:00.08 6/24/2018',
#   'Olivia BAKERSR',
#   '',
#   'Stanford',
#   '2:00.08 ',
#   '6/24/2018'],
#  [],
#  ['Olivia BAKERSR', '', 'Stanford', '2:00.08 ', '6/24/2018'],
#  ['Chanelle PRICETennessee2:00.15  7/21/2012',
#   'Chanelle PRICE',
#   '',
#   'Tennessee',
#   '2:00.15  ',
#   '7/21/2012'],
#  [],
#  ['Chanelle PRICE', '', 'Tennessee', '2:00.15  ', '7/21/2012'],
#  ['Raevyn ROGERSJROregon2:00.18 6/25/2017\xa0\xa0\xa0\xa0\xa059.69/60.50',
#   'Raevyn ROGERSJR',
#   '',
#   'Oregon',
#   '2:00.18 ',
#   '6/25/2017',
#   '\xa0\xa0\xa0\xa0\xa059.69/60.50'],
#  [],
#  ['Raevyn ROGERSJR', '', 'Oregon', '2:00.18 ', '6/25/2017'],
#  ['\xa0\xa0\xa0\xa0\xa059.69/60.50'],
#  ['Roisin WILLISFRStanford2:00.23 qq = Performance occurred during a non-final round. 7/6/2023',
#   'Roisin WILLISFR',
#   '',
#   'Stanford',
#   '2:00.23 qq = Performance occurred during a non-final round. ',
#   '7/6/2023'],
#  [],
#  ['Roisin WILLISFR',
#   '',
#   'Stanford',
#   '2:00.23 qq = Performance occurred during a non-final round. ',
#   '7/6/2023'],
#  ['Laura ROESLERJROregon2:00.23  6/23/2013',
#   'Laura ROESLERJR',
#   '',
#   'Oregon',
#   '2:00.23  ',
#   '6/23/2013'],
#  [],
#  ['Laura ROESLERJR', '', 'Oregon', '2:00.23  ', '6/23/2013'],
#  ['Hazel CLARKFlorida2:00.23  6/21/1998',
#   'Hazel CLARK',
#   '',
#   'Florida',
#   '2:00.23  ',
#   '6/21/1998'],
#  [],
#  ['Hazel CLARK', '', 'Florida', '2:00.23  ', '6/21/1998'],
#  ['Gabija GALVYDYTESOOklahoma State2:00.29  6/21/2023',
#   'Gabija GALVYDYTESO',
#   '',
#   'Oklahoma State',
#   '2:00.29  ',
#   '6/21/2023'],
#  [],
#  ['Gabija GALVYDYTESO', '', 'Oklahoma State', '2:00.29  ', '6/21/2023'],
#  ['Michaela ROSESOLSU2:00.39 qq = Performance occurred during a non-final round. 7/7/2023',
#   'Michaela ROSESO',
#   '',
#   'LSU',
#   '2:00.39 qq = Performance occurred during a non-final round. ',
#   '7/7/2023'],
#  [],
#  ['Michaela ROSESO',
#   '',
#   'LSU',
#   '2:00.39 qq = Performance occurred during a non-final round. ',
#   '7/7/2023'],
#  ['Sinclaire JOHNSONJROklahoma State2:00.43  7/9/2019',
#   'Sinclaire JOHNSONJR',
#   '',
#   'Oklahoma State',
#   '2:00.43  ',
#   '7/9/2019'],
#  [],
#  ['Sinclaire JOHNSONJR', '', 'Oklahoma State', '2:00.43  ', '7/9/2019'],
#  ['Raevyn ROGERSSOOregon2:00.59 7/4/2016',
#   'Raevyn ROGERSSO',
#   '',
#   'Oregon',
#   '2:00.59 ',
#   '7/4/2016'],
#  [],
#  ['Raevyn ROGERSSO', '', 'Oregon', '2:00.59 ', '7/4/2016'],
#  ['Raevyn ROGERSSOOregon2:00.61 qq = Performance occurred during a non-final round. 7/2/2016',
#   'Raevyn ROGERSSO',
#   '',
#   'Oregon',
#   '2:00.61 qq = Performance occurred during a non-final round. ',
#   '7/2/2016'],
#  [],
#  ['Raevyn ROGERSSO',
#   '',
#   'Oregon',
#   '2:00.61 qq = Performance occurred during a non-final round. ',
#   '7/2/2016'],
#  ['Olivia BAKERSRStanford2:00.63 qq = Performance occurred during a non-final round. 6/22/2018',
#   'Olivia BAKERSR',
#   '',
#   'Stanford',
#   '2:00.63 qq = Performance occurred during a non-final round. ',
#   '6/22/2018'],
#  [],
#  ['Olivia BAKERSR',
#   '',
#   'Stanford',
#   '2:00.63 qq = Performance occurred during a non-final round. ',
#   '6/22/2018'],
#  ['Athing MUFRTexas A&M2:00.69 qq = Performance occurred during a non-final round. 6/24/2021',
#   'Athing MUFR',
#   '',
#   'Texas A&M',
#   '2:00.69 qq = Performance occurred during a non-final round. ',
#   '6/24/2021'],
#  [],
#  ['Athing MUFR',
#   '',
#   'Texas A&M',
#   '2:00.69 qq = Performance occurred during a non-final round. ',
#   '6/24/2021'],
#  ['Juliette WHITTAKERFRStanford2:00.74 qq = Performance occurred during a non-final round. 7/6/2023',
#   'Juliette WHITTAKERFR',
#   '',
#   'Stanford',
#   '2:00.74 qq = Performance occurred during a non-final round. ',
#   '7/6/2023'],
#  [],
#  ['Juliette WHITTAKERFR',
#   '',
#   'Stanford',
#   '2:00.74 qq = Performance occurred during a non-final round. ',
#   '7/6/2023'],
#  ['Michaela MEYERSRVirginia2:00.75 qq = Performance occurred during a non-final round. 6/24/2021',
#   'Michaela MEYERSR',
#   '',
#   'Virginia',
#   '2:00.75 qq = Performance occurred during a non-final round. ',
#   '6/24/2021'],
#  [],
#  ['Michaela MEYERSR',
#   '',
#   'Virginia',
#   '2:00.75 qq = Performance occurred during a non-final round. ',
#   '6/24/2021'],
#  ['Michaela ROSESOLSU2:00.79 qq = Performance occurred during a non-final round. 7/6/2023',
#   'Michaela ROSESO',
#   '',
#   'LSU',
#   '2:00.79 qq = Performance occurred during a non-final round. ',
#   '7/6/2023'],
#  [],
#  ['Michaela ROSESO',
#   '',
#   'LSU',
#   '2:00.79 qq = Performance occurred during a non-final round. ',
#   '7/6/2023'],
#  ['', 'AAU Junior Olympics'],
#  ['', '', '', '']]

# %%
rows[136]
# Out:
# ['(24) Phoebe WRIGHTSR',
#  '',
#  'Tennessee',
#  '2:00.87 qq = Performance occurred during a non-final round. ',
#  '5/28/2010']

# %%
len(rows)
# Out:
# 264

# %%
RealRows = []

# %%
for i in range(0,137):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [['(1) Athing MUFRTexas A&M1:57.73📺 4/16/2021',
#   '(1) Athing MUFR',
#   '',
#   'Texas A&M',
#   '1:57.73📺 ',
#   '4/16/2021'],
#  ['(1) Athing MUFR', '', 'Texas A&M', '1:57.73📺 ', '4/16/2021'],
#  ['(2) Michaela ROSESOLSU1:59.08📺 4/13/2023',
#   '(2) Michaela ROSESO',
#   '',
#   'LSU',
#   '1:59.08📺 ',
#   '4/13/2023'],
#  ['(2) Michaela ROSESO', '', 'LSU', '1:59.08📺 ', '4/13/2023'],
#  ['(3) Raevyn ROGERSJROregon1:59.10 4/15/2017',
#   '(3) Raevyn ROGERSJR',
#   '',
#   'Oregon',
#   '1:59.10 ',
#   '4/15/2017'],
#  ['(3) Raevyn ROGERSJR', '', 'Oregon', '1:59.10 ', '4/15/2017'],
#  ['(4) Suzy FAVORSRWisconsin1:59.11  6/1/1990',
#   '(4) Suzy FAVORSR',
#   '',
#   'Wisconsin',
#   '1:59.11  ',
#   '6/1/1990'],
#  ['(4) Suzy FAVORSR', '', 'Wisconsin', '1:59.11  ', '6/1/1990'],
#  ['(5) Alysia JOHNSONJRCalifornia1:59.29  6/9/2007',
#   '(5) Alysia JOHNSONJR',
#   '',
#   'California',
#   '1:59.29  ',
#   '6/9/2007'],
#  ['(5) Alysia JOHNSONJR', '', 'California', '1:59.29  ', '6/9/2007'],
#  ['(6) Katie ERDMANMichigan1:59.35  6/9/2007',
#   '(6) Katie ERDMAN',
#   '',
#   'Michigan',
#   '1:59.35  ',
#   '6/9/2007'],
#  ['(6) Katie ERDMAN', '', 'Michigan', '1:59.35  ', '6/9/2007'],
#  ['\xa0\xa0\xa0\xa0— Rogers {2}Oregon1:59.71 6/13/2015\xa0\xa0\xa0\xa0\xa057.79/61.92',
#   '\xa0\xa0\xa0\xa0— Rogers {2}',
#   '',
#   'Oregon',
#   '1:59.71 ',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa057.79/61.92'],
#  ['\xa0\xa0\xa0\xa0— Rogers {2}', '', 'Oregon', '1:59.71 ', '6/13/2015'],
#  ['\xa0\xa0\xa0\xa0— Rose {2}SOLSU1:59.73 5/13/2023',
#   '\xa0\xa0\xa0\xa0— Rose {2}SO',
#   '',
#   'LSU',
#   '1:59.73 ',
#   '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {2}SO', '', 'LSU', '1:59.73 ', '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {3}SOLSU1:59.83 6/10/2023',
#   '\xa0\xa0\xa0\xa0— Rose {3}SO',
#   '',
#   'LSU',
#   '1:59.83 ',
#   '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {3}SO', '', 'LSU', '1:59.83 ', '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Rogers {3}JROregon2:00.02 6/10/2017\xa0\xa0\xa0\xa0\xa058.34/61.68',
#   '\xa0\xa0\xa0\xa0— Rogers {3}JR',
#   '',
#   'Oregon',
#   '2:00.02 ',
#   '6/10/2017',
#   '\xa0\xa0\xa0\xa0\xa058.34/61.68'],
#  ['\xa0\xa0\xa0\xa0— Rogers {3}JR', '', 'Oregon', '2:00.02 ', '6/10/2017'],
#  ['(7) Claire SEYMOURSRBYU2:00.04 4/13/2023',
#   '(7) Claire SEYMOURSR',
#   '',
#   'BYU',
#   '2:00.04 ',
#   '4/13/2023'],
#  ['(7) Claire SEYMOURSR', '', 'BYU', '2:00.04 ', '4/13/2023'],
#  ['(8) Natoya GOULEJRLSU2:00.06 6/7/2013',
#   '(8) Natoya GOULEJR',
#   '',
#   'LSU',
#   '2:00.06 ',
#   '6/7/2013'],
#  ['(8) Natoya GOULEJR', '', 'LSU', '2:00.06 ', '6/7/2013'],
#  ['(9) Jasmin JONESTennessee2:00.24  6/1/1990',
#   '(9) Jasmin JONES',
#   '',
#   'Tennessee',
#   '2:00.24  ',
#   '6/1/1990'],
#  ['(9) Jasmin JONES', '', 'Tennessee', '2:00.24  ', '6/1/1990'],
#  ['(10) Inez TURNERSRTexas State2:00.27  6/2/1995',
#   '(10) Inez TURNERSR',
#   '',
#   'Texas State',
#   '2:00.27  ',
#   '6/2/1995'],
#  ['(10) Inez TURNERSR', '', 'Texas State', '2:00.27  ', '6/2/1995'],
#  ['(11) Michaela MEYERSRVirginia2:00.28 6/12/2021',
#   '(11) Michaela MEYERSR',
#   '',
#   'Virginia',
#   '2:00.28 ',
#   '6/12/2021'],
#  ['(11) Michaela MEYERSR', '', 'Virginia', '2:00.28 ', '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Rose {4}SOLSU2:00.31 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Rose {4}SO',
#   '',
#   'LSU',
#   '2:00.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {4}SO',
#   '',
#   'LSU',
#   '2:00.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(12) Valery TOBIASSRTexas2:00.31 4/13/2023',
#   '(12) Valery TOBIASSR',
#   '',
#   'Texas',
#   '2:00.31 ',
#   '4/13/2023'],
#  ['(12) Valery TOBIASSR', '', 'Texas', '2:00.31 ', '4/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {5}SOLSU2:00.34 4/8/2023',
#   '\xa0\xa0\xa0\xa0— Rose {5}SO',
#   '',
#   'LSU',
#   '2:00.34 ',
#   '4/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {5}SO', '', 'LSU', '2:00.34 ', '4/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {6}SOLSU2:00.34 4/8/2023',
#   '\xa0\xa0\xa0\xa0— Rose {6}SO',
#   '',
#   'LSU',
#   '2:00.34 ',
#   '4/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {6}SO', '', 'LSU', '2:00.34 ', '4/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Meyer {2}SRVirginia2:00.40 qq = Performance occurred during a non-final round. 5/29/2021',
#   '\xa0\xa0\xa0\xa0— Meyer {2}SR',
#   '',
#   'Virginia',
#   '2:00.40 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Meyer {2}SR',
#   '',
#   'Virginia',
#   '2:00.40 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Meyer {3}SRVirginia2:00.40 qq = Performance occurred during a non-final round. 5/27/2021',
#   '\xa0\xa0\xa0\xa0— Meyer {3}SR',
#   '',
#   'Virginia',
#   '2:00.40 qq = Performance occurred during a non-final round. ',
#   '5/27/2021'],
#  ['\xa0\xa0\xa0\xa0— Meyer {3}SR',
#   '',
#   'Virginia',
#   '2:00.40 qq = Performance occurred during a non-final round. ',
#   '5/27/2021'],
#  ['(13) Gabija GALVYDYTESOOklahoma State2:00.47 6/10/2023',
#   '(13) Gabija GALVYDYTESO',
#   '',
#   'Oklahoma State',
#   '2:00.47 ',
#   '6/10/2023'],
#  ['(13) Gabija GALVYDYTESO', '', 'Oklahoma State', '2:00.47 ', '6/10/2023'],
#  ['(14) Meredith RAINEYHarvard2:00.48  6/1/1990',
#   '(14) Meredith RAINEY',
#   '',
#   'Harvard',
#   '2:00.48  ',
#   '6/1/1990'],
#  ['(14) Meredith RAINEY', '', 'Harvard', '2:00.48  ', '6/1/1990'],
#  ['(15) Laura ROESLERSROregon2:00.54 4/19/2014',
#   '(15) Laura ROESLERSR',
#   '',
#   'Oregon',
#   '2:00.54 ',
#   '4/19/2014'],
#  ['(15) Laura ROESLERSR', '', 'Oregon', '2:00.54 ', '4/19/2014'],
#  ['\xa0\xa0\xa0\xa0— Seymour {2}SRBYU2:00.55 6/10/2023',
#   '\xa0\xa0\xa0\xa0— Seymour {2}SR',
#   '',
#   'BYU',
#   '2:00.55 ',
#   '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Seymour {2}SR', '', 'BYU', '2:00.55 ', '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Johnson {2}California2:00.57  5/17/2008',
#   '\xa0\xa0\xa0\xa0— Johnson {2}',
#   '',
#   'California',
#   '2:00.57  ',
#   '5/17/2008'],
#  ['\xa0\xa0\xa0\xa0— Johnson {2}', '', 'California', '2:00.57  ', '5/17/2008'],
#  ['(16) Sage HURTASRColorado2:00.62 4/3/2021',
#   '(16) Sage HURTASR',
#   '',
#   'Colorado',
#   '2:00.62 ',
#   '4/3/2021'],
#  ['(16) Sage HURTASR', '', 'Colorado', '2:00.62 ', '4/3/2021'],
#  ['(16) Emily RICHARDSJROhio Northern2:00.62  6/10/2017',
#   '(16) Emily RICHARDSJR',
#   '',
#   'Ohio Northern',
#   '2:00.62  ',
#   '6/10/2017'],
#  ['(16) Emily RICHARDSJR', '', 'Ohio Northern', '2:00.62  ', '6/10/2017'],
#  ['(18) Claudia SAUNDERSStanford2:00.63 6/13/2015\xa0\xa0\xa0\xa0\xa058.27/62.36',
#   '(18) Claudia SAUNDERS',
#   '',
#   'Stanford',
#   '2:00.63 ',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa058.27/62.36'],
#  ['(18) Claudia SAUNDERS', '', 'Stanford', '2:00.63 ', '6/13/2015'],
#  ['(19) Laurie BARTONJRClemson2:00.65 6/12/2021',
#   '(19) Laurie BARTONJR',
#   '',
#   'Clemson',
#   '2:00.65 ',
#   '6/12/2021'],
#  ['(19) Laurie BARTONJR', '', 'Clemson', '2:00.65 ', '6/12/2021'],
#  ['(19) Trena HULLUNLV2:00.65  5/16/1987',
#   '(19) Trena HULL',
#   '',
#   'UNLV',
#   '2:00.65  ',
#   '5/16/1987'],
#  ['(19) Trena HULL', '', 'UNLV', '2:00.65  ', '5/16/1987'],
#  ['\xa0\xa0\xa0\xa0— Richards {2}SROhio Northern2:00.67  6/2/2018\xa0\xa0\xa0\xa0\xa058.64/60.67',
#   '\xa0\xa0\xa0\xa0— Richards {2}SR',
#   '',
#   'Ohio Northern',
#   '2:00.67  ',
#   '6/2/2018',
#   '\xa0\xa0\xa0\xa0\xa058.64/60.67'],
#  ['\xa0\xa0\xa0\xa0— Richards {2}SR',
#   '',
#   'Ohio Northern',
#   '2:00.67  ',
#   '6/2/2018'],
#  ['\xa0\xa0\xa0\xa0— Tobias {2}SRTexas2:00.68 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Tobias {2}SR',
#   '',
#   'Texas',
#   '2:00.68 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Tobias {2}SR',
#   '',
#   'Texas',
#   '2:00.68 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Barton {2}JRClemson2:00.70 5/13/2021',
#   '\xa0\xa0\xa0\xa0— Barton {2}JR',
#   '',
#   'Clemson',
#   '2:00.70 ',
#   '5/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Barton {2}JR', '', 'Clemson', '2:00.70 ', '5/13/2021'],
#  ['(21) Sabrina SOUTHERLANDSROregon2:00.72 qq = Performance occurred during a non-final round. 5/25/2018\xa0\xa0\xa0\xa0\xa058.34/62.39',
#   '(21) Sabrina SOUTHERLANDSR',
#   '',
#   'Oregon',
#   '2:00.72 qq = Performance occurred during a non-final round. ',
#   '5/25/2018',
#   '\xa0\xa0\xa0\xa0\xa058.34/62.39'],
#  ['(21) Sabrina SOUTHERLANDSR',
#   '',
#   'Oregon',
#   '2:00.72 qq = Performance occurred during a non-final round. ',
#   '5/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Rogers {4}SOOregon2:00.75 6/11/2016\xa0\xa0\xa0\xa0\xa059.67/61.08: 28.60, 31.07, 31.44 [1:31.11], 29.64 (14.5)',
#   '\xa0\xa0\xa0\xa0— Rogers {4}SO',
#   '',
#   'Oregon',
#   '2:00.75 ',
#   '6/11/2016',
#   '\xa0\xa0\xa0\xa0\xa059.67/61.08: 28.60, 31.07, 31.44 [1:31.11], 29.64 (14.5)'],
#  ['\xa0\xa0\xa0\xa0— Rogers {4}SO', '', 'Oregon', '2:00.75 ', '6/11/2016'],
#  ['\xa0\xa0\xa0\xa0— Goule {2}JRLSU2:00.76 4/20/2013',
#   '\xa0\xa0\xa0\xa0— Goule {2}JR',
#   '',
#   'LSU',
#   '2:00.76 ',
#   '4/20/2013'],
#  ['\xa0\xa0\xa0\xa0— Goule {2}JR', '', 'LSU', '2:00.76 ', '4/20/2013'],
#  ['\xa0\xa0\xa0\xa0— Johnson {3}California2:00.77  5/31/2008',
#   '\xa0\xa0\xa0\xa0— Johnson {3}',
#   '',
#   'California',
#   '2:00.77  ',
#   '5/31/2008'],
#  ['\xa0\xa0\xa0\xa0— Johnson {3}', '', 'California', '2:00.77  ', '5/31/2008'],
#  ['(22) Geena GALLSRMichigan2:00.80  6/13/2009',
#   '(22) Geena GALLSR',
#   '',
#   'Michigan',
#   '2:00.80  ',
#   '6/13/2009'],
#  ['(22) Geena GALLSR', '', 'Michigan', '2:00.80  ', '6/13/2009'],
#  ['\xa0\xa0\xa0\xa0— Seymour {3}SRBYU2:00.81  5/6/2023',
#   '\xa0\xa0\xa0\xa0— Seymour {3}SR',
#   '',
#   'BYU',
#   '2:00.81  ',
#   '5/6/2023'],
#  ['\xa0\xa0\xa0\xa0— Seymour {3}SR', '', 'BYU', '2:00.81  ', '5/6/2023'],
#  ['(23) Karen BAKEWELLMiami (Ohio)2:00.85  6/6/1986',
#   '(23) Karen BAKEWELL',
#   '',
#   'Miami (Ohio)',
#   '2:00.85  ',
#   '6/6/1986'],
#  ['(23) Karen BAKEWELL', '', 'Miami (Ohio)', '2:00.85  ', '6/6/1986'],
#  ['(24) Aaliyah MILLERJRBaylor2:00.87 4/16/2021',
#   '(24) Aaliyah MILLERJR',
#   '',
#   'Baylor',
#   '2:00.87 ',
#   '4/16/2021'],
#  ['(24) Aaliyah MILLERJR', '', 'Baylor', '2:00.87 ', '4/16/2021'],
#  ['(24) Phoebe WRIGHTSRTennessee2:00.87 qq = Performance occurred during a non-final round. 5/28/2010',
#   '(24) Phoebe WRIGHTSR',
#   '',
#   'Tennessee',
#   '2:00.87 qq = Performance occurred during a non-final round. ',
#   '5/28/2010'],
#  ['(24) Phoebe WRIGHTSR',
#   '',
#   'Tennessee',
#   '2:00.87 qq = Performance occurred during a non-final round. ',
#   '5/28/2010']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Athing MUFRTexas A&M1:57.73📺 4/16/2021',
#   '(1) Athing MUFR',
#   '',
#   'Texas A&M',
#   '1:57.73📺 ',
#   '4/16/2021'],
#  ['(2) Michaela ROSESOLSU1:59.08📺 4/13/2023',
#   '(2) Michaela ROSESO',
#   '',
#   'LSU',
#   '1:59.08📺 ',
#   '4/13/2023'],
#  ['(3) Raevyn ROGERSJROregon1:59.10 4/15/2017',
#   '(3) Raevyn ROGERSJR',
#   '',
#   'Oregon',
#   '1:59.10 ',
#   '4/15/2017'],
#  ['(4) Suzy FAVORSRWisconsin1:59.11  6/1/1990',
#   '(4) Suzy FAVORSR',
#   '',
#   'Wisconsin',
#   '1:59.11  ',
#   '6/1/1990'],
#  ['(5) Alysia JOHNSONJRCalifornia1:59.29  6/9/2007',
#   '(5) Alysia JOHNSONJR',
#   '',
#   'California',
#   '1:59.29  ',
#   '6/9/2007'],
#  ['(6) Katie ERDMANMichigan1:59.35  6/9/2007',
#   '(6) Katie ERDMAN',
#   '',
#   'Michigan',
#   '1:59.35  ',
#   '6/9/2007'],
#  ['\xa0\xa0\xa0\xa0— Rogers {2}Oregon1:59.71 6/13/2015\xa0\xa0\xa0\xa0\xa057.79/61.92',
#   '\xa0\xa0\xa0\xa0— Rogers {2}',
#   '',
#   'Oregon',
#   '1:59.71 ',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa057.79/61.92'],
#  ['\xa0\xa0\xa0\xa0— Rose {2}SOLSU1:59.73 5/13/2023',
#   '\xa0\xa0\xa0\xa0— Rose {2}SO',
#   '',
#   'LSU',
#   '1:59.73 ',
#   '5/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {3}SOLSU1:59.83 6/10/2023',
#   '\xa0\xa0\xa0\xa0— Rose {3}SO',
#   '',
#   'LSU',
#   '1:59.83 ',
#   '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Rogers {3}JROregon2:00.02 6/10/2017\xa0\xa0\xa0\xa0\xa058.34/61.68',
#   '\xa0\xa0\xa0\xa0— Rogers {3}JR',
#   '',
#   'Oregon',
#   '2:00.02 ',
#   '6/10/2017',
#   '\xa0\xa0\xa0\xa0\xa058.34/61.68'],
#  ['(7) Claire SEYMOURSRBYU2:00.04 4/13/2023',
#   '(7) Claire SEYMOURSR',
#   '',
#   'BYU',
#   '2:00.04 ',
#   '4/13/2023'],
#  ['(8) Natoya GOULEJRLSU2:00.06 6/7/2013',
#   '(8) Natoya GOULEJR',
#   '',
#   'LSU',
#   '2:00.06 ',
#   '6/7/2013'],
#  ['(9) Jasmin JONESTennessee2:00.24  6/1/1990',
#   '(9) Jasmin JONES',
#   '',
#   'Tennessee',
#   '2:00.24  ',
#   '6/1/1990'],
#  ['(10) Inez TURNERSRTexas State2:00.27  6/2/1995',
#   '(10) Inez TURNERSR',
#   '',
#   'Texas State',
#   '2:00.27  ',
#   '6/2/1995'],
#  ['(11) Michaela MEYERSRVirginia2:00.28 6/12/2021',
#   '(11) Michaela MEYERSR',
#   '',
#   'Virginia',
#   '2:00.28 ',
#   '6/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Rose {4}SOLSU2:00.31 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Rose {4}SO',
#   '',
#   'LSU',
#   '2:00.31 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['(12) Valery TOBIASSRTexas2:00.31 4/13/2023',
#   '(12) Valery TOBIASSR',
#   '',
#   'Texas',
#   '2:00.31 ',
#   '4/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {5}SOLSU2:00.34 4/8/2023',
#   '\xa0\xa0\xa0\xa0— Rose {5}SO',
#   '',
#   'LSU',
#   '2:00.34 ',
#   '4/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Rose {6}SOLSU2:00.34 4/8/2023',
#   '\xa0\xa0\xa0\xa0— Rose {6}SO',
#   '',
#   'LSU',
#   '2:00.34 ',
#   '4/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Meyer {2}SRVirginia2:00.40 qq = Performance occurred during a non-final round. 5/29/2021',
#   '\xa0\xa0\xa0\xa0— Meyer {2}SR',
#   '',
#   'Virginia',
#   '2:00.40 qq = Performance occurred during a non-final round. ',
#   '5/29/2021'],
#  ['\xa0\xa0\xa0\xa0— Meyer {3}SRVirginia2:00.40 qq = Performance occurred during a non-final round. 5/27/2021',
#   '\xa0\xa0\xa0\xa0— Meyer {3}SR',
#   '',
#   'Virginia',
#   '2:00.40 qq = Performance occurred during a non-final round. ',
#   '5/27/2021'],
#  ['(13) Gabija GALVYDYTESOOklahoma State2:00.47 6/10/2023',
#   '(13) Gabija GALVYDYTESO',
#   '',
#   'Oklahoma State',
#   '2:00.47 ',
#   '6/10/2023'],
#  ['(14) Meredith RAINEYHarvard2:00.48  6/1/1990',
#   '(14) Meredith RAINEY',
#   '',
#   'Harvard',
#   '2:00.48  ',
#   '6/1/1990'],
#  ['(15) Laura ROESLERSROregon2:00.54 4/19/2014',
#   '(15) Laura ROESLERSR',
#   '',
#   'Oregon',
#   '2:00.54 ',
#   '4/19/2014'],
#  ['\xa0\xa0\xa0\xa0— Seymour {2}SRBYU2:00.55 6/10/2023',
#   '\xa0\xa0\xa0\xa0— Seymour {2}SR',
#   '',
#   'BYU',
#   '2:00.55 ',
#   '6/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Johnson {2}California2:00.57  5/17/2008',
#   '\xa0\xa0\xa0\xa0— Johnson {2}',
#   '',
#   'California',
#   '2:00.57  ',
#   '5/17/2008'],
#  ['(16) Sage HURTASRColorado2:00.62 4/3/2021',
#   '(16) Sage HURTASR',
#   '',
#   'Colorado',
#   '2:00.62 ',
#   '4/3/2021'],
#  ['(16) Emily RICHARDSJROhio Northern2:00.62  6/10/2017',
#   '(16) Emily RICHARDSJR',
#   '',
#   'Ohio Northern',
#   '2:00.62  ',
#   '6/10/2017'],
#  ['(18) Claudia SAUNDERSStanford2:00.63 6/13/2015\xa0\xa0\xa0\xa0\xa058.27/62.36',
#   '(18) Claudia SAUNDERS',
#   '',
#   'Stanford',
#   '2:00.63 ',
#   '6/13/2015',
#   '\xa0\xa0\xa0\xa0\xa058.27/62.36'],
#  ['(19) Laurie BARTONJRClemson2:00.65 6/12/2021',
#   '(19) Laurie BARTONJR',
#   '',
#   'Clemson',
#   '2:00.65 ',
#   '6/12/2021'],
#  ['(19) Trena HULLUNLV2:00.65  5/16/1987',
#   '(19) Trena HULL',
#   '',
#   'UNLV',
#   '2:00.65  ',
#   '5/16/1987'],
#  ['\xa0\xa0\xa0\xa0— Richards {2}SROhio Northern2:00.67  6/2/2018\xa0\xa0\xa0\xa0\xa058.64/60.67',
#   '\xa0\xa0\xa0\xa0— Richards {2}SR',
#   '',
#   'Ohio Northern',
#   '2:00.67  ',
#   '6/2/2018',
#   '\xa0\xa0\xa0\xa0\xa058.64/60.67'],
#  ['\xa0\xa0\xa0\xa0— Tobias {2}SRTexas2:00.68 qq = Performance occurred during a non-final round. 6/8/2023',
#   '\xa0\xa0\xa0\xa0— Tobias {2}SR',
#   '',
#   'Texas',
#   '2:00.68 qq = Performance occurred during a non-final round. ',
#   '6/8/2023'],
#  ['\xa0\xa0\xa0\xa0— Barton {2}JRClemson2:00.70 5/13/2021',
#   '\xa0\xa0\xa0\xa0— Barton {2}JR',
#   '',
#   'Clemson',
#   '2:00.70 ',
#   '5/13/2021'],
#  ['(21) Sabrina SOUTHERLANDSROregon2:00.72 qq = Performance occurred during a non-final round. 5/25/2018\xa0\xa0\xa0\xa0\xa058.34/62.39',
#   '(21) Sabrina SOUTHERLANDSR',
#   '',
#   'Oregon',
#   '2:00.72 qq = Performance occurred during a non-final round. ',
#   '5/25/2018',
#   '\xa0\xa0\xa0\xa0\xa058.34/62.39'],
#  ['\xa0\xa0\xa0\xa0— Rogers {4}SOOregon2:00.75 6/11/2016\xa0\xa0\xa0\xa0\xa059.67/61.08: 28.60, 31.07, 31.44 [1:31.11], 29.64 (14.5)',
#   '\xa0\xa0\xa0\xa0— Rogers {4}SO',
#   '',
#   'Oregon',
#   '2:00.75 ',
#   '6/11/2016',
#   '\xa0\xa0\xa0\xa0\xa059.67/61.08: 28.60, 31.07, 31.44 [1:31.11], 29.64 (14.5)'],
#  ['\xa0\xa0\xa0\xa0— Goule {2}JRLSU2:00.76 4/20/2013',
#   '\xa0\xa0\xa0\xa0— Goule {2}JR',
#   '',
#   'LSU',
#   '2:00.76 ',
#   '4/20/2013'],
#  ['\xa0\xa0\xa0\xa0— Johnson {3}California2:00.77  5/31/2008',
#   '\xa0\xa0\xa0\xa0— Johnson {3}',
#   '',
#   'California',
#   '2:00.77  ',
#   '5/31/2008'],
#  ['(22) Geena GALLSRMichigan2:00.80  6/13/2009',
#   '(22) Geena GALLSR',
#   '',
#   'Michigan',
#   '2:00.80  ',
#   '6/13/2009'],
#  ['\xa0\xa0\xa0\xa0— Seymour {3}SRBYU2:00.81  5/6/2023',
#   '\xa0\xa0\xa0\xa0— Seymour {3}SR',
#   '',
#   'BYU',
#   '2:00.81  ',
#   '5/6/2023'],
#  ['(23) Karen BAKEWELLMiami (Ohio)2:00.85  6/6/1986',
#   '(23) Karen BAKEWELL',
#   '',
#   'Miami (Ohio)',
#   '2:00.85  ',
#   '6/6/1986'],
#  ['(24) Aaliyah MILLERJRBaylor2:00.87 4/16/2021',
#   '(24) Aaliyah MILLERJR',
#   '',
#   'Baylor',
#   '2:00.87 ',
#   '4/16/2021'],
#  ['(24) Phoebe WRIGHTSRTennessee2:00.87 qq = Performance occurred during a non-final round. 5/28/2010',
#   '(24) Phoebe WRIGHTSR',
#   '',
#   'Tennessee',
#   '2:00.87 qq = Performance occurred during a non-final round. ',
#   '5/28/2010']]

# %%
RealRealRows[1][4]
# Out:
# '1:59.08📺 '

# %%
len(RealRealRows)
# Out:
# 43

# %%
OfficialTimes = []

# %%
for i in range(0,len(RealRealRows)):
    OfficialTimes.append(RealRealRows[i][4])
OfficialTimes
# Out:
# ['1:57.73📺 ',
#  '1:59.08📺 ',
#  '1:59.10 ',
#  '1:59.11  ',
#  '1:59.29  ',
#  '1:59.35  ',
#  '1:59.71 ',
#  '1:59.73 ',
#  '1:59.83 ',
#  '2:00.02 ',
#  '2:00.04 ',
#  '2:00.06 ',
#  '2:00.24  ',
#  '2:00.27  ',
#  '2:00.28 ',
#  '2:00.31 qq = Performance occurred during a non-final round. ',
#  '2:00.31 ',
#  '2:00.34 ',
#  '2:00.34 ',
#  '2:00.40 qq = Performance occurred during a non-final round. ',
#  '2:00.40 qq = Performance occurred during a non-final round. ',
#  '2:00.47 ',
#  '2:00.48  ',
#  '2:00.54 ',
#  '2:00.55 ',
#  '2:00.57  ',
#  '2:00.62 ',
#  '2:00.62  ',
#  '2:00.63 ',
#  '2:00.65 ',
#  '2:00.65  ',
#  '2:00.67  ',
#  '2:00.68 qq = Performance occurred during a non-final round. ',
#  '2:00.70 ',
#  '2:00.72 qq = Performance occurred during a non-final round. ',
#  '2:00.75 ',
#  '2:00.76 ',
#  '2:00.77  ',
#  '2:00.80  ',
#  '2:00.81  ',
#  '2:00.85  ',
#  '2:00.87 ',
#  '2:00.87 qq = Performance occurred during a non-final round. ']

# %%
RealRealRows[0][1]
# Out:
# '(1) Athing MUFR'

# %%
Names = []

for i in range(0,43):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Athing MUFR',
#  '(2) Michaela ROSESO',
#  '(3) Raevyn ROGERSJR',
#  '(4) Suzy FAVORSR',
#  '(5) Alysia JOHNSONJR',
#  '(6) Katie ERDMAN',
#  '\xa0\xa0\xa0\xa0— Rogers {2}',
#  '\xa0\xa0\xa0\xa0— Rose {2}SO',
#  '\xa0\xa0\xa0\xa0— Rose {3}SO',
#  '\xa0\xa0\xa0\xa0— Rogers {3}JR',
#  '(7) Claire SEYMOURSR',
#  '(8) Natoya GOULEJR',
#  '(9) Jasmin JONES',
#  '(10) Inez TURNERSR',
#  '(11) Michaela MEYERSR',
#  '\xa0\xa0\xa0\xa0— Rose {4}SO',
#  '(12) Valery TOBIASSR',
#  '\xa0\xa0\xa0\xa0— Rose {5}SO',
#  '\xa0\xa0\xa0\xa0— Rose {6}SO',
#  '\xa0\xa0\xa0\xa0— Meyer {2}SR',
#  '\xa0\xa0\xa0\xa0— Meyer {3}SR',
#  '(13) Gabija GALVYDYTESO',
#  '(14) Meredith RAINEY',
#  '(15) Laura ROESLERSR',
#  '\xa0\xa0\xa0\xa0— Seymour {2}SR',
#  '\xa0\xa0\xa0\xa0— Johnson {2}',
#  '(16) Sage HURTASR',
#  '(16) Emily RICHARDSJR',
#  '(18) Claudia SAUNDERS',
#  '(19) Laurie BARTONJR',
#  '(19) Trena HULL',
#  '\xa0\xa0\xa0\xa0— Richards {2}SR',
#  '\xa0\xa0\xa0\xa0— Tobias {2}SR',
#  '\xa0\xa0\xa0\xa0— Barton {2}JR',
#  '(21) Sabrina SOUTHERLANDSR',
#  '\xa0\xa0\xa0\xa0— Rogers {4}SO',
#  '\xa0\xa0\xa0\xa0— Goule {2}JR',
#  '\xa0\xa0\xa0\xa0— Johnson {3}',
#  '(22) Geena GALLSR',
#  '\xa0\xa0\xa0\xa0— Seymour {3}SR',
#  '(23) Karen BAKEWELL',
#  '(24) Aaliyah MILLERJR',
#  '(24) Phoebe WRIGHTSR']

# %%
OfficialReGexNames = []

# %%
for i in range(0,43):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Athing MUFR',
#  '(2) Michaela ROSESO',
#  '(3) Raevyn ROGERSJR',
#  '(4) Suzy FAVORSR',
#  '(5) Alysia JOHNSONJR',
#  '(6) Katie ERDMAN',
#  '— Rogers {2}',
#  '— Rose {2}SO',
#  '— Rose {3}SO',
#  '— Rogers {3}JR',
#  '(7) Claire SEYMOURSR',
#  '(8) Natoya GOULEJR',
#  '(9) Jasmin JONES',
#  '(10) Inez TURNERSR',
#  '(11) Michaela MEYERSR',
#  '— Rose {4}SO',
#  '(12) Valery TOBIASSR',
#  '— Rose {5}SO',
#  '— Rose {6}SO',
#  '— Meyer {2}SR',
#  '— Meyer {3}SR',
#  '(13) Gabija GALVYDYTESO',
#  '(14) Meredith RAINEY',
#  '(15) Laura ROESLERSR',
#  '— Seymour {2}SR',
#  '— Johnson {2}',
#  '(16) Sage HURTASR',
#  '(16) Emily RICHARDSJR',
#  '(18) Claudia SAUNDERS',
#  '(19) Laurie BARTONJR',
#  '(19) Trena HULL',
#  '— Richards {2}SR',
#  '— Tobias {2}SR',
#  '— Barton {2}JR',
#  '(21) Sabrina SOUTHERLANDSR',
#  '— Rogers {4}SO',
#  '— Goule {2}JR',
#  '— Johnson {3}',
#  '(22) Geena GALLSR',
#  '— Seymour {3}SR',
#  '(23) Karen BAKEWELL',
#  '(24) Aaliyah MILLERJR',
#  '(24) Phoebe WRIGHTSR']

# %%
len(OfficialTimes)
# Out:
# 43

# %%
len(OfficialReGexNames)
# Out:
# 43

# %%
Schools = []

for i in range(0,len(OfficialTimes)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Texas A&M',
#  'LSU',
#  'Oregon',
#  'Wisconsin',
#  'California',
#  'Michigan',
#  'Oregon',
#  'LSU',
#  'LSU',
#  'Oregon',
#  'BYU',
#  'LSU',
#  'Tennessee',
#  'Texas State',
#  'Virginia',
#  'LSU',
#  'Texas',
#  'LSU',
#  'LSU',
#  'Virginia',
#  'Virginia',
#  'Oklahoma State',
#  'Harvard',
#  'Oregon',
#  'BYU',
#  'California',
#  'Colorado',
#  'Ohio Northern',
#  'Stanford',
#  'Clemson',
#  'UNLV',
#  'Ohio Northern',
#  'Texas',
#  'Clemson',
#  'Oregon',
#  'Oregon',
#  'LSU',
#  'California',
#  'Michigan',
#  'BYU',
#  'Miami (Ohio)',
#  'Baylor',
#  'Tennessee']

# %%
Times = []
for i in range(0,len(OfficialTimes)):
    Times.append(OfficialTimes[i][:7])
    
Times
# Out:
# ['1:57.73',
#  '1:59.08',
#  '1:59.10',
#  '1:59.11',
#  '1:59.29',
#  '1:59.35',
#  '1:59.71',
#  '1:59.73',
#  '1:59.83',
#  '2:00.02',
#  '2:00.04',
#  '2:00.06',
#  '2:00.24',
#  '2:00.27',
#  '2:00.28',
#  '2:00.31',
#  '2:00.31',
#  '2:00.34',
#  '2:00.34',
#  '2:00.40',
#  '2:00.40',
#  '2:00.47',
#  '2:00.48',
#  '2:00.54',
#  '2:00.55',
#  '2:00.57',
#  '2:00.62',
#  '2:00.62',
#  '2:00.63',
#  '2:00.65',
#  '2:00.65',
#  '2:00.67',
#  '2:00.68',
#  '2:00.70',
#  '2:00.72',
#  '2:00.75',
#  '2:00.76',
#  '2:00.77',
#  '2:00.80',
#  '2:00.81',
#  '2:00.85',
#  '2:00.87',
#  '2:00.87']

# %%
Womens800mDF = pd.DataFrame({'Names': OfficialReGexNames, 'Times': Times, 'Schools': Schools})
Womens800mDF.to_csv('Womens100m.csv', index=False)
