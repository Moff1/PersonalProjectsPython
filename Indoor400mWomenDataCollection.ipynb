# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
LinkIndoor400mWomen = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?sport=1&gender=2&div=20527&top=25&event=4"

# %%
page = requests.get(LinkIndoor400mWomen)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7488009" target="_blank">(1) Britton WILSON</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720966" target="_blank">49.48</a><a href="https://www.youtube.com/watch?v=JgNU-0wouls" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7488009" target="_blank">(1) Britton WILSON</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720966" target="_blank">49.48</a><a href="https://www.youtube.com/watch?v=JgNU-0wouls" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7732042" target="_blank">(2) Talitha DIGGS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691831" target="_blank">50.15</a><a href="https://twitter.com/GatorsTF/status/1629619657077571584?s=20" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/25/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7732042" target="_blank">(2) Talitha DIGGS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691831" target="_blank">50.15</a><a href="https://twitter.com/GatorsTF/status/1629619657077571584?s=20" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/25/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7690419" target="_blank">(3) Rhasidat ADELEKE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77924/4693842" target="_blank">50.33</a><a href="https://twitter.com/stan_becton/status/1629612020298383360" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7690419" target="_blank">(3) Rhasidat ADELEKE</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77924/4693842" target="_blank">50.33</a><a href="https://twitter.com/stan_becton/status/1629612020298383360" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5095585" target="_blank">(4) Kendall ELLIS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335588" target="_blank">50.34</a><a href="https://www.youtube.com/watch?v=6QObHhNGbPA" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     23.63, 26.71</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5095585" target="_blank">(4) Kendall ELLIS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335588" target="_blank">50.34</a><a href="https://www.youtube.com/watch?v=6QObHhNGbPA" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     23.63, 26.71</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6531200" target="_blank">(5) Sydney MCLAUGHLIN</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335588" target="_blank">50.36</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     23.73, 26.63</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6531200" target="_blank">(5) Sydney MCLAUGHLIN</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335588" target="_blank">50.36</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     23.73, 26.63</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Adeleke {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720966" target="_blank">50.45</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Adeleke {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720966" target="_blank">50.45</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Adeleke {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76085/4659583" target="_blank">50.45</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="New Mexico Collegiate Classic (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/3/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Adeleke {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76085/4659583" target="_blank">50.45</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="New Mexico Collegiate Classic (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/3/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3272975" target="_blank">(6) Phyllis FRANCIS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/34001/2083828" target="_blank">50.46</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;">3/15/2014</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     24.17/26.29</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3272975" target="_blank">(6) Phyllis FRANCIS</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/34001/2083828" target="_blank">50.46</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;">3/15/2014</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     24.17/26.29</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Diggs {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720966" target="_blank">50.49</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Diggs {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720966" target="_blank">50.49</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729637" target="_blank">(7) Athing MU</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67284/4062873" target="_blank">50.52</a> </td><td style="width: 10%;text-align:right;" title="Texas A&amp;M Charlie Thomas Invitational (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/6/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7729637" target="_blank">(7) Athing MU</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/67284/4062873" target="_blank">50.52</a> </td><td style="width: 10%;text-align:right;" title="Texas A&amp;M Charlie Thomas Invitational (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/6/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — McLaughlin {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/53840/3311610" target="_blank">50.52</a> <span class="tooltip" style="font-size: smaller;">b<span class="tooltiptext" style="font-size: smaller;">b = Performance occurred on a 200m/220yd banked track</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — McLaughlin {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/53840/3311610" target="_blank">50.52</a> <span class="tooltip" style="font-size: smaller;">b<span class="tooltiptext" style="font-size: smaller;">b = Performance occurred on a 200m/220yd banked track</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7478918" target="_blank">(8) Rosey EFFIONG</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720966" target="_blank">50.54</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7478918" target="_blank">(8) Rosey EFFIONG</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720966" target="_blank">50.54</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(8) Francena MCCORORY</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Hampton" class="group-logo-inline" src="/images/logos/rankings-article/hampton.png" title="Hampton"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=623">Hampton</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/15673" target="_blank">50.54</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2010</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(8) Francena MCCORORY</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Hampton" class="group-logo-inline" src="/images/logos/rankings-article/hampton.png" title="Hampton"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=623">Hampton</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/15673" target="_blank">50.54</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2010</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6562293" target="_blank">(10) Lynna IRBY</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/53840/3311610" target="_blank">50.62</a> <span class="tooltip" style="font-size: smaller;">b<span class="tooltiptext" style="font-size: smaller;">b = Performance occurred on a 200m/220yd banked track</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6562293" target="_blank">(10) Lynna IRBY</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/53840/3311610" target="_blank">50.62</a> <span class="tooltip" style="font-size: smaller;">b<span class="tooltiptext" style="font-size: smaller;">b = Performance occurred on a 200m/220yd banked track</span></span> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/25/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7511452" target="_blank">(11) Amber ANNING</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691831" target="_blank">50.68</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/25/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7511452" target="_blank">(11) Amber ANNING</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77404/4691831" target="_blank">50.68</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/25/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Wilson {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720966" target="_blank">50.69</a><a href="https://www.youtube.com/watch?v=1hVP8SDCYsQ&amp;list=PL9WSsnpWNE8NiGBTkrzMZgJEYeRqp5AGR&amp;index=40" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Wilson {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720966" target="_blank">50.69</a><a href="https://www.youtube.com/watch?v=1hVP8SDCYsQ&amp;list=PL9WSsnpWNE8NiGBTkrzMZgJEYeRqp5AGR&amp;index=40" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4206022" target="_blank">(12) Courtney OKOLO</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41706" target="_blank">50.69</a> <span class="tooltip" style="font-size: smaller;">i<span class="tooltiptext" style="font-size: smaller;">i = event moved indoors because of weather or another issue.</span></span> </td><td style="width: 10%;text-align:right;" title="Birmingham-Southern Invitational (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4206022" target="_blank">(12) Courtney OKOLO</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/41706" target="_blank">50.69</a> <span class="tooltip" style="font-size: smaller;">i<span class="tooltiptext" style="font-size: smaller;">i = event moved indoors because of weather or another issue.</span></span> </td><td style="width: 10%;text-align:right;" title="Birmingham-Southern Invitational (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Okolo {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702428" target="_blank">50.69</a><a href="https://www.youtube.com/watch?v=K5-wgVjEaAA&amp;list=PL9WSsnpWNE8NiGBTkrzMZgJEYeRqp5AGR&amp;index=58" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">b<span class="tooltiptext" style="font-size: smaller;">b = Performance occurred on a 200m/220yd banked track</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Okolo {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702428" target="_blank">50.69</a><a href="https://www.youtube.com/watch?v=K5-wgVjEaAA&amp;list=PL9WSsnpWNE8NiGBTkrzMZgJEYeRqp5AGR&amp;index=58" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">b<span class="tooltiptext" style="font-size: smaller;">b = Performance occurred on a 200m/220yd banked track</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6989583" target="_blank">(13) Alexis HOLMES</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72951/4389474" target="_blank">50.77</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/26/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/6989583" target="_blank">(13) Alexis HOLMES</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/72951/4389474" target="_blank">50.77</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">2/26/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Diggs {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720966" target="_blank">50.79</a><a href="https://www.youtube.com/watch?v=m4PvMnn0JpU&amp;list=PL9WSsnpWNE8NiGBTkrzMZgJEYeRqp5AGR&amp;index=45" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Diggs {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720966" target="_blank">50.79</a><a href="https://www.youtube.com/watch?v=m4PvMnn0JpU&amp;list=PL9WSsnpWNE8NiGBTkrzMZgJEYeRqp5AGR&amp;index=45" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/1736818" target="_blank">(14) Jessica BEARD</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/20091" target="_blank">50.79</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2011</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/1736818" target="_blank">(14) Jessica BEARD</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/20091" target="_blank">50.79</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2011</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(15) Natasha HASTINGS</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="South Carolina" class="group-logo-inline" src="/images/logos/rankings-article/south-carolina.png" title="South Carolina"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1411">South Carolina</a></td><td style="width: 25%;">50.80  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2007</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(15) Natasha HASTINGS</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="South Carolina" class="group-logo-inline" src="/images/logos/rankings-article/south-carolina.png" title="South Carolina"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1411">South Carolina</a></td><td style="width: 25%;">50.80  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2007</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(16) Sanya RICHARDS</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;">50.82  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2004</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(16) Sanya RICHARDS</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;">50.82  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2004</span></td></tr>,
# ...
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Diggs {4}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416377" target="_blank">50.98</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Diggs {4}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Florida" class="group-logo-inline" src="/images/logos/rankings-article/florida.png" title="Florida"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=521">Florida</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416377" target="_blank">50.98</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7008907" target="_blank">(22) Kennedy SIMON</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77924/4693842" target="_blank">51.01</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7008907" target="_blank">(22) Kennedy SIMON</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77924/4693842" target="_blank">51.01</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Effiong {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76074/4667514" target="_blank">51.02</a> </td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Effiong {2}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76074/4667514" target="_blank">51.02</a> </td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Mu {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118033" target="_blank">51.02</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Mu {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118033" target="_blank">51.02</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7519684" target="_blank">(23) Jan'Taijah FORD</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720966" target="_blank">51.03</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7519684" target="_blank">(23) Jan'Taijah FORD</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720966" target="_blank">51.03</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Mu {3}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118033" target="_blank">51.03</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Mu {3}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas A&amp;M" class="group-logo-inline" src="/images/logos/rankings-article/texas-am.png" title="Texas A&amp;M"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=1559">Texas A&amp;M</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118033" target="_blank">51.03</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2761484" target="_blank">(24) Regina GEORGE</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/29008" target="_blank">51.05</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2013</span></td></tr><tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     24.51, 27.87</td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/2761484" target="_blank">(24) Regina GEORGE</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arkansas" class="group-logo-inline" src="/images/logos/rankings-article/arkansas.png" title="Arkansas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=59">Arkansas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/29008" target="_blank">51.05</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2013</span></td></tr>,
#  <tr><td colspan="6" style="font-size: 0.8em; font-style:italic;">     24.51, 27.87</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>(24) Maicel MALONE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona State" class="group-logo-inline" src="/images/logos/rankings-article/arizona-state.png" title="Arizona State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=57">Arizona State</a></td><td style="width: 25%;">51.05  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/1991</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>(24) Maicel MALONE</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Arizona State" class="group-logo-inline" src="/images/logos/rankings-article/arizona-state.png" title="Arizona State"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=4&amp;team=57">Arizona State</a></td><td style="width: 25%;">51.05  </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Indianapolis, Ind.)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/1991</span></td></tr>,
#  <tr><td class="group-logo-50"><a href="https://allathletics.tv/?utc_source=ustfccca&amp;utc_medium=web&amp;utc_campaign=broadcast_schedule_sidebar" target="_blank"><img alt="eaa" src="/images/logos/rankings-article/eaa.png" title="EAA"/></a></td><td style="line-height: 1em;"><a href="https://allathletics.tv/?utc_source=ustfccca&amp;utc_medium=web&amp;utc_campaign=broadcast_schedule_sidebar" target="_blank">European U20 Championships</a></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Britton WILSONSOArkansas49.48📺 3/11/2023',
#   '(1) Britton WILSONSO',
#   '',
#   'Arkansas',
#   '49.48📺 ',
#   '3/11/2023'],
#  [],
#  ['(1) Britton WILSONSO', '', 'Arkansas', '49.48📺 ', '3/11/2023'],
#  ['(2) Talitha DIGGSSOFlorida50.15📺 2/25/2023',
#   '(2) Talitha DIGGSSO',
#   '',
#   'Florida',
#   '50.15📺 ',
#   '2/25/2023'],
#  [],
#  ['(2) Talitha DIGGSSO', '', 'Florida', '50.15📺 ', '2/25/2023'],
#  ['(3) Rhasidat ADELEKESOTexas50.33📺 2/24/2023',
#   '(3) Rhasidat ADELEKESO',
#   '',
#   'Texas',
#   '50.33📺 ',
#   '2/24/2023'],
#  [],
#  ['(3) Rhasidat ADELEKESO', '', 'Texas', '50.33📺 ', '2/24/2023'],
#  ['(4) Kendall ELLISSRSouthern California50.34📺 3/10/2018\xa0\xa0\xa0\xa0\xa023.63, 26.71',
#   '(4) Kendall ELLISSR',
#   '',
#   'Southern California',
#   '50.34📺 ',
#   '3/10/2018',
#   '\xa0\xa0\xa0\xa0\xa023.63, 26.71'],
#  [],
#  ['(4) Kendall ELLISSR', '', 'Southern California', '50.34📺 ', '3/10/2018'],
#  ['\xa0\xa0\xa0\xa0\xa023.63, 26.71'],
#  ['(5) Sydney MCLAUGHLINFRKentucky50.36 3/10/2018\xa0\xa0\xa0\xa0\xa023.73, 26.63',
#   '(5) Sydney MCLAUGHLINFR',
#   '',
#   'Kentucky',
#   '50.36 ',
#   '3/10/2018',
#   '\xa0\xa0\xa0\xa0\xa023.73, 26.63'],
#  [],
#  ['(5) Sydney MCLAUGHLINFR', '', 'Kentucky', '50.36 ', '3/10/2018'],
#  ['\xa0\xa0\xa0\xa0\xa023.73, 26.63'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {2}SOTexas50.45 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {2}SO',
#   '',
#   'Texas',
#   '50.45 ',
#   '3/11/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Adeleke {2}SO', '', 'Texas', '50.45 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {3}SOTexas50.45 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {3}SO',
#   '',
#   'Texas',
#   '50.45 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Adeleke {3}SO',
#   '',
#   'Texas',
#   '50.45 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['(6) Phyllis FRANCISOregon50.46 AA = Performance occurred at altitude (>1000 meters above sea level) 3/15/2014\xa0\xa0\xa0\xa0\xa024.17/26.29',
#   '(6) Phyllis FRANCIS',
#   '',
#   'Oregon',
#   '50.46 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014',
#   '\xa0\xa0\xa0\xa0\xa024.17/26.29'],
#  [],
#  ['(6) Phyllis FRANCIS',
#   '',
#   'Oregon',
#   '50.46 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  ['\xa0\xa0\xa0\xa0\xa024.17/26.29'],
#  ['\xa0\xa0\xa0\xa0— Diggs {2}SOFlorida50.49 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Diggs {2}SO',
#   '',
#   'Florida',
#   '50.49 ',
#   '3/11/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Diggs {2}SO', '', 'Florida', '50.49 ', '3/11/2023'],
#  ['(7) Athing MUFRTexas A&M50.52 2/6/2021',
#   '(7) Athing MUFR',
#   '',
#   'Texas A&M',
#   '50.52 ',
#   '2/6/2021'],
#  [],
#  ['(7) Athing MUFR', '', 'Texas A&M', '50.52 ', '2/6/2021'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {2}FRKentucky50.52 bb = Performance occurred on a 200m/220yd banked track 2/25/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {2}FR',
#   '',
#   'Kentucky',
#   '50.52 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/25/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {2}FR',
#   '',
#   'Kentucky',
#   '50.52 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/25/2018'],
#  ['(8) Rosey EFFIONGJRArkansas50.54 3/11/2023',
#   '(8) Rosey EFFIONGJR',
#   '',
#   'Arkansas',
#   '50.54 ',
#   '3/11/2023'],
#  [],
#  ['(8) Rosey EFFIONGJR', '', 'Arkansas', '50.54 ', '3/11/2023'],
#  ['(8) Francena MCCORORYHampton50.54 3/13/2010',
#   '(8) Francena MCCORORY',
#   '',
#   'Hampton',
#   '50.54 ',
#   '3/13/2010'],
#  [],
#  ['(8) Francena MCCORORY', '', 'Hampton', '50.54 ', '3/13/2010'],
#  ['(10) Lynna IRBYFRGeorgia50.62 bb = Performance occurred on a 200m/220yd banked track 2/25/2018',
#   '(10) Lynna IRBYFR',
#   '',
#   'Georgia',
#   '50.62 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/25/2018'],
#  [],
#  ['(10) Lynna IRBYFR',
#   '',
#   'Georgia',
#   '50.62 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/25/2018'],
#  ['(11) Amber ANNINGJRArkansas50.68 2/25/2023',
#   '(11) Amber ANNINGJR',
#   '',
#   'Arkansas',
#   '50.68 ',
#   '2/25/2023'],
#  [],
#  ['(11) Amber ANNINGJR', '', 'Arkansas', '50.68 ', '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}SOArkansas50.69📺 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}SO',
#   '',
#   'Arkansas',
#   '50.69📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}SO',
#   '',
#   'Arkansas',
#   '50.69📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(12) Courtney OKOLOSRTexas50.69 ii = event moved indoors because of weather or another issue. 3/12/2016',
#   '(12) Courtney OKOLOSR',
#   '',
#   'Texas',
#   '50.69 ii = event moved indoors because of weather or another issue. ',
#   '3/12/2016'],
#  [],
#  ['(12) Courtney OKOLOSR',
#   '',
#   'Texas',
#   '50.69 ii = event moved indoors because of weather or another issue. ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Okolo {2}SRTexas50.69📺 bb = Performance occurred on a 200m/220yd banked track 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Okolo {2}SR',
#   '',
#   'Texas',
#   '50.69📺 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/12/2016'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Okolo {2}SR',
#   '',
#   'Texas',
#   '50.69📺 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/12/2016'],
#  ['(13) Alexis HOLMESJRKentucky50.77 2/26/2022',
#   '(13) Alexis HOLMESJR',
#   '',
#   'Kentucky',
#   '50.77 ',
#   '2/26/2022'],
#  [],
#  ['(13) Alexis HOLMESJR', '', 'Kentucky', '50.77 ', '2/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Diggs {3}SOFlorida50.79📺 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Diggs {3}SO',
#   '',
#   'Florida',
#   '50.79📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Diggs {3}SO',
#   '',
#   'Florida',
#   '50.79📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(14) Jessica BEARDTexas A&M50.79 3/12/2011',
#   '(14) Jessica BEARD',
#   '',
#   'Texas A&M',
#   '50.79 ',
#   '3/12/2011'],
#  [],
#  ['(14) Jessica BEARD', '', 'Texas A&M', '50.79 ', '3/12/2011'],
#  ['(15) Natasha HASTINGSJRSouth Carolina50.80  3/10/2007',
#   '(15) Natasha HASTINGSJR',
#   '',
#   'South Carolina',
#   '50.80  ',
#   '3/10/2007'],
#  [],
#  ['(15) Natasha HASTINGSJR', '', 'South Carolina', '50.80  ', '3/10/2007'],
#  ['(16) Sanya RICHARDSSOTexas50.82  3/13/2004',
#   '(16) Sanya RICHARDSSO',
#   '',
#   'Texas',
#   '50.82  ',
#   '3/13/2004'],
#  [],
#  ['(16) Sanya RICHARDSSO', '', 'Texas', '50.82  ', '3/13/2004'],
#  ['(17) Kaelin ROBERTSSRSouthern California50.84 3/13/2021',
#   '(17) Kaelin ROBERTSSR',
#   '',
#   'Southern California',
#   '50.84 ',
#   '3/13/2021'],
#  [],
#  ['(17) Kaelin ROBERTSSR', '', 'Southern California', '50.84 ', '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Irby {2}FRGeorgia50.87 3/10/2018\xa0\xa0\xa0\xa0\xa023.59, 27.28',
#   '\xa0\xa0\xa0\xa0— Irby {2}FR',
#   '',
#   'Georgia',
#   '50.87 ',
#   '3/10/2018',
#   '\xa0\xa0\xa0\xa0\xa023.59, 27.28'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Irby {2}FR', '', 'Georgia', '50.87 ', '3/10/2018'],
#  ['\xa0\xa0\xa0\xa0\xa023.59, 27.28'],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}FRArkansas50.88 2/26/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {3}FR',
#   '',
#   'Arkansas',
#   '50.88 ',
#   '2/26/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}FR', '', 'Arkansas', '50.88 ', '2/26/2022'],
#  ['(18) Shaunae MILLERFRGeorgia50.88 3/9/2013\xa0\xa0\xa0\xa0\xa023.52, 27.36',
#   '(18) Shaunae MILLERFR',
#   '',
#   'Georgia',
#   '50.88 ',
#   '3/9/2013',
#   '\xa0\xa0\xa0\xa0\xa023.52, 27.36'],
#  [],
#  ['(18) Shaunae MILLERFR', '', 'Georgia', '50.88 ', '3/9/2013'],
#  ['\xa0\xa0\xa0\xa0\xa023.52, 27.36'],
#  ['(19) Tiandra PONTEENSOFlorida50.91  3/12/2005',
#   '(19) Tiandra PONTEENSO',
#   '',
#   'Florida',
#   '50.91  ',
#   '3/12/2005'],
#  [],
#  ['(19) Tiandra PONTEENSO', '', 'Florida', '50.91  ', '3/12/2005'],
#  ['(20) Hazel-Ann REGISSRLSU50.92  3/12/2005',
#   '(20) Hazel-Ann REGISSR',
#   '',
#   'LSU',
#   '50.92  ',
#   '3/12/2005'],
#  [],
#  ['(20) Hazel-Ann REGISSR', '', 'LSU', '50.92  ', '3/12/2005'],
#  ['(21) Kamaria BROWNJRTexas A&M50.94 bb = Performance occurred on a 200m/220yd banked track 3/1/2014',
#   '(21) Kamaria BROWNJR',
#   '',
#   'Texas A&M',
#   '50.94 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/1/2014'],
#  [],
#  ['(21) Kamaria BROWNJR',
#   '',
#   'Texas A&M',
#   '50.94 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/1/2014'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {3}FRKentucky50.97 bb = Performance occurred on a 200m/220yd banked trackqq = Performance occurred during a non-final round. 2/25/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {3}FR',
#   '',
#   'Kentucky',
#   '50.97 bb = Performance occurred on a 200m/220yd banked trackqq = Performance occurred during a non-final round. ',
#   '2/25/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {3}FR',
#   '',
#   'Kentucky',
#   '50.97 bb = Performance occurred on a 200m/220yd banked trackqq = Performance occurred during a non-final round. ',
#   '2/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Diggs {4}FRFlorida50.98 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Diggs {4}FR',
#   '',
#   'Florida',
#   '50.98 ',
#   '3/12/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Diggs {4}FR', '', 'Florida', '50.98 ', '3/12/2022'],
#  ['(22) Kennedy SIMONSRTexas51.01 2/24/2023',
#   '(22) Kennedy SIMONSR',
#   '',
#   'Texas',
#   '51.01 ',
#   '2/24/2023'],
#  [],
#  ['(22) Kennedy SIMONSR', '', 'Texas', '51.01 ', '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Effiong {2}JRArkansas51.02 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Effiong {2}JR',
#   '',
#   'Arkansas',
#   '51.02 ',
#   '2/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Effiong {2}JR', '', 'Arkansas', '51.02 ', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FRTexas A&M51.02 qq = Performance occurred during a non-final round. 3/12/2021',
#   '\xa0\xa0\xa0\xa0— Mu {2}FR',
#   '',
#   'Texas A&M',
#   '51.02 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FR',
#   '',
#   'Texas A&M',
#   '51.02 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ["(23) Jan'Taijah FORDJRSouthern California51.03 3/11/2023",
#   "(23) Jan'Taijah FORDJR",
#   '',
#   'Southern California',
#   '51.03 ',
#   '3/11/2023'],
#  [],
#  ["(23) Jan'Taijah FORDJR", '', 'Southern California', '51.03 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Mu {3}FRTexas A&M51.03 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Mu {3}FR',
#   '',
#   'Texas A&M',
#   '51.03 ',
#   '3/13/2021'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Mu {3}FR', '', 'Texas A&M', '51.03 ', '3/13/2021'],
#  ['(24) Regina GEORGESRArkansas51.05 3/9/2013\xa0\xa0\xa0\xa0\xa024.51, 27.87',
#   '(24) Regina GEORGESR',
#   '',
#   'Arkansas',
#   '51.05 ',
#   '3/9/2013',
#   '\xa0\xa0\xa0\xa0\xa024.51, 27.87'],
#  [],
#  ['(24) Regina GEORGESR', '', 'Arkansas', '51.05 ', '3/9/2013'],
#  ['\xa0\xa0\xa0\xa0\xa024.51, 27.87'],
#  ['(24) Maicel MALONEArizona State51.05  3/9/1991',
#   '(24) Maicel MALONE',
#   '',
#   'Arizona State',
#   '51.05  ',
#   '3/9/1991'],
#  [],
#  ['(24) Maicel MALONE', '', 'Arizona State', '51.05  ', '3/9/1991'],
#  ['', 'European U20 Championships'],
#  ['', '', '', '']]

# %%
len(rows)
# Out:
# 127

# %%
rows[124]
# Out:
# ['(24) Maicel MALONE', '', 'Arizona State', '51.05  ', '3/9/1991']

# %%
len(rows)
# Out:
# 127

# %%
RealRows = []

# %%
for i in range(0,124):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [['(1) Britton WILSONSOArkansas49.48📺 3/11/2023',
#   '(1) Britton WILSONSO',
#   '',
#   'Arkansas',
#   '49.48📺 ',
#   '3/11/2023'],
#  ['(1) Britton WILSONSO', '', 'Arkansas', '49.48📺 ', '3/11/2023'],
#  ['(2) Talitha DIGGSSOFlorida50.15📺 2/25/2023',
#   '(2) Talitha DIGGSSO',
#   '',
#   'Florida',
#   '50.15📺 ',
#   '2/25/2023'],
#  ['(2) Talitha DIGGSSO', '', 'Florida', '50.15📺 ', '2/25/2023'],
#  ['(3) Rhasidat ADELEKESOTexas50.33📺 2/24/2023',
#   '(3) Rhasidat ADELEKESO',
#   '',
#   'Texas',
#   '50.33📺 ',
#   '2/24/2023'],
#  ['(3) Rhasidat ADELEKESO', '', 'Texas', '50.33📺 ', '2/24/2023'],
#  ['(4) Kendall ELLISSRSouthern California50.34📺 3/10/2018\xa0\xa0\xa0\xa0\xa023.63, 26.71',
#   '(4) Kendall ELLISSR',
#   '',
#   'Southern California',
#   '50.34📺 ',
#   '3/10/2018',
#   '\xa0\xa0\xa0\xa0\xa023.63, 26.71'],
#  ['(4) Kendall ELLISSR', '', 'Southern California', '50.34📺 ', '3/10/2018'],
#  ['(5) Sydney MCLAUGHLINFRKentucky50.36 3/10/2018\xa0\xa0\xa0\xa0\xa023.73, 26.63',
#   '(5) Sydney MCLAUGHLINFR',
#   '',
#   'Kentucky',
#   '50.36 ',
#   '3/10/2018',
#   '\xa0\xa0\xa0\xa0\xa023.73, 26.63'],
#  ['(5) Sydney MCLAUGHLINFR', '', 'Kentucky', '50.36 ', '3/10/2018'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {2}SOTexas50.45 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {2}SO',
#   '',
#   'Texas',
#   '50.45 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {2}SO', '', 'Texas', '50.45 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {3}SOTexas50.45 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {3}SO',
#   '',
#   'Texas',
#   '50.45 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {3}SO',
#   '',
#   'Texas',
#   '50.45 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['(6) Phyllis FRANCISOregon50.46 AA = Performance occurred at altitude (>1000 meters above sea level) 3/15/2014\xa0\xa0\xa0\xa0\xa024.17/26.29',
#   '(6) Phyllis FRANCIS',
#   '',
#   'Oregon',
#   '50.46 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014',
#   '\xa0\xa0\xa0\xa0\xa024.17/26.29'],
#  ['(6) Phyllis FRANCIS',
#   '',
#   'Oregon',
#   '50.46 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  ['\xa0\xa0\xa0\xa0— Diggs {2}SOFlorida50.49 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Diggs {2}SO',
#   '',
#   'Florida',
#   '50.49 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Diggs {2}SO', '', 'Florida', '50.49 ', '3/11/2023'],
#  ['(7) Athing MUFRTexas A&M50.52 2/6/2021',
#   '(7) Athing MUFR',
#   '',
#   'Texas A&M',
#   '50.52 ',
#   '2/6/2021'],
#  ['(7) Athing MUFR', '', 'Texas A&M', '50.52 ', '2/6/2021'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {2}FRKentucky50.52 bb = Performance occurred on a 200m/220yd banked track 2/25/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {2}FR',
#   '',
#   'Kentucky',
#   '50.52 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/25/2018'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {2}FR',
#   '',
#   'Kentucky',
#   '50.52 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/25/2018'],
#  ['(8) Rosey EFFIONGJRArkansas50.54 3/11/2023',
#   '(8) Rosey EFFIONGJR',
#   '',
#   'Arkansas',
#   '50.54 ',
#   '3/11/2023'],
#  ['(8) Rosey EFFIONGJR', '', 'Arkansas', '50.54 ', '3/11/2023'],
#  ['(8) Francena MCCORORYHampton50.54 3/13/2010',
#   '(8) Francena MCCORORY',
#   '',
#   'Hampton',
#   '50.54 ',
#   '3/13/2010'],
#  ['(8) Francena MCCORORY', '', 'Hampton', '50.54 ', '3/13/2010'],
#  ['(10) Lynna IRBYFRGeorgia50.62 bb = Performance occurred on a 200m/220yd banked track 2/25/2018',
#   '(10) Lynna IRBYFR',
#   '',
#   'Georgia',
#   '50.62 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/25/2018'],
#  ['(10) Lynna IRBYFR',
#   '',
#   'Georgia',
#   '50.62 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/25/2018'],
#  ['(11) Amber ANNINGJRArkansas50.68 2/25/2023',
#   '(11) Amber ANNINGJR',
#   '',
#   'Arkansas',
#   '50.68 ',
#   '2/25/2023'],
#  ['(11) Amber ANNINGJR', '', 'Arkansas', '50.68 ', '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}SOArkansas50.69📺 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}SO',
#   '',
#   'Arkansas',
#   '50.69📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}SO',
#   '',
#   'Arkansas',
#   '50.69📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(12) Courtney OKOLOSRTexas50.69 ii = event moved indoors because of weather or another issue. 3/12/2016',
#   '(12) Courtney OKOLOSR',
#   '',
#   'Texas',
#   '50.69 ii = event moved indoors because of weather or another issue. ',
#   '3/12/2016'],
#  ['(12) Courtney OKOLOSR',
#   '',
#   'Texas',
#   '50.69 ii = event moved indoors because of weather or another issue. ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Okolo {2}SRTexas50.69📺 bb = Performance occurred on a 200m/220yd banked track 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Okolo {2}SR',
#   '',
#   'Texas',
#   '50.69📺 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Okolo {2}SR',
#   '',
#   'Texas',
#   '50.69📺 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/12/2016'],
#  ['(13) Alexis HOLMESJRKentucky50.77 2/26/2022',
#   '(13) Alexis HOLMESJR',
#   '',
#   'Kentucky',
#   '50.77 ',
#   '2/26/2022'],
#  ['(13) Alexis HOLMESJR', '', 'Kentucky', '50.77 ', '2/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Diggs {3}SOFlorida50.79📺 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Diggs {3}SO',
#   '',
#   'Florida',
#   '50.79📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Diggs {3}SO',
#   '',
#   'Florida',
#   '50.79📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(14) Jessica BEARDTexas A&M50.79 3/12/2011',
#   '(14) Jessica BEARD',
#   '',
#   'Texas A&M',
#   '50.79 ',
#   '3/12/2011'],
#  ['(14) Jessica BEARD', '', 'Texas A&M', '50.79 ', '3/12/2011'],
#  ['(15) Natasha HASTINGSJRSouth Carolina50.80  3/10/2007',
#   '(15) Natasha HASTINGSJR',
#   '',
#   'South Carolina',
#   '50.80  ',
#   '3/10/2007'],
#  ['(15) Natasha HASTINGSJR', '', 'South Carolina', '50.80  ', '3/10/2007'],
#  ['(16) Sanya RICHARDSSOTexas50.82  3/13/2004',
#   '(16) Sanya RICHARDSSO',
#   '',
#   'Texas',
#   '50.82  ',
#   '3/13/2004'],
#  ['(16) Sanya RICHARDSSO', '', 'Texas', '50.82  ', '3/13/2004'],
#  ['(17) Kaelin ROBERTSSRSouthern California50.84 3/13/2021',
#   '(17) Kaelin ROBERTSSR',
#   '',
#   'Southern California',
#   '50.84 ',
#   '3/13/2021'],
#  ['(17) Kaelin ROBERTSSR', '', 'Southern California', '50.84 ', '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Irby {2}FRGeorgia50.87 3/10/2018\xa0\xa0\xa0\xa0\xa023.59, 27.28',
#   '\xa0\xa0\xa0\xa0— Irby {2}FR',
#   '',
#   'Georgia',
#   '50.87 ',
#   '3/10/2018',
#   '\xa0\xa0\xa0\xa0\xa023.59, 27.28'],
#  ['\xa0\xa0\xa0\xa0— Irby {2}FR', '', 'Georgia', '50.87 ', '3/10/2018'],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}FRArkansas50.88 2/26/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {3}FR',
#   '',
#   'Arkansas',
#   '50.88 ',
#   '2/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}FR', '', 'Arkansas', '50.88 ', '2/26/2022'],
#  ['(18) Shaunae MILLERFRGeorgia50.88 3/9/2013\xa0\xa0\xa0\xa0\xa023.52, 27.36',
#   '(18) Shaunae MILLERFR',
#   '',
#   'Georgia',
#   '50.88 ',
#   '3/9/2013',
#   '\xa0\xa0\xa0\xa0\xa023.52, 27.36'],
#  ['(18) Shaunae MILLERFR', '', 'Georgia', '50.88 ', '3/9/2013'],
#  ['(19) Tiandra PONTEENSOFlorida50.91  3/12/2005',
#   '(19) Tiandra PONTEENSO',
#   '',
#   'Florida',
#   '50.91  ',
#   '3/12/2005'],
#  ['(19) Tiandra PONTEENSO', '', 'Florida', '50.91  ', '3/12/2005'],
#  ['(20) Hazel-Ann REGISSRLSU50.92  3/12/2005',
#   '(20) Hazel-Ann REGISSR',
#   '',
#   'LSU',
#   '50.92  ',
#   '3/12/2005'],
#  ['(20) Hazel-Ann REGISSR', '', 'LSU', '50.92  ', '3/12/2005'],
#  ['(21) Kamaria BROWNJRTexas A&M50.94 bb = Performance occurred on a 200m/220yd banked track 3/1/2014',
#   '(21) Kamaria BROWNJR',
#   '',
#   'Texas A&M',
#   '50.94 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/1/2014'],
#  ['(21) Kamaria BROWNJR',
#   '',
#   'Texas A&M',
#   '50.94 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/1/2014'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {3}FRKentucky50.97 bb = Performance occurred on a 200m/220yd banked trackqq = Performance occurred during a non-final round. 2/25/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {3}FR',
#   '',
#   'Kentucky',
#   '50.97 bb = Performance occurred on a 200m/220yd banked trackqq = Performance occurred during a non-final round. ',
#   '2/25/2018'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {3}FR',
#   '',
#   'Kentucky',
#   '50.97 bb = Performance occurred on a 200m/220yd banked trackqq = Performance occurred during a non-final round. ',
#   '2/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Diggs {4}FRFlorida50.98 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Diggs {4}FR',
#   '',
#   'Florida',
#   '50.98 ',
#   '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Diggs {4}FR', '', 'Florida', '50.98 ', '3/12/2022'],
#  ['(22) Kennedy SIMONSRTexas51.01 2/24/2023',
#   '(22) Kennedy SIMONSR',
#   '',
#   'Texas',
#   '51.01 ',
#   '2/24/2023'],
#  ['(22) Kennedy SIMONSR', '', 'Texas', '51.01 ', '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Effiong {2}JRArkansas51.02 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Effiong {2}JR',
#   '',
#   'Arkansas',
#   '51.02 ',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Effiong {2}JR', '', 'Arkansas', '51.02 ', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FRTexas A&M51.02 qq = Performance occurred during a non-final round. 3/12/2021',
#   '\xa0\xa0\xa0\xa0— Mu {2}FR',
#   '',
#   'Texas A&M',
#   '51.02 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FR',
#   '',
#   'Texas A&M',
#   '51.02 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ["(23) Jan'Taijah FORDJRSouthern California51.03 3/11/2023",
#   "(23) Jan'Taijah FORDJR",
#   '',
#   'Southern California',
#   '51.03 ',
#   '3/11/2023'],
#  ["(23) Jan'Taijah FORDJR", '', 'Southern California', '51.03 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Mu {3}FRTexas A&M51.03 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Mu {3}FR',
#   '',
#   'Texas A&M',
#   '51.03 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Mu {3}FR', '', 'Texas A&M', '51.03 ', '3/13/2021'],
#  ['(24) Regina GEORGESRArkansas51.05 3/9/2013\xa0\xa0\xa0\xa0\xa024.51, 27.87',
#   '(24) Regina GEORGESR',
#   '',
#   'Arkansas',
#   '51.05 ',
#   '3/9/2013',
#   '\xa0\xa0\xa0\xa0\xa024.51, 27.87'],
#  ['(24) Regina GEORGESR', '', 'Arkansas', '51.05 ', '3/9/2013'],
#  ['(24) Maicel MALONEArizona State51.05  3/9/1991',
#   '(24) Maicel MALONE',
#   '',
#   'Arizona State',
#   '51.05  ',
#   '3/9/1991']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Britton WILSONSOArkansas49.48📺 3/11/2023',
#   '(1) Britton WILSONSO',
#   '',
#   'Arkansas',
#   '49.48📺 ',
#   '3/11/2023'],
#  ['(2) Talitha DIGGSSOFlorida50.15📺 2/25/2023',
#   '(2) Talitha DIGGSSO',
#   '',
#   'Florida',
#   '50.15📺 ',
#   '2/25/2023'],
#  ['(3) Rhasidat ADELEKESOTexas50.33📺 2/24/2023',
#   '(3) Rhasidat ADELEKESO',
#   '',
#   'Texas',
#   '50.33📺 ',
#   '2/24/2023'],
#  ['(4) Kendall ELLISSRSouthern California50.34📺 3/10/2018\xa0\xa0\xa0\xa0\xa023.63, 26.71',
#   '(4) Kendall ELLISSR',
#   '',
#   'Southern California',
#   '50.34📺 ',
#   '3/10/2018',
#   '\xa0\xa0\xa0\xa0\xa023.63, 26.71'],
#  ['(5) Sydney MCLAUGHLINFRKentucky50.36 3/10/2018\xa0\xa0\xa0\xa0\xa023.73, 26.63',
#   '(5) Sydney MCLAUGHLINFR',
#   '',
#   'Kentucky',
#   '50.36 ',
#   '3/10/2018',
#   '\xa0\xa0\xa0\xa0\xa023.73, 26.63'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {2}SOTexas50.45 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {2}SO',
#   '',
#   'Texas',
#   '50.45 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Adeleke {3}SOTexas50.45 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Adeleke {3}SO',
#   '',
#   'Texas',
#   '50.45 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['(6) Phyllis FRANCISOregon50.46 AA = Performance occurred at altitude (>1000 meters above sea level) 3/15/2014\xa0\xa0\xa0\xa0\xa024.17/26.29',
#   '(6) Phyllis FRANCIS',
#   '',
#   'Oregon',
#   '50.46 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014',
#   '\xa0\xa0\xa0\xa0\xa024.17/26.29'],
#  ['\xa0\xa0\xa0\xa0— Diggs {2}SOFlorida50.49 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Diggs {2}SO',
#   '',
#   'Florida',
#   '50.49 ',
#   '3/11/2023'],
#  ['(7) Athing MUFRTexas A&M50.52 2/6/2021',
#   '(7) Athing MUFR',
#   '',
#   'Texas A&M',
#   '50.52 ',
#   '2/6/2021'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {2}FRKentucky50.52 bb = Performance occurred on a 200m/220yd banked track 2/25/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {2}FR',
#   '',
#   'Kentucky',
#   '50.52 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/25/2018'],
#  ['(8) Rosey EFFIONGJRArkansas50.54 3/11/2023',
#   '(8) Rosey EFFIONGJR',
#   '',
#   'Arkansas',
#   '50.54 ',
#   '3/11/2023'],
#  ['(8) Francena MCCORORYHampton50.54 3/13/2010',
#   '(8) Francena MCCORORY',
#   '',
#   'Hampton',
#   '50.54 ',
#   '3/13/2010'],
#  ['(10) Lynna IRBYFRGeorgia50.62 bb = Performance occurred on a 200m/220yd banked track 2/25/2018',
#   '(10) Lynna IRBYFR',
#   '',
#   'Georgia',
#   '50.62 bb = Performance occurred on a 200m/220yd banked track ',
#   '2/25/2018'],
#  ['(11) Amber ANNINGJRArkansas50.68 2/25/2023',
#   '(11) Amber ANNINGJR',
#   '',
#   'Arkansas',
#   '50.68 ',
#   '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}SOArkansas50.69📺 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}SO',
#   '',
#   'Arkansas',
#   '50.69📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(12) Courtney OKOLOSRTexas50.69 ii = event moved indoors because of weather or another issue. 3/12/2016',
#   '(12) Courtney OKOLOSR',
#   '',
#   'Texas',
#   '50.69 ii = event moved indoors because of weather or another issue. ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Okolo {2}SRTexas50.69📺 bb = Performance occurred on a 200m/220yd banked track 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Okolo {2}SR',
#   '',
#   'Texas',
#   '50.69📺 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/12/2016'],
#  ['(13) Alexis HOLMESJRKentucky50.77 2/26/2022',
#   '(13) Alexis HOLMESJR',
#   '',
#   'Kentucky',
#   '50.77 ',
#   '2/26/2022'],
#  ['\xa0\xa0\xa0\xa0— Diggs {3}SOFlorida50.79📺 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Diggs {3}SO',
#   '',
#   'Florida',
#   '50.79📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(14) Jessica BEARDTexas A&M50.79 3/12/2011',
#   '(14) Jessica BEARD',
#   '',
#   'Texas A&M',
#   '50.79 ',
#   '3/12/2011'],
#  ['(15) Natasha HASTINGSJRSouth Carolina50.80  3/10/2007',
#   '(15) Natasha HASTINGSJR',
#   '',
#   'South Carolina',
#   '50.80  ',
#   '3/10/2007'],
#  ['(16) Sanya RICHARDSSOTexas50.82  3/13/2004',
#   '(16) Sanya RICHARDSSO',
#   '',
#   'Texas',
#   '50.82  ',
#   '3/13/2004'],
#  ['(17) Kaelin ROBERTSSRSouthern California50.84 3/13/2021',
#   '(17) Kaelin ROBERTSSR',
#   '',
#   'Southern California',
#   '50.84 ',
#   '3/13/2021'],
#  ['\xa0\xa0\xa0\xa0— Irby {2}FRGeorgia50.87 3/10/2018\xa0\xa0\xa0\xa0\xa023.59, 27.28',
#   '\xa0\xa0\xa0\xa0— Irby {2}FR',
#   '',
#   'Georgia',
#   '50.87 ',
#   '3/10/2018',
#   '\xa0\xa0\xa0\xa0\xa023.59, 27.28'],
#  ['\xa0\xa0\xa0\xa0— Wilson {3}FRArkansas50.88 2/26/2022',
#   '\xa0\xa0\xa0\xa0— Wilson {3}FR',
#   '',
#   'Arkansas',
#   '50.88 ',
#   '2/26/2022'],
#  ['(18) Shaunae MILLERFRGeorgia50.88 3/9/2013\xa0\xa0\xa0\xa0\xa023.52, 27.36',
#   '(18) Shaunae MILLERFR',
#   '',
#   'Georgia',
#   '50.88 ',
#   '3/9/2013',
#   '\xa0\xa0\xa0\xa0\xa023.52, 27.36'],
#  ['(19) Tiandra PONTEENSOFlorida50.91  3/12/2005',
#   '(19) Tiandra PONTEENSO',
#   '',
#   'Florida',
#   '50.91  ',
#   '3/12/2005'],
#  ['(20) Hazel-Ann REGISSRLSU50.92  3/12/2005',
#   '(20) Hazel-Ann REGISSR',
#   '',
#   'LSU',
#   '50.92  ',
#   '3/12/2005'],
#  ['(21) Kamaria BROWNJRTexas A&M50.94 bb = Performance occurred on a 200m/220yd banked track 3/1/2014',
#   '(21) Kamaria BROWNJR',
#   '',
#   'Texas A&M',
#   '50.94 bb = Performance occurred on a 200m/220yd banked track ',
#   '3/1/2014'],
#  ['\xa0\xa0\xa0\xa0— McLaughlin {3}FRKentucky50.97 bb = Performance occurred on a 200m/220yd banked trackqq = Performance occurred during a non-final round. 2/25/2018',
#   '\xa0\xa0\xa0\xa0— McLaughlin {3}FR',
#   '',
#   'Kentucky',
#   '50.97 bb = Performance occurred on a 200m/220yd banked trackqq = Performance occurred during a non-final round. ',
#   '2/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Diggs {4}FRFlorida50.98 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Diggs {4}FR',
#   '',
#   'Florida',
#   '50.98 ',
#   '3/12/2022'],
#  ['(22) Kennedy SIMONSRTexas51.01 2/24/2023',
#   '(22) Kennedy SIMONSR',
#   '',
#   'Texas',
#   '51.01 ',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Effiong {2}JRArkansas51.02 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Effiong {2}JR',
#   '',
#   'Arkansas',
#   '51.02 ',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Mu {2}FRTexas A&M51.02 qq = Performance occurred during a non-final round. 3/12/2021',
#   '\xa0\xa0\xa0\xa0— Mu {2}FR',
#   '',
#   'Texas A&M',
#   '51.02 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ["(23) Jan'Taijah FORDJRSouthern California51.03 3/11/2023",
#   "(23) Jan'Taijah FORDJR",
#   '',
#   'Southern California',
#   '51.03 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Mu {3}FRTexas A&M51.03 3/13/2021',
#   '\xa0\xa0\xa0\xa0— Mu {3}FR',
#   '',
#   'Texas A&M',
#   '51.03 ',
#   '3/13/2021'],
#  ['(24) Regina GEORGESRArkansas51.05 3/9/2013\xa0\xa0\xa0\xa0\xa024.51, 27.87',
#   '(24) Regina GEORGESR',
#   '',
#   'Arkansas',
#   '51.05 ',
#   '3/9/2013',
#   '\xa0\xa0\xa0\xa0\xa024.51, 27.87'],
#  ['(24) Maicel MALONEArizona State51.05  3/9/1991',
#   '(24) Maicel MALONE',
#   '',
#   'Arizona State',
#   '51.05  ',
#   '3/9/1991']]

# %%
RealRealRows[1][4]
# Out:
# '50.15📺 '

# %%
len(RealRealRows)
# Out:
# 39

# %%
OfficialTimes = []

# %%
for i in range(0,len(RealRealRows)):
    OfficialTimes.append(RealRealRows[i][4])
OfficialTimes
# Out:
# ['49.48📺 ',
#  '50.15📺 ',
#  '50.33📺 ',
#  '50.34📺 ',
#  '50.36 ',
#  '50.45 ',
#  '50.45 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '50.46 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '50.49 ',
#  '50.52 ',
#  '50.52 bb = Performance occurred on a 200m/220yd banked track ',
#  '50.54 ',
#  '50.54 ',
#  '50.62 bb = Performance occurred on a 200m/220yd banked track ',
#  '50.68 ',
#  '50.69📺 qq = Performance occurred during a non-final round. ',
#  '50.69 ii = event moved indoors because of weather or another issue. ',
#  '50.69📺 bb = Performance occurred on a 200m/220yd banked track ',
#  '50.77 ',
#  '50.79📺 qq = Performance occurred during a non-final round. ',
#  '50.79 ',
#  '50.80  ',
#  '50.82  ',
#  '50.84 ',
#  '50.87 ',
#  '50.88 ',
#  '50.88 ',
#  '50.91  ',
#  '50.92  ',
#  '50.94 bb = Performance occurred on a 200m/220yd banked track ',
#  '50.97 bb = Performance occurred on a 200m/220yd banked trackqq = Performance occurred during a non-final round. ',
#  '50.98 ',
#  '51.01 ',
#  '51.02 ',
#  '51.02 qq = Performance occurred during a non-final round. ',
#  '51.03 ',
#  '51.03 ',
#  '51.05 ',
#  '51.05  ']

# %%
RealRealRows[0][1]
# Out:
# '(1) Britton WILSONSO'

# %%
Names = []

for i in range(0,len(RealRealRows)):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Britton WILSONSO',
#  '(2) Talitha DIGGSSO',
#  '(3) Rhasidat ADELEKESO',
#  '(4) Kendall ELLISSR',
#  '(5) Sydney MCLAUGHLINFR',
#  '\xa0\xa0\xa0\xa0— Adeleke {2}SO',
#  '\xa0\xa0\xa0\xa0— Adeleke {3}SO',
#  '(6) Phyllis FRANCIS',
#  '\xa0\xa0\xa0\xa0— Diggs {2}SO',
#  '(7) Athing MUFR',
#  '\xa0\xa0\xa0\xa0— McLaughlin {2}FR',
#  '(8) Rosey EFFIONGJR',
#  '(8) Francena MCCORORY',
#  '(10) Lynna IRBYFR',
#  '(11) Amber ANNINGJR',
#  '\xa0\xa0\xa0\xa0— Wilson {2}SO',
#  '(12) Courtney OKOLOSR',
#  '\xa0\xa0\xa0\xa0— Okolo {2}SR',
#  '(13) Alexis HOLMESJR',
#  '\xa0\xa0\xa0\xa0— Diggs {3}SO',
#  '(14) Jessica BEARD',
#  '(15) Natasha HASTINGSJR',
#  '(16) Sanya RICHARDSSO',
#  '(17) Kaelin ROBERTSSR',
#  '\xa0\xa0\xa0\xa0— Irby {2}FR',
#  '\xa0\xa0\xa0\xa0— Wilson {3}FR',
#  '(18) Shaunae MILLERFR',
#  '(19) Tiandra PONTEENSO',
#  '(20) Hazel-Ann REGISSR',
#  '(21) Kamaria BROWNJR',
#  '\xa0\xa0\xa0\xa0— McLaughlin {3}FR',
#  '\xa0\xa0\xa0\xa0— Diggs {4}FR',
#  '(22) Kennedy SIMONSR',
#  '\xa0\xa0\xa0\xa0— Effiong {2}JR',
#  '\xa0\xa0\xa0\xa0— Mu {2}FR',
#  "(23) Jan'Taijah FORDJR",
#  '\xa0\xa0\xa0\xa0— Mu {3}FR',
#  '(24) Regina GEORGESR',
#  '(24) Maicel MALONE']

# %%
OfficialReGexNames = []

# %%
for i in range(0,39):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Britton WILSONSO',
#  '(2) Talitha DIGGSSO',
#  '(3) Rhasidat ADELEKESO',
#  '(4) Kendall ELLISSR',
#  '(5) Sydney MCLAUGHLINFR',
#  '— Adeleke {2}SO',
#  '— Adeleke {3}SO',
#  '(6) Phyllis FRANCIS',
#  '— Diggs {2}SO',
#  '(7) Athing MUFR',
#  '— McLaughlin {2}FR',
#  '(8) Rosey EFFIONGJR',
#  '(8) Francena MCCORORY',
#  '(10) Lynna IRBYFR',
#  '(11) Amber ANNINGJR',
#  '— Wilson {2}SO',
#  '(12) Courtney OKOLOSR',
#  '— Okolo {2}SR',
#  '(13) Alexis HOLMESJR',
#  '— Diggs {3}SO',
#  '(14) Jessica BEARD',
#  '(15) Natasha HASTINGSJR',
#  '(16) Sanya RICHARDSSO',
#  '(17) Kaelin ROBERTSSR',
#  '— Irby {2}FR',
#  '— Wilson {3}FR',
#  '(18) Shaunae MILLERFR',
#  '(19) Tiandra PONTEENSO',
#  '(20) Hazel-Ann REGISSR',
#  '(21) Kamaria BROWNJR',
#  '— McLaughlin {3}FR',
#  '— Diggs {4}FR',
#  '(22) Kennedy SIMONSR',
#  '— Effiong {2}JR',
#  '— Mu {2}FR',
#  "(23) Jan'Taijah FORDJR",
#  '— Mu {3}FR',
#  '(24) Regina GEORGESR',
#  '(24) Maicel MALONE']

# %%
CleanedNames = []

for i in range(0,len(RealRealRows)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Britton WILSONSO',
#  'Talitha DIGGSSO',
#  'Rhasidat ADELEKESO',
#  'Kendall ELLISSR',
#  'Sydney MCLAUGHLINFR',
#  'Adeleke {2}SO',
#  'Adeleke {3}SO',
#  'Phyllis FRANCIS',
#  'Diggs {2}SO',
#  'Athing MUFR',
#  'McLaughlin {2}FR',
#  'Rosey EFFIONGJR',
#  'Francena MCCORORY',
#  ' Lynna IRBYFR',
#  ' Amber ANNINGJR',
#  'Wilson {2}SO',
#  ' Courtney OKOLOSR',
#  'Okolo {2}SR',
#  ' Alexis HOLMESJR',
#  'Diggs {3}SO',
#  ' Jessica BEARD',
#  ' Natasha HASTINGSJR',
#  ' Sanya RICHARDSSO',
#  ' Kaelin ROBERTSSR',
#  'Irby {2}FR',
#  'Wilson {3}FR',
#  ' Shaunae MILLERFR',
#  ' Tiandra PONTEENSO',
#  ' Hazel-Ann REGISSR',
#  ' Kamaria BROWNJR',
#  'McLaughlin {3}FR',
#  'Diggs {4}FR',
#  ' Kennedy SIMONSR',
#  'Effiong {2}JR',
#  'Mu {2}FR',
#  " Jan'Taijah FORDJR",
#  'Mu {3}FR',
#  ' Regina GEORGESR',
#  ' Maicel MALONE']

# %%
CleanedNames2 = []

for i in range(0,len(RealRealRows)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Britton WILSONSO',
#  'Talitha DIGGSSO',
#  'Rhasidat ADELEKESO',
#  'Kendall ELLISSR',
#  'Sydney MCLAUGHLINFR',
#  'Adeleke {2}SO',
#  'Adeleke {3}SO',
#  'Phyllis FRANCIS',
#  'Diggs {2}SO',
#  'Athing MUFR',
#  'McLaughlin {2}FR',
#  'Rosey EFFIONGJR',
#  'Francena MCCORORY',
#  'Lynna IRBYFR',
#  'Amber ANNINGJR',
#  'Wilson {2}SO',
#  'Courtney OKOLOSR',
#  'Okolo {2}SR',
#  'Alexis HOLMESJR',
#  'Diggs {3}SO',
#  'Jessica BEARD',
#  'Natasha HASTINGSJR',
#  'Sanya RICHARDSSO',
#  'Kaelin ROBERTSSR',
#  'Irby {2}FR',
#  'Wilson {3}FR',
#  'Shaunae MILLERFR',
#  'Tiandra PONTEENSO',
#  'Hazel-Ann REGISSR',
#  'Kamaria BROWNJR',
#  'McLaughlin {3}FR',
#  'Diggs {4}FR',
#  'Kennedy SIMONSR',
#  'Effiong {2}JR',
#  'Mu {2}FR',
#  "Jan'Taijah FORDJR",
#  'Mu {3}FR',
#  'Regina GEORGESR',
#  'Maicel MALONE']

# %%
len(OfficialTimes)
# Out:
# 39

# %%
len(OfficialReGexNames)
# Out:
# 39

# %%
Times = []

# %%
for i in range(0,len(OfficialTimes)):
    Times.append(OfficialTimes[i][:5])
    
Times
# Out:
# ['49.48',
#  '50.15',
#  '50.33',
#  '50.34',
#  '50.36',
#  '50.45',
#  '50.45',
#  '50.46',
#  '50.49',
#  '50.52',
#  '50.52',
#  '50.54',
#  '50.54',
#  '50.62',
#  '50.68',
#  '50.69',
#  '50.69',
#  '50.69',
#  '50.77',
#  '50.79',
#  '50.79',
#  '50.80',
#  '50.82',
#  '50.84',
#  '50.87',
#  '50.88',
#  '50.88',
#  '50.91',
#  '50.92',
#  '50.94',
#  '50.97',
#  '50.98',
#  '51.01',
#  '51.02',
#  '51.02',
#  '51.03',
#  '51.03',
#  '51.05',
#  '51.05']

# %%
Schools = []

for i in range(0,len(OfficialTimes)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Arkansas',
#  'Florida',
#  'Texas',
#  'Southern California',
#  'Kentucky',
#  'Texas',
#  'Texas',
#  'Oregon',
#  'Florida',
#  'Texas A&M',
#  'Kentucky',
#  'Arkansas',
#  'Hampton',
#  'Georgia',
#  'Arkansas',
#  'Arkansas',
#  'Texas',
#  'Texas',
#  'Kentucky',
#  'Florida',
#  'Texas A&M',
#  'South Carolina',
#  'Texas',
#  'Southern California',
#  'Georgia',
#  'Arkansas',
#  'Georgia',
#  'Florida',
#  'LSU',
#  'Texas A&M',
#  'Kentucky',
#  'Florida',
#  'Texas',
#  'Arkansas',
#  'Texas A&M',
#  'Southern California',
#  'Texas A&M',
#  'Arkansas',
#  'Arizona State']

# %%
Womens400mDF = pd.DataFrame({'Names': CleanedNames2, 'Times': Times, 'Schools': Schools})

# %%
Womens400mDF.to_csv('IndoorWomens400m.csv', index=False)
