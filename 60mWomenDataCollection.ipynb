# %%
import math
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import lxml
import re
from random import seed
from collections import Counter
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import array
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import findspark
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import desc
# Out:
# C:\Users\MoJo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
Link60mWomen = "http://www.ustfccca.org/records-lists/outdoor-collegiate-all-time-bests?sport=1&gender=2&div=20527&top=25&event=1"

# %%
page = requests.get(Link60mWomen)
soup = BeautifulSoup(page.text,'html')
soup

table = soup.find("table")

# %%
Header = soup.findAll('th')
Headers = []
for h in Header:
    Headers.append(h.text)

# %%
Headers
# Out:
# ['Athlete', 'Institution', 'Mark', 'Date', '']

# %%
row_soup = soup.findAll('tr')

# %%
row_soup
# Out:
# [<tr><th style="width: 35%;">Athlete</th><th colspan="2" style="width: 30%;">Institution</th><th style="width: 25%;">Mark</th><th style="width: 10%;">Date</th><th></th></tr>,
#  <tr><td colspan="100" style="font-weight: bolder;">UNOFFICIAL Top 25 Performers and Performances</td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7087489" target="_blank">(1) Julien ALFRED</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720934" target="_blank">6.94</a><a href="https://www.youtube.com/watch?v=DRVqmj28XFc" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7087489" target="_blank">(1) Julien ALFRED</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720934" target="_blank">6.94</a><a href="https://www.youtube.com/watch?v=DRVqmj28XFc" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720934" target="_blank">6.96</a><a href="https://www.youtube.com/watch?v=w6i8ZYeRuxI" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720934" target="_blank">6.96</a><a href="https://www.youtube.com/watch?v=w6i8ZYeRuxI" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77924/4693817" target="_blank">6.97</a><a href="https://twitter.com/TexasTechTF/status/1629578246781108225" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77924/4693817" target="_blank">6.97</a><a href="https://twitter.com/TexasTechTF/status/1629578246781108225" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {4}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76085/4659558" target="_blank">7.00</a><a href="https://twitter.com/FloTrack/status/1621984806274842625" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="New Mexico Collegiate Classic (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/3/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {4}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76085/4659558" target="_blank">7.00</a><a href="https://twitter.com/FloTrack/status/1621984806274842625" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="New Mexico Collegiate Classic (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/3/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {5}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75270/4638885" target="_blank">7.02</a><a href="https://twitter.com/TexasTFXC/status/1616908385076809728" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="Martin Luther King, Jr. Invitational (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">1/21/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {5}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75270/4638885" target="_blank">7.02</a><a href="https://twitter.com/TexasTFXC/status/1616908385076809728" target="_blank">📺</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="Martin Luther King, Jr. Invitational (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">1/21/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {6}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77924/4693817" target="_blank">7.03</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {6}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77924/4693817" target="_blank">7.03</a> </td><td style="width: 10%;text-align:right;" title="Big 12 Indoor Championships (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7534774" target="_blank">(2) Jacious SEARS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720934" target="_blank">7.04</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7534774" target="_blank">(2) Jacious SEARS</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Tennessee" class="group-logo-inline" src="/images/logos/rankings-article/tennessee.png" title="Tennessee"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1553">Tennessee</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720934" target="_blank">7.04</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {7}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416346" target="_blank">7.04</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {7}</span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416346" target="_blank">7.04</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {8}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76085/4659558" target="_blank">7.05</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="New Mexico Collegiate Classic (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/3/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {8}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/76085/4659558" target="_blank">7.05</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="New Mexico Collegiate Classic (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/3/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Alfred {9}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75270/4638885" target="_blank">7.05</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="Martin Luther King, Jr. Invitational (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">1/21/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Alfred {9}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas" class="group-logo-inline" src="/images/logos/rankings-article/texas.png" title="Texas"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1558">Texas</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/75270/4638885" target="_blank">7.05</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="Martin Luther King, Jr. Invitational (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">1/21/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7722970" target="_blank">(3) Kemba NELSON</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118002" target="_blank">7.05</a><a href="https://www.youtube.com/watch?v=X5vazdWu_lo" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7722970" target="_blank">(3) Kemba NELSON</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/68220/4118002" target="_blank">7.05</a><a href="https://www.youtube.com/watch?v=X5vazdWu_lo" target="_blank">📺</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/13/2021</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8235201" target="_blank">(4) Kaila JACKSON</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720934" target="_blank">7.07</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8235201" target="_blank">(4) Kaila JACKSON</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720934" target="_blank">7.07</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7722969" target="_blank">(4) Jadyn MAYS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720934" target="_blank">7.07</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7722969" target="_blank">(4) Jadyn MAYS</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720934" target="_blank">7.07</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/10/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8107788" target="_blank">(4) Samirah MOODY</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77618/4693686" target="_blank">7.07</a> </td><td style="width: 10%;text-align:right;" title="Ken Shannon Invitational (Seattle, Wash.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8107788" target="_blank">(4) Samirah MOODY</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Southern California" class="group-logo-inline" src="/images/logos/rankings-article/southern-california.png" title="Southern California"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1432">Southern California</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77618/4693686" target="_blank">7.07</a> </td><td style="width: 10%;text-align:right;" title="Ken Shannon Invitational (Seattle, Wash.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">2/24/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5122093" target="_blank">(4) Aleia HOBBS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335556" target="_blank">7.07</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5122093" target="_blank">(4) Aleia HOBBS</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335556" target="_blank">7.07</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5640210" target="_blank">(4) Hannah CUNLIFFE</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/48729" target="_blank">7.07</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="Don Kirby Collegiate Elite (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;">2/11/2017</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5640210" target="_blank">(4) Hannah CUNLIFFE</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/48729" target="_blank">7.07</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="Don Kirby Collegiate Elite (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;">2/11/2017</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Jackson {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720934" target="_blank">7.08</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Jackson {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Georgia" class="group-logo-inline" src="/images/logos/rankings-article/georgia.png" title="Georgia"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=573">Georgia</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/78382/4720934" target="_blank">7.08</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">3/11/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5122060" target="_blank">(9) Mikiah BRISCO</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51964" target="_blank">7.08</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="New Mexico Collegiate Classic (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;">2/3/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/5122060" target="_blank">(9) Mikiah BRISCO</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/51964" target="_blank">7.08</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="New Mexico Collegiate Classic (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;">2/3/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4638070" target="_blank">(9) Remona BURCHELL</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/36571" target="_blank">7.08</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">2/28/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4638070" target="_blank">(9) Remona BURCHELL</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/36571" target="_blank">7.08</a> </td><td style="width: 10%;text-align:right;" title="SEC Indoor Championships (Lexington, Ky.)"><span class="mark-date" style="width: 10%;text-align:right;">2/28/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7548443" target="_blank">(11) Rosemary CHUKWUMA</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77195/4648906" target="_blank">7.09</a> </td><td style="width: 10%;text-align:right;" title="Texas Tech Open &amp; Multis (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">1/26/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7548443" target="_blank">(11) Rosemary CHUKWUMA</a></span><span style="float:right;font-size:0.9em;">JR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Texas Tech" class="group-logo-inline" src="/images/logos/rankings-article/texas-tech.png" title="Texas Tech"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1569">Texas Tech</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77195/4648906" target="_blank">7.09</a> </td><td style="width: 10%;text-align:right;" title="Texas Tech Open &amp; Multis (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">1/26/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8114808" target="_blank">(11) Kiara GRANT</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=311">Clemson</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77002/4635835" target="_blank">7.09</a> </td><td style="width: 10%;text-align:right;" title="Texas Tech Red Raider Open (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">1/20/2023</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/8114808" target="_blank">(11) Kiara GRANT</a></span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Clemson" class="group-logo-inline" src="/images/logos/rankings-article/clemson.png" title="Clemson"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=311">Clemson</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/77002/4635835" target="_blank">7.09</a> </td><td style="width: 10%;text-align:right;" title="Texas Tech Red Raider Open (Lubbock, Texas)"><span class="mark-date" style="width: 10%;text-align:right;background: lightblue; color: black; font-weight: bold;">1/20/2023</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7540568" target="_blank">(11) Melissa JEFFERSON</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Coastal Carolina" class="group-logo-inline" src="/images/logos/rankings-article/coastal-carolina.png" title="Coastal Carolina"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=320">Coastal Carolina</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416346" target="_blank">7.09</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7540568" target="_blank">(11) Melissa JEFFERSON</a></span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Coastal Carolina" class="group-logo-inline" src="/images/logos/rankings-article/coastal-carolina.png" title="Coastal Carolina"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=320">Coastal Carolina</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416346" target="_blank">7.09</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2022</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Mays {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416346" target="_blank">7.09</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2022</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Mays {2}</span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/73365/4416346" target="_blank">7.09</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2022</span></td></tr>,
# ...
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7026466" target="_blank">(23) Natalliah WHYTE</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=74">Auburn</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335556" target="_blank">7.12</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/7026466" target="_blank">(23) Natalliah WHYTE</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Auburn" class="group-logo-inline" src="/images/logos/rankings-article/auburn.png" title="Auburn"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=74">Auburn</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335556" target="_blank">7.12</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Hobbs {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335556" target="_blank">7.12</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Hobbs {2}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/54721/3335556" target="_blank">7.12</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (College Station, Texas)"><span class="mark-date" style="width: 10%;text-align:right;">3/9/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Hobbs {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/52327/3285911" target="_blank">7.12</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/9/2018</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Hobbs {3}</span><span style="float:right;font-size:0.9em;">SR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="LSU" class="group-logo-inline" src="/images/logos/rankings-article/lsu.png" title="LSU"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=869">LSU</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/52327/3285911" target="_blank">7.12</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="Tyson Invitational (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">2/9/2018</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Cunliffe {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702407" target="_blank">7.12</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Cunliffe {2}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702407" target="_blank">7.12</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/12/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Cunliffe {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702407" target="_blank">7.12</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2016</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Cunliffe {3}</span><span style="float:right;font-size:0.9em;">SO</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/44282/2702407" target="_blank">7.12</a> <span class="tooltip" style="font-size: smaller;">q<span class="tooltiptext" style="font-size: smaller;">q = Performance occurred during a non-final round.</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Birmingham, Ala.)"><span class="mark-date" style="width: 10%;text-align:right;">3/11/2016</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span>    — Burchell {3}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/39148/2390358" target="_blank">7.12</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/14/2015</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span>    — Burchell {3}</span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Alabama" class="group-logo-inline" src="/images/logos/rankings-article/alabama.png" title="Alabama"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=12">Alabama</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/39148/2390358" target="_blank">7.12</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Fayetteville, Ark.)"><span class="mark-date" style="width: 10%;text-align:right;">3/14/2015</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4513695" target="_blank">(23) Dezerea BRYANT</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/34001/2083796" target="_blank">7.12</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;">3/15/2014</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/4513695" target="_blank">(23) Dezerea BRYANT</a></span><span style="float:right;font-size:0.9em;"></span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Kentucky" class="group-logo-inline" src="/images/logos/rankings-article/kentucky.png" title="Kentucky"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=770">Kentucky</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/34001/2083796" target="_blank">7.12</a> <span class="tooltip" style="font-size: smaller;">A<span class="tooltiptext" style="font-size: smaller;">A = Performance occurred at altitude (&gt;1000 meters above sea level)</span></span> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Albuquerque, N.M.)"><span class="mark-date" style="width: 10%;text-align:right;">3/15/2014</span></td></tr>,
#  <tr><td colspan="5"><div class="container-table" style="width: 100%;"><table class="embed" width="100%"><thead><tr></tr></thead><tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3272976" target="_blank">(23) English GARDNER</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/24457" target="_blank">7.12</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Nampa, Idaho)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2012</span></td></tr></table></div></td></tr>,
#  <tr></tr>,
#  <tr><td style="width: 35%;"><span><a href="https://tfrrs.org/athletes/3272976" target="_blank">(23) English GARDNER</a></span><span style="float:right;font-size:0.9em;background-color: lightcyan;">FR</span></td><td style="width: 5%;"><span class="group-logo-inline"><img alt="Oregon" class="group-logo-inline" src="/images/logos/rankings-article/oregon.png" title="Oregon"/></span></td><td style="width: 25%;"><a href="/records-lists/outdoor-collegiate-all-time-bests?sport=1&amp;gender=2&amp;div=20527&amp;top=25&amp;event=1&amp;team=1180">Oregon</a></td><td style="width: 25%;"><a href="https://www.tfrrs.org/results/24457" target="_blank">7.12</a> </td><td style="width: 10%;text-align:right;" title="NCAA Division I Indoor Championships (Nampa, Idaho)"><span class="mark-date" style="width: 10%;text-align:right;">3/10/2012</span></td></tr>,
#  <tr>
#  <td align="center" width="25%"><a href="https://twitter.com/USTFCCCA"><img src="/images/sidebar/twitter-logo-new.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.facebook.com/USTFCCCA/"><img src="/images/sidebar/facebook-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="https://www.instagram.com/ustfccca/?hl=en"><img src="/images/sidebar/instagram-logo.png"/></a></td>
#  <td align="center" width="25%"><a href="/ustfccca-calendar"><img src="/images/sidebar/calendar-logo.png"/></a></td>
#  </tr>]

# %%
rows = []
for row in row_soup:
    row_data = []
    for cell in row.findAll('td'):
        row_data.append(cell.text)
    rows.append(row_data)

# %%
rows
# Out:
# [[],
#  ['UNOFFICIAL Top 25 Performers and Performances'],
#  ['(1) Julien ALFREDSRTexas6.94📺 3/11/2023',
#   '(1) Julien ALFREDSR',
#   '',
#   'Texas',
#   '6.94📺 ',
#   '3/11/2023'],
#  [],
#  ['(1) Julien ALFREDSR', '', 'Texas', '6.94📺 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}SRTexas6.96📺 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {2}SR',
#   '',
#   'Texas',
#   '6.96📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}SR',
#   '',
#   'Texas',
#   '6.96📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}SRTexas6.97📺 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {3}SR',
#   '',
#   'Texas',
#   '6.97📺 ',
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}SR', '', 'Texas', '6.97📺 ', '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SRTexas7.00📺 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {4}SR',
#   '',
#   'Texas',
#   '7.00📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SR',
#   '',
#   'Texas',
#   '7.00📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {5}SRTexas7.02📺 AA = Performance occurred at altitude (>1000 meters above sea level) 1/21/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {5}SR',
#   '',
#   'Texas',
#   '7.02📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {5}SR',
#   '',
#   'Texas',
#   '7.02📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {6}SRTexas7.03 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {6}SR',
#   '',
#   'Texas',
#   '7.03 ',
#   '2/24/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {6}SR', '', 'Texas', '7.03 ', '2/24/2023'],
#  ['(2) Jacious SEARSJRTennessee7.04 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(2) Jacious SEARSJR',
#   '',
#   'Tennessee',
#   '7.04 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['(2) Jacious SEARSJR',
#   '',
#   'Tennessee',
#   '7.04 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {7}JRTexas7.04 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Alfred {7}JR',
#   '',
#   'Texas',
#   '7.04 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {7}JR',
#   '',
#   'Texas',
#   '7.04 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {8}SRTexas7.05 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {8}SR',
#   '',
#   'Texas',
#   '7.05 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {8}SR',
#   '',
#   'Texas',
#   '7.05 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {9}SRTexas7.05 AA = Performance occurred at altitude (>1000 meters above sea level) 1/21/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {9}SR',
#   '',
#   'Texas',
#   '7.05 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {9}SR',
#   '',
#   'Texas',
#   '7.05 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  ['(3) Kemba NELSONJROregon7.05📺 3/13/2021',
#   '(3) Kemba NELSONJR',
#   '',
#   'Oregon',
#   '7.05📺 ',
#   '3/13/2021'],
#  [],
#  ['(3) Kemba NELSONJR', '', 'Oregon', '7.05📺 ', '3/13/2021'],
#  ['(4) Kaila JACKSONFRGeorgia7.07 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(4) Kaila JACKSONFR',
#   '',
#   'Georgia',
#   '7.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['(4) Kaila JACKSONFR',
#   '',
#   'Georgia',
#   '7.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(4) Jadyn MAYSSOOregon7.07 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(4) Jadyn MAYSSO',
#   '',
#   'Oregon',
#   '7.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['(4) Jadyn MAYSSO',
#   '',
#   'Oregon',
#   '7.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(4) Samirah MOODYSOSouthern California7.07 2/24/2023',
#   '(4) Samirah MOODYSO',
#   '',
#   'Southern California',
#   '7.07 ',
#   '2/24/2023'],
#  [],
#  ['(4) Samirah MOODYSO', '', 'Southern California', '7.07 ', '2/24/2023'],
#  ['(4) Aleia HOBBSSRLSU7.07 3/10/2018',
#   '(4) Aleia HOBBSSR',
#   '',
#   'LSU',
#   '7.07 ',
#   '3/10/2018'],
#  [],
#  ['(4) Aleia HOBBSSR', '', 'LSU', '7.07 ', '3/10/2018'],
#  ['(4) Hannah CUNLIFFEJROregon7.07 AA = Performance occurred at altitude (>1000 meters above sea level) 2/11/2017',
#   '(4) Hannah CUNLIFFEJR',
#   '',
#   'Oregon',
#   '7.07 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/11/2017'],
#  [],
#  ['(4) Hannah CUNLIFFEJR',
#   '',
#   'Oregon',
#   '7.07 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/11/2017'],
#  ['\xa0\xa0\xa0\xa0— Jackson {2}FRGeorgia7.08 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Jackson {2}FR',
#   '',
#   'Georgia',
#   '7.08 ',
#   '3/11/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Jackson {2}FR', '', 'Georgia', '7.08 ', '3/11/2023'],
#  ['(9) Mikiah BRISCOSRLSU7.08 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2018',
#   '(9) Mikiah BRISCOSR',
#   '',
#   'LSU',
#   '7.08 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2018'],
#  [],
#  ['(9) Mikiah BRISCOSR',
#   '',
#   'LSU',
#   '7.08 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2018'],
#  ['(9) Remona BURCHELLSRAlabama7.08 2/28/2015',
#   '(9) Remona BURCHELLSR',
#   '',
#   'Alabama',
#   '7.08 ',
#   '2/28/2015'],
#  [],
#  ['(9) Remona BURCHELLSR', '', 'Alabama', '7.08 ', '2/28/2015'],
#  ['(11) Rosemary CHUKWUMAJRTexas Tech7.09 1/26/2023',
#   '(11) Rosemary CHUKWUMAJR',
#   '',
#   'Texas Tech',
#   '7.09 ',
#   '1/26/2023'],
#  [],
#  ['(11) Rosemary CHUKWUMAJR', '', 'Texas Tech', '7.09 ', '1/26/2023'],
#  ['(11) Kiara GRANTSRClemson7.09 1/20/2023',
#   '(11) Kiara GRANTSR',
#   '',
#   'Clemson',
#   '7.09 ',
#   '1/20/2023'],
#  [],
#  ['(11) Kiara GRANTSR', '', 'Clemson', '7.09 ', '1/20/2023'],
#  ['(11) Melissa JEFFERSONSOCoastal Carolina7.09 3/12/2022',
#   '(11) Melissa JEFFERSONSO',
#   '',
#   'Coastal Carolina',
#   '7.09 ',
#   '3/12/2022'],
#  [],
#  ['(11) Melissa JEFFERSONSO', '', 'Coastal Carolina', '7.09 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Mays {2}FROregon7.09 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Mays {2}FR',
#   '',
#   'Oregon',
#   '7.09 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Mays {2}FR',
#   '',
#   'Oregon',
#   '7.09 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(11) Twanisha TERRYSRSouthern California7.09 qq = Performance occurred during a non-final round. 3/12/2021',
#   '(11) Twanisha TERRYSR',
#   '',
#   'Southern California',
#   '7.09 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  [],
#  ['(11) Twanisha TERRYSR',
#   '',
#   'Southern California',
#   '7.09 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ['(11) Lakya BROOKINSSRSouth Carolina7.09 3/12/2011',
#   '(11) Lakya BROOKINSSR',
#   '',
#   'South Carolina',
#   '7.09 ',
#   '3/12/2011'],
#  [],
#  ['(11) Lakya BROOKINSSR', '', 'South Carolina', '7.09 ', '3/12/2011'],
#  ['(11) Angela WILLIAMSJRSouthern California7.09  3/11/2001',
#   '(11) Angela WILLIAMSJR',
#   '',
#   'Southern California',
#   '7.09  ',
#   '3/11/2001'],
#  [],
#  ['(11) Angela WILLIAMSJR', '', 'Southern California', '7.09  ', '3/11/2001'],
#  ['\xa0\xa0\xa0\xa0— Sears {2}JRTennessee7.10 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Sears {2}JR',
#   '',
#   'Tennessee',
#   '7.10 ',
#   '3/11/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Sears {2}JR', '', 'Tennessee', '7.10 ', '3/11/2023'],
#  ['(17) McKenzie LONGSROle Miss7.10 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(17) McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['(17) McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(17) Abby STEINERJRKentucky7.10 3/12/2022',
#   '(17) Abby STEINERJR',
#   '',
#   'Kentucky',
#   '7.10 ',
#   '3/12/2022'],
#  [],
#  ['(17) Abby STEINERJR', '', 'Kentucky', '7.10 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}SOCoastal Carolina7.10 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Jefferson {2}SO',
#   '',
#   'Coastal Carolina',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}SO',
#   '',
#   'Coastal Carolina',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(17) Grace STARKSOFlorida7.10 qq = Performance occurred during a non-final round. 3/11/2022',
#   '(17) Grace STARKSO',
#   '',
#   'Florida',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  [],
#  ['(17) Grace STARKSO',
#   '',
#   'Florida',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {10}JRTexas7.10 1/21/2022',
#   '\xa0\xa0\xa0\xa0— Alfred {10}JR',
#   '',
#   'Texas',
#   '7.10 ',
#   '1/21/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {10}JR', '', 'Texas', '7.10 ', '1/21/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {11}SOTexas7.10 AA = Performance occurred at altitude (>1000 meters above sea level) 1/25/2020',
#   '\xa0\xa0\xa0\xa0— Alfred {11}SO',
#   '',
#   'Texas',
#   '7.10 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/25/2020'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Alfred {11}SO',
#   '',
#   'Texas',
#   '7.10 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/25/2020'],
#  ['\xa0\xa0\xa0\xa0— Brisco {2}SRLSU7.10 2/25/2018',
#   '\xa0\xa0\xa0\xa0— Brisco {2}SR',
#   '',
#   'LSU',
#   '7.10 ',
#   '2/25/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Brisco {2}SR', '', 'LSU', '7.10 ', '2/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Williams {2}JRSouthern California7.10 qq = Performance occurred during a non-final round. 3/11/2001',
#   '\xa0\xa0\xa0\xa0— Williams {2}JR',
#   '',
#   'Southern California',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2001'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Williams {2}JR',
#   '',
#   'Southern California',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2001'],
#  ['\xa0\xa0\xa0\xa0— Sears {3}JRTennessee7.11 2/25/2023',
#   '\xa0\xa0\xa0\xa0— Sears {3}JR',
#   '',
#   'Tennessee',
#   '7.11 ',
#   '2/25/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Sears {3}JR', '', 'Tennessee', '7.11 ', '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Chukwuma {2}JRTexas Tech7.11 1/13/2023',
#   '\xa0\xa0\xa0\xa0— Chukwuma {2}JR',
#   '',
#   'Texas Tech',
#   '7.11 ',
#   '1/13/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Chukwuma {2}JR', '', 'Texas Tech', '7.11 ', '1/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Mays {3}FROregon7.11 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Mays {3}FR',
#   '',
#   'Oregon',
#   '7.11 ',
#   '3/12/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Mays {3}FR', '', 'Oregon', '7.11 ', '3/12/2022'],
#  ['(20) Alia ARMSTRONGSOLSU7.11 2/26/2022',
#   '(20) Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '7.11 ',
#   '2/26/2022'],
#  [],
#  ['(20) Alia ARMSTRONGSO', '', 'LSU', '7.11 ', '2/26/2022'],
#  ['(20) Kiara GRANTJRNorfolk State7.11 qq = Performance occurred during a non-final round. 3/12/2021',
#   '(20) Kiara GRANTJR',
#   '',
#   'Norfolk State',
#   '7.11 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  [],
#  ['(20) Kiara GRANTJR',
#   '',
#   'Norfolk State',
#   '7.11 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Brisco {3}SRLSU7.11 3/10/2018',
#   '\xa0\xa0\xa0\xa0— Brisco {3}SR',
#   '',
#   'LSU',
#   '7.11 ',
#   '3/10/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Brisco {3}SR', '', 'LSU', '7.11 ', '3/10/2018'],
#  ['(20) Teahna DANIELSFRTexas7.11📺 3/12/2016',
#   '(20) Teahna DANIELSFR',
#   '',
#   'Texas',
#   '7.11📺 ',
#   '3/12/2016'],
#  [],
#  ['(20) Teahna DANIELSFR', '', 'Texas', '7.11📺 ', '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Burchell {2}Alabama7.11 AA = Performance occurred at altitude (>1000 meters above sea level) 3/15/2014',
#   '\xa0\xa0\xa0\xa0— Burchell {2}',
#   '',
#   'Alabama',
#   '7.11 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Burchell {2}',
#   '',
#   'Alabama',
#   '7.11 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  ['(23) Autumn WILSONFRGeorgia7.12 3/11/2023',
#   '(23) Autumn WILSONFR',
#   '',
#   'Georgia',
#   '7.12 ',
#   '3/11/2023'],
#  [],
#  ['(23) Autumn WILSONFR', '', 'Georgia', '7.12 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}FRGeorgia7.12 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}FR',
#   '',
#   'Georgia',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}FR',
#   '',
#   'Georgia',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Sears {4}JRTennessee7.12 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Sears {4}JR',
#   '',
#   'Tennessee',
#   '7.12 ',
#   '2/10/2023'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Sears {4}JR', '', 'Tennessee', '7.12 ', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JRKentucky7.12 qq = Performance occurred during a non-final round. 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '2/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JRKentucky7.12 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {3}JR',
#   '',
#   'Kentucky',
#   '7.12 ',
#   '2/11/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JR', '', 'Kentucky', '7.12 ', '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Stark {2}SOFlorida7.12 qq = Performance occurred during a non-final round. 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Stark {2}SO',
#   '',
#   'Florida',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Stark {2}SO',
#   '',
#   'Florida',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Stark {3}SOFlorida7.12 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Stark {3}SO',
#   '',
#   'Florida',
#   '7.12 ',
#   '1/28/2022'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Stark {3}SO', '', 'Florida', '7.12 ', '1/28/2022'],
#  ['(23) Natalliah WHYTEFRAuburn7.12 3/10/2018',
#   '(23) Natalliah WHYTEFR',
#   '',
#   'Auburn',
#   '7.12 ',
#   '3/10/2018'],
#  [],
#  ['(23) Natalliah WHYTEFR', '', 'Auburn', '7.12 ', '3/10/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {2}SRLSU7.12 qq = Performance occurred during a non-final round. 3/9/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {2}SR',
#   '',
#   'LSU',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/9/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Hobbs {2}SR',
#   '',
#   'LSU',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {3}SRLSU7.12 qq = Performance occurred during a non-final round. 2/9/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {3}SR',
#   '',
#   'LSU',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '2/9/2018'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Hobbs {3}SR',
#   '',
#   'LSU',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '2/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Cunliffe {2}SOOregon7.12 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Cunliffe {2}SO',
#   '',
#   'Oregon',
#   '7.12 ',
#   '3/12/2016'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunliffe {2}SO', '', 'Oregon', '7.12 ', '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Cunliffe {3}SOOregon7.12 qq = Performance occurred during a non-final round. 3/11/2016',
#   '\xa0\xa0\xa0\xa0— Cunliffe {3}SO',
#   '',
#   'Oregon',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Cunliffe {3}SO',
#   '',
#   'Oregon',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  ['\xa0\xa0\xa0\xa0— Burchell {3}Alabama7.12 3/14/2015',
#   '\xa0\xa0\xa0\xa0— Burchell {3}',
#   '',
#   'Alabama',
#   '7.12 ',
#   '3/14/2015'],
#  [],
#  ['\xa0\xa0\xa0\xa0— Burchell {3}', '', 'Alabama', '7.12 ', '3/14/2015'],
#  ['(23) Dezerea BRYANTKentucky7.12 AA = Performance occurred at altitude (>1000 meters above sea level) 3/15/2014',
#   '(23) Dezerea BRYANT',
#   '',
#   'Kentucky',
#   '7.12 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  [],
#  ['(23) Dezerea BRYANT',
#   '',
#   'Kentucky',
#   '7.12 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  ['(23) English GARDNERFROregon7.12 3/10/2012',
#   '(23) English GARDNERFR',
#   '',
#   'Oregon',
#   '7.12 ',
#   '3/10/2012'],
#  [],
#  ['(23) English GARDNERFR', '', 'Oregon', '7.12 ', '3/10/2012'],
#  ['', '', '', '']]

# %%
len(rows)
# Out:
# 177

# %%
rows[175]
# Out:
# ['(23) English GARDNERFR', '', 'Oregon', '7.12 ', '3/10/2012']

# %%
len(rows)
# Out:
# 177

# %%
RealRows = []

# %%
for i in range(0,175):
    if len(rows[i]) > 1:
        RealRows.append(rows[i])

# %%
RealRows
# Out:
# [['(1) Julien ALFREDSRTexas6.94📺 3/11/2023',
#   '(1) Julien ALFREDSR',
#   '',
#   'Texas',
#   '6.94📺 ',
#   '3/11/2023'],
#  ['(1) Julien ALFREDSR', '', 'Texas', '6.94📺 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}SRTexas6.96📺 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {2}SR',
#   '',
#   'Texas',
#   '6.96📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}SR',
#   '',
#   'Texas',
#   '6.96📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}SRTexas6.97📺 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {3}SR',
#   '',
#   'Texas',
#   '6.97📺 ',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}SR', '', 'Texas', '6.97📺 ', '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SRTexas7.00📺 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {4}SR',
#   '',
#   'Texas',
#   '7.00📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SR',
#   '',
#   'Texas',
#   '7.00📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {5}SRTexas7.02📺 AA = Performance occurred at altitude (>1000 meters above sea level) 1/21/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {5}SR',
#   '',
#   'Texas',
#   '7.02📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {5}SR',
#   '',
#   'Texas',
#   '7.02📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {6}SRTexas7.03 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {6}SR',
#   '',
#   'Texas',
#   '7.03 ',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {6}SR', '', 'Texas', '7.03 ', '2/24/2023'],
#  ['(2) Jacious SEARSJRTennessee7.04 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(2) Jacious SEARSJR',
#   '',
#   'Tennessee',
#   '7.04 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(2) Jacious SEARSJR',
#   '',
#   'Tennessee',
#   '7.04 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {7}JRTexas7.04 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Alfred {7}JR',
#   '',
#   'Texas',
#   '7.04 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {7}JR',
#   '',
#   'Texas',
#   '7.04 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {8}SRTexas7.05 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {8}SR',
#   '',
#   'Texas',
#   '7.05 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {8}SR',
#   '',
#   'Texas',
#   '7.05 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {9}SRTexas7.05 AA = Performance occurred at altitude (>1000 meters above sea level) 1/21/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {9}SR',
#   '',
#   'Texas',
#   '7.05 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {9}SR',
#   '',
#   'Texas',
#   '7.05 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  ['(3) Kemba NELSONJROregon7.05📺 3/13/2021',
#   '(3) Kemba NELSONJR',
#   '',
#   'Oregon',
#   '7.05📺 ',
#   '3/13/2021'],
#  ['(3) Kemba NELSONJR', '', 'Oregon', '7.05📺 ', '3/13/2021'],
#  ['(4) Kaila JACKSONFRGeorgia7.07 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(4) Kaila JACKSONFR',
#   '',
#   'Georgia',
#   '7.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(4) Kaila JACKSONFR',
#   '',
#   'Georgia',
#   '7.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(4) Jadyn MAYSSOOregon7.07 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(4) Jadyn MAYSSO',
#   '',
#   'Oregon',
#   '7.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(4) Jadyn MAYSSO',
#   '',
#   'Oregon',
#   '7.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(4) Samirah MOODYSOSouthern California7.07 2/24/2023',
#   '(4) Samirah MOODYSO',
#   '',
#   'Southern California',
#   '7.07 ',
#   '2/24/2023'],
#  ['(4) Samirah MOODYSO', '', 'Southern California', '7.07 ', '2/24/2023'],
#  ['(4) Aleia HOBBSSRLSU7.07 3/10/2018',
#   '(4) Aleia HOBBSSR',
#   '',
#   'LSU',
#   '7.07 ',
#   '3/10/2018'],
#  ['(4) Aleia HOBBSSR', '', 'LSU', '7.07 ', '3/10/2018'],
#  ['(4) Hannah CUNLIFFEJROregon7.07 AA = Performance occurred at altitude (>1000 meters above sea level) 2/11/2017',
#   '(4) Hannah CUNLIFFEJR',
#   '',
#   'Oregon',
#   '7.07 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/11/2017'],
#  ['(4) Hannah CUNLIFFEJR',
#   '',
#   'Oregon',
#   '7.07 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/11/2017'],
#  ['\xa0\xa0\xa0\xa0— Jackson {2}FRGeorgia7.08 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Jackson {2}FR',
#   '',
#   'Georgia',
#   '7.08 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Jackson {2}FR', '', 'Georgia', '7.08 ', '3/11/2023'],
#  ['(9) Mikiah BRISCOSRLSU7.08 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2018',
#   '(9) Mikiah BRISCOSR',
#   '',
#   'LSU',
#   '7.08 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2018'],
#  ['(9) Mikiah BRISCOSR',
#   '',
#   'LSU',
#   '7.08 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2018'],
#  ['(9) Remona BURCHELLSRAlabama7.08 2/28/2015',
#   '(9) Remona BURCHELLSR',
#   '',
#   'Alabama',
#   '7.08 ',
#   '2/28/2015'],
#  ['(9) Remona BURCHELLSR', '', 'Alabama', '7.08 ', '2/28/2015'],
#  ['(11) Rosemary CHUKWUMAJRTexas Tech7.09 1/26/2023',
#   '(11) Rosemary CHUKWUMAJR',
#   '',
#   'Texas Tech',
#   '7.09 ',
#   '1/26/2023'],
#  ['(11) Rosemary CHUKWUMAJR', '', 'Texas Tech', '7.09 ', '1/26/2023'],
#  ['(11) Kiara GRANTSRClemson7.09 1/20/2023',
#   '(11) Kiara GRANTSR',
#   '',
#   'Clemson',
#   '7.09 ',
#   '1/20/2023'],
#  ['(11) Kiara GRANTSR', '', 'Clemson', '7.09 ', '1/20/2023'],
#  ['(11) Melissa JEFFERSONSOCoastal Carolina7.09 3/12/2022',
#   '(11) Melissa JEFFERSONSO',
#   '',
#   'Coastal Carolina',
#   '7.09 ',
#   '3/12/2022'],
#  ['(11) Melissa JEFFERSONSO', '', 'Coastal Carolina', '7.09 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Mays {2}FROregon7.09 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Mays {2}FR',
#   '',
#   'Oregon',
#   '7.09 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Mays {2}FR',
#   '',
#   'Oregon',
#   '7.09 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(11) Twanisha TERRYSRSouthern California7.09 qq = Performance occurred during a non-final round. 3/12/2021',
#   '(11) Twanisha TERRYSR',
#   '',
#   'Southern California',
#   '7.09 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ['(11) Twanisha TERRYSR',
#   '',
#   'Southern California',
#   '7.09 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ['(11) Lakya BROOKINSSRSouth Carolina7.09 3/12/2011',
#   '(11) Lakya BROOKINSSR',
#   '',
#   'South Carolina',
#   '7.09 ',
#   '3/12/2011'],
#  ['(11) Lakya BROOKINSSR', '', 'South Carolina', '7.09 ', '3/12/2011'],
#  ['(11) Angela WILLIAMSJRSouthern California7.09  3/11/2001',
#   '(11) Angela WILLIAMSJR',
#   '',
#   'Southern California',
#   '7.09  ',
#   '3/11/2001'],
#  ['(11) Angela WILLIAMSJR', '', 'Southern California', '7.09  ', '3/11/2001'],
#  ['\xa0\xa0\xa0\xa0— Sears {2}JRTennessee7.10 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Sears {2}JR',
#   '',
#   'Tennessee',
#   '7.10 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Sears {2}JR', '', 'Tennessee', '7.10 ', '3/11/2023'],
#  ['(17) McKenzie LONGSROle Miss7.10 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(17) McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(17) McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(17) Abby STEINERJRKentucky7.10 3/12/2022',
#   '(17) Abby STEINERJR',
#   '',
#   'Kentucky',
#   '7.10 ',
#   '3/12/2022'],
#  ['(17) Abby STEINERJR', '', 'Kentucky', '7.10 ', '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}SOCoastal Carolina7.10 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Jefferson {2}SO',
#   '',
#   'Coastal Carolina',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}SO',
#   '',
#   'Coastal Carolina',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(17) Grace STARKSOFlorida7.10 qq = Performance occurred during a non-final round. 3/11/2022',
#   '(17) Grace STARKSO',
#   '',
#   'Florida',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(17) Grace STARKSO',
#   '',
#   'Florida',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {10}JRTexas7.10 1/21/2022',
#   '\xa0\xa0\xa0\xa0— Alfred {10}JR',
#   '',
#   'Texas',
#   '7.10 ',
#   '1/21/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {10}JR', '', 'Texas', '7.10 ', '1/21/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {11}SOTexas7.10 AA = Performance occurred at altitude (>1000 meters above sea level) 1/25/2020',
#   '\xa0\xa0\xa0\xa0— Alfred {11}SO',
#   '',
#   'Texas',
#   '7.10 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/25/2020'],
#  ['\xa0\xa0\xa0\xa0— Alfred {11}SO',
#   '',
#   'Texas',
#   '7.10 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/25/2020'],
#  ['\xa0\xa0\xa0\xa0— Brisco {2}SRLSU7.10 2/25/2018',
#   '\xa0\xa0\xa0\xa0— Brisco {2}SR',
#   '',
#   'LSU',
#   '7.10 ',
#   '2/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Brisco {2}SR', '', 'LSU', '7.10 ', '2/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Williams {2}JRSouthern California7.10 qq = Performance occurred during a non-final round. 3/11/2001',
#   '\xa0\xa0\xa0\xa0— Williams {2}JR',
#   '',
#   'Southern California',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2001'],
#  ['\xa0\xa0\xa0\xa0— Williams {2}JR',
#   '',
#   'Southern California',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2001'],
#  ['\xa0\xa0\xa0\xa0— Sears {3}JRTennessee7.11 2/25/2023',
#   '\xa0\xa0\xa0\xa0— Sears {3}JR',
#   '',
#   'Tennessee',
#   '7.11 ',
#   '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Sears {3}JR', '', 'Tennessee', '7.11 ', '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Chukwuma {2}JRTexas Tech7.11 1/13/2023',
#   '\xa0\xa0\xa0\xa0— Chukwuma {2}JR',
#   '',
#   'Texas Tech',
#   '7.11 ',
#   '1/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Chukwuma {2}JR', '', 'Texas Tech', '7.11 ', '1/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Mays {3}FROregon7.11 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Mays {3}FR',
#   '',
#   'Oregon',
#   '7.11 ',
#   '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Mays {3}FR', '', 'Oregon', '7.11 ', '3/12/2022'],
#  ['(20) Alia ARMSTRONGSOLSU7.11 2/26/2022',
#   '(20) Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '7.11 ',
#   '2/26/2022'],
#  ['(20) Alia ARMSTRONGSO', '', 'LSU', '7.11 ', '2/26/2022'],
#  ['(20) Kiara GRANTJRNorfolk State7.11 qq = Performance occurred during a non-final round. 3/12/2021',
#   '(20) Kiara GRANTJR',
#   '',
#   'Norfolk State',
#   '7.11 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ['(20) Kiara GRANTJR',
#   '',
#   'Norfolk State',
#   '7.11 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Brisco {3}SRLSU7.11 3/10/2018',
#   '\xa0\xa0\xa0\xa0— Brisco {3}SR',
#   '',
#   'LSU',
#   '7.11 ',
#   '3/10/2018'],
#  ['\xa0\xa0\xa0\xa0— Brisco {3}SR', '', 'LSU', '7.11 ', '3/10/2018'],
#  ['(20) Teahna DANIELSFRTexas7.11📺 3/12/2016',
#   '(20) Teahna DANIELSFR',
#   '',
#   'Texas',
#   '7.11📺 ',
#   '3/12/2016'],
#  ['(20) Teahna DANIELSFR', '', 'Texas', '7.11📺 ', '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Burchell {2}Alabama7.11 AA = Performance occurred at altitude (>1000 meters above sea level) 3/15/2014',
#   '\xa0\xa0\xa0\xa0— Burchell {2}',
#   '',
#   'Alabama',
#   '7.11 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  ['\xa0\xa0\xa0\xa0— Burchell {2}',
#   '',
#   'Alabama',
#   '7.11 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  ['(23) Autumn WILSONFRGeorgia7.12 3/11/2023',
#   '(23) Autumn WILSONFR',
#   '',
#   'Georgia',
#   '7.12 ',
#   '3/11/2023'],
#  ['(23) Autumn WILSONFR', '', 'Georgia', '7.12 ', '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}FRGeorgia7.12 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}FR',
#   '',
#   'Georgia',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}FR',
#   '',
#   'Georgia',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Sears {4}JRTennessee7.12 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Sears {4}JR',
#   '',
#   'Tennessee',
#   '7.12 ',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Sears {4}JR', '', 'Tennessee', '7.12 ', '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JRKentucky7.12 qq = Performance occurred during a non-final round. 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JRKentucky7.12 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {3}JR',
#   '',
#   'Kentucky',
#   '7.12 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JR', '', 'Kentucky', '7.12 ', '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Stark {2}SOFlorida7.12 qq = Performance occurred during a non-final round. 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Stark {2}SO',
#   '',
#   'Florida',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Stark {2}SO',
#   '',
#   'Florida',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Stark {3}SOFlorida7.12 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Stark {3}SO',
#   '',
#   'Florida',
#   '7.12 ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Stark {3}SO', '', 'Florida', '7.12 ', '1/28/2022'],
#  ['(23) Natalliah WHYTEFRAuburn7.12 3/10/2018',
#   '(23) Natalliah WHYTEFR',
#   '',
#   'Auburn',
#   '7.12 ',
#   '3/10/2018'],
#  ['(23) Natalliah WHYTEFR', '', 'Auburn', '7.12 ', '3/10/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {2}SRLSU7.12 qq = Performance occurred during a non-final round. 3/9/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {2}SR',
#   '',
#   'LSU',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {2}SR',
#   '',
#   'LSU',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {3}SRLSU7.12 qq = Performance occurred during a non-final round. 2/9/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {3}SR',
#   '',
#   'LSU',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '2/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {3}SR',
#   '',
#   'LSU',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '2/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Cunliffe {2}SOOregon7.12 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Cunliffe {2}SO',
#   '',
#   'Oregon',
#   '7.12 ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Cunliffe {2}SO', '', 'Oregon', '7.12 ', '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Cunliffe {3}SOOregon7.12 qq = Performance occurred during a non-final round. 3/11/2016',
#   '\xa0\xa0\xa0\xa0— Cunliffe {3}SO',
#   '',
#   'Oregon',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  ['\xa0\xa0\xa0\xa0— Cunliffe {3}SO',
#   '',
#   'Oregon',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  ['\xa0\xa0\xa0\xa0— Burchell {3}Alabama7.12 3/14/2015',
#   '\xa0\xa0\xa0\xa0— Burchell {3}',
#   '',
#   'Alabama',
#   '7.12 ',
#   '3/14/2015'],
#  ['\xa0\xa0\xa0\xa0— Burchell {3}', '', 'Alabama', '7.12 ', '3/14/2015'],
#  ['(23) Dezerea BRYANTKentucky7.12 AA = Performance occurred at altitude (>1000 meters above sea level) 3/15/2014',
#   '(23) Dezerea BRYANT',
#   '',
#   'Kentucky',
#   '7.12 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  ['(23) Dezerea BRYANT',
#   '',
#   'Kentucky',
#   '7.12 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  ['(23) English GARDNERFROregon7.12 3/10/2012',
#   '(23) English GARDNERFR',
#   '',
#   'Oregon',
#   '7.12 ',
#   '3/10/2012']]

# %%
RealRealRows = RealRows[::2]
RealRealRows
# Out:
# [['(1) Julien ALFREDSRTexas6.94📺 3/11/2023',
#   '(1) Julien ALFREDSR',
#   '',
#   'Texas',
#   '6.94📺 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {2}SRTexas6.96📺 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {2}SR',
#   '',
#   'Texas',
#   '6.96📺 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {3}SRTexas6.97📺 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {3}SR',
#   '',
#   'Texas',
#   '6.97📺 ',
#   '2/24/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {4}SRTexas7.00📺 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {4}SR',
#   '',
#   'Texas',
#   '7.00📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {5}SRTexas7.02📺 AA = Performance occurred at altitude (>1000 meters above sea level) 1/21/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {5}SR',
#   '',
#   'Texas',
#   '7.02📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {6}SRTexas7.03 2/24/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {6}SR',
#   '',
#   'Texas',
#   '7.03 ',
#   '2/24/2023'],
#  ['(2) Jacious SEARSJRTennessee7.04 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(2) Jacious SEARSJR',
#   '',
#   'Tennessee',
#   '7.04 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {7}JRTexas7.04 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Alfred {7}JR',
#   '',
#   'Texas',
#   '7.04 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {8}SRTexas7.05 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {8}SR',
#   '',
#   'Texas',
#   '7.05 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2023'],
#  ['\xa0\xa0\xa0\xa0— Alfred {9}SRTexas7.05 AA = Performance occurred at altitude (>1000 meters above sea level) 1/21/2023',
#   '\xa0\xa0\xa0\xa0— Alfred {9}SR',
#   '',
#   'Texas',
#   '7.05 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/21/2023'],
#  ['(3) Kemba NELSONJROregon7.05📺 3/13/2021',
#   '(3) Kemba NELSONJR',
#   '',
#   'Oregon',
#   '7.05📺 ',
#   '3/13/2021'],
#  ['(4) Kaila JACKSONFRGeorgia7.07 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(4) Kaila JACKSONFR',
#   '',
#   'Georgia',
#   '7.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(4) Jadyn MAYSSOOregon7.07 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(4) Jadyn MAYSSO',
#   '',
#   'Oregon',
#   '7.07 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(4) Samirah MOODYSOSouthern California7.07 2/24/2023',
#   '(4) Samirah MOODYSO',
#   '',
#   'Southern California',
#   '7.07 ',
#   '2/24/2023'],
#  ['(4) Aleia HOBBSSRLSU7.07 3/10/2018',
#   '(4) Aleia HOBBSSR',
#   '',
#   'LSU',
#   '7.07 ',
#   '3/10/2018'],
#  ['(4) Hannah CUNLIFFEJROregon7.07 AA = Performance occurred at altitude (>1000 meters above sea level) 2/11/2017',
#   '(4) Hannah CUNLIFFEJR',
#   '',
#   'Oregon',
#   '7.07 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/11/2017'],
#  ['\xa0\xa0\xa0\xa0— Jackson {2}FRGeorgia7.08 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Jackson {2}FR',
#   '',
#   'Georgia',
#   '7.08 ',
#   '3/11/2023'],
#  ['(9) Mikiah BRISCOSRLSU7.08 AA = Performance occurred at altitude (>1000 meters above sea level) 2/3/2018',
#   '(9) Mikiah BRISCOSR',
#   '',
#   'LSU',
#   '7.08 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '2/3/2018'],
#  ['(9) Remona BURCHELLSRAlabama7.08 2/28/2015',
#   '(9) Remona BURCHELLSR',
#   '',
#   'Alabama',
#   '7.08 ',
#   '2/28/2015'],
#  ['(11) Rosemary CHUKWUMAJRTexas Tech7.09 1/26/2023',
#   '(11) Rosemary CHUKWUMAJR',
#   '',
#   'Texas Tech',
#   '7.09 ',
#   '1/26/2023'],
#  ['(11) Kiara GRANTSRClemson7.09 1/20/2023',
#   '(11) Kiara GRANTSR',
#   '',
#   'Clemson',
#   '7.09 ',
#   '1/20/2023'],
#  ['(11) Melissa JEFFERSONSOCoastal Carolina7.09 3/12/2022',
#   '(11) Melissa JEFFERSONSO',
#   '',
#   'Coastal Carolina',
#   '7.09 ',
#   '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Mays {2}FROregon7.09 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Mays {2}FR',
#   '',
#   'Oregon',
#   '7.09 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(11) Twanisha TERRYSRSouthern California7.09 qq = Performance occurred during a non-final round. 3/12/2021',
#   '(11) Twanisha TERRYSR',
#   '',
#   'Southern California',
#   '7.09 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ['(11) Lakya BROOKINSSRSouth Carolina7.09 3/12/2011',
#   '(11) Lakya BROOKINSSR',
#   '',
#   'South Carolina',
#   '7.09 ',
#   '3/12/2011'],
#  ['(11) Angela WILLIAMSJRSouthern California7.09  3/11/2001',
#   '(11) Angela WILLIAMSJR',
#   '',
#   'Southern California',
#   '7.09  ',
#   '3/11/2001'],
#  ['\xa0\xa0\xa0\xa0— Sears {2}JRTennessee7.10 3/11/2023',
#   '\xa0\xa0\xa0\xa0— Sears {2}JR',
#   '',
#   'Tennessee',
#   '7.10 ',
#   '3/11/2023'],
#  ['(17) McKenzie LONGSROle Miss7.10 qq = Performance occurred during a non-final round. 3/10/2023',
#   '(17) McKenzie LONGSR',
#   '',
#   'Ole Miss',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['(17) Abby STEINERJRKentucky7.10 3/12/2022',
#   '(17) Abby STEINERJR',
#   '',
#   'Kentucky',
#   '7.10 ',
#   '3/12/2022'],
#  ['\xa0\xa0\xa0\xa0— Jefferson {2}SOCoastal Carolina7.10 qq = Performance occurred during a non-final round. 3/11/2022',
#   '\xa0\xa0\xa0\xa0— Jefferson {2}SO',
#   '',
#   'Coastal Carolina',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['(17) Grace STARKSOFlorida7.10 qq = Performance occurred during a non-final round. 3/11/2022',
#   '(17) Grace STARKSO',
#   '',
#   'Florida',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {10}JRTexas7.10 1/21/2022',
#   '\xa0\xa0\xa0\xa0— Alfred {10}JR',
#   '',
#   'Texas',
#   '7.10 ',
#   '1/21/2022'],
#  ['\xa0\xa0\xa0\xa0— Alfred {11}SOTexas7.10 AA = Performance occurred at altitude (>1000 meters above sea level) 1/25/2020',
#   '\xa0\xa0\xa0\xa0— Alfred {11}SO',
#   '',
#   'Texas',
#   '7.10 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '1/25/2020'],
#  ['\xa0\xa0\xa0\xa0— Brisco {2}SRLSU7.10 2/25/2018',
#   '\xa0\xa0\xa0\xa0— Brisco {2}SR',
#   '',
#   'LSU',
#   '7.10 ',
#   '2/25/2018'],
#  ['\xa0\xa0\xa0\xa0— Williams {2}JRSouthern California7.10 qq = Performance occurred during a non-final round. 3/11/2001',
#   '\xa0\xa0\xa0\xa0— Williams {2}JR',
#   '',
#   'Southern California',
#   '7.10 qq = Performance occurred during a non-final round. ',
#   '3/11/2001'],
#  ['\xa0\xa0\xa0\xa0— Sears {3}JRTennessee7.11 2/25/2023',
#   '\xa0\xa0\xa0\xa0— Sears {3}JR',
#   '',
#   'Tennessee',
#   '7.11 ',
#   '2/25/2023'],
#  ['\xa0\xa0\xa0\xa0— Chukwuma {2}JRTexas Tech7.11 1/13/2023',
#   '\xa0\xa0\xa0\xa0— Chukwuma {2}JR',
#   '',
#   'Texas Tech',
#   '7.11 ',
#   '1/13/2023'],
#  ['\xa0\xa0\xa0\xa0— Mays {3}FROregon7.11 3/12/2022',
#   '\xa0\xa0\xa0\xa0— Mays {3}FR',
#   '',
#   'Oregon',
#   '7.11 ',
#   '3/12/2022'],
#  ['(20) Alia ARMSTRONGSOLSU7.11 2/26/2022',
#   '(20) Alia ARMSTRONGSO',
#   '',
#   'LSU',
#   '7.11 ',
#   '2/26/2022'],
#  ['(20) Kiara GRANTJRNorfolk State7.11 qq = Performance occurred during a non-final round. 3/12/2021',
#   '(20) Kiara GRANTJR',
#   '',
#   'Norfolk State',
#   '7.11 qq = Performance occurred during a non-final round. ',
#   '3/12/2021'],
#  ['\xa0\xa0\xa0\xa0— Brisco {3}SRLSU7.11 3/10/2018',
#   '\xa0\xa0\xa0\xa0— Brisco {3}SR',
#   '',
#   'LSU',
#   '7.11 ',
#   '3/10/2018'],
#  ['(20) Teahna DANIELSFRTexas7.11📺 3/12/2016',
#   '(20) Teahna DANIELSFR',
#   '',
#   'Texas',
#   '7.11📺 ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Burchell {2}Alabama7.11 AA = Performance occurred at altitude (>1000 meters above sea level) 3/15/2014',
#   '\xa0\xa0\xa0\xa0— Burchell {2}',
#   '',
#   'Alabama',
#   '7.11 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  ['(23) Autumn WILSONFRGeorgia7.12 3/11/2023',
#   '(23) Autumn WILSONFR',
#   '',
#   'Georgia',
#   '7.12 ',
#   '3/11/2023'],
#  ['\xa0\xa0\xa0\xa0— Wilson {2}FRGeorgia7.12 qq = Performance occurred during a non-final round. 3/10/2023',
#   '\xa0\xa0\xa0\xa0— Wilson {2}FR',
#   '',
#   'Georgia',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Sears {4}JRTennessee7.12 2/10/2023',
#   '\xa0\xa0\xa0\xa0— Sears {4}JR',
#   '',
#   'Tennessee',
#   '7.12 ',
#   '2/10/2023'],
#  ['\xa0\xa0\xa0\xa0— Steiner {2}JRKentucky7.12 qq = Performance occurred during a non-final round. 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#   '',
#   'Kentucky',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Steiner {3}JRKentucky7.12 2/11/2022',
#   '\xa0\xa0\xa0\xa0— Steiner {3}JR',
#   '',
#   'Kentucky',
#   '7.12 ',
#   '2/11/2022'],
#  ['\xa0\xa0\xa0\xa0— Stark {2}SOFlorida7.12 qq = Performance occurred during a non-final round. 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Stark {2}SO',
#   '',
#   'Florida',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '1/28/2022'],
#  ['\xa0\xa0\xa0\xa0— Stark {3}SOFlorida7.12 1/28/2022',
#   '\xa0\xa0\xa0\xa0— Stark {3}SO',
#   '',
#   'Florida',
#   '7.12 ',
#   '1/28/2022'],
#  ['(23) Natalliah WHYTEFRAuburn7.12 3/10/2018',
#   '(23) Natalliah WHYTEFR',
#   '',
#   'Auburn',
#   '7.12 ',
#   '3/10/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {2}SRLSU7.12 qq = Performance occurred during a non-final round. 3/9/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {2}SR',
#   '',
#   'LSU',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Hobbs {3}SRLSU7.12 qq = Performance occurred during a non-final round. 2/9/2018',
#   '\xa0\xa0\xa0\xa0— Hobbs {3}SR',
#   '',
#   'LSU',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '2/9/2018'],
#  ['\xa0\xa0\xa0\xa0— Cunliffe {2}SOOregon7.12 3/12/2016',
#   '\xa0\xa0\xa0\xa0— Cunliffe {2}SO',
#   '',
#   'Oregon',
#   '7.12 ',
#   '3/12/2016'],
#  ['\xa0\xa0\xa0\xa0— Cunliffe {3}SOOregon7.12 qq = Performance occurred during a non-final round. 3/11/2016',
#   '\xa0\xa0\xa0\xa0— Cunliffe {3}SO',
#   '',
#   'Oregon',
#   '7.12 qq = Performance occurred during a non-final round. ',
#   '3/11/2016'],
#  ['\xa0\xa0\xa0\xa0— Burchell {3}Alabama7.12 3/14/2015',
#   '\xa0\xa0\xa0\xa0— Burchell {3}',
#   '',
#   'Alabama',
#   '7.12 ',
#   '3/14/2015'],
#  ['(23) Dezerea BRYANTKentucky7.12 AA = Performance occurred at altitude (>1000 meters above sea level) 3/15/2014',
#   '(23) Dezerea BRYANT',
#   '',
#   'Kentucky',
#   '7.12 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#   '3/15/2014'],
#  ['(23) English GARDNERFROregon7.12 3/10/2012',
#   '(23) English GARDNERFR',
#   '',
#   'Oregon',
#   '7.12 ',
#   '3/10/2012']]

# %%
RealRealRows[1][4]
# Out:
# '6.96📺 qq = Performance occurred during a non-final round. '

# %%
len(RealRealRows)
# Out:
# 58

# %%
OfficialTimes = []

# %%
for i in range(0,58):
    OfficialTimes.append(RealRealRows[i][4])
OfficialTimes
# Out:
# ['6.94📺 ',
#  '6.96📺 qq = Performance occurred during a non-final round. ',
#  '6.97📺 ',
#  '7.00📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '7.02📺 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '7.03 ',
#  '7.04 qq = Performance occurred during a non-final round. ',
#  '7.04 qq = Performance occurred during a non-final round. ',
#  '7.05 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '7.05 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '7.05📺 ',
#  '7.07 qq = Performance occurred during a non-final round. ',
#  '7.07 qq = Performance occurred during a non-final round. ',
#  '7.07 ',
#  '7.07 ',
#  '7.07 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '7.08 ',
#  '7.08 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '7.08 ',
#  '7.09 ',
#  '7.09 ',
#  '7.09 ',
#  '7.09 qq = Performance occurred during a non-final round. ',
#  '7.09 qq = Performance occurred during a non-final round. ',
#  '7.09 ',
#  '7.09  ',
#  '7.10 ',
#  '7.10 qq = Performance occurred during a non-final round. ',
#  '7.10 ',
#  '7.10 qq = Performance occurred during a non-final round. ',
#  '7.10 qq = Performance occurred during a non-final round. ',
#  '7.10 ',
#  '7.10 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '7.10 ',
#  '7.10 qq = Performance occurred during a non-final round. ',
#  '7.11 ',
#  '7.11 ',
#  '7.11 ',
#  '7.11 ',
#  '7.11 qq = Performance occurred during a non-final round. ',
#  '7.11 ',
#  '7.11📺 ',
#  '7.11 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '7.12 ',
#  '7.12 qq = Performance occurred during a non-final round. ',
#  '7.12 ',
#  '7.12 qq = Performance occurred during a non-final round. ',
#  '7.12 ',
#  '7.12 qq = Performance occurred during a non-final round. ',
#  '7.12 ',
#  '7.12 ',
#  '7.12 qq = Performance occurred during a non-final round. ',
#  '7.12 qq = Performance occurred during a non-final round. ',
#  '7.12 ',
#  '7.12 qq = Performance occurred during a non-final round. ',
#  '7.12 ',
#  '7.12 AA = Performance occurred at altitude (>1000 meters above sea level) ',
#  '7.12 ']

# %%
RealRealRows[0][1]
# Out:
# '(1) Julien ALFREDSR'

# %%
Names = []

for i in range(0,58):
    Names.append(RealRealRows[i][1])
Names
# Out:
# ['(1) Julien ALFREDSR',
#  '\xa0\xa0\xa0\xa0— Alfred {2}SR',
#  '\xa0\xa0\xa0\xa0— Alfred {3}SR',
#  '\xa0\xa0\xa0\xa0— Alfred {4}SR',
#  '\xa0\xa0\xa0\xa0— Alfred {5}SR',
#  '\xa0\xa0\xa0\xa0— Alfred {6}SR',
#  '(2) Jacious SEARSJR',
#  '\xa0\xa0\xa0\xa0— Alfred {7}JR',
#  '\xa0\xa0\xa0\xa0— Alfred {8}SR',
#  '\xa0\xa0\xa0\xa0— Alfred {9}SR',
#  '(3) Kemba NELSONJR',
#  '(4) Kaila JACKSONFR',
#  '(4) Jadyn MAYSSO',
#  '(4) Samirah MOODYSO',
#  '(4) Aleia HOBBSSR',
#  '(4) Hannah CUNLIFFEJR',
#  '\xa0\xa0\xa0\xa0— Jackson {2}FR',
#  '(9) Mikiah BRISCOSR',
#  '(9) Remona BURCHELLSR',
#  '(11) Rosemary CHUKWUMAJR',
#  '(11) Kiara GRANTSR',
#  '(11) Melissa JEFFERSONSO',
#  '\xa0\xa0\xa0\xa0— Mays {2}FR',
#  '(11) Twanisha TERRYSR',
#  '(11) Lakya BROOKINSSR',
#  '(11) Angela WILLIAMSJR',
#  '\xa0\xa0\xa0\xa0— Sears {2}JR',
#  '(17) McKenzie LONGSR',
#  '(17) Abby STEINERJR',
#  '\xa0\xa0\xa0\xa0— Jefferson {2}SO',
#  '(17) Grace STARKSO',
#  '\xa0\xa0\xa0\xa0— Alfred {10}JR',
#  '\xa0\xa0\xa0\xa0— Alfred {11}SO',
#  '\xa0\xa0\xa0\xa0— Brisco {2}SR',
#  '\xa0\xa0\xa0\xa0— Williams {2}JR',
#  '\xa0\xa0\xa0\xa0— Sears {3}JR',
#  '\xa0\xa0\xa0\xa0— Chukwuma {2}JR',
#  '\xa0\xa0\xa0\xa0— Mays {3}FR',
#  '(20) Alia ARMSTRONGSO',
#  '(20) Kiara GRANTJR',
#  '\xa0\xa0\xa0\xa0— Brisco {3}SR',
#  '(20) Teahna DANIELSFR',
#  '\xa0\xa0\xa0\xa0— Burchell {2}',
#  '(23) Autumn WILSONFR',
#  '\xa0\xa0\xa0\xa0— Wilson {2}FR',
#  '\xa0\xa0\xa0\xa0— Sears {4}JR',
#  '\xa0\xa0\xa0\xa0— Steiner {2}JR',
#  '\xa0\xa0\xa0\xa0— Steiner {3}JR',
#  '\xa0\xa0\xa0\xa0— Stark {2}SO',
#  '\xa0\xa0\xa0\xa0— Stark {3}SO',
#  '(23) Natalliah WHYTEFR',
#  '\xa0\xa0\xa0\xa0— Hobbs {2}SR',
#  '\xa0\xa0\xa0\xa0— Hobbs {3}SR',
#  '\xa0\xa0\xa0\xa0— Cunliffe {2}SO',
#  '\xa0\xa0\xa0\xa0— Cunliffe {3}SO',
#  '\xa0\xa0\xa0\xa0— Burchell {3}',
#  '(23) Dezerea BRYANT',
#  '(23) English GARDNERFR']

# %%
OfficialReGexNames = []

# %%
for i in range(0,58):
    if Names[i].startswith("\xa0\xa0"):
        OfficialReGexNames.append(Names[i][4:])
    else:
        OfficialReGexNames.append(Names[i])
        
OfficialReGexNames
# Out:
# ['(1) Julien ALFREDSR',
#  '— Alfred {2}SR',
#  '— Alfred {3}SR',
#  '— Alfred {4}SR',
#  '— Alfred {5}SR',
#  '— Alfred {6}SR',
#  '(2) Jacious SEARSJR',
#  '— Alfred {7}JR',
#  '— Alfred {8}SR',
#  '— Alfred {9}SR',
#  '(3) Kemba NELSONJR',
#  '(4) Kaila JACKSONFR',
#  '(4) Jadyn MAYSSO',
#  '(4) Samirah MOODYSO',
#  '(4) Aleia HOBBSSR',
#  '(4) Hannah CUNLIFFEJR',
#  '— Jackson {2}FR',
#  '(9) Mikiah BRISCOSR',
#  '(9) Remona BURCHELLSR',
#  '(11) Rosemary CHUKWUMAJR',
#  '(11) Kiara GRANTSR',
#  '(11) Melissa JEFFERSONSO',
#  '— Mays {2}FR',
#  '(11) Twanisha TERRYSR',
#  '(11) Lakya BROOKINSSR',
#  '(11) Angela WILLIAMSJR',
#  '— Sears {2}JR',
#  '(17) McKenzie LONGSR',
#  '(17) Abby STEINERJR',
#  '— Jefferson {2}SO',
#  '(17) Grace STARKSO',
#  '— Alfred {10}JR',
#  '— Alfred {11}SO',
#  '— Brisco {2}SR',
#  '— Williams {2}JR',
#  '— Sears {3}JR',
#  '— Chukwuma {2}JR',
#  '— Mays {3}FR',
#  '(20) Alia ARMSTRONGSO',
#  '(20) Kiara GRANTJR',
#  '— Brisco {3}SR',
#  '(20) Teahna DANIELSFR',
#  '— Burchell {2}',
#  '(23) Autumn WILSONFR',
#  '— Wilson {2}FR',
#  '— Sears {4}JR',
#  '— Steiner {2}JR',
#  '— Steiner {3}JR',
#  '— Stark {2}SO',
#  '— Stark {3}SO',
#  '(23) Natalliah WHYTEFR',
#  '— Hobbs {2}SR',
#  '— Hobbs {3}SR',
#  '— Cunliffe {2}SO',
#  '— Cunliffe {3}SO',
#  '— Burchell {3}',
#  '(23) Dezerea BRYANT',
#  '(23) English GARDNERFR']

# %%
CleanedNames = []

for i in range(0,len(RealRealRows)):
    if OfficialReGexNames[i].startswith("—"):
        CleanedNames.append(OfficialReGexNames[i][2:])
    if OfficialReGexNames[i].startswith("("):
        CleanedNames.append(OfficialReGexNames[i][4:])        
CleanedNames
# Out:
# ['Julien ALFREDSR',
#  'Alfred {2}SR',
#  'Alfred {3}SR',
#  'Alfred {4}SR',
#  'Alfred {5}SR',
#  'Alfred {6}SR',
#  'Jacious SEARSJR',
#  'Alfred {7}JR',
#  'Alfred {8}SR',
#  'Alfred {9}SR',
#  'Kemba NELSONJR',
#  'Kaila JACKSONFR',
#  'Jadyn MAYSSO',
#  'Samirah MOODYSO',
#  'Aleia HOBBSSR',
#  'Hannah CUNLIFFEJR',
#  'Jackson {2}FR',
#  'Mikiah BRISCOSR',
#  'Remona BURCHELLSR',
#  ' Rosemary CHUKWUMAJR',
#  ' Kiara GRANTSR',
#  ' Melissa JEFFERSONSO',
#  'Mays {2}FR',
#  ' Twanisha TERRYSR',
#  ' Lakya BROOKINSSR',
#  ' Angela WILLIAMSJR',
#  'Sears {2}JR',
#  ' McKenzie LONGSR',
#  ' Abby STEINERJR',
#  'Jefferson {2}SO',
#  ' Grace STARKSO',
#  'Alfred {10}JR',
#  'Alfred {11}SO',
#  'Brisco {2}SR',
#  'Williams {2}JR',
#  'Sears {3}JR',
#  'Chukwuma {2}JR',
#  'Mays {3}FR',
#  ' Alia ARMSTRONGSO',
#  ' Kiara GRANTJR',
#  'Brisco {3}SR',
#  ' Teahna DANIELSFR',
#  'Burchell {2}',
#  ' Autumn WILSONFR',
#  'Wilson {2}FR',
#  'Sears {4}JR',
#  'Steiner {2}JR',
#  'Steiner {3}JR',
#  'Stark {2}SO',
#  'Stark {3}SO',
#  ' Natalliah WHYTEFR',
#  'Hobbs {2}SR',
#  'Hobbs {3}SR',
#  'Cunliffe {2}SO',
#  'Cunliffe {3}SO',
#  'Burchell {3}',
#  ' Dezerea BRYANT',
#  ' English GARDNERFR']

# %%
CleanedNames2 = []

for i in range(0,len(RealRealRows)):
    if CleanedNames[i].startswith(" "):
        CleanedNames2.append(CleanedNames[i][1:])
    else:
        CleanedNames2.append(CleanedNames[i])        
CleanedNames2
# Out:
# ['Julien ALFREDSR',
#  'Alfred {2}SR',
#  'Alfred {3}SR',
#  'Alfred {4}SR',
#  'Alfred {5}SR',
#  'Alfred {6}SR',
#  'Jacious SEARSJR',
#  'Alfred {7}JR',
#  'Alfred {8}SR',
#  'Alfred {9}SR',
#  'Kemba NELSONJR',
#  'Kaila JACKSONFR',
#  'Jadyn MAYSSO',
#  'Samirah MOODYSO',
#  'Aleia HOBBSSR',
#  'Hannah CUNLIFFEJR',
#  'Jackson {2}FR',
#  'Mikiah BRISCOSR',
#  'Remona BURCHELLSR',
#  'Rosemary CHUKWUMAJR',
#  'Kiara GRANTSR',
#  'Melissa JEFFERSONSO',
#  'Mays {2}FR',
#  'Twanisha TERRYSR',
#  'Lakya BROOKINSSR',
#  'Angela WILLIAMSJR',
#  'Sears {2}JR',
#  'McKenzie LONGSR',
#  'Abby STEINERJR',
#  'Jefferson {2}SO',
#  'Grace STARKSO',
#  'Alfred {10}JR',
#  'Alfred {11}SO',
#  'Brisco {2}SR',
#  'Williams {2}JR',
#  'Sears {3}JR',
#  'Chukwuma {2}JR',
#  'Mays {3}FR',
#  'Alia ARMSTRONGSO',
#  'Kiara GRANTJR',
#  'Brisco {3}SR',
#  'Teahna DANIELSFR',
#  'Burchell {2}',
#  'Autumn WILSONFR',
#  'Wilson {2}FR',
#  'Sears {4}JR',
#  'Steiner {2}JR',
#  'Steiner {3}JR',
#  'Stark {2}SO',
#  'Stark {3}SO',
#  'Natalliah WHYTEFR',
#  'Hobbs {2}SR',
#  'Hobbs {3}SR',
#  'Cunliffe {2}SO',
#  'Cunliffe {3}SO',
#  'Burchell {3}',
#  'Dezerea BRYANT',
#  'English GARDNERFR']

# %%
len(OfficialTimes)
# Out:
# 58

# %%
len(OfficialReGexNames)
# Out:
# 58

# %%
Schools = []

for i in range(0,len(OfficialTimes)):
    Schools.append(RealRealRows[i][3])
Schools
# Out:
# ['Texas',
#  'Texas',
#  'Texas',
#  'Texas',
#  'Texas',
#  'Texas',
#  'Tennessee',
#  'Texas',
#  'Texas',
#  'Texas',
#  'Oregon',
#  'Georgia',
#  'Oregon',
#  'Southern California',
#  'LSU',
#  'Oregon',
#  'Georgia',
#  'LSU',
#  'Alabama',
#  'Texas Tech',
#  'Clemson',
#  'Coastal Carolina',
#  'Oregon',
#  'Southern California',
#  'South Carolina',
#  'Southern California',
#  'Tennessee',
#  'Ole Miss',
#  'Kentucky',
#  'Coastal Carolina',
#  'Florida',
#  'Texas',
#  'Texas',
#  'LSU',
#  'Southern California',
#  'Tennessee',
#  'Texas Tech',
#  'Oregon',
#  'LSU',
#  'Norfolk State',
#  'LSU',
#  'Texas',
#  'Alabama',
#  'Georgia',
#  'Georgia',
#  'Tennessee',
#  'Kentucky',
#  'Kentucky',
#  'Florida',
#  'Florida',
#  'Auburn',
#  'LSU',
#  'LSU',
#  'Oregon',
#  'Oregon',
#  'Alabama',
#  'Kentucky',
#  'Oregon']

# %%
Times = []
for i in range(0,len(OfficialTimes)):
    Times.append(OfficialTimes[i][:4])
    
Times
# Out:
# ['6.94',
#  '6.96',
#  '6.97',
#  '7.00',
#  '7.02',
#  '7.03',
#  '7.04',
#  '7.04',
#  '7.05',
#  '7.05',
#  '7.05',
#  '7.07',
#  '7.07',
#  '7.07',
#  '7.07',
#  '7.07',
#  '7.08',
#  '7.08',
#  '7.08',
#  '7.09',
#  '7.09',
#  '7.09',
#  '7.09',
#  '7.09',
#  '7.09',
#  '7.09',
#  '7.10',
#  '7.10',
#  '7.10',
#  '7.10',
#  '7.10',
#  '7.10',
#  '7.10',
#  '7.10',
#  '7.10',
#  '7.11',
#  '7.11',
#  '7.11',
#  '7.11',
#  '7.11',
#  '7.11',
#  '7.11',
#  '7.11',
#  '7.12',
#  '7.12',
#  '7.12',
#  '7.12',
#  '7.12',
#  '7.12',
#  '7.12',
#  '7.12',
#  '7.12',
#  '7.12',
#  '7.12',
#  '7.12',
#  '7.12',
#  '7.12',
#  '7.12']

# %%
Womens60mDF = pd.DataFrame({'Names': CleanedNames2, 'Times': Times, 'Schools': Schools})
Womens60mDF.to_csv('Womens60m.csv', index=False)
